# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_030cc3d279dfeef29fdb10ad4312c0d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_030cc3d279dfeef29fdb10ad4312c0d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_030cc3d279dfeef29fdb10ad4312c0d5 = L.map(
#                 &quot;map_030cc3d279dfeef29fdb10ad4312c0d5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e51616c070f1448edea28d05a6ba9433 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e51616c070f1448edea28d05a6ba9433.addTo(map_030cc3d279dfeef29fdb10ad4312c0d5);
#
#
#             var marker_f5d8f03db924085397ffdbfd3a44baff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_030cc3d279dfeef29fdb10ad4312c0d5);
#
#
#         var popup_8565ba91401c5468abe8c7f461af387a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a028074a854a472d50dcbd90c29c35d5 = $(`&lt;div id=&quot;html_a028074a854a472d50dcbd90c29c35d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8565ba91401c5468abe8c7f461af387a.setContent(html_a028074a854a472d50dcbd90c29c35d5);
#
#
#
#         marker_f5d8f03db924085397ffdbfd3a44baff.bindPopup(popup_8565ba91401c5468abe8c7f461af387a)
#         ;
#
#
#
#
#             var marker_9a95cd9a3168163be90d7cbc3bc1be56 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_030cc3d279dfeef29fdb10ad4312c0d5);
#
#
#         var popup_653021641ebe19e9fe0bcf8b5cddb434 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_843d9fbe4054daea6eeb975a5c9b17a2 = $(`&lt;div id=&quot;html_843d9fbe4054daea6eeb975a5c9b17a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_653021641ebe19e9fe0bcf8b5cddb434.setContent(html_843d9fbe4054daea6eeb975a5c9b17a2);
#
#
#
#         marker_9a95cd9a3168163be90d7cbc3bc1be56.bindPopup(popup_653021641ebe19e9fe0bcf8b5cddb434)
#         ;
#
#
#
#
#             var marker_b36292692959f835d1ef91eefa49df7f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_030cc3d279dfeef29fdb10ad4312c0d5);
#
#
#         var popup_27a04b0d0d266a9f7b89d88b6b76bf24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_416548a418cee51141fa1c4353434b0d = $(`&lt;div id=&quot;html_416548a418cee51141fa1c4353434b0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_27a04b0d0d266a9f7b89d88b6b76bf24.setContent(html_416548a418cee51141fa1c4353434b0d);
#
#
#
#         marker_b36292692959f835d1ef91eefa49df7f.bindPopup(popup_27a04b0d0d266a9f7b89d88b6b76bf24)
#         ;
#
#
#
#
#             var marker_bbcae1ec52f459c95531fcde79fd87ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_030cc3d279dfeef29fdb10ad4312c0d5);
#
#
#         var popup_12880225a04082de00b47d865e00b816 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01795a87a8e1dd61e0fd4d422e314722 = $(`&lt;div id=&quot;html_01795a87a8e1dd61e0fd4d422e314722&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_12880225a04082de00b47d865e00b816.setContent(html_01795a87a8e1dd61e0fd4d422e314722);
#
#
#
#         marker_bbcae1ec52f459c95531fcde79fd87ac.bindPopup(popup_12880225a04082de00b47d865e00b816)
#         ;
#
#
#
#
#             var marker_6d4b934b83a596891351b86dbd68e9bb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_030cc3d279dfeef29fdb10ad4312c0d5);
#
#
#         var popup_94ce46a95bbb80f5c024443bcd39934d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1efdfa7114249f57aa20073339f46357 = $(`&lt;div id=&quot;html_1efdfa7114249f57aa20073339f46357&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_94ce46a95bbb80f5c024443bcd39934d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3eeed6e670a5b8610e4c41c8ec50f28 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3eeed6e670a5b8610e4c41c8ec50f28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3eeed6e670a5b8610e4c41c8ec50f28 = L.map(
#                 &quot;map_c3eeed6e670a5b8610e4c41c8ec50f28&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5fa6547c008ef07eaf2fb80b43e32b8c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5fa6547c008ef07eaf2fb80b43e32b8c.addTo(map_c3eeed6e670a5b8610e4c41c8ec50f28);
#
#
#             var feature_group_d947ff7870422d2a4a171e7c813fc6a2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_982aca317a1b5ce36af013575119a525 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d947ff7870422d2a4a171e7c813fc6a2);
#
#
#         var popup_d4d91d381bdcc56a13c9e5494317c9d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88b688096ddd2b2d7d2609096f4fb7a1 = $(`&lt;div id=&quot;html_88b688096ddd2b2d7d2609096f4fb7a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d4d91d381bdcc56a13c9e5494317c9d9.setContent(html_88b688096ddd2b2d7d2609096f4fb7a1);
#
#
#
#         marker_982aca317a1b5ce36af013575119a525.bindPopup(popup_d4d91d381bdcc56a13c9e5494317c9d9)
#         ;
#
#
#
#
#             var marker_595b4212b0a64afc6da7d8ea5300dc0a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d947ff7870422d2a4a171e7c813fc6a2);
#
#
#         var popup_747693446914243bad05a6a795737c4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32032447ed82fa6053ce9cd5e2069762 = $(`&lt;div id=&quot;html_32032447ed82fa6053ce9cd5e2069762&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_747693446914243bad05a6a795737c4e.setContent(html_32032447ed82fa6053ce9cd5e2069762);
#
#
#
#         marker_595b4212b0a64afc6da7d8ea5300dc0a.bindPopup(popup_747693446914243bad05a6a795737c4e)
#         ;
#
#
#
#
#             var marker_e063e00ad35f3c370f3bb67ab0ae2ae5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d947ff7870422d2a4a171e7c813fc6a2);
#
#
#         var popup_4a53cb3c15b173ea818cb1854e9a45cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d546c36dd8cf5d36ca58d3c7ad4ee53a = $(`&lt;div id=&quot;html_d546c36dd8cf5d36ca58d3c7ad4ee53a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4a53cb3c15b173ea818cb1854e9a45cf.setContent(html_d546c36dd8cf5d36ca58d3c7ad4ee53a);
#
#
#
#         marker_e063e00ad35f3c370f3bb67ab0ae2ae5.bindPopup(popup_4a53cb3c15b173ea818cb1854e9a45cf)
#         ;
#
#
#
#
#             var marker_7f83e3222e041deeea647637342c490a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d947ff7870422d2a4a171e7c813fc6a2);
#
#
#         var popup_457f14ec65f1015aa7288023f915a6b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7689a29dd364f4680da5d89bd277f5df = $(`&lt;div id=&quot;html_7689a29dd364f4680da5d89bd277f5df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_457f14ec65f1015aa7288023f915a6b1.setContent(html_7689a29dd364f4680da5d89bd277f5df);
#
#
#
#         marker_7f83e3222e041deeea647637342c490a.bindPopup(popup_457f14ec65f1015aa7288023f915a6b1)
#         ;
#
#
#
#
#             var marker_dc52248301bcc78ab7cbd6251b08cf40 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d947ff7870422d2a4a171e7c813fc6a2);
#
#
#         var popup_d9b893ec2d5da78989b59c8964fd5f38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4985f6e9dbcc208a3ea179ec543421e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4985f6e9dbcc208a3ea179ec543421e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4985f6e9dbcc208a3ea179ec543421e2 = L.map(
#                 &quot;map_4985f6e9dbcc208a3ea179ec543421e2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91c52f6898cd01925cbf25a3eaf858f6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_91c52f6898cd01925cbf25a3eaf858f6.addTo(map_4985f6e9dbcc208a3ea179ec543421e2);
#
#
#             var feature_group_058a872147ac5c438d6ed3b725445cec = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_058a872147ac5c438d6ed3b725445cec.addTo(map_4985f6e9dbcc208a3ea179ec543421e2);
#
#
#             var feature_group_sub_group_a28e97b0cb3e9c0c8fb1aff25b656e42 = L.featureGroup.subGroup(
#                 feature_group_058a872147ac5c438d6ed3b725445cec
#             );
#
#
#             var marker_98aad4baab6ad08d7a50d80bafaeba92 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a28e97b0cb3e9c0c8fb1aff25b656e42);
#
#
#         var popup_ea86eea49566dd662b835ecfbf911200 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_720659d9f9c5fc6ca432480f7acc8335 = $(`&lt;div id=&quot;html_720659d9f9c5fc6ca432480f7acc8335&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ea86eea49566dd662b835ecfbf911200.setContent(html_720659d9f9c5fc6ca432480f7acc8335);
#
#
#
#         marker_98aad4baab6ad08d7a50d80bafaeba92.bindPopup(popup_ea86eea49566dd662b835ecfbf911200)
#         ;
#
#
#
#
#             var marker_cd3f14628a97bc994caf5604c29bca0f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a28e97b0cb3e9c0c8fb1aff25b656e42);
#
#
#         var popup_1d1f8b746c55de1d7dba9eab4f05e37d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b149b04fbad73dcb955995073e5b8c92 = $(`&lt;div id=&quot;html_b149b04fbad73dcb955995073e5b8c92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1d1f8b746c55de1d7dba9eab4f05e37d.setContent(html_b149b04fbad73dcb955995073e5b8c92);
#
#
#
#         marker_cd3f14628a97bc994caf5604c29bca0f.bindPopup(popup_1d1f8b746c55de1d7dba9eab4f05e37d)
#         ;
#
#
#
#
#             var marker_28e4522a28ce86ff4c7de9dbd3e452a9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a28e97b0cb3e9c0c8fb1aff25b656e42);
#
#
#         var popup_e62089abb9c27a64727331a80805cefc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_593599dc1503fc68c72ac1c91563414f = $(`&lt;div id=&quot;html_593599dc1503fc68c72ac1c91563414f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e62089abb9c27a64727331a80805cefc.setContent(html_593599dc1503fc68c72ac1c91563414f);
#
#
#
#         marker_28e4522a28ce86ff4c7de9dbd3e452a9.bindPopup(popup_e62089abb9c27a64727331a80805cefc)
#         ;
#
#
#
#
#             var marker_b21527e35a40b6ce499e9cd64a79ce90 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a28e97b0cb3e9c0c8fb1aff25b656e42);
#
#
#         var popup_6dc149db283e198d631a6c4c279ea61e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_903b8ddef5e2c2e7236ba71d58bf4f10 = $(`&lt;div id=&quot;html_903b8ddef5e2c2e7236ba71d58bf4f10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6dc149db283e198d631a6c4c279ea61e.setContent(html_903b8ddef5e2c2e7236ba71d58bf4f10);
#
#
#
#         marker_
