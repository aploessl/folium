# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b707b9f739e0d397901c369d82078aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b707b9f739e0d397901c369d82078aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b707b9f739e0d397901c369d82078aa = L.map(
#                 &quot;map_3b707b9f739e0d397901c369d82078aa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a4bfdd3a2528650b5bd62fc45969563 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a4bfdd3a2528650b5bd62fc45969563.addTo(map_3b707b9f739e0d397901c369d82078aa);
#
#
#             var marker_2a2394408243d7f69f2dbdf5492946ce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3b707b9f739e0d397901c369d82078aa);
#
#
#         var popup_5d509a8f54deee0eb8267087cea09a32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f0d04f5a9a8da2a6e6e9bf0dc415817 = $(`&lt;div id=&quot;html_6f0d04f5a9a8da2a6e6e9bf0dc415817&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5d509a8f54deee0eb8267087cea09a32.setContent(html_6f0d04f5a9a8da2a6e6e9bf0dc415817);
#
#
#
#         marker_2a2394408243d7f69f2dbdf5492946ce.bindPopup(popup_5d509a8f54deee0eb8267087cea09a32)
#         ;
#
#
#
#
#             var marker_5c7b5d37d31c64872f3713c8dbe18643 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3b707b9f739e0d397901c369d82078aa);
#
#
#         var popup_fc6b947569ec389569e73c5e133a293c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8374c2a049ab99dceb2288186acb282d = $(`&lt;div id=&quot;html_8374c2a049ab99dceb2288186acb282d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fc6b947569ec389569e73c5e133a293c.setContent(html_8374c2a049ab99dceb2288186acb282d);
#
#
#
#         marker_5c7b5d37d31c64872f3713c8dbe18643.bindPopup(popup_fc6b947569ec389569e73c5e133a293c)
#         ;
#
#
#
#
#             var marker_d724af308cf285ef3d7463c416c080ad = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3b707b9f739e0d397901c369d82078aa);
#
#
#         var popup_aff4fceb4b01b5fa72308faf1bfefc4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a3448e914954e2ab47a080ed6da849e = $(`&lt;div id=&quot;html_6a3448e914954e2ab47a080ed6da849e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_aff4fceb4b01b5fa72308faf1bfefc4b.setContent(html_6a3448e914954e2ab47a080ed6da849e);
#
#
#
#         marker_d724af308cf285ef3d7463c416c080ad.bindPopup(popup_aff4fceb4b01b5fa72308faf1bfefc4b)
#         ;
#
#
#
#
#             var marker_1b0a414819aa4ce0e7ac73fc472a916c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3b707b9f739e0d397901c369d82078aa);
#
#
#         var popup_5f98d904093baf963190d598deab8aab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7dff04ce03456ac8655b8ed0b51aff8 = $(`&lt;div id=&quot;html_c7dff04ce03456ac8655b8ed0b51aff8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5f98d904093baf963190d598deab8aab.setContent(html_c7dff04ce03456ac8655b8ed0b51aff8);
#
#
#
#         marker_1b0a414819aa4ce0e7ac73fc472a916c.bindPopup(popup_5f98d904093baf963190d598deab8aab)
#         ;
#
#
#
#
#             var marker_33a8187f03a84673883c2c15abdeaf35 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3b707b9f739e0d397901c369d82078aa);
#
#
#         var popup_993cd1dfed6d0653dcff06385bb31f66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15eb175c5fb7b5edd3045fd83cd560c9 = $(`&lt;div id=&quot;html_15eb175c5fb7b5edd3045fd83cd560c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_993cd1dfed6d0653dcff06385bb31f66.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_721018c734ac07207520f07209b2ab80 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_721018c734ac07207520f07209b2ab80&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_721018c734ac07207520f07209b2ab80 = L.map(
#                 &quot;map_721018c734ac07207520f07209b2ab80&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f664045923cecb040e16025c65f64ac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f664045923cecb040e16025c65f64ac.addTo(map_721018c734ac07207520f07209b2ab80);
#
#
#             var feature_group_dbe8d557130af36dbb2e8f32c7cd1aca = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_39d12a46c1b0619df34947c43260febc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_dbe8d557130af36dbb2e8f32c7cd1aca);
#
#
#         var popup_07f9d5ee15b66054808d6baf1210401b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19e636d67b4644af8ca4aaad89bf71b8 = $(`&lt;div id=&quot;html_19e636d67b4644af8ca4aaad89bf71b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_07f9d5ee15b66054808d6baf1210401b.setContent(html_19e636d67b4644af8ca4aaad89bf71b8);
#
#
#
#         marker_39d12a46c1b0619df34947c43260febc.bindPopup(popup_07f9d5ee15b66054808d6baf1210401b)
#         ;
#
#
#
#
#             var marker_ba8230c40f2e6bdf498c8a8ec8c3d7be = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_dbe8d557130af36dbb2e8f32c7cd1aca);
#
#
#         var popup_fc7ca5cf6e6f25d380e5011f405ee2bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0c87ba76fa3c1e9900ea19c43a87d63 = $(`&lt;div id=&quot;html_d0c87ba76fa3c1e9900ea19c43a87d63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fc7ca5cf6e6f25d380e5011f405ee2bb.setContent(html_d0c87ba76fa3c1e9900ea19c43a87d63);
#
#
#
#         marker_ba8230c40f2e6bdf498c8a8ec8c3d7be.bindPopup(popup_fc7ca5cf6e6f25d380e5011f405ee2bb)
#         ;
#
#
#
#
#             var marker_e3cc5d0ce579498cbd96ba0dde7c96de = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_dbe8d557130af36dbb2e8f32c7cd1aca);
#
#
#         var popup_a76b32a7c96a1509a5efeb93af4b6542 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62703a5dd6b05f85a0ece691dcc91bc0 = $(`&lt;div id=&quot;html_62703a5dd6b05f85a0ece691dcc91bc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a76b32a7c96a1509a5efeb93af4b6542.setContent(html_62703a5dd6b05f85a0ece691dcc91bc0);
#
#
#
#         marker_e3cc5d0ce579498cbd96ba0dde7c96de.bindPopup(popup_a76b32a7c96a1509a5efeb93af4b6542)
#         ;
#
#
#
#
#             var marker_22ac8d1c0836583b89a0bb901f045ec8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_dbe8d557130af36dbb2e8f32c7cd1aca);
#
#
#         var popup_fc52c6ef689d2e96351fa4841da6a0db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7df62f143593e81272b901d6e69bdc05 = $(`&lt;div id=&quot;html_7df62f143593e81272b901d6e69bdc05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_fc52c6ef689d2e96351fa4841da6a0db.setContent(html_7df62f143593e81272b901d6e69bdc05);
#
#
#
#         marker_22ac8d1c0836583b89a0bb901f045ec8.bindPopup(popup_fc52c6ef689d2e96351fa4841da6a0db)
#         ;
#
#
#
#
#             var marker_2bdc4b4d4492bccf880bdbf7ec93377a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_dbe8d557130af36dbb2e8f32c7cd1aca);
#
#
#         var popup_6c6e0af6d1ee0009c489252a8670677b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fe755de32b9557afd2cd6f5639d0514 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fe755de32b9557afd2cd6f5639d0514&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fe755de32b9557afd2cd6f5639d0514 = L.map(
#                 &quot;map_9fe755de32b9557afd2cd6f5639d0514&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee8bf358b620f17703f54edd6a12b9d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ee8bf358b620f17703f54edd6a12b9d3.addTo(map_9fe755de32b9557afd2cd6f5639d0514);
#
#
#             var feature_group_6e87afdc45d1d8a993689e5094359a84 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6e87afdc45d1d8a993689e5094359a84.addTo(map_9fe755de32b9557afd2cd6f5639d0514);
#
#
#             var feature_group_sub_group_e943aafc41866c54421e6567fd35a24c = L.featureGroup.subGroup(
#                 feature_group_6e87afdc45d1d8a993689e5094359a84
#             );
#
#
#             var marker_eaaf6d5098893f310c4b9b592ac3499f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e943aafc41866c54421e6567fd35a24c);
#
#
#         var popup_bea1a67085aede59ef6861baceeaa2f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_078fb176d5d6bff345d0be92a9c0113d = $(`&lt;div id=&quot;html_078fb176d5d6bff345d0be92a9c0113d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bea1a67085aede59ef6861baceeaa2f1.setContent(html_078fb176d5d6bff345d0be92a9c0113d);
#
#
#
#         marker_eaaf6d5098893f310c4b9b592ac3499f.bindPopup(popup_bea1a67085aede59ef6861baceeaa2f1)
#         ;
#
#
#
#
#             var marker_b86f26b1a1f81cd0ce5ddabf53ef2d4d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e943aafc41866c54421e6567fd35a24c);
#
#
#         var popup_cb451673395793281f00b177254c48af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26f28c2eacdcbe5392764060ee64a4a3 = $(`&lt;div id=&quot;html_26f28c2eacdcbe5392764060ee64a4a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cb451673395793281f00b177254c48af.setContent(html_26f28c2eacdcbe5392764060ee64a4a3);
#
#
#
#         marker_b86f26b1a1f81cd0ce5ddabf53ef2d4d.bindPopup(popup_cb451673395793281f00b177254c48af)
#         ;
#
#
#
#
#             var marker_6383d2aa89fe0a62392c2f47b0c0074a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e943aafc41866c54421e6567fd35a24c);
#
#
#         var popup_ed7be7aa16f531f4ed046dd6af2c6c97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a1cbe73f5def1621929da0da03e8af3 = $(`&lt;div id=&quot;html_4a1cbe73f5def1621929da0da03e8af3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ed7be7aa16f531f4ed046dd6af2c6c97.setContent(html_4a1cbe73f5def1621929da0da03e8af3);
#
#
#
#         marker_6383d2aa89fe0a62392c2f47b0c0074a.bindPopup(popup_ed7be7aa16f531f4ed046dd6af2c6c97)
#         ;
#
#
#
#
#             var marker_26e7c6205a4ee71b6db3016e5817f903 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e943aafc41866c54421e6567fd35a24c);
#
#
#         var popup_74e64057c34fa5f159c65120228c2528 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44bf25056a53fc4c1dde94812cbd727f = $(`&lt;div id=&quot;html_44bf25056a53fc4c1dde94812cbd727f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_74e64057c34fa5f159c65120228c2528.setContent(html_44bf25056a53fc4c1dde94812cbd727f);
#
#
#
#         marker_
