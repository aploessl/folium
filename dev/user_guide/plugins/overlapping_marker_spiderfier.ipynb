# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72187dbcb77398b8e3550ec4aa48566a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72187dbcb77398b8e3550ec4aa48566a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72187dbcb77398b8e3550ec4aa48566a = L.map(
#                 &quot;map_72187dbcb77398b8e3550ec4aa48566a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_961fe100ec6c731ec68e92a3c5a68059 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_961fe100ec6c731ec68e92a3c5a68059.addTo(map_72187dbcb77398b8e3550ec4aa48566a);
#
#
#             var marker_791fc352efeb901ba134952e090864c1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_72187dbcb77398b8e3550ec4aa48566a);
#
#
#         var popup_5b0e145eacd9c1a43e489f59ec8b1b0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25d7b28863ad47d87faea6cd66540c81 = $(`&lt;div id=&quot;html_25d7b28863ad47d87faea6cd66540c81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5b0e145eacd9c1a43e489f59ec8b1b0d.setContent(html_25d7b28863ad47d87faea6cd66540c81);
#
#
#
#         marker_791fc352efeb901ba134952e090864c1.bindPopup(popup_5b0e145eacd9c1a43e489f59ec8b1b0d)
#         ;
#
#
#
#
#             var marker_2420bbf11ac97deb7cc24c5f235862ee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_72187dbcb77398b8e3550ec4aa48566a);
#
#
#         var popup_cf5d000eb173b228059e12a95ff8490a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59f677ad76b05af6ed8c0f79cc9b3146 = $(`&lt;div id=&quot;html_59f677ad76b05af6ed8c0f79cc9b3146&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cf5d000eb173b228059e12a95ff8490a.setContent(html_59f677ad76b05af6ed8c0f79cc9b3146);
#
#
#
#         marker_2420bbf11ac97deb7cc24c5f235862ee.bindPopup(popup_cf5d000eb173b228059e12a95ff8490a)
#         ;
#
#
#
#
#             var marker_4d5616d78275e2a41983a357e8c13f50 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_72187dbcb77398b8e3550ec4aa48566a);
#
#
#         var popup_894e0ee5d72f192746518ae750d04479 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab3c86514507c480ebb7675baec42c22 = $(`&lt;div id=&quot;html_ab3c86514507c480ebb7675baec42c22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_894e0ee5d72f192746518ae750d04479.setContent(html_ab3c86514507c480ebb7675baec42c22);
#
#
#
#         marker_4d5616d78275e2a41983a357e8c13f50.bindPopup(popup_894e0ee5d72f192746518ae750d04479)
#         ;
#
#
#
#
#             var marker_f00d877766e5dd8a1d63c2de4889ac28 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_72187dbcb77398b8e3550ec4aa48566a);
#
#
#         var popup_8128fc762b366ca9840eba386f94971b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe2cb9addbcfe55b3769bfebe8bf4bda = $(`&lt;div id=&quot;html_fe2cb9addbcfe55b3769bfebe8bf4bda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8128fc762b366ca9840eba386f94971b.setContent(html_fe2cb9addbcfe55b3769bfebe8bf4bda);
#
#
#
#         marker_f00d877766e5dd8a1d63c2de4889ac28.bindPopup(popup_8128fc762b366ca9840eba386f94971b)
#         ;
#
#
#
#
#             var marker_15c1f3d128a0adc28086be51bcb20ef5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_72187dbcb77398b8e3550ec4aa48566a);
#
#
#         var popup_63ece9e6b2e5941ba62d1115b40ca70e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6002910cc6f5b73a76b4ad2116c377cc = $(`&lt;div id=&quot;html_6002910cc6f5b73a76b4ad2116c377cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_63ece9e6b2e5941ba62d1115b40ca70e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65c1c0995cda95781d6eea0f27a6921c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65c1c0995cda95781d6eea0f27a6921c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65c1c0995cda95781d6eea0f27a6921c = L.map(
#                 &quot;map_65c1c0995cda95781d6eea0f27a6921c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0cdf3c3210395f91ba7de052dacd15e4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0cdf3c3210395f91ba7de052dacd15e4.addTo(map_65c1c0995cda95781d6eea0f27a6921c);
#
#
#             var feature_group_c18e423a92d75e0893f28358c4f78cf4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_92da53e497786a195685d89f8ab8b87f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c18e423a92d75e0893f28358c4f78cf4);
#
#
#         var popup_942ccd461a4c383432c719017de2bc35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04e0d1bd19bd291ae3510f326468ab52 = $(`&lt;div id=&quot;html_04e0d1bd19bd291ae3510f326468ab52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_942ccd461a4c383432c719017de2bc35.setContent(html_04e0d1bd19bd291ae3510f326468ab52);
#
#
#
#         marker_92da53e497786a195685d89f8ab8b87f.bindPopup(popup_942ccd461a4c383432c719017de2bc35)
#         ;
#
#
#
#
#             var marker_d5982ecda83c7e12bf9b5bcbf3dbbba4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c18e423a92d75e0893f28358c4f78cf4);
#
#
#         var popup_1c34bda21bb012dcae19c97d9e8790ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d04acb15d6e0ef22d9052092ff04add = $(`&lt;div id=&quot;html_6d04acb15d6e0ef22d9052092ff04add&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1c34bda21bb012dcae19c97d9e8790ca.setContent(html_6d04acb15d6e0ef22d9052092ff04add);
#
#
#
#         marker_d5982ecda83c7e12bf9b5bcbf3dbbba4.bindPopup(popup_1c34bda21bb012dcae19c97d9e8790ca)
#         ;
#
#
#
#
#             var marker_39b72b888b80bf17a5e9c2f171633957 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c18e423a92d75e0893f28358c4f78cf4);
#
#
#         var popup_0fb6e8ee2daf5325e418ce3c3d6e50cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_706cfe59043894eeceb53d1ea64582f6 = $(`&lt;div id=&quot;html_706cfe59043894eeceb53d1ea64582f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0fb6e8ee2daf5325e418ce3c3d6e50cf.setContent(html_706cfe59043894eeceb53d1ea64582f6);
#
#
#
#         marker_39b72b888b80bf17a5e9c2f171633957.bindPopup(popup_0fb6e8ee2daf5325e418ce3c3d6e50cf)
#         ;
#
#
#
#
#             var marker_5ef94c52a30a6a605a451ead79f8ab31 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c18e423a92d75e0893f28358c4f78cf4);
#
#
#         var popup_b5c3eff461fdb61a00ee013e578d42e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bedd5463e5e435e3b37a629680d7e220 = $(`&lt;div id=&quot;html_bedd5463e5e435e3b37a629680d7e220&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b5c3eff461fdb61a00ee013e578d42e4.setContent(html_bedd5463e5e435e3b37a629680d7e220);
#
#
#
#         marker_5ef94c52a30a6a605a451ead79f8ab31.bindPopup(popup_b5c3eff461fdb61a00ee013e578d42e4)
#         ;
#
#
#
#
#             var marker_85746dfeb8b0d64c0cf202c76fbd53b8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c18e423a92d75e0893f28358c4f78cf4);
#
#
#         var popup_749128c4f550545ab5b7ee017fa7c30f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7cdc98cbc1b5db7e8f117f489e43e5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7cdc98cbc1b5db7e8f117f489e43e5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7cdc98cbc1b5db7e8f117f489e43e5c = L.map(
#                 &quot;map_d7cdc98cbc1b5db7e8f117f489e43e5c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17c6b0297346312cb7b861dcef8059a0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17c6b0297346312cb7b861dcef8059a0.addTo(map_d7cdc98cbc1b5db7e8f117f489e43e5c);
#
#
#             var feature_group_f9fa63bcd0243f35923bf49ccb464ee0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f9fa63bcd0243f35923bf49ccb464ee0.addTo(map_d7cdc98cbc1b5db7e8f117f489e43e5c);
#
#
#             var feature_group_sub_group_2b661c58beaadd126cb1cb1abe752a5f = L.featureGroup.subGroup(
#                 feature_group_f9fa63bcd0243f35923bf49ccb464ee0
#             );
#
#
#             var marker_1df06373822222b4d24d4cb8140fc713 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b661c58beaadd126cb1cb1abe752a5f);
#
#
#         var popup_30ca6b2297cefde420a5b4e88f1b85d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ae25b55cc752e99eb17edf8f7db418f = $(`&lt;div id=&quot;html_2ae25b55cc752e99eb17edf8f7db418f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_30ca6b2297cefde420a5b4e88f1b85d7.setContent(html_2ae25b55cc752e99eb17edf8f7db418f);
#
#
#
#         marker_1df06373822222b4d24d4cb8140fc713.bindPopup(popup_30ca6b2297cefde420a5b4e88f1b85d7)
#         ;
#
#
#
#
#             var marker_431e8cbeb7bd88483099b46315ef1e67 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b661c58beaadd126cb1cb1abe752a5f);
#
#
#         var popup_88eae02c3db5582352cce8812f7d5113 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa2a0b6233af7b5884f7da221e0ea3c1 = $(`&lt;div id=&quot;html_aa2a0b6233af7b5884f7da221e0ea3c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_88eae02c3db5582352cce8812f7d5113.setContent(html_aa2a0b6233af7b5884f7da221e0ea3c1);
#
#
#
#         marker_431e8cbeb7bd88483099b46315ef1e67.bindPopup(popup_88eae02c3db5582352cce8812f7d5113)
#         ;
#
#
#
#
#             var marker_dd657e336a8c69aa7729a235be453c0e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b661c58beaadd126cb1cb1abe752a5f);
#
#
#         var popup_6d1424d6930e0cbacd8901111f12cf19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a816c5661f4c7f83462193bab3267de = $(`&lt;div id=&quot;html_6a816c5661f4c7f83462193bab3267de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6d1424d6930e0cbacd8901111f12cf19.setContent(html_6a816c5661f4c7f83462193bab3267de);
#
#
#
#         marker_dd657e336a8c69aa7729a235be453c0e.bindPopup(popup_6d1424d6930e0cbacd8901111f12cf19)
#         ;
#
#
#
#
#             var marker_beaa9b14451eeb2efef0a298df5a2312 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b661c58beaadd126cb1cb1abe752a5f);
#
#
#         var popup_9d3d192ad3e54527a76ce656e3358725 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d2db051cdd8d7806bdf259dd2c4ff8b = $(`&lt;div id=&quot;html_6d2db051cdd8d7806bdf259dd2c4ff8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9d3d192ad3e54527a76ce656e3358725.setContent(html_6d2db051cdd8d7806bdf259dd2c4ff8b);
#
#
#
#         marker_
