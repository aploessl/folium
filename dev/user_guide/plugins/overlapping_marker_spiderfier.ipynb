# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_763ce948e341d750ab628e6690657842 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_763ce948e341d750ab628e6690657842&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_763ce948e341d750ab628e6690657842 = L.map(
#                 &quot;map_763ce948e341d750ab628e6690657842&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d84176aeeca101628b8e7b3d9ca1a47c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d84176aeeca101628b8e7b3d9ca1a47c.addTo(map_763ce948e341d750ab628e6690657842);
#
#
#             var marker_69e15a8a4b7d850021846e9c84857b96 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_763ce948e341d750ab628e6690657842);
#
#
#         var popup_39b8ace1149dbcf7fca720b41275bb39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4b3f8d065efc61eb6c6ff8608ee4d71 = $(`&lt;div id=&quot;html_a4b3f8d065efc61eb6c6ff8608ee4d71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_39b8ace1149dbcf7fca720b41275bb39.setContent(html_a4b3f8d065efc61eb6c6ff8608ee4d71);
#
#
#
#         marker_69e15a8a4b7d850021846e9c84857b96.bindPopup(popup_39b8ace1149dbcf7fca720b41275bb39)
#         ;
#
#
#
#
#             var marker_6225a4e45270e8d7be05afe3f11892c9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_763ce948e341d750ab628e6690657842);
#
#
#         var popup_8f4f0b47dc15b47149c407acf40c2d55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_650287a447d37aec4c8c5330d2607c82 = $(`&lt;div id=&quot;html_650287a447d37aec4c8c5330d2607c82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8f4f0b47dc15b47149c407acf40c2d55.setContent(html_650287a447d37aec4c8c5330d2607c82);
#
#
#
#         marker_6225a4e45270e8d7be05afe3f11892c9.bindPopup(popup_8f4f0b47dc15b47149c407acf40c2d55)
#         ;
#
#
#
#
#             var marker_46c6f49fc8ab85d195861357a37561fe = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_763ce948e341d750ab628e6690657842);
#
#
#         var popup_536aa4f7d0eedf238f0a02ddc54295ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c2e72417d804ec59ad350c6e5799051 = $(`&lt;div id=&quot;html_0c2e72417d804ec59ad350c6e5799051&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_536aa4f7d0eedf238f0a02ddc54295ac.setContent(html_0c2e72417d804ec59ad350c6e5799051);
#
#
#
#         marker_46c6f49fc8ab85d195861357a37561fe.bindPopup(popup_536aa4f7d0eedf238f0a02ddc54295ac)
#         ;
#
#
#
#
#             var marker_f07fe15f80b29afce6ef6bf133818f2a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_763ce948e341d750ab628e6690657842);
#
#
#         var popup_45e3a063948dff0435841083bb157b3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36df3a122b9a6bf3c29d404125f236a2 = $(`&lt;div id=&quot;html_36df3a122b9a6bf3c29d404125f236a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_45e3a063948dff0435841083bb157b3f.setContent(html_36df3a122b9a6bf3c29d404125f236a2);
#
#
#
#         marker_f07fe15f80b29afce6ef6bf133818f2a.bindPopup(popup_45e3a063948dff0435841083bb157b3f)
#         ;
#
#
#
#
#             var marker_15f051ecac5282c5e58f2c031b6db61c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_763ce948e341d750ab628e6690657842);
#
#
#         var popup_73e90524e64dc859157fd1746a1ecb45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f1975b0f3a57dbf8742ec303e3d0682 = $(`&lt;div id=&quot;html_8f1975b0f3a57dbf8742ec303e3d0682&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_73e90524e64dc859157fd1746a1ecb45.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f751b8b7f048ccc18db4444a5e95583e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f751b8b7f048ccc18db4444a5e95583e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f751b8b7f048ccc18db4444a5e95583e = L.map(
#                 &quot;map_f751b8b7f048ccc18db4444a5e95583e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cba63a321f12db34365010a2b2ac7189 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cba63a321f12db34365010a2b2ac7189.addTo(map_f751b8b7f048ccc18db4444a5e95583e);
#
#
#             var feature_group_6e2c2e1093cab7eecd73bb903a517e38 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b46b3dab3772afb65208796f01bfc265 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6e2c2e1093cab7eecd73bb903a517e38);
#
#
#         var popup_79df287d87dfe220e794e645feac2294 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67004a247cf750516afd3ccba4d4a7f4 = $(`&lt;div id=&quot;html_67004a247cf750516afd3ccba4d4a7f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_79df287d87dfe220e794e645feac2294.setContent(html_67004a247cf750516afd3ccba4d4a7f4);
#
#
#
#         marker_b46b3dab3772afb65208796f01bfc265.bindPopup(popup_79df287d87dfe220e794e645feac2294)
#         ;
#
#
#
#
#             var marker_426fc98cfb8660777c1514b287a417e6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6e2c2e1093cab7eecd73bb903a517e38);
#
#
#         var popup_a87bcd5b3a6b120500ae7f2025ace962 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5783292d92975010e9b8564183fdde4 = $(`&lt;div id=&quot;html_a5783292d92975010e9b8564183fdde4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a87bcd5b3a6b120500ae7f2025ace962.setContent(html_a5783292d92975010e9b8564183fdde4);
#
#
#
#         marker_426fc98cfb8660777c1514b287a417e6.bindPopup(popup_a87bcd5b3a6b120500ae7f2025ace962)
#         ;
#
#
#
#
#             var marker_863cd5acc940ec304c976162081aae65 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6e2c2e1093cab7eecd73bb903a517e38);
#
#
#         var popup_08b028367042f21a932a7dc37085d565 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_931693e426a9e1405ee0814c6defb266 = $(`&lt;div id=&quot;html_931693e426a9e1405ee0814c6defb266&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_08b028367042f21a932a7dc37085d565.setContent(html_931693e426a9e1405ee0814c6defb266);
#
#
#
#         marker_863cd5acc940ec304c976162081aae65.bindPopup(popup_08b028367042f21a932a7dc37085d565)
#         ;
#
#
#
#
#             var marker_8538263c6a41cfb288ab28e2b9afb91a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6e2c2e1093cab7eecd73bb903a517e38);
#
#
#         var popup_03401a971b31b85eefb7429316d6a9ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b34f6ff35b786357ef4cff8da55d3dac = $(`&lt;div id=&quot;html_b34f6ff35b786357ef4cff8da55d3dac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_03401a971b31b85eefb7429316d6a9ff.setContent(html_b34f6ff35b786357ef4cff8da55d3dac);
#
#
#
#         marker_8538263c6a41cfb288ab28e2b9afb91a.bindPopup(popup_03401a971b31b85eefb7429316d6a9ff)
#         ;
#
#
#
#
#             var marker_6d1f486b8e2d90387491a3df43d573cd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6e2c2e1093cab7eecd73bb903a517e38);
#
#
#         var popup_038fc2a06a01592e513603f072b2c727 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06c0a5b2bc5eb304f96e73712ab5d2a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06c0a5b2bc5eb304f96e73712ab5d2a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06c0a5b2bc5eb304f96e73712ab5d2a7 = L.map(
#                 &quot;map_06c0a5b2bc5eb304f96e73712ab5d2a7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ea6dd2760161a11f82d4332663a2d28 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ea6dd2760161a11f82d4332663a2d28.addTo(map_06c0a5b2bc5eb304f96e73712ab5d2a7);
#
#
#             var feature_group_dd08d2c58ec10f4691c6a98c6446f275 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dd08d2c58ec10f4691c6a98c6446f275.addTo(map_06c0a5b2bc5eb304f96e73712ab5d2a7);
#
#
#             var feature_group_sub_group_1985f46d0d04dd8753b4a0a34b7acd5e = L.featureGroup.subGroup(
#                 feature_group_dd08d2c58ec10f4691c6a98c6446f275
#             );
#
#
#             var marker_a54d72eb3b6422584ee7d1b64ca43a8e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1985f46d0d04dd8753b4a0a34b7acd5e);
#
#
#         var popup_91ef59847c99027f8770676c7430e528 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db075190efb8a2ee88429d44d38ba428 = $(`&lt;div id=&quot;html_db075190efb8a2ee88429d44d38ba428&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_91ef59847c99027f8770676c7430e528.setContent(html_db075190efb8a2ee88429d44d38ba428);
#
#
#
#         marker_a54d72eb3b6422584ee7d1b64ca43a8e.bindPopup(popup_91ef59847c99027f8770676c7430e528)
#         ;
#
#
#
#
#             var marker_b7c051258472debcbb68be4c7013b7bf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1985f46d0d04dd8753b4a0a34b7acd5e);
#
#
#         var popup_b0c4f5c4bf90a7ff73ab615f708e6ada = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11f6036dfcc0b1a8ff18ac59fffc4997 = $(`&lt;div id=&quot;html_11f6036dfcc0b1a8ff18ac59fffc4997&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b0c4f5c4bf90a7ff73ab615f708e6ada.setContent(html_11f6036dfcc0b1a8ff18ac59fffc4997);
#
#
#
#         marker_b7c051258472debcbb68be4c7013b7bf.bindPopup(popup_b0c4f5c4bf90a7ff73ab615f708e6ada)
#         ;
#
#
#
#
#             var marker_b7794994a45f0a95285a09116f3566da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1985f46d0d04dd8753b4a0a34b7acd5e);
#
#
#         var popup_eb64c38e3bad7d6bc4d8923b30ad8763 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5160e3be4ecbb71c68e0a2f55e092be = $(`&lt;div id=&quot;html_f5160e3be4ecbb71c68e0a2f55e092be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_eb64c38e3bad7d6bc4d8923b30ad8763.setContent(html_f5160e3be4ecbb71c68e0a2f55e092be);
#
#
#
#         marker_b7794994a45f0a95285a09116f3566da.bindPopup(popup_eb64c38e3bad7d6bc4d8923b30ad8763)
#         ;
#
#
#
#
#             var marker_905eec5855957f51261eecebf6b0ddad = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1985f46d0d04dd8753b4a0a34b7acd5e);
#
#
#         var popup_d1f783616cf17ddabcc1ec625ef96845 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6cccee526713214361b828543bb018b = $(`&lt;div id=&quot;html_b6cccee526713214361b828543bb018b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d1f783616cf17ddabcc1ec625ef96845.setContent(html_b6cccee526713214361b828543bb018b);
#
#
#
#         marker_
