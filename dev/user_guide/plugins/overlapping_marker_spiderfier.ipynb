# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7097f212787d7b33cd24d2c91fd703db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7097f212787d7b33cd24d2c91fd703db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7097f212787d7b33cd24d2c91fd703db = L.map(
#                 &quot;map_7097f212787d7b33cd24d2c91fd703db&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c46bdaaace50e945cf44fe3df534737 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3c46bdaaace50e945cf44fe3df534737.addTo(map_7097f212787d7b33cd24d2c91fd703db);
#
#
#             var marker_8d9035c6349e76e1f921344293a96aa7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7097f212787d7b33cd24d2c91fd703db);
#
#
#         var popup_8178abad68f248a4a4259e9916335d46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c04f82e99cf83adc75a75dd021d61104 = $(`&lt;div id=&quot;html_c04f82e99cf83adc75a75dd021d61104&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8178abad68f248a4a4259e9916335d46.setContent(html_c04f82e99cf83adc75a75dd021d61104);
#
#
#
#         marker_8d9035c6349e76e1f921344293a96aa7.bindPopup(popup_8178abad68f248a4a4259e9916335d46)
#         ;
#
#
#
#
#             var marker_654652520cfb3867164a877961f6b559 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7097f212787d7b33cd24d2c91fd703db);
#
#
#         var popup_11799a4afda603c330f5b21923d644a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d79ebdcdf7c93fddd3c769474118546 = $(`&lt;div id=&quot;html_8d79ebdcdf7c93fddd3c769474118546&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_11799a4afda603c330f5b21923d644a2.setContent(html_8d79ebdcdf7c93fddd3c769474118546);
#
#
#
#         marker_654652520cfb3867164a877961f6b559.bindPopup(popup_11799a4afda603c330f5b21923d644a2)
#         ;
#
#
#
#
#             var marker_5a1b59716531244c032e2aa9df1933e5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7097f212787d7b33cd24d2c91fd703db);
#
#
#         var popup_a287a68af8a99b1c8e93011c29b2806f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f7662d5121d123c5adce3d2d4fa2c36 = $(`&lt;div id=&quot;html_8f7662d5121d123c5adce3d2d4fa2c36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a287a68af8a99b1c8e93011c29b2806f.setContent(html_8f7662d5121d123c5adce3d2d4fa2c36);
#
#
#
#         marker_5a1b59716531244c032e2aa9df1933e5.bindPopup(popup_a287a68af8a99b1c8e93011c29b2806f)
#         ;
#
#
#
#
#             var marker_dcdf8f17ab4475f9c23f2a41cb8de1e4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7097f212787d7b33cd24d2c91fd703db);
#
#
#         var popup_aaadcb7846b0b2b6996ec9a8a492b5e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eeaee405170be23f0a7796d545d3e610 = $(`&lt;div id=&quot;html_eeaee405170be23f0a7796d545d3e610&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_aaadcb7846b0b2b6996ec9a8a492b5e3.setContent(html_eeaee405170be23f0a7796d545d3e610);
#
#
#
#         marker_dcdf8f17ab4475f9c23f2a41cb8de1e4.bindPopup(popup_aaadcb7846b0b2b6996ec9a8a492b5e3)
#         ;
#
#
#
#
#             var marker_8a8200acdcb0f73cb5ee3a391d7e20df = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7097f212787d7b33cd24d2c91fd703db);
#
#
#         var popup_ddd566e6d15dc6cfcf8d9f0e785ad485 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90b9b73b5e826c2cb5ae86e7bf2bf40b = $(`&lt;div id=&quot;html_90b9b73b5e826c2cb5ae86e7bf2bf40b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ddd566e6d15dc6cfcf8d9f0e785ad485.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_55d195a7fb8b333895ebf274972e13b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_55d195a7fb8b333895ebf274972e13b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_55d195a7fb8b333895ebf274972e13b1 = L.map(
#                 &quot;map_55d195a7fb8b333895ebf274972e13b1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81e6b0fd5edb0b4c5f2a8f5105b213a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81e6b0fd5edb0b4c5f2a8f5105b213a4.addTo(map_55d195a7fb8b333895ebf274972e13b1);
#
#
#             var feature_group_4d16dc87678b8eec47add036baaccb22 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_498733e4e72464ebf52b13399d9cf30f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4d16dc87678b8eec47add036baaccb22);
#
#
#         var popup_122886fff3edaef094552161ac65d076 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8810575371d6011fb23b182077b0e61 = $(`&lt;div id=&quot;html_d8810575371d6011fb23b182077b0e61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_122886fff3edaef094552161ac65d076.setContent(html_d8810575371d6011fb23b182077b0e61);
#
#
#
#         marker_498733e4e72464ebf52b13399d9cf30f.bindPopup(popup_122886fff3edaef094552161ac65d076)
#         ;
#
#
#
#
#             var marker_64399536966062512afe52a728cd3143 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4d16dc87678b8eec47add036baaccb22);
#
#
#         var popup_02d2d852a178a822ebc8a8153bcc62b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b61e5c1f97467c818fd789c69f45890 = $(`&lt;div id=&quot;html_2b61e5c1f97467c818fd789c69f45890&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_02d2d852a178a822ebc8a8153bcc62b6.setContent(html_2b61e5c1f97467c818fd789c69f45890);
#
#
#
#         marker_64399536966062512afe52a728cd3143.bindPopup(popup_02d2d852a178a822ebc8a8153bcc62b6)
#         ;
#
#
#
#
#             var marker_fa120f19605c95ed4ba79d9321da94c1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4d16dc87678b8eec47add036baaccb22);
#
#
#         var popup_75dc58b576a05f69e509c5b8039daf23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be9d93d47f5d45175eb4af036bf677d0 = $(`&lt;div id=&quot;html_be9d93d47f5d45175eb4af036bf677d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_75dc58b576a05f69e509c5b8039daf23.setContent(html_be9d93d47f5d45175eb4af036bf677d0);
#
#
#
#         marker_fa120f19605c95ed4ba79d9321da94c1.bindPopup(popup_75dc58b576a05f69e509c5b8039daf23)
#         ;
#
#
#
#
#             var marker_e90d7c47b156fa62a3d99b817af9fe63 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4d16dc87678b8eec47add036baaccb22);
#
#
#         var popup_041034ab258f8fd485c5ce525a70daf1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_778bd595fc88c2bc41537f5d5f545f69 = $(`&lt;div id=&quot;html_778bd595fc88c2bc41537f5d5f545f69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_041034ab258f8fd485c5ce525a70daf1.setContent(html_778bd595fc88c2bc41537f5d5f545f69);
#
#
#
#         marker_e90d7c47b156fa62a3d99b817af9fe63.bindPopup(popup_041034ab258f8fd485c5ce525a70daf1)
#         ;
#
#
#
#
#             var marker_c7413df8fdd2ecd9c925fc0d47a06782 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4d16dc87678b8eec47add036baaccb22);
#
#
#         var popup_adb059eb950224c41d94f1047601a7c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_33b1c710729d41b493c919022ca1a082 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_33b1c710729d41b493c919022ca1a082&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_33b1c710729d41b493c919022ca1a082 = L.map(
#                 &quot;map_33b1c710729d41b493c919022ca1a082&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c6e509019a3e4e8decee6b35aa804ce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3c6e509019a3e4e8decee6b35aa804ce.addTo(map_33b1c710729d41b493c919022ca1a082);
#
#
#             var feature_group_74f56643f42cd791f326c49b41abde6a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_74f56643f42cd791f326c49b41abde6a.addTo(map_33b1c710729d41b493c919022ca1a082);
#
#
#             var feature_group_sub_group_bfc0889ef47b6e269206028bdc4babee = L.featureGroup.subGroup(
#                 feature_group_74f56643f42cd791f326c49b41abde6a
#             );
#
#
#             var marker_7a67bb0b1c34a8ff19700018b6c1847e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bfc0889ef47b6e269206028bdc4babee);
#
#
#         var popup_f6bfcd6e3d0fc42c4dae11e563bd482b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f73f35e4dd4d20ecb74d21aa5fc1993f = $(`&lt;div id=&quot;html_f73f35e4dd4d20ecb74d21aa5fc1993f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f6bfcd6e3d0fc42c4dae11e563bd482b.setContent(html_f73f35e4dd4d20ecb74d21aa5fc1993f);
#
#
#
#         marker_7a67bb0b1c34a8ff19700018b6c1847e.bindPopup(popup_f6bfcd6e3d0fc42c4dae11e563bd482b)
#         ;
#
#
#
#
#             var marker_34a0f50914fb20cfe33d51cac5cbf7c4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bfc0889ef47b6e269206028bdc4babee);
#
#
#         var popup_7ba2b49c850d94c9f7efabbf17c83dab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd1d04b9662463b507c55f5c7d7b56c8 = $(`&lt;div id=&quot;html_cd1d04b9662463b507c55f5c7d7b56c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7ba2b49c850d94c9f7efabbf17c83dab.setContent(html_cd1d04b9662463b507c55f5c7d7b56c8);
#
#
#
#         marker_34a0f50914fb20cfe33d51cac5cbf7c4.bindPopup(popup_7ba2b49c850d94c9f7efabbf17c83dab)
#         ;
#
#
#
#
#             var marker_f6fdbe50a8883fe5ce205d83dbe1963f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bfc0889ef47b6e269206028bdc4babee);
#
#
#         var popup_fdf043f36325e344f5161a9d83af412d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_603d3ed45d7e283992706a8eca0a0ef8 = $(`&lt;div id=&quot;html_603d3ed45d7e283992706a8eca0a0ef8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fdf043f36325e344f5161a9d83af412d.setContent(html_603d3ed45d7e283992706a8eca0a0ef8);
#
#
#
#         marker_f6fdbe50a8883fe5ce205d83dbe1963f.bindPopup(popup_fdf043f36325e344f5161a9d83af412d)
#         ;
#
#
#
#
#             var marker_5d91d6b5a90f5f5d11dfef330c182786 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bfc0889ef47b6e269206028bdc4babee);
#
#
#         var popup_a7e7ae373319f1893a0df531995b480b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a8db2c595e4975b5023adb7069c58d7 = $(`&lt;div id=&quot;html_3a8db2c595e4975b5023adb7069c58d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a7e7ae373319f1893a0df531995b480b.setContent(html_3a8db2c595e4975b5023adb7069c58d7);
#
#
#
#         marker_
