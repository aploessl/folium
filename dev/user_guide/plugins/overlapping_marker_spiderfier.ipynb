# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_422defd389d847e13a2d1794737ccd93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_422defd389d847e13a2d1794737ccd93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_422defd389d847e13a2d1794737ccd93 = L.map(
#                 &quot;map_422defd389d847e13a2d1794737ccd93&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6cf04c0d3118a43671f4dd979494e172 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6cf04c0d3118a43671f4dd979494e172.addTo(map_422defd389d847e13a2d1794737ccd93);
#
#
#             var marker_a62c4fce60faae89e0b5c40f221386ae = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_422defd389d847e13a2d1794737ccd93);
#
#
#         var popup_a53a7f8e4d724e2c2dd6bc16eda42797 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a8dc251d3985d678d38f46eecf0cc5b = $(`&lt;div id=&quot;html_2a8dc251d3985d678d38f46eecf0cc5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a53a7f8e4d724e2c2dd6bc16eda42797.setContent(html_2a8dc251d3985d678d38f46eecf0cc5b);
#
#
#
#         marker_a62c4fce60faae89e0b5c40f221386ae.bindPopup(popup_a53a7f8e4d724e2c2dd6bc16eda42797)
#         ;
#
#
#
#
#             var marker_55d34a766dd9d993d6fdba456cafe4b8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_422defd389d847e13a2d1794737ccd93);
#
#
#         var popup_5927106686e1410285f8bc465239f5cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f4670d57780ddc965fdbf6e82142800 = $(`&lt;div id=&quot;html_4f4670d57780ddc965fdbf6e82142800&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5927106686e1410285f8bc465239f5cb.setContent(html_4f4670d57780ddc965fdbf6e82142800);
#
#
#
#         marker_55d34a766dd9d993d6fdba456cafe4b8.bindPopup(popup_5927106686e1410285f8bc465239f5cb)
#         ;
#
#
#
#
#             var marker_574208d244da5da628e03142e1cc24e6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_422defd389d847e13a2d1794737ccd93);
#
#
#         var popup_09c5db61a84000c5c67c010689a12250 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25b4153d3d6a643207a38cdc14ac0677 = $(`&lt;div id=&quot;html_25b4153d3d6a643207a38cdc14ac0677&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_09c5db61a84000c5c67c010689a12250.setContent(html_25b4153d3d6a643207a38cdc14ac0677);
#
#
#
#         marker_574208d244da5da628e03142e1cc24e6.bindPopup(popup_09c5db61a84000c5c67c010689a12250)
#         ;
#
#
#
#
#             var marker_c720acf3456e8678f61ea0cc72accaa2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_422defd389d847e13a2d1794737ccd93);
#
#
#         var popup_986aa822b987c33b87dc3cdeaddbc7ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3f41f44eeed1e424b02985eeaca4355 = $(`&lt;div id=&quot;html_a3f41f44eeed1e424b02985eeaca4355&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_986aa822b987c33b87dc3cdeaddbc7ad.setContent(html_a3f41f44eeed1e424b02985eeaca4355);
#
#
#
#         marker_c720acf3456e8678f61ea0cc72accaa2.bindPopup(popup_986aa822b987c33b87dc3cdeaddbc7ad)
#         ;
#
#
#
#
#             var marker_1a726615b3ed76e5993f0f363dddf944 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_422defd389d847e13a2d1794737ccd93);
#
#
#         var popup_2fcc483cbe2ad411b08a8aa46739cebd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1053344ab65a0599317c33afaa3926ca = $(`&lt;div id=&quot;html_1053344ab65a0599317c33afaa3926ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2fcc483cbe2ad411b08a8aa46739cebd.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad7b7ca0cbb4361022ad973752d54a4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad7b7ca0cbb4361022ad973752d54a4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad7b7ca0cbb4361022ad973752d54a4f = L.map(
#                 &quot;map_ad7b7ca0cbb4361022ad973752d54a4f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7236fbfb00ad5bf5a0b71336292c87f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7236fbfb00ad5bf5a0b71336292c87f1.addTo(map_ad7b7ca0cbb4361022ad973752d54a4f);
#
#
#             var feature_group_8828cbf735fc03800fde0ca10d530af7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f6b20dd5107ab894e3aaf02169556fed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8828cbf735fc03800fde0ca10d530af7);
#
#
#         var popup_98c7db8c57958fd78f202f1837de19e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c1db612ee70bf67f13789a6c1079ba9 = $(`&lt;div id=&quot;html_6c1db612ee70bf67f13789a6c1079ba9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_98c7db8c57958fd78f202f1837de19e3.setContent(html_6c1db612ee70bf67f13789a6c1079ba9);
#
#
#
#         marker_f6b20dd5107ab894e3aaf02169556fed.bindPopup(popup_98c7db8c57958fd78f202f1837de19e3)
#         ;
#
#
#
#
#             var marker_ab6cbd21e91c8031f7b6fa50697a416c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8828cbf735fc03800fde0ca10d530af7);
#
#
#         var popup_fd579df757b56bd71023220b39c39a08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b06d0be0f538ec69ad38d4c0784a3ae7 = $(`&lt;div id=&quot;html_b06d0be0f538ec69ad38d4c0784a3ae7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fd579df757b56bd71023220b39c39a08.setContent(html_b06d0be0f538ec69ad38d4c0784a3ae7);
#
#
#
#         marker_ab6cbd21e91c8031f7b6fa50697a416c.bindPopup(popup_fd579df757b56bd71023220b39c39a08)
#         ;
#
#
#
#
#             var marker_f9c8970ecd93b94294c85434cbdd1cfe = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8828cbf735fc03800fde0ca10d530af7);
#
#
#         var popup_1bf2f9d8b9139c65b893b60fa1e8309a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcc4a9129edf45c0771ebc52a0b0dafc = $(`&lt;div id=&quot;html_bcc4a9129edf45c0771ebc52a0b0dafc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1bf2f9d8b9139c65b893b60fa1e8309a.setContent(html_bcc4a9129edf45c0771ebc52a0b0dafc);
#
#
#
#         marker_f9c8970ecd93b94294c85434cbdd1cfe.bindPopup(popup_1bf2f9d8b9139c65b893b60fa1e8309a)
#         ;
#
#
#
#
#             var marker_58ab90cb04cfd45916b3b8eea36f9a16 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8828cbf735fc03800fde0ca10d530af7);
#
#
#         var popup_a43ba858cc598ffdd481c76dd5f2db5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2554c28c777503ef3b29eff4d23f277f = $(`&lt;div id=&quot;html_2554c28c777503ef3b29eff4d23f277f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a43ba858cc598ffdd481c76dd5f2db5c.setContent(html_2554c28c777503ef3b29eff4d23f277f);
#
#
#
#         marker_58ab90cb04cfd45916b3b8eea36f9a16.bindPopup(popup_a43ba858cc598ffdd481c76dd5f2db5c)
#         ;
#
#
#
#
#             var marker_7ec4dc8bf94a7e217d823c4e5e694ed3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8828cbf735fc03800fde0ca10d530af7);
#
#
#         var popup_bcc1338d1df4182320906550af8f32e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9387eda51813d4dc78403789b73f2c92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9387eda51813d4dc78403789b73f2c92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9387eda51813d4dc78403789b73f2c92 = L.map(
#                 &quot;map_9387eda51813d4dc78403789b73f2c92&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f49930a9b67f79a2c7a12f2d0b7e6c80 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f49930a9b67f79a2c7a12f2d0b7e6c80.addTo(map_9387eda51813d4dc78403789b73f2c92);
#
#
#             var feature_group_6e2ffced6b71c66d11eab0b0570a7962 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6e2ffced6b71c66d11eab0b0570a7962.addTo(map_9387eda51813d4dc78403789b73f2c92);
#
#
#             var feature_group_sub_group_7e262a89b2581a43dfac07e036fb6f9a = L.featureGroup.subGroup(
#                 feature_group_6e2ffced6b71c66d11eab0b0570a7962
#             );
#
#
#             var marker_1e4d9d64c4c0f5c59014586d607479fd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e262a89b2581a43dfac07e036fb6f9a);
#
#
#         var popup_1579c1402d8308535bd9d17e62469611 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea888cbf691b6356b7438a7377c0512d = $(`&lt;div id=&quot;html_ea888cbf691b6356b7438a7377c0512d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1579c1402d8308535bd9d17e62469611.setContent(html_ea888cbf691b6356b7438a7377c0512d);
#
#
#
#         marker_1e4d9d64c4c0f5c59014586d607479fd.bindPopup(popup_1579c1402d8308535bd9d17e62469611)
#         ;
#
#
#
#
#             var marker_7ddb863cddc8a0727776bafe8ba5466e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e262a89b2581a43dfac07e036fb6f9a);
#
#
#         var popup_9547ec94c2b041776bbf051ab4e4ec30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af0e452b5922160cbbcd50d3500b9d59 = $(`&lt;div id=&quot;html_af0e452b5922160cbbcd50d3500b9d59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9547ec94c2b041776bbf051ab4e4ec30.setContent(html_af0e452b5922160cbbcd50d3500b9d59);
#
#
#
#         marker_7ddb863cddc8a0727776bafe8ba5466e.bindPopup(popup_9547ec94c2b041776bbf051ab4e4ec30)
#         ;
#
#
#
#
#             var marker_eca85b1abd4cb139f28d61cbd36981bb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e262a89b2581a43dfac07e036fb6f9a);
#
#
#         var popup_cf7e38bc16fc40a51fb719c18a99bab6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_318589e86af70369e7ec47ad796877c8 = $(`&lt;div id=&quot;html_318589e86af70369e7ec47ad796877c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_cf7e38bc16fc40a51fb719c18a99bab6.setContent(html_318589e86af70369e7ec47ad796877c8);
#
#
#
#         marker_eca85b1abd4cb139f28d61cbd36981bb.bindPopup(popup_cf7e38bc16fc40a51fb719c18a99bab6)
#         ;
#
#
#
#
#             var marker_c80f57a797b1dff60ff6cb546f0a5e50 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e262a89b2581a43dfac07e036fb6f9a);
#
#
#         var popup_ce62438ccc7333da61b7b274add35464 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6995280f20375d27d008171a98df9222 = $(`&lt;div id=&quot;html_6995280f20375d27d008171a98df9222&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ce62438ccc7333da61b7b274add35464.setContent(html_6995280f20375d27d008171a98df9222);
#
#
#
#         marker_
