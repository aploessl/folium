# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0bfcc5216c8aa89e4fc3ea2ec1721c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0bfcc5216c8aa89e4fc3ea2ec1721c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0bfcc5216c8aa89e4fc3ea2ec1721c5 = L.map(
#                 &quot;map_a0bfcc5216c8aa89e4fc3ea2ec1721c5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a4abf776f63177c5e3270aa13b57add = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a4abf776f63177c5e3270aa13b57add.addTo(map_a0bfcc5216c8aa89e4fc3ea2ec1721c5);
#
#
#             var marker_630add91a96a4399d45397883574704c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a0bfcc5216c8aa89e4fc3ea2ec1721c5);
#
#
#         var popup_c2aad7cce8c50ebc808a7be6c8e8bb3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a58816408b74e744b020f62bdde2b8de = $(`&lt;div id=&quot;html_a58816408b74e744b020f62bdde2b8de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c2aad7cce8c50ebc808a7be6c8e8bb3a.setContent(html_a58816408b74e744b020f62bdde2b8de);
#
#
#
#         marker_630add91a96a4399d45397883574704c.bindPopup(popup_c2aad7cce8c50ebc808a7be6c8e8bb3a)
#         ;
#
#
#
#
#             var marker_6e29a2efaa17436e160180eb489d316b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a0bfcc5216c8aa89e4fc3ea2ec1721c5);
#
#
#         var popup_2f7f9a9e980f2a54ae02426a3f0f0119 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92b6d63df0eb1230cb9d48d137db336b = $(`&lt;div id=&quot;html_92b6d63df0eb1230cb9d48d137db336b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2f7f9a9e980f2a54ae02426a3f0f0119.setContent(html_92b6d63df0eb1230cb9d48d137db336b);
#
#
#
#         marker_6e29a2efaa17436e160180eb489d316b.bindPopup(popup_2f7f9a9e980f2a54ae02426a3f0f0119)
#         ;
#
#
#
#
#             var marker_badd260238c107345788bd76a8edceb9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a0bfcc5216c8aa89e4fc3ea2ec1721c5);
#
#
#         var popup_85077924fa69f67afe1341da44b277a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a781a0fa299f81602fde2cd2025ed9f8 = $(`&lt;div id=&quot;html_a781a0fa299f81602fde2cd2025ed9f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_85077924fa69f67afe1341da44b277a3.setContent(html_a781a0fa299f81602fde2cd2025ed9f8);
#
#
#
#         marker_badd260238c107345788bd76a8edceb9.bindPopup(popup_85077924fa69f67afe1341da44b277a3)
#         ;
#
#
#
#
#             var marker_6aba778a7d79c8450db0b022f58fd7e5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a0bfcc5216c8aa89e4fc3ea2ec1721c5);
#
#
#         var popup_5bb595fc965a600af0000b6ae4686c18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1fe469de956a3b81ebfa1745f8faab8 = $(`&lt;div id=&quot;html_e1fe469de956a3b81ebfa1745f8faab8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5bb595fc965a600af0000b6ae4686c18.setContent(html_e1fe469de956a3b81ebfa1745f8faab8);
#
#
#
#         marker_6aba778a7d79c8450db0b022f58fd7e5.bindPopup(popup_5bb595fc965a600af0000b6ae4686c18)
#         ;
#
#
#
#
#             var marker_c22463fcf0da9366cada87a74e9a7b24 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a0bfcc5216c8aa89e4fc3ea2ec1721c5);
#
#
#         var popup_0682fa7b01a6188c6bfc616e4aefcf22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_858882002c06ed493ef52f065228c952 = $(`&lt;div id=&quot;html_858882002c06ed493ef52f065228c952&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0682fa7b01a6188c6bfc616e4aefcf22.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a18cdad8d372095de678c864a9adf3e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a18cdad8d372095de678c864a9adf3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a18cdad8d372095de678c864a9adf3e = L.map(
#                 &quot;map_2a18cdad8d372095de678c864a9adf3e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2b1ed74ee7f0f15a20f09134ecd8972 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2b1ed74ee7f0f15a20f09134ecd8972.addTo(map_2a18cdad8d372095de678c864a9adf3e);
#
#
#             var feature_group_42e157ca5ec04014f5da9b5b753e6d0d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_12cf7d7ca70dd18d97f3572d29a3aeed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_42e157ca5ec04014f5da9b5b753e6d0d);
#
#
#         var popup_298aa5eec87f0e8d9fc8cc2f6ead4879 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a39d26c6c1d669a6504c8cdd9eb80cd2 = $(`&lt;div id=&quot;html_a39d26c6c1d669a6504c8cdd9eb80cd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_298aa5eec87f0e8d9fc8cc2f6ead4879.setContent(html_a39d26c6c1d669a6504c8cdd9eb80cd2);
#
#
#
#         marker_12cf7d7ca70dd18d97f3572d29a3aeed.bindPopup(popup_298aa5eec87f0e8d9fc8cc2f6ead4879)
#         ;
#
#
#
#
#             var marker_8cbed1b116378b5484195e3fed4a1ead = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_42e157ca5ec04014f5da9b5b753e6d0d);
#
#
#         var popup_0c02bf14e8e08e4159bd60bdf71e2d2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9232efcd5bff38d6c6e999eda82c1646 = $(`&lt;div id=&quot;html_9232efcd5bff38d6c6e999eda82c1646&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0c02bf14e8e08e4159bd60bdf71e2d2c.setContent(html_9232efcd5bff38d6c6e999eda82c1646);
#
#
#
#         marker_8cbed1b116378b5484195e3fed4a1ead.bindPopup(popup_0c02bf14e8e08e4159bd60bdf71e2d2c)
#         ;
#
#
#
#
#             var marker_995be6bab7ba39c7bbd80944737b1d6e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_42e157ca5ec04014f5da9b5b753e6d0d);
#
#
#         var popup_6a2a69b2c65c352ad8ffa89efce51be0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bbb704db164567a186b69692de390a2 = $(`&lt;div id=&quot;html_3bbb704db164567a186b69692de390a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6a2a69b2c65c352ad8ffa89efce51be0.setContent(html_3bbb704db164567a186b69692de390a2);
#
#
#
#         marker_995be6bab7ba39c7bbd80944737b1d6e.bindPopup(popup_6a2a69b2c65c352ad8ffa89efce51be0)
#         ;
#
#
#
#
#             var marker_47b804434d58db765c06258eab67cab8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_42e157ca5ec04014f5da9b5b753e6d0d);
#
#
#         var popup_dff9a1ec0618077b338ad9b724dd9f6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e3eb63c55d5932d762b3b8157873ca0 = $(`&lt;div id=&quot;html_6e3eb63c55d5932d762b3b8157873ca0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_dff9a1ec0618077b338ad9b724dd9f6b.setContent(html_6e3eb63c55d5932d762b3b8157873ca0);
#
#
#
#         marker_47b804434d58db765c06258eab67cab8.bindPopup(popup_dff9a1ec0618077b338ad9b724dd9f6b)
#         ;
#
#
#
#
#             var marker_41d5ca0c38766941ca4c4398154a0a38 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_42e157ca5ec04014f5da9b5b753e6d0d);
#
#
#         var popup_73b1c67ebd50a01d7c71e19cfe569164 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_415ad873d54eb6d0a5a8e592f0c77ab1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_415ad873d54eb6d0a5a8e592f0c77ab1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_415ad873d54eb6d0a5a8e592f0c77ab1 = L.map(
#                 &quot;map_415ad873d54eb6d0a5a8e592f0c77ab1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07983c9e5d270b26652ef7517ee3bc44 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07983c9e5d270b26652ef7517ee3bc44.addTo(map_415ad873d54eb6d0a5a8e592f0c77ab1);
#
#
#             var feature_group_7ac4d1af2ba7597f8a5e37195353ec1a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7ac4d1af2ba7597f8a5e37195353ec1a.addTo(map_415ad873d54eb6d0a5a8e592f0c77ab1);
#
#
#             var feature_group_sub_group_1ed86ab57920c320b8ad5a6f857acebc = L.featureGroup.subGroup(
#                 feature_group_7ac4d1af2ba7597f8a5e37195353ec1a
#             );
#
#
#             var marker_53d7f311f1e4089cb1e356583eefe857 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1ed86ab57920c320b8ad5a6f857acebc);
#
#
#         var popup_14752b17e6a8a7484d6d648bb68e315e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98a9e7c655bbd37099a2590d451dcbd2 = $(`&lt;div id=&quot;html_98a9e7c655bbd37099a2590d451dcbd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_14752b17e6a8a7484d6d648bb68e315e.setContent(html_98a9e7c655bbd37099a2590d451dcbd2);
#
#
#
#         marker_53d7f311f1e4089cb1e356583eefe857.bindPopup(popup_14752b17e6a8a7484d6d648bb68e315e)
#         ;
#
#
#
#
#             var marker_9e1d09edcf9432bacd5f82d029b6d060 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1ed86ab57920c320b8ad5a6f857acebc);
#
#
#         var popup_b913724011f8ad21232000ab7d3f738c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e010e931a779424f8236e97358ea8e4c = $(`&lt;div id=&quot;html_e010e931a779424f8236e97358ea8e4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b913724011f8ad21232000ab7d3f738c.setContent(html_e010e931a779424f8236e97358ea8e4c);
#
#
#
#         marker_9e1d09edcf9432bacd5f82d029b6d060.bindPopup(popup_b913724011f8ad21232000ab7d3f738c)
#         ;
#
#
#
#
#             var marker_dc5c489b8b25c152b498764b69f4e3f4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1ed86ab57920c320b8ad5a6f857acebc);
#
#
#         var popup_f45ec810bce92b6a8892b2831156a666 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65a62ad79ba66641c69d6e0bf4eaec62 = $(`&lt;div id=&quot;html_65a62ad79ba66641c69d6e0bf4eaec62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f45ec810bce92b6a8892b2831156a666.setContent(html_65a62ad79ba66641c69d6e0bf4eaec62);
#
#
#
#         marker_dc5c489b8b25c152b498764b69f4e3f4.bindPopup(popup_f45ec810bce92b6a8892b2831156a666)
#         ;
#
#
#
#
#             var marker_1c3d36da352955138b39b62d1cb867fa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1ed86ab57920c320b8ad5a6f857acebc);
#
#
#         var popup_208f0399d92a0a0547623cd68cb7859f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c9a99777e63f7b735b29c152493a8e6 = $(`&lt;div id=&quot;html_1c9a99777e63f7b735b29c152493a8e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_208f0399d92a0a0547623cd68cb7859f.setContent(html_1c9a99777e63f7b735b29c152493a8e6);
#
#
#
#         marker_
