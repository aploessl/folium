# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d187435e5052570a29565434fb57448 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d187435e5052570a29565434fb57448&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d187435e5052570a29565434fb57448 = L.map(
#                 &quot;map_6d187435e5052570a29565434fb57448&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b60084ff1515dc1b54710ca6af4ff188 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b60084ff1515dc1b54710ca6af4ff188.addTo(map_6d187435e5052570a29565434fb57448);
#
#
#             var marker_71acaff0cde1022c12f8c2f51b35621c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6d187435e5052570a29565434fb57448);
#
#
#         var popup_7714bf55156503f9e71fe59d3ed0c43d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33f4147d15f4f5c287fa8a1288308a5e = $(`&lt;div id=&quot;html_33f4147d15f4f5c287fa8a1288308a5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7714bf55156503f9e71fe59d3ed0c43d.setContent(html_33f4147d15f4f5c287fa8a1288308a5e);
#
#
#
#         marker_71acaff0cde1022c12f8c2f51b35621c.bindPopup(popup_7714bf55156503f9e71fe59d3ed0c43d)
#         ;
#
#
#
#
#             var marker_bb468843979996feef11b3144146851a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6d187435e5052570a29565434fb57448);
#
#
#         var popup_3dc01495aa3bfaf5d2a2cfac5a1c61a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ae15f222a852c50cae63c7f0ae59ac5 = $(`&lt;div id=&quot;html_1ae15f222a852c50cae63c7f0ae59ac5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3dc01495aa3bfaf5d2a2cfac5a1c61a5.setContent(html_1ae15f222a852c50cae63c7f0ae59ac5);
#
#
#
#         marker_bb468843979996feef11b3144146851a.bindPopup(popup_3dc01495aa3bfaf5d2a2cfac5a1c61a5)
#         ;
#
#
#
#
#             var marker_4cd27600d56fa619e920421884a29ea4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6d187435e5052570a29565434fb57448);
#
#
#         var popup_186dd308c9a6780a4d4ba6042324e5b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8abc39e859917e4a5e23c88c77a43f6 = $(`&lt;div id=&quot;html_f8abc39e859917e4a5e23c88c77a43f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_186dd308c9a6780a4d4ba6042324e5b0.setContent(html_f8abc39e859917e4a5e23c88c77a43f6);
#
#
#
#         marker_4cd27600d56fa619e920421884a29ea4.bindPopup(popup_186dd308c9a6780a4d4ba6042324e5b0)
#         ;
#
#
#
#
#             var marker_4384992a3b2a5d92da90987a188a563b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6d187435e5052570a29565434fb57448);
#
#
#         var popup_283205ef117ce53d8ae4c70ad1449136 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_175904bdf4a7e0a1d17710a2c99dc75e = $(`&lt;div id=&quot;html_175904bdf4a7e0a1d17710a2c99dc75e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_283205ef117ce53d8ae4c70ad1449136.setContent(html_175904bdf4a7e0a1d17710a2c99dc75e);
#
#
#
#         marker_4384992a3b2a5d92da90987a188a563b.bindPopup(popup_283205ef117ce53d8ae4c70ad1449136)
#         ;
#
#
#
#
#             var marker_4e7283dfbb13e1f89f951ae359058916 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6d187435e5052570a29565434fb57448);
#
#
#         var popup_46910753950615666c30e88ebe4da42c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d41e5c932409477e8ee39f7380919409 = $(`&lt;div id=&quot;html_d41e5c932409477e8ee39f7380919409&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_46910753950615666c30e88ebe4da42c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b203c911791835cb2695fe0168f575fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b203c911791835cb2695fe0168f575fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b203c911791835cb2695fe0168f575fa = L.map(
#                 &quot;map_b203c911791835cb2695fe0168f575fa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_acd056c48e8c9902dc1f344f0b37d6ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_acd056c48e8c9902dc1f344f0b37d6ea.addTo(map_b203c911791835cb2695fe0168f575fa);
#
#
#             var feature_group_03ac7835e22fa5ae6ec561f1cffce0d0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_045c4ff4293bda918dab073c6f7f4254 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_03ac7835e22fa5ae6ec561f1cffce0d0);
#
#
#         var popup_bced13594fecbb6ccb432bb911d32ee8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1e864fb947cf9220a866177cafa7fb4 = $(`&lt;div id=&quot;html_e1e864fb947cf9220a866177cafa7fb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_bced13594fecbb6ccb432bb911d32ee8.setContent(html_e1e864fb947cf9220a866177cafa7fb4);
#
#
#
#         marker_045c4ff4293bda918dab073c6f7f4254.bindPopup(popup_bced13594fecbb6ccb432bb911d32ee8)
#         ;
#
#
#
#
#             var marker_57064324faa2cf325d3467ece39ef206 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_03ac7835e22fa5ae6ec561f1cffce0d0);
#
#
#         var popup_9e5a710645f9ef15085e78e875aa94d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e878f18236b6dc03e2125837d71d7568 = $(`&lt;div id=&quot;html_e878f18236b6dc03e2125837d71d7568&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9e5a710645f9ef15085e78e875aa94d3.setContent(html_e878f18236b6dc03e2125837d71d7568);
#
#
#
#         marker_57064324faa2cf325d3467ece39ef206.bindPopup(popup_9e5a710645f9ef15085e78e875aa94d3)
#         ;
#
#
#
#
#             var marker_f9c290fcccc7fbffe2ab6e9843c26901 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_03ac7835e22fa5ae6ec561f1cffce0d0);
#
#
#         var popup_f6efe32982851a5f70f0ce2ec08aad1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c436d5744557c299c3006746d4a09819 = $(`&lt;div id=&quot;html_c436d5744557c299c3006746d4a09819&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f6efe32982851a5f70f0ce2ec08aad1f.setContent(html_c436d5744557c299c3006746d4a09819);
#
#
#
#         marker_f9c290fcccc7fbffe2ab6e9843c26901.bindPopup(popup_f6efe32982851a5f70f0ce2ec08aad1f)
#         ;
#
#
#
#
#             var marker_aa6d09d12a3b296e57e87a8481ccd533 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_03ac7835e22fa5ae6ec561f1cffce0d0);
#
#
#         var popup_60942d88215723db85ec8ed2839b3d56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7da346c5c82df175b1103e0de3c5a9a6 = $(`&lt;div id=&quot;html_7da346c5c82df175b1103e0de3c5a9a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_60942d88215723db85ec8ed2839b3d56.setContent(html_7da346c5c82df175b1103e0de3c5a9a6);
#
#
#
#         marker_aa6d09d12a3b296e57e87a8481ccd533.bindPopup(popup_60942d88215723db85ec8ed2839b3d56)
#         ;
#
#
#
#
#             var marker_123da3fa01ab9374081a11d46d38ee20 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_03ac7835e22fa5ae6ec561f1cffce0d0);
#
#
#         var popup_2b1ddd19bdb51b4e7c59a92cf62eb6d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4642812088764be3fc461cc15b14b1bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4642812088764be3fc461cc15b14b1bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4642812088764be3fc461cc15b14b1bf = L.map(
#                 &quot;map_4642812088764be3fc461cc15b14b1bf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b58fcc2de5878995aca3f894f9d31a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1b58fcc2de5878995aca3f894f9d31a6.addTo(map_4642812088764be3fc461cc15b14b1bf);
#
#
#             var feature_group_64c784a34530e2d919564cce1f47042e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_64c784a34530e2d919564cce1f47042e.addTo(map_4642812088764be3fc461cc15b14b1bf);
#
#
#             var feature_group_sub_group_868d5893229014a6a3450dbce279d875 = L.featureGroup.subGroup(
#                 feature_group_64c784a34530e2d919564cce1f47042e
#             );
#
#
#             var marker_d5b2c8c6b887c38d679f1e70716517ee = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_868d5893229014a6a3450dbce279d875);
#
#
#         var popup_9b6e1ad57cccfb5306b2bfc655df4ef7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d1f918c934be2d89a9fbfaddb63f98e = $(`&lt;div id=&quot;html_7d1f918c934be2d89a9fbfaddb63f98e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9b6e1ad57cccfb5306b2bfc655df4ef7.setContent(html_7d1f918c934be2d89a9fbfaddb63f98e);
#
#
#
#         marker_d5b2c8c6b887c38d679f1e70716517ee.bindPopup(popup_9b6e1ad57cccfb5306b2bfc655df4ef7)
#         ;
#
#
#
#
#             var marker_45c65481fafe47c134ec7f811816a495 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_868d5893229014a6a3450dbce279d875);
#
#
#         var popup_2991f3100256ee900cc3505566bb1963 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c00d27f96817bac51e16fe39af8002e1 = $(`&lt;div id=&quot;html_c00d27f96817bac51e16fe39af8002e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2991f3100256ee900cc3505566bb1963.setContent(html_c00d27f96817bac51e16fe39af8002e1);
#
#
#
#         marker_45c65481fafe47c134ec7f811816a495.bindPopup(popup_2991f3100256ee900cc3505566bb1963)
#         ;
#
#
#
#
#             var marker_580d573a0285d72af7169e943c07b134 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_868d5893229014a6a3450dbce279d875);
#
#
#         var popup_e4be53f0e01474bdcc00e19f667c6042 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4dd9faacf66ee21d2699ee006220fefa = $(`&lt;div id=&quot;html_4dd9faacf66ee21d2699ee006220fefa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e4be53f0e01474bdcc00e19f667c6042.setContent(html_4dd9faacf66ee21d2699ee006220fefa);
#
#
#
#         marker_580d573a0285d72af7169e943c07b134.bindPopup(popup_e4be53f0e01474bdcc00e19f667c6042)
#         ;
#
#
#
#
#             var marker_2e8d6c7113b7db3511fb38b865977ee6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_868d5893229014a6a3450dbce279d875);
#
#
#         var popup_5fa61c9ddc8df5a8192d0692a61512fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b17827cafd0c8127e98aeb38505a3a1 = $(`&lt;div id=&quot;html_8b17827cafd0c8127e98aeb38505a3a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5fa61c9ddc8df5a8192d0692a61512fe.setContent(html_8b17827cafd0c8127e98aeb38505a3a1);
#
#
#
#         marker_
