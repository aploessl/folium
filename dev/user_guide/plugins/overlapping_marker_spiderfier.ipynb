# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39c0cd92350ce019e5282d0f067a12bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39c0cd92350ce019e5282d0f067a12bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39c0cd92350ce019e5282d0f067a12bc = L.map(
#                 &quot;map_39c0cd92350ce019e5282d0f067a12bc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5bd020688f6388cdba8fbe1f43d87115 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5bd020688f6388cdba8fbe1f43d87115.addTo(map_39c0cd92350ce019e5282d0f067a12bc);
#
#
#             var marker_336960c537a4bf7f51bc0d4849922458 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_39c0cd92350ce019e5282d0f067a12bc);
#
#
#         var popup_8e7ac2bcbcd500d4f48f32c382d89cb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_932e94708830ba63b6bf62d21907a218 = $(`&lt;div id=&quot;html_932e94708830ba63b6bf62d21907a218&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8e7ac2bcbcd500d4f48f32c382d89cb9.setContent(html_932e94708830ba63b6bf62d21907a218);
#
#
#
#         marker_336960c537a4bf7f51bc0d4849922458.bindPopup(popup_8e7ac2bcbcd500d4f48f32c382d89cb9)
#         ;
#
#
#
#
#             var marker_15e6bca150774b8ac523c22d31469f1b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_39c0cd92350ce019e5282d0f067a12bc);
#
#
#         var popup_767c2fc993aa432f993bda9e87459aba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_537a56c79cffc0c2569906298bec5a59 = $(`&lt;div id=&quot;html_537a56c79cffc0c2569906298bec5a59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_767c2fc993aa432f993bda9e87459aba.setContent(html_537a56c79cffc0c2569906298bec5a59);
#
#
#
#         marker_15e6bca150774b8ac523c22d31469f1b.bindPopup(popup_767c2fc993aa432f993bda9e87459aba)
#         ;
#
#
#
#
#             var marker_bb06c5d0b2df98a7a04226abec92d0b6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_39c0cd92350ce019e5282d0f067a12bc);
#
#
#         var popup_e3c6b0c2ec27bc44ceb80ab7dfa04743 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f90f42695ec383774f3e27a141f0b5ec = $(`&lt;div id=&quot;html_f90f42695ec383774f3e27a141f0b5ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e3c6b0c2ec27bc44ceb80ab7dfa04743.setContent(html_f90f42695ec383774f3e27a141f0b5ec);
#
#
#
#         marker_bb06c5d0b2df98a7a04226abec92d0b6.bindPopup(popup_e3c6b0c2ec27bc44ceb80ab7dfa04743)
#         ;
#
#
#
#
#             var marker_953f6ce55f8c8d6df27650160a0941f0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_39c0cd92350ce019e5282d0f067a12bc);
#
#
#         var popup_585c90c5a31044b93776eb8e0c52fbac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9fdf42506cc2b84fa23a06593d2c10b = $(`&lt;div id=&quot;html_e9fdf42506cc2b84fa23a06593d2c10b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_585c90c5a31044b93776eb8e0c52fbac.setContent(html_e9fdf42506cc2b84fa23a06593d2c10b);
#
#
#
#         marker_953f6ce55f8c8d6df27650160a0941f0.bindPopup(popup_585c90c5a31044b93776eb8e0c52fbac)
#         ;
#
#
#
#
#             var marker_5f5e7bbc925bfbf932726f7e79ce1a4d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_39c0cd92350ce019e5282d0f067a12bc);
#
#
#         var popup_751824e4920a47840d4837372a1df0f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d24b88a920c5f93fc4e9fc53514c8028 = $(`&lt;div id=&quot;html_d24b88a920c5f93fc4e9fc53514c8028&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_751824e4920a47840d4837372a1df0f6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01ddbbc3f2b3acc5fa03cb485f467e3e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01ddbbc3f2b3acc5fa03cb485f467e3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01ddbbc3f2b3acc5fa03cb485f467e3e = L.map(
#                 &quot;map_01ddbbc3f2b3acc5fa03cb485f467e3e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_638584994eb56a6a265062f19b11ddfb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_638584994eb56a6a265062f19b11ddfb.addTo(map_01ddbbc3f2b3acc5fa03cb485f467e3e);
#
#
#             var feature_group_74aa8e846d05fbfe6c29cfac23657805 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e11e2cc36fcc0b90135265b19f213951 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_74aa8e846d05fbfe6c29cfac23657805);
#
#
#         var popup_b4ec36c953d65be7bf1bb9d5472dd42d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_052b816dc0302296a7f0a8d577c17c59 = $(`&lt;div id=&quot;html_052b816dc0302296a7f0a8d577c17c59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b4ec36c953d65be7bf1bb9d5472dd42d.setContent(html_052b816dc0302296a7f0a8d577c17c59);
#
#
#
#         marker_e11e2cc36fcc0b90135265b19f213951.bindPopup(popup_b4ec36c953d65be7bf1bb9d5472dd42d)
#         ;
#
#
#
#
#             var marker_96b96332181f58144096bdab514ab9d1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_74aa8e846d05fbfe6c29cfac23657805);
#
#
#         var popup_6cab66842f14a8eaf06927f151241ccf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9953ba99dbed375ab096d60caab0a3fb = $(`&lt;div id=&quot;html_9953ba99dbed375ab096d60caab0a3fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6cab66842f14a8eaf06927f151241ccf.setContent(html_9953ba99dbed375ab096d60caab0a3fb);
#
#
#
#         marker_96b96332181f58144096bdab514ab9d1.bindPopup(popup_6cab66842f14a8eaf06927f151241ccf)
#         ;
#
#
#
#
#             var marker_1805ae2c7436fb7b1a62f20318c0587b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_74aa8e846d05fbfe6c29cfac23657805);
#
#
#         var popup_9ef99d9bab6a501322912a821560b2d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b3bc5acc3abf4a77cb19b8f4f4c9bac = $(`&lt;div id=&quot;html_9b3bc5acc3abf4a77cb19b8f4f4c9bac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9ef99d9bab6a501322912a821560b2d9.setContent(html_9b3bc5acc3abf4a77cb19b8f4f4c9bac);
#
#
#
#         marker_1805ae2c7436fb7b1a62f20318c0587b.bindPopup(popup_9ef99d9bab6a501322912a821560b2d9)
#         ;
#
#
#
#
#             var marker_bc355623a70541f99f3fc9288058cef2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_74aa8e846d05fbfe6c29cfac23657805);
#
#
#         var popup_c1c4d15fe7c0c198557b93eccb88e86d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_685978d234cc1a761473cb61395c3bb9 = $(`&lt;div id=&quot;html_685978d234cc1a761473cb61395c3bb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c1c4d15fe7c0c198557b93eccb88e86d.setContent(html_685978d234cc1a761473cb61395c3bb9);
#
#
#
#         marker_bc355623a70541f99f3fc9288058cef2.bindPopup(popup_c1c4d15fe7c0c198557b93eccb88e86d)
#         ;
#
#
#
#
#             var marker_704e1fae0859b0afc6431e85c5ad5b22 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_74aa8e846d05fbfe6c29cfac23657805);
#
#
#         var popup_5b660b371f4dccb34cd913505e1e7f58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_266376ec8f9bdc21028c3043d3fb5f34 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_266376ec8f9bdc21028c3043d3fb5f34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_266376ec8f9bdc21028c3043d3fb5f34 = L.map(
#                 &quot;map_266376ec8f9bdc21028c3043d3fb5f34&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70e95cddfd1bff9a30152040f31d0fc7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70e95cddfd1bff9a30152040f31d0fc7.addTo(map_266376ec8f9bdc21028c3043d3fb5f34);
#
#
#             var feature_group_12162ad793c8b8a34a984e374f6fe33b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_12162ad793c8b8a34a984e374f6fe33b.addTo(map_266376ec8f9bdc21028c3043d3fb5f34);
#
#
#             var feature_group_sub_group_c8f8e32f256d0ff3bf9f8b735924a1e3 = L.featureGroup.subGroup(
#                 feature_group_12162ad793c8b8a34a984e374f6fe33b
#             );
#
#
#             var marker_23f517b8d8f54a9b896642bdbab447d9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8f8e32f256d0ff3bf9f8b735924a1e3);
#
#
#         var popup_1b860fde84eb1b94abb16e1930dcb050 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d99d780d67923321abb57c0397ec4165 = $(`&lt;div id=&quot;html_d99d780d67923321abb57c0397ec4165&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1b860fde84eb1b94abb16e1930dcb050.setContent(html_d99d780d67923321abb57c0397ec4165);
#
#
#
#         marker_23f517b8d8f54a9b896642bdbab447d9.bindPopup(popup_1b860fde84eb1b94abb16e1930dcb050)
#         ;
#
#
#
#
#             var marker_9eced7a297ded295ef1fae7d2e054f28 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8f8e32f256d0ff3bf9f8b735924a1e3);
#
#
#         var popup_3b2d46ce29fb69939787edc4cc0988e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1c62377a3f1da516c00154d92658fe6 = $(`&lt;div id=&quot;html_a1c62377a3f1da516c00154d92658fe6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3b2d46ce29fb69939787edc4cc0988e7.setContent(html_a1c62377a3f1da516c00154d92658fe6);
#
#
#
#         marker_9eced7a297ded295ef1fae7d2e054f28.bindPopup(popup_3b2d46ce29fb69939787edc4cc0988e7)
#         ;
#
#
#
#
#             var marker_4533fc331b4b680f329ed2645d297a33 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8f8e32f256d0ff3bf9f8b735924a1e3);
#
#
#         var popup_7beb5f08ffa7184bde3d8965aeb4fbb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6b9c3ba49c78605b118bac84f45e69f = $(`&lt;div id=&quot;html_c6b9c3ba49c78605b118bac84f45e69f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7beb5f08ffa7184bde3d8965aeb4fbb1.setContent(html_c6b9c3ba49c78605b118bac84f45e69f);
#
#
#
#         marker_4533fc331b4b680f329ed2645d297a33.bindPopup(popup_7beb5f08ffa7184bde3d8965aeb4fbb1)
#         ;
#
#
#
#
#             var marker_26a1d35d3dd8bd87b0be4871b8a05ae8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8f8e32f256d0ff3bf9f8b735924a1e3);
#
#
#         var popup_7c8c04c1d339d75f1b60019cb4e132e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_498a6c27d31a1a780a3bd39853f5d956 = $(`&lt;div id=&quot;html_498a6c27d31a1a780a3bd39853f5d956&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7c8c04c1d339d75f1b60019cb4e132e8.setContent(html_498a6c27d31a1a780a3bd39853f5d956);
#
#
#
#         marker_
