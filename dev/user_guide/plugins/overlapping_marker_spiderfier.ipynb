# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_411e688c7da25eed037a69d29d12bd4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_411e688c7da25eed037a69d29d12bd4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_411e688c7da25eed037a69d29d12bd4f = L.map(
#                 &quot;map_411e688c7da25eed037a69d29d12bd4f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f979acd528b6db9830f507f11b1dda8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5f979acd528b6db9830f507f11b1dda8.addTo(map_411e688c7da25eed037a69d29d12bd4f);
#
#
#             var marker_5fb28e00b2172faf2b7097bdf7d53804 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_411e688c7da25eed037a69d29d12bd4f);
#
#
#         var popup_ea70092c8d9712474b97e9fb91e99af5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a31976d9548416843c1135577d11b42a = $(`&lt;div id=&quot;html_a31976d9548416843c1135577d11b42a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ea70092c8d9712474b97e9fb91e99af5.setContent(html_a31976d9548416843c1135577d11b42a);
#
#
#
#         marker_5fb28e00b2172faf2b7097bdf7d53804.bindPopup(popup_ea70092c8d9712474b97e9fb91e99af5)
#         ;
#
#
#
#
#             var marker_e827438b8d135690117a04356ad776dc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_411e688c7da25eed037a69d29d12bd4f);
#
#
#         var popup_939ebfe3c0e6e17fb355b92c75665464 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_075e7cc902968f5d2916676117f0c42c = $(`&lt;div id=&quot;html_075e7cc902968f5d2916676117f0c42c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_939ebfe3c0e6e17fb355b92c75665464.setContent(html_075e7cc902968f5d2916676117f0c42c);
#
#
#
#         marker_e827438b8d135690117a04356ad776dc.bindPopup(popup_939ebfe3c0e6e17fb355b92c75665464)
#         ;
#
#
#
#
#             var marker_adf5442126c071b2b4432bf48237ee09 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_411e688c7da25eed037a69d29d12bd4f);
#
#
#         var popup_71543f949536a15dfcd2a1f6ed796494 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22d45de6a68936545aab040d00fb1eb9 = $(`&lt;div id=&quot;html_22d45de6a68936545aab040d00fb1eb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_71543f949536a15dfcd2a1f6ed796494.setContent(html_22d45de6a68936545aab040d00fb1eb9);
#
#
#
#         marker_adf5442126c071b2b4432bf48237ee09.bindPopup(popup_71543f949536a15dfcd2a1f6ed796494)
#         ;
#
#
#
#
#             var marker_8e45e6576512d2c204a954e9890d6d2c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_411e688c7da25eed037a69d29d12bd4f);
#
#
#         var popup_5f61d3e182765c0c302fff231e46fe43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_902e1f0f4f3fedf66e8206a2c104a688 = $(`&lt;div id=&quot;html_902e1f0f4f3fedf66e8206a2c104a688&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5f61d3e182765c0c302fff231e46fe43.setContent(html_902e1f0f4f3fedf66e8206a2c104a688);
#
#
#
#         marker_8e45e6576512d2c204a954e9890d6d2c.bindPopup(popup_5f61d3e182765c0c302fff231e46fe43)
#         ;
#
#
#
#
#             var marker_6de6537f6dfd0b39daa3f9df2b7dbef4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_411e688c7da25eed037a69d29d12bd4f);
#
#
#         var popup_5375fc8808aff59398b9368a1bd4ac56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebea97d2f9eb05918816172ce2918cac = $(`&lt;div id=&quot;html_ebea97d2f9eb05918816172ce2918cac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5375fc8808aff59398b9368a1bd4ac56.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e505e055e1a0b1384aff80e4e161eb2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e505e055e1a0b1384aff80e4e161eb2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e505e055e1a0b1384aff80e4e161eb2b = L.map(
#                 &quot;map_e505e055e1a0b1384aff80e4e161eb2b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a403f6e8fa0b6f72caf9659c5c255bb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a403f6e8fa0b6f72caf9659c5c255bb.addTo(map_e505e055e1a0b1384aff80e4e161eb2b);
#
#
#             var feature_group_57126820f7d701bb773249ce8b81866f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e17e69dbf06b4ef8fddaa8abd7011cbd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_57126820f7d701bb773249ce8b81866f);
#
#
#         var popup_b0a730e5bc4172c2d04f145e8235cda6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a72154c8b44b23544afc5e3cd137f552 = $(`&lt;div id=&quot;html_a72154c8b44b23544afc5e3cd137f552&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b0a730e5bc4172c2d04f145e8235cda6.setContent(html_a72154c8b44b23544afc5e3cd137f552);
#
#
#
#         marker_e17e69dbf06b4ef8fddaa8abd7011cbd.bindPopup(popup_b0a730e5bc4172c2d04f145e8235cda6)
#         ;
#
#
#
#
#             var marker_f5bd5b785a54ff4cdb325489afb29777 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_57126820f7d701bb773249ce8b81866f);
#
#
#         var popup_787ed18e256eba6e10277f89457e7dff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a8feeb4b93b77bf2077fa3106e03550 = $(`&lt;div id=&quot;html_0a8feeb4b93b77bf2077fa3106e03550&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_787ed18e256eba6e10277f89457e7dff.setContent(html_0a8feeb4b93b77bf2077fa3106e03550);
#
#
#
#         marker_f5bd5b785a54ff4cdb325489afb29777.bindPopup(popup_787ed18e256eba6e10277f89457e7dff)
#         ;
#
#
#
#
#             var marker_9b4a85fbb37fb0588721d6a45e8da3a8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_57126820f7d701bb773249ce8b81866f);
#
#
#         var popup_1661dfed0673b23476188ee0975b4bc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a068c157eb2dd9779cd05067daf1200a = $(`&lt;div id=&quot;html_a068c157eb2dd9779cd05067daf1200a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1661dfed0673b23476188ee0975b4bc4.setContent(html_a068c157eb2dd9779cd05067daf1200a);
#
#
#
#         marker_9b4a85fbb37fb0588721d6a45e8da3a8.bindPopup(popup_1661dfed0673b23476188ee0975b4bc4)
#         ;
#
#
#
#
#             var marker_621fa677fd7c8596bf70257793ea9646 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_57126820f7d701bb773249ce8b81866f);
#
#
#         var popup_b375b1357a460860f0085a1c497d2eb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21ac20bddfa9528905e1f4fcdf47a839 = $(`&lt;div id=&quot;html_21ac20bddfa9528905e1f4fcdf47a839&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b375b1357a460860f0085a1c497d2eb5.setContent(html_21ac20bddfa9528905e1f4fcdf47a839);
#
#
#
#         marker_621fa677fd7c8596bf70257793ea9646.bindPopup(popup_b375b1357a460860f0085a1c497d2eb5)
#         ;
#
#
#
#
#             var marker_bd7a261ad809c4fcd2d5bb36662aead3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_57126820f7d701bb773249ce8b81866f);
#
#
#         var popup_fa3f95be4edb3a7dd7a78687b1ae6312 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66cb7f0452cf80253d155b202cd5cb3c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66cb7f0452cf80253d155b202cd5cb3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66cb7f0452cf80253d155b202cd5cb3c = L.map(
#                 &quot;map_66cb7f0452cf80253d155b202cd5cb3c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27a2515f6d3c8e7854299116f1febaec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_27a2515f6d3c8e7854299116f1febaec.addTo(map_66cb7f0452cf80253d155b202cd5cb3c);
#
#
#             var feature_group_95f0a196222552338d54d55e7b34597a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_95f0a196222552338d54d55e7b34597a.addTo(map_66cb7f0452cf80253d155b202cd5cb3c);
#
#
#             var feature_group_sub_group_ffa60a2df81d63f6f0b09a4b99ca99a5 = L.featureGroup.subGroup(
#                 feature_group_95f0a196222552338d54d55e7b34597a
#             );
#
#
#             var marker_ee27b4bee61947761860bfc9f9686c3b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffa60a2df81d63f6f0b09a4b99ca99a5);
#
#
#         var popup_e51fa62f26f33fd55595a16d3e93448e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a5005b10bc082e84ba930acc407892f = $(`&lt;div id=&quot;html_7a5005b10bc082e84ba930acc407892f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e51fa62f26f33fd55595a16d3e93448e.setContent(html_7a5005b10bc082e84ba930acc407892f);
#
#
#
#         marker_ee27b4bee61947761860bfc9f9686c3b.bindPopup(popup_e51fa62f26f33fd55595a16d3e93448e)
#         ;
#
#
#
#
#             var marker_894650747cd108df30d20de146d848ee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffa60a2df81d63f6f0b09a4b99ca99a5);
#
#
#         var popup_eb85925c6c0218c5e755c974c07903f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00ee78caebd647296ae6e0473b20256a = $(`&lt;div id=&quot;html_00ee78caebd647296ae6e0473b20256a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_eb85925c6c0218c5e755c974c07903f3.setContent(html_00ee78caebd647296ae6e0473b20256a);
#
#
#
#         marker_894650747cd108df30d20de146d848ee.bindPopup(popup_eb85925c6c0218c5e755c974c07903f3)
#         ;
#
#
#
#
#             var marker_aab7406b3694f3529b136cf128d6d85d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffa60a2df81d63f6f0b09a4b99ca99a5);
#
#
#         var popup_023b5193e439221eec2fe7d32ae5d7d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_582278c1c1973fd0f8231f585037fe59 = $(`&lt;div id=&quot;html_582278c1c1973fd0f8231f585037fe59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_023b5193e439221eec2fe7d32ae5d7d0.setContent(html_582278c1c1973fd0f8231f585037fe59);
#
#
#
#         marker_aab7406b3694f3529b136cf128d6d85d.bindPopup(popup_023b5193e439221eec2fe7d32ae5d7d0)
#         ;
#
#
#
#
#             var marker_872a8f127096e7cf1fa87736e7e78c9a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffa60a2df81d63f6f0b09a4b99ca99a5);
#
#
#         var popup_511914fdef048f559ef9d821036c0d14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94a3ff18bc4fc24609d848694866d4ea = $(`&lt;div id=&quot;html_94a3ff18bc4fc24609d848694866d4ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_511914fdef048f559ef9d821036c0d14.setContent(html_94a3ff18bc4fc24609d848694866d4ea);
#
#
#
#         marker_
