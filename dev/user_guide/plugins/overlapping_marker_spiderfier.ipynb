# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_30ba342ff068da230276420f36be1718 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_30ba342ff068da230276420f36be1718&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_30ba342ff068da230276420f36be1718 = L.map(
#                 &quot;map_30ba342ff068da230276420f36be1718&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de5413c8b7420bf8523bf527a0bf307c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_de5413c8b7420bf8523bf527a0bf307c.addTo(map_30ba342ff068da230276420f36be1718);
#
#
#             var marker_fbbc84279994207a40fa446f2e34d7a0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_30ba342ff068da230276420f36be1718);
#
#
#         var popup_4d5fa543bb342d560ec03d038fd53ac1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a71a41ea4065d8a023d339266c125ac = $(`&lt;div id=&quot;html_9a71a41ea4065d8a023d339266c125ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4d5fa543bb342d560ec03d038fd53ac1.setContent(html_9a71a41ea4065d8a023d339266c125ac);
#
#
#
#         marker_fbbc84279994207a40fa446f2e34d7a0.bindPopup(popup_4d5fa543bb342d560ec03d038fd53ac1)
#         ;
#
#
#
#
#             var marker_c62a87bccec9b2189d48df0bde3a2aec = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_30ba342ff068da230276420f36be1718);
#
#
#         var popup_2644d1e0dce5c12b3a1143bdf1f3f8a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e840cd7d2abc7b2075fe4a6731f69062 = $(`&lt;div id=&quot;html_e840cd7d2abc7b2075fe4a6731f69062&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2644d1e0dce5c12b3a1143bdf1f3f8a2.setContent(html_e840cd7d2abc7b2075fe4a6731f69062);
#
#
#
#         marker_c62a87bccec9b2189d48df0bde3a2aec.bindPopup(popup_2644d1e0dce5c12b3a1143bdf1f3f8a2)
#         ;
#
#
#
#
#             var marker_c163f39362e60a359398dac4079ad0de = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_30ba342ff068da230276420f36be1718);
#
#
#         var popup_5127f0ae476e743bac96b7094c1d90c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38fa5836bae60c0344d77622ff081e88 = $(`&lt;div id=&quot;html_38fa5836bae60c0344d77622ff081e88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5127f0ae476e743bac96b7094c1d90c9.setContent(html_38fa5836bae60c0344d77622ff081e88);
#
#
#
#         marker_c163f39362e60a359398dac4079ad0de.bindPopup(popup_5127f0ae476e743bac96b7094c1d90c9)
#         ;
#
#
#
#
#             var marker_38f7f4e60e7ba29bacaacbae063c0fa4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_30ba342ff068da230276420f36be1718);
#
#
#         var popup_69b4063706f4cfd13422809f99947067 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7e6513f20bdfce7996afe93e8bcf61f = $(`&lt;div id=&quot;html_d7e6513f20bdfce7996afe93e8bcf61f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_69b4063706f4cfd13422809f99947067.setContent(html_d7e6513f20bdfce7996afe93e8bcf61f);
#
#
#
#         marker_38f7f4e60e7ba29bacaacbae063c0fa4.bindPopup(popup_69b4063706f4cfd13422809f99947067)
#         ;
#
#
#
#
#             var marker_74e045a84aeba0bf4a16eaad8ae4e054 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_30ba342ff068da230276420f36be1718);
#
#
#         var popup_b9cad0022b576b746a31eb753593b3e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d09e2e370896ea8dfcdf967433337f4d = $(`&lt;div id=&quot;html_d09e2e370896ea8dfcdf967433337f4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b9cad0022b576b746a31eb753593b3e9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b46a4fcb1a9f07c12b356d24c87d765 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b46a4fcb1a9f07c12b356d24c87d765&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b46a4fcb1a9f07c12b356d24c87d765 = L.map(
#                 &quot;map_2b46a4fcb1a9f07c12b356d24c87d765&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7d31f0693bf082bac3319222720d574 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f7d31f0693bf082bac3319222720d574.addTo(map_2b46a4fcb1a9f07c12b356d24c87d765);
#
#
#             var feature_group_7f31179b7fd9706d919a53e0bcf474d4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_20547aeab484447d3a3ea849f1252c6d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7f31179b7fd9706d919a53e0bcf474d4);
#
#
#         var popup_7d3e74497540b53390a2c7d4d915aeb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fca21762f7b37a37a138503e0120ee9b = $(`&lt;div id=&quot;html_fca21762f7b37a37a138503e0120ee9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7d3e74497540b53390a2c7d4d915aeb3.setContent(html_fca21762f7b37a37a138503e0120ee9b);
#
#
#
#         marker_20547aeab484447d3a3ea849f1252c6d.bindPopup(popup_7d3e74497540b53390a2c7d4d915aeb3)
#         ;
#
#
#
#
#             var marker_1fa6baf13547de068551488a501dcd64 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7f31179b7fd9706d919a53e0bcf474d4);
#
#
#         var popup_cf1fc2d4c2a1af981ea939a8ad47e5f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66f6aabed08df0e5a7fb04e8478acbec = $(`&lt;div id=&quot;html_66f6aabed08df0e5a7fb04e8478acbec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cf1fc2d4c2a1af981ea939a8ad47e5f1.setContent(html_66f6aabed08df0e5a7fb04e8478acbec);
#
#
#
#         marker_1fa6baf13547de068551488a501dcd64.bindPopup(popup_cf1fc2d4c2a1af981ea939a8ad47e5f1)
#         ;
#
#
#
#
#             var marker_609dac776ffd1599ef03cb32e0b46099 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7f31179b7fd9706d919a53e0bcf474d4);
#
#
#         var popup_cf21658030de8e8591d4ca4e85f2af88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_252731ecf51d7d6dcc458c87d4c53407 = $(`&lt;div id=&quot;html_252731ecf51d7d6dcc458c87d4c53407&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cf21658030de8e8591d4ca4e85f2af88.setContent(html_252731ecf51d7d6dcc458c87d4c53407);
#
#
#
#         marker_609dac776ffd1599ef03cb32e0b46099.bindPopup(popup_cf21658030de8e8591d4ca4e85f2af88)
#         ;
#
#
#
#
#             var marker_df2f0a9822f0fb9aa727c93f477fbafa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7f31179b7fd9706d919a53e0bcf474d4);
#
#
#         var popup_026248b303646596f553d93edf9aed36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7be9a3dd7e75fc7fc0c0cff0a98c1b1c = $(`&lt;div id=&quot;html_7be9a3dd7e75fc7fc0c0cff0a98c1b1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_026248b303646596f553d93edf9aed36.setContent(html_7be9a3dd7e75fc7fc0c0cff0a98c1b1c);
#
#
#
#         marker_df2f0a9822f0fb9aa727c93f477fbafa.bindPopup(popup_026248b303646596f553d93edf9aed36)
#         ;
#
#
#
#
#             var marker_f1a20725cb59ff87c7cdcb881c45a4dd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7f31179b7fd9706d919a53e0bcf474d4);
#
#
#         var popup_763f76fe4d35d7e7f4b848b7648bd9e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b44f6147021f9103fa41c85a26d23683 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b44f6147021f9103fa41c85a26d23683&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b44f6147021f9103fa41c85a26d23683 = L.map(
#                 &quot;map_b44f6147021f9103fa41c85a26d23683&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66057f09a72b3a3754e3688993d140ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_66057f09a72b3a3754e3688993d140ee.addTo(map_b44f6147021f9103fa41c85a26d23683);
#
#
#             var feature_group_0bf4de66eabb2f259f7ecd498665c4fb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0bf4de66eabb2f259f7ecd498665c4fb.addTo(map_b44f6147021f9103fa41c85a26d23683);
#
#
#             var feature_group_sub_group_8913ea2489fc2cb99de6ec8324b35344 = L.featureGroup.subGroup(
#                 feature_group_0bf4de66eabb2f259f7ecd498665c4fb
#             );
#
#
#             var marker_4e140f03dd69871d7833e87570fcd15f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8913ea2489fc2cb99de6ec8324b35344);
#
#
#         var popup_e2522b398a58d75adbb16e7698d51030 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb398a35898c93f00e4e7d6efe326f67 = $(`&lt;div id=&quot;html_bb398a35898c93f00e4e7d6efe326f67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e2522b398a58d75adbb16e7698d51030.setContent(html_bb398a35898c93f00e4e7d6efe326f67);
#
#
#
#         marker_4e140f03dd69871d7833e87570fcd15f.bindPopup(popup_e2522b398a58d75adbb16e7698d51030)
#         ;
#
#
#
#
#             var marker_77148bcdd25c147d1362d53f7ea63e84 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8913ea2489fc2cb99de6ec8324b35344);
#
#
#         var popup_8ae605ce1e1933e620893e18838ccd65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73350e228a9104203bdac57d0105161b = $(`&lt;div id=&quot;html_73350e228a9104203bdac57d0105161b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8ae605ce1e1933e620893e18838ccd65.setContent(html_73350e228a9104203bdac57d0105161b);
#
#
#
#         marker_77148bcdd25c147d1362d53f7ea63e84.bindPopup(popup_8ae605ce1e1933e620893e18838ccd65)
#         ;
#
#
#
#
#             var marker_18c2150d92ccfa887ce51ba4a9c002b8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8913ea2489fc2cb99de6ec8324b35344);
#
#
#         var popup_dc9bcefbccc9943de1b7f9326b55ea94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5adaf3ebe5a8a5f59d5761cef1d58a27 = $(`&lt;div id=&quot;html_5adaf3ebe5a8a5f59d5761cef1d58a27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_dc9bcefbccc9943de1b7f9326b55ea94.setContent(html_5adaf3ebe5a8a5f59d5761cef1d58a27);
#
#
#
#         marker_18c2150d92ccfa887ce51ba4a9c002b8.bindPopup(popup_dc9bcefbccc9943de1b7f9326b55ea94)
#         ;
#
#
#
#
#             var marker_a8412fc75759984d66e243abe91a192f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8913ea2489fc2cb99de6ec8324b35344);
#
#
#         var popup_22da59f353d9e629f277a3eb00c6f354 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3bd7be6d69f93f20038ca0608845c14 = $(`&lt;div id=&quot;html_d3bd7be6d69f93f20038ca0608845c14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_22da59f353d9e629f277a3eb00c6f354.setContent(html_d3bd7be6d69f93f20038ca0608845c14);
#
#
#
#         marker_
