# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5ccfd8dc335f0333b25584fd9af5181 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5ccfd8dc335f0333b25584fd9af5181&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5ccfd8dc335f0333b25584fd9af5181 = L.map(
#                 &quot;map_f5ccfd8dc335f0333b25584fd9af5181&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2695114048c2750db42e1026db384352 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2695114048c2750db42e1026db384352.addTo(map_f5ccfd8dc335f0333b25584fd9af5181);
#
#
#             var marker_766df49202dc9f8e9f9fed37cc5d4dc2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f5ccfd8dc335f0333b25584fd9af5181);
#
#
#         var popup_dedf316f01711cf738f91c1dd6f63ac9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8584689afd54ae58c90a26e6ba92a331 = $(`&lt;div id=&quot;html_8584689afd54ae58c90a26e6ba92a331&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_dedf316f01711cf738f91c1dd6f63ac9.setContent(html_8584689afd54ae58c90a26e6ba92a331);
#
#
#
#         marker_766df49202dc9f8e9f9fed37cc5d4dc2.bindPopup(popup_dedf316f01711cf738f91c1dd6f63ac9)
#         ;
#
#
#
#
#             var marker_24310c3bccb41a29471e175ea67bdcc7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f5ccfd8dc335f0333b25584fd9af5181);
#
#
#         var popup_a5b5b4e305569b9a0e89a02749dea3c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22dcec484fe9d1f72f73a0f51c8651b0 = $(`&lt;div id=&quot;html_22dcec484fe9d1f72f73a0f51c8651b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a5b5b4e305569b9a0e89a02749dea3c0.setContent(html_22dcec484fe9d1f72f73a0f51c8651b0);
#
#
#
#         marker_24310c3bccb41a29471e175ea67bdcc7.bindPopup(popup_a5b5b4e305569b9a0e89a02749dea3c0)
#         ;
#
#
#
#
#             var marker_c0ab15cde7357a16758382cf509701ac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f5ccfd8dc335f0333b25584fd9af5181);
#
#
#         var popup_dce7f0a2ccce7bc713296db818f68ca3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94f2cc6d1d51b2ddb2e2224ebf21b629 = $(`&lt;div id=&quot;html_94f2cc6d1d51b2ddb2e2224ebf21b629&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dce7f0a2ccce7bc713296db818f68ca3.setContent(html_94f2cc6d1d51b2ddb2e2224ebf21b629);
#
#
#
#         marker_c0ab15cde7357a16758382cf509701ac.bindPopup(popup_dce7f0a2ccce7bc713296db818f68ca3)
#         ;
#
#
#
#
#             var marker_92002b97fc603911f7596cc3b9f29422 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f5ccfd8dc335f0333b25584fd9af5181);
#
#
#         var popup_9461e37fc54058a95d87d09178814ea7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_126bfbb4fd2c5c023fbfe74fdab8f210 = $(`&lt;div id=&quot;html_126bfbb4fd2c5c023fbfe74fdab8f210&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9461e37fc54058a95d87d09178814ea7.setContent(html_126bfbb4fd2c5c023fbfe74fdab8f210);
#
#
#
#         marker_92002b97fc603911f7596cc3b9f29422.bindPopup(popup_9461e37fc54058a95d87d09178814ea7)
#         ;
#
#
#
#
#             var marker_81c21fb18e7fc9e469e30e53d30f54be = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f5ccfd8dc335f0333b25584fd9af5181);
#
#
#         var popup_6a9667ce5d80da9a9236967694808480 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed5fc1a86a129afa895c8362e4809f35 = $(`&lt;div id=&quot;html_ed5fc1a86a129afa895c8362e4809f35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6a9667ce5d80da9a9236967694808480.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7677955a36cea8158020a0bfd42df5f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7677955a36cea8158020a0bfd42df5f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7677955a36cea8158020a0bfd42df5f0 = L.map(
#                 &quot;map_7677955a36cea8158020a0bfd42df5f0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f79456c0e3033880f864ff32f412717d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f79456c0e3033880f864ff32f412717d.addTo(map_7677955a36cea8158020a0bfd42df5f0);
#
#
#             var feature_group_c4e2872af8269c738ff93930670fe3cf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_07b2c01a63399a82a7b3a9726262f462 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c4e2872af8269c738ff93930670fe3cf);
#
#
#         var popup_6834c851e9197968aa5b5a7a6f3290b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_020ff77dc5c573aaa11e9f792f7d51ad = $(`&lt;div id=&quot;html_020ff77dc5c573aaa11e9f792f7d51ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6834c851e9197968aa5b5a7a6f3290b6.setContent(html_020ff77dc5c573aaa11e9f792f7d51ad);
#
#
#
#         marker_07b2c01a63399a82a7b3a9726262f462.bindPopup(popup_6834c851e9197968aa5b5a7a6f3290b6)
#         ;
#
#
#
#
#             var marker_dcfb09e05051c235cb6cf3916ca92c88 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c4e2872af8269c738ff93930670fe3cf);
#
#
#         var popup_2a743d63cd20496d006f1c87e414ee7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_335fe53d2c117bfe1f04b14f975bf34a = $(`&lt;div id=&quot;html_335fe53d2c117bfe1f04b14f975bf34a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2a743d63cd20496d006f1c87e414ee7a.setContent(html_335fe53d2c117bfe1f04b14f975bf34a);
#
#
#
#         marker_dcfb09e05051c235cb6cf3916ca92c88.bindPopup(popup_2a743d63cd20496d006f1c87e414ee7a)
#         ;
#
#
#
#
#             var marker_ff5a721470e724e6c6d1ce8ad4653ccc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c4e2872af8269c738ff93930670fe3cf);
#
#
#         var popup_d4bf7129f5838ae39c55c4b7da2f72ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3cc378ffabf9a6664dca7fcb8bf2bac = $(`&lt;div id=&quot;html_f3cc378ffabf9a6664dca7fcb8bf2bac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d4bf7129f5838ae39c55c4b7da2f72ce.setContent(html_f3cc378ffabf9a6664dca7fcb8bf2bac);
#
#
#
#         marker_ff5a721470e724e6c6d1ce8ad4653ccc.bindPopup(popup_d4bf7129f5838ae39c55c4b7da2f72ce)
#         ;
#
#
#
#
#             var marker_010367203ce08069f30c9d3d619bd000 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c4e2872af8269c738ff93930670fe3cf);
#
#
#         var popup_dc7c4d4e635218b05449e945361d23ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_169fa4419aa3a3249bd8af43d0967769 = $(`&lt;div id=&quot;html_169fa4419aa3a3249bd8af43d0967769&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_dc7c4d4e635218b05449e945361d23ac.setContent(html_169fa4419aa3a3249bd8af43d0967769);
#
#
#
#         marker_010367203ce08069f30c9d3d619bd000.bindPopup(popup_dc7c4d4e635218b05449e945361d23ac)
#         ;
#
#
#
#
#             var marker_bb7ce253a57ea429496fcbe8ea0d89ef = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c4e2872af8269c738ff93930670fe3cf);
#
#
#         var popup_53aef8b85e1d4ada603fdc394d683e45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b47ac41f04f1ba30f43cfc1854e6af73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b47ac41f04f1ba30f43cfc1854e6af73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b47ac41f04f1ba30f43cfc1854e6af73 = L.map(
#                 &quot;map_b47ac41f04f1ba30f43cfc1854e6af73&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09e34cf66f29bb76577c7afa487aafbb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09e34cf66f29bb76577c7afa487aafbb.addTo(map_b47ac41f04f1ba30f43cfc1854e6af73);
#
#
#             var feature_group_d0d0daeb0f3aa9ba4b3dfdbedfd2d72a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d0d0daeb0f3aa9ba4b3dfdbedfd2d72a.addTo(map_b47ac41f04f1ba30f43cfc1854e6af73);
#
#
#             var feature_group_sub_group_01a1a335b84d7f587a57e57e1ddf46fd = L.featureGroup.subGroup(
#                 feature_group_d0d0daeb0f3aa9ba4b3dfdbedfd2d72a
#             );
#
#
#             var marker_831df6bac8a9a7c0aed5375230d83b82 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_01a1a335b84d7f587a57e57e1ddf46fd);
#
#
#         var popup_a195da80a0d670cf1465c428878f04b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db9f60da5c86b06ad7e8f98e8aa45529 = $(`&lt;div id=&quot;html_db9f60da5c86b06ad7e8f98e8aa45529&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a195da80a0d670cf1465c428878f04b2.setContent(html_db9f60da5c86b06ad7e8f98e8aa45529);
#
#
#
#         marker_831df6bac8a9a7c0aed5375230d83b82.bindPopup(popup_a195da80a0d670cf1465c428878f04b2)
#         ;
#
#
#
#
#             var marker_fa0a71d29d8aef1f07c08ebefbb76555 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_01a1a335b84d7f587a57e57e1ddf46fd);
#
#
#         var popup_cfef69b3175dda6a7314ec48d8359c11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db91d5e2f8a7c23767dfb75c27c7780f = $(`&lt;div id=&quot;html_db91d5e2f8a7c23767dfb75c27c7780f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cfef69b3175dda6a7314ec48d8359c11.setContent(html_db91d5e2f8a7c23767dfb75c27c7780f);
#
#
#
#         marker_fa0a71d29d8aef1f07c08ebefbb76555.bindPopup(popup_cfef69b3175dda6a7314ec48d8359c11)
#         ;
#
#
#
#
#             var marker_01259b69dc5bac5d75f58d198e49385e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_01a1a335b84d7f587a57e57e1ddf46fd);
#
#
#         var popup_88ada75c41a89203cef8799b62841825 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bb267f8b6de4a1ae885c19a745abf93 = $(`&lt;div id=&quot;html_3bb267f8b6de4a1ae885c19a745abf93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_88ada75c41a89203cef8799b62841825.setContent(html_3bb267f8b6de4a1ae885c19a745abf93);
#
#
#
#         marker_01259b69dc5bac5d75f58d198e49385e.bindPopup(popup_88ada75c41a89203cef8799b62841825)
#         ;
#
#
#
#
#             var marker_26e5dc59b4ca88bc2ad206607d983dc9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_01a1a335b84d7f587a57e57e1ddf46fd);
#
#
#         var popup_37e98d016741d14e1ba14045b7256160 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_905dc552b1f73c63cf74f108808da127 = $(`&lt;div id=&quot;html_905dc552b1f73c63cf74f108808da127&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_37e98d016741d14e1ba14045b7256160.setContent(html_905dc552b1f73c63cf74f108808da127);
#
#
#
#         marker_
