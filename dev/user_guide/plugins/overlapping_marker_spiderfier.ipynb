# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_768119dd17a75f071783531ea448e976 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_768119dd17a75f071783531ea448e976&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_768119dd17a75f071783531ea448e976 = L.map(
#                 &quot;map_768119dd17a75f071783531ea448e976&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d014547b2216cdac4132b2c1c028b1e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d014547b2216cdac4132b2c1c028b1e.addTo(map_768119dd17a75f071783531ea448e976);
#
#
#             var marker_2a2023ab33475af04127141c6cfd5e53 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_768119dd17a75f071783531ea448e976);
#
#
#         var popup_b5447fcb8293fd2ac0dec3ce5f3e907d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d4b876ac2d93bee05d78f94cef4836f = $(`&lt;div id=&quot;html_2d4b876ac2d93bee05d78f94cef4836f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b5447fcb8293fd2ac0dec3ce5f3e907d.setContent(html_2d4b876ac2d93bee05d78f94cef4836f);
#
#
#
#         marker_2a2023ab33475af04127141c6cfd5e53.bindPopup(popup_b5447fcb8293fd2ac0dec3ce5f3e907d)
#         ;
#
#
#
#
#             var marker_4dd1ba04cac7c304495d3cc4ee9f6ac8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_768119dd17a75f071783531ea448e976);
#
#
#         var popup_8ec88a1bb037d590acde545866cd7326 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96b95a5fd3282a7c72ebb4daf9639603 = $(`&lt;div id=&quot;html_96b95a5fd3282a7c72ebb4daf9639603&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8ec88a1bb037d590acde545866cd7326.setContent(html_96b95a5fd3282a7c72ebb4daf9639603);
#
#
#
#         marker_4dd1ba04cac7c304495d3cc4ee9f6ac8.bindPopup(popup_8ec88a1bb037d590acde545866cd7326)
#         ;
#
#
#
#
#             var marker_b37822a180a3c000df509fcd10e6a2e7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_768119dd17a75f071783531ea448e976);
#
#
#         var popup_a5d66c96eef2cc8c99f1df2311eba37a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80f44469d8642d6c4d3307ddbf45ffcb = $(`&lt;div id=&quot;html_80f44469d8642d6c4d3307ddbf45ffcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a5d66c96eef2cc8c99f1df2311eba37a.setContent(html_80f44469d8642d6c4d3307ddbf45ffcb);
#
#
#
#         marker_b37822a180a3c000df509fcd10e6a2e7.bindPopup(popup_a5d66c96eef2cc8c99f1df2311eba37a)
#         ;
#
#
#
#
#             var marker_885d0cf4431d368f54fac56242cbec78 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_768119dd17a75f071783531ea448e976);
#
#
#         var popup_4668ff90ddf3b80f4dae2c649a013b3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5cc713fbddc2b935c3796be56a8171a5 = $(`&lt;div id=&quot;html_5cc713fbddc2b935c3796be56a8171a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4668ff90ddf3b80f4dae2c649a013b3e.setContent(html_5cc713fbddc2b935c3796be56a8171a5);
#
#
#
#         marker_885d0cf4431d368f54fac56242cbec78.bindPopup(popup_4668ff90ddf3b80f4dae2c649a013b3e)
#         ;
#
#
#
#
#             var marker_5465cdd2235933360039f864719894a2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_768119dd17a75f071783531ea448e976);
#
#
#         var popup_cc8fa45f3e590e611b50c179b8196458 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b18b9e4bfe420abc68af249dd1601f7 = $(`&lt;div id=&quot;html_4b18b9e4bfe420abc68af249dd1601f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_cc8fa45f3e590e611b50c179b8196458.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa954014e885ea7bebc866932ba6ee1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa954014e885ea7bebc866932ba6ee1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa954014e885ea7bebc866932ba6ee1a = L.map(
#                 &quot;map_fa954014e885ea7bebc866932ba6ee1a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60b605267601b80f1981876baa099476 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_60b605267601b80f1981876baa099476.addTo(map_fa954014e885ea7bebc866932ba6ee1a);
#
#
#             var feature_group_79d6ce4b9f291691c9cf3e48fd10b077 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6e6a313f861edf04a46d734872dccd45 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_79d6ce4b9f291691c9cf3e48fd10b077);
#
#
#         var popup_00fe213db8e4becef0eb7ddeca5cd81a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61425a810be7ac785f4f82d1da479ffc = $(`&lt;div id=&quot;html_61425a810be7ac785f4f82d1da479ffc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_00fe213db8e4becef0eb7ddeca5cd81a.setContent(html_61425a810be7ac785f4f82d1da479ffc);
#
#
#
#         marker_6e6a313f861edf04a46d734872dccd45.bindPopup(popup_00fe213db8e4becef0eb7ddeca5cd81a)
#         ;
#
#
#
#
#             var marker_0a38f82d826cbce4332555fdecb67f22 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_79d6ce4b9f291691c9cf3e48fd10b077);
#
#
#         var popup_397de6b434da3fb8ec3e540ab7a740c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84eb0ddb7c33126d23473dea101f1128 = $(`&lt;div id=&quot;html_84eb0ddb7c33126d23473dea101f1128&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_397de6b434da3fb8ec3e540ab7a740c1.setContent(html_84eb0ddb7c33126d23473dea101f1128);
#
#
#
#         marker_0a38f82d826cbce4332555fdecb67f22.bindPopup(popup_397de6b434da3fb8ec3e540ab7a740c1)
#         ;
#
#
#
#
#             var marker_a169b8e3a65a229f094966e9183528ff = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_79d6ce4b9f291691c9cf3e48fd10b077);
#
#
#         var popup_3049862a35c346ba04969fadf6871919 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d7ee98bc2b11a57dab547599fff80ef = $(`&lt;div id=&quot;html_6d7ee98bc2b11a57dab547599fff80ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3049862a35c346ba04969fadf6871919.setContent(html_6d7ee98bc2b11a57dab547599fff80ef);
#
#
#
#         marker_a169b8e3a65a229f094966e9183528ff.bindPopup(popup_3049862a35c346ba04969fadf6871919)
#         ;
#
#
#
#
#             var marker_f0f0cfcc59347168d802464b13e19d18 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_79d6ce4b9f291691c9cf3e48fd10b077);
#
#
#         var popup_5e55ae3a4439fa67951f2c304ff6a804 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45895a69f1aa35f6bd35ddb1bb6feeb3 = $(`&lt;div id=&quot;html_45895a69f1aa35f6bd35ddb1bb6feeb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5e55ae3a4439fa67951f2c304ff6a804.setContent(html_45895a69f1aa35f6bd35ddb1bb6feeb3);
#
#
#
#         marker_f0f0cfcc59347168d802464b13e19d18.bindPopup(popup_5e55ae3a4439fa67951f2c304ff6a804)
#         ;
#
#
#
#
#             var marker_972ae5db255ac87c769926b939291853 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_79d6ce4b9f291691c9cf3e48fd10b077);
#
#
#         var popup_af4fe4248cc3fd79c0240971a9232033 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff403e4ca232911e7f55ba452f51d8cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff403e4ca232911e7f55ba452f51d8cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff403e4ca232911e7f55ba452f51d8cb = L.map(
#                 &quot;map_ff403e4ca232911e7f55ba452f51d8cb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ee58ee1640390219647a1c487217297 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ee58ee1640390219647a1c487217297.addTo(map_ff403e4ca232911e7f55ba452f51d8cb);
#
#
#             var feature_group_720b35008a93faa72528acca34198a3c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_720b35008a93faa72528acca34198a3c.addTo(map_ff403e4ca232911e7f55ba452f51d8cb);
#
#
#             var feature_group_sub_group_82cc63ac89fec672874daf6597e2b2e7 = L.featureGroup.subGroup(
#                 feature_group_720b35008a93faa72528acca34198a3c
#             );
#
#
#             var marker_7ec7582ea34c38bad1ace172755b6d66 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_82cc63ac89fec672874daf6597e2b2e7);
#
#
#         var popup_6f6b93e82c1a73cefac7b411f6c1b4e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63d399e831773276151bc803cf512dec = $(`&lt;div id=&quot;html_63d399e831773276151bc803cf512dec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6f6b93e82c1a73cefac7b411f6c1b4e5.setContent(html_63d399e831773276151bc803cf512dec);
#
#
#
#         marker_7ec7582ea34c38bad1ace172755b6d66.bindPopup(popup_6f6b93e82c1a73cefac7b411f6c1b4e5)
#         ;
#
#
#
#
#             var marker_944b72d09ac55024c82c031bde16e800 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_82cc63ac89fec672874daf6597e2b2e7);
#
#
#         var popup_a07e6c739f6ff9b9d6879289a0afed38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5ca5255ae43b370e37a2ce2d5f277ba = $(`&lt;div id=&quot;html_a5ca5255ae43b370e37a2ce2d5f277ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a07e6c739f6ff9b9d6879289a0afed38.setContent(html_a5ca5255ae43b370e37a2ce2d5f277ba);
#
#
#
#         marker_944b72d09ac55024c82c031bde16e800.bindPopup(popup_a07e6c739f6ff9b9d6879289a0afed38)
#         ;
#
#
#
#
#             var marker_b25e62b94dd83799512fb7baa1688944 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_82cc63ac89fec672874daf6597e2b2e7);
#
#
#         var popup_37926a60aee7583e51d6298d0a2bb549 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fe7d1accc55188701dd534f01cdaf2e = $(`&lt;div id=&quot;html_6fe7d1accc55188701dd534f01cdaf2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_37926a60aee7583e51d6298d0a2bb549.setContent(html_6fe7d1accc55188701dd534f01cdaf2e);
#
#
#
#         marker_b25e62b94dd83799512fb7baa1688944.bindPopup(popup_37926a60aee7583e51d6298d0a2bb549)
#         ;
#
#
#
#
#             var marker_fdacd1b1948c6974db90a96310345eec = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_82cc63ac89fec672874daf6597e2b2e7);
#
#
#         var popup_ef257b798cce3fabedf269cf26025fe8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96293cb8b5383c5a7b25c284dac585ea = $(`&lt;div id=&quot;html_96293cb8b5383c5a7b25c284dac585ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ef257b798cce3fabedf269cf26025fe8.setContent(html_96293cb8b5383c5a7b25c284dac585ea);
#
#
#
#         marker_
