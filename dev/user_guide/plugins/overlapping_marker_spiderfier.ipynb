# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_338eedfabf6414b7305ee1942ddd87a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_338eedfabf6414b7305ee1942ddd87a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_338eedfabf6414b7305ee1942ddd87a1 = L.map(
#                 &quot;map_338eedfabf6414b7305ee1942ddd87a1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22c55eb6b6774b979071b57cc2b99441 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_22c55eb6b6774b979071b57cc2b99441.addTo(map_338eedfabf6414b7305ee1942ddd87a1);
#
#
#             var marker_244b0d36aee276081634d1024ef3eb52 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_338eedfabf6414b7305ee1942ddd87a1);
#
#
#         var popup_1a2f703611173a7c3a4c5e7b654e3f58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42ed2b54ec7bf3a62771fde8bbb97866 = $(`&lt;div id=&quot;html_42ed2b54ec7bf3a62771fde8bbb97866&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1a2f703611173a7c3a4c5e7b654e3f58.setContent(html_42ed2b54ec7bf3a62771fde8bbb97866);
#
#
#
#         marker_244b0d36aee276081634d1024ef3eb52.bindPopup(popup_1a2f703611173a7c3a4c5e7b654e3f58)
#         ;
#
#
#
#
#             var marker_ed50c4f63253f7492af622518c3bb95d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_338eedfabf6414b7305ee1942ddd87a1);
#
#
#         var popup_7ad5e50d54ed3ddeae06760321c24fd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0206d812a8e5ffe7bbf43a07edd0178 = $(`&lt;div id=&quot;html_c0206d812a8e5ffe7bbf43a07edd0178&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7ad5e50d54ed3ddeae06760321c24fd4.setContent(html_c0206d812a8e5ffe7bbf43a07edd0178);
#
#
#
#         marker_ed50c4f63253f7492af622518c3bb95d.bindPopup(popup_7ad5e50d54ed3ddeae06760321c24fd4)
#         ;
#
#
#
#
#             var marker_ba87bc7dbdd343e45b36aecbafe39190 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_338eedfabf6414b7305ee1942ddd87a1);
#
#
#         var popup_e58624272ae27761300fcc314c74205e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_813a39cb5f313739e9b66edae9dc8da6 = $(`&lt;div id=&quot;html_813a39cb5f313739e9b66edae9dc8da6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e58624272ae27761300fcc314c74205e.setContent(html_813a39cb5f313739e9b66edae9dc8da6);
#
#
#
#         marker_ba87bc7dbdd343e45b36aecbafe39190.bindPopup(popup_e58624272ae27761300fcc314c74205e)
#         ;
#
#
#
#
#             var marker_cd64a5d7e4ed0d856c52755b955573aa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_338eedfabf6414b7305ee1942ddd87a1);
#
#
#         var popup_9aca659a61af7508767c41ae1d4ba59f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a0da2a6653f5ca337d1069e06d4500a = $(`&lt;div id=&quot;html_5a0da2a6653f5ca337d1069e06d4500a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9aca659a61af7508767c41ae1d4ba59f.setContent(html_5a0da2a6653f5ca337d1069e06d4500a);
#
#
#
#         marker_cd64a5d7e4ed0d856c52755b955573aa.bindPopup(popup_9aca659a61af7508767c41ae1d4ba59f)
#         ;
#
#
#
#
#             var marker_3d7b1fec7ed0410d28f690afac8e9bad = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_338eedfabf6414b7305ee1942ddd87a1);
#
#
#         var popup_1f3074dc09a54ee8fc2fb95787711a80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88a8fef8443e1bd766dbc0b219e7a74e = $(`&lt;div id=&quot;html_88a8fef8443e1bd766dbc0b219e7a74e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1f3074dc09a54ee8fc2fb95787711a80.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0809da235e4a5aff245652e7cea749f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0809da235e4a5aff245652e7cea749f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0809da235e4a5aff245652e7cea749f = L.map(
#                 &quot;map_f0809da235e4a5aff245652e7cea749f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8948ce140f985f26957355b6746e84e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c8948ce140f985f26957355b6746e84e.addTo(map_f0809da235e4a5aff245652e7cea749f);
#
#
#             var feature_group_027517fb9019ee9c217115d83136f958 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_450f4505b1d5c7cae623c88fda401b78 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_027517fb9019ee9c217115d83136f958);
#
#
#         var popup_975923b32f1e480238b9c9694d2d4398 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0a6f40f0116223fed961537ceb36705 = $(`&lt;div id=&quot;html_a0a6f40f0116223fed961537ceb36705&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_975923b32f1e480238b9c9694d2d4398.setContent(html_a0a6f40f0116223fed961537ceb36705);
#
#
#
#         marker_450f4505b1d5c7cae623c88fda401b78.bindPopup(popup_975923b32f1e480238b9c9694d2d4398)
#         ;
#
#
#
#
#             var marker_e4af46ca688aef213878b52789b41064 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_027517fb9019ee9c217115d83136f958);
#
#
#         var popup_048658430b7a39d746d7129939db741b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e52f62da491c72a5feb9389d1de83520 = $(`&lt;div id=&quot;html_e52f62da491c72a5feb9389d1de83520&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_048658430b7a39d746d7129939db741b.setContent(html_e52f62da491c72a5feb9389d1de83520);
#
#
#
#         marker_e4af46ca688aef213878b52789b41064.bindPopup(popup_048658430b7a39d746d7129939db741b)
#         ;
#
#
#
#
#             var marker_0e74207f30bbcc4c7a9054e9dfac9018 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_027517fb9019ee9c217115d83136f958);
#
#
#         var popup_94d88dd3917a71beba27b1cf3be5fcf1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b4d71635fc71929ca5ee95cb7cc705b = $(`&lt;div id=&quot;html_2b4d71635fc71929ca5ee95cb7cc705b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_94d88dd3917a71beba27b1cf3be5fcf1.setContent(html_2b4d71635fc71929ca5ee95cb7cc705b);
#
#
#
#         marker_0e74207f30bbcc4c7a9054e9dfac9018.bindPopup(popup_94d88dd3917a71beba27b1cf3be5fcf1)
#         ;
#
#
#
#
#             var marker_1e38ca157e6ad70c9a3440afcac729fe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_027517fb9019ee9c217115d83136f958);
#
#
#         var popup_ba8e034d41caa3bfa2441d69b6c8468c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fc24c9dff070a0c16c488d95850cf16 = $(`&lt;div id=&quot;html_5fc24c9dff070a0c16c488d95850cf16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ba8e034d41caa3bfa2441d69b6c8468c.setContent(html_5fc24c9dff070a0c16c488d95850cf16);
#
#
#
#         marker_1e38ca157e6ad70c9a3440afcac729fe.bindPopup(popup_ba8e034d41caa3bfa2441d69b6c8468c)
#         ;
#
#
#
#
#             var marker_6032645c7954495d8e7512f192e2376b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_027517fb9019ee9c217115d83136f958);
#
#
#         var popup_d2ca52cadc647d4b76767fe66f0b65c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6da1e10395075258cf884121727f941 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6da1e10395075258cf884121727f941&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6da1e10395075258cf884121727f941 = L.map(
#                 &quot;map_a6da1e10395075258cf884121727f941&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3befcddcdfca9fcd493770a68d3b25a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3befcddcdfca9fcd493770a68d3b25a4.addTo(map_a6da1e10395075258cf884121727f941);
#
#
#             var feature_group_df0cf5580e6657da114bdac7e77dde8e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_df0cf5580e6657da114bdac7e77dde8e.addTo(map_a6da1e10395075258cf884121727f941);
#
#
#             var feature_group_sub_group_44c4960b80d6b5dd439436f30251da28 = L.featureGroup.subGroup(
#                 feature_group_df0cf5580e6657da114bdac7e77dde8e
#             );
#
#
#             var marker_4a10199224183fc703b8c1dc2aad6977 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_44c4960b80d6b5dd439436f30251da28);
#
#
#         var popup_76a825291f489d919455efd5f0a4b9b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c96f232a557c769458a522deccd9afdd = $(`&lt;div id=&quot;html_c96f232a557c769458a522deccd9afdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_76a825291f489d919455efd5f0a4b9b1.setContent(html_c96f232a557c769458a522deccd9afdd);
#
#
#
#         marker_4a10199224183fc703b8c1dc2aad6977.bindPopup(popup_76a825291f489d919455efd5f0a4b9b1)
#         ;
#
#
#
#
#             var marker_3694763706036f44545e84eafb3b147c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_44c4960b80d6b5dd439436f30251da28);
#
#
#         var popup_6807a229cdccaa4ab7199dc05d5efbee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5419ce189d9756d8ca1859d2306dd045 = $(`&lt;div id=&quot;html_5419ce189d9756d8ca1859d2306dd045&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6807a229cdccaa4ab7199dc05d5efbee.setContent(html_5419ce189d9756d8ca1859d2306dd045);
#
#
#
#         marker_3694763706036f44545e84eafb3b147c.bindPopup(popup_6807a229cdccaa4ab7199dc05d5efbee)
#         ;
#
#
#
#
#             var marker_55d0b0570886384d04f1add576a80988 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_44c4960b80d6b5dd439436f30251da28);
#
#
#         var popup_66d469f6acd7d2938a541a2d2413db47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7948f7e6f5892d758efcedd3a21f328c = $(`&lt;div id=&quot;html_7948f7e6f5892d758efcedd3a21f328c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_66d469f6acd7d2938a541a2d2413db47.setContent(html_7948f7e6f5892d758efcedd3a21f328c);
#
#
#
#         marker_55d0b0570886384d04f1add576a80988.bindPopup(popup_66d469f6acd7d2938a541a2d2413db47)
#         ;
#
#
#
#
#             var marker_4958e82f189e09386fa6876261147680 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_44c4960b80d6b5dd439436f30251da28);
#
#
#         var popup_55ecb1ba10c5c1ca198a7a0d91172f8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_513aa0fe0874a3e6ea366356aaac7530 = $(`&lt;div id=&quot;html_513aa0fe0874a3e6ea366356aaac7530&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_55ecb1ba10c5c1ca198a7a0d91172f8e.setContent(html_513aa0fe0874a3e6ea366356aaac7530);
#
#
#
#         marker_
