# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd20efdd829a04598e8db63f9eab7701 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd20efdd829a04598e8db63f9eab7701&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd20efdd829a04598e8db63f9eab7701 = L.map(
#                 &quot;map_cd20efdd829a04598e8db63f9eab7701&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fea69cdfd547363e14e25ed2a9aa5683 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fea69cdfd547363e14e25ed2a9aa5683.addTo(map_cd20efdd829a04598e8db63f9eab7701);
#
#
#             var marker_9d4b100f561b0ffda3612df86ea8c291 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cd20efdd829a04598e8db63f9eab7701);
#
#
#         var popup_b406b3260647d986a273481d4b0fce35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6dbaf12cb541b01e9449b51c218c0eeb = $(`&lt;div id=&quot;html_6dbaf12cb541b01e9449b51c218c0eeb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b406b3260647d986a273481d4b0fce35.setContent(html_6dbaf12cb541b01e9449b51c218c0eeb);
#
#
#
#         marker_9d4b100f561b0ffda3612df86ea8c291.bindPopup(popup_b406b3260647d986a273481d4b0fce35)
#         ;
#
#
#
#
#             var marker_fbd67f1ca6d61ede816f6dd644fed031 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cd20efdd829a04598e8db63f9eab7701);
#
#
#         var popup_d4b91d49158a70770175e9b2c92f5da7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7541217e843f6114239300f14ed995c = $(`&lt;div id=&quot;html_f7541217e843f6114239300f14ed995c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d4b91d49158a70770175e9b2c92f5da7.setContent(html_f7541217e843f6114239300f14ed995c);
#
#
#
#         marker_fbd67f1ca6d61ede816f6dd644fed031.bindPopup(popup_d4b91d49158a70770175e9b2c92f5da7)
#         ;
#
#
#
#
#             var marker_91be3183f72501abc8386cf87abe309f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cd20efdd829a04598e8db63f9eab7701);
#
#
#         var popup_c5f5f6a8bfcdd513bfe39676362e3748 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5826b6d1506c1b0e02418e02cff5ac72 = $(`&lt;div id=&quot;html_5826b6d1506c1b0e02418e02cff5ac72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c5f5f6a8bfcdd513bfe39676362e3748.setContent(html_5826b6d1506c1b0e02418e02cff5ac72);
#
#
#
#         marker_91be3183f72501abc8386cf87abe309f.bindPopup(popup_c5f5f6a8bfcdd513bfe39676362e3748)
#         ;
#
#
#
#
#             var marker_bf2b3867b647ee2b89506070ef58bf1a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cd20efdd829a04598e8db63f9eab7701);
#
#
#         var popup_2b666c571aa95c465ea96e52d03ac333 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbdec7d3318cabaa7acffa24831ebbf4 = $(`&lt;div id=&quot;html_dbdec7d3318cabaa7acffa24831ebbf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2b666c571aa95c465ea96e52d03ac333.setContent(html_dbdec7d3318cabaa7acffa24831ebbf4);
#
#
#
#         marker_bf2b3867b647ee2b89506070ef58bf1a.bindPopup(popup_2b666c571aa95c465ea96e52d03ac333)
#         ;
#
#
#
#
#             var marker_01929a40b346525079bd628733ec6dde = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cd20efdd829a04598e8db63f9eab7701);
#
#
#         var popup_1467bf0debb7b18b9d1157e49d3f8fb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d9c30785cf1aeb37823a806094358e5 = $(`&lt;div id=&quot;html_4d9c30785cf1aeb37823a806094358e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1467bf0debb7b18b9d1157e49d3f8fb1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b22b0e60267764d5d2b86dffd2e57330 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b22b0e60267764d5d2b86dffd2e57330&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b22b0e60267764d5d2b86dffd2e57330 = L.map(
#                 &quot;map_b22b0e60267764d5d2b86dffd2e57330&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5444f7f09abc564ff9d3efa948e1212 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a5444f7f09abc564ff9d3efa948e1212.addTo(map_b22b0e60267764d5d2b86dffd2e57330);
#
#
#             var feature_group_e07b7f4e8cfe43315b85324099261068 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4305dc46cedea66d60cb9279fad15126 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e07b7f4e8cfe43315b85324099261068);
#
#
#         var popup_9d660c19daabc1e131b606d9487ca97a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3412665f30e10a7724de2dc109f59fab = $(`&lt;div id=&quot;html_3412665f30e10a7724de2dc109f59fab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9d660c19daabc1e131b606d9487ca97a.setContent(html_3412665f30e10a7724de2dc109f59fab);
#
#
#
#         marker_4305dc46cedea66d60cb9279fad15126.bindPopup(popup_9d660c19daabc1e131b606d9487ca97a)
#         ;
#
#
#
#
#             var marker_98007966e300657553c92c090bbe5d0c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e07b7f4e8cfe43315b85324099261068);
#
#
#         var popup_61c92b748a2c6e86b09ee0435ff9ec49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62aa753b805a92eb7bc287804d442c5f = $(`&lt;div id=&quot;html_62aa753b805a92eb7bc287804d442c5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_61c92b748a2c6e86b09ee0435ff9ec49.setContent(html_62aa753b805a92eb7bc287804d442c5f);
#
#
#
#         marker_98007966e300657553c92c090bbe5d0c.bindPopup(popup_61c92b748a2c6e86b09ee0435ff9ec49)
#         ;
#
#
#
#
#             var marker_1ff02245b707fc0dfd3eb811ef2f1dc1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e07b7f4e8cfe43315b85324099261068);
#
#
#         var popup_c42b1b649a6e999702a6762ac5ebd0d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cae745e40e7baa47bf0f85d229bc632f = $(`&lt;div id=&quot;html_cae745e40e7baa47bf0f85d229bc632f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c42b1b649a6e999702a6762ac5ebd0d0.setContent(html_cae745e40e7baa47bf0f85d229bc632f);
#
#
#
#         marker_1ff02245b707fc0dfd3eb811ef2f1dc1.bindPopup(popup_c42b1b649a6e999702a6762ac5ebd0d0)
#         ;
#
#
#
#
#             var marker_5799cf9674ac26244bcb16b66ca60f63 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e07b7f4e8cfe43315b85324099261068);
#
#
#         var popup_a0b0d1a06e7eebe1c680c2577c5b9989 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ebcab31db728b8c8dc70f62f5b2973d = $(`&lt;div id=&quot;html_3ebcab31db728b8c8dc70f62f5b2973d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a0b0d1a06e7eebe1c680c2577c5b9989.setContent(html_3ebcab31db728b8c8dc70f62f5b2973d);
#
#
#
#         marker_5799cf9674ac26244bcb16b66ca60f63.bindPopup(popup_a0b0d1a06e7eebe1c680c2577c5b9989)
#         ;
#
#
#
#
#             var marker_b7b5d14db6a10130a2add659ebb9fd02 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e07b7f4e8cfe43315b85324099261068);
#
#
#         var popup_85a5ce2f5779b6eb821af564e60a9b90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac730ed74cda24f135d0af59e1ca4faf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac730ed74cda24f135d0af59e1ca4faf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac730ed74cda24f135d0af59e1ca4faf = L.map(
#                 &quot;map_ac730ed74cda24f135d0af59e1ca4faf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a42c8c1203e1f270d1bb431063bf106 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a42c8c1203e1f270d1bb431063bf106.addTo(map_ac730ed74cda24f135d0af59e1ca4faf);
#
#
#             var feature_group_0355e0f8a39c5e252a4fcb09634b3636 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0355e0f8a39c5e252a4fcb09634b3636.addTo(map_ac730ed74cda24f135d0af59e1ca4faf);
#
#
#             var feature_group_sub_group_6bc7d1502d220a326bed8486faecda15 = L.featureGroup.subGroup(
#                 feature_group_0355e0f8a39c5e252a4fcb09634b3636
#             );
#
#
#             var marker_a25a334eb1f025a4f31dce1e53657855 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6bc7d1502d220a326bed8486faecda15);
#
#
#         var popup_a974d4e10d5ccb2609c78045c042c45e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de3e22e022500b59748cf3ae779958d3 = $(`&lt;div id=&quot;html_de3e22e022500b59748cf3ae779958d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a974d4e10d5ccb2609c78045c042c45e.setContent(html_de3e22e022500b59748cf3ae779958d3);
#
#
#
#         marker_a25a334eb1f025a4f31dce1e53657855.bindPopup(popup_a974d4e10d5ccb2609c78045c042c45e)
#         ;
#
#
#
#
#             var marker_7ac0b82e2cfb8edf4dad122df65a8102 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6bc7d1502d220a326bed8486faecda15);
#
#
#         var popup_e1c3d620424f2a7ff8496b011a0f1578 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a75f537bf415cdb317ad24637d1553fe = $(`&lt;div id=&quot;html_a75f537bf415cdb317ad24637d1553fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e1c3d620424f2a7ff8496b011a0f1578.setContent(html_a75f537bf415cdb317ad24637d1553fe);
#
#
#
#         marker_7ac0b82e2cfb8edf4dad122df65a8102.bindPopup(popup_e1c3d620424f2a7ff8496b011a0f1578)
#         ;
#
#
#
#
#             var marker_40968117a039dc2f40dd76d8154bc97f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6bc7d1502d220a326bed8486faecda15);
#
#
#         var popup_2508fe319939f3ab05d0c98d1fb14596 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ed3f6425f5e7328b15cdd44d464e005 = $(`&lt;div id=&quot;html_1ed3f6425f5e7328b15cdd44d464e005&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2508fe319939f3ab05d0c98d1fb14596.setContent(html_1ed3f6425f5e7328b15cdd44d464e005);
#
#
#
#         marker_40968117a039dc2f40dd76d8154bc97f.bindPopup(popup_2508fe319939f3ab05d0c98d1fb14596)
#         ;
#
#
#
#
#             var marker_6a2ce6455a4c107c058926094f04e600 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6bc7d1502d220a326bed8486faecda15);
#
#
#         var popup_c894191749f85b855a90143be7c2315d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cee221d6ded18dcd5a4ffcca4f82939f = $(`&lt;div id=&quot;html_cee221d6ded18dcd5a4ffcca4f82939f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c894191749f85b855a90143be7c2315d.setContent(html_cee221d6ded18dcd5a4ffcca4f82939f);
#
#
#
#         marker_
