# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86772192c1029d05594f611936a04cd9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86772192c1029d05594f611936a04cd9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86772192c1029d05594f611936a04cd9 = L.map(
#                 &quot;map_86772192c1029d05594f611936a04cd9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b6b30ebccefd989327dba574c859792 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b6b30ebccefd989327dba574c859792.addTo(map_86772192c1029d05594f611936a04cd9);
#
#
#             var marker_06e8e5d09415169314ac07beab66a732 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_86772192c1029d05594f611936a04cd9);
#
#
#         var popup_afc7adac03fd93670390696f4b9c05d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0a5f7a79ce9b0b868b3ef6ad04d9224 = $(`&lt;div id=&quot;html_d0a5f7a79ce9b0b868b3ef6ad04d9224&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_afc7adac03fd93670390696f4b9c05d2.setContent(html_d0a5f7a79ce9b0b868b3ef6ad04d9224);
#
#
#
#         marker_06e8e5d09415169314ac07beab66a732.bindPopup(popup_afc7adac03fd93670390696f4b9c05d2)
#         ;
#
#
#
#
#             var marker_dd581d6f5497ba91653610e3eff21302 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_86772192c1029d05594f611936a04cd9);
#
#
#         var popup_562665a6e0e9c1e3387732e340dfd406 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69c90b9ad2b9fa6ac9d98aa01f87efc1 = $(`&lt;div id=&quot;html_69c90b9ad2b9fa6ac9d98aa01f87efc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_562665a6e0e9c1e3387732e340dfd406.setContent(html_69c90b9ad2b9fa6ac9d98aa01f87efc1);
#
#
#
#         marker_dd581d6f5497ba91653610e3eff21302.bindPopup(popup_562665a6e0e9c1e3387732e340dfd406)
#         ;
#
#
#
#
#             var marker_1a19d693038c38fa1591f5e6494546f3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_86772192c1029d05594f611936a04cd9);
#
#
#         var popup_74580e89a1d42be8ec0f1c230097c142 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_337133205f1e0406580e78cdec8704a7 = $(`&lt;div id=&quot;html_337133205f1e0406580e78cdec8704a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_74580e89a1d42be8ec0f1c230097c142.setContent(html_337133205f1e0406580e78cdec8704a7);
#
#
#
#         marker_1a19d693038c38fa1591f5e6494546f3.bindPopup(popup_74580e89a1d42be8ec0f1c230097c142)
#         ;
#
#
#
#
#             var marker_f1243c181dbaaddc31dc975cc1badf8b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_86772192c1029d05594f611936a04cd9);
#
#
#         var popup_538d4d06c1cd1ed8f4c7801173af0ec0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83b53c968d347aa33dd64bcb1b5ee42a = $(`&lt;div id=&quot;html_83b53c968d347aa33dd64bcb1b5ee42a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_538d4d06c1cd1ed8f4c7801173af0ec0.setContent(html_83b53c968d347aa33dd64bcb1b5ee42a);
#
#
#
#         marker_f1243c181dbaaddc31dc975cc1badf8b.bindPopup(popup_538d4d06c1cd1ed8f4c7801173af0ec0)
#         ;
#
#
#
#
#             var marker_dd5c4d050c016a60da8e786a0ac151d8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_86772192c1029d05594f611936a04cd9);
#
#
#         var popup_8f9d654379036593fdf78fdc1c9ce620 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_437700e71d7294e043a7fa88e4234381 = $(`&lt;div id=&quot;html_437700e71d7294e043a7fa88e4234381&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8f9d654379036593fdf78fdc1c9ce620.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12c938018c75ad9eb10dc2a8b04f9663 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12c938018c75ad9eb10dc2a8b04f9663&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12c938018c75ad9eb10dc2a8b04f9663 = L.map(
#                 &quot;map_12c938018c75ad9eb10dc2a8b04f9663&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b25c50bb288476bbc13f76a24586c5d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b25c50bb288476bbc13f76a24586c5d.addTo(map_12c938018c75ad9eb10dc2a8b04f9663);
#
#
#             var feature_group_c9be6003f4a2173fda4ec218600cb294 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2cd2a39ebf98b80fe650583bc9005ee6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c9be6003f4a2173fda4ec218600cb294);
#
#
#         var popup_5dd9bad8e232821fa9915ce15d732a60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21db9b77d95a3ddec506386a4e943e06 = $(`&lt;div id=&quot;html_21db9b77d95a3ddec506386a4e943e06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5dd9bad8e232821fa9915ce15d732a60.setContent(html_21db9b77d95a3ddec506386a4e943e06);
#
#
#
#         marker_2cd2a39ebf98b80fe650583bc9005ee6.bindPopup(popup_5dd9bad8e232821fa9915ce15d732a60)
#         ;
#
#
#
#
#             var marker_09eae3890202539e3835efb6ed431c0e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c9be6003f4a2173fda4ec218600cb294);
#
#
#         var popup_d34d3fb37113e9a4f096a52963b2bd58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_725bd4625e4563f8d685a7ad7d5ea282 = $(`&lt;div id=&quot;html_725bd4625e4563f8d685a7ad7d5ea282&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d34d3fb37113e9a4f096a52963b2bd58.setContent(html_725bd4625e4563f8d685a7ad7d5ea282);
#
#
#
#         marker_09eae3890202539e3835efb6ed431c0e.bindPopup(popup_d34d3fb37113e9a4f096a52963b2bd58)
#         ;
#
#
#
#
#             var marker_2fb666e45191862c353b5c906970ea57 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c9be6003f4a2173fda4ec218600cb294);
#
#
#         var popup_e4410456424c7cbc36295a77267d3f7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a759e547b5d8f83f528cbc61e2cccdf = $(`&lt;div id=&quot;html_2a759e547b5d8f83f528cbc61e2cccdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e4410456424c7cbc36295a77267d3f7f.setContent(html_2a759e547b5d8f83f528cbc61e2cccdf);
#
#
#
#         marker_2fb666e45191862c353b5c906970ea57.bindPopup(popup_e4410456424c7cbc36295a77267d3f7f)
#         ;
#
#
#
#
#             var marker_3e09a435b6a2851ec8ff9b70d4d40d41 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c9be6003f4a2173fda4ec218600cb294);
#
#
#         var popup_6f1eab7e155d005e80dff170608e6617 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58fdae2cae9b7a72197e58d97ae43c35 = $(`&lt;div id=&quot;html_58fdae2cae9b7a72197e58d97ae43c35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6f1eab7e155d005e80dff170608e6617.setContent(html_58fdae2cae9b7a72197e58d97ae43c35);
#
#
#
#         marker_3e09a435b6a2851ec8ff9b70d4d40d41.bindPopup(popup_6f1eab7e155d005e80dff170608e6617)
#         ;
#
#
#
#
#             var marker_21b8633d8023a06568cf3596ac7352df = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c9be6003f4a2173fda4ec218600cb294);
#
#
#         var popup_c30784fe5c45440c02b9fb31e92ab465 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59f3dee15f5820ce49b38639420e87b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59f3dee15f5820ce49b38639420e87b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59f3dee15f5820ce49b38639420e87b0 = L.map(
#                 &quot;map_59f3dee15f5820ce49b38639420e87b0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30ecac629765ff508fe7c3cd41f8057e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_30ecac629765ff508fe7c3cd41f8057e.addTo(map_59f3dee15f5820ce49b38639420e87b0);
#
#
#             var feature_group_b852a0b2c243b7a365650c8b13ea2275 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b852a0b2c243b7a365650c8b13ea2275.addTo(map_59f3dee15f5820ce49b38639420e87b0);
#
#
#             var feature_group_sub_group_3e6021063808612d429a9f5ecff3f18e = L.featureGroup.subGroup(
#                 feature_group_b852a0b2c243b7a365650c8b13ea2275
#             );
#
#
#             var marker_4b5d0869c21f75c88709c9f6bca4bea6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e6021063808612d429a9f5ecff3f18e);
#
#
#         var popup_e36462ea803b208984325608b6a27773 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c26010bf8d180d631480244555490b8c = $(`&lt;div id=&quot;html_c26010bf8d180d631480244555490b8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e36462ea803b208984325608b6a27773.setContent(html_c26010bf8d180d631480244555490b8c);
#
#
#
#         marker_4b5d0869c21f75c88709c9f6bca4bea6.bindPopup(popup_e36462ea803b208984325608b6a27773)
#         ;
#
#
#
#
#             var marker_411febd9529208f06db37b5d1bd34925 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e6021063808612d429a9f5ecff3f18e);
#
#
#         var popup_180dcf61c3b66d59af1728e1db957c9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67e46dddaccae11fd148aa0b73a6f9c3 = $(`&lt;div id=&quot;html_67e46dddaccae11fd148aa0b73a6f9c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_180dcf61c3b66d59af1728e1db957c9c.setContent(html_67e46dddaccae11fd148aa0b73a6f9c3);
#
#
#
#         marker_411febd9529208f06db37b5d1bd34925.bindPopup(popup_180dcf61c3b66d59af1728e1db957c9c)
#         ;
#
#
#
#
#             var marker_37fee975aea6b967a25c73ded31a24a1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e6021063808612d429a9f5ecff3f18e);
#
#
#         var popup_12fd8038c5ea49c39bab358cbff12306 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7d19b3aa0fbc206382c70a2788ae822 = $(`&lt;div id=&quot;html_f7d19b3aa0fbc206382c70a2788ae822&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_12fd8038c5ea49c39bab358cbff12306.setContent(html_f7d19b3aa0fbc206382c70a2788ae822);
#
#
#
#         marker_37fee975aea6b967a25c73ded31a24a1.bindPopup(popup_12fd8038c5ea49c39bab358cbff12306)
#         ;
#
#
#
#
#             var marker_78c96593820bb8c05c9bc44ae4da0999 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e6021063808612d429a9f5ecff3f18e);
#
#
#         var popup_acee7cff624b5e5f71c88ffd8e2e5aca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbf28e7a1505e880af2db92626041dda = $(`&lt;div id=&quot;html_dbf28e7a1505e880af2db92626041dda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_acee7cff624b5e5f71c88ffd8e2e5aca.setContent(html_dbf28e7a1505e880af2db92626041dda);
#
#
#
#         marker_
