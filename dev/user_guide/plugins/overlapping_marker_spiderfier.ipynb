# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6caf84e24c6ac241098a377a80265b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6caf84e24c6ac241098a377a80265b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6caf84e24c6ac241098a377a80265b0 = L.map(
#                 &quot;map_b6caf84e24c6ac241098a377a80265b0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bc7ceba73c4ae93f639b61d779b8392 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7bc7ceba73c4ae93f639b61d779b8392.addTo(map_b6caf84e24c6ac241098a377a80265b0);
#
#
#             var marker_607d0e6614f9fcb25aa06679b87f76ff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b6caf84e24c6ac241098a377a80265b0);
#
#
#         var popup_f1b9cc7efd14200773c87f7b52cb5222 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4ea4556facda1cad7ba384f38506876 = $(`&lt;div id=&quot;html_a4ea4556facda1cad7ba384f38506876&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f1b9cc7efd14200773c87f7b52cb5222.setContent(html_a4ea4556facda1cad7ba384f38506876);
#
#
#
#         marker_607d0e6614f9fcb25aa06679b87f76ff.bindPopup(popup_f1b9cc7efd14200773c87f7b52cb5222)
#         ;
#
#
#
#
#             var marker_9247e62fcc82c35dc926595e29140462 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b6caf84e24c6ac241098a377a80265b0);
#
#
#         var popup_ad3ad693940653067b11fd284b49dede = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6028c8863666f73db5891b20d717141d = $(`&lt;div id=&quot;html_6028c8863666f73db5891b20d717141d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ad3ad693940653067b11fd284b49dede.setContent(html_6028c8863666f73db5891b20d717141d);
#
#
#
#         marker_9247e62fcc82c35dc926595e29140462.bindPopup(popup_ad3ad693940653067b11fd284b49dede)
#         ;
#
#
#
#
#             var marker_20aa0a7b468e34a6d15472df6ecb809e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b6caf84e24c6ac241098a377a80265b0);
#
#
#         var popup_a40c3a56074291dbe3fee2186065ba21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e507480d93fb84aac3c8c55ce91470d9 = $(`&lt;div id=&quot;html_e507480d93fb84aac3c8c55ce91470d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a40c3a56074291dbe3fee2186065ba21.setContent(html_e507480d93fb84aac3c8c55ce91470d9);
#
#
#
#         marker_20aa0a7b468e34a6d15472df6ecb809e.bindPopup(popup_a40c3a56074291dbe3fee2186065ba21)
#         ;
#
#
#
#
#             var marker_9a25fbf71fbb61b927af48139c0fddcb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b6caf84e24c6ac241098a377a80265b0);
#
#
#         var popup_981d6a4d47493665a74107b1efe6ab18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5832b5bbbb037ae742043106e6d706c1 = $(`&lt;div id=&quot;html_5832b5bbbb037ae742043106e6d706c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_981d6a4d47493665a74107b1efe6ab18.setContent(html_5832b5bbbb037ae742043106e6d706c1);
#
#
#
#         marker_9a25fbf71fbb61b927af48139c0fddcb.bindPopup(popup_981d6a4d47493665a74107b1efe6ab18)
#         ;
#
#
#
#
#             var marker_883f0c515b4d317c607b893abc0cae66 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b6caf84e24c6ac241098a377a80265b0);
#
#
#         var popup_c6f6aac2f52e9c272828354f1f50bb1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_903aaeba65df9751cbc724250e7994cf = $(`&lt;div id=&quot;html_903aaeba65df9751cbc724250e7994cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c6f6aac2f52e9c272828354f1f50bb1c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c80ebaf1a6e4c76b8dab0075475b90a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c80ebaf1a6e4c76b8dab0075475b90a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c80ebaf1a6e4c76b8dab0075475b90a4 = L.map(
#                 &quot;map_c80ebaf1a6e4c76b8dab0075475b90a4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c34e8b64ebd86c072ab263744ec82d1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c34e8b64ebd86c072ab263744ec82d1a.addTo(map_c80ebaf1a6e4c76b8dab0075475b90a4);
#
#
#             var feature_group_55b1ba9d26bba575406810ec51c9d106 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_370ee5ed477395a759eaac5919b41f90 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_55b1ba9d26bba575406810ec51c9d106);
#
#
#         var popup_a95b814b9a87330ca26699c362955b17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f029b22baf91deb3967b07b60d2cc58 = $(`&lt;div id=&quot;html_7f029b22baf91deb3967b07b60d2cc58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a95b814b9a87330ca26699c362955b17.setContent(html_7f029b22baf91deb3967b07b60d2cc58);
#
#
#
#         marker_370ee5ed477395a759eaac5919b41f90.bindPopup(popup_a95b814b9a87330ca26699c362955b17)
#         ;
#
#
#
#
#             var marker_092175c78081a79e5301bf2c64faf013 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_55b1ba9d26bba575406810ec51c9d106);
#
#
#         var popup_cb45de7d77be96de8ba0ba7d6eb4c88f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bdcb2a9795a76efe565e6ac6d167ddd = $(`&lt;div id=&quot;html_7bdcb2a9795a76efe565e6ac6d167ddd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cb45de7d77be96de8ba0ba7d6eb4c88f.setContent(html_7bdcb2a9795a76efe565e6ac6d167ddd);
#
#
#
#         marker_092175c78081a79e5301bf2c64faf013.bindPopup(popup_cb45de7d77be96de8ba0ba7d6eb4c88f)
#         ;
#
#
#
#
#             var marker_c5459e4a2a909a0414ec406ec0cef858 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_55b1ba9d26bba575406810ec51c9d106);
#
#
#         var popup_7dfb9b4cf8a80c6f561fc733e353b9ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f13e0fea333dba6b8121b5356e3e4962 = $(`&lt;div id=&quot;html_f13e0fea333dba6b8121b5356e3e4962&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7dfb9b4cf8a80c6f561fc733e353b9ea.setContent(html_f13e0fea333dba6b8121b5356e3e4962);
#
#
#
#         marker_c5459e4a2a909a0414ec406ec0cef858.bindPopup(popup_7dfb9b4cf8a80c6f561fc733e353b9ea)
#         ;
#
#
#
#
#             var marker_160111504c33bbe1ae2656b1406ba446 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_55b1ba9d26bba575406810ec51c9d106);
#
#
#         var popup_1dea2f763306999b442a05e55ea65559 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f383a95f03babafd4c9cb72c43f52452 = $(`&lt;div id=&quot;html_f383a95f03babafd4c9cb72c43f52452&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1dea2f763306999b442a05e55ea65559.setContent(html_f383a95f03babafd4c9cb72c43f52452);
#
#
#
#         marker_160111504c33bbe1ae2656b1406ba446.bindPopup(popup_1dea2f763306999b442a05e55ea65559)
#         ;
#
#
#
#
#             var marker_c712429189d824efcbfb26c7718753e2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_55b1ba9d26bba575406810ec51c9d106);
#
#
#         var popup_cfa1b748504312b3951cf8f20a9e5d56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07b49cd587309054c563dc0bb95f51ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07b49cd587309054c563dc0bb95f51ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07b49cd587309054c563dc0bb95f51ba = L.map(
#                 &quot;map_07b49cd587309054c563dc0bb95f51ba&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fec4ed037345b9ce3bf9c37ba0db30d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fec4ed037345b9ce3bf9c37ba0db30d4.addTo(map_07b49cd587309054c563dc0bb95f51ba);
#
#
#             var feature_group_7313d599ea326baf2d34c0c9a998aca0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7313d599ea326baf2d34c0c9a998aca0.addTo(map_07b49cd587309054c563dc0bb95f51ba);
#
#
#             var feature_group_sub_group_4ad06c3a4c0b658436de8abb554cac75 = L.featureGroup.subGroup(
#                 feature_group_7313d599ea326baf2d34c0c9a998aca0
#             );
#
#
#             var marker_7dd4c0e7321c5e40a8d252a6c44e0a2f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4ad06c3a4c0b658436de8abb554cac75);
#
#
#         var popup_3807a578eeae14d17d68a2e700550e95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f79471326bde5b9cdd9a1b17e592df8 = $(`&lt;div id=&quot;html_0f79471326bde5b9cdd9a1b17e592df8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3807a578eeae14d17d68a2e700550e95.setContent(html_0f79471326bde5b9cdd9a1b17e592df8);
#
#
#
#         marker_7dd4c0e7321c5e40a8d252a6c44e0a2f.bindPopup(popup_3807a578eeae14d17d68a2e700550e95)
#         ;
#
#
#
#
#             var marker_c2078ad9fe58ca5cae0e72b7346eb599 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4ad06c3a4c0b658436de8abb554cac75);
#
#
#         var popup_0ca55e9140c922dac79e70bd7d67f259 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd66c08a76c015de97422236984cdab7 = $(`&lt;div id=&quot;html_cd66c08a76c015de97422236984cdab7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0ca55e9140c922dac79e70bd7d67f259.setContent(html_cd66c08a76c015de97422236984cdab7);
#
#
#
#         marker_c2078ad9fe58ca5cae0e72b7346eb599.bindPopup(popup_0ca55e9140c922dac79e70bd7d67f259)
#         ;
#
#
#
#
#             var marker_0961695219a47774196159d6068e1a53 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4ad06c3a4c0b658436de8abb554cac75);
#
#
#         var popup_abc37e8c886b2907b18b418178152ab9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77c7fc1cfb0270f64d24d0f8ad35cabc = $(`&lt;div id=&quot;html_77c7fc1cfb0270f64d24d0f8ad35cabc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_abc37e8c886b2907b18b418178152ab9.setContent(html_77c7fc1cfb0270f64d24d0f8ad35cabc);
#
#
#
#         marker_0961695219a47774196159d6068e1a53.bindPopup(popup_abc37e8c886b2907b18b418178152ab9)
#         ;
#
#
#
#
#             var marker_595139fd883c310183a2e6ce38385de6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4ad06c3a4c0b658436de8abb554cac75);
#
#
#         var popup_94ae2fc47b0a70422c026f1b2d22fc38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c2fd3b85edb25bee29af336c22ce55d = $(`&lt;div id=&quot;html_3c2fd3b85edb25bee29af336c22ce55d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_94ae2fc47b0a70422c026f1b2d22fc38.setContent(html_3c2fd3b85edb25bee29af336c22ce55d);
#
#
#
#         marker_
