# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b187bc09cf38d036fbd6f78fc0063ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b187bc09cf38d036fbd6f78fc0063ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b187bc09cf38d036fbd6f78fc0063ed = L.map(
#                 &quot;map_8b187bc09cf38d036fbd6f78fc0063ed&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2419b096feb82071cf61898a90300c91 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2419b096feb82071cf61898a90300c91.addTo(map_8b187bc09cf38d036fbd6f78fc0063ed);
#
#
#             var marker_110dffd42cf514a1f1d41fdc1e336455 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8b187bc09cf38d036fbd6f78fc0063ed);
#
#
#         var popup_610a51f23eb6f325489e7ca5e9adb16e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adf897b19056d37e3ccd14bd7d05c054 = $(`&lt;div id=&quot;html_adf897b19056d37e3ccd14bd7d05c054&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_610a51f23eb6f325489e7ca5e9adb16e.setContent(html_adf897b19056d37e3ccd14bd7d05c054);
#
#
#
#         marker_110dffd42cf514a1f1d41fdc1e336455.bindPopup(popup_610a51f23eb6f325489e7ca5e9adb16e)
#         ;
#
#
#
#
#             var marker_2d1b41aefad2868922c0cf2fb920fb93 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8b187bc09cf38d036fbd6f78fc0063ed);
#
#
#         var popup_3d220aca07b35f222685a0373655892e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c93a09ccbe2b660720dae30ea0889bc = $(`&lt;div id=&quot;html_5c93a09ccbe2b660720dae30ea0889bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3d220aca07b35f222685a0373655892e.setContent(html_5c93a09ccbe2b660720dae30ea0889bc);
#
#
#
#         marker_2d1b41aefad2868922c0cf2fb920fb93.bindPopup(popup_3d220aca07b35f222685a0373655892e)
#         ;
#
#
#
#
#             var marker_92cc6b704f9ec3991614bb83cecbfe90 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8b187bc09cf38d036fbd6f78fc0063ed);
#
#
#         var popup_a7e8f2bbda0c2f4dfd858c7e9c5a8aed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77f8bdcf8c17a9e4779992a4cdb5f03e = $(`&lt;div id=&quot;html_77f8bdcf8c17a9e4779992a4cdb5f03e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a7e8f2bbda0c2f4dfd858c7e9c5a8aed.setContent(html_77f8bdcf8c17a9e4779992a4cdb5f03e);
#
#
#
#         marker_92cc6b704f9ec3991614bb83cecbfe90.bindPopup(popup_a7e8f2bbda0c2f4dfd858c7e9c5a8aed)
#         ;
#
#
#
#
#             var marker_25e09735c0ee51dc09f1d80e674b79e1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8b187bc09cf38d036fbd6f78fc0063ed);
#
#
#         var popup_c78b18e4e7d630d564d0380131ff9ed3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e19bb0cb1049cfa989d79a306792f99 = $(`&lt;div id=&quot;html_0e19bb0cb1049cfa989d79a306792f99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c78b18e4e7d630d564d0380131ff9ed3.setContent(html_0e19bb0cb1049cfa989d79a306792f99);
#
#
#
#         marker_25e09735c0ee51dc09f1d80e674b79e1.bindPopup(popup_c78b18e4e7d630d564d0380131ff9ed3)
#         ;
#
#
#
#
#             var marker_e5c87052ff8eaff5281ff80c5124ba6b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8b187bc09cf38d036fbd6f78fc0063ed);
#
#
#         var popup_0331b762cacdadc32a22749d126d70ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8481ba1ed850797aa9e7e6544d364e8a = $(`&lt;div id=&quot;html_8481ba1ed850797aa9e7e6544d364e8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0331b762cacdadc32a22749d126d70ab.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9442f01c3e44aeebf41e153e4c571214 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9442f01c3e44aeebf41e153e4c571214&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9442f01c3e44aeebf41e153e4c571214 = L.map(
#                 &quot;map_9442f01c3e44aeebf41e153e4c571214&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c101a7fa73cca3d83a54fdb61e34a77 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6c101a7fa73cca3d83a54fdb61e34a77.addTo(map_9442f01c3e44aeebf41e153e4c571214);
#
#
#             var feature_group_df67939ae322c02a550132e8dd436194 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_98021a226bf659fbac3689fd6eee7c67 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_df67939ae322c02a550132e8dd436194);
#
#
#         var popup_99a511e078d53f618ec165d46f1ec404 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a767267185ed3188ce01feed9b770491 = $(`&lt;div id=&quot;html_a767267185ed3188ce01feed9b770491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_99a511e078d53f618ec165d46f1ec404.setContent(html_a767267185ed3188ce01feed9b770491);
#
#
#
#         marker_98021a226bf659fbac3689fd6eee7c67.bindPopup(popup_99a511e078d53f618ec165d46f1ec404)
#         ;
#
#
#
#
#             var marker_a10315a7b87155f44e5133e425823a2d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_df67939ae322c02a550132e8dd436194);
#
#
#         var popup_ece9979c6c39b85d4080c679770e7e1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f216e8f67d9ccd7591e3317bfccf3d8a = $(`&lt;div id=&quot;html_f216e8f67d9ccd7591e3317bfccf3d8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ece9979c6c39b85d4080c679770e7e1f.setContent(html_f216e8f67d9ccd7591e3317bfccf3d8a);
#
#
#
#         marker_a10315a7b87155f44e5133e425823a2d.bindPopup(popup_ece9979c6c39b85d4080c679770e7e1f)
#         ;
#
#
#
#
#             var marker_9d93db20d4760b8f8e57be4c6e50296c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_df67939ae322c02a550132e8dd436194);
#
#
#         var popup_53c6de1ebbb6183cf7912be159b60e48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57580953f01615272984c2017ef7c67a = $(`&lt;div id=&quot;html_57580953f01615272984c2017ef7c67a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_53c6de1ebbb6183cf7912be159b60e48.setContent(html_57580953f01615272984c2017ef7c67a);
#
#
#
#         marker_9d93db20d4760b8f8e57be4c6e50296c.bindPopup(popup_53c6de1ebbb6183cf7912be159b60e48)
#         ;
#
#
#
#
#             var marker_3c6ef00dce93f768576c10b5f1939594 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_df67939ae322c02a550132e8dd436194);
#
#
#         var popup_0dc49886e66456f06dbfb0aef3866160 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10649a6206370f9ca5aed65f12d6dc6b = $(`&lt;div id=&quot;html_10649a6206370f9ca5aed65f12d6dc6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0dc49886e66456f06dbfb0aef3866160.setContent(html_10649a6206370f9ca5aed65f12d6dc6b);
#
#
#
#         marker_3c6ef00dce93f768576c10b5f1939594.bindPopup(popup_0dc49886e66456f06dbfb0aef3866160)
#         ;
#
#
#
#
#             var marker_c3a3df6233b2ce8318472d9fbf9ca6e2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_df67939ae322c02a550132e8dd436194);
#
#
#         var popup_d1d787517a9166ece892075750877e18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9bd78e2ec7c707451e3b571a6da8abbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9bd78e2ec7c707451e3b571a6da8abbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9bd78e2ec7c707451e3b571a6da8abbc = L.map(
#                 &quot;map_9bd78e2ec7c707451e3b571a6da8abbc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a53e050b767cfde03ee47e858161572 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a53e050b767cfde03ee47e858161572.addTo(map_9bd78e2ec7c707451e3b571a6da8abbc);
#
#
#             var feature_group_430f86db221abe3caf6b9d67e5f59031 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_430f86db221abe3caf6b9d67e5f59031.addTo(map_9bd78e2ec7c707451e3b571a6da8abbc);
#
#
#             var feature_group_sub_group_63e9e361f2cd9443a8f834064b31480b = L.featureGroup.subGroup(
#                 feature_group_430f86db221abe3caf6b9d67e5f59031
#             );
#
#
#             var marker_bbb4feb602652027c6edb525e45907e1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_63e9e361f2cd9443a8f834064b31480b);
#
#
#         var popup_4d3b3b4aa80006a3a5a3542024fe8e3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_655372409c46b46847c3a8f91e0e1a9a = $(`&lt;div id=&quot;html_655372409c46b46847c3a8f91e0e1a9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4d3b3b4aa80006a3a5a3542024fe8e3f.setContent(html_655372409c46b46847c3a8f91e0e1a9a);
#
#
#
#         marker_bbb4feb602652027c6edb525e45907e1.bindPopup(popup_4d3b3b4aa80006a3a5a3542024fe8e3f)
#         ;
#
#
#
#
#             var marker_9f6a0f400432a9c2e39ba41823cd58aa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_63e9e361f2cd9443a8f834064b31480b);
#
#
#         var popup_704bbe88108f603a431e53a4a4a29100 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4946b22bf948625c151576b7cdb755d6 = $(`&lt;div id=&quot;html_4946b22bf948625c151576b7cdb755d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_704bbe88108f603a431e53a4a4a29100.setContent(html_4946b22bf948625c151576b7cdb755d6);
#
#
#
#         marker_9f6a0f400432a9c2e39ba41823cd58aa.bindPopup(popup_704bbe88108f603a431e53a4a4a29100)
#         ;
#
#
#
#
#             var marker_303f6f0394461a0dc3b6d768a2897503 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_63e9e361f2cd9443a8f834064b31480b);
#
#
#         var popup_8828a69d125be26752e26225f79aca47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d46d00fe28a998ec4bda94940f2359c2 = $(`&lt;div id=&quot;html_d46d00fe28a998ec4bda94940f2359c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8828a69d125be26752e26225f79aca47.setContent(html_d46d00fe28a998ec4bda94940f2359c2);
#
#
#
#         marker_303f6f0394461a0dc3b6d768a2897503.bindPopup(popup_8828a69d125be26752e26225f79aca47)
#         ;
#
#
#
#
#             var marker_b6af2f0844930479a49d65a8560bb660 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_63e9e361f2cd9443a8f834064b31480b);
#
#
#         var popup_4ebd07d023133b2db1ef7fe03be907b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12ca4b29575638a6e8b574fa04806592 = $(`&lt;div id=&quot;html_12ca4b29575638a6e8b574fa04806592&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4ebd07d023133b2db1ef7fe03be907b5.setContent(html_12ca4b29575638a6e8b574fa04806592);
#
#
#
#         marker_
