# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f9c12b1afd436fe1675dfc3e574940f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f9c12b1afd436fe1675dfc3e574940f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f9c12b1afd436fe1675dfc3e574940f = L.map(
#                 &quot;map_7f9c12b1afd436fe1675dfc3e574940f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d181a7d34a3737109d07684e4c91bd80 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d181a7d34a3737109d07684e4c91bd80.addTo(map_7f9c12b1afd436fe1675dfc3e574940f);
#
#
#             var marker_d22d1d1628e65d3212ef53f0c170e954 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7f9c12b1afd436fe1675dfc3e574940f);
#
#
#         var popup_2d3df484d91e455c7d85641514b9090c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59fa1c9f9cd6f2a90270d1a7ef7275c3 = $(`&lt;div id=&quot;html_59fa1c9f9cd6f2a90270d1a7ef7275c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2d3df484d91e455c7d85641514b9090c.setContent(html_59fa1c9f9cd6f2a90270d1a7ef7275c3);
#
#
#
#         marker_d22d1d1628e65d3212ef53f0c170e954.bindPopup(popup_2d3df484d91e455c7d85641514b9090c)
#         ;
#
#
#
#
#             var marker_08d53c11382c7ecbf89c59f42863cf92 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7f9c12b1afd436fe1675dfc3e574940f);
#
#
#         var popup_e03b3fadaa93cf239fb784b8c1c01a2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d523dd19ee8c18fc8d65192bbf9e8ff2 = $(`&lt;div id=&quot;html_d523dd19ee8c18fc8d65192bbf9e8ff2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e03b3fadaa93cf239fb784b8c1c01a2f.setContent(html_d523dd19ee8c18fc8d65192bbf9e8ff2);
#
#
#
#         marker_08d53c11382c7ecbf89c59f42863cf92.bindPopup(popup_e03b3fadaa93cf239fb784b8c1c01a2f)
#         ;
#
#
#
#
#             var marker_e583842fad8df49f2d335b3b02d688d1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7f9c12b1afd436fe1675dfc3e574940f);
#
#
#         var popup_2bce1de2b280db630546efe47e98d6d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b083e3a05adf618731b7094afcaee3c = $(`&lt;div id=&quot;html_8b083e3a05adf618731b7094afcaee3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2bce1de2b280db630546efe47e98d6d4.setContent(html_8b083e3a05adf618731b7094afcaee3c);
#
#
#
#         marker_e583842fad8df49f2d335b3b02d688d1.bindPopup(popup_2bce1de2b280db630546efe47e98d6d4)
#         ;
#
#
#
#
#             var marker_290dba808782d3aec782b1ca26fc1916 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7f9c12b1afd436fe1675dfc3e574940f);
#
#
#         var popup_7dbd2a4fe72eb9cd539810f04a2c5cfb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd7d8d76bc37e9803c0d3b45132c0408 = $(`&lt;div id=&quot;html_dd7d8d76bc37e9803c0d3b45132c0408&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7dbd2a4fe72eb9cd539810f04a2c5cfb.setContent(html_dd7d8d76bc37e9803c0d3b45132c0408);
#
#
#
#         marker_290dba808782d3aec782b1ca26fc1916.bindPopup(popup_7dbd2a4fe72eb9cd539810f04a2c5cfb)
#         ;
#
#
#
#
#             var marker_6b297eac73c0e159e2d443ed6cebc571 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7f9c12b1afd436fe1675dfc3e574940f);
#
#
#         var popup_87f03b8c3dd8cf017aa3325b7c125a53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b167657aabcec08a9765e85089544c01 = $(`&lt;div id=&quot;html_b167657aabcec08a9765e85089544c01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_87f03b8c3dd8cf017aa3325b7c125a53.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfa30f5a65b7e4a670f8f7d5092de72a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfa30f5a65b7e4a670f8f7d5092de72a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfa30f5a65b7e4a670f8f7d5092de72a = L.map(
#                 &quot;map_cfa30f5a65b7e4a670f8f7d5092de72a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eac08685c8f0ba4bad371591cd7b4ca1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eac08685c8f0ba4bad371591cd7b4ca1.addTo(map_cfa30f5a65b7e4a670f8f7d5092de72a);
#
#
#             var feature_group_e1ccecc57ffa182dd564209752597053 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_570580bb6e6f3dca30bad6d3dd41e009 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e1ccecc57ffa182dd564209752597053);
#
#
#         var popup_7781833d2c1bfa4226d1158aa354e03c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41630d3f47b390ce4046d8c4b241408e = $(`&lt;div id=&quot;html_41630d3f47b390ce4046d8c4b241408e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7781833d2c1bfa4226d1158aa354e03c.setContent(html_41630d3f47b390ce4046d8c4b241408e);
#
#
#
#         marker_570580bb6e6f3dca30bad6d3dd41e009.bindPopup(popup_7781833d2c1bfa4226d1158aa354e03c)
#         ;
#
#
#
#
#             var marker_8c5e26fd934a6b43c953c779b94347b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e1ccecc57ffa182dd564209752597053);
#
#
#         var popup_cb1c3e6291c8c24bdd9e17f177dae6cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c19bc0789a045c3595655f696c89b28 = $(`&lt;div id=&quot;html_1c19bc0789a045c3595655f696c89b28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cb1c3e6291c8c24bdd9e17f177dae6cc.setContent(html_1c19bc0789a045c3595655f696c89b28);
#
#
#
#         marker_8c5e26fd934a6b43c953c779b94347b9.bindPopup(popup_cb1c3e6291c8c24bdd9e17f177dae6cc)
#         ;
#
#
#
#
#             var marker_3ee0f2842d05d4efc8316a5ce18d0f4d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e1ccecc57ffa182dd564209752597053);
#
#
#         var popup_93f24dc9c56715283f730b2632056efe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c4d3791bb39bb958d6c96d0ea96d462 = $(`&lt;div id=&quot;html_5c4d3791bb39bb958d6c96d0ea96d462&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_93f24dc9c56715283f730b2632056efe.setContent(html_5c4d3791bb39bb958d6c96d0ea96d462);
#
#
#
#         marker_3ee0f2842d05d4efc8316a5ce18d0f4d.bindPopup(popup_93f24dc9c56715283f730b2632056efe)
#         ;
#
#
#
#
#             var marker_a1c02a27dba9011a9fc3561319af84a2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e1ccecc57ffa182dd564209752597053);
#
#
#         var popup_33019c9850c1bcc35a9b99781151b54a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_728882d3ab6bb9e22206fb402dbb489e = $(`&lt;div id=&quot;html_728882d3ab6bb9e22206fb402dbb489e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_33019c9850c1bcc35a9b99781151b54a.setContent(html_728882d3ab6bb9e22206fb402dbb489e);
#
#
#
#         marker_a1c02a27dba9011a9fc3561319af84a2.bindPopup(popup_33019c9850c1bcc35a9b99781151b54a)
#         ;
#
#
#
#
#             var marker_b960f466ce84a9fa5eb77058d3334af5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e1ccecc57ffa182dd564209752597053);
#
#
#         var popup_ecc98f871aacb3d3ed1ccbd34791eb14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1593a931704388fa7fcdb379a148c6bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1593a931704388fa7fcdb379a148c6bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1593a931704388fa7fcdb379a148c6bb = L.map(
#                 &quot;map_1593a931704388fa7fcdb379a148c6bb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a23796b9615cc9069a8ef40e3c473f54 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a23796b9615cc9069a8ef40e3c473f54.addTo(map_1593a931704388fa7fcdb379a148c6bb);
#
#
#             var feature_group_63e85a532a2b9cc618756868e66ac0a4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_63e85a532a2b9cc618756868e66ac0a4.addTo(map_1593a931704388fa7fcdb379a148c6bb);
#
#
#             var feature_group_sub_group_7f3ded96bd6d716eedf55ee5d8305bfb = L.featureGroup.subGroup(
#                 feature_group_63e85a532a2b9cc618756868e66ac0a4
#             );
#
#
#             var marker_0cc2aef4a52e6821497a3ec0ded53c25 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7f3ded96bd6d716eedf55ee5d8305bfb);
#
#
#         var popup_0a923f1ff9650fdfba7c92977dbc71df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4d7a3d672308a8c54a5e83bde4fb6d2 = $(`&lt;div id=&quot;html_d4d7a3d672308a8c54a5e83bde4fb6d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0a923f1ff9650fdfba7c92977dbc71df.setContent(html_d4d7a3d672308a8c54a5e83bde4fb6d2);
#
#
#
#         marker_0cc2aef4a52e6821497a3ec0ded53c25.bindPopup(popup_0a923f1ff9650fdfba7c92977dbc71df)
#         ;
#
#
#
#
#             var marker_c9af61e1b59fdf663d7e821fc30f983f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7f3ded96bd6d716eedf55ee5d8305bfb);
#
#
#         var popup_63d1390d026c5a2afb8d5c0f04a6a7fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70f268bb1134270d0b27f3fd403e1913 = $(`&lt;div id=&quot;html_70f268bb1134270d0b27f3fd403e1913&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_63d1390d026c5a2afb8d5c0f04a6a7fb.setContent(html_70f268bb1134270d0b27f3fd403e1913);
#
#
#
#         marker_c9af61e1b59fdf663d7e821fc30f983f.bindPopup(popup_63d1390d026c5a2afb8d5c0f04a6a7fb)
#         ;
#
#
#
#
#             var marker_790526b94d590284325b91c0a5d5871f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7f3ded96bd6d716eedf55ee5d8305bfb);
#
#
#         var popup_646b376a6c12ceb43833ffd03ddb145b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ebcf49ab6f9540010d80171288d40bd = $(`&lt;div id=&quot;html_7ebcf49ab6f9540010d80171288d40bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_646b376a6c12ceb43833ffd03ddb145b.setContent(html_7ebcf49ab6f9540010d80171288d40bd);
#
#
#
#         marker_790526b94d590284325b91c0a5d5871f.bindPopup(popup_646b376a6c12ceb43833ffd03ddb145b)
#         ;
#
#
#
#
#             var marker_cad79d73adbe89e60b20cb09ddfb2a7b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7f3ded96bd6d716eedf55ee5d8305bfb);
#
#
#         var popup_1361ae40b13db08925f2852be918bb86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8a492d8a03720a3e4b33c68ec30e193 = $(`&lt;div id=&quot;html_f8a492d8a03720a3e4b33c68ec30e193&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1361ae40b13db08925f2852be918bb86.setContent(html_f8a492d8a03720a3e4b33c68ec30e193);
#
#
#
#         marker_
