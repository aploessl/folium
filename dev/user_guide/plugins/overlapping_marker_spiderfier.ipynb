# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e85198f347c0b7466bbf597604580ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e85198f347c0b7466bbf597604580ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e85198f347c0b7466bbf597604580ea = L.map(
#                 &quot;map_7e85198f347c0b7466bbf597604580ea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86ed7cf3e8141a34a143f39a385cf3a0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_86ed7cf3e8141a34a143f39a385cf3a0.addTo(map_7e85198f347c0b7466bbf597604580ea);
#
#
#             var marker_00b8d9280ab0005fb88463412c1c74e4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7e85198f347c0b7466bbf597604580ea);
#
#
#         var popup_165cdf59da5fc013b4724c8997ff98d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_251b878bbf1d20894a8fcb7441ae4981 = $(`&lt;div id=&quot;html_251b878bbf1d20894a8fcb7441ae4981&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_165cdf59da5fc013b4724c8997ff98d6.setContent(html_251b878bbf1d20894a8fcb7441ae4981);
#
#
#
#         marker_00b8d9280ab0005fb88463412c1c74e4.bindPopup(popup_165cdf59da5fc013b4724c8997ff98d6)
#         ;
#
#
#
#
#             var marker_daf3dbdaad85497da77b6d9e2095beb0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7e85198f347c0b7466bbf597604580ea);
#
#
#         var popup_b046e64bd4e2238911deb26f213c9423 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b7cb3bd9ffb48bcbf562fd3e52dc82a = $(`&lt;div id=&quot;html_6b7cb3bd9ffb48bcbf562fd3e52dc82a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b046e64bd4e2238911deb26f213c9423.setContent(html_6b7cb3bd9ffb48bcbf562fd3e52dc82a);
#
#
#
#         marker_daf3dbdaad85497da77b6d9e2095beb0.bindPopup(popup_b046e64bd4e2238911deb26f213c9423)
#         ;
#
#
#
#
#             var marker_f91ecb786b465590fe8608236692610f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7e85198f347c0b7466bbf597604580ea);
#
#
#         var popup_6da53956a8741b87ac29f9a8727509b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90eb6efd1e274d76e2a4b256d856f9bb = $(`&lt;div id=&quot;html_90eb6efd1e274d76e2a4b256d856f9bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6da53956a8741b87ac29f9a8727509b0.setContent(html_90eb6efd1e274d76e2a4b256d856f9bb);
#
#
#
#         marker_f91ecb786b465590fe8608236692610f.bindPopup(popup_6da53956a8741b87ac29f9a8727509b0)
#         ;
#
#
#
#
#             var marker_953e6c5dbd87a02246103de287ab4b8b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7e85198f347c0b7466bbf597604580ea);
#
#
#         var popup_6e756c26053c2b6f923770d2d509b277 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a610d715c923464c251a67387d41fed6 = $(`&lt;div id=&quot;html_a610d715c923464c251a67387d41fed6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6e756c26053c2b6f923770d2d509b277.setContent(html_a610d715c923464c251a67387d41fed6);
#
#
#
#         marker_953e6c5dbd87a02246103de287ab4b8b.bindPopup(popup_6e756c26053c2b6f923770d2d509b277)
#         ;
#
#
#
#
#             var marker_48f0f42bc3cd6e703cbe14fc5e15bb5c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7e85198f347c0b7466bbf597604580ea);
#
#
#         var popup_439387f55aceeadda25a0e841a9da379 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f13a8f09ac845744c896682ee128c4e = $(`&lt;div id=&quot;html_9f13a8f09ac845744c896682ee128c4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_439387f55aceeadda25a0e841a9da379.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f521b83808bdf489b9a064f859213eed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f521b83808bdf489b9a064f859213eed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f521b83808bdf489b9a064f859213eed = L.map(
#                 &quot;map_f521b83808bdf489b9a064f859213eed&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f13328560cdc2d2fc4e9dd9d93c945f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f13328560cdc2d2fc4e9dd9d93c945f.addTo(map_f521b83808bdf489b9a064f859213eed);
#
#
#             var feature_group_78feae7f8734233335ec6fb17e5afdd1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_dad3523e78a1077fd53c618a1fed5fff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_78feae7f8734233335ec6fb17e5afdd1);
#
#
#         var popup_f994d4b4dc0410e17e0762f46a6060da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25948ae084fb3e14bcd1bab93f46e01e = $(`&lt;div id=&quot;html_25948ae084fb3e14bcd1bab93f46e01e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f994d4b4dc0410e17e0762f46a6060da.setContent(html_25948ae084fb3e14bcd1bab93f46e01e);
#
#
#
#         marker_dad3523e78a1077fd53c618a1fed5fff.bindPopup(popup_f994d4b4dc0410e17e0762f46a6060da)
#         ;
#
#
#
#
#             var marker_52983e8a4e738807817fe27a07d89ece = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_78feae7f8734233335ec6fb17e5afdd1);
#
#
#         var popup_0bfbbc822439e50a68d8d8fbdfeef0b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3638e351924b435bb27487e77c7b0c0d = $(`&lt;div id=&quot;html_3638e351924b435bb27487e77c7b0c0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0bfbbc822439e50a68d8d8fbdfeef0b3.setContent(html_3638e351924b435bb27487e77c7b0c0d);
#
#
#
#         marker_52983e8a4e738807817fe27a07d89ece.bindPopup(popup_0bfbbc822439e50a68d8d8fbdfeef0b3)
#         ;
#
#
#
#
#             var marker_ebb1bb2e08dbbfba1bda1adb5cf3660b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_78feae7f8734233335ec6fb17e5afdd1);
#
#
#         var popup_8e2f1581232924ef45006ddb74a37a1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d45808403882c2f0c650af91b2c9b93 = $(`&lt;div id=&quot;html_5d45808403882c2f0c650af91b2c9b93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8e2f1581232924ef45006ddb74a37a1c.setContent(html_5d45808403882c2f0c650af91b2c9b93);
#
#
#
#         marker_ebb1bb2e08dbbfba1bda1adb5cf3660b.bindPopup(popup_8e2f1581232924ef45006ddb74a37a1c)
#         ;
#
#
#
#
#             var marker_edcdfed36c9929ae1667dc93b3bc2f80 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_78feae7f8734233335ec6fb17e5afdd1);
#
#
#         var popup_615ebe3d05fb44a9147ec6886ef025b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ffdd8b57e80025f7a38663bf4851f13 = $(`&lt;div id=&quot;html_0ffdd8b57e80025f7a38663bf4851f13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_615ebe3d05fb44a9147ec6886ef025b3.setContent(html_0ffdd8b57e80025f7a38663bf4851f13);
#
#
#
#         marker_edcdfed36c9929ae1667dc93b3bc2f80.bindPopup(popup_615ebe3d05fb44a9147ec6886ef025b3)
#         ;
#
#
#
#
#             var marker_6d664185ae167e21843132153ab3fbeb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_78feae7f8734233335ec6fb17e5afdd1);
#
#
#         var popup_6631a765406e612ab212e93ba48a8535 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1572da7ac03c6d9d0da1f85037de48d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1572da7ac03c6d9d0da1f85037de48d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1572da7ac03c6d9d0da1f85037de48d4 = L.map(
#                 &quot;map_1572da7ac03c6d9d0da1f85037de48d4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1473a1e2a08b1b5daa4acbe34dc94042 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1473a1e2a08b1b5daa4acbe34dc94042.addTo(map_1572da7ac03c6d9d0da1f85037de48d4);
#
#
#             var feature_group_5c2ca6b940526777e78799770b1fa0d7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5c2ca6b940526777e78799770b1fa0d7.addTo(map_1572da7ac03c6d9d0da1f85037de48d4);
#
#
#             var feature_group_sub_group_228086deee9170d40db29b4799a5886b = L.featureGroup.subGroup(
#                 feature_group_5c2ca6b940526777e78799770b1fa0d7
#             );
#
#
#             var marker_0070f02714b7ae1c84d7604aa2c00394 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_228086deee9170d40db29b4799a5886b);
#
#
#         var popup_73b123e988df7fba79d87d3d4e047609 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c3f549140bba8d0cc98cea74c922d60 = $(`&lt;div id=&quot;html_5c3f549140bba8d0cc98cea74c922d60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_73b123e988df7fba79d87d3d4e047609.setContent(html_5c3f549140bba8d0cc98cea74c922d60);
#
#
#
#         marker_0070f02714b7ae1c84d7604aa2c00394.bindPopup(popup_73b123e988df7fba79d87d3d4e047609)
#         ;
#
#
#
#
#             var marker_c9690a0050865821c17152170a6f06bd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_228086deee9170d40db29b4799a5886b);
#
#
#         var popup_7a0678bfdceb293ec1dd4d7757ed10bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcbd9351fa1a29ae17a994803f4407a1 = $(`&lt;div id=&quot;html_bcbd9351fa1a29ae17a994803f4407a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7a0678bfdceb293ec1dd4d7757ed10bf.setContent(html_bcbd9351fa1a29ae17a994803f4407a1);
#
#
#
#         marker_c9690a0050865821c17152170a6f06bd.bindPopup(popup_7a0678bfdceb293ec1dd4d7757ed10bf)
#         ;
#
#
#
#
#             var marker_d0ecd448e048415411b6013ec064c257 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_228086deee9170d40db29b4799a5886b);
#
#
#         var popup_044636a533bf932219d776e8a30008e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e64724a99d22f5ab9de6ef0ffb67be4b = $(`&lt;div id=&quot;html_e64724a99d22f5ab9de6ef0ffb67be4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_044636a533bf932219d776e8a30008e7.setContent(html_e64724a99d22f5ab9de6ef0ffb67be4b);
#
#
#
#         marker_d0ecd448e048415411b6013ec064c257.bindPopup(popup_044636a533bf932219d776e8a30008e7)
#         ;
#
#
#
#
#             var marker_ca4da6cc2f44adab40329323a688b260 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_228086deee9170d40db29b4799a5886b);
#
#
#         var popup_ec53e7d23daa5cc8a506b7029877d2a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc38923299269324a62c6e7213f6a652 = $(`&lt;div id=&quot;html_dc38923299269324a62c6e7213f6a652&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ec53e7d23daa5cc8a506b7029877d2a0.setContent(html_dc38923299269324a62c6e7213f6a652);
#
#
#
#         marker_
