# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f7a11f67788e358d13f61548a79cf64 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f7a11f67788e358d13f61548a79cf64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f7a11f67788e358d13f61548a79cf64 = L.map(
#                 &quot;map_9f7a11f67788e358d13f61548a79cf64&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d670d51c2a320f892a5a23c59c5f452 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d670d51c2a320f892a5a23c59c5f452.addTo(map_9f7a11f67788e358d13f61548a79cf64);
#
#
#             var marker_e1e8ac626797608252a027e01d984df0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9f7a11f67788e358d13f61548a79cf64);
#
#
#         var popup_850343f5dc8a0088a73809f3bc0f28ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37ce243aff47d465e8b9fd2a57f32271 = $(`&lt;div id=&quot;html_37ce243aff47d465e8b9fd2a57f32271&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_850343f5dc8a0088a73809f3bc0f28ab.setContent(html_37ce243aff47d465e8b9fd2a57f32271);
#
#
#
#         marker_e1e8ac626797608252a027e01d984df0.bindPopup(popup_850343f5dc8a0088a73809f3bc0f28ab)
#         ;
#
#
#
#
#             var marker_0d840a054b552c9b1be8b73f4fa40e12 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9f7a11f67788e358d13f61548a79cf64);
#
#
#         var popup_4167fab2c55c039ea888ea8b1a25ba1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78a21ac13516af782747de9967a40c97 = $(`&lt;div id=&quot;html_78a21ac13516af782747de9967a40c97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4167fab2c55c039ea888ea8b1a25ba1a.setContent(html_78a21ac13516af782747de9967a40c97);
#
#
#
#         marker_0d840a054b552c9b1be8b73f4fa40e12.bindPopup(popup_4167fab2c55c039ea888ea8b1a25ba1a)
#         ;
#
#
#
#
#             var marker_c6f792e6b67f03e05250f8f9d50def7f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9f7a11f67788e358d13f61548a79cf64);
#
#
#         var popup_3bd99cc5d9a4ac666817ce2e14195ba0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee648e661ca73aab84ef9a56114799f8 = $(`&lt;div id=&quot;html_ee648e661ca73aab84ef9a56114799f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3bd99cc5d9a4ac666817ce2e14195ba0.setContent(html_ee648e661ca73aab84ef9a56114799f8);
#
#
#
#         marker_c6f792e6b67f03e05250f8f9d50def7f.bindPopup(popup_3bd99cc5d9a4ac666817ce2e14195ba0)
#         ;
#
#
#
#
#             var marker_6c27268e5e46a617d71810f902bbdb39 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9f7a11f67788e358d13f61548a79cf64);
#
#
#         var popup_daafa2cef46a2f68c77d3ea916141130 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5bb32c17da3c0c844ec20ae811a8195 = $(`&lt;div id=&quot;html_d5bb32c17da3c0c844ec20ae811a8195&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_daafa2cef46a2f68c77d3ea916141130.setContent(html_d5bb32c17da3c0c844ec20ae811a8195);
#
#
#
#         marker_6c27268e5e46a617d71810f902bbdb39.bindPopup(popup_daafa2cef46a2f68c77d3ea916141130)
#         ;
#
#
#
#
#             var marker_219c755ba8f581f1f83c3d67035e9333 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9f7a11f67788e358d13f61548a79cf64);
#
#
#         var popup_abd83bc55b4b01dac36e78a25effa389 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29cf448a94f1a618e57a161ca2614b9a = $(`&lt;div id=&quot;html_29cf448a94f1a618e57a161ca2614b9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_abd83bc55b4b01dac36e78a25effa389.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f586abbc31feaad85a2db209b067337 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f586abbc31feaad85a2db209b067337&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f586abbc31feaad85a2db209b067337 = L.map(
#                 &quot;map_3f586abbc31feaad85a2db209b067337&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab7d984329bd0da5a057283af1fd4038 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ab7d984329bd0da5a057283af1fd4038.addTo(map_3f586abbc31feaad85a2db209b067337);
#
#
#             var feature_group_b0206287e3161a4344a5543cbdd80800 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_da9fe9fe2d8ddb790b93bebadcd764c3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b0206287e3161a4344a5543cbdd80800);
#
#
#         var popup_553cb4900bdb618837f6cd00751f38d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9976f8b5256f798d4e9b84adb2a73110 = $(`&lt;div id=&quot;html_9976f8b5256f798d4e9b84adb2a73110&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_553cb4900bdb618837f6cd00751f38d9.setContent(html_9976f8b5256f798d4e9b84adb2a73110);
#
#
#
#         marker_da9fe9fe2d8ddb790b93bebadcd764c3.bindPopup(popup_553cb4900bdb618837f6cd00751f38d9)
#         ;
#
#
#
#
#             var marker_4c9df1f3b963eca265326e73e1dde0c2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b0206287e3161a4344a5543cbdd80800);
#
#
#         var popup_c8e22d96b94bf0d2e62b7abded115320 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b38ce6af43a2d343f0834ac6ac284768 = $(`&lt;div id=&quot;html_b38ce6af43a2d343f0834ac6ac284768&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c8e22d96b94bf0d2e62b7abded115320.setContent(html_b38ce6af43a2d343f0834ac6ac284768);
#
#
#
#         marker_4c9df1f3b963eca265326e73e1dde0c2.bindPopup(popup_c8e22d96b94bf0d2e62b7abded115320)
#         ;
#
#
#
#
#             var marker_3e592638af3908a43bfa5218cf636952 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b0206287e3161a4344a5543cbdd80800);
#
#
#         var popup_8f4066bc826ddb6883932228470260ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c94fb1d3c5122a39bf8682589d28fdb0 = $(`&lt;div id=&quot;html_c94fb1d3c5122a39bf8682589d28fdb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8f4066bc826ddb6883932228470260ce.setContent(html_c94fb1d3c5122a39bf8682589d28fdb0);
#
#
#
#         marker_3e592638af3908a43bfa5218cf636952.bindPopup(popup_8f4066bc826ddb6883932228470260ce)
#         ;
#
#
#
#
#             var marker_2d50ee5c690048c5a429efd13744a340 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b0206287e3161a4344a5543cbdd80800);
#
#
#         var popup_295429007b1363d86b035d0dd1a0d511 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a50422dcd94d912987dc5afd7802ec94 = $(`&lt;div id=&quot;html_a50422dcd94d912987dc5afd7802ec94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_295429007b1363d86b035d0dd1a0d511.setContent(html_a50422dcd94d912987dc5afd7802ec94);
#
#
#
#         marker_2d50ee5c690048c5a429efd13744a340.bindPopup(popup_295429007b1363d86b035d0dd1a0d511)
#         ;
#
#
#
#
#             var marker_6e59355ccb498dc30eac1319fecec371 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b0206287e3161a4344a5543cbdd80800);
#
#
#         var popup_de670a339f89766d7a3530b4551848a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d14d1ea8b982fc7ca2fb4b8e7a9826d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d14d1ea8b982fc7ca2fb4b8e7a9826d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d14d1ea8b982fc7ca2fb4b8e7a9826d = L.map(
#                 &quot;map_9d14d1ea8b982fc7ca2fb4b8e7a9826d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43c6eb026d483733a5b35891cd052148 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_43c6eb026d483733a5b35891cd052148.addTo(map_9d14d1ea8b982fc7ca2fb4b8e7a9826d);
#
#
#             var feature_group_2082edd37be1327ad1a7786c4a9f7b1c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2082edd37be1327ad1a7786c4a9f7b1c.addTo(map_9d14d1ea8b982fc7ca2fb4b8e7a9826d);
#
#
#             var feature_group_sub_group_53f102f44272aee55a8cf693019ff103 = L.featureGroup.subGroup(
#                 feature_group_2082edd37be1327ad1a7786c4a9f7b1c
#             );
#
#
#             var marker_c0db1a2588185a6caac9edc3371a564f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_53f102f44272aee55a8cf693019ff103);
#
#
#         var popup_98b64216c01eaab12cca922f14b2100d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e5391a600e4c6264845e2ceb93ff2c5 = $(`&lt;div id=&quot;html_0e5391a600e4c6264845e2ceb93ff2c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_98b64216c01eaab12cca922f14b2100d.setContent(html_0e5391a600e4c6264845e2ceb93ff2c5);
#
#
#
#         marker_c0db1a2588185a6caac9edc3371a564f.bindPopup(popup_98b64216c01eaab12cca922f14b2100d)
#         ;
#
#
#
#
#             var marker_85873397d3b57399ff114b98738ef4b5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_53f102f44272aee55a8cf693019ff103);
#
#
#         var popup_053b1cdf7f5553af085c52868c0d66db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fefc6b7f62fee160857272b96b245c13 = $(`&lt;div id=&quot;html_fefc6b7f62fee160857272b96b245c13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_053b1cdf7f5553af085c52868c0d66db.setContent(html_fefc6b7f62fee160857272b96b245c13);
#
#
#
#         marker_85873397d3b57399ff114b98738ef4b5.bindPopup(popup_053b1cdf7f5553af085c52868c0d66db)
#         ;
#
#
#
#
#             var marker_a3ed329e18de4afacda6432c88ec242a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_53f102f44272aee55a8cf693019ff103);
#
#
#         var popup_ad480aa7220a57c97b6f69c1fad8761d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87cec6cfcbdc90e3ce3148e91bf8d40a = $(`&lt;div id=&quot;html_87cec6cfcbdc90e3ce3148e91bf8d40a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ad480aa7220a57c97b6f69c1fad8761d.setContent(html_87cec6cfcbdc90e3ce3148e91bf8d40a);
#
#
#
#         marker_a3ed329e18de4afacda6432c88ec242a.bindPopup(popup_ad480aa7220a57c97b6f69c1fad8761d)
#         ;
#
#
#
#
#             var marker_4fae787a5b59cffe11da805f6413ce7e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_53f102f44272aee55a8cf693019ff103);
#
#
#         var popup_a52c4ecb808375d24163b2e781065a23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1a32ad7a872ee2e5c11d88fd20b9eef = $(`&lt;div id=&quot;html_d1a32ad7a872ee2e5c11d88fd20b9eef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a52c4ecb808375d24163b2e781065a23.setContent(html_d1a32ad7a872ee2e5c11d88fd20b9eef);
#
#
#
#         marker_
