# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d29a954b5fb603dccd63ee7d904b23b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d29a954b5fb603dccd63ee7d904b23b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d29a954b5fb603dccd63ee7d904b23b = L.map(
#                 &quot;map_6d29a954b5fb603dccd63ee7d904b23b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51e21f3582b2abeb1ed693f399c7fa4c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_51e21f3582b2abeb1ed693f399c7fa4c.addTo(map_6d29a954b5fb603dccd63ee7d904b23b);
#
#
#             var marker_0154219655cbfc10740834c4dddd0337 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6d29a954b5fb603dccd63ee7d904b23b);
#
#
#         var popup_67f0faba6bedfa501f3c7e00c166c7f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f6bcb69e08e2ed727825e1b897f8357 = $(`&lt;div id=&quot;html_6f6bcb69e08e2ed727825e1b897f8357&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_67f0faba6bedfa501f3c7e00c166c7f9.setContent(html_6f6bcb69e08e2ed727825e1b897f8357);
#
#
#
#         marker_0154219655cbfc10740834c4dddd0337.bindPopup(popup_67f0faba6bedfa501f3c7e00c166c7f9)
#         ;
#
#
#
#
#             var marker_0d56331af1bf6b283824beadf44dae5d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6d29a954b5fb603dccd63ee7d904b23b);
#
#
#         var popup_17054ae58825dac9501d899db8583357 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6d40105721dd3d3c1a3f5c5bb74a249 = $(`&lt;div id=&quot;html_b6d40105721dd3d3c1a3f5c5bb74a249&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_17054ae58825dac9501d899db8583357.setContent(html_b6d40105721dd3d3c1a3f5c5bb74a249);
#
#
#
#         marker_0d56331af1bf6b283824beadf44dae5d.bindPopup(popup_17054ae58825dac9501d899db8583357)
#         ;
#
#
#
#
#             var marker_0161d31e5b5ba68ec04600d692e32285 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6d29a954b5fb603dccd63ee7d904b23b);
#
#
#         var popup_998f9bad9011612bb6e04c3f2bec6613 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_329990b4ef83384d58298d5206476120 = $(`&lt;div id=&quot;html_329990b4ef83384d58298d5206476120&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_998f9bad9011612bb6e04c3f2bec6613.setContent(html_329990b4ef83384d58298d5206476120);
#
#
#
#         marker_0161d31e5b5ba68ec04600d692e32285.bindPopup(popup_998f9bad9011612bb6e04c3f2bec6613)
#         ;
#
#
#
#
#             var marker_ac1fb4cdab7cfd87bdc41a3eadf6f3b7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6d29a954b5fb603dccd63ee7d904b23b);
#
#
#         var popup_ed45a69f4d0b5250b61e7be159ba6904 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08d750edce4d3736d853d62bfd9fddfe = $(`&lt;div id=&quot;html_08d750edce4d3736d853d62bfd9fddfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ed45a69f4d0b5250b61e7be159ba6904.setContent(html_08d750edce4d3736d853d62bfd9fddfe);
#
#
#
#         marker_ac1fb4cdab7cfd87bdc41a3eadf6f3b7.bindPopup(popup_ed45a69f4d0b5250b61e7be159ba6904)
#         ;
#
#
#
#
#             var marker_244d6c4b68088251cf75bf48e9c2f7ec = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6d29a954b5fb603dccd63ee7d904b23b);
#
#
#         var popup_db5e6858f8428c31e7f6415968364a52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0c78e8eefa8ba6dbb5ba68646b72d05 = $(`&lt;div id=&quot;html_c0c78e8eefa8ba6dbb5ba68646b72d05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_db5e6858f8428c31e7f6415968364a52.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_296f8198be42757b644f36e8a9728ade {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_296f8198be42757b644f36e8a9728ade&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_296f8198be42757b644f36e8a9728ade = L.map(
#                 &quot;map_296f8198be42757b644f36e8a9728ade&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46867e1bd32fa054219c2bd10de4c1fd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46867e1bd32fa054219c2bd10de4c1fd.addTo(map_296f8198be42757b644f36e8a9728ade);
#
#
#             var feature_group_2525f34a5cec1848178fd921e3f75529 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e035f5d811f5c6f4cb4f254a151cf61b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2525f34a5cec1848178fd921e3f75529);
#
#
#         var popup_f76cde3aa62bd4c3f8dd7f9c3a45799f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9d92d3633ccdf249f66f446c75883df = $(`&lt;div id=&quot;html_e9d92d3633ccdf249f66f446c75883df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f76cde3aa62bd4c3f8dd7f9c3a45799f.setContent(html_e9d92d3633ccdf249f66f446c75883df);
#
#
#
#         marker_e035f5d811f5c6f4cb4f254a151cf61b.bindPopup(popup_f76cde3aa62bd4c3f8dd7f9c3a45799f)
#         ;
#
#
#
#
#             var marker_c34b291d55604f8b50b0946f4e464f6b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2525f34a5cec1848178fd921e3f75529);
#
#
#         var popup_19d8b0ad72a23d7a3fc7ff862d9c3bd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_232d668c147de06239556f34314cd20a = $(`&lt;div id=&quot;html_232d668c147de06239556f34314cd20a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_19d8b0ad72a23d7a3fc7ff862d9c3bd4.setContent(html_232d668c147de06239556f34314cd20a);
#
#
#
#         marker_c34b291d55604f8b50b0946f4e464f6b.bindPopup(popup_19d8b0ad72a23d7a3fc7ff862d9c3bd4)
#         ;
#
#
#
#
#             var marker_79e4b65019d2ecaabe93a12cc5c564e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2525f34a5cec1848178fd921e3f75529);
#
#
#         var popup_ba1681bf522b5682a454ff75b4d69ae7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05b9426ae2d921c65184e78b6b4b27ee = $(`&lt;div id=&quot;html_05b9426ae2d921c65184e78b6b4b27ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ba1681bf522b5682a454ff75b4d69ae7.setContent(html_05b9426ae2d921c65184e78b6b4b27ee);
#
#
#
#         marker_79e4b65019d2ecaabe93a12cc5c564e8.bindPopup(popup_ba1681bf522b5682a454ff75b4d69ae7)
#         ;
#
#
#
#
#             var marker_db1324c8252a34af650e57d87ef9dd0a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2525f34a5cec1848178fd921e3f75529);
#
#
#         var popup_e2f4d0ebe0f52751a21cc2a9db795c75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c977a4063a015421f7b2d94e8184429b = $(`&lt;div id=&quot;html_c977a4063a015421f7b2d94e8184429b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e2f4d0ebe0f52751a21cc2a9db795c75.setContent(html_c977a4063a015421f7b2d94e8184429b);
#
#
#
#         marker_db1324c8252a34af650e57d87ef9dd0a.bindPopup(popup_e2f4d0ebe0f52751a21cc2a9db795c75)
#         ;
#
#
#
#
#             var marker_418175bee945a7abdd5583ed16f024d0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2525f34a5cec1848178fd921e3f75529);
#
#
#         var popup_6eeb4369675ffb5f5eb02dd75b6ed9d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5af4f96a774b1457d78926246264739 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5af4f96a774b1457d78926246264739&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5af4f96a774b1457d78926246264739 = L.map(
#                 &quot;map_f5af4f96a774b1457d78926246264739&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c26b6fe499f6a9f1ac99bd0a36951d61 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c26b6fe499f6a9f1ac99bd0a36951d61.addTo(map_f5af4f96a774b1457d78926246264739);
#
#
#             var feature_group_20ab8ccfc80f9b27d5051e34c9abb312 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_20ab8ccfc80f9b27d5051e34c9abb312.addTo(map_f5af4f96a774b1457d78926246264739);
#
#
#             var feature_group_sub_group_03d603e4c60819b0d203b54a402689e2 = L.featureGroup.subGroup(
#                 feature_group_20ab8ccfc80f9b27d5051e34c9abb312
#             );
#
#
#             var marker_d42eec6bf68571d883d61000a9b34710 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_03d603e4c60819b0d203b54a402689e2);
#
#
#         var popup_447cf5ce0dba370645a806c1f41dcb33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6142bf73149b9a1427b0423b8d01b1b = $(`&lt;div id=&quot;html_e6142bf73149b9a1427b0423b8d01b1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_447cf5ce0dba370645a806c1f41dcb33.setContent(html_e6142bf73149b9a1427b0423b8d01b1b);
#
#
#
#         marker_d42eec6bf68571d883d61000a9b34710.bindPopup(popup_447cf5ce0dba370645a806c1f41dcb33)
#         ;
#
#
#
#
#             var marker_173e01d27425c6d8d09efc31bdbbbf93 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_03d603e4c60819b0d203b54a402689e2);
#
#
#         var popup_701fed2c12ef63b30d00bfe3b3b06458 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef40bedfd2c11990f4f18f82e1b3f0e6 = $(`&lt;div id=&quot;html_ef40bedfd2c11990f4f18f82e1b3f0e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_701fed2c12ef63b30d00bfe3b3b06458.setContent(html_ef40bedfd2c11990f4f18f82e1b3f0e6);
#
#
#
#         marker_173e01d27425c6d8d09efc31bdbbbf93.bindPopup(popup_701fed2c12ef63b30d00bfe3b3b06458)
#         ;
#
#
#
#
#             var marker_76be2848e1fd944c4881a0a44f58e268 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_03d603e4c60819b0d203b54a402689e2);
#
#
#         var popup_0521fb2a2f880581b63b9a05925d4f94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28288fba36deb735da22ccdb5a581c95 = $(`&lt;div id=&quot;html_28288fba36deb735da22ccdb5a581c95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0521fb2a2f880581b63b9a05925d4f94.setContent(html_28288fba36deb735da22ccdb5a581c95);
#
#
#
#         marker_76be2848e1fd944c4881a0a44f58e268.bindPopup(popup_0521fb2a2f880581b63b9a05925d4f94)
#         ;
#
#
#
#
#             var marker_036cafefa54a4655f1b94d01a4132aea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_03d603e4c60819b0d203b54a402689e2);
#
#
#         var popup_505fe3ebb830a6d87cccaab244caa43c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33cea1b4461bc53109230aa8954d7c9c = $(`&lt;div id=&quot;html_33cea1b4461bc53109230aa8954d7c9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_505fe3ebb830a6d87cccaab244caa43c.setContent(html_33cea1b4461bc53109230aa8954d7c9c);
#
#
#
#         marker_
