# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c10dbdc80662ff3853fc3f71e6c7ec8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c10dbdc80662ff3853fc3f71e6c7ec8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c10dbdc80662ff3853fc3f71e6c7ec8d = L.map(
#                 &quot;map_c10dbdc80662ff3853fc3f71e6c7ec8d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfbe582031f598b63031c8d5819f21ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bfbe582031f598b63031c8d5819f21ff.addTo(map_c10dbdc80662ff3853fc3f71e6c7ec8d);
#
#
#             var marker_a13c4159b31c16cca4d7495de8a56720 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c10dbdc80662ff3853fc3f71e6c7ec8d);
#
#
#         var popup_a3c76eca54f6a5091746ed8932495c30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63c039b4649e87ee822cd384c93b04ad = $(`&lt;div id=&quot;html_63c039b4649e87ee822cd384c93b04ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a3c76eca54f6a5091746ed8932495c30.setContent(html_63c039b4649e87ee822cd384c93b04ad);
#
#
#
#         marker_a13c4159b31c16cca4d7495de8a56720.bindPopup(popup_a3c76eca54f6a5091746ed8932495c30)
#         ;
#
#
#
#
#             var marker_cf8af724188b0ecae98ec1a3a78009c6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c10dbdc80662ff3853fc3f71e6c7ec8d);
#
#
#         var popup_b27dccfde8293fc06ba6ce2511b9e55a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f5555e8f290b20c39802ffa5cac3553 = $(`&lt;div id=&quot;html_3f5555e8f290b20c39802ffa5cac3553&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b27dccfde8293fc06ba6ce2511b9e55a.setContent(html_3f5555e8f290b20c39802ffa5cac3553);
#
#
#
#         marker_cf8af724188b0ecae98ec1a3a78009c6.bindPopup(popup_b27dccfde8293fc06ba6ce2511b9e55a)
#         ;
#
#
#
#
#             var marker_fc605d2b078058b8ab978cadf0482c0e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c10dbdc80662ff3853fc3f71e6c7ec8d);
#
#
#         var popup_675bcc7635f395121ba1df948f8d8352 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52c2562e2b90ac61e225f64ffb075372 = $(`&lt;div id=&quot;html_52c2562e2b90ac61e225f64ffb075372&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_675bcc7635f395121ba1df948f8d8352.setContent(html_52c2562e2b90ac61e225f64ffb075372);
#
#
#
#         marker_fc605d2b078058b8ab978cadf0482c0e.bindPopup(popup_675bcc7635f395121ba1df948f8d8352)
#         ;
#
#
#
#
#             var marker_d3d35f8b7ac1cc8fea61e7c287024ce1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c10dbdc80662ff3853fc3f71e6c7ec8d);
#
#
#         var popup_2cfbe3e480b3ac403b79d6a64594c5e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa043bd48fadcc22ddd7d4aa494e0af4 = $(`&lt;div id=&quot;html_aa043bd48fadcc22ddd7d4aa494e0af4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2cfbe3e480b3ac403b79d6a64594c5e3.setContent(html_aa043bd48fadcc22ddd7d4aa494e0af4);
#
#
#
#         marker_d3d35f8b7ac1cc8fea61e7c287024ce1.bindPopup(popup_2cfbe3e480b3ac403b79d6a64594c5e3)
#         ;
#
#
#
#
#             var marker_74d3609b5ed5534a3d0b860cf4a0507b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c10dbdc80662ff3853fc3f71e6c7ec8d);
#
#
#         var popup_3fff2bd7265b91b7134d254c29cce50f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8239a64eb955e127f7541bfcd89bcd0 = $(`&lt;div id=&quot;html_e8239a64eb955e127f7541bfcd89bcd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3fff2bd7265b91b7134d254c29cce50f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a1c6b65cbafe12c2b6e68c1cf645b4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a1c6b65cbafe12c2b6e68c1cf645b4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a1c6b65cbafe12c2b6e68c1cf645b4a = L.map(
#                 &quot;map_1a1c6b65cbafe12c2b6e68c1cf645b4a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d67a359a1f0ea497b748e8c4d9d46b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d67a359a1f0ea497b748e8c4d9d46b0.addTo(map_1a1c6b65cbafe12c2b6e68c1cf645b4a);
#
#
#             var feature_group_1626bf6d50f47cb52cfae1b06b073f4c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_222c45b83b3bb872657b72a38d8e0fca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1626bf6d50f47cb52cfae1b06b073f4c);
#
#
#         var popup_d0ecf535f9e1b1e0ef09cf0aeda35dee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f8b7d3e6a6f078279fddec7292b5dc9 = $(`&lt;div id=&quot;html_0f8b7d3e6a6f078279fddec7292b5dc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d0ecf535f9e1b1e0ef09cf0aeda35dee.setContent(html_0f8b7d3e6a6f078279fddec7292b5dc9);
#
#
#
#         marker_222c45b83b3bb872657b72a38d8e0fca.bindPopup(popup_d0ecf535f9e1b1e0ef09cf0aeda35dee)
#         ;
#
#
#
#
#             var marker_26d69ab497338954f5e6e0f5e6866748 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1626bf6d50f47cb52cfae1b06b073f4c);
#
#
#         var popup_dae6b7c3981675929ecb50c670a113f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba7b7668c736e7cbaccc14765086094f = $(`&lt;div id=&quot;html_ba7b7668c736e7cbaccc14765086094f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_dae6b7c3981675929ecb50c670a113f2.setContent(html_ba7b7668c736e7cbaccc14765086094f);
#
#
#
#         marker_26d69ab497338954f5e6e0f5e6866748.bindPopup(popup_dae6b7c3981675929ecb50c670a113f2)
#         ;
#
#
#
#
#             var marker_9e96620e522f1d7626678c227c7b53db = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1626bf6d50f47cb52cfae1b06b073f4c);
#
#
#         var popup_cf25c25c8d9fc89016edeae7f3e3c0b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31899c53145a6fe4a52cc89d92e00a9a = $(`&lt;div id=&quot;html_31899c53145a6fe4a52cc89d92e00a9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cf25c25c8d9fc89016edeae7f3e3c0b9.setContent(html_31899c53145a6fe4a52cc89d92e00a9a);
#
#
#
#         marker_9e96620e522f1d7626678c227c7b53db.bindPopup(popup_cf25c25c8d9fc89016edeae7f3e3c0b9)
#         ;
#
#
#
#
#             var marker_1f6e4d310136c8257b262cb68e6fe29a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1626bf6d50f47cb52cfae1b06b073f4c);
#
#
#         var popup_50692a77a095d9d77f68036d53aa8638 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddc5fab5317182ff8184bfc250721fea = $(`&lt;div id=&quot;html_ddc5fab5317182ff8184bfc250721fea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_50692a77a095d9d77f68036d53aa8638.setContent(html_ddc5fab5317182ff8184bfc250721fea);
#
#
#
#         marker_1f6e4d310136c8257b262cb68e6fe29a.bindPopup(popup_50692a77a095d9d77f68036d53aa8638)
#         ;
#
#
#
#
#             var marker_f71d1ddd87dfde26c03d6fd29d86fd54 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1626bf6d50f47cb52cfae1b06b073f4c);
#
#
#         var popup_ec6a3f1cc1f5a1930fc051c2db57a50d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d3113e3081b6a9d0be420731ac8adbd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d3113e3081b6a9d0be420731ac8adbd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d3113e3081b6a9d0be420731ac8adbd = L.map(
#                 &quot;map_9d3113e3081b6a9d0be420731ac8adbd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d1264b8b63ac7c9642a454eca5cc4e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d1264b8b63ac7c9642a454eca5cc4e1.addTo(map_9d3113e3081b6a9d0be420731ac8adbd);
#
#
#             var feature_group_e65dd12537dbac3f3c63369cf88994b4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e65dd12537dbac3f3c63369cf88994b4.addTo(map_9d3113e3081b6a9d0be420731ac8adbd);
#
#
#             var feature_group_sub_group_9ede5493dfaf4d69865ce1b91fa7af69 = L.featureGroup.subGroup(
#                 feature_group_e65dd12537dbac3f3c63369cf88994b4
#             );
#
#
#             var marker_dff7b807854697bbd0229a6c0e9deae4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9ede5493dfaf4d69865ce1b91fa7af69);
#
#
#         var popup_09a40f363b37e1f5e428bf1a69015571 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02379ca213c10a44a894c9e201cdeda4 = $(`&lt;div id=&quot;html_02379ca213c10a44a894c9e201cdeda4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_09a40f363b37e1f5e428bf1a69015571.setContent(html_02379ca213c10a44a894c9e201cdeda4);
#
#
#
#         marker_dff7b807854697bbd0229a6c0e9deae4.bindPopup(popup_09a40f363b37e1f5e428bf1a69015571)
#         ;
#
#
#
#
#             var marker_eb42eeb0aab8a0e354a81b3d0cc6261a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9ede5493dfaf4d69865ce1b91fa7af69);
#
#
#         var popup_cb2db34d83ea33b3bc98c2a4f94fc0b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_011c414b28036de8e1aec4510b83ed46 = $(`&lt;div id=&quot;html_011c414b28036de8e1aec4510b83ed46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cb2db34d83ea33b3bc98c2a4f94fc0b3.setContent(html_011c414b28036de8e1aec4510b83ed46);
#
#
#
#         marker_eb42eeb0aab8a0e354a81b3d0cc6261a.bindPopup(popup_cb2db34d83ea33b3bc98c2a4f94fc0b3)
#         ;
#
#
#
#
#             var marker_d82be3ae24bd6cfbc82965e28da9077f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9ede5493dfaf4d69865ce1b91fa7af69);
#
#
#         var popup_bf978d9e59ba663c0e3960c42a5edafd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63eac956ce545205fffbf036219a9238 = $(`&lt;div id=&quot;html_63eac956ce545205fffbf036219a9238&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bf978d9e59ba663c0e3960c42a5edafd.setContent(html_63eac956ce545205fffbf036219a9238);
#
#
#
#         marker_d82be3ae24bd6cfbc82965e28da9077f.bindPopup(popup_bf978d9e59ba663c0e3960c42a5edafd)
#         ;
#
#
#
#
#             var marker_c50622848933920cb6b7c5cc108df26d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9ede5493dfaf4d69865ce1b91fa7af69);
#
#
#         var popup_6e96582a9f4df270d9d228bb342465ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01595436b2dbbb4416c10ae8a15f4aa6 = $(`&lt;div id=&quot;html_01595436b2dbbb4416c10ae8a15f4aa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6e96582a9f4df270d9d228bb342465ea.setContent(html_01595436b2dbbb4416c10ae8a15f4aa6);
#
#
#
#         marker_
