# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_295b7f5a0053b1450b888837100d181a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_295b7f5a0053b1450b888837100d181a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_295b7f5a0053b1450b888837100d181a = L.map(
#                 &quot;map_295b7f5a0053b1450b888837100d181a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a61442cd28c6371bbea25aaa8be76aa9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a61442cd28c6371bbea25aaa8be76aa9.addTo(map_295b7f5a0053b1450b888837100d181a);
#
#
#             var marker_7f252b11dc09cb0b59286565ad94783a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_295b7f5a0053b1450b888837100d181a);
#
#
#         var popup_139840d38f3f3c4ea71167890eb043d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fd801a5c9e2f3c2acf7ccbb6e1dee92 = $(`&lt;div id=&quot;html_5fd801a5c9e2f3c2acf7ccbb6e1dee92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_139840d38f3f3c4ea71167890eb043d0.setContent(html_5fd801a5c9e2f3c2acf7ccbb6e1dee92);
#
#
#
#         marker_7f252b11dc09cb0b59286565ad94783a.bindPopup(popup_139840d38f3f3c4ea71167890eb043d0)
#         ;
#
#
#
#
#             var marker_f02611a1484c9bb3946341d0b42fedab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_295b7f5a0053b1450b888837100d181a);
#
#
#         var popup_dc42e74619c9302cc59f87b71e5e3d1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bf91291be1cdb520b07dc2c7a981f8b = $(`&lt;div id=&quot;html_4bf91291be1cdb520b07dc2c7a981f8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dc42e74619c9302cc59f87b71e5e3d1a.setContent(html_4bf91291be1cdb520b07dc2c7a981f8b);
#
#
#
#         marker_f02611a1484c9bb3946341d0b42fedab.bindPopup(popup_dc42e74619c9302cc59f87b71e5e3d1a)
#         ;
#
#
#
#
#             var marker_aa5e6f21a3df10d53e44b3492cfbe6b3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_295b7f5a0053b1450b888837100d181a);
#
#
#         var popup_872c1555f5ec26667a8bf95534fe3629 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb6baf1e4d8588034a71da778d505b50 = $(`&lt;div id=&quot;html_bb6baf1e4d8588034a71da778d505b50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_872c1555f5ec26667a8bf95534fe3629.setContent(html_bb6baf1e4d8588034a71da778d505b50);
#
#
#
#         marker_aa5e6f21a3df10d53e44b3492cfbe6b3.bindPopup(popup_872c1555f5ec26667a8bf95534fe3629)
#         ;
#
#
#
#
#             var marker_fb2e1e0a4935890ee15c347132115b13 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_295b7f5a0053b1450b888837100d181a);
#
#
#         var popup_9ffea81af89cc2cf9509a7b59b62b39e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47d0059351b6a1cb8745e7a2cd52b8b6 = $(`&lt;div id=&quot;html_47d0059351b6a1cb8745e7a2cd52b8b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9ffea81af89cc2cf9509a7b59b62b39e.setContent(html_47d0059351b6a1cb8745e7a2cd52b8b6);
#
#
#
#         marker_fb2e1e0a4935890ee15c347132115b13.bindPopup(popup_9ffea81af89cc2cf9509a7b59b62b39e)
#         ;
#
#
#
#
#             var marker_346424c38766c0c4cbc3ac6eb66d50ff = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_295b7f5a0053b1450b888837100d181a);
#
#
#         var popup_687f4630b1d312e99271e564d80a0bfe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ec8755cbc2b22243d93a8ffe00c875a = $(`&lt;div id=&quot;html_0ec8755cbc2b22243d93a8ffe00c875a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_687f4630b1d312e99271e564d80a0bfe.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_319b6e7c62bf3a274e543992cacd3340 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_319b6e7c62bf3a274e543992cacd3340&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_319b6e7c62bf3a274e543992cacd3340 = L.map(
#                 &quot;map_319b6e7c62bf3a274e543992cacd3340&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1491d45fd6cc6dee1b1cd81cea124798 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1491d45fd6cc6dee1b1cd81cea124798.addTo(map_319b6e7c62bf3a274e543992cacd3340);
#
#
#             var feature_group_b35a94e92014082f78c39af76ad3ab4a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9f74d1980d90b291180d0114cfb18c70 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b35a94e92014082f78c39af76ad3ab4a);
#
#
#         var popup_56774d04f4e190fe93f3fbcd6d5d6da7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d5e2b1ce8045db34b2f8937e8bd8566 = $(`&lt;div id=&quot;html_2d5e2b1ce8045db34b2f8937e8bd8566&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_56774d04f4e190fe93f3fbcd6d5d6da7.setContent(html_2d5e2b1ce8045db34b2f8937e8bd8566);
#
#
#
#         marker_9f74d1980d90b291180d0114cfb18c70.bindPopup(popup_56774d04f4e190fe93f3fbcd6d5d6da7)
#         ;
#
#
#
#
#             var marker_5cb2f7e1ab1be92b1eb438f23edbfa9f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b35a94e92014082f78c39af76ad3ab4a);
#
#
#         var popup_f9b2b80928933ab07f9fb2073da54677 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64b07c5da4708050dd9159c52b518677 = $(`&lt;div id=&quot;html_64b07c5da4708050dd9159c52b518677&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f9b2b80928933ab07f9fb2073da54677.setContent(html_64b07c5da4708050dd9159c52b518677);
#
#
#
#         marker_5cb2f7e1ab1be92b1eb438f23edbfa9f.bindPopup(popup_f9b2b80928933ab07f9fb2073da54677)
#         ;
#
#
#
#
#             var marker_4c690b7f83f0d1a5fd4e7ee768d3a72c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b35a94e92014082f78c39af76ad3ab4a);
#
#
#         var popup_509669259cd36a16cae95e3066e5573e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9226c6b3111ce9a75f19b9b3178a656f = $(`&lt;div id=&quot;html_9226c6b3111ce9a75f19b9b3178a656f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_509669259cd36a16cae95e3066e5573e.setContent(html_9226c6b3111ce9a75f19b9b3178a656f);
#
#
#
#         marker_4c690b7f83f0d1a5fd4e7ee768d3a72c.bindPopup(popup_509669259cd36a16cae95e3066e5573e)
#         ;
#
#
#
#
#             var marker_b9a91cc6072342699936dca914ea4e2b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b35a94e92014082f78c39af76ad3ab4a);
#
#
#         var popup_48c8ad9eef6de91746e5327b5a34615d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8796807e2c705aeb8dc5a66e1b4d2414 = $(`&lt;div id=&quot;html_8796807e2c705aeb8dc5a66e1b4d2414&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_48c8ad9eef6de91746e5327b5a34615d.setContent(html_8796807e2c705aeb8dc5a66e1b4d2414);
#
#
#
#         marker_b9a91cc6072342699936dca914ea4e2b.bindPopup(popup_48c8ad9eef6de91746e5327b5a34615d)
#         ;
#
#
#
#
#             var marker_e20284a865dd8db61c240fe60e8dfc38 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b35a94e92014082f78c39af76ad3ab4a);
#
#
#         var popup_bd0d9c71e96e6761b377f23e8045f994 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ebb1b9470432db68c9b9f2890cfdc83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ebb1b9470432db68c9b9f2890cfdc83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ebb1b9470432db68c9b9f2890cfdc83 = L.map(
#                 &quot;map_1ebb1b9470432db68c9b9f2890cfdc83&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30251da303d337642ff607ac67f91b8f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_30251da303d337642ff607ac67f91b8f.addTo(map_1ebb1b9470432db68c9b9f2890cfdc83);
#
#
#             var feature_group_250933a3d20907e9880bc0fa55978481 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_250933a3d20907e9880bc0fa55978481.addTo(map_1ebb1b9470432db68c9b9f2890cfdc83);
#
#
#             var feature_group_sub_group_891add17f56e34d00e4d028c69f6e80d = L.featureGroup.subGroup(
#                 feature_group_250933a3d20907e9880bc0fa55978481
#             );
#
#
#             var marker_ef3f48365d5c58c5bc7f57215ae8ed69 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_891add17f56e34d00e4d028c69f6e80d);
#
#
#         var popup_924d57d96b73cf695d722730a49fa2bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f7207891022b60cc425057a3169203d = $(`&lt;div id=&quot;html_7f7207891022b60cc425057a3169203d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_924d57d96b73cf695d722730a49fa2bc.setContent(html_7f7207891022b60cc425057a3169203d);
#
#
#
#         marker_ef3f48365d5c58c5bc7f57215ae8ed69.bindPopup(popup_924d57d96b73cf695d722730a49fa2bc)
#         ;
#
#
#
#
#             var marker_abba8639f00135fec7f131ba440d3551 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_891add17f56e34d00e4d028c69f6e80d);
#
#
#         var popup_5f9ed4e88cf2ae269426f2106e492145 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c0474d4988f4e06dce3e33fcf1809da = $(`&lt;div id=&quot;html_7c0474d4988f4e06dce3e33fcf1809da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5f9ed4e88cf2ae269426f2106e492145.setContent(html_7c0474d4988f4e06dce3e33fcf1809da);
#
#
#
#         marker_abba8639f00135fec7f131ba440d3551.bindPopup(popup_5f9ed4e88cf2ae269426f2106e492145)
#         ;
#
#
#
#
#             var marker_b0897def08d236b1c3f190de403674e2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_891add17f56e34d00e4d028c69f6e80d);
#
#
#         var popup_2a930be1185e7184b463bb716bb271b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fb9251e67ecd0d24e771c3a137adc2d = $(`&lt;div id=&quot;html_8fb9251e67ecd0d24e771c3a137adc2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2a930be1185e7184b463bb716bb271b3.setContent(html_8fb9251e67ecd0d24e771c3a137adc2d);
#
#
#
#         marker_b0897def08d236b1c3f190de403674e2.bindPopup(popup_2a930be1185e7184b463bb716bb271b3)
#         ;
#
#
#
#
#             var marker_e5e23ab7cb0d1fe73f5a2182ae69f151 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_891add17f56e34d00e4d028c69f6e80d);
#
#
#         var popup_87675b0c39bdb27dc6f7e9aadf39d2e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad20d96dd7927e77f25bf8e0e4b51212 = $(`&lt;div id=&quot;html_ad20d96dd7927e77f25bf8e0e4b51212&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_87675b0c39bdb27dc6f7e9aadf39d2e9.setContent(html_ad20d96dd7927e77f25bf8e0e4b51212);
#
#
#
#         marker_
