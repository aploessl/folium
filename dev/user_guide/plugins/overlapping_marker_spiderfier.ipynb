# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73c1934da0a0fc4f64fcf83a146ea4c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73c1934da0a0fc4f64fcf83a146ea4c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73c1934da0a0fc4f64fcf83a146ea4c7 = L.map(
#                 &quot;map_73c1934da0a0fc4f64fcf83a146ea4c7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1008f3949290bf94a1b99ebebc6d5319 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1008f3949290bf94a1b99ebebc6d5319.addTo(map_73c1934da0a0fc4f64fcf83a146ea4c7);
#
#
#             var marker_8839a64afc12c57eda67ed0ffebf18c0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_73c1934da0a0fc4f64fcf83a146ea4c7);
#
#
#         var popup_c66cb1433129e8394b1b527a93da1fef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d606a823743fe7aafd420479ebf535a = $(`&lt;div id=&quot;html_1d606a823743fe7aafd420479ebf535a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c66cb1433129e8394b1b527a93da1fef.setContent(html_1d606a823743fe7aafd420479ebf535a);
#
#
#
#         marker_8839a64afc12c57eda67ed0ffebf18c0.bindPopup(popup_c66cb1433129e8394b1b527a93da1fef)
#         ;
#
#
#
#
#             var marker_78d9f02ea0bb10a8f714e6213e127173 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_73c1934da0a0fc4f64fcf83a146ea4c7);
#
#
#         var popup_7541f63888ba6ae035a698d5bd942c05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e8090f7378b3380e6dfe2d39f384968 = $(`&lt;div id=&quot;html_4e8090f7378b3380e6dfe2d39f384968&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7541f63888ba6ae035a698d5bd942c05.setContent(html_4e8090f7378b3380e6dfe2d39f384968);
#
#
#
#         marker_78d9f02ea0bb10a8f714e6213e127173.bindPopup(popup_7541f63888ba6ae035a698d5bd942c05)
#         ;
#
#
#
#
#             var marker_50405d5f7a5c80010cc52071451ddeed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_73c1934da0a0fc4f64fcf83a146ea4c7);
#
#
#         var popup_87985d7a3294b239b0790f1eada1ebfa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a176dd817abbc1085501552ee95a8cf = $(`&lt;div id=&quot;html_4a176dd817abbc1085501552ee95a8cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_87985d7a3294b239b0790f1eada1ebfa.setContent(html_4a176dd817abbc1085501552ee95a8cf);
#
#
#
#         marker_50405d5f7a5c80010cc52071451ddeed.bindPopup(popup_87985d7a3294b239b0790f1eada1ebfa)
#         ;
#
#
#
#
#             var marker_973b1f4f1d261655511c4d8d61861a38 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_73c1934da0a0fc4f64fcf83a146ea4c7);
#
#
#         var popup_be644ae91bded25553fa8f7c046be7fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_731595313d5193c30592d370b7a78da7 = $(`&lt;div id=&quot;html_731595313d5193c30592d370b7a78da7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_be644ae91bded25553fa8f7c046be7fd.setContent(html_731595313d5193c30592d370b7a78da7);
#
#
#
#         marker_973b1f4f1d261655511c4d8d61861a38.bindPopup(popup_be644ae91bded25553fa8f7c046be7fd)
#         ;
#
#
#
#
#             var marker_ed0ac2d9f5eb8ce306a6a8fd14ee6530 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_73c1934da0a0fc4f64fcf83a146ea4c7);
#
#
#         var popup_a9527aa849fdfb70cee49f61df73b927 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d41e60af53edd89921baad19a62174d = $(`&lt;div id=&quot;html_7d41e60af53edd89921baad19a62174d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a9527aa849fdfb70cee49f61df73b927.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de0f13c86e28b7b167b2539e07684db9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de0f13c86e28b7b167b2539e07684db9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de0f13c86e28b7b167b2539e07684db9 = L.map(
#                 &quot;map_de0f13c86e28b7b167b2539e07684db9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9388db5340d6b82705cfdb118a42bf98 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9388db5340d6b82705cfdb118a42bf98.addTo(map_de0f13c86e28b7b167b2539e07684db9);
#
#
#             var feature_group_fd7ea22de47ebc149f07cd0f75147129 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fc7a03ad0bafa0179a61a28b5b3e934d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fd7ea22de47ebc149f07cd0f75147129);
#
#
#         var popup_c34a7a91f1ba8ffe808f494a7b6615e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85db80b90028dec40971f8bad61c8c44 = $(`&lt;div id=&quot;html_85db80b90028dec40971f8bad61c8c44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c34a7a91f1ba8ffe808f494a7b6615e1.setContent(html_85db80b90028dec40971f8bad61c8c44);
#
#
#
#         marker_fc7a03ad0bafa0179a61a28b5b3e934d.bindPopup(popup_c34a7a91f1ba8ffe808f494a7b6615e1)
#         ;
#
#
#
#
#             var marker_999b803d40be2ca76f6529cd86a27d2f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fd7ea22de47ebc149f07cd0f75147129);
#
#
#         var popup_8ccb2610beacc499b504c8cbeeb6ddf4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6b6f55b11ccb9268e39eeca4349fb35 = $(`&lt;div id=&quot;html_c6b6f55b11ccb9268e39eeca4349fb35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8ccb2610beacc499b504c8cbeeb6ddf4.setContent(html_c6b6f55b11ccb9268e39eeca4349fb35);
#
#
#
#         marker_999b803d40be2ca76f6529cd86a27d2f.bindPopup(popup_8ccb2610beacc499b504c8cbeeb6ddf4)
#         ;
#
#
#
#
#             var marker_32a648ad61aaea03da675ec2f2970b94 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fd7ea22de47ebc149f07cd0f75147129);
#
#
#         var popup_294fcc5e25adec176f663faf9e6b1b86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b09b5ee6e49603cf4a22d7e0863f4e84 = $(`&lt;div id=&quot;html_b09b5ee6e49603cf4a22d7e0863f4e84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_294fcc5e25adec176f663faf9e6b1b86.setContent(html_b09b5ee6e49603cf4a22d7e0863f4e84);
#
#
#
#         marker_32a648ad61aaea03da675ec2f2970b94.bindPopup(popup_294fcc5e25adec176f663faf9e6b1b86)
#         ;
#
#
#
#
#             var marker_af1ef32f70961ffa388c18c4575afd50 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fd7ea22de47ebc149f07cd0f75147129);
#
#
#         var popup_354fc1067ee70ceba53869a672103bde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df79158499000d1d21ab9b62b8aa36a3 = $(`&lt;div id=&quot;html_df79158499000d1d21ab9b62b8aa36a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_354fc1067ee70ceba53869a672103bde.setContent(html_df79158499000d1d21ab9b62b8aa36a3);
#
#
#
#         marker_af1ef32f70961ffa388c18c4575afd50.bindPopup(popup_354fc1067ee70ceba53869a672103bde)
#         ;
#
#
#
#
#             var marker_bd7a70b9a87bcea9c6094bda47c3082a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fd7ea22de47ebc149f07cd0f75147129);
#
#
#         var popup_cb90e22ab500f02ddb32fe03b6098b69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0292ab163488444d7e8d0538004b2b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0292ab163488444d7e8d0538004b2b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0292ab163488444d7e8d0538004b2b5 = L.map(
#                 &quot;map_d0292ab163488444d7e8d0538004b2b5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7452a6832719fad8eedb106e8164815 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c7452a6832719fad8eedb106e8164815.addTo(map_d0292ab163488444d7e8d0538004b2b5);
#
#
#             var feature_group_9c944c0eca482903b3715ef8b387abad = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9c944c0eca482903b3715ef8b387abad.addTo(map_d0292ab163488444d7e8d0538004b2b5);
#
#
#             var feature_group_sub_group_e890a0e03192f18f08b54851966e6efd = L.featureGroup.subGroup(
#                 feature_group_9c944c0eca482903b3715ef8b387abad
#             );
#
#
#             var marker_d0a788229ba308f0a7eb7c553dfaad12 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e890a0e03192f18f08b54851966e6efd);
#
#
#         var popup_d11977b0f55c7cc93eab011d4b10e2ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89c2a46c9bd8866df8263c54f4f505c5 = $(`&lt;div id=&quot;html_89c2a46c9bd8866df8263c54f4f505c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d11977b0f55c7cc93eab011d4b10e2ba.setContent(html_89c2a46c9bd8866df8263c54f4f505c5);
#
#
#
#         marker_d0a788229ba308f0a7eb7c553dfaad12.bindPopup(popup_d11977b0f55c7cc93eab011d4b10e2ba)
#         ;
#
#
#
#
#             var marker_403618a751ed14393e9595e25a4e1f67 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e890a0e03192f18f08b54851966e6efd);
#
#
#         var popup_709968f887a0e4e5b8e2b5876fc49d4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d20b44db71e4afedb95a17d2ecd02a8 = $(`&lt;div id=&quot;html_1d20b44db71e4afedb95a17d2ecd02a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_709968f887a0e4e5b8e2b5876fc49d4a.setContent(html_1d20b44db71e4afedb95a17d2ecd02a8);
#
#
#
#         marker_403618a751ed14393e9595e25a4e1f67.bindPopup(popup_709968f887a0e4e5b8e2b5876fc49d4a)
#         ;
#
#
#
#
#             var marker_f54cb7dd9a5853caed7d106eca3a8d57 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e890a0e03192f18f08b54851966e6efd);
#
#
#         var popup_4b7ac9434ce79b35244a22ff4eced839 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe7d6013c40b11e838725dbc0b464d34 = $(`&lt;div id=&quot;html_fe7d6013c40b11e838725dbc0b464d34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4b7ac9434ce79b35244a22ff4eced839.setContent(html_fe7d6013c40b11e838725dbc0b464d34);
#
#
#
#         marker_f54cb7dd9a5853caed7d106eca3a8d57.bindPopup(popup_4b7ac9434ce79b35244a22ff4eced839)
#         ;
#
#
#
#
#             var marker_fb44db88a18252f98eb4d2eda5ce7115 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e890a0e03192f18f08b54851966e6efd);
#
#
#         var popup_60a96442a2d234db722006c68f2b9012 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_103e3fccb88595e7ec887d8e9e16606b = $(`&lt;div id=&quot;html_103e3fccb88595e7ec887d8e9e16606b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_60a96442a2d234db722006c68f2b9012.setContent(html_103e3fccb88595e7ec887d8e9e16606b);
#
#
#
#         marker_
