# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b611aad15d18d86cdf9873b7b1ee8e01 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b611aad15d18d86cdf9873b7b1ee8e01&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b611aad15d18d86cdf9873b7b1ee8e01 = L.map(
#                 &quot;map_b611aad15d18d86cdf9873b7b1ee8e01&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fdf7e4316cdee483e7ff82bc2ecbe3bb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fdf7e4316cdee483e7ff82bc2ecbe3bb.addTo(map_b611aad15d18d86cdf9873b7b1ee8e01);
#
#
#             var marker_b12d3aaa0bc53fcf5010aac796ca2e68 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b611aad15d18d86cdf9873b7b1ee8e01);
#
#
#         var popup_f29908c2ea0ae3f568af30b6cd8bdd0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a54b60314a681d81706c20fb5763b42f = $(`&lt;div id=&quot;html_a54b60314a681d81706c20fb5763b42f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f29908c2ea0ae3f568af30b6cd8bdd0e.setContent(html_a54b60314a681d81706c20fb5763b42f);
#
#
#
#         marker_b12d3aaa0bc53fcf5010aac796ca2e68.bindPopup(popup_f29908c2ea0ae3f568af30b6cd8bdd0e)
#         ;
#
#
#
#
#             var marker_7a94794aebf2013da342e7734db08a24 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b611aad15d18d86cdf9873b7b1ee8e01);
#
#
#         var popup_439d9c104903dbe81392d9b020b67c3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20d5c5590287179c5c8b589fc91c7894 = $(`&lt;div id=&quot;html_20d5c5590287179c5c8b589fc91c7894&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_439d9c104903dbe81392d9b020b67c3d.setContent(html_20d5c5590287179c5c8b589fc91c7894);
#
#
#
#         marker_7a94794aebf2013da342e7734db08a24.bindPopup(popup_439d9c104903dbe81392d9b020b67c3d)
#         ;
#
#
#
#
#             var marker_c964581ab9d6811c4052a0da3ba6458f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b611aad15d18d86cdf9873b7b1ee8e01);
#
#
#         var popup_53c98ee833d0b4efbf6bda0f06f66899 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13532f1e22454c4eb3bd76c6c735fb1e = $(`&lt;div id=&quot;html_13532f1e22454c4eb3bd76c6c735fb1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_53c98ee833d0b4efbf6bda0f06f66899.setContent(html_13532f1e22454c4eb3bd76c6c735fb1e);
#
#
#
#         marker_c964581ab9d6811c4052a0da3ba6458f.bindPopup(popup_53c98ee833d0b4efbf6bda0f06f66899)
#         ;
#
#
#
#
#             var marker_b057a6c6522dd7ac6b298cdca0e46cb3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b611aad15d18d86cdf9873b7b1ee8e01);
#
#
#         var popup_a2d0d807fc72a0c40d912a5b69736bc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c2616dd5ca0435aab1b1c22acf9b5c8 = $(`&lt;div id=&quot;html_1c2616dd5ca0435aab1b1c22acf9b5c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a2d0d807fc72a0c40d912a5b69736bc8.setContent(html_1c2616dd5ca0435aab1b1c22acf9b5c8);
#
#
#
#         marker_b057a6c6522dd7ac6b298cdca0e46cb3.bindPopup(popup_a2d0d807fc72a0c40d912a5b69736bc8)
#         ;
#
#
#
#
#             var marker_e96a74c1773a4ef6baa26f2e10d1e3f3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b611aad15d18d86cdf9873b7b1ee8e01);
#
#
#         var popup_3af09c2ff10759cd8e09cecebb8fcdfc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a12864a4d2096c202155958abc165b6 = $(`&lt;div id=&quot;html_8a12864a4d2096c202155958abc165b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3af09c2ff10759cd8e09cecebb8fcdfc.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43c8ff6ec14050b1d8a962d8b50ff3a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43c8ff6ec14050b1d8a962d8b50ff3a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43c8ff6ec14050b1d8a962d8b50ff3a6 = L.map(
#                 &quot;map_43c8ff6ec14050b1d8a962d8b50ff3a6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8eb30febe9c8536fb980569c5dcd2ff7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8eb30febe9c8536fb980569c5dcd2ff7.addTo(map_43c8ff6ec14050b1d8a962d8b50ff3a6);
#
#
#             var feature_group_2fed1510e5c3890c1ee887e73b68bfbf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8749112dbdb91207184b991d6d08b0b8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2fed1510e5c3890c1ee887e73b68bfbf);
#
#
#         var popup_356686b7b5f63931a1b53740865f246e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8aca994b00f52e2943626cd7b140746f = $(`&lt;div id=&quot;html_8aca994b00f52e2943626cd7b140746f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_356686b7b5f63931a1b53740865f246e.setContent(html_8aca994b00f52e2943626cd7b140746f);
#
#
#
#         marker_8749112dbdb91207184b991d6d08b0b8.bindPopup(popup_356686b7b5f63931a1b53740865f246e)
#         ;
#
#
#
#
#             var marker_fef7dadb034cb9383504abf702996f65 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2fed1510e5c3890c1ee887e73b68bfbf);
#
#
#         var popup_1489845081ca30e0ca46a442fc6d9cc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6813f8196fb37a6e434d1dfab38ab1c6 = $(`&lt;div id=&quot;html_6813f8196fb37a6e434d1dfab38ab1c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1489845081ca30e0ca46a442fc6d9cc9.setContent(html_6813f8196fb37a6e434d1dfab38ab1c6);
#
#
#
#         marker_fef7dadb034cb9383504abf702996f65.bindPopup(popup_1489845081ca30e0ca46a442fc6d9cc9)
#         ;
#
#
#
#
#             var marker_c7752b2def000f5a2bbccb2eb5d12ff6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2fed1510e5c3890c1ee887e73b68bfbf);
#
#
#         var popup_53fca9eee1ec34bce93af907c899b8c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35eae531f1041dfa72613db92460ed4e = $(`&lt;div id=&quot;html_35eae531f1041dfa72613db92460ed4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_53fca9eee1ec34bce93af907c899b8c7.setContent(html_35eae531f1041dfa72613db92460ed4e);
#
#
#
#         marker_c7752b2def000f5a2bbccb2eb5d12ff6.bindPopup(popup_53fca9eee1ec34bce93af907c899b8c7)
#         ;
#
#
#
#
#             var marker_18c0bbc9291dff2660bc27d37a18ace5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2fed1510e5c3890c1ee887e73b68bfbf);
#
#
#         var popup_198008271b13c6b668f85adee6d1d479 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2b1e937675f35db6a0c3ac9fb26378b = $(`&lt;div id=&quot;html_f2b1e937675f35db6a0c3ac9fb26378b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_198008271b13c6b668f85adee6d1d479.setContent(html_f2b1e937675f35db6a0c3ac9fb26378b);
#
#
#
#         marker_18c0bbc9291dff2660bc27d37a18ace5.bindPopup(popup_198008271b13c6b668f85adee6d1d479)
#         ;
#
#
#
#
#             var marker_13d820862a3f902cb652539c847f4642 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2fed1510e5c3890c1ee887e73b68bfbf);
#
#
#         var popup_c29eef506d8941b16a96c2a7a633da53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c67a45fd58f94fba067b46d16d158de8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c67a45fd58f94fba067b46d16d158de8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c67a45fd58f94fba067b46d16d158de8 = L.map(
#                 &quot;map_c67a45fd58f94fba067b46d16d158de8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_756f13a7da242dd2f7d114b7af147d1f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_756f13a7da242dd2f7d114b7af147d1f.addTo(map_c67a45fd58f94fba067b46d16d158de8);
#
#
#             var feature_group_6d6c24d747e46e259c829c481f47ffe6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6d6c24d747e46e259c829c481f47ffe6.addTo(map_c67a45fd58f94fba067b46d16d158de8);
#
#
#             var feature_group_sub_group_a0d3cb7b358af746de78d306228b4dc2 = L.featureGroup.subGroup(
#                 feature_group_6d6c24d747e46e259c829c481f47ffe6
#             );
#
#
#             var marker_bbf284fe9f44894d8d5d5dd731fc0752 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a0d3cb7b358af746de78d306228b4dc2);
#
#
#         var popup_3473a6919240794e845d0b1fd2747579 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b05dec71b3cf0dff1719d21cb447b5f = $(`&lt;div id=&quot;html_5b05dec71b3cf0dff1719d21cb447b5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3473a6919240794e845d0b1fd2747579.setContent(html_5b05dec71b3cf0dff1719d21cb447b5f);
#
#
#
#         marker_bbf284fe9f44894d8d5d5dd731fc0752.bindPopup(popup_3473a6919240794e845d0b1fd2747579)
#         ;
#
#
#
#
#             var marker_e4d968d64296d8d484eeda20a7fb89f6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a0d3cb7b358af746de78d306228b4dc2);
#
#
#         var popup_2cb1fe9be24f3e29a8c98ee883211c4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e13d89b4080db248b06174b20c46fd29 = $(`&lt;div id=&quot;html_e13d89b4080db248b06174b20c46fd29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2cb1fe9be24f3e29a8c98ee883211c4d.setContent(html_e13d89b4080db248b06174b20c46fd29);
#
#
#
#         marker_e4d968d64296d8d484eeda20a7fb89f6.bindPopup(popup_2cb1fe9be24f3e29a8c98ee883211c4d)
#         ;
#
#
#
#
#             var marker_0ab62e86748dcb009cae3f63d4513590 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a0d3cb7b358af746de78d306228b4dc2);
#
#
#         var popup_7fbac0c3dc71e293f3e7dd0050afac61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4018a98bf1c87bbbb39d5f1f2bcb5a6 = $(`&lt;div id=&quot;html_f4018a98bf1c87bbbb39d5f1f2bcb5a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7fbac0c3dc71e293f3e7dd0050afac61.setContent(html_f4018a98bf1c87bbbb39d5f1f2bcb5a6);
#
#
#
#         marker_0ab62e86748dcb009cae3f63d4513590.bindPopup(popup_7fbac0c3dc71e293f3e7dd0050afac61)
#         ;
#
#
#
#
#             var marker_6e59ce6e0c61554d71ae07385c931dd9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a0d3cb7b358af746de78d306228b4dc2);
#
#
#         var popup_6dc631750708e3248d4cac91353c51d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8795a26907805f05868ccdd521d045ad = $(`&lt;div id=&quot;html_8795a26907805f05868ccdd521d045ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6dc631750708e3248d4cac91353c51d9.setContent(html_8795a26907805f05868ccdd521d045ad);
#
#
#
#         marker_
