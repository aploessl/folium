# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4583d9080ffc5fe1b4ebfee726c4a8e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4583d9080ffc5fe1b4ebfee726c4a8e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4583d9080ffc5fe1b4ebfee726c4a8e9 = L.map(
#                 &quot;map_4583d9080ffc5fe1b4ebfee726c4a8e9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1f5cf2b4e5b155b7767e160764ff48a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a1f5cf2b4e5b155b7767e160764ff48a.addTo(map_4583d9080ffc5fe1b4ebfee726c4a8e9);
#
#
#             var marker_25b9cb1ebebee9610af59757bdb41e2b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4583d9080ffc5fe1b4ebfee726c4a8e9);
#
#
#         var popup_5e8a0c7a14cb1e5c110c0986ecb9ed36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eaf833d2056e452a164bb221e2d79e8c = $(`&lt;div id=&quot;html_eaf833d2056e452a164bb221e2d79e8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5e8a0c7a14cb1e5c110c0986ecb9ed36.setContent(html_eaf833d2056e452a164bb221e2d79e8c);
#
#
#
#         marker_25b9cb1ebebee9610af59757bdb41e2b.bindPopup(popup_5e8a0c7a14cb1e5c110c0986ecb9ed36)
#         ;
#
#
#
#
#             var marker_2730bb1440fca5de589cea31c9359352 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4583d9080ffc5fe1b4ebfee726c4a8e9);
#
#
#         var popup_ab2fbfcb610704d3485defc02539f2f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8d1af24b44e6ff9abd48484e5295f4d = $(`&lt;div id=&quot;html_e8d1af24b44e6ff9abd48484e5295f4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ab2fbfcb610704d3485defc02539f2f6.setContent(html_e8d1af24b44e6ff9abd48484e5295f4d);
#
#
#
#         marker_2730bb1440fca5de589cea31c9359352.bindPopup(popup_ab2fbfcb610704d3485defc02539f2f6)
#         ;
#
#
#
#
#             var marker_fcd7d94069ea8f9addb8895f33f5d894 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4583d9080ffc5fe1b4ebfee726c4a8e9);
#
#
#         var popup_564c0222be2319e53c86e5d0ded71217 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abbbc91ef3217d34860a25e640a9e951 = $(`&lt;div id=&quot;html_abbbc91ef3217d34860a25e640a9e951&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_564c0222be2319e53c86e5d0ded71217.setContent(html_abbbc91ef3217d34860a25e640a9e951);
#
#
#
#         marker_fcd7d94069ea8f9addb8895f33f5d894.bindPopup(popup_564c0222be2319e53c86e5d0ded71217)
#         ;
#
#
#
#
#             var marker_61313c8b6bf8e0d355dc05e5a3771430 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4583d9080ffc5fe1b4ebfee726c4a8e9);
#
#
#         var popup_433756642c94282884c3f2567b7308a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5aa7f98cde259d6ffcba7e92fc88f2d5 = $(`&lt;div id=&quot;html_5aa7f98cde259d6ffcba7e92fc88f2d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_433756642c94282884c3f2567b7308a0.setContent(html_5aa7f98cde259d6ffcba7e92fc88f2d5);
#
#
#
#         marker_61313c8b6bf8e0d355dc05e5a3771430.bindPopup(popup_433756642c94282884c3f2567b7308a0)
#         ;
#
#
#
#
#             var marker_44252e51edc19ebe384a32a4040d5da6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4583d9080ffc5fe1b4ebfee726c4a8e9);
#
#
#         var popup_0137b5e07100fa368812ae45de8b4bb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_623abe2275c5478a826e7ab1b31274b6 = $(`&lt;div id=&quot;html_623abe2275c5478a826e7ab1b31274b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0137b5e07100fa368812ae45de8b4bb0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b11a10a917a4e324785eb76e466e863 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b11a10a917a4e324785eb76e466e863&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b11a10a917a4e324785eb76e466e863 = L.map(
#                 &quot;map_3b11a10a917a4e324785eb76e466e863&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d771717007afb7db27307ceadc5505b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d771717007afb7db27307ceadc5505b.addTo(map_3b11a10a917a4e324785eb76e466e863);
#
#
#             var feature_group_04600cd7cf2accb3ac6b80fec514f0ef = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cdd9cdc573f1f30aa60df47d44bcdeae = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_04600cd7cf2accb3ac6b80fec514f0ef);
#
#
#         var popup_eb94dc76d145c097d900fb148ab4eb33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7857fc8342313bb227a3ef179c74b79 = $(`&lt;div id=&quot;html_a7857fc8342313bb227a3ef179c74b79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_eb94dc76d145c097d900fb148ab4eb33.setContent(html_a7857fc8342313bb227a3ef179c74b79);
#
#
#
#         marker_cdd9cdc573f1f30aa60df47d44bcdeae.bindPopup(popup_eb94dc76d145c097d900fb148ab4eb33)
#         ;
#
#
#
#
#             var marker_52d0cfbe4412287d6e138e0718919137 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_04600cd7cf2accb3ac6b80fec514f0ef);
#
#
#         var popup_fbadf924f5ac3eda3f120ef077844910 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2746712c62583f45cfa1bbdb952cd73c = $(`&lt;div id=&quot;html_2746712c62583f45cfa1bbdb952cd73c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fbadf924f5ac3eda3f120ef077844910.setContent(html_2746712c62583f45cfa1bbdb952cd73c);
#
#
#
#         marker_52d0cfbe4412287d6e138e0718919137.bindPopup(popup_fbadf924f5ac3eda3f120ef077844910)
#         ;
#
#
#
#
#             var marker_f30209dda4c9d7b13a7ed5883d8e0c0e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_04600cd7cf2accb3ac6b80fec514f0ef);
#
#
#         var popup_aaa9265e48b1d246efc2f9cae8120e60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3a36fe3ea730644f520d8fe0478c42c = $(`&lt;div id=&quot;html_f3a36fe3ea730644f520d8fe0478c42c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_aaa9265e48b1d246efc2f9cae8120e60.setContent(html_f3a36fe3ea730644f520d8fe0478c42c);
#
#
#
#         marker_f30209dda4c9d7b13a7ed5883d8e0c0e.bindPopup(popup_aaa9265e48b1d246efc2f9cae8120e60)
#         ;
#
#
#
#
#             var marker_3056b83b751f428f0e109fc14110ae74 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_04600cd7cf2accb3ac6b80fec514f0ef);
#
#
#         var popup_90d28f1c6e2036515f41d12d9c3634ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c969aeb868ef04f6f4025f420cbadfb = $(`&lt;div id=&quot;html_0c969aeb868ef04f6f4025f420cbadfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_90d28f1c6e2036515f41d12d9c3634ef.setContent(html_0c969aeb868ef04f6f4025f420cbadfb);
#
#
#
#         marker_3056b83b751f428f0e109fc14110ae74.bindPopup(popup_90d28f1c6e2036515f41d12d9c3634ef)
#         ;
#
#
#
#
#             var marker_f82fbdb352124601c131c26aafb0a8ff = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_04600cd7cf2accb3ac6b80fec514f0ef);
#
#
#         var popup_ac5a4fbc5e1b580d48ebdb8788b01f9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffc89e846c924229c358f2789965572b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffc89e846c924229c358f2789965572b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ffc89e846c924229c358f2789965572b = L.map(
#                 &quot;map_ffc89e846c924229c358f2789965572b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce4984282aec77d118d5a8b9fe90fb54 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce4984282aec77d118d5a8b9fe90fb54.addTo(map_ffc89e846c924229c358f2789965572b);
#
#
#             var feature_group_294802276a45f37a99a8812126195421 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_294802276a45f37a99a8812126195421.addTo(map_ffc89e846c924229c358f2789965572b);
#
#
#             var feature_group_sub_group_e73a761614e46adaec37e9dbe3b06829 = L.featureGroup.subGroup(
#                 feature_group_294802276a45f37a99a8812126195421
#             );
#
#
#             var marker_8c69963c4cdda47cc621b8e8a83c6814 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e73a761614e46adaec37e9dbe3b06829);
#
#
#         var popup_fdc1fd7e00cba5ec04d0e2fb179562ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83c5145ad83a77b55fd882a755da560d = $(`&lt;div id=&quot;html_83c5145ad83a77b55fd882a755da560d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fdc1fd7e00cba5ec04d0e2fb179562ee.setContent(html_83c5145ad83a77b55fd882a755da560d);
#
#
#
#         marker_8c69963c4cdda47cc621b8e8a83c6814.bindPopup(popup_fdc1fd7e00cba5ec04d0e2fb179562ee)
#         ;
#
#
#
#
#             var marker_574c850e9845ed9357a1f6bf86b92969 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e73a761614e46adaec37e9dbe3b06829);
#
#
#         var popup_8bef48d80f7bb408007dbc545befeddd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71e76221a8421577f9088ff5d2625a9e = $(`&lt;div id=&quot;html_71e76221a8421577f9088ff5d2625a9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8bef48d80f7bb408007dbc545befeddd.setContent(html_71e76221a8421577f9088ff5d2625a9e);
#
#
#
#         marker_574c850e9845ed9357a1f6bf86b92969.bindPopup(popup_8bef48d80f7bb408007dbc545befeddd)
#         ;
#
#
#
#
#             var marker_7d68965e6e4fa6b9b227c3fd53a0111a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e73a761614e46adaec37e9dbe3b06829);
#
#
#         var popup_8dec172476a5fda048c59ca00344fdc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a501e4d48392e029c66f7aa09ce9e67 = $(`&lt;div id=&quot;html_1a501e4d48392e029c66f7aa09ce9e67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8dec172476a5fda048c59ca00344fdc0.setContent(html_1a501e4d48392e029c66f7aa09ce9e67);
#
#
#
#         marker_7d68965e6e4fa6b9b227c3fd53a0111a.bindPopup(popup_8dec172476a5fda048c59ca00344fdc0)
#         ;
#
#
#
#
#             var marker_6f465aff092990579f635a518738714d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e73a761614e46adaec37e9dbe3b06829);
#
#
#         var popup_166bfa68e14bb01ca33c434fc8e0cbbe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc7bbe55c21451426349c5d51883b580 = $(`&lt;div id=&quot;html_fc7bbe55c21451426349c5d51883b580&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_166bfa68e14bb01ca33c434fc8e0cbbe.setContent(html_fc7bbe55c21451426349c5d51883b580);
#
#
#
#         marker_
