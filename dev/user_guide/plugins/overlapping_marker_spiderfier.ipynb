# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6442ce36cf1cf43ad7913d7df8e13f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6442ce36cf1cf43ad7913d7df8e13f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6442ce36cf1cf43ad7913d7df8e13f8 = L.map(
#                 &quot;map_b6442ce36cf1cf43ad7913d7df8e13f8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b62ae9567fe8563d744b2fbe5fb16a56 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b62ae9567fe8563d744b2fbe5fb16a56.addTo(map_b6442ce36cf1cf43ad7913d7df8e13f8);
#
#
#             var marker_800fad5f1f011a8680cc61b89662eca3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b6442ce36cf1cf43ad7913d7df8e13f8);
#
#
#         var popup_fb7cc51fb4be56822277e462660a4e6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1246597c8b9eb376eb62eddcbc4b5593 = $(`&lt;div id=&quot;html_1246597c8b9eb376eb62eddcbc4b5593&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fb7cc51fb4be56822277e462660a4e6f.setContent(html_1246597c8b9eb376eb62eddcbc4b5593);
#
#
#
#         marker_800fad5f1f011a8680cc61b89662eca3.bindPopup(popup_fb7cc51fb4be56822277e462660a4e6f)
#         ;
#
#
#
#
#             var marker_6a9f787e74d2762ec366632eb7b47ad9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b6442ce36cf1cf43ad7913d7df8e13f8);
#
#
#         var popup_13938728e9297d457ca9952220791f66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35a32128aedb679b582a25fb66309305 = $(`&lt;div id=&quot;html_35a32128aedb679b582a25fb66309305&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_13938728e9297d457ca9952220791f66.setContent(html_35a32128aedb679b582a25fb66309305);
#
#
#
#         marker_6a9f787e74d2762ec366632eb7b47ad9.bindPopup(popup_13938728e9297d457ca9952220791f66)
#         ;
#
#
#
#
#             var marker_ea8f88a7703ce6d5a77973ef359b97fc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b6442ce36cf1cf43ad7913d7df8e13f8);
#
#
#         var popup_464a9dd72d62500ca76cc63520665a07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f030a1649e377064ed005f12d7a0bc19 = $(`&lt;div id=&quot;html_f030a1649e377064ed005f12d7a0bc19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_464a9dd72d62500ca76cc63520665a07.setContent(html_f030a1649e377064ed005f12d7a0bc19);
#
#
#
#         marker_ea8f88a7703ce6d5a77973ef359b97fc.bindPopup(popup_464a9dd72d62500ca76cc63520665a07)
#         ;
#
#
#
#
#             var marker_e8da1e2aba163955737668a9cb572f9e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b6442ce36cf1cf43ad7913d7df8e13f8);
#
#
#         var popup_cc161605510680dc4ef5e3895573eaa5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d644b7ddf892d1ea9e9e7cd4c8a83321 = $(`&lt;div id=&quot;html_d644b7ddf892d1ea9e9e7cd4c8a83321&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_cc161605510680dc4ef5e3895573eaa5.setContent(html_d644b7ddf892d1ea9e9e7cd4c8a83321);
#
#
#
#         marker_e8da1e2aba163955737668a9cb572f9e.bindPopup(popup_cc161605510680dc4ef5e3895573eaa5)
#         ;
#
#
#
#
#             var marker_dff0cb36facd12056a05a1743fa0d141 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b6442ce36cf1cf43ad7913d7df8e13f8);
#
#
#         var popup_4cae86a0685e8b6b1110943d72487baa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b1af5295a0160360c2f78bcfdd7b3c9 = $(`&lt;div id=&quot;html_8b1af5295a0160360c2f78bcfdd7b3c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4cae86a0685e8b6b1110943d72487baa.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f837a241cf1575dc85cb5d31be4f0735 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f837a241cf1575dc85cb5d31be4f0735&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f837a241cf1575dc85cb5d31be4f0735 = L.map(
#                 &quot;map_f837a241cf1575dc85cb5d31be4f0735&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_decd7cf1624ecb72830c89e82d87cdd0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_decd7cf1624ecb72830c89e82d87cdd0.addTo(map_f837a241cf1575dc85cb5d31be4f0735);
#
#
#             var feature_group_fcc68751e45db9412fd587c3005f8801 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_dc516da3f29436134920b65a33c42540 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fcc68751e45db9412fd587c3005f8801);
#
#
#         var popup_439ae32a2c9e34755d9a8bd337672792 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a6d4065418ddfb178a94c90ed09ba08 = $(`&lt;div id=&quot;html_8a6d4065418ddfb178a94c90ed09ba08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_439ae32a2c9e34755d9a8bd337672792.setContent(html_8a6d4065418ddfb178a94c90ed09ba08);
#
#
#
#         marker_dc516da3f29436134920b65a33c42540.bindPopup(popup_439ae32a2c9e34755d9a8bd337672792)
#         ;
#
#
#
#
#             var marker_81d460611c76f33094a2d2181fb3dd7a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fcc68751e45db9412fd587c3005f8801);
#
#
#         var popup_abacb5012d74b95d273e8e05753b9c7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e8449917aa52830c1d3137184ade6b2 = $(`&lt;div id=&quot;html_5e8449917aa52830c1d3137184ade6b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_abacb5012d74b95d273e8e05753b9c7b.setContent(html_5e8449917aa52830c1d3137184ade6b2);
#
#
#
#         marker_81d460611c76f33094a2d2181fb3dd7a.bindPopup(popup_abacb5012d74b95d273e8e05753b9c7b)
#         ;
#
#
#
#
#             var marker_9ec1f80d6ed152d8b2abed93d95d1401 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fcc68751e45db9412fd587c3005f8801);
#
#
#         var popup_fb47525b2bb01c3ff1610a37c302ad81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b5472ad27238a8dddf82de1476cb969 = $(`&lt;div id=&quot;html_4b5472ad27238a8dddf82de1476cb969&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fb47525b2bb01c3ff1610a37c302ad81.setContent(html_4b5472ad27238a8dddf82de1476cb969);
#
#
#
#         marker_9ec1f80d6ed152d8b2abed93d95d1401.bindPopup(popup_fb47525b2bb01c3ff1610a37c302ad81)
#         ;
#
#
#
#
#             var marker_da3685b6d53306c425c33a265de68a4c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fcc68751e45db9412fd587c3005f8801);
#
#
#         var popup_d8ec70123d7d7bdc7e09ecf2fb624031 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a420d09c8ac151029ff0cf6c3f4c797 = $(`&lt;div id=&quot;html_0a420d09c8ac151029ff0cf6c3f4c797&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d8ec70123d7d7bdc7e09ecf2fb624031.setContent(html_0a420d09c8ac151029ff0cf6c3f4c797);
#
#
#
#         marker_da3685b6d53306c425c33a265de68a4c.bindPopup(popup_d8ec70123d7d7bdc7e09ecf2fb624031)
#         ;
#
#
#
#
#             var marker_b3d5a81080de1a328f26544364a5d8e0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fcc68751e45db9412fd587c3005f8801);
#
#
#         var popup_8fb93368532a614ce4c878f01790ffaf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b229f3198002985395dd3b7dbf61b6bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b229f3198002985395dd3b7dbf61b6bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b229f3198002985395dd3b7dbf61b6bf = L.map(
#                 &quot;map_b229f3198002985395dd3b7dbf61b6bf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b53a9dc89d2d87204010fe726744f53f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b53a9dc89d2d87204010fe726744f53f.addTo(map_b229f3198002985395dd3b7dbf61b6bf);
#
#
#             var feature_group_e71674bc5b9f74d9207b7de5f043061a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e71674bc5b9f74d9207b7de5f043061a.addTo(map_b229f3198002985395dd3b7dbf61b6bf);
#
#
#             var feature_group_sub_group_92428a6b02128f9d9c6ebd41e438f061 = L.featureGroup.subGroup(
#                 feature_group_e71674bc5b9f74d9207b7de5f043061a
#             );
#
#
#             var marker_8a57130d15c4bf0ed69f88c6b2c84f7a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_92428a6b02128f9d9c6ebd41e438f061);
#
#
#         var popup_c03f7f6d7e807a7257e9759dc7a92278 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_073ba0fa84896d7787eb113c50c465a5 = $(`&lt;div id=&quot;html_073ba0fa84896d7787eb113c50c465a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c03f7f6d7e807a7257e9759dc7a92278.setContent(html_073ba0fa84896d7787eb113c50c465a5);
#
#
#
#         marker_8a57130d15c4bf0ed69f88c6b2c84f7a.bindPopup(popup_c03f7f6d7e807a7257e9759dc7a92278)
#         ;
#
#
#
#
#             var marker_9af7d5bc7a13378e67d60d58b709a421 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_92428a6b02128f9d9c6ebd41e438f061);
#
#
#         var popup_d327b26b3467395931e5c909af0463ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6fd80934520ad7c454932914a5e901a = $(`&lt;div id=&quot;html_c6fd80934520ad7c454932914a5e901a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d327b26b3467395931e5c909af0463ed.setContent(html_c6fd80934520ad7c454932914a5e901a);
#
#
#
#         marker_9af7d5bc7a13378e67d60d58b709a421.bindPopup(popup_d327b26b3467395931e5c909af0463ed)
#         ;
#
#
#
#
#             var marker_5d5ed3056f706bf19c8812ae09c7842e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_92428a6b02128f9d9c6ebd41e438f061);
#
#
#         var popup_1df86ab690b915acc3c8532202ea82bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d9bd6c85c82f7548d84cce7f1b4f03b = $(`&lt;div id=&quot;html_6d9bd6c85c82f7548d84cce7f1b4f03b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1df86ab690b915acc3c8532202ea82bd.setContent(html_6d9bd6c85c82f7548d84cce7f1b4f03b);
#
#
#
#         marker_5d5ed3056f706bf19c8812ae09c7842e.bindPopup(popup_1df86ab690b915acc3c8532202ea82bd)
#         ;
#
#
#
#
#             var marker_659239f75aa54e25352b390bcf4b4e0b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_92428a6b02128f9d9c6ebd41e438f061);
#
#
#         var popup_133bd5b983756b3dd2fec895c7eb4dae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a50434264bb0ae2c6d3966a53f5e834 = $(`&lt;div id=&quot;html_4a50434264bb0ae2c6d3966a53f5e834&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_133bd5b983756b3dd2fec895c7eb4dae.setContent(html_4a50434264bb0ae2c6d3966a53f5e834);
#
#
#
#         marker_
