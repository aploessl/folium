# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da0521c1d50ce2c90d55ff6f8a95ff05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da0521c1d50ce2c90d55ff6f8a95ff05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da0521c1d50ce2c90d55ff6f8a95ff05 = L.map(
#                 &quot;map_da0521c1d50ce2c90d55ff6f8a95ff05&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9accc20c07f16c33d14d29c4eb9ca324 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9accc20c07f16c33d14d29c4eb9ca324.addTo(map_da0521c1d50ce2c90d55ff6f8a95ff05);
#
#
#             var marker_d8a5c59c5a3b24985f298e6f3cf259c1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_da0521c1d50ce2c90d55ff6f8a95ff05);
#
#
#         var popup_1c2cfe7d4239bf094a794edf5c530b74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86802b0ec1bf35b7d6a8297de9247a83 = $(`&lt;div id=&quot;html_86802b0ec1bf35b7d6a8297de9247a83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1c2cfe7d4239bf094a794edf5c530b74.setContent(html_86802b0ec1bf35b7d6a8297de9247a83);
#
#
#
#         marker_d8a5c59c5a3b24985f298e6f3cf259c1.bindPopup(popup_1c2cfe7d4239bf094a794edf5c530b74)
#         ;
#
#
#
#
#             var marker_10e28a8c9c5ed067c380626d71a6a3fb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_da0521c1d50ce2c90d55ff6f8a95ff05);
#
#
#         var popup_c25484f7c1b475fa627e85fef4fc4766 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91940d929825e231a989fd7bbabe709a = $(`&lt;div id=&quot;html_91940d929825e231a989fd7bbabe709a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c25484f7c1b475fa627e85fef4fc4766.setContent(html_91940d929825e231a989fd7bbabe709a);
#
#
#
#         marker_10e28a8c9c5ed067c380626d71a6a3fb.bindPopup(popup_c25484f7c1b475fa627e85fef4fc4766)
#         ;
#
#
#
#
#             var marker_ce0b9f831768b6d1e51e0ee142abe7a3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_da0521c1d50ce2c90d55ff6f8a95ff05);
#
#
#         var popup_b50416e4e394a4c2d64d5805fdf836a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7a5f09508cc52cf017383ce0ff39f88 = $(`&lt;div id=&quot;html_d7a5f09508cc52cf017383ce0ff39f88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b50416e4e394a4c2d64d5805fdf836a8.setContent(html_d7a5f09508cc52cf017383ce0ff39f88);
#
#
#
#         marker_ce0b9f831768b6d1e51e0ee142abe7a3.bindPopup(popup_b50416e4e394a4c2d64d5805fdf836a8)
#         ;
#
#
#
#
#             var marker_a3cd18f3340a85af033fdf1fe93efea3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_da0521c1d50ce2c90d55ff6f8a95ff05);
#
#
#         var popup_9021a3e1f8b25739e8918f20ca9e5513 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc75b915751d3c87a19da164324dff2d = $(`&lt;div id=&quot;html_dc75b915751d3c87a19da164324dff2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9021a3e1f8b25739e8918f20ca9e5513.setContent(html_dc75b915751d3c87a19da164324dff2d);
#
#
#
#         marker_a3cd18f3340a85af033fdf1fe93efea3.bindPopup(popup_9021a3e1f8b25739e8918f20ca9e5513)
#         ;
#
#
#
#
#             var marker_b9a410a8870c8f1bb787267b1d5a1541 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_da0521c1d50ce2c90d55ff6f8a95ff05);
#
#
#         var popup_406ccb6e85bd83d3b068680bd931f0a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2039dea7376872170c18a83c27028d4b = $(`&lt;div id=&quot;html_2039dea7376872170c18a83c27028d4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_406ccb6e85bd83d3b068680bd931f0a7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d18e48640bf4c7bd85b16bce51a4362e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d18e48640bf4c7bd85b16bce51a4362e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d18e48640bf4c7bd85b16bce51a4362e = L.map(
#                 &quot;map_d18e48640bf4c7bd85b16bce51a4362e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91fd7feedc76dab6ac3d61fb57aaf8ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_91fd7feedc76dab6ac3d61fb57aaf8ae.addTo(map_d18e48640bf4c7bd85b16bce51a4362e);
#
#
#             var feature_group_392d7e47510a3b329ced0a29183ac81d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c3e6d8aae960f99ef1b9c38741e87d35 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_392d7e47510a3b329ced0a29183ac81d);
#
#
#         var popup_44e25926f61924bc4d17145c74a9dec7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5379a5256fa9b5d6558b55582b7c6ef = $(`&lt;div id=&quot;html_a5379a5256fa9b5d6558b55582b7c6ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_44e25926f61924bc4d17145c74a9dec7.setContent(html_a5379a5256fa9b5d6558b55582b7c6ef);
#
#
#
#         marker_c3e6d8aae960f99ef1b9c38741e87d35.bindPopup(popup_44e25926f61924bc4d17145c74a9dec7)
#         ;
#
#
#
#
#             var marker_73a4f84e4d90baf065282909ba7bd832 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_392d7e47510a3b329ced0a29183ac81d);
#
#
#         var popup_a5bfcf3f7f1fe6896d686abb7f5f537d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_651eb476754942d8ee2bf6d85ecf0a88 = $(`&lt;div id=&quot;html_651eb476754942d8ee2bf6d85ecf0a88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a5bfcf3f7f1fe6896d686abb7f5f537d.setContent(html_651eb476754942d8ee2bf6d85ecf0a88);
#
#
#
#         marker_73a4f84e4d90baf065282909ba7bd832.bindPopup(popup_a5bfcf3f7f1fe6896d686abb7f5f537d)
#         ;
#
#
#
#
#             var marker_28eb8b84c799d2e731c8d6f9d661be1b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_392d7e47510a3b329ced0a29183ac81d);
#
#
#         var popup_3300e453a0eb7ff76acecfd1616dde37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e3c9e31f5a87bcfe66b607494f5fd62 = $(`&lt;div id=&quot;html_5e3c9e31f5a87bcfe66b607494f5fd62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3300e453a0eb7ff76acecfd1616dde37.setContent(html_5e3c9e31f5a87bcfe66b607494f5fd62);
#
#
#
#         marker_28eb8b84c799d2e731c8d6f9d661be1b.bindPopup(popup_3300e453a0eb7ff76acecfd1616dde37)
#         ;
#
#
#
#
#             var marker_edca394d057526c0e3811ef281a7e42d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_392d7e47510a3b329ced0a29183ac81d);
#
#
#         var popup_0111a6503855e47fcad2566593db7f48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f73012cbe23215924b5b57fd7acf080c = $(`&lt;div id=&quot;html_f73012cbe23215924b5b57fd7acf080c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0111a6503855e47fcad2566593db7f48.setContent(html_f73012cbe23215924b5b57fd7acf080c);
#
#
#
#         marker_edca394d057526c0e3811ef281a7e42d.bindPopup(popup_0111a6503855e47fcad2566593db7f48)
#         ;
#
#
#
#
#             var marker_c9a29665c91c5d6a38a5d11d5f81e75d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_392d7e47510a3b329ced0a29183ac81d);
#
#
#         var popup_9632c0bc8a063fe3b90349452097ec03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2455d1b94eee318ce5f2373d052f88a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2455d1b94eee318ce5f2373d052f88a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2455d1b94eee318ce5f2373d052f88a5 = L.map(
#                 &quot;map_2455d1b94eee318ce5f2373d052f88a5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74c0b98d6a91168b4f87842600728a82 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_74c0b98d6a91168b4f87842600728a82.addTo(map_2455d1b94eee318ce5f2373d052f88a5);
#
#
#             var feature_group_34b4dbe91cd8b6a019df8557e4985475 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_34b4dbe91cd8b6a019df8557e4985475.addTo(map_2455d1b94eee318ce5f2373d052f88a5);
#
#
#             var feature_group_sub_group_84595351dc0492cf158901172efc278c = L.featureGroup.subGroup(
#                 feature_group_34b4dbe91cd8b6a019df8557e4985475
#             );
#
#
#             var marker_dd9b26d7291dacc841fda9df3585b708 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_84595351dc0492cf158901172efc278c);
#
#
#         var popup_2400949cc8a580efe957b90a2d205bc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adc95504d87db1d79e77f1caca68dc93 = $(`&lt;div id=&quot;html_adc95504d87db1d79e77f1caca68dc93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2400949cc8a580efe957b90a2d205bc0.setContent(html_adc95504d87db1d79e77f1caca68dc93);
#
#
#
#         marker_dd9b26d7291dacc841fda9df3585b708.bindPopup(popup_2400949cc8a580efe957b90a2d205bc0)
#         ;
#
#
#
#
#             var marker_f6b34eb913e4361ec9398d4ade7d4aeb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_84595351dc0492cf158901172efc278c);
#
#
#         var popup_04b585c3386a76067f6e54264d3a7fc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cff65401cccdfb65ffa0394e93eda8eb = $(`&lt;div id=&quot;html_cff65401cccdfb65ffa0394e93eda8eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_04b585c3386a76067f6e54264d3a7fc9.setContent(html_cff65401cccdfb65ffa0394e93eda8eb);
#
#
#
#         marker_f6b34eb913e4361ec9398d4ade7d4aeb.bindPopup(popup_04b585c3386a76067f6e54264d3a7fc9)
#         ;
#
#
#
#
#             var marker_7231cb345bf6801367e62c9e9c1fc75c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_84595351dc0492cf158901172efc278c);
#
#
#         var popup_6eb67ddbfa4b332e15e9716c6f33cf48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2d0625bcb1c82902ff2d7e562613a5e = $(`&lt;div id=&quot;html_a2d0625bcb1c82902ff2d7e562613a5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6eb67ddbfa4b332e15e9716c6f33cf48.setContent(html_a2d0625bcb1c82902ff2d7e562613a5e);
#
#
#
#         marker_7231cb345bf6801367e62c9e9c1fc75c.bindPopup(popup_6eb67ddbfa4b332e15e9716c6f33cf48)
#         ;
#
#
#
#
#             var marker_ce798fb95bfdaaa38bdb7120069f6c73 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_84595351dc0492cf158901172efc278c);
#
#
#         var popup_c3b33625c29a12bc9a902f07e19e9df7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63554b9785097884f6e159789416d152 = $(`&lt;div id=&quot;html_63554b9785097884f6e159789416d152&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c3b33625c29a12bc9a902f07e19e9df7.setContent(html_63554b9785097884f6e159789416d152);
#
#
#
#         marker_
