# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65b8044c36e983e234c452e4ced028dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65b8044c36e983e234c452e4ced028dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65b8044c36e983e234c452e4ced028dc = L.map(
#                 &quot;map_65b8044c36e983e234c452e4ced028dc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3882dccea2bada3c8ef75f5ddd024fb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3882dccea2bada3c8ef75f5ddd024fb.addTo(map_65b8044c36e983e234c452e4ced028dc);
#
#
#             var marker_6bf560ba7043aaa96d8f281a94de10ee = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_65b8044c36e983e234c452e4ced028dc);
#
#
#         var popup_c4aadd4ca887003e8a48d33e11981325 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_768a85f244bd2e7b5b5fd3cfffdb36f1 = $(`&lt;div id=&quot;html_768a85f244bd2e7b5b5fd3cfffdb36f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c4aadd4ca887003e8a48d33e11981325.setContent(html_768a85f244bd2e7b5b5fd3cfffdb36f1);
#
#
#
#         marker_6bf560ba7043aaa96d8f281a94de10ee.bindPopup(popup_c4aadd4ca887003e8a48d33e11981325)
#         ;
#
#
#
#
#             var marker_0c43acceda1ee325ea1f04a0777440c2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_65b8044c36e983e234c452e4ced028dc);
#
#
#         var popup_daf6ecacd4bec1e8bea224398a5339ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66222aca0aebbbf1011e5120ea4e5146 = $(`&lt;div id=&quot;html_66222aca0aebbbf1011e5120ea4e5146&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_daf6ecacd4bec1e8bea224398a5339ae.setContent(html_66222aca0aebbbf1011e5120ea4e5146);
#
#
#
#         marker_0c43acceda1ee325ea1f04a0777440c2.bindPopup(popup_daf6ecacd4bec1e8bea224398a5339ae)
#         ;
#
#
#
#
#             var marker_6923ff01bf1f516641ddae1e98eb116c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_65b8044c36e983e234c452e4ced028dc);
#
#
#         var popup_d3fb8e67ecd7e916519f43c3a138b945 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8241178fc030cba19569fa5d68be1cbe = $(`&lt;div id=&quot;html_8241178fc030cba19569fa5d68be1cbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d3fb8e67ecd7e916519f43c3a138b945.setContent(html_8241178fc030cba19569fa5d68be1cbe);
#
#
#
#         marker_6923ff01bf1f516641ddae1e98eb116c.bindPopup(popup_d3fb8e67ecd7e916519f43c3a138b945)
#         ;
#
#
#
#
#             var marker_963fcc86a7bf95b1e9e162da44d397ff = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_65b8044c36e983e234c452e4ced028dc);
#
#
#         var popup_eb754ba8d656f40c6c8a8188394c4cd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5df0e3b7aa3b438b11b124e4c99b9d15 = $(`&lt;div id=&quot;html_5df0e3b7aa3b438b11b124e4c99b9d15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_eb754ba8d656f40c6c8a8188394c4cd7.setContent(html_5df0e3b7aa3b438b11b124e4c99b9d15);
#
#
#
#         marker_963fcc86a7bf95b1e9e162da44d397ff.bindPopup(popup_eb754ba8d656f40c6c8a8188394c4cd7)
#         ;
#
#
#
#
#             var marker_99c736c32b2a0d75c9fd3a8bd77022d3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_65b8044c36e983e234c452e4ced028dc);
#
#
#         var popup_7891555b810ad680bfacb6b72b8a9fa7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03cfecf57fd60e1c859b0bae4526ece5 = $(`&lt;div id=&quot;html_03cfecf57fd60e1c859b0bae4526ece5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7891555b810ad680bfacb6b72b8a9fa7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4dfbce5aecc1cd4a857cf35da288b93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4dfbce5aecc1cd4a857cf35da288b93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4dfbce5aecc1cd4a857cf35da288b93 = L.map(
#                 &quot;map_e4dfbce5aecc1cd4a857cf35da288b93&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfdaf94aa9fd6546649beed436bc12ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cfdaf94aa9fd6546649beed436bc12ff.addTo(map_e4dfbce5aecc1cd4a857cf35da288b93);
#
#
#             var feature_group_6fb7bdffd870c2f886e584ee327757fe = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_893bb24087d36005d5b0c53e7ecbb664 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6fb7bdffd870c2f886e584ee327757fe);
#
#
#         var popup_30aeb0bee76c063de71d0f62ea24fdbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f1baf10eade045a1de572566d00655f = $(`&lt;div id=&quot;html_7f1baf10eade045a1de572566d00655f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_30aeb0bee76c063de71d0f62ea24fdbd.setContent(html_7f1baf10eade045a1de572566d00655f);
#
#
#
#         marker_893bb24087d36005d5b0c53e7ecbb664.bindPopup(popup_30aeb0bee76c063de71d0f62ea24fdbd)
#         ;
#
#
#
#
#             var marker_28f40fe7f9d5e24e76f9c0a5a1bb2330 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6fb7bdffd870c2f886e584ee327757fe);
#
#
#         var popup_a91c1b48247286c3c3b17131e09fd7f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4f4edee9cb87892f575a18b4e84c3ac = $(`&lt;div id=&quot;html_b4f4edee9cb87892f575a18b4e84c3ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a91c1b48247286c3c3b17131e09fd7f8.setContent(html_b4f4edee9cb87892f575a18b4e84c3ac);
#
#
#
#         marker_28f40fe7f9d5e24e76f9c0a5a1bb2330.bindPopup(popup_a91c1b48247286c3c3b17131e09fd7f8)
#         ;
#
#
#
#
#             var marker_0a647b1a864e35f9541b82a937793208 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6fb7bdffd870c2f886e584ee327757fe);
#
#
#         var popup_d9a7a84107c168a3661a30a51858bd9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c141ed03d382a1bb87b6a24592c19db3 = $(`&lt;div id=&quot;html_c141ed03d382a1bb87b6a24592c19db3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d9a7a84107c168a3661a30a51858bd9c.setContent(html_c141ed03d382a1bb87b6a24592c19db3);
#
#
#
#         marker_0a647b1a864e35f9541b82a937793208.bindPopup(popup_d9a7a84107c168a3661a30a51858bd9c)
#         ;
#
#
#
#
#             var marker_175978de7c2008924f7fe4d0c45d2041 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6fb7bdffd870c2f886e584ee327757fe);
#
#
#         var popup_04ffd9090e9bab62c18166f42a287004 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74e4e860508cd441422640eedda41937 = $(`&lt;div id=&quot;html_74e4e860508cd441422640eedda41937&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_04ffd9090e9bab62c18166f42a287004.setContent(html_74e4e860508cd441422640eedda41937);
#
#
#
#         marker_175978de7c2008924f7fe4d0c45d2041.bindPopup(popup_04ffd9090e9bab62c18166f42a287004)
#         ;
#
#
#
#
#             var marker_21e37b6dc928819361ec4e31b797d74f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6fb7bdffd870c2f886e584ee327757fe);
#
#
#         var popup_1eea8618ef1959a375fb79131672dac9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b73639c791fb00430883e170ab9aa08e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b73639c791fb00430883e170ab9aa08e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b73639c791fb00430883e170ab9aa08e = L.map(
#                 &quot;map_b73639c791fb00430883e170ab9aa08e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e29f7fe134d504129441a219cebdf0c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e29f7fe134d504129441a219cebdf0c.addTo(map_b73639c791fb00430883e170ab9aa08e);
#
#
#             var feature_group_cc559cfece717312bcae01ea9c7abfd6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cc559cfece717312bcae01ea9c7abfd6.addTo(map_b73639c791fb00430883e170ab9aa08e);
#
#
#             var feature_group_sub_group_32ab2713321170b7a32efb9594b350f2 = L.featureGroup.subGroup(
#                 feature_group_cc559cfece717312bcae01ea9c7abfd6
#             );
#
#
#             var marker_23d1ae47e5df3182d376e9cc72418c6a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_32ab2713321170b7a32efb9594b350f2);
#
#
#         var popup_5af2dad97ab9c51b20c21c2adcc3f1ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84ef8d59af73fb22c323d292cc3df1fa = $(`&lt;div id=&quot;html_84ef8d59af73fb22c323d292cc3df1fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5af2dad97ab9c51b20c21c2adcc3f1ee.setContent(html_84ef8d59af73fb22c323d292cc3df1fa);
#
#
#
#         marker_23d1ae47e5df3182d376e9cc72418c6a.bindPopup(popup_5af2dad97ab9c51b20c21c2adcc3f1ee)
#         ;
#
#
#
#
#             var marker_a640e0a4ec66d4d48d7f8d44eb3e67fc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_32ab2713321170b7a32efb9594b350f2);
#
#
#         var popup_fee0a36734f02b82f0995ef3af6b5a29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57615d4d7b6cbd26934788310a5f4a08 = $(`&lt;div id=&quot;html_57615d4d7b6cbd26934788310a5f4a08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fee0a36734f02b82f0995ef3af6b5a29.setContent(html_57615d4d7b6cbd26934788310a5f4a08);
#
#
#
#         marker_a640e0a4ec66d4d48d7f8d44eb3e67fc.bindPopup(popup_fee0a36734f02b82f0995ef3af6b5a29)
#         ;
#
#
#
#
#             var marker_8642c7f34a4e4f8617e31770cf39402f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_32ab2713321170b7a32efb9594b350f2);
#
#
#         var popup_9b4d380a885e66d181e01187fadce959 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03833def9faf5f9df9476fd11d9ecdcf = $(`&lt;div id=&quot;html_03833def9faf5f9df9476fd11d9ecdcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9b4d380a885e66d181e01187fadce959.setContent(html_03833def9faf5f9df9476fd11d9ecdcf);
#
#
#
#         marker_8642c7f34a4e4f8617e31770cf39402f.bindPopup(popup_9b4d380a885e66d181e01187fadce959)
#         ;
#
#
#
#
#             var marker_1a04d8f8eaeef4aa2eda565f09d1009a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_32ab2713321170b7a32efb9594b350f2);
#
#
#         var popup_ebb7a172942ec3036c1ba69998c0ad43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1879530907e1b9ba08843a0dda7b297a = $(`&lt;div id=&quot;html_1879530907e1b9ba08843a0dda7b297a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ebb7a172942ec3036c1ba69998c0ad43.setContent(html_1879530907e1b9ba08843a0dda7b297a);
#
#
#
#         marker_
