# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c57bb2ada6d508cc05f3d9c4795af45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c57bb2ada6d508cc05f3d9c4795af45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c57bb2ada6d508cc05f3d9c4795af45 = L.map(
#                 &quot;map_7c57bb2ada6d508cc05f3d9c4795af45&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea0f4e0c24cad84fb3db99c64a057863 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea0f4e0c24cad84fb3db99c64a057863.addTo(map_7c57bb2ada6d508cc05f3d9c4795af45);
#
#
#             var marker_d0fb19a9d86e24e71e2691b87e1c053a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7c57bb2ada6d508cc05f3d9c4795af45);
#
#
#         var popup_168fbe110b5299edb7dff3a49fc037de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cff041322bbd12289ce1bfe5cbd2e9cb = $(`&lt;div id=&quot;html_cff041322bbd12289ce1bfe5cbd2e9cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_168fbe110b5299edb7dff3a49fc037de.setContent(html_cff041322bbd12289ce1bfe5cbd2e9cb);
#
#
#
#         marker_d0fb19a9d86e24e71e2691b87e1c053a.bindPopup(popup_168fbe110b5299edb7dff3a49fc037de)
#         ;
#
#
#
#
#             var marker_6bb413dc50c71666b59886b649671b68 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7c57bb2ada6d508cc05f3d9c4795af45);
#
#
#         var popup_6e2d76f3b4f15af2f37cfd09e3c10234 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a540ec936eba29fef20c38408c5949c = $(`&lt;div id=&quot;html_9a540ec936eba29fef20c38408c5949c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6e2d76f3b4f15af2f37cfd09e3c10234.setContent(html_9a540ec936eba29fef20c38408c5949c);
#
#
#
#         marker_6bb413dc50c71666b59886b649671b68.bindPopup(popup_6e2d76f3b4f15af2f37cfd09e3c10234)
#         ;
#
#
#
#
#             var marker_52cafd41f26ce7a0ed41a73978a89637 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7c57bb2ada6d508cc05f3d9c4795af45);
#
#
#         var popup_c5a2260405cfe64e6949e01aabcd7c91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a4e97f06997a64d886d71d54881dc2b = $(`&lt;div id=&quot;html_4a4e97f06997a64d886d71d54881dc2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c5a2260405cfe64e6949e01aabcd7c91.setContent(html_4a4e97f06997a64d886d71d54881dc2b);
#
#
#
#         marker_52cafd41f26ce7a0ed41a73978a89637.bindPopup(popup_c5a2260405cfe64e6949e01aabcd7c91)
#         ;
#
#
#
#
#             var marker_daba36c82500d4ff741afd476da54b42 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7c57bb2ada6d508cc05f3d9c4795af45);
#
#
#         var popup_57ef037d6c854daa311ccde062234daf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_354ee923072e91301069422938c27616 = $(`&lt;div id=&quot;html_354ee923072e91301069422938c27616&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_57ef037d6c854daa311ccde062234daf.setContent(html_354ee923072e91301069422938c27616);
#
#
#
#         marker_daba36c82500d4ff741afd476da54b42.bindPopup(popup_57ef037d6c854daa311ccde062234daf)
#         ;
#
#
#
#
#             var marker_f896af45d72b885cb91e93f95243db3b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7c57bb2ada6d508cc05f3d9c4795af45);
#
#
#         var popup_3a2299548b62d822d04971aa822e9331 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ae038f5817d5d7e3047e51e53931da6 = $(`&lt;div id=&quot;html_6ae038f5817d5d7e3047e51e53931da6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3a2299548b62d822d04971aa822e9331.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e3927fbd49f781a9655b773897a1b46 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e3927fbd49f781a9655b773897a1b46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e3927fbd49f781a9655b773897a1b46 = L.map(
#                 &quot;map_0e3927fbd49f781a9655b773897a1b46&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4dd2d47901f75204ec40ae4e0e433941 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4dd2d47901f75204ec40ae4e0e433941.addTo(map_0e3927fbd49f781a9655b773897a1b46);
#
#
#             var feature_group_e8450715ce365c264d9d95800e70981b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e35366ae5442b733349ee696f00e7db3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e8450715ce365c264d9d95800e70981b);
#
#
#         var popup_8e085d7da9dd3f1882d3840c4e97bb75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f529ab737aabb7f4d709f5b578bd2221 = $(`&lt;div id=&quot;html_f529ab737aabb7f4d709f5b578bd2221&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8e085d7da9dd3f1882d3840c4e97bb75.setContent(html_f529ab737aabb7f4d709f5b578bd2221);
#
#
#
#         marker_e35366ae5442b733349ee696f00e7db3.bindPopup(popup_8e085d7da9dd3f1882d3840c4e97bb75)
#         ;
#
#
#
#
#             var marker_ea553654bb3468137692087aa8b77cdf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e8450715ce365c264d9d95800e70981b);
#
#
#         var popup_108e83409ff0d04c3cfba76639808460 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c63ab00e6fef96a0ee52945fb9c0a76 = $(`&lt;div id=&quot;html_9c63ab00e6fef96a0ee52945fb9c0a76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_108e83409ff0d04c3cfba76639808460.setContent(html_9c63ab00e6fef96a0ee52945fb9c0a76);
#
#
#
#         marker_ea553654bb3468137692087aa8b77cdf.bindPopup(popup_108e83409ff0d04c3cfba76639808460)
#         ;
#
#
#
#
#             var marker_a10202a1d804d000aa7144b3b25cb2be = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e8450715ce365c264d9d95800e70981b);
#
#
#         var popup_3fc2742e911a8887d0a78ebe19a0dba6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab0b7fc4738f7ed67831ce18cf52db6f = $(`&lt;div id=&quot;html_ab0b7fc4738f7ed67831ce18cf52db6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3fc2742e911a8887d0a78ebe19a0dba6.setContent(html_ab0b7fc4738f7ed67831ce18cf52db6f);
#
#
#
#         marker_a10202a1d804d000aa7144b3b25cb2be.bindPopup(popup_3fc2742e911a8887d0a78ebe19a0dba6)
#         ;
#
#
#
#
#             var marker_222e1e5fa1264d2702987b8e48e50444 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e8450715ce365c264d9d95800e70981b);
#
#
#         var popup_595f106ae8f9556cf2c60862fb30016f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33220d45121f9d3f2629809a57385507 = $(`&lt;div id=&quot;html_33220d45121f9d3f2629809a57385507&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_595f106ae8f9556cf2c60862fb30016f.setContent(html_33220d45121f9d3f2629809a57385507);
#
#
#
#         marker_222e1e5fa1264d2702987b8e48e50444.bindPopup(popup_595f106ae8f9556cf2c60862fb30016f)
#         ;
#
#
#
#
#             var marker_80dd8b9008f5261b175e6938f10e0eae = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e8450715ce365c264d9d95800e70981b);
#
#
#         var popup_6f177a54e9c611fa0afe6590db5819b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d4c0846d74604e3ff7ede2019e05e6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d4c0846d74604e3ff7ede2019e05e6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d4c0846d74604e3ff7ede2019e05e6e = L.map(
#                 &quot;map_2d4c0846d74604e3ff7ede2019e05e6e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4324c65b6246a275c11b1bd7faf00193 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4324c65b6246a275c11b1bd7faf00193.addTo(map_2d4c0846d74604e3ff7ede2019e05e6e);
#
#
#             var feature_group_c0e3fe26e90d24a423a0f9dcbf6a71ab = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c0e3fe26e90d24a423a0f9dcbf6a71ab.addTo(map_2d4c0846d74604e3ff7ede2019e05e6e);
#
#
#             var feature_group_sub_group_cbe2f982804d99698d9eb35dc95ab747 = L.featureGroup.subGroup(
#                 feature_group_c0e3fe26e90d24a423a0f9dcbf6a71ab
#             );
#
#
#             var marker_e4a672d1bc14c4f6ee4f86c3a86cac36 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbe2f982804d99698d9eb35dc95ab747);
#
#
#         var popup_267bcec3cdeb33f6174d8be8c367cdc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91c9075e59f47e2202075eaf0b910bdb = $(`&lt;div id=&quot;html_91c9075e59f47e2202075eaf0b910bdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_267bcec3cdeb33f6174d8be8c367cdc9.setContent(html_91c9075e59f47e2202075eaf0b910bdb);
#
#
#
#         marker_e4a672d1bc14c4f6ee4f86c3a86cac36.bindPopup(popup_267bcec3cdeb33f6174d8be8c367cdc9)
#         ;
#
#
#
#
#             var marker_d6f2cf108a0d43a4f60cecda8751a181 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbe2f982804d99698d9eb35dc95ab747);
#
#
#         var popup_31e3f156edc1ac04faa358c600479f28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee778c2c6a74854eb855b242330e2c3d = $(`&lt;div id=&quot;html_ee778c2c6a74854eb855b242330e2c3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_31e3f156edc1ac04faa358c600479f28.setContent(html_ee778c2c6a74854eb855b242330e2c3d);
#
#
#
#         marker_d6f2cf108a0d43a4f60cecda8751a181.bindPopup(popup_31e3f156edc1ac04faa358c600479f28)
#         ;
#
#
#
#
#             var marker_d62a5370e2c50c9f4d299bda59fd98f4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbe2f982804d99698d9eb35dc95ab747);
#
#
#         var popup_d27b281b84963863eeb081b9a4ee4b89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1eac80b6680fb8665923374a0a8cc7c = $(`&lt;div id=&quot;html_c1eac80b6680fb8665923374a0a8cc7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d27b281b84963863eeb081b9a4ee4b89.setContent(html_c1eac80b6680fb8665923374a0a8cc7c);
#
#
#
#         marker_d62a5370e2c50c9f4d299bda59fd98f4.bindPopup(popup_d27b281b84963863eeb081b9a4ee4b89)
#         ;
#
#
#
#
#             var marker_a4a66073364b579a67c972c4a7f53ac9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbe2f982804d99698d9eb35dc95ab747);
#
#
#         var popup_5c5abf56007eaf4811be6b4970021e96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfe25ae5c4418dafbf4636f33c501b83 = $(`&lt;div id=&quot;html_bfe25ae5c4418dafbf4636f33c501b83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5c5abf56007eaf4811be6b4970021e96.setContent(html_bfe25ae5c4418dafbf4636f33c501b83);
#
#
#
#         marker_
