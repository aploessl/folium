# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66a378ba78c8dfe2a136130f01e54378 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66a378ba78c8dfe2a136130f01e54378&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66a378ba78c8dfe2a136130f01e54378 = L.map(
#                 &quot;map_66a378ba78c8dfe2a136130f01e54378&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_897b25bcd35b71f7678186a78d371c08 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_897b25bcd35b71f7678186a78d371c08.addTo(map_66a378ba78c8dfe2a136130f01e54378);
#
#
#             var marker_2d9e24a8bb63e9075839381f19ce098a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_66a378ba78c8dfe2a136130f01e54378);
#
#
#         var popup_3b03fb6c131c2b6285df1c7e4aea1179 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d97a929567abc64c74180149461352c = $(`&lt;div id=&quot;html_7d97a929567abc64c74180149461352c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3b03fb6c131c2b6285df1c7e4aea1179.setContent(html_7d97a929567abc64c74180149461352c);
#
#
#
#         marker_2d9e24a8bb63e9075839381f19ce098a.bindPopup(popup_3b03fb6c131c2b6285df1c7e4aea1179)
#         ;
#
#
#
#
#             var marker_e15d2d424186a919248f194b663ce52b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_66a378ba78c8dfe2a136130f01e54378);
#
#
#         var popup_54e216191cd48325aa87911d6a7e82de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cf9a75adf23e76fc41479709a6c2078 = $(`&lt;div id=&quot;html_0cf9a75adf23e76fc41479709a6c2078&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_54e216191cd48325aa87911d6a7e82de.setContent(html_0cf9a75adf23e76fc41479709a6c2078);
#
#
#
#         marker_e15d2d424186a919248f194b663ce52b.bindPopup(popup_54e216191cd48325aa87911d6a7e82de)
#         ;
#
#
#
#
#             var marker_647e8fa8137ad197f824690f6e893029 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_66a378ba78c8dfe2a136130f01e54378);
#
#
#         var popup_d538f07d0ba35dc97c2a51cd32676634 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f88210cf31984156972978ed34de5878 = $(`&lt;div id=&quot;html_f88210cf31984156972978ed34de5878&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d538f07d0ba35dc97c2a51cd32676634.setContent(html_f88210cf31984156972978ed34de5878);
#
#
#
#         marker_647e8fa8137ad197f824690f6e893029.bindPopup(popup_d538f07d0ba35dc97c2a51cd32676634)
#         ;
#
#
#
#
#             var marker_8f10533a77e4bb99b200e34a83877eb3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_66a378ba78c8dfe2a136130f01e54378);
#
#
#         var popup_b1c8de15f7e925d311934895f3cf2626 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89ac4098017fa5674194a343ca765356 = $(`&lt;div id=&quot;html_89ac4098017fa5674194a343ca765356&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b1c8de15f7e925d311934895f3cf2626.setContent(html_89ac4098017fa5674194a343ca765356);
#
#
#
#         marker_8f10533a77e4bb99b200e34a83877eb3.bindPopup(popup_b1c8de15f7e925d311934895f3cf2626)
#         ;
#
#
#
#
#             var marker_2a63e08d806e6c6fd057da17356ebd61 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_66a378ba78c8dfe2a136130f01e54378);
#
#
#         var popup_28dfdb4fc4bb43aebe52de892e5e6183 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f01bfb1ddec247f3d8229aa2e13e0a0c = $(`&lt;div id=&quot;html_f01bfb1ddec247f3d8229aa2e13e0a0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_28dfdb4fc4bb43aebe52de892e5e6183.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38e2cb0fb3fc0d54eb0abc9a5597fe2e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38e2cb0fb3fc0d54eb0abc9a5597fe2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38e2cb0fb3fc0d54eb0abc9a5597fe2e = L.map(
#                 &quot;map_38e2cb0fb3fc0d54eb0abc9a5597fe2e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e99b6fd1d1368906228f9b2ede2bdf05 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e99b6fd1d1368906228f9b2ede2bdf05.addTo(map_38e2cb0fb3fc0d54eb0abc9a5597fe2e);
#
#
#             var feature_group_a30da367e9323f24575b1f5da0754f8b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b1191c0d73dd94ac2d76d006e2ca6913 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a30da367e9323f24575b1f5da0754f8b);
#
#
#         var popup_1c65200467d4b002425c4c59896efb36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40f9a8814466612df7682cfdcb6beaa8 = $(`&lt;div id=&quot;html_40f9a8814466612df7682cfdcb6beaa8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1c65200467d4b002425c4c59896efb36.setContent(html_40f9a8814466612df7682cfdcb6beaa8);
#
#
#
#         marker_b1191c0d73dd94ac2d76d006e2ca6913.bindPopup(popup_1c65200467d4b002425c4c59896efb36)
#         ;
#
#
#
#
#             var marker_03677c7b9d51b5b7d9b9b4a8c63c9e5d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a30da367e9323f24575b1f5da0754f8b);
#
#
#         var popup_a69a35c455d07a74d226769a5164c962 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ab7505cdba210a4ec1dfacf850158de = $(`&lt;div id=&quot;html_0ab7505cdba210a4ec1dfacf850158de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a69a35c455d07a74d226769a5164c962.setContent(html_0ab7505cdba210a4ec1dfacf850158de);
#
#
#
#         marker_03677c7b9d51b5b7d9b9b4a8c63c9e5d.bindPopup(popup_a69a35c455d07a74d226769a5164c962)
#         ;
#
#
#
#
#             var marker_1535c1d3b732ba7c59296672d95a029b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a30da367e9323f24575b1f5da0754f8b);
#
#
#         var popup_82d49efdbe856db9d7275cfcec013655 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1404e6d4ca2c753698dd0b31f02ec55 = $(`&lt;div id=&quot;html_f1404e6d4ca2c753698dd0b31f02ec55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_82d49efdbe856db9d7275cfcec013655.setContent(html_f1404e6d4ca2c753698dd0b31f02ec55);
#
#
#
#         marker_1535c1d3b732ba7c59296672d95a029b.bindPopup(popup_82d49efdbe856db9d7275cfcec013655)
#         ;
#
#
#
#
#             var marker_e67d400c72169c8a257ea9885b2ce35b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a30da367e9323f24575b1f5da0754f8b);
#
#
#         var popup_eff293a8a74f5244793945edb0af9139 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fbc54b986e747697f9f43a76af25962 = $(`&lt;div id=&quot;html_4fbc54b986e747697f9f43a76af25962&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_eff293a8a74f5244793945edb0af9139.setContent(html_4fbc54b986e747697f9f43a76af25962);
#
#
#
#         marker_e67d400c72169c8a257ea9885b2ce35b.bindPopup(popup_eff293a8a74f5244793945edb0af9139)
#         ;
#
#
#
#
#             var marker_25ef7b97745eff798ce85fa66c2fd878 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a30da367e9323f24575b1f5da0754f8b);
#
#
#         var popup_ebf76cf6f9ed582e729805660f53651a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c0f0922ec010cd786afe6395e2f7db3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c0f0922ec010cd786afe6395e2f7db3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c0f0922ec010cd786afe6395e2f7db3 = L.map(
#                 &quot;map_0c0f0922ec010cd786afe6395e2f7db3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13dc67e5c3c6164dcbf7f8ea9ad9f561 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_13dc67e5c3c6164dcbf7f8ea9ad9f561.addTo(map_0c0f0922ec010cd786afe6395e2f7db3);
#
#
#             var feature_group_92c8bee68708ef1da22eb1b99fa8d3ba = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_92c8bee68708ef1da22eb1b99fa8d3ba.addTo(map_0c0f0922ec010cd786afe6395e2f7db3);
#
#
#             var feature_group_sub_group_b76c2684555d5ea2e6784e7b11bb24f3 = L.featureGroup.subGroup(
#                 feature_group_92c8bee68708ef1da22eb1b99fa8d3ba
#             );
#
#
#             var marker_cd3eeed0dac31bde8433da2af0360cb5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b76c2684555d5ea2e6784e7b11bb24f3);
#
#
#         var popup_acae7b3595c0dae48ab0a35897fd2c92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e95eebbe62f0ddfa3439453befe66909 = $(`&lt;div id=&quot;html_e95eebbe62f0ddfa3439453befe66909&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_acae7b3595c0dae48ab0a35897fd2c92.setContent(html_e95eebbe62f0ddfa3439453befe66909);
#
#
#
#         marker_cd3eeed0dac31bde8433da2af0360cb5.bindPopup(popup_acae7b3595c0dae48ab0a35897fd2c92)
#         ;
#
#
#
#
#             var marker_2e9f6ffefd204a005cdd09333f527553 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b76c2684555d5ea2e6784e7b11bb24f3);
#
#
#         var popup_f3d6adf3b294d35b8ed774a7034438da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97e9eceef6046c1ffb7841c49d3bafe9 = $(`&lt;div id=&quot;html_97e9eceef6046c1ffb7841c49d3bafe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f3d6adf3b294d35b8ed774a7034438da.setContent(html_97e9eceef6046c1ffb7841c49d3bafe9);
#
#
#
#         marker_2e9f6ffefd204a005cdd09333f527553.bindPopup(popup_f3d6adf3b294d35b8ed774a7034438da)
#         ;
#
#
#
#
#             var marker_e6007d4b938d80b97b2994de49915c50 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b76c2684555d5ea2e6784e7b11bb24f3);
#
#
#         var popup_51a69678731ac5901b2a97bcc7e3d37d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7370e81dbb76037957a608c0ee96df98 = $(`&lt;div id=&quot;html_7370e81dbb76037957a608c0ee96df98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_51a69678731ac5901b2a97bcc7e3d37d.setContent(html_7370e81dbb76037957a608c0ee96df98);
#
#
#
#         marker_e6007d4b938d80b97b2994de49915c50.bindPopup(popup_51a69678731ac5901b2a97bcc7e3d37d)
#         ;
#
#
#
#
#             var marker_21d5bafbb6cd0a617f6e5716fe2710f9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b76c2684555d5ea2e6784e7b11bb24f3);
#
#
#         var popup_adbe9b39fae3219f1da1bdd84589ad20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccfe3c87bbbf026e84110c139eaacff4 = $(`&lt;div id=&quot;html_ccfe3c87bbbf026e84110c139eaacff4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_adbe9b39fae3219f1da1bdd84589ad20.setContent(html_ccfe3c87bbbf026e84110c139eaacff4);
#
#
#
#         marker_
