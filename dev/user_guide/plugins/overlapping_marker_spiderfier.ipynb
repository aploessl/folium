# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f5d06bd90d8e1511863082fe72be62c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f5d06bd90d8e1511863082fe72be62c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f5d06bd90d8e1511863082fe72be62c = L.map(
#                 &quot;map_4f5d06bd90d8e1511863082fe72be62c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3399a1bb67543d089b3c7415255c1c71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3399a1bb67543d089b3c7415255c1c71.addTo(map_4f5d06bd90d8e1511863082fe72be62c);
#
#
#             var marker_48c7ab96dcf13a38e97791ed3da470a3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4f5d06bd90d8e1511863082fe72be62c);
#
#
#         var popup_9515e764828073e0618dac41f8657bf4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7a2c4cf415045739a09bd9d4c94541f = $(`&lt;div id=&quot;html_e7a2c4cf415045739a09bd9d4c94541f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9515e764828073e0618dac41f8657bf4.setContent(html_e7a2c4cf415045739a09bd9d4c94541f);
#
#
#
#         marker_48c7ab96dcf13a38e97791ed3da470a3.bindPopup(popup_9515e764828073e0618dac41f8657bf4)
#         ;
#
#
#
#
#             var marker_8f910356266621bb7b3d4f35a412f49a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4f5d06bd90d8e1511863082fe72be62c);
#
#
#         var popup_1cae5ddcc04ef4d194208666c8593e79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56858727d17128e034a6343e896cfb3f = $(`&lt;div id=&quot;html_56858727d17128e034a6343e896cfb3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1cae5ddcc04ef4d194208666c8593e79.setContent(html_56858727d17128e034a6343e896cfb3f);
#
#
#
#         marker_8f910356266621bb7b3d4f35a412f49a.bindPopup(popup_1cae5ddcc04ef4d194208666c8593e79)
#         ;
#
#
#
#
#             var marker_42256d7c7536b524e8113ecd17411c23 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4f5d06bd90d8e1511863082fe72be62c);
#
#
#         var popup_7468d28fed9475baede391502c49219e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a70da64c3a920e5830326af7b2f4c49f = $(`&lt;div id=&quot;html_a70da64c3a920e5830326af7b2f4c49f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7468d28fed9475baede391502c49219e.setContent(html_a70da64c3a920e5830326af7b2f4c49f);
#
#
#
#         marker_42256d7c7536b524e8113ecd17411c23.bindPopup(popup_7468d28fed9475baede391502c49219e)
#         ;
#
#
#
#
#             var marker_f51d1d9ba9d438b289166a9964737612 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4f5d06bd90d8e1511863082fe72be62c);
#
#
#         var popup_385b3bbc06843407c090aebc0f8da90f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df78f866be4bebd758b188219576af7f = $(`&lt;div id=&quot;html_df78f866be4bebd758b188219576af7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_385b3bbc06843407c090aebc0f8da90f.setContent(html_df78f866be4bebd758b188219576af7f);
#
#
#
#         marker_f51d1d9ba9d438b289166a9964737612.bindPopup(popup_385b3bbc06843407c090aebc0f8da90f)
#         ;
#
#
#
#
#             var marker_7b9e7236cd9af1b4c1306d7a25314de3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4f5d06bd90d8e1511863082fe72be62c);
#
#
#         var popup_b4db0b71d9e10611d1a040e607d9201c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fabc832ecac5583917f436cda6954e2f = $(`&lt;div id=&quot;html_fabc832ecac5583917f436cda6954e2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b4db0b71d9e10611d1a040e607d9201c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_879c7a57651cffa60f019d90aa6e5220 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_879c7a57651cffa60f019d90aa6e5220&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_879c7a57651cffa60f019d90aa6e5220 = L.map(
#                 &quot;map_879c7a57651cffa60f019d90aa6e5220&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_edef1d317e8d6375a0334222e9a46fb6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_edef1d317e8d6375a0334222e9a46fb6.addTo(map_879c7a57651cffa60f019d90aa6e5220);
#
#
#             var feature_group_5897865f129e41d95716a2d076551ade = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3a48472806272b83db94e4d85cdd69a3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5897865f129e41d95716a2d076551ade);
#
#
#         var popup_b59d25ba056306a02e0317ba5b4a5372 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c82ca6df085a4bc3567e62c3e1db5fcc = $(`&lt;div id=&quot;html_c82ca6df085a4bc3567e62c3e1db5fcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b59d25ba056306a02e0317ba5b4a5372.setContent(html_c82ca6df085a4bc3567e62c3e1db5fcc);
#
#
#
#         marker_3a48472806272b83db94e4d85cdd69a3.bindPopup(popup_b59d25ba056306a02e0317ba5b4a5372)
#         ;
#
#
#
#
#             var marker_f3db012ecfaa27a44983ca97f9e28d6f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5897865f129e41d95716a2d076551ade);
#
#
#         var popup_1a9c5dca7dcda6e6676797f5e78fe1ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5b765f896e21aaa13bf8def523ade92 = $(`&lt;div id=&quot;html_b5b765f896e21aaa13bf8def523ade92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1a9c5dca7dcda6e6676797f5e78fe1ac.setContent(html_b5b765f896e21aaa13bf8def523ade92);
#
#
#
#         marker_f3db012ecfaa27a44983ca97f9e28d6f.bindPopup(popup_1a9c5dca7dcda6e6676797f5e78fe1ac)
#         ;
#
#
#
#
#             var marker_2e1148e18090ed0ffde7d95fbe670bdd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5897865f129e41d95716a2d076551ade);
#
#
#         var popup_84fe0d3b571f231d1c4e85aeac8a236c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_492e1dbd13beb564868aa696dd7bc45d = $(`&lt;div id=&quot;html_492e1dbd13beb564868aa696dd7bc45d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_84fe0d3b571f231d1c4e85aeac8a236c.setContent(html_492e1dbd13beb564868aa696dd7bc45d);
#
#
#
#         marker_2e1148e18090ed0ffde7d95fbe670bdd.bindPopup(popup_84fe0d3b571f231d1c4e85aeac8a236c)
#         ;
#
#
#
#
#             var marker_4f8c8582ced2454cc56e74f0c17a07b1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5897865f129e41d95716a2d076551ade);
#
#
#         var popup_db4329510f25627814f933eb87a9d97d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b40d2b1432dbd13d3e25a1001c27205 = $(`&lt;div id=&quot;html_1b40d2b1432dbd13d3e25a1001c27205&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_db4329510f25627814f933eb87a9d97d.setContent(html_1b40d2b1432dbd13d3e25a1001c27205);
#
#
#
#         marker_4f8c8582ced2454cc56e74f0c17a07b1.bindPopup(popup_db4329510f25627814f933eb87a9d97d)
#         ;
#
#
#
#
#             var marker_ea96ee41ce641d3cf29a2788426bff8d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5897865f129e41d95716a2d076551ade);
#
#
#         var popup_7b7761a5b9673ecf88efbe6e8417232e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c37392eda6f2ff8dc859ec3f4cc065c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c37392eda6f2ff8dc859ec3f4cc065c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c37392eda6f2ff8dc859ec3f4cc065c3 = L.map(
#                 &quot;map_c37392eda6f2ff8dc859ec3f4cc065c3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10c122f75104c910f5cb0c821e2cf96f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10c122f75104c910f5cb0c821e2cf96f.addTo(map_c37392eda6f2ff8dc859ec3f4cc065c3);
#
#
#             var feature_group_46f64c2e370dcd512cc5c76b0afa96f2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_46f64c2e370dcd512cc5c76b0afa96f2.addTo(map_c37392eda6f2ff8dc859ec3f4cc065c3);
#
#
#             var feature_group_sub_group_98dc72661578ca0f28b6a03e6f541819 = L.featureGroup.subGroup(
#                 feature_group_46f64c2e370dcd512cc5c76b0afa96f2
#             );
#
#
#             var marker_70f87be1c233d6c2e98f9f49dac36637 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_98dc72661578ca0f28b6a03e6f541819);
#
#
#         var popup_de3f44b2fc08cce813c233ebbcb32524 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64f3b5e2fb7605b143c8bf6f0e99d3ba = $(`&lt;div id=&quot;html_64f3b5e2fb7605b143c8bf6f0e99d3ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_de3f44b2fc08cce813c233ebbcb32524.setContent(html_64f3b5e2fb7605b143c8bf6f0e99d3ba);
#
#
#
#         marker_70f87be1c233d6c2e98f9f49dac36637.bindPopup(popup_de3f44b2fc08cce813c233ebbcb32524)
#         ;
#
#
#
#
#             var marker_1bbea387e48f0b8940c17af91e88c541 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_98dc72661578ca0f28b6a03e6f541819);
#
#
#         var popup_754bf38a8bb789f68be0d8883a6fe9b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c20c32bdd6c1dcf31ab164e4b5b8da8f = $(`&lt;div id=&quot;html_c20c32bdd6c1dcf31ab164e4b5b8da8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_754bf38a8bb789f68be0d8883a6fe9b8.setContent(html_c20c32bdd6c1dcf31ab164e4b5b8da8f);
#
#
#
#         marker_1bbea387e48f0b8940c17af91e88c541.bindPopup(popup_754bf38a8bb789f68be0d8883a6fe9b8)
#         ;
#
#
#
#
#             var marker_7564b42207fc152a961a68ff3431da81 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_98dc72661578ca0f28b6a03e6f541819);
#
#
#         var popup_25b87b874730187c8563df65f38e8065 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4b95ba2feababffb2018f49111b3c2b = $(`&lt;div id=&quot;html_d4b95ba2feababffb2018f49111b3c2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_25b87b874730187c8563df65f38e8065.setContent(html_d4b95ba2feababffb2018f49111b3c2b);
#
#
#
#         marker_7564b42207fc152a961a68ff3431da81.bindPopup(popup_25b87b874730187c8563df65f38e8065)
#         ;
#
#
#
#
#             var marker_8b1a1e4bca9e321d0aadcf44f939a34a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_98dc72661578ca0f28b6a03e6f541819);
#
#
#         var popup_f90e439585beb56905dfc955b231d260 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fce84034412c6784cdc0da93e7a592a2 = $(`&lt;div id=&quot;html_fce84034412c6784cdc0da93e7a592a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f90e439585beb56905dfc955b231d260.setContent(html_fce84034412c6784cdc0da93e7a592a2);
#
#
#
#         marker_
