# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e99926b5e6011f117bc78757070e75a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e99926b5e6011f117bc78757070e75a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e99926b5e6011f117bc78757070e75a3 = L.map(
#                 &quot;map_e99926b5e6011f117bc78757070e75a3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e89fb7d85a06a7b2519481d73819a60a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e89fb7d85a06a7b2519481d73819a60a.addTo(map_e99926b5e6011f117bc78757070e75a3);
#
#
#             var marker_8221c8371425d79abc4ef90c28ff5a76 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e99926b5e6011f117bc78757070e75a3);
#
#
#         var popup_f778dea2d83de60268cf7177f5492a27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6b475945970c3d713ee9f064d3c0c90 = $(`&lt;div id=&quot;html_c6b475945970c3d713ee9f064d3c0c90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f778dea2d83de60268cf7177f5492a27.setContent(html_c6b475945970c3d713ee9f064d3c0c90);
#
#
#
#         marker_8221c8371425d79abc4ef90c28ff5a76.bindPopup(popup_f778dea2d83de60268cf7177f5492a27)
#         ;
#
#
#
#
#             var marker_1515f0466c7bf3afa8538919f53ee034 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e99926b5e6011f117bc78757070e75a3);
#
#
#         var popup_8d8c11972f4f8829eaad778ab81d4c1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fa443325d77e8d15503be8b50a766be = $(`&lt;div id=&quot;html_2fa443325d77e8d15503be8b50a766be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8d8c11972f4f8829eaad778ab81d4c1c.setContent(html_2fa443325d77e8d15503be8b50a766be);
#
#
#
#         marker_1515f0466c7bf3afa8538919f53ee034.bindPopup(popup_8d8c11972f4f8829eaad778ab81d4c1c)
#         ;
#
#
#
#
#             var marker_ffe5a356745097e7474aed6900c00527 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e99926b5e6011f117bc78757070e75a3);
#
#
#         var popup_9dd5314534246419293296ba4991c11f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7b4209178f994c3c3e227e467a78933 = $(`&lt;div id=&quot;html_f7b4209178f994c3c3e227e467a78933&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9dd5314534246419293296ba4991c11f.setContent(html_f7b4209178f994c3c3e227e467a78933);
#
#
#
#         marker_ffe5a356745097e7474aed6900c00527.bindPopup(popup_9dd5314534246419293296ba4991c11f)
#         ;
#
#
#
#
#             var marker_323506a89c0983829ff4b6de6ca3ca67 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e99926b5e6011f117bc78757070e75a3);
#
#
#         var popup_94db90615b72393aed06a640b1c101c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1f495bb9adf43a410f8d61093c2943a = $(`&lt;div id=&quot;html_f1f495bb9adf43a410f8d61093c2943a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_94db90615b72393aed06a640b1c101c1.setContent(html_f1f495bb9adf43a410f8d61093c2943a);
#
#
#
#         marker_323506a89c0983829ff4b6de6ca3ca67.bindPopup(popup_94db90615b72393aed06a640b1c101c1)
#         ;
#
#
#
#
#             var marker_90a2676768e25f1af1b36c4272955ed3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e99926b5e6011f117bc78757070e75a3);
#
#
#         var popup_3d65ed8aac7bb2d467709ba51596f6d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f85d8e4c2aa9167793308720bc416aec = $(`&lt;div id=&quot;html_f85d8e4c2aa9167793308720bc416aec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3d65ed8aac7bb2d467709ba51596f6d6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3967013eead2b78997bdf398ac787ac4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3967013eead2b78997bdf398ac787ac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3967013eead2b78997bdf398ac787ac4 = L.map(
#                 &quot;map_3967013eead2b78997bdf398ac787ac4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb764a81535a4a06a849cf13a220dbaf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fb764a81535a4a06a849cf13a220dbaf.addTo(map_3967013eead2b78997bdf398ac787ac4);
#
#
#             var feature_group_de391449541121bc4487e14d675734fc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_65c6a8f131ef7b8d6e49ce78581d4633 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_de391449541121bc4487e14d675734fc);
#
#
#         var popup_e4023fef8291b7f53a4e70ade8820469 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f1c111acd2083ffb73ff5bc4d70b30f = $(`&lt;div id=&quot;html_9f1c111acd2083ffb73ff5bc4d70b30f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e4023fef8291b7f53a4e70ade8820469.setContent(html_9f1c111acd2083ffb73ff5bc4d70b30f);
#
#
#
#         marker_65c6a8f131ef7b8d6e49ce78581d4633.bindPopup(popup_e4023fef8291b7f53a4e70ade8820469)
#         ;
#
#
#
#
#             var marker_8daccf95181560e7c4a07dd872cbd7ba = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_de391449541121bc4487e14d675734fc);
#
#
#         var popup_5692867384124a118844f109e3bcb5aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0e441c7ef37570a2e3b06c2b202efd6 = $(`&lt;div id=&quot;html_d0e441c7ef37570a2e3b06c2b202efd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5692867384124a118844f109e3bcb5aa.setContent(html_d0e441c7ef37570a2e3b06c2b202efd6);
#
#
#
#         marker_8daccf95181560e7c4a07dd872cbd7ba.bindPopup(popup_5692867384124a118844f109e3bcb5aa)
#         ;
#
#
#
#
#             var marker_86008bd739eed1a91a488b63bde14b60 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_de391449541121bc4487e14d675734fc);
#
#
#         var popup_dfcd5f64973af6cfe9134d5f6c6f1a3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71947bf82bf39daed50b62b3df0f1ad1 = $(`&lt;div id=&quot;html_71947bf82bf39daed50b62b3df0f1ad1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_dfcd5f64973af6cfe9134d5f6c6f1a3a.setContent(html_71947bf82bf39daed50b62b3df0f1ad1);
#
#
#
#         marker_86008bd739eed1a91a488b63bde14b60.bindPopup(popup_dfcd5f64973af6cfe9134d5f6c6f1a3a)
#         ;
#
#
#
#
#             var marker_b01d7a71cdbf19cb66025eeeffa08444 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_de391449541121bc4487e14d675734fc);
#
#
#         var popup_8d665bdd41961ea0958cd567e5f97b98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05a12882caed81b09be78074da4e4a2c = $(`&lt;div id=&quot;html_05a12882caed81b09be78074da4e4a2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8d665bdd41961ea0958cd567e5f97b98.setContent(html_05a12882caed81b09be78074da4e4a2c);
#
#
#
#         marker_b01d7a71cdbf19cb66025eeeffa08444.bindPopup(popup_8d665bdd41961ea0958cd567e5f97b98)
#         ;
#
#
#
#
#             var marker_ef20234f47e024c4293f97f39ef0f2c2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_de391449541121bc4487e14d675734fc);
#
#
#         var popup_5e0521c83ee6091ab06a9f6b1acdffc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5abc0735ee3f61d7adbb40eb57f3b240 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5abc0735ee3f61d7adbb40eb57f3b240&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5abc0735ee3f61d7adbb40eb57f3b240 = L.map(
#                 &quot;map_5abc0735ee3f61d7adbb40eb57f3b240&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42f7c208f2ec4ae0406a77eb771f5e8e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_42f7c208f2ec4ae0406a77eb771f5e8e.addTo(map_5abc0735ee3f61d7adbb40eb57f3b240);
#
#
#             var feature_group_144bb665d8aee65328acc52568be01d2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_144bb665d8aee65328acc52568be01d2.addTo(map_5abc0735ee3f61d7adbb40eb57f3b240);
#
#
#             var feature_group_sub_group_d5771f1c65b204876768b40d42773be9 = L.featureGroup.subGroup(
#                 feature_group_144bb665d8aee65328acc52568be01d2
#             );
#
#
#             var marker_44d661dd433a651451960738b1e69254 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d5771f1c65b204876768b40d42773be9);
#
#
#         var popup_730dba10a45f9abee472c53530c16c87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_639dd84ae3547e0edd3021e71e29b427 = $(`&lt;div id=&quot;html_639dd84ae3547e0edd3021e71e29b427&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_730dba10a45f9abee472c53530c16c87.setContent(html_639dd84ae3547e0edd3021e71e29b427);
#
#
#
#         marker_44d661dd433a651451960738b1e69254.bindPopup(popup_730dba10a45f9abee472c53530c16c87)
#         ;
#
#
#
#
#             var marker_cb93f8699a774bbc29875fb03f18d115 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d5771f1c65b204876768b40d42773be9);
#
#
#         var popup_330d8e82a0f63bd264202af84335a367 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63166dec57c38772624949f728c9cd27 = $(`&lt;div id=&quot;html_63166dec57c38772624949f728c9cd27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_330d8e82a0f63bd264202af84335a367.setContent(html_63166dec57c38772624949f728c9cd27);
#
#
#
#         marker_cb93f8699a774bbc29875fb03f18d115.bindPopup(popup_330d8e82a0f63bd264202af84335a367)
#         ;
#
#
#
#
#             var marker_4d6a5fe4770a4061c579a05f11c8ab39 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d5771f1c65b204876768b40d42773be9);
#
#
#         var popup_35794d86fa1d960c9717de6870b23f27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea343bf2fcbbc9938d52c2b7557b5acf = $(`&lt;div id=&quot;html_ea343bf2fcbbc9938d52c2b7557b5acf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_35794d86fa1d960c9717de6870b23f27.setContent(html_ea343bf2fcbbc9938d52c2b7557b5acf);
#
#
#
#         marker_4d6a5fe4770a4061c579a05f11c8ab39.bindPopup(popup_35794d86fa1d960c9717de6870b23f27)
#         ;
#
#
#
#
#             var marker_89e0e6ac9775126d5bc4a50d0832007c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d5771f1c65b204876768b40d42773be9);
#
#
#         var popup_7d20f266c5f230e13cc56d7c0735c670 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_207b3818927b482bf5f4d3fb9465b153 = $(`&lt;div id=&quot;html_207b3818927b482bf5f4d3fb9465b153&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7d20f266c5f230e13cc56d7c0735c670.setContent(html_207b3818927b482bf5f4d3fb9465b153);
#
#
#
#         marker_
