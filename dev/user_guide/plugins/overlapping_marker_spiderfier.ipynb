# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d98c5be9c8f2a5f2133c54fdce8797d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d98c5be9c8f2a5f2133c54fdce8797d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d98c5be9c8f2a5f2133c54fdce8797d = L.map(
#                 &quot;map_2d98c5be9c8f2a5f2133c54fdce8797d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1fca9a0705ccbee38c3ac84be3c66fad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1fca9a0705ccbee38c3ac84be3c66fad.addTo(map_2d98c5be9c8f2a5f2133c54fdce8797d);
#
#
#             var marker_fa1c8e660f477519cc9f16bfe39787a2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2d98c5be9c8f2a5f2133c54fdce8797d);
#
#
#         var popup_ed6c421bfb3660617c1562d273db2fce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49278e5a4bc29e965573fe6c934a5e5c = $(`&lt;div id=&quot;html_49278e5a4bc29e965573fe6c934a5e5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ed6c421bfb3660617c1562d273db2fce.setContent(html_49278e5a4bc29e965573fe6c934a5e5c);
#
#
#
#         marker_fa1c8e660f477519cc9f16bfe39787a2.bindPopup(popup_ed6c421bfb3660617c1562d273db2fce)
#         ;
#
#
#
#
#             var marker_27fee900bd2b022b62411dd0cd726d1a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2d98c5be9c8f2a5f2133c54fdce8797d);
#
#
#         var popup_d449d34ccfcd42e1be38cad869ddce1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c1bdf4d6a596fbcffbf2d1fe4cf136c = $(`&lt;div id=&quot;html_4c1bdf4d6a596fbcffbf2d1fe4cf136c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d449d34ccfcd42e1be38cad869ddce1d.setContent(html_4c1bdf4d6a596fbcffbf2d1fe4cf136c);
#
#
#
#         marker_27fee900bd2b022b62411dd0cd726d1a.bindPopup(popup_d449d34ccfcd42e1be38cad869ddce1d)
#         ;
#
#
#
#
#             var marker_8508dda5a22ea6519fc011bce2a956a8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2d98c5be9c8f2a5f2133c54fdce8797d);
#
#
#         var popup_b393937759993d324edb1e78c02202cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_816a8c8800ff3d170e1672e9a067a5d7 = $(`&lt;div id=&quot;html_816a8c8800ff3d170e1672e9a067a5d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b393937759993d324edb1e78c02202cc.setContent(html_816a8c8800ff3d170e1672e9a067a5d7);
#
#
#
#         marker_8508dda5a22ea6519fc011bce2a956a8.bindPopup(popup_b393937759993d324edb1e78c02202cc)
#         ;
#
#
#
#
#             var marker_2b8465d97a1fa45d0a622e6b8b0cd6f1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2d98c5be9c8f2a5f2133c54fdce8797d);
#
#
#         var popup_dc50f6eaa01550cef121dbc9da4c03d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_355ef9ba2b76fc2bdbec5441df71e80b = $(`&lt;div id=&quot;html_355ef9ba2b76fc2bdbec5441df71e80b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_dc50f6eaa01550cef121dbc9da4c03d4.setContent(html_355ef9ba2b76fc2bdbec5441df71e80b);
#
#
#
#         marker_2b8465d97a1fa45d0a622e6b8b0cd6f1.bindPopup(popup_dc50f6eaa01550cef121dbc9da4c03d4)
#         ;
#
#
#
#
#             var marker_dba63fb2c2e6edd5bc2795a11c485ee8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2d98c5be9c8f2a5f2133c54fdce8797d);
#
#
#         var popup_a53aacc94a26b124ba06e46bc2d2c529 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6134e48e583e0d05d9c22c66120a2ed8 = $(`&lt;div id=&quot;html_6134e48e583e0d05d9c22c66120a2ed8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a53aacc94a26b124ba06e46bc2d2c529.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09f5146f65b963f230be04ac104e8fba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09f5146f65b963f230be04ac104e8fba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09f5146f65b963f230be04ac104e8fba = L.map(
#                 &quot;map_09f5146f65b963f230be04ac104e8fba&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f33f3517bbdd0198659e3ec60e51e172 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f33f3517bbdd0198659e3ec60e51e172.addTo(map_09f5146f65b963f230be04ac104e8fba);
#
#
#             var feature_group_eb8d986f04387d02170499294ec082ef = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_40cc9a1fecbb2ee12ad8fdff961fff79 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_eb8d986f04387d02170499294ec082ef);
#
#
#         var popup_02a9eb2b1684927e436b77d4270bd955 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b95501ebff1ee6d50af8c937727477f1 = $(`&lt;div id=&quot;html_b95501ebff1ee6d50af8c937727477f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_02a9eb2b1684927e436b77d4270bd955.setContent(html_b95501ebff1ee6d50af8c937727477f1);
#
#
#
#         marker_40cc9a1fecbb2ee12ad8fdff961fff79.bindPopup(popup_02a9eb2b1684927e436b77d4270bd955)
#         ;
#
#
#
#
#             var marker_0e7cde52a02c770e166370d6df712444 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_eb8d986f04387d02170499294ec082ef);
#
#
#         var popup_7ac547fc1e4171bcaa137b863d7957d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49b3fee4e4423d6cbff5cdf0dd894623 = $(`&lt;div id=&quot;html_49b3fee4e4423d6cbff5cdf0dd894623&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7ac547fc1e4171bcaa137b863d7957d4.setContent(html_49b3fee4e4423d6cbff5cdf0dd894623);
#
#
#
#         marker_0e7cde52a02c770e166370d6df712444.bindPopup(popup_7ac547fc1e4171bcaa137b863d7957d4)
#         ;
#
#
#
#
#             var marker_cc88c8f2a5a6785221b4e6376842dc3c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_eb8d986f04387d02170499294ec082ef);
#
#
#         var popup_e89058a580c6a55fbcd4e728bff084df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_965e0ba26d265c248804475b210d86f2 = $(`&lt;div id=&quot;html_965e0ba26d265c248804475b210d86f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e89058a580c6a55fbcd4e728bff084df.setContent(html_965e0ba26d265c248804475b210d86f2);
#
#
#
#         marker_cc88c8f2a5a6785221b4e6376842dc3c.bindPopup(popup_e89058a580c6a55fbcd4e728bff084df)
#         ;
#
#
#
#
#             var marker_e9d7cc76ec0eb6d699df8ceaeed3fb57 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_eb8d986f04387d02170499294ec082ef);
#
#
#         var popup_ec1eef8cb4cb7931254dd79c255628ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70c7da8e93f1e00dbf3b1aa4fdaa9f01 = $(`&lt;div id=&quot;html_70c7da8e93f1e00dbf3b1aa4fdaa9f01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ec1eef8cb4cb7931254dd79c255628ef.setContent(html_70c7da8e93f1e00dbf3b1aa4fdaa9f01);
#
#
#
#         marker_e9d7cc76ec0eb6d699df8ceaeed3fb57.bindPopup(popup_ec1eef8cb4cb7931254dd79c255628ef)
#         ;
#
#
#
#
#             var marker_5a1c35d885f3b2e3788aa109e701794c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_eb8d986f04387d02170499294ec082ef);
#
#
#         var popup_f32553d1fde2aa146d9ccc441c6a74d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_161b7e7cfbbc7814bab9cb3841c0a9a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_161b7e7cfbbc7814bab9cb3841c0a9a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_161b7e7cfbbc7814bab9cb3841c0a9a1 = L.map(
#                 &quot;map_161b7e7cfbbc7814bab9cb3841c0a9a1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d70068d3eb77703d01b45589cd829a1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2d70068d3eb77703d01b45589cd829a1.addTo(map_161b7e7cfbbc7814bab9cb3841c0a9a1);
#
#
#             var feature_group_5aec252f9925ef1aa5542ade88ed2652 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5aec252f9925ef1aa5542ade88ed2652.addTo(map_161b7e7cfbbc7814bab9cb3841c0a9a1);
#
#
#             var feature_group_sub_group_b418bcab490f54dbdc962623a4e0eaac = L.featureGroup.subGroup(
#                 feature_group_5aec252f9925ef1aa5542ade88ed2652
#             );
#
#
#             var marker_a2e69b5c88435ac7138e06212e14f42c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b418bcab490f54dbdc962623a4e0eaac);
#
#
#         var popup_912eb48fab244064ae31d34e981b9d78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be0a726bf3a8577c1c26a88306795b71 = $(`&lt;div id=&quot;html_be0a726bf3a8577c1c26a88306795b71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_912eb48fab244064ae31d34e981b9d78.setContent(html_be0a726bf3a8577c1c26a88306795b71);
#
#
#
#         marker_a2e69b5c88435ac7138e06212e14f42c.bindPopup(popup_912eb48fab244064ae31d34e981b9d78)
#         ;
#
#
#
#
#             var marker_e012b25690713c2d0ddb50c970701e8e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b418bcab490f54dbdc962623a4e0eaac);
#
#
#         var popup_02acb4b240d167e99fdf53ac20534899 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b23fc4a92ad9da0a4485adda25ae78aa = $(`&lt;div id=&quot;html_b23fc4a92ad9da0a4485adda25ae78aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_02acb4b240d167e99fdf53ac20534899.setContent(html_b23fc4a92ad9da0a4485adda25ae78aa);
#
#
#
#         marker_e012b25690713c2d0ddb50c970701e8e.bindPopup(popup_02acb4b240d167e99fdf53ac20534899)
#         ;
#
#
#
#
#             var marker_3f304a9ee4686863cda92a2935034eec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b418bcab490f54dbdc962623a4e0eaac);
#
#
#         var popup_b2eedce86e0d9146c41ca211da5b0346 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7fe401822e9127d9cfe9ac943ebd061 = $(`&lt;div id=&quot;html_b7fe401822e9127d9cfe9ac943ebd061&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b2eedce86e0d9146c41ca211da5b0346.setContent(html_b7fe401822e9127d9cfe9ac943ebd061);
#
#
#
#         marker_3f304a9ee4686863cda92a2935034eec.bindPopup(popup_b2eedce86e0d9146c41ca211da5b0346)
#         ;
#
#
#
#
#             var marker_d7c2c9dceaa918fb96018c7e419f3c26 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b418bcab490f54dbdc962623a4e0eaac);
#
#
#         var popup_7e111498e6d55f2a6cf45d55bc52595a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a2288d33e5d228b147f05220b2fd488 = $(`&lt;div id=&quot;html_5a2288d33e5d228b147f05220b2fd488&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7e111498e6d55f2a6cf45d55bc52595a.setContent(html_5a2288d33e5d228b147f05220b2fd488);
#
#
#
#         marker_
