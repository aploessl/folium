# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ddaf46574357e7073efe4134f62fd907 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ddaf46574357e7073efe4134f62fd907&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ddaf46574357e7073efe4134f62fd907 = L.map(
#                 &quot;map_ddaf46574357e7073efe4134f62fd907&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f25c77bc760f3d9b5643db38314cad15 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f25c77bc760f3d9b5643db38314cad15.addTo(map_ddaf46574357e7073efe4134f62fd907);
#
#
#             var marker_e4064a10269167d22b779a7e55b213fe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ddaf46574357e7073efe4134f62fd907);
#
#
#         var popup_19e46800ce64474162bf18a433a5c626 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4106e4cd03e1bb9929bee04bac467654 = $(`&lt;div id=&quot;html_4106e4cd03e1bb9929bee04bac467654&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_19e46800ce64474162bf18a433a5c626.setContent(html_4106e4cd03e1bb9929bee04bac467654);
#
#
#
#         marker_e4064a10269167d22b779a7e55b213fe.bindPopup(popup_19e46800ce64474162bf18a433a5c626)
#         ;
#
#
#
#
#             var marker_c510e6e2758a9c08936865f59984a532 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ddaf46574357e7073efe4134f62fd907);
#
#
#         var popup_a1d1fbd7f982a3473e3f8713ea4a4b1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_925017dbee0e48f161333d0b385a2121 = $(`&lt;div id=&quot;html_925017dbee0e48f161333d0b385a2121&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a1d1fbd7f982a3473e3f8713ea4a4b1d.setContent(html_925017dbee0e48f161333d0b385a2121);
#
#
#
#         marker_c510e6e2758a9c08936865f59984a532.bindPopup(popup_a1d1fbd7f982a3473e3f8713ea4a4b1d)
#         ;
#
#
#
#
#             var marker_65622978adf146260fde0e0d0af619a5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ddaf46574357e7073efe4134f62fd907);
#
#
#         var popup_4c846ae32c7f94bab3f479a470c3b8a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29f0100b023b6a7f35cdf5ccd907fe12 = $(`&lt;div id=&quot;html_29f0100b023b6a7f35cdf5ccd907fe12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4c846ae32c7f94bab3f479a470c3b8a4.setContent(html_29f0100b023b6a7f35cdf5ccd907fe12);
#
#
#
#         marker_65622978adf146260fde0e0d0af619a5.bindPopup(popup_4c846ae32c7f94bab3f479a470c3b8a4)
#         ;
#
#
#
#
#             var marker_912b035890e0f8991e6434149f1701aa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ddaf46574357e7073efe4134f62fd907);
#
#
#         var popup_55d9e98a2513844c0d86ad8bd1b725a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6170afca080329aaf4eb1dbfe98021b7 = $(`&lt;div id=&quot;html_6170afca080329aaf4eb1dbfe98021b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_55d9e98a2513844c0d86ad8bd1b725a3.setContent(html_6170afca080329aaf4eb1dbfe98021b7);
#
#
#
#         marker_912b035890e0f8991e6434149f1701aa.bindPopup(popup_55d9e98a2513844c0d86ad8bd1b725a3)
#         ;
#
#
#
#
#             var marker_5c52bf55c981684cfa44c2dc544ababc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ddaf46574357e7073efe4134f62fd907);
#
#
#         var popup_e3f2cf6372c10483fe5de435d1aeda5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b49a6ebd95285627226566c2709962b8 = $(`&lt;div id=&quot;html_b49a6ebd95285627226566c2709962b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e3f2cf6372c10483fe5de435d1aeda5a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_812092387f2b5374ce71f6275d518778 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_812092387f2b5374ce71f6275d518778&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_812092387f2b5374ce71f6275d518778 = L.map(
#                 &quot;map_812092387f2b5374ce71f6275d518778&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_119e3e1a7eb4079ec042fe8a349891b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_119e3e1a7eb4079ec042fe8a349891b1.addTo(map_812092387f2b5374ce71f6275d518778);
#
#
#             var feature_group_af22f7389a5dbafabe7e4b1dadb0c9c2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fdf092c41fe02caf10733d0c586bdc5c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_af22f7389a5dbafabe7e4b1dadb0c9c2);
#
#
#         var popup_1179cf559523a7855154c9714cfa5fa3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_389727cfd6d2aab0c2ef38c48a3d30b8 = $(`&lt;div id=&quot;html_389727cfd6d2aab0c2ef38c48a3d30b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1179cf559523a7855154c9714cfa5fa3.setContent(html_389727cfd6d2aab0c2ef38c48a3d30b8);
#
#
#
#         marker_fdf092c41fe02caf10733d0c586bdc5c.bindPopup(popup_1179cf559523a7855154c9714cfa5fa3)
#         ;
#
#
#
#
#             var marker_80f4a8cfeb864e4b8cda9b02485ac895 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_af22f7389a5dbafabe7e4b1dadb0c9c2);
#
#
#         var popup_48d41c282e1507d368190ad7aa096012 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09cfc289c24426ba585148ea2e3e49dc = $(`&lt;div id=&quot;html_09cfc289c24426ba585148ea2e3e49dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_48d41c282e1507d368190ad7aa096012.setContent(html_09cfc289c24426ba585148ea2e3e49dc);
#
#
#
#         marker_80f4a8cfeb864e4b8cda9b02485ac895.bindPopup(popup_48d41c282e1507d368190ad7aa096012)
#         ;
#
#
#
#
#             var marker_26d85aab1f41ebbfff7b1fcb6b124da1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_af22f7389a5dbafabe7e4b1dadb0c9c2);
#
#
#         var popup_1d295511756d9e415b161f212b816988 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ca802d7fb991fc0708cc30bf3e9d7fd = $(`&lt;div id=&quot;html_1ca802d7fb991fc0708cc30bf3e9d7fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1d295511756d9e415b161f212b816988.setContent(html_1ca802d7fb991fc0708cc30bf3e9d7fd);
#
#
#
#         marker_26d85aab1f41ebbfff7b1fcb6b124da1.bindPopup(popup_1d295511756d9e415b161f212b816988)
#         ;
#
#
#
#
#             var marker_c6c2f7898f8f661592597ddc74dc7ee0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_af22f7389a5dbafabe7e4b1dadb0c9c2);
#
#
#         var popup_df08d26e4aa88baa7c8f3607b316da4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8e68e4c99bbaaf9fb5a14a630fbf98d = $(`&lt;div id=&quot;html_a8e68e4c99bbaaf9fb5a14a630fbf98d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_df08d26e4aa88baa7c8f3607b316da4d.setContent(html_a8e68e4c99bbaaf9fb5a14a630fbf98d);
#
#
#
#         marker_c6c2f7898f8f661592597ddc74dc7ee0.bindPopup(popup_df08d26e4aa88baa7c8f3607b316da4d)
#         ;
#
#
#
#
#             var marker_87314971878c1db71b3a5ddfbee140b8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_af22f7389a5dbafabe7e4b1dadb0c9c2);
#
#
#         var popup_205f2eb19a2d421972ec656e541b25c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f478a5b431de6ce7a6c2a92b009ba851 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f478a5b431de6ce7a6c2a92b009ba851&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f478a5b431de6ce7a6c2a92b009ba851 = L.map(
#                 &quot;map_f478a5b431de6ce7a6c2a92b009ba851&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f24f4e1182dd7b1aff66664ecf55004c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f24f4e1182dd7b1aff66664ecf55004c.addTo(map_f478a5b431de6ce7a6c2a92b009ba851);
#
#
#             var feature_group_d1c99b877975f6ef9583c4e17d5a5ed0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d1c99b877975f6ef9583c4e17d5a5ed0.addTo(map_f478a5b431de6ce7a6c2a92b009ba851);
#
#
#             var feature_group_sub_group_73eda770ff6c164ae016a736c377585c = L.featureGroup.subGroup(
#                 feature_group_d1c99b877975f6ef9583c4e17d5a5ed0
#             );
#
#
#             var marker_e7e14379f3ae4105f75b22e6f60884a2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_73eda770ff6c164ae016a736c377585c);
#
#
#         var popup_8673234013b6f86093c9ca4c90a536ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3f7946147a897dfecb67b347b8a3971 = $(`&lt;div id=&quot;html_c3f7946147a897dfecb67b347b8a3971&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8673234013b6f86093c9ca4c90a536ff.setContent(html_c3f7946147a897dfecb67b347b8a3971);
#
#
#
#         marker_e7e14379f3ae4105f75b22e6f60884a2.bindPopup(popup_8673234013b6f86093c9ca4c90a536ff)
#         ;
#
#
#
#
#             var marker_1f2e0f71b9ae426d82c65224a9e22832 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_73eda770ff6c164ae016a736c377585c);
#
#
#         var popup_ed39c2ff19fdea5636cb9beed59c90b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcd8fab543b9f49b60a4f9268bdd64b8 = $(`&lt;div id=&quot;html_fcd8fab543b9f49b60a4f9268bdd64b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ed39c2ff19fdea5636cb9beed59c90b8.setContent(html_fcd8fab543b9f49b60a4f9268bdd64b8);
#
#
#
#         marker_1f2e0f71b9ae426d82c65224a9e22832.bindPopup(popup_ed39c2ff19fdea5636cb9beed59c90b8)
#         ;
#
#
#
#
#             var marker_e92da28e90ea9f6cf9181879f29c0ff5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_73eda770ff6c164ae016a736c377585c);
#
#
#         var popup_832f5cbe701c67c7020b81bafef1fcc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_243261531c57e9800b4955dbb498f423 = $(`&lt;div id=&quot;html_243261531c57e9800b4955dbb498f423&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_832f5cbe701c67c7020b81bafef1fcc4.setContent(html_243261531c57e9800b4955dbb498f423);
#
#
#
#         marker_e92da28e90ea9f6cf9181879f29c0ff5.bindPopup(popup_832f5cbe701c67c7020b81bafef1fcc4)
#         ;
#
#
#
#
#             var marker_d36b8cddb3e68b3e49714b6cec12376b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_73eda770ff6c164ae016a736c377585c);
#
#
#         var popup_eadcb4390ba28baf4265355ead898e66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86b9e827b742b20faf1e91909614136c = $(`&lt;div id=&quot;html_86b9e827b742b20faf1e91909614136c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_eadcb4390ba28baf4265355ead898e66.setContent(html_86b9e827b742b20faf1e91909614136c);
#
#
#
#         marker_
