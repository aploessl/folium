# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6cb074b8dc92d8e1705b2233eda814e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6cb074b8dc92d8e1705b2233eda814e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6cb074b8dc92d8e1705b2233eda814e6 = L.map(
#                 &quot;map_6cb074b8dc92d8e1705b2233eda814e6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_603231b839bd9f18afd5be7813bfec21 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_603231b839bd9f18afd5be7813bfec21.addTo(map_6cb074b8dc92d8e1705b2233eda814e6);
#
#
#             var marker_9dc2b23e004d366480eb0b4b64c84665 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6cb074b8dc92d8e1705b2233eda814e6);
#
#
#         var popup_23f686babcbf794e6dcf3af988b9167f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac1dccd9eb0c9a1d5667525f6375443e = $(`&lt;div id=&quot;html_ac1dccd9eb0c9a1d5667525f6375443e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_23f686babcbf794e6dcf3af988b9167f.setContent(html_ac1dccd9eb0c9a1d5667525f6375443e);
#
#
#
#         marker_9dc2b23e004d366480eb0b4b64c84665.bindPopup(popup_23f686babcbf794e6dcf3af988b9167f)
#         ;
#
#
#
#
#             var marker_1f738e361b2d583cbfba5d74caac29ed = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6cb074b8dc92d8e1705b2233eda814e6);
#
#
#         var popup_46a8ba1bb6e00f39f8e6246367092db8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdf86aaff27c0eb16539cec04e23a69d = $(`&lt;div id=&quot;html_bdf86aaff27c0eb16539cec04e23a69d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_46a8ba1bb6e00f39f8e6246367092db8.setContent(html_bdf86aaff27c0eb16539cec04e23a69d);
#
#
#
#         marker_1f738e361b2d583cbfba5d74caac29ed.bindPopup(popup_46a8ba1bb6e00f39f8e6246367092db8)
#         ;
#
#
#
#
#             var marker_995d628719c6836162f04adc0507bd2f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6cb074b8dc92d8e1705b2233eda814e6);
#
#
#         var popup_9803cc70abce0f3e4fcb2357a5af8106 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4d3de4ba57896680d5577f241a2d548 = $(`&lt;div id=&quot;html_e4d3de4ba57896680d5577f241a2d548&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9803cc70abce0f3e4fcb2357a5af8106.setContent(html_e4d3de4ba57896680d5577f241a2d548);
#
#
#
#         marker_995d628719c6836162f04adc0507bd2f.bindPopup(popup_9803cc70abce0f3e4fcb2357a5af8106)
#         ;
#
#
#
#
#             var marker_a3c070a19879ebf1d1e1f0c5c12c99af = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6cb074b8dc92d8e1705b2233eda814e6);
#
#
#         var popup_12c161d0bde8fa7f132897e4120b5b34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e985a398df9d9852cd26c7d4e3da361 = $(`&lt;div id=&quot;html_0e985a398df9d9852cd26c7d4e3da361&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_12c161d0bde8fa7f132897e4120b5b34.setContent(html_0e985a398df9d9852cd26c7d4e3da361);
#
#
#
#         marker_a3c070a19879ebf1d1e1f0c5c12c99af.bindPopup(popup_12c161d0bde8fa7f132897e4120b5b34)
#         ;
#
#
#
#
#             var marker_64838082776c879c88a4fa0be392b1da = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6cb074b8dc92d8e1705b2233eda814e6);
#
#
#         var popup_49607f8385b2cce187388a5aab95a73f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4144eff4a2a796b9f5affa363fb7f043 = $(`&lt;div id=&quot;html_4144eff4a2a796b9f5affa363fb7f043&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_49607f8385b2cce187388a5aab95a73f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ff93e7d19a954a978a182f55e76e15d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ff93e7d19a954a978a182f55e76e15d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6ff93e7d19a954a978a182f55e76e15d = L.map(
#                 &quot;map_6ff93e7d19a954a978a182f55e76e15d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f6d08e31b1807aa363d8668d13fa3e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f6d08e31b1807aa363d8668d13fa3e5.addTo(map_6ff93e7d19a954a978a182f55e76e15d);
#
#
#             var feature_group_5b6db524afb585254aa5350e0b208529 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1804f8444ddda8ca2b5aa4186734f057 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5b6db524afb585254aa5350e0b208529);
#
#
#         var popup_2788f4b99541177689507d714da9397f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_174dc8b60e9998e77c4b9129bfad5210 = $(`&lt;div id=&quot;html_174dc8b60e9998e77c4b9129bfad5210&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2788f4b99541177689507d714da9397f.setContent(html_174dc8b60e9998e77c4b9129bfad5210);
#
#
#
#         marker_1804f8444ddda8ca2b5aa4186734f057.bindPopup(popup_2788f4b99541177689507d714da9397f)
#         ;
#
#
#
#
#             var marker_26862e3d393a1649d3432eb64ce38a1d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5b6db524afb585254aa5350e0b208529);
#
#
#         var popup_75a612b272461868fdf66ce7af2553d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1547f3c6ac55f8628a9437df14fe8a26 = $(`&lt;div id=&quot;html_1547f3c6ac55f8628a9437df14fe8a26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_75a612b272461868fdf66ce7af2553d7.setContent(html_1547f3c6ac55f8628a9437df14fe8a26);
#
#
#
#         marker_26862e3d393a1649d3432eb64ce38a1d.bindPopup(popup_75a612b272461868fdf66ce7af2553d7)
#         ;
#
#
#
#
#             var marker_da5e487d2112428192c2699ec67b47ec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5b6db524afb585254aa5350e0b208529);
#
#
#         var popup_5e6843f518b911a00e019d5753caadf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1ea7b3dc1af458bd5a9d579780a4eff = $(`&lt;div id=&quot;html_c1ea7b3dc1af458bd5a9d579780a4eff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5e6843f518b911a00e019d5753caadf6.setContent(html_c1ea7b3dc1af458bd5a9d579780a4eff);
#
#
#
#         marker_da5e487d2112428192c2699ec67b47ec.bindPopup(popup_5e6843f518b911a00e019d5753caadf6)
#         ;
#
#
#
#
#             var marker_e906f32717f24f55a06ee5b16fc37f6b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5b6db524afb585254aa5350e0b208529);
#
#
#         var popup_3bcc68aa9b314b69fe3efa73bb49e9ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2dd57587cf9c4a1f65c187b542af2d4d = $(`&lt;div id=&quot;html_2dd57587cf9c4a1f65c187b542af2d4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3bcc68aa9b314b69fe3efa73bb49e9ba.setContent(html_2dd57587cf9c4a1f65c187b542af2d4d);
#
#
#
#         marker_e906f32717f24f55a06ee5b16fc37f6b.bindPopup(popup_3bcc68aa9b314b69fe3efa73bb49e9ba)
#         ;
#
#
#
#
#             var marker_357329f30e19ebc5f6454339737e9c5d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5b6db524afb585254aa5350e0b208529);
#
#
#         var popup_96bdd3a2a2b578e057806f3e5a00083f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91f6ca23cd1872a406e8e9c1951dbbb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91f6ca23cd1872a406e8e9c1951dbbb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91f6ca23cd1872a406e8e9c1951dbbb2 = L.map(
#                 &quot;map_91f6ca23cd1872a406e8e9c1951dbbb2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84d85e708de4909a687bf5df4a834540 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84d85e708de4909a687bf5df4a834540.addTo(map_91f6ca23cd1872a406e8e9c1951dbbb2);
#
#
#             var feature_group_ead90506b4d82ae39305a3fe35828195 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ead90506b4d82ae39305a3fe35828195.addTo(map_91f6ca23cd1872a406e8e9c1951dbbb2);
#
#
#             var feature_group_sub_group_15f6e01e64fc713c93becb4b9386f424 = L.featureGroup.subGroup(
#                 feature_group_ead90506b4d82ae39305a3fe35828195
#             );
#
#
#             var marker_af307035451a8313030e8c984dce7f45 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_15f6e01e64fc713c93becb4b9386f424);
#
#
#         var popup_388e1ad26674a0f96173d0e8675579ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_881c6788145423519759557ea4c4d245 = $(`&lt;div id=&quot;html_881c6788145423519759557ea4c4d245&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_388e1ad26674a0f96173d0e8675579ec.setContent(html_881c6788145423519759557ea4c4d245);
#
#
#
#         marker_af307035451a8313030e8c984dce7f45.bindPopup(popup_388e1ad26674a0f96173d0e8675579ec)
#         ;
#
#
#
#
#             var marker_dccc73810815b952457515f4a505ce76 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_15f6e01e64fc713c93becb4b9386f424);
#
#
#         var popup_08edcc0be499b5b504091e5ec02bbd79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d114c9bad61e72487bcbb3b9e173dad = $(`&lt;div id=&quot;html_5d114c9bad61e72487bcbb3b9e173dad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_08edcc0be499b5b504091e5ec02bbd79.setContent(html_5d114c9bad61e72487bcbb3b9e173dad);
#
#
#
#         marker_dccc73810815b952457515f4a505ce76.bindPopup(popup_08edcc0be499b5b504091e5ec02bbd79)
#         ;
#
#
#
#
#             var marker_cdcd696662b13394334c648fc99f1d8a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_15f6e01e64fc713c93becb4b9386f424);
#
#
#         var popup_f2b51210ee63b8130e57ff69710737fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1278cdc783a148ca0f631655ca490fca = $(`&lt;div id=&quot;html_1278cdc783a148ca0f631655ca490fca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f2b51210ee63b8130e57ff69710737fd.setContent(html_1278cdc783a148ca0f631655ca490fca);
#
#
#
#         marker_cdcd696662b13394334c648fc99f1d8a.bindPopup(popup_f2b51210ee63b8130e57ff69710737fd)
#         ;
#
#
#
#
#             var marker_cb02b1401a3de9f9d27dbf90ff0b158f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_15f6e01e64fc713c93becb4b9386f424);
#
#
#         var popup_08a220a1da2af6c4532912481836c793 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b21b7bf4291fe285eb6c5f2f499e6237 = $(`&lt;div id=&quot;html_b21b7bf4291fe285eb6c5f2f499e6237&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_08a220a1da2af6c4532912481836c793.setContent(html_b21b7bf4291fe285eb6c5f2f499e6237);
#
#
#
#         marker_
