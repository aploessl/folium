# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb69ade97096754a88cc6ca9b55bbbd8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb69ade97096754a88cc6ca9b55bbbd8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb69ade97096754a88cc6ca9b55bbbd8 = L.map(
#                 &quot;map_bb69ade97096754a88cc6ca9b55bbbd8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2dfdc4ab09c2f570c54f11b7bd5ae38 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d2dfdc4ab09c2f570c54f11b7bd5ae38.addTo(map_bb69ade97096754a88cc6ca9b55bbbd8);
#
#
#             var marker_73b75be0a1d33a6695f58817452f93e3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bb69ade97096754a88cc6ca9b55bbbd8);
#
#
#         var popup_8b054d8a5845b946363577f7361fd491 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17130468b8268470218c85abb0fe2f18 = $(`&lt;div id=&quot;html_17130468b8268470218c85abb0fe2f18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8b054d8a5845b946363577f7361fd491.setContent(html_17130468b8268470218c85abb0fe2f18);
#
#
#
#         marker_73b75be0a1d33a6695f58817452f93e3.bindPopup(popup_8b054d8a5845b946363577f7361fd491)
#         ;
#
#
#
#
#             var marker_27c52eb95fe72f27d0b6f0364b4f3a6a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bb69ade97096754a88cc6ca9b55bbbd8);
#
#
#         var popup_419aa729d7fb1164175b65bbc741e2dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f63096f89b6a665ea7dd67127495c9a1 = $(`&lt;div id=&quot;html_f63096f89b6a665ea7dd67127495c9a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_419aa729d7fb1164175b65bbc741e2dc.setContent(html_f63096f89b6a665ea7dd67127495c9a1);
#
#
#
#         marker_27c52eb95fe72f27d0b6f0364b4f3a6a.bindPopup(popup_419aa729d7fb1164175b65bbc741e2dc)
#         ;
#
#
#
#
#             var marker_ba7334ec1cce8831b5014a781759b92e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bb69ade97096754a88cc6ca9b55bbbd8);
#
#
#         var popup_72d05bc70614d41867eeddbc636c1c92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcff54ee2e6129969a4dea6477366da7 = $(`&lt;div id=&quot;html_fcff54ee2e6129969a4dea6477366da7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_72d05bc70614d41867eeddbc636c1c92.setContent(html_fcff54ee2e6129969a4dea6477366da7);
#
#
#
#         marker_ba7334ec1cce8831b5014a781759b92e.bindPopup(popup_72d05bc70614d41867eeddbc636c1c92)
#         ;
#
#
#
#
#             var marker_37309d03e5322a8a23267dcd048ea01d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bb69ade97096754a88cc6ca9b55bbbd8);
#
#
#         var popup_3d2f5fe3b1900870c7523bcd16a1887c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0506c54b3b44325854d67c46d180a03d = $(`&lt;div id=&quot;html_0506c54b3b44325854d67c46d180a03d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3d2f5fe3b1900870c7523bcd16a1887c.setContent(html_0506c54b3b44325854d67c46d180a03d);
#
#
#
#         marker_37309d03e5322a8a23267dcd048ea01d.bindPopup(popup_3d2f5fe3b1900870c7523bcd16a1887c)
#         ;
#
#
#
#
#             var marker_f58cc446fce796381a5fcd8504aa577d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bb69ade97096754a88cc6ca9b55bbbd8);
#
#
#         var popup_35d8806b11594b5e5b00fd9fe987d2b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5692546b957b66298529d973d54a83e = $(`&lt;div id=&quot;html_a5692546b957b66298529d973d54a83e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_35d8806b11594b5e5b00fd9fe987d2b2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9c5b26093efbed2e7dd1facc4899a17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9c5b26093efbed2e7dd1facc4899a17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9c5b26093efbed2e7dd1facc4899a17 = L.map(
#                 &quot;map_a9c5b26093efbed2e7dd1facc4899a17&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08e766ad86d25a6f2f950f1b848e8464 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08e766ad86d25a6f2f950f1b848e8464.addTo(map_a9c5b26093efbed2e7dd1facc4899a17);
#
#
#             var feature_group_229356ae364a9ac71363ff03d65dbc8f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_39fc7dc2a9bf673238b451b0c16d143d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_229356ae364a9ac71363ff03d65dbc8f);
#
#
#         var popup_be91be46628d320ae0dc68badb9e55d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8269cf533e7f20b4e324639d546a8f2 = $(`&lt;div id=&quot;html_f8269cf533e7f20b4e324639d546a8f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_be91be46628d320ae0dc68badb9e55d1.setContent(html_f8269cf533e7f20b4e324639d546a8f2);
#
#
#
#         marker_39fc7dc2a9bf673238b451b0c16d143d.bindPopup(popup_be91be46628d320ae0dc68badb9e55d1)
#         ;
#
#
#
#
#             var marker_2ab8ec06efdcd1005763227dc77defc6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_229356ae364a9ac71363ff03d65dbc8f);
#
#
#         var popup_c6e9898221054ad414c2b82896b21c3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cf8a2164e01473fdca2cca4e62f6069 = $(`&lt;div id=&quot;html_1cf8a2164e01473fdca2cca4e62f6069&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c6e9898221054ad414c2b82896b21c3d.setContent(html_1cf8a2164e01473fdca2cca4e62f6069);
#
#
#
#         marker_2ab8ec06efdcd1005763227dc77defc6.bindPopup(popup_c6e9898221054ad414c2b82896b21c3d)
#         ;
#
#
#
#
#             var marker_edc4708aa6182b05c3ff18bcfcc32891 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_229356ae364a9ac71363ff03d65dbc8f);
#
#
#         var popup_14d1d1986b7c9dedf2feabc712b1e7c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_036e3b1f8ef606abb8b11711dd05c6f0 = $(`&lt;div id=&quot;html_036e3b1f8ef606abb8b11711dd05c6f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_14d1d1986b7c9dedf2feabc712b1e7c4.setContent(html_036e3b1f8ef606abb8b11711dd05c6f0);
#
#
#
#         marker_edc4708aa6182b05c3ff18bcfcc32891.bindPopup(popup_14d1d1986b7c9dedf2feabc712b1e7c4)
#         ;
#
#
#
#
#             var marker_e0bdda2a166eef5d688bc21f17cc343b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_229356ae364a9ac71363ff03d65dbc8f);
#
#
#         var popup_1b83fbbdbcf535bdcc6b27f4c2a58ae2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_833ef29fe49c0301f027f7eea4c4e5ec = $(`&lt;div id=&quot;html_833ef29fe49c0301f027f7eea4c4e5ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1b83fbbdbcf535bdcc6b27f4c2a58ae2.setContent(html_833ef29fe49c0301f027f7eea4c4e5ec);
#
#
#
#         marker_e0bdda2a166eef5d688bc21f17cc343b.bindPopup(popup_1b83fbbdbcf535bdcc6b27f4c2a58ae2)
#         ;
#
#
#
#
#             var marker_4bd41d4723f0671e1f1c73a29fd9ab42 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_229356ae364a9ac71363ff03d65dbc8f);
#
#
#         var popup_e8ba9b8b3f96a0dc50d08a23d0ac494b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7694ff127a9f64095b699643ac26235a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7694ff127a9f64095b699643ac26235a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7694ff127a9f64095b699643ac26235a = L.map(
#                 &quot;map_7694ff127a9f64095b699643ac26235a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b15e259a373951358557e940c32edb0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b15e259a373951358557e940c32edb0.addTo(map_7694ff127a9f64095b699643ac26235a);
#
#
#             var feature_group_48be99bfddb8d07cb63545a1fe852d06 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_48be99bfddb8d07cb63545a1fe852d06.addTo(map_7694ff127a9f64095b699643ac26235a);
#
#
#             var feature_group_sub_group_ffec70b5c201875ae12a009151c14e81 = L.featureGroup.subGroup(
#                 feature_group_48be99bfddb8d07cb63545a1fe852d06
#             );
#
#
#             var marker_8a7455e16114940ff25289a9f8c2dc6e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffec70b5c201875ae12a009151c14e81);
#
#
#         var popup_495431b47adf0f8ae0aa7c4e45fc5f74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af6b0673ee985b4616fd405cb687d72f = $(`&lt;div id=&quot;html_af6b0673ee985b4616fd405cb687d72f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_495431b47adf0f8ae0aa7c4e45fc5f74.setContent(html_af6b0673ee985b4616fd405cb687d72f);
#
#
#
#         marker_8a7455e16114940ff25289a9f8c2dc6e.bindPopup(popup_495431b47adf0f8ae0aa7c4e45fc5f74)
#         ;
#
#
#
#
#             var marker_6df8b610e11d05735b40d86b7ea75aae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffec70b5c201875ae12a009151c14e81);
#
#
#         var popup_bd27ddb5d2427518d2f2f40fd9f6d6ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4cd0af34a2f0334a4b386c09c04f1dc = $(`&lt;div id=&quot;html_b4cd0af34a2f0334a4b386c09c04f1dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bd27ddb5d2427518d2f2f40fd9f6d6ba.setContent(html_b4cd0af34a2f0334a4b386c09c04f1dc);
#
#
#
#         marker_6df8b610e11d05735b40d86b7ea75aae.bindPopup(popup_bd27ddb5d2427518d2f2f40fd9f6d6ba)
#         ;
#
#
#
#
#             var marker_b645f920e171f29976f2c15fee806aa1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffec70b5c201875ae12a009151c14e81);
#
#
#         var popup_88884bd591f9b88c8b74b05704363477 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdbef9799a4336d7cf3af82a7f2a992b = $(`&lt;div id=&quot;html_bdbef9799a4336d7cf3af82a7f2a992b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_88884bd591f9b88c8b74b05704363477.setContent(html_bdbef9799a4336d7cf3af82a7f2a992b);
#
#
#
#         marker_b645f920e171f29976f2c15fee806aa1.bindPopup(popup_88884bd591f9b88c8b74b05704363477)
#         ;
#
#
#
#
#             var marker_420fc8a74f6a86bcaa79ef1352bd550c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffec70b5c201875ae12a009151c14e81);
#
#
#         var popup_2ddaa4040d4e484dca046562d4d7710f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52e1d1893f8778aeba2186c8ed33e9c6 = $(`&lt;div id=&quot;html_52e1d1893f8778aeba2186c8ed33e9c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2ddaa4040d4e484dca046562d4d7710f.setContent(html_52e1d1893f8778aeba2186c8ed33e9c6);
#
#
#
#         marker_
