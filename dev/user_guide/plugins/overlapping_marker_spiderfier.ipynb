# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a085e5fc65a75b590d549385a1810ab9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a085e5fc65a75b590d549385a1810ab9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a085e5fc65a75b590d549385a1810ab9 = L.map(
#                 &quot;map_a085e5fc65a75b590d549385a1810ab9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6443606f3a44cc63d12ead253891878 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f6443606f3a44cc63d12ead253891878.addTo(map_a085e5fc65a75b590d549385a1810ab9);
#
#
#             var marker_02af84580d7d223d60c00227c1a63f6b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a085e5fc65a75b590d549385a1810ab9);
#
#
#         var popup_3b262bdcb211c7c868533024dea5bde9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9758e01a9f033a6b56889e34d3b10369 = $(`&lt;div id=&quot;html_9758e01a9f033a6b56889e34d3b10369&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3b262bdcb211c7c868533024dea5bde9.setContent(html_9758e01a9f033a6b56889e34d3b10369);
#
#
#
#         marker_02af84580d7d223d60c00227c1a63f6b.bindPopup(popup_3b262bdcb211c7c868533024dea5bde9)
#         ;
#
#
#
#
#             var marker_a3a9ce16b286c5ed845b3330b4b9f792 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a085e5fc65a75b590d549385a1810ab9);
#
#
#         var popup_750a4c6fc0ac3d073e0ead6b32aec3c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c544ae239939bc4c3e99db081fd2975 = $(`&lt;div id=&quot;html_0c544ae239939bc4c3e99db081fd2975&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_750a4c6fc0ac3d073e0ead6b32aec3c9.setContent(html_0c544ae239939bc4c3e99db081fd2975);
#
#
#
#         marker_a3a9ce16b286c5ed845b3330b4b9f792.bindPopup(popup_750a4c6fc0ac3d073e0ead6b32aec3c9)
#         ;
#
#
#
#
#             var marker_296ffbe57dd2f3a047be42fe44be9249 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a085e5fc65a75b590d549385a1810ab9);
#
#
#         var popup_3ea80c4ec96b98e0814a5dd472173b32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e88f95f96dd8446d80e37d39265cd989 = $(`&lt;div id=&quot;html_e88f95f96dd8446d80e37d39265cd989&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3ea80c4ec96b98e0814a5dd472173b32.setContent(html_e88f95f96dd8446d80e37d39265cd989);
#
#
#
#         marker_296ffbe57dd2f3a047be42fe44be9249.bindPopup(popup_3ea80c4ec96b98e0814a5dd472173b32)
#         ;
#
#
#
#
#             var marker_8d5c17d169bc890fe0dc25de454ac81d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a085e5fc65a75b590d549385a1810ab9);
#
#
#         var popup_bb55c71337e1bf867ce8fb319d715822 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7363a65d799e1031e522d10f45d82e43 = $(`&lt;div id=&quot;html_7363a65d799e1031e522d10f45d82e43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bb55c71337e1bf867ce8fb319d715822.setContent(html_7363a65d799e1031e522d10f45d82e43);
#
#
#
#         marker_8d5c17d169bc890fe0dc25de454ac81d.bindPopup(popup_bb55c71337e1bf867ce8fb319d715822)
#         ;
#
#
#
#
#             var marker_8c9ba7a5918b2df347f2545d98820b1c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a085e5fc65a75b590d549385a1810ab9);
#
#
#         var popup_2eaa275bf2ff825d47feac0d68d12ac6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dfa5dc712140e55e993e3cac4a7ce1a = $(`&lt;div id=&quot;html_9dfa5dc712140e55e993e3cac4a7ce1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2eaa275bf2ff825d47feac0d68d12ac6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5eb69cd358f8fbc0d2acc7d656778b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5eb69cd358f8fbc0d2acc7d656778b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5eb69cd358f8fbc0d2acc7d656778b1 = L.map(
#                 &quot;map_c5eb69cd358f8fbc0d2acc7d656778b1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fca85149216ab7a1da5c4afa725d48e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7fca85149216ab7a1da5c4afa725d48e.addTo(map_c5eb69cd358f8fbc0d2acc7d656778b1);
#
#
#             var feature_group_ba46db0be8f7912bfaba874f07d22260 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1518427767f7def4c7f18f0e84217b19 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ba46db0be8f7912bfaba874f07d22260);
#
#
#         var popup_3f5a9a2d94ecd761f4bb54e3d3645b1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb313df7ab128c39a4d0b28e5cb9ee84 = $(`&lt;div id=&quot;html_bb313df7ab128c39a4d0b28e5cb9ee84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3f5a9a2d94ecd761f4bb54e3d3645b1a.setContent(html_bb313df7ab128c39a4d0b28e5cb9ee84);
#
#
#
#         marker_1518427767f7def4c7f18f0e84217b19.bindPopup(popup_3f5a9a2d94ecd761f4bb54e3d3645b1a)
#         ;
#
#
#
#
#             var marker_0d301e19d6a5d874ef48db222f0a044f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ba46db0be8f7912bfaba874f07d22260);
#
#
#         var popup_351c6f8393ea9eb9c5465dae1b0a3540 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e20d3adea2b87997f409566defa42263 = $(`&lt;div id=&quot;html_e20d3adea2b87997f409566defa42263&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_351c6f8393ea9eb9c5465dae1b0a3540.setContent(html_e20d3adea2b87997f409566defa42263);
#
#
#
#         marker_0d301e19d6a5d874ef48db222f0a044f.bindPopup(popup_351c6f8393ea9eb9c5465dae1b0a3540)
#         ;
#
#
#
#
#             var marker_9e761d8a4b8d89760c19e1bf9e34ee92 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ba46db0be8f7912bfaba874f07d22260);
#
#
#         var popup_49a55ecfe3f3853b25d82f2a5c72a86a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a16523e72f1df2539ed6adc999bca32 = $(`&lt;div id=&quot;html_0a16523e72f1df2539ed6adc999bca32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_49a55ecfe3f3853b25d82f2a5c72a86a.setContent(html_0a16523e72f1df2539ed6adc999bca32);
#
#
#
#         marker_9e761d8a4b8d89760c19e1bf9e34ee92.bindPopup(popup_49a55ecfe3f3853b25d82f2a5c72a86a)
#         ;
#
#
#
#
#             var marker_37531df889cf54999fbff66adff1462c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ba46db0be8f7912bfaba874f07d22260);
#
#
#         var popup_1efe6796f8131ff660ee617295df670c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d4ec07997516b273130c9265f111d6d = $(`&lt;div id=&quot;html_2d4ec07997516b273130c9265f111d6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1efe6796f8131ff660ee617295df670c.setContent(html_2d4ec07997516b273130c9265f111d6d);
#
#
#
#         marker_37531df889cf54999fbff66adff1462c.bindPopup(popup_1efe6796f8131ff660ee617295df670c)
#         ;
#
#
#
#
#             var marker_e62d3447b20651a075989ddee39e97c5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ba46db0be8f7912bfaba874f07d22260);
#
#
#         var popup_b813ecd45af2d17bdae4e783449385ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64f6d9281a1084ea7259b9d7875bd19c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64f6d9281a1084ea7259b9d7875bd19c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_64f6d9281a1084ea7259b9d7875bd19c = L.map(
#                 &quot;map_64f6d9281a1084ea7259b9d7875bd19c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed575ab0227dd63de587eddc1478a7e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed575ab0227dd63de587eddc1478a7e3.addTo(map_64f6d9281a1084ea7259b9d7875bd19c);
#
#
#             var feature_group_f3656da885fb5bfcbc9d35c63cd18ae0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f3656da885fb5bfcbc9d35c63cd18ae0.addTo(map_64f6d9281a1084ea7259b9d7875bd19c);
#
#
#             var feature_group_sub_group_82399d4752ea56129b0eb1dc6d85033e = L.featureGroup.subGroup(
#                 feature_group_f3656da885fb5bfcbc9d35c63cd18ae0
#             );
#
#
#             var marker_2335ebd941001f8965071219be05ad23 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_82399d4752ea56129b0eb1dc6d85033e);
#
#
#         var popup_e97ab67fab819596885954c8ec79b3cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3522deae044010403db79805acb33cd = $(`&lt;div id=&quot;html_f3522deae044010403db79805acb33cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e97ab67fab819596885954c8ec79b3cf.setContent(html_f3522deae044010403db79805acb33cd);
#
#
#
#         marker_2335ebd941001f8965071219be05ad23.bindPopup(popup_e97ab67fab819596885954c8ec79b3cf)
#         ;
#
#
#
#
#             var marker_47c09d35f44cb83c129d643de5838714 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_82399d4752ea56129b0eb1dc6d85033e);
#
#
#         var popup_e78c2e348722e833f528c67c050a079e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2ce2cd1d816a1971f3808fe0ed93041 = $(`&lt;div id=&quot;html_b2ce2cd1d816a1971f3808fe0ed93041&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e78c2e348722e833f528c67c050a079e.setContent(html_b2ce2cd1d816a1971f3808fe0ed93041);
#
#
#
#         marker_47c09d35f44cb83c129d643de5838714.bindPopup(popup_e78c2e348722e833f528c67c050a079e)
#         ;
#
#
#
#
#             var marker_d02e9d9b3a7a071495ef6efd364f92e4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_82399d4752ea56129b0eb1dc6d85033e);
#
#
#         var popup_d6fe57f1fdc759264937ea1977c7b537 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64551c7251eef51a45f9f6b74a1b2ab8 = $(`&lt;div id=&quot;html_64551c7251eef51a45f9f6b74a1b2ab8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d6fe57f1fdc759264937ea1977c7b537.setContent(html_64551c7251eef51a45f9f6b74a1b2ab8);
#
#
#
#         marker_d02e9d9b3a7a071495ef6efd364f92e4.bindPopup(popup_d6fe57f1fdc759264937ea1977c7b537)
#         ;
#
#
#
#
#             var marker_5a365d96c966c6b950608a9e4e0cf59f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_82399d4752ea56129b0eb1dc6d85033e);
#
#
#         var popup_37d7309f4ff15404edd08a7c416c9cc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4df84f386982ff687911b407ac5edf81 = $(`&lt;div id=&quot;html_4df84f386982ff687911b407ac5edf81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_37d7309f4ff15404edd08a7c416c9cc8.setContent(html_4df84f386982ff687911b407ac5edf81);
#
#
#
#         marker_
