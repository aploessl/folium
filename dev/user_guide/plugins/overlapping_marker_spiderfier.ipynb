# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e363dd20a73fb28f1ea812d540cb645e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e363dd20a73fb28f1ea812d540cb645e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e363dd20a73fb28f1ea812d540cb645e = L.map(
#                 &quot;map_e363dd20a73fb28f1ea812d540cb645e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42ebdbb98bb55ce9d0bbd0c4a579c006 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_42ebdbb98bb55ce9d0bbd0c4a579c006.addTo(map_e363dd20a73fb28f1ea812d540cb645e);
#
#
#             var marker_07b02bff5e07ef6d9dd7000626af1fff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e363dd20a73fb28f1ea812d540cb645e);
#
#
#         var popup_843f82c7dbbbff37fdab904105c4e365 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_201518c02bfe8e14524ba121cfcb3187 = $(`&lt;div id=&quot;html_201518c02bfe8e14524ba121cfcb3187&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_843f82c7dbbbff37fdab904105c4e365.setContent(html_201518c02bfe8e14524ba121cfcb3187);
#
#
#
#         marker_07b02bff5e07ef6d9dd7000626af1fff.bindPopup(popup_843f82c7dbbbff37fdab904105c4e365)
#         ;
#
#
#
#
#             var marker_babed46a6768e3e49b6818297825b948 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e363dd20a73fb28f1ea812d540cb645e);
#
#
#         var popup_6787addeb7fd290891272d44d305ae52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3d338627ea5c5b5fa257846eedcadd5 = $(`&lt;div id=&quot;html_d3d338627ea5c5b5fa257846eedcadd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6787addeb7fd290891272d44d305ae52.setContent(html_d3d338627ea5c5b5fa257846eedcadd5);
#
#
#
#         marker_babed46a6768e3e49b6818297825b948.bindPopup(popup_6787addeb7fd290891272d44d305ae52)
#         ;
#
#
#
#
#             var marker_a3e14e618930a93440ad9bbd04ba3291 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e363dd20a73fb28f1ea812d540cb645e);
#
#
#         var popup_5b34d31065023ab83e7f19c19b8bf6cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03e4393809d60b96af5c6da5a97d6e5a = $(`&lt;div id=&quot;html_03e4393809d60b96af5c6da5a97d6e5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5b34d31065023ab83e7f19c19b8bf6cb.setContent(html_03e4393809d60b96af5c6da5a97d6e5a);
#
#
#
#         marker_a3e14e618930a93440ad9bbd04ba3291.bindPopup(popup_5b34d31065023ab83e7f19c19b8bf6cb)
#         ;
#
#
#
#
#             var marker_868fbcbfe6ed8013ee3642708c786f27 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e363dd20a73fb28f1ea812d540cb645e);
#
#
#         var popup_0872fcdfdb180b318efd6502f57c0cb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0616cacc2cedcdc7cf0c0d71e56a064 = $(`&lt;div id=&quot;html_c0616cacc2cedcdc7cf0c0d71e56a064&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0872fcdfdb180b318efd6502f57c0cb2.setContent(html_c0616cacc2cedcdc7cf0c0d71e56a064);
#
#
#
#         marker_868fbcbfe6ed8013ee3642708c786f27.bindPopup(popup_0872fcdfdb180b318efd6502f57c0cb2)
#         ;
#
#
#
#
#             var marker_e43d3227c752c3d9dfca5f154e0ee252 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e363dd20a73fb28f1ea812d540cb645e);
#
#
#         var popup_a3e6fab4e15db52f37a907269d75c599 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08fd1d26ee92d900c08c4de73cf177c2 = $(`&lt;div id=&quot;html_08fd1d26ee92d900c08c4de73cf177c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a3e6fab4e15db52f37a907269d75c599.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e106be3401b0f13b2d9f021f7b1fcc86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e106be3401b0f13b2d9f021f7b1fcc86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e106be3401b0f13b2d9f021f7b1fcc86 = L.map(
#                 &quot;map_e106be3401b0f13b2d9f021f7b1fcc86&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aacf1e59eefb39d0c8fc1cd91be8f4b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aacf1e59eefb39d0c8fc1cd91be8f4b3.addTo(map_e106be3401b0f13b2d9f021f7b1fcc86);
#
#
#             var feature_group_05abd1810023928dc4c2cdc1e06284f5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_583c4004c9a2aa99cbd133c259ea245f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_05abd1810023928dc4c2cdc1e06284f5);
#
#
#         var popup_2af42afe4caabea6ccf7e0ef057137e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f9459a5794b643687bc15cdc417b670 = $(`&lt;div id=&quot;html_2f9459a5794b643687bc15cdc417b670&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2af42afe4caabea6ccf7e0ef057137e2.setContent(html_2f9459a5794b643687bc15cdc417b670);
#
#
#
#         marker_583c4004c9a2aa99cbd133c259ea245f.bindPopup(popup_2af42afe4caabea6ccf7e0ef057137e2)
#         ;
#
#
#
#
#             var marker_2cbc98ed4bba65032b6285fe9296b641 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_05abd1810023928dc4c2cdc1e06284f5);
#
#
#         var popup_a94abbae5e3e532be3300d967a60c621 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78210b7fbfad971ea89f37ed5e73399c = $(`&lt;div id=&quot;html_78210b7fbfad971ea89f37ed5e73399c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a94abbae5e3e532be3300d967a60c621.setContent(html_78210b7fbfad971ea89f37ed5e73399c);
#
#
#
#         marker_2cbc98ed4bba65032b6285fe9296b641.bindPopup(popup_a94abbae5e3e532be3300d967a60c621)
#         ;
#
#
#
#
#             var marker_d6bebd5261b6e1cd8b098f63c25f3614 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_05abd1810023928dc4c2cdc1e06284f5);
#
#
#         var popup_d3fbd476306139702928a8924701b1c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b21f32654afc0cd02787093ccc31c8bb = $(`&lt;div id=&quot;html_b21f32654afc0cd02787093ccc31c8bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d3fbd476306139702928a8924701b1c4.setContent(html_b21f32654afc0cd02787093ccc31c8bb);
#
#
#
#         marker_d6bebd5261b6e1cd8b098f63c25f3614.bindPopup(popup_d3fbd476306139702928a8924701b1c4)
#         ;
#
#
#
#
#             var marker_e662ed6249972812c8de31ad6b35304b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_05abd1810023928dc4c2cdc1e06284f5);
#
#
#         var popup_6da788777ffcd1e7efac2e2bed5263d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f31f58210d2e73493b380e5ac5eaada = $(`&lt;div id=&quot;html_2f31f58210d2e73493b380e5ac5eaada&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6da788777ffcd1e7efac2e2bed5263d2.setContent(html_2f31f58210d2e73493b380e5ac5eaada);
#
#
#
#         marker_e662ed6249972812c8de31ad6b35304b.bindPopup(popup_6da788777ffcd1e7efac2e2bed5263d2)
#         ;
#
#
#
#
#             var marker_66f8bbfbfd24ab2429bc40f7bac3b2cf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_05abd1810023928dc4c2cdc1e06284f5);
#
#
#         var popup_8abb518085ae4e1642af9da363994150 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef4bb6b7e3fbc3f26140857f7337c7cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef4bb6b7e3fbc3f26140857f7337c7cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef4bb6b7e3fbc3f26140857f7337c7cc = L.map(
#                 &quot;map_ef4bb6b7e3fbc3f26140857f7337c7cc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_265a9aefc8a67fb19870d3e6cd9c340c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_265a9aefc8a67fb19870d3e6cd9c340c.addTo(map_ef4bb6b7e3fbc3f26140857f7337c7cc);
#
#
#             var feature_group_24dfc92e1891c54db6155b0b37a3de6e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_24dfc92e1891c54db6155b0b37a3de6e.addTo(map_ef4bb6b7e3fbc3f26140857f7337c7cc);
#
#
#             var feature_group_sub_group_825a08e3bc86520ab1e4af7b69f00a0c = L.featureGroup.subGroup(
#                 feature_group_24dfc92e1891c54db6155b0b37a3de6e
#             );
#
#
#             var marker_738f17fd3c46d17c2dc136b31943cbb9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_825a08e3bc86520ab1e4af7b69f00a0c);
#
#
#         var popup_7e05c142e6a449bb117e0d4ddc5a655a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bce7e892f16f987ba6ee0b8edb398c80 = $(`&lt;div id=&quot;html_bce7e892f16f987ba6ee0b8edb398c80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7e05c142e6a449bb117e0d4ddc5a655a.setContent(html_bce7e892f16f987ba6ee0b8edb398c80);
#
#
#
#         marker_738f17fd3c46d17c2dc136b31943cbb9.bindPopup(popup_7e05c142e6a449bb117e0d4ddc5a655a)
#         ;
#
#
#
#
#             var marker_38d5e9875e4b741441ffd9019ed988c9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_825a08e3bc86520ab1e4af7b69f00a0c);
#
#
#         var popup_e904694eb2a90fce4bce081b0325b5ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c6d3bf4859a5d5961a9a900c5c30ccc = $(`&lt;div id=&quot;html_3c6d3bf4859a5d5961a9a900c5c30ccc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e904694eb2a90fce4bce081b0325b5ff.setContent(html_3c6d3bf4859a5d5961a9a900c5c30ccc);
#
#
#
#         marker_38d5e9875e4b741441ffd9019ed988c9.bindPopup(popup_e904694eb2a90fce4bce081b0325b5ff)
#         ;
#
#
#
#
#             var marker_64a6b0c8b2498ba233659e3634800034 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_825a08e3bc86520ab1e4af7b69f00a0c);
#
#
#         var popup_494f81854dbdf0fd7fc4417ec56f6f4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af3336c0991cd5044c1dcc2cabce250d = $(`&lt;div id=&quot;html_af3336c0991cd5044c1dcc2cabce250d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_494f81854dbdf0fd7fc4417ec56f6f4b.setContent(html_af3336c0991cd5044c1dcc2cabce250d);
#
#
#
#         marker_64a6b0c8b2498ba233659e3634800034.bindPopup(popup_494f81854dbdf0fd7fc4417ec56f6f4b)
#         ;
#
#
#
#
#             var marker_b0823818c81284ef92ecc47800a20e83 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_825a08e3bc86520ab1e4af7b69f00a0c);
#
#
#         var popup_42a2be91054e7863a3985a6edf9e484c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0cc79f4106817e74702849fbc821c11 = $(`&lt;div id=&quot;html_d0cc79f4106817e74702849fbc821c11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_42a2be91054e7863a3985a6edf9e484c.setContent(html_d0cc79f4106817e74702849fbc821c11);
#
#
#
#         marker_
