# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1920dbc1c872c9a12dfaed344026647b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1920dbc1c872c9a12dfaed344026647b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1920dbc1c872c9a12dfaed344026647b = L.map(
#                 &quot;map_1920dbc1c872c9a12dfaed344026647b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0788229bd158fe2216084f098faeffec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0788229bd158fe2216084f098faeffec.addTo(map_1920dbc1c872c9a12dfaed344026647b);
#
#
#             var marker_e7b0b59d2aab753d2d447d33498d9d39 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1920dbc1c872c9a12dfaed344026647b);
#
#
#         var popup_c6fedd1360aedad62b13128a8f432fab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_241de4f8e3ea3a5ae44bac8ff857b7c7 = $(`&lt;div id=&quot;html_241de4f8e3ea3a5ae44bac8ff857b7c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c6fedd1360aedad62b13128a8f432fab.setContent(html_241de4f8e3ea3a5ae44bac8ff857b7c7);
#
#
#
#         marker_e7b0b59d2aab753d2d447d33498d9d39.bindPopup(popup_c6fedd1360aedad62b13128a8f432fab)
#         ;
#
#
#
#
#             var marker_9182eda94f2053a63833ea02ba42741e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1920dbc1c872c9a12dfaed344026647b);
#
#
#         var popup_c83be74aacc06ab25393b1fc20d61e9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79e65c490074378581e2c44fd27d9ad8 = $(`&lt;div id=&quot;html_79e65c490074378581e2c44fd27d9ad8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c83be74aacc06ab25393b1fc20d61e9f.setContent(html_79e65c490074378581e2c44fd27d9ad8);
#
#
#
#         marker_9182eda94f2053a63833ea02ba42741e.bindPopup(popup_c83be74aacc06ab25393b1fc20d61e9f)
#         ;
#
#
#
#
#             var marker_bc0fc69bce949c0c4a0c5fac13cef227 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1920dbc1c872c9a12dfaed344026647b);
#
#
#         var popup_2f062583b95727a721044301f1865aab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12ff09641855409381ad9ddceee081ec = $(`&lt;div id=&quot;html_12ff09641855409381ad9ddceee081ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2f062583b95727a721044301f1865aab.setContent(html_12ff09641855409381ad9ddceee081ec);
#
#
#
#         marker_bc0fc69bce949c0c4a0c5fac13cef227.bindPopup(popup_2f062583b95727a721044301f1865aab)
#         ;
#
#
#
#
#             var marker_bece970918b1f794690e4e340cfd775e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1920dbc1c872c9a12dfaed344026647b);
#
#
#         var popup_e57c6bf47a4cb37095b981c58db0cc7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc011b417037e66794da2c23e4d60099 = $(`&lt;div id=&quot;html_bc011b417037e66794da2c23e4d60099&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e57c6bf47a4cb37095b981c58db0cc7f.setContent(html_bc011b417037e66794da2c23e4d60099);
#
#
#
#         marker_bece970918b1f794690e4e340cfd775e.bindPopup(popup_e57c6bf47a4cb37095b981c58db0cc7f)
#         ;
#
#
#
#
#             var marker_d8ffb3e38c484a70b087276b0e46c9cd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1920dbc1c872c9a12dfaed344026647b);
#
#
#         var popup_a1db4bb98c82b243a6247bb8c5f1cd2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_539bb26c79d212b11c8cfe120b312454 = $(`&lt;div id=&quot;html_539bb26c79d212b11c8cfe120b312454&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a1db4bb98c82b243a6247bb8c5f1cd2a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67f33b22aaa658248a72cc4423f643f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67f33b22aaa658248a72cc4423f643f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67f33b22aaa658248a72cc4423f643f8 = L.map(
#                 &quot;map_67f33b22aaa658248a72cc4423f643f8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b69bac5fa70f815d3d34147299946427 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b69bac5fa70f815d3d34147299946427.addTo(map_67f33b22aaa658248a72cc4423f643f8);
#
#
#             var feature_group_bb5893a235bf53d780c52d612ecd57b2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bf6b353466a6de73d966ea5ecf83c601 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_bb5893a235bf53d780c52d612ecd57b2);
#
#
#         var popup_c8ebe6e094ff55a3f1cd65bd682c4fc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_441b8140db8ed8a68095dcb9e52c765e = $(`&lt;div id=&quot;html_441b8140db8ed8a68095dcb9e52c765e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c8ebe6e094ff55a3f1cd65bd682c4fc0.setContent(html_441b8140db8ed8a68095dcb9e52c765e);
#
#
#
#         marker_bf6b353466a6de73d966ea5ecf83c601.bindPopup(popup_c8ebe6e094ff55a3f1cd65bd682c4fc0)
#         ;
#
#
#
#
#             var marker_f400fda9d3344c72f3dc3f7a98c10961 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_bb5893a235bf53d780c52d612ecd57b2);
#
#
#         var popup_f7e2bc4b72a2ee0340e5e77c3c48ce07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfb95adaf65858023effd9fca31e594a = $(`&lt;div id=&quot;html_bfb95adaf65858023effd9fca31e594a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f7e2bc4b72a2ee0340e5e77c3c48ce07.setContent(html_bfb95adaf65858023effd9fca31e594a);
#
#
#
#         marker_f400fda9d3344c72f3dc3f7a98c10961.bindPopup(popup_f7e2bc4b72a2ee0340e5e77c3c48ce07)
#         ;
#
#
#
#
#             var marker_0284147bf757a25801cbadaca75354cd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_bb5893a235bf53d780c52d612ecd57b2);
#
#
#         var popup_68fbec61e8cda03cb5fc4a7832a6ca64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2b87611ca866476ad7cbe8a41be1635 = $(`&lt;div id=&quot;html_a2b87611ca866476ad7cbe8a41be1635&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_68fbec61e8cda03cb5fc4a7832a6ca64.setContent(html_a2b87611ca866476ad7cbe8a41be1635);
#
#
#
#         marker_0284147bf757a25801cbadaca75354cd.bindPopup(popup_68fbec61e8cda03cb5fc4a7832a6ca64)
#         ;
#
#
#
#
#             var marker_00dd8f47b70eec32b70ce26ef496ab4d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_bb5893a235bf53d780c52d612ecd57b2);
#
#
#         var popup_e2ef15da3b5d33bf20a4ccf2d7b9d5f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e884d5b1e32e73acb1a91c114d794c47 = $(`&lt;div id=&quot;html_e884d5b1e32e73acb1a91c114d794c47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e2ef15da3b5d33bf20a4ccf2d7b9d5f8.setContent(html_e884d5b1e32e73acb1a91c114d794c47);
#
#
#
#         marker_00dd8f47b70eec32b70ce26ef496ab4d.bindPopup(popup_e2ef15da3b5d33bf20a4ccf2d7b9d5f8)
#         ;
#
#
#
#
#             var marker_d66b6ed4ea95bc1ce4df2122c20f064e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_bb5893a235bf53d780c52d612ecd57b2);
#
#
#         var popup_021b9131d728bc156d0584f61da37d99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ed82f519f51d9facebb4b4579a98602 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ed82f519f51d9facebb4b4579a98602&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ed82f519f51d9facebb4b4579a98602 = L.map(
#                 &quot;map_9ed82f519f51d9facebb4b4579a98602&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1145f17ac2cc35a7fb2d2bc0a98532f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d1145f17ac2cc35a7fb2d2bc0a98532f.addTo(map_9ed82f519f51d9facebb4b4579a98602);
#
#
#             var feature_group_fd26653a9abbbaf13eebe28489ecfb31 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fd26653a9abbbaf13eebe28489ecfb31.addTo(map_9ed82f519f51d9facebb4b4579a98602);
#
#
#             var feature_group_sub_group_c9702bf8da29f37492a219840730d16b = L.featureGroup.subGroup(
#                 feature_group_fd26653a9abbbaf13eebe28489ecfb31
#             );
#
#
#             var marker_07c250d1a9649bb9d02b0f90b618fce9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9702bf8da29f37492a219840730d16b);
#
#
#         var popup_ae67be3f6bc836a42df0fc2961e476b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b25e70b9db32a37a25a8be17e855b670 = $(`&lt;div id=&quot;html_b25e70b9db32a37a25a8be17e855b670&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ae67be3f6bc836a42df0fc2961e476b6.setContent(html_b25e70b9db32a37a25a8be17e855b670);
#
#
#
#         marker_07c250d1a9649bb9d02b0f90b618fce9.bindPopup(popup_ae67be3f6bc836a42df0fc2961e476b6)
#         ;
#
#
#
#
#             var marker_704f61bfd81999b4c223398df27ed35e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9702bf8da29f37492a219840730d16b);
#
#
#         var popup_f75ff80d3d82a86562cea908aa7be6e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e7f6eb1f2cb348fab88f961ad0e1390 = $(`&lt;div id=&quot;html_4e7f6eb1f2cb348fab88f961ad0e1390&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f75ff80d3d82a86562cea908aa7be6e9.setContent(html_4e7f6eb1f2cb348fab88f961ad0e1390);
#
#
#
#         marker_704f61bfd81999b4c223398df27ed35e.bindPopup(popup_f75ff80d3d82a86562cea908aa7be6e9)
#         ;
#
#
#
#
#             var marker_125311dbdf2f29c2dc022a81c03d52cf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9702bf8da29f37492a219840730d16b);
#
#
#         var popup_5830cb6786bc6133ec8bb851136ae7aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb6d3de341072979defd17631c2b7968 = $(`&lt;div id=&quot;html_eb6d3de341072979defd17631c2b7968&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5830cb6786bc6133ec8bb851136ae7aa.setContent(html_eb6d3de341072979defd17631c2b7968);
#
#
#
#         marker_125311dbdf2f29c2dc022a81c03d52cf.bindPopup(popup_5830cb6786bc6133ec8bb851136ae7aa)
#         ;
#
#
#
#
#             var marker_f5f21104b3481c2033c100f8c5593a2e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9702bf8da29f37492a219840730d16b);
#
#
#         var popup_fba01508f3e3bd6f27b3d37be9ed8af7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ec940cb88e2c829d812afeb7690030b = $(`&lt;div id=&quot;html_1ec940cb88e2c829d812afeb7690030b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fba01508f3e3bd6f27b3d37be9ed8af7.setContent(html_1ec940cb88e2c829d812afeb7690030b);
#
#
#
#         marker_
