# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b24635222fe7dc0c0d04c9df670310e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b24635222fe7dc0c0d04c9df670310e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b24635222fe7dc0c0d04c9df670310e1 = L.map(
#                 &quot;map_b24635222fe7dc0c0d04c9df670310e1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e4f64d8d50af956e24092cabb166f58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e4f64d8d50af956e24092cabb166f58.addTo(map_b24635222fe7dc0c0d04c9df670310e1);
#
#
#             var marker_187be13033df3ea39d08c9edd5d86ba3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b24635222fe7dc0c0d04c9df670310e1);
#
#
#         var popup_1d8edcc0cc29a49a6333542e08ec2664 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_721ab2db3a20dff8aed7f13274273f5b = $(`&lt;div id=&quot;html_721ab2db3a20dff8aed7f13274273f5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1d8edcc0cc29a49a6333542e08ec2664.setContent(html_721ab2db3a20dff8aed7f13274273f5b);
#
#
#
#         marker_187be13033df3ea39d08c9edd5d86ba3.bindPopup(popup_1d8edcc0cc29a49a6333542e08ec2664)
#         ;
#
#
#
#
#             var marker_514f118c51c25d82708ba8333ca299eb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b24635222fe7dc0c0d04c9df670310e1);
#
#
#         var popup_5a9645b9ca9487e1e5b642e2b69f8004 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfd4116a46b87531e038636296fc027b = $(`&lt;div id=&quot;html_cfd4116a46b87531e038636296fc027b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5a9645b9ca9487e1e5b642e2b69f8004.setContent(html_cfd4116a46b87531e038636296fc027b);
#
#
#
#         marker_514f118c51c25d82708ba8333ca299eb.bindPopup(popup_5a9645b9ca9487e1e5b642e2b69f8004)
#         ;
#
#
#
#
#             var marker_b4bbafd162423e39f7e7388846dca1ae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b24635222fe7dc0c0d04c9df670310e1);
#
#
#         var popup_558aa1bea4ae8f8891da48f737bf84c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a02d1eb66e2236b75876ad64c8141d1a = $(`&lt;div id=&quot;html_a02d1eb66e2236b75876ad64c8141d1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_558aa1bea4ae8f8891da48f737bf84c7.setContent(html_a02d1eb66e2236b75876ad64c8141d1a);
#
#
#
#         marker_b4bbafd162423e39f7e7388846dca1ae.bindPopup(popup_558aa1bea4ae8f8891da48f737bf84c7)
#         ;
#
#
#
#
#             var marker_0487b2046b41ccb0f7bf600b9ede5579 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b24635222fe7dc0c0d04c9df670310e1);
#
#
#         var popup_086cdefc208660e8fa1448fda72600eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7a6333b33cc92b29f048e193d334c0c = $(`&lt;div id=&quot;html_d7a6333b33cc92b29f048e193d334c0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_086cdefc208660e8fa1448fda72600eb.setContent(html_d7a6333b33cc92b29f048e193d334c0c);
#
#
#
#         marker_0487b2046b41ccb0f7bf600b9ede5579.bindPopup(popup_086cdefc208660e8fa1448fda72600eb)
#         ;
#
#
#
#
#             var marker_a96cd75da6f0beebf542eeac63099fa2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b24635222fe7dc0c0d04c9df670310e1);
#
#
#         var popup_87dbf0972a95a57d7350035eb6ff6f59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c05c96260c3b1f1246edffaafa995e59 = $(`&lt;div id=&quot;html_c05c96260c3b1f1246edffaafa995e59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_87dbf0972a95a57d7350035eb6ff6f59.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba7e46af15b1164066738e5282001852 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba7e46af15b1164066738e5282001852&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba7e46af15b1164066738e5282001852 = L.map(
#                 &quot;map_ba7e46af15b1164066738e5282001852&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40e8f4195a07a64f92ebc2fce31297fe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_40e8f4195a07a64f92ebc2fce31297fe.addTo(map_ba7e46af15b1164066738e5282001852);
#
#
#             var feature_group_5cc17519a5e649d01b95676fa12c7eef = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_617585ac5556339fffcb259438eb4dbf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5cc17519a5e649d01b95676fa12c7eef);
#
#
#         var popup_de9e7f62a8040b41f47c8f1a8518d94c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6092d9dae7b99bf6d9bd968f97bbe196 = $(`&lt;div id=&quot;html_6092d9dae7b99bf6d9bd968f97bbe196&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_de9e7f62a8040b41f47c8f1a8518d94c.setContent(html_6092d9dae7b99bf6d9bd968f97bbe196);
#
#
#
#         marker_617585ac5556339fffcb259438eb4dbf.bindPopup(popup_de9e7f62a8040b41f47c8f1a8518d94c)
#         ;
#
#
#
#
#             var marker_d54cfab26e12134221a2b9fbfa3cef13 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5cc17519a5e649d01b95676fa12c7eef);
#
#
#         var popup_402c22aa80fc5c9e43ffe624824c3bc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c28827231a91cc5c9e6689236e00911f = $(`&lt;div id=&quot;html_c28827231a91cc5c9e6689236e00911f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_402c22aa80fc5c9e43ffe624824c3bc4.setContent(html_c28827231a91cc5c9e6689236e00911f);
#
#
#
#         marker_d54cfab26e12134221a2b9fbfa3cef13.bindPopup(popup_402c22aa80fc5c9e43ffe624824c3bc4)
#         ;
#
#
#
#
#             var marker_8a2bd9ef41d8652c128b25f6d23694a0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5cc17519a5e649d01b95676fa12c7eef);
#
#
#         var popup_7099650e82815542978724580cfc11f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02f98843192ef8a32175dc199e70a2da = $(`&lt;div id=&quot;html_02f98843192ef8a32175dc199e70a2da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7099650e82815542978724580cfc11f4.setContent(html_02f98843192ef8a32175dc199e70a2da);
#
#
#
#         marker_8a2bd9ef41d8652c128b25f6d23694a0.bindPopup(popup_7099650e82815542978724580cfc11f4)
#         ;
#
#
#
#
#             var marker_a5e83b78a48a9925325b602c94a73fa7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5cc17519a5e649d01b95676fa12c7eef);
#
#
#         var popup_206a0ed64a9dcc1374624bbc3ff6f222 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccc0c9a0094acca405f5d9a794113b9e = $(`&lt;div id=&quot;html_ccc0c9a0094acca405f5d9a794113b9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_206a0ed64a9dcc1374624bbc3ff6f222.setContent(html_ccc0c9a0094acca405f5d9a794113b9e);
#
#
#
#         marker_a5e83b78a48a9925325b602c94a73fa7.bindPopup(popup_206a0ed64a9dcc1374624bbc3ff6f222)
#         ;
#
#
#
#
#             var marker_ecc9328b878dbf0d8a353779edda7a7f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5cc17519a5e649d01b95676fa12c7eef);
#
#
#         var popup_d268923e309792667c411505261ade4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b2bc229cf2a110f1a95dc9dd1f4ee67 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b2bc229cf2a110f1a95dc9dd1f4ee67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b2bc229cf2a110f1a95dc9dd1f4ee67 = L.map(
#                 &quot;map_4b2bc229cf2a110f1a95dc9dd1f4ee67&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64457d64c9d6f0f5165732487664ca61 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_64457d64c9d6f0f5165732487664ca61.addTo(map_4b2bc229cf2a110f1a95dc9dd1f4ee67);
#
#
#             var feature_group_7589342a40be94bfa064c44f61011b60 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7589342a40be94bfa064c44f61011b60.addTo(map_4b2bc229cf2a110f1a95dc9dd1f4ee67);
#
#
#             var feature_group_sub_group_f8bf90e1e48bf21197460e9a10eb5282 = L.featureGroup.subGroup(
#                 feature_group_7589342a40be94bfa064c44f61011b60
#             );
#
#
#             var marker_ea3e315ac8604721a25bff376d531ae0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f8bf90e1e48bf21197460e9a10eb5282);
#
#
#         var popup_d50c583d5ce8ce2b0d08f2bb49544316 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37303d2dac0d614b862f8680152c6be0 = $(`&lt;div id=&quot;html_37303d2dac0d614b862f8680152c6be0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d50c583d5ce8ce2b0d08f2bb49544316.setContent(html_37303d2dac0d614b862f8680152c6be0);
#
#
#
#         marker_ea3e315ac8604721a25bff376d531ae0.bindPopup(popup_d50c583d5ce8ce2b0d08f2bb49544316)
#         ;
#
#
#
#
#             var marker_cb965809ef318b6ae068f0c2b83484c4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f8bf90e1e48bf21197460e9a10eb5282);
#
#
#         var popup_bdf6d1fa3ff64326c4a6ce961981bb44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e71787c6e6e6082766ddfc6ffb0efc33 = $(`&lt;div id=&quot;html_e71787c6e6e6082766ddfc6ffb0efc33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bdf6d1fa3ff64326c4a6ce961981bb44.setContent(html_e71787c6e6e6082766ddfc6ffb0efc33);
#
#
#
#         marker_cb965809ef318b6ae068f0c2b83484c4.bindPopup(popup_bdf6d1fa3ff64326c4a6ce961981bb44)
#         ;
#
#
#
#
#             var marker_114e7dcc503eb83b26c1aefbe5bb1500 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f8bf90e1e48bf21197460e9a10eb5282);
#
#
#         var popup_75034c823d8840d4cb6874c1bdf5f8b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff9fa28661f72f174133fa96d1a3d8cd = $(`&lt;div id=&quot;html_ff9fa28661f72f174133fa96d1a3d8cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_75034c823d8840d4cb6874c1bdf5f8b8.setContent(html_ff9fa28661f72f174133fa96d1a3d8cd);
#
#
#
#         marker_114e7dcc503eb83b26c1aefbe5bb1500.bindPopup(popup_75034c823d8840d4cb6874c1bdf5f8b8)
#         ;
#
#
#
#
#             var marker_2f187289a3679a8ba0948c4a5f655ff2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f8bf90e1e48bf21197460e9a10eb5282);
#
#
#         var popup_57a7be3c83294165ec154066457dd26d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_955816320dde64aea7ac98151417b02c = $(`&lt;div id=&quot;html_955816320dde64aea7ac98151417b02c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_57a7be3c83294165ec154066457dd26d.setContent(html_955816320dde64aea7ac98151417b02c);
#
#
#
#         marker_
