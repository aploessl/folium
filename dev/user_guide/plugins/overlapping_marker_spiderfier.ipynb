# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_446c959c7a4e7ed4b1481d8c53447cbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_446c959c7a4e7ed4b1481d8c53447cbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_446c959c7a4e7ed4b1481d8c53447cbc = L.map(
#                 &quot;map_446c959c7a4e7ed4b1481d8c53447cbc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc7c071ccf64a14123d6213d0716daf1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dc7c071ccf64a14123d6213d0716daf1.addTo(map_446c959c7a4e7ed4b1481d8c53447cbc);
#
#
#             var marker_70896ddd5d3f94fafcc53c98e32b206d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_446c959c7a4e7ed4b1481d8c53447cbc);
#
#
#         var popup_d6bfa635c1ac4de81064bbb4b50d60f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_daa2319081f6701fba1371ce6ba323cd = $(`&lt;div id=&quot;html_daa2319081f6701fba1371ce6ba323cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d6bfa635c1ac4de81064bbb4b50d60f2.setContent(html_daa2319081f6701fba1371ce6ba323cd);
#
#
#
#         marker_70896ddd5d3f94fafcc53c98e32b206d.bindPopup(popup_d6bfa635c1ac4de81064bbb4b50d60f2)
#         ;
#
#
#
#
#             var marker_9d80f887923316f02275f39d7f69cc40 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_446c959c7a4e7ed4b1481d8c53447cbc);
#
#
#         var popup_6316d5f476e551b4be97a214673b47fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc3f6316f8079925becb4d89e39375bd = $(`&lt;div id=&quot;html_fc3f6316f8079925becb4d89e39375bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6316d5f476e551b4be97a214673b47fe.setContent(html_fc3f6316f8079925becb4d89e39375bd);
#
#
#
#         marker_9d80f887923316f02275f39d7f69cc40.bindPopup(popup_6316d5f476e551b4be97a214673b47fe)
#         ;
#
#
#
#
#             var marker_d7d406e765d74c33dbc1a73dc65ee6d2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_446c959c7a4e7ed4b1481d8c53447cbc);
#
#
#         var popup_146d984f4035b8efcb7597e8adf203b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9ae2784fc768ad2ac0e6084cfca2c7d = $(`&lt;div id=&quot;html_d9ae2784fc768ad2ac0e6084cfca2c7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_146d984f4035b8efcb7597e8adf203b6.setContent(html_d9ae2784fc768ad2ac0e6084cfca2c7d);
#
#
#
#         marker_d7d406e765d74c33dbc1a73dc65ee6d2.bindPopup(popup_146d984f4035b8efcb7597e8adf203b6)
#         ;
#
#
#
#
#             var marker_3100358151e33580778f56370577e81d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_446c959c7a4e7ed4b1481d8c53447cbc);
#
#
#         var popup_dbb294bb5dd6d161cb4e0ebe18cefd9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_252d8cb4decd9d23a2bf5199a2aa61fe = $(`&lt;div id=&quot;html_252d8cb4decd9d23a2bf5199a2aa61fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_dbb294bb5dd6d161cb4e0ebe18cefd9d.setContent(html_252d8cb4decd9d23a2bf5199a2aa61fe);
#
#
#
#         marker_3100358151e33580778f56370577e81d.bindPopup(popup_dbb294bb5dd6d161cb4e0ebe18cefd9d)
#         ;
#
#
#
#
#             var marker_a4400a7a91c7fcc8437e2f0468275101 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_446c959c7a4e7ed4b1481d8c53447cbc);
#
#
#         var popup_944f924f3c8c1b884d0e2d714f523ff1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_569fabaf9fa70c3dd263939fb110f12b = $(`&lt;div id=&quot;html_569fabaf9fa70c3dd263939fb110f12b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_944f924f3c8c1b884d0e2d714f523ff1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68d59626890633f7a1f5cb000678e240 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68d59626890633f7a1f5cb000678e240&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68d59626890633f7a1f5cb000678e240 = L.map(
#                 &quot;map_68d59626890633f7a1f5cb000678e240&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_330852d2429b076c103dee2525bf048f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_330852d2429b076c103dee2525bf048f.addTo(map_68d59626890633f7a1f5cb000678e240);
#
#
#             var feature_group_baf345a890a9671f0ddc59ebde440165 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_80ca95b564d72d4e2ac93bee25c734d4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_baf345a890a9671f0ddc59ebde440165);
#
#
#         var popup_0091f899e9c582d349cde485ab8dca3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_271121cdd33465c7ec4b3a4b905a6fea = $(`&lt;div id=&quot;html_271121cdd33465c7ec4b3a4b905a6fea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0091f899e9c582d349cde485ab8dca3a.setContent(html_271121cdd33465c7ec4b3a4b905a6fea);
#
#
#
#         marker_80ca95b564d72d4e2ac93bee25c734d4.bindPopup(popup_0091f899e9c582d349cde485ab8dca3a)
#         ;
#
#
#
#
#             var marker_efe97d1531fc10396d962866a7db7d6d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_baf345a890a9671f0ddc59ebde440165);
#
#
#         var popup_84714333eea697be072d8154ae2fd9dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28e349fc6ec69772567f5465f6eb0c90 = $(`&lt;div id=&quot;html_28e349fc6ec69772567f5465f6eb0c90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_84714333eea697be072d8154ae2fd9dd.setContent(html_28e349fc6ec69772567f5465f6eb0c90);
#
#
#
#         marker_efe97d1531fc10396d962866a7db7d6d.bindPopup(popup_84714333eea697be072d8154ae2fd9dd)
#         ;
#
#
#
#
#             var marker_3b51d56e628c88bc95ebe918bf784cc5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_baf345a890a9671f0ddc59ebde440165);
#
#
#         var popup_4b3eaeb778697a4c86ea368e7eff7fae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff94f6db0d1fdd3b375cbd551b4afabc = $(`&lt;div id=&quot;html_ff94f6db0d1fdd3b375cbd551b4afabc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4b3eaeb778697a4c86ea368e7eff7fae.setContent(html_ff94f6db0d1fdd3b375cbd551b4afabc);
#
#
#
#         marker_3b51d56e628c88bc95ebe918bf784cc5.bindPopup(popup_4b3eaeb778697a4c86ea368e7eff7fae)
#         ;
#
#
#
#
#             var marker_48889ec93f88174b04461ac4ad580bc5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_baf345a890a9671f0ddc59ebde440165);
#
#
#         var popup_af1c447633029aeeb3e7c936158c88f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe06c4c62ee0fb2f12a5eb9d84b7abc7 = $(`&lt;div id=&quot;html_fe06c4c62ee0fb2f12a5eb9d84b7abc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_af1c447633029aeeb3e7c936158c88f4.setContent(html_fe06c4c62ee0fb2f12a5eb9d84b7abc7);
#
#
#
#         marker_48889ec93f88174b04461ac4ad580bc5.bindPopup(popup_af1c447633029aeeb3e7c936158c88f4)
#         ;
#
#
#
#
#             var marker_bd9d327e8f967e288a17869a6896d93c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_baf345a890a9671f0ddc59ebde440165);
#
#
#         var popup_ee5aa9e8163acf22f0281066dd6f39d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aabca6fee27e293d5a0af01f20723395 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aabca6fee27e293d5a0af01f20723395&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aabca6fee27e293d5a0af01f20723395 = L.map(
#                 &quot;map_aabca6fee27e293d5a0af01f20723395&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a42461305ba3965b17128a2213b85a82 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a42461305ba3965b17128a2213b85a82.addTo(map_aabca6fee27e293d5a0af01f20723395);
#
#
#             var feature_group_5ae21d994ee7d1c64cacf931ac7ba1ca = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5ae21d994ee7d1c64cacf931ac7ba1ca.addTo(map_aabca6fee27e293d5a0af01f20723395);
#
#
#             var feature_group_sub_group_74c9c258c2d5387499d9fdbda2643fc3 = L.featureGroup.subGroup(
#                 feature_group_5ae21d994ee7d1c64cacf931ac7ba1ca
#             );
#
#
#             var marker_49e8fb219c78722f3b62295694e7dcd3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_74c9c258c2d5387499d9fdbda2643fc3);
#
#
#         var popup_be7206112137f30fa8a9e5fa309a8a7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_315cfde62e49e6484f7c404fb5af1139 = $(`&lt;div id=&quot;html_315cfde62e49e6484f7c404fb5af1139&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_be7206112137f30fa8a9e5fa309a8a7b.setContent(html_315cfde62e49e6484f7c404fb5af1139);
#
#
#
#         marker_49e8fb219c78722f3b62295694e7dcd3.bindPopup(popup_be7206112137f30fa8a9e5fa309a8a7b)
#         ;
#
#
#
#
#             var marker_06e3d46e956edae326512b2ebb493441 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_74c9c258c2d5387499d9fdbda2643fc3);
#
#
#         var popup_78d9613765df82be0a90a5697c99fbc1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09a9cc3f062e0841d93acc8f58d33023 = $(`&lt;div id=&quot;html_09a9cc3f062e0841d93acc8f58d33023&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_78d9613765df82be0a90a5697c99fbc1.setContent(html_09a9cc3f062e0841d93acc8f58d33023);
#
#
#
#         marker_06e3d46e956edae326512b2ebb493441.bindPopup(popup_78d9613765df82be0a90a5697c99fbc1)
#         ;
#
#
#
#
#             var marker_78afaa0266a8dd8977de4fb57246fc72 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_74c9c258c2d5387499d9fdbda2643fc3);
#
#
#         var popup_fe57e6cdadb92b6e230bf5616bac5de1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d258e3543877de887f73d6369a6bbc2 = $(`&lt;div id=&quot;html_2d258e3543877de887f73d6369a6bbc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fe57e6cdadb92b6e230bf5616bac5de1.setContent(html_2d258e3543877de887f73d6369a6bbc2);
#
#
#
#         marker_78afaa0266a8dd8977de4fb57246fc72.bindPopup(popup_fe57e6cdadb92b6e230bf5616bac5de1)
#         ;
#
#
#
#
#             var marker_e2e024b85e1c8b00cf86a5d919c05ec0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_74c9c258c2d5387499d9fdbda2643fc3);
#
#
#         var popup_a5ccc7726d4049665439329893a58fe5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71251759a48cb55bd5fe42fc057872b7 = $(`&lt;div id=&quot;html_71251759a48cb55bd5fe42fc057872b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a5ccc7726d4049665439329893a58fe5.setContent(html_71251759a48cb55bd5fe42fc057872b7);
#
#
#
#         marker_
