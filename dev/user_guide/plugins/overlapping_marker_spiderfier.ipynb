# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b504fcd2b8f227a49aabdc8bab115f30 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b504fcd2b8f227a49aabdc8bab115f30&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b504fcd2b8f227a49aabdc8bab115f30 = L.map(
#                 &quot;map_b504fcd2b8f227a49aabdc8bab115f30&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f869b8118b68bf56351402d697395b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5f869b8118b68bf56351402d697395b1.addTo(map_b504fcd2b8f227a49aabdc8bab115f30);
#
#
#             var marker_8091acce365571f8967c53a6b20bbabf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b504fcd2b8f227a49aabdc8bab115f30);
#
#
#         var popup_c0c9be722616f4d1ec8a4fd5fc6df896 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c152f7d017c7507404965578c7855045 = $(`&lt;div id=&quot;html_c152f7d017c7507404965578c7855045&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c0c9be722616f4d1ec8a4fd5fc6df896.setContent(html_c152f7d017c7507404965578c7855045);
#
#
#
#         marker_8091acce365571f8967c53a6b20bbabf.bindPopup(popup_c0c9be722616f4d1ec8a4fd5fc6df896)
#         ;
#
#
#
#
#             var marker_029759cf136a7e0d1fca1249e1d1a529 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b504fcd2b8f227a49aabdc8bab115f30);
#
#
#         var popup_4a3e30847a48f1cda53c248b866a2036 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8844fff2c737cf7d6d90ac0f9ec81688 = $(`&lt;div id=&quot;html_8844fff2c737cf7d6d90ac0f9ec81688&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4a3e30847a48f1cda53c248b866a2036.setContent(html_8844fff2c737cf7d6d90ac0f9ec81688);
#
#
#
#         marker_029759cf136a7e0d1fca1249e1d1a529.bindPopup(popup_4a3e30847a48f1cda53c248b866a2036)
#         ;
#
#
#
#
#             var marker_af7a3d8819839c36f76e5537b72e6574 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b504fcd2b8f227a49aabdc8bab115f30);
#
#
#         var popup_3e1ca82fcaefa45f1c1449519c24be5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_210518982f6c294ffbccd63f575376a2 = $(`&lt;div id=&quot;html_210518982f6c294ffbccd63f575376a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3e1ca82fcaefa45f1c1449519c24be5d.setContent(html_210518982f6c294ffbccd63f575376a2);
#
#
#
#         marker_af7a3d8819839c36f76e5537b72e6574.bindPopup(popup_3e1ca82fcaefa45f1c1449519c24be5d)
#         ;
#
#
#
#
#             var marker_df57f66a5601b436ccd906d301b5845e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b504fcd2b8f227a49aabdc8bab115f30);
#
#
#         var popup_620a97dc3d74140ddc02bb0a0deb0243 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b43d8b51eea7350f9b653b70dc6d2617 = $(`&lt;div id=&quot;html_b43d8b51eea7350f9b653b70dc6d2617&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_620a97dc3d74140ddc02bb0a0deb0243.setContent(html_b43d8b51eea7350f9b653b70dc6d2617);
#
#
#
#         marker_df57f66a5601b436ccd906d301b5845e.bindPopup(popup_620a97dc3d74140ddc02bb0a0deb0243)
#         ;
#
#
#
#
#             var marker_0cf022708be0b7d7873d1d0727508f00 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b504fcd2b8f227a49aabdc8bab115f30);
#
#
#         var popup_0135c96c0ff8efef4661dfe4812b7757 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d328d1f8f04aa5b6b0ffa5bb37cd963c = $(`&lt;div id=&quot;html_d328d1f8f04aa5b6b0ffa5bb37cd963c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0135c96c0ff8efef4661dfe4812b7757.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db3b35e44fe20ed38ee2f72af64145c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db3b35e44fe20ed38ee2f72af64145c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db3b35e44fe20ed38ee2f72af64145c6 = L.map(
#                 &quot;map_db3b35e44fe20ed38ee2f72af64145c6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e3f5c85b31e61a4faf7dccaaa2ed32f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e3f5c85b31e61a4faf7dccaaa2ed32f.addTo(map_db3b35e44fe20ed38ee2f72af64145c6);
#
#
#             var feature_group_aceebbb8ffb754e594f8f9fcba535982 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cc5ccef54e98936f43e0011219004509 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_aceebbb8ffb754e594f8f9fcba535982);
#
#
#         var popup_cd9fca73374a04ece60b6861eb88de63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2b75d86a0477f20645f2b9ca9fb0fa9 = $(`&lt;div id=&quot;html_e2b75d86a0477f20645f2b9ca9fb0fa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cd9fca73374a04ece60b6861eb88de63.setContent(html_e2b75d86a0477f20645f2b9ca9fb0fa9);
#
#
#
#         marker_cc5ccef54e98936f43e0011219004509.bindPopup(popup_cd9fca73374a04ece60b6861eb88de63)
#         ;
#
#
#
#
#             var marker_7ef7e4324a2be5c480ceade5daf5c298 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_aceebbb8ffb754e594f8f9fcba535982);
#
#
#         var popup_f23188efd005a27c5abc02e6b669cd57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f16891bb8fc0f97d937d580bed8b9bdb = $(`&lt;div id=&quot;html_f16891bb8fc0f97d937d580bed8b9bdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f23188efd005a27c5abc02e6b669cd57.setContent(html_f16891bb8fc0f97d937d580bed8b9bdb);
#
#
#
#         marker_7ef7e4324a2be5c480ceade5daf5c298.bindPopup(popup_f23188efd005a27c5abc02e6b669cd57)
#         ;
#
#
#
#
#             var marker_319777d357ed108e93a921e0eaee57e5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_aceebbb8ffb754e594f8f9fcba535982);
#
#
#         var popup_2c8d07318e1e571a88a5cd2aa6b6ec88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9caf9369d18a72bf4cf37dc983487ff = $(`&lt;div id=&quot;html_f9caf9369d18a72bf4cf37dc983487ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2c8d07318e1e571a88a5cd2aa6b6ec88.setContent(html_f9caf9369d18a72bf4cf37dc983487ff);
#
#
#
#         marker_319777d357ed108e93a921e0eaee57e5.bindPopup(popup_2c8d07318e1e571a88a5cd2aa6b6ec88)
#         ;
#
#
#
#
#             var marker_20a850b045b63203c606484ab4e3d7f2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_aceebbb8ffb754e594f8f9fcba535982);
#
#
#         var popup_9b647956914d226f2abb49d1a228975c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f68563d998b419fe9ae8e3fb8f0b8405 = $(`&lt;div id=&quot;html_f68563d998b419fe9ae8e3fb8f0b8405&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9b647956914d226f2abb49d1a228975c.setContent(html_f68563d998b419fe9ae8e3fb8f0b8405);
#
#
#
#         marker_20a850b045b63203c606484ab4e3d7f2.bindPopup(popup_9b647956914d226f2abb49d1a228975c)
#         ;
#
#
#
#
#             var marker_d8012f924c7ed5f14500ab9f36415fe0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_aceebbb8ffb754e594f8f9fcba535982);
#
#
#         var popup_d24ebec4b7017a16ebbb6ddae1bc38a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a0d1dfd10eaf2a391d27be80b6377da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a0d1dfd10eaf2a391d27be80b6377da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a0d1dfd10eaf2a391d27be80b6377da = L.map(
#                 &quot;map_6a0d1dfd10eaf2a391d27be80b6377da&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53c9741d9a7546760712e8e8de6eead2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53c9741d9a7546760712e8e8de6eead2.addTo(map_6a0d1dfd10eaf2a391d27be80b6377da);
#
#
#             var feature_group_10f409d7bcef8f9dab73b80c99699f7f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_10f409d7bcef8f9dab73b80c99699f7f.addTo(map_6a0d1dfd10eaf2a391d27be80b6377da);
#
#
#             var feature_group_sub_group_6c0a290e78a5d3784d035209bce36a20 = L.featureGroup.subGroup(
#                 feature_group_10f409d7bcef8f9dab73b80c99699f7f
#             );
#
#
#             var marker_9a2e3865d8a6d7ff219d2b4e61cbf628 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c0a290e78a5d3784d035209bce36a20);
#
#
#         var popup_37b4e39cf869ec48b6584a0b621e2f14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60a6b0d1f06cc98ce2d58c65a4ceed9d = $(`&lt;div id=&quot;html_60a6b0d1f06cc98ce2d58c65a4ceed9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_37b4e39cf869ec48b6584a0b621e2f14.setContent(html_60a6b0d1f06cc98ce2d58c65a4ceed9d);
#
#
#
#         marker_9a2e3865d8a6d7ff219d2b4e61cbf628.bindPopup(popup_37b4e39cf869ec48b6584a0b621e2f14)
#         ;
#
#
#
#
#             var marker_b04544d2a880bbe2cb4677954f43fd76 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c0a290e78a5d3784d035209bce36a20);
#
#
#         var popup_d74e7f2664205bb66f9889c16d0b16dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5edfd6499adfe97c1170f32d64d0e55 = $(`&lt;div id=&quot;html_d5edfd6499adfe97c1170f32d64d0e55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d74e7f2664205bb66f9889c16d0b16dc.setContent(html_d5edfd6499adfe97c1170f32d64d0e55);
#
#
#
#         marker_b04544d2a880bbe2cb4677954f43fd76.bindPopup(popup_d74e7f2664205bb66f9889c16d0b16dc)
#         ;
#
#
#
#
#             var marker_9059404eea49f9ef39024fae85df8954 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c0a290e78a5d3784d035209bce36a20);
#
#
#         var popup_1388b3b5a0818b58c2c798f829afa7e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f1ab881025c6a37794e9adfb77cdd24 = $(`&lt;div id=&quot;html_6f1ab881025c6a37794e9adfb77cdd24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1388b3b5a0818b58c2c798f829afa7e0.setContent(html_6f1ab881025c6a37794e9adfb77cdd24);
#
#
#
#         marker_9059404eea49f9ef39024fae85df8954.bindPopup(popup_1388b3b5a0818b58c2c798f829afa7e0)
#         ;
#
#
#
#
#             var marker_29bd18658f96315c348e121a2119111a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c0a290e78a5d3784d035209bce36a20);
#
#
#         var popup_a77d666f6ba8787f1c14af723fe56908 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f11726898a027c8997fee9658cfdc9c = $(`&lt;div id=&quot;html_1f11726898a027c8997fee9658cfdc9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a77d666f6ba8787f1c14af723fe56908.setContent(html_1f11726898a027c8997fee9658cfdc9c);
#
#
#
#         marker_
