# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cf1f0b1a05b701e1a8d42a88d978bc6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cf1f0b1a05b701e1a8d42a88d978bc6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cf1f0b1a05b701e1a8d42a88d978bc6 = L.map(
#                 &quot;map_1cf1f0b1a05b701e1a8d42a88d978bc6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a8bf2fadafe7d1fc2d143bf60b45d4c0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a8bf2fadafe7d1fc2d143bf60b45d4c0.addTo(map_1cf1f0b1a05b701e1a8d42a88d978bc6);
#
#
#             var marker_a4800c2017efc63285d8588cc70fa204 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1cf1f0b1a05b701e1a8d42a88d978bc6);
#
#
#         var popup_629e7a230bebe217b7ec9c1c25e58a3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_173d1c7463b94d086d935fb52b26e4cc = $(`&lt;div id=&quot;html_173d1c7463b94d086d935fb52b26e4cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_629e7a230bebe217b7ec9c1c25e58a3c.setContent(html_173d1c7463b94d086d935fb52b26e4cc);
#
#
#
#         marker_a4800c2017efc63285d8588cc70fa204.bindPopup(popup_629e7a230bebe217b7ec9c1c25e58a3c)
#         ;
#
#
#
#
#             var marker_168ed1aca940707abe5b2c0372e6cf16 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1cf1f0b1a05b701e1a8d42a88d978bc6);
#
#
#         var popup_939a0348f424c84296f2bddd9d5bc6f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_712b55bda3044a056544858a12513255 = $(`&lt;div id=&quot;html_712b55bda3044a056544858a12513255&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_939a0348f424c84296f2bddd9d5bc6f5.setContent(html_712b55bda3044a056544858a12513255);
#
#
#
#         marker_168ed1aca940707abe5b2c0372e6cf16.bindPopup(popup_939a0348f424c84296f2bddd9d5bc6f5)
#         ;
#
#
#
#
#             var marker_025b9e90bd5d6b8f818127b42600e13f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1cf1f0b1a05b701e1a8d42a88d978bc6);
#
#
#         var popup_8157f34ff1ab6d182338081bb61cf1e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef16eb23407877062b27b330ca3eaf91 = $(`&lt;div id=&quot;html_ef16eb23407877062b27b330ca3eaf91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8157f34ff1ab6d182338081bb61cf1e6.setContent(html_ef16eb23407877062b27b330ca3eaf91);
#
#
#
#         marker_025b9e90bd5d6b8f818127b42600e13f.bindPopup(popup_8157f34ff1ab6d182338081bb61cf1e6)
#         ;
#
#
#
#
#             var marker_63490fcf9a31b7b98aee177b7c3ad1bf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1cf1f0b1a05b701e1a8d42a88d978bc6);
#
#
#         var popup_f5716c4dd5cacf1145106ed5e3848439 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd1b89a3d8f010ecd4954645e3aee23c = $(`&lt;div id=&quot;html_dd1b89a3d8f010ecd4954645e3aee23c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f5716c4dd5cacf1145106ed5e3848439.setContent(html_dd1b89a3d8f010ecd4954645e3aee23c);
#
#
#
#         marker_63490fcf9a31b7b98aee177b7c3ad1bf.bindPopup(popup_f5716c4dd5cacf1145106ed5e3848439)
#         ;
#
#
#
#
#             var marker_32b61284bec5bf1e914166ffd8434ecc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1cf1f0b1a05b701e1a8d42a88d978bc6);
#
#
#         var popup_310269674667ac2e830ebe82ebde6c6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a17524ae5365afdc3d98ff816b34aaed = $(`&lt;div id=&quot;html_a17524ae5365afdc3d98ff816b34aaed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_310269674667ac2e830ebe82ebde6c6a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83976d73e8d04cdb361b93b3c69a69b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83976d73e8d04cdb361b93b3c69a69b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83976d73e8d04cdb361b93b3c69a69b2 = L.map(
#                 &quot;map_83976d73e8d04cdb361b93b3c69a69b2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_353c19a0517539d3aec0a6afd4168d2c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_353c19a0517539d3aec0a6afd4168d2c.addTo(map_83976d73e8d04cdb361b93b3c69a69b2);
#
#
#             var feature_group_ed3ea1230f6f6f17940522ca07ba4ea4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c3ec531a2a5a1dc5c700b756c537d265 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ed3ea1230f6f6f17940522ca07ba4ea4);
#
#
#         var popup_70672ce177dd66aea1c99c6204ea386d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d0c3456897c0cf87c1e24e3a2c9e209 = $(`&lt;div id=&quot;html_0d0c3456897c0cf87c1e24e3a2c9e209&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_70672ce177dd66aea1c99c6204ea386d.setContent(html_0d0c3456897c0cf87c1e24e3a2c9e209);
#
#
#
#         marker_c3ec531a2a5a1dc5c700b756c537d265.bindPopup(popup_70672ce177dd66aea1c99c6204ea386d)
#         ;
#
#
#
#
#             var marker_3f83316d8923ffec96b895c285c35dd7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ed3ea1230f6f6f17940522ca07ba4ea4);
#
#
#         var popup_c9495bad2aacdec968a463d76f59a1fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a0b4b0854573cce08f923ec66dbb80c = $(`&lt;div id=&quot;html_0a0b4b0854573cce08f923ec66dbb80c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c9495bad2aacdec968a463d76f59a1fc.setContent(html_0a0b4b0854573cce08f923ec66dbb80c);
#
#
#
#         marker_3f83316d8923ffec96b895c285c35dd7.bindPopup(popup_c9495bad2aacdec968a463d76f59a1fc)
#         ;
#
#
#
#
#             var marker_df14546fe5b78834961db9bbc4daf6c3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ed3ea1230f6f6f17940522ca07ba4ea4);
#
#
#         var popup_29cc14a7cf63aecfda9a07a714414377 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3596d2af3aea3c98050e024b265c6944 = $(`&lt;div id=&quot;html_3596d2af3aea3c98050e024b265c6944&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_29cc14a7cf63aecfda9a07a714414377.setContent(html_3596d2af3aea3c98050e024b265c6944);
#
#
#
#         marker_df14546fe5b78834961db9bbc4daf6c3.bindPopup(popup_29cc14a7cf63aecfda9a07a714414377)
#         ;
#
#
#
#
#             var marker_bfe729fcfa1ee87c7fccdf2766153faf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ed3ea1230f6f6f17940522ca07ba4ea4);
#
#
#         var popup_0fb708b56dde9c063fe81d33b676df5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_166f2dfd41003fcbc701359537030ecd = $(`&lt;div id=&quot;html_166f2dfd41003fcbc701359537030ecd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0fb708b56dde9c063fe81d33b676df5a.setContent(html_166f2dfd41003fcbc701359537030ecd);
#
#
#
#         marker_bfe729fcfa1ee87c7fccdf2766153faf.bindPopup(popup_0fb708b56dde9c063fe81d33b676df5a)
#         ;
#
#
#
#
#             var marker_5475eb0a396dd1064be14ac4931f45a4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ed3ea1230f6f6f17940522ca07ba4ea4);
#
#
#         var popup_cd76c291b953be054ae8a24d669f13ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5d6f184d8e0dd992f4ebc9f1cdc00e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5d6f184d8e0dd992f4ebc9f1cdc00e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5d6f184d8e0dd992f4ebc9f1cdc00e3 = L.map(
#                 &quot;map_b5d6f184d8e0dd992f4ebc9f1cdc00e3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae3883e3aa3bded663903225e88ec87c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ae3883e3aa3bded663903225e88ec87c.addTo(map_b5d6f184d8e0dd992f4ebc9f1cdc00e3);
#
#
#             var feature_group_babe9a762f97a3e1da26718404706391 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_babe9a762f97a3e1da26718404706391.addTo(map_b5d6f184d8e0dd992f4ebc9f1cdc00e3);
#
#
#             var feature_group_sub_group_c351888761597a0ef608f1c51fbdc78b = L.featureGroup.subGroup(
#                 feature_group_babe9a762f97a3e1da26718404706391
#             );
#
#
#             var marker_fc9379caa55bbf151eec8964899dce7b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c351888761597a0ef608f1c51fbdc78b);
#
#
#         var popup_82581ed80405807afba484574ce0f118 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1a6ad2210d85105012bdae3579a69c8 = $(`&lt;div id=&quot;html_b1a6ad2210d85105012bdae3579a69c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_82581ed80405807afba484574ce0f118.setContent(html_b1a6ad2210d85105012bdae3579a69c8);
#
#
#
#         marker_fc9379caa55bbf151eec8964899dce7b.bindPopup(popup_82581ed80405807afba484574ce0f118)
#         ;
#
#
#
#
#             var marker_2579452ff04a22856c4be66ddb7f5390 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c351888761597a0ef608f1c51fbdc78b);
#
#
#         var popup_f6be839ce335d328d72ebcee2952c45b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abc09a258355645f7a316d3dc799a931 = $(`&lt;div id=&quot;html_abc09a258355645f7a316d3dc799a931&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f6be839ce335d328d72ebcee2952c45b.setContent(html_abc09a258355645f7a316d3dc799a931);
#
#
#
#         marker_2579452ff04a22856c4be66ddb7f5390.bindPopup(popup_f6be839ce335d328d72ebcee2952c45b)
#         ;
#
#
#
#
#             var marker_f5551ca2db65ff585a2595d659d4be0a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c351888761597a0ef608f1c51fbdc78b);
#
#
#         var popup_702c8bbb15a076641142454523e0e629 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dbe2f685223b7ded74bf5d722617890 = $(`&lt;div id=&quot;html_9dbe2f685223b7ded74bf5d722617890&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_702c8bbb15a076641142454523e0e629.setContent(html_9dbe2f685223b7ded74bf5d722617890);
#
#
#
#         marker_f5551ca2db65ff585a2595d659d4be0a.bindPopup(popup_702c8bbb15a076641142454523e0e629)
#         ;
#
#
#
#
#             var marker_8a6c25cc6a43f4c712f24d2fe177e0f6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c351888761597a0ef608f1c51fbdc78b);
#
#
#         var popup_ca116bf0b65bbcbf8c02f8c5697f7405 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4ba7ab3603b6d9a63ec2be72c6a7685 = $(`&lt;div id=&quot;html_f4ba7ab3603b6d9a63ec2be72c6a7685&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ca116bf0b65bbcbf8c02f8c5697f7405.setContent(html_f4ba7ab3603b6d9a63ec2be72c6a7685);
#
#
#
#         marker_
