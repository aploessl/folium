# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e1e92b3c93d36c7ab9b127d8b3349d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e1e92b3c93d36c7ab9b127d8b3349d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e1e92b3c93d36c7ab9b127d8b3349d2 = L.map(
#                 &quot;map_8e1e92b3c93d36c7ab9b127d8b3349d2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d472226d6069e110735101dd640aadc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d472226d6069e110735101dd640aadc3.addTo(map_8e1e92b3c93d36c7ab9b127d8b3349d2);
#
#
#             var marker_7fb8e338f1718b68f2bbd3109e481fb6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8e1e92b3c93d36c7ab9b127d8b3349d2);
#
#
#         var popup_81d534e64be6b2615b7e8cf900a9450b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c80cccf143d664b169cf8f9586e8d59 = $(`&lt;div id=&quot;html_3c80cccf143d664b169cf8f9586e8d59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_81d534e64be6b2615b7e8cf900a9450b.setContent(html_3c80cccf143d664b169cf8f9586e8d59);
#
#
#
#         marker_7fb8e338f1718b68f2bbd3109e481fb6.bindPopup(popup_81d534e64be6b2615b7e8cf900a9450b)
#         ;
#
#
#
#
#             var marker_472c00a91e16c08fe5606d2a518cdf01 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8e1e92b3c93d36c7ab9b127d8b3349d2);
#
#
#         var popup_8a1aae8dbc16ba459731d621b1c6a88f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16d62d0af677b7c2cd21d2b4c4927223 = $(`&lt;div id=&quot;html_16d62d0af677b7c2cd21d2b4c4927223&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8a1aae8dbc16ba459731d621b1c6a88f.setContent(html_16d62d0af677b7c2cd21d2b4c4927223);
#
#
#
#         marker_472c00a91e16c08fe5606d2a518cdf01.bindPopup(popup_8a1aae8dbc16ba459731d621b1c6a88f)
#         ;
#
#
#
#
#             var marker_24d2650481e09beedc8dba14dcb54d8a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8e1e92b3c93d36c7ab9b127d8b3349d2);
#
#
#         var popup_214d0e150cd081ff1733a0538fa929dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71701a6120359b4105e2c571db0138dd = $(`&lt;div id=&quot;html_71701a6120359b4105e2c571db0138dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_214d0e150cd081ff1733a0538fa929dd.setContent(html_71701a6120359b4105e2c571db0138dd);
#
#
#
#         marker_24d2650481e09beedc8dba14dcb54d8a.bindPopup(popup_214d0e150cd081ff1733a0538fa929dd)
#         ;
#
#
#
#
#             var marker_f286b7a5f5d04c7697ee72b33b027e22 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8e1e92b3c93d36c7ab9b127d8b3349d2);
#
#
#         var popup_e508a1e096b95d42c72ed1cb4e6d660a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5519b7c0484b30c9f7337a090eb7f5e4 = $(`&lt;div id=&quot;html_5519b7c0484b30c9f7337a090eb7f5e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e508a1e096b95d42c72ed1cb4e6d660a.setContent(html_5519b7c0484b30c9f7337a090eb7f5e4);
#
#
#
#         marker_f286b7a5f5d04c7697ee72b33b027e22.bindPopup(popup_e508a1e096b95d42c72ed1cb4e6d660a)
#         ;
#
#
#
#
#             var marker_b303002ddbc09711584edc018756452a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8e1e92b3c93d36c7ab9b127d8b3349d2);
#
#
#         var popup_f26431cdb6f3773efc8b4de433ee9fe4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7552f17a3229630243cac20dd9057bb6 = $(`&lt;div id=&quot;html_7552f17a3229630243cac20dd9057bb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f26431cdb6f3773efc8b4de433ee9fe4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_008a07af3f7bb983e838b7eb49947319 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_008a07af3f7bb983e838b7eb49947319&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_008a07af3f7bb983e838b7eb49947319 = L.map(
#                 &quot;map_008a07af3f7bb983e838b7eb49947319&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f5e0a06c44868c40a282e9d25b4ed6f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f5e0a06c44868c40a282e9d25b4ed6f.addTo(map_008a07af3f7bb983e838b7eb49947319);
#
#
#             var feature_group_950844e4a146842ccdac324aa0312836 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3ec6541e377c13c039ad446c5aa748b2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_950844e4a146842ccdac324aa0312836);
#
#
#         var popup_f45be0ac7bde0496be487aace5505755 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2767af33dda319229fe1090a1415856 = $(`&lt;div id=&quot;html_d2767af33dda319229fe1090a1415856&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f45be0ac7bde0496be487aace5505755.setContent(html_d2767af33dda319229fe1090a1415856);
#
#
#
#         marker_3ec6541e377c13c039ad446c5aa748b2.bindPopup(popup_f45be0ac7bde0496be487aace5505755)
#         ;
#
#
#
#
#             var marker_077c43d3cb514175251ddf1ebdd252bd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_950844e4a146842ccdac324aa0312836);
#
#
#         var popup_0b91b327baa7250bc72201abd24e3486 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb7aa6932d91fe6e5f32daa1dac44468 = $(`&lt;div id=&quot;html_bb7aa6932d91fe6e5f32daa1dac44468&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0b91b327baa7250bc72201abd24e3486.setContent(html_bb7aa6932d91fe6e5f32daa1dac44468);
#
#
#
#         marker_077c43d3cb514175251ddf1ebdd252bd.bindPopup(popup_0b91b327baa7250bc72201abd24e3486)
#         ;
#
#
#
#
#             var marker_e14caecee4a82575d6d8987eaf63d6c7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_950844e4a146842ccdac324aa0312836);
#
#
#         var popup_68a5c2603f5fd6363a7a0989b422f308 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57dc7583abaf2bfeb4aed6752c7c803c = $(`&lt;div id=&quot;html_57dc7583abaf2bfeb4aed6752c7c803c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_68a5c2603f5fd6363a7a0989b422f308.setContent(html_57dc7583abaf2bfeb4aed6752c7c803c);
#
#
#
#         marker_e14caecee4a82575d6d8987eaf63d6c7.bindPopup(popup_68a5c2603f5fd6363a7a0989b422f308)
#         ;
#
#
#
#
#             var marker_08a5a1a1aa3eff2bc48a379d6740f3ba = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_950844e4a146842ccdac324aa0312836);
#
#
#         var popup_8139fad4577437cd46b71a05c1e4642a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_596400658e91185322a0b2e7211e33ed = $(`&lt;div id=&quot;html_596400658e91185322a0b2e7211e33ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8139fad4577437cd46b71a05c1e4642a.setContent(html_596400658e91185322a0b2e7211e33ed);
#
#
#
#         marker_08a5a1a1aa3eff2bc48a379d6740f3ba.bindPopup(popup_8139fad4577437cd46b71a05c1e4642a)
#         ;
#
#
#
#
#             var marker_77da7d61ba856f9a641085ae7bafd03e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_950844e4a146842ccdac324aa0312836);
#
#
#         var popup_7c1f0ab301b69a5fdf9ff645b8d826a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eab8ffce9202f9a6fa17fe084114b1d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eab8ffce9202f9a6fa17fe084114b1d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eab8ffce9202f9a6fa17fe084114b1d8 = L.map(
#                 &quot;map_eab8ffce9202f9a6fa17fe084114b1d8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d24bab802d593528b23e9967ebe8eb1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6d24bab802d593528b23e9967ebe8eb1.addTo(map_eab8ffce9202f9a6fa17fe084114b1d8);
#
#
#             var feature_group_6fc84841c8989bdae92055e5ba33a95c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6fc84841c8989bdae92055e5ba33a95c.addTo(map_eab8ffce9202f9a6fa17fe084114b1d8);
#
#
#             var feature_group_sub_group_5dd550f233f0e7b2cb41be8097ea3608 = L.featureGroup.subGroup(
#                 feature_group_6fc84841c8989bdae92055e5ba33a95c
#             );
#
#
#             var marker_dcd79cbee7593ae77a089788c266f82d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5dd550f233f0e7b2cb41be8097ea3608);
#
#
#         var popup_917b85928397029ed13753485a31aaa2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b60f85f4e7fcf56bd7e7c6376f9caff7 = $(`&lt;div id=&quot;html_b60f85f4e7fcf56bd7e7c6376f9caff7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_917b85928397029ed13753485a31aaa2.setContent(html_b60f85f4e7fcf56bd7e7c6376f9caff7);
#
#
#
#         marker_dcd79cbee7593ae77a089788c266f82d.bindPopup(popup_917b85928397029ed13753485a31aaa2)
#         ;
#
#
#
#
#             var marker_4ab80c3adb4565a704c64345f51c548c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5dd550f233f0e7b2cb41be8097ea3608);
#
#
#         var popup_3b6aaeabcfe7785deb345ac925d41220 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c35b16730238427fbbc5056829ad18d0 = $(`&lt;div id=&quot;html_c35b16730238427fbbc5056829ad18d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3b6aaeabcfe7785deb345ac925d41220.setContent(html_c35b16730238427fbbc5056829ad18d0);
#
#
#
#         marker_4ab80c3adb4565a704c64345f51c548c.bindPopup(popup_3b6aaeabcfe7785deb345ac925d41220)
#         ;
#
#
#
#
#             var marker_6188e2a5776405d0bca76afc2601f2c9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5dd550f233f0e7b2cb41be8097ea3608);
#
#
#         var popup_cfdb52f8d450cebaa12866d4b2394367 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f87216aaecd8ed572d81c6d6c795d9d = $(`&lt;div id=&quot;html_0f87216aaecd8ed572d81c6d6c795d9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_cfdb52f8d450cebaa12866d4b2394367.setContent(html_0f87216aaecd8ed572d81c6d6c795d9d);
#
#
#
#         marker_6188e2a5776405d0bca76afc2601f2c9.bindPopup(popup_cfdb52f8d450cebaa12866d4b2394367)
#         ;
#
#
#
#
#             var marker_76ddee901afa497925231da5fb097496 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5dd550f233f0e7b2cb41be8097ea3608);
#
#
#         var popup_f6b3c8e9e034fbc68a0ee9b28769c65a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_267c646732637f4db341885b4391d528 = $(`&lt;div id=&quot;html_267c646732637f4db341885b4391d528&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f6b3c8e9e034fbc68a0ee9b28769c65a.setContent(html_267c646732637f4db341885b4391d528);
#
#
#
#         marker_
