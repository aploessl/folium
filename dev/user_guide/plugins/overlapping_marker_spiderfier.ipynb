# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ce6e2050793a7e237adb0671a7ba15a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ce6e2050793a7e237adb0671a7ba15a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ce6e2050793a7e237adb0671a7ba15a = L.map(
#                 &quot;map_0ce6e2050793a7e237adb0671a7ba15a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7319c1b82689fad659ae1d3d864fc592 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7319c1b82689fad659ae1d3d864fc592.addTo(map_0ce6e2050793a7e237adb0671a7ba15a);
#
#
#             var marker_fc06ffb2aa33c20c165a37a7b0c7e46f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0ce6e2050793a7e237adb0671a7ba15a);
#
#
#         var popup_a0329f19010a6fe50ef05c6ef117216d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3be292ccc52e5ba5d1b373126bf8a2e = $(`&lt;div id=&quot;html_d3be292ccc52e5ba5d1b373126bf8a2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a0329f19010a6fe50ef05c6ef117216d.setContent(html_d3be292ccc52e5ba5d1b373126bf8a2e);
#
#
#
#         marker_fc06ffb2aa33c20c165a37a7b0c7e46f.bindPopup(popup_a0329f19010a6fe50ef05c6ef117216d)
#         ;
#
#
#
#
#             var marker_421af2412af53ef13519a3a432ee7f38 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0ce6e2050793a7e237adb0671a7ba15a);
#
#
#         var popup_c1f405040920405e3a0c2ec992321cae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eae2d4b0859fe723d7add25075b21bc9 = $(`&lt;div id=&quot;html_eae2d4b0859fe723d7add25075b21bc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c1f405040920405e3a0c2ec992321cae.setContent(html_eae2d4b0859fe723d7add25075b21bc9);
#
#
#
#         marker_421af2412af53ef13519a3a432ee7f38.bindPopup(popup_c1f405040920405e3a0c2ec992321cae)
#         ;
#
#
#
#
#             var marker_ba88084640fe0bf2ca306e772203fada = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0ce6e2050793a7e237adb0671a7ba15a);
#
#
#         var popup_e50c5ad08a429f38fe198ea9813c000e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2c58e9eedf54d12d302ea7e6b27f290 = $(`&lt;div id=&quot;html_f2c58e9eedf54d12d302ea7e6b27f290&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e50c5ad08a429f38fe198ea9813c000e.setContent(html_f2c58e9eedf54d12d302ea7e6b27f290);
#
#
#
#         marker_ba88084640fe0bf2ca306e772203fada.bindPopup(popup_e50c5ad08a429f38fe198ea9813c000e)
#         ;
#
#
#
#
#             var marker_c09f7642c4d053730325cd4ffd8f040c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0ce6e2050793a7e237adb0671a7ba15a);
#
#
#         var popup_ff029b5247b3feb4acd21bc2a6ffbe3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e96abbbb1f70d07e70422d6b6d7cd109 = $(`&lt;div id=&quot;html_e96abbbb1f70d07e70422d6b6d7cd109&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ff029b5247b3feb4acd21bc2a6ffbe3c.setContent(html_e96abbbb1f70d07e70422d6b6d7cd109);
#
#
#
#         marker_c09f7642c4d053730325cd4ffd8f040c.bindPopup(popup_ff029b5247b3feb4acd21bc2a6ffbe3c)
#         ;
#
#
#
#
#             var marker_0c46556d038b02f81f0406dbb8bec843 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0ce6e2050793a7e237adb0671a7ba15a);
#
#
#         var popup_0bf96952f3056b19e7145301cbc9deea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_108ddb5401106c715682902f6476ee1d = $(`&lt;div id=&quot;html_108ddb5401106c715682902f6476ee1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0bf96952f3056b19e7145301cbc9deea.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0955461b0fa2ed225d2d3935fd5e6eac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0955461b0fa2ed225d2d3935fd5e6eac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0955461b0fa2ed225d2d3935fd5e6eac = L.map(
#                 &quot;map_0955461b0fa2ed225d2d3935fd5e6eac&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07a0fbf8a077e5d5dde5dcaa49cba992 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07a0fbf8a077e5d5dde5dcaa49cba992.addTo(map_0955461b0fa2ed225d2d3935fd5e6eac);
#
#
#             var feature_group_a46e19487ce82cb17460340d314cadc3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5b786363c96941da0ac04db31daa7e30 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a46e19487ce82cb17460340d314cadc3);
#
#
#         var popup_806bac1f820bb438970bcaebefe95570 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86bb3d102a78587d001127fb98284c39 = $(`&lt;div id=&quot;html_86bb3d102a78587d001127fb98284c39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_806bac1f820bb438970bcaebefe95570.setContent(html_86bb3d102a78587d001127fb98284c39);
#
#
#
#         marker_5b786363c96941da0ac04db31daa7e30.bindPopup(popup_806bac1f820bb438970bcaebefe95570)
#         ;
#
#
#
#
#             var marker_28f0d4e851c1f4e0ae91ebc0b862bce7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a46e19487ce82cb17460340d314cadc3);
#
#
#         var popup_222375ba4cb33a259f6dd9ef6ce35992 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_630cbd81ba9aa68e0be8ff4c3e0e78f7 = $(`&lt;div id=&quot;html_630cbd81ba9aa68e0be8ff4c3e0e78f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_222375ba4cb33a259f6dd9ef6ce35992.setContent(html_630cbd81ba9aa68e0be8ff4c3e0e78f7);
#
#
#
#         marker_28f0d4e851c1f4e0ae91ebc0b862bce7.bindPopup(popup_222375ba4cb33a259f6dd9ef6ce35992)
#         ;
#
#
#
#
#             var marker_f366f9c59676b28de365e7b1bd7bf058 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a46e19487ce82cb17460340d314cadc3);
#
#
#         var popup_a32ffcd31119dd6a0a60cdedf76457c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a30c16539e68bc3d72e12ee21fea9926 = $(`&lt;div id=&quot;html_a30c16539e68bc3d72e12ee21fea9926&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a32ffcd31119dd6a0a60cdedf76457c8.setContent(html_a30c16539e68bc3d72e12ee21fea9926);
#
#
#
#         marker_f366f9c59676b28de365e7b1bd7bf058.bindPopup(popup_a32ffcd31119dd6a0a60cdedf76457c8)
#         ;
#
#
#
#
#             var marker_a27fdf3c81142e0e168096ee7e06fcc2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a46e19487ce82cb17460340d314cadc3);
#
#
#         var popup_76083bba94ec0647d1224044ccededfb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fabb1bb70a4a5642977c51b99d6a897 = $(`&lt;div id=&quot;html_3fabb1bb70a4a5642977c51b99d6a897&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_76083bba94ec0647d1224044ccededfb.setContent(html_3fabb1bb70a4a5642977c51b99d6a897);
#
#
#
#         marker_a27fdf3c81142e0e168096ee7e06fcc2.bindPopup(popup_76083bba94ec0647d1224044ccededfb)
#         ;
#
#
#
#
#             var marker_b8b7e203e085b15ce21d39847913a5b6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a46e19487ce82cb17460340d314cadc3);
#
#
#         var popup_a349881586e3fae7000f5fc5f724b19a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_471d8feaa3ed12b6fdbe5d7e7d8e7acd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_471d8feaa3ed12b6fdbe5d7e7d8e7acd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_471d8feaa3ed12b6fdbe5d7e7d8e7acd = L.map(
#                 &quot;map_471d8feaa3ed12b6fdbe5d7e7d8e7acd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58dd806517fd8f424b8b1db8d542a708 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_58dd806517fd8f424b8b1db8d542a708.addTo(map_471d8feaa3ed12b6fdbe5d7e7d8e7acd);
#
#
#             var feature_group_bc0016da8bf1aae110854b188fff5cd1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bc0016da8bf1aae110854b188fff5cd1.addTo(map_471d8feaa3ed12b6fdbe5d7e7d8e7acd);
#
#
#             var feature_group_sub_group_56cc2f5bef38142d468db7878d684ae8 = L.featureGroup.subGroup(
#                 feature_group_bc0016da8bf1aae110854b188fff5cd1
#             );
#
#
#             var marker_c07d90b2e0d6b068a05f12ca605f95cd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_56cc2f5bef38142d468db7878d684ae8);
#
#
#         var popup_79ea95226a424ab0d7683b6a6f4d41a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39bd1c05308fd7ceafa48bc036ffe0d5 = $(`&lt;div id=&quot;html_39bd1c05308fd7ceafa48bc036ffe0d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_79ea95226a424ab0d7683b6a6f4d41a9.setContent(html_39bd1c05308fd7ceafa48bc036ffe0d5);
#
#
#
#         marker_c07d90b2e0d6b068a05f12ca605f95cd.bindPopup(popup_79ea95226a424ab0d7683b6a6f4d41a9)
#         ;
#
#
#
#
#             var marker_2a59ab4959d4e9b0beacdb05b12f9a66 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_56cc2f5bef38142d468db7878d684ae8);
#
#
#         var popup_9fc8b29bb257a49393f837eafb9a4e5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_872b04957ed71af4c57366b988205a21 = $(`&lt;div id=&quot;html_872b04957ed71af4c57366b988205a21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9fc8b29bb257a49393f837eafb9a4e5f.setContent(html_872b04957ed71af4c57366b988205a21);
#
#
#
#         marker_2a59ab4959d4e9b0beacdb05b12f9a66.bindPopup(popup_9fc8b29bb257a49393f837eafb9a4e5f)
#         ;
#
#
#
#
#             var marker_2dd81e636dadc711b8c3325055574e46 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_56cc2f5bef38142d468db7878d684ae8);
#
#
#         var popup_085f0583638c6f86bd1b4efc713f3fb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67c05c86e2a491be7d054431446a822f = $(`&lt;div id=&quot;html_67c05c86e2a491be7d054431446a822f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_085f0583638c6f86bd1b4efc713f3fb5.setContent(html_67c05c86e2a491be7d054431446a822f);
#
#
#
#         marker_2dd81e636dadc711b8c3325055574e46.bindPopup(popup_085f0583638c6f86bd1b4efc713f3fb5)
#         ;
#
#
#
#
#             var marker_92bbc4905608c3f18fab4eee78b7c012 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_56cc2f5bef38142d468db7878d684ae8);
#
#
#         var popup_7d459c23bfcb98a6715ddef7417760a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14884c552d2e825aa6201e3506981d0e = $(`&lt;div id=&quot;html_14884c552d2e825aa6201e3506981d0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7d459c23bfcb98a6715ddef7417760a0.setContent(html_14884c552d2e825aa6201e3506981d0e);
#
#
#
#         marker_
