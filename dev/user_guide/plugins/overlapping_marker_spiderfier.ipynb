# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe4f4570d063e252f95a79a1ec574587 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe4f4570d063e252f95a79a1ec574587&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe4f4570d063e252f95a79a1ec574587 = L.map(
#                 &quot;map_fe4f4570d063e252f95a79a1ec574587&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce450d5275f2163db13c9478bae3149b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce450d5275f2163db13c9478bae3149b.addTo(map_fe4f4570d063e252f95a79a1ec574587);
#
#
#             var marker_1c1fb4249a346cd4cea41975af214321 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fe4f4570d063e252f95a79a1ec574587);
#
#
#         var popup_efecf039c1acf85c3ec1b626974f680a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5cc2189663d904eb3a9566abb31f2573 = $(`&lt;div id=&quot;html_5cc2189663d904eb3a9566abb31f2573&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_efecf039c1acf85c3ec1b626974f680a.setContent(html_5cc2189663d904eb3a9566abb31f2573);
#
#
#
#         marker_1c1fb4249a346cd4cea41975af214321.bindPopup(popup_efecf039c1acf85c3ec1b626974f680a)
#         ;
#
#
#
#
#             var marker_d0ba01d1bb50a77dfe6d97d250b35b65 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fe4f4570d063e252f95a79a1ec574587);
#
#
#         var popup_8f5d046c473bd00646648d8236c7ae07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e0f124008f5fb7fa4c4d279d38275e2 = $(`&lt;div id=&quot;html_6e0f124008f5fb7fa4c4d279d38275e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8f5d046c473bd00646648d8236c7ae07.setContent(html_6e0f124008f5fb7fa4c4d279d38275e2);
#
#
#
#         marker_d0ba01d1bb50a77dfe6d97d250b35b65.bindPopup(popup_8f5d046c473bd00646648d8236c7ae07)
#         ;
#
#
#
#
#             var marker_0ea4cf75979592a9530a7c341939bcc5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fe4f4570d063e252f95a79a1ec574587);
#
#
#         var popup_38fb9a85687318e47ae4ec6d7ea7e269 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a29b6235832f47f7db44ab593cd5f8f = $(`&lt;div id=&quot;html_7a29b6235832f47f7db44ab593cd5f8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_38fb9a85687318e47ae4ec6d7ea7e269.setContent(html_7a29b6235832f47f7db44ab593cd5f8f);
#
#
#
#         marker_0ea4cf75979592a9530a7c341939bcc5.bindPopup(popup_38fb9a85687318e47ae4ec6d7ea7e269)
#         ;
#
#
#
#
#             var marker_79116f0c1a4b648663f2e6cfd93e37a2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fe4f4570d063e252f95a79a1ec574587);
#
#
#         var popup_855c0fdac571bec7332fc614858ccb59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ab2a7fa52127aa28fe8f9483cd1e9d1 = $(`&lt;div id=&quot;html_6ab2a7fa52127aa28fe8f9483cd1e9d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_855c0fdac571bec7332fc614858ccb59.setContent(html_6ab2a7fa52127aa28fe8f9483cd1e9d1);
#
#
#
#         marker_79116f0c1a4b648663f2e6cfd93e37a2.bindPopup(popup_855c0fdac571bec7332fc614858ccb59)
#         ;
#
#
#
#
#             var marker_5853cef6bd5f40da47b2e95952d17a18 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fe4f4570d063e252f95a79a1ec574587);
#
#
#         var popup_bc6e7e4315cf582a6cdbe218ebe3c52c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4eedf4ac69bfe6bb93e26f8047c2409e = $(`&lt;div id=&quot;html_4eedf4ac69bfe6bb93e26f8047c2409e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bc6e7e4315cf582a6cdbe218ebe3c52c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc5051a756ae7482aaaed88b11e61039 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc5051a756ae7482aaaed88b11e61039&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc5051a756ae7482aaaed88b11e61039 = L.map(
#                 &quot;map_cc5051a756ae7482aaaed88b11e61039&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_170c143b13995bac0862a6da3ac6c44f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_170c143b13995bac0862a6da3ac6c44f.addTo(map_cc5051a756ae7482aaaed88b11e61039);
#
#
#             var feature_group_4a17723cb866241e7e7c187575705ad7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4299c9443f2fececab0cb13b5821648a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4a17723cb866241e7e7c187575705ad7);
#
#
#         var popup_778b60d17151711ea01ee55633de4790 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d954751768666d5b696488ef4b2eed0 = $(`&lt;div id=&quot;html_7d954751768666d5b696488ef4b2eed0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_778b60d17151711ea01ee55633de4790.setContent(html_7d954751768666d5b696488ef4b2eed0);
#
#
#
#         marker_4299c9443f2fececab0cb13b5821648a.bindPopup(popup_778b60d17151711ea01ee55633de4790)
#         ;
#
#
#
#
#             var marker_4c1e9e5755b96d80380ff28b866bf065 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4a17723cb866241e7e7c187575705ad7);
#
#
#         var popup_e55f08bb1a74a3095d844a4c0100f4e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_755580eac0cb063e66c88dfce2964cd2 = $(`&lt;div id=&quot;html_755580eac0cb063e66c88dfce2964cd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e55f08bb1a74a3095d844a4c0100f4e4.setContent(html_755580eac0cb063e66c88dfce2964cd2);
#
#
#
#         marker_4c1e9e5755b96d80380ff28b866bf065.bindPopup(popup_e55f08bb1a74a3095d844a4c0100f4e4)
#         ;
#
#
#
#
#             var marker_91904af5d7f52b59722fbc0120405f73 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4a17723cb866241e7e7c187575705ad7);
#
#
#         var popup_39bff8fcedbd4ce66c09b91bc38fc9ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12a2c591e6c694bfb0afcb66d6dc7381 = $(`&lt;div id=&quot;html_12a2c591e6c694bfb0afcb66d6dc7381&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_39bff8fcedbd4ce66c09b91bc38fc9ef.setContent(html_12a2c591e6c694bfb0afcb66d6dc7381);
#
#
#
#         marker_91904af5d7f52b59722fbc0120405f73.bindPopup(popup_39bff8fcedbd4ce66c09b91bc38fc9ef)
#         ;
#
#
#
#
#             var marker_91eedcc5930c13740607a168a68e77f9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4a17723cb866241e7e7c187575705ad7);
#
#
#         var popup_29f4ad1bbc980d76a643880564c9c3bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac62b1f8f655f602d8c509c11c60534c = $(`&lt;div id=&quot;html_ac62b1f8f655f602d8c509c11c60534c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_29f4ad1bbc980d76a643880564c9c3bc.setContent(html_ac62b1f8f655f602d8c509c11c60534c);
#
#
#
#         marker_91eedcc5930c13740607a168a68e77f9.bindPopup(popup_29f4ad1bbc980d76a643880564c9c3bc)
#         ;
#
#
#
#
#             var marker_f0c03a3567d86d288572d099fb48a6bc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4a17723cb866241e7e7c187575705ad7);
#
#
#         var popup_5b79c07d3c0897a80a7106d53b2fab51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29b73f568fa35287642d9bfa7b03ec28 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29b73f568fa35287642d9bfa7b03ec28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29b73f568fa35287642d9bfa7b03ec28 = L.map(
#                 &quot;map_29b73f568fa35287642d9bfa7b03ec28&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f543ebf578442f7347cef2f1fcb6a724 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f543ebf578442f7347cef2f1fcb6a724.addTo(map_29b73f568fa35287642d9bfa7b03ec28);
#
#
#             var feature_group_91db6e3b0370f79797a1aedda2b314ed = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_91db6e3b0370f79797a1aedda2b314ed.addTo(map_29b73f568fa35287642d9bfa7b03ec28);
#
#
#             var feature_group_sub_group_1efe10f9735582576832642df187882c = L.featureGroup.subGroup(
#                 feature_group_91db6e3b0370f79797a1aedda2b314ed
#             );
#
#
#             var marker_94e7d160c606433e6f885fb118ff5588 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1efe10f9735582576832642df187882c);
#
#
#         var popup_d857fc417aa20bf5c62f8be7a47abe2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54e15efbf07dd37388ebb084fda13d9d = $(`&lt;div id=&quot;html_54e15efbf07dd37388ebb084fda13d9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d857fc417aa20bf5c62f8be7a47abe2c.setContent(html_54e15efbf07dd37388ebb084fda13d9d);
#
#
#
#         marker_94e7d160c606433e6f885fb118ff5588.bindPopup(popup_d857fc417aa20bf5c62f8be7a47abe2c)
#         ;
#
#
#
#
#             var marker_bfc68c4f695f1ce1e01f8673ae84170c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1efe10f9735582576832642df187882c);
#
#
#         var popup_93254fafe9c98b838f1a487e1f7f4ffa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_003bb797c8169c4d336ef6376c91907e = $(`&lt;div id=&quot;html_003bb797c8169c4d336ef6376c91907e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_93254fafe9c98b838f1a487e1f7f4ffa.setContent(html_003bb797c8169c4d336ef6376c91907e);
#
#
#
#         marker_bfc68c4f695f1ce1e01f8673ae84170c.bindPopup(popup_93254fafe9c98b838f1a487e1f7f4ffa)
#         ;
#
#
#
#
#             var marker_36894e3ebc5917d1e3b8aae0790e1071 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1efe10f9735582576832642df187882c);
#
#
#         var popup_75e7b0e1df03840ca4a65ec83d94b612 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bd1873b04b76c138b6e7fafe3da07b0 = $(`&lt;div id=&quot;html_6bd1873b04b76c138b6e7fafe3da07b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_75e7b0e1df03840ca4a65ec83d94b612.setContent(html_6bd1873b04b76c138b6e7fafe3da07b0);
#
#
#
#         marker_36894e3ebc5917d1e3b8aae0790e1071.bindPopup(popup_75e7b0e1df03840ca4a65ec83d94b612)
#         ;
#
#
#
#
#             var marker_d28310d720c1cd8ac65bc00e66e5bee8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1efe10f9735582576832642df187882c);
#
#
#         var popup_375e745bf11852fd742c345912afaafc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3477d38bbf4d24a0b96dc9be7432fd6c = $(`&lt;div id=&quot;html_3477d38bbf4d24a0b96dc9be7432fd6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_375e745bf11852fd742c345912afaafc.setContent(html_3477d38bbf4d24a0b96dc9be7432fd6c);
#
#
#
#         marker_
