# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_664f7ae26b5066b38e3e6c4213cd7b82 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_664f7ae26b5066b38e3e6c4213cd7b82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_664f7ae26b5066b38e3e6c4213cd7b82 = L.map(
#                 &quot;map_664f7ae26b5066b38e3e6c4213cd7b82&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_062b60cee533ca39ff36227b5486c8e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_062b60cee533ca39ff36227b5486c8e7.addTo(map_664f7ae26b5066b38e3e6c4213cd7b82);
#
#
#             var marker_9b83174b984094eabd7c69ad99ed1418 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_664f7ae26b5066b38e3e6c4213cd7b82);
#
#
#         var popup_c1fe8b912718a696fc3f92c1614d9cf3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01cc76253e3e53d2fd17b56611a85930 = $(`&lt;div id=&quot;html_01cc76253e3e53d2fd17b56611a85930&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c1fe8b912718a696fc3f92c1614d9cf3.setContent(html_01cc76253e3e53d2fd17b56611a85930);
#
#
#
#         marker_9b83174b984094eabd7c69ad99ed1418.bindPopup(popup_c1fe8b912718a696fc3f92c1614d9cf3)
#         ;
#
#
#
#
#             var marker_9348231ecda29532467c90d904fd13a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_664f7ae26b5066b38e3e6c4213cd7b82);
#
#
#         var popup_b912531add85fe66f5ce5a329c27e735 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_408403a3d0d1b8a770578688f7667ee6 = $(`&lt;div id=&quot;html_408403a3d0d1b8a770578688f7667ee6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b912531add85fe66f5ce5a329c27e735.setContent(html_408403a3d0d1b8a770578688f7667ee6);
#
#
#
#         marker_9348231ecda29532467c90d904fd13a6.bindPopup(popup_b912531add85fe66f5ce5a329c27e735)
#         ;
#
#
#
#
#             var marker_15accb0016a1aaf3b184e3f2f24b8db1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_664f7ae26b5066b38e3e6c4213cd7b82);
#
#
#         var popup_22725900a4f7948412dd82c3ad65380e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f80468441ea19afa31b43064918efff = $(`&lt;div id=&quot;html_0f80468441ea19afa31b43064918efff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_22725900a4f7948412dd82c3ad65380e.setContent(html_0f80468441ea19afa31b43064918efff);
#
#
#
#         marker_15accb0016a1aaf3b184e3f2f24b8db1.bindPopup(popup_22725900a4f7948412dd82c3ad65380e)
#         ;
#
#
#
#
#             var marker_bf6712c3efa32a10f735fde655b9d99a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_664f7ae26b5066b38e3e6c4213cd7b82);
#
#
#         var popup_0143201843c539151e66231ac491137a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e81e385a665ca64b882edcf8cdf5cd8 = $(`&lt;div id=&quot;html_6e81e385a665ca64b882edcf8cdf5cd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0143201843c539151e66231ac491137a.setContent(html_6e81e385a665ca64b882edcf8cdf5cd8);
#
#
#
#         marker_bf6712c3efa32a10f735fde655b9d99a.bindPopup(popup_0143201843c539151e66231ac491137a)
#         ;
#
#
#
#
#             var marker_977324d200e3f8c257fd5de26f576ef2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_664f7ae26b5066b38e3e6c4213cd7b82);
#
#
#         var popup_d9034dd336742a51ea81cebff03b3c0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58cd2f30ed33ffe4e8dfd9bb121010ce = $(`&lt;div id=&quot;html_58cd2f30ed33ffe4e8dfd9bb121010ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d9034dd336742a51ea81cebff03b3c0e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48a575941905cbab9c746678b9113b2a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48a575941905cbab9c746678b9113b2a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48a575941905cbab9c746678b9113b2a = L.map(
#                 &quot;map_48a575941905cbab9c746678b9113b2a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_238175474da908f27ee187c10a618a30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_238175474da908f27ee187c10a618a30.addTo(map_48a575941905cbab9c746678b9113b2a);
#
#
#             var feature_group_1bec2eec38ec37a1ae5ce6db0d96f0e4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2439f3e0f519d3d15ba9d47f31f4357c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1bec2eec38ec37a1ae5ce6db0d96f0e4);
#
#
#         var popup_aff18b158d20c4dfbf9c5f6bfdcb9e2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f6d9374e3c70e3a1fde823f05cc9e41 = $(`&lt;div id=&quot;html_8f6d9374e3c70e3a1fde823f05cc9e41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_aff18b158d20c4dfbf9c5f6bfdcb9e2b.setContent(html_8f6d9374e3c70e3a1fde823f05cc9e41);
#
#
#
#         marker_2439f3e0f519d3d15ba9d47f31f4357c.bindPopup(popup_aff18b158d20c4dfbf9c5f6bfdcb9e2b)
#         ;
#
#
#
#
#             var marker_b15b976346b195413c67bb8d497881e6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1bec2eec38ec37a1ae5ce6db0d96f0e4);
#
#
#         var popup_5d13adf50e465e1f3544a465e40f75b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03590add40c291aea4b47183c025cab5 = $(`&lt;div id=&quot;html_03590add40c291aea4b47183c025cab5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5d13adf50e465e1f3544a465e40f75b3.setContent(html_03590add40c291aea4b47183c025cab5);
#
#
#
#         marker_b15b976346b195413c67bb8d497881e6.bindPopup(popup_5d13adf50e465e1f3544a465e40f75b3)
#         ;
#
#
#
#
#             var marker_ca5b4325d5aea013173171ca6c8279ab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1bec2eec38ec37a1ae5ce6db0d96f0e4);
#
#
#         var popup_52b2cb3bc68f4f336b08724ca2b519a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6981d73794597ea9786e31b018c08680 = $(`&lt;div id=&quot;html_6981d73794597ea9786e31b018c08680&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_52b2cb3bc68f4f336b08724ca2b519a1.setContent(html_6981d73794597ea9786e31b018c08680);
#
#
#
#         marker_ca5b4325d5aea013173171ca6c8279ab.bindPopup(popup_52b2cb3bc68f4f336b08724ca2b519a1)
#         ;
#
#
#
#
#             var marker_4fe117dad2e9d0337d89647ecbb3eb25 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1bec2eec38ec37a1ae5ce6db0d96f0e4);
#
#
#         var popup_f4123f022d6d7199b93b0053313ffbd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bc958a5ef4357e8d3e0a7f602237145 = $(`&lt;div id=&quot;html_0bc958a5ef4357e8d3e0a7f602237145&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f4123f022d6d7199b93b0053313ffbd5.setContent(html_0bc958a5ef4357e8d3e0a7f602237145);
#
#
#
#         marker_4fe117dad2e9d0337d89647ecbb3eb25.bindPopup(popup_f4123f022d6d7199b93b0053313ffbd5)
#         ;
#
#
#
#
#             var marker_db5dd7a6439f52936c3704adcb3c46a0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1bec2eec38ec37a1ae5ce6db0d96f0e4);
#
#
#         var popup_f33276d61a77a04deada27e0880eb39e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34c4143e8364c25c96f94c317b807644 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34c4143e8364c25c96f94c317b807644&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34c4143e8364c25c96f94c317b807644 = L.map(
#                 &quot;map_34c4143e8364c25c96f94c317b807644&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3793e2386bdadf06c166e5383a7e6eef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3793e2386bdadf06c166e5383a7e6eef.addTo(map_34c4143e8364c25c96f94c317b807644);
#
#
#             var feature_group_124e8bf5da6795c02e7cc8bd358b2ed8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_124e8bf5da6795c02e7cc8bd358b2ed8.addTo(map_34c4143e8364c25c96f94c317b807644);
#
#
#             var feature_group_sub_group_13259d8dacac191062d99c1aeeed1c9c = L.featureGroup.subGroup(
#                 feature_group_124e8bf5da6795c02e7cc8bd358b2ed8
#             );
#
#
#             var marker_6f4bc945d6e583b52171142a367bcca3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_13259d8dacac191062d99c1aeeed1c9c);
#
#
#         var popup_5c6592db03365b68df33fd3ea34c50ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9c16ec4539d2706671deb2594dabd6b = $(`&lt;div id=&quot;html_e9c16ec4539d2706671deb2594dabd6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5c6592db03365b68df33fd3ea34c50ba.setContent(html_e9c16ec4539d2706671deb2594dabd6b);
#
#
#
#         marker_6f4bc945d6e583b52171142a367bcca3.bindPopup(popup_5c6592db03365b68df33fd3ea34c50ba)
#         ;
#
#
#
#
#             var marker_fedabd16b6d0b89d9dd6aad95c91e175 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_13259d8dacac191062d99c1aeeed1c9c);
#
#
#         var popup_c47741a0102b7a3b8da488f3de9b0e76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c4ad334773723bce2219b5306d71a34 = $(`&lt;div id=&quot;html_0c4ad334773723bce2219b5306d71a34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c47741a0102b7a3b8da488f3de9b0e76.setContent(html_0c4ad334773723bce2219b5306d71a34);
#
#
#
#         marker_fedabd16b6d0b89d9dd6aad95c91e175.bindPopup(popup_c47741a0102b7a3b8da488f3de9b0e76)
#         ;
#
#
#
#
#             var marker_ee28be8654c92e1bbb3ec07ed6a2d9b8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_13259d8dacac191062d99c1aeeed1c9c);
#
#
#         var popup_fd5e4c26ad199d906706f869ab25987a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_020616d48aed3cf2d322eaea7705a9cc = $(`&lt;div id=&quot;html_020616d48aed3cf2d322eaea7705a9cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fd5e4c26ad199d906706f869ab25987a.setContent(html_020616d48aed3cf2d322eaea7705a9cc);
#
#
#
#         marker_ee28be8654c92e1bbb3ec07ed6a2d9b8.bindPopup(popup_fd5e4c26ad199d906706f869ab25987a)
#         ;
#
#
#
#
#             var marker_7a1cafe3b9b3182fce8bf31cb14ad8b3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_13259d8dacac191062d99c1aeeed1c9c);
#
#
#         var popup_38633ad82645d940e49fc993964d1ed1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62456c5027278ad82221ba8d0803a4c9 = $(`&lt;div id=&quot;html_62456c5027278ad82221ba8d0803a4c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_38633ad82645d940e49fc993964d1ed1.setContent(html_62456c5027278ad82221ba8d0803a4c9);
#
#
#
#         marker_
