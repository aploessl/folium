# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a21b637b4e136db7fa1b929d3b33e23 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a21b637b4e136db7fa1b929d3b33e23&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a21b637b4e136db7fa1b929d3b33e23 = L.map(
#                 &quot;map_4a21b637b4e136db7fa1b929d3b33e23&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0c2e4d444bd7a42441a3d93d62e1493 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0c2e4d444bd7a42441a3d93d62e1493.addTo(map_4a21b637b4e136db7fa1b929d3b33e23);
#
#
#             var marker_63c749cbb41d3a007b5fd1ebe1d767a8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4a21b637b4e136db7fa1b929d3b33e23);
#
#
#         var popup_2459b1e77bc5e3882c85cfafb18400bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec13a0de227c7a664f038b0bce6a7f73 = $(`&lt;div id=&quot;html_ec13a0de227c7a664f038b0bce6a7f73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2459b1e77bc5e3882c85cfafb18400bc.setContent(html_ec13a0de227c7a664f038b0bce6a7f73);
#
#
#
#         marker_63c749cbb41d3a007b5fd1ebe1d767a8.bindPopup(popup_2459b1e77bc5e3882c85cfafb18400bc)
#         ;
#
#
#
#
#             var marker_b4ddd9fbafe990a1769c062c385657bd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4a21b637b4e136db7fa1b929d3b33e23);
#
#
#         var popup_ca615fbd49bcc424735350cfbcd5c287 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_724f1ca3d7a28495836885db6aa104ec = $(`&lt;div id=&quot;html_724f1ca3d7a28495836885db6aa104ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ca615fbd49bcc424735350cfbcd5c287.setContent(html_724f1ca3d7a28495836885db6aa104ec);
#
#
#
#         marker_b4ddd9fbafe990a1769c062c385657bd.bindPopup(popup_ca615fbd49bcc424735350cfbcd5c287)
#         ;
#
#
#
#
#             var marker_fd857a3707f376da7890c798110b18c7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4a21b637b4e136db7fa1b929d3b33e23);
#
#
#         var popup_a7e2f0b876e32597cdf4e93642c7a487 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ca086bbd7fa0ab972af7816e7c39b10 = $(`&lt;div id=&quot;html_3ca086bbd7fa0ab972af7816e7c39b10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a7e2f0b876e32597cdf4e93642c7a487.setContent(html_3ca086bbd7fa0ab972af7816e7c39b10);
#
#
#
#         marker_fd857a3707f376da7890c798110b18c7.bindPopup(popup_a7e2f0b876e32597cdf4e93642c7a487)
#         ;
#
#
#
#
#             var marker_0bdc9ffc69aa1220cdb78f4a48afc6af = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4a21b637b4e136db7fa1b929d3b33e23);
#
#
#         var popup_998db47d7ae3da2e0297907a03540145 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ba0cd8cd569e253b462744164a10bf0 = $(`&lt;div id=&quot;html_7ba0cd8cd569e253b462744164a10bf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_998db47d7ae3da2e0297907a03540145.setContent(html_7ba0cd8cd569e253b462744164a10bf0);
#
#
#
#         marker_0bdc9ffc69aa1220cdb78f4a48afc6af.bindPopup(popup_998db47d7ae3da2e0297907a03540145)
#         ;
#
#
#
#
#             var marker_a8c2c0e865254d587bb2edefcc7481c9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4a21b637b4e136db7fa1b929d3b33e23);
#
#
#         var popup_7e29ec7a9e552bb25472b444aa0bd51d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69bd0e8eff52b8931dd91353885c7be7 = $(`&lt;div id=&quot;html_69bd0e8eff52b8931dd91353885c7be7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7e29ec7a9e552bb25472b444aa0bd51d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c72d7f75900147c1e3e91fdee09107e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c72d7f75900147c1e3e91fdee09107e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c72d7f75900147c1e3e91fdee09107e3 = L.map(
#                 &quot;map_c72d7f75900147c1e3e91fdee09107e3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1220d277afcb4fb710d465d79d2082b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e1220d277afcb4fb710d465d79d2082b.addTo(map_c72d7f75900147c1e3e91fdee09107e3);
#
#
#             var feature_group_6ed04f3265ef52e3d66292941d4bc10b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_da38e14740866779af93ea131eecd85c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6ed04f3265ef52e3d66292941d4bc10b);
#
#
#         var popup_64747649d267d55c7453efed632f54e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08c99c7e4f176a9a064e1335362542c3 = $(`&lt;div id=&quot;html_08c99c7e4f176a9a064e1335362542c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_64747649d267d55c7453efed632f54e7.setContent(html_08c99c7e4f176a9a064e1335362542c3);
#
#
#
#         marker_da38e14740866779af93ea131eecd85c.bindPopup(popup_64747649d267d55c7453efed632f54e7)
#         ;
#
#
#
#
#             var marker_6cad0e7d646f631b81864b3bbb92fe46 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6ed04f3265ef52e3d66292941d4bc10b);
#
#
#         var popup_63981bc20e2cb0e6cde430ebaa15ba26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2bda94833776254ca0b5fe04a406e02 = $(`&lt;div id=&quot;html_c2bda94833776254ca0b5fe04a406e02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_63981bc20e2cb0e6cde430ebaa15ba26.setContent(html_c2bda94833776254ca0b5fe04a406e02);
#
#
#
#         marker_6cad0e7d646f631b81864b3bbb92fe46.bindPopup(popup_63981bc20e2cb0e6cde430ebaa15ba26)
#         ;
#
#
#
#
#             var marker_7864afcc83926f205e4eaed35f650702 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6ed04f3265ef52e3d66292941d4bc10b);
#
#
#         var popup_ed86ea9763b4a74917e63add1630e773 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68272bb8b304a95b7fa3d99a71d930f6 = $(`&lt;div id=&quot;html_68272bb8b304a95b7fa3d99a71d930f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ed86ea9763b4a74917e63add1630e773.setContent(html_68272bb8b304a95b7fa3d99a71d930f6);
#
#
#
#         marker_7864afcc83926f205e4eaed35f650702.bindPopup(popup_ed86ea9763b4a74917e63add1630e773)
#         ;
#
#
#
#
#             var marker_fe06f755bee41723da375bda45871a56 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6ed04f3265ef52e3d66292941d4bc10b);
#
#
#         var popup_3e338b08f98447e56ad571a46d662d3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9ae2b1a46eb4de4c6b0456684279daf = $(`&lt;div id=&quot;html_c9ae2b1a46eb4de4c6b0456684279daf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3e338b08f98447e56ad571a46d662d3d.setContent(html_c9ae2b1a46eb4de4c6b0456684279daf);
#
#
#
#         marker_fe06f755bee41723da375bda45871a56.bindPopup(popup_3e338b08f98447e56ad571a46d662d3d)
#         ;
#
#
#
#
#             var marker_3f78c79e9dd521f2e72b0ef1773ce1b3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6ed04f3265ef52e3d66292941d4bc10b);
#
#
#         var popup_f3ff4863d834455e292754a51951f718 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c78e741e57096c9a790b62d68edf6986 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c78e741e57096c9a790b62d68edf6986&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c78e741e57096c9a790b62d68edf6986 = L.map(
#                 &quot;map_c78e741e57096c9a790b62d68edf6986&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1949272b1fb360847b19f764c80eca8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e1949272b1fb360847b19f764c80eca8.addTo(map_c78e741e57096c9a790b62d68edf6986);
#
#
#             var feature_group_a00f63dfc30bea86dbd94211e10b31a2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a00f63dfc30bea86dbd94211e10b31a2.addTo(map_c78e741e57096c9a790b62d68edf6986);
#
#
#             var feature_group_sub_group_22bdcd05163e8c76ca78fea20ff8a2ac = L.featureGroup.subGroup(
#                 feature_group_a00f63dfc30bea86dbd94211e10b31a2
#             );
#
#
#             var marker_c176c31e0577476cea3b2b871713c9b8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_22bdcd05163e8c76ca78fea20ff8a2ac);
#
#
#         var popup_575840366da6fda014fb73dae619bb8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ace3371bba7244171b4002822f974f5b = $(`&lt;div id=&quot;html_ace3371bba7244171b4002822f974f5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_575840366da6fda014fb73dae619bb8d.setContent(html_ace3371bba7244171b4002822f974f5b);
#
#
#
#         marker_c176c31e0577476cea3b2b871713c9b8.bindPopup(popup_575840366da6fda014fb73dae619bb8d)
#         ;
#
#
#
#
#             var marker_93a0c77817b2ad8eabbb8280ebeb35ef = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_22bdcd05163e8c76ca78fea20ff8a2ac);
#
#
#         var popup_d1a81ac4c9efa16f86f29c0dbc7c65e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0cd66108d40355eb80dbea631ebe322 = $(`&lt;div id=&quot;html_e0cd66108d40355eb80dbea631ebe322&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d1a81ac4c9efa16f86f29c0dbc7c65e7.setContent(html_e0cd66108d40355eb80dbea631ebe322);
#
#
#
#         marker_93a0c77817b2ad8eabbb8280ebeb35ef.bindPopup(popup_d1a81ac4c9efa16f86f29c0dbc7c65e7)
#         ;
#
#
#
#
#             var marker_6c72c9ddc07e3d7c374a015686700290 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_22bdcd05163e8c76ca78fea20ff8a2ac);
#
#
#         var popup_f068e485e2a0b8d3285511a470e3be00 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_baad5b2a6b8382e22b7791792e1ead5b = $(`&lt;div id=&quot;html_baad5b2a6b8382e22b7791792e1ead5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f068e485e2a0b8d3285511a470e3be00.setContent(html_baad5b2a6b8382e22b7791792e1ead5b);
#
#
#
#         marker_6c72c9ddc07e3d7c374a015686700290.bindPopup(popup_f068e485e2a0b8d3285511a470e3be00)
#         ;
#
#
#
#
#             var marker_e04f50c5c5a1db453511a3d523c09e3d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_22bdcd05163e8c76ca78fea20ff8a2ac);
#
#
#         var popup_18b38597fda566419ff0b0fd1b57b361 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42c0107cefa60c4f015af29793c330a3 = $(`&lt;div id=&quot;html_42c0107cefa60c4f015af29793c330a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_18b38597fda566419ff0b0fd1b57b361.setContent(html_42c0107cefa60c4f015af29793c330a3);
#
#
#
#         marker_
