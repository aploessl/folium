# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dac196ff7355c47b6df58e34bbcf84a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dac196ff7355c47b6df58e34bbcf84a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dac196ff7355c47b6df58e34bbcf84a6 = L.map(
#                 &quot;map_dac196ff7355c47b6df58e34bbcf84a6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ad0a16f9b2a339d6dbf88ab3106aafb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0ad0a16f9b2a339d6dbf88ab3106aafb.addTo(map_dac196ff7355c47b6df58e34bbcf84a6);
#
#
#             var marker_e16131adc09c201d26e1d0407a8109a2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_dac196ff7355c47b6df58e34bbcf84a6);
#
#
#         var popup_e939d5845a776a703fcb8e18c664c85d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a8d6b643456f6f43a3877aa5a9e6e2e = $(`&lt;div id=&quot;html_6a8d6b643456f6f43a3877aa5a9e6e2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e939d5845a776a703fcb8e18c664c85d.setContent(html_6a8d6b643456f6f43a3877aa5a9e6e2e);
#
#
#
#         marker_e16131adc09c201d26e1d0407a8109a2.bindPopup(popup_e939d5845a776a703fcb8e18c664c85d)
#         ;
#
#
#
#
#             var marker_4f2b5ae1b77dfc039d216bb80530693b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_dac196ff7355c47b6df58e34bbcf84a6);
#
#
#         var popup_579899e94c25f365e6e6107c876c9bce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08c9be880d731a4d3fcde731fd7bb652 = $(`&lt;div id=&quot;html_08c9be880d731a4d3fcde731fd7bb652&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_579899e94c25f365e6e6107c876c9bce.setContent(html_08c9be880d731a4d3fcde731fd7bb652);
#
#
#
#         marker_4f2b5ae1b77dfc039d216bb80530693b.bindPopup(popup_579899e94c25f365e6e6107c876c9bce)
#         ;
#
#
#
#
#             var marker_0a6d1f4453d9405a3fa7e0978ff8143e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_dac196ff7355c47b6df58e34bbcf84a6);
#
#
#         var popup_0c3824987146ee84b0ed282422105530 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cac07d5edf996bc6217b2df0caf35f0c = $(`&lt;div id=&quot;html_cac07d5edf996bc6217b2df0caf35f0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0c3824987146ee84b0ed282422105530.setContent(html_cac07d5edf996bc6217b2df0caf35f0c);
#
#
#
#         marker_0a6d1f4453d9405a3fa7e0978ff8143e.bindPopup(popup_0c3824987146ee84b0ed282422105530)
#         ;
#
#
#
#
#             var marker_fdbf448bcc22146cbd42048b5e2ab25a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_dac196ff7355c47b6df58e34bbcf84a6);
#
#
#         var popup_d18f3d1711cb59207243b3c84b48a276 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa0f0ded461c535b8422be1c423539c4 = $(`&lt;div id=&quot;html_aa0f0ded461c535b8422be1c423539c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d18f3d1711cb59207243b3c84b48a276.setContent(html_aa0f0ded461c535b8422be1c423539c4);
#
#
#
#         marker_fdbf448bcc22146cbd42048b5e2ab25a.bindPopup(popup_d18f3d1711cb59207243b3c84b48a276)
#         ;
#
#
#
#
#             var marker_766c19bdbe393a0cf377fb1f35a3433a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_dac196ff7355c47b6df58e34bbcf84a6);
#
#
#         var popup_d7a9c0a85122c53a2754cc2860eec1ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfc88066051cbb5e71ebfe9d2469de96 = $(`&lt;div id=&quot;html_cfc88066051cbb5e71ebfe9d2469de96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d7a9c0a85122c53a2754cc2860eec1ea.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5985eda8e6d3065350f836034a27fb49 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5985eda8e6d3065350f836034a27fb49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5985eda8e6d3065350f836034a27fb49 = L.map(
#                 &quot;map_5985eda8e6d3065350f836034a27fb49&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66a10e59e598068e37cf6b9b920f89cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_66a10e59e598068e37cf6b9b920f89cb.addTo(map_5985eda8e6d3065350f836034a27fb49);
#
#
#             var feature_group_c703fc68199bb460bfdfacced4077375 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f9004ab08faf45c384ab8ac77c189129 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c703fc68199bb460bfdfacced4077375);
#
#
#         var popup_355ac2df469709122aba7849a927ccd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb601d8a1aa36e952a46a810150ec972 = $(`&lt;div id=&quot;html_cb601d8a1aa36e952a46a810150ec972&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_355ac2df469709122aba7849a927ccd5.setContent(html_cb601d8a1aa36e952a46a810150ec972);
#
#
#
#         marker_f9004ab08faf45c384ab8ac77c189129.bindPopup(popup_355ac2df469709122aba7849a927ccd5)
#         ;
#
#
#
#
#             var marker_589b8700b77fc19296c61844ced19047 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c703fc68199bb460bfdfacced4077375);
#
#
#         var popup_55430e3b823a3b3dc74c1b13ab23889f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c7ede179a711d47356dfb208b03f62e = $(`&lt;div id=&quot;html_3c7ede179a711d47356dfb208b03f62e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_55430e3b823a3b3dc74c1b13ab23889f.setContent(html_3c7ede179a711d47356dfb208b03f62e);
#
#
#
#         marker_589b8700b77fc19296c61844ced19047.bindPopup(popup_55430e3b823a3b3dc74c1b13ab23889f)
#         ;
#
#
#
#
#             var marker_316dc88fddcab0cb09a2dcf1d0d31dc8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c703fc68199bb460bfdfacced4077375);
#
#
#         var popup_b9d2b2dc987944e6e1d283d77e9e0590 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4119f1b657bcb1a4052aa01b5f269bec = $(`&lt;div id=&quot;html_4119f1b657bcb1a4052aa01b5f269bec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b9d2b2dc987944e6e1d283d77e9e0590.setContent(html_4119f1b657bcb1a4052aa01b5f269bec);
#
#
#
#         marker_316dc88fddcab0cb09a2dcf1d0d31dc8.bindPopup(popup_b9d2b2dc987944e6e1d283d77e9e0590)
#         ;
#
#
#
#
#             var marker_a23e0c0a074dbf7539365042191d1a28 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c703fc68199bb460bfdfacced4077375);
#
#
#         var popup_8d2c40fb9ce5afb8382e4f2d62fdb5e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e829bbd5f22083a48f27efd0d1e0dfce = $(`&lt;div id=&quot;html_e829bbd5f22083a48f27efd0d1e0dfce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8d2c40fb9ce5afb8382e4f2d62fdb5e5.setContent(html_e829bbd5f22083a48f27efd0d1e0dfce);
#
#
#
#         marker_a23e0c0a074dbf7539365042191d1a28.bindPopup(popup_8d2c40fb9ce5afb8382e4f2d62fdb5e5)
#         ;
#
#
#
#
#             var marker_174c0922f48eebbb9768d56c9683aa6c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c703fc68199bb460bfdfacced4077375);
#
#
#         var popup_30dd89bd6f33e6729abe5c0411ec44aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f969cb222d2523f3c5e58eebb5a5a3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f969cb222d2523f3c5e58eebb5a5a3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f969cb222d2523f3c5e58eebb5a5a3d = L.map(
#                 &quot;map_4f969cb222d2523f3c5e58eebb5a5a3d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9cc437976c0da9f1a7a331f5d086bae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e9cc437976c0da9f1a7a331f5d086bae.addTo(map_4f969cb222d2523f3c5e58eebb5a5a3d);
#
#
#             var feature_group_943d04399513921a4741836ea4cd2ad0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_943d04399513921a4741836ea4cd2ad0.addTo(map_4f969cb222d2523f3c5e58eebb5a5a3d);
#
#
#             var feature_group_sub_group_5f6729938e5c3de02d78d18bf6db8a72 = L.featureGroup.subGroup(
#                 feature_group_943d04399513921a4741836ea4cd2ad0
#             );
#
#
#             var marker_0fd90332f56328dab9a9b986e0e6f5c5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f6729938e5c3de02d78d18bf6db8a72);
#
#
#         var popup_0ea478303047e8053cbe2c038bf5fdc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b38a3464ae948d3faab47c5d7efb6272 = $(`&lt;div id=&quot;html_b38a3464ae948d3faab47c5d7efb6272&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0ea478303047e8053cbe2c038bf5fdc4.setContent(html_b38a3464ae948d3faab47c5d7efb6272);
#
#
#
#         marker_0fd90332f56328dab9a9b986e0e6f5c5.bindPopup(popup_0ea478303047e8053cbe2c038bf5fdc4)
#         ;
#
#
#
#
#             var marker_f5ae3233dd96fd6752c3864b05fb5b82 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f6729938e5c3de02d78d18bf6db8a72);
#
#
#         var popup_7f36f19ee81a02271344392776314ff5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d06e87c91f4fbed00ade99a7fba10cd = $(`&lt;div id=&quot;html_4d06e87c91f4fbed00ade99a7fba10cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7f36f19ee81a02271344392776314ff5.setContent(html_4d06e87c91f4fbed00ade99a7fba10cd);
#
#
#
#         marker_f5ae3233dd96fd6752c3864b05fb5b82.bindPopup(popup_7f36f19ee81a02271344392776314ff5)
#         ;
#
#
#
#
#             var marker_38e7e4e8f5b313a29c2e0d71a35bed08 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f6729938e5c3de02d78d18bf6db8a72);
#
#
#         var popup_77b98666ff5987305fdd342ee534bb7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02630c2517455c821685eb870747e976 = $(`&lt;div id=&quot;html_02630c2517455c821685eb870747e976&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_77b98666ff5987305fdd342ee534bb7f.setContent(html_02630c2517455c821685eb870747e976);
#
#
#
#         marker_38e7e4e8f5b313a29c2e0d71a35bed08.bindPopup(popup_77b98666ff5987305fdd342ee534bb7f)
#         ;
#
#
#
#
#             var marker_7d1d06ae4236ac3d5551f42a5c8a71fd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f6729938e5c3de02d78d18bf6db8a72);
#
#
#         var popup_813a87f168e523c950d431d53e1575fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe4f013539af636a226050b3162c2a55 = $(`&lt;div id=&quot;html_fe4f013539af636a226050b3162c2a55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_813a87f168e523c950d431d53e1575fb.setContent(html_fe4f013539af636a226050b3162c2a55);
#
#
#
#         marker_
