# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c0176e558bddf224a43b118a6a2e239 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c0176e558bddf224a43b118a6a2e239&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c0176e558bddf224a43b118a6a2e239 = L.map(
#                 &quot;map_1c0176e558bddf224a43b118a6a2e239&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_102ff39ae1aa2098dba202aa1f3fd834 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_102ff39ae1aa2098dba202aa1f3fd834.addTo(map_1c0176e558bddf224a43b118a6a2e239);
#
#
#             var marker_8b2e7198916c2f4922818b1c4f9a7c76 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1c0176e558bddf224a43b118a6a2e239);
#
#
#         var popup_74e0f56024281ff2b07bb0516207f0b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1644efd56e9d2807ce8794064110c5ee = $(`&lt;div id=&quot;html_1644efd56e9d2807ce8794064110c5ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_74e0f56024281ff2b07bb0516207f0b6.setContent(html_1644efd56e9d2807ce8794064110c5ee);
#
#
#
#         marker_8b2e7198916c2f4922818b1c4f9a7c76.bindPopup(popup_74e0f56024281ff2b07bb0516207f0b6)
#         ;
#
#
#
#
#             var marker_122bfeb970c1b54fdd49b527297e6184 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1c0176e558bddf224a43b118a6a2e239);
#
#
#         var popup_94e53ba860e8eed3d4abece8a69314a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c59810942791f473e1f0b83668cf0f85 = $(`&lt;div id=&quot;html_c59810942791f473e1f0b83668cf0f85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_94e53ba860e8eed3d4abece8a69314a5.setContent(html_c59810942791f473e1f0b83668cf0f85);
#
#
#
#         marker_122bfeb970c1b54fdd49b527297e6184.bindPopup(popup_94e53ba860e8eed3d4abece8a69314a5)
#         ;
#
#
#
#
#             var marker_cc2f60429866d2d1036df18cfd6f71e0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1c0176e558bddf224a43b118a6a2e239);
#
#
#         var popup_7d1a3081ab058594a71be54b533a5d38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76941e070c8d855aca3dec63b53658cd = $(`&lt;div id=&quot;html_76941e070c8d855aca3dec63b53658cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7d1a3081ab058594a71be54b533a5d38.setContent(html_76941e070c8d855aca3dec63b53658cd);
#
#
#
#         marker_cc2f60429866d2d1036df18cfd6f71e0.bindPopup(popup_7d1a3081ab058594a71be54b533a5d38)
#         ;
#
#
#
#
#             var marker_420c161cc7700205b2a1e4e8fb2f8fe8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1c0176e558bddf224a43b118a6a2e239);
#
#
#         var popup_9262cd0b08f5df5da75a3f69d5b09249 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6efa142c9a2fb604c829b5ae8f628e9d = $(`&lt;div id=&quot;html_6efa142c9a2fb604c829b5ae8f628e9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9262cd0b08f5df5da75a3f69d5b09249.setContent(html_6efa142c9a2fb604c829b5ae8f628e9d);
#
#
#
#         marker_420c161cc7700205b2a1e4e8fb2f8fe8.bindPopup(popup_9262cd0b08f5df5da75a3f69d5b09249)
#         ;
#
#
#
#
#             var marker_27bf04e1b9c0333a4fd4a1a764731cd7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1c0176e558bddf224a43b118a6a2e239);
#
#
#         var popup_271d52377d34734d820bcf7db1cf14b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78a60bba6b511cb5be9650999dda0870 = $(`&lt;div id=&quot;html_78a60bba6b511cb5be9650999dda0870&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_271d52377d34734d820bcf7db1cf14b8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_487eb209da8d9a33285c18abdaec2f75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_487eb209da8d9a33285c18abdaec2f75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_487eb209da8d9a33285c18abdaec2f75 = L.map(
#                 &quot;map_487eb209da8d9a33285c18abdaec2f75&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0806fccec7551a1c1cbce2b32358b73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0806fccec7551a1c1cbce2b32358b73.addTo(map_487eb209da8d9a33285c18abdaec2f75);
#
#
#             var feature_group_e006f15d0e1cd5197e6761a2f4372795 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_89cf47c70c2c779001572a8813119575 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e006f15d0e1cd5197e6761a2f4372795);
#
#
#         var popup_0d57c82374464fe0149eed9906d00352 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c6ac1466374b0dedadc5412cf21e949 = $(`&lt;div id=&quot;html_1c6ac1466374b0dedadc5412cf21e949&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0d57c82374464fe0149eed9906d00352.setContent(html_1c6ac1466374b0dedadc5412cf21e949);
#
#
#
#         marker_89cf47c70c2c779001572a8813119575.bindPopup(popup_0d57c82374464fe0149eed9906d00352)
#         ;
#
#
#
#
#             var marker_5848ed54157ba4fca96cbcdba86c938c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e006f15d0e1cd5197e6761a2f4372795);
#
#
#         var popup_d8745bfbf880345afa77e070f0a1fece = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7494a810461c9dbfbd17c55e6d702b5 = $(`&lt;div id=&quot;html_d7494a810461c9dbfbd17c55e6d702b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d8745bfbf880345afa77e070f0a1fece.setContent(html_d7494a810461c9dbfbd17c55e6d702b5);
#
#
#
#         marker_5848ed54157ba4fca96cbcdba86c938c.bindPopup(popup_d8745bfbf880345afa77e070f0a1fece)
#         ;
#
#
#
#
#             var marker_ff33d5315aeadfc4d0a11e100c61f42f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e006f15d0e1cd5197e6761a2f4372795);
#
#
#         var popup_1fb98b8a540dcbbfff4facde107964da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a41ce3c4eede5bfabeed9de302829eda = $(`&lt;div id=&quot;html_a41ce3c4eede5bfabeed9de302829eda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1fb98b8a540dcbbfff4facde107964da.setContent(html_a41ce3c4eede5bfabeed9de302829eda);
#
#
#
#         marker_ff33d5315aeadfc4d0a11e100c61f42f.bindPopup(popup_1fb98b8a540dcbbfff4facde107964da)
#         ;
#
#
#
#
#             var marker_7068d8c81767a02f2996eaa43360649a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e006f15d0e1cd5197e6761a2f4372795);
#
#
#         var popup_5fc326d31579a1afba8c0ae48546f77f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc28bc74f563d5deebc66fa37ce5790a = $(`&lt;div id=&quot;html_dc28bc74f563d5deebc66fa37ce5790a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5fc326d31579a1afba8c0ae48546f77f.setContent(html_dc28bc74f563d5deebc66fa37ce5790a);
#
#
#
#         marker_7068d8c81767a02f2996eaa43360649a.bindPopup(popup_5fc326d31579a1afba8c0ae48546f77f)
#         ;
#
#
#
#
#             var marker_d3ff441f8b67b35f435d278a9a095963 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e006f15d0e1cd5197e6761a2f4372795);
#
#
#         var popup_de93ce9ce4cd9af17d7524b84c27d380 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_443c962bfa235aa58dae30cde4d59a5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_443c962bfa235aa58dae30cde4d59a5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_443c962bfa235aa58dae30cde4d59a5e = L.map(
#                 &quot;map_443c962bfa235aa58dae30cde4d59a5e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9dee1dcc8d76fe2a360f4b3284f8161b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9dee1dcc8d76fe2a360f4b3284f8161b.addTo(map_443c962bfa235aa58dae30cde4d59a5e);
#
#
#             var feature_group_4b79970b6a8006fb395bdbd4a40c8da2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4b79970b6a8006fb395bdbd4a40c8da2.addTo(map_443c962bfa235aa58dae30cde4d59a5e);
#
#
#             var feature_group_sub_group_c14fd4453354811372e63332dd1bf978 = L.featureGroup.subGroup(
#                 feature_group_4b79970b6a8006fb395bdbd4a40c8da2
#             );
#
#
#             var marker_266f4860c2b5af3bbb104c92ac94ed91 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c14fd4453354811372e63332dd1bf978);
#
#
#         var popup_11de70da6700e1ca2c1e060f29fd1c1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c90e184015f681690e8ee080a04a297 = $(`&lt;div id=&quot;html_8c90e184015f681690e8ee080a04a297&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_11de70da6700e1ca2c1e060f29fd1c1e.setContent(html_8c90e184015f681690e8ee080a04a297);
#
#
#
#         marker_266f4860c2b5af3bbb104c92ac94ed91.bindPopup(popup_11de70da6700e1ca2c1e060f29fd1c1e)
#         ;
#
#
#
#
#             var marker_4270bcdf47ee95403a55beb79fa827d4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c14fd4453354811372e63332dd1bf978);
#
#
#         var popup_e9fda7a9ee9259401c04c634b78640fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90824b02f51bdd84fd259fc2a47e99ce = $(`&lt;div id=&quot;html_90824b02f51bdd84fd259fc2a47e99ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e9fda7a9ee9259401c04c634b78640fc.setContent(html_90824b02f51bdd84fd259fc2a47e99ce);
#
#
#
#         marker_4270bcdf47ee95403a55beb79fa827d4.bindPopup(popup_e9fda7a9ee9259401c04c634b78640fc)
#         ;
#
#
#
#
#             var marker_37ce0dafa5d58e7900caf5f991958c51 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c14fd4453354811372e63332dd1bf978);
#
#
#         var popup_14024ee03cedd2b778ba5162c7b68916 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88e83189398a893cb78e29aebf9701d8 = $(`&lt;div id=&quot;html_88e83189398a893cb78e29aebf9701d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_14024ee03cedd2b778ba5162c7b68916.setContent(html_88e83189398a893cb78e29aebf9701d8);
#
#
#
#         marker_37ce0dafa5d58e7900caf5f991958c51.bindPopup(popup_14024ee03cedd2b778ba5162c7b68916)
#         ;
#
#
#
#
#             var marker_62000978c5f2c50ec02d79f8f9a4256c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c14fd4453354811372e63332dd1bf978);
#
#
#         var popup_20f1275a84925f104b94e454011a5878 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bacfdf1ffdc7b3b5f19cbfce6b2e1c40 = $(`&lt;div id=&quot;html_bacfdf1ffdc7b3b5f19cbfce6b2e1c40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_20f1275a84925f104b94e454011a5878.setContent(html_bacfdf1ffdc7b3b5f19cbfce6b2e1c40);
#
#
#
#         marker_
