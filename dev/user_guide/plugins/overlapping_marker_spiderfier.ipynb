# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d9016d163bb21edeb1d6b5cca4ff08d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d9016d163bb21edeb1d6b5cca4ff08d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d9016d163bb21edeb1d6b5cca4ff08d = L.map(
#                 &quot;map_5d9016d163bb21edeb1d6b5cca4ff08d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cebfdc9d5cfa4086840efa904b92c0c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cebfdc9d5cfa4086840efa904b92c0c1.addTo(map_5d9016d163bb21edeb1d6b5cca4ff08d);
#
#
#             var marker_5029a87ae1b54c8c57b836754422f819 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5d9016d163bb21edeb1d6b5cca4ff08d);
#
#
#         var popup_3f1d9330aac662f731b3386ac330b69a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edaadeba6c86af760abc8db6047ef5ef = $(`&lt;div id=&quot;html_edaadeba6c86af760abc8db6047ef5ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3f1d9330aac662f731b3386ac330b69a.setContent(html_edaadeba6c86af760abc8db6047ef5ef);
#
#
#
#         marker_5029a87ae1b54c8c57b836754422f819.bindPopup(popup_3f1d9330aac662f731b3386ac330b69a)
#         ;
#
#
#
#
#             var marker_efbf86da40b3759904a5e09ff14ba54a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5d9016d163bb21edeb1d6b5cca4ff08d);
#
#
#         var popup_5076381c43344bec67ae9cdc0e6c2ca3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e566f7cdbaaed5417b259a71310e0bd5 = $(`&lt;div id=&quot;html_e566f7cdbaaed5417b259a71310e0bd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5076381c43344bec67ae9cdc0e6c2ca3.setContent(html_e566f7cdbaaed5417b259a71310e0bd5);
#
#
#
#         marker_efbf86da40b3759904a5e09ff14ba54a.bindPopup(popup_5076381c43344bec67ae9cdc0e6c2ca3)
#         ;
#
#
#
#
#             var marker_f8523ab036b5d452577539ebccb00a92 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5d9016d163bb21edeb1d6b5cca4ff08d);
#
#
#         var popup_2833b87b0b888b474b5dc45a2495809c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e95a140f8222e79ce0a0e10a0708f941 = $(`&lt;div id=&quot;html_e95a140f8222e79ce0a0e10a0708f941&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2833b87b0b888b474b5dc45a2495809c.setContent(html_e95a140f8222e79ce0a0e10a0708f941);
#
#
#
#         marker_f8523ab036b5d452577539ebccb00a92.bindPopup(popup_2833b87b0b888b474b5dc45a2495809c)
#         ;
#
#
#
#
#             var marker_b7efc8f8a9d62c82d0d4da728519ba37 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5d9016d163bb21edeb1d6b5cca4ff08d);
#
#
#         var popup_bb23c7527d165285e4d59241cbd80c6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b99248bc1a568e35e861bbf34d005717 = $(`&lt;div id=&quot;html_b99248bc1a568e35e861bbf34d005717&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bb23c7527d165285e4d59241cbd80c6e.setContent(html_b99248bc1a568e35e861bbf34d005717);
#
#
#
#         marker_b7efc8f8a9d62c82d0d4da728519ba37.bindPopup(popup_bb23c7527d165285e4d59241cbd80c6e)
#         ;
#
#
#
#
#             var marker_8dc10afcb5882ce28044f406f897c7b9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5d9016d163bb21edeb1d6b5cca4ff08d);
#
#
#         var popup_f275929f7026068513d7e5404b4bbb90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7defb3c7d33604b36b5349629b357d60 = $(`&lt;div id=&quot;html_7defb3c7d33604b36b5349629b357d60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f275929f7026068513d7e5404b4bbb90.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_370162abb02fb419bd0ca6daee87670c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_370162abb02fb419bd0ca6daee87670c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_370162abb02fb419bd0ca6daee87670c = L.map(
#                 &quot;map_370162abb02fb419bd0ca6daee87670c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a2481b847aacda02a8b02c63a7103ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a2481b847aacda02a8b02c63a7103ab.addTo(map_370162abb02fb419bd0ca6daee87670c);
#
#
#             var feature_group_8ce6c933a100fe1aad417b57f805659e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8f48b61adf297fd0a1e78fa5318864f2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8ce6c933a100fe1aad417b57f805659e);
#
#
#         var popup_6dfe28a04cf637050b0ccd8a6e182ca5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0bec172cb3a4b1e8423489e62f0d555 = $(`&lt;div id=&quot;html_f0bec172cb3a4b1e8423489e62f0d555&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6dfe28a04cf637050b0ccd8a6e182ca5.setContent(html_f0bec172cb3a4b1e8423489e62f0d555);
#
#
#
#         marker_8f48b61adf297fd0a1e78fa5318864f2.bindPopup(popup_6dfe28a04cf637050b0ccd8a6e182ca5)
#         ;
#
#
#
#
#             var marker_609707d4cae1d22e4f13413985391b1a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8ce6c933a100fe1aad417b57f805659e);
#
#
#         var popup_3682a6a80881b367ca86c1d34d32f847 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afe06edaadd3de8cd9fea4b6449113d0 = $(`&lt;div id=&quot;html_afe06edaadd3de8cd9fea4b6449113d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3682a6a80881b367ca86c1d34d32f847.setContent(html_afe06edaadd3de8cd9fea4b6449113d0);
#
#
#
#         marker_609707d4cae1d22e4f13413985391b1a.bindPopup(popup_3682a6a80881b367ca86c1d34d32f847)
#         ;
#
#
#
#
#             var marker_321d7ccada5917df6daff01bbe4b55ff = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8ce6c933a100fe1aad417b57f805659e);
#
#
#         var popup_1645c4b84747607993a13f63d2564530 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e7c6d8e8bda2d1921caf4d7308edebd = $(`&lt;div id=&quot;html_3e7c6d8e8bda2d1921caf4d7308edebd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1645c4b84747607993a13f63d2564530.setContent(html_3e7c6d8e8bda2d1921caf4d7308edebd);
#
#
#
#         marker_321d7ccada5917df6daff01bbe4b55ff.bindPopup(popup_1645c4b84747607993a13f63d2564530)
#         ;
#
#
#
#
#             var marker_f104fff00230d24f77c5c5fbf76338f9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8ce6c933a100fe1aad417b57f805659e);
#
#
#         var popup_d2b90ea4bc3b237b3e623bb0cf417834 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b547682a049934035bd74a8cc49c70eb = $(`&lt;div id=&quot;html_b547682a049934035bd74a8cc49c70eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d2b90ea4bc3b237b3e623bb0cf417834.setContent(html_b547682a049934035bd74a8cc49c70eb);
#
#
#
#         marker_f104fff00230d24f77c5c5fbf76338f9.bindPopup(popup_d2b90ea4bc3b237b3e623bb0cf417834)
#         ;
#
#
#
#
#             var marker_b5557d9ed006085b777236868e02c332 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8ce6c933a100fe1aad417b57f805659e);
#
#
#         var popup_3be2c8a9101ecbf9ac3b5f4029c4b5c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7d1b96732a06e4fa19c852e42ecd269 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7d1b96732a06e4fa19c852e42ecd269&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7d1b96732a06e4fa19c852e42ecd269 = L.map(
#                 &quot;map_d7d1b96732a06e4fa19c852e42ecd269&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef897e23cf1183f520f61543874116b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ef897e23cf1183f520f61543874116b3.addTo(map_d7d1b96732a06e4fa19c852e42ecd269);
#
#
#             var feature_group_02e2e3ad18f5e8dab901b8922081091c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_02e2e3ad18f5e8dab901b8922081091c.addTo(map_d7d1b96732a06e4fa19c852e42ecd269);
#
#
#             var feature_group_sub_group_f65faf6abe7bca2938edcfdf2baceea3 = L.featureGroup.subGroup(
#                 feature_group_02e2e3ad18f5e8dab901b8922081091c
#             );
#
#
#             var marker_bc871693740f6d054973de38e0015e62 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f65faf6abe7bca2938edcfdf2baceea3);
#
#
#         var popup_8b9902251cf80224266c49911dae379a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bad64b4fef8234413ab46cabe46c4987 = $(`&lt;div id=&quot;html_bad64b4fef8234413ab46cabe46c4987&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8b9902251cf80224266c49911dae379a.setContent(html_bad64b4fef8234413ab46cabe46c4987);
#
#
#
#         marker_bc871693740f6d054973de38e0015e62.bindPopup(popup_8b9902251cf80224266c49911dae379a)
#         ;
#
#
#
#
#             var marker_b365b2c5b64abf2416ea2814f685308e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f65faf6abe7bca2938edcfdf2baceea3);
#
#
#         var popup_5109123b6b4dc4966a0858e2c5df2f81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e9c372ed1575e2afcd33d9ebb6a4272 = $(`&lt;div id=&quot;html_1e9c372ed1575e2afcd33d9ebb6a4272&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5109123b6b4dc4966a0858e2c5df2f81.setContent(html_1e9c372ed1575e2afcd33d9ebb6a4272);
#
#
#
#         marker_b365b2c5b64abf2416ea2814f685308e.bindPopup(popup_5109123b6b4dc4966a0858e2c5df2f81)
#         ;
#
#
#
#
#             var marker_ab359be48b44538f4635b534b8f44fcc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f65faf6abe7bca2938edcfdf2baceea3);
#
#
#         var popup_ff097e1d40623c828e3345fa4fd8a8bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c302ce2761cbd791bfb65019fb776dea = $(`&lt;div id=&quot;html_c302ce2761cbd791bfb65019fb776dea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ff097e1d40623c828e3345fa4fd8a8bc.setContent(html_c302ce2761cbd791bfb65019fb776dea);
#
#
#
#         marker_ab359be48b44538f4635b534b8f44fcc.bindPopup(popup_ff097e1d40623c828e3345fa4fd8a8bc)
#         ;
#
#
#
#
#             var marker_b275055ceef335a5c01969436268ed3b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f65faf6abe7bca2938edcfdf2baceea3);
#
#
#         var popup_7516559226f78c2844d98ece429ef8b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b58a8f7f19165b27817a3cbab96d228 = $(`&lt;div id=&quot;html_4b58a8f7f19165b27817a3cbab96d228&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7516559226f78c2844d98ece429ef8b6.setContent(html_4b58a8f7f19165b27817a3cbab96d228);
#
#
#
#         marker_
