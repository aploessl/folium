# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66350503d74735eedaff4530dc3f60fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66350503d74735eedaff4530dc3f60fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66350503d74735eedaff4530dc3f60fe = L.map(
#                 &quot;map_66350503d74735eedaff4530dc3f60fe&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1ed1c99a46204f7e78af77fa5958c4e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e1ed1c99a46204f7e78af77fa5958c4e.addTo(map_66350503d74735eedaff4530dc3f60fe);
#
#
#             var marker_47eae6216c993d85b93ef997d9b89860 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_66350503d74735eedaff4530dc3f60fe);
#
#
#         var popup_32a562cfe13769522c0a92227e7eb51b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf34506ef881eecd169eb1563ed07508 = $(`&lt;div id=&quot;html_bf34506ef881eecd169eb1563ed07508&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_32a562cfe13769522c0a92227e7eb51b.setContent(html_bf34506ef881eecd169eb1563ed07508);
#
#
#
#         marker_47eae6216c993d85b93ef997d9b89860.bindPopup(popup_32a562cfe13769522c0a92227e7eb51b)
#         ;
#
#
#
#
#             var marker_32ca11448521caab5ff1c5cfd19f0fd0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_66350503d74735eedaff4530dc3f60fe);
#
#
#         var popup_573197a38c658234da2ca620e0f63c1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e7f3a0a221d120ffc97f98e237fa59c = $(`&lt;div id=&quot;html_6e7f3a0a221d120ffc97f98e237fa59c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_573197a38c658234da2ca620e0f63c1e.setContent(html_6e7f3a0a221d120ffc97f98e237fa59c);
#
#
#
#         marker_32ca11448521caab5ff1c5cfd19f0fd0.bindPopup(popup_573197a38c658234da2ca620e0f63c1e)
#         ;
#
#
#
#
#             var marker_e8e53ae7cbfbdb858d02397ef55d8623 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_66350503d74735eedaff4530dc3f60fe);
#
#
#         var popup_c238eac8e20f5eb1a16684cfe33b423a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2e22146ceecf0c07b8f382236f5bf39 = $(`&lt;div id=&quot;html_a2e22146ceecf0c07b8f382236f5bf39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c238eac8e20f5eb1a16684cfe33b423a.setContent(html_a2e22146ceecf0c07b8f382236f5bf39);
#
#
#
#         marker_e8e53ae7cbfbdb858d02397ef55d8623.bindPopup(popup_c238eac8e20f5eb1a16684cfe33b423a)
#         ;
#
#
#
#
#             var marker_070ab61a50f201f80eeaeb843aa3fece = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_66350503d74735eedaff4530dc3f60fe);
#
#
#         var popup_6a3d3d6eba90e357d8e873932bb60a16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f1483dfe1b45d6c7f8eab94d483a142 = $(`&lt;div id=&quot;html_9f1483dfe1b45d6c7f8eab94d483a142&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6a3d3d6eba90e357d8e873932bb60a16.setContent(html_9f1483dfe1b45d6c7f8eab94d483a142);
#
#
#
#         marker_070ab61a50f201f80eeaeb843aa3fece.bindPopup(popup_6a3d3d6eba90e357d8e873932bb60a16)
#         ;
#
#
#
#
#             var marker_ba39d71320f7ffe259c2b588e22b9575 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_66350503d74735eedaff4530dc3f60fe);
#
#
#         var popup_01831618209912189c76759322e61c58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_647baba33f3d6a129ee62a7e9aae0ad0 = $(`&lt;div id=&quot;html_647baba33f3d6a129ee62a7e9aae0ad0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_01831618209912189c76759322e61c58.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_187ddb13b0c6a9ac6bfb9b31d4be7cd5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_187ddb13b0c6a9ac6bfb9b31d4be7cd5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_187ddb13b0c6a9ac6bfb9b31d4be7cd5 = L.map(
#                 &quot;map_187ddb13b0c6a9ac6bfb9b31d4be7cd5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75dd4307288d62d3b264d65be5e10cc5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_75dd4307288d62d3b264d65be5e10cc5.addTo(map_187ddb13b0c6a9ac6bfb9b31d4be7cd5);
#
#
#             var feature_group_716d15a4a89db67fe455ca191a11c7d4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_934dc11012b600d9d27cb32d57328021 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_716d15a4a89db67fe455ca191a11c7d4);
#
#
#         var popup_4209d30391ad19f0d764b1368c9bf9c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8283bc6d60e12b1100ff0c313866045d = $(`&lt;div id=&quot;html_8283bc6d60e12b1100ff0c313866045d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4209d30391ad19f0d764b1368c9bf9c3.setContent(html_8283bc6d60e12b1100ff0c313866045d);
#
#
#
#         marker_934dc11012b600d9d27cb32d57328021.bindPopup(popup_4209d30391ad19f0d764b1368c9bf9c3)
#         ;
#
#
#
#
#             var marker_150b8c7f30d051be51334ac44052f280 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_716d15a4a89db67fe455ca191a11c7d4);
#
#
#         var popup_5142b3801b8530eb683990f3fc3e4c6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13593570ea6eea65dfe531a9d81a6149 = $(`&lt;div id=&quot;html_13593570ea6eea65dfe531a9d81a6149&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5142b3801b8530eb683990f3fc3e4c6d.setContent(html_13593570ea6eea65dfe531a9d81a6149);
#
#
#
#         marker_150b8c7f30d051be51334ac44052f280.bindPopup(popup_5142b3801b8530eb683990f3fc3e4c6d)
#         ;
#
#
#
#
#             var marker_822cf1ef66b794982315aee2438e3642 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_716d15a4a89db67fe455ca191a11c7d4);
#
#
#         var popup_ed5776c2f0bc3b0dbf84ab58749217c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a8a9e0ed17baf73294d924b0908d49e = $(`&lt;div id=&quot;html_9a8a9e0ed17baf73294d924b0908d49e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ed5776c2f0bc3b0dbf84ab58749217c4.setContent(html_9a8a9e0ed17baf73294d924b0908d49e);
#
#
#
#         marker_822cf1ef66b794982315aee2438e3642.bindPopup(popup_ed5776c2f0bc3b0dbf84ab58749217c4)
#         ;
#
#
#
#
#             var marker_0cd3dfb9083b573c21dcfebc31660bef = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_716d15a4a89db67fe455ca191a11c7d4);
#
#
#         var popup_0cddb65702cfd929c6dbfe76590f1fbe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6626925c8b6b5f648a6bad9f6bf4b045 = $(`&lt;div id=&quot;html_6626925c8b6b5f648a6bad9f6bf4b045&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0cddb65702cfd929c6dbfe76590f1fbe.setContent(html_6626925c8b6b5f648a6bad9f6bf4b045);
#
#
#
#         marker_0cd3dfb9083b573c21dcfebc31660bef.bindPopup(popup_0cddb65702cfd929c6dbfe76590f1fbe)
#         ;
#
#
#
#
#             var marker_a60b13da96ebd1d23a5aa15a942527cd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_716d15a4a89db67fe455ca191a11c7d4);
#
#
#         var popup_ccb88dd981b3f7651ff8ac10cb9ebb6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3abf089259409fc4b9c0100019da6a5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3abf089259409fc4b9c0100019da6a5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3abf089259409fc4b9c0100019da6a5c = L.map(
#                 &quot;map_3abf089259409fc4b9c0100019da6a5c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f77da58c6c69b9314a03f9c8ee1165d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f77da58c6c69b9314a03f9c8ee1165d.addTo(map_3abf089259409fc4b9c0100019da6a5c);
#
#
#             var feature_group_df0c0c441fedf19c6fd86917ebd04d25 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_df0c0c441fedf19c6fd86917ebd04d25.addTo(map_3abf089259409fc4b9c0100019da6a5c);
#
#
#             var feature_group_sub_group_c24e3875b1b6721ffa2c054aa7fff3cb = L.featureGroup.subGroup(
#                 feature_group_df0c0c441fedf19c6fd86917ebd04d25
#             );
#
#
#             var marker_d91ef87918bd9aefd040d79a8385a235 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c24e3875b1b6721ffa2c054aa7fff3cb);
#
#
#         var popup_37826aa9421988abbfffe2bfcdda0502 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6c3620b7f242d7dc27289b2369517e0 = $(`&lt;div id=&quot;html_c6c3620b7f242d7dc27289b2369517e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_37826aa9421988abbfffe2bfcdda0502.setContent(html_c6c3620b7f242d7dc27289b2369517e0);
#
#
#
#         marker_d91ef87918bd9aefd040d79a8385a235.bindPopup(popup_37826aa9421988abbfffe2bfcdda0502)
#         ;
#
#
#
#
#             var marker_f951bb8d4da2a5ceb3d75a216b16cb8b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c24e3875b1b6721ffa2c054aa7fff3cb);
#
#
#         var popup_26c0ebb802c82e2ab030c951355b1639 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2171876c5a07b891989ee9d4fb8f214 = $(`&lt;div id=&quot;html_f2171876c5a07b891989ee9d4fb8f214&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_26c0ebb802c82e2ab030c951355b1639.setContent(html_f2171876c5a07b891989ee9d4fb8f214);
#
#
#
#         marker_f951bb8d4da2a5ceb3d75a216b16cb8b.bindPopup(popup_26c0ebb802c82e2ab030c951355b1639)
#         ;
#
#
#
#
#             var marker_aff67a93e32ece39d37052dcafa1c847 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c24e3875b1b6721ffa2c054aa7fff3cb);
#
#
#         var popup_38c3912a61916b94dbb1dae860104ce4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69779f202f6d7bed4396a818504a5057 = $(`&lt;div id=&quot;html_69779f202f6d7bed4396a818504a5057&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_38c3912a61916b94dbb1dae860104ce4.setContent(html_69779f202f6d7bed4396a818504a5057);
#
#
#
#         marker_aff67a93e32ece39d37052dcafa1c847.bindPopup(popup_38c3912a61916b94dbb1dae860104ce4)
#         ;
#
#
#
#
#             var marker_5c087751450dedc0ee142420e4e6ed2e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c24e3875b1b6721ffa2c054aa7fff3cb);
#
#
#         var popup_94c9bcd8061bcf010a9d491c7f2bac2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1db994897f838613b9b4ad4dc0b6c409 = $(`&lt;div id=&quot;html_1db994897f838613b9b4ad4dc0b6c409&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_94c9bcd8061bcf010a9d491c7f2bac2c.setContent(html_1db994897f838613b9b4ad4dc0b6c409);
#
#
#
#         marker_
