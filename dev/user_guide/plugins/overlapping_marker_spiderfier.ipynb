# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5872caf215c8dca070381f85c4f7c112 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5872caf215c8dca070381f85c4f7c112&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5872caf215c8dca070381f85c4f7c112 = L.map(
#                 &quot;map_5872caf215c8dca070381f85c4f7c112&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0875f0a7c2ae32836bf261489243237 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0875f0a7c2ae32836bf261489243237.addTo(map_5872caf215c8dca070381f85c4f7c112);
#
#
#             var marker_d6c03a974ecee9540754fcab171fdf4c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5872caf215c8dca070381f85c4f7c112);
#
#
#         var popup_08de4f7b34f31fb772ad8dbf9518a7f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cd5771ba76ab48705e4bde45bfdbcdf = $(`&lt;div id=&quot;html_0cd5771ba76ab48705e4bde45bfdbcdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_08de4f7b34f31fb772ad8dbf9518a7f7.setContent(html_0cd5771ba76ab48705e4bde45bfdbcdf);
#
#
#
#         marker_d6c03a974ecee9540754fcab171fdf4c.bindPopup(popup_08de4f7b34f31fb772ad8dbf9518a7f7)
#         ;
#
#
#
#
#             var marker_7761011d166d445bcf9656a5a8eb6f7a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5872caf215c8dca070381f85c4f7c112);
#
#
#         var popup_84198c7005693d1c70ee226233acaf16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10b56cf8446a56b42ceb6fb7c5a16ff6 = $(`&lt;div id=&quot;html_10b56cf8446a56b42ceb6fb7c5a16ff6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_84198c7005693d1c70ee226233acaf16.setContent(html_10b56cf8446a56b42ceb6fb7c5a16ff6);
#
#
#
#         marker_7761011d166d445bcf9656a5a8eb6f7a.bindPopup(popup_84198c7005693d1c70ee226233acaf16)
#         ;
#
#
#
#
#             var marker_a159421887a1d3bfcc37e90d42c11f56 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5872caf215c8dca070381f85c4f7c112);
#
#
#         var popup_db687367fca77492fe71fe03fec75e57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e49db407c76abf4f4e37798c5769088 = $(`&lt;div id=&quot;html_2e49db407c76abf4f4e37798c5769088&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_db687367fca77492fe71fe03fec75e57.setContent(html_2e49db407c76abf4f4e37798c5769088);
#
#
#
#         marker_a159421887a1d3bfcc37e90d42c11f56.bindPopup(popup_db687367fca77492fe71fe03fec75e57)
#         ;
#
#
#
#
#             var marker_7d90d73c7dd40376fe44b0f9ffe7e0e3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5872caf215c8dca070381f85c4f7c112);
#
#
#         var popup_307a4511803addf0e861ee9a62b7b196 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83fcc6b85c73ef5f477e68c42e0a0c22 = $(`&lt;div id=&quot;html_83fcc6b85c73ef5f477e68c42e0a0c22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_307a4511803addf0e861ee9a62b7b196.setContent(html_83fcc6b85c73ef5f477e68c42e0a0c22);
#
#
#
#         marker_7d90d73c7dd40376fe44b0f9ffe7e0e3.bindPopup(popup_307a4511803addf0e861ee9a62b7b196)
#         ;
#
#
#
#
#             var marker_e1ba87002049118a0c689729f9edc33f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5872caf215c8dca070381f85c4f7c112);
#
#
#         var popup_cf57fd8501dfb44b8867348b9fae8661 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ec643492860427f6552aec62e044f18 = $(`&lt;div id=&quot;html_8ec643492860427f6552aec62e044f18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_cf57fd8501dfb44b8867348b9fae8661.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23a4258ceb3b9fcd4a6b24369c8594d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23a4258ceb3b9fcd4a6b24369c8594d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23a4258ceb3b9fcd4a6b24369c8594d9 = L.map(
#                 &quot;map_23a4258ceb3b9fcd4a6b24369c8594d9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e972dcb12a2ae3db873f5ebec8027a6a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e972dcb12a2ae3db873f5ebec8027a6a.addTo(map_23a4258ceb3b9fcd4a6b24369c8594d9);
#
#
#             var feature_group_62eb27d39e865db895db509e3a13eda1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4767fa58c752b630585e9a36b74feac2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_62eb27d39e865db895db509e3a13eda1);
#
#
#         var popup_7123494bacb827196be31492bf0ea0b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c2f8a69571c806dfd4a70f4682a9b45 = $(`&lt;div id=&quot;html_3c2f8a69571c806dfd4a70f4682a9b45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7123494bacb827196be31492bf0ea0b9.setContent(html_3c2f8a69571c806dfd4a70f4682a9b45);
#
#
#
#         marker_4767fa58c752b630585e9a36b74feac2.bindPopup(popup_7123494bacb827196be31492bf0ea0b9)
#         ;
#
#
#
#
#             var marker_07ac792d13fd96db970cc9678de4afdf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_62eb27d39e865db895db509e3a13eda1);
#
#
#         var popup_d1cd02d11bff43b2d805bc8faecb8e04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_815d3ba311746b206d0f4a5fdcad3879 = $(`&lt;div id=&quot;html_815d3ba311746b206d0f4a5fdcad3879&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d1cd02d11bff43b2d805bc8faecb8e04.setContent(html_815d3ba311746b206d0f4a5fdcad3879);
#
#
#
#         marker_07ac792d13fd96db970cc9678de4afdf.bindPopup(popup_d1cd02d11bff43b2d805bc8faecb8e04)
#         ;
#
#
#
#
#             var marker_ee10b814d1bac0cf75d5b48d5fb15526 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_62eb27d39e865db895db509e3a13eda1);
#
#
#         var popup_c8534b284135c7fcd5bf0293fa78704d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38dc0d8d8769fe27bbe98732900e4e7c = $(`&lt;div id=&quot;html_38dc0d8d8769fe27bbe98732900e4e7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c8534b284135c7fcd5bf0293fa78704d.setContent(html_38dc0d8d8769fe27bbe98732900e4e7c);
#
#
#
#         marker_ee10b814d1bac0cf75d5b48d5fb15526.bindPopup(popup_c8534b284135c7fcd5bf0293fa78704d)
#         ;
#
#
#
#
#             var marker_84391d90b228a75606857f1f189258ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_62eb27d39e865db895db509e3a13eda1);
#
#
#         var popup_032b960b4b9a6187b8f4437cf61235a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11e1f2393f5ced13891c30afc70f4a68 = $(`&lt;div id=&quot;html_11e1f2393f5ced13891c30afc70f4a68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_032b960b4b9a6187b8f4437cf61235a7.setContent(html_11e1f2393f5ced13891c30afc70f4a68);
#
#
#
#         marker_84391d90b228a75606857f1f189258ac.bindPopup(popup_032b960b4b9a6187b8f4437cf61235a7)
#         ;
#
#
#
#
#             var marker_94600da704896fe1466c71d36f19a680 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_62eb27d39e865db895db509e3a13eda1);
#
#
#         var popup_523e6441f369b2b9febf676efb2eb7df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6cba40afcf9c97e48179c9fdc69ecc5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6cba40afcf9c97e48179c9fdc69ecc5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6cba40afcf9c97e48179c9fdc69ecc5 = L.map(
#                 &quot;map_c6cba40afcf9c97e48179c9fdc69ecc5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72461915b4116a30e9d1f58a46e0404b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_72461915b4116a30e9d1f58a46e0404b.addTo(map_c6cba40afcf9c97e48179c9fdc69ecc5);
#
#
#             var feature_group_7f0665220eee79286d297fcc9e60f188 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7f0665220eee79286d297fcc9e60f188.addTo(map_c6cba40afcf9c97e48179c9fdc69ecc5);
#
#
#             var feature_group_sub_group_ef80e242a6e93b1b32fbf0146d9fb14c = L.featureGroup.subGroup(
#                 feature_group_7f0665220eee79286d297fcc9e60f188
#             );
#
#
#             var marker_f5f588b1ca370a08b424c628f5ff2417 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef80e242a6e93b1b32fbf0146d9fb14c);
#
#
#         var popup_c81934efbdcd2f1d730e36f371a172ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0897b6c0070cfae253d53fbcd8c1687 = $(`&lt;div id=&quot;html_a0897b6c0070cfae253d53fbcd8c1687&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c81934efbdcd2f1d730e36f371a172ff.setContent(html_a0897b6c0070cfae253d53fbcd8c1687);
#
#
#
#         marker_f5f588b1ca370a08b424c628f5ff2417.bindPopup(popup_c81934efbdcd2f1d730e36f371a172ff)
#         ;
#
#
#
#
#             var marker_1547aae5417f687f39154f7bd343c89e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef80e242a6e93b1b32fbf0146d9fb14c);
#
#
#         var popup_2225242701f5dcaeb78f02138b6243ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2442350cdbb1e35d32880cc475d4d690 = $(`&lt;div id=&quot;html_2442350cdbb1e35d32880cc475d4d690&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2225242701f5dcaeb78f02138b6243ae.setContent(html_2442350cdbb1e35d32880cc475d4d690);
#
#
#
#         marker_1547aae5417f687f39154f7bd343c89e.bindPopup(popup_2225242701f5dcaeb78f02138b6243ae)
#         ;
#
#
#
#
#             var marker_44bc09a889f980ce65b59727e3445b1d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef80e242a6e93b1b32fbf0146d9fb14c);
#
#
#         var popup_3b8b9136bb8640a4476ea8463039652b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1422423bafbd7843d2a792373ae7e8d = $(`&lt;div id=&quot;html_b1422423bafbd7843d2a792373ae7e8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3b8b9136bb8640a4476ea8463039652b.setContent(html_b1422423bafbd7843d2a792373ae7e8d);
#
#
#
#         marker_44bc09a889f980ce65b59727e3445b1d.bindPopup(popup_3b8b9136bb8640a4476ea8463039652b)
#         ;
#
#
#
#
#             var marker_a3b647cfd019261f5f68303fb4dbdcaa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef80e242a6e93b1b32fbf0146d9fb14c);
#
#
#         var popup_a73772a1824c39af315596c03d2bfcdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1ac312f270a9260fd506f893035a3f0 = $(`&lt;div id=&quot;html_e1ac312f270a9260fd506f893035a3f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a73772a1824c39af315596c03d2bfcdc.setContent(html_e1ac312f270a9260fd506f893035a3f0);
#
#
#
#         marker_
