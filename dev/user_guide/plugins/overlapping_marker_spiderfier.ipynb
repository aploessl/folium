# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78a5d11735b34b3dbb7698ace09dc367 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78a5d11735b34b3dbb7698ace09dc367&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78a5d11735b34b3dbb7698ace09dc367 = L.map(
#                 &quot;map_78a5d11735b34b3dbb7698ace09dc367&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd350c7de0f8627691b4055b44ec03d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd350c7de0f8627691b4055b44ec03d5.addTo(map_78a5d11735b34b3dbb7698ace09dc367);
#
#
#             var marker_c79e47239e819c37b2649a61dd90c19c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_78a5d11735b34b3dbb7698ace09dc367);
#
#
#         var popup_5f11b3bef171a911e3cbfee2c07adc14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c447775116fc86b79122ae2c2cbbae80 = $(`&lt;div id=&quot;html_c447775116fc86b79122ae2c2cbbae80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5f11b3bef171a911e3cbfee2c07adc14.setContent(html_c447775116fc86b79122ae2c2cbbae80);
#
#
#
#         marker_c79e47239e819c37b2649a61dd90c19c.bindPopup(popup_5f11b3bef171a911e3cbfee2c07adc14)
#         ;
#
#
#
#
#             var marker_c9075c265d96d617958c79579e5c5688 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_78a5d11735b34b3dbb7698ace09dc367);
#
#
#         var popup_55f9a0736fb52eec373ca6deba5341b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86174a9fe821bd91ccd64dd073152fba = $(`&lt;div id=&quot;html_86174a9fe821bd91ccd64dd073152fba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_55f9a0736fb52eec373ca6deba5341b7.setContent(html_86174a9fe821bd91ccd64dd073152fba);
#
#
#
#         marker_c9075c265d96d617958c79579e5c5688.bindPopup(popup_55f9a0736fb52eec373ca6deba5341b7)
#         ;
#
#
#
#
#             var marker_7628565f0f291c886f29dc90b424a2fa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_78a5d11735b34b3dbb7698ace09dc367);
#
#
#         var popup_f179cced05d46ce618443047d8e22758 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24ad62b74c6d60670de61f704af2e69e = $(`&lt;div id=&quot;html_24ad62b74c6d60670de61f704af2e69e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f179cced05d46ce618443047d8e22758.setContent(html_24ad62b74c6d60670de61f704af2e69e);
#
#
#
#         marker_7628565f0f291c886f29dc90b424a2fa.bindPopup(popup_f179cced05d46ce618443047d8e22758)
#         ;
#
#
#
#
#             var marker_926dc65af409e601820b4af4ccfb1350 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_78a5d11735b34b3dbb7698ace09dc367);
#
#
#         var popup_f9c1ef0e35e3a05ded5b5fe43ac6203c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b83da723a631fe935dfdb66500f28bb = $(`&lt;div id=&quot;html_8b83da723a631fe935dfdb66500f28bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f9c1ef0e35e3a05ded5b5fe43ac6203c.setContent(html_8b83da723a631fe935dfdb66500f28bb);
#
#
#
#         marker_926dc65af409e601820b4af4ccfb1350.bindPopup(popup_f9c1ef0e35e3a05ded5b5fe43ac6203c)
#         ;
#
#
#
#
#             var marker_9afe008bfd04a071b68ddab87f487a1f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_78a5d11735b34b3dbb7698ace09dc367);
#
#
#         var popup_71c546c342c0b5a25524ac4b39fd9fae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cb971d94523e78bc992d3ff4b53718b = $(`&lt;div id=&quot;html_3cb971d94523e78bc992d3ff4b53718b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_71c546c342c0b5a25524ac4b39fd9fae.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c48560512adc75e4c378ad562fd76ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c48560512adc75e4c378ad562fd76ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c48560512adc75e4c378ad562fd76ab = L.map(
#                 &quot;map_2c48560512adc75e4c378ad562fd76ab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07596d2db44cab2d40612543406187cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07596d2db44cab2d40612543406187cd.addTo(map_2c48560512adc75e4c378ad562fd76ab);
#
#
#             var feature_group_b2dd1983dcabbbc5950ba296bbfd56b5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_882643e748dd959352804dbfd7ea3946 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b2dd1983dcabbbc5950ba296bbfd56b5);
#
#
#         var popup_e09ab88ef3c2c94dcf87dfe3bac92897 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5553be6a911e324ce312a23824454714 = $(`&lt;div id=&quot;html_5553be6a911e324ce312a23824454714&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e09ab88ef3c2c94dcf87dfe3bac92897.setContent(html_5553be6a911e324ce312a23824454714);
#
#
#
#         marker_882643e748dd959352804dbfd7ea3946.bindPopup(popup_e09ab88ef3c2c94dcf87dfe3bac92897)
#         ;
#
#
#
#
#             var marker_c0be1cd3d68f23dc8766c70230a788b2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b2dd1983dcabbbc5950ba296bbfd56b5);
#
#
#         var popup_880fb5b0581fa768ca166660982f3c5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_569737855d7a75ab17894e7ee78f95ba = $(`&lt;div id=&quot;html_569737855d7a75ab17894e7ee78f95ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_880fb5b0581fa768ca166660982f3c5f.setContent(html_569737855d7a75ab17894e7ee78f95ba);
#
#
#
#         marker_c0be1cd3d68f23dc8766c70230a788b2.bindPopup(popup_880fb5b0581fa768ca166660982f3c5f)
#         ;
#
#
#
#
#             var marker_28a10d260feb1311ec1fc928152abfe7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b2dd1983dcabbbc5950ba296bbfd56b5);
#
#
#         var popup_d73978cf0d6e0e1013ae00f70b557dde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_733800d72f0cfdc59bbb56990d19fb67 = $(`&lt;div id=&quot;html_733800d72f0cfdc59bbb56990d19fb67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d73978cf0d6e0e1013ae00f70b557dde.setContent(html_733800d72f0cfdc59bbb56990d19fb67);
#
#
#
#         marker_28a10d260feb1311ec1fc928152abfe7.bindPopup(popup_d73978cf0d6e0e1013ae00f70b557dde)
#         ;
#
#
#
#
#             var marker_aa810e7961f22efbd45707a33a1b0e66 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b2dd1983dcabbbc5950ba296bbfd56b5);
#
#
#         var popup_631cc733e1281e54e19ccc43a210c910 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7c878218c3ed25cbad658585a2cac26 = $(`&lt;div id=&quot;html_b7c878218c3ed25cbad658585a2cac26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_631cc733e1281e54e19ccc43a210c910.setContent(html_b7c878218c3ed25cbad658585a2cac26);
#
#
#
#         marker_aa810e7961f22efbd45707a33a1b0e66.bindPopup(popup_631cc733e1281e54e19ccc43a210c910)
#         ;
#
#
#
#
#             var marker_35af332cc4fbbfdd96291676c1144efa = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b2dd1983dcabbbc5950ba296bbfd56b5);
#
#
#         var popup_204f98b14327cc62a70c83b5ca17bc88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c48f75d6c5f83526fc26549ba2733e84 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c48f75d6c5f83526fc26549ba2733e84&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c48f75d6c5f83526fc26549ba2733e84 = L.map(
#                 &quot;map_c48f75d6c5f83526fc26549ba2733e84&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2501e42775382b6cf7368e63c46fe048 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2501e42775382b6cf7368e63c46fe048.addTo(map_c48f75d6c5f83526fc26549ba2733e84);
#
#
#             var feature_group_c67ada3dd1d2e779c76276db99f1cbc6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c67ada3dd1d2e779c76276db99f1cbc6.addTo(map_c48f75d6c5f83526fc26549ba2733e84);
#
#
#             var feature_group_sub_group_4bbe0662829cf135cad3f0f10a66866b = L.featureGroup.subGroup(
#                 feature_group_c67ada3dd1d2e779c76276db99f1cbc6
#             );
#
#
#             var marker_b4ded87e6cfd5a06ccd6330a04fe757d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4bbe0662829cf135cad3f0f10a66866b);
#
#
#         var popup_32da3e6c1a882b9ae7eb37dc0f5c726e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_825e5238134866d0db17bd8a331a9a36 = $(`&lt;div id=&quot;html_825e5238134866d0db17bd8a331a9a36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_32da3e6c1a882b9ae7eb37dc0f5c726e.setContent(html_825e5238134866d0db17bd8a331a9a36);
#
#
#
#         marker_b4ded87e6cfd5a06ccd6330a04fe757d.bindPopup(popup_32da3e6c1a882b9ae7eb37dc0f5c726e)
#         ;
#
#
#
#
#             var marker_dc653e30c310188674781461fd4ff867 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4bbe0662829cf135cad3f0f10a66866b);
#
#
#         var popup_7ab83f8c68450c19fcfdec9127474481 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca273248873959bad2d78a8399868d93 = $(`&lt;div id=&quot;html_ca273248873959bad2d78a8399868d93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7ab83f8c68450c19fcfdec9127474481.setContent(html_ca273248873959bad2d78a8399868d93);
#
#
#
#         marker_dc653e30c310188674781461fd4ff867.bindPopup(popup_7ab83f8c68450c19fcfdec9127474481)
#         ;
#
#
#
#
#             var marker_9c495a5ae0e19b979eeeced23f17a3ec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4bbe0662829cf135cad3f0f10a66866b);
#
#
#         var popup_fafdfe562ae28d3e174bfb4d15d14d47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30339bfcf1aedf6fe0ae12a07f01e928 = $(`&lt;div id=&quot;html_30339bfcf1aedf6fe0ae12a07f01e928&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fafdfe562ae28d3e174bfb4d15d14d47.setContent(html_30339bfcf1aedf6fe0ae12a07f01e928);
#
#
#
#         marker_9c495a5ae0e19b979eeeced23f17a3ec.bindPopup(popup_fafdfe562ae28d3e174bfb4d15d14d47)
#         ;
#
#
#
#
#             var marker_5f739c12194580a8fabc1ded7d972d30 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4bbe0662829cf135cad3f0f10a66866b);
#
#
#         var popup_89391999abffbc694a25979e26ddd205 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33bbb42fd7d14e843f90ef29ecbd4ed3 = $(`&lt;div id=&quot;html_33bbb42fd7d14e843f90ef29ecbd4ed3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_89391999abffbc694a25979e26ddd205.setContent(html_33bbb42fd7d14e843f90ef29ecbd4ed3);
#
#
#
#         marker_
