# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c693e405de3ce0b02d035e557fb941b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c693e405de3ce0b02d035e557fb941b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c693e405de3ce0b02d035e557fb941b = L.map(
#                 &quot;map_6c693e405de3ce0b02d035e557fb941b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d494389ed69161316deee55dacd44e83 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d494389ed69161316deee55dacd44e83.addTo(map_6c693e405de3ce0b02d035e557fb941b);
#
#
#             var marker_6496a41367660c831af6066fe62d799a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6c693e405de3ce0b02d035e557fb941b);
#
#
#         var popup_990912afcc209d1083bbbe080a2704c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c19dd85b023376ba4de4effccf0b50e4 = $(`&lt;div id=&quot;html_c19dd85b023376ba4de4effccf0b50e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_990912afcc209d1083bbbe080a2704c7.setContent(html_c19dd85b023376ba4de4effccf0b50e4);
#
#
#
#         marker_6496a41367660c831af6066fe62d799a.bindPopup(popup_990912afcc209d1083bbbe080a2704c7)
#         ;
#
#
#
#
#             var marker_c0a9508021700a0105d2316123a36e82 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6c693e405de3ce0b02d035e557fb941b);
#
#
#         var popup_a868c0f6e007ac0f6ae5ee4e9a30d640 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e50a5c72dd91a8500a0c9c77a27ae9e = $(`&lt;div id=&quot;html_3e50a5c72dd91a8500a0c9c77a27ae9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a868c0f6e007ac0f6ae5ee4e9a30d640.setContent(html_3e50a5c72dd91a8500a0c9c77a27ae9e);
#
#
#
#         marker_c0a9508021700a0105d2316123a36e82.bindPopup(popup_a868c0f6e007ac0f6ae5ee4e9a30d640)
#         ;
#
#
#
#
#             var marker_7dcc7d0d8ef02b88086da5d77af88428 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6c693e405de3ce0b02d035e557fb941b);
#
#
#         var popup_916eba33e1b8e6305da495c34fb4016f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74e86174af7e4729be90e75ebe98380b = $(`&lt;div id=&quot;html_74e86174af7e4729be90e75ebe98380b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_916eba33e1b8e6305da495c34fb4016f.setContent(html_74e86174af7e4729be90e75ebe98380b);
#
#
#
#         marker_7dcc7d0d8ef02b88086da5d77af88428.bindPopup(popup_916eba33e1b8e6305da495c34fb4016f)
#         ;
#
#
#
#
#             var marker_b7e3e254b66b31483adf3aa5de87d87b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6c693e405de3ce0b02d035e557fb941b);
#
#
#         var popup_0acb11f6191684f55d1b7f1326a735b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42faf7be09e04bbea6c22f108eb95b96 = $(`&lt;div id=&quot;html_42faf7be09e04bbea6c22f108eb95b96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0acb11f6191684f55d1b7f1326a735b4.setContent(html_42faf7be09e04bbea6c22f108eb95b96);
#
#
#
#         marker_b7e3e254b66b31483adf3aa5de87d87b.bindPopup(popup_0acb11f6191684f55d1b7f1326a735b4)
#         ;
#
#
#
#
#             var marker_5dd0f12f0c7b617fac024698d71f9d2e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6c693e405de3ce0b02d035e557fb941b);
#
#
#         var popup_9692480708db227697a36678762c9d7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7ec96a9a6e2856730e24b68cc383b2b = $(`&lt;div id=&quot;html_c7ec96a9a6e2856730e24b68cc383b2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9692480708db227697a36678762c9d7e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73704f604d1de3542fd966a3886928b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73704f604d1de3542fd966a3886928b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73704f604d1de3542fd966a3886928b1 = L.map(
#                 &quot;map_73704f604d1de3542fd966a3886928b1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9be160ae0950411662ad9c473500fea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f9be160ae0950411662ad9c473500fea.addTo(map_73704f604d1de3542fd966a3886928b1);
#
#
#             var feature_group_98754351a8ab83457abe85de647b83b1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_01844a9dbfa284ee250cba7f4f0c325d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_98754351a8ab83457abe85de647b83b1);
#
#
#         var popup_fa2984b3dd93bf816dde3b284e61b988 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56794d89b29ed964afdc91046539c5c0 = $(`&lt;div id=&quot;html_56794d89b29ed964afdc91046539c5c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fa2984b3dd93bf816dde3b284e61b988.setContent(html_56794d89b29ed964afdc91046539c5c0);
#
#
#
#         marker_01844a9dbfa284ee250cba7f4f0c325d.bindPopup(popup_fa2984b3dd93bf816dde3b284e61b988)
#         ;
#
#
#
#
#             var marker_d6438cc830ef42aaba64a6f7a4cd015f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_98754351a8ab83457abe85de647b83b1);
#
#
#         var popup_8701dcbb3583ea071aa7d438aa921616 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e02847f2a5d4d0b0526368d48af31a4 = $(`&lt;div id=&quot;html_0e02847f2a5d4d0b0526368d48af31a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8701dcbb3583ea071aa7d438aa921616.setContent(html_0e02847f2a5d4d0b0526368d48af31a4);
#
#
#
#         marker_d6438cc830ef42aaba64a6f7a4cd015f.bindPopup(popup_8701dcbb3583ea071aa7d438aa921616)
#         ;
#
#
#
#
#             var marker_c144c3e59f9717d8d258b7c8e90dbe33 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_98754351a8ab83457abe85de647b83b1);
#
#
#         var popup_c3c79faf58ac48d3da2c58b17be3073d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc2ebce679fcb21046bca927783da2ba = $(`&lt;div id=&quot;html_cc2ebce679fcb21046bca927783da2ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c3c79faf58ac48d3da2c58b17be3073d.setContent(html_cc2ebce679fcb21046bca927783da2ba);
#
#
#
#         marker_c144c3e59f9717d8d258b7c8e90dbe33.bindPopup(popup_c3c79faf58ac48d3da2c58b17be3073d)
#         ;
#
#
#
#
#             var marker_ea2b371332f59946675c174a710ca6f7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_98754351a8ab83457abe85de647b83b1);
#
#
#         var popup_cf0e2f865ac8b2bb4764fefb93f42705 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8ef736a34e4e992eace03538cc43ec5 = $(`&lt;div id=&quot;html_a8ef736a34e4e992eace03538cc43ec5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cf0e2f865ac8b2bb4764fefb93f42705.setContent(html_a8ef736a34e4e992eace03538cc43ec5);
#
#
#
#         marker_ea2b371332f59946675c174a710ca6f7.bindPopup(popup_cf0e2f865ac8b2bb4764fefb93f42705)
#         ;
#
#
#
#
#             var marker_e127bd0ed00273d849030e746e79094e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_98754351a8ab83457abe85de647b83b1);
#
#
#         var popup_f849a4a1dacedd40f495ad678b181e05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93583cedefff3d99f618df429526567a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93583cedefff3d99f618df429526567a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93583cedefff3d99f618df429526567a = L.map(
#                 &quot;map_93583cedefff3d99f618df429526567a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_607c81209398904ca4055a29d99ef605 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_607c81209398904ca4055a29d99ef605.addTo(map_93583cedefff3d99f618df429526567a);
#
#
#             var feature_group_26acedb886ddd97ef98741b7e50e575c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_26acedb886ddd97ef98741b7e50e575c.addTo(map_93583cedefff3d99f618df429526567a);
#
#
#             var feature_group_sub_group_7ba4e9d49648bfebd0117505dae95194 = L.featureGroup.subGroup(
#                 feature_group_26acedb886ddd97ef98741b7e50e575c
#             );
#
#
#             var marker_b34d71ba132c4559c295c3d15b768bc0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7ba4e9d49648bfebd0117505dae95194);
#
#
#         var popup_3035ef77b4c62313997ebc688a54ba5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc21df492e681e0f5e45f1b2057dbb75 = $(`&lt;div id=&quot;html_bc21df492e681e0f5e45f1b2057dbb75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3035ef77b4c62313997ebc688a54ba5f.setContent(html_bc21df492e681e0f5e45f1b2057dbb75);
#
#
#
#         marker_b34d71ba132c4559c295c3d15b768bc0.bindPopup(popup_3035ef77b4c62313997ebc688a54ba5f)
#         ;
#
#
#
#
#             var marker_21229a5441f2e2f410d8b0a648f8af5c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7ba4e9d49648bfebd0117505dae95194);
#
#
#         var popup_177715ad025754120f3439f4e8bc6d2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9ab0e00f082147a71f1eeac970da41b = $(`&lt;div id=&quot;html_c9ab0e00f082147a71f1eeac970da41b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_177715ad025754120f3439f4e8bc6d2c.setContent(html_c9ab0e00f082147a71f1eeac970da41b);
#
#
#
#         marker_21229a5441f2e2f410d8b0a648f8af5c.bindPopup(popup_177715ad025754120f3439f4e8bc6d2c)
#         ;
#
#
#
#
#             var marker_6a5ebdb9965dbb1b7dc59057126650a6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7ba4e9d49648bfebd0117505dae95194);
#
#
#         var popup_e15af6b90fa2740c401e468584e26278 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed72cd47a7ec992eec2424fd90a2fae1 = $(`&lt;div id=&quot;html_ed72cd47a7ec992eec2424fd90a2fae1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e15af6b90fa2740c401e468584e26278.setContent(html_ed72cd47a7ec992eec2424fd90a2fae1);
#
#
#
#         marker_6a5ebdb9965dbb1b7dc59057126650a6.bindPopup(popup_e15af6b90fa2740c401e468584e26278)
#         ;
#
#
#
#
#             var marker_163144406e524f2c9866f7a04cd59772 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7ba4e9d49648bfebd0117505dae95194);
#
#
#         var popup_8f3e526b8895f0d09273c9852591557a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_041d302fad1b0aefba31fa2bace4b8c0 = $(`&lt;div id=&quot;html_041d302fad1b0aefba31fa2bace4b8c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8f3e526b8895f0d09273c9852591557a.setContent(html_041d302fad1b0aefba31fa2bace4b8c0);
#
#
#
#         marker_
