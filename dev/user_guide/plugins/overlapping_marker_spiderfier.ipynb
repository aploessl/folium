# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9b89ef1c2e136ba8f0c0a2c48c994c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9b89ef1c2e136ba8f0c0a2c48c994c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9b89ef1c2e136ba8f0c0a2c48c994c3 = L.map(
#                 &quot;map_f9b89ef1c2e136ba8f0c0a2c48c994c3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c109e1286b27508b7bc5641f1af1d9c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c109e1286b27508b7bc5641f1af1d9c5.addTo(map_f9b89ef1c2e136ba8f0c0a2c48c994c3);
#
#
#             var marker_f5d8e264a0be340106c60b53d99040ac = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f9b89ef1c2e136ba8f0c0a2c48c994c3);
#
#
#         var popup_4f06363951ad0b8e95e93ce7a38a8d6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ea08df5d0d758e7e8551bdc2b5e6da3 = $(`&lt;div id=&quot;html_9ea08df5d0d758e7e8551bdc2b5e6da3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4f06363951ad0b8e95e93ce7a38a8d6f.setContent(html_9ea08df5d0d758e7e8551bdc2b5e6da3);
#
#
#
#         marker_f5d8e264a0be340106c60b53d99040ac.bindPopup(popup_4f06363951ad0b8e95e93ce7a38a8d6f)
#         ;
#
#
#
#
#             var marker_a2de015e9256a4c27b4081150379f4a9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f9b89ef1c2e136ba8f0c0a2c48c994c3);
#
#
#         var popup_7d5fc68d23fd4db4083defc8ad3d54df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5265c42057dfd45d2995740b459b85db = $(`&lt;div id=&quot;html_5265c42057dfd45d2995740b459b85db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7d5fc68d23fd4db4083defc8ad3d54df.setContent(html_5265c42057dfd45d2995740b459b85db);
#
#
#
#         marker_a2de015e9256a4c27b4081150379f4a9.bindPopup(popup_7d5fc68d23fd4db4083defc8ad3d54df)
#         ;
#
#
#
#
#             var marker_d684a49c756487a0e22270cb8855a66e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f9b89ef1c2e136ba8f0c0a2c48c994c3);
#
#
#         var popup_2b1e312fb30a48d76035228586d125e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e5a4bfb0441999f615391e0deb83f13 = $(`&lt;div id=&quot;html_3e5a4bfb0441999f615391e0deb83f13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2b1e312fb30a48d76035228586d125e5.setContent(html_3e5a4bfb0441999f615391e0deb83f13);
#
#
#
#         marker_d684a49c756487a0e22270cb8855a66e.bindPopup(popup_2b1e312fb30a48d76035228586d125e5)
#         ;
#
#
#
#
#             var marker_3927a0eb84caacfdd5f26dd3cd81ae92 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f9b89ef1c2e136ba8f0c0a2c48c994c3);
#
#
#         var popup_bf333e965664c932b4be4e960978d40f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a0650f50018ceec65943e22423c27b8 = $(`&lt;div id=&quot;html_1a0650f50018ceec65943e22423c27b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bf333e965664c932b4be4e960978d40f.setContent(html_1a0650f50018ceec65943e22423c27b8);
#
#
#
#         marker_3927a0eb84caacfdd5f26dd3cd81ae92.bindPopup(popup_bf333e965664c932b4be4e960978d40f)
#         ;
#
#
#
#
#             var marker_921f8b8b28366a53789128b8d249690e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f9b89ef1c2e136ba8f0c0a2c48c994c3);
#
#
#         var popup_e1b21ae331b4c527276ef28e3ae3e8fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b065166ee79f84e3e5a5c713d3b8ac8 = $(`&lt;div id=&quot;html_1b065166ee79f84e3e5a5c713d3b8ac8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e1b21ae331b4c527276ef28e3ae3e8fb.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e452bc1f9c1186b4987a84630d84bd8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e452bc1f9c1186b4987a84630d84bd8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e452bc1f9c1186b4987a84630d84bd8b = L.map(
#                 &quot;map_e452bc1f9c1186b4987a84630d84bd8b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_232c1408dea5297206504b4a1edfc187 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_232c1408dea5297206504b4a1edfc187.addTo(map_e452bc1f9c1186b4987a84630d84bd8b);
#
#
#             var feature_group_76d979249be14a57abcc3209a1b660d5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0a30271d7070072084e0d67bb0ab9ef8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_76d979249be14a57abcc3209a1b660d5);
#
#
#         var popup_488e62c138da89e4ca852546b3f9ef19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92bb58f50d0f6c4e3dc4a8ebff30fe6c = $(`&lt;div id=&quot;html_92bb58f50d0f6c4e3dc4a8ebff30fe6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_488e62c138da89e4ca852546b3f9ef19.setContent(html_92bb58f50d0f6c4e3dc4a8ebff30fe6c);
#
#
#
#         marker_0a30271d7070072084e0d67bb0ab9ef8.bindPopup(popup_488e62c138da89e4ca852546b3f9ef19)
#         ;
#
#
#
#
#             var marker_311069a7ff407ea72df3232b49729fa2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_76d979249be14a57abcc3209a1b660d5);
#
#
#         var popup_a55538dbad847b267cdc4e4960f35058 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6233ede740aff2f20ab076a5f959e2cd = $(`&lt;div id=&quot;html_6233ede740aff2f20ab076a5f959e2cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a55538dbad847b267cdc4e4960f35058.setContent(html_6233ede740aff2f20ab076a5f959e2cd);
#
#
#
#         marker_311069a7ff407ea72df3232b49729fa2.bindPopup(popup_a55538dbad847b267cdc4e4960f35058)
#         ;
#
#
#
#
#             var marker_3d700d23ecb97499ea798419494dc2cc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_76d979249be14a57abcc3209a1b660d5);
#
#
#         var popup_e1c4d4da1036895bc9baeb6d38a9992d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23ddcc05f82cdc24245221bb04c61a04 = $(`&lt;div id=&quot;html_23ddcc05f82cdc24245221bb04c61a04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e1c4d4da1036895bc9baeb6d38a9992d.setContent(html_23ddcc05f82cdc24245221bb04c61a04);
#
#
#
#         marker_3d700d23ecb97499ea798419494dc2cc.bindPopup(popup_e1c4d4da1036895bc9baeb6d38a9992d)
#         ;
#
#
#
#
#             var marker_e805937fcd67f7b549b8f48b4c682d8e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_76d979249be14a57abcc3209a1b660d5);
#
#
#         var popup_cb1c309a56cd849c8d2f2ace963b06e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d30a6975c5d45ff6982fd97e387f2fee = $(`&lt;div id=&quot;html_d30a6975c5d45ff6982fd97e387f2fee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cb1c309a56cd849c8d2f2ace963b06e8.setContent(html_d30a6975c5d45ff6982fd97e387f2fee);
#
#
#
#         marker_e805937fcd67f7b549b8f48b4c682d8e.bindPopup(popup_cb1c309a56cd849c8d2f2ace963b06e8)
#         ;
#
#
#
#
#             var marker_ac0d8fffc4812e11651a52c326cf2dd8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_76d979249be14a57abcc3209a1b660d5);
#
#
#         var popup_464ae76683e3746b071c946a51f106d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cfc567b2156b8abc0976466d9951191 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cfc567b2156b8abc0976466d9951191&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cfc567b2156b8abc0976466d9951191 = L.map(
#                 &quot;map_1cfc567b2156b8abc0976466d9951191&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a149fda33f531c7d7f1882975f98b55 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a149fda33f531c7d7f1882975f98b55.addTo(map_1cfc567b2156b8abc0976466d9951191);
#
#
#             var feature_group_9c884b67da277cba2551074e94961b7c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9c884b67da277cba2551074e94961b7c.addTo(map_1cfc567b2156b8abc0976466d9951191);
#
#
#             var feature_group_sub_group_8333688e70347bcc2384ae86e30c6a9d = L.featureGroup.subGroup(
#                 feature_group_9c884b67da277cba2551074e94961b7c
#             );
#
#
#             var marker_1ca3560064a4201c1cda59f8cd773f93 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8333688e70347bcc2384ae86e30c6a9d);
#
#
#         var popup_51d5d3218a09f436295b60152e160477 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_802ae7b92adaf4d97ef94dd3dfe45474 = $(`&lt;div id=&quot;html_802ae7b92adaf4d97ef94dd3dfe45474&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_51d5d3218a09f436295b60152e160477.setContent(html_802ae7b92adaf4d97ef94dd3dfe45474);
#
#
#
#         marker_1ca3560064a4201c1cda59f8cd773f93.bindPopup(popup_51d5d3218a09f436295b60152e160477)
#         ;
#
#
#
#
#             var marker_00e57a09636ebf852c83d3f7e4e51350 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8333688e70347bcc2384ae86e30c6a9d);
#
#
#         var popup_a60566560fcb9bba50b9179b948b2c8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3bd3e01867d3d43208d71d04afef42e = $(`&lt;div id=&quot;html_c3bd3e01867d3d43208d71d04afef42e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a60566560fcb9bba50b9179b948b2c8e.setContent(html_c3bd3e01867d3d43208d71d04afef42e);
#
#
#
#         marker_00e57a09636ebf852c83d3f7e4e51350.bindPopup(popup_a60566560fcb9bba50b9179b948b2c8e)
#         ;
#
#
#
#
#             var marker_c3bf54409b2499b2e734b47efc32bc5f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8333688e70347bcc2384ae86e30c6a9d);
#
#
#         var popup_4ca80f67e3ef3e67dcca3d988a5126ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af09dcb69fd6a6503a0e3eeea1e8209e = $(`&lt;div id=&quot;html_af09dcb69fd6a6503a0e3eeea1e8209e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4ca80f67e3ef3e67dcca3d988a5126ff.setContent(html_af09dcb69fd6a6503a0e3eeea1e8209e);
#
#
#
#         marker_c3bf54409b2499b2e734b47efc32bc5f.bindPopup(popup_4ca80f67e3ef3e67dcca3d988a5126ff)
#         ;
#
#
#
#
#             var marker_ead33476bf6b633470ac81439c127cbb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8333688e70347bcc2384ae86e30c6a9d);
#
#
#         var popup_7c9952bb7f3e5cae496396f547bfb5cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5a3310343ac32996cbb1eaa3cdbb6c0 = $(`&lt;div id=&quot;html_a5a3310343ac32996cbb1eaa3cdbb6c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7c9952bb7f3e5cae496396f547bfb5cc.setContent(html_a5a3310343ac32996cbb1eaa3cdbb6c0);
#
#
#
#         marker_
