# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61d7d2f6f8f6c0d9cf351430f5a93ffa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61d7d2f6f8f6c0d9cf351430f5a93ffa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61d7d2f6f8f6c0d9cf351430f5a93ffa = L.map(
#                 &quot;map_61d7d2f6f8f6c0d9cf351430f5a93ffa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a18780f86305fbbffa1ac5982aae243a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a18780f86305fbbffa1ac5982aae243a.addTo(map_61d7d2f6f8f6c0d9cf351430f5a93ffa);
#
#
#             var marker_add3c756d3c5d3993548bacb4ad8a3ae = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_61d7d2f6f8f6c0d9cf351430f5a93ffa);
#
#
#         var popup_9a3dd210b35c3cfb32698147b8956b57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b3891753706dbcb26d121a2acd1c9a1 = $(`&lt;div id=&quot;html_6b3891753706dbcb26d121a2acd1c9a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9a3dd210b35c3cfb32698147b8956b57.setContent(html_6b3891753706dbcb26d121a2acd1c9a1);
#
#
#
#         marker_add3c756d3c5d3993548bacb4ad8a3ae.bindPopup(popup_9a3dd210b35c3cfb32698147b8956b57)
#         ;
#
#
#
#
#             var marker_2e3fc55658ee5c405224dfa3571240cd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_61d7d2f6f8f6c0d9cf351430f5a93ffa);
#
#
#         var popup_82bd9fd7d3e1ce9d847e0481e3b07723 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_451eb1b3199bbe9a9ad61b21ce09f543 = $(`&lt;div id=&quot;html_451eb1b3199bbe9a9ad61b21ce09f543&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_82bd9fd7d3e1ce9d847e0481e3b07723.setContent(html_451eb1b3199bbe9a9ad61b21ce09f543);
#
#
#
#         marker_2e3fc55658ee5c405224dfa3571240cd.bindPopup(popup_82bd9fd7d3e1ce9d847e0481e3b07723)
#         ;
#
#
#
#
#             var marker_1802abe804fe5f977aedb09e28814449 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_61d7d2f6f8f6c0d9cf351430f5a93ffa);
#
#
#         var popup_5f9344d02a2fb0c51436fabb6a0e6550 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb17532f78860e451927c2266eb432ce = $(`&lt;div id=&quot;html_fb17532f78860e451927c2266eb432ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5f9344d02a2fb0c51436fabb6a0e6550.setContent(html_fb17532f78860e451927c2266eb432ce);
#
#
#
#         marker_1802abe804fe5f977aedb09e28814449.bindPopup(popup_5f9344d02a2fb0c51436fabb6a0e6550)
#         ;
#
#
#
#
#             var marker_5d0e0b2b9ee3d4875045e6db4adfc2b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_61d7d2f6f8f6c0d9cf351430f5a93ffa);
#
#
#         var popup_b80cf41e9c584279a2b6b47b58379582 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b7a7ef0b658fb5527e1fa17bcb06bc4 = $(`&lt;div id=&quot;html_9b7a7ef0b658fb5527e1fa17bcb06bc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b80cf41e9c584279a2b6b47b58379582.setContent(html_9b7a7ef0b658fb5527e1fa17bcb06bc4);
#
#
#
#         marker_5d0e0b2b9ee3d4875045e6db4adfc2b4.bindPopup(popup_b80cf41e9c584279a2b6b47b58379582)
#         ;
#
#
#
#
#             var marker_582705f655141f72463e948ed642ba09 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_61d7d2f6f8f6c0d9cf351430f5a93ffa);
#
#
#         var popup_73e18d3ed3de8f65e67fb53f6592b4a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fce0e557ece4e8dfd12addb91cf2eab = $(`&lt;div id=&quot;html_2fce0e557ece4e8dfd12addb91cf2eab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_73e18d3ed3de8f65e67fb53f6592b4a1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f72503ce8352cb17bfdda03ff32650e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f72503ce8352cb17bfdda03ff32650e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f72503ce8352cb17bfdda03ff32650e7 = L.map(
#                 &quot;map_f72503ce8352cb17bfdda03ff32650e7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ce453824cad73d1f79fdece119e5963 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ce453824cad73d1f79fdece119e5963.addTo(map_f72503ce8352cb17bfdda03ff32650e7);
#
#
#             var feature_group_2b6308cf99fb045180591615227d1847 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8a444669cdf6cb4fc2dc009a697a784d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2b6308cf99fb045180591615227d1847);
#
#
#         var popup_c76d68a9ec773a9b3d65f37b641b8910 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d3c476f485910bb0157736b0fb44fa8 = $(`&lt;div id=&quot;html_0d3c476f485910bb0157736b0fb44fa8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c76d68a9ec773a9b3d65f37b641b8910.setContent(html_0d3c476f485910bb0157736b0fb44fa8);
#
#
#
#         marker_8a444669cdf6cb4fc2dc009a697a784d.bindPopup(popup_c76d68a9ec773a9b3d65f37b641b8910)
#         ;
#
#
#
#
#             var marker_5b5c992027035fa20beffde72cfd77d0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2b6308cf99fb045180591615227d1847);
#
#
#         var popup_acfc1b2cf294f55eebf5a62121627f8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d980a4cdc53042f3ac1fd89b42eead13 = $(`&lt;div id=&quot;html_d980a4cdc53042f3ac1fd89b42eead13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_acfc1b2cf294f55eebf5a62121627f8b.setContent(html_d980a4cdc53042f3ac1fd89b42eead13);
#
#
#
#         marker_5b5c992027035fa20beffde72cfd77d0.bindPopup(popup_acfc1b2cf294f55eebf5a62121627f8b)
#         ;
#
#
#
#
#             var marker_3b9e31c058a3bcae2776c34c55c2edd1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2b6308cf99fb045180591615227d1847);
#
#
#         var popup_d06966beaa7f8fd055aef638b08aaa9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_776df6711d405244a91e1d99418595a5 = $(`&lt;div id=&quot;html_776df6711d405244a91e1d99418595a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d06966beaa7f8fd055aef638b08aaa9d.setContent(html_776df6711d405244a91e1d99418595a5);
#
#
#
#         marker_3b9e31c058a3bcae2776c34c55c2edd1.bindPopup(popup_d06966beaa7f8fd055aef638b08aaa9d)
#         ;
#
#
#
#
#             var marker_e695a2cad7449e78d68a0bb66f719b4a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2b6308cf99fb045180591615227d1847);
#
#
#         var popup_5982bbc847222e8d03aaed842bcfb1f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae8ac9645aa2925e646db96a7f15f435 = $(`&lt;div id=&quot;html_ae8ac9645aa2925e646db96a7f15f435&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5982bbc847222e8d03aaed842bcfb1f6.setContent(html_ae8ac9645aa2925e646db96a7f15f435);
#
#
#
#         marker_e695a2cad7449e78d68a0bb66f719b4a.bindPopup(popup_5982bbc847222e8d03aaed842bcfb1f6)
#         ;
#
#
#
#
#             var marker_431a60993f974cbaa45158a3ab953f46 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2b6308cf99fb045180591615227d1847);
#
#
#         var popup_b1d5764d89af3dded490ed626fdbf880 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe512666ed0815e2084c4a285253bec7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe512666ed0815e2084c4a285253bec7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe512666ed0815e2084c4a285253bec7 = L.map(
#                 &quot;map_fe512666ed0815e2084c4a285253bec7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de0baf54e891ea7f2576bd6afd8cab9a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_de0baf54e891ea7f2576bd6afd8cab9a.addTo(map_fe512666ed0815e2084c4a285253bec7);
#
#
#             var feature_group_be53e3cecc13dfd7fdc5b629e5d80622 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_be53e3cecc13dfd7fdc5b629e5d80622.addTo(map_fe512666ed0815e2084c4a285253bec7);
#
#
#             var feature_group_sub_group_b6c333701b1668554bddc35651d76acc = L.featureGroup.subGroup(
#                 feature_group_be53e3cecc13dfd7fdc5b629e5d80622
#             );
#
#
#             var marker_3917ec413ffa614dfdd0a8f96dbe8e60 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b6c333701b1668554bddc35651d76acc);
#
#
#         var popup_d5c4bfa954ac560aff37334e0a75cbc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_631a0a1bee100dbf5680a7b5e82503c0 = $(`&lt;div id=&quot;html_631a0a1bee100dbf5680a7b5e82503c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d5c4bfa954ac560aff37334e0a75cbc8.setContent(html_631a0a1bee100dbf5680a7b5e82503c0);
#
#
#
#         marker_3917ec413ffa614dfdd0a8f96dbe8e60.bindPopup(popup_d5c4bfa954ac560aff37334e0a75cbc8)
#         ;
#
#
#
#
#             var marker_ebfb24bcb31f9f2f8df171ec3b7d9524 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b6c333701b1668554bddc35651d76acc);
#
#
#         var popup_9511110361d0c958d8c622fa7142939c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6a58bbdb30452497a1db25a8569d7f7 = $(`&lt;div id=&quot;html_f6a58bbdb30452497a1db25a8569d7f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9511110361d0c958d8c622fa7142939c.setContent(html_f6a58bbdb30452497a1db25a8569d7f7);
#
#
#
#         marker_ebfb24bcb31f9f2f8df171ec3b7d9524.bindPopup(popup_9511110361d0c958d8c622fa7142939c)
#         ;
#
#
#
#
#             var marker_44086b261716a6240886258f1be3754f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b6c333701b1668554bddc35651d76acc);
#
#
#         var popup_564ffabac315e39b73b96cc7af13f31e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e7b67af30ba4f9c6fe87d5066afa04f = $(`&lt;div id=&quot;html_0e7b67af30ba4f9c6fe87d5066afa04f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_564ffabac315e39b73b96cc7af13f31e.setContent(html_0e7b67af30ba4f9c6fe87d5066afa04f);
#
#
#
#         marker_44086b261716a6240886258f1be3754f.bindPopup(popup_564ffabac315e39b73b96cc7af13f31e)
#         ;
#
#
#
#
#             var marker_35f42b926f35c84b2578b752fd7a830d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b6c333701b1668554bddc35651d76acc);
#
#
#         var popup_7db06623fa0b6c909d2fb370e1aad278 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1182a0b3ce368b15a2c874862800a6d4 = $(`&lt;div id=&quot;html_1182a0b3ce368b15a2c874862800a6d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7db06623fa0b6c909d2fb370e1aad278.setContent(html_1182a0b3ce368b15a2c874862800a6d4);
#
#
#
#         marker_
