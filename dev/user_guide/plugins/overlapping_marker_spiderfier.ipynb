# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_535b659d2e8146c61c7ee728fac994b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_535b659d2e8146c61c7ee728fac994b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_535b659d2e8146c61c7ee728fac994b9 = L.map(
#                 &quot;map_535b659d2e8146c61c7ee728fac994b9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0865e19832550ecf87c0e94a200c143 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0865e19832550ecf87c0e94a200c143.addTo(map_535b659d2e8146c61c7ee728fac994b9);
#
#
#             var marker_fbaacb88f2272066337401f6e3e30dbf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_535b659d2e8146c61c7ee728fac994b9);
#
#
#         var popup_c588b71841ae314d5ff05813af66e5ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2b0ea3e92ed52437413307a037ce2ff = $(`&lt;div id=&quot;html_c2b0ea3e92ed52437413307a037ce2ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c588b71841ae314d5ff05813af66e5ab.setContent(html_c2b0ea3e92ed52437413307a037ce2ff);
#
#
#
#         marker_fbaacb88f2272066337401f6e3e30dbf.bindPopup(popup_c588b71841ae314d5ff05813af66e5ab)
#         ;
#
#
#
#
#             var marker_305e6292ef64af9900054fdc1beb0872 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_535b659d2e8146c61c7ee728fac994b9);
#
#
#         var popup_f42df74180b9df41102666fd35599f04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9d63d75db92dbeb95761b62454dde3b = $(`&lt;div id=&quot;html_c9d63d75db92dbeb95761b62454dde3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f42df74180b9df41102666fd35599f04.setContent(html_c9d63d75db92dbeb95761b62454dde3b);
#
#
#
#         marker_305e6292ef64af9900054fdc1beb0872.bindPopup(popup_f42df74180b9df41102666fd35599f04)
#         ;
#
#
#
#
#             var marker_2ffd21284583ab60a0e3abb5bbafae8c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_535b659d2e8146c61c7ee728fac994b9);
#
#
#         var popup_effc039b7f9ec5444db389be37cfdf36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0be10529756f958bc02cd42386fb0825 = $(`&lt;div id=&quot;html_0be10529756f958bc02cd42386fb0825&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_effc039b7f9ec5444db389be37cfdf36.setContent(html_0be10529756f958bc02cd42386fb0825);
#
#
#
#         marker_2ffd21284583ab60a0e3abb5bbafae8c.bindPopup(popup_effc039b7f9ec5444db389be37cfdf36)
#         ;
#
#
#
#
#             var marker_37f90acaa9ab5c5301ace8f5b45de8bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_535b659d2e8146c61c7ee728fac994b9);
#
#
#         var popup_8b4ea61e36461b336b03f24e385af2d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c076a3c6afb6295bad83295757903a6 = $(`&lt;div id=&quot;html_4c076a3c6afb6295bad83295757903a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8b4ea61e36461b336b03f24e385af2d6.setContent(html_4c076a3c6afb6295bad83295757903a6);
#
#
#
#         marker_37f90acaa9ab5c5301ace8f5b45de8bc.bindPopup(popup_8b4ea61e36461b336b03f24e385af2d6)
#         ;
#
#
#
#
#             var marker_897ffe132232c2bb9aa3d01df8adf75e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_535b659d2e8146c61c7ee728fac994b9);
#
#
#         var popup_2c9718a38c6b744cc0e325e0c622f5ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c74555d60333e9daa28bdca5e418c0f = $(`&lt;div id=&quot;html_7c74555d60333e9daa28bdca5e418c0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2c9718a38c6b744cc0e325e0c622f5ba.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b511cbde0624bb7bb6613e8d38857e7d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b511cbde0624bb7bb6613e8d38857e7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b511cbde0624bb7bb6613e8d38857e7d = L.map(
#                 &quot;map_b511cbde0624bb7bb6613e8d38857e7d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dcfc1d4316e71726d1f8eca1104933b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dcfc1d4316e71726d1f8eca1104933b7.addTo(map_b511cbde0624bb7bb6613e8d38857e7d);
#
#
#             var feature_group_0ac390bfe61181e4e20fb59a9fa245fa = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e7cabcb3c7afad807e12c70485c0442c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0ac390bfe61181e4e20fb59a9fa245fa);
#
#
#         var popup_ac66e4d99ea289e22d3bf0e007b7d22d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_218485ac0c65ae9e2a91f3dda54d7373 = $(`&lt;div id=&quot;html_218485ac0c65ae9e2a91f3dda54d7373&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ac66e4d99ea289e22d3bf0e007b7d22d.setContent(html_218485ac0c65ae9e2a91f3dda54d7373);
#
#
#
#         marker_e7cabcb3c7afad807e12c70485c0442c.bindPopup(popup_ac66e4d99ea289e22d3bf0e007b7d22d)
#         ;
#
#
#
#
#             var marker_b7af0178056dd40bb1ead4a9a42d3564 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0ac390bfe61181e4e20fb59a9fa245fa);
#
#
#         var popup_7ce0332ebdb04d2f66bf09d2dd3e15e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e8fec0ee10f0a571d4fa9b16a80a7ae = $(`&lt;div id=&quot;html_9e8fec0ee10f0a571d4fa9b16a80a7ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7ce0332ebdb04d2f66bf09d2dd3e15e1.setContent(html_9e8fec0ee10f0a571d4fa9b16a80a7ae);
#
#
#
#         marker_b7af0178056dd40bb1ead4a9a42d3564.bindPopup(popup_7ce0332ebdb04d2f66bf09d2dd3e15e1)
#         ;
#
#
#
#
#             var marker_9082c5d9d68debcfcdc134d535bd0b52 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0ac390bfe61181e4e20fb59a9fa245fa);
#
#
#         var popup_40c55e04110503ad73b28cde0216ef34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf103708f56ec455a5b3d612822e20d0 = $(`&lt;div id=&quot;html_bf103708f56ec455a5b3d612822e20d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_40c55e04110503ad73b28cde0216ef34.setContent(html_bf103708f56ec455a5b3d612822e20d0);
#
#
#
#         marker_9082c5d9d68debcfcdc134d535bd0b52.bindPopup(popup_40c55e04110503ad73b28cde0216ef34)
#         ;
#
#
#
#
#             var marker_662bcdd4260cbe558efd2d0face54c6d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0ac390bfe61181e4e20fb59a9fa245fa);
#
#
#         var popup_d0c1367c6164be0cd21dff3abb28d2bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ef3d5e3088b6053e575e3ce226583d9 = $(`&lt;div id=&quot;html_7ef3d5e3088b6053e575e3ce226583d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d0c1367c6164be0cd21dff3abb28d2bb.setContent(html_7ef3d5e3088b6053e575e3ce226583d9);
#
#
#
#         marker_662bcdd4260cbe558efd2d0face54c6d.bindPopup(popup_d0c1367c6164be0cd21dff3abb28d2bb)
#         ;
#
#
#
#
#             var marker_05dfbe6de135f6113de427546591578a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0ac390bfe61181e4e20fb59a9fa245fa);
#
#
#         var popup_fff9fcdfd16993e2550f22c4e4db2789 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22d273b6bf569e6789abd9ac6002028f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22d273b6bf569e6789abd9ac6002028f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_22d273b6bf569e6789abd9ac6002028f = L.map(
#                 &quot;map_22d273b6bf569e6789abd9ac6002028f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e1f24160371b765a92fc7baf7592c01 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e1f24160371b765a92fc7baf7592c01.addTo(map_22d273b6bf569e6789abd9ac6002028f);
#
#
#             var feature_group_b54446931f12fbae6727f5af8e7e9904 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b54446931f12fbae6727f5af8e7e9904.addTo(map_22d273b6bf569e6789abd9ac6002028f);
#
#
#             var feature_group_sub_group_9c385376ab84464c557c8460b8c9e7f3 = L.featureGroup.subGroup(
#                 feature_group_b54446931f12fbae6727f5af8e7e9904
#             );
#
#
#             var marker_e8d54175eac15f6665a535974834058b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9c385376ab84464c557c8460b8c9e7f3);
#
#
#         var popup_d4f7815cc0fd3335443b2811f3d73172 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bcb51f9898f8561f7f4a3a233cdac09 = $(`&lt;div id=&quot;html_1bcb51f9898f8561f7f4a3a233cdac09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d4f7815cc0fd3335443b2811f3d73172.setContent(html_1bcb51f9898f8561f7f4a3a233cdac09);
#
#
#
#         marker_e8d54175eac15f6665a535974834058b.bindPopup(popup_d4f7815cc0fd3335443b2811f3d73172)
#         ;
#
#
#
#
#             var marker_17f0d6518359068117bdec83087ace6f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9c385376ab84464c557c8460b8c9e7f3);
#
#
#         var popup_62b81da564444e2784d42acfdf5713a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_034673ce69dfa3f7a03f5a123c65f636 = $(`&lt;div id=&quot;html_034673ce69dfa3f7a03f5a123c65f636&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_62b81da564444e2784d42acfdf5713a7.setContent(html_034673ce69dfa3f7a03f5a123c65f636);
#
#
#
#         marker_17f0d6518359068117bdec83087ace6f.bindPopup(popup_62b81da564444e2784d42acfdf5713a7)
#         ;
#
#
#
#
#             var marker_d1073cdcedb3728a8a211319ed0d337e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9c385376ab84464c557c8460b8c9e7f3);
#
#
#         var popup_bf755adfa25be9dbcb39603e542037ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_754a14efddf0545e392df74d54d5e0aa = $(`&lt;div id=&quot;html_754a14efddf0545e392df74d54d5e0aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bf755adfa25be9dbcb39603e542037ce.setContent(html_754a14efddf0545e392df74d54d5e0aa);
#
#
#
#         marker_d1073cdcedb3728a8a211319ed0d337e.bindPopup(popup_bf755adfa25be9dbcb39603e542037ce)
#         ;
#
#
#
#
#             var marker_502173ff85be5fedf05e9eec2b6a48e0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9c385376ab84464c557c8460b8c9e7f3);
#
#
#         var popup_dea2ed41cf3eebc84af74ffd84c77fe7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_784394c3b53fd9ac5f6132f12b64a965 = $(`&lt;div id=&quot;html_784394c3b53fd9ac5f6132f12b64a965&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_dea2ed41cf3eebc84af74ffd84c77fe7.setContent(html_784394c3b53fd9ac5f6132f12b64a965);
#
#
#
#         marker_
