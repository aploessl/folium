# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_352d6ea636fd0890e79906669279342a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_352d6ea636fd0890e79906669279342a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_352d6ea636fd0890e79906669279342a = L.map(
#                 &quot;map_352d6ea636fd0890e79906669279342a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6539db0bc24959c8b48b493543fcd728 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6539db0bc24959c8b48b493543fcd728.addTo(map_352d6ea636fd0890e79906669279342a);
#
#
#             var marker_74191acb00dd3e4896606f4567326c6a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_352d6ea636fd0890e79906669279342a);
#
#
#         var popup_84f8a9d5fa750720ec9c661ee7027179 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bbd2325b6ce6c1b2c9cb4253e18fe8a = $(`&lt;div id=&quot;html_9bbd2325b6ce6c1b2c9cb4253e18fe8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_84f8a9d5fa750720ec9c661ee7027179.setContent(html_9bbd2325b6ce6c1b2c9cb4253e18fe8a);
#
#
#
#         marker_74191acb00dd3e4896606f4567326c6a.bindPopup(popup_84f8a9d5fa750720ec9c661ee7027179)
#         ;
#
#
#
#
#             var marker_c28f2893b9adcf12d6ddbdb862e7f0b0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_352d6ea636fd0890e79906669279342a);
#
#
#         var popup_a1e9330de76620ab4ae12face10616cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76a75cd2cd046f9df01174066d2116dc = $(`&lt;div id=&quot;html_76a75cd2cd046f9df01174066d2116dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a1e9330de76620ab4ae12face10616cb.setContent(html_76a75cd2cd046f9df01174066d2116dc);
#
#
#
#         marker_c28f2893b9adcf12d6ddbdb862e7f0b0.bindPopup(popup_a1e9330de76620ab4ae12face10616cb)
#         ;
#
#
#
#
#             var marker_a210518f58f83db05f3f891f2a12bd46 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_352d6ea636fd0890e79906669279342a);
#
#
#         var popup_39d7cefc035482a568cbc9ff29f7ab6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6586e437ccbaeb4d3dbeb7094ba9c640 = $(`&lt;div id=&quot;html_6586e437ccbaeb4d3dbeb7094ba9c640&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_39d7cefc035482a568cbc9ff29f7ab6b.setContent(html_6586e437ccbaeb4d3dbeb7094ba9c640);
#
#
#
#         marker_a210518f58f83db05f3f891f2a12bd46.bindPopup(popup_39d7cefc035482a568cbc9ff29f7ab6b)
#         ;
#
#
#
#
#             var marker_315f90e706501bc3d690efaff4de6607 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_352d6ea636fd0890e79906669279342a);
#
#
#         var popup_5834c5a096a9abef31b58d8d8095e5a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9d87bb4531319a352dfe81204b4c21a = $(`&lt;div id=&quot;html_a9d87bb4531319a352dfe81204b4c21a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5834c5a096a9abef31b58d8d8095e5a3.setContent(html_a9d87bb4531319a352dfe81204b4c21a);
#
#
#
#         marker_315f90e706501bc3d690efaff4de6607.bindPopup(popup_5834c5a096a9abef31b58d8d8095e5a3)
#         ;
#
#
#
#
#             var marker_6f4b42f0a324c7895f0ed489cac98997 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_352d6ea636fd0890e79906669279342a);
#
#
#         var popup_36c9105052728c59407a1bebe3bc5da4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a5a7994553d013ab212aa3aeb4c77be = $(`&lt;div id=&quot;html_3a5a7994553d013ab212aa3aeb4c77be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_36c9105052728c59407a1bebe3bc5da4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52133cc75664a54ee185dd7c6a9781c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52133cc75664a54ee185dd7c6a9781c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52133cc75664a54ee185dd7c6a9781c5 = L.map(
#                 &quot;map_52133cc75664a54ee185dd7c6a9781c5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b9e5b91e3b50d5db6544edd93b5780b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1b9e5b91e3b50d5db6544edd93b5780b.addTo(map_52133cc75664a54ee185dd7c6a9781c5);
#
#
#             var feature_group_e354dee1ca1e68d433fc9e813d439442 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_debfa9f27e7da9f34068aaf8be4e9328 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e354dee1ca1e68d433fc9e813d439442);
#
#
#         var popup_33068e7e8d011a52fa9f42337e7e1a0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7de8858b760dd4e7b59c682c71c5fca = $(`&lt;div id=&quot;html_c7de8858b760dd4e7b59c682c71c5fca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_33068e7e8d011a52fa9f42337e7e1a0e.setContent(html_c7de8858b760dd4e7b59c682c71c5fca);
#
#
#
#         marker_debfa9f27e7da9f34068aaf8be4e9328.bindPopup(popup_33068e7e8d011a52fa9f42337e7e1a0e)
#         ;
#
#
#
#
#             var marker_b2ac2fa961834a5e00f3eaf51c465fd4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e354dee1ca1e68d433fc9e813d439442);
#
#
#         var popup_22c70cb928aec02b166f696eec9bbf84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_479f751cdaf06519d82d0b690080a98c = $(`&lt;div id=&quot;html_479f751cdaf06519d82d0b690080a98c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_22c70cb928aec02b166f696eec9bbf84.setContent(html_479f751cdaf06519d82d0b690080a98c);
#
#
#
#         marker_b2ac2fa961834a5e00f3eaf51c465fd4.bindPopup(popup_22c70cb928aec02b166f696eec9bbf84)
#         ;
#
#
#
#
#             var marker_8adfba7fba1f249f66da844d66cb319a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e354dee1ca1e68d433fc9e813d439442);
#
#
#         var popup_e0ad70b1104895cda6457e7caaccddb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9611761566db8486d39164e38f3a3718 = $(`&lt;div id=&quot;html_9611761566db8486d39164e38f3a3718&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e0ad70b1104895cda6457e7caaccddb8.setContent(html_9611761566db8486d39164e38f3a3718);
#
#
#
#         marker_8adfba7fba1f249f66da844d66cb319a.bindPopup(popup_e0ad70b1104895cda6457e7caaccddb8)
#         ;
#
#
#
#
#             var marker_91021bc07c00091b099c3474111796f2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e354dee1ca1e68d433fc9e813d439442);
#
#
#         var popup_af2264877bc361e637f56681f69cb41c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46f8ddeb09a3ea36e1f2e5c835331dcf = $(`&lt;div id=&quot;html_46f8ddeb09a3ea36e1f2e5c835331dcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_af2264877bc361e637f56681f69cb41c.setContent(html_46f8ddeb09a3ea36e1f2e5c835331dcf);
#
#
#
#         marker_91021bc07c00091b099c3474111796f2.bindPopup(popup_af2264877bc361e637f56681f69cb41c)
#         ;
#
#
#
#
#             var marker_0b56e79d42eccee51670a29f1e76e1e1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e354dee1ca1e68d433fc9e813d439442);
#
#
#         var popup_9cf73741a5db838586e9cb78a4513253 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b84191f1ea71ef4bc6b7529378f40ad4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b84191f1ea71ef4bc6b7529378f40ad4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b84191f1ea71ef4bc6b7529378f40ad4 = L.map(
#                 &quot;map_b84191f1ea71ef4bc6b7529378f40ad4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0fcbcd2927113043083c396ce5a715d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c0fcbcd2927113043083c396ce5a715d.addTo(map_b84191f1ea71ef4bc6b7529378f40ad4);
#
#
#             var feature_group_6c005f732160f7639ee13d3ddaf485f1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6c005f732160f7639ee13d3ddaf485f1.addTo(map_b84191f1ea71ef4bc6b7529378f40ad4);
#
#
#             var feature_group_sub_group_4a4830e0a0eaa377f62c8aca594dc158 = L.featureGroup.subGroup(
#                 feature_group_6c005f732160f7639ee13d3ddaf485f1
#             );
#
#
#             var marker_c7accbff757601d9d778e8c36ece8fd4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4a4830e0a0eaa377f62c8aca594dc158);
#
#
#         var popup_24be48d887e30a02f9a71941d4467b08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14f774fbd5317561fe162ed6288158c9 = $(`&lt;div id=&quot;html_14f774fbd5317561fe162ed6288158c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_24be48d887e30a02f9a71941d4467b08.setContent(html_14f774fbd5317561fe162ed6288158c9);
#
#
#
#         marker_c7accbff757601d9d778e8c36ece8fd4.bindPopup(popup_24be48d887e30a02f9a71941d4467b08)
#         ;
#
#
#
#
#             var marker_aab0e955c99532fcba3c8b09451e5b2f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4a4830e0a0eaa377f62c8aca594dc158);
#
#
#         var popup_1b34e07725877aa8634f5821e7390296 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74227f02805eb913108c2705a801386e = $(`&lt;div id=&quot;html_74227f02805eb913108c2705a801386e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1b34e07725877aa8634f5821e7390296.setContent(html_74227f02805eb913108c2705a801386e);
#
#
#
#         marker_aab0e955c99532fcba3c8b09451e5b2f.bindPopup(popup_1b34e07725877aa8634f5821e7390296)
#         ;
#
#
#
#
#             var marker_f41114fa2f50c65f3e90a0ae66a20515 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4a4830e0a0eaa377f62c8aca594dc158);
#
#
#         var popup_8fb0c825f62286f428a9b7f6f70b1e3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee8f6a04dd358e6f185610d31cd03396 = $(`&lt;div id=&quot;html_ee8f6a04dd358e6f185610d31cd03396&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8fb0c825f62286f428a9b7f6f70b1e3a.setContent(html_ee8f6a04dd358e6f185610d31cd03396);
#
#
#
#         marker_f41114fa2f50c65f3e90a0ae66a20515.bindPopup(popup_8fb0c825f62286f428a9b7f6f70b1e3a)
#         ;
#
#
#
#
#             var marker_c16bbd823a62f6a77efbc48dd016c33e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4a4830e0a0eaa377f62c8aca594dc158);
#
#
#         var popup_5d5ce205fc62cf8c57632c144fa2079e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcfbd7a8c0ff912741d0f10d3f722461 = $(`&lt;div id=&quot;html_fcfbd7a8c0ff912741d0f10d3f722461&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5d5ce205fc62cf8c57632c144fa2079e.setContent(html_fcfbd7a8c0ff912741d0f10d3f722461);
#
#
#
#         marker_
