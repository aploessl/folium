# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44f87dc4f0bbe5b710a8d5fefa383aea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44f87dc4f0bbe5b710a8d5fefa383aea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44f87dc4f0bbe5b710a8d5fefa383aea = L.map(
#                 &quot;map_44f87dc4f0bbe5b710a8d5fefa383aea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44d245b06945f1e47bdde160de2ca205 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_44d245b06945f1e47bdde160de2ca205.addTo(map_44f87dc4f0bbe5b710a8d5fefa383aea);
#
#
#             var marker_41d7a9af1da208dd3b56934e9e3e9c32 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_44f87dc4f0bbe5b710a8d5fefa383aea);
#
#
#         var popup_3ac2cec7e98f46d737416678bd2d69b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10283b3aff1d09ac17bad1e0ae230f74 = $(`&lt;div id=&quot;html_10283b3aff1d09ac17bad1e0ae230f74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3ac2cec7e98f46d737416678bd2d69b3.setContent(html_10283b3aff1d09ac17bad1e0ae230f74);
#
#
#
#         marker_41d7a9af1da208dd3b56934e9e3e9c32.bindPopup(popup_3ac2cec7e98f46d737416678bd2d69b3)
#         ;
#
#
#
#
#             var marker_69970b5a84c03efda54039ff383fc323 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_44f87dc4f0bbe5b710a8d5fefa383aea);
#
#
#         var popup_61a5811e13db4f34f46da8a0a99b0780 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ca7a1053950ceb2eb8b53aa85715f81 = $(`&lt;div id=&quot;html_4ca7a1053950ceb2eb8b53aa85715f81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_61a5811e13db4f34f46da8a0a99b0780.setContent(html_4ca7a1053950ceb2eb8b53aa85715f81);
#
#
#
#         marker_69970b5a84c03efda54039ff383fc323.bindPopup(popup_61a5811e13db4f34f46da8a0a99b0780)
#         ;
#
#
#
#
#             var marker_8d411bbff69768a3590b4f3c6dff4b4e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_44f87dc4f0bbe5b710a8d5fefa383aea);
#
#
#         var popup_3910ac405bdb85a3fe2f345a5d3b1480 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8ec55aec7994c1b1e0a6007c2091162 = $(`&lt;div id=&quot;html_e8ec55aec7994c1b1e0a6007c2091162&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3910ac405bdb85a3fe2f345a5d3b1480.setContent(html_e8ec55aec7994c1b1e0a6007c2091162);
#
#
#
#         marker_8d411bbff69768a3590b4f3c6dff4b4e.bindPopup(popup_3910ac405bdb85a3fe2f345a5d3b1480)
#         ;
#
#
#
#
#             var marker_b22da82e9d39f6497674a8f2902bb633 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_44f87dc4f0bbe5b710a8d5fefa383aea);
#
#
#         var popup_2a2a657fce401fb6b80ca439e5523825 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44296f39f1b47bda8f7d950bfb08a24c = $(`&lt;div id=&quot;html_44296f39f1b47bda8f7d950bfb08a24c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2a2a657fce401fb6b80ca439e5523825.setContent(html_44296f39f1b47bda8f7d950bfb08a24c);
#
#
#
#         marker_b22da82e9d39f6497674a8f2902bb633.bindPopup(popup_2a2a657fce401fb6b80ca439e5523825)
#         ;
#
#
#
#
#             var marker_2c9af14dc3efa071359795b5e01b7c87 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_44f87dc4f0bbe5b710a8d5fefa383aea);
#
#
#         var popup_712e70a550867cd3187d877713d4fc07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c36872536be4fbee32d61ed6bc17b43 = $(`&lt;div id=&quot;html_3c36872536be4fbee32d61ed6bc17b43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_712e70a550867cd3187d877713d4fc07.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7a1efba9560660ed136871add18afe9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7a1efba9560660ed136871add18afe9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7a1efba9560660ed136871add18afe9 = L.map(
#                 &quot;map_f7a1efba9560660ed136871add18afe9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_465648942fc01d018aafba89dd1f7e91 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_465648942fc01d018aafba89dd1f7e91.addTo(map_f7a1efba9560660ed136871add18afe9);
#
#
#             var feature_group_ec634ec71b598d9e0fee1692efa07720 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_21979a70fb8a73b18ee7fda4a7bb56d8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ec634ec71b598d9e0fee1692efa07720);
#
#
#         var popup_ecfa57010bc4f4c42884afce4949e15d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_276fc681089dfd575d37670f54c777e0 = $(`&lt;div id=&quot;html_276fc681089dfd575d37670f54c777e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ecfa57010bc4f4c42884afce4949e15d.setContent(html_276fc681089dfd575d37670f54c777e0);
#
#
#
#         marker_21979a70fb8a73b18ee7fda4a7bb56d8.bindPopup(popup_ecfa57010bc4f4c42884afce4949e15d)
#         ;
#
#
#
#
#             var marker_9eeab71c8a34037ce44f2a4725d1a7bd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ec634ec71b598d9e0fee1692efa07720);
#
#
#         var popup_c039bfe860193dddf6998a0687fd80c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11359ea471f8aaa8b9dce167cd07bba5 = $(`&lt;div id=&quot;html_11359ea471f8aaa8b9dce167cd07bba5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c039bfe860193dddf6998a0687fd80c2.setContent(html_11359ea471f8aaa8b9dce167cd07bba5);
#
#
#
#         marker_9eeab71c8a34037ce44f2a4725d1a7bd.bindPopup(popup_c039bfe860193dddf6998a0687fd80c2)
#         ;
#
#
#
#
#             var marker_4f4ab4356e28ccae103525e8f1a38d5b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ec634ec71b598d9e0fee1692efa07720);
#
#
#         var popup_a8651b02c7ba02e0b2b08a5d55a3e9a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d131e4216187dd31efd9ebcb2b8bddd1 = $(`&lt;div id=&quot;html_d131e4216187dd31efd9ebcb2b8bddd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a8651b02c7ba02e0b2b08a5d55a3e9a1.setContent(html_d131e4216187dd31efd9ebcb2b8bddd1);
#
#
#
#         marker_4f4ab4356e28ccae103525e8f1a38d5b.bindPopup(popup_a8651b02c7ba02e0b2b08a5d55a3e9a1)
#         ;
#
#
#
#
#             var marker_aef6461cb42e1f8ba0e7801d165d7f93 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ec634ec71b598d9e0fee1692efa07720);
#
#
#         var popup_8380fbbf05ca2dc98cb36f3fe71a6be8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6202b1c56c5ffa65f96208383bb9537a = $(`&lt;div id=&quot;html_6202b1c56c5ffa65f96208383bb9537a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8380fbbf05ca2dc98cb36f3fe71a6be8.setContent(html_6202b1c56c5ffa65f96208383bb9537a);
#
#
#
#         marker_aef6461cb42e1f8ba0e7801d165d7f93.bindPopup(popup_8380fbbf05ca2dc98cb36f3fe71a6be8)
#         ;
#
#
#
#
#             var marker_95fcd1d0fb2bd35be72bfb44bbf920fa = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ec634ec71b598d9e0fee1692efa07720);
#
#
#         var popup_7ccb8d59ea4b3706df3a6691414432d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1212a100ebe68a32894516c40387a54e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1212a100ebe68a32894516c40387a54e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1212a100ebe68a32894516c40387a54e = L.map(
#                 &quot;map_1212a100ebe68a32894516c40387a54e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9225f71038fe29591bffa70cfb199768 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9225f71038fe29591bffa70cfb199768.addTo(map_1212a100ebe68a32894516c40387a54e);
#
#
#             var feature_group_dad9c9fb5aa732cddc2c65a4cde8aad1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dad9c9fb5aa732cddc2c65a4cde8aad1.addTo(map_1212a100ebe68a32894516c40387a54e);
#
#
#             var feature_group_sub_group_35cb14e8a530ce7b2d8bfba964f8a764 = L.featureGroup.subGroup(
#                 feature_group_dad9c9fb5aa732cddc2c65a4cde8aad1
#             );
#
#
#             var marker_9c571bf0119a06bc3d4d519abd341f42 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_35cb14e8a530ce7b2d8bfba964f8a764);
#
#
#         var popup_1e848e0f03cdb23f5a4d30be5a5f2ff8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a0a95450829c5d846082125124d631a = $(`&lt;div id=&quot;html_7a0a95450829c5d846082125124d631a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1e848e0f03cdb23f5a4d30be5a5f2ff8.setContent(html_7a0a95450829c5d846082125124d631a);
#
#
#
#         marker_9c571bf0119a06bc3d4d519abd341f42.bindPopup(popup_1e848e0f03cdb23f5a4d30be5a5f2ff8)
#         ;
#
#
#
#
#             var marker_ba54790ab5f8ed5721dc095f9c7db5cc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_35cb14e8a530ce7b2d8bfba964f8a764);
#
#
#         var popup_b9954ab1dfe764658554c0d1c96d7616 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dfb9d6412a92ff876bd735cc002cd61 = $(`&lt;div id=&quot;html_0dfb9d6412a92ff876bd735cc002cd61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b9954ab1dfe764658554c0d1c96d7616.setContent(html_0dfb9d6412a92ff876bd735cc002cd61);
#
#
#
#         marker_ba54790ab5f8ed5721dc095f9c7db5cc.bindPopup(popup_b9954ab1dfe764658554c0d1c96d7616)
#         ;
#
#
#
#
#             var marker_2576163c81fe9c5a9d1c8d9921eee2e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_35cb14e8a530ce7b2d8bfba964f8a764);
#
#
#         var popup_a0b59ec4657adaae36ff4168fe27e859 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_848591edca734144431e24f39b9bed10 = $(`&lt;div id=&quot;html_848591edca734144431e24f39b9bed10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a0b59ec4657adaae36ff4168fe27e859.setContent(html_848591edca734144431e24f39b9bed10);
#
#
#
#         marker_2576163c81fe9c5a9d1c8d9921eee2e8.bindPopup(popup_a0b59ec4657adaae36ff4168fe27e859)
#         ;
#
#
#
#
#             var marker_be9804802d7db57a36927e5801b644ab = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_35cb14e8a530ce7b2d8bfba964f8a764);
#
#
#         var popup_a75fd5d1485c732fadecec27a506a93a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4055bbc77efd2cee7f5b3b94c15862d6 = $(`&lt;div id=&quot;html_4055bbc77efd2cee7f5b3b94c15862d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a75fd5d1485c732fadecec27a506a93a.setContent(html_4055bbc77efd2cee7f5b3b94c15862d6);
#
#
#
#         marker_
