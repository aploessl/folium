# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81634c5331b5c79e3ace721a25bf6b77 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81634c5331b5c79e3ace721a25bf6b77&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81634c5331b5c79e3ace721a25bf6b77 = L.map(
#                 &quot;map_81634c5331b5c79e3ace721a25bf6b77&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_085d8a38acc9d62b8c108bfba0a7d399 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_085d8a38acc9d62b8c108bfba0a7d399.addTo(map_81634c5331b5c79e3ace721a25bf6b77);
#
#
#             var marker_aff33c62ca98873c7f1b529c389609d6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_81634c5331b5c79e3ace721a25bf6b77);
#
#
#         var popup_03f5fcec162176ec3bbf5af1596e6de4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7ca645e2c04f7f31c3ecf57187544c4 = $(`&lt;div id=&quot;html_a7ca645e2c04f7f31c3ecf57187544c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_03f5fcec162176ec3bbf5af1596e6de4.setContent(html_a7ca645e2c04f7f31c3ecf57187544c4);
#
#
#
#         marker_aff33c62ca98873c7f1b529c389609d6.bindPopup(popup_03f5fcec162176ec3bbf5af1596e6de4)
#         ;
#
#
#
#
#             var marker_f2db9d1f8c11adac2044983dc2707e50 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_81634c5331b5c79e3ace721a25bf6b77);
#
#
#         var popup_d3c6a95291847fb8a631ea6d43cf91a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eafbcf1fb9317514c8da0b821e410d58 = $(`&lt;div id=&quot;html_eafbcf1fb9317514c8da0b821e410d58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d3c6a95291847fb8a631ea6d43cf91a8.setContent(html_eafbcf1fb9317514c8da0b821e410d58);
#
#
#
#         marker_f2db9d1f8c11adac2044983dc2707e50.bindPopup(popup_d3c6a95291847fb8a631ea6d43cf91a8)
#         ;
#
#
#
#
#             var marker_63a2b78238e4e2e322d0a712044139d2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_81634c5331b5c79e3ace721a25bf6b77);
#
#
#         var popup_dc9ed2e35e37e88dd9b357c35069cb53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32441a123d9b85a59f2a37f5a84f8ab2 = $(`&lt;div id=&quot;html_32441a123d9b85a59f2a37f5a84f8ab2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dc9ed2e35e37e88dd9b357c35069cb53.setContent(html_32441a123d9b85a59f2a37f5a84f8ab2);
#
#
#
#         marker_63a2b78238e4e2e322d0a712044139d2.bindPopup(popup_dc9ed2e35e37e88dd9b357c35069cb53)
#         ;
#
#
#
#
#             var marker_9dd8edd793c88e053092684a8365cc4d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_81634c5331b5c79e3ace721a25bf6b77);
#
#
#         var popup_9d51c22db1816ea2f731e3084ce3d008 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1eb1d5680bd0b3006434ea93bc3ae32c = $(`&lt;div id=&quot;html_1eb1d5680bd0b3006434ea93bc3ae32c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9d51c22db1816ea2f731e3084ce3d008.setContent(html_1eb1d5680bd0b3006434ea93bc3ae32c);
#
#
#
#         marker_9dd8edd793c88e053092684a8365cc4d.bindPopup(popup_9d51c22db1816ea2f731e3084ce3d008)
#         ;
#
#
#
#
#             var marker_916f6a8a645689d5c4c4f3806848f5bf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_81634c5331b5c79e3ace721a25bf6b77);
#
#
#         var popup_b1111865306b35443775be11fcbd52b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d2b1c2df4cd16801e01cff83511ed47 = $(`&lt;div id=&quot;html_1d2b1c2df4cd16801e01cff83511ed47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b1111865306b35443775be11fcbd52b6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5cef31b524eef48129d1040ddcc633e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5cef31b524eef48129d1040ddcc633e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5cef31b524eef48129d1040ddcc633e9 = L.map(
#                 &quot;map_5cef31b524eef48129d1040ddcc633e9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1805d9aedd2c90a897d32b5ad102a93d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1805d9aedd2c90a897d32b5ad102a93d.addTo(map_5cef31b524eef48129d1040ddcc633e9);
#
#
#             var feature_group_5272663e0ccfdaf8b1235d9496babef5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a87aa838dcddca8f53d1cea3ea915fdf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5272663e0ccfdaf8b1235d9496babef5);
#
#
#         var popup_ac4ecdd25324d8b809280b91dc59c4f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_307d0e05718a7d97e0e956ea9a4fdda3 = $(`&lt;div id=&quot;html_307d0e05718a7d97e0e956ea9a4fdda3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ac4ecdd25324d8b809280b91dc59c4f6.setContent(html_307d0e05718a7d97e0e956ea9a4fdda3);
#
#
#
#         marker_a87aa838dcddca8f53d1cea3ea915fdf.bindPopup(popup_ac4ecdd25324d8b809280b91dc59c4f6)
#         ;
#
#
#
#
#             var marker_c49b4680fba4680328d7c2e8e034ef0a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5272663e0ccfdaf8b1235d9496babef5);
#
#
#         var popup_3231b993e0f16ec799d6a7b2d4349371 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91ff577ded5a528b1dcdb01df17174fa = $(`&lt;div id=&quot;html_91ff577ded5a528b1dcdb01df17174fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3231b993e0f16ec799d6a7b2d4349371.setContent(html_91ff577ded5a528b1dcdb01df17174fa);
#
#
#
#         marker_c49b4680fba4680328d7c2e8e034ef0a.bindPopup(popup_3231b993e0f16ec799d6a7b2d4349371)
#         ;
#
#
#
#
#             var marker_21e6e6e6722700ee2d824e26b3646599 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5272663e0ccfdaf8b1235d9496babef5);
#
#
#         var popup_eb0de655bbff6872227b8ee9f83333a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c79c05094c06362ab45e5a1eec64aba4 = $(`&lt;div id=&quot;html_c79c05094c06362ab45e5a1eec64aba4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_eb0de655bbff6872227b8ee9f83333a4.setContent(html_c79c05094c06362ab45e5a1eec64aba4);
#
#
#
#         marker_21e6e6e6722700ee2d824e26b3646599.bindPopup(popup_eb0de655bbff6872227b8ee9f83333a4)
#         ;
#
#
#
#
#             var marker_b33098685d2499d252c985a3548673b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5272663e0ccfdaf8b1235d9496babef5);
#
#
#         var popup_c7a15f0b6d9cf411f5b41fd01b895b78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58eb53d3ce38305ed20cd59488ee10a0 = $(`&lt;div id=&quot;html_58eb53d3ce38305ed20cd59488ee10a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c7a15f0b6d9cf411f5b41fd01b895b78.setContent(html_58eb53d3ce38305ed20cd59488ee10a0);
#
#
#
#         marker_b33098685d2499d252c985a3548673b4.bindPopup(popup_c7a15f0b6d9cf411f5b41fd01b895b78)
#         ;
#
#
#
#
#             var marker_515b7ef8be4ea2f5be00a0c7b9121290 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5272663e0ccfdaf8b1235d9496babef5);
#
#
#         var popup_31dc767106bae1038ec5aa6fa352ee08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e5f07f35cc950b4096332100c3e42dc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e5f07f35cc950b4096332100c3e42dc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e5f07f35cc950b4096332100c3e42dc8 = L.map(
#                 &quot;map_e5f07f35cc950b4096332100c3e42dc8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09c45d610b8f1da3b7cb42a1c6d1dc5a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09c45d610b8f1da3b7cb42a1c6d1dc5a.addTo(map_e5f07f35cc950b4096332100c3e42dc8);
#
#
#             var feature_group_da9bbd4580027177c801d97c0e9939d2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_da9bbd4580027177c801d97c0e9939d2.addTo(map_e5f07f35cc950b4096332100c3e42dc8);
#
#
#             var feature_group_sub_group_8aeb5c1485421af688ba08b76f4c8f40 = L.featureGroup.subGroup(
#                 feature_group_da9bbd4580027177c801d97c0e9939d2
#             );
#
#
#             var marker_617729184115d1d970937379aa90d168 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8aeb5c1485421af688ba08b76f4c8f40);
#
#
#         var popup_91a7bf7dd2f8a8ee87a9c85aa93c78ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e11af61ae6f9ffe272e0c94564768508 = $(`&lt;div id=&quot;html_e11af61ae6f9ffe272e0c94564768508&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_91a7bf7dd2f8a8ee87a9c85aa93c78ee.setContent(html_e11af61ae6f9ffe272e0c94564768508);
#
#
#
#         marker_617729184115d1d970937379aa90d168.bindPopup(popup_91a7bf7dd2f8a8ee87a9c85aa93c78ee)
#         ;
#
#
#
#
#             var marker_09f167c7f06fe562b342553f9746a8ce = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8aeb5c1485421af688ba08b76f4c8f40);
#
#
#         var popup_d2d2c200cb0366deec3faa4dc274c9f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f2c24d707146ae1f1c40cbf101afbea = $(`&lt;div id=&quot;html_8f2c24d707146ae1f1c40cbf101afbea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d2d2c200cb0366deec3faa4dc274c9f0.setContent(html_8f2c24d707146ae1f1c40cbf101afbea);
#
#
#
#         marker_09f167c7f06fe562b342553f9746a8ce.bindPopup(popup_d2d2c200cb0366deec3faa4dc274c9f0)
#         ;
#
#
#
#
#             var marker_0415d6e04cd4625f0bfb675daf68f5f6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8aeb5c1485421af688ba08b76f4c8f40);
#
#
#         var popup_00365eb3632e74764508e7c5bd81a8cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_487b7ed15802666be346f828ec7c25d7 = $(`&lt;div id=&quot;html_487b7ed15802666be346f828ec7c25d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_00365eb3632e74764508e7c5bd81a8cd.setContent(html_487b7ed15802666be346f828ec7c25d7);
#
#
#
#         marker_0415d6e04cd4625f0bfb675daf68f5f6.bindPopup(popup_00365eb3632e74764508e7c5bd81a8cd)
#         ;
#
#
#
#
#             var marker_85408f87925a931277d10cceca5c24b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8aeb5c1485421af688ba08b76f4c8f40);
#
#
#         var popup_8c13e92d966f64f72d356f8be11c94e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f460b4bc1e75d6b46f2af45a1c09ed36 = $(`&lt;div id=&quot;html_f460b4bc1e75d6b46f2af45a1c09ed36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8c13e92d966f64f72d356f8be11c94e1.setContent(html_f460b4bc1e75d6b46f2af45a1c09ed36);
#
#
#
#         marker_
