# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_027e4acaa72feb3a4060f40dfa2afd82 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_027e4acaa72feb3a4060f40dfa2afd82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_027e4acaa72feb3a4060f40dfa2afd82 = L.map(
#                 &quot;map_027e4acaa72feb3a4060f40dfa2afd82&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5094b93834bac4c7476a190783b435b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5094b93834bac4c7476a190783b435b9.addTo(map_027e4acaa72feb3a4060f40dfa2afd82);
#
#
#             var marker_55c4a8bff3fb6f77a000b5ee309a1e52 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_027e4acaa72feb3a4060f40dfa2afd82);
#
#
#         var popup_692921e6be56d07d103f8ce9a2c66008 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adba0406a883dfb62c1b08445f9d24b9 = $(`&lt;div id=&quot;html_adba0406a883dfb62c1b08445f9d24b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_692921e6be56d07d103f8ce9a2c66008.setContent(html_adba0406a883dfb62c1b08445f9d24b9);
#
#
#
#         marker_55c4a8bff3fb6f77a000b5ee309a1e52.bindPopup(popup_692921e6be56d07d103f8ce9a2c66008)
#         ;
#
#
#
#
#             var marker_31d28c5158cd8fdcee88a1c6c778b7a7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_027e4acaa72feb3a4060f40dfa2afd82);
#
#
#         var popup_dc5ffb3d27f38d6036e0002158ec2cbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f836419cd3b44a9c93b8d3cc19dd80f7 = $(`&lt;div id=&quot;html_f836419cd3b44a9c93b8d3cc19dd80f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dc5ffb3d27f38d6036e0002158ec2cbb.setContent(html_f836419cd3b44a9c93b8d3cc19dd80f7);
#
#
#
#         marker_31d28c5158cd8fdcee88a1c6c778b7a7.bindPopup(popup_dc5ffb3d27f38d6036e0002158ec2cbb)
#         ;
#
#
#
#
#             var marker_c6789ae5ba5d45a719b444c300af8664 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_027e4acaa72feb3a4060f40dfa2afd82);
#
#
#         var popup_41edc6361c0a6b50f5dd6ee88d5f779c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fedb918db8387e5e44b98e273734d07b = $(`&lt;div id=&quot;html_fedb918db8387e5e44b98e273734d07b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_41edc6361c0a6b50f5dd6ee88d5f779c.setContent(html_fedb918db8387e5e44b98e273734d07b);
#
#
#
#         marker_c6789ae5ba5d45a719b444c300af8664.bindPopup(popup_41edc6361c0a6b50f5dd6ee88d5f779c)
#         ;
#
#
#
#
#             var marker_02b26ae9f1c81fc8b7c0a5eb96d0b727 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_027e4acaa72feb3a4060f40dfa2afd82);
#
#
#         var popup_446aaea3db05928d5de63e3b9b8b3357 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ded4414d972a4220fdf360aa01d143d1 = $(`&lt;div id=&quot;html_ded4414d972a4220fdf360aa01d143d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_446aaea3db05928d5de63e3b9b8b3357.setContent(html_ded4414d972a4220fdf360aa01d143d1);
#
#
#
#         marker_02b26ae9f1c81fc8b7c0a5eb96d0b727.bindPopup(popup_446aaea3db05928d5de63e3b9b8b3357)
#         ;
#
#
#
#
#             var marker_376f2956b9e30abc45f69c3db7ef170f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_027e4acaa72feb3a4060f40dfa2afd82);
#
#
#         var popup_7e2a968661df4efa4c84638923960fde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a2e05de399eec66ee7479f6500dfdc2 = $(`&lt;div id=&quot;html_8a2e05de399eec66ee7479f6500dfdc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7e2a968661df4efa4c84638923960fde.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b8852995d498184fdfde65da056c851 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b8852995d498184fdfde65da056c851&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b8852995d498184fdfde65da056c851 = L.map(
#                 &quot;map_5b8852995d498184fdfde65da056c851&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e64a98885a52f5d77037956a821bb2b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e64a98885a52f5d77037956a821bb2b1.addTo(map_5b8852995d498184fdfde65da056c851);
#
#
#             var feature_group_a21906317e9c32e704c6e41e6dcca199 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7bc55494f1620627fa90cef4d66a764d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a21906317e9c32e704c6e41e6dcca199);
#
#
#         var popup_6a2bab092d89fd97613afa5235385c5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adbb85a8cfcf1f76040224246f2a1087 = $(`&lt;div id=&quot;html_adbb85a8cfcf1f76040224246f2a1087&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6a2bab092d89fd97613afa5235385c5b.setContent(html_adbb85a8cfcf1f76040224246f2a1087);
#
#
#
#         marker_7bc55494f1620627fa90cef4d66a764d.bindPopup(popup_6a2bab092d89fd97613afa5235385c5b)
#         ;
#
#
#
#
#             var marker_fb3993c9ab024cc96b3cb16a11e25d61 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a21906317e9c32e704c6e41e6dcca199);
#
#
#         var popup_d9f61c00c563d80e0a975eb648e476c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd981955d16f63892cc68ff211f18098 = $(`&lt;div id=&quot;html_dd981955d16f63892cc68ff211f18098&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d9f61c00c563d80e0a975eb648e476c0.setContent(html_dd981955d16f63892cc68ff211f18098);
#
#
#
#         marker_fb3993c9ab024cc96b3cb16a11e25d61.bindPopup(popup_d9f61c00c563d80e0a975eb648e476c0)
#         ;
#
#
#
#
#             var marker_b0a7273139ddb0ad4e72382eebc8f4b2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a21906317e9c32e704c6e41e6dcca199);
#
#
#         var popup_84c5755b2b3170f66264d3e072cbe9f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10ae76391aebc7379002c73a4e048676 = $(`&lt;div id=&quot;html_10ae76391aebc7379002c73a4e048676&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_84c5755b2b3170f66264d3e072cbe9f3.setContent(html_10ae76391aebc7379002c73a4e048676);
#
#
#
#         marker_b0a7273139ddb0ad4e72382eebc8f4b2.bindPopup(popup_84c5755b2b3170f66264d3e072cbe9f3)
#         ;
#
#
#
#
#             var marker_32d88d9b8270287b937706a7c8458892 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a21906317e9c32e704c6e41e6dcca199);
#
#
#         var popup_085c08cc8c496b233bd51fbf50ec2f5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_408ad6b5cf5b627d14b080543fb56df9 = $(`&lt;div id=&quot;html_408ad6b5cf5b627d14b080543fb56df9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_085c08cc8c496b233bd51fbf50ec2f5e.setContent(html_408ad6b5cf5b627d14b080543fb56df9);
#
#
#
#         marker_32d88d9b8270287b937706a7c8458892.bindPopup(popup_085c08cc8c496b233bd51fbf50ec2f5e)
#         ;
#
#
#
#
#             var marker_22454df58e972909559ba447890f0162 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a21906317e9c32e704c6e41e6dcca199);
#
#
#         var popup_0e8e0a87f99b71fec30e5a56094ccb40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4470a11f539a1951b83649ca5390a944 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4470a11f539a1951b83649ca5390a944&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4470a11f539a1951b83649ca5390a944 = L.map(
#                 &quot;map_4470a11f539a1951b83649ca5390a944&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fda9db4299565df8e28d0d1f4cfea594 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fda9db4299565df8e28d0d1f4cfea594.addTo(map_4470a11f539a1951b83649ca5390a944);
#
#
#             var feature_group_40eb1a2d20a81febc4aaf57b209b3149 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_40eb1a2d20a81febc4aaf57b209b3149.addTo(map_4470a11f539a1951b83649ca5390a944);
#
#
#             var feature_group_sub_group_a5d0046c335058dfc5aa9374670696cc = L.featureGroup.subGroup(
#                 feature_group_40eb1a2d20a81febc4aaf57b209b3149
#             );
#
#
#             var marker_46e8f0bc4a05159ff5b45a323ea303c6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a5d0046c335058dfc5aa9374670696cc);
#
#
#         var popup_5888da5341e33db5ec34a3b0ad76c7f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97205fe4dc82da6b7c3d4b076c19c131 = $(`&lt;div id=&quot;html_97205fe4dc82da6b7c3d4b076c19c131&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5888da5341e33db5ec34a3b0ad76c7f2.setContent(html_97205fe4dc82da6b7c3d4b076c19c131);
#
#
#
#         marker_46e8f0bc4a05159ff5b45a323ea303c6.bindPopup(popup_5888da5341e33db5ec34a3b0ad76c7f2)
#         ;
#
#
#
#
#             var marker_e722b0702c52081b8fa6b676f948face = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a5d0046c335058dfc5aa9374670696cc);
#
#
#         var popup_a56f743433eb9be9018252c23da823f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_008a59880c87da771970a0092697b21b = $(`&lt;div id=&quot;html_008a59880c87da771970a0092697b21b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a56f743433eb9be9018252c23da823f2.setContent(html_008a59880c87da771970a0092697b21b);
#
#
#
#         marker_e722b0702c52081b8fa6b676f948face.bindPopup(popup_a56f743433eb9be9018252c23da823f2)
#         ;
#
#
#
#
#             var marker_a54f78269996a5231c8091464324c5a2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a5d0046c335058dfc5aa9374670696cc);
#
#
#         var popup_7f97de23f5758b3183b3c5137bd1104c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18ba34cf0b50fd4abb0e3f7f44f8efec = $(`&lt;div id=&quot;html_18ba34cf0b50fd4abb0e3f7f44f8efec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7f97de23f5758b3183b3c5137bd1104c.setContent(html_18ba34cf0b50fd4abb0e3f7f44f8efec);
#
#
#
#         marker_a54f78269996a5231c8091464324c5a2.bindPopup(popup_7f97de23f5758b3183b3c5137bd1104c)
#         ;
#
#
#
#
#             var marker_3968746b94e7ddf1b106cd5730592792 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a5d0046c335058dfc5aa9374670696cc);
#
#
#         var popup_a52f670f14cae18e0a61b7dd7d2cd9ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52788e1e4b6164732700e06470ec7f10 = $(`&lt;div id=&quot;html_52788e1e4b6164732700e06470ec7f10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a52f670f14cae18e0a61b7dd7d2cd9ad.setContent(html_52788e1e4b6164732700e06470ec7f10);
#
#
#
#         marker_
