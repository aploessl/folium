# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2db7a914bd490d9b272df778b4e404f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2db7a914bd490d9b272df778b4e404f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2db7a914bd490d9b272df778b4e404f = L.map(
#                 &quot;map_b2db7a914bd490d9b272df778b4e404f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a1101f1b5d8c32999165ab0688634f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a1101f1b5d8c32999165ab0688634f7.addTo(map_b2db7a914bd490d9b272df778b4e404f);
#
#
#             var marker_78163276c7fdf4da4b5a7f36e271320e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b2db7a914bd490d9b272df778b4e404f);
#
#
#         var popup_f0d8f96ff7fb8cc29b8c22adb6529606 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa10757fd2bb05f7c583340ba3ada47e = $(`&lt;div id=&quot;html_aa10757fd2bb05f7c583340ba3ada47e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f0d8f96ff7fb8cc29b8c22adb6529606.setContent(html_aa10757fd2bb05f7c583340ba3ada47e);
#
#
#
#         marker_78163276c7fdf4da4b5a7f36e271320e.bindPopup(popup_f0d8f96ff7fb8cc29b8c22adb6529606)
#         ;
#
#
#
#
#             var marker_45feab03d94680ff7d22c42ad9f4490c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b2db7a914bd490d9b272df778b4e404f);
#
#
#         var popup_3ee3a7f16be3a006c5f61d06d3d8c647 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44e91d2ff5e2bfcc15c0fdfc73e13420 = $(`&lt;div id=&quot;html_44e91d2ff5e2bfcc15c0fdfc73e13420&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3ee3a7f16be3a006c5f61d06d3d8c647.setContent(html_44e91d2ff5e2bfcc15c0fdfc73e13420);
#
#
#
#         marker_45feab03d94680ff7d22c42ad9f4490c.bindPopup(popup_3ee3a7f16be3a006c5f61d06d3d8c647)
#         ;
#
#
#
#
#             var marker_189bc985bc5595fd1814d78ef8f315c1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b2db7a914bd490d9b272df778b4e404f);
#
#
#         var popup_1727320c7128f5882f9f136da0309467 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5a2d837cf77dca33d301ce6d121ddb2 = $(`&lt;div id=&quot;html_f5a2d837cf77dca33d301ce6d121ddb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1727320c7128f5882f9f136da0309467.setContent(html_f5a2d837cf77dca33d301ce6d121ddb2);
#
#
#
#         marker_189bc985bc5595fd1814d78ef8f315c1.bindPopup(popup_1727320c7128f5882f9f136da0309467)
#         ;
#
#
#
#
#             var marker_35d60a0dd603c8e4190d69de65bc9870 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b2db7a914bd490d9b272df778b4e404f);
#
#
#         var popup_eed6d28fe10239a848a304f650291955 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_483fb5887e054c97f4e5b98f94aa8964 = $(`&lt;div id=&quot;html_483fb5887e054c97f4e5b98f94aa8964&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_eed6d28fe10239a848a304f650291955.setContent(html_483fb5887e054c97f4e5b98f94aa8964);
#
#
#
#         marker_35d60a0dd603c8e4190d69de65bc9870.bindPopup(popup_eed6d28fe10239a848a304f650291955)
#         ;
#
#
#
#
#             var marker_6200abd5e751a21e258f648f23e9fed5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b2db7a914bd490d9b272df778b4e404f);
#
#
#         var popup_495d3c0a7362a92630d9411777d2f069 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c802e3933364803d574260f728001d31 = $(`&lt;div id=&quot;html_c802e3933364803d574260f728001d31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_495d3c0a7362a92630d9411777d2f069.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f332219afea34c74b2ce6fd1be2fb24b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f332219afea34c74b2ce6fd1be2fb24b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f332219afea34c74b2ce6fd1be2fb24b = L.map(
#                 &quot;map_f332219afea34c74b2ce6fd1be2fb24b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb2d7c81779248c1df60f666ab8c83ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eb2d7c81779248c1df60f666ab8c83ba.addTo(map_f332219afea34c74b2ce6fd1be2fb24b);
#
#
#             var feature_group_48d543edbbcdce9791c5627fb2d18fe4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7ca66f732093979ca12809f851b42ed9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_48d543edbbcdce9791c5627fb2d18fe4);
#
#
#         var popup_a0a89b8df23052b8db5eefae4283e254 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a3f77a2db34a6857127e1e7fc69df15 = $(`&lt;div id=&quot;html_7a3f77a2db34a6857127e1e7fc69df15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a0a89b8df23052b8db5eefae4283e254.setContent(html_7a3f77a2db34a6857127e1e7fc69df15);
#
#
#
#         marker_7ca66f732093979ca12809f851b42ed9.bindPopup(popup_a0a89b8df23052b8db5eefae4283e254)
#         ;
#
#
#
#
#             var marker_2cf563b06cf0c2e928645b835f9bb74f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_48d543edbbcdce9791c5627fb2d18fe4);
#
#
#         var popup_27489b6eb0df4626e3fd9c320cd8586f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dc815f01ebfc73b5274498cb41ffb66 = $(`&lt;div id=&quot;html_3dc815f01ebfc73b5274498cb41ffb66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_27489b6eb0df4626e3fd9c320cd8586f.setContent(html_3dc815f01ebfc73b5274498cb41ffb66);
#
#
#
#         marker_2cf563b06cf0c2e928645b835f9bb74f.bindPopup(popup_27489b6eb0df4626e3fd9c320cd8586f)
#         ;
#
#
#
#
#             var marker_51fd282906c40f79118a23fce378197b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_48d543edbbcdce9791c5627fb2d18fe4);
#
#
#         var popup_aaa73020f436f70d081db7ffa33f8ff7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dcc21b4717a8743258f734010b2dfbc = $(`&lt;div id=&quot;html_8dcc21b4717a8743258f734010b2dfbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_aaa73020f436f70d081db7ffa33f8ff7.setContent(html_8dcc21b4717a8743258f734010b2dfbc);
#
#
#
#         marker_51fd282906c40f79118a23fce378197b.bindPopup(popup_aaa73020f436f70d081db7ffa33f8ff7)
#         ;
#
#
#
#
#             var marker_60288a91242cb7030600e53dee31482f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_48d543edbbcdce9791c5627fb2d18fe4);
#
#
#         var popup_82be92a09dae7e1da60530d7b7010774 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b197cb7c264fbb0df3b5ffd9a8ea721 = $(`&lt;div id=&quot;html_2b197cb7c264fbb0df3b5ffd9a8ea721&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_82be92a09dae7e1da60530d7b7010774.setContent(html_2b197cb7c264fbb0df3b5ffd9a8ea721);
#
#
#
#         marker_60288a91242cb7030600e53dee31482f.bindPopup(popup_82be92a09dae7e1da60530d7b7010774)
#         ;
#
#
#
#
#             var marker_2c696b5f5bb068b58cc04c511836799c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_48d543edbbcdce9791c5627fb2d18fe4);
#
#
#         var popup_b2e0969741d8aace963fab9de9c442d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e49d1229b7d110622cde5d081f647abb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e49d1229b7d110622cde5d081f647abb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e49d1229b7d110622cde5d081f647abb = L.map(
#                 &quot;map_e49d1229b7d110622cde5d081f647abb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4436f51047eba06add51f5a0a49bcadb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4436f51047eba06add51f5a0a49bcadb.addTo(map_e49d1229b7d110622cde5d081f647abb);
#
#
#             var feature_group_efdba767d281556ccf18ef88b3593f0a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_efdba767d281556ccf18ef88b3593f0a.addTo(map_e49d1229b7d110622cde5d081f647abb);
#
#
#             var feature_group_sub_group_2e65355c43bf79d9069980b2f73c686f = L.featureGroup.subGroup(
#                 feature_group_efdba767d281556ccf18ef88b3593f0a
#             );
#
#
#             var marker_287ed849847b0c13eb54a0e0d57284c0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e65355c43bf79d9069980b2f73c686f);
#
#
#         var popup_17bb2bfd67e8ebd7189363980fc56e8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebed7fa32dc25834d3c5ec7cefd2a849 = $(`&lt;div id=&quot;html_ebed7fa32dc25834d3c5ec7cefd2a849&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_17bb2bfd67e8ebd7189363980fc56e8e.setContent(html_ebed7fa32dc25834d3c5ec7cefd2a849);
#
#
#
#         marker_287ed849847b0c13eb54a0e0d57284c0.bindPopup(popup_17bb2bfd67e8ebd7189363980fc56e8e)
#         ;
#
#
#
#
#             var marker_8d32912e9702d8c7ce2c3cac2f0c49fb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e65355c43bf79d9069980b2f73c686f);
#
#
#         var popup_606e4cc87f6c821e0f1af77606eb834f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01227c36598b796c0d00ae62274b8d9c = $(`&lt;div id=&quot;html_01227c36598b796c0d00ae62274b8d9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_606e4cc87f6c821e0f1af77606eb834f.setContent(html_01227c36598b796c0d00ae62274b8d9c);
#
#
#
#         marker_8d32912e9702d8c7ce2c3cac2f0c49fb.bindPopup(popup_606e4cc87f6c821e0f1af77606eb834f)
#         ;
#
#
#
#
#             var marker_c8557a6f74a455cc445365a97892dc69 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e65355c43bf79d9069980b2f73c686f);
#
#
#         var popup_8d58d6af21f7f615bceff523a1ac2a9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_920ea93c47528980768eb3d63448ba94 = $(`&lt;div id=&quot;html_920ea93c47528980768eb3d63448ba94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8d58d6af21f7f615bceff523a1ac2a9a.setContent(html_920ea93c47528980768eb3d63448ba94);
#
#
#
#         marker_c8557a6f74a455cc445365a97892dc69.bindPopup(popup_8d58d6af21f7f615bceff523a1ac2a9a)
#         ;
#
#
#
#
#             var marker_4ca0bce119280de82cdca6870f34d13c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e65355c43bf79d9069980b2f73c686f);
#
#
#         var popup_fffa278bb1d2d772d5c05a2d434c07c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f3bc4aa0237a1c4ca9b813f67baab10 = $(`&lt;div id=&quot;html_2f3bc4aa0237a1c4ca9b813f67baab10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fffa278bb1d2d772d5c05a2d434c07c8.setContent(html_2f3bc4aa0237a1c4ca9b813f67baab10);
#
#
#
#         marker_
