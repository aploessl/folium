# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe9f9abc63cde32f246347d744af9801 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe9f9abc63cde32f246347d744af9801&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe9f9abc63cde32f246347d744af9801 = L.map(
#                 &quot;map_fe9f9abc63cde32f246347d744af9801&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_32abeceb1ad0ef6f9670207e5c0a5dd8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_32abeceb1ad0ef6f9670207e5c0a5dd8.addTo(map_fe9f9abc63cde32f246347d744af9801);
#
#
#             var marker_1649b9b3c65d1ae08ec29e74ebcb4d09 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fe9f9abc63cde32f246347d744af9801);
#
#
#         var popup_e3169b03ca5e53facd20cec09032584d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9cbfeac1a610240b16d63749d8e8ef2 = $(`&lt;div id=&quot;html_e9cbfeac1a610240b16d63749d8e8ef2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e3169b03ca5e53facd20cec09032584d.setContent(html_e9cbfeac1a610240b16d63749d8e8ef2);
#
#
#
#         marker_1649b9b3c65d1ae08ec29e74ebcb4d09.bindPopup(popup_e3169b03ca5e53facd20cec09032584d)
#         ;
#
#
#
#
#             var marker_033f16c06af0e4e7df3cb9161385c506 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fe9f9abc63cde32f246347d744af9801);
#
#
#         var popup_b80e2fb171180381e29903a956ebedeb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_763e13bc93be5f671e140c184bea47b6 = $(`&lt;div id=&quot;html_763e13bc93be5f671e140c184bea47b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b80e2fb171180381e29903a956ebedeb.setContent(html_763e13bc93be5f671e140c184bea47b6);
#
#
#
#         marker_033f16c06af0e4e7df3cb9161385c506.bindPopup(popup_b80e2fb171180381e29903a956ebedeb)
#         ;
#
#
#
#
#             var marker_6dc8d13f2bda9b0ec33c1d95e93c0353 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fe9f9abc63cde32f246347d744af9801);
#
#
#         var popup_c342189e7764be4df094caa7ea7cb8f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_967acacfeae54f5a9a5dad814cd1dea8 = $(`&lt;div id=&quot;html_967acacfeae54f5a9a5dad814cd1dea8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c342189e7764be4df094caa7ea7cb8f9.setContent(html_967acacfeae54f5a9a5dad814cd1dea8);
#
#
#
#         marker_6dc8d13f2bda9b0ec33c1d95e93c0353.bindPopup(popup_c342189e7764be4df094caa7ea7cb8f9)
#         ;
#
#
#
#
#             var marker_1754e9ad8319be2308c4752e522d97c8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fe9f9abc63cde32f246347d744af9801);
#
#
#         var popup_9f23a5d8d0794de87a4cb7cc2a69254e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf6706cbcc60ea36a373bec8ea9a5598 = $(`&lt;div id=&quot;html_bf6706cbcc60ea36a373bec8ea9a5598&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9f23a5d8d0794de87a4cb7cc2a69254e.setContent(html_bf6706cbcc60ea36a373bec8ea9a5598);
#
#
#
#         marker_1754e9ad8319be2308c4752e522d97c8.bindPopup(popup_9f23a5d8d0794de87a4cb7cc2a69254e)
#         ;
#
#
#
#
#             var marker_0b2475a33cb90336005914f6f7b29f62 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fe9f9abc63cde32f246347d744af9801);
#
#
#         var popup_a46669744316065d0d93b6f607dad79a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6194c744ababfc540c59c86d6d466b4 = $(`&lt;div id=&quot;html_d6194c744ababfc540c59c86d6d466b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a46669744316065d0d93b6f607dad79a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e42673f20b02020f75567c186ba411e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e42673f20b02020f75567c186ba411e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e42673f20b02020f75567c186ba411e1 = L.map(
#                 &quot;map_e42673f20b02020f75567c186ba411e1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad8000b253cced1aaaba3e9ab6ae220d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ad8000b253cced1aaaba3e9ab6ae220d.addTo(map_e42673f20b02020f75567c186ba411e1);
#
#
#             var feature_group_ccdafddebfac0cd2f4c019264b682fe8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_53870c97d99a23a347d707c4ee4e3b96 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ccdafddebfac0cd2f4c019264b682fe8);
#
#
#         var popup_d54fd5bbf3f221e3d8fdb257b7ac2008 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d550727ac89a4216a4a7993a093de363 = $(`&lt;div id=&quot;html_d550727ac89a4216a4a7993a093de363&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d54fd5bbf3f221e3d8fdb257b7ac2008.setContent(html_d550727ac89a4216a4a7993a093de363);
#
#
#
#         marker_53870c97d99a23a347d707c4ee4e3b96.bindPopup(popup_d54fd5bbf3f221e3d8fdb257b7ac2008)
#         ;
#
#
#
#
#             var marker_2559bf9f3b5400615ead2622e28781fc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ccdafddebfac0cd2f4c019264b682fe8);
#
#
#         var popup_537c12864b17d5f3ae414cdea0f20740 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ce6e257a3807e2c08dd34242a22264e = $(`&lt;div id=&quot;html_7ce6e257a3807e2c08dd34242a22264e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_537c12864b17d5f3ae414cdea0f20740.setContent(html_7ce6e257a3807e2c08dd34242a22264e);
#
#
#
#         marker_2559bf9f3b5400615ead2622e28781fc.bindPopup(popup_537c12864b17d5f3ae414cdea0f20740)
#         ;
#
#
#
#
#             var marker_08c9d6c9f3d558e397441114ab6db9b2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ccdafddebfac0cd2f4c019264b682fe8);
#
#
#         var popup_6235e7ed25774fe8e90cf1955116b451 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3033f5c99727040477ef3ddaf6b94b43 = $(`&lt;div id=&quot;html_3033f5c99727040477ef3ddaf6b94b43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6235e7ed25774fe8e90cf1955116b451.setContent(html_3033f5c99727040477ef3ddaf6b94b43);
#
#
#
#         marker_08c9d6c9f3d558e397441114ab6db9b2.bindPopup(popup_6235e7ed25774fe8e90cf1955116b451)
#         ;
#
#
#
#
#             var marker_c4fb4fa8c0f6b5fae859f26d5f374373 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ccdafddebfac0cd2f4c019264b682fe8);
#
#
#         var popup_321d26a7ad0988d30b9c19a68d30036e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ad628bc6566c9e45749f885b4fa9c0f = $(`&lt;div id=&quot;html_1ad628bc6566c9e45749f885b4fa9c0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_321d26a7ad0988d30b9c19a68d30036e.setContent(html_1ad628bc6566c9e45749f885b4fa9c0f);
#
#
#
#         marker_c4fb4fa8c0f6b5fae859f26d5f374373.bindPopup(popup_321d26a7ad0988d30b9c19a68d30036e)
#         ;
#
#
#
#
#             var marker_b829b21e074085c496441d26df1a3a93 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ccdafddebfac0cd2f4c019264b682fe8);
#
#
#         var popup_642125f4372b02cc6d48838511d963f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3fa77204634bcb4bbf19417d5a58b144 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3fa77204634bcb4bbf19417d5a58b144&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3fa77204634bcb4bbf19417d5a58b144 = L.map(
#                 &quot;map_3fa77204634bcb4bbf19417d5a58b144&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82c80c6d797d7f1b73c6030763980d04 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_82c80c6d797d7f1b73c6030763980d04.addTo(map_3fa77204634bcb4bbf19417d5a58b144);
#
#
#             var feature_group_14bc95b6a4d5ff693abe884fb06def1d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_14bc95b6a4d5ff693abe884fb06def1d.addTo(map_3fa77204634bcb4bbf19417d5a58b144);
#
#
#             var feature_group_sub_group_3bf0659ccfd4c795f6ab12079141a237 = L.featureGroup.subGroup(
#                 feature_group_14bc95b6a4d5ff693abe884fb06def1d
#             );
#
#
#             var marker_1edfaf187179239ff68e8415c1f4bcf1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3bf0659ccfd4c795f6ab12079141a237);
#
#
#         var popup_e48d30629151df8a9333f32cdcc7023e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9ba3fafc70d5b3b528c542ba9f7159b = $(`&lt;div id=&quot;html_f9ba3fafc70d5b3b528c542ba9f7159b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e48d30629151df8a9333f32cdcc7023e.setContent(html_f9ba3fafc70d5b3b528c542ba9f7159b);
#
#
#
#         marker_1edfaf187179239ff68e8415c1f4bcf1.bindPopup(popup_e48d30629151df8a9333f32cdcc7023e)
#         ;
#
#
#
#
#             var marker_0db538038ebf4eace8e7c44728eed318 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3bf0659ccfd4c795f6ab12079141a237);
#
#
#         var popup_c2286ad5ec89b3647e7ce483e6d5a703 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b63f448544780f15226183325d83419a = $(`&lt;div id=&quot;html_b63f448544780f15226183325d83419a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c2286ad5ec89b3647e7ce483e6d5a703.setContent(html_b63f448544780f15226183325d83419a);
#
#
#
#         marker_0db538038ebf4eace8e7c44728eed318.bindPopup(popup_c2286ad5ec89b3647e7ce483e6d5a703)
#         ;
#
#
#
#
#             var marker_083dc15a982c3d12ba62a1aa0ccdd6fc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3bf0659ccfd4c795f6ab12079141a237);
#
#
#         var popup_387d7e88a695bae463b01f155597b2d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a303229d0948d1bdde4906ddb47fa96a = $(`&lt;div id=&quot;html_a303229d0948d1bdde4906ddb47fa96a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_387d7e88a695bae463b01f155597b2d7.setContent(html_a303229d0948d1bdde4906ddb47fa96a);
#
#
#
#         marker_083dc15a982c3d12ba62a1aa0ccdd6fc.bindPopup(popup_387d7e88a695bae463b01f155597b2d7)
#         ;
#
#
#
#
#             var marker_5edf9cc24ecc8a54590fec6b6064ae5e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3bf0659ccfd4c795f6ab12079141a237);
#
#
#         var popup_780c1e79842b1616ec7b8c1752655116 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77b1561f3f5a26ffa8f0fd7fa3fba9e1 = $(`&lt;div id=&quot;html_77b1561f3f5a26ffa8f0fd7fa3fba9e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_780c1e79842b1616ec7b8c1752655116.setContent(html_77b1561f3f5a26ffa8f0fd7fa3fba9e1);
#
#
#
#         marker_
