# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb6642b2fbb74e7c7d77248b6b5e33f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb6642b2fbb74e7c7d77248b6b5e33f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb6642b2fbb74e7c7d77248b6b5e33f7 = L.map(
#                 &quot;map_cb6642b2fbb74e7c7d77248b6b5e33f7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_920f627dd3f534623dcd8097889346cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_920f627dd3f534623dcd8097889346cd.addTo(map_cb6642b2fbb74e7c7d77248b6b5e33f7);
#
#
#             var marker_f2d2f2beda7323f029a3d178ad4ee809 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cb6642b2fbb74e7c7d77248b6b5e33f7);
#
#
#         var popup_a2cdc66762c84a7eab0df1cbd684e589 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d34dccf194f06e02081b77ad3e80b2d = $(`&lt;div id=&quot;html_5d34dccf194f06e02081b77ad3e80b2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a2cdc66762c84a7eab0df1cbd684e589.setContent(html_5d34dccf194f06e02081b77ad3e80b2d);
#
#
#
#         marker_f2d2f2beda7323f029a3d178ad4ee809.bindPopup(popup_a2cdc66762c84a7eab0df1cbd684e589)
#         ;
#
#
#
#
#             var marker_c7ec75f6e425cdf6ef7e6a1430f85c2b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cb6642b2fbb74e7c7d77248b6b5e33f7);
#
#
#         var popup_bbb95ac8044515cd9637cb7400b35018 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ec4e3ff274ed09919984a028cc6645b = $(`&lt;div id=&quot;html_4ec4e3ff274ed09919984a028cc6645b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bbb95ac8044515cd9637cb7400b35018.setContent(html_4ec4e3ff274ed09919984a028cc6645b);
#
#
#
#         marker_c7ec75f6e425cdf6ef7e6a1430f85c2b.bindPopup(popup_bbb95ac8044515cd9637cb7400b35018)
#         ;
#
#
#
#
#             var marker_6389dbd820907e51c48c5cd0e88f6f73 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cb6642b2fbb74e7c7d77248b6b5e33f7);
#
#
#         var popup_fcc3e80e8e787bd070f5783d9585f79f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0551389a661ceee5c6472f9b24a0e1f9 = $(`&lt;div id=&quot;html_0551389a661ceee5c6472f9b24a0e1f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fcc3e80e8e787bd070f5783d9585f79f.setContent(html_0551389a661ceee5c6472f9b24a0e1f9);
#
#
#
#         marker_6389dbd820907e51c48c5cd0e88f6f73.bindPopup(popup_fcc3e80e8e787bd070f5783d9585f79f)
#         ;
#
#
#
#
#             var marker_dc68bdc1da72cf3508a05b466877bb28 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cb6642b2fbb74e7c7d77248b6b5e33f7);
#
#
#         var popup_e1f87e4532ae11b3c4a37d5cbf4aa057 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2ac79573c938bd1312663483a511924 = $(`&lt;div id=&quot;html_b2ac79573c938bd1312663483a511924&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e1f87e4532ae11b3c4a37d5cbf4aa057.setContent(html_b2ac79573c938bd1312663483a511924);
#
#
#
#         marker_dc68bdc1da72cf3508a05b466877bb28.bindPopup(popup_e1f87e4532ae11b3c4a37d5cbf4aa057)
#         ;
#
#
#
#
#             var marker_cba68dcdcaf11942b777595b621f169e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cb6642b2fbb74e7c7d77248b6b5e33f7);
#
#
#         var popup_036afcc8433dd40b57dc7887d82619d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_463b1688482e3bb8de13ace6bf598df5 = $(`&lt;div id=&quot;html_463b1688482e3bb8de13ace6bf598df5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_036afcc8433dd40b57dc7887d82619d7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6fd39e23ef1cc9ccffe83a796002e323 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6fd39e23ef1cc9ccffe83a796002e323&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6fd39e23ef1cc9ccffe83a796002e323 = L.map(
#                 &quot;map_6fd39e23ef1cc9ccffe83a796002e323&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4fe8212ce04b93e804463829f344841 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d4fe8212ce04b93e804463829f344841.addTo(map_6fd39e23ef1cc9ccffe83a796002e323);
#
#
#             var feature_group_087b317fe05fa299da931783ea0dfb25 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5b7167e1760978fb5e330903a641dd6c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_087b317fe05fa299da931783ea0dfb25);
#
#
#         var popup_c59a02973addae280cfdd70357d85c9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9f9cb624e116699042283afa733bb51 = $(`&lt;div id=&quot;html_a9f9cb624e116699042283afa733bb51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c59a02973addae280cfdd70357d85c9f.setContent(html_a9f9cb624e116699042283afa733bb51);
#
#
#
#         marker_5b7167e1760978fb5e330903a641dd6c.bindPopup(popup_c59a02973addae280cfdd70357d85c9f)
#         ;
#
#
#
#
#             var marker_6fcbf22eea9a6781c45f6119a8d27357 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_087b317fe05fa299da931783ea0dfb25);
#
#
#         var popup_f3ee7d3fc710f7c215005c2e3b17f0c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20c7c8f4131b8e8600f29b2cc5c7a2ed = $(`&lt;div id=&quot;html_20c7c8f4131b8e8600f29b2cc5c7a2ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f3ee7d3fc710f7c215005c2e3b17f0c3.setContent(html_20c7c8f4131b8e8600f29b2cc5c7a2ed);
#
#
#
#         marker_6fcbf22eea9a6781c45f6119a8d27357.bindPopup(popup_f3ee7d3fc710f7c215005c2e3b17f0c3)
#         ;
#
#
#
#
#             var marker_fd798aa861c5cda65123873fb7490c4c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_087b317fe05fa299da931783ea0dfb25);
#
#
#         var popup_5a64824efbd4919c29ffbe3276cfb515 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_508b4e6129246c37fcefe6997356bb9d = $(`&lt;div id=&quot;html_508b4e6129246c37fcefe6997356bb9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5a64824efbd4919c29ffbe3276cfb515.setContent(html_508b4e6129246c37fcefe6997356bb9d);
#
#
#
#         marker_fd798aa861c5cda65123873fb7490c4c.bindPopup(popup_5a64824efbd4919c29ffbe3276cfb515)
#         ;
#
#
#
#
#             var marker_1ec7c9b1916575af16511bd5b82d4831 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_087b317fe05fa299da931783ea0dfb25);
#
#
#         var popup_b9eab403ec39bda9154e2febab196c23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ae4f30bb5a80d74ad119de389e762a1 = $(`&lt;div id=&quot;html_5ae4f30bb5a80d74ad119de389e762a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b9eab403ec39bda9154e2febab196c23.setContent(html_5ae4f30bb5a80d74ad119de389e762a1);
#
#
#
#         marker_1ec7c9b1916575af16511bd5b82d4831.bindPopup(popup_b9eab403ec39bda9154e2febab196c23)
#         ;
#
#
#
#
#             var marker_2289834f4b040c51f992bf3b2f633ecd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_087b317fe05fa299da931783ea0dfb25);
#
#
#         var popup_f50252aee43c987e01bbd37870405381 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b260ed3f6273a58a5e9572f7ae538d52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b260ed3f6273a58a5e9572f7ae538d52&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b260ed3f6273a58a5e9572f7ae538d52 = L.map(
#                 &quot;map_b260ed3f6273a58a5e9572f7ae538d52&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc864b5da34013c9d3358626536d5497 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dc864b5da34013c9d3358626536d5497.addTo(map_b260ed3f6273a58a5e9572f7ae538d52);
#
#
#             var feature_group_743193bb86883c6ac2f1fdcc85d72588 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_743193bb86883c6ac2f1fdcc85d72588.addTo(map_b260ed3f6273a58a5e9572f7ae538d52);
#
#
#             var feature_group_sub_group_3ccdd7fe762d62a4b70717fbe2a462f9 = L.featureGroup.subGroup(
#                 feature_group_743193bb86883c6ac2f1fdcc85d72588
#             );
#
#
#             var marker_56c2c843fd1ebd7f8582383330766885 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ccdd7fe762d62a4b70717fbe2a462f9);
#
#
#         var popup_7a761b2c86768d748510e4b07e1c0bb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0f5d973dc1a7fab3ea2bf1e6ba7f90f = $(`&lt;div id=&quot;html_e0f5d973dc1a7fab3ea2bf1e6ba7f90f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7a761b2c86768d748510e4b07e1c0bb1.setContent(html_e0f5d973dc1a7fab3ea2bf1e6ba7f90f);
#
#
#
#         marker_56c2c843fd1ebd7f8582383330766885.bindPopup(popup_7a761b2c86768d748510e4b07e1c0bb1)
#         ;
#
#
#
#
#             var marker_27ba8d8e9a9939a5b4f4f0f3eddbdfe0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ccdd7fe762d62a4b70717fbe2a462f9);
#
#
#         var popup_5710adcc23462fe161f8405316562f38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26a01cf1c9d3ea6a8d6296803e12def1 = $(`&lt;div id=&quot;html_26a01cf1c9d3ea6a8d6296803e12def1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5710adcc23462fe161f8405316562f38.setContent(html_26a01cf1c9d3ea6a8d6296803e12def1);
#
#
#
#         marker_27ba8d8e9a9939a5b4f4f0f3eddbdfe0.bindPopup(popup_5710adcc23462fe161f8405316562f38)
#         ;
#
#
#
#
#             var marker_e6c9358e42f13770fbbc2b61e6ec29ea = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ccdd7fe762d62a4b70717fbe2a462f9);
#
#
#         var popup_5e7b91380d4c74b8d0d56a01ec877fc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b14268019330f20416490a4cd36c3bd9 = $(`&lt;div id=&quot;html_b14268019330f20416490a4cd36c3bd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5e7b91380d4c74b8d0d56a01ec877fc7.setContent(html_b14268019330f20416490a4cd36c3bd9);
#
#
#
#         marker_e6c9358e42f13770fbbc2b61e6ec29ea.bindPopup(popup_5e7b91380d4c74b8d0d56a01ec877fc7)
#         ;
#
#
#
#
#             var marker_3720b6efcdb762c0210938e4f1a72df7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ccdd7fe762d62a4b70717fbe2a462f9);
#
#
#         var popup_c1fe448dd931914430f32b1c383e80c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c8109d26240d14243aa9f09846fa2ea = $(`&lt;div id=&quot;html_7c8109d26240d14243aa9f09846fa2ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c1fe448dd931914430f32b1c383e80c9.setContent(html_7c8109d26240d14243aa9f09846fa2ea);
#
#
#
#         marker_
