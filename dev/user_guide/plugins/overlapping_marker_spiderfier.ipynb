# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6382c0fcb0e6778b5d22789de4124883 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6382c0fcb0e6778b5d22789de4124883&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6382c0fcb0e6778b5d22789de4124883 = L.map(
#                 &quot;map_6382c0fcb0e6778b5d22789de4124883&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1212866e140b5c9b87c5b871e464cac8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1212866e140b5c9b87c5b871e464cac8.addTo(map_6382c0fcb0e6778b5d22789de4124883);
#
#
#             var marker_5ce0a9ec8e1781e64a6d69e51bf525a9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6382c0fcb0e6778b5d22789de4124883);
#
#
#         var popup_de16e727944a69f13493c15ac2e52e05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_009700680096d1d99427e030ce1dd6fc = $(`&lt;div id=&quot;html_009700680096d1d99427e030ce1dd6fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_de16e727944a69f13493c15ac2e52e05.setContent(html_009700680096d1d99427e030ce1dd6fc);
#
#
#
#         marker_5ce0a9ec8e1781e64a6d69e51bf525a9.bindPopup(popup_de16e727944a69f13493c15ac2e52e05)
#         ;
#
#
#
#
#             var marker_b7c8f1e08d6d2858b957189a6b87033a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6382c0fcb0e6778b5d22789de4124883);
#
#
#         var popup_7206a51ede70ba9ce94a7e9d505557f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9b3cbc12efd530441300faff452cc47 = $(`&lt;div id=&quot;html_e9b3cbc12efd530441300faff452cc47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7206a51ede70ba9ce94a7e9d505557f9.setContent(html_e9b3cbc12efd530441300faff452cc47);
#
#
#
#         marker_b7c8f1e08d6d2858b957189a6b87033a.bindPopup(popup_7206a51ede70ba9ce94a7e9d505557f9)
#         ;
#
#
#
#
#             var marker_a65047f13a81f37a9bcc8053be6224d2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6382c0fcb0e6778b5d22789de4124883);
#
#
#         var popup_a0587e12e7619f9b756e9c175d78e02a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb60fd92eff02a262adc8f8a3821d5a1 = $(`&lt;div id=&quot;html_cb60fd92eff02a262adc8f8a3821d5a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a0587e12e7619f9b756e9c175d78e02a.setContent(html_cb60fd92eff02a262adc8f8a3821d5a1);
#
#
#
#         marker_a65047f13a81f37a9bcc8053be6224d2.bindPopup(popup_a0587e12e7619f9b756e9c175d78e02a)
#         ;
#
#
#
#
#             var marker_47429d4588f1b6db334c793061680239 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6382c0fcb0e6778b5d22789de4124883);
#
#
#         var popup_92364896cae070bea55e8f2cc68dcc22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c6b46abb5b8fe72707be355eea4b8fb = $(`&lt;div id=&quot;html_8c6b46abb5b8fe72707be355eea4b8fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_92364896cae070bea55e8f2cc68dcc22.setContent(html_8c6b46abb5b8fe72707be355eea4b8fb);
#
#
#
#         marker_47429d4588f1b6db334c793061680239.bindPopup(popup_92364896cae070bea55e8f2cc68dcc22)
#         ;
#
#
#
#
#             var marker_f8693b12419bb348822601df70c236f0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6382c0fcb0e6778b5d22789de4124883);
#
#
#         var popup_55098ee528fa2b21ba9ac31f4fe5b1cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_236c9b115fb6011987e5d6a5226750d0 = $(`&lt;div id=&quot;html_236c9b115fb6011987e5d6a5226750d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_55098ee528fa2b21ba9ac31f4fe5b1cf.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_afec05cf89fecb79237179edf637e25b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_afec05cf89fecb79237179edf637e25b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_afec05cf89fecb79237179edf637e25b = L.map(
#                 &quot;map_afec05cf89fecb79237179edf637e25b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1af7b815e17b092e76aebb7d857c7b39 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1af7b815e17b092e76aebb7d857c7b39.addTo(map_afec05cf89fecb79237179edf637e25b);
#
#
#             var feature_group_fa1d492824317175da06a37dfe946652 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ca783b2c1a24529d8581b8d3615e4399 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fa1d492824317175da06a37dfe946652);
#
#
#         var popup_35835a434869d08a2fb4ae9ef5069648 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_439768d01744308f0349f980f53a0201 = $(`&lt;div id=&quot;html_439768d01744308f0349f980f53a0201&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_35835a434869d08a2fb4ae9ef5069648.setContent(html_439768d01744308f0349f980f53a0201);
#
#
#
#         marker_ca783b2c1a24529d8581b8d3615e4399.bindPopup(popup_35835a434869d08a2fb4ae9ef5069648)
#         ;
#
#
#
#
#             var marker_12493dd94b984fee494073be0ef9f4e2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fa1d492824317175da06a37dfe946652);
#
#
#         var popup_62d9e048e2cc1c6e622abf437410ce3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40599a9cd57d4f71193a8e269497ae77 = $(`&lt;div id=&quot;html_40599a9cd57d4f71193a8e269497ae77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_62d9e048e2cc1c6e622abf437410ce3f.setContent(html_40599a9cd57d4f71193a8e269497ae77);
#
#
#
#         marker_12493dd94b984fee494073be0ef9f4e2.bindPopup(popup_62d9e048e2cc1c6e622abf437410ce3f)
#         ;
#
#
#
#
#             var marker_fdb1fdf3b476cec300c2d8a63b6e38e1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fa1d492824317175da06a37dfe946652);
#
#
#         var popup_b533d45adc769274feba1aebaf1850ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72fedba5ac4c4470d90956158b42954f = $(`&lt;div id=&quot;html_72fedba5ac4c4470d90956158b42954f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b533d45adc769274feba1aebaf1850ad.setContent(html_72fedba5ac4c4470d90956158b42954f);
#
#
#
#         marker_fdb1fdf3b476cec300c2d8a63b6e38e1.bindPopup(popup_b533d45adc769274feba1aebaf1850ad)
#         ;
#
#
#
#
#             var marker_82ba36f1f30abc10fb15ef8a15653344 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fa1d492824317175da06a37dfe946652);
#
#
#         var popup_b0e62d542ad992c7a56829e60bf1bd7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b44c712339c413668de34846fa5ecab7 = $(`&lt;div id=&quot;html_b44c712339c413668de34846fa5ecab7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b0e62d542ad992c7a56829e60bf1bd7e.setContent(html_b44c712339c413668de34846fa5ecab7);
#
#
#
#         marker_82ba36f1f30abc10fb15ef8a15653344.bindPopup(popup_b0e62d542ad992c7a56829e60bf1bd7e)
#         ;
#
#
#
#
#             var marker_0e7092dab748b0cba6a7a844dacdf5e9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fa1d492824317175da06a37dfe946652);
#
#
#         var popup_79b90e8ea48407a69e7da952038d68a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bf839ea6def127b6071fd7fa492dcd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bf839ea6def127b6071fd7fa492dcd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bf839ea6def127b6071fd7fa492dcd6 = L.map(
#                 &quot;map_4bf839ea6def127b6071fd7fa492dcd6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0de8c64eb0f68e12083279146bce3a18 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0de8c64eb0f68e12083279146bce3a18.addTo(map_4bf839ea6def127b6071fd7fa492dcd6);
#
#
#             var feature_group_6697d069c519e287590b8a546c68b500 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6697d069c519e287590b8a546c68b500.addTo(map_4bf839ea6def127b6071fd7fa492dcd6);
#
#
#             var feature_group_sub_group_18cc22a67e6f4304a211a5090f83aea9 = L.featureGroup.subGroup(
#                 feature_group_6697d069c519e287590b8a546c68b500
#             );
#
#
#             var marker_ed1afc00d76e31dfc87c4a92dd0298d8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_18cc22a67e6f4304a211a5090f83aea9);
#
#
#         var popup_725c21c19b4f25581d28e060cace68b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c654aa2e72d3371fdddc6d56c4deffa = $(`&lt;div id=&quot;html_2c654aa2e72d3371fdddc6d56c4deffa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_725c21c19b4f25581d28e060cace68b3.setContent(html_2c654aa2e72d3371fdddc6d56c4deffa);
#
#
#
#         marker_ed1afc00d76e31dfc87c4a92dd0298d8.bindPopup(popup_725c21c19b4f25581d28e060cace68b3)
#         ;
#
#
#
#
#             var marker_5608c503b6d61f5bcb2afecd03155252 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_18cc22a67e6f4304a211a5090f83aea9);
#
#
#         var popup_6119d4afbb3d1088914666a38a834cb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_941ec475c438091f8cb5dc65b2acf42d = $(`&lt;div id=&quot;html_941ec475c438091f8cb5dc65b2acf42d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6119d4afbb3d1088914666a38a834cb7.setContent(html_941ec475c438091f8cb5dc65b2acf42d);
#
#
#
#         marker_5608c503b6d61f5bcb2afecd03155252.bindPopup(popup_6119d4afbb3d1088914666a38a834cb7)
#         ;
#
#
#
#
#             var marker_a7ad59addfd70f612b4f8e16c40f46bf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_18cc22a67e6f4304a211a5090f83aea9);
#
#
#         var popup_08e095996580721428c44b47d92ed695 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98e863fe3c010f63ce5b4802437155d2 = $(`&lt;div id=&quot;html_98e863fe3c010f63ce5b4802437155d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_08e095996580721428c44b47d92ed695.setContent(html_98e863fe3c010f63ce5b4802437155d2);
#
#
#
#         marker_a7ad59addfd70f612b4f8e16c40f46bf.bindPopup(popup_08e095996580721428c44b47d92ed695)
#         ;
#
#
#
#
#             var marker_ac1181ef06a1a35cc9c05dc8c841ab4c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_18cc22a67e6f4304a211a5090f83aea9);
#
#
#         var popup_24b8556f0aa8f4669c3cd1a07c1a129e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d72ab4fb3e20541f1079a366160e8e6 = $(`&lt;div id=&quot;html_3d72ab4fb3e20541f1079a366160e8e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_24b8556f0aa8f4669c3cd1a07c1a129e.setContent(html_3d72ab4fb3e20541f1079a366160e8e6);
#
#
#
#         marker_
