# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fe37c2d59cda5dfaa4a327f1371f788 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fe37c2d59cda5dfaa4a327f1371f788&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7fe37c2d59cda5dfaa4a327f1371f788 = L.map(
#                 &quot;map_7fe37c2d59cda5dfaa4a327f1371f788&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aef01d2be1d7fc7063a9cc8a4907c68c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aef01d2be1d7fc7063a9cc8a4907c68c.addTo(map_7fe37c2d59cda5dfaa4a327f1371f788);
#
#
#             var marker_8d49b32e59fddab81706f15a2b2a3372 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7fe37c2d59cda5dfaa4a327f1371f788);
#
#
#         var popup_c417a1a989983f9d5e585e04c7a97f90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fa3c2b786bf6ce41ea0edb727e9c1ae = $(`&lt;div id=&quot;html_4fa3c2b786bf6ce41ea0edb727e9c1ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c417a1a989983f9d5e585e04c7a97f90.setContent(html_4fa3c2b786bf6ce41ea0edb727e9c1ae);
#
#
#
#         marker_8d49b32e59fddab81706f15a2b2a3372.bindPopup(popup_c417a1a989983f9d5e585e04c7a97f90)
#         ;
#
#
#
#
#             var marker_2755eefabecdd26fbe8728ac1056e064 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7fe37c2d59cda5dfaa4a327f1371f788);
#
#
#         var popup_9d6e184655d82770c7f3b6409d0eaf59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b96b1a38192c22289dba930490e1f1b = $(`&lt;div id=&quot;html_3b96b1a38192c22289dba930490e1f1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9d6e184655d82770c7f3b6409d0eaf59.setContent(html_3b96b1a38192c22289dba930490e1f1b);
#
#
#
#         marker_2755eefabecdd26fbe8728ac1056e064.bindPopup(popup_9d6e184655d82770c7f3b6409d0eaf59)
#         ;
#
#
#
#
#             var marker_cbd8b83d9cb9bb58a1acb7d0b7dccae1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7fe37c2d59cda5dfaa4a327f1371f788);
#
#
#         var popup_80030de06af02ee741eb0e68ffd90197 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_745f2688cf17522eb7456e341fdf09a1 = $(`&lt;div id=&quot;html_745f2688cf17522eb7456e341fdf09a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_80030de06af02ee741eb0e68ffd90197.setContent(html_745f2688cf17522eb7456e341fdf09a1);
#
#
#
#         marker_cbd8b83d9cb9bb58a1acb7d0b7dccae1.bindPopup(popup_80030de06af02ee741eb0e68ffd90197)
#         ;
#
#
#
#
#             var marker_749e3694eed1417c43b3786f2aa81e76 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7fe37c2d59cda5dfaa4a327f1371f788);
#
#
#         var popup_77951dffa6a0283efba731478c519b23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45495511a532cd5f29eac4c50b58153c = $(`&lt;div id=&quot;html_45495511a532cd5f29eac4c50b58153c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_77951dffa6a0283efba731478c519b23.setContent(html_45495511a532cd5f29eac4c50b58153c);
#
#
#
#         marker_749e3694eed1417c43b3786f2aa81e76.bindPopup(popup_77951dffa6a0283efba731478c519b23)
#         ;
#
#
#
#
#             var marker_9f40d5baff03154d4c0c4a234adee3ca = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7fe37c2d59cda5dfaa4a327f1371f788);
#
#
#         var popup_24da14737dfd012657d07d198dbe078a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02644321e9986b325bd2dc2300a7bd69 = $(`&lt;div id=&quot;html_02644321e9986b325bd2dc2300a7bd69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_24da14737dfd012657d07d198dbe078a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8538b84a1c2dbda6644b0007fd56ba26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8538b84a1c2dbda6644b0007fd56ba26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8538b84a1c2dbda6644b0007fd56ba26 = L.map(
#                 &quot;map_8538b84a1c2dbda6644b0007fd56ba26&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db729bb12c2a574fb53e4516fbea7e01 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db729bb12c2a574fb53e4516fbea7e01.addTo(map_8538b84a1c2dbda6644b0007fd56ba26);
#
#
#             var feature_group_d7496c4d1de81389664f319cbdf3da7c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_72c03e382d2ebbe9028d2fd7b47eb38b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d7496c4d1de81389664f319cbdf3da7c);
#
#
#         var popup_fcfafb5eefbae6181c1a335cd9c04b9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b90f4e1b4ea4886774c6c6693e48d5c8 = $(`&lt;div id=&quot;html_b90f4e1b4ea4886774c6c6693e48d5c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fcfafb5eefbae6181c1a335cd9c04b9a.setContent(html_b90f4e1b4ea4886774c6c6693e48d5c8);
#
#
#
#         marker_72c03e382d2ebbe9028d2fd7b47eb38b.bindPopup(popup_fcfafb5eefbae6181c1a335cd9c04b9a)
#         ;
#
#
#
#
#             var marker_db99e787b01df0dd636810fdf38a5db7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d7496c4d1de81389664f319cbdf3da7c);
#
#
#         var popup_5d4581b0dd51103a815e9259b7c4df28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a375eafcf09a7bc29b3a0b6ca21defd = $(`&lt;div id=&quot;html_7a375eafcf09a7bc29b3a0b6ca21defd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5d4581b0dd51103a815e9259b7c4df28.setContent(html_7a375eafcf09a7bc29b3a0b6ca21defd);
#
#
#
#         marker_db99e787b01df0dd636810fdf38a5db7.bindPopup(popup_5d4581b0dd51103a815e9259b7c4df28)
#         ;
#
#
#
#
#             var marker_bc351c7ebe1e25f759ff8e26a773c870 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d7496c4d1de81389664f319cbdf3da7c);
#
#
#         var popup_4a064d6f3e557bbc5ac0c4b2f2cebcd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dedaf5d7d03c86c3ec14886a42c7a722 = $(`&lt;div id=&quot;html_dedaf5d7d03c86c3ec14886a42c7a722&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4a064d6f3e557bbc5ac0c4b2f2cebcd2.setContent(html_dedaf5d7d03c86c3ec14886a42c7a722);
#
#
#
#         marker_bc351c7ebe1e25f759ff8e26a773c870.bindPopup(popup_4a064d6f3e557bbc5ac0c4b2f2cebcd2)
#         ;
#
#
#
#
#             var marker_2d95cda85066670af0a90f7e65c17d4c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d7496c4d1de81389664f319cbdf3da7c);
#
#
#         var popup_654c4ed4ad0efae04e9a0e09d9952b4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1a81d170bc0917d3c829ad10ad3c5ce = $(`&lt;div id=&quot;html_f1a81d170bc0917d3c829ad10ad3c5ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_654c4ed4ad0efae04e9a0e09d9952b4c.setContent(html_f1a81d170bc0917d3c829ad10ad3c5ce);
#
#
#
#         marker_2d95cda85066670af0a90f7e65c17d4c.bindPopup(popup_654c4ed4ad0efae04e9a0e09d9952b4c)
#         ;
#
#
#
#
#             var marker_e2f507c586cef3476a7eff0c66bb453b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d7496c4d1de81389664f319cbdf3da7c);
#
#
#         var popup_5df49545965242bbe29e4ddeb3d95771 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32c93b015f1193c2233fd92c1429fff7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32c93b015f1193c2233fd92c1429fff7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32c93b015f1193c2233fd92c1429fff7 = L.map(
#                 &quot;map_32c93b015f1193c2233fd92c1429fff7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d362c8240f348b4de8b6ff2299afd10d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d362c8240f348b4de8b6ff2299afd10d.addTo(map_32c93b015f1193c2233fd92c1429fff7);
#
#
#             var feature_group_eda3e4b475e0b7f0f5709398796f9eae = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_eda3e4b475e0b7f0f5709398796f9eae.addTo(map_32c93b015f1193c2233fd92c1429fff7);
#
#
#             var feature_group_sub_group_ea8911d253e6fc17439efc688ff9ad2d = L.featureGroup.subGroup(
#                 feature_group_eda3e4b475e0b7f0f5709398796f9eae
#             );
#
#
#             var marker_62b6eb1c9d443ad9b13dba18889d446e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ea8911d253e6fc17439efc688ff9ad2d);
#
#
#         var popup_60c87c965817b9f0ae5577df3bb2d42b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e97b53229fc6c881e089f1e170b5f58 = $(`&lt;div id=&quot;html_3e97b53229fc6c881e089f1e170b5f58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_60c87c965817b9f0ae5577df3bb2d42b.setContent(html_3e97b53229fc6c881e089f1e170b5f58);
#
#
#
#         marker_62b6eb1c9d443ad9b13dba18889d446e.bindPopup(popup_60c87c965817b9f0ae5577df3bb2d42b)
#         ;
#
#
#
#
#             var marker_9fd70ab4c90efc5721dbc05aad44e4c8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ea8911d253e6fc17439efc688ff9ad2d);
#
#
#         var popup_4fd2fe7dea150130663a7298affaf989 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e9c7600e320a1cd12145322f5613743 = $(`&lt;div id=&quot;html_2e9c7600e320a1cd12145322f5613743&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4fd2fe7dea150130663a7298affaf989.setContent(html_2e9c7600e320a1cd12145322f5613743);
#
#
#
#         marker_9fd70ab4c90efc5721dbc05aad44e4c8.bindPopup(popup_4fd2fe7dea150130663a7298affaf989)
#         ;
#
#
#
#
#             var marker_42a6286d34aaa94e6b1319e137b37b54 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ea8911d253e6fc17439efc688ff9ad2d);
#
#
#         var popup_cd663fe91238a2647f9c329408c7d9d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa372978707898b31dca205bbaca5aa1 = $(`&lt;div id=&quot;html_fa372978707898b31dca205bbaca5aa1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_cd663fe91238a2647f9c329408c7d9d4.setContent(html_fa372978707898b31dca205bbaca5aa1);
#
#
#
#         marker_42a6286d34aaa94e6b1319e137b37b54.bindPopup(popup_cd663fe91238a2647f9c329408c7d9d4)
#         ;
#
#
#
#
#             var marker_46a07a9e111cffa451a275392b0f55b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ea8911d253e6fc17439efc688ff9ad2d);
#
#
#         var popup_ff2c755e31fa9c15ee299078b490d14e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23b0a48a7b793d952b898b96b0fe801b = $(`&lt;div id=&quot;html_23b0a48a7b793d952b898b96b0fe801b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ff2c755e31fa9c15ee299078b490d14e.setContent(html_23b0a48a7b793d952b898b96b0fe801b);
#
#
#
#         marker_
