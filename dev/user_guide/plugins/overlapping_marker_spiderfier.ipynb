# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af6dafba13b283b5fa87ce841441c34d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af6dafba13b283b5fa87ce841441c34d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af6dafba13b283b5fa87ce841441c34d = L.map(
#                 &quot;map_af6dafba13b283b5fa87ce841441c34d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de9a71609356450daa673d17e518883f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_de9a71609356450daa673d17e518883f.addTo(map_af6dafba13b283b5fa87ce841441c34d);
#
#
#             var marker_5912210ae3571c1606c02b55dc537f20 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_af6dafba13b283b5fa87ce841441c34d);
#
#
#         var popup_6924b263c57e6040319f6fc38ef6302a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f84b0bde635c5a639cc36106110366d = $(`&lt;div id=&quot;html_0f84b0bde635c5a639cc36106110366d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6924b263c57e6040319f6fc38ef6302a.setContent(html_0f84b0bde635c5a639cc36106110366d);
#
#
#
#         marker_5912210ae3571c1606c02b55dc537f20.bindPopup(popup_6924b263c57e6040319f6fc38ef6302a)
#         ;
#
#
#
#
#             var marker_4f8371272f9d8c8cd42900f2e8868805 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_af6dafba13b283b5fa87ce841441c34d);
#
#
#         var popup_f43544f936de26b454cf00a52d762426 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3b6eab119486064d5afab0ed4c7db16 = $(`&lt;div id=&quot;html_c3b6eab119486064d5afab0ed4c7db16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f43544f936de26b454cf00a52d762426.setContent(html_c3b6eab119486064d5afab0ed4c7db16);
#
#
#
#         marker_4f8371272f9d8c8cd42900f2e8868805.bindPopup(popup_f43544f936de26b454cf00a52d762426)
#         ;
#
#
#
#
#             var marker_07c9304a1c4baac86f24ade0b1f5ade3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_af6dafba13b283b5fa87ce841441c34d);
#
#
#         var popup_3b0deaba5a93c47a6cb2d9f68aec5db8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03e2d97ca2a1b661475a9b193b44de44 = $(`&lt;div id=&quot;html_03e2d97ca2a1b661475a9b193b44de44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3b0deaba5a93c47a6cb2d9f68aec5db8.setContent(html_03e2d97ca2a1b661475a9b193b44de44);
#
#
#
#         marker_07c9304a1c4baac86f24ade0b1f5ade3.bindPopup(popup_3b0deaba5a93c47a6cb2d9f68aec5db8)
#         ;
#
#
#
#
#             var marker_4b785b40cc2201376e0783702ab687cf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_af6dafba13b283b5fa87ce841441c34d);
#
#
#         var popup_5c3f02b2136918f819eb63c814aa6649 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4669d641959cc62fb322db8a48cc20aa = $(`&lt;div id=&quot;html_4669d641959cc62fb322db8a48cc20aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5c3f02b2136918f819eb63c814aa6649.setContent(html_4669d641959cc62fb322db8a48cc20aa);
#
#
#
#         marker_4b785b40cc2201376e0783702ab687cf.bindPopup(popup_5c3f02b2136918f819eb63c814aa6649)
#         ;
#
#
#
#
#             var marker_724394d9c7cd41b7cf702c9ac734095f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_af6dafba13b283b5fa87ce841441c34d);
#
#
#         var popup_6f2b2be00b0cf7c91bbe96d502cbb6d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39f5d981dfc5126e7370501c46b93863 = $(`&lt;div id=&quot;html_39f5d981dfc5126e7370501c46b93863&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6f2b2be00b0cf7c91bbe96d502cbb6d4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f98d622d6dc7c720f99d64d706251133 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f98d622d6dc7c720f99d64d706251133&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f98d622d6dc7c720f99d64d706251133 = L.map(
#                 &quot;map_f98d622d6dc7c720f99d64d706251133&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce3359cfd55693342a6d27357e343020 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce3359cfd55693342a6d27357e343020.addTo(map_f98d622d6dc7c720f99d64d706251133);
#
#
#             var feature_group_29a32f77f62037a264ff6d31d66c7d8a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_eaaa335b15ff46619267ec7dc6544aa7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_29a32f77f62037a264ff6d31d66c7d8a);
#
#
#         var popup_2cfe2f5bc6dadfceb742428d8d91ad37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17b51324ec8adeb407b94577530f92a1 = $(`&lt;div id=&quot;html_17b51324ec8adeb407b94577530f92a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2cfe2f5bc6dadfceb742428d8d91ad37.setContent(html_17b51324ec8adeb407b94577530f92a1);
#
#
#
#         marker_eaaa335b15ff46619267ec7dc6544aa7.bindPopup(popup_2cfe2f5bc6dadfceb742428d8d91ad37)
#         ;
#
#
#
#
#             var marker_34ef2dcb6234ee45efad34c7b83dcf26 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_29a32f77f62037a264ff6d31d66c7d8a);
#
#
#         var popup_b720e33f0c98ef6c9dd7554e4b1320bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30f543f4aec5f462a47eae97df820363 = $(`&lt;div id=&quot;html_30f543f4aec5f462a47eae97df820363&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b720e33f0c98ef6c9dd7554e4b1320bb.setContent(html_30f543f4aec5f462a47eae97df820363);
#
#
#
#         marker_34ef2dcb6234ee45efad34c7b83dcf26.bindPopup(popup_b720e33f0c98ef6c9dd7554e4b1320bb)
#         ;
#
#
#
#
#             var marker_20aec9eed9a280af6effa0b2f128bc2f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_29a32f77f62037a264ff6d31d66c7d8a);
#
#
#         var popup_bab8d4e9a4ac49e6ae300efbb427a5fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc9f9d7b43181bcd61d1e40e856b3b06 = $(`&lt;div id=&quot;html_cc9f9d7b43181bcd61d1e40e856b3b06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bab8d4e9a4ac49e6ae300efbb427a5fe.setContent(html_cc9f9d7b43181bcd61d1e40e856b3b06);
#
#
#
#         marker_20aec9eed9a280af6effa0b2f128bc2f.bindPopup(popup_bab8d4e9a4ac49e6ae300efbb427a5fe)
#         ;
#
#
#
#
#             var marker_53d131662c0fd3a6c0d3d3d06670c3c8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_29a32f77f62037a264ff6d31d66c7d8a);
#
#
#         var popup_0edcb81721bef93e006a4fa972209a32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fd8f05c86cdaaffee8b8a1257ac067b = $(`&lt;div id=&quot;html_2fd8f05c86cdaaffee8b8a1257ac067b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0edcb81721bef93e006a4fa972209a32.setContent(html_2fd8f05c86cdaaffee8b8a1257ac067b);
#
#
#
#         marker_53d131662c0fd3a6c0d3d3d06670c3c8.bindPopup(popup_0edcb81721bef93e006a4fa972209a32)
#         ;
#
#
#
#
#             var marker_1a82bc681f7bf3229b540d2a25521a04 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_29a32f77f62037a264ff6d31d66c7d8a);
#
#
#         var popup_5fc04cc7d7e7b1177f198b1d78456c02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_597415495a048aab2a73acc2c6253cfc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_597415495a048aab2a73acc2c6253cfc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_597415495a048aab2a73acc2c6253cfc = L.map(
#                 &quot;map_597415495a048aab2a73acc2c6253cfc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4cb749044c49f32a30505f403b878e7f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4cb749044c49f32a30505f403b878e7f.addTo(map_597415495a048aab2a73acc2c6253cfc);
#
#
#             var feature_group_8d70df44ca7e215ff3933a0609c8b241 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8d70df44ca7e215ff3933a0609c8b241.addTo(map_597415495a048aab2a73acc2c6253cfc);
#
#
#             var feature_group_sub_group_726dcaa3cb88436ff5b87df0be87f966 = L.featureGroup.subGroup(
#                 feature_group_8d70df44ca7e215ff3933a0609c8b241
#             );
#
#
#             var marker_8086d7ef180ec3f644df25d3e3c39754 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_726dcaa3cb88436ff5b87df0be87f966);
#
#
#         var popup_01195396c753627e17639b37133e1471 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_114ac417ccff27f14bfcc5bcf2be8b21 = $(`&lt;div id=&quot;html_114ac417ccff27f14bfcc5bcf2be8b21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_01195396c753627e17639b37133e1471.setContent(html_114ac417ccff27f14bfcc5bcf2be8b21);
#
#
#
#         marker_8086d7ef180ec3f644df25d3e3c39754.bindPopup(popup_01195396c753627e17639b37133e1471)
#         ;
#
#
#
#
#             var marker_2a62c41b5de6f7ee830a9834709280e8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_726dcaa3cb88436ff5b87df0be87f966);
#
#
#         var popup_6340c4e2ff8ec4c2fd76925237532996 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_047cfd9d841493dbded747f026960dc1 = $(`&lt;div id=&quot;html_047cfd9d841493dbded747f026960dc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6340c4e2ff8ec4c2fd76925237532996.setContent(html_047cfd9d841493dbded747f026960dc1);
#
#
#
#         marker_2a62c41b5de6f7ee830a9834709280e8.bindPopup(popup_6340c4e2ff8ec4c2fd76925237532996)
#         ;
#
#
#
#
#             var marker_65d397ccc0ec9611471b75318ff1aafa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_726dcaa3cb88436ff5b87df0be87f966);
#
#
#         var popup_f322ecae1c14dc289475d884ea048507 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_810c6b617afd84821e074aa95a85b503 = $(`&lt;div id=&quot;html_810c6b617afd84821e074aa95a85b503&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f322ecae1c14dc289475d884ea048507.setContent(html_810c6b617afd84821e074aa95a85b503);
#
#
#
#         marker_65d397ccc0ec9611471b75318ff1aafa.bindPopup(popup_f322ecae1c14dc289475d884ea048507)
#         ;
#
#
#
#
#             var marker_7ffa9b766b60b6b961ab93182a391d05 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_726dcaa3cb88436ff5b87df0be87f966);
#
#
#         var popup_731ce7f4a4750031dbdd2cce89bbc1d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b715a17a9bf8d838067d8564e6cec98 = $(`&lt;div id=&quot;html_8b715a17a9bf8d838067d8564e6cec98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_731ce7f4a4750031dbdd2cce89bbc1d3.setContent(html_8b715a17a9bf8d838067d8564e6cec98);
#
#
#
#         marker_
