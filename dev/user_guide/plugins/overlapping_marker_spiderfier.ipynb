# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ace537ee64f48149af8e7734e7780c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ace537ee64f48149af8e7734e7780c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ace537ee64f48149af8e7734e7780c0 = L.map(
#                 &quot;map_5ace537ee64f48149af8e7734e7780c0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02cd301caf84ab5b9f045efdd59fa36f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_02cd301caf84ab5b9f045efdd59fa36f.addTo(map_5ace537ee64f48149af8e7734e7780c0);
#
#
#             var marker_493c47e97202ce499fa9f672b48b70b0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5ace537ee64f48149af8e7734e7780c0);
#
#
#         var popup_f5910f3bb8e1c533471dc31a1bb7a857 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bc74aa337a6d8cbad5998fb61cb77e3 = $(`&lt;div id=&quot;html_9bc74aa337a6d8cbad5998fb61cb77e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f5910f3bb8e1c533471dc31a1bb7a857.setContent(html_9bc74aa337a6d8cbad5998fb61cb77e3);
#
#
#
#         marker_493c47e97202ce499fa9f672b48b70b0.bindPopup(popup_f5910f3bb8e1c533471dc31a1bb7a857)
#         ;
#
#
#
#
#             var marker_83ef5327260974c4677f04951dc63cd6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5ace537ee64f48149af8e7734e7780c0);
#
#
#         var popup_92fc58861acddfac2e2e30ce6855b82b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abbc1018064eaa3e1a68b3c0df3bc0a7 = $(`&lt;div id=&quot;html_abbc1018064eaa3e1a68b3c0df3bc0a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_92fc58861acddfac2e2e30ce6855b82b.setContent(html_abbc1018064eaa3e1a68b3c0df3bc0a7);
#
#
#
#         marker_83ef5327260974c4677f04951dc63cd6.bindPopup(popup_92fc58861acddfac2e2e30ce6855b82b)
#         ;
#
#
#
#
#             var marker_1442a3e46a72a4428b944391681283e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5ace537ee64f48149af8e7734e7780c0);
#
#
#         var popup_cebd3850edc8ca56b5e5b6eacad4235d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_efeb6f7d22226cd185f15bbaa5db5a0b = $(`&lt;div id=&quot;html_efeb6f7d22226cd185f15bbaa5db5a0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cebd3850edc8ca56b5e5b6eacad4235d.setContent(html_efeb6f7d22226cd185f15bbaa5db5a0b);
#
#
#
#         marker_1442a3e46a72a4428b944391681283e8.bindPopup(popup_cebd3850edc8ca56b5e5b6eacad4235d)
#         ;
#
#
#
#
#             var marker_96b613675a56500e38bcd8de8f9d07a5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5ace537ee64f48149af8e7734e7780c0);
#
#
#         var popup_bfad8ff91ac9fdbe30e20cd3c81272e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73366b2dd6322750e313b53e7a8f71b7 = $(`&lt;div id=&quot;html_73366b2dd6322750e313b53e7a8f71b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bfad8ff91ac9fdbe30e20cd3c81272e1.setContent(html_73366b2dd6322750e313b53e7a8f71b7);
#
#
#
#         marker_96b613675a56500e38bcd8de8f9d07a5.bindPopup(popup_bfad8ff91ac9fdbe30e20cd3c81272e1)
#         ;
#
#
#
#
#             var marker_55017f859150177ce770c896f238cbc0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5ace537ee64f48149af8e7734e7780c0);
#
#
#         var popup_4a467a8080229d43c9864fcff9bfba1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ba8d6b185c4f28663404d575d43c311 = $(`&lt;div id=&quot;html_8ba8d6b185c4f28663404d575d43c311&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4a467a8080229d43c9864fcff9bfba1f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a725fc417b09b7ffb9ed70a1a08446d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a725fc417b09b7ffb9ed70a1a08446d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a725fc417b09b7ffb9ed70a1a08446d = L.map(
#                 &quot;map_4a725fc417b09b7ffb9ed70a1a08446d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cd07719c12a34b02e4f610f48b49eea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2cd07719c12a34b02e4f610f48b49eea.addTo(map_4a725fc417b09b7ffb9ed70a1a08446d);
#
#
#             var feature_group_7e0896a69191cd0dc7080b125f6a8587 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e2c69f6ed46bf4db981bf10d6a60f460 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7e0896a69191cd0dc7080b125f6a8587);
#
#
#         var popup_b95f839089702f4e8c1eb7ed31327fcc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d97b6c6583ae2a477d23b46d8e41fe81 = $(`&lt;div id=&quot;html_d97b6c6583ae2a477d23b46d8e41fe81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b95f839089702f4e8c1eb7ed31327fcc.setContent(html_d97b6c6583ae2a477d23b46d8e41fe81);
#
#
#
#         marker_e2c69f6ed46bf4db981bf10d6a60f460.bindPopup(popup_b95f839089702f4e8c1eb7ed31327fcc)
#         ;
#
#
#
#
#             var marker_f451729f2cea509c604c398e8b6dbfd6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7e0896a69191cd0dc7080b125f6a8587);
#
#
#         var popup_0249700c344f119607319a87541334ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c34488a3c2537d5cd72b87fc9a3686aa = $(`&lt;div id=&quot;html_c34488a3c2537d5cd72b87fc9a3686aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0249700c344f119607319a87541334ab.setContent(html_c34488a3c2537d5cd72b87fc9a3686aa);
#
#
#
#         marker_f451729f2cea509c604c398e8b6dbfd6.bindPopup(popup_0249700c344f119607319a87541334ab)
#         ;
#
#
#
#
#             var marker_61aab8d61faa8af940be6f5ab528d8d7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7e0896a69191cd0dc7080b125f6a8587);
#
#
#         var popup_cfa4939de38a1fb288fef03a29cc5815 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8722e28bed1f100ff0b9b2a035a1eab = $(`&lt;div id=&quot;html_b8722e28bed1f100ff0b9b2a035a1eab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cfa4939de38a1fb288fef03a29cc5815.setContent(html_b8722e28bed1f100ff0b9b2a035a1eab);
#
#
#
#         marker_61aab8d61faa8af940be6f5ab528d8d7.bindPopup(popup_cfa4939de38a1fb288fef03a29cc5815)
#         ;
#
#
#
#
#             var marker_92ec35e2cd220fd584cc321dfbabfdaa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7e0896a69191cd0dc7080b125f6a8587);
#
#
#         var popup_30f507da02e549ca2cbddc900a1a13e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dba99a033c277e6339907b78bb2d01f = $(`&lt;div id=&quot;html_7dba99a033c277e6339907b78bb2d01f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_30f507da02e549ca2cbddc900a1a13e9.setContent(html_7dba99a033c277e6339907b78bb2d01f);
#
#
#
#         marker_92ec35e2cd220fd584cc321dfbabfdaa.bindPopup(popup_30f507da02e549ca2cbddc900a1a13e9)
#         ;
#
#
#
#
#             var marker_57804ae0a1f02a9eb8952d5dfba357bf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7e0896a69191cd0dc7080b125f6a8587);
#
#
#         var popup_f6e2823e8b697899324883304277064d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ec14dc1c1b9f1cf4224ecaf0a5eb641 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ec14dc1c1b9f1cf4224ecaf0a5eb641&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ec14dc1c1b9f1cf4224ecaf0a5eb641 = L.map(
#                 &quot;map_2ec14dc1c1b9f1cf4224ecaf0a5eb641&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_988af9a37811841e410c845881f117ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_988af9a37811841e410c845881f117ba.addTo(map_2ec14dc1c1b9f1cf4224ecaf0a5eb641);
#
#
#             var feature_group_0b35dab3c2d1f4f8602c0552daa76112 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0b35dab3c2d1f4f8602c0552daa76112.addTo(map_2ec14dc1c1b9f1cf4224ecaf0a5eb641);
#
#
#             var feature_group_sub_group_836edfcf9aae63a7c7bcf8262e714c3e = L.featureGroup.subGroup(
#                 feature_group_0b35dab3c2d1f4f8602c0552daa76112
#             );
#
#
#             var marker_f649c68b33919de73a94f4c455b5caf1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_836edfcf9aae63a7c7bcf8262e714c3e);
#
#
#         var popup_e9b8d94a532027a4d5031ffac67013a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a38714807cb9e6090187dbbdb07b3d1f = $(`&lt;div id=&quot;html_a38714807cb9e6090187dbbdb07b3d1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e9b8d94a532027a4d5031ffac67013a8.setContent(html_a38714807cb9e6090187dbbdb07b3d1f);
#
#
#
#         marker_f649c68b33919de73a94f4c455b5caf1.bindPopup(popup_e9b8d94a532027a4d5031ffac67013a8)
#         ;
#
#
#
#
#             var marker_de42f774cbd4e557455ba7b77c65ad7e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_836edfcf9aae63a7c7bcf8262e714c3e);
#
#
#         var popup_3b80df56eec4d460001638f952949579 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77eb959711de6214f9b335b348531698 = $(`&lt;div id=&quot;html_77eb959711de6214f9b335b348531698&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3b80df56eec4d460001638f952949579.setContent(html_77eb959711de6214f9b335b348531698);
#
#
#
#         marker_de42f774cbd4e557455ba7b77c65ad7e.bindPopup(popup_3b80df56eec4d460001638f952949579)
#         ;
#
#
#
#
#             var marker_890db45201f24a85e9dfad16d6237f71 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_836edfcf9aae63a7c7bcf8262e714c3e);
#
#
#         var popup_1f5fbb4bbd0bc4c46c331f4e609d8080 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89696523113a3ed08fd6bf8f4211e725 = $(`&lt;div id=&quot;html_89696523113a3ed08fd6bf8f4211e725&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1f5fbb4bbd0bc4c46c331f4e609d8080.setContent(html_89696523113a3ed08fd6bf8f4211e725);
#
#
#
#         marker_890db45201f24a85e9dfad16d6237f71.bindPopup(popup_1f5fbb4bbd0bc4c46c331f4e609d8080)
#         ;
#
#
#
#
#             var marker_a8d5ff222914dcf0b72843ef6c38f840 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_836edfcf9aae63a7c7bcf8262e714c3e);
#
#
#         var popup_b0207c4a1b034bd203a46369603edea2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e34a55fc245d8b4b84ba69909b18bf3f = $(`&lt;div id=&quot;html_e34a55fc245d8b4b84ba69909b18bf3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b0207c4a1b034bd203a46369603edea2.setContent(html_e34a55fc245d8b4b84ba69909b18bf3f);
#
#
#
#         marker_
