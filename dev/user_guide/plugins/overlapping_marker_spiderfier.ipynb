# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e05951e48aa3049daf04b46f46300dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e05951e48aa3049daf04b46f46300dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e05951e48aa3049daf04b46f46300dd = L.map(
#                 &quot;map_1e05951e48aa3049daf04b46f46300dd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0d3db7ae4517038253087c7554aba76 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b0d3db7ae4517038253087c7554aba76.addTo(map_1e05951e48aa3049daf04b46f46300dd);
#
#
#             var marker_71abdbc17b9282695ad0c23cf9ddf78f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1e05951e48aa3049daf04b46f46300dd);
#
#
#         var popup_38ead211deda9f787880c5eb9f1efa48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_901af1d68992556b3b32cf301b24503b = $(`&lt;div id=&quot;html_901af1d68992556b3b32cf301b24503b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_38ead211deda9f787880c5eb9f1efa48.setContent(html_901af1d68992556b3b32cf301b24503b);
#
#
#
#         marker_71abdbc17b9282695ad0c23cf9ddf78f.bindPopup(popup_38ead211deda9f787880c5eb9f1efa48)
#         ;
#
#
#
#
#             var marker_fedef163609f449b85100f82d1af38b3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1e05951e48aa3049daf04b46f46300dd);
#
#
#         var popup_b425e0e6a1c3963ad2f0485274fc2111 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1212102923a6d06e5383388b6e1c3aea = $(`&lt;div id=&quot;html_1212102923a6d06e5383388b6e1c3aea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b425e0e6a1c3963ad2f0485274fc2111.setContent(html_1212102923a6d06e5383388b6e1c3aea);
#
#
#
#         marker_fedef163609f449b85100f82d1af38b3.bindPopup(popup_b425e0e6a1c3963ad2f0485274fc2111)
#         ;
#
#
#
#
#             var marker_4001ac113c5779ba676f7293af41cb1a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1e05951e48aa3049daf04b46f46300dd);
#
#
#         var popup_9151168f6a540be3d273e3a401ca24bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a31271ada251136ba792216c8078c5c = $(`&lt;div id=&quot;html_0a31271ada251136ba792216c8078c5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9151168f6a540be3d273e3a401ca24bb.setContent(html_0a31271ada251136ba792216c8078c5c);
#
#
#
#         marker_4001ac113c5779ba676f7293af41cb1a.bindPopup(popup_9151168f6a540be3d273e3a401ca24bb)
#         ;
#
#
#
#
#             var marker_bb1bae02a8acf7c333b6f785dd56d5e5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1e05951e48aa3049daf04b46f46300dd);
#
#
#         var popup_f6710934fa0b6f9bb471de21b032393e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_333106233a86668f9c8d943c641d2c3c = $(`&lt;div id=&quot;html_333106233a86668f9c8d943c641d2c3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f6710934fa0b6f9bb471de21b032393e.setContent(html_333106233a86668f9c8d943c641d2c3c);
#
#
#
#         marker_bb1bae02a8acf7c333b6f785dd56d5e5.bindPopup(popup_f6710934fa0b6f9bb471de21b032393e)
#         ;
#
#
#
#
#             var marker_8e850ac81acc8ac1cc485a8a5b4b99b3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1e05951e48aa3049daf04b46f46300dd);
#
#
#         var popup_a3b4731be91ad75b606589368dac6346 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19971a018d44b6027adbe48f396e9e7c = $(`&lt;div id=&quot;html_19971a018d44b6027adbe48f396e9e7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a3b4731be91ad75b606589368dac6346.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_247a5861b4039dbb635fdf3b946ba68d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_247a5861b4039dbb635fdf3b946ba68d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_247a5861b4039dbb635fdf3b946ba68d = L.map(
#                 &quot;map_247a5861b4039dbb635fdf3b946ba68d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d1b91133cc8e471a8735719280171fe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9d1b91133cc8e471a8735719280171fe.addTo(map_247a5861b4039dbb635fdf3b946ba68d);
#
#
#             var feature_group_06635743e28c63a17b0ce39c0b46028c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fde92f398e5143080e38dc2029e443f8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_06635743e28c63a17b0ce39c0b46028c);
#
#
#         var popup_50a8f93adad85f3405e68dc182502c10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f0a79984f418fede2fd7f1eaa8a5e3b = $(`&lt;div id=&quot;html_5f0a79984f418fede2fd7f1eaa8a5e3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_50a8f93adad85f3405e68dc182502c10.setContent(html_5f0a79984f418fede2fd7f1eaa8a5e3b);
#
#
#
#         marker_fde92f398e5143080e38dc2029e443f8.bindPopup(popup_50a8f93adad85f3405e68dc182502c10)
#         ;
#
#
#
#
#             var marker_f714e0d5823e5a45650755400812c37a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_06635743e28c63a17b0ce39c0b46028c);
#
#
#         var popup_d7db2f197e7cbe39fe4506b47fbdd4c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb4d04c556b9511d3512c008c2c6449e = $(`&lt;div id=&quot;html_eb4d04c556b9511d3512c008c2c6449e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d7db2f197e7cbe39fe4506b47fbdd4c3.setContent(html_eb4d04c556b9511d3512c008c2c6449e);
#
#
#
#         marker_f714e0d5823e5a45650755400812c37a.bindPopup(popup_d7db2f197e7cbe39fe4506b47fbdd4c3)
#         ;
#
#
#
#
#             var marker_73bbd9109371c3677b57086872512291 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_06635743e28c63a17b0ce39c0b46028c);
#
#
#         var popup_b0aa687833c41856401292d183e55aa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9228aa3897ef09d58d710ca74f512fc = $(`&lt;div id=&quot;html_a9228aa3897ef09d58d710ca74f512fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b0aa687833c41856401292d183e55aa9.setContent(html_a9228aa3897ef09d58d710ca74f512fc);
#
#
#
#         marker_73bbd9109371c3677b57086872512291.bindPopup(popup_b0aa687833c41856401292d183e55aa9)
#         ;
#
#
#
#
#             var marker_4074464f477433421df8f3a63c775a74 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_06635743e28c63a17b0ce39c0b46028c);
#
#
#         var popup_52ba7df6f5f35fd6e28dddcb0721779c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fef4e61026509f81f09cfab2bdcd54c4 = $(`&lt;div id=&quot;html_fef4e61026509f81f09cfab2bdcd54c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_52ba7df6f5f35fd6e28dddcb0721779c.setContent(html_fef4e61026509f81f09cfab2bdcd54c4);
#
#
#
#         marker_4074464f477433421df8f3a63c775a74.bindPopup(popup_52ba7df6f5f35fd6e28dddcb0721779c)
#         ;
#
#
#
#
#             var marker_af9439994bebcdc20261ba4ef673cb8c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_06635743e28c63a17b0ce39c0b46028c);
#
#
#         var popup_51590aaf15a94f1ca64bbe2896af9caf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9383a3ecbf50188606a8364b6d12f4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9383a3ecbf50188606a8364b6d12f4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9383a3ecbf50188606a8364b6d12f4f = L.map(
#                 &quot;map_a9383a3ecbf50188606a8364b6d12f4f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c51bee3ceea95f7329ee4f0bc9f9b63 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c51bee3ceea95f7329ee4f0bc9f9b63.addTo(map_a9383a3ecbf50188606a8364b6d12f4f);
#
#
#             var feature_group_c10c6279181d3a2d5dfc01b098e4eb52 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c10c6279181d3a2d5dfc01b098e4eb52.addTo(map_a9383a3ecbf50188606a8364b6d12f4f);
#
#
#             var feature_group_sub_group_62278bc7104665caabc0d3f862028e5f = L.featureGroup.subGroup(
#                 feature_group_c10c6279181d3a2d5dfc01b098e4eb52
#             );
#
#
#             var marker_cbc45454ada3e642d983dff9cda49ae6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_62278bc7104665caabc0d3f862028e5f);
#
#
#         var popup_b5c0124629d5dbb355e22bea5f5c672f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79f68124c29d1c3c98cc55d1dd8da887 = $(`&lt;div id=&quot;html_79f68124c29d1c3c98cc55d1dd8da887&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b5c0124629d5dbb355e22bea5f5c672f.setContent(html_79f68124c29d1c3c98cc55d1dd8da887);
#
#
#
#         marker_cbc45454ada3e642d983dff9cda49ae6.bindPopup(popup_b5c0124629d5dbb355e22bea5f5c672f)
#         ;
#
#
#
#
#             var marker_6e0db44e9e5f20ec54989e569795f40b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_62278bc7104665caabc0d3f862028e5f);
#
#
#         var popup_875f54b8947fc041e2ecd199b09ff35b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d187806bf010f19717482a172983b1f8 = $(`&lt;div id=&quot;html_d187806bf010f19717482a172983b1f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_875f54b8947fc041e2ecd199b09ff35b.setContent(html_d187806bf010f19717482a172983b1f8);
#
#
#
#         marker_6e0db44e9e5f20ec54989e569795f40b.bindPopup(popup_875f54b8947fc041e2ecd199b09ff35b)
#         ;
#
#
#
#
#             var marker_7f9cb6b6112ea04c9b150522650f02c6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_62278bc7104665caabc0d3f862028e5f);
#
#
#         var popup_ccee143adbb4c381f2ea97d6bcaf4ccf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a5e668d8af10d47ca705213e6327bc4 = $(`&lt;div id=&quot;html_3a5e668d8af10d47ca705213e6327bc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ccee143adbb4c381f2ea97d6bcaf4ccf.setContent(html_3a5e668d8af10d47ca705213e6327bc4);
#
#
#
#         marker_7f9cb6b6112ea04c9b150522650f02c6.bindPopup(popup_ccee143adbb4c381f2ea97d6bcaf4ccf)
#         ;
#
#
#
#
#             var marker_1cbe93b973afd6f4d1a6631348b62fcf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_62278bc7104665caabc0d3f862028e5f);
#
#
#         var popup_5a24ae18f0aedefbb105202ecba1d686 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcdfee919a427e217f80aad00d449258 = $(`&lt;div id=&quot;html_fcdfee919a427e217f80aad00d449258&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5a24ae18f0aedefbb105202ecba1d686.setContent(html_fcdfee919a427e217f80aad00d449258);
#
#
#
#         marker_
