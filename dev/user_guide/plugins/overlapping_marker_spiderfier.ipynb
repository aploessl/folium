# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d393a164c284a05cf0786fa76305db0e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d393a164c284a05cf0786fa76305db0e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d393a164c284a05cf0786fa76305db0e = L.map(
#                 &quot;map_d393a164c284a05cf0786fa76305db0e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14a87fd5b8b087192f094c15c8624e66 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_14a87fd5b8b087192f094c15c8624e66.addTo(map_d393a164c284a05cf0786fa76305db0e);
#
#
#             var marker_f843a47084c8a539ea02d0164547358f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d393a164c284a05cf0786fa76305db0e);
#
#
#         var popup_d9f685c21c05f1394fa1925f6356cb5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0316418c32b196544122a452c2104465 = $(`&lt;div id=&quot;html_0316418c32b196544122a452c2104465&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d9f685c21c05f1394fa1925f6356cb5b.setContent(html_0316418c32b196544122a452c2104465);
#
#
#
#         marker_f843a47084c8a539ea02d0164547358f.bindPopup(popup_d9f685c21c05f1394fa1925f6356cb5b)
#         ;
#
#
#
#
#             var marker_c470c4db120a5fb4e4f77bcd06aaab17 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d393a164c284a05cf0786fa76305db0e);
#
#
#         var popup_a6627b40504f50d656b3ea03dd7e6f14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1037f7d09d239859f1276565d2f4ec74 = $(`&lt;div id=&quot;html_1037f7d09d239859f1276565d2f4ec74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a6627b40504f50d656b3ea03dd7e6f14.setContent(html_1037f7d09d239859f1276565d2f4ec74);
#
#
#
#         marker_c470c4db120a5fb4e4f77bcd06aaab17.bindPopup(popup_a6627b40504f50d656b3ea03dd7e6f14)
#         ;
#
#
#
#
#             var marker_7a5f0c81d45fb84d67b4bf294b6f4042 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d393a164c284a05cf0786fa76305db0e);
#
#
#         var popup_e21b4991c4af9ed27d18ecf06f410aa4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d31a6a1cf5a9ad72e79f7aafa399872d = $(`&lt;div id=&quot;html_d31a6a1cf5a9ad72e79f7aafa399872d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e21b4991c4af9ed27d18ecf06f410aa4.setContent(html_d31a6a1cf5a9ad72e79f7aafa399872d);
#
#
#
#         marker_7a5f0c81d45fb84d67b4bf294b6f4042.bindPopup(popup_e21b4991c4af9ed27d18ecf06f410aa4)
#         ;
#
#
#
#
#             var marker_58edb6d0040c05a83e2c6ef6e3ce5c80 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d393a164c284a05cf0786fa76305db0e);
#
#
#         var popup_9e1e41bdaf96835be36759aceddb369e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_945fbf1c16d98bc1ac43be5559ffbe5e = $(`&lt;div id=&quot;html_945fbf1c16d98bc1ac43be5559ffbe5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9e1e41bdaf96835be36759aceddb369e.setContent(html_945fbf1c16d98bc1ac43be5559ffbe5e);
#
#
#
#         marker_58edb6d0040c05a83e2c6ef6e3ce5c80.bindPopup(popup_9e1e41bdaf96835be36759aceddb369e)
#         ;
#
#
#
#
#             var marker_8cf6045de8e391211503687f7a040cb8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d393a164c284a05cf0786fa76305db0e);
#
#
#         var popup_7e1e8fcb6737335b895e2b43b3e17112 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a201c639ab12b240e86a0d6b4aeb170 = $(`&lt;div id=&quot;html_3a201c639ab12b240e86a0d6b4aeb170&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7e1e8fcb6737335b895e2b43b3e17112.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5408e76bde38c566d2819037930f48e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5408e76bde38c566d2819037930f48e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5408e76bde38c566d2819037930f48e7 = L.map(
#                 &quot;map_5408e76bde38c566d2819037930f48e7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_593c348c516b07e409583f0a8b38bc2e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_593c348c516b07e409583f0a8b38bc2e.addTo(map_5408e76bde38c566d2819037930f48e7);
#
#
#             var feature_group_3e14d1584fbe6e9b4957525873bf00f0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f6ed16fcb07597134c68a27f7d8a0144 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3e14d1584fbe6e9b4957525873bf00f0);
#
#
#         var popup_9f0ff2bb5c8a6604417191a29625ba5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e88f223cf587e17810b1e3136be951b4 = $(`&lt;div id=&quot;html_e88f223cf587e17810b1e3136be951b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9f0ff2bb5c8a6604417191a29625ba5a.setContent(html_e88f223cf587e17810b1e3136be951b4);
#
#
#
#         marker_f6ed16fcb07597134c68a27f7d8a0144.bindPopup(popup_9f0ff2bb5c8a6604417191a29625ba5a)
#         ;
#
#
#
#
#             var marker_c3936c1fc006f9f2f76d19a506aa7d3f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3e14d1584fbe6e9b4957525873bf00f0);
#
#
#         var popup_041f71eb26b55accc5431fb09a0e6f30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ad18ff73536fea963f836fe6f060e12 = $(`&lt;div id=&quot;html_7ad18ff73536fea963f836fe6f060e12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_041f71eb26b55accc5431fb09a0e6f30.setContent(html_7ad18ff73536fea963f836fe6f060e12);
#
#
#
#         marker_c3936c1fc006f9f2f76d19a506aa7d3f.bindPopup(popup_041f71eb26b55accc5431fb09a0e6f30)
#         ;
#
#
#
#
#             var marker_59acb0b08106bf5826acc45034f880f3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3e14d1584fbe6e9b4957525873bf00f0);
#
#
#         var popup_f8fd21e2b2aa05b690c6e36322b453bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b37e4be306ff1dba56ad5de0db580ede = $(`&lt;div id=&quot;html_b37e4be306ff1dba56ad5de0db580ede&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f8fd21e2b2aa05b690c6e36322b453bb.setContent(html_b37e4be306ff1dba56ad5de0db580ede);
#
#
#
#         marker_59acb0b08106bf5826acc45034f880f3.bindPopup(popup_f8fd21e2b2aa05b690c6e36322b453bb)
#         ;
#
#
#
#
#             var marker_7ef451069468569c399659e75fa2aa1c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3e14d1584fbe6e9b4957525873bf00f0);
#
#
#         var popup_9eab1521d63df539e80ca2388f4a556c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bad2db076068a1e202dde05c31c2c06 = $(`&lt;div id=&quot;html_6bad2db076068a1e202dde05c31c2c06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9eab1521d63df539e80ca2388f4a556c.setContent(html_6bad2db076068a1e202dde05c31c2c06);
#
#
#
#         marker_7ef451069468569c399659e75fa2aa1c.bindPopup(popup_9eab1521d63df539e80ca2388f4a556c)
#         ;
#
#
#
#
#             var marker_b46c8c0deaad56de6620b5d98ed963ca = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3e14d1584fbe6e9b4957525873bf00f0);
#
#
#         var popup_2588f4dd3be08841a37244cdcfe6ed3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4ed99b80b863896a309d23347935be0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4ed99b80b863896a309d23347935be0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4ed99b80b863896a309d23347935be0 = L.map(
#                 &quot;map_f4ed99b80b863896a309d23347935be0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4bec2a496a4b80bd6b5daaf21e483258 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4bec2a496a4b80bd6b5daaf21e483258.addTo(map_f4ed99b80b863896a309d23347935be0);
#
#
#             var feature_group_b92ef5c9f29fac366fd17aa19b271c12 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b92ef5c9f29fac366fd17aa19b271c12.addTo(map_f4ed99b80b863896a309d23347935be0);
#
#
#             var feature_group_sub_group_d160518ca8e0673f77176ae017793e11 = L.featureGroup.subGroup(
#                 feature_group_b92ef5c9f29fac366fd17aa19b271c12
#             );
#
#
#             var marker_b8986b5b3e0a347c4796e325dca86081 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d160518ca8e0673f77176ae017793e11);
#
#
#         var popup_bb429f71881f87316951cae4509b97b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dfe236e302c54c5cdb98197ee534632 = $(`&lt;div id=&quot;html_0dfe236e302c54c5cdb98197ee534632&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bb429f71881f87316951cae4509b97b7.setContent(html_0dfe236e302c54c5cdb98197ee534632);
#
#
#
#         marker_b8986b5b3e0a347c4796e325dca86081.bindPopup(popup_bb429f71881f87316951cae4509b97b7)
#         ;
#
#
#
#
#             var marker_8a31eca88993a3e05efd1bae171ca5be = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d160518ca8e0673f77176ae017793e11);
#
#
#         var popup_f447a62e49b7bef841cc20f16c177ee4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bb82a375d647d3ccc462a6c6e3d1d18 = $(`&lt;div id=&quot;html_0bb82a375d647d3ccc462a6c6e3d1d18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f447a62e49b7bef841cc20f16c177ee4.setContent(html_0bb82a375d647d3ccc462a6c6e3d1d18);
#
#
#
#         marker_8a31eca88993a3e05efd1bae171ca5be.bindPopup(popup_f447a62e49b7bef841cc20f16c177ee4)
#         ;
#
#
#
#
#             var marker_95da69dc5aaa189e2746ffb459768758 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d160518ca8e0673f77176ae017793e11);
#
#
#         var popup_76347dafded5162d20150201feffd821 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_874061186248adfeecb9d4df6352df99 = $(`&lt;div id=&quot;html_874061186248adfeecb9d4df6352df99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_76347dafded5162d20150201feffd821.setContent(html_874061186248adfeecb9d4df6352df99);
#
#
#
#         marker_95da69dc5aaa189e2746ffb459768758.bindPopup(popup_76347dafded5162d20150201feffd821)
#         ;
#
#
#
#
#             var marker_7cc3abf17fa63a0c37ee73a90c233a51 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d160518ca8e0673f77176ae017793e11);
#
#
#         var popup_24708855efb1347eca9208adcf552cec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a33b76c591ec9f9723edd35dfd203a8 = $(`&lt;div id=&quot;html_4a33b76c591ec9f9723edd35dfd203a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_24708855efb1347eca9208adcf552cec.setContent(html_4a33b76c591ec9f9723edd35dfd203a8);
#
#
#
#         marker_
