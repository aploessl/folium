# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ebd92ad777b28024dd8037682b3e8f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ebd92ad777b28024dd8037682b3e8f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ebd92ad777b28024dd8037682b3e8f9 = L.map(
#                 &quot;map_2ebd92ad777b28024dd8037682b3e8f9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b92a4be2b40ab5432468e3c215e17c94 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b92a4be2b40ab5432468e3c215e17c94.addTo(map_2ebd92ad777b28024dd8037682b3e8f9);
#
#
#             var marker_e6f2d6d2cfa5b152fc873752b9cc598c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2ebd92ad777b28024dd8037682b3e8f9);
#
#
#         var popup_0f9becccba561817261d12d7caa29d7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c773f3fdc8cfcc94b9adfd383117f709 = $(`&lt;div id=&quot;html_c773f3fdc8cfcc94b9adfd383117f709&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0f9becccba561817261d12d7caa29d7c.setContent(html_c773f3fdc8cfcc94b9adfd383117f709);
#
#
#
#         marker_e6f2d6d2cfa5b152fc873752b9cc598c.bindPopup(popup_0f9becccba561817261d12d7caa29d7c)
#         ;
#
#
#
#
#             var marker_65efc978b0584522170c253ec3e56de0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2ebd92ad777b28024dd8037682b3e8f9);
#
#
#         var popup_5c4ad4c09996eacdb89a285fc1b4ca87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bc1ec41ad05621bbb329ecbc6f223b3 = $(`&lt;div id=&quot;html_7bc1ec41ad05621bbb329ecbc6f223b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5c4ad4c09996eacdb89a285fc1b4ca87.setContent(html_7bc1ec41ad05621bbb329ecbc6f223b3);
#
#
#
#         marker_65efc978b0584522170c253ec3e56de0.bindPopup(popup_5c4ad4c09996eacdb89a285fc1b4ca87)
#         ;
#
#
#
#
#             var marker_045d39598843796d8712a65a827f8528 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2ebd92ad777b28024dd8037682b3e8f9);
#
#
#         var popup_4664af3c3f3d7bc17bb080488f31a2f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_091031e38e3efaeda6b486e44a1ee91f = $(`&lt;div id=&quot;html_091031e38e3efaeda6b486e44a1ee91f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4664af3c3f3d7bc17bb080488f31a2f1.setContent(html_091031e38e3efaeda6b486e44a1ee91f);
#
#
#
#         marker_045d39598843796d8712a65a827f8528.bindPopup(popup_4664af3c3f3d7bc17bb080488f31a2f1)
#         ;
#
#
#
#
#             var marker_fce85077962dfaa1195504ff0be4cc69 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2ebd92ad777b28024dd8037682b3e8f9);
#
#
#         var popup_1adcd42c557c79febff4c5e437be3374 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfb42c8c51a04c68ad10b5d896eeda5d = $(`&lt;div id=&quot;html_cfb42c8c51a04c68ad10b5d896eeda5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1adcd42c557c79febff4c5e437be3374.setContent(html_cfb42c8c51a04c68ad10b5d896eeda5d);
#
#
#
#         marker_fce85077962dfaa1195504ff0be4cc69.bindPopup(popup_1adcd42c557c79febff4c5e437be3374)
#         ;
#
#
#
#
#             var marker_c4b3741febe466757f14dadf0cc749b5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2ebd92ad777b28024dd8037682b3e8f9);
#
#
#         var popup_2d70e1fce4624cfaa26d6a32b1e6f88e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64ef68fce692dbe091b627e613750011 = $(`&lt;div id=&quot;html_64ef68fce692dbe091b627e613750011&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2d70e1fce4624cfaa26d6a32b1e6f88e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_381da83236a8a78a801eba447c0cc001 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_381da83236a8a78a801eba447c0cc001&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_381da83236a8a78a801eba447c0cc001 = L.map(
#                 &quot;map_381da83236a8a78a801eba447c0cc001&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc5485236258b76619e17722dc0c20e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dc5485236258b76619e17722dc0c20e6.addTo(map_381da83236a8a78a801eba447c0cc001);
#
#
#             var feature_group_12447043b683da2b4028c72b7d77d7fa = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_923bfabcabba28bc2a2b6b67fa5098a7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_12447043b683da2b4028c72b7d77d7fa);
#
#
#         var popup_e579a24996a6c1924b85a57375605f17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c65b5bd83c9432c5415702827c6fc728 = $(`&lt;div id=&quot;html_c65b5bd83c9432c5415702827c6fc728&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e579a24996a6c1924b85a57375605f17.setContent(html_c65b5bd83c9432c5415702827c6fc728);
#
#
#
#         marker_923bfabcabba28bc2a2b6b67fa5098a7.bindPopup(popup_e579a24996a6c1924b85a57375605f17)
#         ;
#
#
#
#
#             var marker_f79e08ff9a6b0588f589ddaecd9ab5d5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_12447043b683da2b4028c72b7d77d7fa);
#
#
#         var popup_8c4033333e96ffe262e052a6bbc81b87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b10971a437a08e82ef8891ce26cdd4f5 = $(`&lt;div id=&quot;html_b10971a437a08e82ef8891ce26cdd4f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8c4033333e96ffe262e052a6bbc81b87.setContent(html_b10971a437a08e82ef8891ce26cdd4f5);
#
#
#
#         marker_f79e08ff9a6b0588f589ddaecd9ab5d5.bindPopup(popup_8c4033333e96ffe262e052a6bbc81b87)
#         ;
#
#
#
#
#             var marker_c7e6215d8e414a56d5d098a2fe089cad = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_12447043b683da2b4028c72b7d77d7fa);
#
#
#         var popup_73283cb7892b1ad3dd389b5c39d82133 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4da5ce62abf36740bea0a51865f43aeb = $(`&lt;div id=&quot;html_4da5ce62abf36740bea0a51865f43aeb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_73283cb7892b1ad3dd389b5c39d82133.setContent(html_4da5ce62abf36740bea0a51865f43aeb);
#
#
#
#         marker_c7e6215d8e414a56d5d098a2fe089cad.bindPopup(popup_73283cb7892b1ad3dd389b5c39d82133)
#         ;
#
#
#
#
#             var marker_422ca67a580b5f1a662db72afc3de9f7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_12447043b683da2b4028c72b7d77d7fa);
#
#
#         var popup_41b4aba160387e39ebe90d6cbac4efd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c54f7217a5bf64d467d00dc7f2a263a = $(`&lt;div id=&quot;html_0c54f7217a5bf64d467d00dc7f2a263a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_41b4aba160387e39ebe90d6cbac4efd1.setContent(html_0c54f7217a5bf64d467d00dc7f2a263a);
#
#
#
#         marker_422ca67a580b5f1a662db72afc3de9f7.bindPopup(popup_41b4aba160387e39ebe90d6cbac4efd1)
#         ;
#
#
#
#
#             var marker_f6014dc4546826321fc68f387691c3db = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_12447043b683da2b4028c72b7d77d7fa);
#
#
#         var popup_2b1fdcb54fc1c38d38c8eef33bcf4d62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6745eea40d172944b025c5d9f6090591 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6745eea40d172944b025c5d9f6090591&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6745eea40d172944b025c5d9f6090591 = L.map(
#                 &quot;map_6745eea40d172944b025c5d9f6090591&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b0d89d528ac444d35aa946bca285691 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b0d89d528ac444d35aa946bca285691.addTo(map_6745eea40d172944b025c5d9f6090591);
#
#
#             var feature_group_9a0aa201625b5d7c12b3acc46d07a244 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9a0aa201625b5d7c12b3acc46d07a244.addTo(map_6745eea40d172944b025c5d9f6090591);
#
#
#             var feature_group_sub_group_d3e467209e0007dbdaa92f918f49cc9e = L.featureGroup.subGroup(
#                 feature_group_9a0aa201625b5d7c12b3acc46d07a244
#             );
#
#
#             var marker_27d4de3234405277a38d8f5869ddf11f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d3e467209e0007dbdaa92f918f49cc9e);
#
#
#         var popup_7ac5f490f647614e8f95ec9e6f90219a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ae1e34fab421b8518aacde0a44b07d1 = $(`&lt;div id=&quot;html_7ae1e34fab421b8518aacde0a44b07d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7ac5f490f647614e8f95ec9e6f90219a.setContent(html_7ae1e34fab421b8518aacde0a44b07d1);
#
#
#
#         marker_27d4de3234405277a38d8f5869ddf11f.bindPopup(popup_7ac5f490f647614e8f95ec9e6f90219a)
#         ;
#
#
#
#
#             var marker_ad4415b452616de38f689a3213ada291 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d3e467209e0007dbdaa92f918f49cc9e);
#
#
#         var popup_63056efbb4985e3736b26df87a3f6e41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_921cdf74ebaa3d34c183b8f123aad184 = $(`&lt;div id=&quot;html_921cdf74ebaa3d34c183b8f123aad184&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_63056efbb4985e3736b26df87a3f6e41.setContent(html_921cdf74ebaa3d34c183b8f123aad184);
#
#
#
#         marker_ad4415b452616de38f689a3213ada291.bindPopup(popup_63056efbb4985e3736b26df87a3f6e41)
#         ;
#
#
#
#
#             var marker_34140b0ffa0ec15b4e9939f1ac6d48e6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d3e467209e0007dbdaa92f918f49cc9e);
#
#
#         var popup_fec88aafdd2d52f96dd314d9e52db309 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de372de9a524d004ecb83ea9e2f3c702 = $(`&lt;div id=&quot;html_de372de9a524d004ecb83ea9e2f3c702&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fec88aafdd2d52f96dd314d9e52db309.setContent(html_de372de9a524d004ecb83ea9e2f3c702);
#
#
#
#         marker_34140b0ffa0ec15b4e9939f1ac6d48e6.bindPopup(popup_fec88aafdd2d52f96dd314d9e52db309)
#         ;
#
#
#
#
#             var marker_13b4a44f6ef644809e2e75b3a4428cc1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d3e467209e0007dbdaa92f918f49cc9e);
#
#
#         var popup_f1097e7a7dc7aacde7cdc08490260254 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea190f4f3ab06210ec382dbfd71f8fc3 = $(`&lt;div id=&quot;html_ea190f4f3ab06210ec382dbfd71f8fc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f1097e7a7dc7aacde7cdc08490260254.setContent(html_ea190f4f3ab06210ec382dbfd71f8fc3);
#
#
#
#         marker_
