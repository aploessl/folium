# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d18dbe4f02634a62bc572836bf1e5de5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d18dbe4f02634a62bc572836bf1e5de5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d18dbe4f02634a62bc572836bf1e5de5 = L.map(
#                 &quot;map_d18dbe4f02634a62bc572836bf1e5de5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b8d397b20010393ac1f561ddd86a04e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b8d397b20010393ac1f561ddd86a04e.addTo(map_d18dbe4f02634a62bc572836bf1e5de5);
#
#
#             var marker_05e6eccbaff97e57284be1c22697e466 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d18dbe4f02634a62bc572836bf1e5de5);
#
#
#         var popup_51b220db52326b92d746a74b62d7cc2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_775e5d8fb64fc0777ea6c8ee5ace40ff = $(`&lt;div id=&quot;html_775e5d8fb64fc0777ea6c8ee5ace40ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_51b220db52326b92d746a74b62d7cc2a.setContent(html_775e5d8fb64fc0777ea6c8ee5ace40ff);
#
#
#
#         marker_05e6eccbaff97e57284be1c22697e466.bindPopup(popup_51b220db52326b92d746a74b62d7cc2a)
#         ;
#
#
#
#
#             var marker_038615ec0d6d873cb78525ed5128e07c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d18dbe4f02634a62bc572836bf1e5de5);
#
#
#         var popup_c1ca83d937207ac04a5b268fc93bd634 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73a4199398ea601569efceada6d32e4e = $(`&lt;div id=&quot;html_73a4199398ea601569efceada6d32e4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c1ca83d937207ac04a5b268fc93bd634.setContent(html_73a4199398ea601569efceada6d32e4e);
#
#
#
#         marker_038615ec0d6d873cb78525ed5128e07c.bindPopup(popup_c1ca83d937207ac04a5b268fc93bd634)
#         ;
#
#
#
#
#             var marker_6a7314b3d13bddbe1796320594c6f20a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d18dbe4f02634a62bc572836bf1e5de5);
#
#
#         var popup_63fef6e7a826528e0216c02b35f2c87a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c085c3ea0688a25780a6febbd5c93fb2 = $(`&lt;div id=&quot;html_c085c3ea0688a25780a6febbd5c93fb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_63fef6e7a826528e0216c02b35f2c87a.setContent(html_c085c3ea0688a25780a6febbd5c93fb2);
#
#
#
#         marker_6a7314b3d13bddbe1796320594c6f20a.bindPopup(popup_63fef6e7a826528e0216c02b35f2c87a)
#         ;
#
#
#
#
#             var marker_31e43312a577acc63fea9cbc36a98c1d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d18dbe4f02634a62bc572836bf1e5de5);
#
#
#         var popup_0b86bbd6fd84d29b691c843d0f99c163 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6def761f3da0c5c16266be54523b1179 = $(`&lt;div id=&quot;html_6def761f3da0c5c16266be54523b1179&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0b86bbd6fd84d29b691c843d0f99c163.setContent(html_6def761f3da0c5c16266be54523b1179);
#
#
#
#         marker_31e43312a577acc63fea9cbc36a98c1d.bindPopup(popup_0b86bbd6fd84d29b691c843d0f99c163)
#         ;
#
#
#
#
#             var marker_a2bf5672e9ef8e8728f9c76bddc04719 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d18dbe4f02634a62bc572836bf1e5de5);
#
#
#         var popup_9ce5f23bf5973f78321a4c5acba51044 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f0a05a4e592c01982507f2b430f0966 = $(`&lt;div id=&quot;html_6f0a05a4e592c01982507f2b430f0966&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9ce5f23bf5973f78321a4c5acba51044.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb8bafe93a50b2a6bb7cca8f549eedba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb8bafe93a50b2a6bb7cca8f549eedba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb8bafe93a50b2a6bb7cca8f549eedba = L.map(
#                 &quot;map_cb8bafe93a50b2a6bb7cca8f549eedba&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b6e1b98b5d2f02b6a0adb0f61885d7b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8b6e1b98b5d2f02b6a0adb0f61885d7b.addTo(map_cb8bafe93a50b2a6bb7cca8f549eedba);
#
#
#             var feature_group_0cc332dabce8c6157163d7b8a5aca818 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c123eca62a55e76549ee3e6c5cc99de6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0cc332dabce8c6157163d7b8a5aca818);
#
#
#         var popup_a62028377b7bd1d04983beb3de359793 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53f4b1dafa180f484374989711cd0d7f = $(`&lt;div id=&quot;html_53f4b1dafa180f484374989711cd0d7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a62028377b7bd1d04983beb3de359793.setContent(html_53f4b1dafa180f484374989711cd0d7f);
#
#
#
#         marker_c123eca62a55e76549ee3e6c5cc99de6.bindPopup(popup_a62028377b7bd1d04983beb3de359793)
#         ;
#
#
#
#
#             var marker_f665d9aa83f082cf35c81787bf1207ff = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0cc332dabce8c6157163d7b8a5aca818);
#
#
#         var popup_92ae87e6cde1bcee6bde045cac61d0d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77283fd74a85f739298f20f15be77304 = $(`&lt;div id=&quot;html_77283fd74a85f739298f20f15be77304&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_92ae87e6cde1bcee6bde045cac61d0d7.setContent(html_77283fd74a85f739298f20f15be77304);
#
#
#
#         marker_f665d9aa83f082cf35c81787bf1207ff.bindPopup(popup_92ae87e6cde1bcee6bde045cac61d0d7)
#         ;
#
#
#
#
#             var marker_864b75aaeb21dccc91189af66e969619 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0cc332dabce8c6157163d7b8a5aca818);
#
#
#         var popup_c6fa065ecab083fd64ed858575fc7373 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6539882725a5c0eaa8eccfcaf8aa7308 = $(`&lt;div id=&quot;html_6539882725a5c0eaa8eccfcaf8aa7308&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c6fa065ecab083fd64ed858575fc7373.setContent(html_6539882725a5c0eaa8eccfcaf8aa7308);
#
#
#
#         marker_864b75aaeb21dccc91189af66e969619.bindPopup(popup_c6fa065ecab083fd64ed858575fc7373)
#         ;
#
#
#
#
#             var marker_5dea447460ead1ab405b0db7927d4d23 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0cc332dabce8c6157163d7b8a5aca818);
#
#
#         var popup_386c766ea6ccad73b707ed47ced2fe9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17bd187222029ae7530282e8b971bc1d = $(`&lt;div id=&quot;html_17bd187222029ae7530282e8b971bc1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_386c766ea6ccad73b707ed47ced2fe9c.setContent(html_17bd187222029ae7530282e8b971bc1d);
#
#
#
#         marker_5dea447460ead1ab405b0db7927d4d23.bindPopup(popup_386c766ea6ccad73b707ed47ced2fe9c)
#         ;
#
#
#
#
#             var marker_f3591373135ea5f0f8a6af17b0bcec8c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0cc332dabce8c6157163d7b8a5aca818);
#
#
#         var popup_98b6bba59e7012a0e7fe706ab2765be2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35b053034fe8dcf8e17fcd1c98e6d630 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35b053034fe8dcf8e17fcd1c98e6d630&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35b053034fe8dcf8e17fcd1c98e6d630 = L.map(
#                 &quot;map_35b053034fe8dcf8e17fcd1c98e6d630&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7dde18c994a9a0e0a853530b47a39d08 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7dde18c994a9a0e0a853530b47a39d08.addTo(map_35b053034fe8dcf8e17fcd1c98e6d630);
#
#
#             var feature_group_6b903285e1a3f43b39fe49538a24d467 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6b903285e1a3f43b39fe49538a24d467.addTo(map_35b053034fe8dcf8e17fcd1c98e6d630);
#
#
#             var feature_group_sub_group_0b5a0943eb89fe83a21652d2edac8a68 = L.featureGroup.subGroup(
#                 feature_group_6b903285e1a3f43b39fe49538a24d467
#             );
#
#
#             var marker_c9ba302c89cfe2b18778babdc67aeb43 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0b5a0943eb89fe83a21652d2edac8a68);
#
#
#         var popup_8a58fb142266c7b6c7e9a2b6979881f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fd340b96090a909d145b82550b0ea7d = $(`&lt;div id=&quot;html_3fd340b96090a909d145b82550b0ea7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8a58fb142266c7b6c7e9a2b6979881f6.setContent(html_3fd340b96090a909d145b82550b0ea7d);
#
#
#
#         marker_c9ba302c89cfe2b18778babdc67aeb43.bindPopup(popup_8a58fb142266c7b6c7e9a2b6979881f6)
#         ;
#
#
#
#
#             var marker_fab77d92c9ff3628b6b2514242d741d6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0b5a0943eb89fe83a21652d2edac8a68);
#
#
#         var popup_3a301a47459377380bbe7bc8e3c1d7e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee6add88b5c0e70aad49317a11e941f0 = $(`&lt;div id=&quot;html_ee6add88b5c0e70aad49317a11e941f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3a301a47459377380bbe7bc8e3c1d7e5.setContent(html_ee6add88b5c0e70aad49317a11e941f0);
#
#
#
#         marker_fab77d92c9ff3628b6b2514242d741d6.bindPopup(popup_3a301a47459377380bbe7bc8e3c1d7e5)
#         ;
#
#
#
#
#             var marker_89daefb84162cc88c43b8e243af63b82 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0b5a0943eb89fe83a21652d2edac8a68);
#
#
#         var popup_bdcb5ac798a844d0a7318334450d0727 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2cc21f68b17d380c8c86aa4ee9dd458f = $(`&lt;div id=&quot;html_2cc21f68b17d380c8c86aa4ee9dd458f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bdcb5ac798a844d0a7318334450d0727.setContent(html_2cc21f68b17d380c8c86aa4ee9dd458f);
#
#
#
#         marker_89daefb84162cc88c43b8e243af63b82.bindPopup(popup_bdcb5ac798a844d0a7318334450d0727)
#         ;
#
#
#
#
#             var marker_68fa79fa7e40d8f1181faded3b007c9b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0b5a0943eb89fe83a21652d2edac8a68);
#
#
#         var popup_4a323a6b98ecb7fa65f27861f31cc89e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2886e24df6355e10847bb5aa676ad3f4 = $(`&lt;div id=&quot;html_2886e24df6355e10847bb5aa676ad3f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4a323a6b98ecb7fa65f27861f31cc89e.setContent(html_2886e24df6355e10847bb5aa676ad3f4);
#
#
#
#         marker_
