# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_558e3502dfc68eb865cfa7b864ca0225 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_558e3502dfc68eb865cfa7b864ca0225&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_558e3502dfc68eb865cfa7b864ca0225 = L.map(
#                 &quot;map_558e3502dfc68eb865cfa7b864ca0225&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a606a84bbbcf73e4d49c8a80cf98281c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a606a84bbbcf73e4d49c8a80cf98281c.addTo(map_558e3502dfc68eb865cfa7b864ca0225);
#
#
#             var marker_b8226596fae575bde317ced70f3d85f8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_558e3502dfc68eb865cfa7b864ca0225);
#
#
#         var popup_8123692d83b429c1a7fa94e633069a0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e01e11893cefaefa916dca3063a97ee9 = $(`&lt;div id=&quot;html_e01e11893cefaefa916dca3063a97ee9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8123692d83b429c1a7fa94e633069a0e.setContent(html_e01e11893cefaefa916dca3063a97ee9);
#
#
#
#         marker_b8226596fae575bde317ced70f3d85f8.bindPopup(popup_8123692d83b429c1a7fa94e633069a0e)
#         ;
#
#
#
#
#             var marker_b50dd2bec5e1e178da243b69b6426090 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_558e3502dfc68eb865cfa7b864ca0225);
#
#
#         var popup_028c6e0588e751c92f75c5f0432d9f6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_221db368b500baa3dba2c1ec6d2d8f9e = $(`&lt;div id=&quot;html_221db368b500baa3dba2c1ec6d2d8f9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_028c6e0588e751c92f75c5f0432d9f6e.setContent(html_221db368b500baa3dba2c1ec6d2d8f9e);
#
#
#
#         marker_b50dd2bec5e1e178da243b69b6426090.bindPopup(popup_028c6e0588e751c92f75c5f0432d9f6e)
#         ;
#
#
#
#
#             var marker_d76db60d27ab33e24f511c9bc674eefa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_558e3502dfc68eb865cfa7b864ca0225);
#
#
#         var popup_198a4d4b4b4486bdda4a1ef5ce78925a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4361b71d57863607e763ad64d2fc8b26 = $(`&lt;div id=&quot;html_4361b71d57863607e763ad64d2fc8b26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_198a4d4b4b4486bdda4a1ef5ce78925a.setContent(html_4361b71d57863607e763ad64d2fc8b26);
#
#
#
#         marker_d76db60d27ab33e24f511c9bc674eefa.bindPopup(popup_198a4d4b4b4486bdda4a1ef5ce78925a)
#         ;
#
#
#
#
#             var marker_4fabc45c3d10ac798ed6466939e1d954 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_558e3502dfc68eb865cfa7b864ca0225);
#
#
#         var popup_d6c1d837ee213cd7efaed5806420fc86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6d0f7755223ec73bd3965ae02c57aef = $(`&lt;div id=&quot;html_a6d0f7755223ec73bd3965ae02c57aef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d6c1d837ee213cd7efaed5806420fc86.setContent(html_a6d0f7755223ec73bd3965ae02c57aef);
#
#
#
#         marker_4fabc45c3d10ac798ed6466939e1d954.bindPopup(popup_d6c1d837ee213cd7efaed5806420fc86)
#         ;
#
#
#
#
#             var marker_c3af3060b324a13efa3df7956cb9b378 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_558e3502dfc68eb865cfa7b864ca0225);
#
#
#         var popup_8e3689b124f12dcbc1026ac1ee3e3f1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bb130751f9a4c24f11bf7e493cb95f5 = $(`&lt;div id=&quot;html_0bb130751f9a4c24f11bf7e493cb95f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8e3689b124f12dcbc1026ac1ee3e3f1a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_071843405d7355ea52918be7ea51275f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_071843405d7355ea52918be7ea51275f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_071843405d7355ea52918be7ea51275f = L.map(
#                 &quot;map_071843405d7355ea52918be7ea51275f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d36440e2a89f8aa72a04084bab06b7f6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d36440e2a89f8aa72a04084bab06b7f6.addTo(map_071843405d7355ea52918be7ea51275f);
#
#
#             var feature_group_4c4a8db520b5c4cf9ee87a863b73175d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ddf8d635f799702f9304dd1ef0990696 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4c4a8db520b5c4cf9ee87a863b73175d);
#
#
#         var popup_cef20cf6a075bf4965c92bf2a768c3d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_762d481dc90d927f9fa19fb6840edd16 = $(`&lt;div id=&quot;html_762d481dc90d927f9fa19fb6840edd16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cef20cf6a075bf4965c92bf2a768c3d8.setContent(html_762d481dc90d927f9fa19fb6840edd16);
#
#
#
#         marker_ddf8d635f799702f9304dd1ef0990696.bindPopup(popup_cef20cf6a075bf4965c92bf2a768c3d8)
#         ;
#
#
#
#
#             var marker_f69d27fe76ce0dddfdfb2a1a57911919 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4c4a8db520b5c4cf9ee87a863b73175d);
#
#
#         var popup_12784dad91c2efc09dda399d86b93fb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a68c073de8ce567bd5bc55d2f9f7e6f3 = $(`&lt;div id=&quot;html_a68c073de8ce567bd5bc55d2f9f7e6f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_12784dad91c2efc09dda399d86b93fb3.setContent(html_a68c073de8ce567bd5bc55d2f9f7e6f3);
#
#
#
#         marker_f69d27fe76ce0dddfdfb2a1a57911919.bindPopup(popup_12784dad91c2efc09dda399d86b93fb3)
#         ;
#
#
#
#
#             var marker_70f78ad75212801e772560ca166ee9ad = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4c4a8db520b5c4cf9ee87a863b73175d);
#
#
#         var popup_633ac041fdefaabc089459f4f3c74e90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d696c7f69f6616c0326516127adc760 = $(`&lt;div id=&quot;html_2d696c7f69f6616c0326516127adc760&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_633ac041fdefaabc089459f4f3c74e90.setContent(html_2d696c7f69f6616c0326516127adc760);
#
#
#
#         marker_70f78ad75212801e772560ca166ee9ad.bindPopup(popup_633ac041fdefaabc089459f4f3c74e90)
#         ;
#
#
#
#
#             var marker_4a921d16fee0fe6baacc4dc8d47e9700 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4c4a8db520b5c4cf9ee87a863b73175d);
#
#
#         var popup_eccb7ec78db6b0ec9a4e880b339de25e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c6bbadab7b0f3df456440727444d417 = $(`&lt;div id=&quot;html_5c6bbadab7b0f3df456440727444d417&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_eccb7ec78db6b0ec9a4e880b339de25e.setContent(html_5c6bbadab7b0f3df456440727444d417);
#
#
#
#         marker_4a921d16fee0fe6baacc4dc8d47e9700.bindPopup(popup_eccb7ec78db6b0ec9a4e880b339de25e)
#         ;
#
#
#
#
#             var marker_6c37efc01386d16996132d3cce9d16bc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4c4a8db520b5c4cf9ee87a863b73175d);
#
#
#         var popup_c7d863463aaf0fc83c330da30e4c12ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ab8adce393a273a48e4e133bb39899b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ab8adce393a273a48e4e133bb39899b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ab8adce393a273a48e4e133bb39899b = L.map(
#                 &quot;map_3ab8adce393a273a48e4e133bb39899b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2138ee6e843b5b42ba16e6877846a12 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d2138ee6e843b5b42ba16e6877846a12.addTo(map_3ab8adce393a273a48e4e133bb39899b);
#
#
#             var feature_group_507d1290ce0d4b4e2380f198190ec7b3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_507d1290ce0d4b4e2380f198190ec7b3.addTo(map_3ab8adce393a273a48e4e133bb39899b);
#
#
#             var feature_group_sub_group_de08d60037a502ff11052610cf2ad494 = L.featureGroup.subGroup(
#                 feature_group_507d1290ce0d4b4e2380f198190ec7b3
#             );
#
#
#             var marker_726ee79e3725028b3347250b8bffc741 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_de08d60037a502ff11052610cf2ad494);
#
#
#         var popup_e8ca4dfb76084de59cda101f55df5ce1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a23153d1692fc9dff23f867925e1a44d = $(`&lt;div id=&quot;html_a23153d1692fc9dff23f867925e1a44d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e8ca4dfb76084de59cda101f55df5ce1.setContent(html_a23153d1692fc9dff23f867925e1a44d);
#
#
#
#         marker_726ee79e3725028b3347250b8bffc741.bindPopup(popup_e8ca4dfb76084de59cda101f55df5ce1)
#         ;
#
#
#
#
#             var marker_c425f6437b4bc8346ea9bb793878648a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_de08d60037a502ff11052610cf2ad494);
#
#
#         var popup_7c1d64efb02627f5bcdaf16dfd5d83cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5710b2278b12e4614c5d55aa2d33152e = $(`&lt;div id=&quot;html_5710b2278b12e4614c5d55aa2d33152e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7c1d64efb02627f5bcdaf16dfd5d83cf.setContent(html_5710b2278b12e4614c5d55aa2d33152e);
#
#
#
#         marker_c425f6437b4bc8346ea9bb793878648a.bindPopup(popup_7c1d64efb02627f5bcdaf16dfd5d83cf)
#         ;
#
#
#
#
#             var marker_4d7dba84b32aa0f5d69f305f2ed6cb7f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_de08d60037a502ff11052610cf2ad494);
#
#
#         var popup_5a9a879c5226e33464812c973102a2a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5049c8acd7be7c5d8ef5b1d66c12c71b = $(`&lt;div id=&quot;html_5049c8acd7be7c5d8ef5b1d66c12c71b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5a9a879c5226e33464812c973102a2a4.setContent(html_5049c8acd7be7c5d8ef5b1d66c12c71b);
#
#
#
#         marker_4d7dba84b32aa0f5d69f305f2ed6cb7f.bindPopup(popup_5a9a879c5226e33464812c973102a2a4)
#         ;
#
#
#
#
#             var marker_d8e3c2b7ba29e3f117af77c8d390051a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_de08d60037a502ff11052610cf2ad494);
#
#
#         var popup_37e2fc6c87fd8f8956f74433d9dbf49a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ea7f8f87e93ef62be6ea6151b7b878c = $(`&lt;div id=&quot;html_8ea7f8f87e93ef62be6ea6151b7b878c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_37e2fc6c87fd8f8956f74433d9dbf49a.setContent(html_8ea7f8f87e93ef62be6ea6151b7b878c);
#
#
#
#         marker_
