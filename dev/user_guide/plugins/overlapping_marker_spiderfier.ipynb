# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5894b88fd92dfeea32a6beb41114eb7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5894b88fd92dfeea32a6beb41114eb7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5894b88fd92dfeea32a6beb41114eb7b = L.map(
#                 &quot;map_5894b88fd92dfeea32a6beb41114eb7b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2debc57aa45fc889607b996de5cd7488 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2debc57aa45fc889607b996de5cd7488.addTo(map_5894b88fd92dfeea32a6beb41114eb7b);
#
#
#             var marker_0e078e90507ffccf32bedce39bb53a55 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5894b88fd92dfeea32a6beb41114eb7b);
#
#
#         var popup_00b0f97fea2eaa5d42085a4edb0eaf31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6981a847e5f04651aada59035249ef7f = $(`&lt;div id=&quot;html_6981a847e5f04651aada59035249ef7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_00b0f97fea2eaa5d42085a4edb0eaf31.setContent(html_6981a847e5f04651aada59035249ef7f);
#
#
#
#         marker_0e078e90507ffccf32bedce39bb53a55.bindPopup(popup_00b0f97fea2eaa5d42085a4edb0eaf31)
#         ;
#
#
#
#
#             var marker_9465b64a5992711afbf915993e7cc6b8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5894b88fd92dfeea32a6beb41114eb7b);
#
#
#         var popup_c7cfa9d50bd6126728e315141372a246 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d44a2c1c98fcf42cf4d841662212dbb = $(`&lt;div id=&quot;html_8d44a2c1c98fcf42cf4d841662212dbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c7cfa9d50bd6126728e315141372a246.setContent(html_8d44a2c1c98fcf42cf4d841662212dbb);
#
#
#
#         marker_9465b64a5992711afbf915993e7cc6b8.bindPopup(popup_c7cfa9d50bd6126728e315141372a246)
#         ;
#
#
#
#
#             var marker_872365038088634dc8fae29da1181cab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5894b88fd92dfeea32a6beb41114eb7b);
#
#
#         var popup_76985fe7896ef4ce24fa93c2a2b3f281 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58b028c68c8a3deeba5b3841b78ab81e = $(`&lt;div id=&quot;html_58b028c68c8a3deeba5b3841b78ab81e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_76985fe7896ef4ce24fa93c2a2b3f281.setContent(html_58b028c68c8a3deeba5b3841b78ab81e);
#
#
#
#         marker_872365038088634dc8fae29da1181cab.bindPopup(popup_76985fe7896ef4ce24fa93c2a2b3f281)
#         ;
#
#
#
#
#             var marker_840764fd4c3c5904f54973f5c9d3a714 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5894b88fd92dfeea32a6beb41114eb7b);
#
#
#         var popup_0ef17a531943cb25d37881d9e7aa433c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_457356ecf731b421612411a0c3112b3e = $(`&lt;div id=&quot;html_457356ecf731b421612411a0c3112b3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0ef17a531943cb25d37881d9e7aa433c.setContent(html_457356ecf731b421612411a0c3112b3e);
#
#
#
#         marker_840764fd4c3c5904f54973f5c9d3a714.bindPopup(popup_0ef17a531943cb25d37881d9e7aa433c)
#         ;
#
#
#
#
#             var marker_259635208581369d9c5813842fc566e9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5894b88fd92dfeea32a6beb41114eb7b);
#
#
#         var popup_764292640e0326da78a689001a65310e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_303dabc31d69bc6487539845ab8fbd5d = $(`&lt;div id=&quot;html_303dabc31d69bc6487539845ab8fbd5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_764292640e0326da78a689001a65310e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de983253b5fff8f057491e38005533a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de983253b5fff8f057491e38005533a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de983253b5fff8f057491e38005533a1 = L.map(
#                 &quot;map_de983253b5fff8f057491e38005533a1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8b4fd87d94ce639178e0dcde41a345d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e8b4fd87d94ce639178e0dcde41a345d.addTo(map_de983253b5fff8f057491e38005533a1);
#
#
#             var feature_group_8d75e60e8ddbe83864836ed4a9e5c178 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b45f6fce60debd6fdcb8dd8b540b5fa6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8d75e60e8ddbe83864836ed4a9e5c178);
#
#
#         var popup_3c02ebb5ea8a9cd4156ce0b5726e8c24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e110347e855e2f9f18102c93d9407fa7 = $(`&lt;div id=&quot;html_e110347e855e2f9f18102c93d9407fa7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3c02ebb5ea8a9cd4156ce0b5726e8c24.setContent(html_e110347e855e2f9f18102c93d9407fa7);
#
#
#
#         marker_b45f6fce60debd6fdcb8dd8b540b5fa6.bindPopup(popup_3c02ebb5ea8a9cd4156ce0b5726e8c24)
#         ;
#
#
#
#
#             var marker_b9847bc1f728a15b5512960c512424cb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8d75e60e8ddbe83864836ed4a9e5c178);
#
#
#         var popup_76aedb66eb028bae6b8ac8574610a82b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_332659d50579e59faf6bff33a3fde697 = $(`&lt;div id=&quot;html_332659d50579e59faf6bff33a3fde697&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_76aedb66eb028bae6b8ac8574610a82b.setContent(html_332659d50579e59faf6bff33a3fde697);
#
#
#
#         marker_b9847bc1f728a15b5512960c512424cb.bindPopup(popup_76aedb66eb028bae6b8ac8574610a82b)
#         ;
#
#
#
#
#             var marker_a4238b4581f15aa2cbfc5508e887f4b6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8d75e60e8ddbe83864836ed4a9e5c178);
#
#
#         var popup_f84bc8a83aedd657d255b8bf1220d934 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee0147d2cbb1fc71578760f325158d5d = $(`&lt;div id=&quot;html_ee0147d2cbb1fc71578760f325158d5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f84bc8a83aedd657d255b8bf1220d934.setContent(html_ee0147d2cbb1fc71578760f325158d5d);
#
#
#
#         marker_a4238b4581f15aa2cbfc5508e887f4b6.bindPopup(popup_f84bc8a83aedd657d255b8bf1220d934)
#         ;
#
#
#
#
#             var marker_0ddb35c3055f887738e75c432e63b1c6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8d75e60e8ddbe83864836ed4a9e5c178);
#
#
#         var popup_1a4e574862a2cb74c68318174b7dac4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f610bea14e05030d172b0cd2a62c2086 = $(`&lt;div id=&quot;html_f610bea14e05030d172b0cd2a62c2086&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1a4e574862a2cb74c68318174b7dac4f.setContent(html_f610bea14e05030d172b0cd2a62c2086);
#
#
#
#         marker_0ddb35c3055f887738e75c432e63b1c6.bindPopup(popup_1a4e574862a2cb74c68318174b7dac4f)
#         ;
#
#
#
#
#             var marker_f7f43a7865693d395cc0539e00253806 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8d75e60e8ddbe83864836ed4a9e5c178);
#
#
#         var popup_c44de72f0e22b90c8e4c8ef799387ac2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96b28059b9b7c75e79300c00aaa16f2a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96b28059b9b7c75e79300c00aaa16f2a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96b28059b9b7c75e79300c00aaa16f2a = L.map(
#                 &quot;map_96b28059b9b7c75e79300c00aaa16f2a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_943cbb7eb6f1270c21a5c88bab2705ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_943cbb7eb6f1270c21a5c88bab2705ef.addTo(map_96b28059b9b7c75e79300c00aaa16f2a);
#
#
#             var feature_group_7fd07304e6863353ec38656cbcdfd50f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7fd07304e6863353ec38656cbcdfd50f.addTo(map_96b28059b9b7c75e79300c00aaa16f2a);
#
#
#             var feature_group_sub_group_7ce1e7a575a1e418af25dbf77476b1cf = L.featureGroup.subGroup(
#                 feature_group_7fd07304e6863353ec38656cbcdfd50f
#             );
#
#
#             var marker_318ef32d9c499cd3e064b74c7e7d6f8f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7ce1e7a575a1e418af25dbf77476b1cf);
#
#
#         var popup_e1601681a50eeda154dfb3203ab52fc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de4c2b23ffea488d5a55bdbd05d0c3e2 = $(`&lt;div id=&quot;html_de4c2b23ffea488d5a55bdbd05d0c3e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e1601681a50eeda154dfb3203ab52fc5.setContent(html_de4c2b23ffea488d5a55bdbd05d0c3e2);
#
#
#
#         marker_318ef32d9c499cd3e064b74c7e7d6f8f.bindPopup(popup_e1601681a50eeda154dfb3203ab52fc5)
#         ;
#
#
#
#
#             var marker_afb1fd561d6a8c1ecd601f3dafdea625 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7ce1e7a575a1e418af25dbf77476b1cf);
#
#
#         var popup_cf015a5e9ea034fbe08e0990d6f56710 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_954d05ba563e2af53618509babd6df88 = $(`&lt;div id=&quot;html_954d05ba563e2af53618509babd6df88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cf015a5e9ea034fbe08e0990d6f56710.setContent(html_954d05ba563e2af53618509babd6df88);
#
#
#
#         marker_afb1fd561d6a8c1ecd601f3dafdea625.bindPopup(popup_cf015a5e9ea034fbe08e0990d6f56710)
#         ;
#
#
#
#
#             var marker_43d1830b0b85b8932a3bab2fc9e37830 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7ce1e7a575a1e418af25dbf77476b1cf);
#
#
#         var popup_5155ab77d35e5bdd67e9924c0cb0fca1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_867190b409d899d5053e720f0dae92aa = $(`&lt;div id=&quot;html_867190b409d899d5053e720f0dae92aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5155ab77d35e5bdd67e9924c0cb0fca1.setContent(html_867190b409d899d5053e720f0dae92aa);
#
#
#
#         marker_43d1830b0b85b8932a3bab2fc9e37830.bindPopup(popup_5155ab77d35e5bdd67e9924c0cb0fca1)
#         ;
#
#
#
#
#             var marker_e1b8cfaa6315d52a6dc8383d0b948c04 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7ce1e7a575a1e418af25dbf77476b1cf);
#
#
#         var popup_80724c7e6402683ae14ef736e0eba998 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_872eb6eb80d6f7ade53a15b744bb4a4c = $(`&lt;div id=&quot;html_872eb6eb80d6f7ade53a15b744bb4a4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_80724c7e6402683ae14ef736e0eba998.setContent(html_872eb6eb80d6f7ade53a15b744bb4a4c);
#
#
#
#         marker_
