# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_624de50c57ad2bab40fdf4ae3c3858a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_624de50c57ad2bab40fdf4ae3c3858a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_624de50c57ad2bab40fdf4ae3c3858a4 = L.map(
#                 &quot;map_624de50c57ad2bab40fdf4ae3c3858a4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ec267db513291af4f3f2c4eded79012 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3ec267db513291af4f3f2c4eded79012.addTo(map_624de50c57ad2bab40fdf4ae3c3858a4);
#
#
#             var marker_7eaf3f033697b1fb062fb2572f95ec3a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_624de50c57ad2bab40fdf4ae3c3858a4);
#
#
#         var popup_b6a5cff6dff0c189d85a39aa9f08e47b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d46256e503910aec30d2c635ac807dfd = $(`&lt;div id=&quot;html_d46256e503910aec30d2c635ac807dfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b6a5cff6dff0c189d85a39aa9f08e47b.setContent(html_d46256e503910aec30d2c635ac807dfd);
#
#
#
#         marker_7eaf3f033697b1fb062fb2572f95ec3a.bindPopup(popup_b6a5cff6dff0c189d85a39aa9f08e47b)
#         ;
#
#
#
#
#             var marker_a3540ee6c4dfd5d9c64ed71811374d3f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_624de50c57ad2bab40fdf4ae3c3858a4);
#
#
#         var popup_3c7222b63b4781604b93e0ed4388d77a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8347ba3c2125759f4e85d2d96ee227ba = $(`&lt;div id=&quot;html_8347ba3c2125759f4e85d2d96ee227ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3c7222b63b4781604b93e0ed4388d77a.setContent(html_8347ba3c2125759f4e85d2d96ee227ba);
#
#
#
#         marker_a3540ee6c4dfd5d9c64ed71811374d3f.bindPopup(popup_3c7222b63b4781604b93e0ed4388d77a)
#         ;
#
#
#
#
#             var marker_f65f9196b7025b339e52ec75266d41d1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_624de50c57ad2bab40fdf4ae3c3858a4);
#
#
#         var popup_9134ecb49bba0ce57aed62234d19e1af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39691e8507b7e8f85dd8ebbcb3d30b1e = $(`&lt;div id=&quot;html_39691e8507b7e8f85dd8ebbcb3d30b1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9134ecb49bba0ce57aed62234d19e1af.setContent(html_39691e8507b7e8f85dd8ebbcb3d30b1e);
#
#
#
#         marker_f65f9196b7025b339e52ec75266d41d1.bindPopup(popup_9134ecb49bba0ce57aed62234d19e1af)
#         ;
#
#
#
#
#             var marker_61058ed44e4164e01b427d9667ebf110 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_624de50c57ad2bab40fdf4ae3c3858a4);
#
#
#         var popup_1c4aec4b19816b3b3a963cf24d925ba9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4703a051f73d2f36defd267c99bf3736 = $(`&lt;div id=&quot;html_4703a051f73d2f36defd267c99bf3736&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1c4aec4b19816b3b3a963cf24d925ba9.setContent(html_4703a051f73d2f36defd267c99bf3736);
#
#
#
#         marker_61058ed44e4164e01b427d9667ebf110.bindPopup(popup_1c4aec4b19816b3b3a963cf24d925ba9)
#         ;
#
#
#
#
#             var marker_c422fe0f78e3f956d031b38336c95500 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_624de50c57ad2bab40fdf4ae3c3858a4);
#
#
#         var popup_12c7248b5a9b7b2e0e1bfb2c11db9144 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f821cb960f664f8a1047659caf2db6f8 = $(`&lt;div id=&quot;html_f821cb960f664f8a1047659caf2db6f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_12c7248b5a9b7b2e0e1bfb2c11db9144.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dda06a7dcfe63d2dd2473df71c518481 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dda06a7dcfe63d2dd2473df71c518481&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dda06a7dcfe63d2dd2473df71c518481 = L.map(
#                 &quot;map_dda06a7dcfe63d2dd2473df71c518481&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d9f83d55b28dfbab9f976d49fb3fd03 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6d9f83d55b28dfbab9f976d49fb3fd03.addTo(map_dda06a7dcfe63d2dd2473df71c518481);
#
#
#             var feature_group_17dfb74840462e351ba68c40050fc074 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6808dfd7a0248823162f5ed700dca04f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_17dfb74840462e351ba68c40050fc074);
#
#
#         var popup_347e92fee9fa7503910e475418c7b671 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_817511f19c691f83bd17eb87e1420ae8 = $(`&lt;div id=&quot;html_817511f19c691f83bd17eb87e1420ae8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_347e92fee9fa7503910e475418c7b671.setContent(html_817511f19c691f83bd17eb87e1420ae8);
#
#
#
#         marker_6808dfd7a0248823162f5ed700dca04f.bindPopup(popup_347e92fee9fa7503910e475418c7b671)
#         ;
#
#
#
#
#             var marker_f720edb1433b8c45f736f5f533ba8b5f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_17dfb74840462e351ba68c40050fc074);
#
#
#         var popup_620636cf58c201fe41030aeb20c06ca5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0791cfb636536de1b799eb3b5ca537d5 = $(`&lt;div id=&quot;html_0791cfb636536de1b799eb3b5ca537d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_620636cf58c201fe41030aeb20c06ca5.setContent(html_0791cfb636536de1b799eb3b5ca537d5);
#
#
#
#         marker_f720edb1433b8c45f736f5f533ba8b5f.bindPopup(popup_620636cf58c201fe41030aeb20c06ca5)
#         ;
#
#
#
#
#             var marker_c74b2ea792c943fbdeda294ee2d62861 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_17dfb74840462e351ba68c40050fc074);
#
#
#         var popup_20e5da1d4b102eea8d2625b04ac8dd21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_044018417ea108c6a080483fc3c15938 = $(`&lt;div id=&quot;html_044018417ea108c6a080483fc3c15938&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_20e5da1d4b102eea8d2625b04ac8dd21.setContent(html_044018417ea108c6a080483fc3c15938);
#
#
#
#         marker_c74b2ea792c943fbdeda294ee2d62861.bindPopup(popup_20e5da1d4b102eea8d2625b04ac8dd21)
#         ;
#
#
#
#
#             var marker_ce3ba2331e0aea09b3d537f93ed37ebc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_17dfb74840462e351ba68c40050fc074);
#
#
#         var popup_09fc71d9e35dcad6714e87fd84d122da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dfcb8cd0c3a0781a4c1c7b545810f37 = $(`&lt;div id=&quot;html_7dfcb8cd0c3a0781a4c1c7b545810f37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_09fc71d9e35dcad6714e87fd84d122da.setContent(html_7dfcb8cd0c3a0781a4c1c7b545810f37);
#
#
#
#         marker_ce3ba2331e0aea09b3d537f93ed37ebc.bindPopup(popup_09fc71d9e35dcad6714e87fd84d122da)
#         ;
#
#
#
#
#             var marker_8f4566dea14a7f2d427f0cc931db3289 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_17dfb74840462e351ba68c40050fc074);
#
#
#         var popup_edeae827d5d3a861d4b65b17d8806a96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa8315e19dde085742218a8fd911484b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa8315e19dde085742218a8fd911484b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa8315e19dde085742218a8fd911484b = L.map(
#                 &quot;map_fa8315e19dde085742218a8fd911484b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff40463e9ec5280418e7d2e3b1754ac5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff40463e9ec5280418e7d2e3b1754ac5.addTo(map_fa8315e19dde085742218a8fd911484b);
#
#
#             var feature_group_f98b95bf70a4d89c56d9e1b486660f7e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f98b95bf70a4d89c56d9e1b486660f7e.addTo(map_fa8315e19dde085742218a8fd911484b);
#
#
#             var feature_group_sub_group_732376abb9d49900960c3628415e4467 = L.featureGroup.subGroup(
#                 feature_group_f98b95bf70a4d89c56d9e1b486660f7e
#             );
#
#
#             var marker_1a4b282552093da50dc519b3d14f915a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_732376abb9d49900960c3628415e4467);
#
#
#         var popup_3e53fb013bda8bb242e96949b7bf9325 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1112f59d9990c3289c2d08cb9fdc50ba = $(`&lt;div id=&quot;html_1112f59d9990c3289c2d08cb9fdc50ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3e53fb013bda8bb242e96949b7bf9325.setContent(html_1112f59d9990c3289c2d08cb9fdc50ba);
#
#
#
#         marker_1a4b282552093da50dc519b3d14f915a.bindPopup(popup_3e53fb013bda8bb242e96949b7bf9325)
#         ;
#
#
#
#
#             var marker_7dbde75fe587c4eb472be0018d9cf02d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_732376abb9d49900960c3628415e4467);
#
#
#         var popup_4428dea35d2b9d10c809a3deb2f0cd4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be9f1110434a2e1892b8364a68cb5cd3 = $(`&lt;div id=&quot;html_be9f1110434a2e1892b8364a68cb5cd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4428dea35d2b9d10c809a3deb2f0cd4f.setContent(html_be9f1110434a2e1892b8364a68cb5cd3);
#
#
#
#         marker_7dbde75fe587c4eb472be0018d9cf02d.bindPopup(popup_4428dea35d2b9d10c809a3deb2f0cd4f)
#         ;
#
#
#
#
#             var marker_3c3b004723b2ce660827a6b80e5e86b6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_732376abb9d49900960c3628415e4467);
#
#
#         var popup_2e5e23eb8d4593994b7886e119574836 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0f26c4d0eb10b209bfcb59cb5517f10 = $(`&lt;div id=&quot;html_d0f26c4d0eb10b209bfcb59cb5517f10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2e5e23eb8d4593994b7886e119574836.setContent(html_d0f26c4d0eb10b209bfcb59cb5517f10);
#
#
#
#         marker_3c3b004723b2ce660827a6b80e5e86b6.bindPopup(popup_2e5e23eb8d4593994b7886e119574836)
#         ;
#
#
#
#
#             var marker_ced3dbe629095629a8a42219b28c7c66 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_732376abb9d49900960c3628415e4467);
#
#
#         var popup_3022fdb732786d08cef6fe77a6737500 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2676442520bfef54bdc28efef97651d8 = $(`&lt;div id=&quot;html_2676442520bfef54bdc28efef97651d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3022fdb732786d08cef6fe77a6737500.setContent(html_2676442520bfef54bdc28efef97651d8);
#
#
#
#         marker_
