# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a76298e280cb4b07f5ea0eeaa30eea0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a76298e280cb4b07f5ea0eeaa30eea0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8a76298e280cb4b07f5ea0eeaa30eea0 = L.map(
#                 &quot;map_8a76298e280cb4b07f5ea0eeaa30eea0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_daa3b46e427dffb87c8aed21053a28f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_daa3b46e427dffb87c8aed21053a28f0.addTo(map_8a76298e280cb4b07f5ea0eeaa30eea0);
#
#
#             var marker_f1016e90076ae9bfc1f0c00bd502e8dc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8a76298e280cb4b07f5ea0eeaa30eea0);
#
#
#         var popup_77e3be98027b694e49a6d42e952dd8a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9348eafe89da582faf6af15bbf8cccf5 = $(`&lt;div id=&quot;html_9348eafe89da582faf6af15bbf8cccf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_77e3be98027b694e49a6d42e952dd8a2.setContent(html_9348eafe89da582faf6af15bbf8cccf5);
#
#
#
#         marker_f1016e90076ae9bfc1f0c00bd502e8dc.bindPopup(popup_77e3be98027b694e49a6d42e952dd8a2)
#         ;
#
#
#
#
#             var marker_fc8f314e0170d9f310db86b15412b1d3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8a76298e280cb4b07f5ea0eeaa30eea0);
#
#
#         var popup_d9a85b3457da7dd282874df277cf3970 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6dca7798918e4bd4f5d54ee62e09dec2 = $(`&lt;div id=&quot;html_6dca7798918e4bd4f5d54ee62e09dec2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d9a85b3457da7dd282874df277cf3970.setContent(html_6dca7798918e4bd4f5d54ee62e09dec2);
#
#
#
#         marker_fc8f314e0170d9f310db86b15412b1d3.bindPopup(popup_d9a85b3457da7dd282874df277cf3970)
#         ;
#
#
#
#
#             var marker_bfe84144c53a2fafd4805b9bc77505d4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8a76298e280cb4b07f5ea0eeaa30eea0);
#
#
#         var popup_a09c0face8b257578272c759473de419 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12c5be5e47d72e5521d17786bc790eda = $(`&lt;div id=&quot;html_12c5be5e47d72e5521d17786bc790eda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a09c0face8b257578272c759473de419.setContent(html_12c5be5e47d72e5521d17786bc790eda);
#
#
#
#         marker_bfe84144c53a2fafd4805b9bc77505d4.bindPopup(popup_a09c0face8b257578272c759473de419)
#         ;
#
#
#
#
#             var marker_806c926c87084c131bf57a3cb57e6832 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8a76298e280cb4b07f5ea0eeaa30eea0);
#
#
#         var popup_767c0bf16e7423467d133173b1bc2ee4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99a37d9ef11803610d1fd1c8ce8d7f8a = $(`&lt;div id=&quot;html_99a37d9ef11803610d1fd1c8ce8d7f8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_767c0bf16e7423467d133173b1bc2ee4.setContent(html_99a37d9ef11803610d1fd1c8ce8d7f8a);
#
#
#
#         marker_806c926c87084c131bf57a3cb57e6832.bindPopup(popup_767c0bf16e7423467d133173b1bc2ee4)
#         ;
#
#
#
#
#             var marker_35dfebf69e9cc8e22c497c999b3e360f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8a76298e280cb4b07f5ea0eeaa30eea0);
#
#
#         var popup_14658ac202655f5a34465aa50668961a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe33917ef0f45ee78c6049bf74fe927a = $(`&lt;div id=&quot;html_fe33917ef0f45ee78c6049bf74fe927a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_14658ac202655f5a34465aa50668961a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7998e32c95db8e67712b5c73e5b93596 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7998e32c95db8e67712b5c73e5b93596&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7998e32c95db8e67712b5c73e5b93596 = L.map(
#                 &quot;map_7998e32c95db8e67712b5c73e5b93596&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a32bcd51055b6cb99607fa2ef51881b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a32bcd51055b6cb99607fa2ef51881b.addTo(map_7998e32c95db8e67712b5c73e5b93596);
#
#
#             var feature_group_dc14db988bea8f22c764c1139628d459 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a624d17d2977fa557acd486ffe40677a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_dc14db988bea8f22c764c1139628d459);
#
#
#         var popup_529fbce31097a414d02a34cdb6bced6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64fc1d8710ea9814d6a6fe1e096d015e = $(`&lt;div id=&quot;html_64fc1d8710ea9814d6a6fe1e096d015e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_529fbce31097a414d02a34cdb6bced6a.setContent(html_64fc1d8710ea9814d6a6fe1e096d015e);
#
#
#
#         marker_a624d17d2977fa557acd486ffe40677a.bindPopup(popup_529fbce31097a414d02a34cdb6bced6a)
#         ;
#
#
#
#
#             var marker_181cb8c23986fa916f4edec6b60eaf6c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_dc14db988bea8f22c764c1139628d459);
#
#
#         var popup_fb4395e9ed5dbd8751de679d386b898a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcb6a7704708183862fa514144e85759 = $(`&lt;div id=&quot;html_dcb6a7704708183862fa514144e85759&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fb4395e9ed5dbd8751de679d386b898a.setContent(html_dcb6a7704708183862fa514144e85759);
#
#
#
#         marker_181cb8c23986fa916f4edec6b60eaf6c.bindPopup(popup_fb4395e9ed5dbd8751de679d386b898a)
#         ;
#
#
#
#
#             var marker_5f0816289b5b0b41f7f1bb0985b96733 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_dc14db988bea8f22c764c1139628d459);
#
#
#         var popup_65d4fd24386b8bdc531d287d83880180 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78bda4f704c2245436d6e63722db8d12 = $(`&lt;div id=&quot;html_78bda4f704c2245436d6e63722db8d12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_65d4fd24386b8bdc531d287d83880180.setContent(html_78bda4f704c2245436d6e63722db8d12);
#
#
#
#         marker_5f0816289b5b0b41f7f1bb0985b96733.bindPopup(popup_65d4fd24386b8bdc531d287d83880180)
#         ;
#
#
#
#
#             var marker_f0c1a61e71091417ed47c19da1c51d93 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_dc14db988bea8f22c764c1139628d459);
#
#
#         var popup_3591a24831300d70effd2f81cbe4e797 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b283fa7e1165407fc5e0efa224cbc652 = $(`&lt;div id=&quot;html_b283fa7e1165407fc5e0efa224cbc652&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3591a24831300d70effd2f81cbe4e797.setContent(html_b283fa7e1165407fc5e0efa224cbc652);
#
#
#
#         marker_f0c1a61e71091417ed47c19da1c51d93.bindPopup(popup_3591a24831300d70effd2f81cbe4e797)
#         ;
#
#
#
#
#             var marker_6b08d2a423a1afb875e941cbd6ee686a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_dc14db988bea8f22c764c1139628d459);
#
#
#         var popup_4cded560bdedd6914f2849dd554dbfc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90ccb1667ba0fee29500629efeb53c5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90ccb1667ba0fee29500629efeb53c5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90ccb1667ba0fee29500629efeb53c5c = L.map(
#                 &quot;map_90ccb1667ba0fee29500629efeb53c5c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f980337dd7f31f954ff7cca71dc5838 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f980337dd7f31f954ff7cca71dc5838.addTo(map_90ccb1667ba0fee29500629efeb53c5c);
#
#
#             var feature_group_b346f02f05c9f1977eaf796e86d98c03 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b346f02f05c9f1977eaf796e86d98c03.addTo(map_90ccb1667ba0fee29500629efeb53c5c);
#
#
#             var feature_group_sub_group_339aaadc460d608b37dd4188ae5e1128 = L.featureGroup.subGroup(
#                 feature_group_b346f02f05c9f1977eaf796e86d98c03
#             );
#
#
#             var marker_fa5cd76fc0050947d1a2923190198d40 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_339aaadc460d608b37dd4188ae5e1128);
#
#
#         var popup_c19e6b94e1907407f4e6a5593495db1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ad52fb4021db2d2ea08ea1ac1d3e4ad = $(`&lt;div id=&quot;html_0ad52fb4021db2d2ea08ea1ac1d3e4ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c19e6b94e1907407f4e6a5593495db1e.setContent(html_0ad52fb4021db2d2ea08ea1ac1d3e4ad);
#
#
#
#         marker_fa5cd76fc0050947d1a2923190198d40.bindPopup(popup_c19e6b94e1907407f4e6a5593495db1e)
#         ;
#
#
#
#
#             var marker_af56122d0af2f33aee9e95e1c78c4936 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_339aaadc460d608b37dd4188ae5e1128);
#
#
#         var popup_f550ef1ab22000dbaa280513e2f72e69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8146398109461a08c1ee66894a0fbd79 = $(`&lt;div id=&quot;html_8146398109461a08c1ee66894a0fbd79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f550ef1ab22000dbaa280513e2f72e69.setContent(html_8146398109461a08c1ee66894a0fbd79);
#
#
#
#         marker_af56122d0af2f33aee9e95e1c78c4936.bindPopup(popup_f550ef1ab22000dbaa280513e2f72e69)
#         ;
#
#
#
#
#             var marker_c381fbf746b5204da4e3d6c71589be44 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_339aaadc460d608b37dd4188ae5e1128);
#
#
#         var popup_bc106b60ac67f0b8a4a0edd055237490 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51d97f7cf3b8501830eb6cfe0927015a = $(`&lt;div id=&quot;html_51d97f7cf3b8501830eb6cfe0927015a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bc106b60ac67f0b8a4a0edd055237490.setContent(html_51d97f7cf3b8501830eb6cfe0927015a);
#
#
#
#         marker_c381fbf746b5204da4e3d6c71589be44.bindPopup(popup_bc106b60ac67f0b8a4a0edd055237490)
#         ;
#
#
#
#
#             var marker_662b0d73b026b8ad59a1d4033adf574a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_339aaadc460d608b37dd4188ae5e1128);
#
#
#         var popup_d6a6766a0fe196b4e12b9eee12efe474 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfa594ad588fd3aecbe67b646d30d630 = $(`&lt;div id=&quot;html_bfa594ad588fd3aecbe67b646d30d630&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d6a6766a0fe196b4e12b9eee12efe474.setContent(html_bfa594ad588fd3aecbe67b646d30d630);
#
#
#
#         marker_
