# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b1f6bed3adf760f7a8e925ab062b6ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b1f6bed3adf760f7a8e925ab062b6ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b1f6bed3adf760f7a8e925ab062b6ec = L.map(
#                 &quot;map_3b1f6bed3adf760f7a8e925ab062b6ec&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_26bba2e0fe22c97fc66de02102edd2bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_26bba2e0fe22c97fc66de02102edd2bc.addTo(map_3b1f6bed3adf760f7a8e925ab062b6ec);
#
#
#             var marker_c1804379ec823b9befd6485d7924b9f7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3b1f6bed3adf760f7a8e925ab062b6ec);
#
#
#         var popup_6b64c93d0153306e5e432dfff4d5c74a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4d226e8e4748851913a10a792ec8529 = $(`&lt;div id=&quot;html_c4d226e8e4748851913a10a792ec8529&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6b64c93d0153306e5e432dfff4d5c74a.setContent(html_c4d226e8e4748851913a10a792ec8529);
#
#
#
#         marker_c1804379ec823b9befd6485d7924b9f7.bindPopup(popup_6b64c93d0153306e5e432dfff4d5c74a)
#         ;
#
#
#
#
#             var marker_e9a512180d4ab423c0c79e389d75f2ae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3b1f6bed3adf760f7a8e925ab062b6ec);
#
#
#         var popup_f9f84a972edab41765e781804216f465 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_918a94a23ae81317f58e7ed2680c4f84 = $(`&lt;div id=&quot;html_918a94a23ae81317f58e7ed2680c4f84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f9f84a972edab41765e781804216f465.setContent(html_918a94a23ae81317f58e7ed2680c4f84);
#
#
#
#         marker_e9a512180d4ab423c0c79e389d75f2ae.bindPopup(popup_f9f84a972edab41765e781804216f465)
#         ;
#
#
#
#
#             var marker_2628fb7003023f94871a9583bda3615b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3b1f6bed3adf760f7a8e925ab062b6ec);
#
#
#         var popup_12db133b26823f430971d52926fda7f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04ad77a2bc3ed71b7e61feec854e9c7e = $(`&lt;div id=&quot;html_04ad77a2bc3ed71b7e61feec854e9c7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_12db133b26823f430971d52926fda7f0.setContent(html_04ad77a2bc3ed71b7e61feec854e9c7e);
#
#
#
#         marker_2628fb7003023f94871a9583bda3615b.bindPopup(popup_12db133b26823f430971d52926fda7f0)
#         ;
#
#
#
#
#             var marker_4589b3fd53d81eaa83206bd5a0201324 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3b1f6bed3adf760f7a8e925ab062b6ec);
#
#
#         var popup_f25001cc2733a0dd79fa3e8b902b427e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_418784dbf79f8e57b6cfcadc3eefa336 = $(`&lt;div id=&quot;html_418784dbf79f8e57b6cfcadc3eefa336&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f25001cc2733a0dd79fa3e8b902b427e.setContent(html_418784dbf79f8e57b6cfcadc3eefa336);
#
#
#
#         marker_4589b3fd53d81eaa83206bd5a0201324.bindPopup(popup_f25001cc2733a0dd79fa3e8b902b427e)
#         ;
#
#
#
#
#             var marker_5bac5cd21841b65d468b4a9afa0c6b1c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3b1f6bed3adf760f7a8e925ab062b6ec);
#
#
#         var popup_b6aad90a724ce77f33b3e391466f56d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86b3844ec8c3b7b4365e2d7159925faf = $(`&lt;div id=&quot;html_86b3844ec8c3b7b4365e2d7159925faf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b6aad90a724ce77f33b3e391466f56d7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff76b87bf582d9506ee7dfb97750a6a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff76b87bf582d9506ee7dfb97750a6a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff76b87bf582d9506ee7dfb97750a6a4 = L.map(
#                 &quot;map_ff76b87bf582d9506ee7dfb97750a6a4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96b09102d8cdac78373ead1d168d2955 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_96b09102d8cdac78373ead1d168d2955.addTo(map_ff76b87bf582d9506ee7dfb97750a6a4);
#
#
#             var feature_group_8ab6c511044f73f395c02c8d4fca72f9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_67fccbae7c7f36fe8a177f2c0253b007 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8ab6c511044f73f395c02c8d4fca72f9);
#
#
#         var popup_d408643edf98070868a4af9a254fce45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21a39e0eaddf2a7ae6e310d45e897be0 = $(`&lt;div id=&quot;html_21a39e0eaddf2a7ae6e310d45e897be0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d408643edf98070868a4af9a254fce45.setContent(html_21a39e0eaddf2a7ae6e310d45e897be0);
#
#
#
#         marker_67fccbae7c7f36fe8a177f2c0253b007.bindPopup(popup_d408643edf98070868a4af9a254fce45)
#         ;
#
#
#
#
#             var marker_f9341faf03dd099203542b9de59b1de8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8ab6c511044f73f395c02c8d4fca72f9);
#
#
#         var popup_d1044c9d991a151901220f609886af34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a35ccaf60e0239d2ffbeb81310ea616a = $(`&lt;div id=&quot;html_a35ccaf60e0239d2ffbeb81310ea616a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d1044c9d991a151901220f609886af34.setContent(html_a35ccaf60e0239d2ffbeb81310ea616a);
#
#
#
#         marker_f9341faf03dd099203542b9de59b1de8.bindPopup(popup_d1044c9d991a151901220f609886af34)
#         ;
#
#
#
#
#             var marker_ac265f9d74a7d11db493bd68f72ab981 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8ab6c511044f73f395c02c8d4fca72f9);
#
#
#         var popup_bea1d789f11e46ac9bcfb4758eec48de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f10dea3ca6004981543734dde63e455a = $(`&lt;div id=&quot;html_f10dea3ca6004981543734dde63e455a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bea1d789f11e46ac9bcfb4758eec48de.setContent(html_f10dea3ca6004981543734dde63e455a);
#
#
#
#         marker_ac265f9d74a7d11db493bd68f72ab981.bindPopup(popup_bea1d789f11e46ac9bcfb4758eec48de)
#         ;
#
#
#
#
#             var marker_b82a27204a0d20c9d9fe42409a9b4351 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8ab6c511044f73f395c02c8d4fca72f9);
#
#
#         var popup_0b422c74fc8928fbe7f675dbb73e6f11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07b514df436b90a0d62ddf14ea56d912 = $(`&lt;div id=&quot;html_07b514df436b90a0d62ddf14ea56d912&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0b422c74fc8928fbe7f675dbb73e6f11.setContent(html_07b514df436b90a0d62ddf14ea56d912);
#
#
#
#         marker_b82a27204a0d20c9d9fe42409a9b4351.bindPopup(popup_0b422c74fc8928fbe7f675dbb73e6f11)
#         ;
#
#
#
#
#             var marker_8e7d9d80b93c27db87849a59441dffea = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8ab6c511044f73f395c02c8d4fca72f9);
#
#
#         var popup_7b9e15738d0f556945a9930d8aea6ae1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b0ab3c86b56aceba71302c50d0c3df6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b0ab3c86b56aceba71302c50d0c3df6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b0ab3c86b56aceba71302c50d0c3df6e = L.map(
#                 &quot;map_b0ab3c86b56aceba71302c50d0c3df6e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed71edc5bf7c06c1d6d4ba63518503db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed71edc5bf7c06c1d6d4ba63518503db.addTo(map_b0ab3c86b56aceba71302c50d0c3df6e);
#
#
#             var feature_group_12f29de92aabff9cd0ac726096184d92 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_12f29de92aabff9cd0ac726096184d92.addTo(map_b0ab3c86b56aceba71302c50d0c3df6e);
#
#
#             var feature_group_sub_group_79e44926ad8c875b212b3e16ee536faf = L.featureGroup.subGroup(
#                 feature_group_12f29de92aabff9cd0ac726096184d92
#             );
#
#
#             var marker_08a2dd0859b82db2533279ae50c2359a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_79e44926ad8c875b212b3e16ee536faf);
#
#
#         var popup_c705057a81e85742ac2c3ea5306308b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30d8d765c95db4ec04ced9321c25884f = $(`&lt;div id=&quot;html_30d8d765c95db4ec04ced9321c25884f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c705057a81e85742ac2c3ea5306308b9.setContent(html_30d8d765c95db4ec04ced9321c25884f);
#
#
#
#         marker_08a2dd0859b82db2533279ae50c2359a.bindPopup(popup_c705057a81e85742ac2c3ea5306308b9)
#         ;
#
#
#
#
#             var marker_3bcf8d72f8d201cf3c66c977f3f907f5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_79e44926ad8c875b212b3e16ee536faf);
#
#
#         var popup_65a0e406e399a17de80377b9ddecf75b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5a2103f536b27f93c65824fd63d0ba5 = $(`&lt;div id=&quot;html_a5a2103f536b27f93c65824fd63d0ba5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_65a0e406e399a17de80377b9ddecf75b.setContent(html_a5a2103f536b27f93c65824fd63d0ba5);
#
#
#
#         marker_3bcf8d72f8d201cf3c66c977f3f907f5.bindPopup(popup_65a0e406e399a17de80377b9ddecf75b)
#         ;
#
#
#
#
#             var marker_da0d9f9eadf2ea6813a7f8c5cfb7dc66 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_79e44926ad8c875b212b3e16ee536faf);
#
#
#         var popup_94cc39bfaaa4c4954c85d6e0707aed75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_787b1d4ded5e2aad2ddbc174ed58cbe0 = $(`&lt;div id=&quot;html_787b1d4ded5e2aad2ddbc174ed58cbe0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_94cc39bfaaa4c4954c85d6e0707aed75.setContent(html_787b1d4ded5e2aad2ddbc174ed58cbe0);
#
#
#
#         marker_da0d9f9eadf2ea6813a7f8c5cfb7dc66.bindPopup(popup_94cc39bfaaa4c4954c85d6e0707aed75)
#         ;
#
#
#
#
#             var marker_314c05e6f009c13e637bb426ec8aa2e2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_79e44926ad8c875b212b3e16ee536faf);
#
#
#         var popup_9983d0a242f96821aff91af90350cbe1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_445ddefaec64565a8d719120669d6bae = $(`&lt;div id=&quot;html_445ddefaec64565a8d719120669d6bae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9983d0a242f96821aff91af90350cbe1.setContent(html_445ddefaec64565a8d719120669d6bae);
#
#
#
#         marker_
