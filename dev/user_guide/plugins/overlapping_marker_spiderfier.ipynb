# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f027d46669b04520e61d2b2fcbe2d2cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f027d46669b04520e61d2b2fcbe2d2cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f027d46669b04520e61d2b2fcbe2d2cb = L.map(
#                 &quot;map_f027d46669b04520e61d2b2fcbe2d2cb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ae1b2d790c4fad8402a5f5402410073 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ae1b2d790c4fad8402a5f5402410073.addTo(map_f027d46669b04520e61d2b2fcbe2d2cb);
#
#
#             var marker_5c6114211b0c71e31df21c69ef95eb58 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f027d46669b04520e61d2b2fcbe2d2cb);
#
#
#         var popup_08cdfc4030c757aede1f7799e5c61d09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b9bec1bcd30e96c331a0b45cbc85c7b = $(`&lt;div id=&quot;html_6b9bec1bcd30e96c331a0b45cbc85c7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_08cdfc4030c757aede1f7799e5c61d09.setContent(html_6b9bec1bcd30e96c331a0b45cbc85c7b);
#
#
#
#         marker_5c6114211b0c71e31df21c69ef95eb58.bindPopup(popup_08cdfc4030c757aede1f7799e5c61d09)
#         ;
#
#
#
#
#             var marker_0bdff451d894f4b798cd74b3c19fba61 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f027d46669b04520e61d2b2fcbe2d2cb);
#
#
#         var popup_dbc1295dcb32a5d4c0aa1181f1ebc760 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12bf2686974b44f6b5aa40f5ca848245 = $(`&lt;div id=&quot;html_12bf2686974b44f6b5aa40f5ca848245&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dbc1295dcb32a5d4c0aa1181f1ebc760.setContent(html_12bf2686974b44f6b5aa40f5ca848245);
#
#
#
#         marker_0bdff451d894f4b798cd74b3c19fba61.bindPopup(popup_dbc1295dcb32a5d4c0aa1181f1ebc760)
#         ;
#
#
#
#
#             var marker_d882b0a5d7ebd2f802a9ac6068e8c8cd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f027d46669b04520e61d2b2fcbe2d2cb);
#
#
#         var popup_d87893f8eedb6b6fd851c2c86cf288c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd6821e906e9fadb53f3d3700fd65969 = $(`&lt;div id=&quot;html_cd6821e906e9fadb53f3d3700fd65969&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d87893f8eedb6b6fd851c2c86cf288c0.setContent(html_cd6821e906e9fadb53f3d3700fd65969);
#
#
#
#         marker_d882b0a5d7ebd2f802a9ac6068e8c8cd.bindPopup(popup_d87893f8eedb6b6fd851c2c86cf288c0)
#         ;
#
#
#
#
#             var marker_e44be87f5d34cb5cc19c1ac5a68850e5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f027d46669b04520e61d2b2fcbe2d2cb);
#
#
#         var popup_558764a476ad27e65cec676df53db3f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd8085c48cba222abb0d3e04bf099ebd = $(`&lt;div id=&quot;html_bd8085c48cba222abb0d3e04bf099ebd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_558764a476ad27e65cec676df53db3f2.setContent(html_bd8085c48cba222abb0d3e04bf099ebd);
#
#
#
#         marker_e44be87f5d34cb5cc19c1ac5a68850e5.bindPopup(popup_558764a476ad27e65cec676df53db3f2)
#         ;
#
#
#
#
#             var marker_65bfdbbf1e57d6c8148fbe4c703fa246 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f027d46669b04520e61d2b2fcbe2d2cb);
#
#
#         var popup_a4d1290d6e3c6319bc1219f5d9be8224 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cc81eeac6eff68942ca51351a023b82 = $(`&lt;div id=&quot;html_7cc81eeac6eff68942ca51351a023b82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a4d1290d6e3c6319bc1219f5d9be8224.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aebd532e9845205b152f5d3f635e8694 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aebd532e9845205b152f5d3f635e8694&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aebd532e9845205b152f5d3f635e8694 = L.map(
#                 &quot;map_aebd532e9845205b152f5d3f635e8694&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e3101b95221be713989739bb2f095ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e3101b95221be713989739bb2f095ef.addTo(map_aebd532e9845205b152f5d3f635e8694);
#
#
#             var feature_group_9ca7732abbb8c927779ca6263bc28f57 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_acf2c4065b0e26b453830d644bfc2849 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9ca7732abbb8c927779ca6263bc28f57);
#
#
#         var popup_457d7cab49c624addad4cf0caf08e245 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_490104eb5788d965d36e04ef7f9f4625 = $(`&lt;div id=&quot;html_490104eb5788d965d36e04ef7f9f4625&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_457d7cab49c624addad4cf0caf08e245.setContent(html_490104eb5788d965d36e04ef7f9f4625);
#
#
#
#         marker_acf2c4065b0e26b453830d644bfc2849.bindPopup(popup_457d7cab49c624addad4cf0caf08e245)
#         ;
#
#
#
#
#             var marker_33cdcbbacf70bc0e67bc6cb482adba17 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9ca7732abbb8c927779ca6263bc28f57);
#
#
#         var popup_55d8cf55292963fb8794216052ef82f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34fd55dfc36aafd015e1009cf17da3d3 = $(`&lt;div id=&quot;html_34fd55dfc36aafd015e1009cf17da3d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_55d8cf55292963fb8794216052ef82f3.setContent(html_34fd55dfc36aafd015e1009cf17da3d3);
#
#
#
#         marker_33cdcbbacf70bc0e67bc6cb482adba17.bindPopup(popup_55d8cf55292963fb8794216052ef82f3)
#         ;
#
#
#
#
#             var marker_520a343ba03d764e36fff4111c782df0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9ca7732abbb8c927779ca6263bc28f57);
#
#
#         var popup_5cc422a89144f5cec2fc46f701d44b2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec23991a05c4451518d993f342b67faf = $(`&lt;div id=&quot;html_ec23991a05c4451518d993f342b67faf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5cc422a89144f5cec2fc46f701d44b2f.setContent(html_ec23991a05c4451518d993f342b67faf);
#
#
#
#         marker_520a343ba03d764e36fff4111c782df0.bindPopup(popup_5cc422a89144f5cec2fc46f701d44b2f)
#         ;
#
#
#
#
#             var marker_079896181388b3d5a5daf4ac83199a5a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9ca7732abbb8c927779ca6263bc28f57);
#
#
#         var popup_2e1160afab5f08d39b79595b69f7dafd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d1986a72671725a3f55719d011a1be1 = $(`&lt;div id=&quot;html_5d1986a72671725a3f55719d011a1be1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2e1160afab5f08d39b79595b69f7dafd.setContent(html_5d1986a72671725a3f55719d011a1be1);
#
#
#
#         marker_079896181388b3d5a5daf4ac83199a5a.bindPopup(popup_2e1160afab5f08d39b79595b69f7dafd)
#         ;
#
#
#
#
#             var marker_3191582d8d15b9f8540712e515872133 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9ca7732abbb8c927779ca6263bc28f57);
#
#
#         var popup_128faec57e18b72b9a1e522979038953 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee3f034589b70471c0533fe2ecb0d8a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee3f034589b70471c0533fe2ecb0d8a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee3f034589b70471c0533fe2ecb0d8a6 = L.map(
#                 &quot;map_ee3f034589b70471c0533fe2ecb0d8a6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d9a2b4e239251aedf936e90c1e6aa98 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1d9a2b4e239251aedf936e90c1e6aa98.addTo(map_ee3f034589b70471c0533fe2ecb0d8a6);
#
#
#             var feature_group_b49dde8ff29e711474a39c34a13b4eaf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b49dde8ff29e711474a39c34a13b4eaf.addTo(map_ee3f034589b70471c0533fe2ecb0d8a6);
#
#
#             var feature_group_sub_group_dcb894171a5b098377b2dac6690cbb64 = L.featureGroup.subGroup(
#                 feature_group_b49dde8ff29e711474a39c34a13b4eaf
#             );
#
#
#             var marker_e5154f7b9e1c9c03a112d05488cfcbb6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_dcb894171a5b098377b2dac6690cbb64);
#
#
#         var popup_32a761aa17560e7e6dddd08cfbef78c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09325405c2db23315f53a6341f7d0033 = $(`&lt;div id=&quot;html_09325405c2db23315f53a6341f7d0033&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_32a761aa17560e7e6dddd08cfbef78c2.setContent(html_09325405c2db23315f53a6341f7d0033);
#
#
#
#         marker_e5154f7b9e1c9c03a112d05488cfcbb6.bindPopup(popup_32a761aa17560e7e6dddd08cfbef78c2)
#         ;
#
#
#
#
#             var marker_8fb3b616d7104ed997853fa97fe55206 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_dcb894171a5b098377b2dac6690cbb64);
#
#
#         var popup_f2c22c8e1b19ad1e26a33730707957b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9f2f576f069a159b56b3a67c197e903 = $(`&lt;div id=&quot;html_d9f2f576f069a159b56b3a67c197e903&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f2c22c8e1b19ad1e26a33730707957b6.setContent(html_d9f2f576f069a159b56b3a67c197e903);
#
#
#
#         marker_8fb3b616d7104ed997853fa97fe55206.bindPopup(popup_f2c22c8e1b19ad1e26a33730707957b6)
#         ;
#
#
#
#
#             var marker_7afa8f2956df08bd22169b16f98dd237 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_dcb894171a5b098377b2dac6690cbb64);
#
#
#         var popup_b514f56667642156e0007027d83f398b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_913eb5672156fdf01afeae362d89d7d0 = $(`&lt;div id=&quot;html_913eb5672156fdf01afeae362d89d7d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b514f56667642156e0007027d83f398b.setContent(html_913eb5672156fdf01afeae362d89d7d0);
#
#
#
#         marker_7afa8f2956df08bd22169b16f98dd237.bindPopup(popup_b514f56667642156e0007027d83f398b)
#         ;
#
#
#
#
#             var marker_9388bd06a45c04bc272eeee4c46c78d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_dcb894171a5b098377b2dac6690cbb64);
#
#
#         var popup_3e4c590d54edc42705fd067482ecaac1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03df8bdd684338638f816e1906d61e6e = $(`&lt;div id=&quot;html_03df8bdd684338638f816e1906d61e6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3e4c590d54edc42705fd067482ecaac1.setContent(html_03df8bdd684338638f816e1906d61e6e);
#
#
#
#         marker_
