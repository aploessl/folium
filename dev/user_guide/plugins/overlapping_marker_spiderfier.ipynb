# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57c710d7720465d31b805f15a05a6ef1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57c710d7720465d31b805f15a05a6ef1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57c710d7720465d31b805f15a05a6ef1 = L.map(
#                 &quot;map_57c710d7720465d31b805f15a05a6ef1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb86a6eed7077c8b7aa51c4104368aa5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb86a6eed7077c8b7aa51c4104368aa5.addTo(map_57c710d7720465d31b805f15a05a6ef1);
#
#
#             var marker_25a90e63bd431b136450c182a43477d1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_57c710d7720465d31b805f15a05a6ef1);
#
#
#         var popup_8e960af7d571e5b61fc4d6f685504699 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fbf93b4e788a39f4b9ac92682f5766d = $(`&lt;div id=&quot;html_1fbf93b4e788a39f4b9ac92682f5766d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8e960af7d571e5b61fc4d6f685504699.setContent(html_1fbf93b4e788a39f4b9ac92682f5766d);
#
#
#
#         marker_25a90e63bd431b136450c182a43477d1.bindPopup(popup_8e960af7d571e5b61fc4d6f685504699)
#         ;
#
#
#
#
#             var marker_740ccf32ac88fb75f043a1d1b4a92f9e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_57c710d7720465d31b805f15a05a6ef1);
#
#
#         var popup_e0230994d6ce8373df1d635b4952ce91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e665b66c3ff687725c3ad8dd95f7680 = $(`&lt;div id=&quot;html_0e665b66c3ff687725c3ad8dd95f7680&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e0230994d6ce8373df1d635b4952ce91.setContent(html_0e665b66c3ff687725c3ad8dd95f7680);
#
#
#
#         marker_740ccf32ac88fb75f043a1d1b4a92f9e.bindPopup(popup_e0230994d6ce8373df1d635b4952ce91)
#         ;
#
#
#
#
#             var marker_96bb5bdbc3293953bc46b23baeff5439 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_57c710d7720465d31b805f15a05a6ef1);
#
#
#         var popup_010a5b1ec5169835cc0e83da2f8d1b2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_436eb807cddc2e1704f9d57e66271767 = $(`&lt;div id=&quot;html_436eb807cddc2e1704f9d57e66271767&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_010a5b1ec5169835cc0e83da2f8d1b2a.setContent(html_436eb807cddc2e1704f9d57e66271767);
#
#
#
#         marker_96bb5bdbc3293953bc46b23baeff5439.bindPopup(popup_010a5b1ec5169835cc0e83da2f8d1b2a)
#         ;
#
#
#
#
#             var marker_f244f312779284db9fe20d45f4caa24d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_57c710d7720465d31b805f15a05a6ef1);
#
#
#         var popup_a686b4135a6ba7fc7169430012544102 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b79a426ed7c563fd4e1fcc222ad482ef = $(`&lt;div id=&quot;html_b79a426ed7c563fd4e1fcc222ad482ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a686b4135a6ba7fc7169430012544102.setContent(html_b79a426ed7c563fd4e1fcc222ad482ef);
#
#
#
#         marker_f244f312779284db9fe20d45f4caa24d.bindPopup(popup_a686b4135a6ba7fc7169430012544102)
#         ;
#
#
#
#
#             var marker_61649943b30380e5e7595d5e19e287db = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_57c710d7720465d31b805f15a05a6ef1);
#
#
#         var popup_882859e257416e7005cf873d84874758 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb45435be0766e9d6327e46fcdb9d565 = $(`&lt;div id=&quot;html_bb45435be0766e9d6327e46fcdb9d565&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_882859e257416e7005cf873d84874758.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_445bb4ec7b84ae101e87094f594dc011 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_445bb4ec7b84ae101e87094f594dc011&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_445bb4ec7b84ae101e87094f594dc011 = L.map(
#                 &quot;map_445bb4ec7b84ae101e87094f594dc011&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ffcbca76fe984bcb6998df6e1832de1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ffcbca76fe984bcb6998df6e1832de1.addTo(map_445bb4ec7b84ae101e87094f594dc011);
#
#
#             var feature_group_855b991492cf03b591f93d00e0ca2a97 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0e31ab2e19b8543aa5556bc3e5a575e0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_855b991492cf03b591f93d00e0ca2a97);
#
#
#         var popup_79a7282127fcb67996927edf64a26665 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a07cf7e66a6d0d88ca0c392003cb0f43 = $(`&lt;div id=&quot;html_a07cf7e66a6d0d88ca0c392003cb0f43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_79a7282127fcb67996927edf64a26665.setContent(html_a07cf7e66a6d0d88ca0c392003cb0f43);
#
#
#
#         marker_0e31ab2e19b8543aa5556bc3e5a575e0.bindPopup(popup_79a7282127fcb67996927edf64a26665)
#         ;
#
#
#
#
#             var marker_41c673b365623bf5e831334f3e2c726f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_855b991492cf03b591f93d00e0ca2a97);
#
#
#         var popup_a37bf1fdd3f8568be112b83bcc1328e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63070289122ee84a230928962119d9b7 = $(`&lt;div id=&quot;html_63070289122ee84a230928962119d9b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a37bf1fdd3f8568be112b83bcc1328e4.setContent(html_63070289122ee84a230928962119d9b7);
#
#
#
#         marker_41c673b365623bf5e831334f3e2c726f.bindPopup(popup_a37bf1fdd3f8568be112b83bcc1328e4)
#         ;
#
#
#
#
#             var marker_487593192cc508accaa2cd54fcb64df1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_855b991492cf03b591f93d00e0ca2a97);
#
#
#         var popup_8e8afb6c1129df413829cfbab4093ee5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_667744a21a23d1ff843facb6f0f78af0 = $(`&lt;div id=&quot;html_667744a21a23d1ff843facb6f0f78af0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8e8afb6c1129df413829cfbab4093ee5.setContent(html_667744a21a23d1ff843facb6f0f78af0);
#
#
#
#         marker_487593192cc508accaa2cd54fcb64df1.bindPopup(popup_8e8afb6c1129df413829cfbab4093ee5)
#         ;
#
#
#
#
#             var marker_df1f09aeaec71973f81ff3c6341dfc4b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_855b991492cf03b591f93d00e0ca2a97);
#
#
#         var popup_91538221fbe9df389ca9c4dd5901d9df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a23c7b76ca35554600db07026197c8e8 = $(`&lt;div id=&quot;html_a23c7b76ca35554600db07026197c8e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_91538221fbe9df389ca9c4dd5901d9df.setContent(html_a23c7b76ca35554600db07026197c8e8);
#
#
#
#         marker_df1f09aeaec71973f81ff3c6341dfc4b.bindPopup(popup_91538221fbe9df389ca9c4dd5901d9df)
#         ;
#
#
#
#
#             var marker_e1a2f7d95933c3820735ee89b05216c5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_855b991492cf03b591f93d00e0ca2a97);
#
#
#         var popup_dc8b780c3322499134a1c6f481c65abc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff9962939a4bccdd9c5bc8b39baac502 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff9962939a4bccdd9c5bc8b39baac502&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff9962939a4bccdd9c5bc8b39baac502 = L.map(
#                 &quot;map_ff9962939a4bccdd9c5bc8b39baac502&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e302a04980f95949c7ba00b841d9828 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e302a04980f95949c7ba00b841d9828.addTo(map_ff9962939a4bccdd9c5bc8b39baac502);
#
#
#             var feature_group_56051cc5ca221bd43aad89ae645446f2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_56051cc5ca221bd43aad89ae645446f2.addTo(map_ff9962939a4bccdd9c5bc8b39baac502);
#
#
#             var feature_group_sub_group_d32878c0400aeacd3d9ee9bcd0f19953 = L.featureGroup.subGroup(
#                 feature_group_56051cc5ca221bd43aad89ae645446f2
#             );
#
#
#             var marker_7a6647c9e1b22c6ca3680748d191981f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d32878c0400aeacd3d9ee9bcd0f19953);
#
#
#         var popup_1003c94bf3764c678915ca5e682ebe0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28c3046765a6b3b2dbd7fa3c7031f99a = $(`&lt;div id=&quot;html_28c3046765a6b3b2dbd7fa3c7031f99a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1003c94bf3764c678915ca5e682ebe0e.setContent(html_28c3046765a6b3b2dbd7fa3c7031f99a);
#
#
#
#         marker_7a6647c9e1b22c6ca3680748d191981f.bindPopup(popup_1003c94bf3764c678915ca5e682ebe0e)
#         ;
#
#
#
#
#             var marker_e2e0dcb8135eaa4e7337c304c0d5c524 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d32878c0400aeacd3d9ee9bcd0f19953);
#
#
#         var popup_e52b325e41dd45d2587f91c155ee6b20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a34be0d59abcb08880d555617c48af97 = $(`&lt;div id=&quot;html_a34be0d59abcb08880d555617c48af97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e52b325e41dd45d2587f91c155ee6b20.setContent(html_a34be0d59abcb08880d555617c48af97);
#
#
#
#         marker_e2e0dcb8135eaa4e7337c304c0d5c524.bindPopup(popup_e52b325e41dd45d2587f91c155ee6b20)
#         ;
#
#
#
#
#             var marker_96637ce2732801afa443ac23fe93051b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d32878c0400aeacd3d9ee9bcd0f19953);
#
#
#         var popup_d44ce6c992ce9bcf4680d8fc0c2b025d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66c806359bfdf797437de8a456098b62 = $(`&lt;div id=&quot;html_66c806359bfdf797437de8a456098b62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d44ce6c992ce9bcf4680d8fc0c2b025d.setContent(html_66c806359bfdf797437de8a456098b62);
#
#
#
#         marker_96637ce2732801afa443ac23fe93051b.bindPopup(popup_d44ce6c992ce9bcf4680d8fc0c2b025d)
#         ;
#
#
#
#
#             var marker_85ec6637b166dd6e60e8d66f45cd87db = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d32878c0400aeacd3d9ee9bcd0f19953);
#
#
#         var popup_1786fef4169df048fcd1cbc80e21e986 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4aa3d2333ebcfe3d5f9c28e95a2143c = $(`&lt;div id=&quot;html_e4aa3d2333ebcfe3d5f9c28e95a2143c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1786fef4169df048fcd1cbc80e21e986.setContent(html_e4aa3d2333ebcfe3d5f9c28e95a2143c);
#
#
#
#         marker_
