# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ae8c0dcde46bfe59e66f8eebe2c11c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ae8c0dcde46bfe59e66f8eebe2c11c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6ae8c0dcde46bfe59e66f8eebe2c11c7 = L.map(
#                 &quot;map_6ae8c0dcde46bfe59e66f8eebe2c11c7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7c85a46b7fc40e4a112e1ad8986271c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d7c85a46b7fc40e4a112e1ad8986271c.addTo(map_6ae8c0dcde46bfe59e66f8eebe2c11c7);
#
#
#             var marker_2a7b406a0e4b1077f103b0bcb01ed3f3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6ae8c0dcde46bfe59e66f8eebe2c11c7);
#
#
#         var popup_3fe96516191c1cb4033e88754155f569 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e11126d7fb94563d53242690f51086e8 = $(`&lt;div id=&quot;html_e11126d7fb94563d53242690f51086e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3fe96516191c1cb4033e88754155f569.setContent(html_e11126d7fb94563d53242690f51086e8);
#
#
#
#         marker_2a7b406a0e4b1077f103b0bcb01ed3f3.bindPopup(popup_3fe96516191c1cb4033e88754155f569)
#         ;
#
#
#
#
#             var marker_d0e9c1624012ed3dcdf220b81a225d96 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6ae8c0dcde46bfe59e66f8eebe2c11c7);
#
#
#         var popup_b3793f0bafeaf1634d86ad08f8464711 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_988a13da7f5976fed3b9f9c90f4d3267 = $(`&lt;div id=&quot;html_988a13da7f5976fed3b9f9c90f4d3267&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b3793f0bafeaf1634d86ad08f8464711.setContent(html_988a13da7f5976fed3b9f9c90f4d3267);
#
#
#
#         marker_d0e9c1624012ed3dcdf220b81a225d96.bindPopup(popup_b3793f0bafeaf1634d86ad08f8464711)
#         ;
#
#
#
#
#             var marker_ec42b46483e87ba54440c72db37919b8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6ae8c0dcde46bfe59e66f8eebe2c11c7);
#
#
#         var popup_306eb0e000fcb3cf9c2f996b7cf058d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40c2ea8692c9537359b4b752dbfc7f79 = $(`&lt;div id=&quot;html_40c2ea8692c9537359b4b752dbfc7f79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_306eb0e000fcb3cf9c2f996b7cf058d7.setContent(html_40c2ea8692c9537359b4b752dbfc7f79);
#
#
#
#         marker_ec42b46483e87ba54440c72db37919b8.bindPopup(popup_306eb0e000fcb3cf9c2f996b7cf058d7)
#         ;
#
#
#
#
#             var marker_6e972f6d7fb57dd76ea82dd4d2924fcb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6ae8c0dcde46bfe59e66f8eebe2c11c7);
#
#
#         var popup_c30048cb209d6f93ac98ed642a4c74aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a4866607644eeba2c8506fe9e815ce9 = $(`&lt;div id=&quot;html_7a4866607644eeba2c8506fe9e815ce9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c30048cb209d6f93ac98ed642a4c74aa.setContent(html_7a4866607644eeba2c8506fe9e815ce9);
#
#
#
#         marker_6e972f6d7fb57dd76ea82dd4d2924fcb.bindPopup(popup_c30048cb209d6f93ac98ed642a4c74aa)
#         ;
#
#
#
#
#             var marker_da6965277c525a45323aba77d1495c29 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6ae8c0dcde46bfe59e66f8eebe2c11c7);
#
#
#         var popup_be1940500a6918659e89207096c589b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f2453fc1ab35df95c9c38745a5a1a03 = $(`&lt;div id=&quot;html_9f2453fc1ab35df95c9c38745a5a1a03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_be1940500a6918659e89207096c589b5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9288b75253efb4fccee3d4e2c8de4afd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9288b75253efb4fccee3d4e2c8de4afd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9288b75253efb4fccee3d4e2c8de4afd = L.map(
#                 &quot;map_9288b75253efb4fccee3d4e2c8de4afd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1476203b3575d7814d88582bcc5e3b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d1476203b3575d7814d88582bcc5e3b9.addTo(map_9288b75253efb4fccee3d4e2c8de4afd);
#
#
#             var feature_group_f6a723f1212924586b197fe640d43089 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e950b2e3c6f7935fafb584fe37b58567 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f6a723f1212924586b197fe640d43089);
#
#
#         var popup_9d092d61fb70307f7125a988d1b54163 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d1fd8dc08757f0be778439ef48dcb96 = $(`&lt;div id=&quot;html_1d1fd8dc08757f0be778439ef48dcb96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9d092d61fb70307f7125a988d1b54163.setContent(html_1d1fd8dc08757f0be778439ef48dcb96);
#
#
#
#         marker_e950b2e3c6f7935fafb584fe37b58567.bindPopup(popup_9d092d61fb70307f7125a988d1b54163)
#         ;
#
#
#
#
#             var marker_4661f03a86c454f48c217318d88fe918 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f6a723f1212924586b197fe640d43089);
#
#
#         var popup_fa042ad7066461b815f9b73fdd9cf4ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1fc60928689c79f0208c967970a90f6 = $(`&lt;div id=&quot;html_e1fc60928689c79f0208c967970a90f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fa042ad7066461b815f9b73fdd9cf4ba.setContent(html_e1fc60928689c79f0208c967970a90f6);
#
#
#
#         marker_4661f03a86c454f48c217318d88fe918.bindPopup(popup_fa042ad7066461b815f9b73fdd9cf4ba)
#         ;
#
#
#
#
#             var marker_59d22951cc2710cacdbbc41dbfd12fc1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f6a723f1212924586b197fe640d43089);
#
#
#         var popup_739d67a3aa28532ca14527aaee307800 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a72ce3328e9120d86b6aa8252d8dbac3 = $(`&lt;div id=&quot;html_a72ce3328e9120d86b6aa8252d8dbac3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_739d67a3aa28532ca14527aaee307800.setContent(html_a72ce3328e9120d86b6aa8252d8dbac3);
#
#
#
#         marker_59d22951cc2710cacdbbc41dbfd12fc1.bindPopup(popup_739d67a3aa28532ca14527aaee307800)
#         ;
#
#
#
#
#             var marker_9945bfe5105278c619991d43f050f323 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f6a723f1212924586b197fe640d43089);
#
#
#         var popup_80e6578021efcd8d1f052824e5d7513d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fe6290b085d7b3e4e11e804f9861c00 = $(`&lt;div id=&quot;html_8fe6290b085d7b3e4e11e804f9861c00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_80e6578021efcd8d1f052824e5d7513d.setContent(html_8fe6290b085d7b3e4e11e804f9861c00);
#
#
#
#         marker_9945bfe5105278c619991d43f050f323.bindPopup(popup_80e6578021efcd8d1f052824e5d7513d)
#         ;
#
#
#
#
#             var marker_b73cd72367f1dd325b716eb5d25de1e3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f6a723f1212924586b197fe640d43089);
#
#
#         var popup_c509942a82242fc628933262003479a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b224497eeca0d6306f0cf40d771ef3b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b224497eeca0d6306f0cf40d771ef3b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b224497eeca0d6306f0cf40d771ef3b7 = L.map(
#                 &quot;map_b224497eeca0d6306f0cf40d771ef3b7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd1735d6f76fbcc60aec960876f4081d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bd1735d6f76fbcc60aec960876f4081d.addTo(map_b224497eeca0d6306f0cf40d771ef3b7);
#
#
#             var feature_group_537ccc38aa4bb50c04dadee8c81998cf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_537ccc38aa4bb50c04dadee8c81998cf.addTo(map_b224497eeca0d6306f0cf40d771ef3b7);
#
#
#             var feature_group_sub_group_565d895f6f1cbe11e7156df0926221ca = L.featureGroup.subGroup(
#                 feature_group_537ccc38aa4bb50c04dadee8c81998cf
#             );
#
#
#             var marker_ee7f0d257345348454ebac9ae9d94e8c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_565d895f6f1cbe11e7156df0926221ca);
#
#
#         var popup_8a22e9c87fd8c1ca06d06c0d65cc5b28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa916984cad9a7d4803fd7d860e8ffa9 = $(`&lt;div id=&quot;html_aa916984cad9a7d4803fd7d860e8ffa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8a22e9c87fd8c1ca06d06c0d65cc5b28.setContent(html_aa916984cad9a7d4803fd7d860e8ffa9);
#
#
#
#         marker_ee7f0d257345348454ebac9ae9d94e8c.bindPopup(popup_8a22e9c87fd8c1ca06d06c0d65cc5b28)
#         ;
#
#
#
#
#             var marker_aafed9bc264d7c55ef496d77804dc339 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_565d895f6f1cbe11e7156df0926221ca);
#
#
#         var popup_2626f0314e93177664de13c90b4e7895 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b8e45b608cf0e477e369d1ec2bef75b = $(`&lt;div id=&quot;html_6b8e45b608cf0e477e369d1ec2bef75b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2626f0314e93177664de13c90b4e7895.setContent(html_6b8e45b608cf0e477e369d1ec2bef75b);
#
#
#
#         marker_aafed9bc264d7c55ef496d77804dc339.bindPopup(popup_2626f0314e93177664de13c90b4e7895)
#         ;
#
#
#
#
#             var marker_6c8862c3a9125547bf784806d7b198e5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_565d895f6f1cbe11e7156df0926221ca);
#
#
#         var popup_992ae3a54d9dec183ad881b17ad8947f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c24492c168db9b0ec1151d0a3a0758ce = $(`&lt;div id=&quot;html_c24492c168db9b0ec1151d0a3a0758ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_992ae3a54d9dec183ad881b17ad8947f.setContent(html_c24492c168db9b0ec1151d0a3a0758ce);
#
#
#
#         marker_6c8862c3a9125547bf784806d7b198e5.bindPopup(popup_992ae3a54d9dec183ad881b17ad8947f)
#         ;
#
#
#
#
#             var marker_97815a9e590aec725e3ccb0ccb1360c4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_565d895f6f1cbe11e7156df0926221ca);
#
#
#         var popup_11b8f70984ef07fa365451b833ddff33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7e17a29cb825a674c49ae423430159f = $(`&lt;div id=&quot;html_e7e17a29cb825a674c49ae423430159f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_11b8f70984ef07fa365451b833ddff33.setContent(html_e7e17a29cb825a674c49ae423430159f);
#
#
#
#         marker_
