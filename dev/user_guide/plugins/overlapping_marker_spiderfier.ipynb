# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a838a6cd3883e4101ff33b8c9d9e671 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a838a6cd3883e4101ff33b8c9d9e671&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a838a6cd3883e4101ff33b8c9d9e671 = L.map(
#                 &quot;map_9a838a6cd3883e4101ff33b8c9d9e671&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6df1a4c7b5ce6ed7ad0c0aa027fa5cb2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6df1a4c7b5ce6ed7ad0c0aa027fa5cb2.addTo(map_9a838a6cd3883e4101ff33b8c9d9e671);
#
#
#             var marker_a2114dd4203ee75546a128bb0e20290b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9a838a6cd3883e4101ff33b8c9d9e671);
#
#
#         var popup_98a6dd5118b4873dcc4fcd46dd454bb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58e4ebb054aceba39a6e541d48c74d2e = $(`&lt;div id=&quot;html_58e4ebb054aceba39a6e541d48c74d2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_98a6dd5118b4873dcc4fcd46dd454bb9.setContent(html_58e4ebb054aceba39a6e541d48c74d2e);
#
#
#
#         marker_a2114dd4203ee75546a128bb0e20290b.bindPopup(popup_98a6dd5118b4873dcc4fcd46dd454bb9)
#         ;
#
#
#
#
#             var marker_af646a4129bdf1f82e0ad979539f427a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9a838a6cd3883e4101ff33b8c9d9e671);
#
#
#         var popup_3f9684a863cc2b46a2744a6c756fe433 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f555bfbc6f8aea6524f3e900753053c = $(`&lt;div id=&quot;html_5f555bfbc6f8aea6524f3e900753053c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3f9684a863cc2b46a2744a6c756fe433.setContent(html_5f555bfbc6f8aea6524f3e900753053c);
#
#
#
#         marker_af646a4129bdf1f82e0ad979539f427a.bindPopup(popup_3f9684a863cc2b46a2744a6c756fe433)
#         ;
#
#
#
#
#             var marker_dd45202213152419d05e96531aafb6cc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9a838a6cd3883e4101ff33b8c9d9e671);
#
#
#         var popup_fab34e6e202ef589e7e5e8fa82c0dfee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2225c5c975c99d6cb65087136747360 = $(`&lt;div id=&quot;html_e2225c5c975c99d6cb65087136747360&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fab34e6e202ef589e7e5e8fa82c0dfee.setContent(html_e2225c5c975c99d6cb65087136747360);
#
#
#
#         marker_dd45202213152419d05e96531aafb6cc.bindPopup(popup_fab34e6e202ef589e7e5e8fa82c0dfee)
#         ;
#
#
#
#
#             var marker_f35fbb0f238c9362b355e23c1190c0f3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9a838a6cd3883e4101ff33b8c9d9e671);
#
#
#         var popup_23f317cee8e21ec9d62985f96ff2454d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_570f03a656aefdb55098a71253334594 = $(`&lt;div id=&quot;html_570f03a656aefdb55098a71253334594&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_23f317cee8e21ec9d62985f96ff2454d.setContent(html_570f03a656aefdb55098a71253334594);
#
#
#
#         marker_f35fbb0f238c9362b355e23c1190c0f3.bindPopup(popup_23f317cee8e21ec9d62985f96ff2454d)
#         ;
#
#
#
#
#             var marker_3f358b86cd79f738c03857d6eca03512 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9a838a6cd3883e4101ff33b8c9d9e671);
#
#
#         var popup_c0fdea9249d4889168dc4cfbf7b69a6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96828195a2bbd3b83e0ad96209e6a0a5 = $(`&lt;div id=&quot;html_96828195a2bbd3b83e0ad96209e6a0a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c0fdea9249d4889168dc4cfbf7b69a6a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77121546f239946a54f7dc602d4188de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77121546f239946a54f7dc602d4188de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77121546f239946a54f7dc602d4188de = L.map(
#                 &quot;map_77121546f239946a54f7dc602d4188de&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eaf4c9250439b95a609ff12538ede2ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eaf4c9250439b95a609ff12538ede2ab.addTo(map_77121546f239946a54f7dc602d4188de);
#
#
#             var feature_group_6e6afcb52804c2dd706b35cdfb3310aa = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b2861baca8b1207acaca0318a5fa722e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6e6afcb52804c2dd706b35cdfb3310aa);
#
#
#         var popup_44007675ca9154bc53bcd594d1710ef5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9b1f54e3b0bea9d491b8ff733606874 = $(`&lt;div id=&quot;html_e9b1f54e3b0bea9d491b8ff733606874&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_44007675ca9154bc53bcd594d1710ef5.setContent(html_e9b1f54e3b0bea9d491b8ff733606874);
#
#
#
#         marker_b2861baca8b1207acaca0318a5fa722e.bindPopup(popup_44007675ca9154bc53bcd594d1710ef5)
#         ;
#
#
#
#
#             var marker_9dc9c65f12ba7280d07951966b4c3180 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6e6afcb52804c2dd706b35cdfb3310aa);
#
#
#         var popup_af6c164b3e13ac2705e626160e1c256f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d76f547bafbe557fcaf527906b1bb7f2 = $(`&lt;div id=&quot;html_d76f547bafbe557fcaf527906b1bb7f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_af6c164b3e13ac2705e626160e1c256f.setContent(html_d76f547bafbe557fcaf527906b1bb7f2);
#
#
#
#         marker_9dc9c65f12ba7280d07951966b4c3180.bindPopup(popup_af6c164b3e13ac2705e626160e1c256f)
#         ;
#
#
#
#
#             var marker_7490d0227a4fa9dbb0c8558f706fb168 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6e6afcb52804c2dd706b35cdfb3310aa);
#
#
#         var popup_f760eab0dca060e9ec6ae4ed8b0adea7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97d73aa90e7ef237dcba95cd57958cfa = $(`&lt;div id=&quot;html_97d73aa90e7ef237dcba95cd57958cfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f760eab0dca060e9ec6ae4ed8b0adea7.setContent(html_97d73aa90e7ef237dcba95cd57958cfa);
#
#
#
#         marker_7490d0227a4fa9dbb0c8558f706fb168.bindPopup(popup_f760eab0dca060e9ec6ae4ed8b0adea7)
#         ;
#
#
#
#
#             var marker_3ed936a7ec039edc5c1cf68c0be76d64 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6e6afcb52804c2dd706b35cdfb3310aa);
#
#
#         var popup_458a896ec094662413d0ade3eeb4f129 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9233bdd49f0c4418516fa7e591fa0014 = $(`&lt;div id=&quot;html_9233bdd49f0c4418516fa7e591fa0014&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_458a896ec094662413d0ade3eeb4f129.setContent(html_9233bdd49f0c4418516fa7e591fa0014);
#
#
#
#         marker_3ed936a7ec039edc5c1cf68c0be76d64.bindPopup(popup_458a896ec094662413d0ade3eeb4f129)
#         ;
#
#
#
#
#             var marker_9d2b9b39cebabddcc53ccc3d85d7b075 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6e6afcb52804c2dd706b35cdfb3310aa);
#
#
#         var popup_fbde672ee4553332a5a3a630367f6dff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_305a052a19806f7833d0d16dbf124a63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_305a052a19806f7833d0d16dbf124a63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_305a052a19806f7833d0d16dbf124a63 = L.map(
#                 &quot;map_305a052a19806f7833d0d16dbf124a63&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_edeac09a11631c942624780952e8e09a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_edeac09a11631c942624780952e8e09a.addTo(map_305a052a19806f7833d0d16dbf124a63);
#
#
#             var feature_group_995bd3bd60c9610e70836c67417c8879 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_995bd3bd60c9610e70836c67417c8879.addTo(map_305a052a19806f7833d0d16dbf124a63);
#
#
#             var feature_group_sub_group_af8529030b34215c268d0ead683a61f1 = L.featureGroup.subGroup(
#                 feature_group_995bd3bd60c9610e70836c67417c8879
#             );
#
#
#             var marker_2dac09f2a8d202c8dc4c4b2fcd022d49 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_af8529030b34215c268d0ead683a61f1);
#
#
#         var popup_1720f1987957002280fbec00d603ccb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f21d960b5bb0738a4cb0f5df486bef79 = $(`&lt;div id=&quot;html_f21d960b5bb0738a4cb0f5df486bef79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1720f1987957002280fbec00d603ccb7.setContent(html_f21d960b5bb0738a4cb0f5df486bef79);
#
#
#
#         marker_2dac09f2a8d202c8dc4c4b2fcd022d49.bindPopup(popup_1720f1987957002280fbec00d603ccb7)
#         ;
#
#
#
#
#             var marker_dcd5bf8c8b48a21f961f5fcf61f8fe8e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_af8529030b34215c268d0ead683a61f1);
#
#
#         var popup_29ff9b0a97ebe9e35ea09941cacff927 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9780b7c308bb7f40138e8c2ae1ba768 = $(`&lt;div id=&quot;html_f9780b7c308bb7f40138e8c2ae1ba768&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_29ff9b0a97ebe9e35ea09941cacff927.setContent(html_f9780b7c308bb7f40138e8c2ae1ba768);
#
#
#
#         marker_dcd5bf8c8b48a21f961f5fcf61f8fe8e.bindPopup(popup_29ff9b0a97ebe9e35ea09941cacff927)
#         ;
#
#
#
#
#             var marker_380d7e0adb74eb8c7a595d8afb3c7d06 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_af8529030b34215c268d0ead683a61f1);
#
#
#         var popup_bafb7d7dfcfa7156b55c15e0da1a5fcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f40857609b312c9a7f21c2415e0af71 = $(`&lt;div id=&quot;html_2f40857609b312c9a7f21c2415e0af71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bafb7d7dfcfa7156b55c15e0da1a5fcb.setContent(html_2f40857609b312c9a7f21c2415e0af71);
#
#
#
#         marker_380d7e0adb74eb8c7a595d8afb3c7d06.bindPopup(popup_bafb7d7dfcfa7156b55c15e0da1a5fcb)
#         ;
#
#
#
#
#             var marker_730c960b8ada6cfc9a08c8ab823245fe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_af8529030b34215c268d0ead683a61f1);
#
#
#         var popup_39e64e11b1608e1ff95088413ff079ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce52e69a8f85e073834e48ca8f52d3ab = $(`&lt;div id=&quot;html_ce52e69a8f85e073834e48ca8f52d3ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_39e64e11b1608e1ff95088413ff079ab.setContent(html_ce52e69a8f85e073834e48ca8f52d3ab);
#
#
#
#         marker_
