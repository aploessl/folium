# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34b58219df9ee93c36f572f258ac12e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34b58219df9ee93c36f572f258ac12e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34b58219df9ee93c36f572f258ac12e8 = L.map(
#                 &quot;map_34b58219df9ee93c36f572f258ac12e8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5c1d8ff9d22ae8ba3a5de8e01552d95 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b5c1d8ff9d22ae8ba3a5de8e01552d95.addTo(map_34b58219df9ee93c36f572f258ac12e8);
#
#
#             var marker_f1efdb0c2558319fec721f2a870af896 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_34b58219df9ee93c36f572f258ac12e8);
#
#
#         var popup_386cd2a2b1f8b5f74c854466c16b62d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a63b20fbd54e5c80a7a176d8afc41bd = $(`&lt;div id=&quot;html_2a63b20fbd54e5c80a7a176d8afc41bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_386cd2a2b1f8b5f74c854466c16b62d9.setContent(html_2a63b20fbd54e5c80a7a176d8afc41bd);
#
#
#
#         marker_f1efdb0c2558319fec721f2a870af896.bindPopup(popup_386cd2a2b1f8b5f74c854466c16b62d9)
#         ;
#
#
#
#
#             var marker_478544b3d835ab5aa3f74c919d8008a4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_34b58219df9ee93c36f572f258ac12e8);
#
#
#         var popup_da871bbf32b5b190dffb82855b581abd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_074b3e256413d6d06935c2f68648d791 = $(`&lt;div id=&quot;html_074b3e256413d6d06935c2f68648d791&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_da871bbf32b5b190dffb82855b581abd.setContent(html_074b3e256413d6d06935c2f68648d791);
#
#
#
#         marker_478544b3d835ab5aa3f74c919d8008a4.bindPopup(popup_da871bbf32b5b190dffb82855b581abd)
#         ;
#
#
#
#
#             var marker_f8a23850c0465db176445a44c53cfd1a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_34b58219df9ee93c36f572f258ac12e8);
#
#
#         var popup_6503810888dc39e1e2f27e88f9ddc3a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01f5dc4cf7bb03a048e260267ff19086 = $(`&lt;div id=&quot;html_01f5dc4cf7bb03a048e260267ff19086&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6503810888dc39e1e2f27e88f9ddc3a6.setContent(html_01f5dc4cf7bb03a048e260267ff19086);
#
#
#
#         marker_f8a23850c0465db176445a44c53cfd1a.bindPopup(popup_6503810888dc39e1e2f27e88f9ddc3a6)
#         ;
#
#
#
#
#             var marker_b95e86e694f292712764231a6e6b1e27 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_34b58219df9ee93c36f572f258ac12e8);
#
#
#         var popup_fee6c6ffd2b4ba16e3f38efda21595ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7db5488f328ae4007952dd25ed67656c = $(`&lt;div id=&quot;html_7db5488f328ae4007952dd25ed67656c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fee6c6ffd2b4ba16e3f38efda21595ec.setContent(html_7db5488f328ae4007952dd25ed67656c);
#
#
#
#         marker_b95e86e694f292712764231a6e6b1e27.bindPopup(popup_fee6c6ffd2b4ba16e3f38efda21595ec)
#         ;
#
#
#
#
#             var marker_15a76ccdac209b7cebfe8a58d5b00d86 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_34b58219df9ee93c36f572f258ac12e8);
#
#
#         var popup_7c6af2a140cad7d9e0713e82c88a5420 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_161c961ba90dfce6ff1dc35faeb9b3a9 = $(`&lt;div id=&quot;html_161c961ba90dfce6ff1dc35faeb9b3a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7c6af2a140cad7d9e0713e82c88a5420.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4edf7deff44b87a967cc93ab525aa9b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4edf7deff44b87a967cc93ab525aa9b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4edf7deff44b87a967cc93ab525aa9b3 = L.map(
#                 &quot;map_4edf7deff44b87a967cc93ab525aa9b3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9aecdf65b7213e801fad618087a3ece = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e9aecdf65b7213e801fad618087a3ece.addTo(map_4edf7deff44b87a967cc93ab525aa9b3);
#
#
#             var feature_group_033b4eb2ca0608fda45c54d68c3c74cc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_17a8bbe950321acd12951de36f66892f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_033b4eb2ca0608fda45c54d68c3c74cc);
#
#
#         var popup_41ab4f3519d782529278410a96cbb6fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b583280149f37f1b0308f166d4ae3d0e = $(`&lt;div id=&quot;html_b583280149f37f1b0308f166d4ae3d0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_41ab4f3519d782529278410a96cbb6fc.setContent(html_b583280149f37f1b0308f166d4ae3d0e);
#
#
#
#         marker_17a8bbe950321acd12951de36f66892f.bindPopup(popup_41ab4f3519d782529278410a96cbb6fc)
#         ;
#
#
#
#
#             var marker_edc8503846fe5f335b2f7b5530440f4f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_033b4eb2ca0608fda45c54d68c3c74cc);
#
#
#         var popup_91afefd8c4b31e148a71a6993ad89558 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83bcaae9b6160bfb87e57b01d164669b = $(`&lt;div id=&quot;html_83bcaae9b6160bfb87e57b01d164669b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_91afefd8c4b31e148a71a6993ad89558.setContent(html_83bcaae9b6160bfb87e57b01d164669b);
#
#
#
#         marker_edc8503846fe5f335b2f7b5530440f4f.bindPopup(popup_91afefd8c4b31e148a71a6993ad89558)
#         ;
#
#
#
#
#             var marker_2dafe20b6a8d5ab4a199417a38e6c584 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_033b4eb2ca0608fda45c54d68c3c74cc);
#
#
#         var popup_5b8965ec1ca298f3fc9531e9772c3670 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cda56b285ee6d691ccd7dae814276c1d = $(`&lt;div id=&quot;html_cda56b285ee6d691ccd7dae814276c1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5b8965ec1ca298f3fc9531e9772c3670.setContent(html_cda56b285ee6d691ccd7dae814276c1d);
#
#
#
#         marker_2dafe20b6a8d5ab4a199417a38e6c584.bindPopup(popup_5b8965ec1ca298f3fc9531e9772c3670)
#         ;
#
#
#
#
#             var marker_fc46280c05e154fadb8aa5c14f1762ee = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_033b4eb2ca0608fda45c54d68c3c74cc);
#
#
#         var popup_25259234a6ad5b6ca19b799c52f53147 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_377642c019d50460719d31f21ce26068 = $(`&lt;div id=&quot;html_377642c019d50460719d31f21ce26068&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_25259234a6ad5b6ca19b799c52f53147.setContent(html_377642c019d50460719d31f21ce26068);
#
#
#
#         marker_fc46280c05e154fadb8aa5c14f1762ee.bindPopup(popup_25259234a6ad5b6ca19b799c52f53147)
#         ;
#
#
#
#
#             var marker_411fa5f8ae0046ff9040b93fba6a55d2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_033b4eb2ca0608fda45c54d68c3c74cc);
#
#
#         var popup_d2945c3d2a91f82b67f84e936c38cf62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d73da502f6b9570a854b7e64d1255b60 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d73da502f6b9570a854b7e64d1255b60&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d73da502f6b9570a854b7e64d1255b60 = L.map(
#                 &quot;map_d73da502f6b9570a854b7e64d1255b60&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14ae18337c94d239aef720aff31f4de9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_14ae18337c94d239aef720aff31f4de9.addTo(map_d73da502f6b9570a854b7e64d1255b60);
#
#
#             var feature_group_8ba85e7b7902c07239094e66a23be2b5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8ba85e7b7902c07239094e66a23be2b5.addTo(map_d73da502f6b9570a854b7e64d1255b60);
#
#
#             var feature_group_sub_group_d386c4c204c1256569cfc923694b0d3f = L.featureGroup.subGroup(
#                 feature_group_8ba85e7b7902c07239094e66a23be2b5
#             );
#
#
#             var marker_fe171e485dc48b45392fee25b11e6a5e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d386c4c204c1256569cfc923694b0d3f);
#
#
#         var popup_af3419c644e4977b12b584f430d8b83c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe917e19cca959baf6d6363be3329604 = $(`&lt;div id=&quot;html_fe917e19cca959baf6d6363be3329604&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_af3419c644e4977b12b584f430d8b83c.setContent(html_fe917e19cca959baf6d6363be3329604);
#
#
#
#         marker_fe171e485dc48b45392fee25b11e6a5e.bindPopup(popup_af3419c644e4977b12b584f430d8b83c)
#         ;
#
#
#
#
#             var marker_8a21c934bc7a2b74b2efe1c03984b138 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d386c4c204c1256569cfc923694b0d3f);
#
#
#         var popup_3153b536234b6d46e3044f88ec0b2072 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b89981f8f8d2163b3aab22c2d8bb7bdb = $(`&lt;div id=&quot;html_b89981f8f8d2163b3aab22c2d8bb7bdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3153b536234b6d46e3044f88ec0b2072.setContent(html_b89981f8f8d2163b3aab22c2d8bb7bdb);
#
#
#
#         marker_8a21c934bc7a2b74b2efe1c03984b138.bindPopup(popup_3153b536234b6d46e3044f88ec0b2072)
#         ;
#
#
#
#
#             var marker_50a4ae10137ddbd28a486bff0a801f3d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d386c4c204c1256569cfc923694b0d3f);
#
#
#         var popup_b3ea9dec39c3397d9a1ffb1a81591193 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f6759c87846b7f8df61fffff0b43bae = $(`&lt;div id=&quot;html_4f6759c87846b7f8df61fffff0b43bae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b3ea9dec39c3397d9a1ffb1a81591193.setContent(html_4f6759c87846b7f8df61fffff0b43bae);
#
#
#
#         marker_50a4ae10137ddbd28a486bff0a801f3d.bindPopup(popup_b3ea9dec39c3397d9a1ffb1a81591193)
#         ;
#
#
#
#
#             var marker_9b33f608e7b98dc1167d4736d0bc588b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d386c4c204c1256569cfc923694b0d3f);
#
#
#         var popup_539d7cd852ccfd74ab1f32577574b994 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23c81320723c521b257886e12c0e2d39 = $(`&lt;div id=&quot;html_23c81320723c521b257886e12c0e2d39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_539d7cd852ccfd74ab1f32577574b994.setContent(html_23c81320723c521b257886e12c0e2d39);
#
#
#
#         marker_
