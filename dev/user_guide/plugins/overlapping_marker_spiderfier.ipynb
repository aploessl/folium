# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf5d71ee72212850d007548c367cec6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf5d71ee72212850d007548c367cec6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf5d71ee72212850d007548c367cec6e = L.map(
#                 &quot;map_bf5d71ee72212850d007548c367cec6e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d4ab14b7babdbd9e5fae1036a938dc1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d4ab14b7babdbd9e5fae1036a938dc1.addTo(map_bf5d71ee72212850d007548c367cec6e);
#
#
#             var marker_f3785152cc8bec068759e77ae76c3b96 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bf5d71ee72212850d007548c367cec6e);
#
#
#         var popup_58966395d96ac3338c67ec8be48f8cbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f70ad0dd9f82e111dd226d8b55e0087d = $(`&lt;div id=&quot;html_f70ad0dd9f82e111dd226d8b55e0087d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_58966395d96ac3338c67ec8be48f8cbf.setContent(html_f70ad0dd9f82e111dd226d8b55e0087d);
#
#
#
#         marker_f3785152cc8bec068759e77ae76c3b96.bindPopup(popup_58966395d96ac3338c67ec8be48f8cbf)
#         ;
#
#
#
#
#             var marker_5d4a1f66e887b2956ccbe23226bd615d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bf5d71ee72212850d007548c367cec6e);
#
#
#         var popup_b9b9b899fe02143b3a00e2ac0a88d1d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec475f798cfcb33cf3c55a3190162d6a = $(`&lt;div id=&quot;html_ec475f798cfcb33cf3c55a3190162d6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b9b9b899fe02143b3a00e2ac0a88d1d2.setContent(html_ec475f798cfcb33cf3c55a3190162d6a);
#
#
#
#         marker_5d4a1f66e887b2956ccbe23226bd615d.bindPopup(popup_b9b9b899fe02143b3a00e2ac0a88d1d2)
#         ;
#
#
#
#
#             var marker_47dbbea1a9c2395abeb18600ad5f41a0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bf5d71ee72212850d007548c367cec6e);
#
#
#         var popup_3c698076f2ba8415569c433ed1eab657 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6e50dc95e80bde6311af651dd9dab17 = $(`&lt;div id=&quot;html_e6e50dc95e80bde6311af651dd9dab17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3c698076f2ba8415569c433ed1eab657.setContent(html_e6e50dc95e80bde6311af651dd9dab17);
#
#
#
#         marker_47dbbea1a9c2395abeb18600ad5f41a0.bindPopup(popup_3c698076f2ba8415569c433ed1eab657)
#         ;
#
#
#
#
#             var marker_93a06d49d9791b82610ccfedd3a1b505 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bf5d71ee72212850d007548c367cec6e);
#
#
#         var popup_7f744fa096475c4c141956138e6f7633 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ed7867130c6b7c3f1f153c543b50c46 = $(`&lt;div id=&quot;html_8ed7867130c6b7c3f1f153c543b50c46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7f744fa096475c4c141956138e6f7633.setContent(html_8ed7867130c6b7c3f1f153c543b50c46);
#
#
#
#         marker_93a06d49d9791b82610ccfedd3a1b505.bindPopup(popup_7f744fa096475c4c141956138e6f7633)
#         ;
#
#
#
#
#             var marker_a5f52d4eb3c64e126d46686c45cb3942 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bf5d71ee72212850d007548c367cec6e);
#
#
#         var popup_79045d50a628c053a852a94dedf750f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a526694f177f48806cee612186eaf984 = $(`&lt;div id=&quot;html_a526694f177f48806cee612186eaf984&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_79045d50a628c053a852a94dedf750f1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fd64af66204218709968ff2e30dec3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fd64af66204218709968ff2e30dec3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fd64af66204218709968ff2e30dec3b = L.map(
#                 &quot;map_5fd64af66204218709968ff2e30dec3b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23f345c574b5a200a33712c8e4e584e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_23f345c574b5a200a33712c8e4e584e0.addTo(map_5fd64af66204218709968ff2e30dec3b);
#
#
#             var feature_group_cac161e6303e4f0e23c9cbb4918bdf8f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_61c37532e015e352ba65b3bdc6c68438 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cac161e6303e4f0e23c9cbb4918bdf8f);
#
#
#         var popup_c32c860bebfaed0f7cdb5340f17800a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0712735bb99fd157f95277646b30d868 = $(`&lt;div id=&quot;html_0712735bb99fd157f95277646b30d868&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c32c860bebfaed0f7cdb5340f17800a5.setContent(html_0712735bb99fd157f95277646b30d868);
#
#
#
#         marker_61c37532e015e352ba65b3bdc6c68438.bindPopup(popup_c32c860bebfaed0f7cdb5340f17800a5)
#         ;
#
#
#
#
#             var marker_6a80629fcd613f44d1f6ab0506c8dca5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cac161e6303e4f0e23c9cbb4918bdf8f);
#
#
#         var popup_a2a8b5611d99434d374624227f8acd64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f13fc247dcca7315358b269dabf498ec = $(`&lt;div id=&quot;html_f13fc247dcca7315358b269dabf498ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a2a8b5611d99434d374624227f8acd64.setContent(html_f13fc247dcca7315358b269dabf498ec);
#
#
#
#         marker_6a80629fcd613f44d1f6ab0506c8dca5.bindPopup(popup_a2a8b5611d99434d374624227f8acd64)
#         ;
#
#
#
#
#             var marker_ee4755099af3985d51d6a505a12dd88c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cac161e6303e4f0e23c9cbb4918bdf8f);
#
#
#         var popup_f3b291fd376e77a9182df4ac291abbc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d9825d8be7609622b332f54adebcd4b = $(`&lt;div id=&quot;html_1d9825d8be7609622b332f54adebcd4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f3b291fd376e77a9182df4ac291abbc4.setContent(html_1d9825d8be7609622b332f54adebcd4b);
#
#
#
#         marker_ee4755099af3985d51d6a505a12dd88c.bindPopup(popup_f3b291fd376e77a9182df4ac291abbc4)
#         ;
#
#
#
#
#             var marker_7e6dc5ac339bd24e14fc61d1634fdbce = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cac161e6303e4f0e23c9cbb4918bdf8f);
#
#
#         var popup_9c77199ca1b96296da45342592b5675e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_158aafe679b0f0c902997bafa4dcae16 = $(`&lt;div id=&quot;html_158aafe679b0f0c902997bafa4dcae16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9c77199ca1b96296da45342592b5675e.setContent(html_158aafe679b0f0c902997bafa4dcae16);
#
#
#
#         marker_7e6dc5ac339bd24e14fc61d1634fdbce.bindPopup(popup_9c77199ca1b96296da45342592b5675e)
#         ;
#
#
#
#
#             var marker_031f1ac642f13dace9ef6939b209c5ce = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cac161e6303e4f0e23c9cbb4918bdf8f);
#
#
#         var popup_306a8d4f6cc372d9b0fc250e97913975 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6459990abe50215c32b7acb5457a471 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6459990abe50215c32b7acb5457a471&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6459990abe50215c32b7acb5457a471 = L.map(
#                 &quot;map_c6459990abe50215c32b7acb5457a471&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c286e111028f96cbabd9c990275d300f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c286e111028f96cbabd9c990275d300f.addTo(map_c6459990abe50215c32b7acb5457a471);
#
#
#             var feature_group_61ac2a1607f20b39036641e9a41dd8eb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_61ac2a1607f20b39036641e9a41dd8eb.addTo(map_c6459990abe50215c32b7acb5457a471);
#
#
#             var feature_group_sub_group_65f8c7f4b05d76bbce97257113a11c95 = L.featureGroup.subGroup(
#                 feature_group_61ac2a1607f20b39036641e9a41dd8eb
#             );
#
#
#             var marker_90a30d4d14cddfb4507a6271351dbc27 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_65f8c7f4b05d76bbce97257113a11c95);
#
#
#         var popup_beaa35e9bc90e16ddc26a6d8a9ae04c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5dedf13f64254f45eea6694b7ee4ee7d = $(`&lt;div id=&quot;html_5dedf13f64254f45eea6694b7ee4ee7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_beaa35e9bc90e16ddc26a6d8a9ae04c0.setContent(html_5dedf13f64254f45eea6694b7ee4ee7d);
#
#
#
#         marker_90a30d4d14cddfb4507a6271351dbc27.bindPopup(popup_beaa35e9bc90e16ddc26a6d8a9ae04c0)
#         ;
#
#
#
#
#             var marker_496a63f1edbacce99a626e2556c76575 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_65f8c7f4b05d76bbce97257113a11c95);
#
#
#         var popup_fa3a852b5bc97798320f81897ff587b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94371b7524dc4f11f3a8054395662212 = $(`&lt;div id=&quot;html_94371b7524dc4f11f3a8054395662212&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fa3a852b5bc97798320f81897ff587b7.setContent(html_94371b7524dc4f11f3a8054395662212);
#
#
#
#         marker_496a63f1edbacce99a626e2556c76575.bindPopup(popup_fa3a852b5bc97798320f81897ff587b7)
#         ;
#
#
#
#
#             var marker_188501ca177afabd8587f0bf32377862 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_65f8c7f4b05d76bbce97257113a11c95);
#
#
#         var popup_89b450cb1f6624406ff9d0ea2237fdf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee68086a1899032a3dea032e09faf944 = $(`&lt;div id=&quot;html_ee68086a1899032a3dea032e09faf944&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_89b450cb1f6624406ff9d0ea2237fdf7.setContent(html_ee68086a1899032a3dea032e09faf944);
#
#
#
#         marker_188501ca177afabd8587f0bf32377862.bindPopup(popup_89b450cb1f6624406ff9d0ea2237fdf7)
#         ;
#
#
#
#
#             var marker_cca3477faa0af2f3f144c2ee59e050b0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_65f8c7f4b05d76bbce97257113a11c95);
#
#
#         var popup_ebf88b8107e6401955ac79fb18d98141 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_440fb52ae6af609b4925cd8d082e8762 = $(`&lt;div id=&quot;html_440fb52ae6af609b4925cd8d082e8762&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ebf88b8107e6401955ac79fb18d98141.setContent(html_440fb52ae6af609b4925cd8d082e8762);
#
#
#
#         marker_
