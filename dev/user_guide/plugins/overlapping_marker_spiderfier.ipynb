# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_926e26c42ee45998964275600c17b317 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_926e26c42ee45998964275600c17b317&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_926e26c42ee45998964275600c17b317 = L.map(
#                 &quot;map_926e26c42ee45998964275600c17b317&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cde7a3b0d81d05a7780ecd4b86436f0b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cde7a3b0d81d05a7780ecd4b86436f0b.addTo(map_926e26c42ee45998964275600c17b317);
#
#
#             var marker_4896698280c88ca87a21e8798d4820e1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_926e26c42ee45998964275600c17b317);
#
#
#         var popup_1129dabf63a0e38bc5a7e206adf19092 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc8cb6ba81a6ee4bfbf3445d1d5ad2f7 = $(`&lt;div id=&quot;html_fc8cb6ba81a6ee4bfbf3445d1d5ad2f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1129dabf63a0e38bc5a7e206adf19092.setContent(html_fc8cb6ba81a6ee4bfbf3445d1d5ad2f7);
#
#
#
#         marker_4896698280c88ca87a21e8798d4820e1.bindPopup(popup_1129dabf63a0e38bc5a7e206adf19092)
#         ;
#
#
#
#
#             var marker_1c5a1e836faf0d1d389569c8054fb3c8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_926e26c42ee45998964275600c17b317);
#
#
#         var popup_3722e42e50a30ce7b7d35aeb3b7d245f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c066fd0b73ae5d75314902ad3f66d84 = $(`&lt;div id=&quot;html_2c066fd0b73ae5d75314902ad3f66d84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3722e42e50a30ce7b7d35aeb3b7d245f.setContent(html_2c066fd0b73ae5d75314902ad3f66d84);
#
#
#
#         marker_1c5a1e836faf0d1d389569c8054fb3c8.bindPopup(popup_3722e42e50a30ce7b7d35aeb3b7d245f)
#         ;
#
#
#
#
#             var marker_a2ad0fe3be206b3755984d63357e4c54 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_926e26c42ee45998964275600c17b317);
#
#
#         var popup_dda3b7895bcbb80cedab229a93038d04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50ad72eff586b434fc07ff5f2e2c6962 = $(`&lt;div id=&quot;html_50ad72eff586b434fc07ff5f2e2c6962&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dda3b7895bcbb80cedab229a93038d04.setContent(html_50ad72eff586b434fc07ff5f2e2c6962);
#
#
#
#         marker_a2ad0fe3be206b3755984d63357e4c54.bindPopup(popup_dda3b7895bcbb80cedab229a93038d04)
#         ;
#
#
#
#
#             var marker_5da87b48bca3bf72099ed0662c7b5d04 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_926e26c42ee45998964275600c17b317);
#
#
#         var popup_0b1f52a662a235c7a3a2a9522c0e4932 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_240dfe35d0eb126364081618758c8692 = $(`&lt;div id=&quot;html_240dfe35d0eb126364081618758c8692&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0b1f52a662a235c7a3a2a9522c0e4932.setContent(html_240dfe35d0eb126364081618758c8692);
#
#
#
#         marker_5da87b48bca3bf72099ed0662c7b5d04.bindPopup(popup_0b1f52a662a235c7a3a2a9522c0e4932)
#         ;
#
#
#
#
#             var marker_0efce01ad0fdf7e58f696dd2d909572d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_926e26c42ee45998964275600c17b317);
#
#
#         var popup_287dc5da1234b25200ee35384a5f51c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce56016904a73b27ed31e07b4f8b2d07 = $(`&lt;div id=&quot;html_ce56016904a73b27ed31e07b4f8b2d07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_287dc5da1234b25200ee35384a5f51c0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4733d22f41c57018c5316fd50ed62c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4733d22f41c57018c5316fd50ed62c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4733d22f41c57018c5316fd50ed62c5 = L.map(
#                 &quot;map_e4733d22f41c57018c5316fd50ed62c5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8fd932dd55da8253152bc02b6abf56da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8fd932dd55da8253152bc02b6abf56da.addTo(map_e4733d22f41c57018c5316fd50ed62c5);
#
#
#             var feature_group_b93144be0353ab5208741a470325fb69 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e1917e5cca05742bce1cae4ba2bb67f1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b93144be0353ab5208741a470325fb69);
#
#
#         var popup_2c27937a3e2278450d701866b2751ee7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b332fa7d00170623fda92d67fa2e9aa9 = $(`&lt;div id=&quot;html_b332fa7d00170623fda92d67fa2e9aa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2c27937a3e2278450d701866b2751ee7.setContent(html_b332fa7d00170623fda92d67fa2e9aa9);
#
#
#
#         marker_e1917e5cca05742bce1cae4ba2bb67f1.bindPopup(popup_2c27937a3e2278450d701866b2751ee7)
#         ;
#
#
#
#
#             var marker_6bdbbd6cea6957f72573fbf7fd907fc8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b93144be0353ab5208741a470325fb69);
#
#
#         var popup_75447d4ba45e165d8dd443e103e842af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7158c78cd48f35222fe78b652df99061 = $(`&lt;div id=&quot;html_7158c78cd48f35222fe78b652df99061&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_75447d4ba45e165d8dd443e103e842af.setContent(html_7158c78cd48f35222fe78b652df99061);
#
#
#
#         marker_6bdbbd6cea6957f72573fbf7fd907fc8.bindPopup(popup_75447d4ba45e165d8dd443e103e842af)
#         ;
#
#
#
#
#             var marker_fc26fa45c646a313960f57c70965d90d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b93144be0353ab5208741a470325fb69);
#
#
#         var popup_a60e8c632ffd8f8a08975ff8f3aa91c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e54c03c76454df1d7f9e555159c84422 = $(`&lt;div id=&quot;html_e54c03c76454df1d7f9e555159c84422&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a60e8c632ffd8f8a08975ff8f3aa91c5.setContent(html_e54c03c76454df1d7f9e555159c84422);
#
#
#
#         marker_fc26fa45c646a313960f57c70965d90d.bindPopup(popup_a60e8c632ffd8f8a08975ff8f3aa91c5)
#         ;
#
#
#
#
#             var marker_5577ee19c4b310bfbbef62854d8a8a18 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b93144be0353ab5208741a470325fb69);
#
#
#         var popup_89925dca42b8ea693b5cf4fb686dff49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0608f9d6d127943235d9ad87bb847d8c = $(`&lt;div id=&quot;html_0608f9d6d127943235d9ad87bb847d8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_89925dca42b8ea693b5cf4fb686dff49.setContent(html_0608f9d6d127943235d9ad87bb847d8c);
#
#
#
#         marker_5577ee19c4b310bfbbef62854d8a8a18.bindPopup(popup_89925dca42b8ea693b5cf4fb686dff49)
#         ;
#
#
#
#
#             var marker_16dc6ef32f649ff5972e2b1992c59951 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b93144be0353ab5208741a470325fb69);
#
#
#         var popup_927ea78bcf6cb766cc7cf2dfb639b7fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12e808c93e71dd9c4347e20b4da1c193 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12e808c93e71dd9c4347e20b4da1c193&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12e808c93e71dd9c4347e20b4da1c193 = L.map(
#                 &quot;map_12e808c93e71dd9c4347e20b4da1c193&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aaf2960ef0058d850052aef68e3594bb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aaf2960ef0058d850052aef68e3594bb.addTo(map_12e808c93e71dd9c4347e20b4da1c193);
#
#
#             var feature_group_2f7622b55309d55130cd303e9db6f20b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2f7622b55309d55130cd303e9db6f20b.addTo(map_12e808c93e71dd9c4347e20b4da1c193);
#
#
#             var feature_group_sub_group_2e6cf9d1a65469b77b8816ac31f69893 = L.featureGroup.subGroup(
#                 feature_group_2f7622b55309d55130cd303e9db6f20b
#             );
#
#
#             var marker_5c96fc74cb53267642339cd7a8eca10f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e6cf9d1a65469b77b8816ac31f69893);
#
#
#         var popup_76570e87cb126788b40f74f9606e81b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3724b00c715c210cebe2ff24bde1285 = $(`&lt;div id=&quot;html_a3724b00c715c210cebe2ff24bde1285&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_76570e87cb126788b40f74f9606e81b1.setContent(html_a3724b00c715c210cebe2ff24bde1285);
#
#
#
#         marker_5c96fc74cb53267642339cd7a8eca10f.bindPopup(popup_76570e87cb126788b40f74f9606e81b1)
#         ;
#
#
#
#
#             var marker_1f168d7f7983920db63af696331797e3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e6cf9d1a65469b77b8816ac31f69893);
#
#
#         var popup_812004392470bf9eaf7c20b635ce96b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_663d2a229706acfc16550df7ff768aa2 = $(`&lt;div id=&quot;html_663d2a229706acfc16550df7ff768aa2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_812004392470bf9eaf7c20b635ce96b9.setContent(html_663d2a229706acfc16550df7ff768aa2);
#
#
#
#         marker_1f168d7f7983920db63af696331797e3.bindPopup(popup_812004392470bf9eaf7c20b635ce96b9)
#         ;
#
#
#
#
#             var marker_99c171e914f38d39085bf7c6b8ac1759 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e6cf9d1a65469b77b8816ac31f69893);
#
#
#         var popup_af8eb8595d710023769b990a8d9ee2a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bfcf1e22d1d63d9804f0f48bf631974 = $(`&lt;div id=&quot;html_6bfcf1e22d1d63d9804f0f48bf631974&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_af8eb8595d710023769b990a8d9ee2a8.setContent(html_6bfcf1e22d1d63d9804f0f48bf631974);
#
#
#
#         marker_99c171e914f38d39085bf7c6b8ac1759.bindPopup(popup_af8eb8595d710023769b990a8d9ee2a8)
#         ;
#
#
#
#
#             var marker_5dab9a6e27d57e46085eac6198dbee26 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e6cf9d1a65469b77b8816ac31f69893);
#
#
#         var popup_cae3eea59784ee422c59968c0afae363 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6aa3620b9e65c527cce8eb2bedd2d0c = $(`&lt;div id=&quot;html_a6aa3620b9e65c527cce8eb2bedd2d0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_cae3eea59784ee422c59968c0afae363.setContent(html_a6aa3620b9e65c527cce8eb2bedd2d0c);
#
#
#
#         marker_
