# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7100705bf0f260cf743330b190fc196c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7100705bf0f260cf743330b190fc196c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7100705bf0f260cf743330b190fc196c = L.map(
#                 &quot;map_7100705bf0f260cf743330b190fc196c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8aba713708f219b3e27c5642da4ccda = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e8aba713708f219b3e27c5642da4ccda.addTo(map_7100705bf0f260cf743330b190fc196c);
#
#
#             var marker_8f909bcd21d42b3a47026e7949c198bc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7100705bf0f260cf743330b190fc196c);
#
#
#         var popup_d47e6f9569d15050381a2008251f1bb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e265327ff98da034d80be9c07d434cff = $(`&lt;div id=&quot;html_e265327ff98da034d80be9c07d434cff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d47e6f9569d15050381a2008251f1bb1.setContent(html_e265327ff98da034d80be9c07d434cff);
#
#
#
#         marker_8f909bcd21d42b3a47026e7949c198bc.bindPopup(popup_d47e6f9569d15050381a2008251f1bb1)
#         ;
#
#
#
#
#             var marker_394f3afdbee5d29f18802b84dea61d50 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7100705bf0f260cf743330b190fc196c);
#
#
#         var popup_fbb5aced45c004e411c2af95e470d1ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82323ceee0fb97d243d6d254b852331c = $(`&lt;div id=&quot;html_82323ceee0fb97d243d6d254b852331c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fbb5aced45c004e411c2af95e470d1ba.setContent(html_82323ceee0fb97d243d6d254b852331c);
#
#
#
#         marker_394f3afdbee5d29f18802b84dea61d50.bindPopup(popup_fbb5aced45c004e411c2af95e470d1ba)
#         ;
#
#
#
#
#             var marker_63a12a9928004c4de45a1d4fcd21de13 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7100705bf0f260cf743330b190fc196c);
#
#
#         var popup_1c04575b8f2133b83b1cb027fd9bef3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_520e32dd2737a2675d2faab0c7ce7e83 = $(`&lt;div id=&quot;html_520e32dd2737a2675d2faab0c7ce7e83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1c04575b8f2133b83b1cb027fd9bef3c.setContent(html_520e32dd2737a2675d2faab0c7ce7e83);
#
#
#
#         marker_63a12a9928004c4de45a1d4fcd21de13.bindPopup(popup_1c04575b8f2133b83b1cb027fd9bef3c)
#         ;
#
#
#
#
#             var marker_2b22fdc05e4fcdf846c02af9c75ef091 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7100705bf0f260cf743330b190fc196c);
#
#
#         var popup_3027006d8c4f9079984e16cfcb0e75c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4155428787c1316ff08a0f5641bdd358 = $(`&lt;div id=&quot;html_4155428787c1316ff08a0f5641bdd358&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3027006d8c4f9079984e16cfcb0e75c3.setContent(html_4155428787c1316ff08a0f5641bdd358);
#
#
#
#         marker_2b22fdc05e4fcdf846c02af9c75ef091.bindPopup(popup_3027006d8c4f9079984e16cfcb0e75c3)
#         ;
#
#
#
#
#             var marker_73208db0598510aa590de58a3423cc69 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7100705bf0f260cf743330b190fc196c);
#
#
#         var popup_58bd3a6b5ffdcbcead340d726ece03fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c7d18fac1b2733e86d3cec61aa4dfea = $(`&lt;div id=&quot;html_2c7d18fac1b2733e86d3cec61aa4dfea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_58bd3a6b5ffdcbcead340d726ece03fd.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0bcead23c92470da900a329c4ba7acda {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0bcead23c92470da900a329c4ba7acda&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0bcead23c92470da900a329c4ba7acda = L.map(
#                 &quot;map_0bcead23c92470da900a329c4ba7acda&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd4bf2f6010c3451f36e229528e80ca5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd4bf2f6010c3451f36e229528e80ca5.addTo(map_0bcead23c92470da900a329c4ba7acda);
#
#
#             var feature_group_105fe7d35c96b41b5b7b62cf2a524d23 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0c3e7b4894b750d2b43df5931ba1c2fa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_105fe7d35c96b41b5b7b62cf2a524d23);
#
#
#         var popup_b4649d14c49ee28bc829f55f2fd3cfc1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_184e06222d903acdccfc48bcbbf2d3c6 = $(`&lt;div id=&quot;html_184e06222d903acdccfc48bcbbf2d3c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b4649d14c49ee28bc829f55f2fd3cfc1.setContent(html_184e06222d903acdccfc48bcbbf2d3c6);
#
#
#
#         marker_0c3e7b4894b750d2b43df5931ba1c2fa.bindPopup(popup_b4649d14c49ee28bc829f55f2fd3cfc1)
#         ;
#
#
#
#
#             var marker_0bb8cbdc9d0d4b5245e6a6b218c8524f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_105fe7d35c96b41b5b7b62cf2a524d23);
#
#
#         var popup_193981797bd11845d225aa1645aaadbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbd709d99dfd270ded985999ca0f7739 = $(`&lt;div id=&quot;html_cbd709d99dfd270ded985999ca0f7739&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_193981797bd11845d225aa1645aaadbf.setContent(html_cbd709d99dfd270ded985999ca0f7739);
#
#
#
#         marker_0bb8cbdc9d0d4b5245e6a6b218c8524f.bindPopup(popup_193981797bd11845d225aa1645aaadbf)
#         ;
#
#
#
#
#             var marker_37f93d023d2884e3496b5b2d209ffcc5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_105fe7d35c96b41b5b7b62cf2a524d23);
#
#
#         var popup_f1af510e5f6c382bef0d9c28c2423320 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68a41991a877a8a5e21324efe86d8661 = $(`&lt;div id=&quot;html_68a41991a877a8a5e21324efe86d8661&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f1af510e5f6c382bef0d9c28c2423320.setContent(html_68a41991a877a8a5e21324efe86d8661);
#
#
#
#         marker_37f93d023d2884e3496b5b2d209ffcc5.bindPopup(popup_f1af510e5f6c382bef0d9c28c2423320)
#         ;
#
#
#
#
#             var marker_488919afb70617cc0555c262964a7abc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_105fe7d35c96b41b5b7b62cf2a524d23);
#
#
#         var popup_c42f667d803a34b558d4f0d59059029e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6298069ed15e4cf197677498f64566b8 = $(`&lt;div id=&quot;html_6298069ed15e4cf197677498f64566b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c42f667d803a34b558d4f0d59059029e.setContent(html_6298069ed15e4cf197677498f64566b8);
#
#
#
#         marker_488919afb70617cc0555c262964a7abc.bindPopup(popup_c42f667d803a34b558d4f0d59059029e)
#         ;
#
#
#
#
#             var marker_43343df1644e5d30b71e59e6814899a5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_105fe7d35c96b41b5b7b62cf2a524d23);
#
#
#         var popup_c54277cd9064d151cb1122fb3f3cba92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22e87fd82b3e27fbe28f85fa41530323 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22e87fd82b3e27fbe28f85fa41530323&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_22e87fd82b3e27fbe28f85fa41530323 = L.map(
#                 &quot;map_22e87fd82b3e27fbe28f85fa41530323&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9beaf377359311ffefd527b17c40b5dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9beaf377359311ffefd527b17c40b5dc.addTo(map_22e87fd82b3e27fbe28f85fa41530323);
#
#
#             var feature_group_2cb0cc7108b4a1bd9750123d80aa923d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2cb0cc7108b4a1bd9750123d80aa923d.addTo(map_22e87fd82b3e27fbe28f85fa41530323);
#
#
#             var feature_group_sub_group_b1cf45470bb59d52796d80c85c6ff32b = L.featureGroup.subGroup(
#                 feature_group_2cb0cc7108b4a1bd9750123d80aa923d
#             );
#
#
#             var marker_a7a66b15d4000e08b6cc57116f8b918e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b1cf45470bb59d52796d80c85c6ff32b);
#
#
#         var popup_a5bf5457dbe7047b53507ae507eccd9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_538ac5f964b8d1aec5480d59e7434607 = $(`&lt;div id=&quot;html_538ac5f964b8d1aec5480d59e7434607&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a5bf5457dbe7047b53507ae507eccd9e.setContent(html_538ac5f964b8d1aec5480d59e7434607);
#
#
#
#         marker_a7a66b15d4000e08b6cc57116f8b918e.bindPopup(popup_a5bf5457dbe7047b53507ae507eccd9e)
#         ;
#
#
#
#
#             var marker_2538a502490aac8ea04d734d1c534814 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b1cf45470bb59d52796d80c85c6ff32b);
#
#
#         var popup_de55dd44164f7b1e2df97f326f4d1cd8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eaff8b9d7cf4bb9efc966bb82037b6ef = $(`&lt;div id=&quot;html_eaff8b9d7cf4bb9efc966bb82037b6ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_de55dd44164f7b1e2df97f326f4d1cd8.setContent(html_eaff8b9d7cf4bb9efc966bb82037b6ef);
#
#
#
#         marker_2538a502490aac8ea04d734d1c534814.bindPopup(popup_de55dd44164f7b1e2df97f326f4d1cd8)
#         ;
#
#
#
#
#             var marker_f3a44a17caffd859c83156a222507098 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b1cf45470bb59d52796d80c85c6ff32b);
#
#
#         var popup_9b850bbfa638630ded9ae6492bff90cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_090bc87ebbf2c80538f72fb69404d39c = $(`&lt;div id=&quot;html_090bc87ebbf2c80538f72fb69404d39c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9b850bbfa638630ded9ae6492bff90cc.setContent(html_090bc87ebbf2c80538f72fb69404d39c);
#
#
#
#         marker_f3a44a17caffd859c83156a222507098.bindPopup(popup_9b850bbfa638630ded9ae6492bff90cc)
#         ;
#
#
#
#
#             var marker_87de037f727860a1b30684c0eeefce04 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b1cf45470bb59d52796d80c85c6ff32b);
#
#
#         var popup_289afae1c4d68a6c4a0b16ec98f1d181 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_440d6ab7eefc6701b1b78d4ae19c01ca = $(`&lt;div id=&quot;html_440d6ab7eefc6701b1b78d4ae19c01ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_289afae1c4d68a6c4a0b16ec98f1d181.setContent(html_440d6ab7eefc6701b1b78d4ae19c01ca);
#
#
#
#         marker_
