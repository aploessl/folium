# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abad40162948e391dc21a01be253391b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abad40162948e391dc21a01be253391b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abad40162948e391dc21a01be253391b = L.map(
#                 &quot;map_abad40162948e391dc21a01be253391b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9bea4fe1f46a9537aae7275067bc895 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a9bea4fe1f46a9537aae7275067bc895.addTo(map_abad40162948e391dc21a01be253391b);
#
#
#             var marker_57d1dd39c65d3fe27d7a246b15c4ad3a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_abad40162948e391dc21a01be253391b);
#
#
#         var popup_3aa186b85a412550e39ae13bc3e8a75b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d69a2f06193bbe0e3eefcb5db80ff84c = $(`&lt;div id=&quot;html_d69a2f06193bbe0e3eefcb5db80ff84c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3aa186b85a412550e39ae13bc3e8a75b.setContent(html_d69a2f06193bbe0e3eefcb5db80ff84c);
#
#
#
#         marker_57d1dd39c65d3fe27d7a246b15c4ad3a.bindPopup(popup_3aa186b85a412550e39ae13bc3e8a75b)
#         ;
#
#
#
#
#             var marker_12c42060ad2b43a51f989253953401eb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_abad40162948e391dc21a01be253391b);
#
#
#         var popup_39c81ea24c9c2dda7af9c2c91227b02a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15d4fb99be99fdd498e1254c67866bb3 = $(`&lt;div id=&quot;html_15d4fb99be99fdd498e1254c67866bb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_39c81ea24c9c2dda7af9c2c91227b02a.setContent(html_15d4fb99be99fdd498e1254c67866bb3);
#
#
#
#         marker_12c42060ad2b43a51f989253953401eb.bindPopup(popup_39c81ea24c9c2dda7af9c2c91227b02a)
#         ;
#
#
#
#
#             var marker_d662939368894d4409bb3e7e0645c2ed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_abad40162948e391dc21a01be253391b);
#
#
#         var popup_7649b231e8e72e090eb5ebb148b05a7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba2d4daa18947cc0f6db0b3ac9ef66b5 = $(`&lt;div id=&quot;html_ba2d4daa18947cc0f6db0b3ac9ef66b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7649b231e8e72e090eb5ebb148b05a7f.setContent(html_ba2d4daa18947cc0f6db0b3ac9ef66b5);
#
#
#
#         marker_d662939368894d4409bb3e7e0645c2ed.bindPopup(popup_7649b231e8e72e090eb5ebb148b05a7f)
#         ;
#
#
#
#
#             var marker_49579ad5ea347dadd707605dbc0611b6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_abad40162948e391dc21a01be253391b);
#
#
#         var popup_2ea8a4e8c5cd05dd2a3fefaf6ae545ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e8534497b7f3614052e0853515144fe = $(`&lt;div id=&quot;html_7e8534497b7f3614052e0853515144fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2ea8a4e8c5cd05dd2a3fefaf6ae545ce.setContent(html_7e8534497b7f3614052e0853515144fe);
#
#
#
#         marker_49579ad5ea347dadd707605dbc0611b6.bindPopup(popup_2ea8a4e8c5cd05dd2a3fefaf6ae545ce)
#         ;
#
#
#
#
#             var marker_dfc3ee16329effe9fdb2a5d55cb81065 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_abad40162948e391dc21a01be253391b);
#
#
#         var popup_6c0b98ba74ff2276352422b3f12e2f5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa3cc50280d66ad57f911892bbf03e75 = $(`&lt;div id=&quot;html_fa3cc50280d66ad57f911892bbf03e75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6c0b98ba74ff2276352422b3f12e2f5e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a15d292e3b7396228841f4ebe446dec4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a15d292e3b7396228841f4ebe446dec4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a15d292e3b7396228841f4ebe446dec4 = L.map(
#                 &quot;map_a15d292e3b7396228841f4ebe446dec4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b40027862e78b555117e4fe305caea71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b40027862e78b555117e4fe305caea71.addTo(map_a15d292e3b7396228841f4ebe446dec4);
#
#
#             var feature_group_1f6a76e0898593dd66e957693f346f85 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a03e2c9b78bc00ab48fd12723f7f7562 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1f6a76e0898593dd66e957693f346f85);
#
#
#         var popup_121ba1191a5e61ab64ccc678bacb6d11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9eacb2ce1fa5ea979e11186d63914e6f = $(`&lt;div id=&quot;html_9eacb2ce1fa5ea979e11186d63914e6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_121ba1191a5e61ab64ccc678bacb6d11.setContent(html_9eacb2ce1fa5ea979e11186d63914e6f);
#
#
#
#         marker_a03e2c9b78bc00ab48fd12723f7f7562.bindPopup(popup_121ba1191a5e61ab64ccc678bacb6d11)
#         ;
#
#
#
#
#             var marker_b81f1df69135a8aa1e3f801ee5eca673 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1f6a76e0898593dd66e957693f346f85);
#
#
#         var popup_b70fb4be768013f3d16ad135d2975961 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_255cb3a02a2f9919ad7d606b037d9539 = $(`&lt;div id=&quot;html_255cb3a02a2f9919ad7d606b037d9539&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b70fb4be768013f3d16ad135d2975961.setContent(html_255cb3a02a2f9919ad7d606b037d9539);
#
#
#
#         marker_b81f1df69135a8aa1e3f801ee5eca673.bindPopup(popup_b70fb4be768013f3d16ad135d2975961)
#         ;
#
#
#
#
#             var marker_7c9ba6c9f2db433cc0e7b44c4db25ce4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1f6a76e0898593dd66e957693f346f85);
#
#
#         var popup_5404aea2d7c4cdf4fac755327f65275e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_700da1f67dfe6c3fa8d45548e6207bee = $(`&lt;div id=&quot;html_700da1f67dfe6c3fa8d45548e6207bee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5404aea2d7c4cdf4fac755327f65275e.setContent(html_700da1f67dfe6c3fa8d45548e6207bee);
#
#
#
#         marker_7c9ba6c9f2db433cc0e7b44c4db25ce4.bindPopup(popup_5404aea2d7c4cdf4fac755327f65275e)
#         ;
#
#
#
#
#             var marker_4d9adf3c873c6ff98fe6a1fbde8e4a56 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1f6a76e0898593dd66e957693f346f85);
#
#
#         var popup_d2438c1ca5989a0b6b3828e42f6f805e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa96eb4de658f66e1cd0870ada9ac2d2 = $(`&lt;div id=&quot;html_aa96eb4de658f66e1cd0870ada9ac2d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d2438c1ca5989a0b6b3828e42f6f805e.setContent(html_aa96eb4de658f66e1cd0870ada9ac2d2);
#
#
#
#         marker_4d9adf3c873c6ff98fe6a1fbde8e4a56.bindPopup(popup_d2438c1ca5989a0b6b3828e42f6f805e)
#         ;
#
#
#
#
#             var marker_cff4f52902222fa5876ff1bc26866b7e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1f6a76e0898593dd66e957693f346f85);
#
#
#         var popup_2152440d203ed7a26b2d758ff785c822 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_722e6d7db444fdd1102e1243fec91c24 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_722e6d7db444fdd1102e1243fec91c24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_722e6d7db444fdd1102e1243fec91c24 = L.map(
#                 &quot;map_722e6d7db444fdd1102e1243fec91c24&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4882e807cb339e93a10f1a8a8194a06 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d4882e807cb339e93a10f1a8a8194a06.addTo(map_722e6d7db444fdd1102e1243fec91c24);
#
#
#             var feature_group_bfea392dd4261c1a5c9b27a6ed8edff9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bfea392dd4261c1a5c9b27a6ed8edff9.addTo(map_722e6d7db444fdd1102e1243fec91c24);
#
#
#             var feature_group_sub_group_2faf667b91285ca9f177c2701d616cf9 = L.featureGroup.subGroup(
#                 feature_group_bfea392dd4261c1a5c9b27a6ed8edff9
#             );
#
#
#             var marker_9967cf07fdac1c209dbed7abc0172e1a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2faf667b91285ca9f177c2701d616cf9);
#
#
#         var popup_8e876e0352eb8e53ee80aefc15082147 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6be4dd2f7df0b37dfa8a75bb53e68afc = $(`&lt;div id=&quot;html_6be4dd2f7df0b37dfa8a75bb53e68afc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8e876e0352eb8e53ee80aefc15082147.setContent(html_6be4dd2f7df0b37dfa8a75bb53e68afc);
#
#
#
#         marker_9967cf07fdac1c209dbed7abc0172e1a.bindPopup(popup_8e876e0352eb8e53ee80aefc15082147)
#         ;
#
#
#
#
#             var marker_3b8410d78cfab250c21f4c96b73cc693 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2faf667b91285ca9f177c2701d616cf9);
#
#
#         var popup_cd3e45a9121ba96682622a90d62fdd1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0012d731553b739c3ff4d18942602f9 = $(`&lt;div id=&quot;html_e0012d731553b739c3ff4d18942602f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cd3e45a9121ba96682622a90d62fdd1a.setContent(html_e0012d731553b739c3ff4d18942602f9);
#
#
#
#         marker_3b8410d78cfab250c21f4c96b73cc693.bindPopup(popup_cd3e45a9121ba96682622a90d62fdd1a)
#         ;
#
#
#
#
#             var marker_49315854596f8835eebe615f8bf2ea88 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2faf667b91285ca9f177c2701d616cf9);
#
#
#         var popup_dc8ae43fffdd6b038cc6dceda71d0f76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b425c5f53b8991f90dd8f2a4fe66f3eb = $(`&lt;div id=&quot;html_b425c5f53b8991f90dd8f2a4fe66f3eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_dc8ae43fffdd6b038cc6dceda71d0f76.setContent(html_b425c5f53b8991f90dd8f2a4fe66f3eb);
#
#
#
#         marker_49315854596f8835eebe615f8bf2ea88.bindPopup(popup_dc8ae43fffdd6b038cc6dceda71d0f76)
#         ;
#
#
#
#
#             var marker_125c03284dd988d913ab44667b22ddb3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2faf667b91285ca9f177c2701d616cf9);
#
#
#         var popup_2e66eaa857c305af6fd9e215f6adb780 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16cc7f00968d52037dda294932d8d23e = $(`&lt;div id=&quot;html_16cc7f00968d52037dda294932d8d23e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2e66eaa857c305af6fd9e215f6adb780.setContent(html_16cc7f00968d52037dda294932d8d23e);
#
#
#
#         marker_
