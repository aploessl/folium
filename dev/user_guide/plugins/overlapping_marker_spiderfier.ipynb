# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_964905cde9a37d401419ad1c48803843 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_964905cde9a37d401419ad1c48803843&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_964905cde9a37d401419ad1c48803843 = L.map(
#                 &quot;map_964905cde9a37d401419ad1c48803843&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e34507783d03832139acbe9ea1aad4e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e34507783d03832139acbe9ea1aad4e3.addTo(map_964905cde9a37d401419ad1c48803843);
#
#
#             var marker_e231cc9984d61da0083a8f5b9d46ef63 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_964905cde9a37d401419ad1c48803843);
#
#
#         var popup_2fb699ff4359486cf0483120ff4ae7b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afa4fd8a863fb6b86876d7f954f0428a = $(`&lt;div id=&quot;html_afa4fd8a863fb6b86876d7f954f0428a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2fb699ff4359486cf0483120ff4ae7b8.setContent(html_afa4fd8a863fb6b86876d7f954f0428a);
#
#
#
#         marker_e231cc9984d61da0083a8f5b9d46ef63.bindPopup(popup_2fb699ff4359486cf0483120ff4ae7b8)
#         ;
#
#
#
#
#             var marker_44ec7a309a9f6999c96c960884fe0107 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_964905cde9a37d401419ad1c48803843);
#
#
#         var popup_377257567b3b4e65c96899016485d8a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f96aa5e0457f4d2188046060bf43810 = $(`&lt;div id=&quot;html_5f96aa5e0457f4d2188046060bf43810&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_377257567b3b4e65c96899016485d8a6.setContent(html_5f96aa5e0457f4d2188046060bf43810);
#
#
#
#         marker_44ec7a309a9f6999c96c960884fe0107.bindPopup(popup_377257567b3b4e65c96899016485d8a6)
#         ;
#
#
#
#
#             var marker_fba5b9da3fc8140055d9a139cdba5be4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_964905cde9a37d401419ad1c48803843);
#
#
#         var popup_62b209d468d18609d6ffc2c5b2714412 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a64a26b20cbca814341ac03aeb4deb40 = $(`&lt;div id=&quot;html_a64a26b20cbca814341ac03aeb4deb40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_62b209d468d18609d6ffc2c5b2714412.setContent(html_a64a26b20cbca814341ac03aeb4deb40);
#
#
#
#         marker_fba5b9da3fc8140055d9a139cdba5be4.bindPopup(popup_62b209d468d18609d6ffc2c5b2714412)
#         ;
#
#
#
#
#             var marker_3172a0cff82a56d548a40ce9dc21be28 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_964905cde9a37d401419ad1c48803843);
#
#
#         var popup_37c90e94a91930886b00d4f026b8fadc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b340fa3e968eb0b8d4d65a54d0f4de5 = $(`&lt;div id=&quot;html_9b340fa3e968eb0b8d4d65a54d0f4de5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_37c90e94a91930886b00d4f026b8fadc.setContent(html_9b340fa3e968eb0b8d4d65a54d0f4de5);
#
#
#
#         marker_3172a0cff82a56d548a40ce9dc21be28.bindPopup(popup_37c90e94a91930886b00d4f026b8fadc)
#         ;
#
#
#
#
#             var marker_15c7da251676eec32f684e29147c1ff9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_964905cde9a37d401419ad1c48803843);
#
#
#         var popup_c80b0f8e3f8f6320a2dc6043d1cba3b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5391cb194246b42df933b259d5f0aee7 = $(`&lt;div id=&quot;html_5391cb194246b42df933b259d5f0aee7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c80b0f8e3f8f6320a2dc6043d1cba3b0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07acdb1c4000c8fd83e2db87afc1ec56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07acdb1c4000c8fd83e2db87afc1ec56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07acdb1c4000c8fd83e2db87afc1ec56 = L.map(
#                 &quot;map_07acdb1c4000c8fd83e2db87afc1ec56&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6925ad2125f150c2aa2d3be865865602 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6925ad2125f150c2aa2d3be865865602.addTo(map_07acdb1c4000c8fd83e2db87afc1ec56);
#
#
#             var feature_group_826fada4ca1e7e636445a19e807ef0fe = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_17bcc99e59bd4867466ecb7a03e97ff7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_826fada4ca1e7e636445a19e807ef0fe);
#
#
#         var popup_2b99a72c06e596d5e972ce5083f8213c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89436b33f4c781c356e9a6c5e2684ff0 = $(`&lt;div id=&quot;html_89436b33f4c781c356e9a6c5e2684ff0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2b99a72c06e596d5e972ce5083f8213c.setContent(html_89436b33f4c781c356e9a6c5e2684ff0);
#
#
#
#         marker_17bcc99e59bd4867466ecb7a03e97ff7.bindPopup(popup_2b99a72c06e596d5e972ce5083f8213c)
#         ;
#
#
#
#
#             var marker_68b3ec4bd2545f9a1fb5e69649842f03 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_826fada4ca1e7e636445a19e807ef0fe);
#
#
#         var popup_c101ccc36c3387280781e91cddb6e07b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eae04e95c0a61a700d03c3c1af214e37 = $(`&lt;div id=&quot;html_eae04e95c0a61a700d03c3c1af214e37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c101ccc36c3387280781e91cddb6e07b.setContent(html_eae04e95c0a61a700d03c3c1af214e37);
#
#
#
#         marker_68b3ec4bd2545f9a1fb5e69649842f03.bindPopup(popup_c101ccc36c3387280781e91cddb6e07b)
#         ;
#
#
#
#
#             var marker_aff017758b7088f56887f4c4ab0e6f57 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_826fada4ca1e7e636445a19e807ef0fe);
#
#
#         var popup_42e9d3eb8fec43c7c6eaefd860c21918 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c240bf3b489935a0693473c0ca363282 = $(`&lt;div id=&quot;html_c240bf3b489935a0693473c0ca363282&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_42e9d3eb8fec43c7c6eaefd860c21918.setContent(html_c240bf3b489935a0693473c0ca363282);
#
#
#
#         marker_aff017758b7088f56887f4c4ab0e6f57.bindPopup(popup_42e9d3eb8fec43c7c6eaefd860c21918)
#         ;
#
#
#
#
#             var marker_bb302b0d1a0bd90f2f1f6a453ae987be = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_826fada4ca1e7e636445a19e807ef0fe);
#
#
#         var popup_dc51282739c62108f6d93a70d5168fbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_049d83adaadf3a64ef6e8a2465496e17 = $(`&lt;div id=&quot;html_049d83adaadf3a64ef6e8a2465496e17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_dc51282739c62108f6d93a70d5168fbd.setContent(html_049d83adaadf3a64ef6e8a2465496e17);
#
#
#
#         marker_bb302b0d1a0bd90f2f1f6a453ae987be.bindPopup(popup_dc51282739c62108f6d93a70d5168fbd)
#         ;
#
#
#
#
#             var marker_19365a90a96b9d82b44d819907732ad5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_826fada4ca1e7e636445a19e807ef0fe);
#
#
#         var popup_7565a256120cd77ff5b8ff82d68f7dc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b63caf49afcca71663d792dd47675e23 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b63caf49afcca71663d792dd47675e23&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b63caf49afcca71663d792dd47675e23 = L.map(
#                 &quot;map_b63caf49afcca71663d792dd47675e23&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ac32926663ce18fb162a16cde6caf09 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ac32926663ce18fb162a16cde6caf09.addTo(map_b63caf49afcca71663d792dd47675e23);
#
#
#             var feature_group_0787c5c418604d093209f059c6ed94c1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0787c5c418604d093209f059c6ed94c1.addTo(map_b63caf49afcca71663d792dd47675e23);
#
#
#             var feature_group_sub_group_39f478343afab1a21cc9078ca8738610 = L.featureGroup.subGroup(
#                 feature_group_0787c5c418604d093209f059c6ed94c1
#             );
#
#
#             var marker_12719a996f16b4dace580a9cc3284889 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_39f478343afab1a21cc9078ca8738610);
#
#
#         var popup_29eeeff1127355a15946e65980d6ae19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ab3049313afd9c70bb524634e28cf53 = $(`&lt;div id=&quot;html_2ab3049313afd9c70bb524634e28cf53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_29eeeff1127355a15946e65980d6ae19.setContent(html_2ab3049313afd9c70bb524634e28cf53);
#
#
#
#         marker_12719a996f16b4dace580a9cc3284889.bindPopup(popup_29eeeff1127355a15946e65980d6ae19)
#         ;
#
#
#
#
#             var marker_8daa5c2dd213f989790b485aa10bb325 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_39f478343afab1a21cc9078ca8738610);
#
#
#         var popup_80dcfde6832b40a96cddd22ed33f0586 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5715783209ff0a81b306e1f1dc9d565 = $(`&lt;div id=&quot;html_e5715783209ff0a81b306e1f1dc9d565&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_80dcfde6832b40a96cddd22ed33f0586.setContent(html_e5715783209ff0a81b306e1f1dc9d565);
#
#
#
#         marker_8daa5c2dd213f989790b485aa10bb325.bindPopup(popup_80dcfde6832b40a96cddd22ed33f0586)
#         ;
#
#
#
#
#             var marker_6f08d19e0cc06660a22d0b1f682da9da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_39f478343afab1a21cc9078ca8738610);
#
#
#         var popup_c99f4616f88de0182a9e6fb6b44c0ab4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0173192ad4039e4c0454322b41de8e27 = $(`&lt;div id=&quot;html_0173192ad4039e4c0454322b41de8e27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c99f4616f88de0182a9e6fb6b44c0ab4.setContent(html_0173192ad4039e4c0454322b41de8e27);
#
#
#
#         marker_6f08d19e0cc06660a22d0b1f682da9da.bindPopup(popup_c99f4616f88de0182a9e6fb6b44c0ab4)
#         ;
#
#
#
#
#             var marker_4496e37dae73ff250b5b9b8705cf16c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_39f478343afab1a21cc9078ca8738610);
#
#
#         var popup_feb99ea320728a4c1e146bcf946a4a7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e55f085debeae6ac0f8d2f4ada568d90 = $(`&lt;div id=&quot;html_e55f085debeae6ac0f8d2f4ada568d90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_feb99ea320728a4c1e146bcf946a4a7c.setContent(html_e55f085debeae6ac0f8d2f4ada568d90);
#
#
#
#         marker_
