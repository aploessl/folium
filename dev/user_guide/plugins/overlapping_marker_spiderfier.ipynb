# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_059f4007bccb38858ab27e2024544c1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_059f4007bccb38858ab27e2024544c1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_059f4007bccb38858ab27e2024544c1c = L.map(
#                 &quot;map_059f4007bccb38858ab27e2024544c1c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c54ce7dc7f620fd89bba5998999b14a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0c54ce7dc7f620fd89bba5998999b14a.addTo(map_059f4007bccb38858ab27e2024544c1c);
#
#
#             var marker_78c24f2bde0996afe09aa8417852da0c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_059f4007bccb38858ab27e2024544c1c);
#
#
#         var popup_d19bae411ef2f3103d0470850fc55387 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d81cbd2ba6d939f686861b7c846cbf7 = $(`&lt;div id=&quot;html_6d81cbd2ba6d939f686861b7c846cbf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d19bae411ef2f3103d0470850fc55387.setContent(html_6d81cbd2ba6d939f686861b7c846cbf7);
#
#
#
#         marker_78c24f2bde0996afe09aa8417852da0c.bindPopup(popup_d19bae411ef2f3103d0470850fc55387)
#         ;
#
#
#
#
#             var marker_0024c6eda964930c7d4ee87d8df09610 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_059f4007bccb38858ab27e2024544c1c);
#
#
#         var popup_5e9aeebd8c9a7c4c1dc2ee163d3c8aff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10ea8a22930b56350e805c928d4f7846 = $(`&lt;div id=&quot;html_10ea8a22930b56350e805c928d4f7846&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5e9aeebd8c9a7c4c1dc2ee163d3c8aff.setContent(html_10ea8a22930b56350e805c928d4f7846);
#
#
#
#         marker_0024c6eda964930c7d4ee87d8df09610.bindPopup(popup_5e9aeebd8c9a7c4c1dc2ee163d3c8aff)
#         ;
#
#
#
#
#             var marker_59ef225840a98a0e6981481362effe68 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_059f4007bccb38858ab27e2024544c1c);
#
#
#         var popup_1d102cc2ecb0db82103babca3ca6a925 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb293b5106f5a42cfb5abed9a9bd7f7c = $(`&lt;div id=&quot;html_fb293b5106f5a42cfb5abed9a9bd7f7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1d102cc2ecb0db82103babca3ca6a925.setContent(html_fb293b5106f5a42cfb5abed9a9bd7f7c);
#
#
#
#         marker_59ef225840a98a0e6981481362effe68.bindPopup(popup_1d102cc2ecb0db82103babca3ca6a925)
#         ;
#
#
#
#
#             var marker_f6231d99a1725ee0781caebdf0a1f416 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_059f4007bccb38858ab27e2024544c1c);
#
#
#         var popup_e22113cd1eb2ec73985369bf707222f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebdd00705a52f0d774bea836549511f2 = $(`&lt;div id=&quot;html_ebdd00705a52f0d774bea836549511f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e22113cd1eb2ec73985369bf707222f1.setContent(html_ebdd00705a52f0d774bea836549511f2);
#
#
#
#         marker_f6231d99a1725ee0781caebdf0a1f416.bindPopup(popup_e22113cd1eb2ec73985369bf707222f1)
#         ;
#
#
#
#
#             var marker_8b097ba73c7b4b83dcc5b9e8e9e3055f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_059f4007bccb38858ab27e2024544c1c);
#
#
#         var popup_a7d7a23f2dbd741d8c0b5870b32964bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c700cce094704a6887c0857aadce8ff6 = $(`&lt;div id=&quot;html_c700cce094704a6887c0857aadce8ff6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a7d7a23f2dbd741d8c0b5870b32964bb.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f88a2dc02ea5715bf2d56065a5d81f72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f88a2dc02ea5715bf2d56065a5d81f72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f88a2dc02ea5715bf2d56065a5d81f72 = L.map(
#                 &quot;map_f88a2dc02ea5715bf2d56065a5d81f72&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc0d57891872a53ac660d37bb193921c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dc0d57891872a53ac660d37bb193921c.addTo(map_f88a2dc02ea5715bf2d56065a5d81f72);
#
#
#             var feature_group_308b1c90a751120e2f3f0ad0fb2ac8a7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_28726157d5bea9e42d6b89915ba3c3dc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_308b1c90a751120e2f3f0ad0fb2ac8a7);
#
#
#         var popup_1121ee85ca5724f5346f6d699d33f737 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_456ea3e4bcf111e0c2130adbbf8afa52 = $(`&lt;div id=&quot;html_456ea3e4bcf111e0c2130adbbf8afa52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1121ee85ca5724f5346f6d699d33f737.setContent(html_456ea3e4bcf111e0c2130adbbf8afa52);
#
#
#
#         marker_28726157d5bea9e42d6b89915ba3c3dc.bindPopup(popup_1121ee85ca5724f5346f6d699d33f737)
#         ;
#
#
#
#
#             var marker_0db2dbf964915beddf057359f48f3df3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_308b1c90a751120e2f3f0ad0fb2ac8a7);
#
#
#         var popup_65e4b5fb5d0fc3839e68d591ddaf32ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ed32832b7ee887a0019d8fec09d9b89 = $(`&lt;div id=&quot;html_7ed32832b7ee887a0019d8fec09d9b89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_65e4b5fb5d0fc3839e68d591ddaf32ff.setContent(html_7ed32832b7ee887a0019d8fec09d9b89);
#
#
#
#         marker_0db2dbf964915beddf057359f48f3df3.bindPopup(popup_65e4b5fb5d0fc3839e68d591ddaf32ff)
#         ;
#
#
#
#
#             var marker_21a57648cb527b59f74fb0d81fd091db = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_308b1c90a751120e2f3f0ad0fb2ac8a7);
#
#
#         var popup_71081a242b271f639e4e9683f5a97126 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_341014eadf06e163ff11a76f7a72f880 = $(`&lt;div id=&quot;html_341014eadf06e163ff11a76f7a72f880&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_71081a242b271f639e4e9683f5a97126.setContent(html_341014eadf06e163ff11a76f7a72f880);
#
#
#
#         marker_21a57648cb527b59f74fb0d81fd091db.bindPopup(popup_71081a242b271f639e4e9683f5a97126)
#         ;
#
#
#
#
#             var marker_5bed6969af36971e65322196cc1ead4f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_308b1c90a751120e2f3f0ad0fb2ac8a7);
#
#
#         var popup_5058fe044b35604c370242e36d88bb49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_924416dae17c962619364802e3884017 = $(`&lt;div id=&quot;html_924416dae17c962619364802e3884017&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5058fe044b35604c370242e36d88bb49.setContent(html_924416dae17c962619364802e3884017);
#
#
#
#         marker_5bed6969af36971e65322196cc1ead4f.bindPopup(popup_5058fe044b35604c370242e36d88bb49)
#         ;
#
#
#
#
#             var marker_4ec493d8e2ad0f7565dbf2cba55aa466 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_308b1c90a751120e2f3f0ad0fb2ac8a7);
#
#
#         var popup_81640f36b66122c4f72c61e5e49e0400 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e5c9105f7845ac014178ef3aafbdb69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e5c9105f7845ac014178ef3aafbdb69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e5c9105f7845ac014178ef3aafbdb69 = L.map(
#                 &quot;map_9e5c9105f7845ac014178ef3aafbdb69&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3fed5c206a51dbba2578d199d1fdb05d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3fed5c206a51dbba2578d199d1fdb05d.addTo(map_9e5c9105f7845ac014178ef3aafbdb69);
#
#
#             var feature_group_0a7bedd86ee25bd34d7c2f4edf001691 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0a7bedd86ee25bd34d7c2f4edf001691.addTo(map_9e5c9105f7845ac014178ef3aafbdb69);
#
#
#             var feature_group_sub_group_146ae3a3e4572eef6e5fdc6638aabb4f = L.featureGroup.subGroup(
#                 feature_group_0a7bedd86ee25bd34d7c2f4edf001691
#             );
#
#
#             var marker_9990302479381e1e361a3090773c2892 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_146ae3a3e4572eef6e5fdc6638aabb4f);
#
#
#         var popup_14efc643227391b502b49df308e03c87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1be0cb9126bca0d6d562b99c8031d2d = $(`&lt;div id=&quot;html_c1be0cb9126bca0d6d562b99c8031d2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_14efc643227391b502b49df308e03c87.setContent(html_c1be0cb9126bca0d6d562b99c8031d2d);
#
#
#
#         marker_9990302479381e1e361a3090773c2892.bindPopup(popup_14efc643227391b502b49df308e03c87)
#         ;
#
#
#
#
#             var marker_660c09122502f857374c8e0909c3bdcd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_146ae3a3e4572eef6e5fdc6638aabb4f);
#
#
#         var popup_81545fee58977a31b90b6ad9fbc0bd0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b42c6407a37437432be943c280efd5e = $(`&lt;div id=&quot;html_8b42c6407a37437432be943c280efd5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_81545fee58977a31b90b6ad9fbc0bd0c.setContent(html_8b42c6407a37437432be943c280efd5e);
#
#
#
#         marker_660c09122502f857374c8e0909c3bdcd.bindPopup(popup_81545fee58977a31b90b6ad9fbc0bd0c)
#         ;
#
#
#
#
#             var marker_f07c991e14c2ad510281145c8aa0243e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_146ae3a3e4572eef6e5fdc6638aabb4f);
#
#
#         var popup_a399ac02c9324be1044429b095f19451 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2ca71aa81dc65b6c595917a4718e0f4 = $(`&lt;div id=&quot;html_e2ca71aa81dc65b6c595917a4718e0f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a399ac02c9324be1044429b095f19451.setContent(html_e2ca71aa81dc65b6c595917a4718e0f4);
#
#
#
#         marker_f07c991e14c2ad510281145c8aa0243e.bindPopup(popup_a399ac02c9324be1044429b095f19451)
#         ;
#
#
#
#
#             var marker_c63f7c1e6992c6e4db1fd14f8d6cd750 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_146ae3a3e4572eef6e5fdc6638aabb4f);
#
#
#         var popup_6516cbb95a9e68ada70acaed32411aee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a17f86c2eceef71d4202fcc1a726c13 = $(`&lt;div id=&quot;html_2a17f86c2eceef71d4202fcc1a726c13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6516cbb95a9e68ada70acaed32411aee.setContent(html_2a17f86c2eceef71d4202fcc1a726c13);
#
#
#
#         marker_
