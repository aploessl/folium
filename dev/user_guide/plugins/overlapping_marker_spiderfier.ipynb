# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6ba93318c46fadac7c8f344509cba59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6ba93318c46fadac7c8f344509cba59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6ba93318c46fadac7c8f344509cba59 = L.map(
#                 &quot;map_b6ba93318c46fadac7c8f344509cba59&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60747758c5a807fe47c5bd8b91687d1d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_60747758c5a807fe47c5bd8b91687d1d.addTo(map_b6ba93318c46fadac7c8f344509cba59);
#
#
#             var marker_03a9adc5945bc2b06acc89dabdfad1fd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b6ba93318c46fadac7c8f344509cba59);
#
#
#         var popup_8941391b2cb4c2d0f4668b2b3f57793a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4991c14dc323854dd3ead85d7f0a18c = $(`&lt;div id=&quot;html_a4991c14dc323854dd3ead85d7f0a18c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8941391b2cb4c2d0f4668b2b3f57793a.setContent(html_a4991c14dc323854dd3ead85d7f0a18c);
#
#
#
#         marker_03a9adc5945bc2b06acc89dabdfad1fd.bindPopup(popup_8941391b2cb4c2d0f4668b2b3f57793a)
#         ;
#
#
#
#
#             var marker_527e717fceab0ab134e80ea5b824005e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b6ba93318c46fadac7c8f344509cba59);
#
#
#         var popup_f10614c10626a6c5e8ebe3739641793f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0ccc6b795f84d510577accba2f88941 = $(`&lt;div id=&quot;html_c0ccc6b795f84d510577accba2f88941&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f10614c10626a6c5e8ebe3739641793f.setContent(html_c0ccc6b795f84d510577accba2f88941);
#
#
#
#         marker_527e717fceab0ab134e80ea5b824005e.bindPopup(popup_f10614c10626a6c5e8ebe3739641793f)
#         ;
#
#
#
#
#             var marker_742ffeeaf520bb027fb35aa36df0dbfa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b6ba93318c46fadac7c8f344509cba59);
#
#
#         var popup_75473c4b6a776e15025727dba05a6dae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db9cdec44d769a085bd790957fb5dfcf = $(`&lt;div id=&quot;html_db9cdec44d769a085bd790957fb5dfcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_75473c4b6a776e15025727dba05a6dae.setContent(html_db9cdec44d769a085bd790957fb5dfcf);
#
#
#
#         marker_742ffeeaf520bb027fb35aa36df0dbfa.bindPopup(popup_75473c4b6a776e15025727dba05a6dae)
#         ;
#
#
#
#
#             var marker_20ba8548e46a5f0f1caf6b96a73d224e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b6ba93318c46fadac7c8f344509cba59);
#
#
#         var popup_4405987706d8e6bf8fecab26b07437d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e633eff139306e490e4f8af41a4e17f = $(`&lt;div id=&quot;html_9e633eff139306e490e4f8af41a4e17f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4405987706d8e6bf8fecab26b07437d8.setContent(html_9e633eff139306e490e4f8af41a4e17f);
#
#
#
#         marker_20ba8548e46a5f0f1caf6b96a73d224e.bindPopup(popup_4405987706d8e6bf8fecab26b07437d8)
#         ;
#
#
#
#
#             var marker_03c8aef45024dc95f881f21d0a032bad = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b6ba93318c46fadac7c8f344509cba59);
#
#
#         var popup_274efa7d023dd2815e911178b40ddc0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea725dc1a439e46a761a0f34691b4e6b = $(`&lt;div id=&quot;html_ea725dc1a439e46a761a0f34691b4e6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_274efa7d023dd2815e911178b40ddc0e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5dcacec7c5b2ab2854e2a3e273817df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5dcacec7c5b2ab2854e2a3e273817df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5dcacec7c5b2ab2854e2a3e273817df = L.map(
#                 &quot;map_b5dcacec7c5b2ab2854e2a3e273817df&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f505443f723c865084835f616e0e27f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f505443f723c865084835f616e0e27f.addTo(map_b5dcacec7c5b2ab2854e2a3e273817df);
#
#
#             var feature_group_4d4a6e4d662a53e5f13fd6dd31ee68ec = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_21e34205281770a8863b754d4ade0105 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4d4a6e4d662a53e5f13fd6dd31ee68ec);
#
#
#         var popup_aad84ec4e80d8833b9f16b1e5ce0c8ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f0ad7867a7071973f17a0e789b88a24 = $(`&lt;div id=&quot;html_1f0ad7867a7071973f17a0e789b88a24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_aad84ec4e80d8833b9f16b1e5ce0c8ad.setContent(html_1f0ad7867a7071973f17a0e789b88a24);
#
#
#
#         marker_21e34205281770a8863b754d4ade0105.bindPopup(popup_aad84ec4e80d8833b9f16b1e5ce0c8ad)
#         ;
#
#
#
#
#             var marker_7595def8c2abaad125091bb4a4bd0f1c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4d4a6e4d662a53e5f13fd6dd31ee68ec);
#
#
#         var popup_6d9d99d7b7a304f5a80cb56a37c909f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b100adf90bb051aa97df78fcf8749b91 = $(`&lt;div id=&quot;html_b100adf90bb051aa97df78fcf8749b91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6d9d99d7b7a304f5a80cb56a37c909f5.setContent(html_b100adf90bb051aa97df78fcf8749b91);
#
#
#
#         marker_7595def8c2abaad125091bb4a4bd0f1c.bindPopup(popup_6d9d99d7b7a304f5a80cb56a37c909f5)
#         ;
#
#
#
#
#             var marker_98a9b5aeab7408bf26bb90ea704f3505 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4d4a6e4d662a53e5f13fd6dd31ee68ec);
#
#
#         var popup_79bb9b160e5dbf2331a68ae3cf780c57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66b8592eb3759edec13d6c36f18943b6 = $(`&lt;div id=&quot;html_66b8592eb3759edec13d6c36f18943b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_79bb9b160e5dbf2331a68ae3cf780c57.setContent(html_66b8592eb3759edec13d6c36f18943b6);
#
#
#
#         marker_98a9b5aeab7408bf26bb90ea704f3505.bindPopup(popup_79bb9b160e5dbf2331a68ae3cf780c57)
#         ;
#
#
#
#
#             var marker_d9057f9206fdb3d686d4a2db2397b759 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4d4a6e4d662a53e5f13fd6dd31ee68ec);
#
#
#         var popup_d7260796c40f2bd5e171c22bad097b3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3c524bb190bffd2e1288dae6829650a = $(`&lt;div id=&quot;html_a3c524bb190bffd2e1288dae6829650a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d7260796c40f2bd5e171c22bad097b3e.setContent(html_a3c524bb190bffd2e1288dae6829650a);
#
#
#
#         marker_d9057f9206fdb3d686d4a2db2397b759.bindPopup(popup_d7260796c40f2bd5e171c22bad097b3e)
#         ;
#
#
#
#
#             var marker_916cf14daf292d879d7a92312c41fad0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4d4a6e4d662a53e5f13fd6dd31ee68ec);
#
#
#         var popup_758289f1516818b490ec2a13f0659662 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d3c844f899460d5d9b48379bafbc254 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d3c844f899460d5d9b48379bafbc254&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d3c844f899460d5d9b48379bafbc254 = L.map(
#                 &quot;map_7d3c844f899460d5d9b48379bafbc254&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba23264803cdc5996b9ea37fe69cc236 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba23264803cdc5996b9ea37fe69cc236.addTo(map_7d3c844f899460d5d9b48379bafbc254);
#
#
#             var feature_group_62f0f8dbc5aec2b953719a161e2d19e2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_62f0f8dbc5aec2b953719a161e2d19e2.addTo(map_7d3c844f899460d5d9b48379bafbc254);
#
#
#             var feature_group_sub_group_fc4cf8e322202dbc28c0723536123879 = L.featureGroup.subGroup(
#                 feature_group_62f0f8dbc5aec2b953719a161e2d19e2
#             );
#
#
#             var marker_7b19e7451fec08713e59942fa8745a55 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fc4cf8e322202dbc28c0723536123879);
#
#
#         var popup_c81504fd08d4168428dab88e23a2abeb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3816f7c403f223f066b11b44f5450410 = $(`&lt;div id=&quot;html_3816f7c403f223f066b11b44f5450410&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c81504fd08d4168428dab88e23a2abeb.setContent(html_3816f7c403f223f066b11b44f5450410);
#
#
#
#         marker_7b19e7451fec08713e59942fa8745a55.bindPopup(popup_c81504fd08d4168428dab88e23a2abeb)
#         ;
#
#
#
#
#             var marker_ac739018a441a9b17c1bb7fe5f5aae08 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fc4cf8e322202dbc28c0723536123879);
#
#
#         var popup_a2a830a11a6ab0bc4aeba1cf71a0bf3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27fdc9ef58e3a0f855544c424db1eba2 = $(`&lt;div id=&quot;html_27fdc9ef58e3a0f855544c424db1eba2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a2a830a11a6ab0bc4aeba1cf71a0bf3d.setContent(html_27fdc9ef58e3a0f855544c424db1eba2);
#
#
#
#         marker_ac739018a441a9b17c1bb7fe5f5aae08.bindPopup(popup_a2a830a11a6ab0bc4aeba1cf71a0bf3d)
#         ;
#
#
#
#
#             var marker_2bdec91cc42e99d2c6ac1315f17ea357 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fc4cf8e322202dbc28c0723536123879);
#
#
#         var popup_7ae4b31fa6f3e15e2e938c67dfeb5a08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17686c6848f47adab5186d4075f26dab = $(`&lt;div id=&quot;html_17686c6848f47adab5186d4075f26dab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7ae4b31fa6f3e15e2e938c67dfeb5a08.setContent(html_17686c6848f47adab5186d4075f26dab);
#
#
#
#         marker_2bdec91cc42e99d2c6ac1315f17ea357.bindPopup(popup_7ae4b31fa6f3e15e2e938c67dfeb5a08)
#         ;
#
#
#
#
#             var marker_fbed95ac679849e2d7a3a9d4cf667ca1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fc4cf8e322202dbc28c0723536123879);
#
#
#         var popup_22325bd517e7fe2d9d55a47dffb2504e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb17ef9cb5c013c1e632977332bfccf9 = $(`&lt;div id=&quot;html_fb17ef9cb5c013c1e632977332bfccf9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_22325bd517e7fe2d9d55a47dffb2504e.setContent(html_fb17ef9cb5c013c1e632977332bfccf9);
#
#
#
#         marker_
