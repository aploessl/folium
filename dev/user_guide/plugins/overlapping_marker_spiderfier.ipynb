# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e15ed3a72035daaffc253417e1b42142 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e15ed3a72035daaffc253417e1b42142&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e15ed3a72035daaffc253417e1b42142 = L.map(
#                 &quot;map_e15ed3a72035daaffc253417e1b42142&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f6ce83f3cb5a6d5f65db887593471bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5f6ce83f3cb5a6d5f65db887593471bf.addTo(map_e15ed3a72035daaffc253417e1b42142);
#
#
#             var marker_dd38d63b616af574d89467586c31122f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e15ed3a72035daaffc253417e1b42142);
#
#
#         var popup_61dc17700f62e9890da8b4c64469534d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6678b69d38fcb87d4ef8180d2da843ef = $(`&lt;div id=&quot;html_6678b69d38fcb87d4ef8180d2da843ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_61dc17700f62e9890da8b4c64469534d.setContent(html_6678b69d38fcb87d4ef8180d2da843ef);
#
#
#
#         marker_dd38d63b616af574d89467586c31122f.bindPopup(popup_61dc17700f62e9890da8b4c64469534d)
#         ;
#
#
#
#
#             var marker_3e536ed18861b1d25d531d5bfba81dd6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e15ed3a72035daaffc253417e1b42142);
#
#
#         var popup_b10f536b94f05b987cb05b99ac83d84c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5482f62f01676a31c58c2c29a8d73c93 = $(`&lt;div id=&quot;html_5482f62f01676a31c58c2c29a8d73c93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b10f536b94f05b987cb05b99ac83d84c.setContent(html_5482f62f01676a31c58c2c29a8d73c93);
#
#
#
#         marker_3e536ed18861b1d25d531d5bfba81dd6.bindPopup(popup_b10f536b94f05b987cb05b99ac83d84c)
#         ;
#
#
#
#
#             var marker_857374dd6f2ae0bc19f88a2cc4437b9a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e15ed3a72035daaffc253417e1b42142);
#
#
#         var popup_df1bf89bdeeb9a12c5737dbab39260fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2004af95dfad1802884740a3f046a29 = $(`&lt;div id=&quot;html_c2004af95dfad1802884740a3f046a29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_df1bf89bdeeb9a12c5737dbab39260fb.setContent(html_c2004af95dfad1802884740a3f046a29);
#
#
#
#         marker_857374dd6f2ae0bc19f88a2cc4437b9a.bindPopup(popup_df1bf89bdeeb9a12c5737dbab39260fb)
#         ;
#
#
#
#
#             var marker_ff0b498ad5ea06f6cc1ca8bb07b26cf1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e15ed3a72035daaffc253417e1b42142);
#
#
#         var popup_546e58260dc402a6b245d1aee91e1b14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b847f766203f5cd0a6237bf4b4961e24 = $(`&lt;div id=&quot;html_b847f766203f5cd0a6237bf4b4961e24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_546e58260dc402a6b245d1aee91e1b14.setContent(html_b847f766203f5cd0a6237bf4b4961e24);
#
#
#
#         marker_ff0b498ad5ea06f6cc1ca8bb07b26cf1.bindPopup(popup_546e58260dc402a6b245d1aee91e1b14)
#         ;
#
#
#
#
#             var marker_e233269bb837c3d101f7a3e443e0558a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e15ed3a72035daaffc253417e1b42142);
#
#
#         var popup_08ba622328f0372e8e4a4f6a8fba704f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ceeee9ca9ca21d276b47a03c2d44538d = $(`&lt;div id=&quot;html_ceeee9ca9ca21d276b47a03c2d44538d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_08ba622328f0372e8e4a4f6a8fba704f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_433061c421c4551d37f448062d3dcd57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_433061c421c4551d37f448062d3dcd57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_433061c421c4551d37f448062d3dcd57 = L.map(
#                 &quot;map_433061c421c4551d37f448062d3dcd57&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc5d3d32a7ff9b0f240bcc1a00964f68 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fc5d3d32a7ff9b0f240bcc1a00964f68.addTo(map_433061c421c4551d37f448062d3dcd57);
#
#
#             var feature_group_1db40ef9b121698021aa6c272a027e70 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bd07cb2615b42fd0b891e7d681c43429 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1db40ef9b121698021aa6c272a027e70);
#
#
#         var popup_ca230eba8bc25de3b7ba1cb91d7295f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e00d2c875eb4649e75f528cd70eac7ff = $(`&lt;div id=&quot;html_e00d2c875eb4649e75f528cd70eac7ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ca230eba8bc25de3b7ba1cb91d7295f8.setContent(html_e00d2c875eb4649e75f528cd70eac7ff);
#
#
#
#         marker_bd07cb2615b42fd0b891e7d681c43429.bindPopup(popup_ca230eba8bc25de3b7ba1cb91d7295f8)
#         ;
#
#
#
#
#             var marker_06404a87f3f7df9ef80d9d533ad2827c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1db40ef9b121698021aa6c272a027e70);
#
#
#         var popup_3739c2f1dd6078a434a44a1151a8492a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b608f4124f9ce74b683e0830c261c38f = $(`&lt;div id=&quot;html_b608f4124f9ce74b683e0830c261c38f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3739c2f1dd6078a434a44a1151a8492a.setContent(html_b608f4124f9ce74b683e0830c261c38f);
#
#
#
#         marker_06404a87f3f7df9ef80d9d533ad2827c.bindPopup(popup_3739c2f1dd6078a434a44a1151a8492a)
#         ;
#
#
#
#
#             var marker_ff2539b03fd816e6d7bd158c0ceb3585 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1db40ef9b121698021aa6c272a027e70);
#
#
#         var popup_b8a0bd7e238b03db2efb4d0fbbab4ae1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e96ee81caba8f0cda6963a8c954073c4 = $(`&lt;div id=&quot;html_e96ee81caba8f0cda6963a8c954073c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b8a0bd7e238b03db2efb4d0fbbab4ae1.setContent(html_e96ee81caba8f0cda6963a8c954073c4);
#
#
#
#         marker_ff2539b03fd816e6d7bd158c0ceb3585.bindPopup(popup_b8a0bd7e238b03db2efb4d0fbbab4ae1)
#         ;
#
#
#
#
#             var marker_2124d4c3e522abbe96f39ce0669c4346 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1db40ef9b121698021aa6c272a027e70);
#
#
#         var popup_8dda1773da6de41c23030f5c33bf76b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_420539e3024014fb222640d342d9d9f7 = $(`&lt;div id=&quot;html_420539e3024014fb222640d342d9d9f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8dda1773da6de41c23030f5c33bf76b2.setContent(html_420539e3024014fb222640d342d9d9f7);
#
#
#
#         marker_2124d4c3e522abbe96f39ce0669c4346.bindPopup(popup_8dda1773da6de41c23030f5c33bf76b2)
#         ;
#
#
#
#
#             var marker_00d35505c5c1e099864c723f67ea48a2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1db40ef9b121698021aa6c272a027e70);
#
#
#         var popup_331476d78be91aa7e62a104aaf30e91c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f97c269a5e1a414633dad28e0d73746d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f97c269a5e1a414633dad28e0d73746d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f97c269a5e1a414633dad28e0d73746d = L.map(
#                 &quot;map_f97c269a5e1a414633dad28e0d73746d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03352d57df3a1c5aad940bc71d27960d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_03352d57df3a1c5aad940bc71d27960d.addTo(map_f97c269a5e1a414633dad28e0d73746d);
#
#
#             var feature_group_1ac494170ed3a30ab2f943b09ddf2c8f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1ac494170ed3a30ab2f943b09ddf2c8f.addTo(map_f97c269a5e1a414633dad28e0d73746d);
#
#
#             var feature_group_sub_group_bc1d744042d7d92f9d51791da48189a9 = L.featureGroup.subGroup(
#                 feature_group_1ac494170ed3a30ab2f943b09ddf2c8f
#             );
#
#
#             var marker_e41d4388fa1d01aa2693878473fe50f6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bc1d744042d7d92f9d51791da48189a9);
#
#
#         var popup_3255696b27b518bb22ed3040d0953ec1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d55c2d8eeebe0259bd40cc1afcdf9b5d = $(`&lt;div id=&quot;html_d55c2d8eeebe0259bd40cc1afcdf9b5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3255696b27b518bb22ed3040d0953ec1.setContent(html_d55c2d8eeebe0259bd40cc1afcdf9b5d);
#
#
#
#         marker_e41d4388fa1d01aa2693878473fe50f6.bindPopup(popup_3255696b27b518bb22ed3040d0953ec1)
#         ;
#
#
#
#
#             var marker_8c5ee09f89423419af7e2b709630b366 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bc1d744042d7d92f9d51791da48189a9);
#
#
#         var popup_903e238f485bea08a41591beb435b8e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16eee3d86a3744836cb82bdba7ff375a = $(`&lt;div id=&quot;html_16eee3d86a3744836cb82bdba7ff375a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_903e238f485bea08a41591beb435b8e0.setContent(html_16eee3d86a3744836cb82bdba7ff375a);
#
#
#
#         marker_8c5ee09f89423419af7e2b709630b366.bindPopup(popup_903e238f485bea08a41591beb435b8e0)
#         ;
#
#
#
#
#             var marker_a77f6c81a3caae3408fd2487a33c48ef = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bc1d744042d7d92f9d51791da48189a9);
#
#
#         var popup_fb407eb919d2428a521ee10d4a55956b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_324cab9323f159e4df384ff3edbe639e = $(`&lt;div id=&quot;html_324cab9323f159e4df384ff3edbe639e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fb407eb919d2428a521ee10d4a55956b.setContent(html_324cab9323f159e4df384ff3edbe639e);
#
#
#
#         marker_a77f6c81a3caae3408fd2487a33c48ef.bindPopup(popup_fb407eb919d2428a521ee10d4a55956b)
#         ;
#
#
#
#
#             var marker_c926e5dee293296868efcc62f0a54fa5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bc1d744042d7d92f9d51791da48189a9);
#
#
#         var popup_af50f84ae304d7caa67a98ab8460d69f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15c79b0d4c20fc50ec88122449a96775 = $(`&lt;div id=&quot;html_15c79b0d4c20fc50ec88122449a96775&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_af50f84ae304d7caa67a98ab8460d69f.setContent(html_15c79b0d4c20fc50ec88122449a96775);
#
#
#
#         marker_
