# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1b6e36fba502dbe0f5e185b7391e07a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1b6e36fba502dbe0f5e185b7391e07a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1b6e36fba502dbe0f5e185b7391e07a = L.map(
#                 &quot;map_f1b6e36fba502dbe0f5e185b7391e07a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a29c24612b1cfc44a7d7e9eab40af0b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a29c24612b1cfc44a7d7e9eab40af0b.addTo(map_f1b6e36fba502dbe0f5e185b7391e07a);
#
#
#             var marker_bfbfd8b84f87530ec65d7a14d23d8d8e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f1b6e36fba502dbe0f5e185b7391e07a);
#
#
#         var popup_b1b4e095fd8e7fcd48475f013e8d05d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fae21b9701c14036d2acd6e284a61b45 = $(`&lt;div id=&quot;html_fae21b9701c14036d2acd6e284a61b45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b1b4e095fd8e7fcd48475f013e8d05d6.setContent(html_fae21b9701c14036d2acd6e284a61b45);
#
#
#
#         marker_bfbfd8b84f87530ec65d7a14d23d8d8e.bindPopup(popup_b1b4e095fd8e7fcd48475f013e8d05d6)
#         ;
#
#
#
#
#             var marker_c6c90d40f490fe836b7fa99735476e5c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f1b6e36fba502dbe0f5e185b7391e07a);
#
#
#         var popup_21b367795541b7d343f2742a80b6f838 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_492d6c52852b9773fda36c8b1a3db406 = $(`&lt;div id=&quot;html_492d6c52852b9773fda36c8b1a3db406&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_21b367795541b7d343f2742a80b6f838.setContent(html_492d6c52852b9773fda36c8b1a3db406);
#
#
#
#         marker_c6c90d40f490fe836b7fa99735476e5c.bindPopup(popup_21b367795541b7d343f2742a80b6f838)
#         ;
#
#
#
#
#             var marker_86ea36f844a9d89fe1a47b07c99e08ed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f1b6e36fba502dbe0f5e185b7391e07a);
#
#
#         var popup_006c8667404bdf07de49eb87bfec23f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82fe4e7639faf866fdaa6a9af544ce90 = $(`&lt;div id=&quot;html_82fe4e7639faf866fdaa6a9af544ce90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_006c8667404bdf07de49eb87bfec23f1.setContent(html_82fe4e7639faf866fdaa6a9af544ce90);
#
#
#
#         marker_86ea36f844a9d89fe1a47b07c99e08ed.bindPopup(popup_006c8667404bdf07de49eb87bfec23f1)
#         ;
#
#
#
#
#             var marker_61f90d6e53a575fefb5c4f67c58fa95c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f1b6e36fba502dbe0f5e185b7391e07a);
#
#
#         var popup_e9110a4b90a715c0e10d4dd3dd9f283b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47bddedf4ec8f119b6f781a7256cea9e = $(`&lt;div id=&quot;html_47bddedf4ec8f119b6f781a7256cea9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e9110a4b90a715c0e10d4dd3dd9f283b.setContent(html_47bddedf4ec8f119b6f781a7256cea9e);
#
#
#
#         marker_61f90d6e53a575fefb5c4f67c58fa95c.bindPopup(popup_e9110a4b90a715c0e10d4dd3dd9f283b)
#         ;
#
#
#
#
#             var marker_76a537c1efa5540143cc406049c02b2f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f1b6e36fba502dbe0f5e185b7391e07a);
#
#
#         var popup_059b9eb1515926521a47f48b062a4575 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc0b882677ab9d0a756eaa91acb2de28 = $(`&lt;div id=&quot;html_fc0b882677ab9d0a756eaa91acb2de28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_059b9eb1515926521a47f48b062a4575.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad144c60a811f3a57a6a94bc959a5b21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad144c60a811f3a57a6a94bc959a5b21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad144c60a811f3a57a6a94bc959a5b21 = L.map(
#                 &quot;map_ad144c60a811f3a57a6a94bc959a5b21&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ecff3cdc40851ee5d72ba9c59c54968a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ecff3cdc40851ee5d72ba9c59c54968a.addTo(map_ad144c60a811f3a57a6a94bc959a5b21);
#
#
#             var feature_group_fc8a4f5c6400bf1cfdbdc1c355d86c88 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a165d7f0478d886bfe48f520674245fc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fc8a4f5c6400bf1cfdbdc1c355d86c88);
#
#
#         var popup_261c72d8d21595f026d17f3fbeca3150 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2d67569b036060e6b054089a77e22a8 = $(`&lt;div id=&quot;html_b2d67569b036060e6b054089a77e22a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_261c72d8d21595f026d17f3fbeca3150.setContent(html_b2d67569b036060e6b054089a77e22a8);
#
#
#
#         marker_a165d7f0478d886bfe48f520674245fc.bindPopup(popup_261c72d8d21595f026d17f3fbeca3150)
#         ;
#
#
#
#
#             var marker_ed5fb820faa98e6c1eb92aec51c6bd57 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fc8a4f5c6400bf1cfdbdc1c355d86c88);
#
#
#         var popup_4e3597204e088ac25ca975d9f2c8fa42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_351400cc4ef0e147d73a92af543c7883 = $(`&lt;div id=&quot;html_351400cc4ef0e147d73a92af543c7883&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4e3597204e088ac25ca975d9f2c8fa42.setContent(html_351400cc4ef0e147d73a92af543c7883);
#
#
#
#         marker_ed5fb820faa98e6c1eb92aec51c6bd57.bindPopup(popup_4e3597204e088ac25ca975d9f2c8fa42)
#         ;
#
#
#
#
#             var marker_414788cdc85f43ac2dad039b5f269f5e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fc8a4f5c6400bf1cfdbdc1c355d86c88);
#
#
#         var popup_061b38935a7dea0826f5e55e44396304 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef5dd41063227466cd00bce4198b0f27 = $(`&lt;div id=&quot;html_ef5dd41063227466cd00bce4198b0f27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_061b38935a7dea0826f5e55e44396304.setContent(html_ef5dd41063227466cd00bce4198b0f27);
#
#
#
#         marker_414788cdc85f43ac2dad039b5f269f5e.bindPopup(popup_061b38935a7dea0826f5e55e44396304)
#         ;
#
#
#
#
#             var marker_92786d28f9844ffa5fcfbbc3496cddfb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fc8a4f5c6400bf1cfdbdc1c355d86c88);
#
#
#         var popup_8bf9416377be9ad452a54648c1e09a59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b62dcd91a5b1198a4ef981018cca129f = $(`&lt;div id=&quot;html_b62dcd91a5b1198a4ef981018cca129f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8bf9416377be9ad452a54648c1e09a59.setContent(html_b62dcd91a5b1198a4ef981018cca129f);
#
#
#
#         marker_92786d28f9844ffa5fcfbbc3496cddfb.bindPopup(popup_8bf9416377be9ad452a54648c1e09a59)
#         ;
#
#
#
#
#             var marker_ed1fd26641b83951e072281125b3c0bc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fc8a4f5c6400bf1cfdbdc1c355d86c88);
#
#
#         var popup_fce5a174ca7defb4e27dd6f605190cce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ee8a69ae9c72643d7b76fdc69753301 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ee8a69ae9c72643d7b76fdc69753301&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ee8a69ae9c72643d7b76fdc69753301 = L.map(
#                 &quot;map_3ee8a69ae9c72643d7b76fdc69753301&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a01c0f25de099b1d1b76fc0649591110 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a01c0f25de099b1d1b76fc0649591110.addTo(map_3ee8a69ae9c72643d7b76fdc69753301);
#
#
#             var feature_group_d179ccbd7b5b1c68b6f73dec632717dd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d179ccbd7b5b1c68b6f73dec632717dd.addTo(map_3ee8a69ae9c72643d7b76fdc69753301);
#
#
#             var feature_group_sub_group_c8fa11da3f750f49a2bc9d205f57cc7d = L.featureGroup.subGroup(
#                 feature_group_d179ccbd7b5b1c68b6f73dec632717dd
#             );
#
#
#             var marker_d46867664f57c173f45bdde9bf3a5d3b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8fa11da3f750f49a2bc9d205f57cc7d);
#
#
#         var popup_95cdd89c38df5d86129baa3703643c43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b02cefd4b90f542f7a1018954c7648e4 = $(`&lt;div id=&quot;html_b02cefd4b90f542f7a1018954c7648e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_95cdd89c38df5d86129baa3703643c43.setContent(html_b02cefd4b90f542f7a1018954c7648e4);
#
#
#
#         marker_d46867664f57c173f45bdde9bf3a5d3b.bindPopup(popup_95cdd89c38df5d86129baa3703643c43)
#         ;
#
#
#
#
#             var marker_0f7a97da7934b637046697632920a979 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8fa11da3f750f49a2bc9d205f57cc7d);
#
#
#         var popup_047db330b6d1b860a4f318c0ef0ad898 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78c703c0407dd06aba8dff94530c3778 = $(`&lt;div id=&quot;html_78c703c0407dd06aba8dff94530c3778&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_047db330b6d1b860a4f318c0ef0ad898.setContent(html_78c703c0407dd06aba8dff94530c3778);
#
#
#
#         marker_0f7a97da7934b637046697632920a979.bindPopup(popup_047db330b6d1b860a4f318c0ef0ad898)
#         ;
#
#
#
#
#             var marker_746f4a45e7e5bba22ec83c3712c318a3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8fa11da3f750f49a2bc9d205f57cc7d);
#
#
#         var popup_5ac6ab517c02f05bc61543dfdac9bc1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9fdc61e372ef306222d4dd6b5f55798 = $(`&lt;div id=&quot;html_d9fdc61e372ef306222d4dd6b5f55798&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5ac6ab517c02f05bc61543dfdac9bc1a.setContent(html_d9fdc61e372ef306222d4dd6b5f55798);
#
#
#
#         marker_746f4a45e7e5bba22ec83c3712c318a3.bindPopup(popup_5ac6ab517c02f05bc61543dfdac9bc1a)
#         ;
#
#
#
#
#             var marker_caa51edb5bea0710119501114c73ac04 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c8fa11da3f750f49a2bc9d205f57cc7d);
#
#
#         var popup_e0521ac6283cd4509cafe17b4492ff0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e34b712f795e1c75c6281d15b591838c = $(`&lt;div id=&quot;html_e34b712f795e1c75c6281d15b591838c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e0521ac6283cd4509cafe17b4492ff0d.setContent(html_e34b712f795e1c75c6281d15b591838c);
#
#
#
#         marker_
