# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4be08b324cb745a1778f59b4c4ca4239 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4be08b324cb745a1778f59b4c4ca4239&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4be08b324cb745a1778f59b4c4ca4239 = L.map(
#                 &quot;map_4be08b324cb745a1778f59b4c4ca4239&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_188879f5601528503970c2feefe2be19 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_188879f5601528503970c2feefe2be19.addTo(map_4be08b324cb745a1778f59b4c4ca4239);
#
#
#             var marker_3b31fd508719e5df0bb19e3056de6dfe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4be08b324cb745a1778f59b4c4ca4239);
#
#
#         var popup_22b10fb54e52f92a0033b220a10180bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2ffe8fbff97c8ac25d5654ebe22d5ab = $(`&lt;div id=&quot;html_e2ffe8fbff97c8ac25d5654ebe22d5ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_22b10fb54e52f92a0033b220a10180bc.setContent(html_e2ffe8fbff97c8ac25d5654ebe22d5ab);
#
#
#
#         marker_3b31fd508719e5df0bb19e3056de6dfe.bindPopup(popup_22b10fb54e52f92a0033b220a10180bc)
#         ;
#
#
#
#
#             var marker_487548e5d8f7d994e947975fadaa5280 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4be08b324cb745a1778f59b4c4ca4239);
#
#
#         var popup_b25a096703402aca1613b3c2a691b759 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7578476b5dab59906853164437722e32 = $(`&lt;div id=&quot;html_7578476b5dab59906853164437722e32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b25a096703402aca1613b3c2a691b759.setContent(html_7578476b5dab59906853164437722e32);
#
#
#
#         marker_487548e5d8f7d994e947975fadaa5280.bindPopup(popup_b25a096703402aca1613b3c2a691b759)
#         ;
#
#
#
#
#             var marker_763426f3b8f71651316ab982df46d294 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4be08b324cb745a1778f59b4c4ca4239);
#
#
#         var popup_20a7fd1d14a1f7dbe1a5a63afc861b28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_206b7dcee2b503d046a071fad6f1c48b = $(`&lt;div id=&quot;html_206b7dcee2b503d046a071fad6f1c48b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_20a7fd1d14a1f7dbe1a5a63afc861b28.setContent(html_206b7dcee2b503d046a071fad6f1c48b);
#
#
#
#         marker_763426f3b8f71651316ab982df46d294.bindPopup(popup_20a7fd1d14a1f7dbe1a5a63afc861b28)
#         ;
#
#
#
#
#             var marker_a766612dbe40f8c76b1ad1213b667dbb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4be08b324cb745a1778f59b4c4ca4239);
#
#
#         var popup_36b306435f08d419fc33344b81747fa1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09c9c0a206a56730fa30cf2ffcdb8525 = $(`&lt;div id=&quot;html_09c9c0a206a56730fa30cf2ffcdb8525&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_36b306435f08d419fc33344b81747fa1.setContent(html_09c9c0a206a56730fa30cf2ffcdb8525);
#
#
#
#         marker_a766612dbe40f8c76b1ad1213b667dbb.bindPopup(popup_36b306435f08d419fc33344b81747fa1)
#         ;
#
#
#
#
#             var marker_5aa592d69219cef8f7075f8db97dcf4c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4be08b324cb745a1778f59b4c4ca4239);
#
#
#         var popup_2d2c899dfb7f1dc9d51053d98efe600e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df18ea80d62c2cee7ad209e1ecff586d = $(`&lt;div id=&quot;html_df18ea80d62c2cee7ad209e1ecff586d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2d2c899dfb7f1dc9d51053d98efe600e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d44153452f589dfad90a34b703e73c33 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d44153452f589dfad90a34b703e73c33&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d44153452f589dfad90a34b703e73c33 = L.map(
#                 &quot;map_d44153452f589dfad90a34b703e73c33&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc0d123eb0f99bbc455d68ea16d28580 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bc0d123eb0f99bbc455d68ea16d28580.addTo(map_d44153452f589dfad90a34b703e73c33);
#
#
#             var feature_group_b296236a92eb8a90a1e5fb1f28180321 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_245adfca37f2d6db61a12541dac2e30f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b296236a92eb8a90a1e5fb1f28180321);
#
#
#         var popup_ccac9e5cd2a3b8bafe5f264a3441f8a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3d8d5c91f2f278501836027b9bd2ecf = $(`&lt;div id=&quot;html_a3d8d5c91f2f278501836027b9bd2ecf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ccac9e5cd2a3b8bafe5f264a3441f8a7.setContent(html_a3d8d5c91f2f278501836027b9bd2ecf);
#
#
#
#         marker_245adfca37f2d6db61a12541dac2e30f.bindPopup(popup_ccac9e5cd2a3b8bafe5f264a3441f8a7)
#         ;
#
#
#
#
#             var marker_17c1a3a0cc9174e6a2a50b7cd6fe463f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b296236a92eb8a90a1e5fb1f28180321);
#
#
#         var popup_8d6cbab22eb96da30a75194462d802ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcafbc3d1982a670f8590c0def9a3d1f = $(`&lt;div id=&quot;html_dcafbc3d1982a670f8590c0def9a3d1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8d6cbab22eb96da30a75194462d802ae.setContent(html_dcafbc3d1982a670f8590c0def9a3d1f);
#
#
#
#         marker_17c1a3a0cc9174e6a2a50b7cd6fe463f.bindPopup(popup_8d6cbab22eb96da30a75194462d802ae)
#         ;
#
#
#
#
#             var marker_99ab83552460e23a164301ad4f2df7ed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b296236a92eb8a90a1e5fb1f28180321);
#
#
#         var popup_030ed9e09f9a287e9112b735862521d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5815957ea12017ee48354bd65b8a450c = $(`&lt;div id=&quot;html_5815957ea12017ee48354bd65b8a450c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_030ed9e09f9a287e9112b735862521d8.setContent(html_5815957ea12017ee48354bd65b8a450c);
#
#
#
#         marker_99ab83552460e23a164301ad4f2df7ed.bindPopup(popup_030ed9e09f9a287e9112b735862521d8)
#         ;
#
#
#
#
#             var marker_33370585ba3f80a669c92d48861aba88 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b296236a92eb8a90a1e5fb1f28180321);
#
#
#         var popup_cbc5965dc5ec4490ac05373a1c07b7a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42bd7d6c35f4de6e8608eb3dff5470a6 = $(`&lt;div id=&quot;html_42bd7d6c35f4de6e8608eb3dff5470a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cbc5965dc5ec4490ac05373a1c07b7a8.setContent(html_42bd7d6c35f4de6e8608eb3dff5470a6);
#
#
#
#         marker_33370585ba3f80a669c92d48861aba88.bindPopup(popup_cbc5965dc5ec4490ac05373a1c07b7a8)
#         ;
#
#
#
#
#             var marker_509ef87a3e354d3aa92de520254c0305 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b296236a92eb8a90a1e5fb1f28180321);
#
#
#         var popup_fcbcb42ec428c9a3cedf67dedef0abc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1686593ee5dae3be13c1e47f6eb1261f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1686593ee5dae3be13c1e47f6eb1261f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1686593ee5dae3be13c1e47f6eb1261f = L.map(
#                 &quot;map_1686593ee5dae3be13c1e47f6eb1261f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e505d659d2640c2028fc0f338110743 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e505d659d2640c2028fc0f338110743.addTo(map_1686593ee5dae3be13c1e47f6eb1261f);
#
#
#             var feature_group_04f1b62e9af037daad29e251986b23e2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_04f1b62e9af037daad29e251986b23e2.addTo(map_1686593ee5dae3be13c1e47f6eb1261f);
#
#
#             var feature_group_sub_group_87c73ac24799fa08c2b0b61719b83b71 = L.featureGroup.subGroup(
#                 feature_group_04f1b62e9af037daad29e251986b23e2
#             );
#
#
#             var marker_959ebde4c77e5d2909d60eb0dfe33508 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_87c73ac24799fa08c2b0b61719b83b71);
#
#
#         var popup_558ee133c66d8c20bb8f25cd5db28318 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96f0eea0f421a0e47476623dff40bd12 = $(`&lt;div id=&quot;html_96f0eea0f421a0e47476623dff40bd12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_558ee133c66d8c20bb8f25cd5db28318.setContent(html_96f0eea0f421a0e47476623dff40bd12);
#
#
#
#         marker_959ebde4c77e5d2909d60eb0dfe33508.bindPopup(popup_558ee133c66d8c20bb8f25cd5db28318)
#         ;
#
#
#
#
#             var marker_7c0252f96ca95605333991c17d4239bf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_87c73ac24799fa08c2b0b61719b83b71);
#
#
#         var popup_5a7b03d5d6ebdae11a4d918bcde65ef1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d9e25075678f89f9fe79dcd3406e87a = $(`&lt;div id=&quot;html_4d9e25075678f89f9fe79dcd3406e87a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5a7b03d5d6ebdae11a4d918bcde65ef1.setContent(html_4d9e25075678f89f9fe79dcd3406e87a);
#
#
#
#         marker_7c0252f96ca95605333991c17d4239bf.bindPopup(popup_5a7b03d5d6ebdae11a4d918bcde65ef1)
#         ;
#
#
#
#
#             var marker_343e942d4323733360aebae3b9c0e101 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_87c73ac24799fa08c2b0b61719b83b71);
#
#
#         var popup_c41d4a6650ff049ab5628197cc27703d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a713d930b7496dedfe5384fbae1dd6cc = $(`&lt;div id=&quot;html_a713d930b7496dedfe5384fbae1dd6cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c41d4a6650ff049ab5628197cc27703d.setContent(html_a713d930b7496dedfe5384fbae1dd6cc);
#
#
#
#         marker_343e942d4323733360aebae3b9c0e101.bindPopup(popup_c41d4a6650ff049ab5628197cc27703d)
#         ;
#
#
#
#
#             var marker_c8ad3d07fc776b325528a4a55d98a3f3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_87c73ac24799fa08c2b0b61719b83b71);
#
#
#         var popup_e8756451055028b8f5c75c2d2c4e9af4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd60291cd3da9f81331423190141b174 = $(`&lt;div id=&quot;html_fd60291cd3da9f81331423190141b174&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e8756451055028b8f5c75c2d2c4e9af4.setContent(html_fd60291cd3da9f81331423190141b174);
#
#
#
#         marker_
