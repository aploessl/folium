# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62e5510d4cd17e62ce319681b84a09c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62e5510d4cd17e62ce319681b84a09c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62e5510d4cd17e62ce319681b84a09c8 = L.map(
#                 &quot;map_62e5510d4cd17e62ce319681b84a09c8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a7e38ecb59c83ac163e54bb6833754f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3a7e38ecb59c83ac163e54bb6833754f.addTo(map_62e5510d4cd17e62ce319681b84a09c8);
#
#
#             var marker_c6de00bb79f908d7bc3f3f85f37f2902 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_62e5510d4cd17e62ce319681b84a09c8);
#
#
#         var popup_b016286ce4dbe7217ac80a857364c908 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2c653ea8d59f36fe802d408a687cb95 = $(`&lt;div id=&quot;html_e2c653ea8d59f36fe802d408a687cb95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b016286ce4dbe7217ac80a857364c908.setContent(html_e2c653ea8d59f36fe802d408a687cb95);
#
#
#
#         marker_c6de00bb79f908d7bc3f3f85f37f2902.bindPopup(popup_b016286ce4dbe7217ac80a857364c908)
#         ;
#
#
#
#
#             var marker_381de4873a78bdec6ecb7cff0b652658 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_62e5510d4cd17e62ce319681b84a09c8);
#
#
#         var popup_1b3c37a4479e2a37ffaf78f195c88faa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd7572c24708f1671aa646e67cd9a901 = $(`&lt;div id=&quot;html_bd7572c24708f1671aa646e67cd9a901&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1b3c37a4479e2a37ffaf78f195c88faa.setContent(html_bd7572c24708f1671aa646e67cd9a901);
#
#
#
#         marker_381de4873a78bdec6ecb7cff0b652658.bindPopup(popup_1b3c37a4479e2a37ffaf78f195c88faa)
#         ;
#
#
#
#
#             var marker_7f958c1687f4b5e9fefaedffe62c7098 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_62e5510d4cd17e62ce319681b84a09c8);
#
#
#         var popup_39101adac94b862c0f0e5c4536efbb86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7de04519beba80f1a85655c10a2365b2 = $(`&lt;div id=&quot;html_7de04519beba80f1a85655c10a2365b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_39101adac94b862c0f0e5c4536efbb86.setContent(html_7de04519beba80f1a85655c10a2365b2);
#
#
#
#         marker_7f958c1687f4b5e9fefaedffe62c7098.bindPopup(popup_39101adac94b862c0f0e5c4536efbb86)
#         ;
#
#
#
#
#             var marker_af9932f0e28763ecb7315b4b2616d019 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_62e5510d4cd17e62ce319681b84a09c8);
#
#
#         var popup_9316865d23fdd9297b06dc8b11ce75b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ec9dca2fda4043b2f0b5c0a17515616 = $(`&lt;div id=&quot;html_3ec9dca2fda4043b2f0b5c0a17515616&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9316865d23fdd9297b06dc8b11ce75b1.setContent(html_3ec9dca2fda4043b2f0b5c0a17515616);
#
#
#
#         marker_af9932f0e28763ecb7315b4b2616d019.bindPopup(popup_9316865d23fdd9297b06dc8b11ce75b1)
#         ;
#
#
#
#
#             var marker_97973f853857e1b191155a959414927e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_62e5510d4cd17e62ce319681b84a09c8);
#
#
#         var popup_6737afc02d535537dc14c00915c21b46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b132bf850f29099f08563a053f64995 = $(`&lt;div id=&quot;html_4b132bf850f29099f08563a053f64995&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6737afc02d535537dc14c00915c21b46.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7b119d2305583703ef2f08d6d23541f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7b119d2305583703ef2f08d6d23541f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7b119d2305583703ef2f08d6d23541f = L.map(
#                 &quot;map_f7b119d2305583703ef2f08d6d23541f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15f04a486ba2341b18192d9022dc6092 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15f04a486ba2341b18192d9022dc6092.addTo(map_f7b119d2305583703ef2f08d6d23541f);
#
#
#             var feature_group_e522546098eaba9e9c415f6df794a779 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d04a69a8ea5172a59bf12dfa96ce5b56 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e522546098eaba9e9c415f6df794a779);
#
#
#         var popup_78cb7aa414d99d19b7aea3f855512791 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_999bf69670299dc506d1ed5ce24c5ebb = $(`&lt;div id=&quot;html_999bf69670299dc506d1ed5ce24c5ebb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_78cb7aa414d99d19b7aea3f855512791.setContent(html_999bf69670299dc506d1ed5ce24c5ebb);
#
#
#
#         marker_d04a69a8ea5172a59bf12dfa96ce5b56.bindPopup(popup_78cb7aa414d99d19b7aea3f855512791)
#         ;
#
#
#
#
#             var marker_d522718bc1b75b13fc1e8dd7e24d17ff = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e522546098eaba9e9c415f6df794a779);
#
#
#         var popup_cb506d7d8e3d397981f3b03d5064e002 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_913f115a5d9c189cc63e359e4db93f1a = $(`&lt;div id=&quot;html_913f115a5d9c189cc63e359e4db93f1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cb506d7d8e3d397981f3b03d5064e002.setContent(html_913f115a5d9c189cc63e359e4db93f1a);
#
#
#
#         marker_d522718bc1b75b13fc1e8dd7e24d17ff.bindPopup(popup_cb506d7d8e3d397981f3b03d5064e002)
#         ;
#
#
#
#
#             var marker_4e005c6a3849b3d9c4fde7777a711bfa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e522546098eaba9e9c415f6df794a779);
#
#
#         var popup_3d01e0a66ab4a5086587ea4b9b6f07d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22c28dd02af3c057a57cde6ccb74b311 = $(`&lt;div id=&quot;html_22c28dd02af3c057a57cde6ccb74b311&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3d01e0a66ab4a5086587ea4b9b6f07d1.setContent(html_22c28dd02af3c057a57cde6ccb74b311);
#
#
#
#         marker_4e005c6a3849b3d9c4fde7777a711bfa.bindPopup(popup_3d01e0a66ab4a5086587ea4b9b6f07d1)
#         ;
#
#
#
#
#             var marker_807b87e7a04afe95d88388097234748b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e522546098eaba9e9c415f6df794a779);
#
#
#         var popup_2962bdf32578ab30845e8e8db2022793 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44777a1d730bae987de13646346e43cb = $(`&lt;div id=&quot;html_44777a1d730bae987de13646346e43cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2962bdf32578ab30845e8e8db2022793.setContent(html_44777a1d730bae987de13646346e43cb);
#
#
#
#         marker_807b87e7a04afe95d88388097234748b.bindPopup(popup_2962bdf32578ab30845e8e8db2022793)
#         ;
#
#
#
#
#             var marker_21f232c6ad3ebf6724c469d24cda96a8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e522546098eaba9e9c415f6df794a779);
#
#
#         var popup_dca711a79118e4c2d5a440ec43917ea9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_def62600df74bfc711bac0ea3ea59734 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_def62600df74bfc711bac0ea3ea59734&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_def62600df74bfc711bac0ea3ea59734 = L.map(
#                 &quot;map_def62600df74bfc711bac0ea3ea59734&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99309da9d2ba4db4c58326f892bf2a57 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_99309da9d2ba4db4c58326f892bf2a57.addTo(map_def62600df74bfc711bac0ea3ea59734);
#
#
#             var feature_group_3f2c808cce0df69b91b5df33b5e6b9f5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3f2c808cce0df69b91b5df33b5e6b9f5.addTo(map_def62600df74bfc711bac0ea3ea59734);
#
#
#             var feature_group_sub_group_3ad4039f5e7e6094f8728cf2860f3c12 = L.featureGroup.subGroup(
#                 feature_group_3f2c808cce0df69b91b5df33b5e6b9f5
#             );
#
#
#             var marker_d8a61bfea46242ddfb47ebb5fcf335ee = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ad4039f5e7e6094f8728cf2860f3c12);
#
#
#         var popup_6b3e09c8c040626024a685010c48635f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18b2b0e1e9452f579309700135a9d5cc = $(`&lt;div id=&quot;html_18b2b0e1e9452f579309700135a9d5cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6b3e09c8c040626024a685010c48635f.setContent(html_18b2b0e1e9452f579309700135a9d5cc);
#
#
#
#         marker_d8a61bfea46242ddfb47ebb5fcf335ee.bindPopup(popup_6b3e09c8c040626024a685010c48635f)
#         ;
#
#
#
#
#             var marker_e50020214076dba5b51154bc2f6598c4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ad4039f5e7e6094f8728cf2860f3c12);
#
#
#         var popup_cd363ed10b9df44162210d9c29263a38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85b8e89c979e138660af910e8a06828a = $(`&lt;div id=&quot;html_85b8e89c979e138660af910e8a06828a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cd363ed10b9df44162210d9c29263a38.setContent(html_85b8e89c979e138660af910e8a06828a);
#
#
#
#         marker_e50020214076dba5b51154bc2f6598c4.bindPopup(popup_cd363ed10b9df44162210d9c29263a38)
#         ;
#
#
#
#
#             var marker_55d2714e106789c77b72b4a9a73f5a46 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ad4039f5e7e6094f8728cf2860f3c12);
#
#
#         var popup_8d819b84e4a6322b2f392b23d2230af7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_964803df428f48690d15f02a31bcf686 = $(`&lt;div id=&quot;html_964803df428f48690d15f02a31bcf686&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8d819b84e4a6322b2f392b23d2230af7.setContent(html_964803df428f48690d15f02a31bcf686);
#
#
#
#         marker_55d2714e106789c77b72b4a9a73f5a46.bindPopup(popup_8d819b84e4a6322b2f392b23d2230af7)
#         ;
#
#
#
#
#             var marker_b448550c8eef41887db3c3ba2dfd55c6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ad4039f5e7e6094f8728cf2860f3c12);
#
#
#         var popup_95fc14890616c2e6601391a410203a1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3a1c58b9a4f6f604ccb48cb7639da7d = $(`&lt;div id=&quot;html_c3a1c58b9a4f6f604ccb48cb7639da7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_95fc14890616c2e6601391a410203a1e.setContent(html_c3a1c58b9a4f6f604ccb48cb7639da7d);
#
#
#
#         marker_
