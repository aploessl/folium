# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8425e811898bf94af17a07a63077665 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8425e811898bf94af17a07a63077665&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8425e811898bf94af17a07a63077665 = L.map(
#                 &quot;map_a8425e811898bf94af17a07a63077665&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76e46c79489cc8cb538500efa136ae70 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_76e46c79489cc8cb538500efa136ae70.addTo(map_a8425e811898bf94af17a07a63077665);
#
#
#             var marker_51a50114343f918920d304a37377b322 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a8425e811898bf94af17a07a63077665);
#
#
#         var popup_67d27b0effb6d220220c0f85cb07c822 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_495c11a4d6f09c4a5ecaf1c47de54a9e = $(`&lt;div id=&quot;html_495c11a4d6f09c4a5ecaf1c47de54a9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_67d27b0effb6d220220c0f85cb07c822.setContent(html_495c11a4d6f09c4a5ecaf1c47de54a9e);
#
#
#
#         marker_51a50114343f918920d304a37377b322.bindPopup(popup_67d27b0effb6d220220c0f85cb07c822)
#         ;
#
#
#
#
#             var marker_9b6b82b907e4d75a94971cd035b43e8b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a8425e811898bf94af17a07a63077665);
#
#
#         var popup_97110d228ddd732f8440b1062d2a461e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b388a251974018925cf44247dbc4c7e = $(`&lt;div id=&quot;html_4b388a251974018925cf44247dbc4c7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_97110d228ddd732f8440b1062d2a461e.setContent(html_4b388a251974018925cf44247dbc4c7e);
#
#
#
#         marker_9b6b82b907e4d75a94971cd035b43e8b.bindPopup(popup_97110d228ddd732f8440b1062d2a461e)
#         ;
#
#
#
#
#             var marker_083e2ebe9d57200db90c40e2d529203f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a8425e811898bf94af17a07a63077665);
#
#
#         var popup_c1d5ae1c49b484c2a131f4dd98e22d80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_deae2f3b7d4c162d02b73107b210b99b = $(`&lt;div id=&quot;html_deae2f3b7d4c162d02b73107b210b99b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c1d5ae1c49b484c2a131f4dd98e22d80.setContent(html_deae2f3b7d4c162d02b73107b210b99b);
#
#
#
#         marker_083e2ebe9d57200db90c40e2d529203f.bindPopup(popup_c1d5ae1c49b484c2a131f4dd98e22d80)
#         ;
#
#
#
#
#             var marker_98b3d133169a10d0cb2b2055fb083ec0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a8425e811898bf94af17a07a63077665);
#
#
#         var popup_528cf2ddc4a3d3ecaf1e41131628e5b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d71cbe18401518282870a68a0fa3cab4 = $(`&lt;div id=&quot;html_d71cbe18401518282870a68a0fa3cab4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_528cf2ddc4a3d3ecaf1e41131628e5b5.setContent(html_d71cbe18401518282870a68a0fa3cab4);
#
#
#
#         marker_98b3d133169a10d0cb2b2055fb083ec0.bindPopup(popup_528cf2ddc4a3d3ecaf1e41131628e5b5)
#         ;
#
#
#
#
#             var marker_d79a058e5458478bc535daac6d89cb42 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a8425e811898bf94af17a07a63077665);
#
#
#         var popup_6cbb01c01cabd6679d9dc8f322f8f9f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0caa74b964295ff8745c61a47ce086b = $(`&lt;div id=&quot;html_d0caa74b964295ff8745c61a47ce086b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6cbb01c01cabd6679d9dc8f322f8f9f4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5b8e2936bc19b08fdc869b7436c93a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5b8e2936bc19b08fdc869b7436c93a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5b8e2936bc19b08fdc869b7436c93a8 = L.map(
#                 &quot;map_d5b8e2936bc19b08fdc869b7436c93a8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0edaecad33d79fb1e7ebe762bface447 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0edaecad33d79fb1e7ebe762bface447.addTo(map_d5b8e2936bc19b08fdc869b7436c93a8);
#
#
#             var feature_group_1932c812c6f70d3adb6536a6f0893832 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8518774bf0327640aefb4da7d2e1f512 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1932c812c6f70d3adb6536a6f0893832);
#
#
#         var popup_1892120a4c20df3c4e417b01d186a792 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13cd84830f6ea298ad857a46dd25ed91 = $(`&lt;div id=&quot;html_13cd84830f6ea298ad857a46dd25ed91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1892120a4c20df3c4e417b01d186a792.setContent(html_13cd84830f6ea298ad857a46dd25ed91);
#
#
#
#         marker_8518774bf0327640aefb4da7d2e1f512.bindPopup(popup_1892120a4c20df3c4e417b01d186a792)
#         ;
#
#
#
#
#             var marker_b02bd574c6545b60bd52ac72ffc69a0f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1932c812c6f70d3adb6536a6f0893832);
#
#
#         var popup_39b1bfe2a1f51dff78651464607bee08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d26d3d2155a169d6cba6b8b8a361167b = $(`&lt;div id=&quot;html_d26d3d2155a169d6cba6b8b8a361167b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_39b1bfe2a1f51dff78651464607bee08.setContent(html_d26d3d2155a169d6cba6b8b8a361167b);
#
#
#
#         marker_b02bd574c6545b60bd52ac72ffc69a0f.bindPopup(popup_39b1bfe2a1f51dff78651464607bee08)
#         ;
#
#
#
#
#             var marker_2980b1e29c51dd8120d7117995249886 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1932c812c6f70d3adb6536a6f0893832);
#
#
#         var popup_511f29da1177b36637acaf5c1e0366e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0961503fd628754f4073f4227fed5aa = $(`&lt;div id=&quot;html_f0961503fd628754f4073f4227fed5aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_511f29da1177b36637acaf5c1e0366e9.setContent(html_f0961503fd628754f4073f4227fed5aa);
#
#
#
#         marker_2980b1e29c51dd8120d7117995249886.bindPopup(popup_511f29da1177b36637acaf5c1e0366e9)
#         ;
#
#
#
#
#             var marker_bc568dcee9cbc6d217b49158bc48dc97 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1932c812c6f70d3adb6536a6f0893832);
#
#
#         var popup_081b03b20ac5b8d9c44b7ffcc2bee87a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d17fd00b087ed0db538f1c82af7b943f = $(`&lt;div id=&quot;html_d17fd00b087ed0db538f1c82af7b943f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_081b03b20ac5b8d9c44b7ffcc2bee87a.setContent(html_d17fd00b087ed0db538f1c82af7b943f);
#
#
#
#         marker_bc568dcee9cbc6d217b49158bc48dc97.bindPopup(popup_081b03b20ac5b8d9c44b7ffcc2bee87a)
#         ;
#
#
#
#
#             var marker_83b4138c1f6a8e9ccc75030a5ce32560 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1932c812c6f70d3adb6536a6f0893832);
#
#
#         var popup_278cbe8840344981e425138975c0d08d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a74a57f9ab32bb46e015fcf734ddd0cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a74a57f9ab32bb46e015fcf734ddd0cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a74a57f9ab32bb46e015fcf734ddd0cc = L.map(
#                 &quot;map_a74a57f9ab32bb46e015fcf734ddd0cc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b76e5c1b672bcf42c7cdcb4cffe790e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b76e5c1b672bcf42c7cdcb4cffe790e1.addTo(map_a74a57f9ab32bb46e015fcf734ddd0cc);
#
#
#             var feature_group_f0b01961795f7da147b9ce2106582ec9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f0b01961795f7da147b9ce2106582ec9.addTo(map_a74a57f9ab32bb46e015fcf734ddd0cc);
#
#
#             var feature_group_sub_group_fbc15dac2b5062c4d2cb86359faa4e50 = L.featureGroup.subGroup(
#                 feature_group_f0b01961795f7da147b9ce2106582ec9
#             );
#
#
#             var marker_5fcf9458ebafe5cb142f932207fa7a7d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fbc15dac2b5062c4d2cb86359faa4e50);
#
#
#         var popup_be2e0eede4338b3de3bc3c9dd9881097 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d5ef9dfcf963fb7cf4f518bddfe7b7f = $(`&lt;div id=&quot;html_7d5ef9dfcf963fb7cf4f518bddfe7b7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_be2e0eede4338b3de3bc3c9dd9881097.setContent(html_7d5ef9dfcf963fb7cf4f518bddfe7b7f);
#
#
#
#         marker_5fcf9458ebafe5cb142f932207fa7a7d.bindPopup(popup_be2e0eede4338b3de3bc3c9dd9881097)
#         ;
#
#
#
#
#             var marker_c5c3622d2a2d52a9cb337dc74591aa75 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fbc15dac2b5062c4d2cb86359faa4e50);
#
#
#         var popup_70b053b086fe3ca5bfc85510b93e4fd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdd9ff28f43e1ae3286acfa466780abe = $(`&lt;div id=&quot;html_fdd9ff28f43e1ae3286acfa466780abe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_70b053b086fe3ca5bfc85510b93e4fd9.setContent(html_fdd9ff28f43e1ae3286acfa466780abe);
#
#
#
#         marker_c5c3622d2a2d52a9cb337dc74591aa75.bindPopup(popup_70b053b086fe3ca5bfc85510b93e4fd9)
#         ;
#
#
#
#
#             var marker_de4e0b84b55cd18d8ebe6fa09728d81c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fbc15dac2b5062c4d2cb86359faa4e50);
#
#
#         var popup_4c7d3d295a468db5c96111f9258d8495 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1708a660d2ea12e465d9846852eb8232 = $(`&lt;div id=&quot;html_1708a660d2ea12e465d9846852eb8232&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4c7d3d295a468db5c96111f9258d8495.setContent(html_1708a660d2ea12e465d9846852eb8232);
#
#
#
#         marker_de4e0b84b55cd18d8ebe6fa09728d81c.bindPopup(popup_4c7d3d295a468db5c96111f9258d8495)
#         ;
#
#
#
#
#             var marker_65124f05ae923a57c4be1b059560371e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fbc15dac2b5062c4d2cb86359faa4e50);
#
#
#         var popup_08e61dc5a37e41134e28bf65fca97fba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2d960637f334ad78e35014584febff2 = $(`&lt;div id=&quot;html_c2d960637f334ad78e35014584febff2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_08e61dc5a37e41134e28bf65fca97fba.setContent(html_c2d960637f334ad78e35014584febff2);
#
#
#
#         marker_
