# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11126ee7033e8caa3db9d771d281cffe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11126ee7033e8caa3db9d771d281cffe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11126ee7033e8caa3db9d771d281cffe = L.map(
#                 &quot;map_11126ee7033e8caa3db9d771d281cffe&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef7f085f39f9e94db96c51d4209ccfc5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ef7f085f39f9e94db96c51d4209ccfc5.addTo(map_11126ee7033e8caa3db9d771d281cffe);
#
#
#             var marker_0a49c3f4544fe57e9701763873ff221e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_11126ee7033e8caa3db9d771d281cffe);
#
#
#         var popup_92aab5b8c3da9619b82c82b351d9741f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75328fc96a6090177591890cf1680ab5 = $(`&lt;div id=&quot;html_75328fc96a6090177591890cf1680ab5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_92aab5b8c3da9619b82c82b351d9741f.setContent(html_75328fc96a6090177591890cf1680ab5);
#
#
#
#         marker_0a49c3f4544fe57e9701763873ff221e.bindPopup(popup_92aab5b8c3da9619b82c82b351d9741f)
#         ;
#
#
#
#
#             var marker_cfa70fc3a02d35e81d114e490421de1a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_11126ee7033e8caa3db9d771d281cffe);
#
#
#         var popup_b21c01b2ad96bb9543ed443d09924863 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3865bcab129baae58df930e64a747c64 = $(`&lt;div id=&quot;html_3865bcab129baae58df930e64a747c64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b21c01b2ad96bb9543ed443d09924863.setContent(html_3865bcab129baae58df930e64a747c64);
#
#
#
#         marker_cfa70fc3a02d35e81d114e490421de1a.bindPopup(popup_b21c01b2ad96bb9543ed443d09924863)
#         ;
#
#
#
#
#             var marker_161f786b54f9fbec5bbd17c143e670a5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_11126ee7033e8caa3db9d771d281cffe);
#
#
#         var popup_d053709319d0feeb6b2d47243caccdac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f949bfdcfa80014e5c4214251f2196ac = $(`&lt;div id=&quot;html_f949bfdcfa80014e5c4214251f2196ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d053709319d0feeb6b2d47243caccdac.setContent(html_f949bfdcfa80014e5c4214251f2196ac);
#
#
#
#         marker_161f786b54f9fbec5bbd17c143e670a5.bindPopup(popup_d053709319d0feeb6b2d47243caccdac)
#         ;
#
#
#
#
#             var marker_a0c751d452c1e80cf98c3f1f808ef65e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_11126ee7033e8caa3db9d771d281cffe);
#
#
#         var popup_a0b68bc0585f1eb96b889bbb4c048e10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0c8f017a2084e865d1bbe7b6f0c392f = $(`&lt;div id=&quot;html_b0c8f017a2084e865d1bbe7b6f0c392f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a0b68bc0585f1eb96b889bbb4c048e10.setContent(html_b0c8f017a2084e865d1bbe7b6f0c392f);
#
#
#
#         marker_a0c751d452c1e80cf98c3f1f808ef65e.bindPopup(popup_a0b68bc0585f1eb96b889bbb4c048e10)
#         ;
#
#
#
#
#             var marker_be0799715e42c7af13af7fbe3e7a5139 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_11126ee7033e8caa3db9d771d281cffe);
#
#
#         var popup_a551157061db89223163b53e6900ef44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21659870f061daf9b31df933c73f54ec = $(`&lt;div id=&quot;html_21659870f061daf9b31df933c73f54ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a551157061db89223163b53e6900ef44.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06459403e585436734d0f38ad110b465 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06459403e585436734d0f38ad110b465&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06459403e585436734d0f38ad110b465 = L.map(
#                 &quot;map_06459403e585436734d0f38ad110b465&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e063568fd42c9ec44f65f650afa95ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e063568fd42c9ec44f65f650afa95ad.addTo(map_06459403e585436734d0f38ad110b465);
#
#
#             var feature_group_48df8fd60e2dc761bf0e985c8da0c5fb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c79892c2bbd16cfc0093253f9e7a2c05 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_48df8fd60e2dc761bf0e985c8da0c5fb);
#
#
#         var popup_0dfcce068bd6baf297a381616cefc547 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c65622477597a99d7a06966467736f8 = $(`&lt;div id=&quot;html_4c65622477597a99d7a06966467736f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0dfcce068bd6baf297a381616cefc547.setContent(html_4c65622477597a99d7a06966467736f8);
#
#
#
#         marker_c79892c2bbd16cfc0093253f9e7a2c05.bindPopup(popup_0dfcce068bd6baf297a381616cefc547)
#         ;
#
#
#
#
#             var marker_03ee078715c0227b59b99a3629dd2a62 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_48df8fd60e2dc761bf0e985c8da0c5fb);
#
#
#         var popup_a4f0377cc26c17196346258d3fcf3d4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6225d1dbcfb652ea90457417b3ed0254 = $(`&lt;div id=&quot;html_6225d1dbcfb652ea90457417b3ed0254&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a4f0377cc26c17196346258d3fcf3d4e.setContent(html_6225d1dbcfb652ea90457417b3ed0254);
#
#
#
#         marker_03ee078715c0227b59b99a3629dd2a62.bindPopup(popup_a4f0377cc26c17196346258d3fcf3d4e)
#         ;
#
#
#
#
#             var marker_eba97fffd91579e35fb4cd085253cdc6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_48df8fd60e2dc761bf0e985c8da0c5fb);
#
#
#         var popup_8025a79f29f3f50b837a601ac0319e81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5089530a780d9acdc3799d9c1b7fa36 = $(`&lt;div id=&quot;html_a5089530a780d9acdc3799d9c1b7fa36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8025a79f29f3f50b837a601ac0319e81.setContent(html_a5089530a780d9acdc3799d9c1b7fa36);
#
#
#
#         marker_eba97fffd91579e35fb4cd085253cdc6.bindPopup(popup_8025a79f29f3f50b837a601ac0319e81)
#         ;
#
#
#
#
#             var marker_a0054b9ac80a5f4b8934d572b4c9797d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_48df8fd60e2dc761bf0e985c8da0c5fb);
#
#
#         var popup_5ed9299310f688ecb1775b2e425a6165 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d26a7bb364d105414a8f4781daae489a = $(`&lt;div id=&quot;html_d26a7bb364d105414a8f4781daae489a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5ed9299310f688ecb1775b2e425a6165.setContent(html_d26a7bb364d105414a8f4781daae489a);
#
#
#
#         marker_a0054b9ac80a5f4b8934d572b4c9797d.bindPopup(popup_5ed9299310f688ecb1775b2e425a6165)
#         ;
#
#
#
#
#             var marker_56f5ab67e0d84b896e5f18873361a995 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_48df8fd60e2dc761bf0e985c8da0c5fb);
#
#
#         var popup_00ae6977c2976326f50c9e9ea3bdd7e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acef9eb146872610053d789fd889745c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acef9eb146872610053d789fd889745c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acef9eb146872610053d789fd889745c = L.map(
#                 &quot;map_acef9eb146872610053d789fd889745c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c030f05b6217294526e64da84e18c429 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c030f05b6217294526e64da84e18c429.addTo(map_acef9eb146872610053d789fd889745c);
#
#
#             var feature_group_f0fcd63f4347bb7c685d760ee2de5aba = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f0fcd63f4347bb7c685d760ee2de5aba.addTo(map_acef9eb146872610053d789fd889745c);
#
#
#             var feature_group_sub_group_7bc5f544bd8480e4a6daf55b547d2af3 = L.featureGroup.subGroup(
#                 feature_group_f0fcd63f4347bb7c685d760ee2de5aba
#             );
#
#
#             var marker_4e1337516b123abac9de2598910536e9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7bc5f544bd8480e4a6daf55b547d2af3);
#
#
#         var popup_3f086347ff3b3c5211af9dca94bfb320 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_360c404e39ace32cef4a766c7f5db042 = $(`&lt;div id=&quot;html_360c404e39ace32cef4a766c7f5db042&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3f086347ff3b3c5211af9dca94bfb320.setContent(html_360c404e39ace32cef4a766c7f5db042);
#
#
#
#         marker_4e1337516b123abac9de2598910536e9.bindPopup(popup_3f086347ff3b3c5211af9dca94bfb320)
#         ;
#
#
#
#
#             var marker_b28e6840a0e61abe01285b7cc78e41b8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7bc5f544bd8480e4a6daf55b547d2af3);
#
#
#         var popup_9b6eb2c9d0134935ff544499f7741b57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e7ae3497f96ad7bbbc4c4cbef9cf60f = $(`&lt;div id=&quot;html_0e7ae3497f96ad7bbbc4c4cbef9cf60f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9b6eb2c9d0134935ff544499f7741b57.setContent(html_0e7ae3497f96ad7bbbc4c4cbef9cf60f);
#
#
#
#         marker_b28e6840a0e61abe01285b7cc78e41b8.bindPopup(popup_9b6eb2c9d0134935ff544499f7741b57)
#         ;
#
#
#
#
#             var marker_4056ce5d8cd8ae01b0bf7403297da967 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7bc5f544bd8480e4a6daf55b547d2af3);
#
#
#         var popup_342f77175cb7336d8f727c27216b08fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26fbbee92a882a0140c75c90cb01bdbc = $(`&lt;div id=&quot;html_26fbbee92a882a0140c75c90cb01bdbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_342f77175cb7336d8f727c27216b08fc.setContent(html_26fbbee92a882a0140c75c90cb01bdbc);
#
#
#
#         marker_4056ce5d8cd8ae01b0bf7403297da967.bindPopup(popup_342f77175cb7336d8f727c27216b08fc)
#         ;
#
#
#
#
#             var marker_7ae4b8977322b89d324aef7f5e61c1d7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7bc5f544bd8480e4a6daf55b547d2af3);
#
#
#         var popup_19a866706e47ecbcee314dac9bdfeef1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2cf25b175a007b7991988dc6dfa72610 = $(`&lt;div id=&quot;html_2cf25b175a007b7991988dc6dfa72610&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_19a866706e47ecbcee314dac9bdfeef1.setContent(html_2cf25b175a007b7991988dc6dfa72610);
#
#
#
#         marker_
