# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12846928d512ec41ca4d4f92460ec426 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12846928d512ec41ca4d4f92460ec426&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12846928d512ec41ca4d4f92460ec426 = L.map(
#                 &quot;map_12846928d512ec41ca4d4f92460ec426&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_699042110f7c35b82e3bbc4592b2c966 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_699042110f7c35b82e3bbc4592b2c966.addTo(map_12846928d512ec41ca4d4f92460ec426);
#
#
#             var marker_16774f6d228cb6f40da5b08915a99f1a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_12846928d512ec41ca4d4f92460ec426);
#
#
#         var popup_3a978c54a6c10e704beca57baaf53b00 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41899c0077b24c6bd74855cb4c1fbe41 = $(`&lt;div id=&quot;html_41899c0077b24c6bd74855cb4c1fbe41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3a978c54a6c10e704beca57baaf53b00.setContent(html_41899c0077b24c6bd74855cb4c1fbe41);
#
#
#
#         marker_16774f6d228cb6f40da5b08915a99f1a.bindPopup(popup_3a978c54a6c10e704beca57baaf53b00)
#         ;
#
#
#
#
#             var marker_d6d2f084fceea97dbb7fd6d7ea67dd60 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_12846928d512ec41ca4d4f92460ec426);
#
#
#         var popup_784340da982d94d60e25151fecc60f57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2e7632cf20c232decd5cdb3f8089950 = $(`&lt;div id=&quot;html_b2e7632cf20c232decd5cdb3f8089950&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_784340da982d94d60e25151fecc60f57.setContent(html_b2e7632cf20c232decd5cdb3f8089950);
#
#
#
#         marker_d6d2f084fceea97dbb7fd6d7ea67dd60.bindPopup(popup_784340da982d94d60e25151fecc60f57)
#         ;
#
#
#
#
#             var marker_06f6cda20c6951c662e88a1d12182cb8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_12846928d512ec41ca4d4f92460ec426);
#
#
#         var popup_f7a99752c2fb1ef99bb70f44f3ab5720 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8097a1a730e812f324f21d272954741 = $(`&lt;div id=&quot;html_c8097a1a730e812f324f21d272954741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f7a99752c2fb1ef99bb70f44f3ab5720.setContent(html_c8097a1a730e812f324f21d272954741);
#
#
#
#         marker_06f6cda20c6951c662e88a1d12182cb8.bindPopup(popup_f7a99752c2fb1ef99bb70f44f3ab5720)
#         ;
#
#
#
#
#             var marker_8780b0965f8ad2868ccf363d5dafff98 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_12846928d512ec41ca4d4f92460ec426);
#
#
#         var popup_11b2c8afd6d20eff00f8a6694f782ad5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c102af24934ebf673525b0db97a1c9d = $(`&lt;div id=&quot;html_1c102af24934ebf673525b0db97a1c9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_11b2c8afd6d20eff00f8a6694f782ad5.setContent(html_1c102af24934ebf673525b0db97a1c9d);
#
#
#
#         marker_8780b0965f8ad2868ccf363d5dafff98.bindPopup(popup_11b2c8afd6d20eff00f8a6694f782ad5)
#         ;
#
#
#
#
#             var marker_6aaabc9f29872e99ed8db00d01a07ddd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_12846928d512ec41ca4d4f92460ec426);
#
#
#         var popup_af160c90cffd928def5325d4eb46f6c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_888ebfe95c742777191ccff90da3e383 = $(`&lt;div id=&quot;html_888ebfe95c742777191ccff90da3e383&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_af160c90cffd928def5325d4eb46f6c3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2c47a1ab9ebfe4d6d18d1dd963e3839 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2c47a1ab9ebfe4d6d18d1dd963e3839&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2c47a1ab9ebfe4d6d18d1dd963e3839 = L.map(
#                 &quot;map_f2c47a1ab9ebfe4d6d18d1dd963e3839&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7cc9df62b90c8f7f9cb95ddb8e531f31 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7cc9df62b90c8f7f9cb95ddb8e531f31.addTo(map_f2c47a1ab9ebfe4d6d18d1dd963e3839);
#
#
#             var feature_group_5a4e08e98b4029b446bc3a67c93820a8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c1f97782dca3317b58717a8fd1ae98c9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5a4e08e98b4029b446bc3a67c93820a8);
#
#
#         var popup_df8783fee5ae42a3f1c7904415da1d77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b6b072c0b3544c97064328669c4879a = $(`&lt;div id=&quot;html_8b6b072c0b3544c97064328669c4879a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_df8783fee5ae42a3f1c7904415da1d77.setContent(html_8b6b072c0b3544c97064328669c4879a);
#
#
#
#         marker_c1f97782dca3317b58717a8fd1ae98c9.bindPopup(popup_df8783fee5ae42a3f1c7904415da1d77)
#         ;
#
#
#
#
#             var marker_d572eb9848808bff2937e083c7a656ef = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5a4e08e98b4029b446bc3a67c93820a8);
#
#
#         var popup_4e8f9a5c1e7dbcf1f2191e45bce371ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_637cf7aa0dc47f90a5f9a8c2be955813 = $(`&lt;div id=&quot;html_637cf7aa0dc47f90a5f9a8c2be955813&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4e8f9a5c1e7dbcf1f2191e45bce371ab.setContent(html_637cf7aa0dc47f90a5f9a8c2be955813);
#
#
#
#         marker_d572eb9848808bff2937e083c7a656ef.bindPopup(popup_4e8f9a5c1e7dbcf1f2191e45bce371ab)
#         ;
#
#
#
#
#             var marker_0999b7773ab2bdab23e1ce4391015da0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5a4e08e98b4029b446bc3a67c93820a8);
#
#
#         var popup_3aab2b1c605db6ca489fea227490153a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cbecb8fb0dfeeec42a311e93470958e = $(`&lt;div id=&quot;html_4cbecb8fb0dfeeec42a311e93470958e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3aab2b1c605db6ca489fea227490153a.setContent(html_4cbecb8fb0dfeeec42a311e93470958e);
#
#
#
#         marker_0999b7773ab2bdab23e1ce4391015da0.bindPopup(popup_3aab2b1c605db6ca489fea227490153a)
#         ;
#
#
#
#
#             var marker_f0f04b2315f798a416a54ece2de387c1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5a4e08e98b4029b446bc3a67c93820a8);
#
#
#         var popup_63aeef6b8b26e6fd9c3b6c2864cfcd80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_230c161a936a1f104c70b391b1c05d95 = $(`&lt;div id=&quot;html_230c161a936a1f104c70b391b1c05d95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_63aeef6b8b26e6fd9c3b6c2864cfcd80.setContent(html_230c161a936a1f104c70b391b1c05d95);
#
#
#
#         marker_f0f04b2315f798a416a54ece2de387c1.bindPopup(popup_63aeef6b8b26e6fd9c3b6c2864cfcd80)
#         ;
#
#
#
#
#             var marker_7d6448ce0ff7abeb224ab7965b332668 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5a4e08e98b4029b446bc3a67c93820a8);
#
#
#         var popup_f44e29f71e4ddfd6803b42f7eaf4d52c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a98b1dec7c20b1bdac11ec5543e8d32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a98b1dec7c20b1bdac11ec5543e8d32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a98b1dec7c20b1bdac11ec5543e8d32 = L.map(
#                 &quot;map_5a98b1dec7c20b1bdac11ec5543e8d32&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_860110e36a5dd0f39028d241790aa859 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_860110e36a5dd0f39028d241790aa859.addTo(map_5a98b1dec7c20b1bdac11ec5543e8d32);
#
#
#             var feature_group_484f3af68db7e839ca36e26ecac23d4a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_484f3af68db7e839ca36e26ecac23d4a.addTo(map_5a98b1dec7c20b1bdac11ec5543e8d32);
#
#
#             var feature_group_sub_group_20d6b832b014bb22e71622e6aa4fad81 = L.featureGroup.subGroup(
#                 feature_group_484f3af68db7e839ca36e26ecac23d4a
#             );
#
#
#             var marker_17ef7b6d0608a2f7674038fc0bc9225e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_20d6b832b014bb22e71622e6aa4fad81);
#
#
#         var popup_007c0496e475e16fb30baf39d70c674b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3c5ec1148f5783a51dfed7555d56f38 = $(`&lt;div id=&quot;html_c3c5ec1148f5783a51dfed7555d56f38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_007c0496e475e16fb30baf39d70c674b.setContent(html_c3c5ec1148f5783a51dfed7555d56f38);
#
#
#
#         marker_17ef7b6d0608a2f7674038fc0bc9225e.bindPopup(popup_007c0496e475e16fb30baf39d70c674b)
#         ;
#
#
#
#
#             var marker_5ef1d39182e96d1b0aa301d5672a6f62 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_20d6b832b014bb22e71622e6aa4fad81);
#
#
#         var popup_2d707dddfed9032157d038d4e254f51a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b90c019b36fc4d138452cccda4617110 = $(`&lt;div id=&quot;html_b90c019b36fc4d138452cccda4617110&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2d707dddfed9032157d038d4e254f51a.setContent(html_b90c019b36fc4d138452cccda4617110);
#
#
#
#         marker_5ef1d39182e96d1b0aa301d5672a6f62.bindPopup(popup_2d707dddfed9032157d038d4e254f51a)
#         ;
#
#
#
#
#             var marker_cde130c8d8e4d07e03645a32100cda40 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_20d6b832b014bb22e71622e6aa4fad81);
#
#
#         var popup_cdaecbff495d50482d38b6741bacec62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dce0d134fbdb1f5a47e085aa261f955d = $(`&lt;div id=&quot;html_dce0d134fbdb1f5a47e085aa261f955d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_cdaecbff495d50482d38b6741bacec62.setContent(html_dce0d134fbdb1f5a47e085aa261f955d);
#
#
#
#         marker_cde130c8d8e4d07e03645a32100cda40.bindPopup(popup_cdaecbff495d50482d38b6741bacec62)
#         ;
#
#
#
#
#             var marker_762853b7813e851542d7fc93743c9f13 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_20d6b832b014bb22e71622e6aa4fad81);
#
#
#         var popup_481680967bf6bacdc6e1502a8dcab7f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e76c552e0b1e0768c5c2866357ea9f1e = $(`&lt;div id=&quot;html_e76c552e0b1e0768c5c2866357ea9f1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_481680967bf6bacdc6e1502a8dcab7f8.setContent(html_e76c552e0b1e0768c5c2866357ea9f1e);
#
#
#
#         marker_
