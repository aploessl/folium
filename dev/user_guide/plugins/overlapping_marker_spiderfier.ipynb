# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b358c83c07ddb2dc80e83776cf2c051 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b358c83c07ddb2dc80e83776cf2c051&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b358c83c07ddb2dc80e83776cf2c051 = L.map(
#                 &quot;map_3b358c83c07ddb2dc80e83776cf2c051&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21197678c3c395c22e0f7be6445f6c00 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_21197678c3c395c22e0f7be6445f6c00.addTo(map_3b358c83c07ddb2dc80e83776cf2c051);
#
#
#             var marker_16ddc92e1cff5681d9303891eaa13f3e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3b358c83c07ddb2dc80e83776cf2c051);
#
#
#         var popup_6bf74aba7eed8555b96d60d04d93ca38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ee9e21863973ef3d48a3824b36ec66a = $(`&lt;div id=&quot;html_4ee9e21863973ef3d48a3824b36ec66a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6bf74aba7eed8555b96d60d04d93ca38.setContent(html_4ee9e21863973ef3d48a3824b36ec66a);
#
#
#
#         marker_16ddc92e1cff5681d9303891eaa13f3e.bindPopup(popup_6bf74aba7eed8555b96d60d04d93ca38)
#         ;
#
#
#
#
#             var marker_aa57c64a7113c66831ae5f0440b182b5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3b358c83c07ddb2dc80e83776cf2c051);
#
#
#         var popup_78e82ae06bf2c8fdd3b5b1e272c8757e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_142dd548cedab6ba0cd77bcc0c1ce1d3 = $(`&lt;div id=&quot;html_142dd548cedab6ba0cd77bcc0c1ce1d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_78e82ae06bf2c8fdd3b5b1e272c8757e.setContent(html_142dd548cedab6ba0cd77bcc0c1ce1d3);
#
#
#
#         marker_aa57c64a7113c66831ae5f0440b182b5.bindPopup(popup_78e82ae06bf2c8fdd3b5b1e272c8757e)
#         ;
#
#
#
#
#             var marker_f8c4fec4f396666f8b95628f66866423 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3b358c83c07ddb2dc80e83776cf2c051);
#
#
#         var popup_9bd9e10ee0a76451b28f28cf48209090 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4a68b05b830726342080f7d56b05b87 = $(`&lt;div id=&quot;html_f4a68b05b830726342080f7d56b05b87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9bd9e10ee0a76451b28f28cf48209090.setContent(html_f4a68b05b830726342080f7d56b05b87);
#
#
#
#         marker_f8c4fec4f396666f8b95628f66866423.bindPopup(popup_9bd9e10ee0a76451b28f28cf48209090)
#         ;
#
#
#
#
#             var marker_258e59cedd4f4ae4e8bfa7afc851b711 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3b358c83c07ddb2dc80e83776cf2c051);
#
#
#         var popup_621ab1f45c9ad7039b5e3142eb4b66df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0a2eac544e35c16215a7bbbc816bed8 = $(`&lt;div id=&quot;html_a0a2eac544e35c16215a7bbbc816bed8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_621ab1f45c9ad7039b5e3142eb4b66df.setContent(html_a0a2eac544e35c16215a7bbbc816bed8);
#
#
#
#         marker_258e59cedd4f4ae4e8bfa7afc851b711.bindPopup(popup_621ab1f45c9ad7039b5e3142eb4b66df)
#         ;
#
#
#
#
#             var marker_816e1784b1289b463bcd87309979fc95 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3b358c83c07ddb2dc80e83776cf2c051);
#
#
#         var popup_88c9e76acbf14cb501c104d0872ec58f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5da6dd57007e0a58a82afc6d97fa7fd = $(`&lt;div id=&quot;html_b5da6dd57007e0a58a82afc6d97fa7fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_88c9e76acbf14cb501c104d0872ec58f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ddc4ebeeff93b8286be680c91a0d637c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ddc4ebeeff93b8286be680c91a0d637c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ddc4ebeeff93b8286be680c91a0d637c = L.map(
#                 &quot;map_ddc4ebeeff93b8286be680c91a0d637c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_090afe3172c339c165d1e16f24d36d29 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_090afe3172c339c165d1e16f24d36d29.addTo(map_ddc4ebeeff93b8286be680c91a0d637c);
#
#
#             var feature_group_cffdcd050e8bc8e3c9aa19a9ac56dd13 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4e0827f2c4e52416778c54f59b85ad2a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cffdcd050e8bc8e3c9aa19a9ac56dd13);
#
#
#         var popup_98273a1ae1bb6d781d32d5eda49281e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c9839c639eddb57afbfd25ddccb814f = $(`&lt;div id=&quot;html_6c9839c639eddb57afbfd25ddccb814f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_98273a1ae1bb6d781d32d5eda49281e6.setContent(html_6c9839c639eddb57afbfd25ddccb814f);
#
#
#
#         marker_4e0827f2c4e52416778c54f59b85ad2a.bindPopup(popup_98273a1ae1bb6d781d32d5eda49281e6)
#         ;
#
#
#
#
#             var marker_6c1974a279336bd93228ba303d31969b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cffdcd050e8bc8e3c9aa19a9ac56dd13);
#
#
#         var popup_6ac0ac49b175b02385117c89a65135f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_240fb438ab7c5f8f9d5f4b0c5a9a57ab = $(`&lt;div id=&quot;html_240fb438ab7c5f8f9d5f4b0c5a9a57ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6ac0ac49b175b02385117c89a65135f1.setContent(html_240fb438ab7c5f8f9d5f4b0c5a9a57ab);
#
#
#
#         marker_6c1974a279336bd93228ba303d31969b.bindPopup(popup_6ac0ac49b175b02385117c89a65135f1)
#         ;
#
#
#
#
#             var marker_fb4ac1b2673f0a94729b7774e6bc0bab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cffdcd050e8bc8e3c9aa19a9ac56dd13);
#
#
#         var popup_143162dfdd1a2beb73c00f61fd1a523e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e97bf6589da76c2a17952cf38d725a9b = $(`&lt;div id=&quot;html_e97bf6589da76c2a17952cf38d725a9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_143162dfdd1a2beb73c00f61fd1a523e.setContent(html_e97bf6589da76c2a17952cf38d725a9b);
#
#
#
#         marker_fb4ac1b2673f0a94729b7774e6bc0bab.bindPopup(popup_143162dfdd1a2beb73c00f61fd1a523e)
#         ;
#
#
#
#
#             var marker_6d6d99880cd23a64402acac9ee9eace7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cffdcd050e8bc8e3c9aa19a9ac56dd13);
#
#
#         var popup_f643742e2b08cde4d5f2021d90bb8fc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9ec15d8de97122079ea4749e76a2431 = $(`&lt;div id=&quot;html_e9ec15d8de97122079ea4749e76a2431&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f643742e2b08cde4d5f2021d90bb8fc5.setContent(html_e9ec15d8de97122079ea4749e76a2431);
#
#
#
#         marker_6d6d99880cd23a64402acac9ee9eace7.bindPopup(popup_f643742e2b08cde4d5f2021d90bb8fc5)
#         ;
#
#
#
#
#             var marker_0de48e6e81148605d0fdca96f4b2b9be = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cffdcd050e8bc8e3c9aa19a9ac56dd13);
#
#
#         var popup_f5d035077c79d41e5f3733fd97804214 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2481590b8d44dc4e5c7833962ac9e23 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2481590b8d44dc4e5c7833962ac9e23&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2481590b8d44dc4e5c7833962ac9e23 = L.map(
#                 &quot;map_c2481590b8d44dc4e5c7833962ac9e23&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f0aac82a0fbab716f839e9cabe6a594 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f0aac82a0fbab716f839e9cabe6a594.addTo(map_c2481590b8d44dc4e5c7833962ac9e23);
#
#
#             var feature_group_43d1f22f8c22c8bf8fe794ec23551327 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_43d1f22f8c22c8bf8fe794ec23551327.addTo(map_c2481590b8d44dc4e5c7833962ac9e23);
#
#
#             var feature_group_sub_group_bd75dca10dd3d17f17e0037fda2f550f = L.featureGroup.subGroup(
#                 feature_group_43d1f22f8c22c8bf8fe794ec23551327
#             );
#
#
#             var marker_9dd0e6fbf43e1e1c6dc893cf6fb340fa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd75dca10dd3d17f17e0037fda2f550f);
#
#
#         var popup_c3546e92022c71176ab6004ab81fc463 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a4a0b0b984624e0fc5c9d538ccff25a = $(`&lt;div id=&quot;html_6a4a0b0b984624e0fc5c9d538ccff25a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c3546e92022c71176ab6004ab81fc463.setContent(html_6a4a0b0b984624e0fc5c9d538ccff25a);
#
#
#
#         marker_9dd0e6fbf43e1e1c6dc893cf6fb340fa.bindPopup(popup_c3546e92022c71176ab6004ab81fc463)
#         ;
#
#
#
#
#             var marker_139b9680e577e5ec3e6369edb52cb058 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd75dca10dd3d17f17e0037fda2f550f);
#
#
#         var popup_a26c1b33bd9c6f0c7089c380e0bb3bfe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cecb261510e27ace6a06c728a15a97a = $(`&lt;div id=&quot;html_8cecb261510e27ace6a06c728a15a97a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a26c1b33bd9c6f0c7089c380e0bb3bfe.setContent(html_8cecb261510e27ace6a06c728a15a97a);
#
#
#
#         marker_139b9680e577e5ec3e6369edb52cb058.bindPopup(popup_a26c1b33bd9c6f0c7089c380e0bb3bfe)
#         ;
#
#
#
#
#             var marker_b74554f9c9bf9486a44d74375d941ffa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd75dca10dd3d17f17e0037fda2f550f);
#
#
#         var popup_df898bd1545dfe55b916e829cecb517d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09c842886a92a4c5bfffbedd309f06e8 = $(`&lt;div id=&quot;html_09c842886a92a4c5bfffbedd309f06e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_df898bd1545dfe55b916e829cecb517d.setContent(html_09c842886a92a4c5bfffbedd309f06e8);
#
#
#
#         marker_b74554f9c9bf9486a44d74375d941ffa.bindPopup(popup_df898bd1545dfe55b916e829cecb517d)
#         ;
#
#
#
#
#             var marker_f96bda4efe075976a3f68a44927c7d0a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd75dca10dd3d17f17e0037fda2f550f);
#
#
#         var popup_b9cc45a5164255ed6c6c7995cb4132b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3297d8c7087604b26ab95ae5e3a31ef = $(`&lt;div id=&quot;html_c3297d8c7087604b26ab95ae5e3a31ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b9cc45a5164255ed6c6c7995cb4132b3.setContent(html_c3297d8c7087604b26ab95ae5e3a31ef);
#
#
#
#         marker_
