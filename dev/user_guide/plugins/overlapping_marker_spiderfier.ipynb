# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_919fa320e02fafccf950343933a01e11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_919fa320e02fafccf950343933a01e11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_919fa320e02fafccf950343933a01e11 = L.map(
#                 &quot;map_919fa320e02fafccf950343933a01e11&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_221f7b1b7bc769a14aaad185ee66b03c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_221f7b1b7bc769a14aaad185ee66b03c.addTo(map_919fa320e02fafccf950343933a01e11);
#
#
#             var marker_98ac082fa001f378ce26dd8b15716542 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_919fa320e02fafccf950343933a01e11);
#
#
#         var popup_1a27de1b805e630e1b3284009d8b54b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cea6646853945f3e39ad6c299eda6039 = $(`&lt;div id=&quot;html_cea6646853945f3e39ad6c299eda6039&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1a27de1b805e630e1b3284009d8b54b7.setContent(html_cea6646853945f3e39ad6c299eda6039);
#
#
#
#         marker_98ac082fa001f378ce26dd8b15716542.bindPopup(popup_1a27de1b805e630e1b3284009d8b54b7)
#         ;
#
#
#
#
#             var marker_fa87c9396c95713bd2a7776873b9b451 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_919fa320e02fafccf950343933a01e11);
#
#
#         var popup_61a01d0acefff8ebd8d4222d6c99c068 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50e8a982b96c95c0f29d84cf0e637a8d = $(`&lt;div id=&quot;html_50e8a982b96c95c0f29d84cf0e637a8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_61a01d0acefff8ebd8d4222d6c99c068.setContent(html_50e8a982b96c95c0f29d84cf0e637a8d);
#
#
#
#         marker_fa87c9396c95713bd2a7776873b9b451.bindPopup(popup_61a01d0acefff8ebd8d4222d6c99c068)
#         ;
#
#
#
#
#             var marker_85302e51fca37e426e92bcb2411c99cb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_919fa320e02fafccf950343933a01e11);
#
#
#         var popup_2ccb92e9acff07c3b4cdb9ee41ff00bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d58f273a04a842fe5b735d5327edebeb = $(`&lt;div id=&quot;html_d58f273a04a842fe5b735d5327edebeb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2ccb92e9acff07c3b4cdb9ee41ff00bf.setContent(html_d58f273a04a842fe5b735d5327edebeb);
#
#
#
#         marker_85302e51fca37e426e92bcb2411c99cb.bindPopup(popup_2ccb92e9acff07c3b4cdb9ee41ff00bf)
#         ;
#
#
#
#
#             var marker_7afcf1adbcc728e49ce7e46591aa5f2b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_919fa320e02fafccf950343933a01e11);
#
#
#         var popup_658be8c424bfc9d8ee696cb3f4b0ebd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_400dd7c328bdf4fe8a3dd0c645c538c8 = $(`&lt;div id=&quot;html_400dd7c328bdf4fe8a3dd0c645c538c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_658be8c424bfc9d8ee696cb3f4b0ebd2.setContent(html_400dd7c328bdf4fe8a3dd0c645c538c8);
#
#
#
#         marker_7afcf1adbcc728e49ce7e46591aa5f2b.bindPopup(popup_658be8c424bfc9d8ee696cb3f4b0ebd2)
#         ;
#
#
#
#
#             var marker_0f74b8b76540125a89da062b79ba190c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_919fa320e02fafccf950343933a01e11);
#
#
#         var popup_66be9d1da49ef5a6aa822241a4fb1389 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22377cb43fc4bb7ba1baef2ac673afb9 = $(`&lt;div id=&quot;html_22377cb43fc4bb7ba1baef2ac673afb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_66be9d1da49ef5a6aa822241a4fb1389.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c53463bc3f6678afdb3b680b94687363 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c53463bc3f6678afdb3b680b94687363&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c53463bc3f6678afdb3b680b94687363 = L.map(
#                 &quot;map_c53463bc3f6678afdb3b680b94687363&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4c51daa2f457439f14382b48eee4e61e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4c51daa2f457439f14382b48eee4e61e.addTo(map_c53463bc3f6678afdb3b680b94687363);
#
#
#             var feature_group_ad528e9e8fc700e696b176b644c2b35b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ad388d5901d4f7a8b0e351206ca984b0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ad528e9e8fc700e696b176b644c2b35b);
#
#
#         var popup_f73c712851727fcfecef69e46676dc2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24e9eb8c3b2cc35f9c3d4d2704ae4b8f = $(`&lt;div id=&quot;html_24e9eb8c3b2cc35f9c3d4d2704ae4b8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f73c712851727fcfecef69e46676dc2a.setContent(html_24e9eb8c3b2cc35f9c3d4d2704ae4b8f);
#
#
#
#         marker_ad388d5901d4f7a8b0e351206ca984b0.bindPopup(popup_f73c712851727fcfecef69e46676dc2a)
#         ;
#
#
#
#
#             var marker_13db4afbf484bad748be9f6e77780e40 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ad528e9e8fc700e696b176b644c2b35b);
#
#
#         var popup_357c307f72b32c975509ab57cd1e8a9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38659876febfc44bf6ce5b24f9c22660 = $(`&lt;div id=&quot;html_38659876febfc44bf6ce5b24f9c22660&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_357c307f72b32c975509ab57cd1e8a9a.setContent(html_38659876febfc44bf6ce5b24f9c22660);
#
#
#
#         marker_13db4afbf484bad748be9f6e77780e40.bindPopup(popup_357c307f72b32c975509ab57cd1e8a9a)
#         ;
#
#
#
#
#             var marker_9b69e82632252cb4926d266e532153ef = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ad528e9e8fc700e696b176b644c2b35b);
#
#
#         var popup_6f21f66b14331554b8aa6f67b5e7db2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4aeb37358c24d82674d4fa29e1a6b575 = $(`&lt;div id=&quot;html_4aeb37358c24d82674d4fa29e1a6b575&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6f21f66b14331554b8aa6f67b5e7db2e.setContent(html_4aeb37358c24d82674d4fa29e1a6b575);
#
#
#
#         marker_9b69e82632252cb4926d266e532153ef.bindPopup(popup_6f21f66b14331554b8aa6f67b5e7db2e)
#         ;
#
#
#
#
#             var marker_c162fbc3a039babe443ef800b2170ea9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ad528e9e8fc700e696b176b644c2b35b);
#
#
#         var popup_ad24ba9237ff808de8e2b048976d314a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46ba94429a45b5357037b56a43438759 = $(`&lt;div id=&quot;html_46ba94429a45b5357037b56a43438759&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ad24ba9237ff808de8e2b048976d314a.setContent(html_46ba94429a45b5357037b56a43438759);
#
#
#
#         marker_c162fbc3a039babe443ef800b2170ea9.bindPopup(popup_ad24ba9237ff808de8e2b048976d314a)
#         ;
#
#
#
#
#             var marker_e49379b07ebd15f7c9b7ed36d32c5c07 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ad528e9e8fc700e696b176b644c2b35b);
#
#
#         var popup_6bb63a69a9bfe5deba8f056e6259088a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1a098a1be7f294f0f48149db8c1b9c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1a098a1be7f294f0f48149db8c1b9c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1a098a1be7f294f0f48149db8c1b9c4 = L.map(
#                 &quot;map_f1a098a1be7f294f0f48149db8c1b9c4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6fe2eb0de6f0f343fb2751dca61a21eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6fe2eb0de6f0f343fb2751dca61a21eb.addTo(map_f1a098a1be7f294f0f48149db8c1b9c4);
#
#
#             var feature_group_ba5606afefb89ea8ba78a55d21206209 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ba5606afefb89ea8ba78a55d21206209.addTo(map_f1a098a1be7f294f0f48149db8c1b9c4);
#
#
#             var feature_group_sub_group_31f0b3bb83b168f76edd11a86bbd5449 = L.featureGroup.subGroup(
#                 feature_group_ba5606afefb89ea8ba78a55d21206209
#             );
#
#
#             var marker_cbe2962c9b9239ebf9d602f9506a59df = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_31f0b3bb83b168f76edd11a86bbd5449);
#
#
#         var popup_108081c543f52919963e036988a10247 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c5a062ef7e38e3b9f18b2e4fccd53be = $(`&lt;div id=&quot;html_9c5a062ef7e38e3b9f18b2e4fccd53be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_108081c543f52919963e036988a10247.setContent(html_9c5a062ef7e38e3b9f18b2e4fccd53be);
#
#
#
#         marker_cbe2962c9b9239ebf9d602f9506a59df.bindPopup(popup_108081c543f52919963e036988a10247)
#         ;
#
#
#
#
#             var marker_fba5cd6e9195394e71d77756659c1ca8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_31f0b3bb83b168f76edd11a86bbd5449);
#
#
#         var popup_7c451cee2148e9c15da5307bc2431d84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfa76d823a4793b662aedc0eadb411cf = $(`&lt;div id=&quot;html_cfa76d823a4793b662aedc0eadb411cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7c451cee2148e9c15da5307bc2431d84.setContent(html_cfa76d823a4793b662aedc0eadb411cf);
#
#
#
#         marker_fba5cd6e9195394e71d77756659c1ca8.bindPopup(popup_7c451cee2148e9c15da5307bc2431d84)
#         ;
#
#
#
#
#             var marker_acd3e7dd33c026b69b92431cd22ca20d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_31f0b3bb83b168f76edd11a86bbd5449);
#
#
#         var popup_db1fed3f3386ed1a3601540fe8c222ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e97e2e2a6af5f61f14ecacec8a8ff364 = $(`&lt;div id=&quot;html_e97e2e2a6af5f61f14ecacec8a8ff364&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_db1fed3f3386ed1a3601540fe8c222ff.setContent(html_e97e2e2a6af5f61f14ecacec8a8ff364);
#
#
#
#         marker_acd3e7dd33c026b69b92431cd22ca20d.bindPopup(popup_db1fed3f3386ed1a3601540fe8c222ff)
#         ;
#
#
#
#
#             var marker_a404ade6318d98f6129799dc69fda390 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_31f0b3bb83b168f76edd11a86bbd5449);
#
#
#         var popup_44878b995dee3e1b275978589307da2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_336c9fa4aa750bb2c02d3407106a7cb5 = $(`&lt;div id=&quot;html_336c9fa4aa750bb2c02d3407106a7cb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_44878b995dee3e1b275978589307da2b.setContent(html_336c9fa4aa750bb2c02d3407106a7cb5);
#
#
#
#         marker_
