# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f03b5919aef12af3139d5cdf073ef728 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f03b5919aef12af3139d5cdf073ef728&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f03b5919aef12af3139d5cdf073ef728 = L.map(
#                 &quot;map_f03b5919aef12af3139d5cdf073ef728&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a04f5e77ec3a291fe70b975a1806adb0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a04f5e77ec3a291fe70b975a1806adb0.addTo(map_f03b5919aef12af3139d5cdf073ef728);
#
#
#             var marker_61a9cf00514738010f4f4a6aecf33957 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f03b5919aef12af3139d5cdf073ef728);
#
#
#         var popup_6edf1697c05ffdd81c0a4bba85b868ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6025dae463b085c3545f3451c1fad86d = $(`&lt;div id=&quot;html_6025dae463b085c3545f3451c1fad86d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6edf1697c05ffdd81c0a4bba85b868ff.setContent(html_6025dae463b085c3545f3451c1fad86d);
#
#
#
#         marker_61a9cf00514738010f4f4a6aecf33957.bindPopup(popup_6edf1697c05ffdd81c0a4bba85b868ff)
#         ;
#
#
#
#
#             var marker_2e190190d9c55302f1957341bf020695 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f03b5919aef12af3139d5cdf073ef728);
#
#
#         var popup_6eea40e5190fa55dfba517a1e83d8fa0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77756d16081b1c89027bc1299e323a91 = $(`&lt;div id=&quot;html_77756d16081b1c89027bc1299e323a91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6eea40e5190fa55dfba517a1e83d8fa0.setContent(html_77756d16081b1c89027bc1299e323a91);
#
#
#
#         marker_2e190190d9c55302f1957341bf020695.bindPopup(popup_6eea40e5190fa55dfba517a1e83d8fa0)
#         ;
#
#
#
#
#             var marker_2d7f6b67df1abbc17eeff3ce76c368c2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f03b5919aef12af3139d5cdf073ef728);
#
#
#         var popup_bdb22fa64c6896ed8c4b2ed62a35976c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06485476f3f84fe03305541a9a6883a1 = $(`&lt;div id=&quot;html_06485476f3f84fe03305541a9a6883a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bdb22fa64c6896ed8c4b2ed62a35976c.setContent(html_06485476f3f84fe03305541a9a6883a1);
#
#
#
#         marker_2d7f6b67df1abbc17eeff3ce76c368c2.bindPopup(popup_bdb22fa64c6896ed8c4b2ed62a35976c)
#         ;
#
#
#
#
#             var marker_d679fd9caaea6f65dc40e6a4a77147de = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f03b5919aef12af3139d5cdf073ef728);
#
#
#         var popup_903fd7d949cdc3875fb54fde20b8be5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eed11d722a7c45be2887124efc900149 = $(`&lt;div id=&quot;html_eed11d722a7c45be2887124efc900149&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_903fd7d949cdc3875fb54fde20b8be5b.setContent(html_eed11d722a7c45be2887124efc900149);
#
#
#
#         marker_d679fd9caaea6f65dc40e6a4a77147de.bindPopup(popup_903fd7d949cdc3875fb54fde20b8be5b)
#         ;
#
#
#
#
#             var marker_c8f74dcddd52e62fb129296eb7bf8d7f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f03b5919aef12af3139d5cdf073ef728);
#
#
#         var popup_11d4f76d76655bafe76bd6e44ffa5e87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1948e7faaeddec4f0da89615c11bc3ad = $(`&lt;div id=&quot;html_1948e7faaeddec4f0da89615c11bc3ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_11d4f76d76655bafe76bd6e44ffa5e87.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1b16cdffc7db54655821e35810ed5ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1b16cdffc7db54655821e35810ed5ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e1b16cdffc7db54655821e35810ed5ce = L.map(
#                 &quot;map_e1b16cdffc7db54655821e35810ed5ce&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03f9e10b52c0aeb9509fb94967081af2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_03f9e10b52c0aeb9509fb94967081af2.addTo(map_e1b16cdffc7db54655821e35810ed5ce);
#
#
#             var feature_group_1fa1c7928e4d1eded2298302034a9126 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8beaebbd625ff8144bd0f8cd8e169bcd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1fa1c7928e4d1eded2298302034a9126);
#
#
#         var popup_e6a9428efa386e0c1e0d49b2ffe2ce16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdb61e0ef5d3a8d0746b8864cc460b9c = $(`&lt;div id=&quot;html_fdb61e0ef5d3a8d0746b8864cc460b9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e6a9428efa386e0c1e0d49b2ffe2ce16.setContent(html_fdb61e0ef5d3a8d0746b8864cc460b9c);
#
#
#
#         marker_8beaebbd625ff8144bd0f8cd8e169bcd.bindPopup(popup_e6a9428efa386e0c1e0d49b2ffe2ce16)
#         ;
#
#
#
#
#             var marker_db68bc9ed8c3186d3c36c82e6cffbbb9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1fa1c7928e4d1eded2298302034a9126);
#
#
#         var popup_2d3841915f464687e3220282fe2a6816 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5751086b620db0925ba79790cfe26f18 = $(`&lt;div id=&quot;html_5751086b620db0925ba79790cfe26f18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2d3841915f464687e3220282fe2a6816.setContent(html_5751086b620db0925ba79790cfe26f18);
#
#
#
#         marker_db68bc9ed8c3186d3c36c82e6cffbbb9.bindPopup(popup_2d3841915f464687e3220282fe2a6816)
#         ;
#
#
#
#
#             var marker_51c0fa93405073bff68597de4c304411 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1fa1c7928e4d1eded2298302034a9126);
#
#
#         var popup_3e40c74b6d5f469a294700af30dc4891 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a2d1cab97d487eb986d790955e9f00e = $(`&lt;div id=&quot;html_7a2d1cab97d487eb986d790955e9f00e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3e40c74b6d5f469a294700af30dc4891.setContent(html_7a2d1cab97d487eb986d790955e9f00e);
#
#
#
#         marker_51c0fa93405073bff68597de4c304411.bindPopup(popup_3e40c74b6d5f469a294700af30dc4891)
#         ;
#
#
#
#
#             var marker_6cf1d06f9330dc8bc0ef3ae3f8f01690 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1fa1c7928e4d1eded2298302034a9126);
#
#
#         var popup_354a3112acc6b404033c32d5e6feb8b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8f7c47322308d2f989f4de450c9a1c0 = $(`&lt;div id=&quot;html_e8f7c47322308d2f989f4de450c9a1c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_354a3112acc6b404033c32d5e6feb8b7.setContent(html_e8f7c47322308d2f989f4de450c9a1c0);
#
#
#
#         marker_6cf1d06f9330dc8bc0ef3ae3f8f01690.bindPopup(popup_354a3112acc6b404033c32d5e6feb8b7)
#         ;
#
#
#
#
#             var marker_5974e9f805a6847ad563a884b8024e77 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1fa1c7928e4d1eded2298302034a9126);
#
#
#         var popup_081286ff7e96763f84d27932c1536afb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7edb1214a09ca02c38d3493227396a6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7edb1214a09ca02c38d3493227396a6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7edb1214a09ca02c38d3493227396a6a = L.map(
#                 &quot;map_7edb1214a09ca02c38d3493227396a6a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2e1a52aedaaa32126a7f8f6ee2edece = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a2e1a52aedaaa32126a7f8f6ee2edece.addTo(map_7edb1214a09ca02c38d3493227396a6a);
#
#
#             var feature_group_a20133631dd6bad2ad5c97488b517133 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a20133631dd6bad2ad5c97488b517133.addTo(map_7edb1214a09ca02c38d3493227396a6a);
#
#
#             var feature_group_sub_group_23068320a937342b9a72bcb8521d13af = L.featureGroup.subGroup(
#                 feature_group_a20133631dd6bad2ad5c97488b517133
#             );
#
#
#             var marker_30d5d59d7b4229797e0ba0e9e8e300f4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_23068320a937342b9a72bcb8521d13af);
#
#
#         var popup_4ddd725225c00bca39740401d3af6fe8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb624a95f8d6b172f0674679d7269a32 = $(`&lt;div id=&quot;html_eb624a95f8d6b172f0674679d7269a32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4ddd725225c00bca39740401d3af6fe8.setContent(html_eb624a95f8d6b172f0674679d7269a32);
#
#
#
#         marker_30d5d59d7b4229797e0ba0e9e8e300f4.bindPopup(popup_4ddd725225c00bca39740401d3af6fe8)
#         ;
#
#
#
#
#             var marker_7285f228390d43e60a9676b1dc726231 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_23068320a937342b9a72bcb8521d13af);
#
#
#         var popup_dd0aeed3157645cfc923f3eae4fe8390 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62f993bfc63f75b0efd060fd233a96c5 = $(`&lt;div id=&quot;html_62f993bfc63f75b0efd060fd233a96c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_dd0aeed3157645cfc923f3eae4fe8390.setContent(html_62f993bfc63f75b0efd060fd233a96c5);
#
#
#
#         marker_7285f228390d43e60a9676b1dc726231.bindPopup(popup_dd0aeed3157645cfc923f3eae4fe8390)
#         ;
#
#
#
#
#             var marker_54e53561a5756b65e826453389570916 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_23068320a937342b9a72bcb8521d13af);
#
#
#         var popup_6cf693ae01e7eb2068318c52204471bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9f4bd452a85ddbd8ed7fc7d88f3c35d = $(`&lt;div id=&quot;html_f9f4bd452a85ddbd8ed7fc7d88f3c35d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6cf693ae01e7eb2068318c52204471bf.setContent(html_f9f4bd452a85ddbd8ed7fc7d88f3c35d);
#
#
#
#         marker_54e53561a5756b65e826453389570916.bindPopup(popup_6cf693ae01e7eb2068318c52204471bf)
#         ;
#
#
#
#
#             var marker_5e6b0f7b4e7ad8f549f50c9fe03b4af9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_23068320a937342b9a72bcb8521d13af);
#
#
#         var popup_993ca9f6769d4b5b38426701e9a0c99d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60af41405e91973f5ad5860ac9fba65e = $(`&lt;div id=&quot;html_60af41405e91973f5ad5860ac9fba65e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_993ca9f6769d4b5b38426701e9a0c99d.setContent(html_60af41405e91973f5ad5860ac9fba65e);
#
#
#
#         marker_
