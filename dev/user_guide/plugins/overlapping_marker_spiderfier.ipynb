# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4949574c670aaf67b8e8cc63f9db773 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4949574c670aaf67b8e8cc63f9db773&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4949574c670aaf67b8e8cc63f9db773 = L.map(
#                 &quot;map_e4949574c670aaf67b8e8cc63f9db773&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e393d874bbb6e7eb0436ec1f2fd1c568 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e393d874bbb6e7eb0436ec1f2fd1c568.addTo(map_e4949574c670aaf67b8e8cc63f9db773);
#
#
#             var marker_0fc4dd0a8ef4511009e844ea9faa149a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e4949574c670aaf67b8e8cc63f9db773);
#
#
#         var popup_49b132d382411b60624e82a8fcb9a38f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d080e02cf3216c60b554900e224c191 = $(`&lt;div id=&quot;html_9d080e02cf3216c60b554900e224c191&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_49b132d382411b60624e82a8fcb9a38f.setContent(html_9d080e02cf3216c60b554900e224c191);
#
#
#
#         marker_0fc4dd0a8ef4511009e844ea9faa149a.bindPopup(popup_49b132d382411b60624e82a8fcb9a38f)
#         ;
#
#
#
#
#             var marker_89e5663ad07feb7dce69104e3669da1a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e4949574c670aaf67b8e8cc63f9db773);
#
#
#         var popup_60f62d579cd0baa01aa310fd830541b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec29a16d65ec8577a145c111f7460d38 = $(`&lt;div id=&quot;html_ec29a16d65ec8577a145c111f7460d38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_60f62d579cd0baa01aa310fd830541b1.setContent(html_ec29a16d65ec8577a145c111f7460d38);
#
#
#
#         marker_89e5663ad07feb7dce69104e3669da1a.bindPopup(popup_60f62d579cd0baa01aa310fd830541b1)
#         ;
#
#
#
#
#             var marker_4af25b02a89f3aae2a3f17d0e9756c56 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e4949574c670aaf67b8e8cc63f9db773);
#
#
#         var popup_9c9062c420238b99cad8f501741aa39e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8db93d370eb33561d58fb7663efd0e4f = $(`&lt;div id=&quot;html_8db93d370eb33561d58fb7663efd0e4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9c9062c420238b99cad8f501741aa39e.setContent(html_8db93d370eb33561d58fb7663efd0e4f);
#
#
#
#         marker_4af25b02a89f3aae2a3f17d0e9756c56.bindPopup(popup_9c9062c420238b99cad8f501741aa39e)
#         ;
#
#
#
#
#             var marker_cd2bad027de38ba7f8fda85efb41371f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e4949574c670aaf67b8e8cc63f9db773);
#
#
#         var popup_8ab5765efdf455682e74f8592fe060f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a4d2d6bd21cf5727e254a2f04105da5 = $(`&lt;div id=&quot;html_1a4d2d6bd21cf5727e254a2f04105da5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8ab5765efdf455682e74f8592fe060f0.setContent(html_1a4d2d6bd21cf5727e254a2f04105da5);
#
#
#
#         marker_cd2bad027de38ba7f8fda85efb41371f.bindPopup(popup_8ab5765efdf455682e74f8592fe060f0)
#         ;
#
#
#
#
#             var marker_17f52ac7920c1948ecfd857ab5ee06e0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e4949574c670aaf67b8e8cc63f9db773);
#
#
#         var popup_b9fce37b57ffc2d557d2bacc042e3771 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_192cee450325f677a758915f9988df71 = $(`&lt;div id=&quot;html_192cee450325f677a758915f9988df71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b9fce37b57ffc2d557d2bacc042e3771.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2572e3be8ea20ad178af4e8741ab9717 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2572e3be8ea20ad178af4e8741ab9717&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2572e3be8ea20ad178af4e8741ab9717 = L.map(
#                 &quot;map_2572e3be8ea20ad178af4e8741ab9717&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d60f5eb466f209e13e5c8e7b052e2dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d60f5eb466f209e13e5c8e7b052e2dd.addTo(map_2572e3be8ea20ad178af4e8741ab9717);
#
#
#             var feature_group_dea662bbcf33d9f0c7056768f5fd207d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9c99887c1ca08589485a2aee82b943e4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_dea662bbcf33d9f0c7056768f5fd207d);
#
#
#         var popup_69d1e489c60bb67e61e337efef1505df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bb716a87a4a2c9d1cffbd992e4f6e71 = $(`&lt;div id=&quot;html_4bb716a87a4a2c9d1cffbd992e4f6e71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_69d1e489c60bb67e61e337efef1505df.setContent(html_4bb716a87a4a2c9d1cffbd992e4f6e71);
#
#
#
#         marker_9c99887c1ca08589485a2aee82b943e4.bindPopup(popup_69d1e489c60bb67e61e337efef1505df)
#         ;
#
#
#
#
#             var marker_d6b4d38865b79c90e8a6a4ae280f37f9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_dea662bbcf33d9f0c7056768f5fd207d);
#
#
#         var popup_5fc45be40e8d78c811c138361f879a5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5252a2247a7a4b2bb13b1526735350b = $(`&lt;div id=&quot;html_e5252a2247a7a4b2bb13b1526735350b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5fc45be40e8d78c811c138361f879a5f.setContent(html_e5252a2247a7a4b2bb13b1526735350b);
#
#
#
#         marker_d6b4d38865b79c90e8a6a4ae280f37f9.bindPopup(popup_5fc45be40e8d78c811c138361f879a5f)
#         ;
#
#
#
#
#             var marker_fcb7da8e296ff37b4f00fd493e2562e6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_dea662bbcf33d9f0c7056768f5fd207d);
#
#
#         var popup_843d18b69dbad4b792075b917092e7f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1558957c7cbfaf7d31d241d8edbd6348 = $(`&lt;div id=&quot;html_1558957c7cbfaf7d31d241d8edbd6348&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_843d18b69dbad4b792075b917092e7f4.setContent(html_1558957c7cbfaf7d31d241d8edbd6348);
#
#
#
#         marker_fcb7da8e296ff37b4f00fd493e2562e6.bindPopup(popup_843d18b69dbad4b792075b917092e7f4)
#         ;
#
#
#
#
#             var marker_19bf44ddc2e91a011d118572b11c2591 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_dea662bbcf33d9f0c7056768f5fd207d);
#
#
#         var popup_030e1e1ac352f95afdf95ca329fde070 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0fd2e09946bb094550d2c09f2e577634 = $(`&lt;div id=&quot;html_0fd2e09946bb094550d2c09f2e577634&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_030e1e1ac352f95afdf95ca329fde070.setContent(html_0fd2e09946bb094550d2c09f2e577634);
#
#
#
#         marker_19bf44ddc2e91a011d118572b11c2591.bindPopup(popup_030e1e1ac352f95afdf95ca329fde070)
#         ;
#
#
#
#
#             var marker_a40a404db0d3173de3ef543e13cb0252 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_dea662bbcf33d9f0c7056768f5fd207d);
#
#
#         var popup_75448714d7a95007289531c9986429e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_894b97b3ba5c84c4ec05489a78fc2a2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_894b97b3ba5c84c4ec05489a78fc2a2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_894b97b3ba5c84c4ec05489a78fc2a2b = L.map(
#                 &quot;map_894b97b3ba5c84c4ec05489a78fc2a2b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a4772f247c75c2b59c837b24a99956d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a4772f247c75c2b59c837b24a99956d3.addTo(map_894b97b3ba5c84c4ec05489a78fc2a2b);
#
#
#             var feature_group_65e5f8ad2f6e5f8d0a48945393764910 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_65e5f8ad2f6e5f8d0a48945393764910.addTo(map_894b97b3ba5c84c4ec05489a78fc2a2b);
#
#
#             var feature_group_sub_group_cb5f62e289c248e780b5a7aaca8d2bab = L.featureGroup.subGroup(
#                 feature_group_65e5f8ad2f6e5f8d0a48945393764910
#             );
#
#
#             var marker_90b2c402f7caf8b8bf2b0ef7fa4e8601 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cb5f62e289c248e780b5a7aaca8d2bab);
#
#
#         var popup_0ada988eb8c6a748e2c9a35a7a2ae76e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f81b355e48aaa1c40a176a88c35ef794 = $(`&lt;div id=&quot;html_f81b355e48aaa1c40a176a88c35ef794&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0ada988eb8c6a748e2c9a35a7a2ae76e.setContent(html_f81b355e48aaa1c40a176a88c35ef794);
#
#
#
#         marker_90b2c402f7caf8b8bf2b0ef7fa4e8601.bindPopup(popup_0ada988eb8c6a748e2c9a35a7a2ae76e)
#         ;
#
#
#
#
#             var marker_33eba590f6c0ebc8e4e57b65347def39 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cb5f62e289c248e780b5a7aaca8d2bab);
#
#
#         var popup_bb09f2e376d8001f3d736ed6e83eed4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a35a420507a87b949c024f4759295edc = $(`&lt;div id=&quot;html_a35a420507a87b949c024f4759295edc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bb09f2e376d8001f3d736ed6e83eed4f.setContent(html_a35a420507a87b949c024f4759295edc);
#
#
#
#         marker_33eba590f6c0ebc8e4e57b65347def39.bindPopup(popup_bb09f2e376d8001f3d736ed6e83eed4f)
#         ;
#
#
#
#
#             var marker_4a48b0a47281e6088b1279aa04a87a24 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cb5f62e289c248e780b5a7aaca8d2bab);
#
#
#         var popup_8837f5342e9fefe0844692eb790a5766 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0b8de48febb31bd3a038d1540dba2a6 = $(`&lt;div id=&quot;html_f0b8de48febb31bd3a038d1540dba2a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8837f5342e9fefe0844692eb790a5766.setContent(html_f0b8de48febb31bd3a038d1540dba2a6);
#
#
#
#         marker_4a48b0a47281e6088b1279aa04a87a24.bindPopup(popup_8837f5342e9fefe0844692eb790a5766)
#         ;
#
#
#
#
#             var marker_ca98af841e743c330fca664b6e97f7e0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cb5f62e289c248e780b5a7aaca8d2bab);
#
#
#         var popup_5915cc3bf38d154f9daad4a4dfcc0476 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08aab5275ab114cdf5503defc5636b98 = $(`&lt;div id=&quot;html_08aab5275ab114cdf5503defc5636b98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5915cc3bf38d154f9daad4a4dfcc0476.setContent(html_08aab5275ab114cdf5503defc5636b98);
#
#
#
#         marker_
