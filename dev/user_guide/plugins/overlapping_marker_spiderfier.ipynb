# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04026304e7dae99e12256e791c29618d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04026304e7dae99e12256e791c29618d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04026304e7dae99e12256e791c29618d = L.map(
#                 &quot;map_04026304e7dae99e12256e791c29618d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82f56b7c5fb9beb1c07b1b86541a739b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_82f56b7c5fb9beb1c07b1b86541a739b.addTo(map_04026304e7dae99e12256e791c29618d);
#
#
#             var marker_44727dcb9e8bb19f04534c3bc87b2d72 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_04026304e7dae99e12256e791c29618d);
#
#
#         var popup_9a1ac1f4dc95d06cc751cc2eaedbd8be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9d7279681a886b5706d45ccbbcfc27f = $(`&lt;div id=&quot;html_c9d7279681a886b5706d45ccbbcfc27f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9a1ac1f4dc95d06cc751cc2eaedbd8be.setContent(html_c9d7279681a886b5706d45ccbbcfc27f);
#
#
#
#         marker_44727dcb9e8bb19f04534c3bc87b2d72.bindPopup(popup_9a1ac1f4dc95d06cc751cc2eaedbd8be)
#         ;
#
#
#
#
#             var marker_b20e8fa76e8be3c67108d2e7c3be9ed4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_04026304e7dae99e12256e791c29618d);
#
#
#         var popup_3342bdcac84e197ce143ad42d879d579 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba7c636eefabaa763f288905c28500f0 = $(`&lt;div id=&quot;html_ba7c636eefabaa763f288905c28500f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3342bdcac84e197ce143ad42d879d579.setContent(html_ba7c636eefabaa763f288905c28500f0);
#
#
#
#         marker_b20e8fa76e8be3c67108d2e7c3be9ed4.bindPopup(popup_3342bdcac84e197ce143ad42d879d579)
#         ;
#
#
#
#
#             var marker_3bc86785a3e3718c14d46b8baf5a0916 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_04026304e7dae99e12256e791c29618d);
#
#
#         var popup_ace4b624938a74d3761b0b31159ff8d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6dae95206afaebb4e1e918f63f52cb3 = $(`&lt;div id=&quot;html_b6dae95206afaebb4e1e918f63f52cb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ace4b624938a74d3761b0b31159ff8d0.setContent(html_b6dae95206afaebb4e1e918f63f52cb3);
#
#
#
#         marker_3bc86785a3e3718c14d46b8baf5a0916.bindPopup(popup_ace4b624938a74d3761b0b31159ff8d0)
#         ;
#
#
#
#
#             var marker_1fdf98b8faaac6dfbe34474c580f79a5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_04026304e7dae99e12256e791c29618d);
#
#
#         var popup_bdf84e476bc3da51c2d616d18cabf8e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_998329fd2f6b6e21c9914ad1c3575bc8 = $(`&lt;div id=&quot;html_998329fd2f6b6e21c9914ad1c3575bc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bdf84e476bc3da51c2d616d18cabf8e6.setContent(html_998329fd2f6b6e21c9914ad1c3575bc8);
#
#
#
#         marker_1fdf98b8faaac6dfbe34474c580f79a5.bindPopup(popup_bdf84e476bc3da51c2d616d18cabf8e6)
#         ;
#
#
#
#
#             var marker_0c7a0f2f4020b8ddd11bf992ab3ccea2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_04026304e7dae99e12256e791c29618d);
#
#
#         var popup_5e25ddff67ed1f2c8803b5194508aead = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d7c8dfc4006b3cc2c0e806fd6577b58 = $(`&lt;div id=&quot;html_1d7c8dfc4006b3cc2c0e806fd6577b58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5e25ddff67ed1f2c8803b5194508aead.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6afe0831f560dd8bc3bd5127be533b8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6afe0831f560dd8bc3bd5127be533b8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6afe0831f560dd8bc3bd5127be533b8f = L.map(
#                 &quot;map_6afe0831f560dd8bc3bd5127be533b8f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eeb2f17049916d438d6d0210ae5b8331 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eeb2f17049916d438d6d0210ae5b8331.addTo(map_6afe0831f560dd8bc3bd5127be533b8f);
#
#
#             var feature_group_66bbdbbf5f4cd326087f8cbf49b86fcf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7483212fb8c9f755fcf1cf32ddb69e66 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_66bbdbbf5f4cd326087f8cbf49b86fcf);
#
#
#         var popup_1d677ddd62e7fa1ea61876cb6c935d99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48b08a611a9cd0ecba33207de201fd55 = $(`&lt;div id=&quot;html_48b08a611a9cd0ecba33207de201fd55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1d677ddd62e7fa1ea61876cb6c935d99.setContent(html_48b08a611a9cd0ecba33207de201fd55);
#
#
#
#         marker_7483212fb8c9f755fcf1cf32ddb69e66.bindPopup(popup_1d677ddd62e7fa1ea61876cb6c935d99)
#         ;
#
#
#
#
#             var marker_7459503091fb10afc9f6e7b7d256d67f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_66bbdbbf5f4cd326087f8cbf49b86fcf);
#
#
#         var popup_0982f91cc76f498ee9b5aea979737c48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_813676e4b386890054881515f309f883 = $(`&lt;div id=&quot;html_813676e4b386890054881515f309f883&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0982f91cc76f498ee9b5aea979737c48.setContent(html_813676e4b386890054881515f309f883);
#
#
#
#         marker_7459503091fb10afc9f6e7b7d256d67f.bindPopup(popup_0982f91cc76f498ee9b5aea979737c48)
#         ;
#
#
#
#
#             var marker_789ae97291c4f8bbd0a49009b26a4c91 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_66bbdbbf5f4cd326087f8cbf49b86fcf);
#
#
#         var popup_df2b47cdd58608a9c30ac797c99bf628 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45b27dada091649d7eef7105ac4f80a5 = $(`&lt;div id=&quot;html_45b27dada091649d7eef7105ac4f80a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_df2b47cdd58608a9c30ac797c99bf628.setContent(html_45b27dada091649d7eef7105ac4f80a5);
#
#
#
#         marker_789ae97291c4f8bbd0a49009b26a4c91.bindPopup(popup_df2b47cdd58608a9c30ac797c99bf628)
#         ;
#
#
#
#
#             var marker_b3c381e5033b8e058580129f34eb48ec = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_66bbdbbf5f4cd326087f8cbf49b86fcf);
#
#
#         var popup_dcbad63fbc1366cc6c23020771723860 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bdde4909d10f8fd0808ac88cfc266f9 = $(`&lt;div id=&quot;html_4bdde4909d10f8fd0808ac88cfc266f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_dcbad63fbc1366cc6c23020771723860.setContent(html_4bdde4909d10f8fd0808ac88cfc266f9);
#
#
#
#         marker_b3c381e5033b8e058580129f34eb48ec.bindPopup(popup_dcbad63fbc1366cc6c23020771723860)
#         ;
#
#
#
#
#             var marker_3ca5e7d1c1da0abe416697b94f8205c6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_66bbdbbf5f4cd326087f8cbf49b86fcf);
#
#
#         var popup_18c43652722d1a4f4c043278fcd55600 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff98fd1573a0bc97d9515042deef5a04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff98fd1573a0bc97d9515042deef5a04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff98fd1573a0bc97d9515042deef5a04 = L.map(
#                 &quot;map_ff98fd1573a0bc97d9515042deef5a04&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3473c438f693b0c55b46a152f828e97 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3473c438f693b0c55b46a152f828e97.addTo(map_ff98fd1573a0bc97d9515042deef5a04);
#
#
#             var feature_group_218dc8f360aea8c9cd4872474ac4d5c9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_218dc8f360aea8c9cd4872474ac4d5c9.addTo(map_ff98fd1573a0bc97d9515042deef5a04);
#
#
#             var feature_group_sub_group_b6fadbe9be4d0b739872ed9b09ce196b = L.featureGroup.subGroup(
#                 feature_group_218dc8f360aea8c9cd4872474ac4d5c9
#             );
#
#
#             var marker_a44bfd0ad83b19f19529059cf8216257 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b6fadbe9be4d0b739872ed9b09ce196b);
#
#
#         var popup_ffdeed224b5fca0cb29c72b674069ce6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b23979d8ca912527cd5fd5a9ca293fe0 = $(`&lt;div id=&quot;html_b23979d8ca912527cd5fd5a9ca293fe0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ffdeed224b5fca0cb29c72b674069ce6.setContent(html_b23979d8ca912527cd5fd5a9ca293fe0);
#
#
#
#         marker_a44bfd0ad83b19f19529059cf8216257.bindPopup(popup_ffdeed224b5fca0cb29c72b674069ce6)
#         ;
#
#
#
#
#             var marker_479b34a48f3dc8d6fa3663d55f2df541 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b6fadbe9be4d0b739872ed9b09ce196b);
#
#
#         var popup_d031ba641945116d931aa856149d5020 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f3b819985a15d1ea4a4ca63209cfeb3 = $(`&lt;div id=&quot;html_9f3b819985a15d1ea4a4ca63209cfeb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d031ba641945116d931aa856149d5020.setContent(html_9f3b819985a15d1ea4a4ca63209cfeb3);
#
#
#
#         marker_479b34a48f3dc8d6fa3663d55f2df541.bindPopup(popup_d031ba641945116d931aa856149d5020)
#         ;
#
#
#
#
#             var marker_a7f0ef0596f7bf2dc7d704468f9359d3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b6fadbe9be4d0b739872ed9b09ce196b);
#
#
#         var popup_3a9d4f1ec9ad549489d8e051c5a67665 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c195986bc549b55726bb0e6cd66b9c5 = $(`&lt;div id=&quot;html_2c195986bc549b55726bb0e6cd66b9c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3a9d4f1ec9ad549489d8e051c5a67665.setContent(html_2c195986bc549b55726bb0e6cd66b9c5);
#
#
#
#         marker_a7f0ef0596f7bf2dc7d704468f9359d3.bindPopup(popup_3a9d4f1ec9ad549489d8e051c5a67665)
#         ;
#
#
#
#
#             var marker_ab69ffa6b6c85edf0781d6d616740a9f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b6fadbe9be4d0b739872ed9b09ce196b);
#
#
#         var popup_c865e3f05a071d2ebcebc98878197b02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc038bfaeb4a0569477dd6bfb48ee63a = $(`&lt;div id=&quot;html_fc038bfaeb4a0569477dd6bfb48ee63a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c865e3f05a071d2ebcebc98878197b02.setContent(html_fc038bfaeb4a0569477dd6bfb48ee63a);
#
#
#
#         marker_
