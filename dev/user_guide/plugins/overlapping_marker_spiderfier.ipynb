# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7a96f42eb7e458617d4f6bfbe7b3460 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7a96f42eb7e458617d4f6bfbe7b3460&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7a96f42eb7e458617d4f6bfbe7b3460 = L.map(
#                 &quot;map_e7a96f42eb7e458617d4f6bfbe7b3460&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef5152539e77533fb9a78e2172f243c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ef5152539e77533fb9a78e2172f243c2.addTo(map_e7a96f42eb7e458617d4f6bfbe7b3460);
#
#
#             var marker_bde58282684bad8b0daaf9fbc2d43434 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e7a96f42eb7e458617d4f6bfbe7b3460);
#
#
#         var popup_3c714fd41d06828a2af9d1013d4ef73f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60b7d78b0605d3a349dc191be83d02ad = $(`&lt;div id=&quot;html_60b7d78b0605d3a349dc191be83d02ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3c714fd41d06828a2af9d1013d4ef73f.setContent(html_60b7d78b0605d3a349dc191be83d02ad);
#
#
#
#         marker_bde58282684bad8b0daaf9fbc2d43434.bindPopup(popup_3c714fd41d06828a2af9d1013d4ef73f)
#         ;
#
#
#
#
#             var marker_0360d21e599c43ddf33ce50614db6169 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e7a96f42eb7e458617d4f6bfbe7b3460);
#
#
#         var popup_9532b298ef4d99762ecd760c119b3751 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe122947e7dd5a815ec9b8ebc360736e = $(`&lt;div id=&quot;html_fe122947e7dd5a815ec9b8ebc360736e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9532b298ef4d99762ecd760c119b3751.setContent(html_fe122947e7dd5a815ec9b8ebc360736e);
#
#
#
#         marker_0360d21e599c43ddf33ce50614db6169.bindPopup(popup_9532b298ef4d99762ecd760c119b3751)
#         ;
#
#
#
#
#             var marker_928d2f2a0389f7db13a92ee733540000 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e7a96f42eb7e458617d4f6bfbe7b3460);
#
#
#         var popup_7813fe3824333b8fd1481161744cf853 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6010ea34943de7d91f402bfed3633d9b = $(`&lt;div id=&quot;html_6010ea34943de7d91f402bfed3633d9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7813fe3824333b8fd1481161744cf853.setContent(html_6010ea34943de7d91f402bfed3633d9b);
#
#
#
#         marker_928d2f2a0389f7db13a92ee733540000.bindPopup(popup_7813fe3824333b8fd1481161744cf853)
#         ;
#
#
#
#
#             var marker_3959a5f8085953ddc08ad36c43594cd3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e7a96f42eb7e458617d4f6bfbe7b3460);
#
#
#         var popup_25bbf162795033c4f19e3f403052c9bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d153a348a2103c5320995e12749fe2ae = $(`&lt;div id=&quot;html_d153a348a2103c5320995e12749fe2ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_25bbf162795033c4f19e3f403052c9bd.setContent(html_d153a348a2103c5320995e12749fe2ae);
#
#
#
#         marker_3959a5f8085953ddc08ad36c43594cd3.bindPopup(popup_25bbf162795033c4f19e3f403052c9bd)
#         ;
#
#
#
#
#             var marker_4be3fdd28026ce801e857ec21ef6ef5b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e7a96f42eb7e458617d4f6bfbe7b3460);
#
#
#         var popup_4d8e859305903aa8c50f327a718b5a15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_722f24e0fd0fce9dc343177a9fef803b = $(`&lt;div id=&quot;html_722f24e0fd0fce9dc343177a9fef803b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4d8e859305903aa8c50f327a718b5a15.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea12369c22c3883c79b660ef5a16e005 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea12369c22c3883c79b660ef5a16e005&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea12369c22c3883c79b660ef5a16e005 = L.map(
#                 &quot;map_ea12369c22c3883c79b660ef5a16e005&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f849fdafcf63c790406bc41b8b300c06 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f849fdafcf63c790406bc41b8b300c06.addTo(map_ea12369c22c3883c79b660ef5a16e005);
#
#
#             var feature_group_075b16b76d0bbc4767df3eaefbe4bbad = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e6388324977313936c4e09f4ed347fe3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_075b16b76d0bbc4767df3eaefbe4bbad);
#
#
#         var popup_335af684b8586ba3307078396eaa772a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b29dadc7213c949231a88026655a5636 = $(`&lt;div id=&quot;html_b29dadc7213c949231a88026655a5636&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_335af684b8586ba3307078396eaa772a.setContent(html_b29dadc7213c949231a88026655a5636);
#
#
#
#         marker_e6388324977313936c4e09f4ed347fe3.bindPopup(popup_335af684b8586ba3307078396eaa772a)
#         ;
#
#
#
#
#             var marker_4c05040c6b2617a8bb01ab252cf221c0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_075b16b76d0bbc4767df3eaefbe4bbad);
#
#
#         var popup_54a76b0ccb3ffdb9ed1a62dd72855687 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6411d4c3014eaf8aef42137eac307c76 = $(`&lt;div id=&quot;html_6411d4c3014eaf8aef42137eac307c76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_54a76b0ccb3ffdb9ed1a62dd72855687.setContent(html_6411d4c3014eaf8aef42137eac307c76);
#
#
#
#         marker_4c05040c6b2617a8bb01ab252cf221c0.bindPopup(popup_54a76b0ccb3ffdb9ed1a62dd72855687)
#         ;
#
#
#
#
#             var marker_d591e1f47ff4c2e80d400ca5454dc9c3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_075b16b76d0bbc4767df3eaefbe4bbad);
#
#
#         var popup_4e35d0122c8ca58de6e8dad4064b32f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90fecc00ea2a412f5a961199b636b040 = $(`&lt;div id=&quot;html_90fecc00ea2a412f5a961199b636b040&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4e35d0122c8ca58de6e8dad4064b32f5.setContent(html_90fecc00ea2a412f5a961199b636b040);
#
#
#
#         marker_d591e1f47ff4c2e80d400ca5454dc9c3.bindPopup(popup_4e35d0122c8ca58de6e8dad4064b32f5)
#         ;
#
#
#
#
#             var marker_25198405017846214d97461bde27f070 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_075b16b76d0bbc4767df3eaefbe4bbad);
#
#
#         var popup_29fb4ffabfc073e64f36f8b351ed5c01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e18eba8e9909941e9bd4cf5069efcca3 = $(`&lt;div id=&quot;html_e18eba8e9909941e9bd4cf5069efcca3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_29fb4ffabfc073e64f36f8b351ed5c01.setContent(html_e18eba8e9909941e9bd4cf5069efcca3);
#
#
#
#         marker_25198405017846214d97461bde27f070.bindPopup(popup_29fb4ffabfc073e64f36f8b351ed5c01)
#         ;
#
#
#
#
#             var marker_f8baaac2e3d8b41b83daa3ce26883cc9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_075b16b76d0bbc4767df3eaefbe4bbad);
#
#
#         var popup_760344a16e4cbcea984e48d2f8a24e9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc64ee4be7b078d6398eee567715b661 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc64ee4be7b078d6398eee567715b661&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc64ee4be7b078d6398eee567715b661 = L.map(
#                 &quot;map_dc64ee4be7b078d6398eee567715b661&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3d7c436aa64e6c7291c38877153062f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e3d7c436aa64e6c7291c38877153062f.addTo(map_dc64ee4be7b078d6398eee567715b661);
#
#
#             var feature_group_e1e1e5502fb114bee57ca3c2ae3d688b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e1e1e5502fb114bee57ca3c2ae3d688b.addTo(map_dc64ee4be7b078d6398eee567715b661);
#
#
#             var feature_group_sub_group_c3551fc65b4fbc041beb4b00eb7e8694 = L.featureGroup.subGroup(
#                 feature_group_e1e1e5502fb114bee57ca3c2ae3d688b
#             );
#
#
#             var marker_cd349838e683bc87cd4bef733e8ff560 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c3551fc65b4fbc041beb4b00eb7e8694);
#
#
#         var popup_407f3040ac778f92f5c27d4126cd15cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b84ae6ed3cfd02b91f6fc8471b70cb61 = $(`&lt;div id=&quot;html_b84ae6ed3cfd02b91f6fc8471b70cb61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_407f3040ac778f92f5c27d4126cd15cb.setContent(html_b84ae6ed3cfd02b91f6fc8471b70cb61);
#
#
#
#         marker_cd349838e683bc87cd4bef733e8ff560.bindPopup(popup_407f3040ac778f92f5c27d4126cd15cb)
#         ;
#
#
#
#
#             var marker_8c1001a6bcf7e05a1dd9a763422b7161 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c3551fc65b4fbc041beb4b00eb7e8694);
#
#
#         var popup_1bee0bd062866ab2d71ab748b513f0c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac8b43e11cbc81867fcd99bbdbe77f8d = $(`&lt;div id=&quot;html_ac8b43e11cbc81867fcd99bbdbe77f8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1bee0bd062866ab2d71ab748b513f0c7.setContent(html_ac8b43e11cbc81867fcd99bbdbe77f8d);
#
#
#
#         marker_8c1001a6bcf7e05a1dd9a763422b7161.bindPopup(popup_1bee0bd062866ab2d71ab748b513f0c7)
#         ;
#
#
#
#
#             var marker_de5513f283746620dfd27fe57ebe5268 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c3551fc65b4fbc041beb4b00eb7e8694);
#
#
#         var popup_26f1a8b3c9ca8b1dc86afe3fa42c27a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86f3a66cf160a1dd120d00a34622f2eb = $(`&lt;div id=&quot;html_86f3a66cf160a1dd120d00a34622f2eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_26f1a8b3c9ca8b1dc86afe3fa42c27a9.setContent(html_86f3a66cf160a1dd120d00a34622f2eb);
#
#
#
#         marker_de5513f283746620dfd27fe57ebe5268.bindPopup(popup_26f1a8b3c9ca8b1dc86afe3fa42c27a9)
#         ;
#
#
#
#
#             var marker_a7f3cb5420f25b7aa4a112ded18b8959 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c3551fc65b4fbc041beb4b00eb7e8694);
#
#
#         var popup_a8c75293b215bbbb270014fd00a82ae7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4684c24fe2867da00bceb715bc30ce51 = $(`&lt;div id=&quot;html_4684c24fe2867da00bceb715bc30ce51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a8c75293b215bbbb270014fd00a82ae7.setContent(html_4684c24fe2867da00bceb715bc30ce51);
#
#
#
#         marker_
