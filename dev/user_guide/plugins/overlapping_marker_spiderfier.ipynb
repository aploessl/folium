# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d60310813587f9e56a8eb65a8062792 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d60310813587f9e56a8eb65a8062792&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d60310813587f9e56a8eb65a8062792 = L.map(
#                 &quot;map_5d60310813587f9e56a8eb65a8062792&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d7e33a8b45c52dee07f5a1b3c3cd2c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d7e33a8b45c52dee07f5a1b3c3cd2c1.addTo(map_5d60310813587f9e56a8eb65a8062792);
#
#
#             var marker_7f71dc576d87b7345b7e49a8e3bd17d2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5d60310813587f9e56a8eb65a8062792);
#
#
#         var popup_fbcf181b06d5220526f7d21fee478230 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51b77ec794da35513c01c5e212b9fc9d = $(`&lt;div id=&quot;html_51b77ec794da35513c01c5e212b9fc9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fbcf181b06d5220526f7d21fee478230.setContent(html_51b77ec794da35513c01c5e212b9fc9d);
#
#
#
#         marker_7f71dc576d87b7345b7e49a8e3bd17d2.bindPopup(popup_fbcf181b06d5220526f7d21fee478230)
#         ;
#
#
#
#
#             var marker_cc52772bd9a121c2a54acc93852e2acf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5d60310813587f9e56a8eb65a8062792);
#
#
#         var popup_1acc19c59577a94a470be7ee4d9f8128 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5f6b0ef2da3ea11bf2b35bb890218b2 = $(`&lt;div id=&quot;html_a5f6b0ef2da3ea11bf2b35bb890218b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1acc19c59577a94a470be7ee4d9f8128.setContent(html_a5f6b0ef2da3ea11bf2b35bb890218b2);
#
#
#
#         marker_cc52772bd9a121c2a54acc93852e2acf.bindPopup(popup_1acc19c59577a94a470be7ee4d9f8128)
#         ;
#
#
#
#
#             var marker_3b8ac90f78a7858397e749b0abd77ff0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5d60310813587f9e56a8eb65a8062792);
#
#
#         var popup_c35e8a06f6e104b1b8fe9c4f7fcb575c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fb9f80b41b600b80e0f3fe62af459dc = $(`&lt;div id=&quot;html_2fb9f80b41b600b80e0f3fe62af459dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c35e8a06f6e104b1b8fe9c4f7fcb575c.setContent(html_2fb9f80b41b600b80e0f3fe62af459dc);
#
#
#
#         marker_3b8ac90f78a7858397e749b0abd77ff0.bindPopup(popup_c35e8a06f6e104b1b8fe9c4f7fcb575c)
#         ;
#
#
#
#
#             var marker_6fa0557d6ccc5778c466e6d381843c7d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5d60310813587f9e56a8eb65a8062792);
#
#
#         var popup_7bfe775bbd3a9cbc23f5f759ff0e5be3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdc6129c64f91a429cb0c418df7bf913 = $(`&lt;div id=&quot;html_fdc6129c64f91a429cb0c418df7bf913&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7bfe775bbd3a9cbc23f5f759ff0e5be3.setContent(html_fdc6129c64f91a429cb0c418df7bf913);
#
#
#
#         marker_6fa0557d6ccc5778c466e6d381843c7d.bindPopup(popup_7bfe775bbd3a9cbc23f5f759ff0e5be3)
#         ;
#
#
#
#
#             var marker_726b351c91b819b97b5142c9097a7373 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5d60310813587f9e56a8eb65a8062792);
#
#
#         var popup_e02c8f5008d80f57dd9a9f157761fc32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_388dbfdd039c21f66b24e0bf24575bd6 = $(`&lt;div id=&quot;html_388dbfdd039c21f66b24e0bf24575bd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e02c8f5008d80f57dd9a9f157761fc32.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10451afa1061ead3d242dd5b97d75f03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10451afa1061ead3d242dd5b97d75f03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10451afa1061ead3d242dd5b97d75f03 = L.map(
#                 &quot;map_10451afa1061ead3d242dd5b97d75f03&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c58ed379c2a61113b9dead2df60ccab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c58ed379c2a61113b9dead2df60ccab.addTo(map_10451afa1061ead3d242dd5b97d75f03);
#
#
#             var feature_group_d8e6e7d4afae64568eab2b96aa51e5a1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f351ec4a8686b8a970da835347f83490 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d8e6e7d4afae64568eab2b96aa51e5a1);
#
#
#         var popup_fff63ce66ecf55d6da7d1b6cfc8f4e58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05f9f136e06ab1194ce2d51af05c7734 = $(`&lt;div id=&quot;html_05f9f136e06ab1194ce2d51af05c7734&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fff63ce66ecf55d6da7d1b6cfc8f4e58.setContent(html_05f9f136e06ab1194ce2d51af05c7734);
#
#
#
#         marker_f351ec4a8686b8a970da835347f83490.bindPopup(popup_fff63ce66ecf55d6da7d1b6cfc8f4e58)
#         ;
#
#
#
#
#             var marker_fadb8fe04354598d9251b9488d3a52c9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d8e6e7d4afae64568eab2b96aa51e5a1);
#
#
#         var popup_87132d9f480356df7094746a2ad38b57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc0522c2617bcde83dbae4684ce4d1fb = $(`&lt;div id=&quot;html_fc0522c2617bcde83dbae4684ce4d1fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_87132d9f480356df7094746a2ad38b57.setContent(html_fc0522c2617bcde83dbae4684ce4d1fb);
#
#
#
#         marker_fadb8fe04354598d9251b9488d3a52c9.bindPopup(popup_87132d9f480356df7094746a2ad38b57)
#         ;
#
#
#
#
#             var marker_edf418ddbbbf9fe80e3e39e509612564 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d8e6e7d4afae64568eab2b96aa51e5a1);
#
#
#         var popup_2ad67eeeb6dea58dd53c33f0b46f06eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f5da7e90fc944cf9ef068f7c5a87706 = $(`&lt;div id=&quot;html_8f5da7e90fc944cf9ef068f7c5a87706&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2ad67eeeb6dea58dd53c33f0b46f06eb.setContent(html_8f5da7e90fc944cf9ef068f7c5a87706);
#
#
#
#         marker_edf418ddbbbf9fe80e3e39e509612564.bindPopup(popup_2ad67eeeb6dea58dd53c33f0b46f06eb)
#         ;
#
#
#
#
#             var marker_a84a1bd85cf71d352dcbfb609732c2a6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d8e6e7d4afae64568eab2b96aa51e5a1);
#
#
#         var popup_5df6b8ccb9c735288d35f801f5e25075 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0679b05c1d0559bae6d8917a2ac6f4d = $(`&lt;div id=&quot;html_a0679b05c1d0559bae6d8917a2ac6f4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5df6b8ccb9c735288d35f801f5e25075.setContent(html_a0679b05c1d0559bae6d8917a2ac6f4d);
#
#
#
#         marker_a84a1bd85cf71d352dcbfb609732c2a6.bindPopup(popup_5df6b8ccb9c735288d35f801f5e25075)
#         ;
#
#
#
#
#             var marker_e5a794e9ce73414d9e206a8e469d3344 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d8e6e7d4afae64568eab2b96aa51e5a1);
#
#
#         var popup_61d22245fe58b6a57e51bc39d33e94a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_997b9fbe3ab7a389a1ec46ac175afaa0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_997b9fbe3ab7a389a1ec46ac175afaa0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_997b9fbe3ab7a389a1ec46ac175afaa0 = L.map(
#                 &quot;map_997b9fbe3ab7a389a1ec46ac175afaa0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0155e6f80b267747d6ef04e61da1f195 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0155e6f80b267747d6ef04e61da1f195.addTo(map_997b9fbe3ab7a389a1ec46ac175afaa0);
#
#
#             var feature_group_700d9dee703583eef2b3a7166abacbb2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_700d9dee703583eef2b3a7166abacbb2.addTo(map_997b9fbe3ab7a389a1ec46ac175afaa0);
#
#
#             var feature_group_sub_group_aae74c610a021c7e109b529077dc24f9 = L.featureGroup.subGroup(
#                 feature_group_700d9dee703583eef2b3a7166abacbb2
#             );
#
#
#             var marker_7b765f3ee5ea3537c11b3c970bac1037 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_aae74c610a021c7e109b529077dc24f9);
#
#
#         var popup_3b5166dc64f07fa774111df9fae97746 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f512ea3f7fa6e828ef7ba884c13a8d3f = $(`&lt;div id=&quot;html_f512ea3f7fa6e828ef7ba884c13a8d3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3b5166dc64f07fa774111df9fae97746.setContent(html_f512ea3f7fa6e828ef7ba884c13a8d3f);
#
#
#
#         marker_7b765f3ee5ea3537c11b3c970bac1037.bindPopup(popup_3b5166dc64f07fa774111df9fae97746)
#         ;
#
#
#
#
#             var marker_a2eea951c98cc0a6a191395b52948ff9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_aae74c610a021c7e109b529077dc24f9);
#
#
#         var popup_749e659dce73b0bb3946464fdb371383 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4893c78342572bf7947f5d427dd729b = $(`&lt;div id=&quot;html_f4893c78342572bf7947f5d427dd729b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_749e659dce73b0bb3946464fdb371383.setContent(html_f4893c78342572bf7947f5d427dd729b);
#
#
#
#         marker_a2eea951c98cc0a6a191395b52948ff9.bindPopup(popup_749e659dce73b0bb3946464fdb371383)
#         ;
#
#
#
#
#             var marker_1f81744defc486e4539acf52aa03e459 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_aae74c610a021c7e109b529077dc24f9);
#
#
#         var popup_e6faf0bc9cc1cbdcc7f26e70f1e003f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_793c314e26ef79fef5751dc988005f01 = $(`&lt;div id=&quot;html_793c314e26ef79fef5751dc988005f01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e6faf0bc9cc1cbdcc7f26e70f1e003f9.setContent(html_793c314e26ef79fef5751dc988005f01);
#
#
#
#         marker_1f81744defc486e4539acf52aa03e459.bindPopup(popup_e6faf0bc9cc1cbdcc7f26e70f1e003f9)
#         ;
#
#
#
#
#             var marker_0193d822c0d707f79e99117d96e3daca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_aae74c610a021c7e109b529077dc24f9);
#
#
#         var popup_fac340517a3f9d2e02e6592a936c36da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3e920aef68197620c8fe119762a9dcf = $(`&lt;div id=&quot;html_a3e920aef68197620c8fe119762a9dcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fac340517a3f9d2e02e6592a936c36da.setContent(html_a3e920aef68197620c8fe119762a9dcf);
#
#
#
#         marker_
