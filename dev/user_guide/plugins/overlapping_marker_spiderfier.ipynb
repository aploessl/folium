# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77a6b508147b71689ffc222cf08707e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77a6b508147b71689ffc222cf08707e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77a6b508147b71689ffc222cf08707e8 = L.map(
#                 &quot;map_77a6b508147b71689ffc222cf08707e8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c44fdae68bc864ce2f26dd617c5011b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c44fdae68bc864ce2f26dd617c5011b.addTo(map_77a6b508147b71689ffc222cf08707e8);
#
#
#             var marker_6593e55c8fbfd5a0c0ee6256d9bf7436 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_77a6b508147b71689ffc222cf08707e8);
#
#
#         var popup_0a3f269d36187e4ff6765f4d363b45d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87d462ad966bf2ee2ccd4551337a02c1 = $(`&lt;div id=&quot;html_87d462ad966bf2ee2ccd4551337a02c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0a3f269d36187e4ff6765f4d363b45d3.setContent(html_87d462ad966bf2ee2ccd4551337a02c1);
#
#
#
#         marker_6593e55c8fbfd5a0c0ee6256d9bf7436.bindPopup(popup_0a3f269d36187e4ff6765f4d363b45d3)
#         ;
#
#
#
#
#             var marker_d513a78832d333d86a6a5552c4bdab46 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_77a6b508147b71689ffc222cf08707e8);
#
#
#         var popup_26bb3969de5d3acdafbc3cedbb01dfde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0ff7669c4407e36df1999a396e4010f = $(`&lt;div id=&quot;html_b0ff7669c4407e36df1999a396e4010f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_26bb3969de5d3acdafbc3cedbb01dfde.setContent(html_b0ff7669c4407e36df1999a396e4010f);
#
#
#
#         marker_d513a78832d333d86a6a5552c4bdab46.bindPopup(popup_26bb3969de5d3acdafbc3cedbb01dfde)
#         ;
#
#
#
#
#             var marker_f5a36737b04d4128e252f8d003489393 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_77a6b508147b71689ffc222cf08707e8);
#
#
#         var popup_4000af7f5c9b9e68a45108a9301b5690 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba5e08c3fa7392c79782431e9eec0f88 = $(`&lt;div id=&quot;html_ba5e08c3fa7392c79782431e9eec0f88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4000af7f5c9b9e68a45108a9301b5690.setContent(html_ba5e08c3fa7392c79782431e9eec0f88);
#
#
#
#         marker_f5a36737b04d4128e252f8d003489393.bindPopup(popup_4000af7f5c9b9e68a45108a9301b5690)
#         ;
#
#
#
#
#             var marker_29b3b39009716a1f01196bc131d2698f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_77a6b508147b71689ffc222cf08707e8);
#
#
#         var popup_577901dbfe45ecfa64bb4ec63b531055 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5baf287854cb6815e53154e4360e2cf = $(`&lt;div id=&quot;html_f5baf287854cb6815e53154e4360e2cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_577901dbfe45ecfa64bb4ec63b531055.setContent(html_f5baf287854cb6815e53154e4360e2cf);
#
#
#
#         marker_29b3b39009716a1f01196bc131d2698f.bindPopup(popup_577901dbfe45ecfa64bb4ec63b531055)
#         ;
#
#
#
#
#             var marker_c1686c64a7f38933b7f1e4961f79922e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_77a6b508147b71689ffc222cf08707e8);
#
#
#         var popup_6fd4c2a441edef45db351e5101c89165 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ecf651968142b6ff3c6f1dccae6df7d = $(`&lt;div id=&quot;html_8ecf651968142b6ff3c6f1dccae6df7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6fd4c2a441edef45db351e5101c89165.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c288a25be29e9c92465109bedfb9ec7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c288a25be29e9c92465109bedfb9ec7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c288a25be29e9c92465109bedfb9ec7 = L.map(
#                 &quot;map_3c288a25be29e9c92465109bedfb9ec7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ebf9063b6b8472ebd99fbe0c479d965 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ebf9063b6b8472ebd99fbe0c479d965.addTo(map_3c288a25be29e9c92465109bedfb9ec7);
#
#
#             var feature_group_9a5953c63829de5d88c0c60ec2727bf5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bbaa1c33582ba6988690cfc1d10a5db7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9a5953c63829de5d88c0c60ec2727bf5);
#
#
#         var popup_a7b80b1b3318f57f366d9c3cda8d461b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0b3212180264d95c87599a87532e49c = $(`&lt;div id=&quot;html_f0b3212180264d95c87599a87532e49c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a7b80b1b3318f57f366d9c3cda8d461b.setContent(html_f0b3212180264d95c87599a87532e49c);
#
#
#
#         marker_bbaa1c33582ba6988690cfc1d10a5db7.bindPopup(popup_a7b80b1b3318f57f366d9c3cda8d461b)
#         ;
#
#
#
#
#             var marker_cca9115078dd4a1ae3f0bc3ad7f26286 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9a5953c63829de5d88c0c60ec2727bf5);
#
#
#         var popup_3e1f969c0224a1ac8cc3d155b842fb96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98521e41794349586166a61cc9e7f65c = $(`&lt;div id=&quot;html_98521e41794349586166a61cc9e7f65c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3e1f969c0224a1ac8cc3d155b842fb96.setContent(html_98521e41794349586166a61cc9e7f65c);
#
#
#
#         marker_cca9115078dd4a1ae3f0bc3ad7f26286.bindPopup(popup_3e1f969c0224a1ac8cc3d155b842fb96)
#         ;
#
#
#
#
#             var marker_7e7bcc6478f299823a9fce85addec5e3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9a5953c63829de5d88c0c60ec2727bf5);
#
#
#         var popup_e91e84d707bf11c946148f5786567e59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a83e79496a619e6bcb1b444d64bbf23 = $(`&lt;div id=&quot;html_3a83e79496a619e6bcb1b444d64bbf23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e91e84d707bf11c946148f5786567e59.setContent(html_3a83e79496a619e6bcb1b444d64bbf23);
#
#
#
#         marker_7e7bcc6478f299823a9fce85addec5e3.bindPopup(popup_e91e84d707bf11c946148f5786567e59)
#         ;
#
#
#
#
#             var marker_8482c3b30003c3d7a956f7708ab85cc4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9a5953c63829de5d88c0c60ec2727bf5);
#
#
#         var popup_40337df866b6d27f12be1f24652c52f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e62f388dabb42c5a8eb4c566c954491 = $(`&lt;div id=&quot;html_0e62f388dabb42c5a8eb4c566c954491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_40337df866b6d27f12be1f24652c52f6.setContent(html_0e62f388dabb42c5a8eb4c566c954491);
#
#
#
#         marker_8482c3b30003c3d7a956f7708ab85cc4.bindPopup(popup_40337df866b6d27f12be1f24652c52f6)
#         ;
#
#
#
#
#             var marker_a61f7e1417a977d270685e1792250836 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9a5953c63829de5d88c0c60ec2727bf5);
#
#
#         var popup_5135aaa6bcee224f3fd264450092d0e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a2a872372bdd797cb41a8075e8f29f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a2a872372bdd797cb41a8075e8f29f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a2a872372bdd797cb41a8075e8f29f1 = L.map(
#                 &quot;map_2a2a872372bdd797cb41a8075e8f29f1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3d6e8b612eff75b090bc009f9408e50 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c3d6e8b612eff75b090bc009f9408e50.addTo(map_2a2a872372bdd797cb41a8075e8f29f1);
#
#
#             var feature_group_330ef0b80ae634ff9519742c3385e075 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_330ef0b80ae634ff9519742c3385e075.addTo(map_2a2a872372bdd797cb41a8075e8f29f1);
#
#
#             var feature_group_sub_group_70c5b7a7764b9ce0706190e2d1324ccc = L.featureGroup.subGroup(
#                 feature_group_330ef0b80ae634ff9519742c3385e075
#             );
#
#
#             var marker_e42b384144f5a13111b9952c15908472 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_70c5b7a7764b9ce0706190e2d1324ccc);
#
#
#         var popup_8f8393851a20f1c8f67e74b219f59b4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f501f512a744fffce9392c891bf3b536 = $(`&lt;div id=&quot;html_f501f512a744fffce9392c891bf3b536&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8f8393851a20f1c8f67e74b219f59b4b.setContent(html_f501f512a744fffce9392c891bf3b536);
#
#
#
#         marker_e42b384144f5a13111b9952c15908472.bindPopup(popup_8f8393851a20f1c8f67e74b219f59b4b)
#         ;
#
#
#
#
#             var marker_2325ec5f947bfbc2d8f6a6c02f64cfdd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_70c5b7a7764b9ce0706190e2d1324ccc);
#
#
#         var popup_6366bff3c7e62a6f50982849bcbf9242 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ecd2d3d8ca67c1f12afa36f83eee150 = $(`&lt;div id=&quot;html_7ecd2d3d8ca67c1f12afa36f83eee150&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6366bff3c7e62a6f50982849bcbf9242.setContent(html_7ecd2d3d8ca67c1f12afa36f83eee150);
#
#
#
#         marker_2325ec5f947bfbc2d8f6a6c02f64cfdd.bindPopup(popup_6366bff3c7e62a6f50982849bcbf9242)
#         ;
#
#
#
#
#             var marker_d5e668ac7922f7e3b4e62b08f25dde27 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_70c5b7a7764b9ce0706190e2d1324ccc);
#
#
#         var popup_a974cd8f2664e67d8cc910ffa860f829 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20d1908b30d834185646fc5147552fd5 = $(`&lt;div id=&quot;html_20d1908b30d834185646fc5147552fd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a974cd8f2664e67d8cc910ffa860f829.setContent(html_20d1908b30d834185646fc5147552fd5);
#
#
#
#         marker_d5e668ac7922f7e3b4e62b08f25dde27.bindPopup(popup_a974cd8f2664e67d8cc910ffa860f829)
#         ;
#
#
#
#
#             var marker_1afccc587969e9e91853e8a37011f9d3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_70c5b7a7764b9ce0706190e2d1324ccc);
#
#
#         var popup_a82b022faab8afd67acc813b1dd8982a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4eb4e42b0d72fc5f97c410c0aeb10733 = $(`&lt;div id=&quot;html_4eb4e42b0d72fc5f97c410c0aeb10733&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a82b022faab8afd67acc813b1dd8982a.setContent(html_4eb4e42b0d72fc5f97c410c0aeb10733);
#
#
#
#         marker_
