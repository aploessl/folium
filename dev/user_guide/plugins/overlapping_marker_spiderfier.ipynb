# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_950b32ed323cb3df778faaa8316c9460 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_950b32ed323cb3df778faaa8316c9460&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_950b32ed323cb3df778faaa8316c9460 = L.map(
#                 &quot;map_950b32ed323cb3df778faaa8316c9460&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_772136b9d0de6658af6867970fa74358 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_772136b9d0de6658af6867970fa74358.addTo(map_950b32ed323cb3df778faaa8316c9460);
#
#
#             var marker_2a2098ea9693c139cee3e53a1d165f6f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_950b32ed323cb3df778faaa8316c9460);
#
#
#         var popup_45b2c7b9b9520354b84af64dce304a4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1645c4edd88b33644e464d76c586d374 = $(`&lt;div id=&quot;html_1645c4edd88b33644e464d76c586d374&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_45b2c7b9b9520354b84af64dce304a4d.setContent(html_1645c4edd88b33644e464d76c586d374);
#
#
#
#         marker_2a2098ea9693c139cee3e53a1d165f6f.bindPopup(popup_45b2c7b9b9520354b84af64dce304a4d)
#         ;
#
#
#
#
#             var marker_edca05c2ca4ea33a391ab81e7c0d5334 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_950b32ed323cb3df778faaa8316c9460);
#
#
#         var popup_52f0f9c6ff252f8a65b16cab1ce7df5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a57c6e9c437e249b79935c4fec490392 = $(`&lt;div id=&quot;html_a57c6e9c437e249b79935c4fec490392&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_52f0f9c6ff252f8a65b16cab1ce7df5b.setContent(html_a57c6e9c437e249b79935c4fec490392);
#
#
#
#         marker_edca05c2ca4ea33a391ab81e7c0d5334.bindPopup(popup_52f0f9c6ff252f8a65b16cab1ce7df5b)
#         ;
#
#
#
#
#             var marker_e61febe109fc269681fb34dfd24ec526 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_950b32ed323cb3df778faaa8316c9460);
#
#
#         var popup_9cdab4d16d5978e67444c231b91b1831 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b61252b1558b6b880dfe18f1acc16c3 = $(`&lt;div id=&quot;html_4b61252b1558b6b880dfe18f1acc16c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9cdab4d16d5978e67444c231b91b1831.setContent(html_4b61252b1558b6b880dfe18f1acc16c3);
#
#
#
#         marker_e61febe109fc269681fb34dfd24ec526.bindPopup(popup_9cdab4d16d5978e67444c231b91b1831)
#         ;
#
#
#
#
#             var marker_0c79b846d298c4b8e0057bff5f70feb8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_950b32ed323cb3df778faaa8316c9460);
#
#
#         var popup_fd7596b067f6eb201970bcedce7f33a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d339fb37318a8c4e45b8b5ab58fa0d36 = $(`&lt;div id=&quot;html_d339fb37318a8c4e45b8b5ab58fa0d36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fd7596b067f6eb201970bcedce7f33a5.setContent(html_d339fb37318a8c4e45b8b5ab58fa0d36);
#
#
#
#         marker_0c79b846d298c4b8e0057bff5f70feb8.bindPopup(popup_fd7596b067f6eb201970bcedce7f33a5)
#         ;
#
#
#
#
#             var marker_518474663009d8aac95504ff3c551135 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_950b32ed323cb3df778faaa8316c9460);
#
#
#         var popup_fd7c8107ae6dfd0ce836e995af9346f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdac75105562dd72f58c48eb8b1cdacf = $(`&lt;div id=&quot;html_cdac75105562dd72f58c48eb8b1cdacf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fd7c8107ae6dfd0ce836e995af9346f3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f2b3ef3fabc1210041fbcfc87c0f100 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f2b3ef3fabc1210041fbcfc87c0f100&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f2b3ef3fabc1210041fbcfc87c0f100 = L.map(
#                 &quot;map_4f2b3ef3fabc1210041fbcfc87c0f100&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_daee5ef1042a4bbe94bc7d1d20b5f906 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_daee5ef1042a4bbe94bc7d1d20b5f906.addTo(map_4f2b3ef3fabc1210041fbcfc87c0f100);
#
#
#             var feature_group_d7ac4524712a4015d7f718988dcba201 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f54365efc986047e8f6e2edfc0a44263 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d7ac4524712a4015d7f718988dcba201);
#
#
#         var popup_082a4e078787dbd3179764f0c5ce25ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9d2b6766f677eb78cc9a63fca990c84 = $(`&lt;div id=&quot;html_d9d2b6766f677eb78cc9a63fca990c84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_082a4e078787dbd3179764f0c5ce25ed.setContent(html_d9d2b6766f677eb78cc9a63fca990c84);
#
#
#
#         marker_f54365efc986047e8f6e2edfc0a44263.bindPopup(popup_082a4e078787dbd3179764f0c5ce25ed)
#         ;
#
#
#
#
#             var marker_2dd31a7925e0e7ae2f8d207d263969a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d7ac4524712a4015d7f718988dcba201);
#
#
#         var popup_a8287a5544aab1089c65fb5df475e2fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19439deee780081464d088882bb8c202 = $(`&lt;div id=&quot;html_19439deee780081464d088882bb8c202&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a8287a5544aab1089c65fb5df475e2fe.setContent(html_19439deee780081464d088882bb8c202);
#
#
#
#         marker_2dd31a7925e0e7ae2f8d207d263969a6.bindPopup(popup_a8287a5544aab1089c65fb5df475e2fe)
#         ;
#
#
#
#
#             var marker_0e2835df292fb1e298b5719811cc7bf0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d7ac4524712a4015d7f718988dcba201);
#
#
#         var popup_18d97c2b71d0c8cfaf79ee9a0cabd2ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73796c188da5b45808c02ff852c742b1 = $(`&lt;div id=&quot;html_73796c188da5b45808c02ff852c742b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_18d97c2b71d0c8cfaf79ee9a0cabd2ea.setContent(html_73796c188da5b45808c02ff852c742b1);
#
#
#
#         marker_0e2835df292fb1e298b5719811cc7bf0.bindPopup(popup_18d97c2b71d0c8cfaf79ee9a0cabd2ea)
#         ;
#
#
#
#
#             var marker_08a81439732f321c17064204e0c1cd4e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d7ac4524712a4015d7f718988dcba201);
#
#
#         var popup_7c345c8713671586c57be8ac5f7f7abb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08f3c484fe1fbd02642efa3394b61d3c = $(`&lt;div id=&quot;html_08f3c484fe1fbd02642efa3394b61d3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7c345c8713671586c57be8ac5f7f7abb.setContent(html_08f3c484fe1fbd02642efa3394b61d3c);
#
#
#
#         marker_08a81439732f321c17064204e0c1cd4e.bindPopup(popup_7c345c8713671586c57be8ac5f7f7abb)
#         ;
#
#
#
#
#             var marker_0a5163ca88afb47473fe5cc057dea644 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d7ac4524712a4015d7f718988dcba201);
#
#
#         var popup_815afc853b169284d9d1bbba72a7b842 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82c30a0bd1ea516682eee543ea8039ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82c30a0bd1ea516682eee543ea8039ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82c30a0bd1ea516682eee543ea8039ab = L.map(
#                 &quot;map_82c30a0bd1ea516682eee543ea8039ab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc5972d07a294a5f1665954c3d643a8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cc5972d07a294a5f1665954c3d643a8d.addTo(map_82c30a0bd1ea516682eee543ea8039ab);
#
#
#             var feature_group_23ead66f9b71f58803cb24a3a0e60a74 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_23ead66f9b71f58803cb24a3a0e60a74.addTo(map_82c30a0bd1ea516682eee543ea8039ab);
#
#
#             var feature_group_sub_group_c0151d81e4da034372196c3f8928dc1c = L.featureGroup.subGroup(
#                 feature_group_23ead66f9b71f58803cb24a3a0e60a74
#             );
#
#
#             var marker_74be88151eda2561e40f38c4937cf88e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c0151d81e4da034372196c3f8928dc1c);
#
#
#         var popup_c8d1c2ece563cd1ece1cc8c37fcb3b57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c6bed6417083f1bca6b75329b9026b1 = $(`&lt;div id=&quot;html_6c6bed6417083f1bca6b75329b9026b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c8d1c2ece563cd1ece1cc8c37fcb3b57.setContent(html_6c6bed6417083f1bca6b75329b9026b1);
#
#
#
#         marker_74be88151eda2561e40f38c4937cf88e.bindPopup(popup_c8d1c2ece563cd1ece1cc8c37fcb3b57)
#         ;
#
#
#
#
#             var marker_c7e506ad88c176e2eea0151a37db9245 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c0151d81e4da034372196c3f8928dc1c);
#
#
#         var popup_dbe3b3254b23f9ac3020df59cab05a84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53b4e126af1fe00ae4eaf3fab0d26bd6 = $(`&lt;div id=&quot;html_53b4e126af1fe00ae4eaf3fab0d26bd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_dbe3b3254b23f9ac3020df59cab05a84.setContent(html_53b4e126af1fe00ae4eaf3fab0d26bd6);
#
#
#
#         marker_c7e506ad88c176e2eea0151a37db9245.bindPopup(popup_dbe3b3254b23f9ac3020df59cab05a84)
#         ;
#
#
#
#
#             var marker_eb097728a339166b0b138b9feebe9438 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c0151d81e4da034372196c3f8928dc1c);
#
#
#         var popup_e6fb1d81a1dbdc89459830075c01e947 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f930a2584607f762e68c2adeffa6270 = $(`&lt;div id=&quot;html_9f930a2584607f762e68c2adeffa6270&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e6fb1d81a1dbdc89459830075c01e947.setContent(html_9f930a2584607f762e68c2adeffa6270);
#
#
#
#         marker_eb097728a339166b0b138b9feebe9438.bindPopup(popup_e6fb1d81a1dbdc89459830075c01e947)
#         ;
#
#
#
#
#             var marker_8d215254aebbedf246dc8e374bec3fd2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c0151d81e4da034372196c3f8928dc1c);
#
#
#         var popup_064f62ffe91437f9f4693af2b031d25a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d812b52d56316a3677f5f1580eb6753 = $(`&lt;div id=&quot;html_1d812b52d56316a3677f5f1580eb6753&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_064f62ffe91437f9f4693af2b031d25a.setContent(html_1d812b52d56316a3677f5f1580eb6753);
#
#
#
#         marker_
