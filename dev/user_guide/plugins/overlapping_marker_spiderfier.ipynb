# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e157044056490f7de24d17ece4a4e4d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e157044056490f7de24d17ece4a4e4d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e157044056490f7de24d17ece4a4e4d2 = L.map(
#                 &quot;map_e157044056490f7de24d17ece4a4e4d2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3972fe769410de5b7560571eef4801b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3972fe769410de5b7560571eef4801b2.addTo(map_e157044056490f7de24d17ece4a4e4d2);
#
#
#             var marker_c60fb1a9a8546e0911c8d88d3564de5b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e157044056490f7de24d17ece4a4e4d2);
#
#
#         var popup_5447a14b0aa8420aa669d6141d17740d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_babd336fc0182600b829b2161f6e22f9 = $(`&lt;div id=&quot;html_babd336fc0182600b829b2161f6e22f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5447a14b0aa8420aa669d6141d17740d.setContent(html_babd336fc0182600b829b2161f6e22f9);
#
#
#
#         marker_c60fb1a9a8546e0911c8d88d3564de5b.bindPopup(popup_5447a14b0aa8420aa669d6141d17740d)
#         ;
#
#
#
#
#             var marker_db2f75c9eb5928becd24b222580cc818 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e157044056490f7de24d17ece4a4e4d2);
#
#
#         var popup_5f60ecba4032764ce0a83e4d75b48ba8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_644d77d2b908a59a1f5e8fc0fc471fc3 = $(`&lt;div id=&quot;html_644d77d2b908a59a1f5e8fc0fc471fc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5f60ecba4032764ce0a83e4d75b48ba8.setContent(html_644d77d2b908a59a1f5e8fc0fc471fc3);
#
#
#
#         marker_db2f75c9eb5928becd24b222580cc818.bindPopup(popup_5f60ecba4032764ce0a83e4d75b48ba8)
#         ;
#
#
#
#
#             var marker_5e5bfdc5c3cbd59c8a91fece2552e7d7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e157044056490f7de24d17ece4a4e4d2);
#
#
#         var popup_69745ae93e31d9272e09d10544487bfc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f295fdcec07055cc6a71b603ffcaa96 = $(`&lt;div id=&quot;html_8f295fdcec07055cc6a71b603ffcaa96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_69745ae93e31d9272e09d10544487bfc.setContent(html_8f295fdcec07055cc6a71b603ffcaa96);
#
#
#
#         marker_5e5bfdc5c3cbd59c8a91fece2552e7d7.bindPopup(popup_69745ae93e31d9272e09d10544487bfc)
#         ;
#
#
#
#
#             var marker_92b057788149da77f345f397374fe0f5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e157044056490f7de24d17ece4a4e4d2);
#
#
#         var popup_182891c422df2fc722d7a22b51fa8584 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d03965298875de358a87d4955840734f = $(`&lt;div id=&quot;html_d03965298875de358a87d4955840734f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_182891c422df2fc722d7a22b51fa8584.setContent(html_d03965298875de358a87d4955840734f);
#
#
#
#         marker_92b057788149da77f345f397374fe0f5.bindPopup(popup_182891c422df2fc722d7a22b51fa8584)
#         ;
#
#
#
#
#             var marker_cac3565bc1e17d0c0b069f25cdff234b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e157044056490f7de24d17ece4a4e4d2);
#
#
#         var popup_5ba7b9c26305b358709e967e346f8a50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28189684aa838cf3155208b1e8974f10 = $(`&lt;div id=&quot;html_28189684aa838cf3155208b1e8974f10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5ba7b9c26305b358709e967e346f8a50.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_969b932a859478a0c5814dfd8bf2a364 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_969b932a859478a0c5814dfd8bf2a364&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_969b932a859478a0c5814dfd8bf2a364 = L.map(
#                 &quot;map_969b932a859478a0c5814dfd8bf2a364&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a4d9fe773da7650f4398abec974a0a7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a4d9fe773da7650f4398abec974a0a7.addTo(map_969b932a859478a0c5814dfd8bf2a364);
#
#
#             var feature_group_0a9b3643b8b1107a8eccba49a0343e2d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cf5ef80d46fe1da4300d7f2e54e39780 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0a9b3643b8b1107a8eccba49a0343e2d);
#
#
#         var popup_92a4ff8310685fbf1873c60f944a4fa7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28a66bf53eb6a70bd52d543fb3d321e4 = $(`&lt;div id=&quot;html_28a66bf53eb6a70bd52d543fb3d321e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_92a4ff8310685fbf1873c60f944a4fa7.setContent(html_28a66bf53eb6a70bd52d543fb3d321e4);
#
#
#
#         marker_cf5ef80d46fe1da4300d7f2e54e39780.bindPopup(popup_92a4ff8310685fbf1873c60f944a4fa7)
#         ;
#
#
#
#
#             var marker_b44ecaa522b627335bb1f05c717c49c2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0a9b3643b8b1107a8eccba49a0343e2d);
#
#
#         var popup_2f6cbe671f02f2d42fdf07960a88bd5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_793e419133a79bfe0024694e0ebd0380 = $(`&lt;div id=&quot;html_793e419133a79bfe0024694e0ebd0380&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2f6cbe671f02f2d42fdf07960a88bd5a.setContent(html_793e419133a79bfe0024694e0ebd0380);
#
#
#
#         marker_b44ecaa522b627335bb1f05c717c49c2.bindPopup(popup_2f6cbe671f02f2d42fdf07960a88bd5a)
#         ;
#
#
#
#
#             var marker_798f80edf7736b6df1d2fc6650318cf2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0a9b3643b8b1107a8eccba49a0343e2d);
#
#
#         var popup_505511339c24ffc89c1f20c0f4ff1032 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a732a4d0aa0e45dad1424588b60bb1e = $(`&lt;div id=&quot;html_8a732a4d0aa0e45dad1424588b60bb1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_505511339c24ffc89c1f20c0f4ff1032.setContent(html_8a732a4d0aa0e45dad1424588b60bb1e);
#
#
#
#         marker_798f80edf7736b6df1d2fc6650318cf2.bindPopup(popup_505511339c24ffc89c1f20c0f4ff1032)
#         ;
#
#
#
#
#             var marker_9fc242de62ddca19be19902c8d0dcfa9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0a9b3643b8b1107a8eccba49a0343e2d);
#
#
#         var popup_724d858186fe583c379da8f476b50693 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_040498961698286c66d327d4d61945af = $(`&lt;div id=&quot;html_040498961698286c66d327d4d61945af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_724d858186fe583c379da8f476b50693.setContent(html_040498961698286c66d327d4d61945af);
#
#
#
#         marker_9fc242de62ddca19be19902c8d0dcfa9.bindPopup(popup_724d858186fe583c379da8f476b50693)
#         ;
#
#
#
#
#             var marker_0b9108885cd0d313c4c45f8fac2b6c93 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0a9b3643b8b1107a8eccba49a0343e2d);
#
#
#         var popup_d9e8194738c8e40beb44b47981f76b80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa0674d9a10cb75ee58c11501935d8ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa0674d9a10cb75ee58c11501935d8ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa0674d9a10cb75ee58c11501935d8ed = L.map(
#                 &quot;map_fa0674d9a10cb75ee58c11501935d8ed&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e094b61adcb605ee3717ca6f1896677e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e094b61adcb605ee3717ca6f1896677e.addTo(map_fa0674d9a10cb75ee58c11501935d8ed);
#
#
#             var feature_group_62dafa0f53ed81172e5fefda35aeb573 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_62dafa0f53ed81172e5fefda35aeb573.addTo(map_fa0674d9a10cb75ee58c11501935d8ed);
#
#
#             var feature_group_sub_group_547c483f611e79a5b9ea24c2b4d8bdbc = L.featureGroup.subGroup(
#                 feature_group_62dafa0f53ed81172e5fefda35aeb573
#             );
#
#
#             var marker_192d649133ddc84eae270d572db69c4e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_547c483f611e79a5b9ea24c2b4d8bdbc);
#
#
#         var popup_355ed9f8c99bd6c758f129bee72a1ab8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b536e2ce2a6d3eb21bc221baabd84aab = $(`&lt;div id=&quot;html_b536e2ce2a6d3eb21bc221baabd84aab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_355ed9f8c99bd6c758f129bee72a1ab8.setContent(html_b536e2ce2a6d3eb21bc221baabd84aab);
#
#
#
#         marker_192d649133ddc84eae270d572db69c4e.bindPopup(popup_355ed9f8c99bd6c758f129bee72a1ab8)
#         ;
#
#
#
#
#             var marker_4ed93f8e3ec238b28d993bc2171718fa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_547c483f611e79a5b9ea24c2b4d8bdbc);
#
#
#         var popup_08f8f66ce200cf8a74299ff470ca05ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a917ae56b09966f1cc866b59814f210f = $(`&lt;div id=&quot;html_a917ae56b09966f1cc866b59814f210f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_08f8f66ce200cf8a74299ff470ca05ce.setContent(html_a917ae56b09966f1cc866b59814f210f);
#
#
#
#         marker_4ed93f8e3ec238b28d993bc2171718fa.bindPopup(popup_08f8f66ce200cf8a74299ff470ca05ce)
#         ;
#
#
#
#
#             var marker_1bb07a0ed051250545f6ae141ea4054f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_547c483f611e79a5b9ea24c2b4d8bdbc);
#
#
#         var popup_5f285d7e7793d9b310a4bf25998b3a00 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3da0abc5ceb61cb040446dd38295c884 = $(`&lt;div id=&quot;html_3da0abc5ceb61cb040446dd38295c884&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5f285d7e7793d9b310a4bf25998b3a00.setContent(html_3da0abc5ceb61cb040446dd38295c884);
#
#
#
#         marker_1bb07a0ed051250545f6ae141ea4054f.bindPopup(popup_5f285d7e7793d9b310a4bf25998b3a00)
#         ;
#
#
#
#
#             var marker_892bdb5bba40103fd7f2804e9d6765a6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_547c483f611e79a5b9ea24c2b4d8bdbc);
#
#
#         var popup_60be5a12c17ca62bef181ae57efb642b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f155477fcab900528cc07371cfab64c5 = $(`&lt;div id=&quot;html_f155477fcab900528cc07371cfab64c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_60be5a12c17ca62bef181ae57efb642b.setContent(html_f155477fcab900528cc07371cfab64c5);
#
#
#
#         marker_
