# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48d574649f02dffad4cef3f550ac07c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48d574649f02dffad4cef3f550ac07c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48d574649f02dffad4cef3f550ac07c2 = L.map(
#                 &quot;map_48d574649f02dffad4cef3f550ac07c2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f861a70958d2adb7f3f9f9beecd98074 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f861a70958d2adb7f3f9f9beecd98074.addTo(map_48d574649f02dffad4cef3f550ac07c2);
#
#
#             var marker_82091b175474d7ec854964ccd4a8db4b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_48d574649f02dffad4cef3f550ac07c2);
#
#
#         var popup_15665b4ed35db88f29c9477099fde3cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a117bda36357ad55c1112ff02cd5a976 = $(`&lt;div id=&quot;html_a117bda36357ad55c1112ff02cd5a976&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_15665b4ed35db88f29c9477099fde3cd.setContent(html_a117bda36357ad55c1112ff02cd5a976);
#
#
#
#         marker_82091b175474d7ec854964ccd4a8db4b.bindPopup(popup_15665b4ed35db88f29c9477099fde3cd)
#         ;
#
#
#
#
#             var marker_fb954fa4547ba5a47acc725970952b56 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_48d574649f02dffad4cef3f550ac07c2);
#
#
#         var popup_22616ae81d14a44b1779372bf0b181aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f85077ff4d9510919e092d4c1dd285d3 = $(`&lt;div id=&quot;html_f85077ff4d9510919e092d4c1dd285d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_22616ae81d14a44b1779372bf0b181aa.setContent(html_f85077ff4d9510919e092d4c1dd285d3);
#
#
#
#         marker_fb954fa4547ba5a47acc725970952b56.bindPopup(popup_22616ae81d14a44b1779372bf0b181aa)
#         ;
#
#
#
#
#             var marker_47cbbb53f7b02de4f482f95cf6d8f737 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_48d574649f02dffad4cef3f550ac07c2);
#
#
#         var popup_44853cfc371bf57c80de407580a27a26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d530eeebb90d12ecae5d5ced8e70fc03 = $(`&lt;div id=&quot;html_d530eeebb90d12ecae5d5ced8e70fc03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_44853cfc371bf57c80de407580a27a26.setContent(html_d530eeebb90d12ecae5d5ced8e70fc03);
#
#
#
#         marker_47cbbb53f7b02de4f482f95cf6d8f737.bindPopup(popup_44853cfc371bf57c80de407580a27a26)
#         ;
#
#
#
#
#             var marker_7530e0cd3a290cf44f78f1cb43f7818d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_48d574649f02dffad4cef3f550ac07c2);
#
#
#         var popup_c8942aa64e420ed632a6b3c410395df5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fdafa3f9aefd4648dbb35bfe58a2986 = $(`&lt;div id=&quot;html_7fdafa3f9aefd4648dbb35bfe58a2986&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c8942aa64e420ed632a6b3c410395df5.setContent(html_7fdafa3f9aefd4648dbb35bfe58a2986);
#
#
#
#         marker_7530e0cd3a290cf44f78f1cb43f7818d.bindPopup(popup_c8942aa64e420ed632a6b3c410395df5)
#         ;
#
#
#
#
#             var marker_e39bc34ffedbdc312c7e044fcaf6afa6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_48d574649f02dffad4cef3f550ac07c2);
#
#
#         var popup_8c23687effacef34634c6ff06551d18c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f2100c2251e84b2fcb03a8e0c6a9e4f = $(`&lt;div id=&quot;html_6f2100c2251e84b2fcb03a8e0c6a9e4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8c23687effacef34634c6ff06551d18c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0551b40eb6d965504bb184b9ab2dc52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0551b40eb6d965504bb184b9ab2dc52&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0551b40eb6d965504bb184b9ab2dc52 = L.map(
#                 &quot;map_a0551b40eb6d965504bb184b9ab2dc52&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f97b20888657555eb78d3546a9a5b8c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f97b20888657555eb78d3546a9a5b8c2.addTo(map_a0551b40eb6d965504bb184b9ab2dc52);
#
#
#             var feature_group_541c404ceb1ed82785309c40d2bd58f2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3538dc4bb9ad154b23f9e51eef317ed7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_541c404ceb1ed82785309c40d2bd58f2);
#
#
#         var popup_5acdb7eded842704b407c44c4c3a79c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea986d8d16089b6cc14e3021e7d5125a = $(`&lt;div id=&quot;html_ea986d8d16089b6cc14e3021e7d5125a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5acdb7eded842704b407c44c4c3a79c3.setContent(html_ea986d8d16089b6cc14e3021e7d5125a);
#
#
#
#         marker_3538dc4bb9ad154b23f9e51eef317ed7.bindPopup(popup_5acdb7eded842704b407c44c4c3a79c3)
#         ;
#
#
#
#
#             var marker_3a534aa2b46d49654e6b22de5d1575af = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_541c404ceb1ed82785309c40d2bd58f2);
#
#
#         var popup_2f45811204fc666450b5a534517d52a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da113ade9fe01fa3f3a9f92f3db07bdf = $(`&lt;div id=&quot;html_da113ade9fe01fa3f3a9f92f3db07bdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2f45811204fc666450b5a534517d52a2.setContent(html_da113ade9fe01fa3f3a9f92f3db07bdf);
#
#
#
#         marker_3a534aa2b46d49654e6b22de5d1575af.bindPopup(popup_2f45811204fc666450b5a534517d52a2)
#         ;
#
#
#
#
#             var marker_2bd19b070902b721fae5f0e244261d88 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_541c404ceb1ed82785309c40d2bd58f2);
#
#
#         var popup_449ca5600f8814f314a7e4538bf571a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62a4299969ef19247dc4f2472425c794 = $(`&lt;div id=&quot;html_62a4299969ef19247dc4f2472425c794&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_449ca5600f8814f314a7e4538bf571a4.setContent(html_62a4299969ef19247dc4f2472425c794);
#
#
#
#         marker_2bd19b070902b721fae5f0e244261d88.bindPopup(popup_449ca5600f8814f314a7e4538bf571a4)
#         ;
#
#
#
#
#             var marker_aaed0300c8dc7691a2cb867bc3499744 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_541c404ceb1ed82785309c40d2bd58f2);
#
#
#         var popup_cd17172de446763914c3203d6f067d8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1bb2463542899fd93b14211ef372b49 = $(`&lt;div id=&quot;html_e1bb2463542899fd93b14211ef372b49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cd17172de446763914c3203d6f067d8b.setContent(html_e1bb2463542899fd93b14211ef372b49);
#
#
#
#         marker_aaed0300c8dc7691a2cb867bc3499744.bindPopup(popup_cd17172de446763914c3203d6f067d8b)
#         ;
#
#
#
#
#             var marker_719f491033560ac2c1d034e1ca8ed1d2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_541c404ceb1ed82785309c40d2bd58f2);
#
#
#         var popup_f71025c628a6efb298cd3567c212dd28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8bfa1e8b91a0d5b51debbe60b5c253a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8bfa1e8b91a0d5b51debbe60b5c253a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8bfa1e8b91a0d5b51debbe60b5c253a = L.map(
#                 &quot;map_c8bfa1e8b91a0d5b51debbe60b5c253a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2c1b67e0f48c9f68337c3591d422423 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2c1b67e0f48c9f68337c3591d422423.addTo(map_c8bfa1e8b91a0d5b51debbe60b5c253a);
#
#
#             var feature_group_61a2a8b2516230e4d51ba1b9e94568c5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_61a2a8b2516230e4d51ba1b9e94568c5.addTo(map_c8bfa1e8b91a0d5b51debbe60b5c253a);
#
#
#             var feature_group_sub_group_c21f1a789dfacf91399247c61a50a9d0 = L.featureGroup.subGroup(
#                 feature_group_61a2a8b2516230e4d51ba1b9e94568c5
#             );
#
#
#             var marker_b68fd678af40d661c21d7941eae61b7b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c21f1a789dfacf91399247c61a50a9d0);
#
#
#         var popup_dd86fcfc54b5cccb2ff76e50331ab3f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_964e77f0b4299b9dd6fe82994cdc2ac3 = $(`&lt;div id=&quot;html_964e77f0b4299b9dd6fe82994cdc2ac3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_dd86fcfc54b5cccb2ff76e50331ab3f6.setContent(html_964e77f0b4299b9dd6fe82994cdc2ac3);
#
#
#
#         marker_b68fd678af40d661c21d7941eae61b7b.bindPopup(popup_dd86fcfc54b5cccb2ff76e50331ab3f6)
#         ;
#
#
#
#
#             var marker_e942aac6fa9650f6dab7bf19fb4b84de = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c21f1a789dfacf91399247c61a50a9d0);
#
#
#         var popup_2fe771e1950360d1c04ae896fcdbca4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46be0fbf0c9f9aff40fb3436e1777421 = $(`&lt;div id=&quot;html_46be0fbf0c9f9aff40fb3436e1777421&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2fe771e1950360d1c04ae896fcdbca4c.setContent(html_46be0fbf0c9f9aff40fb3436e1777421);
#
#
#
#         marker_e942aac6fa9650f6dab7bf19fb4b84de.bindPopup(popup_2fe771e1950360d1c04ae896fcdbca4c)
#         ;
#
#
#
#
#             var marker_05cfd66b274022ece34a4a6ba7d34cf3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c21f1a789dfacf91399247c61a50a9d0);
#
#
#         var popup_b85242465f7a7a17b5e03aa6969979f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_399fd9d7cd0748ce85fb233b0283c44c = $(`&lt;div id=&quot;html_399fd9d7cd0748ce85fb233b0283c44c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b85242465f7a7a17b5e03aa6969979f5.setContent(html_399fd9d7cd0748ce85fb233b0283c44c);
#
#
#
#         marker_05cfd66b274022ece34a4a6ba7d34cf3.bindPopup(popup_b85242465f7a7a17b5e03aa6969979f5)
#         ;
#
#
#
#
#             var marker_3734164fe39fa082c6edbe186384ce2c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c21f1a789dfacf91399247c61a50a9d0);
#
#
#         var popup_8b70fa3707ff30a39b9faa2c887a8dd3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_398f3b5e75b8ec54c1cc1297a347734f = $(`&lt;div id=&quot;html_398f3b5e75b8ec54c1cc1297a347734f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8b70fa3707ff30a39b9faa2c887a8dd3.setContent(html_398f3b5e75b8ec54c1cc1297a347734f);
#
#
#
#         marker_
