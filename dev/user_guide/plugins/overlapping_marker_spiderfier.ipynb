# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c60c1adf035d8584b8c88b1adeb7934 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c60c1adf035d8584b8c88b1adeb7934&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c60c1adf035d8584b8c88b1adeb7934 = L.map(
#                 &quot;map_6c60c1adf035d8584b8c88b1adeb7934&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_977036122a4f46a8a2e6a0c36cf8f38c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_977036122a4f46a8a2e6a0c36cf8f38c.addTo(map_6c60c1adf035d8584b8c88b1adeb7934);
#
#
#             var marker_34d83c7b6be5f7eb4f9dcea666a592b3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6c60c1adf035d8584b8c88b1adeb7934);
#
#
#         var popup_7e8ec1e1a1b8e11ae1a563d9176df2f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d18dd4df39fa661c6bb5a218b72e3c5 = $(`&lt;div id=&quot;html_5d18dd4df39fa661c6bb5a218b72e3c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7e8ec1e1a1b8e11ae1a563d9176df2f5.setContent(html_5d18dd4df39fa661c6bb5a218b72e3c5);
#
#
#
#         marker_34d83c7b6be5f7eb4f9dcea666a592b3.bindPopup(popup_7e8ec1e1a1b8e11ae1a563d9176df2f5)
#         ;
#
#
#
#
#             var marker_1eb2f38e686224f406865ddde17e7a7f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6c60c1adf035d8584b8c88b1adeb7934);
#
#
#         var popup_a95a613ada99b948639ef971bf90317a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f4983c5edfc7d919edff02c3f85b2e2 = $(`&lt;div id=&quot;html_6f4983c5edfc7d919edff02c3f85b2e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a95a613ada99b948639ef971bf90317a.setContent(html_6f4983c5edfc7d919edff02c3f85b2e2);
#
#
#
#         marker_1eb2f38e686224f406865ddde17e7a7f.bindPopup(popup_a95a613ada99b948639ef971bf90317a)
#         ;
#
#
#
#
#             var marker_00884ac5306971b4a245f6c42f114abc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6c60c1adf035d8584b8c88b1adeb7934);
#
#
#         var popup_26b2d202e5ef7a50a90596b47eb4af0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a6aa44559dc19a9e04332f128677d57 = $(`&lt;div id=&quot;html_8a6aa44559dc19a9e04332f128677d57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_26b2d202e5ef7a50a90596b47eb4af0f.setContent(html_8a6aa44559dc19a9e04332f128677d57);
#
#
#
#         marker_00884ac5306971b4a245f6c42f114abc.bindPopup(popup_26b2d202e5ef7a50a90596b47eb4af0f)
#         ;
#
#
#
#
#             var marker_9948f0261a3131904f7b76fc180f6451 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6c60c1adf035d8584b8c88b1adeb7934);
#
#
#         var popup_a0963c7b1bd296fd52e00592ac74da31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3634e4430919ebd577b35e2d5337649f = $(`&lt;div id=&quot;html_3634e4430919ebd577b35e2d5337649f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a0963c7b1bd296fd52e00592ac74da31.setContent(html_3634e4430919ebd577b35e2d5337649f);
#
#
#
#         marker_9948f0261a3131904f7b76fc180f6451.bindPopup(popup_a0963c7b1bd296fd52e00592ac74da31)
#         ;
#
#
#
#
#             var marker_12614f6d5b1d8077c03f81e79aebfda0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6c60c1adf035d8584b8c88b1adeb7934);
#
#
#         var popup_fb971cf5a0363150f4afd0436f333b24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba9771e4b48bc68bb656b84530e14f9b = $(`&lt;div id=&quot;html_ba9771e4b48bc68bb656b84530e14f9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fb971cf5a0363150f4afd0436f333b24.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c19e3428ce29476f0ae24bde34b16bde {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c19e3428ce29476f0ae24bde34b16bde&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c19e3428ce29476f0ae24bde34b16bde = L.map(
#                 &quot;map_c19e3428ce29476f0ae24bde34b16bde&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19bd84f3e6c6cf67bda0450de69f7030 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_19bd84f3e6c6cf67bda0450de69f7030.addTo(map_c19e3428ce29476f0ae24bde34b16bde);
#
#
#             var feature_group_7c662ea418e319852dd2c5337a93a23a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8fe044495e34bcc26d21cdab52c3d9ad = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7c662ea418e319852dd2c5337a93a23a);
#
#
#         var popup_c363546741639562999cc721a9cacdc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7355e33da0c71548a55078c52edcaa4 = $(`&lt;div id=&quot;html_f7355e33da0c71548a55078c52edcaa4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c363546741639562999cc721a9cacdc0.setContent(html_f7355e33da0c71548a55078c52edcaa4);
#
#
#
#         marker_8fe044495e34bcc26d21cdab52c3d9ad.bindPopup(popup_c363546741639562999cc721a9cacdc0)
#         ;
#
#
#
#
#             var marker_461b5a8537554ea67c7ac514448140a7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7c662ea418e319852dd2c5337a93a23a);
#
#
#         var popup_d4911ea1a57939783866fb137ddc46c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccae2e888daf3f6940be23cea397c4b3 = $(`&lt;div id=&quot;html_ccae2e888daf3f6940be23cea397c4b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d4911ea1a57939783866fb137ddc46c1.setContent(html_ccae2e888daf3f6940be23cea397c4b3);
#
#
#
#         marker_461b5a8537554ea67c7ac514448140a7.bindPopup(popup_d4911ea1a57939783866fb137ddc46c1)
#         ;
#
#
#
#
#             var marker_0b99fd808b3d27ad85f79a1f55946a09 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7c662ea418e319852dd2c5337a93a23a);
#
#
#         var popup_c57737df65af45c997f21daced91fadb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c679c2a7563cd6e150cd32adc83306d = $(`&lt;div id=&quot;html_2c679c2a7563cd6e150cd32adc83306d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c57737df65af45c997f21daced91fadb.setContent(html_2c679c2a7563cd6e150cd32adc83306d);
#
#
#
#         marker_0b99fd808b3d27ad85f79a1f55946a09.bindPopup(popup_c57737df65af45c997f21daced91fadb)
#         ;
#
#
#
#
#             var marker_5f0c3de5a8cf0be10ff2064cc865048c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7c662ea418e319852dd2c5337a93a23a);
#
#
#         var popup_13953578daee2a926ee0776768bec178 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_085f53be51b306b3619a11de86442435 = $(`&lt;div id=&quot;html_085f53be51b306b3619a11de86442435&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_13953578daee2a926ee0776768bec178.setContent(html_085f53be51b306b3619a11de86442435);
#
#
#
#         marker_5f0c3de5a8cf0be10ff2064cc865048c.bindPopup(popup_13953578daee2a926ee0776768bec178)
#         ;
#
#
#
#
#             var marker_92508eebe996e59346d17f5942303eac = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7c662ea418e319852dd2c5337a93a23a);
#
#
#         var popup_cfec9afae585ce2fc5c4700a6305b992 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_268a3ffa281f0953d1532a3b3120697d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_268a3ffa281f0953d1532a3b3120697d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_268a3ffa281f0953d1532a3b3120697d = L.map(
#                 &quot;map_268a3ffa281f0953d1532a3b3120697d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a513e8b0b4e7ead2f043af5ad4db5aea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a513e8b0b4e7ead2f043af5ad4db5aea.addTo(map_268a3ffa281f0953d1532a3b3120697d);
#
#
#             var feature_group_4ab6d9edb2244eaea7ebd037d76238d8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4ab6d9edb2244eaea7ebd037d76238d8.addTo(map_268a3ffa281f0953d1532a3b3120697d);
#
#
#             var feature_group_sub_group_1e72078a21cb93066817bb3eafa8955b = L.featureGroup.subGroup(
#                 feature_group_4ab6d9edb2244eaea7ebd037d76238d8
#             );
#
#
#             var marker_244189bc081aff0411ebf46fbc9e65e0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1e72078a21cb93066817bb3eafa8955b);
#
#
#         var popup_a53253aac35718a2df6ed05b5205f129 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2105b5277e76cbdd4328d86bb3e004d1 = $(`&lt;div id=&quot;html_2105b5277e76cbdd4328d86bb3e004d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a53253aac35718a2df6ed05b5205f129.setContent(html_2105b5277e76cbdd4328d86bb3e004d1);
#
#
#
#         marker_244189bc081aff0411ebf46fbc9e65e0.bindPopup(popup_a53253aac35718a2df6ed05b5205f129)
#         ;
#
#
#
#
#             var marker_a70f47228a349060e93f94281d39856a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1e72078a21cb93066817bb3eafa8955b);
#
#
#         var popup_8ada35152080caa6ac172ed92b1ab7a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c787cc134c7438e8aede3e371897c018 = $(`&lt;div id=&quot;html_c787cc134c7438e8aede3e371897c018&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8ada35152080caa6ac172ed92b1ab7a5.setContent(html_c787cc134c7438e8aede3e371897c018);
#
#
#
#         marker_a70f47228a349060e93f94281d39856a.bindPopup(popup_8ada35152080caa6ac172ed92b1ab7a5)
#         ;
#
#
#
#
#             var marker_e60c1c140ce34c89f115439633eb630e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1e72078a21cb93066817bb3eafa8955b);
#
#
#         var popup_353212f98f3dbf583148c0a1e9c72fdd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c6d2444195f7e047efb3e3f8c8d3260 = $(`&lt;div id=&quot;html_4c6d2444195f7e047efb3e3f8c8d3260&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_353212f98f3dbf583148c0a1e9c72fdd.setContent(html_4c6d2444195f7e047efb3e3f8c8d3260);
#
#
#
#         marker_e60c1c140ce34c89f115439633eb630e.bindPopup(popup_353212f98f3dbf583148c0a1e9c72fdd)
#         ;
#
#
#
#
#             var marker_14df673f456b2e5b293c7441cc4bb865 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1e72078a21cb93066817bb3eafa8955b);
#
#
#         var popup_95a9ba7e5b60260561e71cf9e5554cc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51e2c7f5860a8343e6c6c79469947ebb = $(`&lt;div id=&quot;html_51e2c7f5860a8343e6c6c79469947ebb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_95a9ba7e5b60260561e71cf9e5554cc3.setContent(html_51e2c7f5860a8343e6c6c79469947ebb);
#
#
#
#         marker_
