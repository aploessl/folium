# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b588b8b6c196c460545570912adf649 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b588b8b6c196c460545570912adf649&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b588b8b6c196c460545570912adf649 = L.map(
#                 &quot;map_8b588b8b6c196c460545570912adf649&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13c092c82a8fc7c569428ed2b36c860b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_13c092c82a8fc7c569428ed2b36c860b.addTo(map_8b588b8b6c196c460545570912adf649);
#
#
#             var marker_dbebaaf25e4d6aeb93096191a966daae = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8b588b8b6c196c460545570912adf649);
#
#
#         var popup_215b3c81e9c9845047d3f3151a587b23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34b89193ad54814753d20fa22c580021 = $(`&lt;div id=&quot;html_34b89193ad54814753d20fa22c580021&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_215b3c81e9c9845047d3f3151a587b23.setContent(html_34b89193ad54814753d20fa22c580021);
#
#
#
#         marker_dbebaaf25e4d6aeb93096191a966daae.bindPopup(popup_215b3c81e9c9845047d3f3151a587b23)
#         ;
#
#
#
#
#             var marker_3c549c783557d7e596276e743082812d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8b588b8b6c196c460545570912adf649);
#
#
#         var popup_7f946a6b8445b445083b0026193f2c19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7150c4832aa053f008e0012b209ff19 = $(`&lt;div id=&quot;html_d7150c4832aa053f008e0012b209ff19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7f946a6b8445b445083b0026193f2c19.setContent(html_d7150c4832aa053f008e0012b209ff19);
#
#
#
#         marker_3c549c783557d7e596276e743082812d.bindPopup(popup_7f946a6b8445b445083b0026193f2c19)
#         ;
#
#
#
#
#             var marker_f3f36919dbfa1febc9233915b9387c45 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8b588b8b6c196c460545570912adf649);
#
#
#         var popup_33a73c2805196ad66596c747b80f4814 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_addfeade91be0a823f5e959172befa58 = $(`&lt;div id=&quot;html_addfeade91be0a823f5e959172befa58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_33a73c2805196ad66596c747b80f4814.setContent(html_addfeade91be0a823f5e959172befa58);
#
#
#
#         marker_f3f36919dbfa1febc9233915b9387c45.bindPopup(popup_33a73c2805196ad66596c747b80f4814)
#         ;
#
#
#
#
#             var marker_da90704c1b9a2cfb0cba37d4c2ec6a6d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8b588b8b6c196c460545570912adf649);
#
#
#         var popup_175ad012374513f62f651330d0187134 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_294e3c7118284705637b7b861569d42d = $(`&lt;div id=&quot;html_294e3c7118284705637b7b861569d42d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_175ad012374513f62f651330d0187134.setContent(html_294e3c7118284705637b7b861569d42d);
#
#
#
#         marker_da90704c1b9a2cfb0cba37d4c2ec6a6d.bindPopup(popup_175ad012374513f62f651330d0187134)
#         ;
#
#
#
#
#             var marker_349e009f7bfb155f55e4cfe1e7d7cb92 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8b588b8b6c196c460545570912adf649);
#
#
#         var popup_7f83451cc8a52f8db4a40f61cefa2118 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e48be43d92fb57b6a4116e5f484ec06 = $(`&lt;div id=&quot;html_5e48be43d92fb57b6a4116e5f484ec06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7f83451cc8a52f8db4a40f61cefa2118.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7056c69d41cbdb41c5083117d7828837 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7056c69d41cbdb41c5083117d7828837&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7056c69d41cbdb41c5083117d7828837 = L.map(
#                 &quot;map_7056c69d41cbdb41c5083117d7828837&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5df449de7d1d2cca408064d63e774268 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5df449de7d1d2cca408064d63e774268.addTo(map_7056c69d41cbdb41c5083117d7828837);
#
#
#             var feature_group_e2860e64e1a7bd2fe3ea1067785270fe = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cb7de8161e1737f1e89d6c0416b33e42 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e2860e64e1a7bd2fe3ea1067785270fe);
#
#
#         var popup_633b436ab63bf891f349c18b6a72683c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69504408b9920be00ae856cf873fed69 = $(`&lt;div id=&quot;html_69504408b9920be00ae856cf873fed69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_633b436ab63bf891f349c18b6a72683c.setContent(html_69504408b9920be00ae856cf873fed69);
#
#
#
#         marker_cb7de8161e1737f1e89d6c0416b33e42.bindPopup(popup_633b436ab63bf891f349c18b6a72683c)
#         ;
#
#
#
#
#             var marker_e1fe9e51aab9340685278bb08c152428 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e2860e64e1a7bd2fe3ea1067785270fe);
#
#
#         var popup_16caa3f97829ca8668e108db53311865 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_629616e48558db1051bffe91c9bfd145 = $(`&lt;div id=&quot;html_629616e48558db1051bffe91c9bfd145&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_16caa3f97829ca8668e108db53311865.setContent(html_629616e48558db1051bffe91c9bfd145);
#
#
#
#         marker_e1fe9e51aab9340685278bb08c152428.bindPopup(popup_16caa3f97829ca8668e108db53311865)
#         ;
#
#
#
#
#             var marker_3fa116b8251de07e66660a1da2e82a54 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e2860e64e1a7bd2fe3ea1067785270fe);
#
#
#         var popup_212bd7319740051fb8ae9cf84589c31d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91169cbd034bbbbc9a74a3a34cccb542 = $(`&lt;div id=&quot;html_91169cbd034bbbbc9a74a3a34cccb542&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_212bd7319740051fb8ae9cf84589c31d.setContent(html_91169cbd034bbbbc9a74a3a34cccb542);
#
#
#
#         marker_3fa116b8251de07e66660a1da2e82a54.bindPopup(popup_212bd7319740051fb8ae9cf84589c31d)
#         ;
#
#
#
#
#             var marker_b7df3942a43ca7ea29950f1a170deb20 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e2860e64e1a7bd2fe3ea1067785270fe);
#
#
#         var popup_2c88e5fd460907867ad4eb96c8f6636c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6da93da7b759698c5adfc50c390fd45a = $(`&lt;div id=&quot;html_6da93da7b759698c5adfc50c390fd45a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2c88e5fd460907867ad4eb96c8f6636c.setContent(html_6da93da7b759698c5adfc50c390fd45a);
#
#
#
#         marker_b7df3942a43ca7ea29950f1a170deb20.bindPopup(popup_2c88e5fd460907867ad4eb96c8f6636c)
#         ;
#
#
#
#
#             var marker_a6488a18846c5ca498b9c72c75b5db0e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e2860e64e1a7bd2fe3ea1067785270fe);
#
#
#         var popup_0119dc2ac9f0cda8ace0f655271a1213 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e690d59e0fc32cb455dca3873d4fa47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e690d59e0fc32cb455dca3873d4fa47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e690d59e0fc32cb455dca3873d4fa47 = L.map(
#                 &quot;map_2e690d59e0fc32cb455dca3873d4fa47&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8fc8c0cf808a8f6d487d1785a00f3f33 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8fc8c0cf808a8f6d487d1785a00f3f33.addTo(map_2e690d59e0fc32cb455dca3873d4fa47);
#
#
#             var feature_group_9399555cfbdc29052d0913c4fcd04b63 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9399555cfbdc29052d0913c4fcd04b63.addTo(map_2e690d59e0fc32cb455dca3873d4fa47);
#
#
#             var feature_group_sub_group_415019991c5ab7a6900e653dada3d958 = L.featureGroup.subGroup(
#                 feature_group_9399555cfbdc29052d0913c4fcd04b63
#             );
#
#
#             var marker_67b423777dfa6a8112507e0ada2e8c9b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_415019991c5ab7a6900e653dada3d958);
#
#
#         var popup_3e183731e583112519826ed979af6d86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2d325c6c9da5ca61a5013224d4df731 = $(`&lt;div id=&quot;html_d2d325c6c9da5ca61a5013224d4df731&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3e183731e583112519826ed979af6d86.setContent(html_d2d325c6c9da5ca61a5013224d4df731);
#
#
#
#         marker_67b423777dfa6a8112507e0ada2e8c9b.bindPopup(popup_3e183731e583112519826ed979af6d86)
#         ;
#
#
#
#
#             var marker_027ef52587e19c5bc14a7f02a0c93ee9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_415019991c5ab7a6900e653dada3d958);
#
#
#         var popup_f2354aa0a8deaccbf9f1f45c39fc3160 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_954e55449d411fbdf5a73a37fcf2854f = $(`&lt;div id=&quot;html_954e55449d411fbdf5a73a37fcf2854f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f2354aa0a8deaccbf9f1f45c39fc3160.setContent(html_954e55449d411fbdf5a73a37fcf2854f);
#
#
#
#         marker_027ef52587e19c5bc14a7f02a0c93ee9.bindPopup(popup_f2354aa0a8deaccbf9f1f45c39fc3160)
#         ;
#
#
#
#
#             var marker_000fc9de91a1ee9bf7c27ce55362cfbc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_415019991c5ab7a6900e653dada3d958);
#
#
#         var popup_e874c3b2ab1f77818b459e718c3192c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0bb2e4b03bec38ef2314ce53df87b31 = $(`&lt;div id=&quot;html_f0bb2e4b03bec38ef2314ce53df87b31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e874c3b2ab1f77818b459e718c3192c8.setContent(html_f0bb2e4b03bec38ef2314ce53df87b31);
#
#
#
#         marker_000fc9de91a1ee9bf7c27ce55362cfbc.bindPopup(popup_e874c3b2ab1f77818b459e718c3192c8)
#         ;
#
#
#
#
#             var marker_844394e5aa8f9ff4e185005ca2514d2b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_415019991c5ab7a6900e653dada3d958);
#
#
#         var popup_fba2807d53b5ee7e170ab93e8e683148 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a91b7d88632ec4f45b4abe80d662405d = $(`&lt;div id=&quot;html_a91b7d88632ec4f45b4abe80d662405d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fba2807d53b5ee7e170ab93e8e683148.setContent(html_a91b7d88632ec4f45b4abe80d662405d);
#
#
#
#         marker_
