# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_760ce271c2926feaaae846602104b19d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_760ce271c2926feaaae846602104b19d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_760ce271c2926feaaae846602104b19d = L.map(
#                 &quot;map_760ce271c2926feaaae846602104b19d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a5aac4ab8b40ac5bddd7183501f9684 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a5aac4ab8b40ac5bddd7183501f9684.addTo(map_760ce271c2926feaaae846602104b19d);
#
#
#             var marker_4e458311040ab379435efd26e114ec6d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_760ce271c2926feaaae846602104b19d);
#
#
#         var popup_076c6097c666020697d95b8e2c9317fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17792d4fa16222019d3e46575d99e037 = $(`&lt;div id=&quot;html_17792d4fa16222019d3e46575d99e037&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_076c6097c666020697d95b8e2c9317fd.setContent(html_17792d4fa16222019d3e46575d99e037);
#
#
#
#         marker_4e458311040ab379435efd26e114ec6d.bindPopup(popup_076c6097c666020697d95b8e2c9317fd)
#         ;
#
#
#
#
#             var marker_221f5e4b795d5baa41d8467ddc7de526 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_760ce271c2926feaaae846602104b19d);
#
#
#         var popup_a54e0cd757b5dd9d2e686f1f5a3ff26d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_470772270a2c903c70c9290ae1038c4e = $(`&lt;div id=&quot;html_470772270a2c903c70c9290ae1038c4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a54e0cd757b5dd9d2e686f1f5a3ff26d.setContent(html_470772270a2c903c70c9290ae1038c4e);
#
#
#
#         marker_221f5e4b795d5baa41d8467ddc7de526.bindPopup(popup_a54e0cd757b5dd9d2e686f1f5a3ff26d)
#         ;
#
#
#
#
#             var marker_5c4d3d2c1f87fdcd783d91da105784bb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_760ce271c2926feaaae846602104b19d);
#
#
#         var popup_5fc7cb8260b3f665804e3e5c9aaad020 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4a560d2f127c2b685443a40ca5436a7 = $(`&lt;div id=&quot;html_a4a560d2f127c2b685443a40ca5436a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5fc7cb8260b3f665804e3e5c9aaad020.setContent(html_a4a560d2f127c2b685443a40ca5436a7);
#
#
#
#         marker_5c4d3d2c1f87fdcd783d91da105784bb.bindPopup(popup_5fc7cb8260b3f665804e3e5c9aaad020)
#         ;
#
#
#
#
#             var marker_38228f3c1b669c759af5cf1ffb46bce3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_760ce271c2926feaaae846602104b19d);
#
#
#         var popup_824d37c2303fb1658372630b404b8347 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f93ef7406e3998b6c4f03c6a26d5bdd1 = $(`&lt;div id=&quot;html_f93ef7406e3998b6c4f03c6a26d5bdd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_824d37c2303fb1658372630b404b8347.setContent(html_f93ef7406e3998b6c4f03c6a26d5bdd1);
#
#
#
#         marker_38228f3c1b669c759af5cf1ffb46bce3.bindPopup(popup_824d37c2303fb1658372630b404b8347)
#         ;
#
#
#
#
#             var marker_16c40b7998e0f3c173d20499359b2f12 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_760ce271c2926feaaae846602104b19d);
#
#
#         var popup_25ae09bfc73529f04da77db4d77200e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4dd90404c8161a88e4a401ae35c67d0 = $(`&lt;div id=&quot;html_e4dd90404c8161a88e4a401ae35c67d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_25ae09bfc73529f04da77db4d77200e4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e9a83ca721df487022b0e439a24780a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e9a83ca721df487022b0e439a24780a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e9a83ca721df487022b0e439a24780a = L.map(
#                 &quot;map_5e9a83ca721df487022b0e439a24780a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb34522f0c28e04abd9429a3e2029028 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bb34522f0c28e04abd9429a3e2029028.addTo(map_5e9a83ca721df487022b0e439a24780a);
#
#
#             var feature_group_a7d1c7848a2f26a38d501eb259887120 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_43c0d1c08252b06b4135622c0a56dabf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a7d1c7848a2f26a38d501eb259887120);
#
#
#         var popup_e34052243379251eaeded7841ad18906 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d34daacb035e9e3bfe117ee0a5c4d521 = $(`&lt;div id=&quot;html_d34daacb035e9e3bfe117ee0a5c4d521&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e34052243379251eaeded7841ad18906.setContent(html_d34daacb035e9e3bfe117ee0a5c4d521);
#
#
#
#         marker_43c0d1c08252b06b4135622c0a56dabf.bindPopup(popup_e34052243379251eaeded7841ad18906)
#         ;
#
#
#
#
#             var marker_bf6f78a2eacebd2946739525bb7d92f1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a7d1c7848a2f26a38d501eb259887120);
#
#
#         var popup_2b3ccdd9c82126ff97cbc8b367a9a59c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a853d2aba1a342e3565affe6db42c267 = $(`&lt;div id=&quot;html_a853d2aba1a342e3565affe6db42c267&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2b3ccdd9c82126ff97cbc8b367a9a59c.setContent(html_a853d2aba1a342e3565affe6db42c267);
#
#
#
#         marker_bf6f78a2eacebd2946739525bb7d92f1.bindPopup(popup_2b3ccdd9c82126ff97cbc8b367a9a59c)
#         ;
#
#
#
#
#             var marker_892cd72030a79b4a4d17409489aa1bc9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a7d1c7848a2f26a38d501eb259887120);
#
#
#         var popup_5601e80e02dd681df2e2855c30202f18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dfaba394c03aaa31691ca7bf420e964 = $(`&lt;div id=&quot;html_9dfaba394c03aaa31691ca7bf420e964&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5601e80e02dd681df2e2855c30202f18.setContent(html_9dfaba394c03aaa31691ca7bf420e964);
#
#
#
#         marker_892cd72030a79b4a4d17409489aa1bc9.bindPopup(popup_5601e80e02dd681df2e2855c30202f18)
#         ;
#
#
#
#
#             var marker_18a685db2e7ef5de8e83355faa5688c2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a7d1c7848a2f26a38d501eb259887120);
#
#
#         var popup_8155bbe50463b86e6a259ae069f63039 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9ca10b09cbfec39246208b4e7949e24 = $(`&lt;div id=&quot;html_a9ca10b09cbfec39246208b4e7949e24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8155bbe50463b86e6a259ae069f63039.setContent(html_a9ca10b09cbfec39246208b4e7949e24);
#
#
#
#         marker_18a685db2e7ef5de8e83355faa5688c2.bindPopup(popup_8155bbe50463b86e6a259ae069f63039)
#         ;
#
#
#
#
#             var marker_5861a14417605d7e9cb93a6c0a6ab4d1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a7d1c7848a2f26a38d501eb259887120);
#
#
#         var popup_3ff036745751c310e3e3c8b5aeabe9b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74114a7b28b5476b73b06f939ec9d9d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74114a7b28b5476b73b06f939ec9d9d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74114a7b28b5476b73b06f939ec9d9d3 = L.map(
#                 &quot;map_74114a7b28b5476b73b06f939ec9d9d3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_41cb582659b31d226b44b5d1d237d72c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_41cb582659b31d226b44b5d1d237d72c.addTo(map_74114a7b28b5476b73b06f939ec9d9d3);
#
#
#             var feature_group_efea8f8d31d1503d32816e2c901ef4b8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_efea8f8d31d1503d32816e2c901ef4b8.addTo(map_74114a7b28b5476b73b06f939ec9d9d3);
#
#
#             var feature_group_sub_group_af4911668d111f2618427321bea63fc3 = L.featureGroup.subGroup(
#                 feature_group_efea8f8d31d1503d32816e2c901ef4b8
#             );
#
#
#             var marker_60616e608c82d0f82e38891d81c1bde1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_af4911668d111f2618427321bea63fc3);
#
#
#         var popup_b1abf9b897102be172f7f4750b6ff1c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_acf97017ea178c4892e967c090ab8d0e = $(`&lt;div id=&quot;html_acf97017ea178c4892e967c090ab8d0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b1abf9b897102be172f7f4750b6ff1c0.setContent(html_acf97017ea178c4892e967c090ab8d0e);
#
#
#
#         marker_60616e608c82d0f82e38891d81c1bde1.bindPopup(popup_b1abf9b897102be172f7f4750b6ff1c0)
#         ;
#
#
#
#
#             var marker_771a54d7da9e5747af72a0c246ef6240 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_af4911668d111f2618427321bea63fc3);
#
#
#         var popup_7fa8f96b521f4e2a75ef408435b05bca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cbba6c7a17378fb18702fec49dcd6c6 = $(`&lt;div id=&quot;html_4cbba6c7a17378fb18702fec49dcd6c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7fa8f96b521f4e2a75ef408435b05bca.setContent(html_4cbba6c7a17378fb18702fec49dcd6c6);
#
#
#
#         marker_771a54d7da9e5747af72a0c246ef6240.bindPopup(popup_7fa8f96b521f4e2a75ef408435b05bca)
#         ;
#
#
#
#
#             var marker_8eeb37fbfe0ea52cc36a2ca1fbfb1681 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_af4911668d111f2618427321bea63fc3);
#
#
#         var popup_2d094a063c5e877bba1051ad9bf2313e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6169b80cf48077a78b63fd37eaa3402f = $(`&lt;div id=&quot;html_6169b80cf48077a78b63fd37eaa3402f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2d094a063c5e877bba1051ad9bf2313e.setContent(html_6169b80cf48077a78b63fd37eaa3402f);
#
#
#
#         marker_8eeb37fbfe0ea52cc36a2ca1fbfb1681.bindPopup(popup_2d094a063c5e877bba1051ad9bf2313e)
#         ;
#
#
#
#
#             var marker_cc9d6f4ba689409ebe90d5bdf41fc13b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_af4911668d111f2618427321bea63fc3);
#
#
#         var popup_f58a69198553f76abfd8b2ca8dafdb82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_495ad8871c0dd03cf3b968f55031b4f4 = $(`&lt;div id=&quot;html_495ad8871c0dd03cf3b968f55031b4f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f58a69198553f76abfd8b2ca8dafdb82.setContent(html_495ad8871c0dd03cf3b968f55031b4f4);
#
#
#
#         marker_
