# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_085f43377436bb8cbb137331585fc576 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_085f43377436bb8cbb137331585fc576&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_085f43377436bb8cbb137331585fc576 = L.map(
#                 &quot;map_085f43377436bb8cbb137331585fc576&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0aa7fc8fada68e283e56222e9b8887d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0aa7fc8fada68e283e56222e9b8887d0.addTo(map_085f43377436bb8cbb137331585fc576);
#
#
#             var marker_f3b057bb912fa00a8d497a992a4758af = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_085f43377436bb8cbb137331585fc576);
#
#
#         var popup_c5d6d5862ddaa27db9b6ef2a32653602 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_075ce2bfa6c4a33c1403cf0afb4f08c6 = $(`&lt;div id=&quot;html_075ce2bfa6c4a33c1403cf0afb4f08c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c5d6d5862ddaa27db9b6ef2a32653602.setContent(html_075ce2bfa6c4a33c1403cf0afb4f08c6);
#
#
#
#         marker_f3b057bb912fa00a8d497a992a4758af.bindPopup(popup_c5d6d5862ddaa27db9b6ef2a32653602)
#         ;
#
#
#
#
#             var marker_50ff62a7532abe678beae5b58af33074 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_085f43377436bb8cbb137331585fc576);
#
#
#         var popup_84cd229aa6923754712832ec896023d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ef46ac40f94d045fb277e0b01bae4ed = $(`&lt;div id=&quot;html_7ef46ac40f94d045fb277e0b01bae4ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_84cd229aa6923754712832ec896023d1.setContent(html_7ef46ac40f94d045fb277e0b01bae4ed);
#
#
#
#         marker_50ff62a7532abe678beae5b58af33074.bindPopup(popup_84cd229aa6923754712832ec896023d1)
#         ;
#
#
#
#
#             var marker_2a5c7879254219fb4e5815d60f9432cb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_085f43377436bb8cbb137331585fc576);
#
#
#         var popup_dc6ffd76d38f035ae75a79346c02e363 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccf20a19807048b0426b5e9a7b36602b = $(`&lt;div id=&quot;html_ccf20a19807048b0426b5e9a7b36602b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dc6ffd76d38f035ae75a79346c02e363.setContent(html_ccf20a19807048b0426b5e9a7b36602b);
#
#
#
#         marker_2a5c7879254219fb4e5815d60f9432cb.bindPopup(popup_dc6ffd76d38f035ae75a79346c02e363)
#         ;
#
#
#
#
#             var marker_2b3a3aa66144c4dfeb456e79575e152f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_085f43377436bb8cbb137331585fc576);
#
#
#         var popup_984e9cec18da1a208fadf5d7c345883e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6fc34758a3fae4f7ff3881a69efdfed = $(`&lt;div id=&quot;html_c6fc34758a3fae4f7ff3881a69efdfed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_984e9cec18da1a208fadf5d7c345883e.setContent(html_c6fc34758a3fae4f7ff3881a69efdfed);
#
#
#
#         marker_2b3a3aa66144c4dfeb456e79575e152f.bindPopup(popup_984e9cec18da1a208fadf5d7c345883e)
#         ;
#
#
#
#
#             var marker_6701937e8b518d67ed9f0ec0773e8746 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_085f43377436bb8cbb137331585fc576);
#
#
#         var popup_5c002f94dbf5391c96972d8000af87cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_768e10a8cf957b7121944a0a7d8334fc = $(`&lt;div id=&quot;html_768e10a8cf957b7121944a0a7d8334fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5c002f94dbf5391c96972d8000af87cd.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d383348b1537bdb579917deb6b2bf4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d383348b1537bdb579917deb6b2bf4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d383348b1537bdb579917deb6b2bf4c = L.map(
#                 &quot;map_6d383348b1537bdb579917deb6b2bf4c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2518fb026c9dacae13685e9f3b46ca11 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2518fb026c9dacae13685e9f3b46ca11.addTo(map_6d383348b1537bdb579917deb6b2bf4c);
#
#
#             var feature_group_bcfc3a2596c3370f450d80f87bf3452a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_dd625643df30d3eb34530770519112a8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_bcfc3a2596c3370f450d80f87bf3452a);
#
#
#         var popup_d5b53f8459fcc34d50886f675d4812b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c70ea8e6f9a53011d853297bdf193efb = $(`&lt;div id=&quot;html_c70ea8e6f9a53011d853297bdf193efb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d5b53f8459fcc34d50886f675d4812b2.setContent(html_c70ea8e6f9a53011d853297bdf193efb);
#
#
#
#         marker_dd625643df30d3eb34530770519112a8.bindPopup(popup_d5b53f8459fcc34d50886f675d4812b2)
#         ;
#
#
#
#
#             var marker_cec2e7ff39a8557038ee8f0a8cd59406 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_bcfc3a2596c3370f450d80f87bf3452a);
#
#
#         var popup_7ea53b6815796822cae0c9199cb03eb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_709620953ba92967c930541318adfb2a = $(`&lt;div id=&quot;html_709620953ba92967c930541318adfb2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7ea53b6815796822cae0c9199cb03eb1.setContent(html_709620953ba92967c930541318adfb2a);
#
#
#
#         marker_cec2e7ff39a8557038ee8f0a8cd59406.bindPopup(popup_7ea53b6815796822cae0c9199cb03eb1)
#         ;
#
#
#
#
#             var marker_7d61f239a7bbb9f32f8c0d4f82c9838b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_bcfc3a2596c3370f450d80f87bf3452a);
#
#
#         var popup_e4ce553880fe8c436c5957168ab2729c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_872d6e3c9a0edfc307f84de1e28c7019 = $(`&lt;div id=&quot;html_872d6e3c9a0edfc307f84de1e28c7019&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e4ce553880fe8c436c5957168ab2729c.setContent(html_872d6e3c9a0edfc307f84de1e28c7019);
#
#
#
#         marker_7d61f239a7bbb9f32f8c0d4f82c9838b.bindPopup(popup_e4ce553880fe8c436c5957168ab2729c)
#         ;
#
#
#
#
#             var marker_bdbdac2b1a296f935f59492be172a64a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_bcfc3a2596c3370f450d80f87bf3452a);
#
#
#         var popup_2796c1e679626ef9406d8b5080948fb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dccb45ec516f373c8d69e5861d64f835 = $(`&lt;div id=&quot;html_dccb45ec516f373c8d69e5861d64f835&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2796c1e679626ef9406d8b5080948fb0.setContent(html_dccb45ec516f373c8d69e5861d64f835);
#
#
#
#         marker_bdbdac2b1a296f935f59492be172a64a.bindPopup(popup_2796c1e679626ef9406d8b5080948fb0)
#         ;
#
#
#
#
#             var marker_aefcfb277636dc2795f9f60378625833 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_bcfc3a2596c3370f450d80f87bf3452a);
#
#
#         var popup_6dc5b78beabc561875c6d8dc575d0c82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35eb12763a84faac5a00efa29e02e524 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35eb12763a84faac5a00efa29e02e524&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35eb12763a84faac5a00efa29e02e524 = L.map(
#                 &quot;map_35eb12763a84faac5a00efa29e02e524&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd629129220530ded43369932da7cd27 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fd629129220530ded43369932da7cd27.addTo(map_35eb12763a84faac5a00efa29e02e524);
#
#
#             var feature_group_db85331cfd4714b35a9ff1a94fd5c370 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_db85331cfd4714b35a9ff1a94fd5c370.addTo(map_35eb12763a84faac5a00efa29e02e524);
#
#
#             var feature_group_sub_group_5b2b90ba8562a6d9e97df38cf660344e = L.featureGroup.subGroup(
#                 feature_group_db85331cfd4714b35a9ff1a94fd5c370
#             );
#
#
#             var marker_be6f5942398e2a8cb74fe8b79ed67524 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b2b90ba8562a6d9e97df38cf660344e);
#
#
#         var popup_a4c7d0fe6f809729171b53e45b306ae2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1af96ad6793a5135aa20aa41516dff22 = $(`&lt;div id=&quot;html_1af96ad6793a5135aa20aa41516dff22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a4c7d0fe6f809729171b53e45b306ae2.setContent(html_1af96ad6793a5135aa20aa41516dff22);
#
#
#
#         marker_be6f5942398e2a8cb74fe8b79ed67524.bindPopup(popup_a4c7d0fe6f809729171b53e45b306ae2)
#         ;
#
#
#
#
#             var marker_a9a51ff892dc613b698c4e74b6728839 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b2b90ba8562a6d9e97df38cf660344e);
#
#
#         var popup_cadb84a91712f47fbce167b1baae0eb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f14087ae732c9d8a8f100e6dece99911 = $(`&lt;div id=&quot;html_f14087ae732c9d8a8f100e6dece99911&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cadb84a91712f47fbce167b1baae0eb1.setContent(html_f14087ae732c9d8a8f100e6dece99911);
#
#
#
#         marker_a9a51ff892dc613b698c4e74b6728839.bindPopup(popup_cadb84a91712f47fbce167b1baae0eb1)
#         ;
#
#
#
#
#             var marker_6fc56041b09bf6c33233bd60a2b41b6e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b2b90ba8562a6d9e97df38cf660344e);
#
#
#         var popup_32b8d797d7213d13f7df222be4d0ba44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bbbe34e64ee90c69181ea80ec2f1ca2 = $(`&lt;div id=&quot;html_7bbbe34e64ee90c69181ea80ec2f1ca2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_32b8d797d7213d13f7df222be4d0ba44.setContent(html_7bbbe34e64ee90c69181ea80ec2f1ca2);
#
#
#
#         marker_6fc56041b09bf6c33233bd60a2b41b6e.bindPopup(popup_32b8d797d7213d13f7df222be4d0ba44)
#         ;
#
#
#
#
#             var marker_d5286630cc8da0b3a880d91ba953415b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b2b90ba8562a6d9e97df38cf660344e);
#
#
#         var popup_95c7c23ee47da0b82c0b1a80eee0210b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5621b57d908fbe115ec5ce6228b5d4f2 = $(`&lt;div id=&quot;html_5621b57d908fbe115ec5ce6228b5d4f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_95c7c23ee47da0b82c0b1a80eee0210b.setContent(html_5621b57d908fbe115ec5ce6228b5d4f2);
#
#
#
#         marker_
