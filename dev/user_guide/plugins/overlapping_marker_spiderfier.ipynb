# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e26a4742e6115c08afc6bae90389287d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e26a4742e6115c08afc6bae90389287d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e26a4742e6115c08afc6bae90389287d = L.map(
#                 &quot;map_e26a4742e6115c08afc6bae90389287d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70386e684b4af69a2320244bf52e0777 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70386e684b4af69a2320244bf52e0777.addTo(map_e26a4742e6115c08afc6bae90389287d);
#
#
#             var marker_2b90a3cc5e1e00ddd5d6b0ffb47d4df8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e26a4742e6115c08afc6bae90389287d);
#
#
#         var popup_dcd36a75f878a36ec9edfc7f369247d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ed34b3191c55c6c8effa1736f483c5f = $(`&lt;div id=&quot;html_5ed34b3191c55c6c8effa1736f483c5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_dcd36a75f878a36ec9edfc7f369247d0.setContent(html_5ed34b3191c55c6c8effa1736f483c5f);
#
#
#
#         marker_2b90a3cc5e1e00ddd5d6b0ffb47d4df8.bindPopup(popup_dcd36a75f878a36ec9edfc7f369247d0)
#         ;
#
#
#
#
#             var marker_ee425fd5174443eb747bff23860d80df = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e26a4742e6115c08afc6bae90389287d);
#
#
#         var popup_2e5f3cd2f4aeedaa552ca83665af9e24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf62a9c592e679002c81b4be5a23f999 = $(`&lt;div id=&quot;html_bf62a9c592e679002c81b4be5a23f999&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2e5f3cd2f4aeedaa552ca83665af9e24.setContent(html_bf62a9c592e679002c81b4be5a23f999);
#
#
#
#         marker_ee425fd5174443eb747bff23860d80df.bindPopup(popup_2e5f3cd2f4aeedaa552ca83665af9e24)
#         ;
#
#
#
#
#             var marker_a3d1f28f35a0092d949d4fcd01a9469f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e26a4742e6115c08afc6bae90389287d);
#
#
#         var popup_fa504069e03cf90c05c176a18012f58c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bebadb70d7e585576f96b9d19c5d35a2 = $(`&lt;div id=&quot;html_bebadb70d7e585576f96b9d19c5d35a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fa504069e03cf90c05c176a18012f58c.setContent(html_bebadb70d7e585576f96b9d19c5d35a2);
#
#
#
#         marker_a3d1f28f35a0092d949d4fcd01a9469f.bindPopup(popup_fa504069e03cf90c05c176a18012f58c)
#         ;
#
#
#
#
#             var marker_8a3c65bfb75ff038bc17e81a7983acc3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e26a4742e6115c08afc6bae90389287d);
#
#
#         var popup_d4b7eb8c0b271d2b0e14edac4aa40e00 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd22cd06a0474e12cb734b16910bcb31 = $(`&lt;div id=&quot;html_cd22cd06a0474e12cb734b16910bcb31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d4b7eb8c0b271d2b0e14edac4aa40e00.setContent(html_cd22cd06a0474e12cb734b16910bcb31);
#
#
#
#         marker_8a3c65bfb75ff038bc17e81a7983acc3.bindPopup(popup_d4b7eb8c0b271d2b0e14edac4aa40e00)
#         ;
#
#
#
#
#             var marker_2c57962a145b1ec0a0c54b2f1e6e02b5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e26a4742e6115c08afc6bae90389287d);
#
#
#         var popup_cef4c33c0eb0e1e1acb594813cf846f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c96c42050b0ef68072cf9272457daecb = $(`&lt;div id=&quot;html_c96c42050b0ef68072cf9272457daecb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_cef4c33c0eb0e1e1acb594813cf846f3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d190dc4d2b036676b7a43cc3d4378c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d190dc4d2b036676b7a43cc3d4378c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d190dc4d2b036676b7a43cc3d4378c8 = L.map(
#                 &quot;map_6d190dc4d2b036676b7a43cc3d4378c8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01e0aa954700be7d0da8374921719a9b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_01e0aa954700be7d0da8374921719a9b.addTo(map_6d190dc4d2b036676b7a43cc3d4378c8);
#
#
#             var feature_group_fa83de92cdcc6f863cf1522b89a6efaf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a6286db20cf40fb43033c2d121f2ecca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fa83de92cdcc6f863cf1522b89a6efaf);
#
#
#         var popup_5fbb7a776e6de8168af49f8ee43893a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bf47b2add6ef179e06af358d781c3f8 = $(`&lt;div id=&quot;html_9bf47b2add6ef179e06af358d781c3f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5fbb7a776e6de8168af49f8ee43893a2.setContent(html_9bf47b2add6ef179e06af358d781c3f8);
#
#
#
#         marker_a6286db20cf40fb43033c2d121f2ecca.bindPopup(popup_5fbb7a776e6de8168af49f8ee43893a2)
#         ;
#
#
#
#
#             var marker_326666abcd57ad8d0237627dc57f451c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fa83de92cdcc6f863cf1522b89a6efaf);
#
#
#         var popup_b2b50d8ec36d1e7a2e922ff4b463e08a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1453fdb0287e4f9ebe364ce29f8a210d = $(`&lt;div id=&quot;html_1453fdb0287e4f9ebe364ce29f8a210d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b2b50d8ec36d1e7a2e922ff4b463e08a.setContent(html_1453fdb0287e4f9ebe364ce29f8a210d);
#
#
#
#         marker_326666abcd57ad8d0237627dc57f451c.bindPopup(popup_b2b50d8ec36d1e7a2e922ff4b463e08a)
#         ;
#
#
#
#
#             var marker_50938cfe449789f090e6d3894be83b7e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fa83de92cdcc6f863cf1522b89a6efaf);
#
#
#         var popup_9437d36560ed6319a0008739617f73cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f39cc6e5759d572cc07ca7b5f3cdcb9 = $(`&lt;div id=&quot;html_6f39cc6e5759d572cc07ca7b5f3cdcb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9437d36560ed6319a0008739617f73cd.setContent(html_6f39cc6e5759d572cc07ca7b5f3cdcb9);
#
#
#
#         marker_50938cfe449789f090e6d3894be83b7e.bindPopup(popup_9437d36560ed6319a0008739617f73cd)
#         ;
#
#
#
#
#             var marker_ea7b6aad224c633ee49a4ca695952aec = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fa83de92cdcc6f863cf1522b89a6efaf);
#
#
#         var popup_acbf166546e5460dc89e0210a7820131 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_064d7b5890528fecc6d8ffce44cde1be = $(`&lt;div id=&quot;html_064d7b5890528fecc6d8ffce44cde1be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_acbf166546e5460dc89e0210a7820131.setContent(html_064d7b5890528fecc6d8ffce44cde1be);
#
#
#
#         marker_ea7b6aad224c633ee49a4ca695952aec.bindPopup(popup_acbf166546e5460dc89e0210a7820131)
#         ;
#
#
#
#
#             var marker_cc8f6ad58a2aeb437dc5a8fd6e4536de = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fa83de92cdcc6f863cf1522b89a6efaf);
#
#
#         var popup_6261a392ebe981517313a3557d52fa16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9aebd9688c37c299d4c38dc6da8189b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9aebd9688c37c299d4c38dc6da8189b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9aebd9688c37c299d4c38dc6da8189b = L.map(
#                 &quot;map_e9aebd9688c37c299d4c38dc6da8189b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4020fd181d3479c4f582808fd2284a7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b4020fd181d3479c4f582808fd2284a7.addTo(map_e9aebd9688c37c299d4c38dc6da8189b);
#
#
#             var feature_group_556951db30ca2b043e8e97522f082691 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_556951db30ca2b043e8e97522f082691.addTo(map_e9aebd9688c37c299d4c38dc6da8189b);
#
#
#             var feature_group_sub_group_2bbf3d114a80f35ee026555b030479cf = L.featureGroup.subGroup(
#                 feature_group_556951db30ca2b043e8e97522f082691
#             );
#
#
#             var marker_4a2f4913461094c7d98a0694880f5380 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2bbf3d114a80f35ee026555b030479cf);
#
#
#         var popup_b7b28801185cfd766cc0e772837d9b32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f329fdfc31d6a5e0700fc3c98a4b2f16 = $(`&lt;div id=&quot;html_f329fdfc31d6a5e0700fc3c98a4b2f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b7b28801185cfd766cc0e772837d9b32.setContent(html_f329fdfc31d6a5e0700fc3c98a4b2f16);
#
#
#
#         marker_4a2f4913461094c7d98a0694880f5380.bindPopup(popup_b7b28801185cfd766cc0e772837d9b32)
#         ;
#
#
#
#
#             var marker_66e8f14b6fdb1ffbddc19e1e92d376d8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2bbf3d114a80f35ee026555b030479cf);
#
#
#         var popup_bfca18a8a37c38d77aebadf5b5764864 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_707a311b5254be0fd8324f36010cbfb2 = $(`&lt;div id=&quot;html_707a311b5254be0fd8324f36010cbfb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bfca18a8a37c38d77aebadf5b5764864.setContent(html_707a311b5254be0fd8324f36010cbfb2);
#
#
#
#         marker_66e8f14b6fdb1ffbddc19e1e92d376d8.bindPopup(popup_bfca18a8a37c38d77aebadf5b5764864)
#         ;
#
#
#
#
#             var marker_8698ee97eb572ae61595c697eece4647 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2bbf3d114a80f35ee026555b030479cf);
#
#
#         var popup_6975f66b873d6f6887513a4e017cf47e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bec702368ed62e3bad79891bc1c56d7 = $(`&lt;div id=&quot;html_1bec702368ed62e3bad79891bc1c56d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6975f66b873d6f6887513a4e017cf47e.setContent(html_1bec702368ed62e3bad79891bc1c56d7);
#
#
#
#         marker_8698ee97eb572ae61595c697eece4647.bindPopup(popup_6975f66b873d6f6887513a4e017cf47e)
#         ;
#
#
#
#
#             var marker_137b6cfe89755e17f9f727bcfd21ef8c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2bbf3d114a80f35ee026555b030479cf);
#
#
#         var popup_9c802b926f5e708ac04ff604c76d3260 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b79430787741bd8aa4368866270f5cc = $(`&lt;div id=&quot;html_6b79430787741bd8aa4368866270f5cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9c802b926f5e708ac04ff604c76d3260.setContent(html_6b79430787741bd8aa4368866270f5cc);
#
#
#
#         marker_
