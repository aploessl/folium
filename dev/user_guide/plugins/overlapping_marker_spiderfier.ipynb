# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed889dc7d3668f0ad63305668fd5c147 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed889dc7d3668f0ad63305668fd5c147&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed889dc7d3668f0ad63305668fd5c147 = L.map(
#                 &quot;map_ed889dc7d3668f0ad63305668fd5c147&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_485a9ccc31f0aec954a06325e8b4f806 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_485a9ccc31f0aec954a06325e8b4f806.addTo(map_ed889dc7d3668f0ad63305668fd5c147);
#
#
#             var marker_3d4deee70a5bafdebd3cf14d0b5de7e6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ed889dc7d3668f0ad63305668fd5c147);
#
#
#         var popup_f1d0546c5cb5116af55538d2054292e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c46a3e6f5aee7587d5efc55dbeb83b5c = $(`&lt;div id=&quot;html_c46a3e6f5aee7587d5efc55dbeb83b5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f1d0546c5cb5116af55538d2054292e7.setContent(html_c46a3e6f5aee7587d5efc55dbeb83b5c);
#
#
#
#         marker_3d4deee70a5bafdebd3cf14d0b5de7e6.bindPopup(popup_f1d0546c5cb5116af55538d2054292e7)
#         ;
#
#
#
#
#             var marker_37b1102fc21aa746aec90d7eee0289a8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ed889dc7d3668f0ad63305668fd5c147);
#
#
#         var popup_a6ad369722616e7d2162d8b92b84343e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77047b43455eaeb71aa81384c7e775d8 = $(`&lt;div id=&quot;html_77047b43455eaeb71aa81384c7e775d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a6ad369722616e7d2162d8b92b84343e.setContent(html_77047b43455eaeb71aa81384c7e775d8);
#
#
#
#         marker_37b1102fc21aa746aec90d7eee0289a8.bindPopup(popup_a6ad369722616e7d2162d8b92b84343e)
#         ;
#
#
#
#
#             var marker_3939dda1eee293cc9a4cb42cd3bbd0e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ed889dc7d3668f0ad63305668fd5c147);
#
#
#         var popup_2d6da142653d1b3e86b0859ad4ea778d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58d72b07e876fdf0cb71aa11169d16e3 = $(`&lt;div id=&quot;html_58d72b07e876fdf0cb71aa11169d16e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2d6da142653d1b3e86b0859ad4ea778d.setContent(html_58d72b07e876fdf0cb71aa11169d16e3);
#
#
#
#         marker_3939dda1eee293cc9a4cb42cd3bbd0e8.bindPopup(popup_2d6da142653d1b3e86b0859ad4ea778d)
#         ;
#
#
#
#
#             var marker_b38965feefe4777d47cd2f8aa013c0ca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ed889dc7d3668f0ad63305668fd5c147);
#
#
#         var popup_c95d2af21ef802084a43de85e4fbc4c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c5d95d3373930fde8282a5fd4a5b18a = $(`&lt;div id=&quot;html_7c5d95d3373930fde8282a5fd4a5b18a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c95d2af21ef802084a43de85e4fbc4c0.setContent(html_7c5d95d3373930fde8282a5fd4a5b18a);
#
#
#
#         marker_b38965feefe4777d47cd2f8aa013c0ca.bindPopup(popup_c95d2af21ef802084a43de85e4fbc4c0)
#         ;
#
#
#
#
#             var marker_35de65a56bf3b48a07eae711664ad274 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ed889dc7d3668f0ad63305668fd5c147);
#
#
#         var popup_234630a975c1e908dc37e87a76c25f1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e247ef769a5de02d0d9a5da416439a5d = $(`&lt;div id=&quot;html_e247ef769a5de02d0d9a5da416439a5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_234630a975c1e908dc37e87a76c25f1c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3223b4991af764af0990f5864083016e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3223b4991af764af0990f5864083016e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3223b4991af764af0990f5864083016e = L.map(
#                 &quot;map_3223b4991af764af0990f5864083016e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_912a7749813bc12a626ca67527ac36bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_912a7749813bc12a626ca67527ac36bc.addTo(map_3223b4991af764af0990f5864083016e);
#
#
#             var feature_group_b9a7f53ca465c7a8921aa7be73ce5100 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_937e1b72109091d64b10a4a828aae90d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b9a7f53ca465c7a8921aa7be73ce5100);
#
#
#         var popup_9d345b4df6da5d6c61b3eb6223ad60f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_647270e28967851e589868597d929f5b = $(`&lt;div id=&quot;html_647270e28967851e589868597d929f5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9d345b4df6da5d6c61b3eb6223ad60f1.setContent(html_647270e28967851e589868597d929f5b);
#
#
#
#         marker_937e1b72109091d64b10a4a828aae90d.bindPopup(popup_9d345b4df6da5d6c61b3eb6223ad60f1)
#         ;
#
#
#
#
#             var marker_4c80c0a3f2190da0e66dac8d7dcf7154 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b9a7f53ca465c7a8921aa7be73ce5100);
#
#
#         var popup_4ba5cf359b25ff6040da9c483b5f0daa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74d8143c4002e453ba2a11f40c72f1b2 = $(`&lt;div id=&quot;html_74d8143c4002e453ba2a11f40c72f1b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4ba5cf359b25ff6040da9c483b5f0daa.setContent(html_74d8143c4002e453ba2a11f40c72f1b2);
#
#
#
#         marker_4c80c0a3f2190da0e66dac8d7dcf7154.bindPopup(popup_4ba5cf359b25ff6040da9c483b5f0daa)
#         ;
#
#
#
#
#             var marker_994e2974d7916849101168099eb9cde8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b9a7f53ca465c7a8921aa7be73ce5100);
#
#
#         var popup_39179137c90d1e27718ff2da04b563ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c089c4c73f7b763d1527b3b83ac88211 = $(`&lt;div id=&quot;html_c089c4c73f7b763d1527b3b83ac88211&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_39179137c90d1e27718ff2da04b563ba.setContent(html_c089c4c73f7b763d1527b3b83ac88211);
#
#
#
#         marker_994e2974d7916849101168099eb9cde8.bindPopup(popup_39179137c90d1e27718ff2da04b563ba)
#         ;
#
#
#
#
#             var marker_1142f3cd9aa0b7e2d3269c9a841000df = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b9a7f53ca465c7a8921aa7be73ce5100);
#
#
#         var popup_524d339059f90c9576e564e42a5d63da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f34f0bdd958ad6662fce7c987117543a = $(`&lt;div id=&quot;html_f34f0bdd958ad6662fce7c987117543a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_524d339059f90c9576e564e42a5d63da.setContent(html_f34f0bdd958ad6662fce7c987117543a);
#
#
#
#         marker_1142f3cd9aa0b7e2d3269c9a841000df.bindPopup(popup_524d339059f90c9576e564e42a5d63da)
#         ;
#
#
#
#
#             var marker_9ad448b17321429098fcad32c6a02a3c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b9a7f53ca465c7a8921aa7be73ce5100);
#
#
#         var popup_2f66806e6688c737dca18d2741b58239 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8ab3bba748e1cb5d37a50b79e413534 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8ab3bba748e1cb5d37a50b79e413534&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8ab3bba748e1cb5d37a50b79e413534 = L.map(
#                 &quot;map_a8ab3bba748e1cb5d37a50b79e413534&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f58142c3be28898b7f255a9e47fa8d65 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f58142c3be28898b7f255a9e47fa8d65.addTo(map_a8ab3bba748e1cb5d37a50b79e413534);
#
#
#             var feature_group_2bae15d62a8579d02f1f08536b5735a0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2bae15d62a8579d02f1f08536b5735a0.addTo(map_a8ab3bba748e1cb5d37a50b79e413534);
#
#
#             var feature_group_sub_group_6ba536b9b4c55c2ee6835b6187aa40e9 = L.featureGroup.subGroup(
#                 feature_group_2bae15d62a8579d02f1f08536b5735a0
#             );
#
#
#             var marker_b3617140aca318f1a05de3bce98dc2f3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6ba536b9b4c55c2ee6835b6187aa40e9);
#
#
#         var popup_8eff7de1cfb2fe428a1496387a6a1ffe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa35f8235ce3cae82085b5045ca6e5f0 = $(`&lt;div id=&quot;html_aa35f8235ce3cae82085b5045ca6e5f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8eff7de1cfb2fe428a1496387a6a1ffe.setContent(html_aa35f8235ce3cae82085b5045ca6e5f0);
#
#
#
#         marker_b3617140aca318f1a05de3bce98dc2f3.bindPopup(popup_8eff7de1cfb2fe428a1496387a6a1ffe)
#         ;
#
#
#
#
#             var marker_e7ba60985e64cd4a90af628a61f79992 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6ba536b9b4c55c2ee6835b6187aa40e9);
#
#
#         var popup_fc8c26d9a0a6a02c453d5ac2b30c202d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89cac1ec39b7fbf0ac2953807390577c = $(`&lt;div id=&quot;html_89cac1ec39b7fbf0ac2953807390577c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fc8c26d9a0a6a02c453d5ac2b30c202d.setContent(html_89cac1ec39b7fbf0ac2953807390577c);
#
#
#
#         marker_e7ba60985e64cd4a90af628a61f79992.bindPopup(popup_fc8c26d9a0a6a02c453d5ac2b30c202d)
#         ;
#
#
#
#
#             var marker_a12fb1a151840247e8a9f1c986c152f4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6ba536b9b4c55c2ee6835b6187aa40e9);
#
#
#         var popup_9dec4113caf16931ee0da36c1338a33e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04519591a03c58347c1a45fdcba8e872 = $(`&lt;div id=&quot;html_04519591a03c58347c1a45fdcba8e872&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9dec4113caf16931ee0da36c1338a33e.setContent(html_04519591a03c58347c1a45fdcba8e872);
#
#
#
#         marker_a12fb1a151840247e8a9f1c986c152f4.bindPopup(popup_9dec4113caf16931ee0da36c1338a33e)
#         ;
#
#
#
#
#             var marker_3c775020620490c8d7b46e548a58b90a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6ba536b9b4c55c2ee6835b6187aa40e9);
#
#
#         var popup_ace0a9b51e2055fca2be324381e4957c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f6bd98798082c558c0b3926cd45dd02 = $(`&lt;div id=&quot;html_0f6bd98798082c558c0b3926cd45dd02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ace0a9b51e2055fca2be324381e4957c.setContent(html_0f6bd98798082c558c0b3926cd45dd02);
#
#
#
#         marker_
