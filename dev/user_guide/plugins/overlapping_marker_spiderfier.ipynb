# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b72c276272d90ea1768cccdf409895a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b72c276272d90ea1768cccdf409895a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b72c276272d90ea1768cccdf409895a9 = L.map(
#                 &quot;map_b72c276272d90ea1768cccdf409895a9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c190fb3d102607a7807b8aabb02136c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c190fb3d102607a7807b8aabb02136c1.addTo(map_b72c276272d90ea1768cccdf409895a9);
#
#
#             var marker_50b763a01b0b539e5458149a72bb5e77 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b72c276272d90ea1768cccdf409895a9);
#
#
#         var popup_ab3fa7c9973ee56879a297a307c5cd22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28fdc566879408e10a167d604809f145 = $(`&lt;div id=&quot;html_28fdc566879408e10a167d604809f145&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ab3fa7c9973ee56879a297a307c5cd22.setContent(html_28fdc566879408e10a167d604809f145);
#
#
#
#         marker_50b763a01b0b539e5458149a72bb5e77.bindPopup(popup_ab3fa7c9973ee56879a297a307c5cd22)
#         ;
#
#
#
#
#             var marker_29e1642809ff6f77df97eca554904d20 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b72c276272d90ea1768cccdf409895a9);
#
#
#         var popup_299b799c9596703f7a97fca8d1290437 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72f144cb7a70842f49c2080d4422a5d5 = $(`&lt;div id=&quot;html_72f144cb7a70842f49c2080d4422a5d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_299b799c9596703f7a97fca8d1290437.setContent(html_72f144cb7a70842f49c2080d4422a5d5);
#
#
#
#         marker_29e1642809ff6f77df97eca554904d20.bindPopup(popup_299b799c9596703f7a97fca8d1290437)
#         ;
#
#
#
#
#             var marker_9520a5f2cc5ad7f2db2ab0bd7062a11b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b72c276272d90ea1768cccdf409895a9);
#
#
#         var popup_b389330c4e847168824d318e87e89db2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6862ac68e08660f51e2b42441348a8f6 = $(`&lt;div id=&quot;html_6862ac68e08660f51e2b42441348a8f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b389330c4e847168824d318e87e89db2.setContent(html_6862ac68e08660f51e2b42441348a8f6);
#
#
#
#         marker_9520a5f2cc5ad7f2db2ab0bd7062a11b.bindPopup(popup_b389330c4e847168824d318e87e89db2)
#         ;
#
#
#
#
#             var marker_f1be7b83c1f4be08212c18ff83c22029 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b72c276272d90ea1768cccdf409895a9);
#
#
#         var popup_ffff3bad80ba1712e580354ef6174732 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1ba1811a77e7f741ab43de51fdd6e39 = $(`&lt;div id=&quot;html_f1ba1811a77e7f741ab43de51fdd6e39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ffff3bad80ba1712e580354ef6174732.setContent(html_f1ba1811a77e7f741ab43de51fdd6e39);
#
#
#
#         marker_f1be7b83c1f4be08212c18ff83c22029.bindPopup(popup_ffff3bad80ba1712e580354ef6174732)
#         ;
#
#
#
#
#             var marker_89cf32ea11de81433bdce51773d6070f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b72c276272d90ea1768cccdf409895a9);
#
#
#         var popup_e4cb0dafceddabe0c00c5bae5ac170b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c99ea23247a7e9894949800e22ed37a = $(`&lt;div id=&quot;html_4c99ea23247a7e9894949800e22ed37a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e4cb0dafceddabe0c00c5bae5ac170b9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fdbaeec4a33a739c1ffcf3d4e1097b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fdbaeec4a33a739c1ffcf3d4e1097b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8fdbaeec4a33a739c1ffcf3d4e1097b5 = L.map(
#                 &quot;map_8fdbaeec4a33a739c1ffcf3d4e1097b5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_914988ae87a51de69e42b505ff7b77d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_914988ae87a51de69e42b505ff7b77d3.addTo(map_8fdbaeec4a33a739c1ffcf3d4e1097b5);
#
#
#             var feature_group_4b1a298e3428a15258e5fe93a5dff53c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bc46cb1fb492fe6fc78111d6a58f8c30 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4b1a298e3428a15258e5fe93a5dff53c);
#
#
#         var popup_be46e6c7e323c4511b8ad76beb741ddf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da2044a5f9157d2d5900ca9ec5d3a0bf = $(`&lt;div id=&quot;html_da2044a5f9157d2d5900ca9ec5d3a0bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_be46e6c7e323c4511b8ad76beb741ddf.setContent(html_da2044a5f9157d2d5900ca9ec5d3a0bf);
#
#
#
#         marker_bc46cb1fb492fe6fc78111d6a58f8c30.bindPopup(popup_be46e6c7e323c4511b8ad76beb741ddf)
#         ;
#
#
#
#
#             var marker_02637d5dc60c845ac8737145c8c60fb9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4b1a298e3428a15258e5fe93a5dff53c);
#
#
#         var popup_4fcb4395d6e96bb7f8f0688112fe512b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1545dcec1ac1efd6b8b196c241c5059e = $(`&lt;div id=&quot;html_1545dcec1ac1efd6b8b196c241c5059e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4fcb4395d6e96bb7f8f0688112fe512b.setContent(html_1545dcec1ac1efd6b8b196c241c5059e);
#
#
#
#         marker_02637d5dc60c845ac8737145c8c60fb9.bindPopup(popup_4fcb4395d6e96bb7f8f0688112fe512b)
#         ;
#
#
#
#
#             var marker_71326653b4559b861ca5fbb4066ea552 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4b1a298e3428a15258e5fe93a5dff53c);
#
#
#         var popup_a5264364954dd1978cadcc28a20f1b54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd96e4e8536afba49765fc625ee637e8 = $(`&lt;div id=&quot;html_cd96e4e8536afba49765fc625ee637e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a5264364954dd1978cadcc28a20f1b54.setContent(html_cd96e4e8536afba49765fc625ee637e8);
#
#
#
#         marker_71326653b4559b861ca5fbb4066ea552.bindPopup(popup_a5264364954dd1978cadcc28a20f1b54)
#         ;
#
#
#
#
#             var marker_49a64737f6bb9e73949cfa25ed030b87 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4b1a298e3428a15258e5fe93a5dff53c);
#
#
#         var popup_9433e2951c530afed17745e3db5463e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a17abe4bad7249e56dc14f52f9562055 = $(`&lt;div id=&quot;html_a17abe4bad7249e56dc14f52f9562055&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9433e2951c530afed17745e3db5463e6.setContent(html_a17abe4bad7249e56dc14f52f9562055);
#
#
#
#         marker_49a64737f6bb9e73949cfa25ed030b87.bindPopup(popup_9433e2951c530afed17745e3db5463e6)
#         ;
#
#
#
#
#             var marker_93ee4423836ff5f56383aa54629a3ffd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4b1a298e3428a15258e5fe93a5dff53c);
#
#
#         var popup_df69e50b180a62a4f5f9f3d87b05417e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e625e9ab02041f0c781f833aacb98bca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e625e9ab02041f0c781f833aacb98bca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e625e9ab02041f0c781f833aacb98bca = L.map(
#                 &quot;map_e625e9ab02041f0c781f833aacb98bca&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa33eb5deb3d6ecc6db48d1c619c512c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aa33eb5deb3d6ecc6db48d1c619c512c.addTo(map_e625e9ab02041f0c781f833aacb98bca);
#
#
#             var feature_group_de4e72d46d36a13a2320f0632ea13aaf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_de4e72d46d36a13a2320f0632ea13aaf.addTo(map_e625e9ab02041f0c781f833aacb98bca);
#
#
#             var feature_group_sub_group_e13a0af91a944520bbbced794584eb5c = L.featureGroup.subGroup(
#                 feature_group_de4e72d46d36a13a2320f0632ea13aaf
#             );
#
#
#             var marker_2b991ebaddbda2712e212b7d18f3dd52 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e13a0af91a944520bbbced794584eb5c);
#
#
#         var popup_a431a71e5ea200cafaac50faa76425bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6f574cf959861bd1277a2cf5d24adf6 = $(`&lt;div id=&quot;html_e6f574cf959861bd1277a2cf5d24adf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a431a71e5ea200cafaac50faa76425bc.setContent(html_e6f574cf959861bd1277a2cf5d24adf6);
#
#
#
#         marker_2b991ebaddbda2712e212b7d18f3dd52.bindPopup(popup_a431a71e5ea200cafaac50faa76425bc)
#         ;
#
#
#
#
#             var marker_5bb72fd6dd10dfeeab687bcb777dbe0e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e13a0af91a944520bbbced794584eb5c);
#
#
#         var popup_3d44267cf144d31d29bb270b75007fbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4cd9eec1152d0235220d70d83948836 = $(`&lt;div id=&quot;html_e4cd9eec1152d0235220d70d83948836&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3d44267cf144d31d29bb270b75007fbb.setContent(html_e4cd9eec1152d0235220d70d83948836);
#
#
#
#         marker_5bb72fd6dd10dfeeab687bcb777dbe0e.bindPopup(popup_3d44267cf144d31d29bb270b75007fbb)
#         ;
#
#
#
#
#             var marker_c9f91d66b0a134856f1cd1cb0adb3396 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e13a0af91a944520bbbced794584eb5c);
#
#
#         var popup_04185667666409360ec8ca17d90ef284 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_518db28429fa259964fdae154973905c = $(`&lt;div id=&quot;html_518db28429fa259964fdae154973905c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_04185667666409360ec8ca17d90ef284.setContent(html_518db28429fa259964fdae154973905c);
#
#
#
#         marker_c9f91d66b0a134856f1cd1cb0adb3396.bindPopup(popup_04185667666409360ec8ca17d90ef284)
#         ;
#
#
#
#
#             var marker_06350061e66597da747d8ba790b15de9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e13a0af91a944520bbbced794584eb5c);
#
#
#         var popup_04264dfa520f7dbb740c6c4ee0779d8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2239a844deb52e4fef14ed923d64391c = $(`&lt;div id=&quot;html_2239a844deb52e4fef14ed923d64391c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_04264dfa520f7dbb740c6c4ee0779d8d.setContent(html_2239a844deb52e4fef14ed923d64391c);
#
#
#
#         marker_
