# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24fdea8be80e6ef5e8d1e8f0cb4392ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24fdea8be80e6ef5e8d1e8f0cb4392ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24fdea8be80e6ef5e8d1e8f0cb4392ba = L.map(
#                 &quot;map_24fdea8be80e6ef5e8d1e8f0cb4392ba&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27bb80eb0b750f7a4fb30e313e97eaca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_27bb80eb0b750f7a4fb30e313e97eaca.addTo(map_24fdea8be80e6ef5e8d1e8f0cb4392ba);
#
#
#             var marker_c43f3dcbf127336205c80f9dad2722a4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_24fdea8be80e6ef5e8d1e8f0cb4392ba);
#
#
#         var popup_51971b90cbb605a4c0b02e01d4ab3e96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_681ae9a2615356955f975de7bbc9eb82 = $(`&lt;div id=&quot;html_681ae9a2615356955f975de7bbc9eb82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_51971b90cbb605a4c0b02e01d4ab3e96.setContent(html_681ae9a2615356955f975de7bbc9eb82);
#
#
#
#         marker_c43f3dcbf127336205c80f9dad2722a4.bindPopup(popup_51971b90cbb605a4c0b02e01d4ab3e96)
#         ;
#
#
#
#
#             var marker_2f3f48b7c08e8cb7981b7d4d8512fafd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_24fdea8be80e6ef5e8d1e8f0cb4392ba);
#
#
#         var popup_e1c8cffb532ec12d560c558cc6c17012 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdad27cddb53e2ae95c3c3562cdd2ac0 = $(`&lt;div id=&quot;html_fdad27cddb53e2ae95c3c3562cdd2ac0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e1c8cffb532ec12d560c558cc6c17012.setContent(html_fdad27cddb53e2ae95c3c3562cdd2ac0);
#
#
#
#         marker_2f3f48b7c08e8cb7981b7d4d8512fafd.bindPopup(popup_e1c8cffb532ec12d560c558cc6c17012)
#         ;
#
#
#
#
#             var marker_47f254f18fef21537f9882000f48ead9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_24fdea8be80e6ef5e8d1e8f0cb4392ba);
#
#
#         var popup_58f0a06b180b2c2a726b6026b0dfbd7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_538ba970f04055a3e1c97fff492ea625 = $(`&lt;div id=&quot;html_538ba970f04055a3e1c97fff492ea625&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_58f0a06b180b2c2a726b6026b0dfbd7e.setContent(html_538ba970f04055a3e1c97fff492ea625);
#
#
#
#         marker_47f254f18fef21537f9882000f48ead9.bindPopup(popup_58f0a06b180b2c2a726b6026b0dfbd7e)
#         ;
#
#
#
#
#             var marker_d792ef7050f83dc3f3a4e30e27a371ed = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_24fdea8be80e6ef5e8d1e8f0cb4392ba);
#
#
#         var popup_bf2c8d09baf056b9152ab8356e5781e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd9bff3e223acf2b8d0d020038f948cf = $(`&lt;div id=&quot;html_bd9bff3e223acf2b8d0d020038f948cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bf2c8d09baf056b9152ab8356e5781e5.setContent(html_bd9bff3e223acf2b8d0d020038f948cf);
#
#
#
#         marker_d792ef7050f83dc3f3a4e30e27a371ed.bindPopup(popup_bf2c8d09baf056b9152ab8356e5781e5)
#         ;
#
#
#
#
#             var marker_d0e2c45f1f9d57e19a3cb7230543f0d1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_24fdea8be80e6ef5e8d1e8f0cb4392ba);
#
#
#         var popup_81c08095d69f88c6c9d4182bc115929c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c75b36aff98b39529410765a67ee396 = $(`&lt;div id=&quot;html_7c75b36aff98b39529410765a67ee396&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_81c08095d69f88c6c9d4182bc115929c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46d5aed8fa065e99d9597eb6c9b5939b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46d5aed8fa065e99d9597eb6c9b5939b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46d5aed8fa065e99d9597eb6c9b5939b = L.map(
#                 &quot;map_46d5aed8fa065e99d9597eb6c9b5939b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82175838cb53ee56ed4fd4d69ff5b2ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_82175838cb53ee56ed4fd4d69ff5b2ed.addTo(map_46d5aed8fa065e99d9597eb6c9b5939b);
#
#
#             var feature_group_7bed8c21c9445c2dfcc73437ec1f4dc7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ee736908cfc0e60ab109c306659aaeee = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7bed8c21c9445c2dfcc73437ec1f4dc7);
#
#
#         var popup_5f42fd856448395955f6c0b4ab6988f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd7fc32eb42d4c78ba38b52ba23eecd2 = $(`&lt;div id=&quot;html_fd7fc32eb42d4c78ba38b52ba23eecd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5f42fd856448395955f6c0b4ab6988f3.setContent(html_fd7fc32eb42d4c78ba38b52ba23eecd2);
#
#
#
#         marker_ee736908cfc0e60ab109c306659aaeee.bindPopup(popup_5f42fd856448395955f6c0b4ab6988f3)
#         ;
#
#
#
#
#             var marker_96086ae885234b70b055aec080d777e1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7bed8c21c9445c2dfcc73437ec1f4dc7);
#
#
#         var popup_d16f7dae824a85b1614b505623c28edb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8297e20ed889fcd4c8ef3303a703b691 = $(`&lt;div id=&quot;html_8297e20ed889fcd4c8ef3303a703b691&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d16f7dae824a85b1614b505623c28edb.setContent(html_8297e20ed889fcd4c8ef3303a703b691);
#
#
#
#         marker_96086ae885234b70b055aec080d777e1.bindPopup(popup_d16f7dae824a85b1614b505623c28edb)
#         ;
#
#
#
#
#             var marker_a522a68e01a59ebb4faa8dba4caa5bea = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7bed8c21c9445c2dfcc73437ec1f4dc7);
#
#
#         var popup_de12babe9c49fd0460588fa2df15ce4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_268f5ecf83420f055c58f8bfcd7dfbd5 = $(`&lt;div id=&quot;html_268f5ecf83420f055c58f8bfcd7dfbd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_de12babe9c49fd0460588fa2df15ce4f.setContent(html_268f5ecf83420f055c58f8bfcd7dfbd5);
#
#
#
#         marker_a522a68e01a59ebb4faa8dba4caa5bea.bindPopup(popup_de12babe9c49fd0460588fa2df15ce4f)
#         ;
#
#
#
#
#             var marker_120d6931e9ef4adb24f650d3aaff9a9d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7bed8c21c9445c2dfcc73437ec1f4dc7);
#
#
#         var popup_509497fecca9ad1c2299f460ffaaba29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7618fb1e1dfdc11054499d6473967fb9 = $(`&lt;div id=&quot;html_7618fb1e1dfdc11054499d6473967fb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_509497fecca9ad1c2299f460ffaaba29.setContent(html_7618fb1e1dfdc11054499d6473967fb9);
#
#
#
#         marker_120d6931e9ef4adb24f650d3aaff9a9d.bindPopup(popup_509497fecca9ad1c2299f460ffaaba29)
#         ;
#
#
#
#
#             var marker_d1ab8443b3d822f483f63cfe1a66558f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7bed8c21c9445c2dfcc73437ec1f4dc7);
#
#
#         var popup_71e168198ce2d2507138ff481bef2ddb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58c46881747ab1fe0716cf9a184dcccf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58c46881747ab1fe0716cf9a184dcccf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58c46881747ab1fe0716cf9a184dcccf = L.map(
#                 &quot;map_58c46881747ab1fe0716cf9a184dcccf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73eaebad8103147076f0e4133f9b45cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_73eaebad8103147076f0e4133f9b45cb.addTo(map_58c46881747ab1fe0716cf9a184dcccf);
#
#
#             var feature_group_f48339cba0f35933dfa86c981cd75414 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f48339cba0f35933dfa86c981cd75414.addTo(map_58c46881747ab1fe0716cf9a184dcccf);
#
#
#             var feature_group_sub_group_49200ff53f6949cd26680f883259f124 = L.featureGroup.subGroup(
#                 feature_group_f48339cba0f35933dfa86c981cd75414
#             );
#
#
#             var marker_c629dd9021732eadd69130183a476ec5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_49200ff53f6949cd26680f883259f124);
#
#
#         var popup_9b89aacc49b1e43cb439db7b0559980e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79bfc5b56c1ff6f522cefc0751d8a8ad = $(`&lt;div id=&quot;html_79bfc5b56c1ff6f522cefc0751d8a8ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9b89aacc49b1e43cb439db7b0559980e.setContent(html_79bfc5b56c1ff6f522cefc0751d8a8ad);
#
#
#
#         marker_c629dd9021732eadd69130183a476ec5.bindPopup(popup_9b89aacc49b1e43cb439db7b0559980e)
#         ;
#
#
#
#
#             var marker_c1085b981d20d9c0c4d724ffc155fab9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_49200ff53f6949cd26680f883259f124);
#
#
#         var popup_64349447b97c97141af1bdd4c2c69783 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42dcaf6a1c1aef5daaa5f54714a3291d = $(`&lt;div id=&quot;html_42dcaf6a1c1aef5daaa5f54714a3291d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_64349447b97c97141af1bdd4c2c69783.setContent(html_42dcaf6a1c1aef5daaa5f54714a3291d);
#
#
#
#         marker_c1085b981d20d9c0c4d724ffc155fab9.bindPopup(popup_64349447b97c97141af1bdd4c2c69783)
#         ;
#
#
#
#
#             var marker_50927955f69eb1c82d316b2febba17b5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_49200ff53f6949cd26680f883259f124);
#
#
#         var popup_7e3599981837d094ff04deafb7ba0d55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df5b78a330a7df723b09926bbb3705d0 = $(`&lt;div id=&quot;html_df5b78a330a7df723b09926bbb3705d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7e3599981837d094ff04deafb7ba0d55.setContent(html_df5b78a330a7df723b09926bbb3705d0);
#
#
#
#         marker_50927955f69eb1c82d316b2febba17b5.bindPopup(popup_7e3599981837d094ff04deafb7ba0d55)
#         ;
#
#
#
#
#             var marker_bc74c726f528244f0bf4557519a0f18d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_49200ff53f6949cd26680f883259f124);
#
#
#         var popup_9c084f3b0c16a0b9bdca4acb22798633 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42047eac3077c01746613abf5adb5efd = $(`&lt;div id=&quot;html_42047eac3077c01746613abf5adb5efd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9c084f3b0c16a0b9bdca4acb22798633.setContent(html_42047eac3077c01746613abf5adb5efd);
#
#
#
#         marker_
