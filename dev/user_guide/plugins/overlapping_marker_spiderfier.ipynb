# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ca267fdea884d19b5f81e1528935908 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ca267fdea884d19b5f81e1528935908&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ca267fdea884d19b5f81e1528935908 = L.map(
#                 &quot;map_7ca267fdea884d19b5f81e1528935908&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14893d827c729e775d3c061feefc70b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_14893d827c729e775d3c061feefc70b3.addTo(map_7ca267fdea884d19b5f81e1528935908);
#
#
#             var marker_036c89c85292a64f04324f466aa85a2e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7ca267fdea884d19b5f81e1528935908);
#
#
#         var popup_0255ad0fc40cd4f86421adfc09ae2a1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92af95b6237899613a00e8a85d2018db = $(`&lt;div id=&quot;html_92af95b6237899613a00e8a85d2018db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0255ad0fc40cd4f86421adfc09ae2a1b.setContent(html_92af95b6237899613a00e8a85d2018db);
#
#
#
#         marker_036c89c85292a64f04324f466aa85a2e.bindPopup(popup_0255ad0fc40cd4f86421adfc09ae2a1b)
#         ;
#
#
#
#
#             var marker_3327cf7949412ef8d4c7fdb698d76692 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7ca267fdea884d19b5f81e1528935908);
#
#
#         var popup_dfc7cb4825af5c7e2a07aea01f605ae1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb12105aae139fe7df4c237e067637dd = $(`&lt;div id=&quot;html_cb12105aae139fe7df4c237e067637dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dfc7cb4825af5c7e2a07aea01f605ae1.setContent(html_cb12105aae139fe7df4c237e067637dd);
#
#
#
#         marker_3327cf7949412ef8d4c7fdb698d76692.bindPopup(popup_dfc7cb4825af5c7e2a07aea01f605ae1)
#         ;
#
#
#
#
#             var marker_f71a4e2b6ef81715b211e15e3babbe05 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7ca267fdea884d19b5f81e1528935908);
#
#
#         var popup_4443f60705f764de32ef70471e466578 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9cd8b8beeee24766e6c73d62209c21d5 = $(`&lt;div id=&quot;html_9cd8b8beeee24766e6c73d62209c21d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4443f60705f764de32ef70471e466578.setContent(html_9cd8b8beeee24766e6c73d62209c21d5);
#
#
#
#         marker_f71a4e2b6ef81715b211e15e3babbe05.bindPopup(popup_4443f60705f764de32ef70471e466578)
#         ;
#
#
#
#
#             var marker_ff14bc94a1d3db196b18f3ca25630057 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7ca267fdea884d19b5f81e1528935908);
#
#
#         var popup_949fe2daa60fe1605f83150ac1043abe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92e44475092acb307e8c2e3c8797c115 = $(`&lt;div id=&quot;html_92e44475092acb307e8c2e3c8797c115&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_949fe2daa60fe1605f83150ac1043abe.setContent(html_92e44475092acb307e8c2e3c8797c115);
#
#
#
#         marker_ff14bc94a1d3db196b18f3ca25630057.bindPopup(popup_949fe2daa60fe1605f83150ac1043abe)
#         ;
#
#
#
#
#             var marker_1db28634b073ac476864c01b526d11f3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7ca267fdea884d19b5f81e1528935908);
#
#
#         var popup_a59522d66958ed9189eccbfee23f3a0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f5d46f7cd8a1a998f1d8f16a66d757b = $(`&lt;div id=&quot;html_1f5d46f7cd8a1a998f1d8f16a66d757b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a59522d66958ed9189eccbfee23f3a0e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7eb730767066b949a4774ae6dd1dbe58 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7eb730767066b949a4774ae6dd1dbe58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7eb730767066b949a4774ae6dd1dbe58 = L.map(
#                 &quot;map_7eb730767066b949a4774ae6dd1dbe58&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4bbc897eac23eed633607a9e0cf6800 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d4bbc897eac23eed633607a9e0cf6800.addTo(map_7eb730767066b949a4774ae6dd1dbe58);
#
#
#             var feature_group_ea9f1766c535c0aaa30d923cc790ec9d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0fa93eabc49fbccfb808d10d811f6c2c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ea9f1766c535c0aaa30d923cc790ec9d);
#
#
#         var popup_be2730c10b637d4e2c2f8bb494e0537e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c682e6a5b1e7eb84f4b2d7abc269948 = $(`&lt;div id=&quot;html_0c682e6a5b1e7eb84f4b2d7abc269948&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_be2730c10b637d4e2c2f8bb494e0537e.setContent(html_0c682e6a5b1e7eb84f4b2d7abc269948);
#
#
#
#         marker_0fa93eabc49fbccfb808d10d811f6c2c.bindPopup(popup_be2730c10b637d4e2c2f8bb494e0537e)
#         ;
#
#
#
#
#             var marker_a7939261ace7efdcdb8b93bb2617407b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ea9f1766c535c0aaa30d923cc790ec9d);
#
#
#         var popup_1431913d9c41ddd0ca947fb4b82a1505 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fce988d0569302dba72ee5f23b25084 = $(`&lt;div id=&quot;html_8fce988d0569302dba72ee5f23b25084&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1431913d9c41ddd0ca947fb4b82a1505.setContent(html_8fce988d0569302dba72ee5f23b25084);
#
#
#
#         marker_a7939261ace7efdcdb8b93bb2617407b.bindPopup(popup_1431913d9c41ddd0ca947fb4b82a1505)
#         ;
#
#
#
#
#             var marker_6a0b42cf5ce2b8a01d203d7fa697ae4e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ea9f1766c535c0aaa30d923cc790ec9d);
#
#
#         var popup_41b7a77af4d8e813a9b19f5a818b973b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ee661d037f6be23c3d38337b4c40018 = $(`&lt;div id=&quot;html_6ee661d037f6be23c3d38337b4c40018&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_41b7a77af4d8e813a9b19f5a818b973b.setContent(html_6ee661d037f6be23c3d38337b4c40018);
#
#
#
#         marker_6a0b42cf5ce2b8a01d203d7fa697ae4e.bindPopup(popup_41b7a77af4d8e813a9b19f5a818b973b)
#         ;
#
#
#
#
#             var marker_7159424c8188db55ef3926614327a759 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ea9f1766c535c0aaa30d923cc790ec9d);
#
#
#         var popup_1121d132286b6ba6118e8c42a8ef5c89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bab699c9d75803208dc0b78a2614291 = $(`&lt;div id=&quot;html_8bab699c9d75803208dc0b78a2614291&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1121d132286b6ba6118e8c42a8ef5c89.setContent(html_8bab699c9d75803208dc0b78a2614291);
#
#
#
#         marker_7159424c8188db55ef3926614327a759.bindPopup(popup_1121d132286b6ba6118e8c42a8ef5c89)
#         ;
#
#
#
#
#             var marker_77c0c9d5b62b079d9edd11f5cfcd4de0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ea9f1766c535c0aaa30d923cc790ec9d);
#
#
#         var popup_6daebe7edb80724b22d24304639bdd95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4cf6d25d9a4201f6b29442cfcb486e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4cf6d25d9a4201f6b29442cfcb486e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4cf6d25d9a4201f6b29442cfcb486e7 = L.map(
#                 &quot;map_e4cf6d25d9a4201f6b29442cfcb486e7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81306a6806a5d03906b5528d5ddafbcd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81306a6806a5d03906b5528d5ddafbcd.addTo(map_e4cf6d25d9a4201f6b29442cfcb486e7);
#
#
#             var feature_group_74258e9770d07a9acb77dc6477207eb1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_74258e9770d07a9acb77dc6477207eb1.addTo(map_e4cf6d25d9a4201f6b29442cfcb486e7);
#
#
#             var feature_group_sub_group_73578fe04b4551fb00005528aef925cd = L.featureGroup.subGroup(
#                 feature_group_74258e9770d07a9acb77dc6477207eb1
#             );
#
#
#             var marker_a72f10786100b9af5485ce66c8f4e851 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_73578fe04b4551fb00005528aef925cd);
#
#
#         var popup_2f54700987e8041a853ceeadefd08ed6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42a72978c8a3d179afc9cc9bbba1caf0 = $(`&lt;div id=&quot;html_42a72978c8a3d179afc9cc9bbba1caf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2f54700987e8041a853ceeadefd08ed6.setContent(html_42a72978c8a3d179afc9cc9bbba1caf0);
#
#
#
#         marker_a72f10786100b9af5485ce66c8f4e851.bindPopup(popup_2f54700987e8041a853ceeadefd08ed6)
#         ;
#
#
#
#
#             var marker_b8814ba0be83a064f062cfca269aa249 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_73578fe04b4551fb00005528aef925cd);
#
#
#         var popup_28f11127570d5ff18a9cd49d205d142e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8defd95c3ffcac54aaef4ed0f5db48ab = $(`&lt;div id=&quot;html_8defd95c3ffcac54aaef4ed0f5db48ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_28f11127570d5ff18a9cd49d205d142e.setContent(html_8defd95c3ffcac54aaef4ed0f5db48ab);
#
#
#
#         marker_b8814ba0be83a064f062cfca269aa249.bindPopup(popup_28f11127570d5ff18a9cd49d205d142e)
#         ;
#
#
#
#
#             var marker_49c7de7749264a511599f3044a83f3c6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_73578fe04b4551fb00005528aef925cd);
#
#
#         var popup_d5bca7b41b4805d33a82be00a371aea9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1a1515b30c19dce5afb9e824b5d4ad4 = $(`&lt;div id=&quot;html_a1a1515b30c19dce5afb9e824b5d4ad4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d5bca7b41b4805d33a82be00a371aea9.setContent(html_a1a1515b30c19dce5afb9e824b5d4ad4);
#
#
#
#         marker_49c7de7749264a511599f3044a83f3c6.bindPopup(popup_d5bca7b41b4805d33a82be00a371aea9)
#         ;
#
#
#
#
#             var marker_dd684e121c310f7024a5108ba3671467 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_73578fe04b4551fb00005528aef925cd);
#
#
#         var popup_0a0b18162ae5cc70e34eec4e3322e837 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee6bd27a364c15f6262832d25260e397 = $(`&lt;div id=&quot;html_ee6bd27a364c15f6262832d25260e397&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0a0b18162ae5cc70e34eec4e3322e837.setContent(html_ee6bd27a364c15f6262832d25260e397);
#
#
#
#         marker_
