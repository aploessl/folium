# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_864549136f071fc1805c77fe07cde4d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_864549136f071fc1805c77fe07cde4d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_864549136f071fc1805c77fe07cde4d3 = L.map(
#                 &quot;map_864549136f071fc1805c77fe07cde4d3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a51d62cfcb4ff9b551819b0f61ee9b9c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a51d62cfcb4ff9b551819b0f61ee9b9c.addTo(map_864549136f071fc1805c77fe07cde4d3);
#
#
#             var marker_ae2287be4c3e65643edfc9020ab696cf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_864549136f071fc1805c77fe07cde4d3);
#
#
#         var popup_35c7c16c229fe3e92a1c61b37e6d9b1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8c49d9c0d299fcb607b766654efd0ff = $(`&lt;div id=&quot;html_a8c49d9c0d299fcb607b766654efd0ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_35c7c16c229fe3e92a1c61b37e6d9b1d.setContent(html_a8c49d9c0d299fcb607b766654efd0ff);
#
#
#
#         marker_ae2287be4c3e65643edfc9020ab696cf.bindPopup(popup_35c7c16c229fe3e92a1c61b37e6d9b1d)
#         ;
#
#
#
#
#             var marker_c2386e994758ac64f420a0629bdbbb43 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_864549136f071fc1805c77fe07cde4d3);
#
#
#         var popup_26f038acfaac70e372c84f97d9266171 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52b992c2f14ba5ada971478bb1ad3b32 = $(`&lt;div id=&quot;html_52b992c2f14ba5ada971478bb1ad3b32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_26f038acfaac70e372c84f97d9266171.setContent(html_52b992c2f14ba5ada971478bb1ad3b32);
#
#
#
#         marker_c2386e994758ac64f420a0629bdbbb43.bindPopup(popup_26f038acfaac70e372c84f97d9266171)
#         ;
#
#
#
#
#             var marker_af5e45053bc0d90e2ebcc06cf67518a9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_864549136f071fc1805c77fe07cde4d3);
#
#
#         var popup_dc3403c84cf344fa28c5d4dfa5601ef5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f97a33d1b2c88809335bfb7426e94dc9 = $(`&lt;div id=&quot;html_f97a33d1b2c88809335bfb7426e94dc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dc3403c84cf344fa28c5d4dfa5601ef5.setContent(html_f97a33d1b2c88809335bfb7426e94dc9);
#
#
#
#         marker_af5e45053bc0d90e2ebcc06cf67518a9.bindPopup(popup_dc3403c84cf344fa28c5d4dfa5601ef5)
#         ;
#
#
#
#
#             var marker_25c50ac8c46b20df72f31e12017b5752 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_864549136f071fc1805c77fe07cde4d3);
#
#
#         var popup_6abf3b1041e955929e80cc751e41c45c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae236592403372317ed5b7bf9f8264ee = $(`&lt;div id=&quot;html_ae236592403372317ed5b7bf9f8264ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6abf3b1041e955929e80cc751e41c45c.setContent(html_ae236592403372317ed5b7bf9f8264ee);
#
#
#
#         marker_25c50ac8c46b20df72f31e12017b5752.bindPopup(popup_6abf3b1041e955929e80cc751e41c45c)
#         ;
#
#
#
#
#             var marker_5f4a48c451f19da7193075cffc310784 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_864549136f071fc1805c77fe07cde4d3);
#
#
#         var popup_a3b8ecbb7c5ee11bcd3d6dbebf1e1603 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63cb2bd3591dd206b0d850d54059c3fb = $(`&lt;div id=&quot;html_63cb2bd3591dd206b0d850d54059c3fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a3b8ecbb7c5ee11bcd3d6dbebf1e1603.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bda51e715a8009b1cefa17da2bf8813 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bda51e715a8009b1cefa17da2bf8813&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bda51e715a8009b1cefa17da2bf8813 = L.map(
#                 &quot;map_4bda51e715a8009b1cefa17da2bf8813&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6083fb9f0b360fbebd2cc2ee441a91ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6083fb9f0b360fbebd2cc2ee441a91ec.addTo(map_4bda51e715a8009b1cefa17da2bf8813);
#
#
#             var feature_group_df83f6b6ab6960821122c4b5f6cfc649 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4dfd95686ccc0d25ee06cd99eebe7249 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_df83f6b6ab6960821122c4b5f6cfc649);
#
#
#         var popup_82c4d1c8312e49daedec38cafe58adb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e1448befb32f3081d48112594c0e2ce = $(`&lt;div id=&quot;html_4e1448befb32f3081d48112594c0e2ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_82c4d1c8312e49daedec38cafe58adb7.setContent(html_4e1448befb32f3081d48112594c0e2ce);
#
#
#
#         marker_4dfd95686ccc0d25ee06cd99eebe7249.bindPopup(popup_82c4d1c8312e49daedec38cafe58adb7)
#         ;
#
#
#
#
#             var marker_792b5e71b1a306afb6efd71ea1b91682 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_df83f6b6ab6960821122c4b5f6cfc649);
#
#
#         var popup_66492292c9f26e42b937d5414613d565 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a39c489fd963adbd0c58a68c981a9afb = $(`&lt;div id=&quot;html_a39c489fd963adbd0c58a68c981a9afb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_66492292c9f26e42b937d5414613d565.setContent(html_a39c489fd963adbd0c58a68c981a9afb);
#
#
#
#         marker_792b5e71b1a306afb6efd71ea1b91682.bindPopup(popup_66492292c9f26e42b937d5414613d565)
#         ;
#
#
#
#
#             var marker_036c21c0e86f1d89b43566b010067e91 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_df83f6b6ab6960821122c4b5f6cfc649);
#
#
#         var popup_d3a3ec656cbf9f81dba35478c81fcfbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4700298f170e1194f72959767360e0fc = $(`&lt;div id=&quot;html_4700298f170e1194f72959767360e0fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d3a3ec656cbf9f81dba35478c81fcfbf.setContent(html_4700298f170e1194f72959767360e0fc);
#
#
#
#         marker_036c21c0e86f1d89b43566b010067e91.bindPopup(popup_d3a3ec656cbf9f81dba35478c81fcfbf)
#         ;
#
#
#
#
#             var marker_7edfa8c22ecfcfeda3b7aee6b837f6c8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_df83f6b6ab6960821122c4b5f6cfc649);
#
#
#         var popup_f550f85f5b509f5c127a12610f9f089a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f067e098b138709d9d3415e13fbe569e = $(`&lt;div id=&quot;html_f067e098b138709d9d3415e13fbe569e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f550f85f5b509f5c127a12610f9f089a.setContent(html_f067e098b138709d9d3415e13fbe569e);
#
#
#
#         marker_7edfa8c22ecfcfeda3b7aee6b837f6c8.bindPopup(popup_f550f85f5b509f5c127a12610f9f089a)
#         ;
#
#
#
#
#             var marker_7d9995d947fe76d04be6e044cc086324 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_df83f6b6ab6960821122c4b5f6cfc649);
#
#
#         var popup_516cb5a526d5a77b1e204c6221593b3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da72bd529cc4f7fbaf81a631a9bb999d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da72bd529cc4f7fbaf81a631a9bb999d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da72bd529cc4f7fbaf81a631a9bb999d = L.map(
#                 &quot;map_da72bd529cc4f7fbaf81a631a9bb999d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe9594b41f9beb16724784fde6808559 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fe9594b41f9beb16724784fde6808559.addTo(map_da72bd529cc4f7fbaf81a631a9bb999d);
#
#
#             var feature_group_66a5ecd4e984e8dc402328355b5d6874 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_66a5ecd4e984e8dc402328355b5d6874.addTo(map_da72bd529cc4f7fbaf81a631a9bb999d);
#
#
#             var feature_group_sub_group_70cffc9184fdc0530aad2156f0e203de = L.featureGroup.subGroup(
#                 feature_group_66a5ecd4e984e8dc402328355b5d6874
#             );
#
#
#             var marker_7acab17e67a9b14b9e26ac611a3415d6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_70cffc9184fdc0530aad2156f0e203de);
#
#
#         var popup_8b0d5d904d16d4bfd26767341fc08094 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a71a6936459a1777bffeb823dc0a03be = $(`&lt;div id=&quot;html_a71a6936459a1777bffeb823dc0a03be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8b0d5d904d16d4bfd26767341fc08094.setContent(html_a71a6936459a1777bffeb823dc0a03be);
#
#
#
#         marker_7acab17e67a9b14b9e26ac611a3415d6.bindPopup(popup_8b0d5d904d16d4bfd26767341fc08094)
#         ;
#
#
#
#
#             var marker_ffe8be7f4e729bb50994f6fc549a0286 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_70cffc9184fdc0530aad2156f0e203de);
#
#
#         var popup_18c1c73f11dafbb13998e4b6caea1107 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39795f2382778c9577eea5e62a01b306 = $(`&lt;div id=&quot;html_39795f2382778c9577eea5e62a01b306&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_18c1c73f11dafbb13998e4b6caea1107.setContent(html_39795f2382778c9577eea5e62a01b306);
#
#
#
#         marker_ffe8be7f4e729bb50994f6fc549a0286.bindPopup(popup_18c1c73f11dafbb13998e4b6caea1107)
#         ;
#
#
#
#
#             var marker_b0b52e53c7dd5d7c9012e56aaa5e56ff = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_70cffc9184fdc0530aad2156f0e203de);
#
#
#         var popup_488ca4e07048244d1e6a574bcc6541c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77d8be2ad77f8b45da0d7cc4be8f09bf = $(`&lt;div id=&quot;html_77d8be2ad77f8b45da0d7cc4be8f09bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_488ca4e07048244d1e6a574bcc6541c8.setContent(html_77d8be2ad77f8b45da0d7cc4be8f09bf);
#
#
#
#         marker_b0b52e53c7dd5d7c9012e56aaa5e56ff.bindPopup(popup_488ca4e07048244d1e6a574bcc6541c8)
#         ;
#
#
#
#
#             var marker_30b1caeb43e6024979629d788de7180d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_70cffc9184fdc0530aad2156f0e203de);
#
#
#         var popup_4829795f246fd4fa2362f44f0b890e66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_790570ae4d4d04a4420f6240e06ed685 = $(`&lt;div id=&quot;html_790570ae4d4d04a4420f6240e06ed685&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4829795f246fd4fa2362f44f0b890e66.setContent(html_790570ae4d4d04a4420f6240e06ed685);
#
#
#
#         marker_
