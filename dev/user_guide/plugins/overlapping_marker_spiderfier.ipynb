# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2976a949ee414ee325611a605479d21e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2976a949ee414ee325611a605479d21e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2976a949ee414ee325611a605479d21e = L.map(
#                 &quot;map_2976a949ee414ee325611a605479d21e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_552fcd08607937a32c16c62aaa89493f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_552fcd08607937a32c16c62aaa89493f.addTo(map_2976a949ee414ee325611a605479d21e);
#
#
#             var marker_df5aee5db9600e7a10dfbffa1781beaf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2976a949ee414ee325611a605479d21e);
#
#
#         var popup_fe7a915cb24082b2f343884360f5b619 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66600b3b86c0ddc0764acd3c21609587 = $(`&lt;div id=&quot;html_66600b3b86c0ddc0764acd3c21609587&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fe7a915cb24082b2f343884360f5b619.setContent(html_66600b3b86c0ddc0764acd3c21609587);
#
#
#
#         marker_df5aee5db9600e7a10dfbffa1781beaf.bindPopup(popup_fe7a915cb24082b2f343884360f5b619)
#         ;
#
#
#
#
#             var marker_b0f28fc7bd6f96330838fea8c80f2823 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2976a949ee414ee325611a605479d21e);
#
#
#         var popup_afb491df0fec24f93b895dc51bd1718c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a896a91f9bd0dd6184357cc48a90cceb = $(`&lt;div id=&quot;html_a896a91f9bd0dd6184357cc48a90cceb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_afb491df0fec24f93b895dc51bd1718c.setContent(html_a896a91f9bd0dd6184357cc48a90cceb);
#
#
#
#         marker_b0f28fc7bd6f96330838fea8c80f2823.bindPopup(popup_afb491df0fec24f93b895dc51bd1718c)
#         ;
#
#
#
#
#             var marker_da04b6e755dd0f5876b18eb250a8f2e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2976a949ee414ee325611a605479d21e);
#
#
#         var popup_e68e7919fe7dd7d9eefe8f02d0f914a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6fb5c76ee5d17fb9fd0b24a0fad335a = $(`&lt;div id=&quot;html_f6fb5c76ee5d17fb9fd0b24a0fad335a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e68e7919fe7dd7d9eefe8f02d0f914a9.setContent(html_f6fb5c76ee5d17fb9fd0b24a0fad335a);
#
#
#
#         marker_da04b6e755dd0f5876b18eb250a8f2e8.bindPopup(popup_e68e7919fe7dd7d9eefe8f02d0f914a9)
#         ;
#
#
#
#
#             var marker_00dc5a7c2fdd92678ccf5a92a1b5de35 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2976a949ee414ee325611a605479d21e);
#
#
#         var popup_b622fdc0b51adcf112f5604eb31a680b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc0360ee7778b304c89112b1220866bb = $(`&lt;div id=&quot;html_fc0360ee7778b304c89112b1220866bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b622fdc0b51adcf112f5604eb31a680b.setContent(html_fc0360ee7778b304c89112b1220866bb);
#
#
#
#         marker_00dc5a7c2fdd92678ccf5a92a1b5de35.bindPopup(popup_b622fdc0b51adcf112f5604eb31a680b)
#         ;
#
#
#
#
#             var marker_46d01c5717392b6c4864f6524e5c9c40 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2976a949ee414ee325611a605479d21e);
#
#
#         var popup_c6b57edfa43c6256d02dd35b7f3db5e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_626f5feb33d1f38554c42dc5bdf0ae2f = $(`&lt;div id=&quot;html_626f5feb33d1f38554c42dc5bdf0ae2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c6b57edfa43c6256d02dd35b7f3db5e9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_713d097c0ccf32b218f047b82bafa39e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_713d097c0ccf32b218f047b82bafa39e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_713d097c0ccf32b218f047b82bafa39e = L.map(
#                 &quot;map_713d097c0ccf32b218f047b82bafa39e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a684568021b0e02641b7599d07b79f1b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a684568021b0e02641b7599d07b79f1b.addTo(map_713d097c0ccf32b218f047b82bafa39e);
#
#
#             var feature_group_a67690c16bbb31d84560bfcadac78abf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1bb70aed1748c971dd5b7021232010f2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a67690c16bbb31d84560bfcadac78abf);
#
#
#         var popup_e3cd6f1a267ef217d7d5137067fd5c35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e3fd4902fb2c0ab5c42011533887073 = $(`&lt;div id=&quot;html_0e3fd4902fb2c0ab5c42011533887073&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e3cd6f1a267ef217d7d5137067fd5c35.setContent(html_0e3fd4902fb2c0ab5c42011533887073);
#
#
#
#         marker_1bb70aed1748c971dd5b7021232010f2.bindPopup(popup_e3cd6f1a267ef217d7d5137067fd5c35)
#         ;
#
#
#
#
#             var marker_0a583d496c1c1c39dbd8a589daf2430a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a67690c16bbb31d84560bfcadac78abf);
#
#
#         var popup_5c8536ed0bdc38aa8a5a49b6a453d415 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ee28d8acf90326451f321d216db6b14 = $(`&lt;div id=&quot;html_7ee28d8acf90326451f321d216db6b14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5c8536ed0bdc38aa8a5a49b6a453d415.setContent(html_7ee28d8acf90326451f321d216db6b14);
#
#
#
#         marker_0a583d496c1c1c39dbd8a589daf2430a.bindPopup(popup_5c8536ed0bdc38aa8a5a49b6a453d415)
#         ;
#
#
#
#
#             var marker_e289902543d42776264302600d9d9848 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a67690c16bbb31d84560bfcadac78abf);
#
#
#         var popup_e14e4dee9c3639be7f13b60c59aaa459 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33ff34dad01cd195ab37433c10d75920 = $(`&lt;div id=&quot;html_33ff34dad01cd195ab37433c10d75920&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e14e4dee9c3639be7f13b60c59aaa459.setContent(html_33ff34dad01cd195ab37433c10d75920);
#
#
#
#         marker_e289902543d42776264302600d9d9848.bindPopup(popup_e14e4dee9c3639be7f13b60c59aaa459)
#         ;
#
#
#
#
#             var marker_2d4a57d325ac551cb3db20f1120aeaaf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a67690c16bbb31d84560bfcadac78abf);
#
#
#         var popup_42fb85c05eda8e454056dfdb069c4238 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_306844fa7c13dbb41c9bfd15e3b3d777 = $(`&lt;div id=&quot;html_306844fa7c13dbb41c9bfd15e3b3d777&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_42fb85c05eda8e454056dfdb069c4238.setContent(html_306844fa7c13dbb41c9bfd15e3b3d777);
#
#
#
#         marker_2d4a57d325ac551cb3db20f1120aeaaf.bindPopup(popup_42fb85c05eda8e454056dfdb069c4238)
#         ;
#
#
#
#
#             var marker_d50a8f7781e6b4e54144bce5b54fc6da = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a67690c16bbb31d84560bfcadac78abf);
#
#
#         var popup_54701ea17e113f86656c682bc104f1f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_947491bcedc439e0859eba8cda2b8eb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_947491bcedc439e0859eba8cda2b8eb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_947491bcedc439e0859eba8cda2b8eb4 = L.map(
#                 &quot;map_947491bcedc439e0859eba8cda2b8eb4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9696dad7c1cfb53fd0993080e53b2a5f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9696dad7c1cfb53fd0993080e53b2a5f.addTo(map_947491bcedc439e0859eba8cda2b8eb4);
#
#
#             var feature_group_6f17455bcf39cfe0c02d9f5167adbcc8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6f17455bcf39cfe0c02d9f5167adbcc8.addTo(map_947491bcedc439e0859eba8cda2b8eb4);
#
#
#             var feature_group_sub_group_111e45156bbc3491bf6035d06a27795c = L.featureGroup.subGroup(
#                 feature_group_6f17455bcf39cfe0c02d9f5167adbcc8
#             );
#
#
#             var marker_79ced04cde59455f3d95f0eac6aff9f9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_111e45156bbc3491bf6035d06a27795c);
#
#
#         var popup_c4d7441e1fe9d5b1c2372bd20d361955 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f1fec6c482fa83f1c518cb86fb82f2e = $(`&lt;div id=&quot;html_5f1fec6c482fa83f1c518cb86fb82f2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c4d7441e1fe9d5b1c2372bd20d361955.setContent(html_5f1fec6c482fa83f1c518cb86fb82f2e);
#
#
#
#         marker_79ced04cde59455f3d95f0eac6aff9f9.bindPopup(popup_c4d7441e1fe9d5b1c2372bd20d361955)
#         ;
#
#
#
#
#             var marker_05e34e6eeb294c35eb488dd2adef004b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_111e45156bbc3491bf6035d06a27795c);
#
#
#         var popup_bb9c31e2f56eae9d35d33f0c12e5bfab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6a891197d148b2e03e884445f1c0591 = $(`&lt;div id=&quot;html_d6a891197d148b2e03e884445f1c0591&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bb9c31e2f56eae9d35d33f0c12e5bfab.setContent(html_d6a891197d148b2e03e884445f1c0591);
#
#
#
#         marker_05e34e6eeb294c35eb488dd2adef004b.bindPopup(popup_bb9c31e2f56eae9d35d33f0c12e5bfab)
#         ;
#
#
#
#
#             var marker_a95d0a94dae26afb5ffda8ed2a8405da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_111e45156bbc3491bf6035d06a27795c);
#
#
#         var popup_2b72825a69302619d11cae606482bd97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03d6f42e2f80c2d8e3de8657436a10be = $(`&lt;div id=&quot;html_03d6f42e2f80c2d8e3de8657436a10be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2b72825a69302619d11cae606482bd97.setContent(html_03d6f42e2f80c2d8e3de8657436a10be);
#
#
#
#         marker_a95d0a94dae26afb5ffda8ed2a8405da.bindPopup(popup_2b72825a69302619d11cae606482bd97)
#         ;
#
#
#
#
#             var marker_7c14a4119a7556e61a252b0528e6f8cf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_111e45156bbc3491bf6035d06a27795c);
#
#
#         var popup_1e47f5e082636a7db840276421952601 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1dcda5ffee5902bd856bebb3c5073c3 = $(`&lt;div id=&quot;html_a1dcda5ffee5902bd856bebb3c5073c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1e47f5e082636a7db840276421952601.setContent(html_a1dcda5ffee5902bd856bebb3c5073c3);
#
#
#
#         marker_
