# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de257368746b5e2e9fea419278466a89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de257368746b5e2e9fea419278466a89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de257368746b5e2e9fea419278466a89 = L.map(
#                 &quot;map_de257368746b5e2e9fea419278466a89&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c3d6d320be069a0cff387e1cf8d0d81 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6c3d6d320be069a0cff387e1cf8d0d81.addTo(map_de257368746b5e2e9fea419278466a89);
#
#
#             var marker_24922603fc19b98ee40e2b4dcb9a3d33 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_de257368746b5e2e9fea419278466a89);
#
#
#         var popup_60f7249a203977f4786a4a3bea92a251 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08efa059576395fcdce4018cf7777cfb = $(`&lt;div id=&quot;html_08efa059576395fcdce4018cf7777cfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_60f7249a203977f4786a4a3bea92a251.setContent(html_08efa059576395fcdce4018cf7777cfb);
#
#
#
#         marker_24922603fc19b98ee40e2b4dcb9a3d33.bindPopup(popup_60f7249a203977f4786a4a3bea92a251)
#         ;
#
#
#
#
#             var marker_308164b4711f3aeb04520f50b0032c7a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_de257368746b5e2e9fea419278466a89);
#
#
#         var popup_2d74af4e3792989a097c7b3fbd0da174 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df7ffde91967a940fc8ab1f53810468e = $(`&lt;div id=&quot;html_df7ffde91967a940fc8ab1f53810468e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2d74af4e3792989a097c7b3fbd0da174.setContent(html_df7ffde91967a940fc8ab1f53810468e);
#
#
#
#         marker_308164b4711f3aeb04520f50b0032c7a.bindPopup(popup_2d74af4e3792989a097c7b3fbd0da174)
#         ;
#
#
#
#
#             var marker_25ec32bafb60577c8b01676eb569ee1e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_de257368746b5e2e9fea419278466a89);
#
#
#         var popup_e34b8cf09b6aaa90eab09168fc73b6da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4791e950b2b02bd4b5264dd72e8c51a8 = $(`&lt;div id=&quot;html_4791e950b2b02bd4b5264dd72e8c51a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e34b8cf09b6aaa90eab09168fc73b6da.setContent(html_4791e950b2b02bd4b5264dd72e8c51a8);
#
#
#
#         marker_25ec32bafb60577c8b01676eb569ee1e.bindPopup(popup_e34b8cf09b6aaa90eab09168fc73b6da)
#         ;
#
#
#
#
#             var marker_575aac0e5c79c1eb36f7341d9b780083 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_de257368746b5e2e9fea419278466a89);
#
#
#         var popup_6452b3735be2d8f55d770f78a53fe1a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbf91f4b5419aa4a84c3e37fb9079136 = $(`&lt;div id=&quot;html_bbf91f4b5419aa4a84c3e37fb9079136&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6452b3735be2d8f55d770f78a53fe1a8.setContent(html_bbf91f4b5419aa4a84c3e37fb9079136);
#
#
#
#         marker_575aac0e5c79c1eb36f7341d9b780083.bindPopup(popup_6452b3735be2d8f55d770f78a53fe1a8)
#         ;
#
#
#
#
#             var marker_af6ec2b0c6414c1e675cd5a59aff5ceb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_de257368746b5e2e9fea419278466a89);
#
#
#         var popup_2b9de7651578c8086048b0ac4aff2736 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3503770e01c53f8a5453dbc24a02bbd7 = $(`&lt;div id=&quot;html_3503770e01c53f8a5453dbc24a02bbd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2b9de7651578c8086048b0ac4aff2736.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0037ee1ef624a773aa7f39c10c084c4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0037ee1ef624a773aa7f39c10c084c4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0037ee1ef624a773aa7f39c10c084c4a = L.map(
#                 &quot;map_0037ee1ef624a773aa7f39c10c084c4a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d05fc3568d8ba0d280296ac8694296ac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d05fc3568d8ba0d280296ac8694296ac.addTo(map_0037ee1ef624a773aa7f39c10c084c4a);
#
#
#             var feature_group_492cf0e02f88257060572e4e0caf9447 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7a725dcbaea214adc1efeaf0c771aa0e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_492cf0e02f88257060572e4e0caf9447);
#
#
#         var popup_f9bfded6ca59fb100975245fdd5d0fd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe52a1e006848926c78e2726f1ac2c41 = $(`&lt;div id=&quot;html_fe52a1e006848926c78e2726f1ac2c41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f9bfded6ca59fb100975245fdd5d0fd9.setContent(html_fe52a1e006848926c78e2726f1ac2c41);
#
#
#
#         marker_7a725dcbaea214adc1efeaf0c771aa0e.bindPopup(popup_f9bfded6ca59fb100975245fdd5d0fd9)
#         ;
#
#
#
#
#             var marker_8e901e8bfe7a99fb2448a0e3bf7b4d52 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_492cf0e02f88257060572e4e0caf9447);
#
#
#         var popup_ae74a2f86395f57d4934a1ef756fa1b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7894e4e47268b72e88371fe026ada926 = $(`&lt;div id=&quot;html_7894e4e47268b72e88371fe026ada926&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ae74a2f86395f57d4934a1ef756fa1b2.setContent(html_7894e4e47268b72e88371fe026ada926);
#
#
#
#         marker_8e901e8bfe7a99fb2448a0e3bf7b4d52.bindPopup(popup_ae74a2f86395f57d4934a1ef756fa1b2)
#         ;
#
#
#
#
#             var marker_e943dbc0965e81adb6c26225acd837a4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_492cf0e02f88257060572e4e0caf9447);
#
#
#         var popup_5b1b6c35a7af712fd0cb5e11963e2413 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4782a5887bc95d98b7c8609021ddd9b = $(`&lt;div id=&quot;html_f4782a5887bc95d98b7c8609021ddd9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5b1b6c35a7af712fd0cb5e11963e2413.setContent(html_f4782a5887bc95d98b7c8609021ddd9b);
#
#
#
#         marker_e943dbc0965e81adb6c26225acd837a4.bindPopup(popup_5b1b6c35a7af712fd0cb5e11963e2413)
#         ;
#
#
#
#
#             var marker_da156307c62a8aaa4981500e78738cff = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_492cf0e02f88257060572e4e0caf9447);
#
#
#         var popup_b2c3c4a3fe518f0ee2add611753800da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b00eebe0a1ff68db9e21d98c57daab2 = $(`&lt;div id=&quot;html_7b00eebe0a1ff68db9e21d98c57daab2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b2c3c4a3fe518f0ee2add611753800da.setContent(html_7b00eebe0a1ff68db9e21d98c57daab2);
#
#
#
#         marker_da156307c62a8aaa4981500e78738cff.bindPopup(popup_b2c3c4a3fe518f0ee2add611753800da)
#         ;
#
#
#
#
#             var marker_9f5e738fc96e207b08953fe3c956aa3d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_492cf0e02f88257060572e4e0caf9447);
#
#
#         var popup_00b28fecd2351ee8c3b4201a2b1b5a10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a82b99b37d3e897c9c204e274aba671 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a82b99b37d3e897c9c204e274aba671&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a82b99b37d3e897c9c204e274aba671 = L.map(
#                 &quot;map_1a82b99b37d3e897c9c204e274aba671&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58cf57b496b61d0a06d84f7da5fd8ba4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_58cf57b496b61d0a06d84f7da5fd8ba4.addTo(map_1a82b99b37d3e897c9c204e274aba671);
#
#
#             var feature_group_a3f57dd47ef892c229794de666fab82f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a3f57dd47ef892c229794de666fab82f.addTo(map_1a82b99b37d3e897c9c204e274aba671);
#
#
#             var feature_group_sub_group_18f7db129ceb2213060063d441cc919c = L.featureGroup.subGroup(
#                 feature_group_a3f57dd47ef892c229794de666fab82f
#             );
#
#
#             var marker_45c0c2dc9ad6c3ba93914e689b7e6931 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_18f7db129ceb2213060063d441cc919c);
#
#
#         var popup_30bb06bf886a0fc7fb35927d6d6a0fdb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_baf4aa076c627b2c7476be3ed6ef884c = $(`&lt;div id=&quot;html_baf4aa076c627b2c7476be3ed6ef884c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_30bb06bf886a0fc7fb35927d6d6a0fdb.setContent(html_baf4aa076c627b2c7476be3ed6ef884c);
#
#
#
#         marker_45c0c2dc9ad6c3ba93914e689b7e6931.bindPopup(popup_30bb06bf886a0fc7fb35927d6d6a0fdb)
#         ;
#
#
#
#
#             var marker_d89887defb561f6cd153077f78fca2e5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_18f7db129ceb2213060063d441cc919c);
#
#
#         var popup_e49168dbabecfb7db04de67d79535a0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_efa858a7aceae474beae5fd0cf3f72c2 = $(`&lt;div id=&quot;html_efa858a7aceae474beae5fd0cf3f72c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e49168dbabecfb7db04de67d79535a0a.setContent(html_efa858a7aceae474beae5fd0cf3f72c2);
#
#
#
#         marker_d89887defb561f6cd153077f78fca2e5.bindPopup(popup_e49168dbabecfb7db04de67d79535a0a)
#         ;
#
#
#
#
#             var marker_9a35591ecc84ecce2dde0388a85242d5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_18f7db129ceb2213060063d441cc919c);
#
#
#         var popup_7e09e3096180efdafa7894d192d1f1df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_047c4286504c244fec5b3e725f741865 = $(`&lt;div id=&quot;html_047c4286504c244fec5b3e725f741865&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7e09e3096180efdafa7894d192d1f1df.setContent(html_047c4286504c244fec5b3e725f741865);
#
#
#
#         marker_9a35591ecc84ecce2dde0388a85242d5.bindPopup(popup_7e09e3096180efdafa7894d192d1f1df)
#         ;
#
#
#
#
#             var marker_059993212bb9ca250f094dc3ca2a3a9f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_18f7db129ceb2213060063d441cc919c);
#
#
#         var popup_576e0d1ea7a7e4e1b678822af2559a99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53dd4a689d5919664935b221b6fab653 = $(`&lt;div id=&quot;html_53dd4a689d5919664935b221b6fab653&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_576e0d1ea7a7e4e1b678822af2559a99.setContent(html_53dd4a689d5919664935b221b6fab653);
#
#
#
#         marker_
