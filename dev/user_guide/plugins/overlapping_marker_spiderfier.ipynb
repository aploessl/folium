# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_242a25fc7873ef00f987d0411a07fbe1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_242a25fc7873ef00f987d0411a07fbe1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_242a25fc7873ef00f987d0411a07fbe1 = L.map(
#                 &quot;map_242a25fc7873ef00f987d0411a07fbe1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed43e7adcbf56d41b8b7ba1a69b447c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed43e7adcbf56d41b8b7ba1a69b447c1.addTo(map_242a25fc7873ef00f987d0411a07fbe1);
#
#
#             var marker_f3a5f1271200eac5a0a19a1a6b1f651c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_242a25fc7873ef00f987d0411a07fbe1);
#
#
#         var popup_a2fc0bfd435b0c0cc959b00ab8804727 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e5cbc7a7112363a4f58dc5a45bfcf0c = $(`&lt;div id=&quot;html_1e5cbc7a7112363a4f58dc5a45bfcf0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a2fc0bfd435b0c0cc959b00ab8804727.setContent(html_1e5cbc7a7112363a4f58dc5a45bfcf0c);
#
#
#
#         marker_f3a5f1271200eac5a0a19a1a6b1f651c.bindPopup(popup_a2fc0bfd435b0c0cc959b00ab8804727)
#         ;
#
#
#
#
#             var marker_50dc182fda70746ee57fe84989abdb91 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_242a25fc7873ef00f987d0411a07fbe1);
#
#
#         var popup_f21ce5bad3157fb89e0ff5c2235795ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_447c30a7330f4516e5bda646c6f0766d = $(`&lt;div id=&quot;html_447c30a7330f4516e5bda646c6f0766d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f21ce5bad3157fb89e0ff5c2235795ae.setContent(html_447c30a7330f4516e5bda646c6f0766d);
#
#
#
#         marker_50dc182fda70746ee57fe84989abdb91.bindPopup(popup_f21ce5bad3157fb89e0ff5c2235795ae)
#         ;
#
#
#
#
#             var marker_f75e4496225ee63733c2d508cd41ade7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_242a25fc7873ef00f987d0411a07fbe1);
#
#
#         var popup_9fce43db2c16f51f564756ceca79acdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00f3806d1aa5d54702eefbd29856a8d3 = $(`&lt;div id=&quot;html_00f3806d1aa5d54702eefbd29856a8d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9fce43db2c16f51f564756ceca79acdc.setContent(html_00f3806d1aa5d54702eefbd29856a8d3);
#
#
#
#         marker_f75e4496225ee63733c2d508cd41ade7.bindPopup(popup_9fce43db2c16f51f564756ceca79acdc)
#         ;
#
#
#
#
#             var marker_18ad0b1f2e5505b62143f0ec4948fdb5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_242a25fc7873ef00f987d0411a07fbe1);
#
#
#         var popup_5ec502255a7c000df2a7cf36410111be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fb3429a435b67f27c1201f56e83302f = $(`&lt;div id=&quot;html_2fb3429a435b67f27c1201f56e83302f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5ec502255a7c000df2a7cf36410111be.setContent(html_2fb3429a435b67f27c1201f56e83302f);
#
#
#
#         marker_18ad0b1f2e5505b62143f0ec4948fdb5.bindPopup(popup_5ec502255a7c000df2a7cf36410111be)
#         ;
#
#
#
#
#             var marker_cf8b95a280433518eb86d75a271e75fa = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_242a25fc7873ef00f987d0411a07fbe1);
#
#
#         var popup_30bc354789b8328238b2b9f047ce43c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_390cfb9723fa6a80db571b2d4e68235d = $(`&lt;div id=&quot;html_390cfb9723fa6a80db571b2d4e68235d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_30bc354789b8328238b2b9f047ce43c6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_415c528f3e1b6a6cb0dc120dc13b1575 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_415c528f3e1b6a6cb0dc120dc13b1575&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_415c528f3e1b6a6cb0dc120dc13b1575 = L.map(
#                 &quot;map_415c528f3e1b6a6cb0dc120dc13b1575&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_735ef31a67ee3e1e7a3ae80d04af8c05 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_735ef31a67ee3e1e7a3ae80d04af8c05.addTo(map_415c528f3e1b6a6cb0dc120dc13b1575);
#
#
#             var feature_group_37c8840722ae1667baad2b75bc778755 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3a7e20e4de9d5876b51eaac5b47df255 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_37c8840722ae1667baad2b75bc778755);
#
#
#         var popup_043d4ec0662c59da283d17e21183753a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79733c5ff1ffc76935386558581ebb36 = $(`&lt;div id=&quot;html_79733c5ff1ffc76935386558581ebb36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_043d4ec0662c59da283d17e21183753a.setContent(html_79733c5ff1ffc76935386558581ebb36);
#
#
#
#         marker_3a7e20e4de9d5876b51eaac5b47df255.bindPopup(popup_043d4ec0662c59da283d17e21183753a)
#         ;
#
#
#
#
#             var marker_e8da215b39b8aebece90522f12bd4623 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_37c8840722ae1667baad2b75bc778755);
#
#
#         var popup_f425bf82ef389f72086298545628e95c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9c51220709b42b4571f5e09c8f6fcbb = $(`&lt;div id=&quot;html_a9c51220709b42b4571f5e09c8f6fcbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f425bf82ef389f72086298545628e95c.setContent(html_a9c51220709b42b4571f5e09c8f6fcbb);
#
#
#
#         marker_e8da215b39b8aebece90522f12bd4623.bindPopup(popup_f425bf82ef389f72086298545628e95c)
#         ;
#
#
#
#
#             var marker_3087dddffc7b9593f09b54211120cf98 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_37c8840722ae1667baad2b75bc778755);
#
#
#         var popup_01f3cb195241be4deeb931b30dae04a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab8b38d8e90f332644434caad66634bf = $(`&lt;div id=&quot;html_ab8b38d8e90f332644434caad66634bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_01f3cb195241be4deeb931b30dae04a9.setContent(html_ab8b38d8e90f332644434caad66634bf);
#
#
#
#         marker_3087dddffc7b9593f09b54211120cf98.bindPopup(popup_01f3cb195241be4deeb931b30dae04a9)
#         ;
#
#
#
#
#             var marker_a845b865f802618d98b7fc634916d2f0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_37c8840722ae1667baad2b75bc778755);
#
#
#         var popup_aeb62d34a88ca8587b1e62ff1dc47b76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea5b4a555892435b4111cb499f1d7d69 = $(`&lt;div id=&quot;html_ea5b4a555892435b4111cb499f1d7d69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_aeb62d34a88ca8587b1e62ff1dc47b76.setContent(html_ea5b4a555892435b4111cb499f1d7d69);
#
#
#
#         marker_a845b865f802618d98b7fc634916d2f0.bindPopup(popup_aeb62d34a88ca8587b1e62ff1dc47b76)
#         ;
#
#
#
#
#             var marker_866dd417aefcac42811b2193819db532 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_37c8840722ae1667baad2b75bc778755);
#
#
#         var popup_2084b58802418412d4b5cd66f8106d6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a31e72147a718aa6806b25ba6fca4a33 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a31e72147a718aa6806b25ba6fca4a33&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a31e72147a718aa6806b25ba6fca4a33 = L.map(
#                 &quot;map_a31e72147a718aa6806b25ba6fca4a33&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a57a5d0365ca8bacee662a6a12da6c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a57a5d0365ca8bacee662a6a12da6c5.addTo(map_a31e72147a718aa6806b25ba6fca4a33);
#
#
#             var feature_group_c580be4bf1acf6a20aee69247ad64207 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c580be4bf1acf6a20aee69247ad64207.addTo(map_a31e72147a718aa6806b25ba6fca4a33);
#
#
#             var feature_group_sub_group_e3e0ee324aa31b6d552fa61293893696 = L.featureGroup.subGroup(
#                 feature_group_c580be4bf1acf6a20aee69247ad64207
#             );
#
#
#             var marker_a84c9c8ac8f7f5a3e1961ce60393803e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e3e0ee324aa31b6d552fa61293893696);
#
#
#         var popup_eb627672bacb6d39ef051a5ef9b2253f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_396541abaf69faca4babeb442f94fbc6 = $(`&lt;div id=&quot;html_396541abaf69faca4babeb442f94fbc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_eb627672bacb6d39ef051a5ef9b2253f.setContent(html_396541abaf69faca4babeb442f94fbc6);
#
#
#
#         marker_a84c9c8ac8f7f5a3e1961ce60393803e.bindPopup(popup_eb627672bacb6d39ef051a5ef9b2253f)
#         ;
#
#
#
#
#             var marker_6f3c27bbab134efce1fd43a6d138a4c7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e3e0ee324aa31b6d552fa61293893696);
#
#
#         var popup_3a3b8dc120b57fe16cb5f51b795b16d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c421506f0f42c64b7a13a6396e2f7d6 = $(`&lt;div id=&quot;html_5c421506f0f42c64b7a13a6396e2f7d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3a3b8dc120b57fe16cb5f51b795b16d5.setContent(html_5c421506f0f42c64b7a13a6396e2f7d6);
#
#
#
#         marker_6f3c27bbab134efce1fd43a6d138a4c7.bindPopup(popup_3a3b8dc120b57fe16cb5f51b795b16d5)
#         ;
#
#
#
#
#             var marker_942b7e035b425d0168de47f891707a46 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e3e0ee324aa31b6d552fa61293893696);
#
#
#         var popup_ffec821535e53284d5d23f2deccb914a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9d7a9be203568c13bdb7f33c6ab0d2f = $(`&lt;div id=&quot;html_a9d7a9be203568c13bdb7f33c6ab0d2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ffec821535e53284d5d23f2deccb914a.setContent(html_a9d7a9be203568c13bdb7f33c6ab0d2f);
#
#
#
#         marker_942b7e035b425d0168de47f891707a46.bindPopup(popup_ffec821535e53284d5d23f2deccb914a)
#         ;
#
#
#
#
#             var marker_6bf53a4d747b05686a206ac64f727d8b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e3e0ee324aa31b6d552fa61293893696);
#
#
#         var popup_73c1da2fbc69f9eec63e9e6475643d7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb415a7359bb5d690aa1b92594e70e91 = $(`&lt;div id=&quot;html_cb415a7359bb5d690aa1b92594e70e91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_73c1da2fbc69f9eec63e9e6475643d7f.setContent(html_cb415a7359bb5d690aa1b92594e70e91);
#
#
#
#         marker_
