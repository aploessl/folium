# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_079fed761d17a5b6865320abb1a5cd0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_079fed761d17a5b6865320abb1a5cd0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_079fed761d17a5b6865320abb1a5cd0a = L.map(
#                 &quot;map_079fed761d17a5b6865320abb1a5cd0a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc2e1049d45e9d605224b040f6ab02b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dc2e1049d45e9d605224b040f6ab02b7.addTo(map_079fed761d17a5b6865320abb1a5cd0a);
#
#
#             var marker_967865c8eabe7dee0e214978e856c15b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_079fed761d17a5b6865320abb1a5cd0a);
#
#
#         var popup_e29fa2bb81e5365d1bbbe492e923682a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38f9415fea4eeeda235825351ce083b9 = $(`&lt;div id=&quot;html_38f9415fea4eeeda235825351ce083b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e29fa2bb81e5365d1bbbe492e923682a.setContent(html_38f9415fea4eeeda235825351ce083b9);
#
#
#
#         marker_967865c8eabe7dee0e214978e856c15b.bindPopup(popup_e29fa2bb81e5365d1bbbe492e923682a)
#         ;
#
#
#
#
#             var marker_0baffe2ab122138ea0df4b794ceb1b43 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_079fed761d17a5b6865320abb1a5cd0a);
#
#
#         var popup_4f4e32f72485a377782a31edc1c51f3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_089df12de26ee226527db6ca7cffac4d = $(`&lt;div id=&quot;html_089df12de26ee226527db6ca7cffac4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4f4e32f72485a377782a31edc1c51f3e.setContent(html_089df12de26ee226527db6ca7cffac4d);
#
#
#
#         marker_0baffe2ab122138ea0df4b794ceb1b43.bindPopup(popup_4f4e32f72485a377782a31edc1c51f3e)
#         ;
#
#
#
#
#             var marker_10f32f61525ed2a9c0b7701003abf80d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_079fed761d17a5b6865320abb1a5cd0a);
#
#
#         var popup_8c8d54e2464c96990da8d51a88008141 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69bf0899bd12ae4b5932bb6cf3128c3a = $(`&lt;div id=&quot;html_69bf0899bd12ae4b5932bb6cf3128c3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8c8d54e2464c96990da8d51a88008141.setContent(html_69bf0899bd12ae4b5932bb6cf3128c3a);
#
#
#
#         marker_10f32f61525ed2a9c0b7701003abf80d.bindPopup(popup_8c8d54e2464c96990da8d51a88008141)
#         ;
#
#
#
#
#             var marker_a03407fe5b5d53b1444e00b9ff467d02 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_079fed761d17a5b6865320abb1a5cd0a);
#
#
#         var popup_60875a60fe2c0ffa65a77b74ccbbc9eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d267c0da4abfccffd7bd5888de2d395 = $(`&lt;div id=&quot;html_9d267c0da4abfccffd7bd5888de2d395&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_60875a60fe2c0ffa65a77b74ccbbc9eb.setContent(html_9d267c0da4abfccffd7bd5888de2d395);
#
#
#
#         marker_a03407fe5b5d53b1444e00b9ff467d02.bindPopup(popup_60875a60fe2c0ffa65a77b74ccbbc9eb)
#         ;
#
#
#
#
#             var marker_a6c1df16bcd9facc3ae406f89a10975e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_079fed761d17a5b6865320abb1a5cd0a);
#
#
#         var popup_1e2186624370b0f820b73035bb9c580a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b2249f3936f17cdbc7d44043175c141 = $(`&lt;div id=&quot;html_6b2249f3936f17cdbc7d44043175c141&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1e2186624370b0f820b73035bb9c580a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0ed454138f2f72dcd12044ff338c2b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0ed454138f2f72dcd12044ff338c2b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0ed454138f2f72dcd12044ff338c2b1 = L.map(
#                 &quot;map_a0ed454138f2f72dcd12044ff338c2b1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ab7f1587be8cff96f044311d398eeac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ab7f1587be8cff96f044311d398eeac.addTo(map_a0ed454138f2f72dcd12044ff338c2b1);
#
#
#             var feature_group_3397ae791f6675cb8e1838a69094d0a7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_31c31fe694b6c17aaba6be68a85b781d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3397ae791f6675cb8e1838a69094d0a7);
#
#
#         var popup_2553107fa9da6d85517293fba8aa76eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f142610a357ecfd2ad7082454ab6d75 = $(`&lt;div id=&quot;html_5f142610a357ecfd2ad7082454ab6d75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2553107fa9da6d85517293fba8aa76eb.setContent(html_5f142610a357ecfd2ad7082454ab6d75);
#
#
#
#         marker_31c31fe694b6c17aaba6be68a85b781d.bindPopup(popup_2553107fa9da6d85517293fba8aa76eb)
#         ;
#
#
#
#
#             var marker_d83afa38eb49f2badeac82c0e7d11a17 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3397ae791f6675cb8e1838a69094d0a7);
#
#
#         var popup_f587935def0a78a1d2a28db27e1516eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bed0591f47bd167b20c93af1885b2d69 = $(`&lt;div id=&quot;html_bed0591f47bd167b20c93af1885b2d69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f587935def0a78a1d2a28db27e1516eb.setContent(html_bed0591f47bd167b20c93af1885b2d69);
#
#
#
#         marker_d83afa38eb49f2badeac82c0e7d11a17.bindPopup(popup_f587935def0a78a1d2a28db27e1516eb)
#         ;
#
#
#
#
#             var marker_47fbd6777d7496712dd685399920d304 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3397ae791f6675cb8e1838a69094d0a7);
#
#
#         var popup_0564d9def13f01d7303add062ab0529a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0186fc5e74c92936f1ccf9d23b37b445 = $(`&lt;div id=&quot;html_0186fc5e74c92936f1ccf9d23b37b445&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0564d9def13f01d7303add062ab0529a.setContent(html_0186fc5e74c92936f1ccf9d23b37b445);
#
#
#
#         marker_47fbd6777d7496712dd685399920d304.bindPopup(popup_0564d9def13f01d7303add062ab0529a)
#         ;
#
#
#
#
#             var marker_df6192f7a6416910abf80ba2aada17a2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3397ae791f6675cb8e1838a69094d0a7);
#
#
#         var popup_2b8b5ce5c9fe0326984b0e848a0b4b27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87989fcea2b61c73604bb55aab00b6b6 = $(`&lt;div id=&quot;html_87989fcea2b61c73604bb55aab00b6b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2b8b5ce5c9fe0326984b0e848a0b4b27.setContent(html_87989fcea2b61c73604bb55aab00b6b6);
#
#
#
#         marker_df6192f7a6416910abf80ba2aada17a2.bindPopup(popup_2b8b5ce5c9fe0326984b0e848a0b4b27)
#         ;
#
#
#
#
#             var marker_bfda1ba65f9cdff3076a19db60350743 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3397ae791f6675cb8e1838a69094d0a7);
#
#
#         var popup_213f91331e90f9286db65213587d18cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03011fd47f4c6e449a1c0e54d53e9cff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03011fd47f4c6e449a1c0e54d53e9cff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03011fd47f4c6e449a1c0e54d53e9cff = L.map(
#                 &quot;map_03011fd47f4c6e449a1c0e54d53e9cff&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_26fbd7e467a91225f47a4b7869feb03c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_26fbd7e467a91225f47a4b7869feb03c.addTo(map_03011fd47f4c6e449a1c0e54d53e9cff);
#
#
#             var feature_group_8d7f140661ed68e7e17f39f91f6dbde7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8d7f140661ed68e7e17f39f91f6dbde7.addTo(map_03011fd47f4c6e449a1c0e54d53e9cff);
#
#
#             var feature_group_sub_group_d00583c7f4c738bc37c17633b7955df4 = L.featureGroup.subGroup(
#                 feature_group_8d7f140661ed68e7e17f39f91f6dbde7
#             );
#
#
#             var marker_47071c2969a9c2e6977dbb519809e72d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d00583c7f4c738bc37c17633b7955df4);
#
#
#         var popup_65291adab71dac7417d13a15cb56bc8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c5f00a140aefaa9246877d8f0fe1e4e = $(`&lt;div id=&quot;html_7c5f00a140aefaa9246877d8f0fe1e4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_65291adab71dac7417d13a15cb56bc8b.setContent(html_7c5f00a140aefaa9246877d8f0fe1e4e);
#
#
#
#         marker_47071c2969a9c2e6977dbb519809e72d.bindPopup(popup_65291adab71dac7417d13a15cb56bc8b)
#         ;
#
#
#
#
#             var marker_6841b87ff7b2c272958a9007a16bf937 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d00583c7f4c738bc37c17633b7955df4);
#
#
#         var popup_aa2066bf89cfc257218885f015025069 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fbeb9ac3ae2943d2c76fa39cb8baeb1 = $(`&lt;div id=&quot;html_7fbeb9ac3ae2943d2c76fa39cb8baeb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_aa2066bf89cfc257218885f015025069.setContent(html_7fbeb9ac3ae2943d2c76fa39cb8baeb1);
#
#
#
#         marker_6841b87ff7b2c272958a9007a16bf937.bindPopup(popup_aa2066bf89cfc257218885f015025069)
#         ;
#
#
#
#
#             var marker_5ac51d6feb9dc1832ce5696d992efbd6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d00583c7f4c738bc37c17633b7955df4);
#
#
#         var popup_846614dab2be30c6f543d509049d6c1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ff3a14b273903b8038dec52e2e17bdb = $(`&lt;div id=&quot;html_7ff3a14b273903b8038dec52e2e17bdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_846614dab2be30c6f543d509049d6c1a.setContent(html_7ff3a14b273903b8038dec52e2e17bdb);
#
#
#
#         marker_5ac51d6feb9dc1832ce5696d992efbd6.bindPopup(popup_846614dab2be30c6f543d509049d6c1a)
#         ;
#
#
#
#
#             var marker_ea5e66cae79ed2c1c15d87595d600e68 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d00583c7f4c738bc37c17633b7955df4);
#
#
#         var popup_0cd996ed857d53aa52608c027308722a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2301a9e1dd68bac002cad4ed2a6c9d9f = $(`&lt;div id=&quot;html_2301a9e1dd68bac002cad4ed2a6c9d9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0cd996ed857d53aa52608c027308722a.setContent(html_2301a9e1dd68bac002cad4ed2a6c9d9f);
#
#
#
#         marker_
