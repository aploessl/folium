# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c31a87e02722f65807ae88f1116d6992 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c31a87e02722f65807ae88f1116d6992&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c31a87e02722f65807ae88f1116d6992 = L.map(
#                 &quot;map_c31a87e02722f65807ae88f1116d6992&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b80b4fcbc2cbbca1a28b235d4ac97ae4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b80b4fcbc2cbbca1a28b235d4ac97ae4.addTo(map_c31a87e02722f65807ae88f1116d6992);
#
#
#             var marker_6102da21c7af171bc8ce0fa1b4f6d774 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c31a87e02722f65807ae88f1116d6992);
#
#
#         var popup_4d39d7adb871c020bcb2861bf5b93f8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed3301d63da36181fddd6130177b9d91 = $(`&lt;div id=&quot;html_ed3301d63da36181fddd6130177b9d91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4d39d7adb871c020bcb2861bf5b93f8e.setContent(html_ed3301d63da36181fddd6130177b9d91);
#
#
#
#         marker_6102da21c7af171bc8ce0fa1b4f6d774.bindPopup(popup_4d39d7adb871c020bcb2861bf5b93f8e)
#         ;
#
#
#
#
#             var marker_b4afd60df410645a9c98f7e2fa1ebcfe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c31a87e02722f65807ae88f1116d6992);
#
#
#         var popup_56ad1f5e5a4d30d73e93a71091b8290e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61d660a7bca12e13f53cfc38049d7b62 = $(`&lt;div id=&quot;html_61d660a7bca12e13f53cfc38049d7b62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_56ad1f5e5a4d30d73e93a71091b8290e.setContent(html_61d660a7bca12e13f53cfc38049d7b62);
#
#
#
#         marker_b4afd60df410645a9c98f7e2fa1ebcfe.bindPopup(popup_56ad1f5e5a4d30d73e93a71091b8290e)
#         ;
#
#
#
#
#             var marker_4ea1e01f555ff77f20017bd720613d3f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c31a87e02722f65807ae88f1116d6992);
#
#
#         var popup_80b9e92ee5460dc4c680b100c879df5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbbbbd87f77510a137a68fba7d8bf320 = $(`&lt;div id=&quot;html_bbbbbd87f77510a137a68fba7d8bf320&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_80b9e92ee5460dc4c680b100c879df5d.setContent(html_bbbbbd87f77510a137a68fba7d8bf320);
#
#
#
#         marker_4ea1e01f555ff77f20017bd720613d3f.bindPopup(popup_80b9e92ee5460dc4c680b100c879df5d)
#         ;
#
#
#
#
#             var marker_5ee88d695115f8f4981740e5b0599acf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c31a87e02722f65807ae88f1116d6992);
#
#
#         var popup_86911d9fa536206489467843d58d44b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e1d19cd0c1b9d210f0e43ccd63df05d = $(`&lt;div id=&quot;html_7e1d19cd0c1b9d210f0e43ccd63df05d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_86911d9fa536206489467843d58d44b2.setContent(html_7e1d19cd0c1b9d210f0e43ccd63df05d);
#
#
#
#         marker_5ee88d695115f8f4981740e5b0599acf.bindPopup(popup_86911d9fa536206489467843d58d44b2)
#         ;
#
#
#
#
#             var marker_4151aeca6d9ce3dbd8dfb8883fa48388 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c31a87e02722f65807ae88f1116d6992);
#
#
#         var popup_0b057bc1a22b91f0407bd26afdd2757e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c21446ebc9a12326e4d2cf39a4fac633 = $(`&lt;div id=&quot;html_c21446ebc9a12326e4d2cf39a4fac633&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0b057bc1a22b91f0407bd26afdd2757e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db958a58b77b8940f969c543e6c35ce8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db958a58b77b8940f969c543e6c35ce8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db958a58b77b8940f969c543e6c35ce8 = L.map(
#                 &quot;map_db958a58b77b8940f969c543e6c35ce8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a325e9ee689e2b00da4740b0b62ae13 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1a325e9ee689e2b00da4740b0b62ae13.addTo(map_db958a58b77b8940f969c543e6c35ce8);
#
#
#             var feature_group_d02518c4c2f558d79c1ef5580fc2c4bf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9ab6248a7c71bdf3f2f57524f72c8f42 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d02518c4c2f558d79c1ef5580fc2c4bf);
#
#
#         var popup_9b28ba43a18537240d59592ee40fa6e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1471934f092cfad61fcc72a7a29b6f86 = $(`&lt;div id=&quot;html_1471934f092cfad61fcc72a7a29b6f86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9b28ba43a18537240d59592ee40fa6e4.setContent(html_1471934f092cfad61fcc72a7a29b6f86);
#
#
#
#         marker_9ab6248a7c71bdf3f2f57524f72c8f42.bindPopup(popup_9b28ba43a18537240d59592ee40fa6e4)
#         ;
#
#
#
#
#             var marker_769f7aae2dbc081bea45e338120a1fdd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d02518c4c2f558d79c1ef5580fc2c4bf);
#
#
#         var popup_7c90d5a67b17f9fcf2544d4a9c8bea41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f98062bbe0d4e3ae70c24108ac453b3 = $(`&lt;div id=&quot;html_7f98062bbe0d4e3ae70c24108ac453b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7c90d5a67b17f9fcf2544d4a9c8bea41.setContent(html_7f98062bbe0d4e3ae70c24108ac453b3);
#
#
#
#         marker_769f7aae2dbc081bea45e338120a1fdd.bindPopup(popup_7c90d5a67b17f9fcf2544d4a9c8bea41)
#         ;
#
#
#
#
#             var marker_4fe746f51d8ce8ac5151e79669b179d3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d02518c4c2f558d79c1ef5580fc2c4bf);
#
#
#         var popup_2ed9b793b038b00eab1f55aacbf11fb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a03630254ae8ca24b90fc269c09d321f = $(`&lt;div id=&quot;html_a03630254ae8ca24b90fc269c09d321f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2ed9b793b038b00eab1f55aacbf11fb7.setContent(html_a03630254ae8ca24b90fc269c09d321f);
#
#
#
#         marker_4fe746f51d8ce8ac5151e79669b179d3.bindPopup(popup_2ed9b793b038b00eab1f55aacbf11fb7)
#         ;
#
#
#
#
#             var marker_a3b972ed509824e68e26df4b59363af1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d02518c4c2f558d79c1ef5580fc2c4bf);
#
#
#         var popup_77c84abc8d0a6922d3b421438a038098 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38c241c974fa451f12b6337acb31ad82 = $(`&lt;div id=&quot;html_38c241c974fa451f12b6337acb31ad82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_77c84abc8d0a6922d3b421438a038098.setContent(html_38c241c974fa451f12b6337acb31ad82);
#
#
#
#         marker_a3b972ed509824e68e26df4b59363af1.bindPopup(popup_77c84abc8d0a6922d3b421438a038098)
#         ;
#
#
#
#
#             var marker_554a07b17ae753ffffb5b5bac700bc12 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d02518c4c2f558d79c1ef5580fc2c4bf);
#
#
#         var popup_871092152cfabb676495ce01523144a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4a90a5badfdf6af2d2036bffbfa5c3a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4a90a5badfdf6af2d2036bffbfa5c3a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4a90a5badfdf6af2d2036bffbfa5c3a = L.map(
#                 &quot;map_b4a90a5badfdf6af2d2036bffbfa5c3a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3381cf1557a4bbddc0e357d022689fb7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3381cf1557a4bbddc0e357d022689fb7.addTo(map_b4a90a5badfdf6af2d2036bffbfa5c3a);
#
#
#             var feature_group_60160e4d1b980f370d3280ca299069b5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_60160e4d1b980f370d3280ca299069b5.addTo(map_b4a90a5badfdf6af2d2036bffbfa5c3a);
#
#
#             var feature_group_sub_group_c96d12ba4f948bd0e47b1d2aedfcee60 = L.featureGroup.subGroup(
#                 feature_group_60160e4d1b980f370d3280ca299069b5
#             );
#
#
#             var marker_99b6a9a2a954677afb3a2b7b8206cbac = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c96d12ba4f948bd0e47b1d2aedfcee60);
#
#
#         var popup_237c85e91718c5be78bcb16d1e93d10b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af64fae29c2f9bdc2921978ec4bdaaff = $(`&lt;div id=&quot;html_af64fae29c2f9bdc2921978ec4bdaaff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_237c85e91718c5be78bcb16d1e93d10b.setContent(html_af64fae29c2f9bdc2921978ec4bdaaff);
#
#
#
#         marker_99b6a9a2a954677afb3a2b7b8206cbac.bindPopup(popup_237c85e91718c5be78bcb16d1e93d10b)
#         ;
#
#
#
#
#             var marker_825ea462ea62d694d53137bcda5b1816 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c96d12ba4f948bd0e47b1d2aedfcee60);
#
#
#         var popup_f5bfec2b57eed947dd8fe4a697200b65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7376d0254a69b32d59ba15c0197a9ea = $(`&lt;div id=&quot;html_b7376d0254a69b32d59ba15c0197a9ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f5bfec2b57eed947dd8fe4a697200b65.setContent(html_b7376d0254a69b32d59ba15c0197a9ea);
#
#
#
#         marker_825ea462ea62d694d53137bcda5b1816.bindPopup(popup_f5bfec2b57eed947dd8fe4a697200b65)
#         ;
#
#
#
#
#             var marker_7c03cd91b0353039c6d2d35d1b46e515 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c96d12ba4f948bd0e47b1d2aedfcee60);
#
#
#         var popup_b0fbbd0279525f61390cfb9df42cd1f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8215708d997f821ef38648ff679a5763 = $(`&lt;div id=&quot;html_8215708d997f821ef38648ff679a5763&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b0fbbd0279525f61390cfb9df42cd1f6.setContent(html_8215708d997f821ef38648ff679a5763);
#
#
#
#         marker_7c03cd91b0353039c6d2d35d1b46e515.bindPopup(popup_b0fbbd0279525f61390cfb9df42cd1f6)
#         ;
#
#
#
#
#             var marker_d8ddc6d3b3575760549f3e0673efd27f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c96d12ba4f948bd0e47b1d2aedfcee60);
#
#
#         var popup_e84a84b27fd1c0b51828bed6141a5426 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b78a33055bc435fbea5aa5ed6ded0b62 = $(`&lt;div id=&quot;html_b78a33055bc435fbea5aa5ed6ded0b62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e84a84b27fd1c0b51828bed6141a5426.setContent(html_b78a33055bc435fbea5aa5ed6ded0b62);
#
#
#
#         marker_
