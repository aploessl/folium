# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34b359f37334098ee9d72826b1c646c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34b359f37334098ee9d72826b1c646c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34b359f37334098ee9d72826b1c646c8 = L.map(
#                 &quot;map_34b359f37334098ee9d72826b1c646c8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8b2d9c850df67dafc48866f68dd1df6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b8b2d9c850df67dafc48866f68dd1df6.addTo(map_34b359f37334098ee9d72826b1c646c8);
#
#
#             var marker_5e44442a6b6e70f814fc53202b4ad8d6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_34b359f37334098ee9d72826b1c646c8);
#
#
#         var popup_4fe0ff4b7f286a95f332703c7ada04ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11661b01183233db898531c7e1c0ec36 = $(`&lt;div id=&quot;html_11661b01183233db898531c7e1c0ec36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4fe0ff4b7f286a95f332703c7ada04ba.setContent(html_11661b01183233db898531c7e1c0ec36);
#
#
#
#         marker_5e44442a6b6e70f814fc53202b4ad8d6.bindPopup(popup_4fe0ff4b7f286a95f332703c7ada04ba)
#         ;
#
#
#
#
#             var marker_6a4f82b2ed0870b4b5abb373674445e4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_34b359f37334098ee9d72826b1c646c8);
#
#
#         var popup_23b12123561504dbcf723cf1e7d03c91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d64ef716b6b76b1a82fe68a406e65577 = $(`&lt;div id=&quot;html_d64ef716b6b76b1a82fe68a406e65577&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_23b12123561504dbcf723cf1e7d03c91.setContent(html_d64ef716b6b76b1a82fe68a406e65577);
#
#
#
#         marker_6a4f82b2ed0870b4b5abb373674445e4.bindPopup(popup_23b12123561504dbcf723cf1e7d03c91)
#         ;
#
#
#
#
#             var marker_b48f3db4d40d1530baa55f97ab59b0df = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_34b359f37334098ee9d72826b1c646c8);
#
#
#         var popup_5c8a36b4ccc9afcbdeb5f33c8a16d189 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b276d98830312687cc602c63c260f09 = $(`&lt;div id=&quot;html_7b276d98830312687cc602c63c260f09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5c8a36b4ccc9afcbdeb5f33c8a16d189.setContent(html_7b276d98830312687cc602c63c260f09);
#
#
#
#         marker_b48f3db4d40d1530baa55f97ab59b0df.bindPopup(popup_5c8a36b4ccc9afcbdeb5f33c8a16d189)
#         ;
#
#
#
#
#             var marker_bce8f73ab635337bd06061dcb2f3e70a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_34b359f37334098ee9d72826b1c646c8);
#
#
#         var popup_558eb1fb5c96b124e07f4a2255280707 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_542572c3e5362c8cfba768403521aa1b = $(`&lt;div id=&quot;html_542572c3e5362c8cfba768403521aa1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_558eb1fb5c96b124e07f4a2255280707.setContent(html_542572c3e5362c8cfba768403521aa1b);
#
#
#
#         marker_bce8f73ab635337bd06061dcb2f3e70a.bindPopup(popup_558eb1fb5c96b124e07f4a2255280707)
#         ;
#
#
#
#
#             var marker_7d7cf98198945e4a779d24d9648ede14 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_34b359f37334098ee9d72826b1c646c8);
#
#
#         var popup_5a86d044acf239dc46fafd1034fb9658 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12489225af482b641b804ae2c98599bc = $(`&lt;div id=&quot;html_12489225af482b641b804ae2c98599bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5a86d044acf239dc46fafd1034fb9658.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0784282947dae982ea5a8622a25e9281 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0784282947dae982ea5a8622a25e9281&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0784282947dae982ea5a8622a25e9281 = L.map(
#                 &quot;map_0784282947dae982ea5a8622a25e9281&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5945a073c6fb298761ff5cb9d34fc6c3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5945a073c6fb298761ff5cb9d34fc6c3.addTo(map_0784282947dae982ea5a8622a25e9281);
#
#
#             var feature_group_f1cedaf42503b3ca436ee4e0538e7e11 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5c41daef2af4b183b681cbec6972227a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f1cedaf42503b3ca436ee4e0538e7e11);
#
#
#         var popup_146d212e80daad606140dfb343d852f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_616d4c75d9bfcd8b959061e185bbcf24 = $(`&lt;div id=&quot;html_616d4c75d9bfcd8b959061e185bbcf24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_146d212e80daad606140dfb343d852f7.setContent(html_616d4c75d9bfcd8b959061e185bbcf24);
#
#
#
#         marker_5c41daef2af4b183b681cbec6972227a.bindPopup(popup_146d212e80daad606140dfb343d852f7)
#         ;
#
#
#
#
#             var marker_8d87b8796239a656b524c3c8d71f5422 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f1cedaf42503b3ca436ee4e0538e7e11);
#
#
#         var popup_9fefb2d1c01e1e3d808a57faf8501558 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_caa329972c8df04549c0c65ed78ce02a = $(`&lt;div id=&quot;html_caa329972c8df04549c0c65ed78ce02a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9fefb2d1c01e1e3d808a57faf8501558.setContent(html_caa329972c8df04549c0c65ed78ce02a);
#
#
#
#         marker_8d87b8796239a656b524c3c8d71f5422.bindPopup(popup_9fefb2d1c01e1e3d808a57faf8501558)
#         ;
#
#
#
#
#             var marker_77fbffe4fdc5c49548e0c9aa5602a3fd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f1cedaf42503b3ca436ee4e0538e7e11);
#
#
#         var popup_f20b1d3303c63f4eb5efc27dfef9e525 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e595e6cfd7da591d50869189a89319c = $(`&lt;div id=&quot;html_1e595e6cfd7da591d50869189a89319c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f20b1d3303c63f4eb5efc27dfef9e525.setContent(html_1e595e6cfd7da591d50869189a89319c);
#
#
#
#         marker_77fbffe4fdc5c49548e0c9aa5602a3fd.bindPopup(popup_f20b1d3303c63f4eb5efc27dfef9e525)
#         ;
#
#
#
#
#             var marker_76051c4d4e4f2a3448c5c3d8a458df27 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f1cedaf42503b3ca436ee4e0538e7e11);
#
#
#         var popup_54426c9105a88415207d9c8bf4728511 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a7b37648bebcb922ca4199bd5be90bd = $(`&lt;div id=&quot;html_0a7b37648bebcb922ca4199bd5be90bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_54426c9105a88415207d9c8bf4728511.setContent(html_0a7b37648bebcb922ca4199bd5be90bd);
#
#
#
#         marker_76051c4d4e4f2a3448c5c3d8a458df27.bindPopup(popup_54426c9105a88415207d9c8bf4728511)
#         ;
#
#
#
#
#             var marker_7bb22fe8649867ab63e0331a932bf5e4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f1cedaf42503b3ca436ee4e0538e7e11);
#
#
#         var popup_260651dee17eebef051f0e71a4f4ed2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6a673f5394f007fa23db2010e51f2ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6a673f5394f007fa23db2010e51f2ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e6a673f5394f007fa23db2010e51f2ba = L.map(
#                 &quot;map_e6a673f5394f007fa23db2010e51f2ba&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0f8f9f9fab4a73cf889187e53c44c24 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0f8f9f9fab4a73cf889187e53c44c24.addTo(map_e6a673f5394f007fa23db2010e51f2ba);
#
#
#             var feature_group_a80041cb71bb15e483eba120a6466ccc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a80041cb71bb15e483eba120a6466ccc.addTo(map_e6a673f5394f007fa23db2010e51f2ba);
#
#
#             var feature_group_sub_group_47ffba93ca909a28b2784cdaaace1ffb = L.featureGroup.subGroup(
#                 feature_group_a80041cb71bb15e483eba120a6466ccc
#             );
#
#
#             var marker_34b40c8dbd05cc58152501eab56d9873 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_47ffba93ca909a28b2784cdaaace1ffb);
#
#
#         var popup_e9fa85b9521d1e4bb36f83049d7bad9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b3bd2563e267de7e590334d355fabfb = $(`&lt;div id=&quot;html_2b3bd2563e267de7e590334d355fabfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e9fa85b9521d1e4bb36f83049d7bad9e.setContent(html_2b3bd2563e267de7e590334d355fabfb);
#
#
#
#         marker_34b40c8dbd05cc58152501eab56d9873.bindPopup(popup_e9fa85b9521d1e4bb36f83049d7bad9e)
#         ;
#
#
#
#
#             var marker_919959ca82efe59e5dbae5df2e4670e9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_47ffba93ca909a28b2784cdaaace1ffb);
#
#
#         var popup_8717e8b8a5592c38cfd8f8839d910639 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65e781cd378f5e9f3888ed308f17c2c5 = $(`&lt;div id=&quot;html_65e781cd378f5e9f3888ed308f17c2c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8717e8b8a5592c38cfd8f8839d910639.setContent(html_65e781cd378f5e9f3888ed308f17c2c5);
#
#
#
#         marker_919959ca82efe59e5dbae5df2e4670e9.bindPopup(popup_8717e8b8a5592c38cfd8f8839d910639)
#         ;
#
#
#
#
#             var marker_c464e3b2e79dd1e1c06a17f078940b09 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_47ffba93ca909a28b2784cdaaace1ffb);
#
#
#         var popup_21bb84a697cd10c4e1ff4d5d66577d40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_543b06490ae24729d40c8a674b8367f2 = $(`&lt;div id=&quot;html_543b06490ae24729d40c8a674b8367f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_21bb84a697cd10c4e1ff4d5d66577d40.setContent(html_543b06490ae24729d40c8a674b8367f2);
#
#
#
#         marker_c464e3b2e79dd1e1c06a17f078940b09.bindPopup(popup_21bb84a697cd10c4e1ff4d5d66577d40)
#         ;
#
#
#
#
#             var marker_31ccec5cb187746318bd12f63f5f5941 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_47ffba93ca909a28b2784cdaaace1ffb);
#
#
#         var popup_ae18e1a4ff6b7069da0c420e4fc1151a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c947079aef905604c40d5135ed29491f = $(`&lt;div id=&quot;html_c947079aef905604c40d5135ed29491f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ae18e1a4ff6b7069da0c420e4fc1151a.setContent(html_c947079aef905604c40d5135ed29491f);
#
#
#
#         marker_
