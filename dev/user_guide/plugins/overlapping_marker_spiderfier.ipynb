# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac6caf65f71271cfc05849341d3c7493 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac6caf65f71271cfc05849341d3c7493&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac6caf65f71271cfc05849341d3c7493 = L.map(
#                 &quot;map_ac6caf65f71271cfc05849341d3c7493&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0155141117e916081749c5550172657e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0155141117e916081749c5550172657e.addTo(map_ac6caf65f71271cfc05849341d3c7493);
#
#
#             var marker_1e6e3f6a4fa80a29cfc9ad0af6ecbfbb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ac6caf65f71271cfc05849341d3c7493);
#
#
#         var popup_ce2c7d691cbe054b8d8aa8b3aa2df61d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9592fd5f7c76674cf6c58eb4e9f73d58 = $(`&lt;div id=&quot;html_9592fd5f7c76674cf6c58eb4e9f73d58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ce2c7d691cbe054b8d8aa8b3aa2df61d.setContent(html_9592fd5f7c76674cf6c58eb4e9f73d58);
#
#
#
#         marker_1e6e3f6a4fa80a29cfc9ad0af6ecbfbb.bindPopup(popup_ce2c7d691cbe054b8d8aa8b3aa2df61d)
#         ;
#
#
#
#
#             var marker_4c4534564af5ddf8e8137245df7769c7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ac6caf65f71271cfc05849341d3c7493);
#
#
#         var popup_e8ba48b71df4752e0a33a6849159c525 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fd4673a6dfa6946cc228f80e0668e0b = $(`&lt;div id=&quot;html_3fd4673a6dfa6946cc228f80e0668e0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e8ba48b71df4752e0a33a6849159c525.setContent(html_3fd4673a6dfa6946cc228f80e0668e0b);
#
#
#
#         marker_4c4534564af5ddf8e8137245df7769c7.bindPopup(popup_e8ba48b71df4752e0a33a6849159c525)
#         ;
#
#
#
#
#             var marker_bfcaf102a6b0fc1630c6231959f4790e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ac6caf65f71271cfc05849341d3c7493);
#
#
#         var popup_c45fb4a034c49d88a9de4f5009ac487a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e670faa95e003e74cdb95a43c467fd4e = $(`&lt;div id=&quot;html_e670faa95e003e74cdb95a43c467fd4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c45fb4a034c49d88a9de4f5009ac487a.setContent(html_e670faa95e003e74cdb95a43c467fd4e);
#
#
#
#         marker_bfcaf102a6b0fc1630c6231959f4790e.bindPopup(popup_c45fb4a034c49d88a9de4f5009ac487a)
#         ;
#
#
#
#
#             var marker_12cbca6fe74a5ac85be08fd65311d0e1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ac6caf65f71271cfc05849341d3c7493);
#
#
#         var popup_ddaa495be0dd457ac9024de2333aee2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2094e5751307c3e4e5a220715a33d55 = $(`&lt;div id=&quot;html_c2094e5751307c3e4e5a220715a33d55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ddaa495be0dd457ac9024de2333aee2a.setContent(html_c2094e5751307c3e4e5a220715a33d55);
#
#
#
#         marker_12cbca6fe74a5ac85be08fd65311d0e1.bindPopup(popup_ddaa495be0dd457ac9024de2333aee2a)
#         ;
#
#
#
#
#             var marker_5b7ffa5bf8a10546993faf6fdba30a0f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ac6caf65f71271cfc05849341d3c7493);
#
#
#         var popup_969397245abc3f4e8d464e717524235d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95c3aaf38c74ae7db3493d228e8cd161 = $(`&lt;div id=&quot;html_95c3aaf38c74ae7db3493d228e8cd161&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_969397245abc3f4e8d464e717524235d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89f943d7ef6289cf237b1180d3bfd748 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89f943d7ef6289cf237b1180d3bfd748&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89f943d7ef6289cf237b1180d3bfd748 = L.map(
#                 &quot;map_89f943d7ef6289cf237b1180d3bfd748&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a9f84b4027a3a01c5d8283b691d959a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a9f84b4027a3a01c5d8283b691d959a.addTo(map_89f943d7ef6289cf237b1180d3bfd748);
#
#
#             var feature_group_9c013a4cc8010a7aee9f961835e2cda6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7951d8784b1a30abc3b047d5418e3a97 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9c013a4cc8010a7aee9f961835e2cda6);
#
#
#         var popup_13157b0729d085019dc7b3393b90e427 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_763b8ee7a6e8130e7c21ee80a0f8327f = $(`&lt;div id=&quot;html_763b8ee7a6e8130e7c21ee80a0f8327f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_13157b0729d085019dc7b3393b90e427.setContent(html_763b8ee7a6e8130e7c21ee80a0f8327f);
#
#
#
#         marker_7951d8784b1a30abc3b047d5418e3a97.bindPopup(popup_13157b0729d085019dc7b3393b90e427)
#         ;
#
#
#
#
#             var marker_bb30fbd011c0d553348d5e75710ec01a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9c013a4cc8010a7aee9f961835e2cda6);
#
#
#         var popup_7a2398b00e15e6857fc0278a8f8767f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_424c04fe294ea8f1169e6c88d6a1d56d = $(`&lt;div id=&quot;html_424c04fe294ea8f1169e6c88d6a1d56d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7a2398b00e15e6857fc0278a8f8767f4.setContent(html_424c04fe294ea8f1169e6c88d6a1d56d);
#
#
#
#         marker_bb30fbd011c0d553348d5e75710ec01a.bindPopup(popup_7a2398b00e15e6857fc0278a8f8767f4)
#         ;
#
#
#
#
#             var marker_94e17b3faa5d1dd3378c4b22f167081c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9c013a4cc8010a7aee9f961835e2cda6);
#
#
#         var popup_3322ece411c320b190d34aaf6351c602 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a87bbd528c75f4ac1fec9bcb350c1f3 = $(`&lt;div id=&quot;html_6a87bbd528c75f4ac1fec9bcb350c1f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3322ece411c320b190d34aaf6351c602.setContent(html_6a87bbd528c75f4ac1fec9bcb350c1f3);
#
#
#
#         marker_94e17b3faa5d1dd3378c4b22f167081c.bindPopup(popup_3322ece411c320b190d34aaf6351c602)
#         ;
#
#
#
#
#             var marker_b81a5155952f092ac1bf2847519e58eb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9c013a4cc8010a7aee9f961835e2cda6);
#
#
#         var popup_bf1ea50be55d18f4e6d7c4fb4f252658 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_804a1a2316c0cca568b866bc8db9d9d2 = $(`&lt;div id=&quot;html_804a1a2316c0cca568b866bc8db9d9d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bf1ea50be55d18f4e6d7c4fb4f252658.setContent(html_804a1a2316c0cca568b866bc8db9d9d2);
#
#
#
#         marker_b81a5155952f092ac1bf2847519e58eb.bindPopup(popup_bf1ea50be55d18f4e6d7c4fb4f252658)
#         ;
#
#
#
#
#             var marker_6249de9ab20f9790d59f22e49421a590 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9c013a4cc8010a7aee9f961835e2cda6);
#
#
#         var popup_366ca3f1377924f73397686585ae157c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8f50cdc3f9628338340522c5b8eb6ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8f50cdc3f9628338340522c5b8eb6ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8f50cdc3f9628338340522c5b8eb6ca = L.map(
#                 &quot;map_d8f50cdc3f9628338340522c5b8eb6ca&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37af22d51f27ab24802e1510ebcf5193 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_37af22d51f27ab24802e1510ebcf5193.addTo(map_d8f50cdc3f9628338340522c5b8eb6ca);
#
#
#             var feature_group_6af8afa03df70320073b3e2b12e3cb90 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6af8afa03df70320073b3e2b12e3cb90.addTo(map_d8f50cdc3f9628338340522c5b8eb6ca);
#
#
#             var feature_group_sub_group_341a828f883e03cd7cda1fa6baf9179c = L.featureGroup.subGroup(
#                 feature_group_6af8afa03df70320073b3e2b12e3cb90
#             );
#
#
#             var marker_45ea1b278d9df8010aaf907c7253eff2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_341a828f883e03cd7cda1fa6baf9179c);
#
#
#         var popup_cf53a23abf90b9997a30b0dca790090b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fc9f8443e0571ffb2ed4d72e55bf3c9 = $(`&lt;div id=&quot;html_6fc9f8443e0571ffb2ed4d72e55bf3c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cf53a23abf90b9997a30b0dca790090b.setContent(html_6fc9f8443e0571ffb2ed4d72e55bf3c9);
#
#
#
#         marker_45ea1b278d9df8010aaf907c7253eff2.bindPopup(popup_cf53a23abf90b9997a30b0dca790090b)
#         ;
#
#
#
#
#             var marker_9b20dc51ca06f977c6ec1d37d5638baa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_341a828f883e03cd7cda1fa6baf9179c);
#
#
#         var popup_86225ab0bff3bf48d8797c4bc1b91fdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53460068f80bf422b06b80a42630b83f = $(`&lt;div id=&quot;html_53460068f80bf422b06b80a42630b83f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_86225ab0bff3bf48d8797c4bc1b91fdc.setContent(html_53460068f80bf422b06b80a42630b83f);
#
#
#
#         marker_9b20dc51ca06f977c6ec1d37d5638baa.bindPopup(popup_86225ab0bff3bf48d8797c4bc1b91fdc)
#         ;
#
#
#
#
#             var marker_36d63151818c2a4baabd37ea9864516a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_341a828f883e03cd7cda1fa6baf9179c);
#
#
#         var popup_df42d7200df9bbeeb6df7120119806cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_756b38ba37d2556d6ba100a6dc4b0022 = $(`&lt;div id=&quot;html_756b38ba37d2556d6ba100a6dc4b0022&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_df42d7200df9bbeeb6df7120119806cb.setContent(html_756b38ba37d2556d6ba100a6dc4b0022);
#
#
#
#         marker_36d63151818c2a4baabd37ea9864516a.bindPopup(popup_df42d7200df9bbeeb6df7120119806cb)
#         ;
#
#
#
#
#             var marker_0606387c5d2c22ccba95923df6a6e6d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_341a828f883e03cd7cda1fa6baf9179c);
#
#
#         var popup_6533258ac408a6b6c0527f65aced9d56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80b925a1713c82f1e2feade1189007db = $(`&lt;div id=&quot;html_80b925a1713c82f1e2feade1189007db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6533258ac408a6b6c0527f65aced9d56.setContent(html_80b925a1713c82f1e2feade1189007db);
#
#
#
#         marker_
