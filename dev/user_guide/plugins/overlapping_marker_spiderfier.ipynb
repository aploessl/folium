# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9dd99f75a3917494cd8894e70cbf395a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9dd99f75a3917494cd8894e70cbf395a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9dd99f75a3917494cd8894e70cbf395a = L.map(
#                 &quot;map_9dd99f75a3917494cd8894e70cbf395a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1bdc9e9d24078ba948fa339ba69204c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a1bdc9e9d24078ba948fa339ba69204c.addTo(map_9dd99f75a3917494cd8894e70cbf395a);
#
#
#             var marker_aeda1e5694ebaae2fe659734f7b8e5f0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9dd99f75a3917494cd8894e70cbf395a);
#
#
#         var popup_f354deb4d35e8405c753e7743841eb96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a06acaa0bd5e5d598bebc4a6211a3062 = $(`&lt;div id=&quot;html_a06acaa0bd5e5d598bebc4a6211a3062&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f354deb4d35e8405c753e7743841eb96.setContent(html_a06acaa0bd5e5d598bebc4a6211a3062);
#
#
#
#         marker_aeda1e5694ebaae2fe659734f7b8e5f0.bindPopup(popup_f354deb4d35e8405c753e7743841eb96)
#         ;
#
#
#
#
#             var marker_de0241feecf4340c927fd5585f73ccec = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9dd99f75a3917494cd8894e70cbf395a);
#
#
#         var popup_cbea2eda6650f4b693c5abdb8a452269 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d7ea15ed8251e22d31a7979e8033de2 = $(`&lt;div id=&quot;html_3d7ea15ed8251e22d31a7979e8033de2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cbea2eda6650f4b693c5abdb8a452269.setContent(html_3d7ea15ed8251e22d31a7979e8033de2);
#
#
#
#         marker_de0241feecf4340c927fd5585f73ccec.bindPopup(popup_cbea2eda6650f4b693c5abdb8a452269)
#         ;
#
#
#
#
#             var marker_6d610a6bc6d7b0b22e0877d72e05c369 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9dd99f75a3917494cd8894e70cbf395a);
#
#
#         var popup_83b40a086cc3b489e3b74211e54dd167 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d3777799b688e4d308f67dab42c439f = $(`&lt;div id=&quot;html_1d3777799b688e4d308f67dab42c439f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_83b40a086cc3b489e3b74211e54dd167.setContent(html_1d3777799b688e4d308f67dab42c439f);
#
#
#
#         marker_6d610a6bc6d7b0b22e0877d72e05c369.bindPopup(popup_83b40a086cc3b489e3b74211e54dd167)
#         ;
#
#
#
#
#             var marker_3adc0db10fc9aeece28961d069a888ce = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9dd99f75a3917494cd8894e70cbf395a);
#
#
#         var popup_b19b845de30eed93258684525458956b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cef00ec6f40b8f49fdff0a7c369625ba = $(`&lt;div id=&quot;html_cef00ec6f40b8f49fdff0a7c369625ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b19b845de30eed93258684525458956b.setContent(html_cef00ec6f40b8f49fdff0a7c369625ba);
#
#
#
#         marker_3adc0db10fc9aeece28961d069a888ce.bindPopup(popup_b19b845de30eed93258684525458956b)
#         ;
#
#
#
#
#             var marker_0c58014e3e807137a9a3b1d117be52ec = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9dd99f75a3917494cd8894e70cbf395a);
#
#
#         var popup_c3ef2d2aacbcbc06feefee07d6bdb6a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8c6517c754d6ce51c1433c7d54393c4 = $(`&lt;div id=&quot;html_b8c6517c754d6ce51c1433c7d54393c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c3ef2d2aacbcbc06feefee07d6bdb6a5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5bbb6740f3263123e8ea566dcfed60f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5bbb6740f3263123e8ea566dcfed60f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5bbb6740f3263123e8ea566dcfed60f0 = L.map(
#                 &quot;map_5bbb6740f3263123e8ea566dcfed60f0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e86c03f79cb9aa7c83de77d95213a23 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e86c03f79cb9aa7c83de77d95213a23.addTo(map_5bbb6740f3263123e8ea566dcfed60f0);
#
#
#             var feature_group_36b57721a0c70995ae8e2355b94cfae5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a42291fbecdd6fdcb5a5427b5ea407cd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_36b57721a0c70995ae8e2355b94cfae5);
#
#
#         var popup_2eebd5800690a57dd04ff9166912eb70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43a48046fd64adb78a0a1f45f911e3f1 = $(`&lt;div id=&quot;html_43a48046fd64adb78a0a1f45f911e3f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2eebd5800690a57dd04ff9166912eb70.setContent(html_43a48046fd64adb78a0a1f45f911e3f1);
#
#
#
#         marker_a42291fbecdd6fdcb5a5427b5ea407cd.bindPopup(popup_2eebd5800690a57dd04ff9166912eb70)
#         ;
#
#
#
#
#             var marker_195aee77e1d160e1ab700d9aa5a50ca6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_36b57721a0c70995ae8e2355b94cfae5);
#
#
#         var popup_2693a2ff0deb98fa1ba77b358c0aeeb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2c97295c8f4d442042e1e37ff8fd91d = $(`&lt;div id=&quot;html_b2c97295c8f4d442042e1e37ff8fd91d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2693a2ff0deb98fa1ba77b358c0aeeb4.setContent(html_b2c97295c8f4d442042e1e37ff8fd91d);
#
#
#
#         marker_195aee77e1d160e1ab700d9aa5a50ca6.bindPopup(popup_2693a2ff0deb98fa1ba77b358c0aeeb4)
#         ;
#
#
#
#
#             var marker_e360e84e49e4e2673e095a2c9948175a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_36b57721a0c70995ae8e2355b94cfae5);
#
#
#         var popup_16439f965cde53a83349d08a6e0d15e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63daf99590bebebc243338eee2cf3c49 = $(`&lt;div id=&quot;html_63daf99590bebebc243338eee2cf3c49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_16439f965cde53a83349d08a6e0d15e4.setContent(html_63daf99590bebebc243338eee2cf3c49);
#
#
#
#         marker_e360e84e49e4e2673e095a2c9948175a.bindPopup(popup_16439f965cde53a83349d08a6e0d15e4)
#         ;
#
#
#
#
#             var marker_ab8542da22a7576f3360f5ef604dac5d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_36b57721a0c70995ae8e2355b94cfae5);
#
#
#         var popup_ce323e023de2c0b7bb0c1864a194acfd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec6c19ceeebe48a0c6c5b9e15aca7365 = $(`&lt;div id=&quot;html_ec6c19ceeebe48a0c6c5b9e15aca7365&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ce323e023de2c0b7bb0c1864a194acfd.setContent(html_ec6c19ceeebe48a0c6c5b9e15aca7365);
#
#
#
#         marker_ab8542da22a7576f3360f5ef604dac5d.bindPopup(popup_ce323e023de2c0b7bb0c1864a194acfd)
#         ;
#
#
#
#
#             var marker_21e4d9b748add457a78747b80330b33a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_36b57721a0c70995ae8e2355b94cfae5);
#
#
#         var popup_40559b1d2e55a681b562149510a05706 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf4b2e703130f1603309c401525b4a15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf4b2e703130f1603309c401525b4a15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf4b2e703130f1603309c401525b4a15 = L.map(
#                 &quot;map_bf4b2e703130f1603309c401525b4a15&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_559c01bf6722448560702d2ac13e338d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_559c01bf6722448560702d2ac13e338d.addTo(map_bf4b2e703130f1603309c401525b4a15);
#
#
#             var feature_group_13b23011bcae5ca78f34f28076f2c974 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_13b23011bcae5ca78f34f28076f2c974.addTo(map_bf4b2e703130f1603309c401525b4a15);
#
#
#             var feature_group_sub_group_130699f5c57ef1a2a7cc2b5ba497a6a9 = L.featureGroup.subGroup(
#                 feature_group_13b23011bcae5ca78f34f28076f2c974
#             );
#
#
#             var marker_444e84f39673c27cf88e287206aeffc4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_130699f5c57ef1a2a7cc2b5ba497a6a9);
#
#
#         var popup_7bfab81675e73b63569caa8cdee6b98d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b65ab0f220af72e48279e3103503e74e = $(`&lt;div id=&quot;html_b65ab0f220af72e48279e3103503e74e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7bfab81675e73b63569caa8cdee6b98d.setContent(html_b65ab0f220af72e48279e3103503e74e);
#
#
#
#         marker_444e84f39673c27cf88e287206aeffc4.bindPopup(popup_7bfab81675e73b63569caa8cdee6b98d)
#         ;
#
#
#
#
#             var marker_71f4db500ff5c70364c9a22747da4045 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_130699f5c57ef1a2a7cc2b5ba497a6a9);
#
#
#         var popup_42eb9e5d4d15c38832d2b3ad8159d7d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d69bacc1ceaf1226493b6d3bc691a6e = $(`&lt;div id=&quot;html_3d69bacc1ceaf1226493b6d3bc691a6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_42eb9e5d4d15c38832d2b3ad8159d7d5.setContent(html_3d69bacc1ceaf1226493b6d3bc691a6e);
#
#
#
#         marker_71f4db500ff5c70364c9a22747da4045.bindPopup(popup_42eb9e5d4d15c38832d2b3ad8159d7d5)
#         ;
#
#
#
#
#             var marker_23df5d1fe841e6570a73f748b65be890 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_130699f5c57ef1a2a7cc2b5ba497a6a9);
#
#
#         var popup_ea478c1466523168d458724585744165 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ca6ff9a4ba14d9690f0f1df6fcb9c20 = $(`&lt;div id=&quot;html_8ca6ff9a4ba14d9690f0f1df6fcb9c20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ea478c1466523168d458724585744165.setContent(html_8ca6ff9a4ba14d9690f0f1df6fcb9c20);
#
#
#
#         marker_23df5d1fe841e6570a73f748b65be890.bindPopup(popup_ea478c1466523168d458724585744165)
#         ;
#
#
#
#
#             var marker_3919056b31d3eed15c84a68cea60a1c5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_130699f5c57ef1a2a7cc2b5ba497a6a9);
#
#
#         var popup_41a674c1ee96e2cc65bee650e440ff17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_925c6449fce9825831098b7f5d6d15ea = $(`&lt;div id=&quot;html_925c6449fce9825831098b7f5d6d15ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_41a674c1ee96e2cc65bee650e440ff17.setContent(html_925c6449fce9825831098b7f5d6d15ea);
#
#
#
#         marker_
