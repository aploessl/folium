# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d84bf7a01fca9f11ea8a8ff4d78e05e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d84bf7a01fca9f11ea8a8ff4d78e05e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d84bf7a01fca9f11ea8a8ff4d78e05e = L.map(
#                 &quot;map_6d84bf7a01fca9f11ea8a8ff4d78e05e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_630d5352130f356ff50855395264741d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_630d5352130f356ff50855395264741d.addTo(map_6d84bf7a01fca9f11ea8a8ff4d78e05e);
#
#
#             var marker_ba1b41a2fdea4d48b8d84743197141f0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6d84bf7a01fca9f11ea8a8ff4d78e05e);
#
#
#         var popup_ba16d36e4d0a417ffa2e47a57ed79052 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_046421c321d63fa0e74ddf97ad512d37 = $(`&lt;div id=&quot;html_046421c321d63fa0e74ddf97ad512d37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ba16d36e4d0a417ffa2e47a57ed79052.setContent(html_046421c321d63fa0e74ddf97ad512d37);
#
#
#
#         marker_ba1b41a2fdea4d48b8d84743197141f0.bindPopup(popup_ba16d36e4d0a417ffa2e47a57ed79052)
#         ;
#
#
#
#
#             var marker_d76b3eb62df9089b3573a8a8e69039e0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6d84bf7a01fca9f11ea8a8ff4d78e05e);
#
#
#         var popup_a398bbb3b7deec830834ffcf0f90e512 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea861aef721c02a7228a8aabedd985b0 = $(`&lt;div id=&quot;html_ea861aef721c02a7228a8aabedd985b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a398bbb3b7deec830834ffcf0f90e512.setContent(html_ea861aef721c02a7228a8aabedd985b0);
#
#
#
#         marker_d76b3eb62df9089b3573a8a8e69039e0.bindPopup(popup_a398bbb3b7deec830834ffcf0f90e512)
#         ;
#
#
#
#
#             var marker_d0a19d94383dd7d63e9016b9e7b777b9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6d84bf7a01fca9f11ea8a8ff4d78e05e);
#
#
#         var popup_da3c701f0f6f737b572494d248bf1c02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e31327cc343ec59ab0d91d14008be23 = $(`&lt;div id=&quot;html_8e31327cc343ec59ab0d91d14008be23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_da3c701f0f6f737b572494d248bf1c02.setContent(html_8e31327cc343ec59ab0d91d14008be23);
#
#
#
#         marker_d0a19d94383dd7d63e9016b9e7b777b9.bindPopup(popup_da3c701f0f6f737b572494d248bf1c02)
#         ;
#
#
#
#
#             var marker_f5ee209b770ff44d8952f237bf1a3ed6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6d84bf7a01fca9f11ea8a8ff4d78e05e);
#
#
#         var popup_5e5d334950a8e3e7278d97a025532ab5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af1365acd2195d5c12409cd75deaf4c4 = $(`&lt;div id=&quot;html_af1365acd2195d5c12409cd75deaf4c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5e5d334950a8e3e7278d97a025532ab5.setContent(html_af1365acd2195d5c12409cd75deaf4c4);
#
#
#
#         marker_f5ee209b770ff44d8952f237bf1a3ed6.bindPopup(popup_5e5d334950a8e3e7278d97a025532ab5)
#         ;
#
#
#
#
#             var marker_efcb1c2ceb5d465aa010dd7e7df8e201 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6d84bf7a01fca9f11ea8a8ff4d78e05e);
#
#
#         var popup_d5b20142ccb5356d340b2192c05af555 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5d63e458d409fdf5839d727ddcbd40c = $(`&lt;div id=&quot;html_b5d63e458d409fdf5839d727ddcbd40c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d5b20142ccb5356d340b2192c05af555.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57caba96e0503ed1a839b55f0b53af73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57caba96e0503ed1a839b55f0b53af73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57caba96e0503ed1a839b55f0b53af73 = L.map(
#                 &quot;map_57caba96e0503ed1a839b55f0b53af73&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_660c3fc32b9574885a9be82e2f7f9240 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_660c3fc32b9574885a9be82e2f7f9240.addTo(map_57caba96e0503ed1a839b55f0b53af73);
#
#
#             var feature_group_79547d35d6538175e25b2fcd46e2316f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0d3ec7b684c1a2d437468056576f632a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_79547d35d6538175e25b2fcd46e2316f);
#
#
#         var popup_637714d6cb79f374f3879990a3f98f34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80d870275f0fff54e1beb6d2b42c2ce1 = $(`&lt;div id=&quot;html_80d870275f0fff54e1beb6d2b42c2ce1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_637714d6cb79f374f3879990a3f98f34.setContent(html_80d870275f0fff54e1beb6d2b42c2ce1);
#
#
#
#         marker_0d3ec7b684c1a2d437468056576f632a.bindPopup(popup_637714d6cb79f374f3879990a3f98f34)
#         ;
#
#
#
#
#             var marker_570ec415dc6f9f80fccf86ea49959046 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_79547d35d6538175e25b2fcd46e2316f);
#
#
#         var popup_fde39bb2d7f0bb63df41f8927efaa54a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_736d76c4d928dca5c72e15a4e2e3f872 = $(`&lt;div id=&quot;html_736d76c4d928dca5c72e15a4e2e3f872&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fde39bb2d7f0bb63df41f8927efaa54a.setContent(html_736d76c4d928dca5c72e15a4e2e3f872);
#
#
#
#         marker_570ec415dc6f9f80fccf86ea49959046.bindPopup(popup_fde39bb2d7f0bb63df41f8927efaa54a)
#         ;
#
#
#
#
#             var marker_6c53715a68723490cb824658eef3674b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_79547d35d6538175e25b2fcd46e2316f);
#
#
#         var popup_b6817a5c62fcd101da83b4ced84b2665 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee72de71b30f1997f1d4d5e01e5a86db = $(`&lt;div id=&quot;html_ee72de71b30f1997f1d4d5e01e5a86db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b6817a5c62fcd101da83b4ced84b2665.setContent(html_ee72de71b30f1997f1d4d5e01e5a86db);
#
#
#
#         marker_6c53715a68723490cb824658eef3674b.bindPopup(popup_b6817a5c62fcd101da83b4ced84b2665)
#         ;
#
#
#
#
#             var marker_9f5bd0a529b3b417a37083d9a8605a40 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_79547d35d6538175e25b2fcd46e2316f);
#
#
#         var popup_6fc214212097a35292f0f6b35b103555 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60a79cd4953cb8fe5ebe6727eabb54dd = $(`&lt;div id=&quot;html_60a79cd4953cb8fe5ebe6727eabb54dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6fc214212097a35292f0f6b35b103555.setContent(html_60a79cd4953cb8fe5ebe6727eabb54dd);
#
#
#
#         marker_9f5bd0a529b3b417a37083d9a8605a40.bindPopup(popup_6fc214212097a35292f0f6b35b103555)
#         ;
#
#
#
#
#             var marker_95cd96e41467e17115c21a32d5b80d57 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_79547d35d6538175e25b2fcd46e2316f);
#
#
#         var popup_9158ce2856f27173ee22b82a11dd8dd8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dca03297def6ccbd8ad6881cface68d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dca03297def6ccbd8ad6881cface68d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dca03297def6ccbd8ad6881cface68d6 = L.map(
#                 &quot;map_dca03297def6ccbd8ad6881cface68d6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb004afddd40fb6d33ba32ca0daae1d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fb004afddd40fb6d33ba32ca0daae1d6.addTo(map_dca03297def6ccbd8ad6881cface68d6);
#
#
#             var feature_group_8ac232f22a0a53a1c5d0c3f76c866da2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8ac232f22a0a53a1c5d0c3f76c866da2.addTo(map_dca03297def6ccbd8ad6881cface68d6);
#
#
#             var feature_group_sub_group_4d1f9b3647f5c08a712beb537fa0aaaa = L.featureGroup.subGroup(
#                 feature_group_8ac232f22a0a53a1c5d0c3f76c866da2
#             );
#
#
#             var marker_50df84a5f10618fbb903907994003df8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4d1f9b3647f5c08a712beb537fa0aaaa);
#
#
#         var popup_e251d8a6b9a73361956fdb933d2e4c82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6076c3d262f7351a90a94100b6c73fe1 = $(`&lt;div id=&quot;html_6076c3d262f7351a90a94100b6c73fe1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e251d8a6b9a73361956fdb933d2e4c82.setContent(html_6076c3d262f7351a90a94100b6c73fe1);
#
#
#
#         marker_50df84a5f10618fbb903907994003df8.bindPopup(popup_e251d8a6b9a73361956fdb933d2e4c82)
#         ;
#
#
#
#
#             var marker_dd314764fe0378fa10c3cd3afc619413 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4d1f9b3647f5c08a712beb537fa0aaaa);
#
#
#         var popup_86eb62349e890df4c8ab40a15407a6c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ed17a2c468af6e95a2b536813b55e7e = $(`&lt;div id=&quot;html_1ed17a2c468af6e95a2b536813b55e7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_86eb62349e890df4c8ab40a15407a6c9.setContent(html_1ed17a2c468af6e95a2b536813b55e7e);
#
#
#
#         marker_dd314764fe0378fa10c3cd3afc619413.bindPopup(popup_86eb62349e890df4c8ab40a15407a6c9)
#         ;
#
#
#
#
#             var marker_1d0c91d692bfcbdaaaf8a3deb4fdac16 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4d1f9b3647f5c08a712beb537fa0aaaa);
#
#
#         var popup_d9947906c0105470d8a817c9264feb3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da5e70c229657ffd99af754c10e8dfa6 = $(`&lt;div id=&quot;html_da5e70c229657ffd99af754c10e8dfa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d9947906c0105470d8a817c9264feb3a.setContent(html_da5e70c229657ffd99af754c10e8dfa6);
#
#
#
#         marker_1d0c91d692bfcbdaaaf8a3deb4fdac16.bindPopup(popup_d9947906c0105470d8a817c9264feb3a)
#         ;
#
#
#
#
#             var marker_a61c61435a6f0702ae3ea1f1fcc03803 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4d1f9b3647f5c08a712beb537fa0aaaa);
#
#
#         var popup_368438d087d874e07f632d9c4a9adb6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80a3956994c2395999eb3237d83ff60a = $(`&lt;div id=&quot;html_80a3956994c2395999eb3237d83ff60a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_368438d087d874e07f632d9c4a9adb6d.setContent(html_80a3956994c2395999eb3237d83ff60a);
#
#
#
#         marker_
