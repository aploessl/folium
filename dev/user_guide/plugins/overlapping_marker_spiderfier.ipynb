# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa9597046f20dbeb7941c6499a846c9d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa9597046f20dbeb7941c6499a846c9d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa9597046f20dbeb7941c6499a846c9d = L.map(
#                 &quot;map_aa9597046f20dbeb7941c6499a846c9d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7948523b9286a8e364670fb35a99d2ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7948523b9286a8e364670fb35a99d2ec.addTo(map_aa9597046f20dbeb7941c6499a846c9d);
#
#
#             var marker_d2b115db12bc50f21600e57b170baf80 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_aa9597046f20dbeb7941c6499a846c9d);
#
#
#         var popup_85179b5073f9e32299d8d08440352e08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4c5e5f071a37159fdd3fb74a1466a6a = $(`&lt;div id=&quot;html_b4c5e5f071a37159fdd3fb74a1466a6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_85179b5073f9e32299d8d08440352e08.setContent(html_b4c5e5f071a37159fdd3fb74a1466a6a);
#
#
#
#         marker_d2b115db12bc50f21600e57b170baf80.bindPopup(popup_85179b5073f9e32299d8d08440352e08)
#         ;
#
#
#
#
#             var marker_a7312ba6eac00a2416c96ec2d7150223 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_aa9597046f20dbeb7941c6499a846c9d);
#
#
#         var popup_adeb3904999fa330fc57608fbddae7e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c34f4a93eb25fe43bf05d45e539c5242 = $(`&lt;div id=&quot;html_c34f4a93eb25fe43bf05d45e539c5242&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_adeb3904999fa330fc57608fbddae7e3.setContent(html_c34f4a93eb25fe43bf05d45e539c5242);
#
#
#
#         marker_a7312ba6eac00a2416c96ec2d7150223.bindPopup(popup_adeb3904999fa330fc57608fbddae7e3)
#         ;
#
#
#
#
#             var marker_4a5ec6e2cf1bea4e80194e4dc99c6b67 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_aa9597046f20dbeb7941c6499a846c9d);
#
#
#         var popup_2abf1526f7c2204b31557c8833eb5761 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae5eb31bd4a5401ac7e086e7f3f81b11 = $(`&lt;div id=&quot;html_ae5eb31bd4a5401ac7e086e7f3f81b11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2abf1526f7c2204b31557c8833eb5761.setContent(html_ae5eb31bd4a5401ac7e086e7f3f81b11);
#
#
#
#         marker_4a5ec6e2cf1bea4e80194e4dc99c6b67.bindPopup(popup_2abf1526f7c2204b31557c8833eb5761)
#         ;
#
#
#
#
#             var marker_e2bd14fd118c593b2cc7785c120f8180 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_aa9597046f20dbeb7941c6499a846c9d);
#
#
#         var popup_8a2c1637d829fe19b48670224dbc8000 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99847669aa747b8ea9f8db776912d09b = $(`&lt;div id=&quot;html_99847669aa747b8ea9f8db776912d09b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8a2c1637d829fe19b48670224dbc8000.setContent(html_99847669aa747b8ea9f8db776912d09b);
#
#
#
#         marker_e2bd14fd118c593b2cc7785c120f8180.bindPopup(popup_8a2c1637d829fe19b48670224dbc8000)
#         ;
#
#
#
#
#             var marker_65574567c3d9c8b798ab3f7878f091bd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_aa9597046f20dbeb7941c6499a846c9d);
#
#
#         var popup_5e1c7731d40f7353ac8b863b30d8c01a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da671f732a6c8f29cd18cf806413cbe7 = $(`&lt;div id=&quot;html_da671f732a6c8f29cd18cf806413cbe7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5e1c7731d40f7353ac8b863b30d8c01a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8502bbec08cf5c102cb4db49e5678c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8502bbec08cf5c102cb4db49e5678c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8502bbec08cf5c102cb4db49e5678c4 = L.map(
#                 &quot;map_a8502bbec08cf5c102cb4db49e5678c4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20cd3b850465e5e62a570115eb5f558d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_20cd3b850465e5e62a570115eb5f558d.addTo(map_a8502bbec08cf5c102cb4db49e5678c4);
#
#
#             var feature_group_ef0c6573934a82b0eb78810ad9294237 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b76c205d4aff637b2d5f53d13f30ab0a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ef0c6573934a82b0eb78810ad9294237);
#
#
#         var popup_d519da10aca0399807175e76ad8d18e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2dcd02a2c5336dc975e81d8943bb87a8 = $(`&lt;div id=&quot;html_2dcd02a2c5336dc975e81d8943bb87a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d519da10aca0399807175e76ad8d18e8.setContent(html_2dcd02a2c5336dc975e81d8943bb87a8);
#
#
#
#         marker_b76c205d4aff637b2d5f53d13f30ab0a.bindPopup(popup_d519da10aca0399807175e76ad8d18e8)
#         ;
#
#
#
#
#             var marker_660cbe436eb3532fe6b71ac3ac0c07cf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ef0c6573934a82b0eb78810ad9294237);
#
#
#         var popup_d66b6c150dd8ac61d2f360fe35b1a0ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fa1ec7949ff6e2799cc91f0007538e9 = $(`&lt;div id=&quot;html_1fa1ec7949ff6e2799cc91f0007538e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d66b6c150dd8ac61d2f360fe35b1a0ca.setContent(html_1fa1ec7949ff6e2799cc91f0007538e9);
#
#
#
#         marker_660cbe436eb3532fe6b71ac3ac0c07cf.bindPopup(popup_d66b6c150dd8ac61d2f360fe35b1a0ca)
#         ;
#
#
#
#
#             var marker_d2987389b5573311f68b36751615371c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ef0c6573934a82b0eb78810ad9294237);
#
#
#         var popup_a19029dcc5ab0380d99bd7f3509b79d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_906281945eef274d625633324d0169d5 = $(`&lt;div id=&quot;html_906281945eef274d625633324d0169d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a19029dcc5ab0380d99bd7f3509b79d2.setContent(html_906281945eef274d625633324d0169d5);
#
#
#
#         marker_d2987389b5573311f68b36751615371c.bindPopup(popup_a19029dcc5ab0380d99bd7f3509b79d2)
#         ;
#
#
#
#
#             var marker_53a8126603bf5cf824a1d512eeaf5a54 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ef0c6573934a82b0eb78810ad9294237);
#
#
#         var popup_1f4bed7ed55effda2e9f458f3711c936 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb9428da7ea1a6c53fb55ef373563637 = $(`&lt;div id=&quot;html_bb9428da7ea1a6c53fb55ef373563637&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1f4bed7ed55effda2e9f458f3711c936.setContent(html_bb9428da7ea1a6c53fb55ef373563637);
#
#
#
#         marker_53a8126603bf5cf824a1d512eeaf5a54.bindPopup(popup_1f4bed7ed55effda2e9f458f3711c936)
#         ;
#
#
#
#
#             var marker_b9e1ea5874fe07dfbc8849a17374a5f3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ef0c6573934a82b0eb78810ad9294237);
#
#
#         var popup_324c3bf2e1bb92a674d013b02dfe0c2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3fd70c29094419312b302623616ad12 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3fd70c29094419312b302623616ad12&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3fd70c29094419312b302623616ad12 = L.map(
#                 &quot;map_e3fd70c29094419312b302623616ad12&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13cb800c998ac7ba8a96b4df62a689dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_13cb800c998ac7ba8a96b4df62a689dc.addTo(map_e3fd70c29094419312b302623616ad12);
#
#
#             var feature_group_166ac43e63ae753d3386bc79d13e6979 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_166ac43e63ae753d3386bc79d13e6979.addTo(map_e3fd70c29094419312b302623616ad12);
#
#
#             var feature_group_sub_group_db3247e548619e5da0e04ea5c5da3624 = L.featureGroup.subGroup(
#                 feature_group_166ac43e63ae753d3386bc79d13e6979
#             );
#
#
#             var marker_f33148cc5c6ad416b066cff40866c2c1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_db3247e548619e5da0e04ea5c5da3624);
#
#
#         var popup_7631ec5c846075d592ad955ab01f0198 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81c3cc190959f215f7cdcc5835769646 = $(`&lt;div id=&quot;html_81c3cc190959f215f7cdcc5835769646&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7631ec5c846075d592ad955ab01f0198.setContent(html_81c3cc190959f215f7cdcc5835769646);
#
#
#
#         marker_f33148cc5c6ad416b066cff40866c2c1.bindPopup(popup_7631ec5c846075d592ad955ab01f0198)
#         ;
#
#
#
#
#             var marker_5cfe83af27d9bdeb32ce6085c1db3043 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_db3247e548619e5da0e04ea5c5da3624);
#
#
#         var popup_708705729fa5ac699e113a6896306bab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fac917955bc7ca5643a71afa1d929445 = $(`&lt;div id=&quot;html_fac917955bc7ca5643a71afa1d929445&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_708705729fa5ac699e113a6896306bab.setContent(html_fac917955bc7ca5643a71afa1d929445);
#
#
#
#         marker_5cfe83af27d9bdeb32ce6085c1db3043.bindPopup(popup_708705729fa5ac699e113a6896306bab)
#         ;
#
#
#
#
#             var marker_995b891f6387eef18a74c3513da0f597 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_db3247e548619e5da0e04ea5c5da3624);
#
#
#         var popup_a1523a379c7ac6f04800bb20bb7f17ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d29b0179c26f106626e75f50154b4ee5 = $(`&lt;div id=&quot;html_d29b0179c26f106626e75f50154b4ee5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a1523a379c7ac6f04800bb20bb7f17ff.setContent(html_d29b0179c26f106626e75f50154b4ee5);
#
#
#
#         marker_995b891f6387eef18a74c3513da0f597.bindPopup(popup_a1523a379c7ac6f04800bb20bb7f17ff)
#         ;
#
#
#
#
#             var marker_b2383e3fc16f04c39337c32b5ddb5577 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_db3247e548619e5da0e04ea5c5da3624);
#
#
#         var popup_a32ad3b216c684de81706bfa50e29d08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac0c7da06a3a760967518ffab9f5b8f2 = $(`&lt;div id=&quot;html_ac0c7da06a3a760967518ffab9f5b8f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a32ad3b216c684de81706bfa50e29d08.setContent(html_ac0c7da06a3a760967518ffab9f5b8f2);
#
#
#
#         marker_
