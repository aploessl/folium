# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e605f764258b680ff8c43700e6e0924 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e605f764258b680ff8c43700e6e0924&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e605f764258b680ff8c43700e6e0924 = L.map(
#                 &quot;map_2e605f764258b680ff8c43700e6e0924&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d848372b0d5b8d00f0d1678beaad03a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6d848372b0d5b8d00f0d1678beaad03a.addTo(map_2e605f764258b680ff8c43700e6e0924);
#
#
#             var marker_0008ae33d5930df12b86010457b10b04 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2e605f764258b680ff8c43700e6e0924);
#
#
#         var popup_e6b3bd81e07ba5ae6cf128b93f77e2cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a225f4f407066efc27f629df254c75ef = $(`&lt;div id=&quot;html_a225f4f407066efc27f629df254c75ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e6b3bd81e07ba5ae6cf128b93f77e2cc.setContent(html_a225f4f407066efc27f629df254c75ef);
#
#
#
#         marker_0008ae33d5930df12b86010457b10b04.bindPopup(popup_e6b3bd81e07ba5ae6cf128b93f77e2cc)
#         ;
#
#
#
#
#             var marker_21ff792aa04038fb3f3b7b6072210841 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2e605f764258b680ff8c43700e6e0924);
#
#
#         var popup_38f5494b1a58079672ffd27199786e47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e053edb42423f0544281476cc16c3ce = $(`&lt;div id=&quot;html_6e053edb42423f0544281476cc16c3ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_38f5494b1a58079672ffd27199786e47.setContent(html_6e053edb42423f0544281476cc16c3ce);
#
#
#
#         marker_21ff792aa04038fb3f3b7b6072210841.bindPopup(popup_38f5494b1a58079672ffd27199786e47)
#         ;
#
#
#
#
#             var marker_cfadcc0944a9e39b639f181d5584d4c2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2e605f764258b680ff8c43700e6e0924);
#
#
#         var popup_2381c1344172a8c5e9ff1bc9c56445c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d587dbc29f52d1085e47ffaff3f67a4c = $(`&lt;div id=&quot;html_d587dbc29f52d1085e47ffaff3f67a4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2381c1344172a8c5e9ff1bc9c56445c5.setContent(html_d587dbc29f52d1085e47ffaff3f67a4c);
#
#
#
#         marker_cfadcc0944a9e39b639f181d5584d4c2.bindPopup(popup_2381c1344172a8c5e9ff1bc9c56445c5)
#         ;
#
#
#
#
#             var marker_789b4ad33b0982959d2d18804c04950c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2e605f764258b680ff8c43700e6e0924);
#
#
#         var popup_30d5c7370e8f7a28c0102d9431a13aa7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83365d2582db165402674f60b91cf6cf = $(`&lt;div id=&quot;html_83365d2582db165402674f60b91cf6cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_30d5c7370e8f7a28c0102d9431a13aa7.setContent(html_83365d2582db165402674f60b91cf6cf);
#
#
#
#         marker_789b4ad33b0982959d2d18804c04950c.bindPopup(popup_30d5c7370e8f7a28c0102d9431a13aa7)
#         ;
#
#
#
#
#             var marker_2b82d6ca52db4e5414327feb4b71b09f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2e605f764258b680ff8c43700e6e0924);
#
#
#         var popup_063cd211f526fc4edf58c817068a5476 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_804d67535c3dbcd0b4f457c50d698e17 = $(`&lt;div id=&quot;html_804d67535c3dbcd0b4f457c50d698e17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_063cd211f526fc4edf58c817068a5476.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1c50a05c75b1c31ad28db5af9a49542 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1c50a05c75b1c31ad28db5af9a49542&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1c50a05c75b1c31ad28db5af9a49542 = L.map(
#                 &quot;map_a1c50a05c75b1c31ad28db5af9a49542&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f2727ef0d9bd478a9edf0f7e1d1579a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f2727ef0d9bd478a9edf0f7e1d1579a.addTo(map_a1c50a05c75b1c31ad28db5af9a49542);
#
#
#             var feature_group_74382b175db5e3f5c36b0085d65fb823 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9d6aa6babe91093812da15fb5cbf40d5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_74382b175db5e3f5c36b0085d65fb823);
#
#
#         var popup_adfa7367325f7e247d13132018783ff6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8fc66f169dabace18ada46683fb6b57 = $(`&lt;div id=&quot;html_a8fc66f169dabace18ada46683fb6b57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_adfa7367325f7e247d13132018783ff6.setContent(html_a8fc66f169dabace18ada46683fb6b57);
#
#
#
#         marker_9d6aa6babe91093812da15fb5cbf40d5.bindPopup(popup_adfa7367325f7e247d13132018783ff6)
#         ;
#
#
#
#
#             var marker_8cb76503f97ad60f7813a72f3c440cfa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_74382b175db5e3f5c36b0085d65fb823);
#
#
#         var popup_7810045300177457554066626232a4ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfcd43c8bd577ac67d3dc0e416f8d890 = $(`&lt;div id=&quot;html_cfcd43c8bd577ac67d3dc0e416f8d890&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7810045300177457554066626232a4ed.setContent(html_cfcd43c8bd577ac67d3dc0e416f8d890);
#
#
#
#         marker_8cb76503f97ad60f7813a72f3c440cfa.bindPopup(popup_7810045300177457554066626232a4ed)
#         ;
#
#
#
#
#             var marker_563f90f784c6b33ef9e5c811aa331f99 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_74382b175db5e3f5c36b0085d65fb823);
#
#
#         var popup_d67492a003f8bff9fb699451a2ee3c24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ff80b4df4eaaaeb98bc95f484c44c61 = $(`&lt;div id=&quot;html_1ff80b4df4eaaaeb98bc95f484c44c61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d67492a003f8bff9fb699451a2ee3c24.setContent(html_1ff80b4df4eaaaeb98bc95f484c44c61);
#
#
#
#         marker_563f90f784c6b33ef9e5c811aa331f99.bindPopup(popup_d67492a003f8bff9fb699451a2ee3c24)
#         ;
#
#
#
#
#             var marker_0eebcdd7adf13a6557b51ae0b5c070de = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_74382b175db5e3f5c36b0085d65fb823);
#
#
#         var popup_c6ed9402c10c48b503dd545e344483ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4baa82edf53c41c1fded22e94eb73a6c = $(`&lt;div id=&quot;html_4baa82edf53c41c1fded22e94eb73a6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c6ed9402c10c48b503dd545e344483ae.setContent(html_4baa82edf53c41c1fded22e94eb73a6c);
#
#
#
#         marker_0eebcdd7adf13a6557b51ae0b5c070de.bindPopup(popup_c6ed9402c10c48b503dd545e344483ae)
#         ;
#
#
#
#
#             var marker_f634ef2f82cc97b39207d89747cb9839 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_74382b175db5e3f5c36b0085d65fb823);
#
#
#         var popup_dda7d8184340c85a533af3c8a338d1eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40ffd5ebf6090c32da3ec90f19b48832 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40ffd5ebf6090c32da3ec90f19b48832&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40ffd5ebf6090c32da3ec90f19b48832 = L.map(
#                 &quot;map_40ffd5ebf6090c32da3ec90f19b48832&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0aa1d2d60452f0289ccb3bf059484748 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0aa1d2d60452f0289ccb3bf059484748.addTo(map_40ffd5ebf6090c32da3ec90f19b48832);
#
#
#             var feature_group_e281c57995e2d6d6c92a322d322116c9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e281c57995e2d6d6c92a322d322116c9.addTo(map_40ffd5ebf6090c32da3ec90f19b48832);
#
#
#             var feature_group_sub_group_1a8598df65c74353ba63b5143634a0d6 = L.featureGroup.subGroup(
#                 feature_group_e281c57995e2d6d6c92a322d322116c9
#             );
#
#
#             var marker_32214832b7cabe7f5095ed3cc1cf9747 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a8598df65c74353ba63b5143634a0d6);
#
#
#         var popup_e811c80922cc8c6bf8d5c1b6e6da2eef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e5da10135a5c740372f34ca0da933e1 = $(`&lt;div id=&quot;html_1e5da10135a5c740372f34ca0da933e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e811c80922cc8c6bf8d5c1b6e6da2eef.setContent(html_1e5da10135a5c740372f34ca0da933e1);
#
#
#
#         marker_32214832b7cabe7f5095ed3cc1cf9747.bindPopup(popup_e811c80922cc8c6bf8d5c1b6e6da2eef)
#         ;
#
#
#
#
#             var marker_08dac4932c101f2802e45eec5d7daaae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a8598df65c74353ba63b5143634a0d6);
#
#
#         var popup_6420d1f3aa67585bc20758ce26f2f31f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7113f27397879a1e7af10cfcdefe3d16 = $(`&lt;div id=&quot;html_7113f27397879a1e7af10cfcdefe3d16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6420d1f3aa67585bc20758ce26f2f31f.setContent(html_7113f27397879a1e7af10cfcdefe3d16);
#
#
#
#         marker_08dac4932c101f2802e45eec5d7daaae.bindPopup(popup_6420d1f3aa67585bc20758ce26f2f31f)
#         ;
#
#
#
#
#             var marker_77500d6a43304c43e4b38733575b2116 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a8598df65c74353ba63b5143634a0d6);
#
#
#         var popup_137aa1a8f3cbe6831580f2f0fa07f558 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7059e8453e97abe4d1752a60a12ec4f8 = $(`&lt;div id=&quot;html_7059e8453e97abe4d1752a60a12ec4f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_137aa1a8f3cbe6831580f2f0fa07f558.setContent(html_7059e8453e97abe4d1752a60a12ec4f8);
#
#
#
#         marker_77500d6a43304c43e4b38733575b2116.bindPopup(popup_137aa1a8f3cbe6831580f2f0fa07f558)
#         ;
#
#
#
#
#             var marker_b5f9c13560dc8269566e540d660542dc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1a8598df65c74353ba63b5143634a0d6);
#
#
#         var popup_f1d5d30daa67723e18461d5213fed601 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7264466e1ed8354dd04f465009e691dc = $(`&lt;div id=&quot;html_7264466e1ed8354dd04f465009e691dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f1d5d30daa67723e18461d5213fed601.setContent(html_7264466e1ed8354dd04f465009e691dc);
#
#
#
#         marker_
