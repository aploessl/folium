# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1440e57dd07705225fcd94902c06e48c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1440e57dd07705225fcd94902c06e48c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1440e57dd07705225fcd94902c06e48c = L.map(
#                 &quot;map_1440e57dd07705225fcd94902c06e48c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63578b6807bc834b49627f77ab7d1be2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_63578b6807bc834b49627f77ab7d1be2.addTo(map_1440e57dd07705225fcd94902c06e48c);
#
#
#             var marker_bb4762dd57c5153b7c9c07d767d15705 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1440e57dd07705225fcd94902c06e48c);
#
#
#         var popup_47ea83e6adfeb3850b808b490cc866aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea308f3d780d1083a996efdc56ae9fd3 = $(`&lt;div id=&quot;html_ea308f3d780d1083a996efdc56ae9fd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_47ea83e6adfeb3850b808b490cc866aa.setContent(html_ea308f3d780d1083a996efdc56ae9fd3);
#
#
#
#         marker_bb4762dd57c5153b7c9c07d767d15705.bindPopup(popup_47ea83e6adfeb3850b808b490cc866aa)
#         ;
#
#
#
#
#             var marker_74cb15bdb73d3c31eff19d677974a58e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1440e57dd07705225fcd94902c06e48c);
#
#
#         var popup_e999a7f11fe73b6d1384e26c43a3245f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a30686e7d5459ed1653485b60313b04 = $(`&lt;div id=&quot;html_9a30686e7d5459ed1653485b60313b04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e999a7f11fe73b6d1384e26c43a3245f.setContent(html_9a30686e7d5459ed1653485b60313b04);
#
#
#
#         marker_74cb15bdb73d3c31eff19d677974a58e.bindPopup(popup_e999a7f11fe73b6d1384e26c43a3245f)
#         ;
#
#
#
#
#             var marker_482f61af07a6996861e5f816064423a3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1440e57dd07705225fcd94902c06e48c);
#
#
#         var popup_5a4f84d9b83215188499c35fc914c42c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdd72a9c214bacbc3c0a2daf592bf3c5 = $(`&lt;div id=&quot;html_bdd72a9c214bacbc3c0a2daf592bf3c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5a4f84d9b83215188499c35fc914c42c.setContent(html_bdd72a9c214bacbc3c0a2daf592bf3c5);
#
#
#
#         marker_482f61af07a6996861e5f816064423a3.bindPopup(popup_5a4f84d9b83215188499c35fc914c42c)
#         ;
#
#
#
#
#             var marker_39cb3a517f1f8e7235053ed07ca7de61 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1440e57dd07705225fcd94902c06e48c);
#
#
#         var popup_6be2d4cc3c1de06b27c13f03f7ad2b10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dd214e8a06d41fe9f1fa62959609b41 = $(`&lt;div id=&quot;html_0dd214e8a06d41fe9f1fa62959609b41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6be2d4cc3c1de06b27c13f03f7ad2b10.setContent(html_0dd214e8a06d41fe9f1fa62959609b41);
#
#
#
#         marker_39cb3a517f1f8e7235053ed07ca7de61.bindPopup(popup_6be2d4cc3c1de06b27c13f03f7ad2b10)
#         ;
#
#
#
#
#             var marker_9379af34c9a0d12c874ac83c4a9ada0e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1440e57dd07705225fcd94902c06e48c);
#
#
#         var popup_7ba83413c0357d73b24b494c4a6499db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b4322d62d7be60f0e8d9509a13001a2 = $(`&lt;div id=&quot;html_1b4322d62d7be60f0e8d9509a13001a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7ba83413c0357d73b24b494c4a6499db.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f36d1ab21a07692ac2ad4db810e6b70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f36d1ab21a07692ac2ad4db810e6b70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f36d1ab21a07692ac2ad4db810e6b70 = L.map(
#                 &quot;map_3f36d1ab21a07692ac2ad4db810e6b70&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5f0cd395e428acb531a5d444b814fd8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c5f0cd395e428acb531a5d444b814fd8.addTo(map_3f36d1ab21a07692ac2ad4db810e6b70);
#
#
#             var feature_group_10a693850109af436b8456c3ec8acbf4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4e3864210a011d9a41b173cb2e60cd36 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_10a693850109af436b8456c3ec8acbf4);
#
#
#         var popup_e6843c81a22bec76b00d2cabc2ee599d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed409ed7936a63cd04b92ec55f986228 = $(`&lt;div id=&quot;html_ed409ed7936a63cd04b92ec55f986228&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e6843c81a22bec76b00d2cabc2ee599d.setContent(html_ed409ed7936a63cd04b92ec55f986228);
#
#
#
#         marker_4e3864210a011d9a41b173cb2e60cd36.bindPopup(popup_e6843c81a22bec76b00d2cabc2ee599d)
#         ;
#
#
#
#
#             var marker_f2f6b88aa9714c3cb07fa646ab8f4a8a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_10a693850109af436b8456c3ec8acbf4);
#
#
#         var popup_5df591d6adf378198fc496793bb1c7ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f20238d1edb80a0f1eb88a011c48d3e7 = $(`&lt;div id=&quot;html_f20238d1edb80a0f1eb88a011c48d3e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5df591d6adf378198fc496793bb1c7ac.setContent(html_f20238d1edb80a0f1eb88a011c48d3e7);
#
#
#
#         marker_f2f6b88aa9714c3cb07fa646ab8f4a8a.bindPopup(popup_5df591d6adf378198fc496793bb1c7ac)
#         ;
#
#
#
#
#             var marker_7a080cd27341c4732ec8e31f6d3644b4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_10a693850109af436b8456c3ec8acbf4);
#
#
#         var popup_d0de2c5efa0dd0c3fdbe680753579a12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74f1046bfe1025668b856507b0379953 = $(`&lt;div id=&quot;html_74f1046bfe1025668b856507b0379953&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d0de2c5efa0dd0c3fdbe680753579a12.setContent(html_74f1046bfe1025668b856507b0379953);
#
#
#
#         marker_7a080cd27341c4732ec8e31f6d3644b4.bindPopup(popup_d0de2c5efa0dd0c3fdbe680753579a12)
#         ;
#
#
#
#
#             var marker_5bf6535cca4bfcbc0052aa94052c916e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_10a693850109af436b8456c3ec8acbf4);
#
#
#         var popup_7077d7928d9406257ad7cfbb5109f683 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c90605c34fbdabc806d7b16d19d0143 = $(`&lt;div id=&quot;html_7c90605c34fbdabc806d7b16d19d0143&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7077d7928d9406257ad7cfbb5109f683.setContent(html_7c90605c34fbdabc806d7b16d19d0143);
#
#
#
#         marker_5bf6535cca4bfcbc0052aa94052c916e.bindPopup(popup_7077d7928d9406257ad7cfbb5109f683)
#         ;
#
#
#
#
#             var marker_14059ffbc6e00152c877625c406e26ba = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_10a693850109af436b8456c3ec8acbf4);
#
#
#         var popup_e564d2ef70aa4bbfc9f8322c38c39bef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_614ccbd1fef3937309ae36f2b411f998 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_614ccbd1fef3937309ae36f2b411f998&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_614ccbd1fef3937309ae36f2b411f998 = L.map(
#                 &quot;map_614ccbd1fef3937309ae36f2b411f998&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa4dfe9f130cd5a71e65e9e2221f76fc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aa4dfe9f130cd5a71e65e9e2221f76fc.addTo(map_614ccbd1fef3937309ae36f2b411f998);
#
#
#             var feature_group_d3185d722450aa0d669a168012f67979 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d3185d722450aa0d669a168012f67979.addTo(map_614ccbd1fef3937309ae36f2b411f998);
#
#
#             var feature_group_sub_group_e577e3fdd6d738b6625a7c4c91ffdf4d = L.featureGroup.subGroup(
#                 feature_group_d3185d722450aa0d669a168012f67979
#             );
#
#
#             var marker_80ca8c8da6cb898dc55d9d80d817f3b3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e577e3fdd6d738b6625a7c4c91ffdf4d);
#
#
#         var popup_ae847d047412b361573a7f9478b5ad97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68136c4e38c7ec071d2dd9f9fe1a9c62 = $(`&lt;div id=&quot;html_68136c4e38c7ec071d2dd9f9fe1a9c62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ae847d047412b361573a7f9478b5ad97.setContent(html_68136c4e38c7ec071d2dd9f9fe1a9c62);
#
#
#
#         marker_80ca8c8da6cb898dc55d9d80d817f3b3.bindPopup(popup_ae847d047412b361573a7f9478b5ad97)
#         ;
#
#
#
#
#             var marker_c622464764c00ba2853fa9d587c6d180 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e577e3fdd6d738b6625a7c4c91ffdf4d);
#
#
#         var popup_fce5d51289bcc806a6f37f19a9f9edde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0e1e5d5a458f22aaa63f28d96b16eb9 = $(`&lt;div id=&quot;html_b0e1e5d5a458f22aaa63f28d96b16eb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fce5d51289bcc806a6f37f19a9f9edde.setContent(html_b0e1e5d5a458f22aaa63f28d96b16eb9);
#
#
#
#         marker_c622464764c00ba2853fa9d587c6d180.bindPopup(popup_fce5d51289bcc806a6f37f19a9f9edde)
#         ;
#
#
#
#
#             var marker_9c969a9891b2c1691c40b42bd9f98560 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e577e3fdd6d738b6625a7c4c91ffdf4d);
#
#
#         var popup_14b83973ab1503a9025795869989ba8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3cea7bfd3bc21272c599940105fbd8c = $(`&lt;div id=&quot;html_f3cea7bfd3bc21272c599940105fbd8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_14b83973ab1503a9025795869989ba8c.setContent(html_f3cea7bfd3bc21272c599940105fbd8c);
#
#
#
#         marker_9c969a9891b2c1691c40b42bd9f98560.bindPopup(popup_14b83973ab1503a9025795869989ba8c)
#         ;
#
#
#
#
#             var marker_ba26289eb80a69bb594b1b6bf69b465c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e577e3fdd6d738b6625a7c4c91ffdf4d);
#
#
#         var popup_02faad256edecaaea33e632c5c55f5b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c87356d646f5e2ddb45fbdb7fdda7951 = $(`&lt;div id=&quot;html_c87356d646f5e2ddb45fbdb7fdda7951&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_02faad256edecaaea33e632c5c55f5b3.setContent(html_c87356d646f5e2ddb45fbdb7fdda7951);
#
#
#
#         marker_
