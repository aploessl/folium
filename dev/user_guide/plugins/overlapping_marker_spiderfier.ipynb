# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2079a4b8bea3f73edb60307aea5d67d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2079a4b8bea3f73edb60307aea5d67d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2079a4b8bea3f73edb60307aea5d67d = L.map(
#                 &quot;map_b2079a4b8bea3f73edb60307aea5d67d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da9fb2d41e6d4e0fc306093b1d173b34 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_da9fb2d41e6d4e0fc306093b1d173b34.addTo(map_b2079a4b8bea3f73edb60307aea5d67d);
#
#
#             var marker_8f2852bcaa112f37960536ac216587af = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b2079a4b8bea3f73edb60307aea5d67d);
#
#
#         var popup_218c9f368d165f0793ebb6de895ba665 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_494bfa6778300bac652f0181fd4c7877 = $(`&lt;div id=&quot;html_494bfa6778300bac652f0181fd4c7877&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_218c9f368d165f0793ebb6de895ba665.setContent(html_494bfa6778300bac652f0181fd4c7877);
#
#
#
#         marker_8f2852bcaa112f37960536ac216587af.bindPopup(popup_218c9f368d165f0793ebb6de895ba665)
#         ;
#
#
#
#
#             var marker_f62e120e9d984e49540510c437551013 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b2079a4b8bea3f73edb60307aea5d67d);
#
#
#         var popup_2506d1dac08f1d80a241dc50b8ea64db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d45331f302cfb006cdeee066c7ce81d5 = $(`&lt;div id=&quot;html_d45331f302cfb006cdeee066c7ce81d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2506d1dac08f1d80a241dc50b8ea64db.setContent(html_d45331f302cfb006cdeee066c7ce81d5);
#
#
#
#         marker_f62e120e9d984e49540510c437551013.bindPopup(popup_2506d1dac08f1d80a241dc50b8ea64db)
#         ;
#
#
#
#
#             var marker_6695b44484381c9ca589dc4cbfb36172 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b2079a4b8bea3f73edb60307aea5d67d);
#
#
#         var popup_268283f8480f09b53d0abdb4f4c51f53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43df87a9c842338ead49a21ab521a879 = $(`&lt;div id=&quot;html_43df87a9c842338ead49a21ab521a879&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_268283f8480f09b53d0abdb4f4c51f53.setContent(html_43df87a9c842338ead49a21ab521a879);
#
#
#
#         marker_6695b44484381c9ca589dc4cbfb36172.bindPopup(popup_268283f8480f09b53d0abdb4f4c51f53)
#         ;
#
#
#
#
#             var marker_ff954f297fe41d1fc74e0f7b0a197d9d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b2079a4b8bea3f73edb60307aea5d67d);
#
#
#         var popup_672e60a68194dc65cf27432b859c00ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0addf99c6f15ca85c51a453a3238a61 = $(`&lt;div id=&quot;html_a0addf99c6f15ca85c51a453a3238a61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_672e60a68194dc65cf27432b859c00ab.setContent(html_a0addf99c6f15ca85c51a453a3238a61);
#
#
#
#         marker_ff954f297fe41d1fc74e0f7b0a197d9d.bindPopup(popup_672e60a68194dc65cf27432b859c00ab)
#         ;
#
#
#
#
#             var marker_eb53fc4c14351f84983093b9a26d62f5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b2079a4b8bea3f73edb60307aea5d67d);
#
#
#         var popup_a77af1f110a721005bb150ec00b0d0f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d943076ba828c7554743756137c4165 = $(`&lt;div id=&quot;html_7d943076ba828c7554743756137c4165&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a77af1f110a721005bb150ec00b0d0f6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a635d7c662a55294b7e69a9054e45a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a635d7c662a55294b7e69a9054e45a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a635d7c662a55294b7e69a9054e45a5 = L.map(
#                 &quot;map_6a635d7c662a55294b7e69a9054e45a5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1bf99953fe6087ee3266cc5cafcbc33d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1bf99953fe6087ee3266cc5cafcbc33d.addTo(map_6a635d7c662a55294b7e69a9054e45a5);
#
#
#             var feature_group_c12e93253bdf95cdb7fc08b013b75c31 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d5858745e6c7dc30eccafae09d4dbe5f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c12e93253bdf95cdb7fc08b013b75c31);
#
#
#         var popup_7c5c8e08de08e297e7b184b6f9177039 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12389370a0ab36c39b78653fbcd9f6a4 = $(`&lt;div id=&quot;html_12389370a0ab36c39b78653fbcd9f6a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7c5c8e08de08e297e7b184b6f9177039.setContent(html_12389370a0ab36c39b78653fbcd9f6a4);
#
#
#
#         marker_d5858745e6c7dc30eccafae09d4dbe5f.bindPopup(popup_7c5c8e08de08e297e7b184b6f9177039)
#         ;
#
#
#
#
#             var marker_b64a557f6439fdb1f5461c52bb6e35b1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c12e93253bdf95cdb7fc08b013b75c31);
#
#
#         var popup_fcf685e414b4e79a6c028866aeb353e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54eefceb10f93214af56af67983273c4 = $(`&lt;div id=&quot;html_54eefceb10f93214af56af67983273c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fcf685e414b4e79a6c028866aeb353e6.setContent(html_54eefceb10f93214af56af67983273c4);
#
#
#
#         marker_b64a557f6439fdb1f5461c52bb6e35b1.bindPopup(popup_fcf685e414b4e79a6c028866aeb353e6)
#         ;
#
#
#
#
#             var marker_8e48a7754ddbd5ccf5ae121360cf8539 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c12e93253bdf95cdb7fc08b013b75c31);
#
#
#         var popup_a5ad9b24ae95ce4493205b2e112fda5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dde40a6a8cf2f8ba5e52a173d8879d72 = $(`&lt;div id=&quot;html_dde40a6a8cf2f8ba5e52a173d8879d72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a5ad9b24ae95ce4493205b2e112fda5c.setContent(html_dde40a6a8cf2f8ba5e52a173d8879d72);
#
#
#
#         marker_8e48a7754ddbd5ccf5ae121360cf8539.bindPopup(popup_a5ad9b24ae95ce4493205b2e112fda5c)
#         ;
#
#
#
#
#             var marker_f7aa679fe5ee4b7293763512dad33654 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c12e93253bdf95cdb7fc08b013b75c31);
#
#
#         var popup_36d157eb0c614f26994b25d33383587d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0aa5672dcbe561fe33714e2ea91a3f7 = $(`&lt;div id=&quot;html_a0aa5672dcbe561fe33714e2ea91a3f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_36d157eb0c614f26994b25d33383587d.setContent(html_a0aa5672dcbe561fe33714e2ea91a3f7);
#
#
#
#         marker_f7aa679fe5ee4b7293763512dad33654.bindPopup(popup_36d157eb0c614f26994b25d33383587d)
#         ;
#
#
#
#
#             var marker_1049ea78d74418bdb196b27640706545 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c12e93253bdf95cdb7fc08b013b75c31);
#
#
#         var popup_c406b4d8664ba9388cf59649f70728a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eed4f758949151a451d46e25923fe1e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eed4f758949151a451d46e25923fe1e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eed4f758949151a451d46e25923fe1e7 = L.map(
#                 &quot;map_eed4f758949151a451d46e25923fe1e7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70a6784579d5421ae0d95d57c97ff38c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70a6784579d5421ae0d95d57c97ff38c.addTo(map_eed4f758949151a451d46e25923fe1e7);
#
#
#             var feature_group_915d7fcf6d15480f6f5e65e97d7a3c05 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_915d7fcf6d15480f6f5e65e97d7a3c05.addTo(map_eed4f758949151a451d46e25923fe1e7);
#
#
#             var feature_group_sub_group_1bb451d25b71b3136acd73587f2494d0 = L.featureGroup.subGroup(
#                 feature_group_915d7fcf6d15480f6f5e65e97d7a3c05
#             );
#
#
#             var marker_403b11eca84d3bd51a9675d83940b360 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1bb451d25b71b3136acd73587f2494d0);
#
#
#         var popup_6866c33190b874d697bdef663c73ac60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_106772d38ab20b9a60304ff43e4ffd25 = $(`&lt;div id=&quot;html_106772d38ab20b9a60304ff43e4ffd25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6866c33190b874d697bdef663c73ac60.setContent(html_106772d38ab20b9a60304ff43e4ffd25);
#
#
#
#         marker_403b11eca84d3bd51a9675d83940b360.bindPopup(popup_6866c33190b874d697bdef663c73ac60)
#         ;
#
#
#
#
#             var marker_d1c5bf309f4a4dcad5490f25a5da8bc2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1bb451d25b71b3136acd73587f2494d0);
#
#
#         var popup_0681aba993aa854c3c44f9f84be0e07c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dea7b285f525802647df9eab3b7b1ea = $(`&lt;div id=&quot;html_9dea7b285f525802647df9eab3b7b1ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0681aba993aa854c3c44f9f84be0e07c.setContent(html_9dea7b285f525802647df9eab3b7b1ea);
#
#
#
#         marker_d1c5bf309f4a4dcad5490f25a5da8bc2.bindPopup(popup_0681aba993aa854c3c44f9f84be0e07c)
#         ;
#
#
#
#
#             var marker_a7adc83d6ec63b1fcb185255984f9b3c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1bb451d25b71b3136acd73587f2494d0);
#
#
#         var popup_26b87be7412609b3ac8c7515b5c1b08f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1193208fef63ffb5da78eadc96b25d8 = $(`&lt;div id=&quot;html_f1193208fef63ffb5da78eadc96b25d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_26b87be7412609b3ac8c7515b5c1b08f.setContent(html_f1193208fef63ffb5da78eadc96b25d8);
#
#
#
#         marker_a7adc83d6ec63b1fcb185255984f9b3c.bindPopup(popup_26b87be7412609b3ac8c7515b5c1b08f)
#         ;
#
#
#
#
#             var marker_99cf95ac317c209208291462bc6a9126 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1bb451d25b71b3136acd73587f2494d0);
#
#
#         var popup_d2523d66be6ac34ceb0a96f0a89939c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d826467f9d6d12a8fc96377b156a4f1 = $(`&lt;div id=&quot;html_0d826467f9d6d12a8fc96377b156a4f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d2523d66be6ac34ceb0a96f0a89939c2.setContent(html_0d826467f9d6d12a8fc96377b156a4f1);
#
#
#
#         marker_
