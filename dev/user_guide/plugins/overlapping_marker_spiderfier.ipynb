# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b80f2e593ffb6a694d9828767118cccf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b80f2e593ffb6a694d9828767118cccf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b80f2e593ffb6a694d9828767118cccf = L.map(
#                 &quot;map_b80f2e593ffb6a694d9828767118cccf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1f188e305546b5cdcc5f95f60a2195d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b1f188e305546b5cdcc5f95f60a2195d.addTo(map_b80f2e593ffb6a694d9828767118cccf);
#
#
#             var marker_d1338821405ca60bce0a389a3263142b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b80f2e593ffb6a694d9828767118cccf);
#
#
#         var popup_812c1561f16b5a1e5d0b8129672ca21d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed3f3fc91ff39ceda11394b982608c59 = $(`&lt;div id=&quot;html_ed3f3fc91ff39ceda11394b982608c59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_812c1561f16b5a1e5d0b8129672ca21d.setContent(html_ed3f3fc91ff39ceda11394b982608c59);
#
#
#
#         marker_d1338821405ca60bce0a389a3263142b.bindPopup(popup_812c1561f16b5a1e5d0b8129672ca21d)
#         ;
#
#
#
#
#             var marker_15466fbd995b85674c46f266d76c89ee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b80f2e593ffb6a694d9828767118cccf);
#
#
#         var popup_f6920ffc1d5782ed20d7c2c207d6f589 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0034753a81a4969eb39b9ab026e5009 = $(`&lt;div id=&quot;html_b0034753a81a4969eb39b9ab026e5009&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f6920ffc1d5782ed20d7c2c207d6f589.setContent(html_b0034753a81a4969eb39b9ab026e5009);
#
#
#
#         marker_15466fbd995b85674c46f266d76c89ee.bindPopup(popup_f6920ffc1d5782ed20d7c2c207d6f589)
#         ;
#
#
#
#
#             var marker_2351038f10dadb35f0c9a7427fb11287 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b80f2e593ffb6a694d9828767118cccf);
#
#
#         var popup_1da16f87885ce41ae1921bcc77ae4d81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b238a030d2b8e97be3014c7066e4337 = $(`&lt;div id=&quot;html_7b238a030d2b8e97be3014c7066e4337&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1da16f87885ce41ae1921bcc77ae4d81.setContent(html_7b238a030d2b8e97be3014c7066e4337);
#
#
#
#         marker_2351038f10dadb35f0c9a7427fb11287.bindPopup(popup_1da16f87885ce41ae1921bcc77ae4d81)
#         ;
#
#
#
#
#             var marker_aecad8b88a6f1014ba047cd556927066 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b80f2e593ffb6a694d9828767118cccf);
#
#
#         var popup_f44fbf7f287c03666b6f38c47cf0a866 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0597a42348eaff72b8a16a0ed6ca2dcb = $(`&lt;div id=&quot;html_0597a42348eaff72b8a16a0ed6ca2dcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f44fbf7f287c03666b6f38c47cf0a866.setContent(html_0597a42348eaff72b8a16a0ed6ca2dcb);
#
#
#
#         marker_aecad8b88a6f1014ba047cd556927066.bindPopup(popup_f44fbf7f287c03666b6f38c47cf0a866)
#         ;
#
#
#
#
#             var marker_4ead68d87a3169ef1600f6eeb7c75bfe = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b80f2e593ffb6a694d9828767118cccf);
#
#
#         var popup_652bb726905b3130ad4b3e42f6b60ccf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_660b60f44d6c1fa8a15760bbd928e1ad = $(`&lt;div id=&quot;html_660b60f44d6c1fa8a15760bbd928e1ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_652bb726905b3130ad4b3e42f6b60ccf.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e57d035bc40a9ed555b4e880974aa82 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e57d035bc40a9ed555b4e880974aa82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e57d035bc40a9ed555b4e880974aa82 = L.map(
#                 &quot;map_2e57d035bc40a9ed555b4e880974aa82&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c51b3edf6eb551fb415c938652bd796 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c51b3edf6eb551fb415c938652bd796.addTo(map_2e57d035bc40a9ed555b4e880974aa82);
#
#
#             var feature_group_b2004dcabd73958fad7b61217ceef492 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5e82114fbfbf8a5efa0ce1f7cd3e04cc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b2004dcabd73958fad7b61217ceef492);
#
#
#         var popup_cf88fe09a446aee479403b311f3984c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f409299a068a7e16ac553735a7e86ba = $(`&lt;div id=&quot;html_0f409299a068a7e16ac553735a7e86ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cf88fe09a446aee479403b311f3984c8.setContent(html_0f409299a068a7e16ac553735a7e86ba);
#
#
#
#         marker_5e82114fbfbf8a5efa0ce1f7cd3e04cc.bindPopup(popup_cf88fe09a446aee479403b311f3984c8)
#         ;
#
#
#
#
#             var marker_ba90893c9a07e6c5db31535bb04ef8c6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b2004dcabd73958fad7b61217ceef492);
#
#
#         var popup_b0d7aba2e6e7aa7efb5bc112aa5dfeb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_809f23ff7ca4edf81f31061e2e0a66d7 = $(`&lt;div id=&quot;html_809f23ff7ca4edf81f31061e2e0a66d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b0d7aba2e6e7aa7efb5bc112aa5dfeb1.setContent(html_809f23ff7ca4edf81f31061e2e0a66d7);
#
#
#
#         marker_ba90893c9a07e6c5db31535bb04ef8c6.bindPopup(popup_b0d7aba2e6e7aa7efb5bc112aa5dfeb1)
#         ;
#
#
#
#
#             var marker_90c4df6ab13ed0a3ae674c67d18ad85a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b2004dcabd73958fad7b61217ceef492);
#
#
#         var popup_6117c0c024b83c1fd725f41cb8cba37f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0be3c5452a6a57d3475219f46173e778 = $(`&lt;div id=&quot;html_0be3c5452a6a57d3475219f46173e778&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6117c0c024b83c1fd725f41cb8cba37f.setContent(html_0be3c5452a6a57d3475219f46173e778);
#
#
#
#         marker_90c4df6ab13ed0a3ae674c67d18ad85a.bindPopup(popup_6117c0c024b83c1fd725f41cb8cba37f)
#         ;
#
#
#
#
#             var marker_cbb8db54a0b28a571f79e782ea69c9e7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b2004dcabd73958fad7b61217ceef492);
#
#
#         var popup_4cf8c281f71f7374c609e55eb18d78ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47caf83ba798dab1b175d789079b0e88 = $(`&lt;div id=&quot;html_47caf83ba798dab1b175d789079b0e88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4cf8c281f71f7374c609e55eb18d78ba.setContent(html_47caf83ba798dab1b175d789079b0e88);
#
#
#
#         marker_cbb8db54a0b28a571f79e782ea69c9e7.bindPopup(popup_4cf8c281f71f7374c609e55eb18d78ba)
#         ;
#
#
#
#
#             var marker_000e756f9882fcb9492bd95869b1d3db = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b2004dcabd73958fad7b61217ceef492);
#
#
#         var popup_3215b600a056551df6bce1265544a31e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cc63d5c971035f81ce0d9696c5eae61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cc63d5c971035f81ce0d9696c5eae61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cc63d5c971035f81ce0d9696c5eae61 = L.map(
#                 &quot;map_1cc63d5c971035f81ce0d9696c5eae61&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f01648e5e54a7f97c500798fd329e00 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f01648e5e54a7f97c500798fd329e00.addTo(map_1cc63d5c971035f81ce0d9696c5eae61);
#
#
#             var feature_group_59a1491631ab56eea4a72bcab6cc64fe = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_59a1491631ab56eea4a72bcab6cc64fe.addTo(map_1cc63d5c971035f81ce0d9696c5eae61);
#
#
#             var feature_group_sub_group_9636a9695b21761fe48b466f9678e1b8 = L.featureGroup.subGroup(
#                 feature_group_59a1491631ab56eea4a72bcab6cc64fe
#             );
#
#
#             var marker_f4f20d6d7f298ee2df056d890438166d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9636a9695b21761fe48b466f9678e1b8);
#
#
#         var popup_4210af04ac90717f446a480bd9994ab1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_787f8bf7e437f2337d746b07e9d8fab9 = $(`&lt;div id=&quot;html_787f8bf7e437f2337d746b07e9d8fab9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4210af04ac90717f446a480bd9994ab1.setContent(html_787f8bf7e437f2337d746b07e9d8fab9);
#
#
#
#         marker_f4f20d6d7f298ee2df056d890438166d.bindPopup(popup_4210af04ac90717f446a480bd9994ab1)
#         ;
#
#
#
#
#             var marker_0e599789246af1db3d52d38b09e5628b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9636a9695b21761fe48b466f9678e1b8);
#
#
#         var popup_a39613e6a2ac91324a7c5c9992b78cae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf7f9b6e61246bd85d31904e82c78f3a = $(`&lt;div id=&quot;html_cf7f9b6e61246bd85d31904e82c78f3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a39613e6a2ac91324a7c5c9992b78cae.setContent(html_cf7f9b6e61246bd85d31904e82c78f3a);
#
#
#
#         marker_0e599789246af1db3d52d38b09e5628b.bindPopup(popup_a39613e6a2ac91324a7c5c9992b78cae)
#         ;
#
#
#
#
#             var marker_18b1da7485393f3a4542e9f4550ecb7f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9636a9695b21761fe48b466f9678e1b8);
#
#
#         var popup_9858e87db9db59ee177d66f67a2a4b15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d76a472e961e557fa11e1bb080c446dd = $(`&lt;div id=&quot;html_d76a472e961e557fa11e1bb080c446dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9858e87db9db59ee177d66f67a2a4b15.setContent(html_d76a472e961e557fa11e1bb080c446dd);
#
#
#
#         marker_18b1da7485393f3a4542e9f4550ecb7f.bindPopup(popup_9858e87db9db59ee177d66f67a2a4b15)
#         ;
#
#
#
#
#             var marker_4234cf9aa6872b9996ba527ef50f707e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9636a9695b21761fe48b466f9678e1b8);
#
#
#         var popup_c3185ccebc6d2dfdc9995e57a58f3a20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7ae322b26d523cf19f79fa12125731d = $(`&lt;div id=&quot;html_a7ae322b26d523cf19f79fa12125731d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c3185ccebc6d2dfdc9995e57a58f3a20.setContent(html_a7ae322b26d523cf19f79fa12125731d);
#
#
#
#         marker_
