# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cbfa9fbedf1059f4f95ca8c7e8836f91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cbfa9fbedf1059f4f95ca8c7e8836f91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cbfa9fbedf1059f4f95ca8c7e8836f91 = L.map(
#                 &quot;map_cbfa9fbedf1059f4f95ca8c7e8836f91&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_555c5425410a6e382d2359a92194766a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_555c5425410a6e382d2359a92194766a.addTo(map_cbfa9fbedf1059f4f95ca8c7e8836f91);
#
#
#             var marker_48764526a04909feb219adea81447e7c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cbfa9fbedf1059f4f95ca8c7e8836f91);
#
#
#         var popup_fe0756120bf7d2b0c90f6daa85bce1b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92036e0a57ea8526721b4bcc1b85a716 = $(`&lt;div id=&quot;html_92036e0a57ea8526721b4bcc1b85a716&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fe0756120bf7d2b0c90f6daa85bce1b1.setContent(html_92036e0a57ea8526721b4bcc1b85a716);
#
#
#
#         marker_48764526a04909feb219adea81447e7c.bindPopup(popup_fe0756120bf7d2b0c90f6daa85bce1b1)
#         ;
#
#
#
#
#             var marker_0f98ffcb9260aabc914525afd4f041a5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cbfa9fbedf1059f4f95ca8c7e8836f91);
#
#
#         var popup_1f2e275f643b515f25bd8536621a198a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc11e9f461ff464b37c4a00e014be5f1 = $(`&lt;div id=&quot;html_fc11e9f461ff464b37c4a00e014be5f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1f2e275f643b515f25bd8536621a198a.setContent(html_fc11e9f461ff464b37c4a00e014be5f1);
#
#
#
#         marker_0f98ffcb9260aabc914525afd4f041a5.bindPopup(popup_1f2e275f643b515f25bd8536621a198a)
#         ;
#
#
#
#
#             var marker_a46fc50e78783c01005a1ba3a746b155 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cbfa9fbedf1059f4f95ca8c7e8836f91);
#
#
#         var popup_1a92743d3931bc592ef8e190ef41df31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26d2fd2fd08dc3ba726e8efe7357cfd2 = $(`&lt;div id=&quot;html_26d2fd2fd08dc3ba726e8efe7357cfd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1a92743d3931bc592ef8e190ef41df31.setContent(html_26d2fd2fd08dc3ba726e8efe7357cfd2);
#
#
#
#         marker_a46fc50e78783c01005a1ba3a746b155.bindPopup(popup_1a92743d3931bc592ef8e190ef41df31)
#         ;
#
#
#
#
#             var marker_b7f3f2e63467d89350da00aee66ec427 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cbfa9fbedf1059f4f95ca8c7e8836f91);
#
#
#         var popup_067443b2009b98bce12bac3f1c3e149e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c8f2cdbaabf5900798f0dad9ec0280f = $(`&lt;div id=&quot;html_6c8f2cdbaabf5900798f0dad9ec0280f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_067443b2009b98bce12bac3f1c3e149e.setContent(html_6c8f2cdbaabf5900798f0dad9ec0280f);
#
#
#
#         marker_b7f3f2e63467d89350da00aee66ec427.bindPopup(popup_067443b2009b98bce12bac3f1c3e149e)
#         ;
#
#
#
#
#             var marker_58763e55beae45c47414d98ee1f3d663 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cbfa9fbedf1059f4f95ca8c7e8836f91);
#
#
#         var popup_75eeaa063c1c374175c87b3869522a7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29fdf7e5a10deeddb9c1f9dd2615facb = $(`&lt;div id=&quot;html_29fdf7e5a10deeddb9c1f9dd2615facb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_75eeaa063c1c374175c87b3869522a7b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_175919df9b805de69eba2ee6346eff37 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_175919df9b805de69eba2ee6346eff37&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_175919df9b805de69eba2ee6346eff37 = L.map(
#                 &quot;map_175919df9b805de69eba2ee6346eff37&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29be2eb47e1b7703a75dbf5b1168697b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_29be2eb47e1b7703a75dbf5b1168697b.addTo(map_175919df9b805de69eba2ee6346eff37);
#
#
#             var feature_group_e27baa27de153ec37ef6f87a96453bc9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_246c4f8fc49b1ef80aaffb3ed222bbad = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e27baa27de153ec37ef6f87a96453bc9);
#
#
#         var popup_e9963ac1ccbb090af780a4fbde427654 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4149e3cddac8d170c50217fc3a7ae35 = $(`&lt;div id=&quot;html_f4149e3cddac8d170c50217fc3a7ae35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e9963ac1ccbb090af780a4fbde427654.setContent(html_f4149e3cddac8d170c50217fc3a7ae35);
#
#
#
#         marker_246c4f8fc49b1ef80aaffb3ed222bbad.bindPopup(popup_e9963ac1ccbb090af780a4fbde427654)
#         ;
#
#
#
#
#             var marker_4e634660e12d61c869c4ef0b794c31c0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e27baa27de153ec37ef6f87a96453bc9);
#
#
#         var popup_a74281702ab4e10c891960950a5e940e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddbee0c2e76f3e860c50c24851d6a44d = $(`&lt;div id=&quot;html_ddbee0c2e76f3e860c50c24851d6a44d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a74281702ab4e10c891960950a5e940e.setContent(html_ddbee0c2e76f3e860c50c24851d6a44d);
#
#
#
#         marker_4e634660e12d61c869c4ef0b794c31c0.bindPopup(popup_a74281702ab4e10c891960950a5e940e)
#         ;
#
#
#
#
#             var marker_fbaf385deb8672b052789d9e25312c61 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e27baa27de153ec37ef6f87a96453bc9);
#
#
#         var popup_96186e847948c55d3df243ad40422677 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_826ab25bfb5e8c98247e419f546eb45a = $(`&lt;div id=&quot;html_826ab25bfb5e8c98247e419f546eb45a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_96186e847948c55d3df243ad40422677.setContent(html_826ab25bfb5e8c98247e419f546eb45a);
#
#
#
#         marker_fbaf385deb8672b052789d9e25312c61.bindPopup(popup_96186e847948c55d3df243ad40422677)
#         ;
#
#
#
#
#             var marker_b07507a2c5f7def25d6959b17ca26df0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e27baa27de153ec37ef6f87a96453bc9);
#
#
#         var popup_0907321dd251c1aba20b0411eaeaf36c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0dd6499a05b8eb69075ceb04c2adc89 = $(`&lt;div id=&quot;html_c0dd6499a05b8eb69075ceb04c2adc89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0907321dd251c1aba20b0411eaeaf36c.setContent(html_c0dd6499a05b8eb69075ceb04c2adc89);
#
#
#
#         marker_b07507a2c5f7def25d6959b17ca26df0.bindPopup(popup_0907321dd251c1aba20b0411eaeaf36c)
#         ;
#
#
#
#
#             var marker_c0323ea50d7744c0d0628e06383d6185 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e27baa27de153ec37ef6f87a96453bc9);
#
#
#         var popup_b9220009676d988c8506a3401388b4d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d4ec173f3e90322c1388d9ec95f30d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d4ec173f3e90322c1388d9ec95f30d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d4ec173f3e90322c1388d9ec95f30d2 = L.map(
#                 &quot;map_1d4ec173f3e90322c1388d9ec95f30d2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57c2fea567291a8d71c3b4a13ec6a358 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57c2fea567291a8d71c3b4a13ec6a358.addTo(map_1d4ec173f3e90322c1388d9ec95f30d2);
#
#
#             var feature_group_9aa94be42beb351a8e1d80e92e15d9fc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9aa94be42beb351a8e1d80e92e15d9fc.addTo(map_1d4ec173f3e90322c1388d9ec95f30d2);
#
#
#             var feature_group_sub_group_c0384c8929a2b8fc08aeb44364a87d18 = L.featureGroup.subGroup(
#                 feature_group_9aa94be42beb351a8e1d80e92e15d9fc
#             );
#
#
#             var marker_7b441b21067feceafe98698ff3972d40 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c0384c8929a2b8fc08aeb44364a87d18);
#
#
#         var popup_67b72f723474e3dac4dd99de55a8bdd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ba011998a1e0a543d86d28d9272ccda = $(`&lt;div id=&quot;html_1ba011998a1e0a543d86d28d9272ccda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_67b72f723474e3dac4dd99de55a8bdd4.setContent(html_1ba011998a1e0a543d86d28d9272ccda);
#
#
#
#         marker_7b441b21067feceafe98698ff3972d40.bindPopup(popup_67b72f723474e3dac4dd99de55a8bdd4)
#         ;
#
#
#
#
#             var marker_2077f9f952aba335ec4118bedd5166ce = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c0384c8929a2b8fc08aeb44364a87d18);
#
#
#         var popup_a9c02bc6deeed6e68d1e4cbb600c719e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19d4b5b532636d4caca1cf29b39ea5d9 = $(`&lt;div id=&quot;html_19d4b5b532636d4caca1cf29b39ea5d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a9c02bc6deeed6e68d1e4cbb600c719e.setContent(html_19d4b5b532636d4caca1cf29b39ea5d9);
#
#
#
#         marker_2077f9f952aba335ec4118bedd5166ce.bindPopup(popup_a9c02bc6deeed6e68d1e4cbb600c719e)
#         ;
#
#
#
#
#             var marker_cf261f8c61a351e69b67786e46501f51 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c0384c8929a2b8fc08aeb44364a87d18);
#
#
#         var popup_5266bdd19e1717005fccfdb78fa42ed7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27007af444410f35cbb620c43b95cfe6 = $(`&lt;div id=&quot;html_27007af444410f35cbb620c43b95cfe6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5266bdd19e1717005fccfdb78fa42ed7.setContent(html_27007af444410f35cbb620c43b95cfe6);
#
#
#
#         marker_cf261f8c61a351e69b67786e46501f51.bindPopup(popup_5266bdd19e1717005fccfdb78fa42ed7)
#         ;
#
#
#
#
#             var marker_5053ad2d7a270dcd7ef8f4ad109cd0ec = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c0384c8929a2b8fc08aeb44364a87d18);
#
#
#         var popup_b876ed7b0c4de1cf4b6d2b746a1667b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8e986788014707615b987e6e22ed225 = $(`&lt;div id=&quot;html_b8e986788014707615b987e6e22ed225&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b876ed7b0c4de1cf4b6d2b746a1667b6.setContent(html_b8e986788014707615b987e6e22ed225);
#
#
#
#         marker_
