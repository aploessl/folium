# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b00578a41c9c8af12a92efe1e41b692 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b00578a41c9c8af12a92efe1e41b692&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b00578a41c9c8af12a92efe1e41b692 = L.map(
#                 &quot;map_9b00578a41c9c8af12a92efe1e41b692&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e0a2916fc439c00ace25a6dd1a16c9d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e0a2916fc439c00ace25a6dd1a16c9d.addTo(map_9b00578a41c9c8af12a92efe1e41b692);
#
#
#             var marker_b31e0c812d8eaa2a87a155e8dde9e019 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9b00578a41c9c8af12a92efe1e41b692);
#
#
#         var popup_25e52ed7d5917c5d86cf440eeecfa235 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50b6750cace353ea1deb0280d881f65f = $(`&lt;div id=&quot;html_50b6750cace353ea1deb0280d881f65f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_25e52ed7d5917c5d86cf440eeecfa235.setContent(html_50b6750cace353ea1deb0280d881f65f);
#
#
#
#         marker_b31e0c812d8eaa2a87a155e8dde9e019.bindPopup(popup_25e52ed7d5917c5d86cf440eeecfa235)
#         ;
#
#
#
#
#             var marker_163c6b1eec5535360271ddb6b6de6148 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9b00578a41c9c8af12a92efe1e41b692);
#
#
#         var popup_d0c257bbc4599be301c853a6547417f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_613217a682aea73142da54e86a183800 = $(`&lt;div id=&quot;html_613217a682aea73142da54e86a183800&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d0c257bbc4599be301c853a6547417f3.setContent(html_613217a682aea73142da54e86a183800);
#
#
#
#         marker_163c6b1eec5535360271ddb6b6de6148.bindPopup(popup_d0c257bbc4599be301c853a6547417f3)
#         ;
#
#
#
#
#             var marker_872946bff863f690bb67fac419839e76 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9b00578a41c9c8af12a92efe1e41b692);
#
#
#         var popup_7ae9cb3ceedfd6487d5e0ba7506366ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c46e4e5ef38e0e631f99aa7f0647b53 = $(`&lt;div id=&quot;html_3c46e4e5ef38e0e631f99aa7f0647b53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7ae9cb3ceedfd6487d5e0ba7506366ce.setContent(html_3c46e4e5ef38e0e631f99aa7f0647b53);
#
#
#
#         marker_872946bff863f690bb67fac419839e76.bindPopup(popup_7ae9cb3ceedfd6487d5e0ba7506366ce)
#         ;
#
#
#
#
#             var marker_8b804f3fe2298079fd8e24c2f78f88c4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9b00578a41c9c8af12a92efe1e41b692);
#
#
#         var popup_51169ee09c5f9d546f9c9fb2cafc3f8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6acc1f762872aa8b7812b3e828603732 = $(`&lt;div id=&quot;html_6acc1f762872aa8b7812b3e828603732&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_51169ee09c5f9d546f9c9fb2cafc3f8a.setContent(html_6acc1f762872aa8b7812b3e828603732);
#
#
#
#         marker_8b804f3fe2298079fd8e24c2f78f88c4.bindPopup(popup_51169ee09c5f9d546f9c9fb2cafc3f8a)
#         ;
#
#
#
#
#             var marker_dc503ca41320c2dc585dc70aeb90f933 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9b00578a41c9c8af12a92efe1e41b692);
#
#
#         var popup_727843ceea7631db29696106a948bd42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92b12c3fb0d34d3feb4cd65ca59890ee = $(`&lt;div id=&quot;html_92b12c3fb0d34d3feb4cd65ca59890ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_727843ceea7631db29696106a948bd42.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b19f95b7cbf66b9485c0a8c49abdc2a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b19f95b7cbf66b9485c0a8c49abdc2a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b19f95b7cbf66b9485c0a8c49abdc2a = L.map(
#                 &quot;map_8b19f95b7cbf66b9485c0a8c49abdc2a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2840a711d4f0f6200279dae83fe1298d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2840a711d4f0f6200279dae83fe1298d.addTo(map_8b19f95b7cbf66b9485c0a8c49abdc2a);
#
#
#             var feature_group_210675644cc3612fbee1f470cbe7eea5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9eafb44dc2ef8fb124f0ea219a274f6e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_210675644cc3612fbee1f470cbe7eea5);
#
#
#         var popup_e59c7aa1dac5ab59dbf7641777edc36c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2aa6e798e2f107abc6ed6e1d62218d05 = $(`&lt;div id=&quot;html_2aa6e798e2f107abc6ed6e1d62218d05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e59c7aa1dac5ab59dbf7641777edc36c.setContent(html_2aa6e798e2f107abc6ed6e1d62218d05);
#
#
#
#         marker_9eafb44dc2ef8fb124f0ea219a274f6e.bindPopup(popup_e59c7aa1dac5ab59dbf7641777edc36c)
#         ;
#
#
#
#
#             var marker_3cb2c045b6884f6a1898c12049d474bb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_210675644cc3612fbee1f470cbe7eea5);
#
#
#         var popup_0cdd369abed9113c614f63b18dc69882 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8b886136e011234cc48a7d8b1b6b2d9 = $(`&lt;div id=&quot;html_c8b886136e011234cc48a7d8b1b6b2d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0cdd369abed9113c614f63b18dc69882.setContent(html_c8b886136e011234cc48a7d8b1b6b2d9);
#
#
#
#         marker_3cb2c045b6884f6a1898c12049d474bb.bindPopup(popup_0cdd369abed9113c614f63b18dc69882)
#         ;
#
#
#
#
#             var marker_eff5d8de958ed34bff0e0e64ed09abce = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_210675644cc3612fbee1f470cbe7eea5);
#
#
#         var popup_c2dc26de40007b0b6acedf93d68fedec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af64ffd484ebf4f4a436969760c598eb = $(`&lt;div id=&quot;html_af64ffd484ebf4f4a436969760c598eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c2dc26de40007b0b6acedf93d68fedec.setContent(html_af64ffd484ebf4f4a436969760c598eb);
#
#
#
#         marker_eff5d8de958ed34bff0e0e64ed09abce.bindPopup(popup_c2dc26de40007b0b6acedf93d68fedec)
#         ;
#
#
#
#
#             var marker_1a03538eef62d07d8dfff39bfbd8d5ee = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_210675644cc3612fbee1f470cbe7eea5);
#
#
#         var popup_da206dfb7d2c43643ed0d1c8aa38d9e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d74617706df4c15d02c22678874db8c6 = $(`&lt;div id=&quot;html_d74617706df4c15d02c22678874db8c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_da206dfb7d2c43643ed0d1c8aa38d9e9.setContent(html_d74617706df4c15d02c22678874db8c6);
#
#
#
#         marker_1a03538eef62d07d8dfff39bfbd8d5ee.bindPopup(popup_da206dfb7d2c43643ed0d1c8aa38d9e9)
#         ;
#
#
#
#
#             var marker_9ef4a3453b62056f4c7cc421f91843fa = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_210675644cc3612fbee1f470cbe7eea5);
#
#
#         var popup_2261d2a44c1ec53feac6ed23a3f92f81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ab2fb47d6c3fa8741fd787469eb8298 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ab2fb47d6c3fa8741fd787469eb8298&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ab2fb47d6c3fa8741fd787469eb8298 = L.map(
#                 &quot;map_0ab2fb47d6c3fa8741fd787469eb8298&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5726519e1b9e55c601962d5ffcb1a3e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5726519e1b9e55c601962d5ffcb1a3e0.addTo(map_0ab2fb47d6c3fa8741fd787469eb8298);
#
#
#             var feature_group_975a2079be34b59811c843189f8d9f86 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_975a2079be34b59811c843189f8d9f86.addTo(map_0ab2fb47d6c3fa8741fd787469eb8298);
#
#
#             var feature_group_sub_group_3ead1fe5dc1f5261eb5a27caf4e463da = L.featureGroup.subGroup(
#                 feature_group_975a2079be34b59811c843189f8d9f86
#             );
#
#
#             var marker_2ce907e987d5fff394916e73c2396b39 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ead1fe5dc1f5261eb5a27caf4e463da);
#
#
#         var popup_5de986b88358c5ab738b98ba64efcd48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f02105ac066af30770e03ac82579b14a = $(`&lt;div id=&quot;html_f02105ac066af30770e03ac82579b14a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5de986b88358c5ab738b98ba64efcd48.setContent(html_f02105ac066af30770e03ac82579b14a);
#
#
#
#         marker_2ce907e987d5fff394916e73c2396b39.bindPopup(popup_5de986b88358c5ab738b98ba64efcd48)
#         ;
#
#
#
#
#             var marker_b2a0081264f033ca85ab200c97f55844 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ead1fe5dc1f5261eb5a27caf4e463da);
#
#
#         var popup_911034f75c7783a09638b006db0decd0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b1e25a2ce0ff240ae27566fa8d52c8c = $(`&lt;div id=&quot;html_3b1e25a2ce0ff240ae27566fa8d52c8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_911034f75c7783a09638b006db0decd0.setContent(html_3b1e25a2ce0ff240ae27566fa8d52c8c);
#
#
#
#         marker_b2a0081264f033ca85ab200c97f55844.bindPopup(popup_911034f75c7783a09638b006db0decd0)
#         ;
#
#
#
#
#             var marker_fab779dfd453afb81cbeba84ffcb1d8e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ead1fe5dc1f5261eb5a27caf4e463da);
#
#
#         var popup_4a90a719b27ae327233384ad574da16a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39090812d74fecfb8c7a67902a6cb870 = $(`&lt;div id=&quot;html_39090812d74fecfb8c7a67902a6cb870&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4a90a719b27ae327233384ad574da16a.setContent(html_39090812d74fecfb8c7a67902a6cb870);
#
#
#
#         marker_fab779dfd453afb81cbeba84ffcb1d8e.bindPopup(popup_4a90a719b27ae327233384ad574da16a)
#         ;
#
#
#
#
#             var marker_609bbd7aadcfcd464286a3d6f340dd76 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ead1fe5dc1f5261eb5a27caf4e463da);
#
#
#         var popup_1ec6b472bfdcf535bfc31ad419b979e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c4bb56e188eb441a1954a60269decc6 = $(`&lt;div id=&quot;html_6c4bb56e188eb441a1954a60269decc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1ec6b472bfdcf535bfc31ad419b979e5.setContent(html_6c4bb56e188eb441a1954a60269decc6);
#
#
#
#         marker_
