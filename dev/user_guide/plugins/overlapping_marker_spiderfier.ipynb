# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4c2fabb163fcc81816350d6100925ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4c2fabb163fcc81816350d6100925ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4c2fabb163fcc81816350d6100925ef = L.map(
#                 &quot;map_f4c2fabb163fcc81816350d6100925ef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_879979beae1a29fa96214c72a0837aad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_879979beae1a29fa96214c72a0837aad.addTo(map_f4c2fabb163fcc81816350d6100925ef);
#
#
#             var marker_b7341857785aaf2a4a411319fd1a382e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f4c2fabb163fcc81816350d6100925ef);
#
#
#         var popup_21e75f0c7c8a027c2d23d34943353057 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f141f3dd4fde875e2ee36cedda27cd2 = $(`&lt;div id=&quot;html_8f141f3dd4fde875e2ee36cedda27cd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_21e75f0c7c8a027c2d23d34943353057.setContent(html_8f141f3dd4fde875e2ee36cedda27cd2);
#
#
#
#         marker_b7341857785aaf2a4a411319fd1a382e.bindPopup(popup_21e75f0c7c8a027c2d23d34943353057)
#         ;
#
#
#
#
#             var marker_cb45ba9cec187e8ea103105841bd14d1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f4c2fabb163fcc81816350d6100925ef);
#
#
#         var popup_79605bc99c431e3451ac5f0bc7433b75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_558bf3372008da9de080855e19c4c8b9 = $(`&lt;div id=&quot;html_558bf3372008da9de080855e19c4c8b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_79605bc99c431e3451ac5f0bc7433b75.setContent(html_558bf3372008da9de080855e19c4c8b9);
#
#
#
#         marker_cb45ba9cec187e8ea103105841bd14d1.bindPopup(popup_79605bc99c431e3451ac5f0bc7433b75)
#         ;
#
#
#
#
#             var marker_cad2f6d7bf6ed1665bb33e6f5d9260b7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f4c2fabb163fcc81816350d6100925ef);
#
#
#         var popup_961c689619d6d827206cc9a1be52f8b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f83e19e79928642d280d903d9df69b88 = $(`&lt;div id=&quot;html_f83e19e79928642d280d903d9df69b88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_961c689619d6d827206cc9a1be52f8b0.setContent(html_f83e19e79928642d280d903d9df69b88);
#
#
#
#         marker_cad2f6d7bf6ed1665bb33e6f5d9260b7.bindPopup(popup_961c689619d6d827206cc9a1be52f8b0)
#         ;
#
#
#
#
#             var marker_e43e6c9a9cf5a4af1ecd916b94ba2402 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f4c2fabb163fcc81816350d6100925ef);
#
#
#         var popup_e58df58213e3e2aa66df961eb250f94b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39e27babaea17f93e85b0e0043b04241 = $(`&lt;div id=&quot;html_39e27babaea17f93e85b0e0043b04241&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e58df58213e3e2aa66df961eb250f94b.setContent(html_39e27babaea17f93e85b0e0043b04241);
#
#
#
#         marker_e43e6c9a9cf5a4af1ecd916b94ba2402.bindPopup(popup_e58df58213e3e2aa66df961eb250f94b)
#         ;
#
#
#
#
#             var marker_fffe9998fc8bb6abdf0be14b77f2ca62 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f4c2fabb163fcc81816350d6100925ef);
#
#
#         var popup_aa0abe19c2c7434343f903233ff1ceaa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a473f2b211f8c78c6384846fc3a28b4f = $(`&lt;div id=&quot;html_a473f2b211f8c78c6384846fc3a28b4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_aa0abe19c2c7434343f903233ff1ceaa.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fb3382c751979e5d38dcec1f86febe6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fb3382c751979e5d38dcec1f86febe6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fb3382c751979e5d38dcec1f86febe6 = L.map(
#                 &quot;map_9fb3382c751979e5d38dcec1f86febe6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_215032f0ae0504021076e2263bc41f62 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_215032f0ae0504021076e2263bc41f62.addTo(map_9fb3382c751979e5d38dcec1f86febe6);
#
#
#             var feature_group_3d22cfe4546b8ae836c28dea3a8bee2e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9e7dac3bfaf6270a659f9003eea7092c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3d22cfe4546b8ae836c28dea3a8bee2e);
#
#
#         var popup_885152be5e8a84db4becfc128e128739 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79212996f7b705ac890b692ed3349ae0 = $(`&lt;div id=&quot;html_79212996f7b705ac890b692ed3349ae0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_885152be5e8a84db4becfc128e128739.setContent(html_79212996f7b705ac890b692ed3349ae0);
#
#
#
#         marker_9e7dac3bfaf6270a659f9003eea7092c.bindPopup(popup_885152be5e8a84db4becfc128e128739)
#         ;
#
#
#
#
#             var marker_25cbf86e1a6b8f2ae5f700d2a69f938a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3d22cfe4546b8ae836c28dea3a8bee2e);
#
#
#         var popup_805a069a16633b2fb4589882227de915 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bbf76ee876404055e0fa536bf5a9d43 = $(`&lt;div id=&quot;html_0bbf76ee876404055e0fa536bf5a9d43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_805a069a16633b2fb4589882227de915.setContent(html_0bbf76ee876404055e0fa536bf5a9d43);
#
#
#
#         marker_25cbf86e1a6b8f2ae5f700d2a69f938a.bindPopup(popup_805a069a16633b2fb4589882227de915)
#         ;
#
#
#
#
#             var marker_7610f14295fa0912aca661f05acb746e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3d22cfe4546b8ae836c28dea3a8bee2e);
#
#
#         var popup_aa4140b4918fb753357205ccf8f115a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e28888f8fcd9b9731ed7617a151ea76 = $(`&lt;div id=&quot;html_4e28888f8fcd9b9731ed7617a151ea76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_aa4140b4918fb753357205ccf8f115a5.setContent(html_4e28888f8fcd9b9731ed7617a151ea76);
#
#
#
#         marker_7610f14295fa0912aca661f05acb746e.bindPopup(popup_aa4140b4918fb753357205ccf8f115a5)
#         ;
#
#
#
#
#             var marker_a52ed8d0a03c94b7074c2d502c56a6d9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3d22cfe4546b8ae836c28dea3a8bee2e);
#
#
#         var popup_b59bafe7955264c9fcc8974d0ff73ec2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51c3597309294f172c86652f2601c43c = $(`&lt;div id=&quot;html_51c3597309294f172c86652f2601c43c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b59bafe7955264c9fcc8974d0ff73ec2.setContent(html_51c3597309294f172c86652f2601c43c);
#
#
#
#         marker_a52ed8d0a03c94b7074c2d502c56a6d9.bindPopup(popup_b59bafe7955264c9fcc8974d0ff73ec2)
#         ;
#
#
#
#
#             var marker_6ec45177cb0b0f96bb41abfa9c733ce3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3d22cfe4546b8ae836c28dea3a8bee2e);
#
#
#         var popup_f5fd3dbbde00e12c62c2289dbffeba83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abd83f51ba15c97d046df7dc05829e0e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abd83f51ba15c97d046df7dc05829e0e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abd83f51ba15c97d046df7dc05829e0e = L.map(
#                 &quot;map_abd83f51ba15c97d046df7dc05829e0e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd06639f42e0df323a324ec513244da8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cd06639f42e0df323a324ec513244da8.addTo(map_abd83f51ba15c97d046df7dc05829e0e);
#
#
#             var feature_group_1ec5b74015af02b338f15aeaf6e29e14 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1ec5b74015af02b338f15aeaf6e29e14.addTo(map_abd83f51ba15c97d046df7dc05829e0e);
#
#
#             var feature_group_sub_group_97354d555eb83f77112af826e15b6f01 = L.featureGroup.subGroup(
#                 feature_group_1ec5b74015af02b338f15aeaf6e29e14
#             );
#
#
#             var marker_46485b6389c120a12a6014aecd54db31 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_97354d555eb83f77112af826e15b6f01);
#
#
#         var popup_668d5d96295ca510684cc619a5b784e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d33f7bee5daa8692bf6c99f79d5ec65 = $(`&lt;div id=&quot;html_3d33f7bee5daa8692bf6c99f79d5ec65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_668d5d96295ca510684cc619a5b784e3.setContent(html_3d33f7bee5daa8692bf6c99f79d5ec65);
#
#
#
#         marker_46485b6389c120a12a6014aecd54db31.bindPopup(popup_668d5d96295ca510684cc619a5b784e3)
#         ;
#
#
#
#
#             var marker_d5504c20f927610ae45346ea65c9f4d5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_97354d555eb83f77112af826e15b6f01);
#
#
#         var popup_12492e3081d5148b52f91920ba56c6a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ec52f3e99e12213c1a7c5abc303a080 = $(`&lt;div id=&quot;html_7ec52f3e99e12213c1a7c5abc303a080&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_12492e3081d5148b52f91920ba56c6a6.setContent(html_7ec52f3e99e12213c1a7c5abc303a080);
#
#
#
#         marker_d5504c20f927610ae45346ea65c9f4d5.bindPopup(popup_12492e3081d5148b52f91920ba56c6a6)
#         ;
#
#
#
#
#             var marker_8e1600cefac761a8fcd355bcc8466dc2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_97354d555eb83f77112af826e15b6f01);
#
#
#         var popup_6a06889cdde544f62ccb5b8150c6b4f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89893afc8b6b198f2d6360eba87727ef = $(`&lt;div id=&quot;html_89893afc8b6b198f2d6360eba87727ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6a06889cdde544f62ccb5b8150c6b4f7.setContent(html_89893afc8b6b198f2d6360eba87727ef);
#
#
#
#         marker_8e1600cefac761a8fcd355bcc8466dc2.bindPopup(popup_6a06889cdde544f62ccb5b8150c6b4f7)
#         ;
#
#
#
#
#             var marker_0bb2c4bb9e696520edafad12763f8f01 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_97354d555eb83f77112af826e15b6f01);
#
#
#         var popup_f37897dac8bd8391bd8bd583c1f293e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_702543d62085e104d1f494199ebf0ce6 = $(`&lt;div id=&quot;html_702543d62085e104d1f494199ebf0ce6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f37897dac8bd8391bd8bd583c1f293e0.setContent(html_702543d62085e104d1f494199ebf0ce6);
#
#
#
#         marker_
