# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af5acb4556ba26c1b6fbb5d96c235f46 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af5acb4556ba26c1b6fbb5d96c235f46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af5acb4556ba26c1b6fbb5d96c235f46 = L.map(
#                 &quot;map_af5acb4556ba26c1b6fbb5d96c235f46&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3090148d9225f36628584ea9231f297e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3090148d9225f36628584ea9231f297e.addTo(map_af5acb4556ba26c1b6fbb5d96c235f46);
#
#
#             var marker_8f8d5d0f13895f4c9bb3012bf331d0ae = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_af5acb4556ba26c1b6fbb5d96c235f46);
#
#
#         var popup_f60ded79f98ff3867b7a05b15eb866e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c24423f3f3e8a155640c183ab26bf875 = $(`&lt;div id=&quot;html_c24423f3f3e8a155640c183ab26bf875&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f60ded79f98ff3867b7a05b15eb866e2.setContent(html_c24423f3f3e8a155640c183ab26bf875);
#
#
#
#         marker_8f8d5d0f13895f4c9bb3012bf331d0ae.bindPopup(popup_f60ded79f98ff3867b7a05b15eb866e2)
#         ;
#
#
#
#
#             var marker_f234c7e4400848cac316fe267a341b7c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_af5acb4556ba26c1b6fbb5d96c235f46);
#
#
#         var popup_e879a0d381b6c768f247dfe4fbdb06f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0c24f4ffd1f4082388563277a28f6fd = $(`&lt;div id=&quot;html_d0c24f4ffd1f4082388563277a28f6fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e879a0d381b6c768f247dfe4fbdb06f4.setContent(html_d0c24f4ffd1f4082388563277a28f6fd);
#
#
#
#         marker_f234c7e4400848cac316fe267a341b7c.bindPopup(popup_e879a0d381b6c768f247dfe4fbdb06f4)
#         ;
#
#
#
#
#             var marker_03e8ffa9246c20a13471b4c3f2cbc7ef = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_af5acb4556ba26c1b6fbb5d96c235f46);
#
#
#         var popup_4b0ff65092ef9ab39d6233ab814c3e69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_618f255a0623176e7ed5a06f4260526e = $(`&lt;div id=&quot;html_618f255a0623176e7ed5a06f4260526e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4b0ff65092ef9ab39d6233ab814c3e69.setContent(html_618f255a0623176e7ed5a06f4260526e);
#
#
#
#         marker_03e8ffa9246c20a13471b4c3f2cbc7ef.bindPopup(popup_4b0ff65092ef9ab39d6233ab814c3e69)
#         ;
#
#
#
#
#             var marker_b9968148f25c331dd6cc2588defab908 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_af5acb4556ba26c1b6fbb5d96c235f46);
#
#
#         var popup_42f9e360488094d554ed83d90058dc87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ea86bd750ed451ca243b2e87b0f6ca0 = $(`&lt;div id=&quot;html_1ea86bd750ed451ca243b2e87b0f6ca0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_42f9e360488094d554ed83d90058dc87.setContent(html_1ea86bd750ed451ca243b2e87b0f6ca0);
#
#
#
#         marker_b9968148f25c331dd6cc2588defab908.bindPopup(popup_42f9e360488094d554ed83d90058dc87)
#         ;
#
#
#
#
#             var marker_3c1904e30815195e86a92c8fc9cacdd8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_af5acb4556ba26c1b6fbb5d96c235f46);
#
#
#         var popup_1f8df3d4355248f4bfd9f56b5953400f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c493a666e126c3e311564661139cbfc = $(`&lt;div id=&quot;html_9c493a666e126c3e311564661139cbfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1f8df3d4355248f4bfd9f56b5953400f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86af90e0c0874063470d30f0cc2e717a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86af90e0c0874063470d30f0cc2e717a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86af90e0c0874063470d30f0cc2e717a = L.map(
#                 &quot;map_86af90e0c0874063470d30f0cc2e717a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_009b8a49f0cb76d5c10b228df4e99aae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_009b8a49f0cb76d5c10b228df4e99aae.addTo(map_86af90e0c0874063470d30f0cc2e717a);
#
#
#             var feature_group_43e32c6024840a2d7d099e8ec15d13df = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b8132002139ddc8336239f25291cc02d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_43e32c6024840a2d7d099e8ec15d13df);
#
#
#         var popup_3313af94431833eb5da9aec65f163d3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_038ca8fd402e9b4175e802c071a8d3ab = $(`&lt;div id=&quot;html_038ca8fd402e9b4175e802c071a8d3ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3313af94431833eb5da9aec65f163d3a.setContent(html_038ca8fd402e9b4175e802c071a8d3ab);
#
#
#
#         marker_b8132002139ddc8336239f25291cc02d.bindPopup(popup_3313af94431833eb5da9aec65f163d3a)
#         ;
#
#
#
#
#             var marker_f66bd1921998c670af2731e791689dc1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_43e32c6024840a2d7d099e8ec15d13df);
#
#
#         var popup_d0d0f810cf0caadc236c0b1c5b76b447 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21760634a2acd343870b4afb941495c6 = $(`&lt;div id=&quot;html_21760634a2acd343870b4afb941495c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d0d0f810cf0caadc236c0b1c5b76b447.setContent(html_21760634a2acd343870b4afb941495c6);
#
#
#
#         marker_f66bd1921998c670af2731e791689dc1.bindPopup(popup_d0d0f810cf0caadc236c0b1c5b76b447)
#         ;
#
#
#
#
#             var marker_582f6c6ff9bee94664c333ed8a035d49 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_43e32c6024840a2d7d099e8ec15d13df);
#
#
#         var popup_75bdba44cc158e5b88184fb00fdf062e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24f50ed5898b7df4ebd199816f4e2e13 = $(`&lt;div id=&quot;html_24f50ed5898b7df4ebd199816f4e2e13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_75bdba44cc158e5b88184fb00fdf062e.setContent(html_24f50ed5898b7df4ebd199816f4e2e13);
#
#
#
#         marker_582f6c6ff9bee94664c333ed8a035d49.bindPopup(popup_75bdba44cc158e5b88184fb00fdf062e)
#         ;
#
#
#
#
#             var marker_5c49fd1534fe23c80e14a56085dcc864 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_43e32c6024840a2d7d099e8ec15d13df);
#
#
#         var popup_7d06bf30923491fa23ea98dca478aeb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e14478073792d123f8490d1d03ab9050 = $(`&lt;div id=&quot;html_e14478073792d123f8490d1d03ab9050&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7d06bf30923491fa23ea98dca478aeb0.setContent(html_e14478073792d123f8490d1d03ab9050);
#
#
#
#         marker_5c49fd1534fe23c80e14a56085dcc864.bindPopup(popup_7d06bf30923491fa23ea98dca478aeb0)
#         ;
#
#
#
#
#             var marker_f7a51f6dbeffee9014826ed4665ec92a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_43e32c6024840a2d7d099e8ec15d13df);
#
#
#         var popup_e2bf4e084ca35cda2fd24d1e45da1b7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8495d1ca016255fd9f21a037b2df8ba6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8495d1ca016255fd9f21a037b2df8ba6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8495d1ca016255fd9f21a037b2df8ba6 = L.map(
#                 &quot;map_8495d1ca016255fd9f21a037b2df8ba6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_41f57213150e8a41ff3e7250b12c12f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_41f57213150e8a41ff3e7250b12c12f4.addTo(map_8495d1ca016255fd9f21a037b2df8ba6);
#
#
#             var feature_group_7b737f1f70db49cbb0c1be2d24c468ec = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7b737f1f70db49cbb0c1be2d24c468ec.addTo(map_8495d1ca016255fd9f21a037b2df8ba6);
#
#
#             var feature_group_sub_group_0bc3bdae4010fc0df8eb6e49214159f9 = L.featureGroup.subGroup(
#                 feature_group_7b737f1f70db49cbb0c1be2d24c468ec
#             );
#
#
#             var marker_1811a8908d2a448d88416d5273b7ebee = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0bc3bdae4010fc0df8eb6e49214159f9);
#
#
#         var popup_3b1df904b18ce4dcfbc6430f5286b67b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15d7da07b239a8f58cbd2c30aed56e4c = $(`&lt;div id=&quot;html_15d7da07b239a8f58cbd2c30aed56e4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3b1df904b18ce4dcfbc6430f5286b67b.setContent(html_15d7da07b239a8f58cbd2c30aed56e4c);
#
#
#
#         marker_1811a8908d2a448d88416d5273b7ebee.bindPopup(popup_3b1df904b18ce4dcfbc6430f5286b67b)
#         ;
#
#
#
#
#             var marker_2d3cb3aefcd47721ed9ec953035207a0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0bc3bdae4010fc0df8eb6e49214159f9);
#
#
#         var popup_124e2fa68b69d48daf1b4301ec285fe8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ebe67258e68c17bae6509159504e46b = $(`&lt;div id=&quot;html_7ebe67258e68c17bae6509159504e46b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_124e2fa68b69d48daf1b4301ec285fe8.setContent(html_7ebe67258e68c17bae6509159504e46b);
#
#
#
#         marker_2d3cb3aefcd47721ed9ec953035207a0.bindPopup(popup_124e2fa68b69d48daf1b4301ec285fe8)
#         ;
#
#
#
#
#             var marker_7fd372116926ac15708d93392276af15 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0bc3bdae4010fc0df8eb6e49214159f9);
#
#
#         var popup_3fbcdb140d8a9c078089bdf306c02b4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c9bd57363be52953a45002cc5e72671 = $(`&lt;div id=&quot;html_4c9bd57363be52953a45002cc5e72671&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3fbcdb140d8a9c078089bdf306c02b4e.setContent(html_4c9bd57363be52953a45002cc5e72671);
#
#
#
#         marker_7fd372116926ac15708d93392276af15.bindPopup(popup_3fbcdb140d8a9c078089bdf306c02b4e)
#         ;
#
#
#
#
#             var marker_5537e88a9d0b945ba2cb0c22a121761a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0bc3bdae4010fc0df8eb6e49214159f9);
#
#
#         var popup_30f03410e0078f02f31e2285094bd106 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47127d2c065ae33e5398648ec0745f44 = $(`&lt;div id=&quot;html_47127d2c065ae33e5398648ec0745f44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_30f03410e0078f02f31e2285094bd106.setContent(html_47127d2c065ae33e5398648ec0745f44);
#
#
#
#         marker_
