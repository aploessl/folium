# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb1f9b69d15e0d12eca4dbc9cd9a5430 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb1f9b69d15e0d12eca4dbc9cd9a5430&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb1f9b69d15e0d12eca4dbc9cd9a5430 = L.map(
#                 &quot;map_fb1f9b69d15e0d12eca4dbc9cd9a5430&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e94131df9bf63f627154e589bfa20bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5e94131df9bf63f627154e589bfa20bd.addTo(map_fb1f9b69d15e0d12eca4dbc9cd9a5430);
#
#
#             var marker_071133b28a5a6267caf9f49528ae80bd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fb1f9b69d15e0d12eca4dbc9cd9a5430);
#
#
#         var popup_d9646ded7c8f0bc5ee69d2bc3fd44fbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2f3b6cbd2cc9e92d4de45de80950bbf = $(`&lt;div id=&quot;html_b2f3b6cbd2cc9e92d4de45de80950bbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d9646ded7c8f0bc5ee69d2bc3fd44fbb.setContent(html_b2f3b6cbd2cc9e92d4de45de80950bbf);
#
#
#
#         marker_071133b28a5a6267caf9f49528ae80bd.bindPopup(popup_d9646ded7c8f0bc5ee69d2bc3fd44fbb)
#         ;
#
#
#
#
#             var marker_403fac2d1a21cc94c74e320a74e1b957 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fb1f9b69d15e0d12eca4dbc9cd9a5430);
#
#
#         var popup_a6ea82cf50e380836627f83c3fa5dfa6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b70d0180afccab9c6426d83b2e22b40 = $(`&lt;div id=&quot;html_7b70d0180afccab9c6426d83b2e22b40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a6ea82cf50e380836627f83c3fa5dfa6.setContent(html_7b70d0180afccab9c6426d83b2e22b40);
#
#
#
#         marker_403fac2d1a21cc94c74e320a74e1b957.bindPopup(popup_a6ea82cf50e380836627f83c3fa5dfa6)
#         ;
#
#
#
#
#             var marker_9adf54d9bfaaac48a81695c616872ac1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fb1f9b69d15e0d12eca4dbc9cd9a5430);
#
#
#         var popup_273e46073fe50ee863b45e26c13b83c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c466fdd661d866d646bc8082cec45286 = $(`&lt;div id=&quot;html_c466fdd661d866d646bc8082cec45286&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_273e46073fe50ee863b45e26c13b83c0.setContent(html_c466fdd661d866d646bc8082cec45286);
#
#
#
#         marker_9adf54d9bfaaac48a81695c616872ac1.bindPopup(popup_273e46073fe50ee863b45e26c13b83c0)
#         ;
#
#
#
#
#             var marker_0795b5a8852f88c172d4ce6f751a4198 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fb1f9b69d15e0d12eca4dbc9cd9a5430);
#
#
#         var popup_381b63488e8901c0748005825838098a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_241053991b0641ed4fc8ffd0734d2469 = $(`&lt;div id=&quot;html_241053991b0641ed4fc8ffd0734d2469&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_381b63488e8901c0748005825838098a.setContent(html_241053991b0641ed4fc8ffd0734d2469);
#
#
#
#         marker_0795b5a8852f88c172d4ce6f751a4198.bindPopup(popup_381b63488e8901c0748005825838098a)
#         ;
#
#
#
#
#             var marker_a4c0e26b98040efb0a2bf7deec40e8ed = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fb1f9b69d15e0d12eca4dbc9cd9a5430);
#
#
#         var popup_b17d13a0148b80e2b66823a16c3105c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df7a66eddba1a4a9c91ff8541dda4d68 = $(`&lt;div id=&quot;html_df7a66eddba1a4a9c91ff8541dda4d68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b17d13a0148b80e2b66823a16c3105c9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f06b8e1ebb51049946215136b6f5225 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f06b8e1ebb51049946215136b6f5225&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f06b8e1ebb51049946215136b6f5225 = L.map(
#                 &quot;map_5f06b8e1ebb51049946215136b6f5225&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f65d8eebd558de80300e9cf929b15e0b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f65d8eebd558de80300e9cf929b15e0b.addTo(map_5f06b8e1ebb51049946215136b6f5225);
#
#
#             var feature_group_b87063a9803c6bf919198458e4f4cf56 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2972ea0038678a57de1cc6ce2261c2aa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b87063a9803c6bf919198458e4f4cf56);
#
#
#         var popup_6a59ffc6ed3d7c41129dd8cf48d9edd0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1284eae7d0fba69b6dd47de362e96831 = $(`&lt;div id=&quot;html_1284eae7d0fba69b6dd47de362e96831&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6a59ffc6ed3d7c41129dd8cf48d9edd0.setContent(html_1284eae7d0fba69b6dd47de362e96831);
#
#
#
#         marker_2972ea0038678a57de1cc6ce2261c2aa.bindPopup(popup_6a59ffc6ed3d7c41129dd8cf48d9edd0)
#         ;
#
#
#
#
#             var marker_59682332b52e6ea69eb6bc9316e17d52 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b87063a9803c6bf919198458e4f4cf56);
#
#
#         var popup_f541122b7ba064d17d119c68347ecc0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7f92679a365647e33bac239a2c29f81 = $(`&lt;div id=&quot;html_a7f92679a365647e33bac239a2c29f81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f541122b7ba064d17d119c68347ecc0e.setContent(html_a7f92679a365647e33bac239a2c29f81);
#
#
#
#         marker_59682332b52e6ea69eb6bc9316e17d52.bindPopup(popup_f541122b7ba064d17d119c68347ecc0e)
#         ;
#
#
#
#
#             var marker_6905ef174c5b3aa8a47c8080d4a1e2e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b87063a9803c6bf919198458e4f4cf56);
#
#
#         var popup_32d743d19f9b92baa3a00d1aba482118 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87c615b9821dcc7750f2a1ffd2638ed6 = $(`&lt;div id=&quot;html_87c615b9821dcc7750f2a1ffd2638ed6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_32d743d19f9b92baa3a00d1aba482118.setContent(html_87c615b9821dcc7750f2a1ffd2638ed6);
#
#
#
#         marker_6905ef174c5b3aa8a47c8080d4a1e2e8.bindPopup(popup_32d743d19f9b92baa3a00d1aba482118)
#         ;
#
#
#
#
#             var marker_1bed7957ed8f50949b14fdb6c861e7c8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b87063a9803c6bf919198458e4f4cf56);
#
#
#         var popup_e1dd78ac51676c6b490da1fdc9a19f2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f141f393f836d9fe63beb9700153223c = $(`&lt;div id=&quot;html_f141f393f836d9fe63beb9700153223c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e1dd78ac51676c6b490da1fdc9a19f2c.setContent(html_f141f393f836d9fe63beb9700153223c);
#
#
#
#         marker_1bed7957ed8f50949b14fdb6c861e7c8.bindPopup(popup_e1dd78ac51676c6b490da1fdc9a19f2c)
#         ;
#
#
#
#
#             var marker_a7738a2d7112432950c2b31b15480b7b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b87063a9803c6bf919198458e4f4cf56);
#
#
#         var popup_edd89c2ad146694b818ea5bd95b99ed7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d9aef14f3a7156a092d1ae092a5438f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d9aef14f3a7156a092d1ae092a5438f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d9aef14f3a7156a092d1ae092a5438f = L.map(
#                 &quot;map_1d9aef14f3a7156a092d1ae092a5438f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b9c16e337a834bd0176976da79e6d5d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b9c16e337a834bd0176976da79e6d5d.addTo(map_1d9aef14f3a7156a092d1ae092a5438f);
#
#
#             var feature_group_1974eb5bdeff045468bc3ed6b012da86 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1974eb5bdeff045468bc3ed6b012da86.addTo(map_1d9aef14f3a7156a092d1ae092a5438f);
#
#
#             var feature_group_sub_group_d55185b39784c31b78997a7191b2d93f = L.featureGroup.subGroup(
#                 feature_group_1974eb5bdeff045468bc3ed6b012da86
#             );
#
#
#             var marker_093a2a8f4e02f5e26f99fe24fd6e9e1a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d55185b39784c31b78997a7191b2d93f);
#
#
#         var popup_8d868060efe1ca899df1896f2897ee0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d586c623151a8efe96a046c110ba8b0b = $(`&lt;div id=&quot;html_d586c623151a8efe96a046c110ba8b0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8d868060efe1ca899df1896f2897ee0d.setContent(html_d586c623151a8efe96a046c110ba8b0b);
#
#
#
#         marker_093a2a8f4e02f5e26f99fe24fd6e9e1a.bindPopup(popup_8d868060efe1ca899df1896f2897ee0d)
#         ;
#
#
#
#
#             var marker_3f7034452d21debcb9736c9c531a5cbe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d55185b39784c31b78997a7191b2d93f);
#
#
#         var popup_37db3d8ff18a4faa3ad4a4a57105411c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51fb225973031d3757486630d2f90f8c = $(`&lt;div id=&quot;html_51fb225973031d3757486630d2f90f8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_37db3d8ff18a4faa3ad4a4a57105411c.setContent(html_51fb225973031d3757486630d2f90f8c);
#
#
#
#         marker_3f7034452d21debcb9736c9c531a5cbe.bindPopup(popup_37db3d8ff18a4faa3ad4a4a57105411c)
#         ;
#
#
#
#
#             var marker_9a475cc951fd2ed1bf1d51edb61ed0f6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d55185b39784c31b78997a7191b2d93f);
#
#
#         var popup_7e5ec396b7a482de0611443201e163bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f7948367079f00999e634ce4b5a2c3b = $(`&lt;div id=&quot;html_0f7948367079f00999e634ce4b5a2c3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7e5ec396b7a482de0611443201e163bc.setContent(html_0f7948367079f00999e634ce4b5a2c3b);
#
#
#
#         marker_9a475cc951fd2ed1bf1d51edb61ed0f6.bindPopup(popup_7e5ec396b7a482de0611443201e163bc)
#         ;
#
#
#
#
#             var marker_6ef161daa461c43f7e44896270027182 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d55185b39784c31b78997a7191b2d93f);
#
#
#         var popup_0b5bcefc2c42812dcd5ee68c0bd7f9b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03b1190f74f0becfddcd600380623a51 = $(`&lt;div id=&quot;html_03b1190f74f0becfddcd600380623a51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0b5bcefc2c42812dcd5ee68c0bd7f9b9.setContent(html_03b1190f74f0becfddcd600380623a51);
#
#
#
#         marker_
