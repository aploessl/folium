# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_619ef942a1129965527a03d074e94d8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_619ef942a1129965527a03d074e94d8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_619ef942a1129965527a03d074e94d8d = L.map(
#                 &quot;map_619ef942a1129965527a03d074e94d8d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd9051dd8b99548c4dae02fbb8b53d12 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd9051dd8b99548c4dae02fbb8b53d12.addTo(map_619ef942a1129965527a03d074e94d8d);
#
#
#             var marker_5827cfe48c41e2873d57e39143ddf270 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_619ef942a1129965527a03d074e94d8d);
#
#
#         var popup_de1fabdf66593af5d23e222c88a99edb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f8bcc7b7a6954ce45c8f937c1dd4d90 = $(`&lt;div id=&quot;html_2f8bcc7b7a6954ce45c8f937c1dd4d90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_de1fabdf66593af5d23e222c88a99edb.setContent(html_2f8bcc7b7a6954ce45c8f937c1dd4d90);
#
#
#
#         marker_5827cfe48c41e2873d57e39143ddf270.bindPopup(popup_de1fabdf66593af5d23e222c88a99edb)
#         ;
#
#
#
#
#             var marker_30ba57c2ccb7d6ccc5a6d122f265ad56 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_619ef942a1129965527a03d074e94d8d);
#
#
#         var popup_74944a4ff9051d6a6b5597632b344030 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90c2ebfcef6c4765b2e6af24aa5a662c = $(`&lt;div id=&quot;html_90c2ebfcef6c4765b2e6af24aa5a662c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_74944a4ff9051d6a6b5597632b344030.setContent(html_90c2ebfcef6c4765b2e6af24aa5a662c);
#
#
#
#         marker_30ba57c2ccb7d6ccc5a6d122f265ad56.bindPopup(popup_74944a4ff9051d6a6b5597632b344030)
#         ;
#
#
#
#
#             var marker_8e5147b2ac9387c407efa2951cc323cd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_619ef942a1129965527a03d074e94d8d);
#
#
#         var popup_9a0a6cd78bbf5daf45c85d6e48ac3e39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_006dba08bd09919284501ccfbbb6b94b = $(`&lt;div id=&quot;html_006dba08bd09919284501ccfbbb6b94b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9a0a6cd78bbf5daf45c85d6e48ac3e39.setContent(html_006dba08bd09919284501ccfbbb6b94b);
#
#
#
#         marker_8e5147b2ac9387c407efa2951cc323cd.bindPopup(popup_9a0a6cd78bbf5daf45c85d6e48ac3e39)
#         ;
#
#
#
#
#             var marker_6bc8a8c693677ca9a1736b6a99b5e195 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_619ef942a1129965527a03d074e94d8d);
#
#
#         var popup_456c388a883fb9f5d4ee5ed052b9db15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_796bb1784f7e84c380a23fdb94446429 = $(`&lt;div id=&quot;html_796bb1784f7e84c380a23fdb94446429&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_456c388a883fb9f5d4ee5ed052b9db15.setContent(html_796bb1784f7e84c380a23fdb94446429);
#
#
#
#         marker_6bc8a8c693677ca9a1736b6a99b5e195.bindPopup(popup_456c388a883fb9f5d4ee5ed052b9db15)
#         ;
#
#
#
#
#             var marker_ba41bc259aaf8070e390ea2d19ae7f2f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_619ef942a1129965527a03d074e94d8d);
#
#
#         var popup_231ade1b68ab4aa5a56db2989353b19f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc2771dde2da7f6980a152b3431d2807 = $(`&lt;div id=&quot;html_fc2771dde2da7f6980a152b3431d2807&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_231ade1b68ab4aa5a56db2989353b19f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_324a5290f5be2819b30ffe3c548de14d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_324a5290f5be2819b30ffe3c548de14d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_324a5290f5be2819b30ffe3c548de14d = L.map(
#                 &quot;map_324a5290f5be2819b30ffe3c548de14d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa346fd9d78e71c73d0585da42a02d4b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fa346fd9d78e71c73d0585da42a02d4b.addTo(map_324a5290f5be2819b30ffe3c548de14d);
#
#
#             var feature_group_7913ff35b3ad42abf2867261060e047f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3d93ebd567cb30f615da235f319ad7da = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7913ff35b3ad42abf2867261060e047f);
#
#
#         var popup_c57619107214045105623d87dbe7af37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_daf02e26c7a544588068ede9a764b41e = $(`&lt;div id=&quot;html_daf02e26c7a544588068ede9a764b41e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c57619107214045105623d87dbe7af37.setContent(html_daf02e26c7a544588068ede9a764b41e);
#
#
#
#         marker_3d93ebd567cb30f615da235f319ad7da.bindPopup(popup_c57619107214045105623d87dbe7af37)
#         ;
#
#
#
#
#             var marker_2f0119cd22d25073660ac8634382a64b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7913ff35b3ad42abf2867261060e047f);
#
#
#         var popup_a2707c924ae97dab86bcce4427346790 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1695433c2d22a3d0140ccb688d61d1c1 = $(`&lt;div id=&quot;html_1695433c2d22a3d0140ccb688d61d1c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a2707c924ae97dab86bcce4427346790.setContent(html_1695433c2d22a3d0140ccb688d61d1c1);
#
#
#
#         marker_2f0119cd22d25073660ac8634382a64b.bindPopup(popup_a2707c924ae97dab86bcce4427346790)
#         ;
#
#
#
#
#             var marker_b822a5529a75252a8dc307092eeddefc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7913ff35b3ad42abf2867261060e047f);
#
#
#         var popup_8c79462a14b708d3a9e9f509244a4f7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02656de041da8b57c4f3a671348a0f86 = $(`&lt;div id=&quot;html_02656de041da8b57c4f3a671348a0f86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8c79462a14b708d3a9e9f509244a4f7a.setContent(html_02656de041da8b57c4f3a671348a0f86);
#
#
#
#         marker_b822a5529a75252a8dc307092eeddefc.bindPopup(popup_8c79462a14b708d3a9e9f509244a4f7a)
#         ;
#
#
#
#
#             var marker_2b154a732bc064e6d4f735a3c3918afb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7913ff35b3ad42abf2867261060e047f);
#
#
#         var popup_38b299b55aa93b2065fb33073506de2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc0cd6301c3dc507c7b8a2279c17deac = $(`&lt;div id=&quot;html_bc0cd6301c3dc507c7b8a2279c17deac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_38b299b55aa93b2065fb33073506de2f.setContent(html_bc0cd6301c3dc507c7b8a2279c17deac);
#
#
#
#         marker_2b154a732bc064e6d4f735a3c3918afb.bindPopup(popup_38b299b55aa93b2065fb33073506de2f)
#         ;
#
#
#
#
#             var marker_464fe3c5c8bf75b0f7ee935fed3f367c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7913ff35b3ad42abf2867261060e047f);
#
#
#         var popup_58bf2d80d8704da71f841c4ecd8c8b88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c46c4219a8ca088ee97e2d428330818 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c46c4219a8ca088ee97e2d428330818&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c46c4219a8ca088ee97e2d428330818 = L.map(
#                 &quot;map_8c46c4219a8ca088ee97e2d428330818&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3649fae0a52c11fb128c4200892c4134 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3649fae0a52c11fb128c4200892c4134.addTo(map_8c46c4219a8ca088ee97e2d428330818);
#
#
#             var feature_group_3406339de3001b4cfb82671ce322b148 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3406339de3001b4cfb82671ce322b148.addTo(map_8c46c4219a8ca088ee97e2d428330818);
#
#
#             var feature_group_sub_group_05ab88d491bdd345ef7df8bb114640ee = L.featureGroup.subGroup(
#                 feature_group_3406339de3001b4cfb82671ce322b148
#             );
#
#
#             var marker_b04b9ab09777e5aa96fffcf619ee460d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_05ab88d491bdd345ef7df8bb114640ee);
#
#
#         var popup_3dc0100c52a35fa00016ea32ccf2e188 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1aa8058efefadab8a26f02a7717faa0 = $(`&lt;div id=&quot;html_a1aa8058efefadab8a26f02a7717faa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3dc0100c52a35fa00016ea32ccf2e188.setContent(html_a1aa8058efefadab8a26f02a7717faa0);
#
#
#
#         marker_b04b9ab09777e5aa96fffcf619ee460d.bindPopup(popup_3dc0100c52a35fa00016ea32ccf2e188)
#         ;
#
#
#
#
#             var marker_cbd408a75ac7e37841d650a5b8d5956c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_05ab88d491bdd345ef7df8bb114640ee);
#
#
#         var popup_8dd60d8286d4ce9439dba6353c330808 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e2c82a164c44e188379c3331512632b = $(`&lt;div id=&quot;html_9e2c82a164c44e188379c3331512632b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8dd60d8286d4ce9439dba6353c330808.setContent(html_9e2c82a164c44e188379c3331512632b);
#
#
#
#         marker_cbd408a75ac7e37841d650a5b8d5956c.bindPopup(popup_8dd60d8286d4ce9439dba6353c330808)
#         ;
#
#
#
#
#             var marker_99ce119423b466dd0d3e29cde50ff3b4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_05ab88d491bdd345ef7df8bb114640ee);
#
#
#         var popup_0d4a8020e39586abaafca56d353a13de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09db83bdd80fb12de6484715351a3cff = $(`&lt;div id=&quot;html_09db83bdd80fb12de6484715351a3cff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0d4a8020e39586abaafca56d353a13de.setContent(html_09db83bdd80fb12de6484715351a3cff);
#
#
#
#         marker_99ce119423b466dd0d3e29cde50ff3b4.bindPopup(popup_0d4a8020e39586abaafca56d353a13de)
#         ;
#
#
#
#
#             var marker_a31374331a5a1887709019aff7226a70 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_05ab88d491bdd345ef7df8bb114640ee);
#
#
#         var popup_38df594bd0643d515f8968f3f4ade3d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65dea28a013a75dae970cb7c8a2d8909 = $(`&lt;div id=&quot;html_65dea28a013a75dae970cb7c8a2d8909&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_38df594bd0643d515f8968f3f4ade3d4.setContent(html_65dea28a013a75dae970cb7c8a2d8909);
#
#
#
#         marker_
