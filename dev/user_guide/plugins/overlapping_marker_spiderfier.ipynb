# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ee54d658a7d43757c12883fb12240e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ee54d658a7d43757c12883fb12240e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ee54d658a7d43757c12883fb12240e3 = L.map(
#                 &quot;map_1ee54d658a7d43757c12883fb12240e3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_503701bfcad0d521d28fb9889f206d1f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_503701bfcad0d521d28fb9889f206d1f.addTo(map_1ee54d658a7d43757c12883fb12240e3);
#
#
#             var marker_bc0167c23dc69afab1ad5e92193d6b42 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1ee54d658a7d43757c12883fb12240e3);
#
#
#         var popup_7b3ead5a232e5663e83df8059275dc53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c0c7e9530e9a3c6017aa5b62371577a = $(`&lt;div id=&quot;html_9c0c7e9530e9a3c6017aa5b62371577a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7b3ead5a232e5663e83df8059275dc53.setContent(html_9c0c7e9530e9a3c6017aa5b62371577a);
#
#
#
#         marker_bc0167c23dc69afab1ad5e92193d6b42.bindPopup(popup_7b3ead5a232e5663e83df8059275dc53)
#         ;
#
#
#
#
#             var marker_44e73f027e1d36e4af024c6658f61b08 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1ee54d658a7d43757c12883fb12240e3);
#
#
#         var popup_8b4c56843d07fc358f08ecc7b5749e9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fd193ca9f5a1334cd8e7056e6b92c61 = $(`&lt;div id=&quot;html_6fd193ca9f5a1334cd8e7056e6b92c61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8b4c56843d07fc358f08ecc7b5749e9f.setContent(html_6fd193ca9f5a1334cd8e7056e6b92c61);
#
#
#
#         marker_44e73f027e1d36e4af024c6658f61b08.bindPopup(popup_8b4c56843d07fc358f08ecc7b5749e9f)
#         ;
#
#
#
#
#             var marker_78f69a0ff8a7c9fa1f15a84266c9bb27 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1ee54d658a7d43757c12883fb12240e3);
#
#
#         var popup_a2575b5a1badfd45a63b574781bfa516 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80ef063710f24681a166a3c7811a4651 = $(`&lt;div id=&quot;html_80ef063710f24681a166a3c7811a4651&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a2575b5a1badfd45a63b574781bfa516.setContent(html_80ef063710f24681a166a3c7811a4651);
#
#
#
#         marker_78f69a0ff8a7c9fa1f15a84266c9bb27.bindPopup(popup_a2575b5a1badfd45a63b574781bfa516)
#         ;
#
#
#
#
#             var marker_0372c91e32a8a1fc09e8c4e891ae0f9f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1ee54d658a7d43757c12883fb12240e3);
#
#
#         var popup_ffaaa5dc4539c908ed352a4d547792dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5c9bd43389622dab45c0ef9afb379b8 = $(`&lt;div id=&quot;html_d5c9bd43389622dab45c0ef9afb379b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ffaaa5dc4539c908ed352a4d547792dc.setContent(html_d5c9bd43389622dab45c0ef9afb379b8);
#
#
#
#         marker_0372c91e32a8a1fc09e8c4e891ae0f9f.bindPopup(popup_ffaaa5dc4539c908ed352a4d547792dc)
#         ;
#
#
#
#
#             var marker_f122831f038ea2c86a707d383eb3fff3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1ee54d658a7d43757c12883fb12240e3);
#
#
#         var popup_b191d3a0960b39aebccc10fbafe04d0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8754ba8ea10f1d3080fb16b4ce0c8e83 = $(`&lt;div id=&quot;html_8754ba8ea10f1d3080fb16b4ce0c8e83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b191d3a0960b39aebccc10fbafe04d0b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b6c0f691add1321f3f835a727e18790 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b6c0f691add1321f3f835a727e18790&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b6c0f691add1321f3f835a727e18790 = L.map(
#                 &quot;map_1b6c0f691add1321f3f835a727e18790&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a4bff72df82896c4ca10d2845a99259 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a4bff72df82896c4ca10d2845a99259.addTo(map_1b6c0f691add1321f3f835a727e18790);
#
#
#             var feature_group_d18276c8f90e87725d1ed2a98a9da5a3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_dfdd091e77a04267e429fb0722a1a02c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d18276c8f90e87725d1ed2a98a9da5a3);
#
#
#         var popup_085b8a00a542d7c0f3e8f359e8774cbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9f5519fa1af0bb7fa519768bcb06f4f = $(`&lt;div id=&quot;html_b9f5519fa1af0bb7fa519768bcb06f4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_085b8a00a542d7c0f3e8f359e8774cbc.setContent(html_b9f5519fa1af0bb7fa519768bcb06f4f);
#
#
#
#         marker_dfdd091e77a04267e429fb0722a1a02c.bindPopup(popup_085b8a00a542d7c0f3e8f359e8774cbc)
#         ;
#
#
#
#
#             var marker_10a962d9065290fc5ca9e6305ead243a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d18276c8f90e87725d1ed2a98a9da5a3);
#
#
#         var popup_de591a83f77a4127b1ee8d3935669f20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abc2b828b73b68222da4b0493336832b = $(`&lt;div id=&quot;html_abc2b828b73b68222da4b0493336832b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_de591a83f77a4127b1ee8d3935669f20.setContent(html_abc2b828b73b68222da4b0493336832b);
#
#
#
#         marker_10a962d9065290fc5ca9e6305ead243a.bindPopup(popup_de591a83f77a4127b1ee8d3935669f20)
#         ;
#
#
#
#
#             var marker_d472ea9605ca9abe253bde161e5a018f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d18276c8f90e87725d1ed2a98a9da5a3);
#
#
#         var popup_5118cebfc6ef3f7c2c4fb1d53291bdb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03e09424b35798c94d544387b06ff006 = $(`&lt;div id=&quot;html_03e09424b35798c94d544387b06ff006&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5118cebfc6ef3f7c2c4fb1d53291bdb1.setContent(html_03e09424b35798c94d544387b06ff006);
#
#
#
#         marker_d472ea9605ca9abe253bde161e5a018f.bindPopup(popup_5118cebfc6ef3f7c2c4fb1d53291bdb1)
#         ;
#
#
#
#
#             var marker_16c6ed2fd1ac4c87a6271fde7b5b3e1e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d18276c8f90e87725d1ed2a98a9da5a3);
#
#
#         var popup_cee9d77fd4f070efc684d4906014b7e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44d97fde9aa783655ca9f1956a98b103 = $(`&lt;div id=&quot;html_44d97fde9aa783655ca9f1956a98b103&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cee9d77fd4f070efc684d4906014b7e7.setContent(html_44d97fde9aa783655ca9f1956a98b103);
#
#
#
#         marker_16c6ed2fd1ac4c87a6271fde7b5b3e1e.bindPopup(popup_cee9d77fd4f070efc684d4906014b7e7)
#         ;
#
#
#
#
#             var marker_29f5b7f1e56562a68a5d0b38fb7876c6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d18276c8f90e87725d1ed2a98a9da5a3);
#
#
#         var popup_6122f7c632a4acf4e2a8e7bb8467e245 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dab95e1faa7d2f99999cc654604e8fe3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dab95e1faa7d2f99999cc654604e8fe3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dab95e1faa7d2f99999cc654604e8fe3 = L.map(
#                 &quot;map_dab95e1faa7d2f99999cc654604e8fe3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7489d0fe806d4712fc9ec0a855cec07 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e7489d0fe806d4712fc9ec0a855cec07.addTo(map_dab95e1faa7d2f99999cc654604e8fe3);
#
#
#             var feature_group_679629a2a4345954b525d1ce63ad91af = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_679629a2a4345954b525d1ce63ad91af.addTo(map_dab95e1faa7d2f99999cc654604e8fe3);
#
#
#             var feature_group_sub_group_26fc2afbdc9c3f7016c2d6cc8edca9bc = L.featureGroup.subGroup(
#                 feature_group_679629a2a4345954b525d1ce63ad91af
#             );
#
#
#             var marker_fa9fbb6dc3c59b81b950417651dfa7de = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_26fc2afbdc9c3f7016c2d6cc8edca9bc);
#
#
#         var popup_18b0b666130cd8119d107700b6e659d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bdb859798f5c4b28f8dd16e566d2ccb = $(`&lt;div id=&quot;html_5bdb859798f5c4b28f8dd16e566d2ccb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_18b0b666130cd8119d107700b6e659d9.setContent(html_5bdb859798f5c4b28f8dd16e566d2ccb);
#
#
#
#         marker_fa9fbb6dc3c59b81b950417651dfa7de.bindPopup(popup_18b0b666130cd8119d107700b6e659d9)
#         ;
#
#
#
#
#             var marker_66bec34dab62a5c8fe538e52cc61e499 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_26fc2afbdc9c3f7016c2d6cc8edca9bc);
#
#
#         var popup_04565c27fec45610266a4e94c23e2e41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4aeda0691e8c482cc3cfa3218de4f857 = $(`&lt;div id=&quot;html_4aeda0691e8c482cc3cfa3218de4f857&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_04565c27fec45610266a4e94c23e2e41.setContent(html_4aeda0691e8c482cc3cfa3218de4f857);
#
#
#
#         marker_66bec34dab62a5c8fe538e52cc61e499.bindPopup(popup_04565c27fec45610266a4e94c23e2e41)
#         ;
#
#
#
#
#             var marker_dfc7e7f98dfc201eb84487b202388a54 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_26fc2afbdc9c3f7016c2d6cc8edca9bc);
#
#
#         var popup_b59d5cf02e5e8725636810cb666352fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72ba91096b45f8d5b0624ba20dbf8c6b = $(`&lt;div id=&quot;html_72ba91096b45f8d5b0624ba20dbf8c6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b59d5cf02e5e8725636810cb666352fe.setContent(html_72ba91096b45f8d5b0624ba20dbf8c6b);
#
#
#
#         marker_dfc7e7f98dfc201eb84487b202388a54.bindPopup(popup_b59d5cf02e5e8725636810cb666352fe)
#         ;
#
#
#
#
#             var marker_167feef0b3a900d56fd01800231d99f2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_26fc2afbdc9c3f7016c2d6cc8edca9bc);
#
#
#         var popup_cdef463f07d1c3e0dd55d777c8604d02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95cf4a69aba869d49c93e9b2be2d449f = $(`&lt;div id=&quot;html_95cf4a69aba869d49c93e9b2be2d449f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_cdef463f07d1c3e0dd55d777c8604d02.setContent(html_95cf4a69aba869d49c93e9b2be2d449f);
#
#
#
#         marker_
