# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_879d36db396bd0e0831ca35a6c83a20c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_879d36db396bd0e0831ca35a6c83a20c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_879d36db396bd0e0831ca35a6c83a20c = L.map(
#                 &quot;map_879d36db396bd0e0831ca35a6c83a20c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c595095de807ca35e8bf197433af6ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5c595095de807ca35e8bf197433af6ef.addTo(map_879d36db396bd0e0831ca35a6c83a20c);
#
#
#             var marker_79cb429abcf42897e41a267730702f06 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_879d36db396bd0e0831ca35a6c83a20c);
#
#
#         var popup_b50e25368ccc6e2bb3ca361d7e554dab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fd1a4eb27111170915d4d96de7f94ec = $(`&lt;div id=&quot;html_1fd1a4eb27111170915d4d96de7f94ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b50e25368ccc6e2bb3ca361d7e554dab.setContent(html_1fd1a4eb27111170915d4d96de7f94ec);
#
#
#
#         marker_79cb429abcf42897e41a267730702f06.bindPopup(popup_b50e25368ccc6e2bb3ca361d7e554dab)
#         ;
#
#
#
#
#             var marker_d8b7eb9575ce42769f016428d583037d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_879d36db396bd0e0831ca35a6c83a20c);
#
#
#         var popup_886ccf9e31805ecd0e6fd7d585401a35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e5829f757a66abb26d42a4d01890e55 = $(`&lt;div id=&quot;html_1e5829f757a66abb26d42a4d01890e55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_886ccf9e31805ecd0e6fd7d585401a35.setContent(html_1e5829f757a66abb26d42a4d01890e55);
#
#
#
#         marker_d8b7eb9575ce42769f016428d583037d.bindPopup(popup_886ccf9e31805ecd0e6fd7d585401a35)
#         ;
#
#
#
#
#             var marker_6f57bc1c5823a15dc2e67b5e2ea6a415 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_879d36db396bd0e0831ca35a6c83a20c);
#
#
#         var popup_885e1c04478dea0a9701e0acc8593e5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2054ff08b881c1105e7489624e1ec997 = $(`&lt;div id=&quot;html_2054ff08b881c1105e7489624e1ec997&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_885e1c04478dea0a9701e0acc8593e5a.setContent(html_2054ff08b881c1105e7489624e1ec997);
#
#
#
#         marker_6f57bc1c5823a15dc2e67b5e2ea6a415.bindPopup(popup_885e1c04478dea0a9701e0acc8593e5a)
#         ;
#
#
#
#
#             var marker_f39ce60bb04b6f00d2458135c8d47cbb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_879d36db396bd0e0831ca35a6c83a20c);
#
#
#         var popup_4e1472269d5420fde499b460f19a04a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9426e8af92cd3da9454df884c0e9dfd = $(`&lt;div id=&quot;html_c9426e8af92cd3da9454df884c0e9dfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4e1472269d5420fde499b460f19a04a7.setContent(html_c9426e8af92cd3da9454df884c0e9dfd);
#
#
#
#         marker_f39ce60bb04b6f00d2458135c8d47cbb.bindPopup(popup_4e1472269d5420fde499b460f19a04a7)
#         ;
#
#
#
#
#             var marker_4d020a79d188b5bf3261f583b3e3b958 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_879d36db396bd0e0831ca35a6c83a20c);
#
#
#         var popup_92885b412c74a98b46e7a71e489757f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fa830b4358b973e8f0d33345ca33a3a = $(`&lt;div id=&quot;html_6fa830b4358b973e8f0d33345ca33a3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_92885b412c74a98b46e7a71e489757f2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48fbb9b166caa93818780bfa2c064406 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48fbb9b166caa93818780bfa2c064406&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48fbb9b166caa93818780bfa2c064406 = L.map(
#                 &quot;map_48fbb9b166caa93818780bfa2c064406&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f2b458f8cb1b370a858b53fb808fba7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f2b458f8cb1b370a858b53fb808fba7.addTo(map_48fbb9b166caa93818780bfa2c064406);
#
#
#             var feature_group_beb20f838b6ed03c488f6e1d9a67fc43 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a7b43f013e697b5ad7bf6aedb7d5861c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_beb20f838b6ed03c488f6e1d9a67fc43);
#
#
#         var popup_916ae1d4a449643c467bd1d37044ae7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_898384a73ca1b71a019d25b38b836c8e = $(`&lt;div id=&quot;html_898384a73ca1b71a019d25b38b836c8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_916ae1d4a449643c467bd1d37044ae7f.setContent(html_898384a73ca1b71a019d25b38b836c8e);
#
#
#
#         marker_a7b43f013e697b5ad7bf6aedb7d5861c.bindPopup(popup_916ae1d4a449643c467bd1d37044ae7f)
#         ;
#
#
#
#
#             var marker_64a4b32d6b33fed55948c08519b9e8c7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_beb20f838b6ed03c488f6e1d9a67fc43);
#
#
#         var popup_06e5c9422e7a0b949fc17fb7ccde5d2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ca4193d3419eaa77b0b3c3040838dad = $(`&lt;div id=&quot;html_7ca4193d3419eaa77b0b3c3040838dad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_06e5c9422e7a0b949fc17fb7ccde5d2b.setContent(html_7ca4193d3419eaa77b0b3c3040838dad);
#
#
#
#         marker_64a4b32d6b33fed55948c08519b9e8c7.bindPopup(popup_06e5c9422e7a0b949fc17fb7ccde5d2b)
#         ;
#
#
#
#
#             var marker_1cc0f1f799079b24c4d7adc694fe413e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_beb20f838b6ed03c488f6e1d9a67fc43);
#
#
#         var popup_130db81f015b267dbc443f5f16df74b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c38989a1af1ba0a041b999a72fd36e3 = $(`&lt;div id=&quot;html_5c38989a1af1ba0a041b999a72fd36e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_130db81f015b267dbc443f5f16df74b9.setContent(html_5c38989a1af1ba0a041b999a72fd36e3);
#
#
#
#         marker_1cc0f1f799079b24c4d7adc694fe413e.bindPopup(popup_130db81f015b267dbc443f5f16df74b9)
#         ;
#
#
#
#
#             var marker_f71023311e2ce131e6dc0aac2b1f31f3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_beb20f838b6ed03c488f6e1d9a67fc43);
#
#
#         var popup_509f5a2abc3abb4c43ca2fb11013bfe7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f2a0ab905167fce51416d0ef8ade72e = $(`&lt;div id=&quot;html_7f2a0ab905167fce51416d0ef8ade72e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_509f5a2abc3abb4c43ca2fb11013bfe7.setContent(html_7f2a0ab905167fce51416d0ef8ade72e);
#
#
#
#         marker_f71023311e2ce131e6dc0aac2b1f31f3.bindPopup(popup_509f5a2abc3abb4c43ca2fb11013bfe7)
#         ;
#
#
#
#
#             var marker_ab5122265a1f874f676ea4f435b28f70 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_beb20f838b6ed03c488f6e1d9a67fc43);
#
#
#         var popup_1c39e0715469efa5812fbf59892b7ac1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7dc803efbdb276f48c1a6f4ca0b73e69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7dc803efbdb276f48c1a6f4ca0b73e69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7dc803efbdb276f48c1a6f4ca0b73e69 = L.map(
#                 &quot;map_7dc803efbdb276f48c1a6f4ca0b73e69&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ad9979e1d75dac0d15bf2518da1259e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ad9979e1d75dac0d15bf2518da1259e.addTo(map_7dc803efbdb276f48c1a6f4ca0b73e69);
#
#
#             var feature_group_885aa88b158e9775d06a3a64369453c0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_885aa88b158e9775d06a3a64369453c0.addTo(map_7dc803efbdb276f48c1a6f4ca0b73e69);
#
#
#             var feature_group_sub_group_94a93917f880a44b72d3c5547ea19900 = L.featureGroup.subGroup(
#                 feature_group_885aa88b158e9775d06a3a64369453c0
#             );
#
#
#             var marker_66493207aadfd4ee0bbcdfafe4cb7004 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_94a93917f880a44b72d3c5547ea19900);
#
#
#         var popup_26eca510a3fe34ecfbf18f4a196c6b6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43ddfe27b864c7e30b585c57ce9e3b01 = $(`&lt;div id=&quot;html_43ddfe27b864c7e30b585c57ce9e3b01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_26eca510a3fe34ecfbf18f4a196c6b6b.setContent(html_43ddfe27b864c7e30b585c57ce9e3b01);
#
#
#
#         marker_66493207aadfd4ee0bbcdfafe4cb7004.bindPopup(popup_26eca510a3fe34ecfbf18f4a196c6b6b)
#         ;
#
#
#
#
#             var marker_90c23fd303a2375302bc31f2e3adfda7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_94a93917f880a44b72d3c5547ea19900);
#
#
#         var popup_c9ad1962e4ff2c49f06b3f7585b90ce5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98bebbb3bfd3f411981752988652dcf2 = $(`&lt;div id=&quot;html_98bebbb3bfd3f411981752988652dcf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c9ad1962e4ff2c49f06b3f7585b90ce5.setContent(html_98bebbb3bfd3f411981752988652dcf2);
#
#
#
#         marker_90c23fd303a2375302bc31f2e3adfda7.bindPopup(popup_c9ad1962e4ff2c49f06b3f7585b90ce5)
#         ;
#
#
#
#
#             var marker_2220609d00f895214c8b0094336fd2c0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_94a93917f880a44b72d3c5547ea19900);
#
#
#         var popup_4b675efc22dad06b4d33acc91d968829 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94d514f657271aace420796e0cf8cd83 = $(`&lt;div id=&quot;html_94d514f657271aace420796e0cf8cd83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4b675efc22dad06b4d33acc91d968829.setContent(html_94d514f657271aace420796e0cf8cd83);
#
#
#
#         marker_2220609d00f895214c8b0094336fd2c0.bindPopup(popup_4b675efc22dad06b4d33acc91d968829)
#         ;
#
#
#
#
#             var marker_d538119a457de73e4374c59595afec8f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_94a93917f880a44b72d3c5547ea19900);
#
#
#         var popup_84c6d47f3b411e36333e462d07254759 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afbe39be676dee6dfe96934ccf9cede2 = $(`&lt;div id=&quot;html_afbe39be676dee6dfe96934ccf9cede2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_84c6d47f3b411e36333e462d07254759.setContent(html_afbe39be676dee6dfe96934ccf9cede2);
#
#
#
#         marker_
