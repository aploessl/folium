# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ceadcaa267f06dea3252b348a6dfafc4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ceadcaa267f06dea3252b348a6dfafc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ceadcaa267f06dea3252b348a6dfafc4 = L.map(
#                 &quot;map_ceadcaa267f06dea3252b348a6dfafc4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b0b8086ebf51a43f7f172e334114820 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8b0b8086ebf51a43f7f172e334114820.addTo(map_ceadcaa267f06dea3252b348a6dfafc4);
#
#
#             var marker_ef614f9cbdc942c4e9aa8829ced50304 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ceadcaa267f06dea3252b348a6dfafc4);
#
#
#         var popup_49c86914e0db54e5db1597eaab2574ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d902999d79c46e3c0274ea17f37c6d9 = $(`&lt;div id=&quot;html_1d902999d79c46e3c0274ea17f37c6d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_49c86914e0db54e5db1597eaab2574ec.setContent(html_1d902999d79c46e3c0274ea17f37c6d9);
#
#
#
#         marker_ef614f9cbdc942c4e9aa8829ced50304.bindPopup(popup_49c86914e0db54e5db1597eaab2574ec)
#         ;
#
#
#
#
#             var marker_d0311cda4472418a8f34302ba2cacf74 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ceadcaa267f06dea3252b348a6dfafc4);
#
#
#         var popup_dfe4ebf0f00ebba28fcd39476888653d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_928168a9119a84bf34b48226c54da029 = $(`&lt;div id=&quot;html_928168a9119a84bf34b48226c54da029&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dfe4ebf0f00ebba28fcd39476888653d.setContent(html_928168a9119a84bf34b48226c54da029);
#
#
#
#         marker_d0311cda4472418a8f34302ba2cacf74.bindPopup(popup_dfe4ebf0f00ebba28fcd39476888653d)
#         ;
#
#
#
#
#             var marker_fb0202afd19c75b25ed7e851e40e5509 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ceadcaa267f06dea3252b348a6dfafc4);
#
#
#         var popup_33d9fb1d5b33fe85f3415b306b2c1c96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b9e6d2b808479d4620fc3b662a1388f = $(`&lt;div id=&quot;html_4b9e6d2b808479d4620fc3b662a1388f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_33d9fb1d5b33fe85f3415b306b2c1c96.setContent(html_4b9e6d2b808479d4620fc3b662a1388f);
#
#
#
#         marker_fb0202afd19c75b25ed7e851e40e5509.bindPopup(popup_33d9fb1d5b33fe85f3415b306b2c1c96)
#         ;
#
#
#
#
#             var marker_8aa5468bf507050569728bfa615e6f03 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ceadcaa267f06dea3252b348a6dfafc4);
#
#
#         var popup_561fb68c2c3a72c365487dda3539c0c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_448cc6107693473d3ccf979d1b3258e9 = $(`&lt;div id=&quot;html_448cc6107693473d3ccf979d1b3258e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_561fb68c2c3a72c365487dda3539c0c3.setContent(html_448cc6107693473d3ccf979d1b3258e9);
#
#
#
#         marker_8aa5468bf507050569728bfa615e6f03.bindPopup(popup_561fb68c2c3a72c365487dda3539c0c3)
#         ;
#
#
#
#
#             var marker_3d7a251324633b73416f44ee567fc13f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ceadcaa267f06dea3252b348a6dfafc4);
#
#
#         var popup_33795fe04d21d097c68ad58757373466 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f86d8d1f3504a9db9aa2066527e6878e = $(`&lt;div id=&quot;html_f86d8d1f3504a9db9aa2066527e6878e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_33795fe04d21d097c68ad58757373466.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d548f7c5f709aedcd89e58b6f1354b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d548f7c5f709aedcd89e58b6f1354b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d548f7c5f709aedcd89e58b6f1354b0 = L.map(
#                 &quot;map_3d548f7c5f709aedcd89e58b6f1354b0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d37abeac71805cb5ef7fca14c25adbe7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d37abeac71805cb5ef7fca14c25adbe7.addTo(map_3d548f7c5f709aedcd89e58b6f1354b0);
#
#
#             var feature_group_937aa3db8350841b647770b25f04d4bc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a3ff9f5fc8b5438592ba0208b1dc23b7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_937aa3db8350841b647770b25f04d4bc);
#
#
#         var popup_e4de722b8fbf2d393568006745d1b130 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_533ccf9e78bdd5dd11f4b3096e960120 = $(`&lt;div id=&quot;html_533ccf9e78bdd5dd11f4b3096e960120&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e4de722b8fbf2d393568006745d1b130.setContent(html_533ccf9e78bdd5dd11f4b3096e960120);
#
#
#
#         marker_a3ff9f5fc8b5438592ba0208b1dc23b7.bindPopup(popup_e4de722b8fbf2d393568006745d1b130)
#         ;
#
#
#
#
#             var marker_a0baabb602854a8e5be18e7c03af5c6b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_937aa3db8350841b647770b25f04d4bc);
#
#
#         var popup_418deff93f3d3a94c2189c9c427023c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_617008fe20ca06fe2de6afd706f9ecfa = $(`&lt;div id=&quot;html_617008fe20ca06fe2de6afd706f9ecfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_418deff93f3d3a94c2189c9c427023c3.setContent(html_617008fe20ca06fe2de6afd706f9ecfa);
#
#
#
#         marker_a0baabb602854a8e5be18e7c03af5c6b.bindPopup(popup_418deff93f3d3a94c2189c9c427023c3)
#         ;
#
#
#
#
#             var marker_bfe5ab0777c33e27f69937f2dc0865e5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_937aa3db8350841b647770b25f04d4bc);
#
#
#         var popup_654150c94f43eda7c12f5f39b54ee18f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25552456d77aae23979d746f06a6876f = $(`&lt;div id=&quot;html_25552456d77aae23979d746f06a6876f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_654150c94f43eda7c12f5f39b54ee18f.setContent(html_25552456d77aae23979d746f06a6876f);
#
#
#
#         marker_bfe5ab0777c33e27f69937f2dc0865e5.bindPopup(popup_654150c94f43eda7c12f5f39b54ee18f)
#         ;
#
#
#
#
#             var marker_eeac1ce206e27418348be61ba82eff7b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_937aa3db8350841b647770b25f04d4bc);
#
#
#         var popup_d273acd87bd82f8989dbe0bf5c664770 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6f078e3ccca1880f9b36b1c85787c6d = $(`&lt;div id=&quot;html_a6f078e3ccca1880f9b36b1c85787c6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d273acd87bd82f8989dbe0bf5c664770.setContent(html_a6f078e3ccca1880f9b36b1c85787c6d);
#
#
#
#         marker_eeac1ce206e27418348be61ba82eff7b.bindPopup(popup_d273acd87bd82f8989dbe0bf5c664770)
#         ;
#
#
#
#
#             var marker_79547d75765b1f39f4d545451fbd893a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_937aa3db8350841b647770b25f04d4bc);
#
#
#         var popup_9bbf823237aaa25db14db044badee202 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7970fe4100a8cfd8b7623c91661046f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7970fe4100a8cfd8b7623c91661046f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7970fe4100a8cfd8b7623c91661046f = L.map(
#                 &quot;map_d7970fe4100a8cfd8b7623c91661046f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b9d48919d6adbbebf4922bd8d5c4d2b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b9d48919d6adbbebf4922bd8d5c4d2b.addTo(map_d7970fe4100a8cfd8b7623c91661046f);
#
#
#             var feature_group_f16c7b6fe34045bce6273105de1e0ae3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f16c7b6fe34045bce6273105de1e0ae3.addTo(map_d7970fe4100a8cfd8b7623c91661046f);
#
#
#             var feature_group_sub_group_d9c764e2a4efb50f6306a5b2f0adeaeb = L.featureGroup.subGroup(
#                 feature_group_f16c7b6fe34045bce6273105de1e0ae3
#             );
#
#
#             var marker_c73a1daadce8fe95369d90b67ad4d4e1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d9c764e2a4efb50f6306a5b2f0adeaeb);
#
#
#         var popup_6f7385993329ca2f80a6e6d682b9d795 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0e25b94030fadfa5450c800132e3ebf = $(`&lt;div id=&quot;html_d0e25b94030fadfa5450c800132e3ebf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6f7385993329ca2f80a6e6d682b9d795.setContent(html_d0e25b94030fadfa5450c800132e3ebf);
#
#
#
#         marker_c73a1daadce8fe95369d90b67ad4d4e1.bindPopup(popup_6f7385993329ca2f80a6e6d682b9d795)
#         ;
#
#
#
#
#             var marker_3e0d24c4e329ec85bf973f2c85af62cd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d9c764e2a4efb50f6306a5b2f0adeaeb);
#
#
#         var popup_a80864a0fbe3dc0dafbb76cf178858c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75d5c8d20199aaa8791313400365f6b9 = $(`&lt;div id=&quot;html_75d5c8d20199aaa8791313400365f6b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a80864a0fbe3dc0dafbb76cf178858c8.setContent(html_75d5c8d20199aaa8791313400365f6b9);
#
#
#
#         marker_3e0d24c4e329ec85bf973f2c85af62cd.bindPopup(popup_a80864a0fbe3dc0dafbb76cf178858c8)
#         ;
#
#
#
#
#             var marker_679afb277c1bec6b05046e270b8b00f4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d9c764e2a4efb50f6306a5b2f0adeaeb);
#
#
#         var popup_e3d9e68fb47e4ad76a2698f112a1a50c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9780d39e69e8e902252fa28ad8c36b1 = $(`&lt;div id=&quot;html_d9780d39e69e8e902252fa28ad8c36b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e3d9e68fb47e4ad76a2698f112a1a50c.setContent(html_d9780d39e69e8e902252fa28ad8c36b1);
#
#
#
#         marker_679afb277c1bec6b05046e270b8b00f4.bindPopup(popup_e3d9e68fb47e4ad76a2698f112a1a50c)
#         ;
#
#
#
#
#             var marker_3329d22085ea2cd10a0528f80041b0fd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d9c764e2a4efb50f6306a5b2f0adeaeb);
#
#
#         var popup_829bdc6ef7dd888a681c5f5083a290f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fc5f29dac005eda6e60f56970edb007 = $(`&lt;div id=&quot;html_6fc5f29dac005eda6e60f56970edb007&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_829bdc6ef7dd888a681c5f5083a290f8.setContent(html_6fc5f29dac005eda6e60f56970edb007);
#
#
#
#         marker_
