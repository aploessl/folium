# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82515ead819f16e0d93f85386943e0e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82515ead819f16e0d93f85386943e0e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82515ead819f16e0d93f85386943e0e5 = L.map(
#                 &quot;map_82515ead819f16e0d93f85386943e0e5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70a1fd536bc36241cdda88e97fd531a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70a1fd536bc36241cdda88e97fd531a5.addTo(map_82515ead819f16e0d93f85386943e0e5);
#
#
#             var marker_a27c82dabe721a5aab231b45534719e0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_82515ead819f16e0d93f85386943e0e5);
#
#
#         var popup_cc073ac29a47efe9c58fb01026713f95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ded40d431fd680430eb48e7b5e981651 = $(`&lt;div id=&quot;html_ded40d431fd680430eb48e7b5e981651&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_cc073ac29a47efe9c58fb01026713f95.setContent(html_ded40d431fd680430eb48e7b5e981651);
#
#
#
#         marker_a27c82dabe721a5aab231b45534719e0.bindPopup(popup_cc073ac29a47efe9c58fb01026713f95)
#         ;
#
#
#
#
#             var marker_ae244ce705acdb3690e0779d0e432039 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_82515ead819f16e0d93f85386943e0e5);
#
#
#         var popup_f6d575f7c6239440e3850f58b2bc4e6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5eee9047d217308346f09b00ec0b1892 = $(`&lt;div id=&quot;html_5eee9047d217308346f09b00ec0b1892&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f6d575f7c6239440e3850f58b2bc4e6f.setContent(html_5eee9047d217308346f09b00ec0b1892);
#
#
#
#         marker_ae244ce705acdb3690e0779d0e432039.bindPopup(popup_f6d575f7c6239440e3850f58b2bc4e6f)
#         ;
#
#
#
#
#             var marker_a28979240441cf533c86a2668f8a773c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_82515ead819f16e0d93f85386943e0e5);
#
#
#         var popup_3b7d5aca94add88626dc092de5599fc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c87a72fd0ae07819218d0b2651c7e9b = $(`&lt;div id=&quot;html_4c87a72fd0ae07819218d0b2651c7e9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3b7d5aca94add88626dc092de5599fc8.setContent(html_4c87a72fd0ae07819218d0b2651c7e9b);
#
#
#
#         marker_a28979240441cf533c86a2668f8a773c.bindPopup(popup_3b7d5aca94add88626dc092de5599fc8)
#         ;
#
#
#
#
#             var marker_6f6031979a023126807e2e225750c11d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_82515ead819f16e0d93f85386943e0e5);
#
#
#         var popup_3bf567dd864d2bcbfe487fb0caf78ed3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d592f1d821e5b8c7327b29bdff3e0172 = $(`&lt;div id=&quot;html_d592f1d821e5b8c7327b29bdff3e0172&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3bf567dd864d2bcbfe487fb0caf78ed3.setContent(html_d592f1d821e5b8c7327b29bdff3e0172);
#
#
#
#         marker_6f6031979a023126807e2e225750c11d.bindPopup(popup_3bf567dd864d2bcbfe487fb0caf78ed3)
#         ;
#
#
#
#
#             var marker_9a6a7d7e9f38125359d4814499e154bf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_82515ead819f16e0d93f85386943e0e5);
#
#
#         var popup_77368de3933a5f38030b88f419f214ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_096df71733892510c14b1573a6f01e0d = $(`&lt;div id=&quot;html_096df71733892510c14b1573a6f01e0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_77368de3933a5f38030b88f419f214ec.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7142afba09ae25171b4c64dc2d98ac54 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7142afba09ae25171b4c64dc2d98ac54&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7142afba09ae25171b4c64dc2d98ac54 = L.map(
#                 &quot;map_7142afba09ae25171b4c64dc2d98ac54&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15a53786ee229ae5d21ed72854bea4f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15a53786ee229ae5d21ed72854bea4f9.addTo(map_7142afba09ae25171b4c64dc2d98ac54);
#
#
#             var feature_group_f511caf5b069be322503b57b2d1648c7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2b89de15e8b2dbc79f7ac8e7317b964f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f511caf5b069be322503b57b2d1648c7);
#
#
#         var popup_1ca79410a1fe2a0cd89d0b81ee0ea78f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9598288319b0249100aca9bdc4c8756 = $(`&lt;div id=&quot;html_e9598288319b0249100aca9bdc4c8756&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1ca79410a1fe2a0cd89d0b81ee0ea78f.setContent(html_e9598288319b0249100aca9bdc4c8756);
#
#
#
#         marker_2b89de15e8b2dbc79f7ac8e7317b964f.bindPopup(popup_1ca79410a1fe2a0cd89d0b81ee0ea78f)
#         ;
#
#
#
#
#             var marker_5be690569b5b66ff18513c1c6051c815 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f511caf5b069be322503b57b2d1648c7);
#
#
#         var popup_09b49d0a826e1ffb8c5bdcda9a6c2d1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b26b6d682b7120e2b3575f88e2892d7c = $(`&lt;div id=&quot;html_b26b6d682b7120e2b3575f88e2892d7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_09b49d0a826e1ffb8c5bdcda9a6c2d1b.setContent(html_b26b6d682b7120e2b3575f88e2892d7c);
#
#
#
#         marker_5be690569b5b66ff18513c1c6051c815.bindPopup(popup_09b49d0a826e1ffb8c5bdcda9a6c2d1b)
#         ;
#
#
#
#
#             var marker_6b99cc15a49ac3a26d0601f790c96639 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f511caf5b069be322503b57b2d1648c7);
#
#
#         var popup_e65f169721aa89e4b849492428126c68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cb49436c2a2fa6476027bcb5cbad166 = $(`&lt;div id=&quot;html_7cb49436c2a2fa6476027bcb5cbad166&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e65f169721aa89e4b849492428126c68.setContent(html_7cb49436c2a2fa6476027bcb5cbad166);
#
#
#
#         marker_6b99cc15a49ac3a26d0601f790c96639.bindPopup(popup_e65f169721aa89e4b849492428126c68)
#         ;
#
#
#
#
#             var marker_d0648353fa72387ff9d768f7ef94cde3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f511caf5b069be322503b57b2d1648c7);
#
#
#         var popup_cf796f48517fa4669b32a1cdefb229e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8dbd665f40bc7cebda3a72df65f2d58 = $(`&lt;div id=&quot;html_b8dbd665f40bc7cebda3a72df65f2d58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cf796f48517fa4669b32a1cdefb229e6.setContent(html_b8dbd665f40bc7cebda3a72df65f2d58);
#
#
#
#         marker_d0648353fa72387ff9d768f7ef94cde3.bindPopup(popup_cf796f48517fa4669b32a1cdefb229e6)
#         ;
#
#
#
#
#             var marker_b8e4260eb8dd18a4ab16ad61bb59d628 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f511caf5b069be322503b57b2d1648c7);
#
#
#         var popup_46faf5e39abc233a48e385584a50a4e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_934399b898ad563383249294fd983054 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_934399b898ad563383249294fd983054&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_934399b898ad563383249294fd983054 = L.map(
#                 &quot;map_934399b898ad563383249294fd983054&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09037e0e9d4239448bcdab7529c1a277 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09037e0e9d4239448bcdab7529c1a277.addTo(map_934399b898ad563383249294fd983054);
#
#
#             var feature_group_511a5bb5f3455d68094e5797e7b7bbfd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_511a5bb5f3455d68094e5797e7b7bbfd.addTo(map_934399b898ad563383249294fd983054);
#
#
#             var feature_group_sub_group_fd96db4a941afdea0e8108153a949089 = L.featureGroup.subGroup(
#                 feature_group_511a5bb5f3455d68094e5797e7b7bbfd
#             );
#
#
#             var marker_2ca85ea079eb6ae9a8bd78be91c859f4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd96db4a941afdea0e8108153a949089);
#
#
#         var popup_56f3222fb4da216fceb70d6ac705eeae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9556f9e09c89375a11ae454ec15fc760 = $(`&lt;div id=&quot;html_9556f9e09c89375a11ae454ec15fc760&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_56f3222fb4da216fceb70d6ac705eeae.setContent(html_9556f9e09c89375a11ae454ec15fc760);
#
#
#
#         marker_2ca85ea079eb6ae9a8bd78be91c859f4.bindPopup(popup_56f3222fb4da216fceb70d6ac705eeae)
#         ;
#
#
#
#
#             var marker_dee2d7817d5f7d538642c2be86f3e4c1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd96db4a941afdea0e8108153a949089);
#
#
#         var popup_41c5f994f84c9d94b2253e412d7ed48a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1db6c5e6bad7a894c0357221dd3ec7c0 = $(`&lt;div id=&quot;html_1db6c5e6bad7a894c0357221dd3ec7c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_41c5f994f84c9d94b2253e412d7ed48a.setContent(html_1db6c5e6bad7a894c0357221dd3ec7c0);
#
#
#
#         marker_dee2d7817d5f7d538642c2be86f3e4c1.bindPopup(popup_41c5f994f84c9d94b2253e412d7ed48a)
#         ;
#
#
#
#
#             var marker_80c89a1fe080836d128fafade939d054 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd96db4a941afdea0e8108153a949089);
#
#
#         var popup_877ab2fe1f3d8c4c2b409e764e2f69a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af7575fa2739464bc9f39c0c15f4cabd = $(`&lt;div id=&quot;html_af7575fa2739464bc9f39c0c15f4cabd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_877ab2fe1f3d8c4c2b409e764e2f69a8.setContent(html_af7575fa2739464bc9f39c0c15f4cabd);
#
#
#
#         marker_80c89a1fe080836d128fafade939d054.bindPopup(popup_877ab2fe1f3d8c4c2b409e764e2f69a8)
#         ;
#
#
#
#
#             var marker_3c3eca42fc36ca10d1e147a3aeb0150d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd96db4a941afdea0e8108153a949089);
#
#
#         var popup_05020ede8c96348fe56b2aea1ae1128d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca18a7ae3e69207460c6c77184ea0ab7 = $(`&lt;div id=&quot;html_ca18a7ae3e69207460c6c77184ea0ab7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_05020ede8c96348fe56b2aea1ae1128d.setContent(html_ca18a7ae3e69207460c6c77184ea0ab7);
#
#
#
#         marker_
