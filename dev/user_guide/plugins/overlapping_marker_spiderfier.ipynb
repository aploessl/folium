# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40df28ae9125680de1c09e685ca663dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40df28ae9125680de1c09e685ca663dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40df28ae9125680de1c09e685ca663dd = L.map(
#                 &quot;map_40df28ae9125680de1c09e685ca663dd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f32ede3f26043a263ddda09181a1342 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f32ede3f26043a263ddda09181a1342.addTo(map_40df28ae9125680de1c09e685ca663dd);
#
#
#             var marker_fb4a0c27636ba0e161ce77ecc0319492 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_40df28ae9125680de1c09e685ca663dd);
#
#
#         var popup_0aaa2ea766b54d25ebf358a379249200 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de4e10895919eaec0172ed479a3fd76c = $(`&lt;div id=&quot;html_de4e10895919eaec0172ed479a3fd76c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0aaa2ea766b54d25ebf358a379249200.setContent(html_de4e10895919eaec0172ed479a3fd76c);
#
#
#
#         marker_fb4a0c27636ba0e161ce77ecc0319492.bindPopup(popup_0aaa2ea766b54d25ebf358a379249200)
#         ;
#
#
#
#
#             var marker_f86a030d1350e4936195b759803a8d46 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_40df28ae9125680de1c09e685ca663dd);
#
#
#         var popup_e569c4a58259040481b31893a216cc38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_933e2b0998c4d9d14f842b766b9631b1 = $(`&lt;div id=&quot;html_933e2b0998c4d9d14f842b766b9631b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e569c4a58259040481b31893a216cc38.setContent(html_933e2b0998c4d9d14f842b766b9631b1);
#
#
#
#         marker_f86a030d1350e4936195b759803a8d46.bindPopup(popup_e569c4a58259040481b31893a216cc38)
#         ;
#
#
#
#
#             var marker_497f0373e4e2c7ec170f03dd7cf57693 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_40df28ae9125680de1c09e685ca663dd);
#
#
#         var popup_342b251669464f60456fa11e12c89daa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf9f07c338cb3cab5ea8a128ad128e10 = $(`&lt;div id=&quot;html_cf9f07c338cb3cab5ea8a128ad128e10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_342b251669464f60456fa11e12c89daa.setContent(html_cf9f07c338cb3cab5ea8a128ad128e10);
#
#
#
#         marker_497f0373e4e2c7ec170f03dd7cf57693.bindPopup(popup_342b251669464f60456fa11e12c89daa)
#         ;
#
#
#
#
#             var marker_4cf6f006a3fc1a061138e8f0e456449a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_40df28ae9125680de1c09e685ca663dd);
#
#
#         var popup_02c7f62967b8ca0ab4fd4f16674ad894 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27dfefc35844576abb475c9b0cc1d8da = $(`&lt;div id=&quot;html_27dfefc35844576abb475c9b0cc1d8da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_02c7f62967b8ca0ab4fd4f16674ad894.setContent(html_27dfefc35844576abb475c9b0cc1d8da);
#
#
#
#         marker_4cf6f006a3fc1a061138e8f0e456449a.bindPopup(popup_02c7f62967b8ca0ab4fd4f16674ad894)
#         ;
#
#
#
#
#             var marker_97825e611cc3749a6035fb24e7f57e3f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_40df28ae9125680de1c09e685ca663dd);
#
#
#         var popup_eced768353dd19f200b737ea5daec531 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68f9f0dc1cbba5b62fa251c869b0e9e7 = $(`&lt;div id=&quot;html_68f9f0dc1cbba5b62fa251c869b0e9e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_eced768353dd19f200b737ea5daec531.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae069ab4c4fa3293dcf96c870a8b2dba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae069ab4c4fa3293dcf96c870a8b2dba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae069ab4c4fa3293dcf96c870a8b2dba = L.map(
#                 &quot;map_ae069ab4c4fa3293dcf96c870a8b2dba&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3519968ff7a0217056a5ba5c9bca59a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3519968ff7a0217056a5ba5c9bca59a4.addTo(map_ae069ab4c4fa3293dcf96c870a8b2dba);
#
#
#             var feature_group_75c87b45b9f8f058ba24652ac0429c8e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1584ab4b00b343cefc458026294d2e3c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_75c87b45b9f8f058ba24652ac0429c8e);
#
#
#         var popup_deb6e5638d05859b4e99c9f59536db65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_147bfce682a50a42470b95f4981bdb29 = $(`&lt;div id=&quot;html_147bfce682a50a42470b95f4981bdb29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_deb6e5638d05859b4e99c9f59536db65.setContent(html_147bfce682a50a42470b95f4981bdb29);
#
#
#
#         marker_1584ab4b00b343cefc458026294d2e3c.bindPopup(popup_deb6e5638d05859b4e99c9f59536db65)
#         ;
#
#
#
#
#             var marker_33f6ed2b79988388b33505cb8edeab5b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_75c87b45b9f8f058ba24652ac0429c8e);
#
#
#         var popup_94a9578107c169f329bdd97f19bf7364 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c837c4ff0ad6fd64f682322f5b51371 = $(`&lt;div id=&quot;html_6c837c4ff0ad6fd64f682322f5b51371&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_94a9578107c169f329bdd97f19bf7364.setContent(html_6c837c4ff0ad6fd64f682322f5b51371);
#
#
#
#         marker_33f6ed2b79988388b33505cb8edeab5b.bindPopup(popup_94a9578107c169f329bdd97f19bf7364)
#         ;
#
#
#
#
#             var marker_895400aeb39b59e8b88722ead2680a7f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_75c87b45b9f8f058ba24652ac0429c8e);
#
#
#         var popup_0d8cb50f2399bc3c2aa4bf15f1141548 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6107ad18fd97cc27dde3978b36ea57b2 = $(`&lt;div id=&quot;html_6107ad18fd97cc27dde3978b36ea57b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0d8cb50f2399bc3c2aa4bf15f1141548.setContent(html_6107ad18fd97cc27dde3978b36ea57b2);
#
#
#
#         marker_895400aeb39b59e8b88722ead2680a7f.bindPopup(popup_0d8cb50f2399bc3c2aa4bf15f1141548)
#         ;
#
#
#
#
#             var marker_2800714818ee7219a7d09a9998fa1646 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_75c87b45b9f8f058ba24652ac0429c8e);
#
#
#         var popup_d1be668b321bd520fefffe959e7c035c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02e40afe347d66a77c8bca264127c104 = $(`&lt;div id=&quot;html_02e40afe347d66a77c8bca264127c104&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d1be668b321bd520fefffe959e7c035c.setContent(html_02e40afe347d66a77c8bca264127c104);
#
#
#
#         marker_2800714818ee7219a7d09a9998fa1646.bindPopup(popup_d1be668b321bd520fefffe959e7c035c)
#         ;
#
#
#
#
#             var marker_ed8421e241bbc3d2c72215f695cc3d1f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_75c87b45b9f8f058ba24652ac0429c8e);
#
#
#         var popup_00668b4b1917f6fec95cf45a4bba1aee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_137d60b89016d771ca4ad85e6778c26b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_137d60b89016d771ca4ad85e6778c26b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_137d60b89016d771ca4ad85e6778c26b = L.map(
#                 &quot;map_137d60b89016d771ca4ad85e6778c26b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd0af34d8610cf7bff202431ef501a9e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cd0af34d8610cf7bff202431ef501a9e.addTo(map_137d60b89016d771ca4ad85e6778c26b);
#
#
#             var feature_group_21b3ee1e526acc55cd567980d0d89d93 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_21b3ee1e526acc55cd567980d0d89d93.addTo(map_137d60b89016d771ca4ad85e6778c26b);
#
#
#             var feature_group_sub_group_8978bf8398de5202c92b72166ccb0187 = L.featureGroup.subGroup(
#                 feature_group_21b3ee1e526acc55cd567980d0d89d93
#             );
#
#
#             var marker_e3ee32afabfb34e03cf7027e399502b9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8978bf8398de5202c92b72166ccb0187);
#
#
#         var popup_074ed43e57674530db59c3b51c499e6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23c439f3b8d1e37f68d88fa9f374950a = $(`&lt;div id=&quot;html_23c439f3b8d1e37f68d88fa9f374950a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_074ed43e57674530db59c3b51c499e6f.setContent(html_23c439f3b8d1e37f68d88fa9f374950a);
#
#
#
#         marker_e3ee32afabfb34e03cf7027e399502b9.bindPopup(popup_074ed43e57674530db59c3b51c499e6f)
#         ;
#
#
#
#
#             var marker_07d2430e5ae8406b63f942792d92bc55 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8978bf8398de5202c92b72166ccb0187);
#
#
#         var popup_a954cf0d76ea28701562ba2737519798 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a72352dda4fe4610601157668faed826 = $(`&lt;div id=&quot;html_a72352dda4fe4610601157668faed826&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a954cf0d76ea28701562ba2737519798.setContent(html_a72352dda4fe4610601157668faed826);
#
#
#
#         marker_07d2430e5ae8406b63f942792d92bc55.bindPopup(popup_a954cf0d76ea28701562ba2737519798)
#         ;
#
#
#
#
#             var marker_3d9bc448fa07836bbecc13ac423e6901 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8978bf8398de5202c92b72166ccb0187);
#
#
#         var popup_4ba8b628fa70c40e6f36945dbf41164b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4987fea82e17018e58d40919e6f4e43e = $(`&lt;div id=&quot;html_4987fea82e17018e58d40919e6f4e43e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4ba8b628fa70c40e6f36945dbf41164b.setContent(html_4987fea82e17018e58d40919e6f4e43e);
#
#
#
#         marker_3d9bc448fa07836bbecc13ac423e6901.bindPopup(popup_4ba8b628fa70c40e6f36945dbf41164b)
#         ;
#
#
#
#
#             var marker_9fcd2486bf1639ab4271042cf63a8770 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8978bf8398de5202c92b72166ccb0187);
#
#
#         var popup_09537288e47a1cbc0819e74ceb4fa49f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8531b3fa3f1c927f760f129a2903cc2 = $(`&lt;div id=&quot;html_e8531b3fa3f1c927f760f129a2903cc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_09537288e47a1cbc0819e74ceb4fa49f.setContent(html_e8531b3fa3f1c927f760f129a2903cc2);
#
#
#
#         marker_
