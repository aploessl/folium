# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af5a16c9cd6f386208b780a58109313f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af5a16c9cd6f386208b780a58109313f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af5a16c9cd6f386208b780a58109313f = L.map(
#                 &quot;map_af5a16c9cd6f386208b780a58109313f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f24c1d97fb938de12eb63c4cfab684c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f24c1d97fb938de12eb63c4cfab684c.addTo(map_af5a16c9cd6f386208b780a58109313f);
#
#
#             var marker_c2a80b3048662b58884335fc0b028dd3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_af5a16c9cd6f386208b780a58109313f);
#
#
#         var popup_e74e544fb93ac9c44e319b91e6e69ad3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f84dfb5d89005b8d58655130cc9e4d72 = $(`&lt;div id=&quot;html_f84dfb5d89005b8d58655130cc9e4d72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e74e544fb93ac9c44e319b91e6e69ad3.setContent(html_f84dfb5d89005b8d58655130cc9e4d72);
#
#
#
#         marker_c2a80b3048662b58884335fc0b028dd3.bindPopup(popup_e74e544fb93ac9c44e319b91e6e69ad3)
#         ;
#
#
#
#
#             var marker_a7a075b92111e3279e6d437c6cdc22b0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_af5a16c9cd6f386208b780a58109313f);
#
#
#         var popup_a4f5da9dde1d0031764956849ca9b604 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c737d27cf54ecdda0e481f937ba25c3 = $(`&lt;div id=&quot;html_5c737d27cf54ecdda0e481f937ba25c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a4f5da9dde1d0031764956849ca9b604.setContent(html_5c737d27cf54ecdda0e481f937ba25c3);
#
#
#
#         marker_a7a075b92111e3279e6d437c6cdc22b0.bindPopup(popup_a4f5da9dde1d0031764956849ca9b604)
#         ;
#
#
#
#
#             var marker_b1a3115f0a0a558fa6c809490034e81f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_af5a16c9cd6f386208b780a58109313f);
#
#
#         var popup_07e25e25355a884be512bfe9ddff12bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b41bea05ecac8491b57dbd35c7e4d9ff = $(`&lt;div id=&quot;html_b41bea05ecac8491b57dbd35c7e4d9ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_07e25e25355a884be512bfe9ddff12bc.setContent(html_b41bea05ecac8491b57dbd35c7e4d9ff);
#
#
#
#         marker_b1a3115f0a0a558fa6c809490034e81f.bindPopup(popup_07e25e25355a884be512bfe9ddff12bc)
#         ;
#
#
#
#
#             var marker_aa414acd4352f7f1299429e4c3296e35 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_af5a16c9cd6f386208b780a58109313f);
#
#
#         var popup_ca4a0d07a517076cd4fdf4ff07203063 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98586f5003d88015a99ec75c3d4078fe = $(`&lt;div id=&quot;html_98586f5003d88015a99ec75c3d4078fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ca4a0d07a517076cd4fdf4ff07203063.setContent(html_98586f5003d88015a99ec75c3d4078fe);
#
#
#
#         marker_aa414acd4352f7f1299429e4c3296e35.bindPopup(popup_ca4a0d07a517076cd4fdf4ff07203063)
#         ;
#
#
#
#
#             var marker_56edbde6738272881a49ff5eb49943b5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_af5a16c9cd6f386208b780a58109313f);
#
#
#         var popup_30fee63424c71c2bcd474f648d0a0079 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f6cdea25d209e70ba15ce7c1e2345f5 = $(`&lt;div id=&quot;html_5f6cdea25d209e70ba15ce7c1e2345f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_30fee63424c71c2bcd474f648d0a0079.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f93680bc8cc8acb2dc67054dbb5110b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f93680bc8cc8acb2dc67054dbb5110b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f93680bc8cc8acb2dc67054dbb5110b = L.map(
#                 &quot;map_6f93680bc8cc8acb2dc67054dbb5110b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_002f9c546d46b1e89310950b99298c67 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_002f9c546d46b1e89310950b99298c67.addTo(map_6f93680bc8cc8acb2dc67054dbb5110b);
#
#
#             var feature_group_00f7afc0c591cea0529d1b11e182a99c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9ff3e8739a160f233a2148c38358c20b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_00f7afc0c591cea0529d1b11e182a99c);
#
#
#         var popup_aa701f7011742845a0373c36ead2650e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdc41bccfaf39ce287e04e1ee7a50cb6 = $(`&lt;div id=&quot;html_fdc41bccfaf39ce287e04e1ee7a50cb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_aa701f7011742845a0373c36ead2650e.setContent(html_fdc41bccfaf39ce287e04e1ee7a50cb6);
#
#
#
#         marker_9ff3e8739a160f233a2148c38358c20b.bindPopup(popup_aa701f7011742845a0373c36ead2650e)
#         ;
#
#
#
#
#             var marker_a4da724e2c464ebce7bd661131f37cc6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_00f7afc0c591cea0529d1b11e182a99c);
#
#
#         var popup_f33eb1f3b4d0cac8941099fee417c2db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24c6fa49b9b5172296bff85f8bc31001 = $(`&lt;div id=&quot;html_24c6fa49b9b5172296bff85f8bc31001&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f33eb1f3b4d0cac8941099fee417c2db.setContent(html_24c6fa49b9b5172296bff85f8bc31001);
#
#
#
#         marker_a4da724e2c464ebce7bd661131f37cc6.bindPopup(popup_f33eb1f3b4d0cac8941099fee417c2db)
#         ;
#
#
#
#
#             var marker_f0107fe74c36ad4178f3b1114db27011 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_00f7afc0c591cea0529d1b11e182a99c);
#
#
#         var popup_1c62e2791524dd31866586ea915f543d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64155f0faf1d33bb7dbf7a783b2bc9b5 = $(`&lt;div id=&quot;html_64155f0faf1d33bb7dbf7a783b2bc9b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1c62e2791524dd31866586ea915f543d.setContent(html_64155f0faf1d33bb7dbf7a783b2bc9b5);
#
#
#
#         marker_f0107fe74c36ad4178f3b1114db27011.bindPopup(popup_1c62e2791524dd31866586ea915f543d)
#         ;
#
#
#
#
#             var marker_f1401245e57290c7dc56e5ca4ea1fd4e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_00f7afc0c591cea0529d1b11e182a99c);
#
#
#         var popup_efcd6a420a00b50df1a75e3a994bb3a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7bf2ff704bdfacb567b56d47a8e7b79 = $(`&lt;div id=&quot;html_d7bf2ff704bdfacb567b56d47a8e7b79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_efcd6a420a00b50df1a75e3a994bb3a3.setContent(html_d7bf2ff704bdfacb567b56d47a8e7b79);
#
#
#
#         marker_f1401245e57290c7dc56e5ca4ea1fd4e.bindPopup(popup_efcd6a420a00b50df1a75e3a994bb3a3)
#         ;
#
#
#
#
#             var marker_90b3b7bee7e853646f48c57180eb6d37 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_00f7afc0c591cea0529d1b11e182a99c);
#
#
#         var popup_a952d4ca18d525ea61ecb119b8e447bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de14d0a6c24fbe49b759b8fe13db3e3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de14d0a6c24fbe49b759b8fe13db3e3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de14d0a6c24fbe49b759b8fe13db3e3d = L.map(
#                 &quot;map_de14d0a6c24fbe49b759b8fe13db3e3d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec157e16fa72fa7d3ca262aeab1453e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec157e16fa72fa7d3ca262aeab1453e1.addTo(map_de14d0a6c24fbe49b759b8fe13db3e3d);
#
#
#             var feature_group_253a86b433f20d2ce652b063e5f88bb0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_253a86b433f20d2ce652b063e5f88bb0.addTo(map_de14d0a6c24fbe49b759b8fe13db3e3d);
#
#
#             var feature_group_sub_group_3a748c83be746d8fcfc11255742eac5a = L.featureGroup.subGroup(
#                 feature_group_253a86b433f20d2ce652b063e5f88bb0
#             );
#
#
#             var marker_eff0f56b9c7e91c31aeb5ef93c031bc5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3a748c83be746d8fcfc11255742eac5a);
#
#
#         var popup_a107d34c5be7a6b4e41f1b02f6bd5bba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56dc9e08931a033f56fe639ea43fe37a = $(`&lt;div id=&quot;html_56dc9e08931a033f56fe639ea43fe37a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a107d34c5be7a6b4e41f1b02f6bd5bba.setContent(html_56dc9e08931a033f56fe639ea43fe37a);
#
#
#
#         marker_eff0f56b9c7e91c31aeb5ef93c031bc5.bindPopup(popup_a107d34c5be7a6b4e41f1b02f6bd5bba)
#         ;
#
#
#
#
#             var marker_569d39e7d4d924d98986b74ba77f5ee7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3a748c83be746d8fcfc11255742eac5a);
#
#
#         var popup_5d8fb323ba86c66e4cbfbfb408e86bbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55a91b27c6e2fbe978063cca77388750 = $(`&lt;div id=&quot;html_55a91b27c6e2fbe978063cca77388750&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5d8fb323ba86c66e4cbfbfb408e86bbb.setContent(html_55a91b27c6e2fbe978063cca77388750);
#
#
#
#         marker_569d39e7d4d924d98986b74ba77f5ee7.bindPopup(popup_5d8fb323ba86c66e4cbfbfb408e86bbb)
#         ;
#
#
#
#
#             var marker_f46d07c850cd709ed3dacfb32f716e4b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3a748c83be746d8fcfc11255742eac5a);
#
#
#         var popup_8960d78a86e0f4f2492bcd42714521e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e838200c8d4dded36b60529bc0010b5c = $(`&lt;div id=&quot;html_e838200c8d4dded36b60529bc0010b5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8960d78a86e0f4f2492bcd42714521e0.setContent(html_e838200c8d4dded36b60529bc0010b5c);
#
#
#
#         marker_f46d07c850cd709ed3dacfb32f716e4b.bindPopup(popup_8960d78a86e0f4f2492bcd42714521e0)
#         ;
#
#
#
#
#             var marker_50319df42d753a410a898bb26a75ed9f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3a748c83be746d8fcfc11255742eac5a);
#
#
#         var popup_62a8d8cb647ed85ef57a7911e91670e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61800ae85728d25be0ba0c131a4a4820 = $(`&lt;div id=&quot;html_61800ae85728d25be0ba0c131a4a4820&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_62a8d8cb647ed85ef57a7911e91670e5.setContent(html_61800ae85728d25be0ba0c131a4a4820);
#
#
#
#         marker_
