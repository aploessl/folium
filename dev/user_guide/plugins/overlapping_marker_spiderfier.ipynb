# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_136f3552af298cec3bcad08fd46bc4ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_136f3552af298cec3bcad08fd46bc4ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_136f3552af298cec3bcad08fd46bc4ae = L.map(
#                 &quot;map_136f3552af298cec3bcad08fd46bc4ae&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51eb8065b031574ab33b5d147ee17b98 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_51eb8065b031574ab33b5d147ee17b98.addTo(map_136f3552af298cec3bcad08fd46bc4ae);
#
#
#             var marker_f09ec2ca9eee59be2604e2cd2c50ad3e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_136f3552af298cec3bcad08fd46bc4ae);
#
#
#         var popup_d1cd6098c814c16a3e481497ba23c963 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd5673f5ab1d49a7339866d81da4efac = $(`&lt;div id=&quot;html_bd5673f5ab1d49a7339866d81da4efac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d1cd6098c814c16a3e481497ba23c963.setContent(html_bd5673f5ab1d49a7339866d81da4efac);
#
#
#
#         marker_f09ec2ca9eee59be2604e2cd2c50ad3e.bindPopup(popup_d1cd6098c814c16a3e481497ba23c963)
#         ;
#
#
#
#
#             var marker_176ccaa468ee78ff30760b7803290aab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_136f3552af298cec3bcad08fd46bc4ae);
#
#
#         var popup_80f5b01384f26d34d009eeb8428d2c42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f907e3d0bf914b47bb39d56f5783f08 = $(`&lt;div id=&quot;html_6f907e3d0bf914b47bb39d56f5783f08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_80f5b01384f26d34d009eeb8428d2c42.setContent(html_6f907e3d0bf914b47bb39d56f5783f08);
#
#
#
#         marker_176ccaa468ee78ff30760b7803290aab.bindPopup(popup_80f5b01384f26d34d009eeb8428d2c42)
#         ;
#
#
#
#
#             var marker_1709cfc21a37379c6765a90892decde1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_136f3552af298cec3bcad08fd46bc4ae);
#
#
#         var popup_592936b184807a2e69f26526719c9cb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dea77c7b2ba665482cb7e77883ce60c7 = $(`&lt;div id=&quot;html_dea77c7b2ba665482cb7e77883ce60c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_592936b184807a2e69f26526719c9cb7.setContent(html_dea77c7b2ba665482cb7e77883ce60c7);
#
#
#
#         marker_1709cfc21a37379c6765a90892decde1.bindPopup(popup_592936b184807a2e69f26526719c9cb7)
#         ;
#
#
#
#
#             var marker_3bd8a40012b407c8f77aeaf77b647142 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_136f3552af298cec3bcad08fd46bc4ae);
#
#
#         var popup_172900cef9ca47eb541903307b659972 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_584fa8acf1666d0b150d250322b5034d = $(`&lt;div id=&quot;html_584fa8acf1666d0b150d250322b5034d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_172900cef9ca47eb541903307b659972.setContent(html_584fa8acf1666d0b150d250322b5034d);
#
#
#
#         marker_3bd8a40012b407c8f77aeaf77b647142.bindPopup(popup_172900cef9ca47eb541903307b659972)
#         ;
#
#
#
#
#             var marker_560ef11ee87ae7d59b36b3333fbe54f5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_136f3552af298cec3bcad08fd46bc4ae);
#
#
#         var popup_05f6339cc682b75103b441400c4daba7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c56feed651a193f9bf544869e5cfecff = $(`&lt;div id=&quot;html_c56feed651a193f9bf544869e5cfecff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_05f6339cc682b75103b441400c4daba7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4d5021b5c585543d81cb6b0a09dfa3e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4d5021b5c585543d81cb6b0a09dfa3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4d5021b5c585543d81cb6b0a09dfa3e = L.map(
#                 &quot;map_d4d5021b5c585543d81cb6b0a09dfa3e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_471c5cb0a41a22b6dfcd93b48f7a1773 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_471c5cb0a41a22b6dfcd93b48f7a1773.addTo(map_d4d5021b5c585543d81cb6b0a09dfa3e);
#
#
#             var feature_group_4e799598bc088a743f916e0d05ea6d20 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2bbbe1f96a186796a2e2a3c6104779a2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4e799598bc088a743f916e0d05ea6d20);
#
#
#         var popup_0cacecb166ba522f7c1c0ee1c50f8b0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6db19f842bb274542de3e263446b573 = $(`&lt;div id=&quot;html_b6db19f842bb274542de3e263446b573&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0cacecb166ba522f7c1c0ee1c50f8b0c.setContent(html_b6db19f842bb274542de3e263446b573);
#
#
#
#         marker_2bbbe1f96a186796a2e2a3c6104779a2.bindPopup(popup_0cacecb166ba522f7c1c0ee1c50f8b0c)
#         ;
#
#
#
#
#             var marker_e233fb897dfd1a35d0aa9307f445b7cd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4e799598bc088a743f916e0d05ea6d20);
#
#
#         var popup_3a51d9c9968fe34ff9044e1ca5af6211 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c49a9b95469a5b7039945ce16aebe4b = $(`&lt;div id=&quot;html_2c49a9b95469a5b7039945ce16aebe4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3a51d9c9968fe34ff9044e1ca5af6211.setContent(html_2c49a9b95469a5b7039945ce16aebe4b);
#
#
#
#         marker_e233fb897dfd1a35d0aa9307f445b7cd.bindPopup(popup_3a51d9c9968fe34ff9044e1ca5af6211)
#         ;
#
#
#
#
#             var marker_792cf484c61a535f0534533494b50752 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4e799598bc088a743f916e0d05ea6d20);
#
#
#         var popup_ac4ba211de31ebc652fa37f18e6629c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b46453477bb1d9bb690aabed20131b0 = $(`&lt;div id=&quot;html_4b46453477bb1d9bb690aabed20131b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ac4ba211de31ebc652fa37f18e6629c2.setContent(html_4b46453477bb1d9bb690aabed20131b0);
#
#
#
#         marker_792cf484c61a535f0534533494b50752.bindPopup(popup_ac4ba211de31ebc652fa37f18e6629c2)
#         ;
#
#
#
#
#             var marker_70002da7dc4b2b03645dee8c88b8a202 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4e799598bc088a743f916e0d05ea6d20);
#
#
#         var popup_f4596fede158c40c3b27a35351264c01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18e263e46df41aa9b40207051ed2822c = $(`&lt;div id=&quot;html_18e263e46df41aa9b40207051ed2822c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f4596fede158c40c3b27a35351264c01.setContent(html_18e263e46df41aa9b40207051ed2822c);
#
#
#
#         marker_70002da7dc4b2b03645dee8c88b8a202.bindPopup(popup_f4596fede158c40c3b27a35351264c01)
#         ;
#
#
#
#
#             var marker_80b021327e9c99dbb56527fa15819e1e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4e799598bc088a743f916e0d05ea6d20);
#
#
#         var popup_c3d2c87d30283de82f088e01aea98b7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cf28fa75ffbadc7857bc0387cae16a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cf28fa75ffbadc7857bc0387cae16a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cf28fa75ffbadc7857bc0387cae16a2 = L.map(
#                 &quot;map_3cf28fa75ffbadc7857bc0387cae16a2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67fd41e06ffca2dde226760fc7d11241 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67fd41e06ffca2dde226760fc7d11241.addTo(map_3cf28fa75ffbadc7857bc0387cae16a2);
#
#
#             var feature_group_bc3d4d49d76d9f6de3c7bdd5a49d2a64 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bc3d4d49d76d9f6de3c7bdd5a49d2a64.addTo(map_3cf28fa75ffbadc7857bc0387cae16a2);
#
#
#             var feature_group_sub_group_76cd6acd6aea17592dea8c6c9130ecb6 = L.featureGroup.subGroup(
#                 feature_group_bc3d4d49d76d9f6de3c7bdd5a49d2a64
#             );
#
#
#             var marker_ca6dae4173407cab4e0847e8f54da5dc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_76cd6acd6aea17592dea8c6c9130ecb6);
#
#
#         var popup_39392ad49917050db6d7af4a9747ac0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1871820797dc81b5180c8591fd5d1bce = $(`&lt;div id=&quot;html_1871820797dc81b5180c8591fd5d1bce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_39392ad49917050db6d7af4a9747ac0b.setContent(html_1871820797dc81b5180c8591fd5d1bce);
#
#
#
#         marker_ca6dae4173407cab4e0847e8f54da5dc.bindPopup(popup_39392ad49917050db6d7af4a9747ac0b)
#         ;
#
#
#
#
#             var marker_24a924decdf5fa038129220d346d0993 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_76cd6acd6aea17592dea8c6c9130ecb6);
#
#
#         var popup_46a0d93d82ae1a6edbf77fe70b9537e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f777575db66db44261d63384b6f800a1 = $(`&lt;div id=&quot;html_f777575db66db44261d63384b6f800a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_46a0d93d82ae1a6edbf77fe70b9537e6.setContent(html_f777575db66db44261d63384b6f800a1);
#
#
#
#         marker_24a924decdf5fa038129220d346d0993.bindPopup(popup_46a0d93d82ae1a6edbf77fe70b9537e6)
#         ;
#
#
#
#
#             var marker_a4378bd9d9d2a9b0f48283c2fd210fdc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_76cd6acd6aea17592dea8c6c9130ecb6);
#
#
#         var popup_6e8045b4c1c3e35b0e0755e9d63d12e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b95096962926a0a8ad4fa4d8a7314ba = $(`&lt;div id=&quot;html_1b95096962926a0a8ad4fa4d8a7314ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6e8045b4c1c3e35b0e0755e9d63d12e9.setContent(html_1b95096962926a0a8ad4fa4d8a7314ba);
#
#
#
#         marker_a4378bd9d9d2a9b0f48283c2fd210fdc.bindPopup(popup_6e8045b4c1c3e35b0e0755e9d63d12e9)
#         ;
#
#
#
#
#             var marker_5e60d09564b880aa926804e36c557af3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_76cd6acd6aea17592dea8c6c9130ecb6);
#
#
#         var popup_ebb738f60fa062dfcca7c14a83b44e06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abb86db4da0cc573dff1b8be0bd4aa2c = $(`&lt;div id=&quot;html_abb86db4da0cc573dff1b8be0bd4aa2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ebb738f60fa062dfcca7c14a83b44e06.setContent(html_abb86db4da0cc573dff1b8be0bd4aa2c);
#
#
#
#         marker_
