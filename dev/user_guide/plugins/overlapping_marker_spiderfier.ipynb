# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e50712c2217e5aeab58dc6fa2147ff74 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e50712c2217e5aeab58dc6fa2147ff74&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e50712c2217e5aeab58dc6fa2147ff74 = L.map(
#                 &quot;map_e50712c2217e5aeab58dc6fa2147ff74&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f4fd2617f91cc1e9dfeafdd0fcb448b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f4fd2617f91cc1e9dfeafdd0fcb448b.addTo(map_e50712c2217e5aeab58dc6fa2147ff74);
#
#
#             var marker_c25f08e9ed7cf6da493cfd157594a5fb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e50712c2217e5aeab58dc6fa2147ff74);
#
#
#         var popup_4c4df606eb6e72edfb303d2246a21347 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_029940d709ddf024b906c8f8de7a100d = $(`&lt;div id=&quot;html_029940d709ddf024b906c8f8de7a100d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4c4df606eb6e72edfb303d2246a21347.setContent(html_029940d709ddf024b906c8f8de7a100d);
#
#
#
#         marker_c25f08e9ed7cf6da493cfd157594a5fb.bindPopup(popup_4c4df606eb6e72edfb303d2246a21347)
#         ;
#
#
#
#
#             var marker_416f131e3083d85f31f7ce497df5d335 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e50712c2217e5aeab58dc6fa2147ff74);
#
#
#         var popup_99d9a7cbe1ef431ad15a9e22ecc3ef01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7eb9ae8ceccdc157a164ef2a0877b2e = $(`&lt;div id=&quot;html_a7eb9ae8ceccdc157a164ef2a0877b2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_99d9a7cbe1ef431ad15a9e22ecc3ef01.setContent(html_a7eb9ae8ceccdc157a164ef2a0877b2e);
#
#
#
#         marker_416f131e3083d85f31f7ce497df5d335.bindPopup(popup_99d9a7cbe1ef431ad15a9e22ecc3ef01)
#         ;
#
#
#
#
#             var marker_bd6ab53b20b4b9676d760e6ddf88f984 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e50712c2217e5aeab58dc6fa2147ff74);
#
#
#         var popup_159f83ad45b4d85cb9fae1bb315145b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27d2979536f546f05a0013ff6263e0c2 = $(`&lt;div id=&quot;html_27d2979536f546f05a0013ff6263e0c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_159f83ad45b4d85cb9fae1bb315145b0.setContent(html_27d2979536f546f05a0013ff6263e0c2);
#
#
#
#         marker_bd6ab53b20b4b9676d760e6ddf88f984.bindPopup(popup_159f83ad45b4d85cb9fae1bb315145b0)
#         ;
#
#
#
#
#             var marker_c29fdf8d5f56caa6210b3079188c7674 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e50712c2217e5aeab58dc6fa2147ff74);
#
#
#         var popup_162aa6cb0b0d35d42e8775796ef90b29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a93530c561706a5e9bc99a9f2c04112 = $(`&lt;div id=&quot;html_0a93530c561706a5e9bc99a9f2c04112&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_162aa6cb0b0d35d42e8775796ef90b29.setContent(html_0a93530c561706a5e9bc99a9f2c04112);
#
#
#
#         marker_c29fdf8d5f56caa6210b3079188c7674.bindPopup(popup_162aa6cb0b0d35d42e8775796ef90b29)
#         ;
#
#
#
#
#             var marker_42380991d7c5b8153529381739c09ec1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e50712c2217e5aeab58dc6fa2147ff74);
#
#
#         var popup_448b316e3d3c5a6cd1cfa60acc06e845 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a80c0e87b645f2616c5512053ca81a9d = $(`&lt;div id=&quot;html_a80c0e87b645f2616c5512053ca81a9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_448b316e3d3c5a6cd1cfa60acc06e845.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71bb230f9857080416def283c76d872f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71bb230f9857080416def283c76d872f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71bb230f9857080416def283c76d872f = L.map(
#                 &quot;map_71bb230f9857080416def283c76d872f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_827233a32b8e94020d0e7398d4ec1b9a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_827233a32b8e94020d0e7398d4ec1b9a.addTo(map_71bb230f9857080416def283c76d872f);
#
#
#             var feature_group_8eee7bd94c68bb6b1fa68545105f969f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f75bdf4ffc0c611ac8fc2aa0b21c2479 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8eee7bd94c68bb6b1fa68545105f969f);
#
#
#         var popup_fd2ac0e59dc3944b556ff4ffe315760a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f93fa1e3c1bc7ae41044244844c30215 = $(`&lt;div id=&quot;html_f93fa1e3c1bc7ae41044244844c30215&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fd2ac0e59dc3944b556ff4ffe315760a.setContent(html_f93fa1e3c1bc7ae41044244844c30215);
#
#
#
#         marker_f75bdf4ffc0c611ac8fc2aa0b21c2479.bindPopup(popup_fd2ac0e59dc3944b556ff4ffe315760a)
#         ;
#
#
#
#
#             var marker_395104d93c81443f595cb36ce4447b03 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8eee7bd94c68bb6b1fa68545105f969f);
#
#
#         var popup_9068e5faa79ca3c7d71e70e552af6884 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1a6c358b1b7dde7527acad4b6a23b0a = $(`&lt;div id=&quot;html_e1a6c358b1b7dde7527acad4b6a23b0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9068e5faa79ca3c7d71e70e552af6884.setContent(html_e1a6c358b1b7dde7527acad4b6a23b0a);
#
#
#
#         marker_395104d93c81443f595cb36ce4447b03.bindPopup(popup_9068e5faa79ca3c7d71e70e552af6884)
#         ;
#
#
#
#
#             var marker_68089e0b813537a4150e4fd0941068fc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8eee7bd94c68bb6b1fa68545105f969f);
#
#
#         var popup_c5c900ee5f29869b6eff5950d3af9df2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74579a45ba4a6a48863182a2e1668951 = $(`&lt;div id=&quot;html_74579a45ba4a6a48863182a2e1668951&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c5c900ee5f29869b6eff5950d3af9df2.setContent(html_74579a45ba4a6a48863182a2e1668951);
#
#
#
#         marker_68089e0b813537a4150e4fd0941068fc.bindPopup(popup_c5c900ee5f29869b6eff5950d3af9df2)
#         ;
#
#
#
#
#             var marker_64d91f9c3a2428eb2b2948b031cfef8e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8eee7bd94c68bb6b1fa68545105f969f);
#
#
#         var popup_464ba81eec056cb842ccb6be73d6f9b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c4fc1b90cfbe1525daaf8e7cfde54c6 = $(`&lt;div id=&quot;html_5c4fc1b90cfbe1525daaf8e7cfde54c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_464ba81eec056cb842ccb6be73d6f9b0.setContent(html_5c4fc1b90cfbe1525daaf8e7cfde54c6);
#
#
#
#         marker_64d91f9c3a2428eb2b2948b031cfef8e.bindPopup(popup_464ba81eec056cb842ccb6be73d6f9b0)
#         ;
#
#
#
#
#             var marker_396f7dfb789e9afb31707126ccb5edb8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8eee7bd94c68bb6b1fa68545105f969f);
#
#
#         var popup_dd6e33d49257e76288a2d4ce4c8aca51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64bbb1073ee2daa1baafff60e074c823 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64bbb1073ee2daa1baafff60e074c823&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_64bbb1073ee2daa1baafff60e074c823 = L.map(
#                 &quot;map_64bbb1073ee2daa1baafff60e074c823&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d56f01c699a3289bf018f4b5cb14a424 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d56f01c699a3289bf018f4b5cb14a424.addTo(map_64bbb1073ee2daa1baafff60e074c823);
#
#
#             var feature_group_8844ce36676838aa8da76089d62f44ba = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8844ce36676838aa8da76089d62f44ba.addTo(map_64bbb1073ee2daa1baafff60e074c823);
#
#
#             var feature_group_sub_group_bd6510081e10609f8d4b3e364e04db7a = L.featureGroup.subGroup(
#                 feature_group_8844ce36676838aa8da76089d62f44ba
#             );
#
#
#             var marker_7259ea89cb34e3ac1445722a4a173458 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd6510081e10609f8d4b3e364e04db7a);
#
#
#         var popup_eb66f78955d89cb4fc21d7ceb6ea39c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f39a962f583b6e9e007a34a8a62cb3f2 = $(`&lt;div id=&quot;html_f39a962f583b6e9e007a34a8a62cb3f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_eb66f78955d89cb4fc21d7ceb6ea39c3.setContent(html_f39a962f583b6e9e007a34a8a62cb3f2);
#
#
#
#         marker_7259ea89cb34e3ac1445722a4a173458.bindPopup(popup_eb66f78955d89cb4fc21d7ceb6ea39c3)
#         ;
#
#
#
#
#             var marker_21d30a155a1cd3920287d7731caa865f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd6510081e10609f8d4b3e364e04db7a);
#
#
#         var popup_74b78638a6c30841c67c595076c800ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_852ddaf73b16e6c00ee52802e7535884 = $(`&lt;div id=&quot;html_852ddaf73b16e6c00ee52802e7535884&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_74b78638a6c30841c67c595076c800ed.setContent(html_852ddaf73b16e6c00ee52802e7535884);
#
#
#
#         marker_21d30a155a1cd3920287d7731caa865f.bindPopup(popup_74b78638a6c30841c67c595076c800ed)
#         ;
#
#
#
#
#             var marker_50587d18bcfadd7f524c7745d3cc8f9a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd6510081e10609f8d4b3e364e04db7a);
#
#
#         var popup_af2e5050907646cb7a34e7156bf3b611 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b553a9ec1dad9745b84c3e7ae76549dc = $(`&lt;div id=&quot;html_b553a9ec1dad9745b84c3e7ae76549dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_af2e5050907646cb7a34e7156bf3b611.setContent(html_b553a9ec1dad9745b84c3e7ae76549dc);
#
#
#
#         marker_50587d18bcfadd7f524c7745d3cc8f9a.bindPopup(popup_af2e5050907646cb7a34e7156bf3b611)
#         ;
#
#
#
#
#             var marker_0c6344e09b0704aa44647e0c96b2dcee = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd6510081e10609f8d4b3e364e04db7a);
#
#
#         var popup_cd81f69650819e6c6c75586815817092 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2e7e7287b60acfe5e7d1f8fc6c98640 = $(`&lt;div id=&quot;html_f2e7e7287b60acfe5e7d1f8fc6c98640&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_cd81f69650819e6c6c75586815817092.setContent(html_f2e7e7287b60acfe5e7d1f8fc6c98640);
#
#
#
#         marker_
