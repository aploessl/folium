# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a30eb82e888e8b640a00ccbf82b1ba1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a30eb82e888e8b640a00ccbf82b1ba1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a30eb82e888e8b640a00ccbf82b1ba1c = L.map(
#                 &quot;map_a30eb82e888e8b640a00ccbf82b1ba1c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c88768d72dad831ef6cf0c31ceb0b79b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c88768d72dad831ef6cf0c31ceb0b79b.addTo(map_a30eb82e888e8b640a00ccbf82b1ba1c);
#
#
#             var marker_6c52b84b885984573457ef095d7952ff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a30eb82e888e8b640a00ccbf82b1ba1c);
#
#
#         var popup_8aa730462190206b8cfd6804672a0bf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d30b70e0354f1e817982616879e61a47 = $(`&lt;div id=&quot;html_d30b70e0354f1e817982616879e61a47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8aa730462190206b8cfd6804672a0bf7.setContent(html_d30b70e0354f1e817982616879e61a47);
#
#
#
#         marker_6c52b84b885984573457ef095d7952ff.bindPopup(popup_8aa730462190206b8cfd6804672a0bf7)
#         ;
#
#
#
#
#             var marker_31b481d537176a8b926233d837206798 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a30eb82e888e8b640a00ccbf82b1ba1c);
#
#
#         var popup_0f15cb0c79b6b200e22539b9b23766df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bdbae0233a614fc8381737292d1696d = $(`&lt;div id=&quot;html_5bdbae0233a614fc8381737292d1696d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0f15cb0c79b6b200e22539b9b23766df.setContent(html_5bdbae0233a614fc8381737292d1696d);
#
#
#
#         marker_31b481d537176a8b926233d837206798.bindPopup(popup_0f15cb0c79b6b200e22539b9b23766df)
#         ;
#
#
#
#
#             var marker_de1b1396510f3141cda0bd0426e40bcc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a30eb82e888e8b640a00ccbf82b1ba1c);
#
#
#         var popup_f35273ba99e6b075b96f3a395ef61558 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bda052a5f1bcb21eef435eb204b57fc = $(`&lt;div id=&quot;html_2bda052a5f1bcb21eef435eb204b57fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f35273ba99e6b075b96f3a395ef61558.setContent(html_2bda052a5f1bcb21eef435eb204b57fc);
#
#
#
#         marker_de1b1396510f3141cda0bd0426e40bcc.bindPopup(popup_f35273ba99e6b075b96f3a395ef61558)
#         ;
#
#
#
#
#             var marker_0f3d1b17c6202ecdfeb21299af5b11d5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a30eb82e888e8b640a00ccbf82b1ba1c);
#
#
#         var popup_a2ced5aeddfc1447e68b7b7ff3255c9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_005e2527952e3964ba7d60ba43079ae6 = $(`&lt;div id=&quot;html_005e2527952e3964ba7d60ba43079ae6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a2ced5aeddfc1447e68b7b7ff3255c9f.setContent(html_005e2527952e3964ba7d60ba43079ae6);
#
#
#
#         marker_0f3d1b17c6202ecdfeb21299af5b11d5.bindPopup(popup_a2ced5aeddfc1447e68b7b7ff3255c9f)
#         ;
#
#
#
#
#             var marker_756c76899230f192df20998f03f27875 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a30eb82e888e8b640a00ccbf82b1ba1c);
#
#
#         var popup_bf8be02571e7f25a1436e36ec6637456 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d563bda77ccb3a8b87273c9393804985 = $(`&lt;div id=&quot;html_d563bda77ccb3a8b87273c9393804985&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bf8be02571e7f25a1436e36ec6637456.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7b518352388c593c6800c0e1b7baeb9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7b518352388c593c6800c0e1b7baeb9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7b518352388c593c6800c0e1b7baeb9 = L.map(
#                 &quot;map_f7b518352388c593c6800c0e1b7baeb9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_16455e887eac4ad8ee9e44cbb2f5290d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_16455e887eac4ad8ee9e44cbb2f5290d.addTo(map_f7b518352388c593c6800c0e1b7baeb9);
#
#
#             var feature_group_58c5859c7db03b33454b012f5f23ef2f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_79795fe86c0d66db0a3399dcbd72e8af = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_58c5859c7db03b33454b012f5f23ef2f);
#
#
#         var popup_f945f460fa2bd9c6ea82735001a343af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f445193edc7f349c17d95c9899e7838b = $(`&lt;div id=&quot;html_f445193edc7f349c17d95c9899e7838b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f945f460fa2bd9c6ea82735001a343af.setContent(html_f445193edc7f349c17d95c9899e7838b);
#
#
#
#         marker_79795fe86c0d66db0a3399dcbd72e8af.bindPopup(popup_f945f460fa2bd9c6ea82735001a343af)
#         ;
#
#
#
#
#             var marker_949ca3350197f69f00dcb7ee1d573a83 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_58c5859c7db03b33454b012f5f23ef2f);
#
#
#         var popup_3dee8973287eccefb5e6e54437d93301 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61b57ab888fbccad15c2fe188b938eb2 = $(`&lt;div id=&quot;html_61b57ab888fbccad15c2fe188b938eb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3dee8973287eccefb5e6e54437d93301.setContent(html_61b57ab888fbccad15c2fe188b938eb2);
#
#
#
#         marker_949ca3350197f69f00dcb7ee1d573a83.bindPopup(popup_3dee8973287eccefb5e6e54437d93301)
#         ;
#
#
#
#
#             var marker_191d0e4b1ca9248ec068929fc1bf8b13 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_58c5859c7db03b33454b012f5f23ef2f);
#
#
#         var popup_354de8819d574ed84f82f161e128f7bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ee8f9a0b0360279cc847ef25d49803d = $(`&lt;div id=&quot;html_9ee8f9a0b0360279cc847ef25d49803d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_354de8819d574ed84f82f161e128f7bf.setContent(html_9ee8f9a0b0360279cc847ef25d49803d);
#
#
#
#         marker_191d0e4b1ca9248ec068929fc1bf8b13.bindPopup(popup_354de8819d574ed84f82f161e128f7bf)
#         ;
#
#
#
#
#             var marker_96bf2a838ff71d28a92b4e5ee28f6e24 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_58c5859c7db03b33454b012f5f23ef2f);
#
#
#         var popup_ef93131f36244532c99b7a09de69f489 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d91f35d6137fd0588c3a286459ff3363 = $(`&lt;div id=&quot;html_d91f35d6137fd0588c3a286459ff3363&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ef93131f36244532c99b7a09de69f489.setContent(html_d91f35d6137fd0588c3a286459ff3363);
#
#
#
#         marker_96bf2a838ff71d28a92b4e5ee28f6e24.bindPopup(popup_ef93131f36244532c99b7a09de69f489)
#         ;
#
#
#
#
#             var marker_24a119b3ac228ff5fd1b83771d0a54a5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_58c5859c7db03b33454b012f5f23ef2f);
#
#
#         var popup_7444e84f562ec1668ae2804c6e9eea1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e0c02597ff07980c1f032b4cc6ed320 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e0c02597ff07980c1f032b4cc6ed320&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e0c02597ff07980c1f032b4cc6ed320 = L.map(
#                 &quot;map_7e0c02597ff07980c1f032b4cc6ed320&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec66866cb4c74a71636012b8a9337ddc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec66866cb4c74a71636012b8a9337ddc.addTo(map_7e0c02597ff07980c1f032b4cc6ed320);
#
#
#             var feature_group_2c3e493ed6394127bd240c89f90c3d16 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2c3e493ed6394127bd240c89f90c3d16.addTo(map_7e0c02597ff07980c1f032b4cc6ed320);
#
#
#             var feature_group_sub_group_6431feb5c68e391d0dc3287acdd2479a = L.featureGroup.subGroup(
#                 feature_group_2c3e493ed6394127bd240c89f90c3d16
#             );
#
#
#             var marker_b461919aaec11e8b95f89ede102c4232 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6431feb5c68e391d0dc3287acdd2479a);
#
#
#         var popup_cb1db0b8667f77fc336bf5efbd82d5b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83cd7b6761ca92451fff284a7efd33c4 = $(`&lt;div id=&quot;html_83cd7b6761ca92451fff284a7efd33c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cb1db0b8667f77fc336bf5efbd82d5b2.setContent(html_83cd7b6761ca92451fff284a7efd33c4);
#
#
#
#         marker_b461919aaec11e8b95f89ede102c4232.bindPopup(popup_cb1db0b8667f77fc336bf5efbd82d5b2)
#         ;
#
#
#
#
#             var marker_6274275e18cf5908e658151fa55c8a20 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6431feb5c68e391d0dc3287acdd2479a);
#
#
#         var popup_dc072dd644c17d6740e0a323bc4478b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e919e72dc1f6bcbf625c7db6cd9dcf9f = $(`&lt;div id=&quot;html_e919e72dc1f6bcbf625c7db6cd9dcf9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_dc072dd644c17d6740e0a323bc4478b3.setContent(html_e919e72dc1f6bcbf625c7db6cd9dcf9f);
#
#
#
#         marker_6274275e18cf5908e658151fa55c8a20.bindPopup(popup_dc072dd644c17d6740e0a323bc4478b3)
#         ;
#
#
#
#
#             var marker_0b829e4828e6d67fd160ccaa60118010 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6431feb5c68e391d0dc3287acdd2479a);
#
#
#         var popup_e9b5937107cd58d4539da77cfe246a77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24741658a9e0a6580c4f8d266398aa37 = $(`&lt;div id=&quot;html_24741658a9e0a6580c4f8d266398aa37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e9b5937107cd58d4539da77cfe246a77.setContent(html_24741658a9e0a6580c4f8d266398aa37);
#
#
#
#         marker_0b829e4828e6d67fd160ccaa60118010.bindPopup(popup_e9b5937107cd58d4539da77cfe246a77)
#         ;
#
#
#
#
#             var marker_2babf710879e9011eeca329d0e358651 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6431feb5c68e391d0dc3287acdd2479a);
#
#
#         var popup_5e921b94a46d0868359c2d5c97f87e21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26d9177d83e7a9004bd71f9782d442e7 = $(`&lt;div id=&quot;html_26d9177d83e7a9004bd71f9782d442e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5e921b94a46d0868359c2d5c97f87e21.setContent(html_26d9177d83e7a9004bd71f9782d442e7);
#
#
#
#         marker_
