# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c12c58b0989dd3e20e09a26381948f7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c12c58b0989dd3e20e09a26381948f7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c12c58b0989dd3e20e09a26381948f7c = L.map(
#                 &quot;map_c12c58b0989dd3e20e09a26381948f7c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_282df32b146b2129aaa62c829465d045 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_282df32b146b2129aaa62c829465d045.addTo(map_c12c58b0989dd3e20e09a26381948f7c);
#
#
#             var marker_1319e2cdc1f87e96e66d8a86a0ee8db6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c12c58b0989dd3e20e09a26381948f7c);
#
#
#         var popup_b55c1c7bc65d48bed73c9acae2699db2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97eda9029ecf8a08627605407224be15 = $(`&lt;div id=&quot;html_97eda9029ecf8a08627605407224be15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b55c1c7bc65d48bed73c9acae2699db2.setContent(html_97eda9029ecf8a08627605407224be15);
#
#
#
#         marker_1319e2cdc1f87e96e66d8a86a0ee8db6.bindPopup(popup_b55c1c7bc65d48bed73c9acae2699db2)
#         ;
#
#
#
#
#             var marker_165edc49af4b55aefc64d5810157f454 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c12c58b0989dd3e20e09a26381948f7c);
#
#
#         var popup_3b3f31a91172fcc779a3e25725719d7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53b9d6d8126066dde6a49d54416c2efe = $(`&lt;div id=&quot;html_53b9d6d8126066dde6a49d54416c2efe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3b3f31a91172fcc779a3e25725719d7f.setContent(html_53b9d6d8126066dde6a49d54416c2efe);
#
#
#
#         marker_165edc49af4b55aefc64d5810157f454.bindPopup(popup_3b3f31a91172fcc779a3e25725719d7f)
#         ;
#
#
#
#
#             var marker_8a0ee5805f6f868bddbaed8dd828a4f3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c12c58b0989dd3e20e09a26381948f7c);
#
#
#         var popup_d4c72186b0d614d96f08502e6929abd8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d94c9616934c4221809576ce000132a = $(`&lt;div id=&quot;html_3d94c9616934c4221809576ce000132a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d4c72186b0d614d96f08502e6929abd8.setContent(html_3d94c9616934c4221809576ce000132a);
#
#
#
#         marker_8a0ee5805f6f868bddbaed8dd828a4f3.bindPopup(popup_d4c72186b0d614d96f08502e6929abd8)
#         ;
#
#
#
#
#             var marker_124aa2b968b978e0158433a39ad3cede = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c12c58b0989dd3e20e09a26381948f7c);
#
#
#         var popup_ece0a2a7dfe6a2483994d13dda3a0c5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5777c465dde81df0e38f2b8a31251217 = $(`&lt;div id=&quot;html_5777c465dde81df0e38f2b8a31251217&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ece0a2a7dfe6a2483994d13dda3a0c5d.setContent(html_5777c465dde81df0e38f2b8a31251217);
#
#
#
#         marker_124aa2b968b978e0158433a39ad3cede.bindPopup(popup_ece0a2a7dfe6a2483994d13dda3a0c5d)
#         ;
#
#
#
#
#             var marker_51f29656d5ef1b2508582e7a3aa23b49 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c12c58b0989dd3e20e09a26381948f7c);
#
#
#         var popup_2f333dec80a3828d7ec56ce17eac33a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4c0b268dee8f8caeac880caa99cd9bb = $(`&lt;div id=&quot;html_f4c0b268dee8f8caeac880caa99cd9bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2f333dec80a3828d7ec56ce17eac33a2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52c4e191eff175bce2b617de41e411a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52c4e191eff175bce2b617de41e411a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52c4e191eff175bce2b617de41e411a3 = L.map(
#                 &quot;map_52c4e191eff175bce2b617de41e411a3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fdcdbb758784aac22a75366568cfd7f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fdcdbb758784aac22a75366568cfd7f2.addTo(map_52c4e191eff175bce2b617de41e411a3);
#
#
#             var feature_group_62d7f66a63e569a42f4db92638f8caef = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2de4253e7a1fb56ae3df9b4598d58bfd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_62d7f66a63e569a42f4db92638f8caef);
#
#
#         var popup_5b841a455dff1876fb92eb56aeaa1af3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_774c7839e66050b6e9cad145ea2be639 = $(`&lt;div id=&quot;html_774c7839e66050b6e9cad145ea2be639&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5b841a455dff1876fb92eb56aeaa1af3.setContent(html_774c7839e66050b6e9cad145ea2be639);
#
#
#
#         marker_2de4253e7a1fb56ae3df9b4598d58bfd.bindPopup(popup_5b841a455dff1876fb92eb56aeaa1af3)
#         ;
#
#
#
#
#             var marker_99faef5c83e09f6c4ba5e5a4da017e47 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_62d7f66a63e569a42f4db92638f8caef);
#
#
#         var popup_b493b3b804d49f4c0809ece8399aefa7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b63fd23adfd72c3c5dc78a4af37b68da = $(`&lt;div id=&quot;html_b63fd23adfd72c3c5dc78a4af37b68da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b493b3b804d49f4c0809ece8399aefa7.setContent(html_b63fd23adfd72c3c5dc78a4af37b68da);
#
#
#
#         marker_99faef5c83e09f6c4ba5e5a4da017e47.bindPopup(popup_b493b3b804d49f4c0809ece8399aefa7)
#         ;
#
#
#
#
#             var marker_843ab49f324d0d5deff6aeb5f7748225 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_62d7f66a63e569a42f4db92638f8caef);
#
#
#         var popup_cc690f59e7115ca825072d58d9314c51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53a578589d31ca3d4bab9c7cf1d03062 = $(`&lt;div id=&quot;html_53a578589d31ca3d4bab9c7cf1d03062&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cc690f59e7115ca825072d58d9314c51.setContent(html_53a578589d31ca3d4bab9c7cf1d03062);
#
#
#
#         marker_843ab49f324d0d5deff6aeb5f7748225.bindPopup(popup_cc690f59e7115ca825072d58d9314c51)
#         ;
#
#
#
#
#             var marker_21e5edb38bf4bf2730c4c60e877a1cf4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_62d7f66a63e569a42f4db92638f8caef);
#
#
#         var popup_746f6285065cc3ca23f8bcbe82b18944 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c99a595495e2c2297e73297d2d461056 = $(`&lt;div id=&quot;html_c99a595495e2c2297e73297d2d461056&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_746f6285065cc3ca23f8bcbe82b18944.setContent(html_c99a595495e2c2297e73297d2d461056);
#
#
#
#         marker_21e5edb38bf4bf2730c4c60e877a1cf4.bindPopup(popup_746f6285065cc3ca23f8bcbe82b18944)
#         ;
#
#
#
#
#             var marker_2833680c9741793f3526d77a201a0774 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_62d7f66a63e569a42f4db92638f8caef);
#
#
#         var popup_826c3a88b4e74a0e3129a89ecf64de1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e3a3eebbd7854fbe4cf329afe58b8f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e3a3eebbd7854fbe4cf329afe58b8f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e3a3eebbd7854fbe4cf329afe58b8f6 = L.map(
#                 &quot;map_7e3a3eebbd7854fbe4cf329afe58b8f6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0844505dceba4cde03db48168b20ae0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0844505dceba4cde03db48168b20ae0.addTo(map_7e3a3eebbd7854fbe4cf329afe58b8f6);
#
#
#             var feature_group_937a23eef6f89450602b70b44db4da76 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_937a23eef6f89450602b70b44db4da76.addTo(map_7e3a3eebbd7854fbe4cf329afe58b8f6);
#
#
#             var feature_group_sub_group_12db4b71561081b1a32544dac1342966 = L.featureGroup.subGroup(
#                 feature_group_937a23eef6f89450602b70b44db4da76
#             );
#
#
#             var marker_119291f9a1367d57f36a53739550c3ee = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_12db4b71561081b1a32544dac1342966);
#
#
#         var popup_bd820253560204753aef599064f57c71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6166e121fb149e3afeef14244ff16bda = $(`&lt;div id=&quot;html_6166e121fb149e3afeef14244ff16bda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bd820253560204753aef599064f57c71.setContent(html_6166e121fb149e3afeef14244ff16bda);
#
#
#
#         marker_119291f9a1367d57f36a53739550c3ee.bindPopup(popup_bd820253560204753aef599064f57c71)
#         ;
#
#
#
#
#             var marker_d04176ec5042bb0355eeead028afbb49 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_12db4b71561081b1a32544dac1342966);
#
#
#         var popup_25a6bb286661a9aea6abd23b37545c1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c4c25305b20601171f1eeab0a75f061 = $(`&lt;div id=&quot;html_9c4c25305b20601171f1eeab0a75f061&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_25a6bb286661a9aea6abd23b37545c1f.setContent(html_9c4c25305b20601171f1eeab0a75f061);
#
#
#
#         marker_d04176ec5042bb0355eeead028afbb49.bindPopup(popup_25a6bb286661a9aea6abd23b37545c1f)
#         ;
#
#
#
#
#             var marker_45fdf5664527cd616374340bb63cdfda = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_12db4b71561081b1a32544dac1342966);
#
#
#         var popup_b534783f6ac21ec8fa0a3be8a7543670 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9074bceb9e40aa0bdd9a9ef7664e191 = $(`&lt;div id=&quot;html_e9074bceb9e40aa0bdd9a9ef7664e191&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b534783f6ac21ec8fa0a3be8a7543670.setContent(html_e9074bceb9e40aa0bdd9a9ef7664e191);
#
#
#
#         marker_45fdf5664527cd616374340bb63cdfda.bindPopup(popup_b534783f6ac21ec8fa0a3be8a7543670)
#         ;
#
#
#
#
#             var marker_e82f9e9f64dc38f19748281846c21a92 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_12db4b71561081b1a32544dac1342966);
#
#
#         var popup_30a898377165962b81a114f55b505751 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d531190de0bef712dc0a65c1ca54f83 = $(`&lt;div id=&quot;html_0d531190de0bef712dc0a65c1ca54f83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_30a898377165962b81a114f55b505751.setContent(html_0d531190de0bef712dc0a65c1ca54f83);
#
#
#
#         marker_
