# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_154d8c583beb5c770ba30ad72f3dff3c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_154d8c583beb5c770ba30ad72f3dff3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_154d8c583beb5c770ba30ad72f3dff3c = L.map(
#                 &quot;map_154d8c583beb5c770ba30ad72f3dff3c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ddda729ef2158eac9908e417b0e20bfb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ddda729ef2158eac9908e417b0e20bfb.addTo(map_154d8c583beb5c770ba30ad72f3dff3c);
#
#
#             var marker_d04babb9efb0d0d3e4bfb408acfa1b7c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_154d8c583beb5c770ba30ad72f3dff3c);
#
#
#         var popup_c2b0365fbaf8b35d596de0e700526904 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f1eb5edd16583847a6e9c815dc7bdff = $(`&lt;div id=&quot;html_8f1eb5edd16583847a6e9c815dc7bdff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c2b0365fbaf8b35d596de0e700526904.setContent(html_8f1eb5edd16583847a6e9c815dc7bdff);
#
#
#
#         marker_d04babb9efb0d0d3e4bfb408acfa1b7c.bindPopup(popup_c2b0365fbaf8b35d596de0e700526904)
#         ;
#
#
#
#
#             var marker_658880b70e61ff3493b842c1575b32b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_154d8c583beb5c770ba30ad72f3dff3c);
#
#
#         var popup_62fd3d1bca13e17900a83909a6d097e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cbf95d577231edd68ae0477b12b2359 = $(`&lt;div id=&quot;html_3cbf95d577231edd68ae0477b12b2359&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_62fd3d1bca13e17900a83909a6d097e8.setContent(html_3cbf95d577231edd68ae0477b12b2359);
#
#
#
#         marker_658880b70e61ff3493b842c1575b32b9.bindPopup(popup_62fd3d1bca13e17900a83909a6d097e8)
#         ;
#
#
#
#
#             var marker_92b75617d6f60754ef3530aaf9d2c818 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_154d8c583beb5c770ba30ad72f3dff3c);
#
#
#         var popup_cf4a3549148a148c22401a689fb6228f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0911418ec851d30d28fcc6ade7a4e0b = $(`&lt;div id=&quot;html_b0911418ec851d30d28fcc6ade7a4e0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cf4a3549148a148c22401a689fb6228f.setContent(html_b0911418ec851d30d28fcc6ade7a4e0b);
#
#
#
#         marker_92b75617d6f60754ef3530aaf9d2c818.bindPopup(popup_cf4a3549148a148c22401a689fb6228f)
#         ;
#
#
#
#
#             var marker_9be5271c8509161542d13aa4aaf75a12 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_154d8c583beb5c770ba30ad72f3dff3c);
#
#
#         var popup_71c72a0dfd428d57d03799b443ebe58f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8aa22b3bec8d2c3353643c34ae9acdc = $(`&lt;div id=&quot;html_d8aa22b3bec8d2c3353643c34ae9acdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_71c72a0dfd428d57d03799b443ebe58f.setContent(html_d8aa22b3bec8d2c3353643c34ae9acdc);
#
#
#
#         marker_9be5271c8509161542d13aa4aaf75a12.bindPopup(popup_71c72a0dfd428d57d03799b443ebe58f)
#         ;
#
#
#
#
#             var marker_cd2e6d47d7c4760631d418ef16d3fa6c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_154d8c583beb5c770ba30ad72f3dff3c);
#
#
#         var popup_18a7144ba00eb08d387894845d829e62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bfae23ff4ae35b7fcb23db6e8f0c708 = $(`&lt;div id=&quot;html_1bfae23ff4ae35b7fcb23db6e8f0c708&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_18a7144ba00eb08d387894845d829e62.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe22c2f124526fe25b347f19a8aa961c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe22c2f124526fe25b347f19a8aa961c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe22c2f124526fe25b347f19a8aa961c = L.map(
#                 &quot;map_fe22c2f124526fe25b347f19a8aa961c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05ce4527da7cf938b78fb56c7d094b6c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05ce4527da7cf938b78fb56c7d094b6c.addTo(map_fe22c2f124526fe25b347f19a8aa961c);
#
#
#             var feature_group_0da647b2f29c12dc85a771e49b7ad453 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a3622cd51adb363042b526f9f7e8f14c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0da647b2f29c12dc85a771e49b7ad453);
#
#
#         var popup_626e44ca675303c696aec944744d1af4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c93b4ef83878e31b19edec05994fa42 = $(`&lt;div id=&quot;html_6c93b4ef83878e31b19edec05994fa42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_626e44ca675303c696aec944744d1af4.setContent(html_6c93b4ef83878e31b19edec05994fa42);
#
#
#
#         marker_a3622cd51adb363042b526f9f7e8f14c.bindPopup(popup_626e44ca675303c696aec944744d1af4)
#         ;
#
#
#
#
#             var marker_55dc5cb0eea40020a693e3dbc65f17c9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0da647b2f29c12dc85a771e49b7ad453);
#
#
#         var popup_dded5492cac417b817672a8ebd6cf27e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52de662e77430ab4045b8c170f3a18f4 = $(`&lt;div id=&quot;html_52de662e77430ab4045b8c170f3a18f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_dded5492cac417b817672a8ebd6cf27e.setContent(html_52de662e77430ab4045b8c170f3a18f4);
#
#
#
#         marker_55dc5cb0eea40020a693e3dbc65f17c9.bindPopup(popup_dded5492cac417b817672a8ebd6cf27e)
#         ;
#
#
#
#
#             var marker_3e27da39f38908b54d0b598183c76c14 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0da647b2f29c12dc85a771e49b7ad453);
#
#
#         var popup_f42c34ce52e9b6db0d4d987b30f6aa81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71b4c672acc93b716abd8b92b3528e7d = $(`&lt;div id=&quot;html_71b4c672acc93b716abd8b92b3528e7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f42c34ce52e9b6db0d4d987b30f6aa81.setContent(html_71b4c672acc93b716abd8b92b3528e7d);
#
#
#
#         marker_3e27da39f38908b54d0b598183c76c14.bindPopup(popup_f42c34ce52e9b6db0d4d987b30f6aa81)
#         ;
#
#
#
#
#             var marker_acea411dcb2597caad90409aa3aac6bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0da647b2f29c12dc85a771e49b7ad453);
#
#
#         var popup_7e44afdf57a31092254c7e9578294938 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_838c5724a3c5aa16fc4eed6bf0dfd712 = $(`&lt;div id=&quot;html_838c5724a3c5aa16fc4eed6bf0dfd712&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7e44afdf57a31092254c7e9578294938.setContent(html_838c5724a3c5aa16fc4eed6bf0dfd712);
#
#
#
#         marker_acea411dcb2597caad90409aa3aac6bc.bindPopup(popup_7e44afdf57a31092254c7e9578294938)
#         ;
#
#
#
#
#             var marker_562369d84044d6825373fdcf61a77152 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0da647b2f29c12dc85a771e49b7ad453);
#
#
#         var popup_a48c86fdaa51c94c60980551ef27664d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_408ad82ee841f8d54e382a6a2a7e5e25 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_408ad82ee841f8d54e382a6a2a7e5e25&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_408ad82ee841f8d54e382a6a2a7e5e25 = L.map(
#                 &quot;map_408ad82ee841f8d54e382a6a2a7e5e25&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9dd17a1aa07366df7dc9762fd95dd6b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a9dd17a1aa07366df7dc9762fd95dd6b.addTo(map_408ad82ee841f8d54e382a6a2a7e5e25);
#
#
#             var feature_group_1958b5fcfcdab349ec5dda018a1cd05f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1958b5fcfcdab349ec5dda018a1cd05f.addTo(map_408ad82ee841f8d54e382a6a2a7e5e25);
#
#
#             var feature_group_sub_group_7eadbf942e3aaea8dc4e486553f522f3 = L.featureGroup.subGroup(
#                 feature_group_1958b5fcfcdab349ec5dda018a1cd05f
#             );
#
#
#             var marker_55d7f58fbbc78b4d999f47a56dc67477 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7eadbf942e3aaea8dc4e486553f522f3);
#
#
#         var popup_8488f7d80acccc8407a3e47234010e58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2a6a0b63f42069191b73c2e41eccfb3 = $(`&lt;div id=&quot;html_a2a6a0b63f42069191b73c2e41eccfb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8488f7d80acccc8407a3e47234010e58.setContent(html_a2a6a0b63f42069191b73c2e41eccfb3);
#
#
#
#         marker_55d7f58fbbc78b4d999f47a56dc67477.bindPopup(popup_8488f7d80acccc8407a3e47234010e58)
#         ;
#
#
#
#
#             var marker_044d57c342988c8a4c46b0284bf7d3c5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7eadbf942e3aaea8dc4e486553f522f3);
#
#
#         var popup_4133e43a04c369b843ea403cc313feae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_859cf2c9eb6f6a06b18ed72d6590291d = $(`&lt;div id=&quot;html_859cf2c9eb6f6a06b18ed72d6590291d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4133e43a04c369b843ea403cc313feae.setContent(html_859cf2c9eb6f6a06b18ed72d6590291d);
#
#
#
#         marker_044d57c342988c8a4c46b0284bf7d3c5.bindPopup(popup_4133e43a04c369b843ea403cc313feae)
#         ;
#
#
#
#
#             var marker_a873b70ac6ccd8b2a97241b6b14b01d9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7eadbf942e3aaea8dc4e486553f522f3);
#
#
#         var popup_aa3b8830aac0386daae7d15f53ca77d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_446d7bf3dcac665d39385db7da11d0ec = $(`&lt;div id=&quot;html_446d7bf3dcac665d39385db7da11d0ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_aa3b8830aac0386daae7d15f53ca77d9.setContent(html_446d7bf3dcac665d39385db7da11d0ec);
#
#
#
#         marker_a873b70ac6ccd8b2a97241b6b14b01d9.bindPopup(popup_aa3b8830aac0386daae7d15f53ca77d9)
#         ;
#
#
#
#
#             var marker_6a286a513f14b3c8f6bc6c4c158e7e75 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7eadbf942e3aaea8dc4e486553f522f3);
#
#
#         var popup_0efef643326ca3ddbc454b5d38417932 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b71da8b2abe0594a98fd03fdd90ee69b = $(`&lt;div id=&quot;html_b71da8b2abe0594a98fd03fdd90ee69b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0efef643326ca3ddbc454b5d38417932.setContent(html_b71da8b2abe0594a98fd03fdd90ee69b);
#
#
#
#         marker_
