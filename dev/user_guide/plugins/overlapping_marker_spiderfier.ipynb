# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5afb1d1d3837b4f63b8a81c0c9c3b9f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5afb1d1d3837b4f63b8a81c0c9c3b9f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5afb1d1d3837b4f63b8a81c0c9c3b9f3 = L.map(
#                 &quot;map_5afb1d1d3837b4f63b8a81c0c9c3b9f3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a09b28e32f79149f90b884bdec1bd467 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a09b28e32f79149f90b884bdec1bd467.addTo(map_5afb1d1d3837b4f63b8a81c0c9c3b9f3);
#
#
#             var marker_79a6ace432e4e1e40f8edf0b7e9bd7e0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5afb1d1d3837b4f63b8a81c0c9c3b9f3);
#
#
#         var popup_8dc825a6fa9cbc1d1a7ae4f5e42ae01a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af3bb252553994e01a23da988b7e7bef = $(`&lt;div id=&quot;html_af3bb252553994e01a23da988b7e7bef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8dc825a6fa9cbc1d1a7ae4f5e42ae01a.setContent(html_af3bb252553994e01a23da988b7e7bef);
#
#
#
#         marker_79a6ace432e4e1e40f8edf0b7e9bd7e0.bindPopup(popup_8dc825a6fa9cbc1d1a7ae4f5e42ae01a)
#         ;
#
#
#
#
#             var marker_35fd999f830892a42f69b77f146c612d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5afb1d1d3837b4f63b8a81c0c9c3b9f3);
#
#
#         var popup_fdf861c679c6eccdc5afeb05bd0720e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6d42ac0868e89ca58085022418d3747 = $(`&lt;div id=&quot;html_d6d42ac0868e89ca58085022418d3747&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fdf861c679c6eccdc5afeb05bd0720e2.setContent(html_d6d42ac0868e89ca58085022418d3747);
#
#
#
#         marker_35fd999f830892a42f69b77f146c612d.bindPopup(popup_fdf861c679c6eccdc5afeb05bd0720e2)
#         ;
#
#
#
#
#             var marker_5d63d7fa06995f3725c727faa1159880 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5afb1d1d3837b4f63b8a81c0c9c3b9f3);
#
#
#         var popup_d7140fde22ddd5ef48008998f0e14a74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcde98ffdb6997077ad167a9c52c2a5f = $(`&lt;div id=&quot;html_fcde98ffdb6997077ad167a9c52c2a5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d7140fde22ddd5ef48008998f0e14a74.setContent(html_fcde98ffdb6997077ad167a9c52c2a5f);
#
#
#
#         marker_5d63d7fa06995f3725c727faa1159880.bindPopup(popup_d7140fde22ddd5ef48008998f0e14a74)
#         ;
#
#
#
#
#             var marker_49512d674340dd42d0255f444461f8de = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5afb1d1d3837b4f63b8a81c0c9c3b9f3);
#
#
#         var popup_340681c4c04214e700f054b6240bcd1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a8a321c69beb0e3a0207532bef80197 = $(`&lt;div id=&quot;html_0a8a321c69beb0e3a0207532bef80197&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_340681c4c04214e700f054b6240bcd1f.setContent(html_0a8a321c69beb0e3a0207532bef80197);
#
#
#
#         marker_49512d674340dd42d0255f444461f8de.bindPopup(popup_340681c4c04214e700f054b6240bcd1f)
#         ;
#
#
#
#
#             var marker_0604d46c25ac75266f9eac8f406f20d6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5afb1d1d3837b4f63b8a81c0c9c3b9f3);
#
#
#         var popup_56bb6c653bf5ffe2816fc7878a6576bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52ea26efa9b8524f5d63ae1b36ab0e1b = $(`&lt;div id=&quot;html_52ea26efa9b8524f5d63ae1b36ab0e1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_56bb6c653bf5ffe2816fc7878a6576bb.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfbc0ae5f4c161f1b84712fe67e2d111 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfbc0ae5f4c161f1b84712fe67e2d111&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfbc0ae5f4c161f1b84712fe67e2d111 = L.map(
#                 &quot;map_cfbc0ae5f4c161f1b84712fe67e2d111&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2107e459acd010a9935fc2d5311c52f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2107e459acd010a9935fc2d5311c52f.addTo(map_cfbc0ae5f4c161f1b84712fe67e2d111);
#
#
#             var feature_group_9a843dc4d03029d3e8b44dd7ab97d2db = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3fd6fa4936f3552a19a2179a37399978 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9a843dc4d03029d3e8b44dd7ab97d2db);
#
#
#         var popup_cae98c4b8b7869a7401de8a53bbae199 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de220b107729c1b1f4e201ce5dc4e878 = $(`&lt;div id=&quot;html_de220b107729c1b1f4e201ce5dc4e878&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cae98c4b8b7869a7401de8a53bbae199.setContent(html_de220b107729c1b1f4e201ce5dc4e878);
#
#
#
#         marker_3fd6fa4936f3552a19a2179a37399978.bindPopup(popup_cae98c4b8b7869a7401de8a53bbae199)
#         ;
#
#
#
#
#             var marker_1c4da9a39bd2f360bd7650e959e4c71a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9a843dc4d03029d3e8b44dd7ab97d2db);
#
#
#         var popup_77e4f417dd180977b982db5066adfd97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f434c6c7ca74a6bad62bc6022b613b93 = $(`&lt;div id=&quot;html_f434c6c7ca74a6bad62bc6022b613b93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_77e4f417dd180977b982db5066adfd97.setContent(html_f434c6c7ca74a6bad62bc6022b613b93);
#
#
#
#         marker_1c4da9a39bd2f360bd7650e959e4c71a.bindPopup(popup_77e4f417dd180977b982db5066adfd97)
#         ;
#
#
#
#
#             var marker_6d6b9074c6fdc0ecece2e27cc44d6300 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9a843dc4d03029d3e8b44dd7ab97d2db);
#
#
#         var popup_adb5bda6b68b6d24e0ea7d9c0f55c29b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_893509a132d1a41f72ccecfad60d8b0d = $(`&lt;div id=&quot;html_893509a132d1a41f72ccecfad60d8b0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_adb5bda6b68b6d24e0ea7d9c0f55c29b.setContent(html_893509a132d1a41f72ccecfad60d8b0d);
#
#
#
#         marker_6d6b9074c6fdc0ecece2e27cc44d6300.bindPopup(popup_adb5bda6b68b6d24e0ea7d9c0f55c29b)
#         ;
#
#
#
#
#             var marker_cfe44b9535696dba47a34596bb00d95b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9a843dc4d03029d3e8b44dd7ab97d2db);
#
#
#         var popup_ef5171e468f3beb9a660b8bcb7fc198a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29583dabe08ca21c8b687b81632b8955 = $(`&lt;div id=&quot;html_29583dabe08ca21c8b687b81632b8955&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ef5171e468f3beb9a660b8bcb7fc198a.setContent(html_29583dabe08ca21c8b687b81632b8955);
#
#
#
#         marker_cfe44b9535696dba47a34596bb00d95b.bindPopup(popup_ef5171e468f3beb9a660b8bcb7fc198a)
#         ;
#
#
#
#
#             var marker_5a380ef06aca1063f565a09376aaee4e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9a843dc4d03029d3e8b44dd7ab97d2db);
#
#
#         var popup_66e74a98444c20e4512d677837c45622 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af8924408eabb15afbdf57c7e608363c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af8924408eabb15afbdf57c7e608363c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af8924408eabb15afbdf57c7e608363c = L.map(
#                 &quot;map_af8924408eabb15afbdf57c7e608363c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c144776736558c5dd8cd0fed81e6229 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c144776736558c5dd8cd0fed81e6229.addTo(map_af8924408eabb15afbdf57c7e608363c);
#
#
#             var feature_group_5da8812b184258a97a8e41cd974c798c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5da8812b184258a97a8e41cd974c798c.addTo(map_af8924408eabb15afbdf57c7e608363c);
#
#
#             var feature_group_sub_group_5aa8d2e9ece12b0e413532810e01b263 = L.featureGroup.subGroup(
#                 feature_group_5da8812b184258a97a8e41cd974c798c
#             );
#
#
#             var marker_2a7048711c2be8e8bd1b5c91e23df5d8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5aa8d2e9ece12b0e413532810e01b263);
#
#
#         var popup_e960ecdc11c645287c8f85255ffa30eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fc9842d7f97e4a6235bb9f0602b3177 = $(`&lt;div id=&quot;html_4fc9842d7f97e4a6235bb9f0602b3177&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e960ecdc11c645287c8f85255ffa30eb.setContent(html_4fc9842d7f97e4a6235bb9f0602b3177);
#
#
#
#         marker_2a7048711c2be8e8bd1b5c91e23df5d8.bindPopup(popup_e960ecdc11c645287c8f85255ffa30eb)
#         ;
#
#
#
#
#             var marker_230f40034505acc8ca5ade6a905d8fd3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5aa8d2e9ece12b0e413532810e01b263);
#
#
#         var popup_ce8d6ca515db3536a4f0ceb6bce4ae83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8962efb22fccd4c4cc9422f1adb2825a = $(`&lt;div id=&quot;html_8962efb22fccd4c4cc9422f1adb2825a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ce8d6ca515db3536a4f0ceb6bce4ae83.setContent(html_8962efb22fccd4c4cc9422f1adb2825a);
#
#
#
#         marker_230f40034505acc8ca5ade6a905d8fd3.bindPopup(popup_ce8d6ca515db3536a4f0ceb6bce4ae83)
#         ;
#
#
#
#
#             var marker_59375e12469cf4c14f44640b6ffb21c3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5aa8d2e9ece12b0e413532810e01b263);
#
#
#         var popup_6d40485411f85c1c40dbf56343efd814 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21f85af15e7d5d214067b03c2ab27fd2 = $(`&lt;div id=&quot;html_21f85af15e7d5d214067b03c2ab27fd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6d40485411f85c1c40dbf56343efd814.setContent(html_21f85af15e7d5d214067b03c2ab27fd2);
#
#
#
#         marker_59375e12469cf4c14f44640b6ffb21c3.bindPopup(popup_6d40485411f85c1c40dbf56343efd814)
#         ;
#
#
#
#
#             var marker_1cdbd9d3575fbb23bfdfb08cce980ab9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5aa8d2e9ece12b0e413532810e01b263);
#
#
#         var popup_3dee92ba2b49c2ee7f63d7d314170a0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d458db2a8e0b0766e072ffb23e3d2a26 = $(`&lt;div id=&quot;html_d458db2a8e0b0766e072ffb23e3d2a26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3dee92ba2b49c2ee7f63d7d314170a0e.setContent(html_d458db2a8e0b0766e072ffb23e3d2a26);
#
#
#
#         marker_
