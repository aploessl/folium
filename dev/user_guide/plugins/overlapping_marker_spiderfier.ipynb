# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0df375bd7203ab36743ce856cd14403d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0df375bd7203ab36743ce856cd14403d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0df375bd7203ab36743ce856cd14403d = L.map(
#                 &quot;map_0df375bd7203ab36743ce856cd14403d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3e9b5d7f39c9a2ea41d122d9a20ba61 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e3e9b5d7f39c9a2ea41d122d9a20ba61.addTo(map_0df375bd7203ab36743ce856cd14403d);
#
#
#             var marker_a37be0d5ab4704c61e641baa5228734e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0df375bd7203ab36743ce856cd14403d);
#
#
#         var popup_c7f223c09d041c1ccd2113b588d7ca6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fafc705c8863ed7033de18f620c0961 = $(`&lt;div id=&quot;html_1fafc705c8863ed7033de18f620c0961&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c7f223c09d041c1ccd2113b588d7ca6b.setContent(html_1fafc705c8863ed7033de18f620c0961);
#
#
#
#         marker_a37be0d5ab4704c61e641baa5228734e.bindPopup(popup_c7f223c09d041c1ccd2113b588d7ca6b)
#         ;
#
#
#
#
#             var marker_171300ed662ed3fa17d028b0fc699987 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0df375bd7203ab36743ce856cd14403d);
#
#
#         var popup_f5020a5f0f844757de49ab2e4068b832 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a49529fe10e39cb8af05c4166cffdfa0 = $(`&lt;div id=&quot;html_a49529fe10e39cb8af05c4166cffdfa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f5020a5f0f844757de49ab2e4068b832.setContent(html_a49529fe10e39cb8af05c4166cffdfa0);
#
#
#
#         marker_171300ed662ed3fa17d028b0fc699987.bindPopup(popup_f5020a5f0f844757de49ab2e4068b832)
#         ;
#
#
#
#
#             var marker_f9eebb009e9467bd88535b0c11e6c906 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0df375bd7203ab36743ce856cd14403d);
#
#
#         var popup_b593d10087ab559e829d6cd4426fa719 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6a9ce37ab013d99ad911c4b510f5a04 = $(`&lt;div id=&quot;html_a6a9ce37ab013d99ad911c4b510f5a04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b593d10087ab559e829d6cd4426fa719.setContent(html_a6a9ce37ab013d99ad911c4b510f5a04);
#
#
#
#         marker_f9eebb009e9467bd88535b0c11e6c906.bindPopup(popup_b593d10087ab559e829d6cd4426fa719)
#         ;
#
#
#
#
#             var marker_130f81a311dfee227e8c3f36900fc977 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0df375bd7203ab36743ce856cd14403d);
#
#
#         var popup_bd8934ded3442b33b13bda997d9399c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09785dd6b6b85c9fd73605c2a9fef155 = $(`&lt;div id=&quot;html_09785dd6b6b85c9fd73605c2a9fef155&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bd8934ded3442b33b13bda997d9399c5.setContent(html_09785dd6b6b85c9fd73605c2a9fef155);
#
#
#
#         marker_130f81a311dfee227e8c3f36900fc977.bindPopup(popup_bd8934ded3442b33b13bda997d9399c5)
#         ;
#
#
#
#
#             var marker_7173d9583188670de8e9a73b4da2d94a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0df375bd7203ab36743ce856cd14403d);
#
#
#         var popup_3f66e63feb0a0158659660cc0f5f98a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_caafb6bad7543285a8ab2ad0dd473914 = $(`&lt;div id=&quot;html_caafb6bad7543285a8ab2ad0dd473914&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3f66e63feb0a0158659660cc0f5f98a1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b63a392b2917d73fd1ad8df16726fea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b63a392b2917d73fd1ad8df16726fea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b63a392b2917d73fd1ad8df16726fea = L.map(
#                 &quot;map_7b63a392b2917d73fd1ad8df16726fea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18cf914a2c982c51ed9fa72820f5340d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18cf914a2c982c51ed9fa72820f5340d.addTo(map_7b63a392b2917d73fd1ad8df16726fea);
#
#
#             var feature_group_e6a87ca55726a8edefacccbd562cafe4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a2f96d2334ea3fe96c68a9e8c86a66a1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e6a87ca55726a8edefacccbd562cafe4);
#
#
#         var popup_38b645b502763b7fe35cbd02fc70ba52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10ad4ebfa3b076273c9481ec85dea0c0 = $(`&lt;div id=&quot;html_10ad4ebfa3b076273c9481ec85dea0c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_38b645b502763b7fe35cbd02fc70ba52.setContent(html_10ad4ebfa3b076273c9481ec85dea0c0);
#
#
#
#         marker_a2f96d2334ea3fe96c68a9e8c86a66a1.bindPopup(popup_38b645b502763b7fe35cbd02fc70ba52)
#         ;
#
#
#
#
#             var marker_5ed5ef1d5b8977d41379cbdd77d0a3b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e6a87ca55726a8edefacccbd562cafe4);
#
#
#         var popup_d8b4437cebba21a2529b375232fccb50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30a4adf8af31bfc5bc8070b656b3f8de = $(`&lt;div id=&quot;html_30a4adf8af31bfc5bc8070b656b3f8de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d8b4437cebba21a2529b375232fccb50.setContent(html_30a4adf8af31bfc5bc8070b656b3f8de);
#
#
#
#         marker_5ed5ef1d5b8977d41379cbdd77d0a3b9.bindPopup(popup_d8b4437cebba21a2529b375232fccb50)
#         ;
#
#
#
#
#             var marker_87fc8650f2aa1e69bfd0a84d1773deb2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e6a87ca55726a8edefacccbd562cafe4);
#
#
#         var popup_975a637edb52c0a3556efef17b74cc72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f7acd14e42b12f82a1fc1c68e79dbed = $(`&lt;div id=&quot;html_6f7acd14e42b12f82a1fc1c68e79dbed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_975a637edb52c0a3556efef17b74cc72.setContent(html_6f7acd14e42b12f82a1fc1c68e79dbed);
#
#
#
#         marker_87fc8650f2aa1e69bfd0a84d1773deb2.bindPopup(popup_975a637edb52c0a3556efef17b74cc72)
#         ;
#
#
#
#
#             var marker_b40f181b0765478e1cb0d6980dccefb9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e6a87ca55726a8edefacccbd562cafe4);
#
#
#         var popup_e8d2364223db69b575bc1f2b7d784293 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c10b57a38249b542bf71b45bc2f4768 = $(`&lt;div id=&quot;html_3c10b57a38249b542bf71b45bc2f4768&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e8d2364223db69b575bc1f2b7d784293.setContent(html_3c10b57a38249b542bf71b45bc2f4768);
#
#
#
#         marker_b40f181b0765478e1cb0d6980dccefb9.bindPopup(popup_e8d2364223db69b575bc1f2b7d784293)
#         ;
#
#
#
#
#             var marker_a4b03b557fc44119219d260b727c3bf6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e6a87ca55726a8edefacccbd562cafe4);
#
#
#         var popup_a502a87147dc99a28994ea19f5240a6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa9745fab481bfdd78eae71e2c4af71b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa9745fab481bfdd78eae71e2c4af71b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa9745fab481bfdd78eae71e2c4af71b = L.map(
#                 &quot;map_fa9745fab481bfdd78eae71e2c4af71b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bab1457d7c592ae5da3a44c11150ac1b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bab1457d7c592ae5da3a44c11150ac1b.addTo(map_fa9745fab481bfdd78eae71e2c4af71b);
#
#
#             var feature_group_4600e0e0c8da85cb6beb9f28d8f53a79 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4600e0e0c8da85cb6beb9f28d8f53a79.addTo(map_fa9745fab481bfdd78eae71e2c4af71b);
#
#
#             var feature_group_sub_group_5a3398dd5589cb7609d3a0cae4f2f0fe = L.featureGroup.subGroup(
#                 feature_group_4600e0e0c8da85cb6beb9f28d8f53a79
#             );
#
#
#             var marker_c6fdb803330668fcdc6f55c9e958771e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5a3398dd5589cb7609d3a0cae4f2f0fe);
#
#
#         var popup_4ecfac8414bd982ab42c5dbdca20f591 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_801fb402da91a3e803df1f199aa0f769 = $(`&lt;div id=&quot;html_801fb402da91a3e803df1f199aa0f769&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4ecfac8414bd982ab42c5dbdca20f591.setContent(html_801fb402da91a3e803df1f199aa0f769);
#
#
#
#         marker_c6fdb803330668fcdc6f55c9e958771e.bindPopup(popup_4ecfac8414bd982ab42c5dbdca20f591)
#         ;
#
#
#
#
#             var marker_e24f8b01fac1cf80284dde433e16d071 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5a3398dd5589cb7609d3a0cae4f2f0fe);
#
#
#         var popup_deb67c17be662a8a9e39bab852f39d78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ff310fc298752cd368d1f89deb105c4 = $(`&lt;div id=&quot;html_4ff310fc298752cd368d1f89deb105c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_deb67c17be662a8a9e39bab852f39d78.setContent(html_4ff310fc298752cd368d1f89deb105c4);
#
#
#
#         marker_e24f8b01fac1cf80284dde433e16d071.bindPopup(popup_deb67c17be662a8a9e39bab852f39d78)
#         ;
#
#
#
#
#             var marker_a153500d037df8a6c9ac644f818db722 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5a3398dd5589cb7609d3a0cae4f2f0fe);
#
#
#         var popup_39ebe6c760b396b0a89197ef4cfd860c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af6e265cc24a1662a4ba2fded337f431 = $(`&lt;div id=&quot;html_af6e265cc24a1662a4ba2fded337f431&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_39ebe6c760b396b0a89197ef4cfd860c.setContent(html_af6e265cc24a1662a4ba2fded337f431);
#
#
#
#         marker_a153500d037df8a6c9ac644f818db722.bindPopup(popup_39ebe6c760b396b0a89197ef4cfd860c)
#         ;
#
#
#
#
#             var marker_c9be5b29fd000f46b7fedd2a8bd503e7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5a3398dd5589cb7609d3a0cae4f2f0fe);
#
#
#         var popup_b4089bd0042ccb0f648e353b3782198c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f316a3bda44612ad64c0032f7ea917c0 = $(`&lt;div id=&quot;html_f316a3bda44612ad64c0032f7ea917c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b4089bd0042ccb0f648e353b3782198c.setContent(html_f316a3bda44612ad64c0032f7ea917c0);
#
#
#
#         marker_
