# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ef8311826f825fd948a49c6713c1377 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ef8311826f825fd948a49c6713c1377&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ef8311826f825fd948a49c6713c1377 = L.map(
#                 &quot;map_1ef8311826f825fd948a49c6713c1377&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3ac090f9ee1aa67e8bd8b077f1910e4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c3ac090f9ee1aa67e8bd8b077f1910e4.addTo(map_1ef8311826f825fd948a49c6713c1377);
#
#
#             var marker_df142aa1593bb2131a795fa4db3b6e7a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1ef8311826f825fd948a49c6713c1377);
#
#
#         var popup_330d7d4a9f3727fbcb2b9307c4290f17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e43031030a397366c8b2afb4a61e3ba1 = $(`&lt;div id=&quot;html_e43031030a397366c8b2afb4a61e3ba1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_330d7d4a9f3727fbcb2b9307c4290f17.setContent(html_e43031030a397366c8b2afb4a61e3ba1);
#
#
#
#         marker_df142aa1593bb2131a795fa4db3b6e7a.bindPopup(popup_330d7d4a9f3727fbcb2b9307c4290f17)
#         ;
#
#
#
#
#             var marker_03a7f73f4028d4c3e1a5d65fb1150b5c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1ef8311826f825fd948a49c6713c1377);
#
#
#         var popup_be5a339a927dd72173b777e02e11d318 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d050c9935c61211629cf42745fa0266e = $(`&lt;div id=&quot;html_d050c9935c61211629cf42745fa0266e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_be5a339a927dd72173b777e02e11d318.setContent(html_d050c9935c61211629cf42745fa0266e);
#
#
#
#         marker_03a7f73f4028d4c3e1a5d65fb1150b5c.bindPopup(popup_be5a339a927dd72173b777e02e11d318)
#         ;
#
#
#
#
#             var marker_1cf8f68703e438c715394f907567ae0b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1ef8311826f825fd948a49c6713c1377);
#
#
#         var popup_3a471ec2f0de998718be104532acbd5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c380478fef6b4af3a02beed4ed95ccf0 = $(`&lt;div id=&quot;html_c380478fef6b4af3a02beed4ed95ccf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3a471ec2f0de998718be104532acbd5b.setContent(html_c380478fef6b4af3a02beed4ed95ccf0);
#
#
#
#         marker_1cf8f68703e438c715394f907567ae0b.bindPopup(popup_3a471ec2f0de998718be104532acbd5b)
#         ;
#
#
#
#
#             var marker_63ee13bb21cb49e118dc7e0a5eedef5b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1ef8311826f825fd948a49c6713c1377);
#
#
#         var popup_8a07afe80f0d770af3f03c157327e304 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a340c04573a22f0a954a72ab75fbb6c = $(`&lt;div id=&quot;html_8a340c04573a22f0a954a72ab75fbb6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8a07afe80f0d770af3f03c157327e304.setContent(html_8a340c04573a22f0a954a72ab75fbb6c);
#
#
#
#         marker_63ee13bb21cb49e118dc7e0a5eedef5b.bindPopup(popup_8a07afe80f0d770af3f03c157327e304)
#         ;
#
#
#
#
#             var marker_5c35db8f12a1575b7d78cad1a53585b7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1ef8311826f825fd948a49c6713c1377);
#
#
#         var popup_01d9edad9b8e4cd75bc97a20e8fde800 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_064d07fd806bcc178ce2d5c5d29ce930 = $(`&lt;div id=&quot;html_064d07fd806bcc178ce2d5c5d29ce930&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_01d9edad9b8e4cd75bc97a20e8fde800.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1463dbc2d40f501adc69831d77d1d075 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1463dbc2d40f501adc69831d77d1d075&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1463dbc2d40f501adc69831d77d1d075 = L.map(
#                 &quot;map_1463dbc2d40f501adc69831d77d1d075&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0b376b6c58d715e27acd9595b622b3a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0b376b6c58d715e27acd9595b622b3a.addTo(map_1463dbc2d40f501adc69831d77d1d075);
#
#
#             var feature_group_403804d896bc3159994fad2d18bd7e57 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_46c4b1e5ef93cdb22bf678375fc2d4fd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_403804d896bc3159994fad2d18bd7e57);
#
#
#         var popup_29cda6a4a6b781a4d91ead652cce2a7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b762b21d9f40a39f02b4e3330cb6a2bb = $(`&lt;div id=&quot;html_b762b21d9f40a39f02b4e3330cb6a2bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_29cda6a4a6b781a4d91ead652cce2a7c.setContent(html_b762b21d9f40a39f02b4e3330cb6a2bb);
#
#
#
#         marker_46c4b1e5ef93cdb22bf678375fc2d4fd.bindPopup(popup_29cda6a4a6b781a4d91ead652cce2a7c)
#         ;
#
#
#
#
#             var marker_61e3f2fb4ce32eb285c67045c4f48817 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_403804d896bc3159994fad2d18bd7e57);
#
#
#         var popup_a526e6da7c57edff769cd55d089e5ba3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d794ff7b0bf70a99406901bf888ccb3f = $(`&lt;div id=&quot;html_d794ff7b0bf70a99406901bf888ccb3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a526e6da7c57edff769cd55d089e5ba3.setContent(html_d794ff7b0bf70a99406901bf888ccb3f);
#
#
#
#         marker_61e3f2fb4ce32eb285c67045c4f48817.bindPopup(popup_a526e6da7c57edff769cd55d089e5ba3)
#         ;
#
#
#
#
#             var marker_fb1cfdc5e99f6a4440f3e0bdeddbd33e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_403804d896bc3159994fad2d18bd7e57);
#
#
#         var popup_4cd86d8582e1e49e2f5d9cffbf09a40c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc808ad323e051a40f4249861f2d474e = $(`&lt;div id=&quot;html_cc808ad323e051a40f4249861f2d474e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4cd86d8582e1e49e2f5d9cffbf09a40c.setContent(html_cc808ad323e051a40f4249861f2d474e);
#
#
#
#         marker_fb1cfdc5e99f6a4440f3e0bdeddbd33e.bindPopup(popup_4cd86d8582e1e49e2f5d9cffbf09a40c)
#         ;
#
#
#
#
#             var marker_21b19113943a126e067feabaf01c414e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_403804d896bc3159994fad2d18bd7e57);
#
#
#         var popup_87e1804645c4f554ecc588885929814b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a9cb1c7c95f0e41e3fd1c807de60d23 = $(`&lt;div id=&quot;html_8a9cb1c7c95f0e41e3fd1c807de60d23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_87e1804645c4f554ecc588885929814b.setContent(html_8a9cb1c7c95f0e41e3fd1c807de60d23);
#
#
#
#         marker_21b19113943a126e067feabaf01c414e.bindPopup(popup_87e1804645c4f554ecc588885929814b)
#         ;
#
#
#
#
#             var marker_5dbd72a2512a141fd639419aafee3c8f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_403804d896bc3159994fad2d18bd7e57);
#
#
#         var popup_053d227aee2cf5c788c3b1548d7e2f34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bab921a706a6b30f8c9026f5ff72487c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bab921a706a6b30f8c9026f5ff72487c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bab921a706a6b30f8c9026f5ff72487c = L.map(
#                 &quot;map_bab921a706a6b30f8c9026f5ff72487c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_470c233997782db09e5902afafdc7c2e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_470c233997782db09e5902afafdc7c2e.addTo(map_bab921a706a6b30f8c9026f5ff72487c);
#
#
#             var feature_group_7dd9d7503bedb07938dd26313fc61eb0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7dd9d7503bedb07938dd26313fc61eb0.addTo(map_bab921a706a6b30f8c9026f5ff72487c);
#
#
#             var feature_group_sub_group_ebc5d38e034893c37485650fe0e4797a = L.featureGroup.subGroup(
#                 feature_group_7dd9d7503bedb07938dd26313fc61eb0
#             );
#
#
#             var marker_041348c3f139092577f84a6c08c065ec = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ebc5d38e034893c37485650fe0e4797a);
#
#
#         var popup_9fed9880702a8407644e1b6b63c3853d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c148e0d82a118f001093ab28cbd2024 = $(`&lt;div id=&quot;html_1c148e0d82a118f001093ab28cbd2024&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9fed9880702a8407644e1b6b63c3853d.setContent(html_1c148e0d82a118f001093ab28cbd2024);
#
#
#
#         marker_041348c3f139092577f84a6c08c065ec.bindPopup(popup_9fed9880702a8407644e1b6b63c3853d)
#         ;
#
#
#
#
#             var marker_88e21c40f0f9e0f5f5eeda3a7e73e41c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ebc5d38e034893c37485650fe0e4797a);
#
#
#         var popup_1ecd9b7c9ae7ac14964ae9e0e903e724 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8a8aeb84f3ff3636e033a4b8c0a4930 = $(`&lt;div id=&quot;html_d8a8aeb84f3ff3636e033a4b8c0a4930&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1ecd9b7c9ae7ac14964ae9e0e903e724.setContent(html_d8a8aeb84f3ff3636e033a4b8c0a4930);
#
#
#
#         marker_88e21c40f0f9e0f5f5eeda3a7e73e41c.bindPopup(popup_1ecd9b7c9ae7ac14964ae9e0e903e724)
#         ;
#
#
#
#
#             var marker_c29c9bc70dd18754b0e042b5447fe8ab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ebc5d38e034893c37485650fe0e4797a);
#
#
#         var popup_a38eac449e27f2d5155145c46dce9d8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f41dec8bae871b6d11b84b36c42253a = $(`&lt;div id=&quot;html_6f41dec8bae871b6d11b84b36c42253a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a38eac449e27f2d5155145c46dce9d8e.setContent(html_6f41dec8bae871b6d11b84b36c42253a);
#
#
#
#         marker_c29c9bc70dd18754b0e042b5447fe8ab.bindPopup(popup_a38eac449e27f2d5155145c46dce9d8e)
#         ;
#
#
#
#
#             var marker_8e7743eb753730a4098390f220190d6f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ebc5d38e034893c37485650fe0e4797a);
#
#
#         var popup_d97de70ab1e3e164e5b556f4c71e2e93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23dbcf8564b0cd27eb66705abc079f4c = $(`&lt;div id=&quot;html_23dbcf8564b0cd27eb66705abc079f4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d97de70ab1e3e164e5b556f4c71e2e93.setContent(html_23dbcf8564b0cd27eb66705abc079f4c);
#
#
#
#         marker_
