# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb13fa25934ef09a80b6accbeb12931e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb13fa25934ef09a80b6accbeb12931e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb13fa25934ef09a80b6accbeb12931e = L.map(
#                 &quot;map_cb13fa25934ef09a80b6accbeb12931e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b384e37b73318e065f2c1d53653323c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b384e37b73318e065f2c1d53653323c.addTo(map_cb13fa25934ef09a80b6accbeb12931e);
#
#
#             var marker_67c3d391e1b59160a1b1470cdd396031 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cb13fa25934ef09a80b6accbeb12931e);
#
#
#         var popup_073f61585fe5660debe5a72b7a9c5ddc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20f8de52b76eff52a2f8957a3cc325d9 = $(`&lt;div id=&quot;html_20f8de52b76eff52a2f8957a3cc325d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_073f61585fe5660debe5a72b7a9c5ddc.setContent(html_20f8de52b76eff52a2f8957a3cc325d9);
#
#
#
#         marker_67c3d391e1b59160a1b1470cdd396031.bindPopup(popup_073f61585fe5660debe5a72b7a9c5ddc)
#         ;
#
#
#
#
#             var marker_8fd8a26d80b77441336e681f9e0630f4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cb13fa25934ef09a80b6accbeb12931e);
#
#
#         var popup_4b3e3ee250e935edabc1482d40647911 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2015f55df46b549dbae9620d5b07beb9 = $(`&lt;div id=&quot;html_2015f55df46b549dbae9620d5b07beb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4b3e3ee250e935edabc1482d40647911.setContent(html_2015f55df46b549dbae9620d5b07beb9);
#
#
#
#         marker_8fd8a26d80b77441336e681f9e0630f4.bindPopup(popup_4b3e3ee250e935edabc1482d40647911)
#         ;
#
#
#
#
#             var marker_ea39e8ad2bfb6f9a7fa6d801d2d6a045 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cb13fa25934ef09a80b6accbeb12931e);
#
#
#         var popup_f3bc7338650e15e88346df626599b5da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35a050d0b5f95834d8bacacc824c00ba = $(`&lt;div id=&quot;html_35a050d0b5f95834d8bacacc824c00ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f3bc7338650e15e88346df626599b5da.setContent(html_35a050d0b5f95834d8bacacc824c00ba);
#
#
#
#         marker_ea39e8ad2bfb6f9a7fa6d801d2d6a045.bindPopup(popup_f3bc7338650e15e88346df626599b5da)
#         ;
#
#
#
#
#             var marker_55e70cbeb24ae75a3917d6fa85c8ffbe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cb13fa25934ef09a80b6accbeb12931e);
#
#
#         var popup_7cb15f74245f5f5cc9ee70c399049ee5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29d46b52f0df26730c1e602eb0fa3222 = $(`&lt;div id=&quot;html_29d46b52f0df26730c1e602eb0fa3222&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7cb15f74245f5f5cc9ee70c399049ee5.setContent(html_29d46b52f0df26730c1e602eb0fa3222);
#
#
#
#         marker_55e70cbeb24ae75a3917d6fa85c8ffbe.bindPopup(popup_7cb15f74245f5f5cc9ee70c399049ee5)
#         ;
#
#
#
#
#             var marker_14efe03679885bc29cc7872b9f46027b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cb13fa25934ef09a80b6accbeb12931e);
#
#
#         var popup_84ea092c9bca39f9f0448e4466263a86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_844fa9071044fdc462d227557cc7324a = $(`&lt;div id=&quot;html_844fa9071044fdc462d227557cc7324a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_84ea092c9bca39f9f0448e4466263a86.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2fec46d4d46c2503fa20cee6ba6e81bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2fec46d4d46c2503fa20cee6ba6e81bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2fec46d4d46c2503fa20cee6ba6e81bb = L.map(
#                 &quot;map_2fec46d4d46c2503fa20cee6ba6e81bb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c049bf7a83c760fc26b7ad759479508 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c049bf7a83c760fc26b7ad759479508.addTo(map_2fec46d4d46c2503fa20cee6ba6e81bb);
#
#
#             var feature_group_04926ba583819c61582218cdab0cec0e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8dd5377b40af0eed4678c5c044b56f32 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_04926ba583819c61582218cdab0cec0e);
#
#
#         var popup_3c97abe2cc25576e0ec84887ed085a2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_057388d83051d5b14359293acab8f060 = $(`&lt;div id=&quot;html_057388d83051d5b14359293acab8f060&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3c97abe2cc25576e0ec84887ed085a2a.setContent(html_057388d83051d5b14359293acab8f060);
#
#
#
#         marker_8dd5377b40af0eed4678c5c044b56f32.bindPopup(popup_3c97abe2cc25576e0ec84887ed085a2a)
#         ;
#
#
#
#
#             var marker_0495cb3d9b4b0770b4cf365ec66ac25c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_04926ba583819c61582218cdab0cec0e);
#
#
#         var popup_9039624421a30a5fd745629f83da24f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eae552e2c70711f4999785f13500e581 = $(`&lt;div id=&quot;html_eae552e2c70711f4999785f13500e581&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9039624421a30a5fd745629f83da24f7.setContent(html_eae552e2c70711f4999785f13500e581);
#
#
#
#         marker_0495cb3d9b4b0770b4cf365ec66ac25c.bindPopup(popup_9039624421a30a5fd745629f83da24f7)
#         ;
#
#
#
#
#             var marker_bd2c21bc1aad1f0808995050b2411a7e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_04926ba583819c61582218cdab0cec0e);
#
#
#         var popup_cef9b9559bd8c4752f9a903eda428b8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df058b47d7e5c9a38318bbe5f57d5c1b = $(`&lt;div id=&quot;html_df058b47d7e5c9a38318bbe5f57d5c1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cef9b9559bd8c4752f9a903eda428b8b.setContent(html_df058b47d7e5c9a38318bbe5f57d5c1b);
#
#
#
#         marker_bd2c21bc1aad1f0808995050b2411a7e.bindPopup(popup_cef9b9559bd8c4752f9a903eda428b8b)
#         ;
#
#
#
#
#             var marker_2b4c8df8fd51bc3df4c282cbc511d8f7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_04926ba583819c61582218cdab0cec0e);
#
#
#         var popup_bf3d1a698834993f3ab5b3349b1ff280 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5370eae04005f8b55c3afad7d17d6635 = $(`&lt;div id=&quot;html_5370eae04005f8b55c3afad7d17d6635&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bf3d1a698834993f3ab5b3349b1ff280.setContent(html_5370eae04005f8b55c3afad7d17d6635);
#
#
#
#         marker_2b4c8df8fd51bc3df4c282cbc511d8f7.bindPopup(popup_bf3d1a698834993f3ab5b3349b1ff280)
#         ;
#
#
#
#
#             var marker_8d00cd8be85a743551a89e5e0d181e08 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_04926ba583819c61582218cdab0cec0e);
#
#
#         var popup_f861ac6d883297335b620e4ebda4f25c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a0ec4cabb66b5c5d762482caeeab836 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a0ec4cabb66b5c5d762482caeeab836&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a0ec4cabb66b5c5d762482caeeab836 = L.map(
#                 &quot;map_1a0ec4cabb66b5c5d762482caeeab836&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e960d1d4e211af0b43b4e768282108e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e960d1d4e211af0b43b4e768282108e.addTo(map_1a0ec4cabb66b5c5d762482caeeab836);
#
#
#             var feature_group_473789d596d978517c680febce3c517a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_473789d596d978517c680febce3c517a.addTo(map_1a0ec4cabb66b5c5d762482caeeab836);
#
#
#             var feature_group_sub_group_427c7dfdd904c01299c5ee7abf6e1c01 = L.featureGroup.subGroup(
#                 feature_group_473789d596d978517c680febce3c517a
#             );
#
#
#             var marker_790874fe214b83693ffb4614251980b4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_427c7dfdd904c01299c5ee7abf6e1c01);
#
#
#         var popup_8ca49c2003b35daf1463239574f1a266 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06f1d78e294a8e598978434931b32f52 = $(`&lt;div id=&quot;html_06f1d78e294a8e598978434931b32f52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8ca49c2003b35daf1463239574f1a266.setContent(html_06f1d78e294a8e598978434931b32f52);
#
#
#
#         marker_790874fe214b83693ffb4614251980b4.bindPopup(popup_8ca49c2003b35daf1463239574f1a266)
#         ;
#
#
#
#
#             var marker_58281a6548d917e820dcc395693c8fa9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_427c7dfdd904c01299c5ee7abf6e1c01);
#
#
#         var popup_3db752eb6c15383b165ebb418eef216c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d94c3a3fdb42270dfe7773ac86dab40 = $(`&lt;div id=&quot;html_1d94c3a3fdb42270dfe7773ac86dab40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3db752eb6c15383b165ebb418eef216c.setContent(html_1d94c3a3fdb42270dfe7773ac86dab40);
#
#
#
#         marker_58281a6548d917e820dcc395693c8fa9.bindPopup(popup_3db752eb6c15383b165ebb418eef216c)
#         ;
#
#
#
#
#             var marker_0b6f8df06506c0e6ea8d6b69708ede2b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_427c7dfdd904c01299c5ee7abf6e1c01);
#
#
#         var popup_f3b84006e6ad5e8476c3c216c69d0524 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f278dca0c365835b06458a0ba4214248 = $(`&lt;div id=&quot;html_f278dca0c365835b06458a0ba4214248&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f3b84006e6ad5e8476c3c216c69d0524.setContent(html_f278dca0c365835b06458a0ba4214248);
#
#
#
#         marker_0b6f8df06506c0e6ea8d6b69708ede2b.bindPopup(popup_f3b84006e6ad5e8476c3c216c69d0524)
#         ;
#
#
#
#
#             var marker_3c9418ee4a56618fa89541269579fe70 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_427c7dfdd904c01299c5ee7abf6e1c01);
#
#
#         var popup_4ebfbfcb9173a1b8ce17a07c94081e68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f77146099af63e57529ed94dd1c2f84 = $(`&lt;div id=&quot;html_0f77146099af63e57529ed94dd1c2f84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4ebfbfcb9173a1b8ce17a07c94081e68.setContent(html_0f77146099af63e57529ed94dd1c2f84);
#
#
#
#         marker_
