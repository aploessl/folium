# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52a2e201cbab030ce09d98b35fae2ffe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52a2e201cbab030ce09d98b35fae2ffe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52a2e201cbab030ce09d98b35fae2ffe = L.map(
#                 &quot;map_52a2e201cbab030ce09d98b35fae2ffe&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d976e3db4b3ce33407ec7ae53c48f07 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3d976e3db4b3ce33407ec7ae53c48f07.addTo(map_52a2e201cbab030ce09d98b35fae2ffe);
#
#
#             var marker_910c2776eb44cd2a5932617909e97d19 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_52a2e201cbab030ce09d98b35fae2ffe);
#
#
#         var popup_9653e595ac7fdf9d56f2086ef21b5f48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4b3c883b93479b533e45c4ab9e46c8a = $(`&lt;div id=&quot;html_c4b3c883b93479b533e45c4ab9e46c8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9653e595ac7fdf9d56f2086ef21b5f48.setContent(html_c4b3c883b93479b533e45c4ab9e46c8a);
#
#
#
#         marker_910c2776eb44cd2a5932617909e97d19.bindPopup(popup_9653e595ac7fdf9d56f2086ef21b5f48)
#         ;
#
#
#
#
#             var marker_1e7df1b9f69781b82e216b0f2c7f6923 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_52a2e201cbab030ce09d98b35fae2ffe);
#
#
#         var popup_10b998046739e8110339b95b3146e598 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f267a585d62f2a49bc5bc962561d1c08 = $(`&lt;div id=&quot;html_f267a585d62f2a49bc5bc962561d1c08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_10b998046739e8110339b95b3146e598.setContent(html_f267a585d62f2a49bc5bc962561d1c08);
#
#
#
#         marker_1e7df1b9f69781b82e216b0f2c7f6923.bindPopup(popup_10b998046739e8110339b95b3146e598)
#         ;
#
#
#
#
#             var marker_3455927bd6485187ae826429e1c754fa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_52a2e201cbab030ce09d98b35fae2ffe);
#
#
#         var popup_c35ec5c995b0cc6e9b3155cd8ab50a06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c748f3601035ddd74580b0291741be8 = $(`&lt;div id=&quot;html_2c748f3601035ddd74580b0291741be8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c35ec5c995b0cc6e9b3155cd8ab50a06.setContent(html_2c748f3601035ddd74580b0291741be8);
#
#
#
#         marker_3455927bd6485187ae826429e1c754fa.bindPopup(popup_c35ec5c995b0cc6e9b3155cd8ab50a06)
#         ;
#
#
#
#
#             var marker_dcf9410950e924ab70df6c44a97261e4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_52a2e201cbab030ce09d98b35fae2ffe);
#
#
#         var popup_35b2359f9780eb395952986a07162985 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f79f86d8532585bd1fba4274f8b7aaf0 = $(`&lt;div id=&quot;html_f79f86d8532585bd1fba4274f8b7aaf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_35b2359f9780eb395952986a07162985.setContent(html_f79f86d8532585bd1fba4274f8b7aaf0);
#
#
#
#         marker_dcf9410950e924ab70df6c44a97261e4.bindPopup(popup_35b2359f9780eb395952986a07162985)
#         ;
#
#
#
#
#             var marker_554ecc57ad8a7ee4c8b21b5bf58749e1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_52a2e201cbab030ce09d98b35fae2ffe);
#
#
#         var popup_ccb072fa479a4d5866c152af851e9a9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba5b61939649bb4f4aafb6278299c6d2 = $(`&lt;div id=&quot;html_ba5b61939649bb4f4aafb6278299c6d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ccb072fa479a4d5866c152af851e9a9e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13056e91bf348c4c47b32ecbc17a0500 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13056e91bf348c4c47b32ecbc17a0500&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13056e91bf348c4c47b32ecbc17a0500 = L.map(
#                 &quot;map_13056e91bf348c4c47b32ecbc17a0500&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7f92113f137bdcd3e4c940a365c7b41 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d7f92113f137bdcd3e4c940a365c7b41.addTo(map_13056e91bf348c4c47b32ecbc17a0500);
#
#
#             var feature_group_0fa05e8a09d598cc3d5897e0ad4d7986 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f9196a539e1cbd8fbd8c6959c4230e2a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0fa05e8a09d598cc3d5897e0ad4d7986);
#
#
#         var popup_cac00b20b7a09697be16f45ecd9dcec5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d86492f94362e2edbf7ce2e61cfb951 = $(`&lt;div id=&quot;html_6d86492f94362e2edbf7ce2e61cfb951&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cac00b20b7a09697be16f45ecd9dcec5.setContent(html_6d86492f94362e2edbf7ce2e61cfb951);
#
#
#
#         marker_f9196a539e1cbd8fbd8c6959c4230e2a.bindPopup(popup_cac00b20b7a09697be16f45ecd9dcec5)
#         ;
#
#
#
#
#             var marker_37dbdc40b380b4339fa179f8bfe22ac0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0fa05e8a09d598cc3d5897e0ad4d7986);
#
#
#         var popup_80e67a8a149648de20b5194262050883 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ed1710aa22de7ecc7203d88474ae7e8 = $(`&lt;div id=&quot;html_2ed1710aa22de7ecc7203d88474ae7e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_80e67a8a149648de20b5194262050883.setContent(html_2ed1710aa22de7ecc7203d88474ae7e8);
#
#
#
#         marker_37dbdc40b380b4339fa179f8bfe22ac0.bindPopup(popup_80e67a8a149648de20b5194262050883)
#         ;
#
#
#
#
#             var marker_dc267d31e15cd4d035ba8993be7b50da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0fa05e8a09d598cc3d5897e0ad4d7986);
#
#
#         var popup_ba7295a929e8d7d28212e6ca8202ac51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af3c9f28f81c559f0b9aa7c72e29f2ca = $(`&lt;div id=&quot;html_af3c9f28f81c559f0b9aa7c72e29f2ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ba7295a929e8d7d28212e6ca8202ac51.setContent(html_af3c9f28f81c559f0b9aa7c72e29f2ca);
#
#
#
#         marker_dc267d31e15cd4d035ba8993be7b50da.bindPopup(popup_ba7295a929e8d7d28212e6ca8202ac51)
#         ;
#
#
#
#
#             var marker_d34a0fc4163da918f861224de50371cb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0fa05e8a09d598cc3d5897e0ad4d7986);
#
#
#         var popup_95d89c0c4966bd5932566500a1394cf8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f4633cf62405e80d628ec9c0bc7a691 = $(`&lt;div id=&quot;html_9f4633cf62405e80d628ec9c0bc7a691&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_95d89c0c4966bd5932566500a1394cf8.setContent(html_9f4633cf62405e80d628ec9c0bc7a691);
#
#
#
#         marker_d34a0fc4163da918f861224de50371cb.bindPopup(popup_95d89c0c4966bd5932566500a1394cf8)
#         ;
#
#
#
#
#             var marker_54278ccafb65f6468b017d8e5f9414f5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0fa05e8a09d598cc3d5897e0ad4d7986);
#
#
#         var popup_6d7629579d2f0e63034b109b5a6b232f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aee7b5ed88b6b43e9b26d1fc796b2131 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aee7b5ed88b6b43e9b26d1fc796b2131&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aee7b5ed88b6b43e9b26d1fc796b2131 = L.map(
#                 &quot;map_aee7b5ed88b6b43e9b26d1fc796b2131&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d49f6bb873e09ebfbc47e08d636ad340 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d49f6bb873e09ebfbc47e08d636ad340.addTo(map_aee7b5ed88b6b43e9b26d1fc796b2131);
#
#
#             var feature_group_5e60205e93f193b8e153c569a0cf7031 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5e60205e93f193b8e153c569a0cf7031.addTo(map_aee7b5ed88b6b43e9b26d1fc796b2131);
#
#
#             var feature_group_sub_group_abaccb4cb7f27ac51468e00cc6367eca = L.featureGroup.subGroup(
#                 feature_group_5e60205e93f193b8e153c569a0cf7031
#             );
#
#
#             var marker_dafe6746deb9a243fb2580f0957c583c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_abaccb4cb7f27ac51468e00cc6367eca);
#
#
#         var popup_8766884876e851fca3e8bf25282cd5e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad3073fe42c9b013307fb9772ee2f253 = $(`&lt;div id=&quot;html_ad3073fe42c9b013307fb9772ee2f253&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8766884876e851fca3e8bf25282cd5e8.setContent(html_ad3073fe42c9b013307fb9772ee2f253);
#
#
#
#         marker_dafe6746deb9a243fb2580f0957c583c.bindPopup(popup_8766884876e851fca3e8bf25282cd5e8)
#         ;
#
#
#
#
#             var marker_dc8597b01697e2ca03215210c2ed1b3a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_abaccb4cb7f27ac51468e00cc6367eca);
#
#
#         var popup_04a78827d56593f34a0bb07c7ccd98ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ab2b2604c49c09a6164ff6c711b5664 = $(`&lt;div id=&quot;html_9ab2b2604c49c09a6164ff6c711b5664&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_04a78827d56593f34a0bb07c7ccd98ec.setContent(html_9ab2b2604c49c09a6164ff6c711b5664);
#
#
#
#         marker_dc8597b01697e2ca03215210c2ed1b3a.bindPopup(popup_04a78827d56593f34a0bb07c7ccd98ec)
#         ;
#
#
#
#
#             var marker_a99d89fa021091a9a52c21094a67dac3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_abaccb4cb7f27ac51468e00cc6367eca);
#
#
#         var popup_1b8e139d32c4ebf086eb82fbe4bc1a27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0164a0a0c0fc07bdf2dce089cd381842 = $(`&lt;div id=&quot;html_0164a0a0c0fc07bdf2dce089cd381842&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1b8e139d32c4ebf086eb82fbe4bc1a27.setContent(html_0164a0a0c0fc07bdf2dce089cd381842);
#
#
#
#         marker_a99d89fa021091a9a52c21094a67dac3.bindPopup(popup_1b8e139d32c4ebf086eb82fbe4bc1a27)
#         ;
#
#
#
#
#             var marker_e0bd7ef90b989e90640559c1fedb03a0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_abaccb4cb7f27ac51468e00cc6367eca);
#
#
#         var popup_135f71bebd647ef4bf199e8b284dc174 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44753ad335ec39f3ff949e6cbaf32c85 = $(`&lt;div id=&quot;html_44753ad335ec39f3ff949e6cbaf32c85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_135f71bebd647ef4bf199e8b284dc174.setContent(html_44753ad335ec39f3ff949e6cbaf32c85);
#
#
#
#         marker_
