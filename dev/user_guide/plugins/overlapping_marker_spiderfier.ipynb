# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_33d9e925a30991af2b25b7679f08e9fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_33d9e925a30991af2b25b7679f08e9fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_33d9e925a30991af2b25b7679f08e9fb = L.map(
#                 &quot;map_33d9e925a30991af2b25b7679f08e9fb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_565af79ab0c4d0442180e8f319e35b02 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_565af79ab0c4d0442180e8f319e35b02.addTo(map_33d9e925a30991af2b25b7679f08e9fb);
#
#
#             var marker_7ca827c45ca158c98c9c8017b9806180 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_33d9e925a30991af2b25b7679f08e9fb);
#
#
#         var popup_02b657f62f5c7ef1b4d30d18be695bf5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d51996563e38ed18b0df07792abaf86 = $(`&lt;div id=&quot;html_0d51996563e38ed18b0df07792abaf86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_02b657f62f5c7ef1b4d30d18be695bf5.setContent(html_0d51996563e38ed18b0df07792abaf86);
#
#
#
#         marker_7ca827c45ca158c98c9c8017b9806180.bindPopup(popup_02b657f62f5c7ef1b4d30d18be695bf5)
#         ;
#
#
#
#
#             var marker_192df1e705325e4341d785bd58628915 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_33d9e925a30991af2b25b7679f08e9fb);
#
#
#         var popup_ead29569ca1ed3203bb21cde6838c2d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_375304f481d2431418f841e3b623378c = $(`&lt;div id=&quot;html_375304f481d2431418f841e3b623378c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ead29569ca1ed3203bb21cde6838c2d9.setContent(html_375304f481d2431418f841e3b623378c);
#
#
#
#         marker_192df1e705325e4341d785bd58628915.bindPopup(popup_ead29569ca1ed3203bb21cde6838c2d9)
#         ;
#
#
#
#
#             var marker_8c3605aa45dfd582b0cbb97c8c4663d8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_33d9e925a30991af2b25b7679f08e9fb);
#
#
#         var popup_76ce38e2a36569b6017f6918524749c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ff0b63fe78f07611e7da94d9efb8265 = $(`&lt;div id=&quot;html_0ff0b63fe78f07611e7da94d9efb8265&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_76ce38e2a36569b6017f6918524749c9.setContent(html_0ff0b63fe78f07611e7da94d9efb8265);
#
#
#
#         marker_8c3605aa45dfd582b0cbb97c8c4663d8.bindPopup(popup_76ce38e2a36569b6017f6918524749c9)
#         ;
#
#
#
#
#             var marker_622de7bbe68a8e8b674c27c2baab77b0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_33d9e925a30991af2b25b7679f08e9fb);
#
#
#         var popup_da86e739d53baf63a0fa1dc479baf3e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e01d755ce974e3593f5729aab207528 = $(`&lt;div id=&quot;html_9e01d755ce974e3593f5729aab207528&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_da86e739d53baf63a0fa1dc479baf3e9.setContent(html_9e01d755ce974e3593f5729aab207528);
#
#
#
#         marker_622de7bbe68a8e8b674c27c2baab77b0.bindPopup(popup_da86e739d53baf63a0fa1dc479baf3e9)
#         ;
#
#
#
#
#             var marker_0c53667a144a8a1aad91e5e1ef166284 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_33d9e925a30991af2b25b7679f08e9fb);
#
#
#         var popup_b9bbf05efcfddbc80d3423871e04f37b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15b83d21d05108bb6d9a89504f87bf20 = $(`&lt;div id=&quot;html_15b83d21d05108bb6d9a89504f87bf20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b9bbf05efcfddbc80d3423871e04f37b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d68661d5bae23df767b0d6ac05b6f48 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d68661d5bae23df767b0d6ac05b6f48&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d68661d5bae23df767b0d6ac05b6f48 = L.map(
#                 &quot;map_8d68661d5bae23df767b0d6ac05b6f48&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8a9d47aad261853c3c4d4e11adcc3df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b8a9d47aad261853c3c4d4e11adcc3df.addTo(map_8d68661d5bae23df767b0d6ac05b6f48);
#
#
#             var feature_group_ab358869589626e9f8793dba33d91e4e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6900c5c566e8d7d2fbfc89bc60ad0c3f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ab358869589626e9f8793dba33d91e4e);
#
#
#         var popup_9187950c64542fb1d68aca019bf5e6d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d04e598b154dbcbd0fa6f375ef23532 = $(`&lt;div id=&quot;html_7d04e598b154dbcbd0fa6f375ef23532&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9187950c64542fb1d68aca019bf5e6d4.setContent(html_7d04e598b154dbcbd0fa6f375ef23532);
#
#
#
#         marker_6900c5c566e8d7d2fbfc89bc60ad0c3f.bindPopup(popup_9187950c64542fb1d68aca019bf5e6d4)
#         ;
#
#
#
#
#             var marker_4358ada8021d587490ab08bf3a58d21d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ab358869589626e9f8793dba33d91e4e);
#
#
#         var popup_c27c8d061549529f5cdd3098a35639bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45895fc61da2531e20ac05be2a88e5ef = $(`&lt;div id=&quot;html_45895fc61da2531e20ac05be2a88e5ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c27c8d061549529f5cdd3098a35639bc.setContent(html_45895fc61da2531e20ac05be2a88e5ef);
#
#
#
#         marker_4358ada8021d587490ab08bf3a58d21d.bindPopup(popup_c27c8d061549529f5cdd3098a35639bc)
#         ;
#
#
#
#
#             var marker_ce4a065092e0950c709ce4a8f3f6349a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ab358869589626e9f8793dba33d91e4e);
#
#
#         var popup_e0f377f237242dea3e3897d0b37f9a84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5146e1bf005dfdf427269ec2914f6bb8 = $(`&lt;div id=&quot;html_5146e1bf005dfdf427269ec2914f6bb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e0f377f237242dea3e3897d0b37f9a84.setContent(html_5146e1bf005dfdf427269ec2914f6bb8);
#
#
#
#         marker_ce4a065092e0950c709ce4a8f3f6349a.bindPopup(popup_e0f377f237242dea3e3897d0b37f9a84)
#         ;
#
#
#
#
#             var marker_49575a1f417a0a540a9d30beac17109a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ab358869589626e9f8793dba33d91e4e);
#
#
#         var popup_9417a5fec5c99efea10a5d6112362544 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40fafd55bc3383a1f0148f106564d8e7 = $(`&lt;div id=&quot;html_40fafd55bc3383a1f0148f106564d8e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9417a5fec5c99efea10a5d6112362544.setContent(html_40fafd55bc3383a1f0148f106564d8e7);
#
#
#
#         marker_49575a1f417a0a540a9d30beac17109a.bindPopup(popup_9417a5fec5c99efea10a5d6112362544)
#         ;
#
#
#
#
#             var marker_45e4242ab1dbbaf7ab66e34b9b1608e8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ab358869589626e9f8793dba33d91e4e);
#
#
#         var popup_42e42a287f33180629a24c8d70a5d82a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21d83755f7e4218ca563fbeecd5ac27a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21d83755f7e4218ca563fbeecd5ac27a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21d83755f7e4218ca563fbeecd5ac27a = L.map(
#                 &quot;map_21d83755f7e4218ca563fbeecd5ac27a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_148db22051214b6fc1b9919a7da81a39 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_148db22051214b6fc1b9919a7da81a39.addTo(map_21d83755f7e4218ca563fbeecd5ac27a);
#
#
#             var feature_group_41fc00f3d11ab97c4eaa78adf7ec17b2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_41fc00f3d11ab97c4eaa78adf7ec17b2.addTo(map_21d83755f7e4218ca563fbeecd5ac27a);
#
#
#             var feature_group_sub_group_6eef66eb399d551e532ad3b9fda9684e = L.featureGroup.subGroup(
#                 feature_group_41fc00f3d11ab97c4eaa78adf7ec17b2
#             );
#
#
#             var marker_22ed19e15cc9c63c31cf0c768983c388 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6eef66eb399d551e532ad3b9fda9684e);
#
#
#         var popup_0cebe07d9d9f8d53e8693d122023a5f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c323608974d39a082ba193150a7ce766 = $(`&lt;div id=&quot;html_c323608974d39a082ba193150a7ce766&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0cebe07d9d9f8d53e8693d122023a5f6.setContent(html_c323608974d39a082ba193150a7ce766);
#
#
#
#         marker_22ed19e15cc9c63c31cf0c768983c388.bindPopup(popup_0cebe07d9d9f8d53e8693d122023a5f6)
#         ;
#
#
#
#
#             var marker_d7f5ed24984bb67b8c12b21d64159104 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6eef66eb399d551e532ad3b9fda9684e);
#
#
#         var popup_92616e6f1c1b73ba02ba75607b411c0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4f0af2816cc5a6c693d38bf18ff5dc3 = $(`&lt;div id=&quot;html_e4f0af2816cc5a6c693d38bf18ff5dc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_92616e6f1c1b73ba02ba75607b411c0b.setContent(html_e4f0af2816cc5a6c693d38bf18ff5dc3);
#
#
#
#         marker_d7f5ed24984bb67b8c12b21d64159104.bindPopup(popup_92616e6f1c1b73ba02ba75607b411c0b)
#         ;
#
#
#
#
#             var marker_be5f8493055774530651f562deb88e42 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6eef66eb399d551e532ad3b9fda9684e);
#
#
#         var popup_4dc009503ee05375701b9027a00e37c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfc95f7a24c2fbc739afcf7ded37f9c5 = $(`&lt;div id=&quot;html_cfc95f7a24c2fbc739afcf7ded37f9c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4dc009503ee05375701b9027a00e37c7.setContent(html_cfc95f7a24c2fbc739afcf7ded37f9c5);
#
#
#
#         marker_be5f8493055774530651f562deb88e42.bindPopup(popup_4dc009503ee05375701b9027a00e37c7)
#         ;
#
#
#
#
#             var marker_ef94f1d124f8f74852f6322dc2d6a0c6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6eef66eb399d551e532ad3b9fda9684e);
#
#
#         var popup_5e6b110fb04975e9b15edaeec211f52c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbd2d8f6c49ee870a74b9e9b9ccc5f1d = $(`&lt;div id=&quot;html_bbd2d8f6c49ee870a74b9e9b9ccc5f1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5e6b110fb04975e9b15edaeec211f52c.setContent(html_bbd2d8f6c49ee870a74b9e9b9ccc5f1d);
#
#
#
#         marker_
