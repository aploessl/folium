# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36bf924d8a0f888300c8d7443aa54278 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36bf924d8a0f888300c8d7443aa54278&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36bf924d8a0f888300c8d7443aa54278 = L.map(
#                 &quot;map_36bf924d8a0f888300c8d7443aa54278&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec2651d9356d7a797c03ecc08846e440 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec2651d9356d7a797c03ecc08846e440.addTo(map_36bf924d8a0f888300c8d7443aa54278);
#
#
#             var marker_8d8a7a012cec63f41ed8d1441f833db1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_36bf924d8a0f888300c8d7443aa54278);
#
#
#         var popup_0289ab85db51b69fd8ca3a87dbd59b8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50fdaa4b925b6973a6adbdc5a8f627d0 = $(`&lt;div id=&quot;html_50fdaa4b925b6973a6adbdc5a8f627d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0289ab85db51b69fd8ca3a87dbd59b8b.setContent(html_50fdaa4b925b6973a6adbdc5a8f627d0);
#
#
#
#         marker_8d8a7a012cec63f41ed8d1441f833db1.bindPopup(popup_0289ab85db51b69fd8ca3a87dbd59b8b)
#         ;
#
#
#
#
#             var marker_64b0e6680587a3ee0a450ea792d6527e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_36bf924d8a0f888300c8d7443aa54278);
#
#
#         var popup_2c0b6d31b3c17a4050b3e1ca49fdba65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa9a6d39d45a3f4ce566376e69c75eb1 = $(`&lt;div id=&quot;html_aa9a6d39d45a3f4ce566376e69c75eb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2c0b6d31b3c17a4050b3e1ca49fdba65.setContent(html_aa9a6d39d45a3f4ce566376e69c75eb1);
#
#
#
#         marker_64b0e6680587a3ee0a450ea792d6527e.bindPopup(popup_2c0b6d31b3c17a4050b3e1ca49fdba65)
#         ;
#
#
#
#
#             var marker_3f90d5cdb3dd710022c1bd6ea57161dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_36bf924d8a0f888300c8d7443aa54278);
#
#
#         var popup_96861a6b81559dd15ac8af76ac4b3719 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71b553877c728ffb9329fa595e0fa591 = $(`&lt;div id=&quot;html_71b553877c728ffb9329fa595e0fa591&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_96861a6b81559dd15ac8af76ac4b3719.setContent(html_71b553877c728ffb9329fa595e0fa591);
#
#
#
#         marker_3f90d5cdb3dd710022c1bd6ea57161dc.bindPopup(popup_96861a6b81559dd15ac8af76ac4b3719)
#         ;
#
#
#
#
#             var marker_ef54be51d962d72ca91192f72035fcf9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_36bf924d8a0f888300c8d7443aa54278);
#
#
#         var popup_96001cd04fbaf734ffce897248e25f8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5418f2d29a56624df33d3b3ff3c3d9a3 = $(`&lt;div id=&quot;html_5418f2d29a56624df33d3b3ff3c3d9a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_96001cd04fbaf734ffce897248e25f8f.setContent(html_5418f2d29a56624df33d3b3ff3c3d9a3);
#
#
#
#         marker_ef54be51d962d72ca91192f72035fcf9.bindPopup(popup_96001cd04fbaf734ffce897248e25f8f)
#         ;
#
#
#
#
#             var marker_e2ea29cb7296e04970b35b0ba5c570ec = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_36bf924d8a0f888300c8d7443aa54278);
#
#
#         var popup_99206d739fda8ae034a85c35aeadf350 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_551025b64d72a64fda82969412319844 = $(`&lt;div id=&quot;html_551025b64d72a64fda82969412319844&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_99206d739fda8ae034a85c35aeadf350.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9366175448139eee7ae9a99eca502791 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9366175448139eee7ae9a99eca502791&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9366175448139eee7ae9a99eca502791 = L.map(
#                 &quot;map_9366175448139eee7ae9a99eca502791&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_029de5721c4295c7578db84b215e5a1f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_029de5721c4295c7578db84b215e5a1f.addTo(map_9366175448139eee7ae9a99eca502791);
#
#
#             var feature_group_c062368f84d6c56f6f0ad051320c9deb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c08234cd9299bdc67c82d84ed8519625 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c062368f84d6c56f6f0ad051320c9deb);
#
#
#         var popup_e0cb5381cdcf038e52fdfd4e32acf1d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4651505e3a3a2816008db5b1352d456e = $(`&lt;div id=&quot;html_4651505e3a3a2816008db5b1352d456e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e0cb5381cdcf038e52fdfd4e32acf1d5.setContent(html_4651505e3a3a2816008db5b1352d456e);
#
#
#
#         marker_c08234cd9299bdc67c82d84ed8519625.bindPopup(popup_e0cb5381cdcf038e52fdfd4e32acf1d5)
#         ;
#
#
#
#
#             var marker_1192276b8f411cdd94218881d89874b7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c062368f84d6c56f6f0ad051320c9deb);
#
#
#         var popup_4a63ef39b27c62674b3200f7495dd15b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70bb1e8c4cd70fd9cbb7f670858307f1 = $(`&lt;div id=&quot;html_70bb1e8c4cd70fd9cbb7f670858307f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4a63ef39b27c62674b3200f7495dd15b.setContent(html_70bb1e8c4cd70fd9cbb7f670858307f1);
#
#
#
#         marker_1192276b8f411cdd94218881d89874b7.bindPopup(popup_4a63ef39b27c62674b3200f7495dd15b)
#         ;
#
#
#
#
#             var marker_831f390fc193596f5a66de1133aabb6a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c062368f84d6c56f6f0ad051320c9deb);
#
#
#         var popup_a16d3e7810d8f92de92a51467375e21b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8554e837bb8423a7fe23d4ab47be9f27 = $(`&lt;div id=&quot;html_8554e837bb8423a7fe23d4ab47be9f27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a16d3e7810d8f92de92a51467375e21b.setContent(html_8554e837bb8423a7fe23d4ab47be9f27);
#
#
#
#         marker_831f390fc193596f5a66de1133aabb6a.bindPopup(popup_a16d3e7810d8f92de92a51467375e21b)
#         ;
#
#
#
#
#             var marker_c08beb97331a730a3a533f2c57335070 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c062368f84d6c56f6f0ad051320c9deb);
#
#
#         var popup_a60b59efd812e6671ecb624f537aae17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6227eb2544645ee0fe078e94d5a5a8a7 = $(`&lt;div id=&quot;html_6227eb2544645ee0fe078e94d5a5a8a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a60b59efd812e6671ecb624f537aae17.setContent(html_6227eb2544645ee0fe078e94d5a5a8a7);
#
#
#
#         marker_c08beb97331a730a3a533f2c57335070.bindPopup(popup_a60b59efd812e6671ecb624f537aae17)
#         ;
#
#
#
#
#             var marker_8d3fb27d444852ed9e61a964a06e0cc5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c062368f84d6c56f6f0ad051320c9deb);
#
#
#         var popup_8b469892bdd530790021da6e34ad2f10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85df4f60a769f03e496ba23f1d715c0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85df4f60a769f03e496ba23f1d715c0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85df4f60a769f03e496ba23f1d715c0d = L.map(
#                 &quot;map_85df4f60a769f03e496ba23f1d715c0d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7658b4fc73b8dcce8c5f866853231f75 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7658b4fc73b8dcce8c5f866853231f75.addTo(map_85df4f60a769f03e496ba23f1d715c0d);
#
#
#             var feature_group_ad166c99ac180bf6cb6773278fbae748 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ad166c99ac180bf6cb6773278fbae748.addTo(map_85df4f60a769f03e496ba23f1d715c0d);
#
#
#             var feature_group_sub_group_45ca79f881a615050c823dfca784da0e = L.featureGroup.subGroup(
#                 feature_group_ad166c99ac180bf6cb6773278fbae748
#             );
#
#
#             var marker_7368bdd4eecd2569949ddfcea589b1aa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_45ca79f881a615050c823dfca784da0e);
#
#
#         var popup_3fc421bcf989d42b6349f790c8fed8cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b65be9866795cfe103ce76073c65678f = $(`&lt;div id=&quot;html_b65be9866795cfe103ce76073c65678f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3fc421bcf989d42b6349f790c8fed8cf.setContent(html_b65be9866795cfe103ce76073c65678f);
#
#
#
#         marker_7368bdd4eecd2569949ddfcea589b1aa.bindPopup(popup_3fc421bcf989d42b6349f790c8fed8cf)
#         ;
#
#
#
#
#             var marker_cb332eb7611956b3d4aba22252ae6633 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_45ca79f881a615050c823dfca784da0e);
#
#
#         var popup_760c0af36dd371602bec836b4fd2b00d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24acf814388260b112714de4c00879b8 = $(`&lt;div id=&quot;html_24acf814388260b112714de4c00879b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_760c0af36dd371602bec836b4fd2b00d.setContent(html_24acf814388260b112714de4c00879b8);
#
#
#
#         marker_cb332eb7611956b3d4aba22252ae6633.bindPopup(popup_760c0af36dd371602bec836b4fd2b00d)
#         ;
#
#
#
#
#             var marker_3151b1d8da68c5af3238e9f569de3ed5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_45ca79f881a615050c823dfca784da0e);
#
#
#         var popup_dd4c9bed10d3ef22a8e7f6f836b7d05a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9e786641212fedc26aa40e91b1c64be = $(`&lt;div id=&quot;html_f9e786641212fedc26aa40e91b1c64be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_dd4c9bed10d3ef22a8e7f6f836b7d05a.setContent(html_f9e786641212fedc26aa40e91b1c64be);
#
#
#
#         marker_3151b1d8da68c5af3238e9f569de3ed5.bindPopup(popup_dd4c9bed10d3ef22a8e7f6f836b7d05a)
#         ;
#
#
#
#
#             var marker_e378b2f7a3795d3252a224908d128e98 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_45ca79f881a615050c823dfca784da0e);
#
#
#         var popup_8d48d5b3afc1efb73aa1824eb1150b64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d3700cedfcf94f427e907b3e90c6ef4 = $(`&lt;div id=&quot;html_3d3700cedfcf94f427e907b3e90c6ef4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8d48d5b3afc1efb73aa1824eb1150b64.setContent(html_3d3700cedfcf94f427e907b3e90c6ef4);
#
#
#
#         marker_
