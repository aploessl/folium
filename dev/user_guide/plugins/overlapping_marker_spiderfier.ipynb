# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5756c4e65d43153f3c6034b56fac204c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5756c4e65d43153f3c6034b56fac204c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5756c4e65d43153f3c6034b56fac204c = L.map(
#                 &quot;map_5756c4e65d43153f3c6034b56fac204c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cac6aef945d96b84aa496ece8b884359 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cac6aef945d96b84aa496ece8b884359.addTo(map_5756c4e65d43153f3c6034b56fac204c);
#
#
#             var marker_d40b9a24405179b33aa6d5d52108c8eb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5756c4e65d43153f3c6034b56fac204c);
#
#
#         var popup_1a249bdb73852e9c4f2c27d0f7e562c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2fd856b44f488ba6957bde97671b1a7 = $(`&lt;div id=&quot;html_d2fd856b44f488ba6957bde97671b1a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1a249bdb73852e9c4f2c27d0f7e562c6.setContent(html_d2fd856b44f488ba6957bde97671b1a7);
#
#
#
#         marker_d40b9a24405179b33aa6d5d52108c8eb.bindPopup(popup_1a249bdb73852e9c4f2c27d0f7e562c6)
#         ;
#
#
#
#
#             var marker_f74d5589cf9fec291d32ebf1fdf01f3c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5756c4e65d43153f3c6034b56fac204c);
#
#
#         var popup_d85bc1de069e50a08590c711fd04ac8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_536da88e257fffc9f39f3862945b47f6 = $(`&lt;div id=&quot;html_536da88e257fffc9f39f3862945b47f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d85bc1de069e50a08590c711fd04ac8a.setContent(html_536da88e257fffc9f39f3862945b47f6);
#
#
#
#         marker_f74d5589cf9fec291d32ebf1fdf01f3c.bindPopup(popup_d85bc1de069e50a08590c711fd04ac8a)
#         ;
#
#
#
#
#             var marker_3c100751ad4c6cab47c4556433a0eaf6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5756c4e65d43153f3c6034b56fac204c);
#
#
#         var popup_1d8b0aee71934e87ea532867e86f5864 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69de2e5c6d2bacc82419dc08c5c2e29a = $(`&lt;div id=&quot;html_69de2e5c6d2bacc82419dc08c5c2e29a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1d8b0aee71934e87ea532867e86f5864.setContent(html_69de2e5c6d2bacc82419dc08c5c2e29a);
#
#
#
#         marker_3c100751ad4c6cab47c4556433a0eaf6.bindPopup(popup_1d8b0aee71934e87ea532867e86f5864)
#         ;
#
#
#
#
#             var marker_2c3dc08823e483f47a5971385712d7f0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5756c4e65d43153f3c6034b56fac204c);
#
#
#         var popup_1f4d80fb2149144fe557b31b7b333716 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c135b4a707c957e2ab286d6ebc6cf1d = $(`&lt;div id=&quot;html_2c135b4a707c957e2ab286d6ebc6cf1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1f4d80fb2149144fe557b31b7b333716.setContent(html_2c135b4a707c957e2ab286d6ebc6cf1d);
#
#
#
#         marker_2c3dc08823e483f47a5971385712d7f0.bindPopup(popup_1f4d80fb2149144fe557b31b7b333716)
#         ;
#
#
#
#
#             var marker_9cfb70a02bb209caf9cd9d20e3d60ebd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5756c4e65d43153f3c6034b56fac204c);
#
#
#         var popup_fa379074c676488838e49d5f3a7dabe8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_efab22284f7ed3d13f24f4c1bf4ea71d = $(`&lt;div id=&quot;html_efab22284f7ed3d13f24f4c1bf4ea71d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fa379074c676488838e49d5f3a7dabe8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f8d696def0217187f4fb4e6b878a6cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f8d696def0217187f4fb4e6b878a6cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f8d696def0217187f4fb4e6b878a6cd = L.map(
#                 &quot;map_3f8d696def0217187f4fb4e6b878a6cd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_709b4c07f1ba9900a94282bd85b19092 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_709b4c07f1ba9900a94282bd85b19092.addTo(map_3f8d696def0217187f4fb4e6b878a6cd);
#
#
#             var feature_group_42ef0a87e18245c8c78062d116387b53 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7e1456ff04cdf23a08c19084722c2dbe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_42ef0a87e18245c8c78062d116387b53);
#
#
#         var popup_a320e34e1fe485ff1266637f303587f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_115f881060a7220282565afe96fc557a = $(`&lt;div id=&quot;html_115f881060a7220282565afe96fc557a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a320e34e1fe485ff1266637f303587f0.setContent(html_115f881060a7220282565afe96fc557a);
#
#
#
#         marker_7e1456ff04cdf23a08c19084722c2dbe.bindPopup(popup_a320e34e1fe485ff1266637f303587f0)
#         ;
#
#
#
#
#             var marker_65c0b5b4578b8a6091338662ac497a2e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_42ef0a87e18245c8c78062d116387b53);
#
#
#         var popup_ec910813c36eb8cd960b1bda16108590 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cb1fd98ed4576c003f427a3919ac8f6 = $(`&lt;div id=&quot;html_0cb1fd98ed4576c003f427a3919ac8f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ec910813c36eb8cd960b1bda16108590.setContent(html_0cb1fd98ed4576c003f427a3919ac8f6);
#
#
#
#         marker_65c0b5b4578b8a6091338662ac497a2e.bindPopup(popup_ec910813c36eb8cd960b1bda16108590)
#         ;
#
#
#
#
#             var marker_b1407da4fbaf12f113dc082fad3333ab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_42ef0a87e18245c8c78062d116387b53);
#
#
#         var popup_b8edf6c9deb09f4a55ce3b42b6375d39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1cc19f7fcdf0f916ef8ec6ce6f39bea = $(`&lt;div id=&quot;html_c1cc19f7fcdf0f916ef8ec6ce6f39bea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b8edf6c9deb09f4a55ce3b42b6375d39.setContent(html_c1cc19f7fcdf0f916ef8ec6ce6f39bea);
#
#
#
#         marker_b1407da4fbaf12f113dc082fad3333ab.bindPopup(popup_b8edf6c9deb09f4a55ce3b42b6375d39)
#         ;
#
#
#
#
#             var marker_b165bd58345728d11ccf501135c762a2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_42ef0a87e18245c8c78062d116387b53);
#
#
#         var popup_ef801ac826d93434180b2c2124b0e005 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49fbb52a12bea0b556b012580db1e242 = $(`&lt;div id=&quot;html_49fbb52a12bea0b556b012580db1e242&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ef801ac826d93434180b2c2124b0e005.setContent(html_49fbb52a12bea0b556b012580db1e242);
#
#
#
#         marker_b165bd58345728d11ccf501135c762a2.bindPopup(popup_ef801ac826d93434180b2c2124b0e005)
#         ;
#
#
#
#
#             var marker_7b6bbff8d5b2e13c899c8c58977b78f1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_42ef0a87e18245c8c78062d116387b53);
#
#
#         var popup_9d35db69548f9c38b5c995a307687119 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d96234f71983bba990c0bdd5385bf7f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d96234f71983bba990c0bdd5385bf7f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d96234f71983bba990c0bdd5385bf7f3 = L.map(
#                 &quot;map_d96234f71983bba990c0bdd5385bf7f3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c1aefb84b6602405ee45b371e3bc135 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c1aefb84b6602405ee45b371e3bc135.addTo(map_d96234f71983bba990c0bdd5385bf7f3);
#
#
#             var feature_group_a3a701451130c3c93397b51331f86554 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a3a701451130c3c93397b51331f86554.addTo(map_d96234f71983bba990c0bdd5385bf7f3);
#
#
#             var feature_group_sub_group_16ccc68a29c9b6138851fe5f8cb3b226 = L.featureGroup.subGroup(
#                 feature_group_a3a701451130c3c93397b51331f86554
#             );
#
#
#             var marker_f7fdd7de0fae4e8e75f9caf093e26dd3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_16ccc68a29c9b6138851fe5f8cb3b226);
#
#
#         var popup_5ea07e3a7c731a1e2cec4e3a3d150883 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a525a7915d971419677aab682ffadd4 = $(`&lt;div id=&quot;html_5a525a7915d971419677aab682ffadd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5ea07e3a7c731a1e2cec4e3a3d150883.setContent(html_5a525a7915d971419677aab682ffadd4);
#
#
#
#         marker_f7fdd7de0fae4e8e75f9caf093e26dd3.bindPopup(popup_5ea07e3a7c731a1e2cec4e3a3d150883)
#         ;
#
#
#
#
#             var marker_6193b7a275e1004e0c222b7ea6af16dc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_16ccc68a29c9b6138851fe5f8cb3b226);
#
#
#         var popup_f2b3058dc62a83d41098342f088fa572 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_977bb2e247cc9307205fcfe221bb41c2 = $(`&lt;div id=&quot;html_977bb2e247cc9307205fcfe221bb41c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f2b3058dc62a83d41098342f088fa572.setContent(html_977bb2e247cc9307205fcfe221bb41c2);
#
#
#
#         marker_6193b7a275e1004e0c222b7ea6af16dc.bindPopup(popup_f2b3058dc62a83d41098342f088fa572)
#         ;
#
#
#
#
#             var marker_c20dca6a588739359ff0785531dd241a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_16ccc68a29c9b6138851fe5f8cb3b226);
#
#
#         var popup_2be518b931abf720dffc8f89d8957acd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be1b9fbbac3becedf53cde307e97183d = $(`&lt;div id=&quot;html_be1b9fbbac3becedf53cde307e97183d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2be518b931abf720dffc8f89d8957acd.setContent(html_be1b9fbbac3becedf53cde307e97183d);
#
#
#
#         marker_c20dca6a588739359ff0785531dd241a.bindPopup(popup_2be518b931abf720dffc8f89d8957acd)
#         ;
#
#
#
#
#             var marker_ea3b4bb1af8cd2c0481e739c9648210a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_16ccc68a29c9b6138851fe5f8cb3b226);
#
#
#         var popup_ee74cdd96b99bb3f031038d9035d62d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_562b065e6e2fac064a92c6f1f7344f02 = $(`&lt;div id=&quot;html_562b065e6e2fac064a92c6f1f7344f02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ee74cdd96b99bb3f031038d9035d62d2.setContent(html_562b065e6e2fac064a92c6f1f7344f02);
#
#
#
#         marker_
