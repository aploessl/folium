# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75a2660437a59a2000abc4dcdbd47532 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75a2660437a59a2000abc4dcdbd47532&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75a2660437a59a2000abc4dcdbd47532 = L.map(
#                 &quot;map_75a2660437a59a2000abc4dcdbd47532&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87e0d773368b90caa7ed7b38b3ec1692 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_87e0d773368b90caa7ed7b38b3ec1692.addTo(map_75a2660437a59a2000abc4dcdbd47532);
#
#
#             var marker_e87f02e1e9490918b3618596ba6de8b6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_75a2660437a59a2000abc4dcdbd47532);
#
#
#         var popup_09465fc6425409e19b801c9c9267cc24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e39e4b038336b2e81cdbf1d4ce727c9 = $(`&lt;div id=&quot;html_7e39e4b038336b2e81cdbf1d4ce727c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_09465fc6425409e19b801c9c9267cc24.setContent(html_7e39e4b038336b2e81cdbf1d4ce727c9);
#
#
#
#         marker_e87f02e1e9490918b3618596ba6de8b6.bindPopup(popup_09465fc6425409e19b801c9c9267cc24)
#         ;
#
#
#
#
#             var marker_64f45aba9b0741859fbdfb23f0447536 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_75a2660437a59a2000abc4dcdbd47532);
#
#
#         var popup_6eac17d86780869a28ef90ee272d0b94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63c560af9ae3fea0a46ba90d6834bb43 = $(`&lt;div id=&quot;html_63c560af9ae3fea0a46ba90d6834bb43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6eac17d86780869a28ef90ee272d0b94.setContent(html_63c560af9ae3fea0a46ba90d6834bb43);
#
#
#
#         marker_64f45aba9b0741859fbdfb23f0447536.bindPopup(popup_6eac17d86780869a28ef90ee272d0b94)
#         ;
#
#
#
#
#             var marker_d37fa053f3f31e4ca414115681e90483 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_75a2660437a59a2000abc4dcdbd47532);
#
#
#         var popup_5d6038416769e3fb11bebecb590dd4bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df68d3ea67201690365f604fe22985e9 = $(`&lt;div id=&quot;html_df68d3ea67201690365f604fe22985e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5d6038416769e3fb11bebecb590dd4bf.setContent(html_df68d3ea67201690365f604fe22985e9);
#
#
#
#         marker_d37fa053f3f31e4ca414115681e90483.bindPopup(popup_5d6038416769e3fb11bebecb590dd4bf)
#         ;
#
#
#
#
#             var marker_2662e47a84bdf2d4cefbe3f8e2fb0969 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_75a2660437a59a2000abc4dcdbd47532);
#
#
#         var popup_a0d462b1070dbbacaa525ece273faf83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_379c964a10ff233e01700147cd31bedf = $(`&lt;div id=&quot;html_379c964a10ff233e01700147cd31bedf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a0d462b1070dbbacaa525ece273faf83.setContent(html_379c964a10ff233e01700147cd31bedf);
#
#
#
#         marker_2662e47a84bdf2d4cefbe3f8e2fb0969.bindPopup(popup_a0d462b1070dbbacaa525ece273faf83)
#         ;
#
#
#
#
#             var marker_82d0e0d687952dfb7ca39ca1bc8e24d2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_75a2660437a59a2000abc4dcdbd47532);
#
#
#         var popup_eee997e85128730c4b9660736c699362 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3727aabb54104d20f27ef2499047b654 = $(`&lt;div id=&quot;html_3727aabb54104d20f27ef2499047b654&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_eee997e85128730c4b9660736c699362.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aebb0207ee6e12b837c9438e38e59542 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aebb0207ee6e12b837c9438e38e59542&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aebb0207ee6e12b837c9438e38e59542 = L.map(
#                 &quot;map_aebb0207ee6e12b837c9438e38e59542&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0dc93fa4ca57c1387e08a9cdf7ebe2b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a0dc93fa4ca57c1387e08a9cdf7ebe2b.addTo(map_aebb0207ee6e12b837c9438e38e59542);
#
#
#             var feature_group_785f0bca1e9bc17cf76295b88d9c7b44 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_49b193c21f6c3b3b5506e80e694b9e02 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_785f0bca1e9bc17cf76295b88d9c7b44);
#
#
#         var popup_9a78c44487b419ac343f10e90615bfa1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fe88de11e952e53fd8194731939f8f8 = $(`&lt;div id=&quot;html_6fe88de11e952e53fd8194731939f8f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9a78c44487b419ac343f10e90615bfa1.setContent(html_6fe88de11e952e53fd8194731939f8f8);
#
#
#
#         marker_49b193c21f6c3b3b5506e80e694b9e02.bindPopup(popup_9a78c44487b419ac343f10e90615bfa1)
#         ;
#
#
#
#
#             var marker_0955b8f17a6e2fa37265f13d9ff2a81b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_785f0bca1e9bc17cf76295b88d9c7b44);
#
#
#         var popup_1cde08abc1472412bd08f736e2fddbda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_609bcebd916d6ea1f59d5feca202834d = $(`&lt;div id=&quot;html_609bcebd916d6ea1f59d5feca202834d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1cde08abc1472412bd08f736e2fddbda.setContent(html_609bcebd916d6ea1f59d5feca202834d);
#
#
#
#         marker_0955b8f17a6e2fa37265f13d9ff2a81b.bindPopup(popup_1cde08abc1472412bd08f736e2fddbda)
#         ;
#
#
#
#
#             var marker_d088822f4dacf930843904081d2ebd42 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_785f0bca1e9bc17cf76295b88d9c7b44);
#
#
#         var popup_e2772e9fcde8e2a1632fd40aad42ea76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_505acca089c97889e3ee034a5c6c938e = $(`&lt;div id=&quot;html_505acca089c97889e3ee034a5c6c938e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e2772e9fcde8e2a1632fd40aad42ea76.setContent(html_505acca089c97889e3ee034a5c6c938e);
#
#
#
#         marker_d088822f4dacf930843904081d2ebd42.bindPopup(popup_e2772e9fcde8e2a1632fd40aad42ea76)
#         ;
#
#
#
#
#             var marker_1632dff0e9aaaf1b8ad71aaca9fa84b0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_785f0bca1e9bc17cf76295b88d9c7b44);
#
#
#         var popup_aad4f8f4630faca7cf60d5e89c67eb32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_456d4b6a68045d95876245c9d8f38137 = $(`&lt;div id=&quot;html_456d4b6a68045d95876245c9d8f38137&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_aad4f8f4630faca7cf60d5e89c67eb32.setContent(html_456d4b6a68045d95876245c9d8f38137);
#
#
#
#         marker_1632dff0e9aaaf1b8ad71aaca9fa84b0.bindPopup(popup_aad4f8f4630faca7cf60d5e89c67eb32)
#         ;
#
#
#
#
#             var marker_ea0c6cbc946ef8f6a145171a81d582bb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_785f0bca1e9bc17cf76295b88d9c7b44);
#
#
#         var popup_da5699cad92c649aeb738f4e2c9713a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd9a70677f229a194f4f3d77b0da9923 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd9a70677f229a194f4f3d77b0da9923&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd9a70677f229a194f4f3d77b0da9923 = L.map(
#                 &quot;map_fd9a70677f229a194f4f3d77b0da9923&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b06180da3be51af192c9232d629c772 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8b06180da3be51af192c9232d629c772.addTo(map_fd9a70677f229a194f4f3d77b0da9923);
#
#
#             var feature_group_3806281cf1a0942e0a585326e9291bb3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3806281cf1a0942e0a585326e9291bb3.addTo(map_fd9a70677f229a194f4f3d77b0da9923);
#
#
#             var feature_group_sub_group_67856cc8e4183ea029b59fc7f120dcd7 = L.featureGroup.subGroup(
#                 feature_group_3806281cf1a0942e0a585326e9291bb3
#             );
#
#
#             var marker_18563ef558759f95b678b834f9cf4b67 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_67856cc8e4183ea029b59fc7f120dcd7);
#
#
#         var popup_c2f937b18cc00063a85753c89dc7db99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c070720a1ef9f0542afd1e2360b45ee = $(`&lt;div id=&quot;html_6c070720a1ef9f0542afd1e2360b45ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c2f937b18cc00063a85753c89dc7db99.setContent(html_6c070720a1ef9f0542afd1e2360b45ee);
#
#
#
#         marker_18563ef558759f95b678b834f9cf4b67.bindPopup(popup_c2f937b18cc00063a85753c89dc7db99)
#         ;
#
#
#
#
#             var marker_984109c0c371d18867563012d78c5b15 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_67856cc8e4183ea029b59fc7f120dcd7);
#
#
#         var popup_142bc61aa915d08cd1dc7ce1a9ff66e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ee025b0e19ad80470c160555e341507 = $(`&lt;div id=&quot;html_5ee025b0e19ad80470c160555e341507&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_142bc61aa915d08cd1dc7ce1a9ff66e6.setContent(html_5ee025b0e19ad80470c160555e341507);
#
#
#
#         marker_984109c0c371d18867563012d78c5b15.bindPopup(popup_142bc61aa915d08cd1dc7ce1a9ff66e6)
#         ;
#
#
#
#
#             var marker_a6cdd4af2552ca996ad8ed57edc7d940 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_67856cc8e4183ea029b59fc7f120dcd7);
#
#
#         var popup_4adf089f16268d84fb0d06d8ea766e0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64cf5fecf5cea100710b3a64b0587a05 = $(`&lt;div id=&quot;html_64cf5fecf5cea100710b3a64b0587a05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4adf089f16268d84fb0d06d8ea766e0c.setContent(html_64cf5fecf5cea100710b3a64b0587a05);
#
#
#
#         marker_a6cdd4af2552ca996ad8ed57edc7d940.bindPopup(popup_4adf089f16268d84fb0d06d8ea766e0c)
#         ;
#
#
#
#
#             var marker_297e2d75770b72d844131a16b5096606 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_67856cc8e4183ea029b59fc7f120dcd7);
#
#
#         var popup_64bd1faee0b5bcf163cecc9b4655bac9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e7e600ca02e472576423069623f49a0 = $(`&lt;div id=&quot;html_5e7e600ca02e472576423069623f49a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_64bd1faee0b5bcf163cecc9b4655bac9.setContent(html_5e7e600ca02e472576423069623f49a0);
#
#
#
#         marker_
