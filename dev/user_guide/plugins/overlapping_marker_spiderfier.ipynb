# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6133c4b60d880b8dc160f9c0926f63f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6133c4b60d880b8dc160f9c0926f63f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6133c4b60d880b8dc160f9c0926f63f0 = L.map(
#                 &quot;map_6133c4b60d880b8dc160f9c0926f63f0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_510e679b203b1a024f4444d250a8b663 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_510e679b203b1a024f4444d250a8b663.addTo(map_6133c4b60d880b8dc160f9c0926f63f0);
#
#
#             var marker_6d2d07bfb19f1dec54c7a8bc1e10c4c4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6133c4b60d880b8dc160f9c0926f63f0);
#
#
#         var popup_771ef3e886ef5f168b12dfe98b303699 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9eb236d72e3218879f266471d908930c = $(`&lt;div id=&quot;html_9eb236d72e3218879f266471d908930c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_771ef3e886ef5f168b12dfe98b303699.setContent(html_9eb236d72e3218879f266471d908930c);
#
#
#
#         marker_6d2d07bfb19f1dec54c7a8bc1e10c4c4.bindPopup(popup_771ef3e886ef5f168b12dfe98b303699)
#         ;
#
#
#
#
#             var marker_ac91b786d0b4bd02b6e19c1f99a62b5d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6133c4b60d880b8dc160f9c0926f63f0);
#
#
#         var popup_b20f2c49af4c691e175bec0954d61b33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bc196b61222cb8f39cc940968217735 = $(`&lt;div id=&quot;html_0bc196b61222cb8f39cc940968217735&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b20f2c49af4c691e175bec0954d61b33.setContent(html_0bc196b61222cb8f39cc940968217735);
#
#
#
#         marker_ac91b786d0b4bd02b6e19c1f99a62b5d.bindPopup(popup_b20f2c49af4c691e175bec0954d61b33)
#         ;
#
#
#
#
#             var marker_4c6eea8b710014aad35e7955c2628e5a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6133c4b60d880b8dc160f9c0926f63f0);
#
#
#         var popup_a5f16fa3dbb89dc59da23fa8373eb3dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb713fc85b4644a422d98b24a27ada9c = $(`&lt;div id=&quot;html_eb713fc85b4644a422d98b24a27ada9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a5f16fa3dbb89dc59da23fa8373eb3dd.setContent(html_eb713fc85b4644a422d98b24a27ada9c);
#
#
#
#         marker_4c6eea8b710014aad35e7955c2628e5a.bindPopup(popup_a5f16fa3dbb89dc59da23fa8373eb3dd)
#         ;
#
#
#
#
#             var marker_80e90cc5c28fcf3f262e6abf5f2e88e3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6133c4b60d880b8dc160f9c0926f63f0);
#
#
#         var popup_ac832bbffeb4f53fe8023d9ed50176b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16bea0405dcbf9a3880fa49ea826fadf = $(`&lt;div id=&quot;html_16bea0405dcbf9a3880fa49ea826fadf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ac832bbffeb4f53fe8023d9ed50176b7.setContent(html_16bea0405dcbf9a3880fa49ea826fadf);
#
#
#
#         marker_80e90cc5c28fcf3f262e6abf5f2e88e3.bindPopup(popup_ac832bbffeb4f53fe8023d9ed50176b7)
#         ;
#
#
#
#
#             var marker_d64e42510557b8dd5bb531c314ee6930 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6133c4b60d880b8dc160f9c0926f63f0);
#
#
#         var popup_789362da816e96174a932bf32cefa2f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c63970347eebbf0a0a15b4702c501915 = $(`&lt;div id=&quot;html_c63970347eebbf0a0a15b4702c501915&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_789362da816e96174a932bf32cefa2f4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abf5d5684171904d86f094f9bd4c7f59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abf5d5684171904d86f094f9bd4c7f59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abf5d5684171904d86f094f9bd4c7f59 = L.map(
#                 &quot;map_abf5d5684171904d86f094f9bd4c7f59&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af15a6a68445ed6bab208068681d9fe7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af15a6a68445ed6bab208068681d9fe7.addTo(map_abf5d5684171904d86f094f9bd4c7f59);
#
#
#             var feature_group_5b7cd72bf650fbe5dca77e85eb870d64 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_664bcf47e5320256bcc5c4d73177177c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5b7cd72bf650fbe5dca77e85eb870d64);
#
#
#         var popup_201549730765367b6ee6e9d63c87d4a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef4d67e7c6613a66ecc52a9ec20cf1ba = $(`&lt;div id=&quot;html_ef4d67e7c6613a66ecc52a9ec20cf1ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_201549730765367b6ee6e9d63c87d4a0.setContent(html_ef4d67e7c6613a66ecc52a9ec20cf1ba);
#
#
#
#         marker_664bcf47e5320256bcc5c4d73177177c.bindPopup(popup_201549730765367b6ee6e9d63c87d4a0)
#         ;
#
#
#
#
#             var marker_db2c7ff55d643cefa1d443638da691e4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5b7cd72bf650fbe5dca77e85eb870d64);
#
#
#         var popup_cfc12a00e29c4b4f31206e3274834bb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c027ce261eda6009ac82c2845c0ae1b1 = $(`&lt;div id=&quot;html_c027ce261eda6009ac82c2845c0ae1b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cfc12a00e29c4b4f31206e3274834bb1.setContent(html_c027ce261eda6009ac82c2845c0ae1b1);
#
#
#
#         marker_db2c7ff55d643cefa1d443638da691e4.bindPopup(popup_cfc12a00e29c4b4f31206e3274834bb1)
#         ;
#
#
#
#
#             var marker_1c8fd1031f8009ae31aff3c34c41f264 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5b7cd72bf650fbe5dca77e85eb870d64);
#
#
#         var popup_3165f8cfb81642b95d454827ee63820c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e023558a1968c8c7bc02596b3778f88 = $(`&lt;div id=&quot;html_4e023558a1968c8c7bc02596b3778f88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3165f8cfb81642b95d454827ee63820c.setContent(html_4e023558a1968c8c7bc02596b3778f88);
#
#
#
#         marker_1c8fd1031f8009ae31aff3c34c41f264.bindPopup(popup_3165f8cfb81642b95d454827ee63820c)
#         ;
#
#
#
#
#             var marker_2161822ffaf7e5d4da6511bde86f5c37 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5b7cd72bf650fbe5dca77e85eb870d64);
#
#
#         var popup_0c87245abcafc6e9544338cb9726909f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc14992f01ec2b65af061f375fab6bd4 = $(`&lt;div id=&quot;html_bc14992f01ec2b65af061f375fab6bd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0c87245abcafc6e9544338cb9726909f.setContent(html_bc14992f01ec2b65af061f375fab6bd4);
#
#
#
#         marker_2161822ffaf7e5d4da6511bde86f5c37.bindPopup(popup_0c87245abcafc6e9544338cb9726909f)
#         ;
#
#
#
#
#             var marker_75143faa99ba4688beb0dece09461b67 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5b7cd72bf650fbe5dca77e85eb870d64);
#
#
#         var popup_dee4574c420ba323639a53bee39b3f38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35b4ad37bc727d827f56d5088fa91295 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35b4ad37bc727d827f56d5088fa91295&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35b4ad37bc727d827f56d5088fa91295 = L.map(
#                 &quot;map_35b4ad37bc727d827f56d5088fa91295&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd3252ad67adeafbd9937429e06ecb40 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fd3252ad67adeafbd9937429e06ecb40.addTo(map_35b4ad37bc727d827f56d5088fa91295);
#
#
#             var feature_group_2d73e9a61508a3de981093b1282753bc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2d73e9a61508a3de981093b1282753bc.addTo(map_35b4ad37bc727d827f56d5088fa91295);
#
#
#             var feature_group_sub_group_c171f678fa4d1803b72a8ea16231100b = L.featureGroup.subGroup(
#                 feature_group_2d73e9a61508a3de981093b1282753bc
#             );
#
#
#             var marker_a2f5a87bfcc23961e134acab1ed154bf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c171f678fa4d1803b72a8ea16231100b);
#
#
#         var popup_8017977f285af7b40a07794ef2e4f790 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_770d34fcf9881f374f7488fba255c356 = $(`&lt;div id=&quot;html_770d34fcf9881f374f7488fba255c356&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8017977f285af7b40a07794ef2e4f790.setContent(html_770d34fcf9881f374f7488fba255c356);
#
#
#
#         marker_a2f5a87bfcc23961e134acab1ed154bf.bindPopup(popup_8017977f285af7b40a07794ef2e4f790)
#         ;
#
#
#
#
#             var marker_be82f6a946bf3447b63c2788ea9977a7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c171f678fa4d1803b72a8ea16231100b);
#
#
#         var popup_136a57b106ca7c25ffc85a5f5d83e39d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_472053665285bac2fe46c10cb85cd2f7 = $(`&lt;div id=&quot;html_472053665285bac2fe46c10cb85cd2f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_136a57b106ca7c25ffc85a5f5d83e39d.setContent(html_472053665285bac2fe46c10cb85cd2f7);
#
#
#
#         marker_be82f6a946bf3447b63c2788ea9977a7.bindPopup(popup_136a57b106ca7c25ffc85a5f5d83e39d)
#         ;
#
#
#
#
#             var marker_f7812cfb1de8ce5a0b658b16498e3b4d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c171f678fa4d1803b72a8ea16231100b);
#
#
#         var popup_58e4479eb8be6da3301ae5f8fef11045 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27f86d86e0f890c9bfd75d7455ff1489 = $(`&lt;div id=&quot;html_27f86d86e0f890c9bfd75d7455ff1489&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_58e4479eb8be6da3301ae5f8fef11045.setContent(html_27f86d86e0f890c9bfd75d7455ff1489);
#
#
#
#         marker_f7812cfb1de8ce5a0b658b16498e3b4d.bindPopup(popup_58e4479eb8be6da3301ae5f8fef11045)
#         ;
#
#
#
#
#             var marker_f0163be4189821efd0f816f518ad789e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c171f678fa4d1803b72a8ea16231100b);
#
#
#         var popup_1dfbcade4a6b649e58bf69dee9483780 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_183319f559ecd93ba836536ed532f39c = $(`&lt;div id=&quot;html_183319f559ecd93ba836536ed532f39c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1dfbcade4a6b649e58bf69dee9483780.setContent(html_183319f559ecd93ba836536ed532f39c);
#
#
#
#         marker_
