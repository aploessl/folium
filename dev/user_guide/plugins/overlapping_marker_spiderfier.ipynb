# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_572bd0d16737118734b1e41335f39168 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_572bd0d16737118734b1e41335f39168&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_572bd0d16737118734b1e41335f39168 = L.map(
#                 &quot;map_572bd0d16737118734b1e41335f39168&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18735fa2b8627398908bcbab002616a9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18735fa2b8627398908bcbab002616a9.addTo(map_572bd0d16737118734b1e41335f39168);
#
#
#             var marker_c2d0f1dccddf911ce358e39f963e51cc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_572bd0d16737118734b1e41335f39168);
#
#
#         var popup_d1bfc30239a8a7562b7d94b37875f167 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24dc46eb0ab6956735ad4c47e2b6696d = $(`&lt;div id=&quot;html_24dc46eb0ab6956735ad4c47e2b6696d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d1bfc30239a8a7562b7d94b37875f167.setContent(html_24dc46eb0ab6956735ad4c47e2b6696d);
#
#
#
#         marker_c2d0f1dccddf911ce358e39f963e51cc.bindPopup(popup_d1bfc30239a8a7562b7d94b37875f167)
#         ;
#
#
#
#
#             var marker_f557937ae600ac419c3ea140cbd8935e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_572bd0d16737118734b1e41335f39168);
#
#
#         var popup_7db0ad364ab1beb9c9136c7e0494225d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdce773501e9f65d0130aedf4eeab5e4 = $(`&lt;div id=&quot;html_bdce773501e9f65d0130aedf4eeab5e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7db0ad364ab1beb9c9136c7e0494225d.setContent(html_bdce773501e9f65d0130aedf4eeab5e4);
#
#
#
#         marker_f557937ae600ac419c3ea140cbd8935e.bindPopup(popup_7db0ad364ab1beb9c9136c7e0494225d)
#         ;
#
#
#
#
#             var marker_1b50c899b98bd71ba9d3f27693430339 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_572bd0d16737118734b1e41335f39168);
#
#
#         var popup_8d8d3bab48eba7f56ff7e9e539fcd31b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7df614bda93fcc0ab111bd3c6eef4fc = $(`&lt;div id=&quot;html_b7df614bda93fcc0ab111bd3c6eef4fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8d8d3bab48eba7f56ff7e9e539fcd31b.setContent(html_b7df614bda93fcc0ab111bd3c6eef4fc);
#
#
#
#         marker_1b50c899b98bd71ba9d3f27693430339.bindPopup(popup_8d8d3bab48eba7f56ff7e9e539fcd31b)
#         ;
#
#
#
#
#             var marker_715d80ae6beb7c08aeb2f27f507573e2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_572bd0d16737118734b1e41335f39168);
#
#
#         var popup_0807decc3bbb0818edb327978b8f22e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf69366e8c25c881f64334bd6dac825b = $(`&lt;div id=&quot;html_bf69366e8c25c881f64334bd6dac825b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0807decc3bbb0818edb327978b8f22e3.setContent(html_bf69366e8c25c881f64334bd6dac825b);
#
#
#
#         marker_715d80ae6beb7c08aeb2f27f507573e2.bindPopup(popup_0807decc3bbb0818edb327978b8f22e3)
#         ;
#
#
#
#
#             var marker_5851f0145eb9fa31c57e109a7be81b12 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_572bd0d16737118734b1e41335f39168);
#
#
#         var popup_398132fa0c88a777487ad26bfe9b7eda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e6e383454b4b643a8417b6735566a1c = $(`&lt;div id=&quot;html_7e6e383454b4b643a8417b6735566a1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_398132fa0c88a777487ad26bfe9b7eda.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad65ce163fa879a077dcc415c2f27957 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad65ce163fa879a077dcc415c2f27957&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad65ce163fa879a077dcc415c2f27957 = L.map(
#                 &quot;map_ad65ce163fa879a077dcc415c2f27957&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae6e1a9ad2255d300e033e1dbf9091a3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ae6e1a9ad2255d300e033e1dbf9091a3.addTo(map_ad65ce163fa879a077dcc415c2f27957);
#
#
#             var feature_group_a9ecde4da0c8b650c68b0af7c125bccd = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b8f3164f1035b2691cbafbf7a2f05e24 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a9ecde4da0c8b650c68b0af7c125bccd);
#
#
#         var popup_2d1dd1a94ceabf8b0ab320639c207ad3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f1f27d445de8e49e176eeb08fe1cfd6 = $(`&lt;div id=&quot;html_6f1f27d445de8e49e176eeb08fe1cfd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2d1dd1a94ceabf8b0ab320639c207ad3.setContent(html_6f1f27d445de8e49e176eeb08fe1cfd6);
#
#
#
#         marker_b8f3164f1035b2691cbafbf7a2f05e24.bindPopup(popup_2d1dd1a94ceabf8b0ab320639c207ad3)
#         ;
#
#
#
#
#             var marker_66f096372f5588b0bc494b0d28cf4624 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a9ecde4da0c8b650c68b0af7c125bccd);
#
#
#         var popup_f739929ccd8dfbd41c386e0adfed96cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7be94049aa9ee8d4c9fc8be2d682bbc7 = $(`&lt;div id=&quot;html_7be94049aa9ee8d4c9fc8be2d682bbc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f739929ccd8dfbd41c386e0adfed96cd.setContent(html_7be94049aa9ee8d4c9fc8be2d682bbc7);
#
#
#
#         marker_66f096372f5588b0bc494b0d28cf4624.bindPopup(popup_f739929ccd8dfbd41c386e0adfed96cd)
#         ;
#
#
#
#
#             var marker_53e475a3d4e09b5b3b98d55144eebdfe = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a9ecde4da0c8b650c68b0af7c125bccd);
#
#
#         var popup_d62ec55021bf39aa04687a745252e1c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63485812a74b6b0c41102529afb68b3a = $(`&lt;div id=&quot;html_63485812a74b6b0c41102529afb68b3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d62ec55021bf39aa04687a745252e1c1.setContent(html_63485812a74b6b0c41102529afb68b3a);
#
#
#
#         marker_53e475a3d4e09b5b3b98d55144eebdfe.bindPopup(popup_d62ec55021bf39aa04687a745252e1c1)
#         ;
#
#
#
#
#             var marker_ac3f4cde60567fbde736b6a90f5cd9a7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a9ecde4da0c8b650c68b0af7c125bccd);
#
#
#         var popup_67832eaaacbaee3561a0909814f8a282 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a54812f6b9872134d3fac39f04990476 = $(`&lt;div id=&quot;html_a54812f6b9872134d3fac39f04990476&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_67832eaaacbaee3561a0909814f8a282.setContent(html_a54812f6b9872134d3fac39f04990476);
#
#
#
#         marker_ac3f4cde60567fbde736b6a90f5cd9a7.bindPopup(popup_67832eaaacbaee3561a0909814f8a282)
#         ;
#
#
#
#
#             var marker_9772abe017a03eaf7616d17583d5aee4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a9ecde4da0c8b650c68b0af7c125bccd);
#
#
#         var popup_bda86d4267610e2d7dc5973f123a77a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f0b45f651ed45fad30cf9e7ec07894e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f0b45f651ed45fad30cf9e7ec07894e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f0b45f651ed45fad30cf9e7ec07894e = L.map(
#                 &quot;map_1f0b45f651ed45fad30cf9e7ec07894e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7189f436a1fd405d5801d58eddf204a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d7189f436a1fd405d5801d58eddf204a.addTo(map_1f0b45f651ed45fad30cf9e7ec07894e);
#
#
#             var feature_group_40f889368e8e12ca709b3d89908ee9d7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_40f889368e8e12ca709b3d89908ee9d7.addTo(map_1f0b45f651ed45fad30cf9e7ec07894e);
#
#
#             var feature_group_sub_group_d7d462524dd5a2656f56171c1c34c3dc = L.featureGroup.subGroup(
#                 feature_group_40f889368e8e12ca709b3d89908ee9d7
#             );
#
#
#             var marker_2f6fc161feff7af5c5edda1ce2e20139 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d7d462524dd5a2656f56171c1c34c3dc);
#
#
#         var popup_5e9d7c6dc2cfa3b05d92d164a9c366fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9faf9cab0544e1769b349d1f25694e16 = $(`&lt;div id=&quot;html_9faf9cab0544e1769b349d1f25694e16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5e9d7c6dc2cfa3b05d92d164a9c366fd.setContent(html_9faf9cab0544e1769b349d1f25694e16);
#
#
#
#         marker_2f6fc161feff7af5c5edda1ce2e20139.bindPopup(popup_5e9d7c6dc2cfa3b05d92d164a9c366fd)
#         ;
#
#
#
#
#             var marker_7516c5edb840bb3ba4159d69f8abf588 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d7d462524dd5a2656f56171c1c34c3dc);
#
#
#         var popup_690d0c55258d68aed63aa7b63b33acf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0c06f00060a201032c66c3e1e5bc5ab = $(`&lt;div id=&quot;html_d0c06f00060a201032c66c3e1e5bc5ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_690d0c55258d68aed63aa7b63b33acf6.setContent(html_d0c06f00060a201032c66c3e1e5bc5ab);
#
#
#
#         marker_7516c5edb840bb3ba4159d69f8abf588.bindPopup(popup_690d0c55258d68aed63aa7b63b33acf6)
#         ;
#
#
#
#
#             var marker_5fc014c93a298e4ef5bfcd330cdd8c74 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d7d462524dd5a2656f56171c1c34c3dc);
#
#
#         var popup_72486ab482cd97d01693c5971146ded3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f762133d45f3cac19e6bf1ccede1f21d = $(`&lt;div id=&quot;html_f762133d45f3cac19e6bf1ccede1f21d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_72486ab482cd97d01693c5971146ded3.setContent(html_f762133d45f3cac19e6bf1ccede1f21d);
#
#
#
#         marker_5fc014c93a298e4ef5bfcd330cdd8c74.bindPopup(popup_72486ab482cd97d01693c5971146ded3)
#         ;
#
#
#
#
#             var marker_3436f6389ee2eb3830badd306a10377b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d7d462524dd5a2656f56171c1c34c3dc);
#
#
#         var popup_1930075369ba02f6491d49a0f2fa923f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b65f027311f7801d505a671199f67ff = $(`&lt;div id=&quot;html_0b65f027311f7801d505a671199f67ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1930075369ba02f6491d49a0f2fa923f.setContent(html_0b65f027311f7801d505a671199f67ff);
#
#
#
#         marker_
