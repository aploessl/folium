# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9311acd811e07a83dfc6ecd60e2f9357 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9311acd811e07a83dfc6ecd60e2f9357&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9311acd811e07a83dfc6ecd60e2f9357 = L.map(
#                 &quot;map_9311acd811e07a83dfc6ecd60e2f9357&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f8c341e6516cc79d3b66debff8e4b38 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f8c341e6516cc79d3b66debff8e4b38.addTo(map_9311acd811e07a83dfc6ecd60e2f9357);
#
#
#             var marker_58088cf82cd2c46b4f0e40dee932cba7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9311acd811e07a83dfc6ecd60e2f9357);
#
#
#         var popup_f751b42628367368db69daa220d1786f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd9840217e2db1729e92311946ffbd61 = $(`&lt;div id=&quot;html_cd9840217e2db1729e92311946ffbd61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f751b42628367368db69daa220d1786f.setContent(html_cd9840217e2db1729e92311946ffbd61);
#
#
#
#         marker_58088cf82cd2c46b4f0e40dee932cba7.bindPopup(popup_f751b42628367368db69daa220d1786f)
#         ;
#
#
#
#
#             var marker_92a47cee9b6472abcf6c00779b771052 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9311acd811e07a83dfc6ecd60e2f9357);
#
#
#         var popup_ab1b8ef50095e4983508c24e9b406447 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9153b057c17d58886860aefbc1cea9c7 = $(`&lt;div id=&quot;html_9153b057c17d58886860aefbc1cea9c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ab1b8ef50095e4983508c24e9b406447.setContent(html_9153b057c17d58886860aefbc1cea9c7);
#
#
#
#         marker_92a47cee9b6472abcf6c00779b771052.bindPopup(popup_ab1b8ef50095e4983508c24e9b406447)
#         ;
#
#
#
#
#             var marker_3aa3c34d800f19357b4ffe1ef33cfb83 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9311acd811e07a83dfc6ecd60e2f9357);
#
#
#         var popup_8086db50e2b802390c4433f00ca96ccf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac6770135b3eebe5d80f7fec3d53ccfa = $(`&lt;div id=&quot;html_ac6770135b3eebe5d80f7fec3d53ccfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8086db50e2b802390c4433f00ca96ccf.setContent(html_ac6770135b3eebe5d80f7fec3d53ccfa);
#
#
#
#         marker_3aa3c34d800f19357b4ffe1ef33cfb83.bindPopup(popup_8086db50e2b802390c4433f00ca96ccf)
#         ;
#
#
#
#
#             var marker_17e447dfec91556532351b82fc1d22cc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9311acd811e07a83dfc6ecd60e2f9357);
#
#
#         var popup_d041ebcd2c5ad0f2ebe7b66ebf522758 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6235ae6c81797bfa5cef51afc5a66212 = $(`&lt;div id=&quot;html_6235ae6c81797bfa5cef51afc5a66212&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d041ebcd2c5ad0f2ebe7b66ebf522758.setContent(html_6235ae6c81797bfa5cef51afc5a66212);
#
#
#
#         marker_17e447dfec91556532351b82fc1d22cc.bindPopup(popup_d041ebcd2c5ad0f2ebe7b66ebf522758)
#         ;
#
#
#
#
#             var marker_ee9cc8184fa5299930e7b02ed4608e7d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9311acd811e07a83dfc6ecd60e2f9357);
#
#
#         var popup_fbdf32357f412c22761126d0d2934b39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c672f4cd53cd790201bed93e98015ab3 = $(`&lt;div id=&quot;html_c672f4cd53cd790201bed93e98015ab3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fbdf32357f412c22761126d0d2934b39.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4eb0b0c2abc2dad5961930e574eae0fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4eb0b0c2abc2dad5961930e574eae0fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4eb0b0c2abc2dad5961930e574eae0fa = L.map(
#                 &quot;map_4eb0b0c2abc2dad5961930e574eae0fa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4186e710bcdcf1950922aa0a4f84bc4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f4186e710bcdcf1950922aa0a4f84bc4.addTo(map_4eb0b0c2abc2dad5961930e574eae0fa);
#
#
#             var feature_group_a7f6830028ea9641121ea5e8d1bd30b9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1d727fe65b736dd2d257029208050f45 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a7f6830028ea9641121ea5e8d1bd30b9);
#
#
#         var popup_f7d1607bb503b02fc5d33e401fdf3adc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a9e37d42425287f819826c2a6258456 = $(`&lt;div id=&quot;html_9a9e37d42425287f819826c2a6258456&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f7d1607bb503b02fc5d33e401fdf3adc.setContent(html_9a9e37d42425287f819826c2a6258456);
#
#
#
#         marker_1d727fe65b736dd2d257029208050f45.bindPopup(popup_f7d1607bb503b02fc5d33e401fdf3adc)
#         ;
#
#
#
#
#             var marker_c16755492825721dfbc4ad63d6e5404c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a7f6830028ea9641121ea5e8d1bd30b9);
#
#
#         var popup_b19dc0f63826f9af38b1db9d9e892a80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2ce9a4c8cd787cff5c7734cea638529 = $(`&lt;div id=&quot;html_c2ce9a4c8cd787cff5c7734cea638529&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b19dc0f63826f9af38b1db9d9e892a80.setContent(html_c2ce9a4c8cd787cff5c7734cea638529);
#
#
#
#         marker_c16755492825721dfbc4ad63d6e5404c.bindPopup(popup_b19dc0f63826f9af38b1db9d9e892a80)
#         ;
#
#
#
#
#             var marker_cf8c8bd4a092eaadeb6a9e24ea75ef0a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a7f6830028ea9641121ea5e8d1bd30b9);
#
#
#         var popup_d49d9c1cc3bdc962f8805c3cac811561 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f14e8c283ed6799f94f576df497456f5 = $(`&lt;div id=&quot;html_f14e8c283ed6799f94f576df497456f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d49d9c1cc3bdc962f8805c3cac811561.setContent(html_f14e8c283ed6799f94f576df497456f5);
#
#
#
#         marker_cf8c8bd4a092eaadeb6a9e24ea75ef0a.bindPopup(popup_d49d9c1cc3bdc962f8805c3cac811561)
#         ;
#
#
#
#
#             var marker_2ee713d06ccb34ff4b32d424df03c1c2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a7f6830028ea9641121ea5e8d1bd30b9);
#
#
#         var popup_7ea34b1a7cc83ce4ac5833a7fc82b376 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_142e53ff3599d890ff921d2d11a0b098 = $(`&lt;div id=&quot;html_142e53ff3599d890ff921d2d11a0b098&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7ea34b1a7cc83ce4ac5833a7fc82b376.setContent(html_142e53ff3599d890ff921d2d11a0b098);
#
#
#
#         marker_2ee713d06ccb34ff4b32d424df03c1c2.bindPopup(popup_7ea34b1a7cc83ce4ac5833a7fc82b376)
#         ;
#
#
#
#
#             var marker_7cdd102d4937b7c19fe536fea922e0a6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a7f6830028ea9641121ea5e8d1bd30b9);
#
#
#         var popup_e99e9de62ea87ebba13fde4b4d01020c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1782792e9f4178f60f410ecaeb2b918 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1782792e9f4178f60f410ecaeb2b918&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1782792e9f4178f60f410ecaeb2b918 = L.map(
#                 &quot;map_c1782792e9f4178f60f410ecaeb2b918&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b694b93ca3baffc341aab6d47f38c1f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3b694b93ca3baffc341aab6d47f38c1f.addTo(map_c1782792e9f4178f60f410ecaeb2b918);
#
#
#             var feature_group_d5fbfc5d0586163ba4cca909a08a0d39 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d5fbfc5d0586163ba4cca909a08a0d39.addTo(map_c1782792e9f4178f60f410ecaeb2b918);
#
#
#             var feature_group_sub_group_ed35f8d73984cffc4699116c14d4cbc6 = L.featureGroup.subGroup(
#                 feature_group_d5fbfc5d0586163ba4cca909a08a0d39
#             );
#
#
#             var marker_1c00d6e6dea605a4ef0963080ce90cb0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed35f8d73984cffc4699116c14d4cbc6);
#
#
#         var popup_cf1da46640da2b068bee94803287e7b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34520793e36e78a6654a77dc66c69859 = $(`&lt;div id=&quot;html_34520793e36e78a6654a77dc66c69859&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cf1da46640da2b068bee94803287e7b6.setContent(html_34520793e36e78a6654a77dc66c69859);
#
#
#
#         marker_1c00d6e6dea605a4ef0963080ce90cb0.bindPopup(popup_cf1da46640da2b068bee94803287e7b6)
#         ;
#
#
#
#
#             var marker_39a710d6fdc283dba1cabcafc6d5e939 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed35f8d73984cffc4699116c14d4cbc6);
#
#
#         var popup_a604627015debfb6cf4b23cac8ffda37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed19defc7db1587b2a09552e52aa2442 = $(`&lt;div id=&quot;html_ed19defc7db1587b2a09552e52aa2442&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a604627015debfb6cf4b23cac8ffda37.setContent(html_ed19defc7db1587b2a09552e52aa2442);
#
#
#
#         marker_39a710d6fdc283dba1cabcafc6d5e939.bindPopup(popup_a604627015debfb6cf4b23cac8ffda37)
#         ;
#
#
#
#
#             var marker_22c36cc337d5ffda5ba0cd1236fba15f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed35f8d73984cffc4699116c14d4cbc6);
#
#
#         var popup_3584e47dcccfe6162a613a2649ef27d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdadf7f6dabc15d0c81b833b9e58e29f = $(`&lt;div id=&quot;html_bdadf7f6dabc15d0c81b833b9e58e29f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3584e47dcccfe6162a613a2649ef27d7.setContent(html_bdadf7f6dabc15d0c81b833b9e58e29f);
#
#
#
#         marker_22c36cc337d5ffda5ba0cd1236fba15f.bindPopup(popup_3584e47dcccfe6162a613a2649ef27d7)
#         ;
#
#
#
#
#             var marker_fec65d9fbc3fdac8738f7d83253d28bb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed35f8d73984cffc4699116c14d4cbc6);
#
#
#         var popup_fbdaf96dad1c073a62a5282ce3788fdb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15597b7e38091dda4b57274b823cdc77 = $(`&lt;div id=&quot;html_15597b7e38091dda4b57274b823cdc77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fbdaf96dad1c073a62a5282ce3788fdb.setContent(html_15597b7e38091dda4b57274b823cdc77);
#
#
#
#         marker_
