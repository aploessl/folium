# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08866ba270d3459e196a80a706d725c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08866ba270d3459e196a80a706d725c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08866ba270d3459e196a80a706d725c7 = L.map(
#                 &quot;map_08866ba270d3459e196a80a706d725c7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d00e5212b716d329debccd010801ecc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1d00e5212b716d329debccd010801ecc.addTo(map_08866ba270d3459e196a80a706d725c7);
#
#
#             var marker_c548b731ebcfcc33089ff5be1accf7e7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_08866ba270d3459e196a80a706d725c7);
#
#
#         var popup_36f20bf9fb26352ebc312972ae32f7e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7022c7c01ad66c7f71aaf009ae0b8de = $(`&lt;div id=&quot;html_c7022c7c01ad66c7f71aaf009ae0b8de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_36f20bf9fb26352ebc312972ae32f7e8.setContent(html_c7022c7c01ad66c7f71aaf009ae0b8de);
#
#
#
#         marker_c548b731ebcfcc33089ff5be1accf7e7.bindPopup(popup_36f20bf9fb26352ebc312972ae32f7e8)
#         ;
#
#
#
#
#             var marker_ce98a3b868a44b57338a1dac57181492 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_08866ba270d3459e196a80a706d725c7);
#
#
#         var popup_ee2c4dee06f8a3330e0284df3b928b5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dec01fecc4d400260f5e729caefe6ad7 = $(`&lt;div id=&quot;html_dec01fecc4d400260f5e729caefe6ad7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ee2c4dee06f8a3330e0284df3b928b5d.setContent(html_dec01fecc4d400260f5e729caefe6ad7);
#
#
#
#         marker_ce98a3b868a44b57338a1dac57181492.bindPopup(popup_ee2c4dee06f8a3330e0284df3b928b5d)
#         ;
#
#
#
#
#             var marker_99dcce6f3ca9a02451f9f07cce5a232b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_08866ba270d3459e196a80a706d725c7);
#
#
#         var popup_709dd54d54ec3778659a6c69adbafebc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6a36e5992417cb4aa61b018825afc25 = $(`&lt;div id=&quot;html_c6a36e5992417cb4aa61b018825afc25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_709dd54d54ec3778659a6c69adbafebc.setContent(html_c6a36e5992417cb4aa61b018825afc25);
#
#
#
#         marker_99dcce6f3ca9a02451f9f07cce5a232b.bindPopup(popup_709dd54d54ec3778659a6c69adbafebc)
#         ;
#
#
#
#
#             var marker_4f900b13e30565898ef189823dc2ebf3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_08866ba270d3459e196a80a706d725c7);
#
#
#         var popup_7c8a4b0440455dc7f473f91daa207c1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_543d09a0a70e68aa0c1d29af7123510f = $(`&lt;div id=&quot;html_543d09a0a70e68aa0c1d29af7123510f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7c8a4b0440455dc7f473f91daa207c1d.setContent(html_543d09a0a70e68aa0c1d29af7123510f);
#
#
#
#         marker_4f900b13e30565898ef189823dc2ebf3.bindPopup(popup_7c8a4b0440455dc7f473f91daa207c1d)
#         ;
#
#
#
#
#             var marker_2b182592a3e17a058d48484e0713922d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_08866ba270d3459e196a80a706d725c7);
#
#
#         var popup_7169e3fc7168ee5b2869b65888a96c83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52c3cd4e933ec56f59fc0e527d2d0661 = $(`&lt;div id=&quot;html_52c3cd4e933ec56f59fc0e527d2d0661&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7169e3fc7168ee5b2869b65888a96c83.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_02b1c6ce20fd93f528dcc0d9dab2188f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_02b1c6ce20fd93f528dcc0d9dab2188f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_02b1c6ce20fd93f528dcc0d9dab2188f = L.map(
#                 &quot;map_02b1c6ce20fd93f528dcc0d9dab2188f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8613abbd6847808bdd5cf785c48416bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8613abbd6847808bdd5cf785c48416bd.addTo(map_02b1c6ce20fd93f528dcc0d9dab2188f);
#
#
#             var feature_group_30940d0fabdb6d1d75e5b2b37a004eaa = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9aaff5866d079faab4d18003fc5f6e23 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_30940d0fabdb6d1d75e5b2b37a004eaa);
#
#
#         var popup_77ab4764c219d26d98734ae9504e9052 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f2183c2c7362da7f656e59d7a592725 = $(`&lt;div id=&quot;html_1f2183c2c7362da7f656e59d7a592725&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_77ab4764c219d26d98734ae9504e9052.setContent(html_1f2183c2c7362da7f656e59d7a592725);
#
#
#
#         marker_9aaff5866d079faab4d18003fc5f6e23.bindPopup(popup_77ab4764c219d26d98734ae9504e9052)
#         ;
#
#
#
#
#             var marker_ad156768352f6970a6bac0e8eeaaadaf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_30940d0fabdb6d1d75e5b2b37a004eaa);
#
#
#         var popup_a555b66a3a19fde6fa97f6e52e401c3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a2105a3f09dc2c388d19709a475a454 = $(`&lt;div id=&quot;html_0a2105a3f09dc2c388d19709a475a454&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a555b66a3a19fde6fa97f6e52e401c3c.setContent(html_0a2105a3f09dc2c388d19709a475a454);
#
#
#
#         marker_ad156768352f6970a6bac0e8eeaaadaf.bindPopup(popup_a555b66a3a19fde6fa97f6e52e401c3c)
#         ;
#
#
#
#
#             var marker_1d7564742aa8ddbf92bdace4778a8d5c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_30940d0fabdb6d1d75e5b2b37a004eaa);
#
#
#         var popup_412999a6008337c394d9ba87e1df4a17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e2e42d58b0c86903ba8c3ada7afdbb0 = $(`&lt;div id=&quot;html_7e2e42d58b0c86903ba8c3ada7afdbb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_412999a6008337c394d9ba87e1df4a17.setContent(html_7e2e42d58b0c86903ba8c3ada7afdbb0);
#
#
#
#         marker_1d7564742aa8ddbf92bdace4778a8d5c.bindPopup(popup_412999a6008337c394d9ba87e1df4a17)
#         ;
#
#
#
#
#             var marker_3d25a2168d7f49e6a067862802f38050 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_30940d0fabdb6d1d75e5b2b37a004eaa);
#
#
#         var popup_ea3b202952b27eb3409d6578b4ed54f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddb71904f741a133ac6e71eaa0800303 = $(`&lt;div id=&quot;html_ddb71904f741a133ac6e71eaa0800303&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ea3b202952b27eb3409d6578b4ed54f2.setContent(html_ddb71904f741a133ac6e71eaa0800303);
#
#
#
#         marker_3d25a2168d7f49e6a067862802f38050.bindPopup(popup_ea3b202952b27eb3409d6578b4ed54f2)
#         ;
#
#
#
#
#             var marker_5c36a17f586164380e5c879627152242 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_30940d0fabdb6d1d75e5b2b37a004eaa);
#
#
#         var popup_e917245cfc9558c072aaf91b3229c5fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ee1ce84979594ec896cdba4156823de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ee1ce84979594ec896cdba4156823de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ee1ce84979594ec896cdba4156823de = L.map(
#                 &quot;map_1ee1ce84979594ec896cdba4156823de&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8759d730a5c6a15c0c30e48d06f1333 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d8759d730a5c6a15c0c30e48d06f1333.addTo(map_1ee1ce84979594ec896cdba4156823de);
#
#
#             var feature_group_7040eb333bbb24f542dfa8704efec853 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7040eb333bbb24f542dfa8704efec853.addTo(map_1ee1ce84979594ec896cdba4156823de);
#
#
#             var feature_group_sub_group_5d6f6e3efa32bceab0a8d460c5eeb24e = L.featureGroup.subGroup(
#                 feature_group_7040eb333bbb24f542dfa8704efec853
#             );
#
#
#             var marker_7ee010bde7e5859cad253f78a5d19e08 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d6f6e3efa32bceab0a8d460c5eeb24e);
#
#
#         var popup_12e979a927c56f53475e41afd544bca8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8318a3ce8a1151d55bbaa5fa40100d1a = $(`&lt;div id=&quot;html_8318a3ce8a1151d55bbaa5fa40100d1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_12e979a927c56f53475e41afd544bca8.setContent(html_8318a3ce8a1151d55bbaa5fa40100d1a);
#
#
#
#         marker_7ee010bde7e5859cad253f78a5d19e08.bindPopup(popup_12e979a927c56f53475e41afd544bca8)
#         ;
#
#
#
#
#             var marker_11c4074b7b7b00f9c1bdd41591bc00d5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d6f6e3efa32bceab0a8d460c5eeb24e);
#
#
#         var popup_364c92ead669d485b8542be21cdbeffe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1a8087d497acfff96fa8ba1399acff3 = $(`&lt;div id=&quot;html_c1a8087d497acfff96fa8ba1399acff3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_364c92ead669d485b8542be21cdbeffe.setContent(html_c1a8087d497acfff96fa8ba1399acff3);
#
#
#
#         marker_11c4074b7b7b00f9c1bdd41591bc00d5.bindPopup(popup_364c92ead669d485b8542be21cdbeffe)
#         ;
#
#
#
#
#             var marker_40624e9749dd39653af8ba827b4c5050 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d6f6e3efa32bceab0a8d460c5eeb24e);
#
#
#         var popup_b9f2e37bf7413a5be0f5f52d1e3ac273 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55f8a602a29b464e6fcc9156133165ee = $(`&lt;div id=&quot;html_55f8a602a29b464e6fcc9156133165ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b9f2e37bf7413a5be0f5f52d1e3ac273.setContent(html_55f8a602a29b464e6fcc9156133165ee);
#
#
#
#         marker_40624e9749dd39653af8ba827b4c5050.bindPopup(popup_b9f2e37bf7413a5be0f5f52d1e3ac273)
#         ;
#
#
#
#
#             var marker_321925f9f3132140212b91e60b7e5a86 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d6f6e3efa32bceab0a8d460c5eeb24e);
#
#
#         var popup_3d02e9d012310b926166a1365adfd230 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae7f3be42db4531e1b6978db09af1fc7 = $(`&lt;div id=&quot;html_ae7f3be42db4531e1b6978db09af1fc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3d02e9d012310b926166a1365adfd230.setContent(html_ae7f3be42db4531e1b6978db09af1fc7);
#
#
#
#         marker_
