# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4128e85f8526db8c0817adcd703767a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4128e85f8526db8c0817adcd703767a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4128e85f8526db8c0817adcd703767a7 = L.map(
#                 &quot;map_4128e85f8526db8c0817adcd703767a7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65990881f410ccaaef048f5228f297ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_65990881f410ccaaef048f5228f297ca.addTo(map_4128e85f8526db8c0817adcd703767a7);
#
#
#             var marker_087d60a98e29b0c7d03ab7fef73d242e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4128e85f8526db8c0817adcd703767a7);
#
#
#         var popup_8165e52e1b420405c444de86e265c138 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_873e9eecd7a78d140ddb4443d8b872d8 = $(`&lt;div id=&quot;html_873e9eecd7a78d140ddb4443d8b872d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8165e52e1b420405c444de86e265c138.setContent(html_873e9eecd7a78d140ddb4443d8b872d8);
#
#
#
#         marker_087d60a98e29b0c7d03ab7fef73d242e.bindPopup(popup_8165e52e1b420405c444de86e265c138)
#         ;
#
#
#
#
#             var marker_9cbea55f090832c9b475de42eaf88af1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4128e85f8526db8c0817adcd703767a7);
#
#
#         var popup_089d64f3b6c2c26afe20a0f149a9d096 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff05958ac74aea52fd02b800e4b89746 = $(`&lt;div id=&quot;html_ff05958ac74aea52fd02b800e4b89746&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_089d64f3b6c2c26afe20a0f149a9d096.setContent(html_ff05958ac74aea52fd02b800e4b89746);
#
#
#
#         marker_9cbea55f090832c9b475de42eaf88af1.bindPopup(popup_089d64f3b6c2c26afe20a0f149a9d096)
#         ;
#
#
#
#
#             var marker_fc56a1024edf14b62fa55c92953e8aae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4128e85f8526db8c0817adcd703767a7);
#
#
#         var popup_2d01c183fc7079341a0eb7664063da5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bee205e190041c743c2d168595add86 = $(`&lt;div id=&quot;html_0bee205e190041c743c2d168595add86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2d01c183fc7079341a0eb7664063da5b.setContent(html_0bee205e190041c743c2d168595add86);
#
#
#
#         marker_fc56a1024edf14b62fa55c92953e8aae.bindPopup(popup_2d01c183fc7079341a0eb7664063da5b)
#         ;
#
#
#
#
#             var marker_75ce9c77a59e11d73a0c336164972417 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4128e85f8526db8c0817adcd703767a7);
#
#
#         var popup_9c20ba87e807353c65841dc45d77a684 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76dc3e2b70ecdbd908833804606ee821 = $(`&lt;div id=&quot;html_76dc3e2b70ecdbd908833804606ee821&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9c20ba87e807353c65841dc45d77a684.setContent(html_76dc3e2b70ecdbd908833804606ee821);
#
#
#
#         marker_75ce9c77a59e11d73a0c336164972417.bindPopup(popup_9c20ba87e807353c65841dc45d77a684)
#         ;
#
#
#
#
#             var marker_19a671473073fda1cad76110d8bf4be8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4128e85f8526db8c0817adcd703767a7);
#
#
#         var popup_9f827d85eaf65588b2788a87dafe8cc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f1a94e7c49dcd883f14f3f9f6c77e96 = $(`&lt;div id=&quot;html_8f1a94e7c49dcd883f14f3f9f6c77e96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9f827d85eaf65588b2788a87dafe8cc3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04007037d17e7abfbb796e3378e54cbb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04007037d17e7abfbb796e3378e54cbb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04007037d17e7abfbb796e3378e54cbb = L.map(
#                 &quot;map_04007037d17e7abfbb796e3378e54cbb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e034184cadfcd25dadd472edc3665ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e034184cadfcd25dadd472edc3665ff.addTo(map_04007037d17e7abfbb796e3378e54cbb);
#
#
#             var feature_group_86b27fa7f6791dc67df088f67fab8b6b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_79560a587f97a77380a59345907ef59c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_86b27fa7f6791dc67df088f67fab8b6b);
#
#
#         var popup_c787a46caa0a20fd318f0340ddb2385c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_076c704e6d678306b5f06af6d1f5954f = $(`&lt;div id=&quot;html_076c704e6d678306b5f06af6d1f5954f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c787a46caa0a20fd318f0340ddb2385c.setContent(html_076c704e6d678306b5f06af6d1f5954f);
#
#
#
#         marker_79560a587f97a77380a59345907ef59c.bindPopup(popup_c787a46caa0a20fd318f0340ddb2385c)
#         ;
#
#
#
#
#             var marker_d6d3d4cfd7ccd60d0cfbfb7e6194e859 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_86b27fa7f6791dc67df088f67fab8b6b);
#
#
#         var popup_a77b51a6e2ba66d3949416ee24049c22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_978c5c3a6646cab1b001a7e08407d874 = $(`&lt;div id=&quot;html_978c5c3a6646cab1b001a7e08407d874&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a77b51a6e2ba66d3949416ee24049c22.setContent(html_978c5c3a6646cab1b001a7e08407d874);
#
#
#
#         marker_d6d3d4cfd7ccd60d0cfbfb7e6194e859.bindPopup(popup_a77b51a6e2ba66d3949416ee24049c22)
#         ;
#
#
#
#
#             var marker_bf4746b5f2af533d872dc51b4470d29b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_86b27fa7f6791dc67df088f67fab8b6b);
#
#
#         var popup_6c5541d4a073a3d19330750b88297a14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8cecb6bcafb5c25d2fa9dc09a57ce0e = $(`&lt;div id=&quot;html_b8cecb6bcafb5c25d2fa9dc09a57ce0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6c5541d4a073a3d19330750b88297a14.setContent(html_b8cecb6bcafb5c25d2fa9dc09a57ce0e);
#
#
#
#         marker_bf4746b5f2af533d872dc51b4470d29b.bindPopup(popup_6c5541d4a073a3d19330750b88297a14)
#         ;
#
#
#
#
#             var marker_422579f3e280c503052e8b3ab4805dd6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_86b27fa7f6791dc67df088f67fab8b6b);
#
#
#         var popup_a99ec02cba6bf24e32177127761c3852 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0fc3253e65419c6dffd8c8af520925e6 = $(`&lt;div id=&quot;html_0fc3253e65419c6dffd8c8af520925e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a99ec02cba6bf24e32177127761c3852.setContent(html_0fc3253e65419c6dffd8c8af520925e6);
#
#
#
#         marker_422579f3e280c503052e8b3ab4805dd6.bindPopup(popup_a99ec02cba6bf24e32177127761c3852)
#         ;
#
#
#
#
#             var marker_19913abd2b77aa448cb2899036a1d1a2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_86b27fa7f6791dc67df088f67fab8b6b);
#
#
#         var popup_83bc89f03b87af1d933a70a191ea2c12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ad99b50e61b8f4704728788a17bdc1f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ad99b50e61b8f4704728788a17bdc1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ad99b50e61b8f4704728788a17bdc1f = L.map(
#                 &quot;map_2ad99b50e61b8f4704728788a17bdc1f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d9cb3e2e9d4911aa28d8a7d315bf204 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d9cb3e2e9d4911aa28d8a7d315bf204.addTo(map_2ad99b50e61b8f4704728788a17bdc1f);
#
#
#             var feature_group_ce8cafdcfd47f996b691505f1a1e1e21 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ce8cafdcfd47f996b691505f1a1e1e21.addTo(map_2ad99b50e61b8f4704728788a17bdc1f);
#
#
#             var feature_group_sub_group_5540ac2c28e1cfb19e097ac8285298d1 = L.featureGroup.subGroup(
#                 feature_group_ce8cafdcfd47f996b691505f1a1e1e21
#             );
#
#
#             var marker_b59b3988d93565b1ac562c812644fe33 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5540ac2c28e1cfb19e097ac8285298d1);
#
#
#         var popup_225cd4392958c9b06e4dace85095d624 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3406891ff2a464c4ff629c34fc02cb93 = $(`&lt;div id=&quot;html_3406891ff2a464c4ff629c34fc02cb93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_225cd4392958c9b06e4dace85095d624.setContent(html_3406891ff2a464c4ff629c34fc02cb93);
#
#
#
#         marker_b59b3988d93565b1ac562c812644fe33.bindPopup(popup_225cd4392958c9b06e4dace85095d624)
#         ;
#
#
#
#
#             var marker_af7e175c9f538d1f8a99030b82a4ab84 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5540ac2c28e1cfb19e097ac8285298d1);
#
#
#         var popup_3afe78ace32328b770ad6bd8e784f9c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_195d8d65fa44f1aee2c60ee6cc2da752 = $(`&lt;div id=&quot;html_195d8d65fa44f1aee2c60ee6cc2da752&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3afe78ace32328b770ad6bd8e784f9c6.setContent(html_195d8d65fa44f1aee2c60ee6cc2da752);
#
#
#
#         marker_af7e175c9f538d1f8a99030b82a4ab84.bindPopup(popup_3afe78ace32328b770ad6bd8e784f9c6)
#         ;
#
#
#
#
#             var marker_2fc61af06fd2c71bfe9776cc0786eea8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5540ac2c28e1cfb19e097ac8285298d1);
#
#
#         var popup_df1c82c6823ebd1877e7c334f3377a8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7862e8dab2cc5b792297c64e44dcbf44 = $(`&lt;div id=&quot;html_7862e8dab2cc5b792297c64e44dcbf44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_df1c82c6823ebd1877e7c334f3377a8c.setContent(html_7862e8dab2cc5b792297c64e44dcbf44);
#
#
#
#         marker_2fc61af06fd2c71bfe9776cc0786eea8.bindPopup(popup_df1c82c6823ebd1877e7c334f3377a8c)
#         ;
#
#
#
#
#             var marker_4c0156d8836a5973e84d4ae12b5e347f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5540ac2c28e1cfb19e097ac8285298d1);
#
#
#         var popup_793f39721651d8848ce67c89d2337af4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a43e19163a9da9ef6439fd781040cf8 = $(`&lt;div id=&quot;html_8a43e19163a9da9ef6439fd781040cf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_793f39721651d8848ce67c89d2337af4.setContent(html_8a43e19163a9da9ef6439fd781040cf8);
#
#
#
#         marker_
