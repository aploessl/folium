# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20a6dc073e5c1c8ca8d28fdee501c7fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20a6dc073e5c1c8ca8d28fdee501c7fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20a6dc073e5c1c8ca8d28fdee501c7fd = L.map(
#                 &quot;map_20a6dc073e5c1c8ca8d28fdee501c7fd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a090efea4dc64182476645d7b5eaa66 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a090efea4dc64182476645d7b5eaa66.addTo(map_20a6dc073e5c1c8ca8d28fdee501c7fd);
#
#
#             var marker_8a9c6b71c93aca3de04eebea21571af4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_20a6dc073e5c1c8ca8d28fdee501c7fd);
#
#
#         var popup_44c49a36abfb657ba18ae5cb0fe0f37c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ca9b77dfda1332caea5ebcc7d2bbecd = $(`&lt;div id=&quot;html_9ca9b77dfda1332caea5ebcc7d2bbecd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_44c49a36abfb657ba18ae5cb0fe0f37c.setContent(html_9ca9b77dfda1332caea5ebcc7d2bbecd);
#
#
#
#         marker_8a9c6b71c93aca3de04eebea21571af4.bindPopup(popup_44c49a36abfb657ba18ae5cb0fe0f37c)
#         ;
#
#
#
#
#             var marker_c5a9371ad225da1261687f7817a4888b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_20a6dc073e5c1c8ca8d28fdee501c7fd);
#
#
#         var popup_857163741c1b17f31eec19294ad526cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50e91b5feca9df5d7683f480c6a884db = $(`&lt;div id=&quot;html_50e91b5feca9df5d7683f480c6a884db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_857163741c1b17f31eec19294ad526cc.setContent(html_50e91b5feca9df5d7683f480c6a884db);
#
#
#
#         marker_c5a9371ad225da1261687f7817a4888b.bindPopup(popup_857163741c1b17f31eec19294ad526cc)
#         ;
#
#
#
#
#             var marker_edb2b6778f8d3cf061dac204b0864325 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_20a6dc073e5c1c8ca8d28fdee501c7fd);
#
#
#         var popup_15d145634e1647414064db059485ccc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9afc8a16b5c68ff7ff6b64f47aa5b567 = $(`&lt;div id=&quot;html_9afc8a16b5c68ff7ff6b64f47aa5b567&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_15d145634e1647414064db059485ccc4.setContent(html_9afc8a16b5c68ff7ff6b64f47aa5b567);
#
#
#
#         marker_edb2b6778f8d3cf061dac204b0864325.bindPopup(popup_15d145634e1647414064db059485ccc4)
#         ;
#
#
#
#
#             var marker_4b548f57212a116cd1d96e2f6ca8ca89 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_20a6dc073e5c1c8ca8d28fdee501c7fd);
#
#
#         var popup_440f3f370dcc6ab25ddf63494a1432ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e4971c39ea07a221db56f4a33d61415 = $(`&lt;div id=&quot;html_6e4971c39ea07a221db56f4a33d61415&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_440f3f370dcc6ab25ddf63494a1432ef.setContent(html_6e4971c39ea07a221db56f4a33d61415);
#
#
#
#         marker_4b548f57212a116cd1d96e2f6ca8ca89.bindPopup(popup_440f3f370dcc6ab25ddf63494a1432ef)
#         ;
#
#
#
#
#             var marker_ce33cc46342092010e45e7c32b32b4eb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_20a6dc073e5c1c8ca8d28fdee501c7fd);
#
#
#         var popup_ad29391498efc01c97a11b8ea5a7e246 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63f46a407990bbe6493b6c02e047d701 = $(`&lt;div id=&quot;html_63f46a407990bbe6493b6c02e047d701&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ad29391498efc01c97a11b8ea5a7e246.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81e761d109c18c35f60d73e58820bf90 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81e761d109c18c35f60d73e58820bf90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81e761d109c18c35f60d73e58820bf90 = L.map(
#                 &quot;map_81e761d109c18c35f60d73e58820bf90&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52f6da6810d84960a32effdb7f4649e9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_52f6da6810d84960a32effdb7f4649e9.addTo(map_81e761d109c18c35f60d73e58820bf90);
#
#
#             var feature_group_d07abd046e6bda262a0957011f364a17 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7205d7f76c2161dd4cb2c6e10bb15249 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d07abd046e6bda262a0957011f364a17);
#
#
#         var popup_76285d3f0c2f4a139ea046b11caadf5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5f6720832888d7d5ea7e2737d4bd965 = $(`&lt;div id=&quot;html_f5f6720832888d7d5ea7e2737d4bd965&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_76285d3f0c2f4a139ea046b11caadf5e.setContent(html_f5f6720832888d7d5ea7e2737d4bd965);
#
#
#
#         marker_7205d7f76c2161dd4cb2c6e10bb15249.bindPopup(popup_76285d3f0c2f4a139ea046b11caadf5e)
#         ;
#
#
#
#
#             var marker_95334ada64ce0b71b311043ed3689ea9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d07abd046e6bda262a0957011f364a17);
#
#
#         var popup_be765b96d2b26fc165b99613f8cefdfa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6126154144b73114662d897933bfbbc3 = $(`&lt;div id=&quot;html_6126154144b73114662d897933bfbbc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_be765b96d2b26fc165b99613f8cefdfa.setContent(html_6126154144b73114662d897933bfbbc3);
#
#
#
#         marker_95334ada64ce0b71b311043ed3689ea9.bindPopup(popup_be765b96d2b26fc165b99613f8cefdfa)
#         ;
#
#
#
#
#             var marker_8e99be0621d9c90289ec89ba595679d5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d07abd046e6bda262a0957011f364a17);
#
#
#         var popup_474694e33f280146efa20b9df14accf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc2725654b13e1bceab7366e5be24a83 = $(`&lt;div id=&quot;html_cc2725654b13e1bceab7366e5be24a83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_474694e33f280146efa20b9df14accf9.setContent(html_cc2725654b13e1bceab7366e5be24a83);
#
#
#
#         marker_8e99be0621d9c90289ec89ba595679d5.bindPopup(popup_474694e33f280146efa20b9df14accf9)
#         ;
#
#
#
#
#             var marker_54003383f17338ccdf419c63833b195c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d07abd046e6bda262a0957011f364a17);
#
#
#         var popup_74f6c652df8017d1f5d4f9baa4a30a19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78fa5bc1ee5d22ca0beaed6d6f42ba0c = $(`&lt;div id=&quot;html_78fa5bc1ee5d22ca0beaed6d6f42ba0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_74f6c652df8017d1f5d4f9baa4a30a19.setContent(html_78fa5bc1ee5d22ca0beaed6d6f42ba0c);
#
#
#
#         marker_54003383f17338ccdf419c63833b195c.bindPopup(popup_74f6c652df8017d1f5d4f9baa4a30a19)
#         ;
#
#
#
#
#             var marker_c8486c15ea499614c70d9c7bffb196c8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d07abd046e6bda262a0957011f364a17);
#
#
#         var popup_082a5195f9850aee4316b55adbc39ba1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eea3cca25b065f2acac39282bf587fbd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eea3cca25b065f2acac39282bf587fbd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eea3cca25b065f2acac39282bf587fbd = L.map(
#                 &quot;map_eea3cca25b065f2acac39282bf587fbd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a65e1cfbbf2d2e389d00207c5ab2b53f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a65e1cfbbf2d2e389d00207c5ab2b53f.addTo(map_eea3cca25b065f2acac39282bf587fbd);
#
#
#             var feature_group_ed5ed7215f29b2f8f9b60e027ff2aec6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ed5ed7215f29b2f8f9b60e027ff2aec6.addTo(map_eea3cca25b065f2acac39282bf587fbd);
#
#
#             var feature_group_sub_group_0c6f268c3ba8fa6549e80eacf9701254 = L.featureGroup.subGroup(
#                 feature_group_ed5ed7215f29b2f8f9b60e027ff2aec6
#             );
#
#
#             var marker_cff04a11c58c69f57515fab3c555ae91 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0c6f268c3ba8fa6549e80eacf9701254);
#
#
#         var popup_8332d7f72c92364cf750f1d7631ce37e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a0f4d14fe66810bf122d20be319d63f = $(`&lt;div id=&quot;html_3a0f4d14fe66810bf122d20be319d63f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8332d7f72c92364cf750f1d7631ce37e.setContent(html_3a0f4d14fe66810bf122d20be319d63f);
#
#
#
#         marker_cff04a11c58c69f57515fab3c555ae91.bindPopup(popup_8332d7f72c92364cf750f1d7631ce37e)
#         ;
#
#
#
#
#             var marker_4db170b25f186c9cdb2341bbdf9e7abd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0c6f268c3ba8fa6549e80eacf9701254);
#
#
#         var popup_e90fbd3eb5330e03605dc6441f077932 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_271dff019873a6666eacecbf7b5a5847 = $(`&lt;div id=&quot;html_271dff019873a6666eacecbf7b5a5847&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e90fbd3eb5330e03605dc6441f077932.setContent(html_271dff019873a6666eacecbf7b5a5847);
#
#
#
#         marker_4db170b25f186c9cdb2341bbdf9e7abd.bindPopup(popup_e90fbd3eb5330e03605dc6441f077932)
#         ;
#
#
#
#
#             var marker_2270d2d5c7179ada4c175d3a9e5dce15 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0c6f268c3ba8fa6549e80eacf9701254);
#
#
#         var popup_9254abdcda50986863bf160181843cda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb7c941a4e60ee53a81203e0d3e8e384 = $(`&lt;div id=&quot;html_cb7c941a4e60ee53a81203e0d3e8e384&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9254abdcda50986863bf160181843cda.setContent(html_cb7c941a4e60ee53a81203e0d3e8e384);
#
#
#
#         marker_2270d2d5c7179ada4c175d3a9e5dce15.bindPopup(popup_9254abdcda50986863bf160181843cda)
#         ;
#
#
#
#
#             var marker_f1856275b6df421bf68b4d97b7ad1c9f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0c6f268c3ba8fa6549e80eacf9701254);
#
#
#         var popup_62e9338ee80cbde16e04cc5d4f23839f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_197e5b2ac73c02da978ad40d199cd574 = $(`&lt;div id=&quot;html_197e5b2ac73c02da978ad40d199cd574&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_62e9338ee80cbde16e04cc5d4f23839f.setContent(html_197e5b2ac73c02da978ad40d199cd574);
#
#
#
#         marker_
