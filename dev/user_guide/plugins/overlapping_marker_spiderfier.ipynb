# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3a27100a56c2b9314fcd131e81a82e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3a27100a56c2b9314fcd131e81a82e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3a27100a56c2b9314fcd131e81a82e9 = L.map(
#                 &quot;map_e3a27100a56c2b9314fcd131e81a82e9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99ab0fd21334bc1a69366229478b7b33 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_99ab0fd21334bc1a69366229478b7b33.addTo(map_e3a27100a56c2b9314fcd131e81a82e9);
#
#
#             var marker_eea388d65a970b2dfb6cefac71e22ef4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e3a27100a56c2b9314fcd131e81a82e9);
#
#
#         var popup_14eab69ee94cffd2893b011041ec9551 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb2305774e85fa32d9b08c7e0979ebb9 = $(`&lt;div id=&quot;html_fb2305774e85fa32d9b08c7e0979ebb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_14eab69ee94cffd2893b011041ec9551.setContent(html_fb2305774e85fa32d9b08c7e0979ebb9);
#
#
#
#         marker_eea388d65a970b2dfb6cefac71e22ef4.bindPopup(popup_14eab69ee94cffd2893b011041ec9551)
#         ;
#
#
#
#
#             var marker_baf0625f17f525f2d7291c96b6f5d506 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e3a27100a56c2b9314fcd131e81a82e9);
#
#
#         var popup_9d90c03870fde619c6c736055167e99d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76642bba6b32072a639b8fc20fdadc9f = $(`&lt;div id=&quot;html_76642bba6b32072a639b8fc20fdadc9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9d90c03870fde619c6c736055167e99d.setContent(html_76642bba6b32072a639b8fc20fdadc9f);
#
#
#
#         marker_baf0625f17f525f2d7291c96b6f5d506.bindPopup(popup_9d90c03870fde619c6c736055167e99d)
#         ;
#
#
#
#
#             var marker_a41286e3a9f18b61942ae553a1372a9c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e3a27100a56c2b9314fcd131e81a82e9);
#
#
#         var popup_1071af921018af6c76f5451ac95c804b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31a85943e794413ab0b4cf59c82456b1 = $(`&lt;div id=&quot;html_31a85943e794413ab0b4cf59c82456b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1071af921018af6c76f5451ac95c804b.setContent(html_31a85943e794413ab0b4cf59c82456b1);
#
#
#
#         marker_a41286e3a9f18b61942ae553a1372a9c.bindPopup(popup_1071af921018af6c76f5451ac95c804b)
#         ;
#
#
#
#
#             var marker_90ca50f98d706aba29f2c5e49d3d008e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e3a27100a56c2b9314fcd131e81a82e9);
#
#
#         var popup_ad66f66a0c32a21978a7a612db1d9a69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b18ff850c341136d0b482d056581b79 = $(`&lt;div id=&quot;html_7b18ff850c341136d0b482d056581b79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ad66f66a0c32a21978a7a612db1d9a69.setContent(html_7b18ff850c341136d0b482d056581b79);
#
#
#
#         marker_90ca50f98d706aba29f2c5e49d3d008e.bindPopup(popup_ad66f66a0c32a21978a7a612db1d9a69)
#         ;
#
#
#
#
#             var marker_df4c2883ba82296d626f825f2f9445b3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e3a27100a56c2b9314fcd131e81a82e9);
#
#
#         var popup_253c969b0a628f26be6e72b1a051253a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79d508aec786365e3773f8826fc3c07c = $(`&lt;div id=&quot;html_79d508aec786365e3773f8826fc3c07c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_253c969b0a628f26be6e72b1a051253a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e0489d2610bb5c5769052099e477f5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e0489d2610bb5c5769052099e477f5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e0489d2610bb5c5769052099e477f5c = L.map(
#                 &quot;map_2e0489d2610bb5c5769052099e477f5c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6416d12d59b1c906622fcad9af79931c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6416d12d59b1c906622fcad9af79931c.addTo(map_2e0489d2610bb5c5769052099e477f5c);
#
#
#             var feature_group_561a44c7f9d6a38a834d907f61f54dbd = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_31f43b8fb05c49d1b4b9c2333ecdea38 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_561a44c7f9d6a38a834d907f61f54dbd);
#
#
#         var popup_f8479d230fd367ba0cfd9a8a326caba6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a698475a3c2684d1eeb46e707c04767 = $(`&lt;div id=&quot;html_1a698475a3c2684d1eeb46e707c04767&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f8479d230fd367ba0cfd9a8a326caba6.setContent(html_1a698475a3c2684d1eeb46e707c04767);
#
#
#
#         marker_31f43b8fb05c49d1b4b9c2333ecdea38.bindPopup(popup_f8479d230fd367ba0cfd9a8a326caba6)
#         ;
#
#
#
#
#             var marker_5395aab04e6526f85e7f84555328254e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_561a44c7f9d6a38a834d907f61f54dbd);
#
#
#         var popup_efc506b690e4567015565130e7ce8b6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_236a1dc40672dfa58d1897f7c3146c7c = $(`&lt;div id=&quot;html_236a1dc40672dfa58d1897f7c3146c7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_efc506b690e4567015565130e7ce8b6c.setContent(html_236a1dc40672dfa58d1897f7c3146c7c);
#
#
#
#         marker_5395aab04e6526f85e7f84555328254e.bindPopup(popup_efc506b690e4567015565130e7ce8b6c)
#         ;
#
#
#
#
#             var marker_78ba6720cfd6b05eb74184b6b71a2489 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_561a44c7f9d6a38a834d907f61f54dbd);
#
#
#         var popup_363b10944f3dbff075eca12b52924dc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbd904981ab13a1d656558644aca897a = $(`&lt;div id=&quot;html_bbd904981ab13a1d656558644aca897a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_363b10944f3dbff075eca12b52924dc6.setContent(html_bbd904981ab13a1d656558644aca897a);
#
#
#
#         marker_78ba6720cfd6b05eb74184b6b71a2489.bindPopup(popup_363b10944f3dbff075eca12b52924dc6)
#         ;
#
#
#
#
#             var marker_a5e2ecf451b0e5b2c1cb007ee29d69c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_561a44c7f9d6a38a834d907f61f54dbd);
#
#
#         var popup_be92ecd2811af78d50608d1722d02f85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28710f1889dbf4a2b9265413de20ed66 = $(`&lt;div id=&quot;html_28710f1889dbf4a2b9265413de20ed66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_be92ecd2811af78d50608d1722d02f85.setContent(html_28710f1889dbf4a2b9265413de20ed66);
#
#
#
#         marker_a5e2ecf451b0e5b2c1cb007ee29d69c0.bindPopup(popup_be92ecd2811af78d50608d1722d02f85)
#         ;
#
#
#
#
#             var marker_9ae2670adcfe4a5f8ed25787f336011c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_561a44c7f9d6a38a834d907f61f54dbd);
#
#
#         var popup_85fc85e16c12372e513a11e3f812c5e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc87a9092cc718a774b9da7a35eaa218 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc87a9092cc718a774b9da7a35eaa218&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc87a9092cc718a774b9da7a35eaa218 = L.map(
#                 &quot;map_dc87a9092cc718a774b9da7a35eaa218&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b80312c62ab454928acec493aacab919 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b80312c62ab454928acec493aacab919.addTo(map_dc87a9092cc718a774b9da7a35eaa218);
#
#
#             var feature_group_e5e45fd9030b9534f061b8dd5eeffb28 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e5e45fd9030b9534f061b8dd5eeffb28.addTo(map_dc87a9092cc718a774b9da7a35eaa218);
#
#
#             var feature_group_sub_group_0496a172bb073f24499732ec9815d570 = L.featureGroup.subGroup(
#                 feature_group_e5e45fd9030b9534f061b8dd5eeffb28
#             );
#
#
#             var marker_38bf2a7c7917d650e72f52b876d7c35c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0496a172bb073f24499732ec9815d570);
#
#
#         var popup_dadde1ea5342eef561af24a5a7f4af07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf6ac87b22159b79b4b492792d4e1cdb = $(`&lt;div id=&quot;html_bf6ac87b22159b79b4b492792d4e1cdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_dadde1ea5342eef561af24a5a7f4af07.setContent(html_bf6ac87b22159b79b4b492792d4e1cdb);
#
#
#
#         marker_38bf2a7c7917d650e72f52b876d7c35c.bindPopup(popup_dadde1ea5342eef561af24a5a7f4af07)
#         ;
#
#
#
#
#             var marker_d9e8f68d37ee3aa5cf5025935647bd42 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0496a172bb073f24499732ec9815d570);
#
#
#         var popup_753aa764c8788d622912a1cb9f46e776 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a8a0b8abd0f487df482e62b3f6f0666 = $(`&lt;div id=&quot;html_4a8a0b8abd0f487df482e62b3f6f0666&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_753aa764c8788d622912a1cb9f46e776.setContent(html_4a8a0b8abd0f487df482e62b3f6f0666);
#
#
#
#         marker_d9e8f68d37ee3aa5cf5025935647bd42.bindPopup(popup_753aa764c8788d622912a1cb9f46e776)
#         ;
#
#
#
#
#             var marker_cd415dd086aadb83db8c99d6432075c5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0496a172bb073f24499732ec9815d570);
#
#
#         var popup_887659db819ea026eeae8c70d561fea2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73dfeea65679a345b79934ad634d0eab = $(`&lt;div id=&quot;html_73dfeea65679a345b79934ad634d0eab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_887659db819ea026eeae8c70d561fea2.setContent(html_73dfeea65679a345b79934ad634d0eab);
#
#
#
#         marker_cd415dd086aadb83db8c99d6432075c5.bindPopup(popup_887659db819ea026eeae8c70d561fea2)
#         ;
#
#
#
#
#             var marker_39ae02aa44f88fd4e4f61c65ca430cf3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0496a172bb073f24499732ec9815d570);
#
#
#         var popup_066987e274584abace664bae0d52d28e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c010c3e905aeacfa6444951bea4fd2ac = $(`&lt;div id=&quot;html_c010c3e905aeacfa6444951bea4fd2ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_066987e274584abace664bae0d52d28e.setContent(html_c010c3e905aeacfa6444951bea4fd2ac);
#
#
#
#         marker_
