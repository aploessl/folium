# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c03908182d06c6f8e56c093e62ef283e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c03908182d06c6f8e56c093e62ef283e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c03908182d06c6f8e56c093e62ef283e = L.map(
#                 &quot;map_c03908182d06c6f8e56c093e62ef283e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_268c8cbae897a3aa2c4e9317b61e82eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_268c8cbae897a3aa2c4e9317b61e82eb.addTo(map_c03908182d06c6f8e56c093e62ef283e);
#
#
#             var marker_f42d34a8f89cef09bb2404792ee3bb83 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c03908182d06c6f8e56c093e62ef283e);
#
#
#         var popup_f470db24b17cad195231fd7037dc78b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e26ef49ecc43bdb9f83c6c1e041e79f = $(`&lt;div id=&quot;html_7e26ef49ecc43bdb9f83c6c1e041e79f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f470db24b17cad195231fd7037dc78b9.setContent(html_7e26ef49ecc43bdb9f83c6c1e041e79f);
#
#
#
#         marker_f42d34a8f89cef09bb2404792ee3bb83.bindPopup(popup_f470db24b17cad195231fd7037dc78b9)
#         ;
#
#
#
#
#             var marker_e73e20749b502f3f43ab94dcaab2dc46 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c03908182d06c6f8e56c093e62ef283e);
#
#
#         var popup_7824a74a29f834c8c5e3d63bfaa4979d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba149a81fa11c50d0702240e8675ca8c = $(`&lt;div id=&quot;html_ba149a81fa11c50d0702240e8675ca8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7824a74a29f834c8c5e3d63bfaa4979d.setContent(html_ba149a81fa11c50d0702240e8675ca8c);
#
#
#
#         marker_e73e20749b502f3f43ab94dcaab2dc46.bindPopup(popup_7824a74a29f834c8c5e3d63bfaa4979d)
#         ;
#
#
#
#
#             var marker_5841f628d40499fcc58353eabfc9c2df = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c03908182d06c6f8e56c093e62ef283e);
#
#
#         var popup_b33e9c6a78addbca7994ebe536578de0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fde50acaae5536f9b2f14a46047ccc1c = $(`&lt;div id=&quot;html_fde50acaae5536f9b2f14a46047ccc1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b33e9c6a78addbca7994ebe536578de0.setContent(html_fde50acaae5536f9b2f14a46047ccc1c);
#
#
#
#         marker_5841f628d40499fcc58353eabfc9c2df.bindPopup(popup_b33e9c6a78addbca7994ebe536578de0)
#         ;
#
#
#
#
#             var marker_eb86e8db5cddd96519f6d519400be3e2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c03908182d06c6f8e56c093e62ef283e);
#
#
#         var popup_98db3d41607c32f95d5d39f65efe6d1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_932bb92779f493de1e9ff2f2d244f508 = $(`&lt;div id=&quot;html_932bb92779f493de1e9ff2f2d244f508&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_98db3d41607c32f95d5d39f65efe6d1f.setContent(html_932bb92779f493de1e9ff2f2d244f508);
#
#
#
#         marker_eb86e8db5cddd96519f6d519400be3e2.bindPopup(popup_98db3d41607c32f95d5d39f65efe6d1f)
#         ;
#
#
#
#
#             var marker_d8a4cff29c943d5b7f152f6348484127 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c03908182d06c6f8e56c093e62ef283e);
#
#
#         var popup_9c116673d10bb842849520eba60b5b45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4796a75f266d53fb5ee1426ee3d0b066 = $(`&lt;div id=&quot;html_4796a75f266d53fb5ee1426ee3d0b066&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9c116673d10bb842849520eba60b5b45.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10561992fa68ea2b0e840dc4e7accd51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10561992fa68ea2b0e840dc4e7accd51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10561992fa68ea2b0e840dc4e7accd51 = L.map(
#                 &quot;map_10561992fa68ea2b0e840dc4e7accd51&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5de0100d109e440a4253781613fdcd43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5de0100d109e440a4253781613fdcd43.addTo(map_10561992fa68ea2b0e840dc4e7accd51);
#
#
#             var feature_group_a77171fda27849b292682247598ddd95 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_58e650e3c331f5c5c89c6de185d55a53 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a77171fda27849b292682247598ddd95);
#
#
#         var popup_8012ac445617d5c1aa4cfa4983da5574 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a868cd4309f0d16c66f7582e0bb7497 = $(`&lt;div id=&quot;html_4a868cd4309f0d16c66f7582e0bb7497&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8012ac445617d5c1aa4cfa4983da5574.setContent(html_4a868cd4309f0d16c66f7582e0bb7497);
#
#
#
#         marker_58e650e3c331f5c5c89c6de185d55a53.bindPopup(popup_8012ac445617d5c1aa4cfa4983da5574)
#         ;
#
#
#
#
#             var marker_2389edbb957161cc5c515b8078c6c777 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a77171fda27849b292682247598ddd95);
#
#
#         var popup_73ff37998a1144c2e5157ec287f1c236 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22aed2fc6d5105cceadc2954c92e32d0 = $(`&lt;div id=&quot;html_22aed2fc6d5105cceadc2954c92e32d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_73ff37998a1144c2e5157ec287f1c236.setContent(html_22aed2fc6d5105cceadc2954c92e32d0);
#
#
#
#         marker_2389edbb957161cc5c515b8078c6c777.bindPopup(popup_73ff37998a1144c2e5157ec287f1c236)
#         ;
#
#
#
#
#             var marker_31a99c3f9fc06bb4088cb4b8c802e037 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a77171fda27849b292682247598ddd95);
#
#
#         var popup_df4fb309f064efb8d4ff9f399c3f131c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec7df52a2a99bc0ecc6c2abc047151cb = $(`&lt;div id=&quot;html_ec7df52a2a99bc0ecc6c2abc047151cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_df4fb309f064efb8d4ff9f399c3f131c.setContent(html_ec7df52a2a99bc0ecc6c2abc047151cb);
#
#
#
#         marker_31a99c3f9fc06bb4088cb4b8c802e037.bindPopup(popup_df4fb309f064efb8d4ff9f399c3f131c)
#         ;
#
#
#
#
#             var marker_33f394101e6e700cacdb0fd694c9970f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a77171fda27849b292682247598ddd95);
#
#
#         var popup_b6c629f2ba32d7c33cacf153754330ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5e1c3f509f66daa7cd04b2b603173a4 = $(`&lt;div id=&quot;html_c5e1c3f509f66daa7cd04b2b603173a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b6c629f2ba32d7c33cacf153754330ab.setContent(html_c5e1c3f509f66daa7cd04b2b603173a4);
#
#
#
#         marker_33f394101e6e700cacdb0fd694c9970f.bindPopup(popup_b6c629f2ba32d7c33cacf153754330ab)
#         ;
#
#
#
#
#             var marker_16e93506dbe646eeac8b6c2cba8764d0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a77171fda27849b292682247598ddd95);
#
#
#         var popup_73ef3233bc4a63a649417c5b09e423fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b87c37ac12385e0fc6cf196625aa0d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b87c37ac12385e0fc6cf196625aa0d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b87c37ac12385e0fc6cf196625aa0d4 = L.map(
#                 &quot;map_0b87c37ac12385e0fc6cf196625aa0d4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9016b293925c729d6693e44392c50b25 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9016b293925c729d6693e44392c50b25.addTo(map_0b87c37ac12385e0fc6cf196625aa0d4);
#
#
#             var feature_group_59e5eec36a2aedcea475ded54be86ac6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_59e5eec36a2aedcea475ded54be86ac6.addTo(map_0b87c37ac12385e0fc6cf196625aa0d4);
#
#
#             var feature_group_sub_group_19a6812b94bfd229bc2fcfce41a5a7d5 = L.featureGroup.subGroup(
#                 feature_group_59e5eec36a2aedcea475ded54be86ac6
#             );
#
#
#             var marker_d1245d57ef91d66a72d8aeada9eb96cd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_19a6812b94bfd229bc2fcfce41a5a7d5);
#
#
#         var popup_0bf206404b1d895902c836837c68014b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12d4ee23e7426e59d62d48b5f1cf1ecd = $(`&lt;div id=&quot;html_12d4ee23e7426e59d62d48b5f1cf1ecd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0bf206404b1d895902c836837c68014b.setContent(html_12d4ee23e7426e59d62d48b5f1cf1ecd);
#
#
#
#         marker_d1245d57ef91d66a72d8aeada9eb96cd.bindPopup(popup_0bf206404b1d895902c836837c68014b)
#         ;
#
#
#
#
#             var marker_d1418ed98ef52a42386c0e994c3f6df7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_19a6812b94bfd229bc2fcfce41a5a7d5);
#
#
#         var popup_fb916783a51611ee1044ca317f8e8e3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73e2735473bdfddfeffcdb1f397a17dd = $(`&lt;div id=&quot;html_73e2735473bdfddfeffcdb1f397a17dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fb916783a51611ee1044ca317f8e8e3a.setContent(html_73e2735473bdfddfeffcdb1f397a17dd);
#
#
#
#         marker_d1418ed98ef52a42386c0e994c3f6df7.bindPopup(popup_fb916783a51611ee1044ca317f8e8e3a)
#         ;
#
#
#
#
#             var marker_e44375af88a6b2632e5bf678c78b1d45 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_19a6812b94bfd229bc2fcfce41a5a7d5);
#
#
#         var popup_b20657768aa2d699be4e7815f4df8953 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64aa5d0fae69fafb20b023364fa08fca = $(`&lt;div id=&quot;html_64aa5d0fae69fafb20b023364fa08fca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b20657768aa2d699be4e7815f4df8953.setContent(html_64aa5d0fae69fafb20b023364fa08fca);
#
#
#
#         marker_e44375af88a6b2632e5bf678c78b1d45.bindPopup(popup_b20657768aa2d699be4e7815f4df8953)
#         ;
#
#
#
#
#             var marker_44a1326f3fdca8c86b876130d6a9b65e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_19a6812b94bfd229bc2fcfce41a5a7d5);
#
#
#         var popup_4e716e72da5dd22177a2e3bd0c8a62bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d86e9c637cfced39c79087434ff9a51a = $(`&lt;div id=&quot;html_d86e9c637cfced39c79087434ff9a51a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4e716e72da5dd22177a2e3bd0c8a62bd.setContent(html_d86e9c637cfced39c79087434ff9a51a);
#
#
#
#         marker_
