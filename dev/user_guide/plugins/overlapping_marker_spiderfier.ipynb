# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9cf9868881c61a25650ec9680bcf4f1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9cf9868881c61a25650ec9680bcf4f1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9cf9868881c61a25650ec9680bcf4f1a = L.map(
#                 &quot;map_9cf9868881c61a25650ec9680bcf4f1a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bae842b155f413735a4af02edc611176 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bae842b155f413735a4af02edc611176.addTo(map_9cf9868881c61a25650ec9680bcf4f1a);
#
#
#             var marker_fb8a4a755badcbc86ae7cf585b290b58 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9cf9868881c61a25650ec9680bcf4f1a);
#
#
#         var popup_c72ad4d64f2a85da53db986122f62e6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c22fcb056ee6cadf021070b38be448e = $(`&lt;div id=&quot;html_3c22fcb056ee6cadf021070b38be448e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c72ad4d64f2a85da53db986122f62e6a.setContent(html_3c22fcb056ee6cadf021070b38be448e);
#
#
#
#         marker_fb8a4a755badcbc86ae7cf585b290b58.bindPopup(popup_c72ad4d64f2a85da53db986122f62e6a)
#         ;
#
#
#
#
#             var marker_340d32f5076e0e3b03c604f72eec98af = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9cf9868881c61a25650ec9680bcf4f1a);
#
#
#         var popup_f4ef12043c40e788551b8140c43dd0b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58ae0ee1eb2ba45b854815b8d765e094 = $(`&lt;div id=&quot;html_58ae0ee1eb2ba45b854815b8d765e094&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f4ef12043c40e788551b8140c43dd0b2.setContent(html_58ae0ee1eb2ba45b854815b8d765e094);
#
#
#
#         marker_340d32f5076e0e3b03c604f72eec98af.bindPopup(popup_f4ef12043c40e788551b8140c43dd0b2)
#         ;
#
#
#
#
#             var marker_2b617caaed45f13a22dd4e0fa2a0f8fb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9cf9868881c61a25650ec9680bcf4f1a);
#
#
#         var popup_16151a55c4797d889232c2ada8691e0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d7a59ca3d0281cfd9964ec254cf8230 = $(`&lt;div id=&quot;html_7d7a59ca3d0281cfd9964ec254cf8230&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_16151a55c4797d889232c2ada8691e0f.setContent(html_7d7a59ca3d0281cfd9964ec254cf8230);
#
#
#
#         marker_2b617caaed45f13a22dd4e0fa2a0f8fb.bindPopup(popup_16151a55c4797d889232c2ada8691e0f)
#         ;
#
#
#
#
#             var marker_253278c335f9752415aa7ec7dc92ad53 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9cf9868881c61a25650ec9680bcf4f1a);
#
#
#         var popup_6fdd4b9c0d13d8051cd337c6592f65da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cc5a894a4a15e1fc58eb12659d0628f = $(`&lt;div id=&quot;html_6cc5a894a4a15e1fc58eb12659d0628f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6fdd4b9c0d13d8051cd337c6592f65da.setContent(html_6cc5a894a4a15e1fc58eb12659d0628f);
#
#
#
#         marker_253278c335f9752415aa7ec7dc92ad53.bindPopup(popup_6fdd4b9c0d13d8051cd337c6592f65da)
#         ;
#
#
#
#
#             var marker_d0db7dc8a642f96258da153221888789 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9cf9868881c61a25650ec9680bcf4f1a);
#
#
#         var popup_0b9793a8cd63bba8fbe653136f6a60db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6aa62d815b60632d2cc390927642435 = $(`&lt;div id=&quot;html_c6aa62d815b60632d2cc390927642435&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0b9793a8cd63bba8fbe653136f6a60db.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0438730e87cddf902377e068ad23b334 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0438730e87cddf902377e068ad23b334&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0438730e87cddf902377e068ad23b334 = L.map(
#                 &quot;map_0438730e87cddf902377e068ad23b334&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c586c776f9fdcaeab02e75a638df7cff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c586c776f9fdcaeab02e75a638df7cff.addTo(map_0438730e87cddf902377e068ad23b334);
#
#
#             var feature_group_0de2e49963199936ebdb28c83e9030c2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4c64702f08952931253888e816563d74 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0de2e49963199936ebdb28c83e9030c2);
#
#
#         var popup_0f7ae00b12336a5e09f5211654a76fa4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24632f7b0ce22e1ede9069ebf38db3b6 = $(`&lt;div id=&quot;html_24632f7b0ce22e1ede9069ebf38db3b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0f7ae00b12336a5e09f5211654a76fa4.setContent(html_24632f7b0ce22e1ede9069ebf38db3b6);
#
#
#
#         marker_4c64702f08952931253888e816563d74.bindPopup(popup_0f7ae00b12336a5e09f5211654a76fa4)
#         ;
#
#
#
#
#             var marker_daa48984699aa1dc635fb3bca59907d5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0de2e49963199936ebdb28c83e9030c2);
#
#
#         var popup_5b22aac97f88e5ff55672ad08a8b3e50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_893bf282d2aae10f84d8ed1f5827361f = $(`&lt;div id=&quot;html_893bf282d2aae10f84d8ed1f5827361f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5b22aac97f88e5ff55672ad08a8b3e50.setContent(html_893bf282d2aae10f84d8ed1f5827361f);
#
#
#
#         marker_daa48984699aa1dc635fb3bca59907d5.bindPopup(popup_5b22aac97f88e5ff55672ad08a8b3e50)
#         ;
#
#
#
#
#             var marker_0337f97b31135c7f9fca0f2c402afc2a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0de2e49963199936ebdb28c83e9030c2);
#
#
#         var popup_8291c41c9f5e4e11edf3e35fed6ea730 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_028908c3b2d0df26568a78c3aad1dd4d = $(`&lt;div id=&quot;html_028908c3b2d0df26568a78c3aad1dd4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8291c41c9f5e4e11edf3e35fed6ea730.setContent(html_028908c3b2d0df26568a78c3aad1dd4d);
#
#
#
#         marker_0337f97b31135c7f9fca0f2c402afc2a.bindPopup(popup_8291c41c9f5e4e11edf3e35fed6ea730)
#         ;
#
#
#
#
#             var marker_8c3c1cfc74e4db41a35cab949b923ecd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0de2e49963199936ebdb28c83e9030c2);
#
#
#         var popup_1725f37207f5b601c4b14fe8050301b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b53a4af6a0033cf6559c08758b0455f = $(`&lt;div id=&quot;html_9b53a4af6a0033cf6559c08758b0455f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1725f37207f5b601c4b14fe8050301b8.setContent(html_9b53a4af6a0033cf6559c08758b0455f);
#
#
#
#         marker_8c3c1cfc74e4db41a35cab949b923ecd.bindPopup(popup_1725f37207f5b601c4b14fe8050301b8)
#         ;
#
#
#
#
#             var marker_59a074009e2162752fc4ac3f3035bc68 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0de2e49963199936ebdb28c83e9030c2);
#
#
#         var popup_4309b3430f4d5ebb51659f4a751734dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_964b21ff3ff63496da65b46e2d27fdd2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_964b21ff3ff63496da65b46e2d27fdd2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_964b21ff3ff63496da65b46e2d27fdd2 = L.map(
#                 &quot;map_964b21ff3ff63496da65b46e2d27fdd2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a11f067f00aff1e81d3880e404116809 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a11f067f00aff1e81d3880e404116809.addTo(map_964b21ff3ff63496da65b46e2d27fdd2);
#
#
#             var feature_group_f2b38291d9902a53252fed18770df3b5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f2b38291d9902a53252fed18770df3b5.addTo(map_964b21ff3ff63496da65b46e2d27fdd2);
#
#
#             var feature_group_sub_group_74cf66f3a1d46980a3c582ad53b3c6c4 = L.featureGroup.subGroup(
#                 feature_group_f2b38291d9902a53252fed18770df3b5
#             );
#
#
#             var marker_7717212ef62b69d939a13ddedd5cd785 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_74cf66f3a1d46980a3c582ad53b3c6c4);
#
#
#         var popup_929920f37749bbf3368c41b69d55c72b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ffe61048e2be4ba1778ca38aef23e9d8 = $(`&lt;div id=&quot;html_ffe61048e2be4ba1778ca38aef23e9d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_929920f37749bbf3368c41b69d55c72b.setContent(html_ffe61048e2be4ba1778ca38aef23e9d8);
#
#
#
#         marker_7717212ef62b69d939a13ddedd5cd785.bindPopup(popup_929920f37749bbf3368c41b69d55c72b)
#         ;
#
#
#
#
#             var marker_0392f7a6846290b3215fc1016f262934 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_74cf66f3a1d46980a3c582ad53b3c6c4);
#
#
#         var popup_c34c8b10322b46bf05d70eff838f93cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65eaf125a6bf7b0a7cbb61b980a58cbd = $(`&lt;div id=&quot;html_65eaf125a6bf7b0a7cbb61b980a58cbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c34c8b10322b46bf05d70eff838f93cf.setContent(html_65eaf125a6bf7b0a7cbb61b980a58cbd);
#
#
#
#         marker_0392f7a6846290b3215fc1016f262934.bindPopup(popup_c34c8b10322b46bf05d70eff838f93cf)
#         ;
#
#
#
#
#             var marker_9a57f48b939ed3d76202f9ae8aeb6c3d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_74cf66f3a1d46980a3c582ad53b3c6c4);
#
#
#         var popup_3393d86639117555e53c25e54bdbb165 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b866463e2ede01397429a448f5f6b385 = $(`&lt;div id=&quot;html_b866463e2ede01397429a448f5f6b385&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3393d86639117555e53c25e54bdbb165.setContent(html_b866463e2ede01397429a448f5f6b385);
#
#
#
#         marker_9a57f48b939ed3d76202f9ae8aeb6c3d.bindPopup(popup_3393d86639117555e53c25e54bdbb165)
#         ;
#
#
#
#
#             var marker_185969a6e06c74b5917846474c7c88c4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_74cf66f3a1d46980a3c582ad53b3c6c4);
#
#
#         var popup_5bddb2a9f1715665ad45295caec52ede = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50a00ca2b6fdcfc83342d3150f6e132d = $(`&lt;div id=&quot;html_50a00ca2b6fdcfc83342d3150f6e132d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5bddb2a9f1715665ad45295caec52ede.setContent(html_50a00ca2b6fdcfc83342d3150f6e132d);
#
#
#
#         marker_
