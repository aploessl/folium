# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cb3695c226809cfece163009be053c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cb3695c226809cfece163009be053c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cb3695c226809cfece163009be053c1 = L.map(
#                 &quot;map_0cb3695c226809cfece163009be053c1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3decc8117802d93d8ae1fa6197829ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d3decc8117802d93d8ae1fa6197829ed.addTo(map_0cb3695c226809cfece163009be053c1);
#
#
#             var marker_f3610d9e2468255ea4cb452a35d97062 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0cb3695c226809cfece163009be053c1);
#
#
#         var popup_ddc0f236a0d5b43b38aa9d1781890b94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ee589205f85b38c4b7f31558c90ebc4 = $(`&lt;div id=&quot;html_9ee589205f85b38c4b7f31558c90ebc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ddc0f236a0d5b43b38aa9d1781890b94.setContent(html_9ee589205f85b38c4b7f31558c90ebc4);
#
#
#
#         marker_f3610d9e2468255ea4cb452a35d97062.bindPopup(popup_ddc0f236a0d5b43b38aa9d1781890b94)
#         ;
#
#
#
#
#             var marker_5cec575ac02311618070537ee28c5119 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0cb3695c226809cfece163009be053c1);
#
#
#         var popup_a1116468f8eab396d4a559bae4760a69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bebaa6100b2ec81c00ef78f0236ffc9 = $(`&lt;div id=&quot;html_1bebaa6100b2ec81c00ef78f0236ffc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a1116468f8eab396d4a559bae4760a69.setContent(html_1bebaa6100b2ec81c00ef78f0236ffc9);
#
#
#
#         marker_5cec575ac02311618070537ee28c5119.bindPopup(popup_a1116468f8eab396d4a559bae4760a69)
#         ;
#
#
#
#
#             var marker_f41191c935279298e6c939f3edd0159d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0cb3695c226809cfece163009be053c1);
#
#
#         var popup_57731db663eca01a29241ef8e54bb7f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b24f06e4ce210f280339d9fa34e9923 = $(`&lt;div id=&quot;html_6b24f06e4ce210f280339d9fa34e9923&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_57731db663eca01a29241ef8e54bb7f0.setContent(html_6b24f06e4ce210f280339d9fa34e9923);
#
#
#
#         marker_f41191c935279298e6c939f3edd0159d.bindPopup(popup_57731db663eca01a29241ef8e54bb7f0)
#         ;
#
#
#
#
#             var marker_a7d0053d25832236b16360d5b4ed91cf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0cb3695c226809cfece163009be053c1);
#
#
#         var popup_22ca977d571708b1ae365da9d9b7c88b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a137f4c9a51b338d700a49441cb5cd14 = $(`&lt;div id=&quot;html_a137f4c9a51b338d700a49441cb5cd14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_22ca977d571708b1ae365da9d9b7c88b.setContent(html_a137f4c9a51b338d700a49441cb5cd14);
#
#
#
#         marker_a7d0053d25832236b16360d5b4ed91cf.bindPopup(popup_22ca977d571708b1ae365da9d9b7c88b)
#         ;
#
#
#
#
#             var marker_b967ffcf6e2a1d69c5fac06918b7cbc5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0cb3695c226809cfece163009be053c1);
#
#
#         var popup_41064b2bd4ef85e38ce44830b0a17f23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32be0eed747437ccb26dcdbb07ca05da = $(`&lt;div id=&quot;html_32be0eed747437ccb26dcdbb07ca05da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_41064b2bd4ef85e38ce44830b0a17f23.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bccaa947df80c7ea1185cc8d6ec53a79 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bccaa947df80c7ea1185cc8d6ec53a79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bccaa947df80c7ea1185cc8d6ec53a79 = L.map(
#                 &quot;map_bccaa947df80c7ea1185cc8d6ec53a79&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be22f42f230106da052041b2a82f91f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be22f42f230106da052041b2a82f91f2.addTo(map_bccaa947df80c7ea1185cc8d6ec53a79);
#
#
#             var feature_group_c830aaa9dae77816b3d9bcdd680f923e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d503c2293746cdfd8854d998f47cc589 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c830aaa9dae77816b3d9bcdd680f923e);
#
#
#         var popup_a33bbbb638f5f094a28419e434e03abd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de1843bd18177a7a01f0e8125a203492 = $(`&lt;div id=&quot;html_de1843bd18177a7a01f0e8125a203492&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a33bbbb638f5f094a28419e434e03abd.setContent(html_de1843bd18177a7a01f0e8125a203492);
#
#
#
#         marker_d503c2293746cdfd8854d998f47cc589.bindPopup(popup_a33bbbb638f5f094a28419e434e03abd)
#         ;
#
#
#
#
#             var marker_79b5e739d2b12515bd92ed588ab97419 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c830aaa9dae77816b3d9bcdd680f923e);
#
#
#         var popup_7357b458e1e7cfa0aa65969fb17f2119 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6af70867b0fae51390f930d884ecd290 = $(`&lt;div id=&quot;html_6af70867b0fae51390f930d884ecd290&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7357b458e1e7cfa0aa65969fb17f2119.setContent(html_6af70867b0fae51390f930d884ecd290);
#
#
#
#         marker_79b5e739d2b12515bd92ed588ab97419.bindPopup(popup_7357b458e1e7cfa0aa65969fb17f2119)
#         ;
#
#
#
#
#             var marker_7d0f03b55e1248f2b43d4eaecd388ff2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c830aaa9dae77816b3d9bcdd680f923e);
#
#
#         var popup_0ccad859693c00d6cd9def5a87b2b70e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c880acc8c693177605d0c4995d90121 = $(`&lt;div id=&quot;html_9c880acc8c693177605d0c4995d90121&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0ccad859693c00d6cd9def5a87b2b70e.setContent(html_9c880acc8c693177605d0c4995d90121);
#
#
#
#         marker_7d0f03b55e1248f2b43d4eaecd388ff2.bindPopup(popup_0ccad859693c00d6cd9def5a87b2b70e)
#         ;
#
#
#
#
#             var marker_4f4461d91237c9ac2eb7c7d7187a1d38 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c830aaa9dae77816b3d9bcdd680f923e);
#
#
#         var popup_78ed744da14260e98604f48ae670ab80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_079a065e35f7a1790a04f2e09796c049 = $(`&lt;div id=&quot;html_079a065e35f7a1790a04f2e09796c049&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_78ed744da14260e98604f48ae670ab80.setContent(html_079a065e35f7a1790a04f2e09796c049);
#
#
#
#         marker_4f4461d91237c9ac2eb7c7d7187a1d38.bindPopup(popup_78ed744da14260e98604f48ae670ab80)
#         ;
#
#
#
#
#             var marker_4c733c92894b51cbc501d567fed62ea1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c830aaa9dae77816b3d9bcdd680f923e);
#
#
#         var popup_2d479c23183208be33c6f5139724a2f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b6442b9f06b9574f8dcc4bcd7575275 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b6442b9f06b9574f8dcc4bcd7575275&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b6442b9f06b9574f8dcc4bcd7575275 = L.map(
#                 &quot;map_4b6442b9f06b9574f8dcc4bcd7575275&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1312ab0b84065af24b32fec5752bf9cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1312ab0b84065af24b32fec5752bf9cd.addTo(map_4b6442b9f06b9574f8dcc4bcd7575275);
#
#
#             var feature_group_ac5728da8e712fa2ec80b7354e597c2e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ac5728da8e712fa2ec80b7354e597c2e.addTo(map_4b6442b9f06b9574f8dcc4bcd7575275);
#
#
#             var feature_group_sub_group_15f9961c7d20136bb2e5fe13ea667136 = L.featureGroup.subGroup(
#                 feature_group_ac5728da8e712fa2ec80b7354e597c2e
#             );
#
#
#             var marker_ef09681e9e1e38bf8f800945b6078cc2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_15f9961c7d20136bb2e5fe13ea667136);
#
#
#         var popup_1e60547e5aa6c0f7882a65fa205ba005 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2aef90aa66ac90ece0d9dda9039b957 = $(`&lt;div id=&quot;html_e2aef90aa66ac90ece0d9dda9039b957&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1e60547e5aa6c0f7882a65fa205ba005.setContent(html_e2aef90aa66ac90ece0d9dda9039b957);
#
#
#
#         marker_ef09681e9e1e38bf8f800945b6078cc2.bindPopup(popup_1e60547e5aa6c0f7882a65fa205ba005)
#         ;
#
#
#
#
#             var marker_eb7e4481c799c029edcca64aa840f095 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_15f9961c7d20136bb2e5fe13ea667136);
#
#
#         var popup_d82fbb565f3c2827b07ff82902e41bfc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4250a498f8c7c0f47c5d866208eed4f3 = $(`&lt;div id=&quot;html_4250a498f8c7c0f47c5d866208eed4f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d82fbb565f3c2827b07ff82902e41bfc.setContent(html_4250a498f8c7c0f47c5d866208eed4f3);
#
#
#
#         marker_eb7e4481c799c029edcca64aa840f095.bindPopup(popup_d82fbb565f3c2827b07ff82902e41bfc)
#         ;
#
#
#
#
#             var marker_76dccb8c773c3af651df1cb381698630 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_15f9961c7d20136bb2e5fe13ea667136);
#
#
#         var popup_9da7fa425aad182ea347cf887bb0df13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ea03cd21bd942ef823454d398e2887e = $(`&lt;div id=&quot;html_2ea03cd21bd942ef823454d398e2887e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9da7fa425aad182ea347cf887bb0df13.setContent(html_2ea03cd21bd942ef823454d398e2887e);
#
#
#
#         marker_76dccb8c773c3af651df1cb381698630.bindPopup(popup_9da7fa425aad182ea347cf887bb0df13)
#         ;
#
#
#
#
#             var marker_a8350ba5e04643fc71e61d0163a234e2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_15f9961c7d20136bb2e5fe13ea667136);
#
#
#         var popup_c8d9eeb135fae8bc6fea781f28b5549c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7f5b66f24591a90d2a9b2f37a6e2f0e = $(`&lt;div id=&quot;html_c7f5b66f24591a90d2a9b2f37a6e2f0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c8d9eeb135fae8bc6fea781f28b5549c.setContent(html_c7f5b66f24591a90d2a9b2f37a6e2f0e);
#
#
#
#         marker_
