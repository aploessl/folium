# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_149b415a4e732ff801ce79338a848159 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_149b415a4e732ff801ce79338a848159&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_149b415a4e732ff801ce79338a848159 = L.map(
#                 &quot;map_149b415a4e732ff801ce79338a848159&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_977f827b55a16e92fc9477be20e83f9f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_977f827b55a16e92fc9477be20e83f9f.addTo(map_149b415a4e732ff801ce79338a848159);
#
#
#             var marker_4d9338470e842396d16572c5f19beffd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_149b415a4e732ff801ce79338a848159);
#
#
#         var popup_cbfd43557eebb5efd9a4c1987ac32d49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c96644178f0e68121c9759019f6dc804 = $(`&lt;div id=&quot;html_c96644178f0e68121c9759019f6dc804&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_cbfd43557eebb5efd9a4c1987ac32d49.setContent(html_c96644178f0e68121c9759019f6dc804);
#
#
#
#         marker_4d9338470e842396d16572c5f19beffd.bindPopup(popup_cbfd43557eebb5efd9a4c1987ac32d49)
#         ;
#
#
#
#
#             var marker_ef35f59c1a5b6cb9f8be50de4de5559e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_149b415a4e732ff801ce79338a848159);
#
#
#         var popup_7cdc44c105ea98ee68931387cbab1762 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94fb6a183ca213bcbc45e15dee9b95b7 = $(`&lt;div id=&quot;html_94fb6a183ca213bcbc45e15dee9b95b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7cdc44c105ea98ee68931387cbab1762.setContent(html_94fb6a183ca213bcbc45e15dee9b95b7);
#
#
#
#         marker_ef35f59c1a5b6cb9f8be50de4de5559e.bindPopup(popup_7cdc44c105ea98ee68931387cbab1762)
#         ;
#
#
#
#
#             var marker_95abc8ab25271c8452704f580adfa390 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_149b415a4e732ff801ce79338a848159);
#
#
#         var popup_06476cc76a31883fa18390e1a44d98b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee1944c6d13feec0742d82e24bb4d424 = $(`&lt;div id=&quot;html_ee1944c6d13feec0742d82e24bb4d424&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_06476cc76a31883fa18390e1a44d98b0.setContent(html_ee1944c6d13feec0742d82e24bb4d424);
#
#
#
#         marker_95abc8ab25271c8452704f580adfa390.bindPopup(popup_06476cc76a31883fa18390e1a44d98b0)
#         ;
#
#
#
#
#             var marker_d9f84c1ce4190e1d4b9b417acf6adf0d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_149b415a4e732ff801ce79338a848159);
#
#
#         var popup_f35987b83e597b8c92e7169cee5e3e81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5f39487d951f46d1e2f60014b6ab16e = $(`&lt;div id=&quot;html_d5f39487d951f46d1e2f60014b6ab16e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f35987b83e597b8c92e7169cee5e3e81.setContent(html_d5f39487d951f46d1e2f60014b6ab16e);
#
#
#
#         marker_d9f84c1ce4190e1d4b9b417acf6adf0d.bindPopup(popup_f35987b83e597b8c92e7169cee5e3e81)
#         ;
#
#
#
#
#             var marker_4a92266e0d8fc2aacd677d1d6d4d9cb3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_149b415a4e732ff801ce79338a848159);
#
#
#         var popup_392edc637d335657f5accc931fa06ea3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5016da704af2ac45afa28b7a5abc9530 = $(`&lt;div id=&quot;html_5016da704af2ac45afa28b7a5abc9530&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_392edc637d335657f5accc931fa06ea3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee7f91e447c56776432485c98bff7ce5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee7f91e447c56776432485c98bff7ce5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee7f91e447c56776432485c98bff7ce5 = L.map(
#                 &quot;map_ee7f91e447c56776432485c98bff7ce5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_206862941d85dc0ce0d5bed74b99f3f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_206862941d85dc0ce0d5bed74b99f3f7.addTo(map_ee7f91e447c56776432485c98bff7ce5);
#
#
#             var feature_group_eefd8083192b6a370adb388317890acf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0283a71a3dbc5dc4e132b3ee25be6ec0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_eefd8083192b6a370adb388317890acf);
#
#
#         var popup_5391cd8f5592664a3d3d257272cedc32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38ea5666a0cee25151a0901afe90640e = $(`&lt;div id=&quot;html_38ea5666a0cee25151a0901afe90640e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5391cd8f5592664a3d3d257272cedc32.setContent(html_38ea5666a0cee25151a0901afe90640e);
#
#
#
#         marker_0283a71a3dbc5dc4e132b3ee25be6ec0.bindPopup(popup_5391cd8f5592664a3d3d257272cedc32)
#         ;
#
#
#
#
#             var marker_b9f125151ea106b3e610b47404a119eb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_eefd8083192b6a370adb388317890acf);
#
#
#         var popup_9dc850ab4cccce02e6137d2e79d96474 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e06d89d21b116a16c643b7c9fb6beea = $(`&lt;div id=&quot;html_3e06d89d21b116a16c643b7c9fb6beea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9dc850ab4cccce02e6137d2e79d96474.setContent(html_3e06d89d21b116a16c643b7c9fb6beea);
#
#
#
#         marker_b9f125151ea106b3e610b47404a119eb.bindPopup(popup_9dc850ab4cccce02e6137d2e79d96474)
#         ;
#
#
#
#
#             var marker_67c7a82cb2b761fe71063b59362d5a8a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_eefd8083192b6a370adb388317890acf);
#
#
#         var popup_4d248d7aeafd332f1793041ea322a129 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df990e5ce9654d724c5d2175eae7c119 = $(`&lt;div id=&quot;html_df990e5ce9654d724c5d2175eae7c119&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4d248d7aeafd332f1793041ea322a129.setContent(html_df990e5ce9654d724c5d2175eae7c119);
#
#
#
#         marker_67c7a82cb2b761fe71063b59362d5a8a.bindPopup(popup_4d248d7aeafd332f1793041ea322a129)
#         ;
#
#
#
#
#             var marker_fde5f95b8971596716712a6567ac556c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_eefd8083192b6a370adb388317890acf);
#
#
#         var popup_5ae8ef6f9b6da241ac8bdff0e93d5ff1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b825cc5a9ceb37002763281b02eec8ea = $(`&lt;div id=&quot;html_b825cc5a9ceb37002763281b02eec8ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5ae8ef6f9b6da241ac8bdff0e93d5ff1.setContent(html_b825cc5a9ceb37002763281b02eec8ea);
#
#
#
#         marker_fde5f95b8971596716712a6567ac556c.bindPopup(popup_5ae8ef6f9b6da241ac8bdff0e93d5ff1)
#         ;
#
#
#
#
#             var marker_16865e8760a53c9298af90190c373437 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_eefd8083192b6a370adb388317890acf);
#
#
#         var popup_405a5b9309b942e9221899d9d95f8944 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fa4bc7e010070789a34ea54898f8e55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fa4bc7e010070789a34ea54898f8e55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fa4bc7e010070789a34ea54898f8e55 = L.map(
#                 &quot;map_1fa4bc7e010070789a34ea54898f8e55&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5af24a62a490e7dcf8f954804e5b87d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5af24a62a490e7dcf8f954804e5b87d5.addTo(map_1fa4bc7e010070789a34ea54898f8e55);
#
#
#             var feature_group_14bca58d620317334c4dd8b10d8338e9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_14bca58d620317334c4dd8b10d8338e9.addTo(map_1fa4bc7e010070789a34ea54898f8e55);
#
#
#             var feature_group_sub_group_c39c58e3f64b5c9e9dba84b3c50d09cf = L.featureGroup.subGroup(
#                 feature_group_14bca58d620317334c4dd8b10d8338e9
#             );
#
#
#             var marker_5e7f72445d8fec4ba15381354b35ce1d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c39c58e3f64b5c9e9dba84b3c50d09cf);
#
#
#         var popup_a1ed6289d110b7f59292bec2a1e7c07f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_200a18ecac83e3ab3f084e4ba691af98 = $(`&lt;div id=&quot;html_200a18ecac83e3ab3f084e4ba691af98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a1ed6289d110b7f59292bec2a1e7c07f.setContent(html_200a18ecac83e3ab3f084e4ba691af98);
#
#
#
#         marker_5e7f72445d8fec4ba15381354b35ce1d.bindPopup(popup_a1ed6289d110b7f59292bec2a1e7c07f)
#         ;
#
#
#
#
#             var marker_b2aff79f00a00cc09325aaf531b1b690 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c39c58e3f64b5c9e9dba84b3c50d09cf);
#
#
#         var popup_9267afad1d14e6dde5b80f6992ae083b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03b000ccbe4b3965e13d92805e50965b = $(`&lt;div id=&quot;html_03b000ccbe4b3965e13d92805e50965b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9267afad1d14e6dde5b80f6992ae083b.setContent(html_03b000ccbe4b3965e13d92805e50965b);
#
#
#
#         marker_b2aff79f00a00cc09325aaf531b1b690.bindPopup(popup_9267afad1d14e6dde5b80f6992ae083b)
#         ;
#
#
#
#
#             var marker_9fa91063021f5cf1286106006208bfee = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c39c58e3f64b5c9e9dba84b3c50d09cf);
#
#
#         var popup_438d5a9811a14b5c90c82588495b3ec9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e3a8d11945eb23ba3fdda595be326b2 = $(`&lt;div id=&quot;html_4e3a8d11945eb23ba3fdda595be326b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_438d5a9811a14b5c90c82588495b3ec9.setContent(html_4e3a8d11945eb23ba3fdda595be326b2);
#
#
#
#         marker_9fa91063021f5cf1286106006208bfee.bindPopup(popup_438d5a9811a14b5c90c82588495b3ec9)
#         ;
#
#
#
#
#             var marker_9b3875cc722ebac72a2a922da79474f4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c39c58e3f64b5c9e9dba84b3c50d09cf);
#
#
#         var popup_a384b0dbef324478289851e69e56fa9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ae95594e049fac58b5d310e96ac5fbd = $(`&lt;div id=&quot;html_0ae95594e049fac58b5d310e96ac5fbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a384b0dbef324478289851e69e56fa9e.setContent(html_0ae95594e049fac58b5d310e96ac5fbd);
#
#
#
#         marker_
