# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba9cf873d396d280336e6e8c3eb4a7db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba9cf873d396d280336e6e8c3eb4a7db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba9cf873d396d280336e6e8c3eb4a7db = L.map(
#                 &quot;map_ba9cf873d396d280336e6e8c3eb4a7db&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2baa80b62f87f9c0c3ec91740c371d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2baa80b62f87f9c0c3ec91740c371d6.addTo(map_ba9cf873d396d280336e6e8c3eb4a7db);
#
#
#             var marker_5b9b7ff51f02f3d73ef22e1c82a3a166 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ba9cf873d396d280336e6e8c3eb4a7db);
#
#
#         var popup_2891e8381551dec68af582b11e3a1311 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fe66b9aaad573258af786f7471812f9 = $(`&lt;div id=&quot;html_9fe66b9aaad573258af786f7471812f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2891e8381551dec68af582b11e3a1311.setContent(html_9fe66b9aaad573258af786f7471812f9);
#
#
#
#         marker_5b9b7ff51f02f3d73ef22e1c82a3a166.bindPopup(popup_2891e8381551dec68af582b11e3a1311)
#         ;
#
#
#
#
#             var marker_faa675c750399b873a4f8dc4163ce135 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ba9cf873d396d280336e6e8c3eb4a7db);
#
#
#         var popup_f2b7e5d38b05d5c5bea8b0eb4645dc1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72e28d915bffb29e4778c3cc163b3d5b = $(`&lt;div id=&quot;html_72e28d915bffb29e4778c3cc163b3d5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f2b7e5d38b05d5c5bea8b0eb4645dc1c.setContent(html_72e28d915bffb29e4778c3cc163b3d5b);
#
#
#
#         marker_faa675c750399b873a4f8dc4163ce135.bindPopup(popup_f2b7e5d38b05d5c5bea8b0eb4645dc1c)
#         ;
#
#
#
#
#             var marker_f1fcda31f5c6adc79bc41754c6c78a76 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ba9cf873d396d280336e6e8c3eb4a7db);
#
#
#         var popup_5bd6a8e9e4a50158b404b72cdd2456af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38ac859b225c7e6624c3293556efbc73 = $(`&lt;div id=&quot;html_38ac859b225c7e6624c3293556efbc73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5bd6a8e9e4a50158b404b72cdd2456af.setContent(html_38ac859b225c7e6624c3293556efbc73);
#
#
#
#         marker_f1fcda31f5c6adc79bc41754c6c78a76.bindPopup(popup_5bd6a8e9e4a50158b404b72cdd2456af)
#         ;
#
#
#
#
#             var marker_6c5a425f399abba47a4fe66be813eda7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ba9cf873d396d280336e6e8c3eb4a7db);
#
#
#         var popup_35becd2988c46798eb1cc29b1b70991e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47914cfdeb491966c2e21426bc50579a = $(`&lt;div id=&quot;html_47914cfdeb491966c2e21426bc50579a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_35becd2988c46798eb1cc29b1b70991e.setContent(html_47914cfdeb491966c2e21426bc50579a);
#
#
#
#         marker_6c5a425f399abba47a4fe66be813eda7.bindPopup(popup_35becd2988c46798eb1cc29b1b70991e)
#         ;
#
#
#
#
#             var marker_9df0dbdfaf535db0e8769ed8fb36651b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ba9cf873d396d280336e6e8c3eb4a7db);
#
#
#         var popup_642f4864f04d0c2a63f22b9216828ae3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fb73ed223dad7069609c744c9e4bb85 = $(`&lt;div id=&quot;html_6fb73ed223dad7069609c744c9e4bb85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_642f4864f04d0c2a63f22b9216828ae3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e659a0fc83bee124c9e0ff9cdd1e4a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e659a0fc83bee124c9e0ff9cdd1e4a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e659a0fc83bee124c9e0ff9cdd1e4a2 = L.map(
#                 &quot;map_4e659a0fc83bee124c9e0ff9cdd1e4a2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0dbf1f73a6faac600c9278094a0854c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0dbf1f73a6faac600c9278094a0854c1.addTo(map_4e659a0fc83bee124c9e0ff9cdd1e4a2);
#
#
#             var feature_group_cb9aa4e9d6380a10347e89c3afb3d9d3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b2efe791bd48884286d972f976ee8e4d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cb9aa4e9d6380a10347e89c3afb3d9d3);
#
#
#         var popup_68a34cfc08bd489deabbe6f010d694f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0394abaee937dde522947ff4f5198e47 = $(`&lt;div id=&quot;html_0394abaee937dde522947ff4f5198e47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_68a34cfc08bd489deabbe6f010d694f3.setContent(html_0394abaee937dde522947ff4f5198e47);
#
#
#
#         marker_b2efe791bd48884286d972f976ee8e4d.bindPopup(popup_68a34cfc08bd489deabbe6f010d694f3)
#         ;
#
#
#
#
#             var marker_f3eed999f9e1f3894716362f69509a99 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cb9aa4e9d6380a10347e89c3afb3d9d3);
#
#
#         var popup_0e763b6da5e94a93ca725284f7981c36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d3f229f7af55fb03dff5861f43878c2 = $(`&lt;div id=&quot;html_3d3f229f7af55fb03dff5861f43878c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0e763b6da5e94a93ca725284f7981c36.setContent(html_3d3f229f7af55fb03dff5861f43878c2);
#
#
#
#         marker_f3eed999f9e1f3894716362f69509a99.bindPopup(popup_0e763b6da5e94a93ca725284f7981c36)
#         ;
#
#
#
#
#             var marker_a66dc43d3ff06a68201eca49557e0c97 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cb9aa4e9d6380a10347e89c3afb3d9d3);
#
#
#         var popup_bda603e1b912e5c9a63c83a647c8f327 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e7f7c6e69c9471de17018fecad507a0 = $(`&lt;div id=&quot;html_7e7f7c6e69c9471de17018fecad507a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bda603e1b912e5c9a63c83a647c8f327.setContent(html_7e7f7c6e69c9471de17018fecad507a0);
#
#
#
#         marker_a66dc43d3ff06a68201eca49557e0c97.bindPopup(popup_bda603e1b912e5c9a63c83a647c8f327)
#         ;
#
#
#
#
#             var marker_ee03ae90514db1c77d8a212ca22617ed = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cb9aa4e9d6380a10347e89c3afb3d9d3);
#
#
#         var popup_91d244afabe88574f7dc0b3dd17df804 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea07ec1effbd7b05f80147a8a46bba41 = $(`&lt;div id=&quot;html_ea07ec1effbd7b05f80147a8a46bba41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_91d244afabe88574f7dc0b3dd17df804.setContent(html_ea07ec1effbd7b05f80147a8a46bba41);
#
#
#
#         marker_ee03ae90514db1c77d8a212ca22617ed.bindPopup(popup_91d244afabe88574f7dc0b3dd17df804)
#         ;
#
#
#
#
#             var marker_de96282c3f2aaaf19591065d10c5718a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cb9aa4e9d6380a10347e89c3afb3d9d3);
#
#
#         var popup_07e5ff5d802ab1c005a1bd9d771a3502 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b8141adbc231294630bdf163c877b68 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b8141adbc231294630bdf163c877b68&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b8141adbc231294630bdf163c877b68 = L.map(
#                 &quot;map_2b8141adbc231294630bdf163c877b68&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36a53bea9632bb882007965a2ce0b920 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36a53bea9632bb882007965a2ce0b920.addTo(map_2b8141adbc231294630bdf163c877b68);
#
#
#             var feature_group_48521f07d48a2b0d437ec9f573e0b992 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_48521f07d48a2b0d437ec9f573e0b992.addTo(map_2b8141adbc231294630bdf163c877b68);
#
#
#             var feature_group_sub_group_bc4b871f54581d8f997d4653f96aa304 = L.featureGroup.subGroup(
#                 feature_group_48521f07d48a2b0d437ec9f573e0b992
#             );
#
#
#             var marker_c3bbc71d940cb5b8abce41dfdf172c9a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bc4b871f54581d8f997d4653f96aa304);
#
#
#         var popup_1ff005f6e7996e3b2ff0843ec9800944 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a91561fbf12506dd7283326dac7b2a5 = $(`&lt;div id=&quot;html_8a91561fbf12506dd7283326dac7b2a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1ff005f6e7996e3b2ff0843ec9800944.setContent(html_8a91561fbf12506dd7283326dac7b2a5);
#
#
#
#         marker_c3bbc71d940cb5b8abce41dfdf172c9a.bindPopup(popup_1ff005f6e7996e3b2ff0843ec9800944)
#         ;
#
#
#
#
#             var marker_cadcaae3e614a8aa09a821478475d659 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bc4b871f54581d8f997d4653f96aa304);
#
#
#         var popup_7237a5eec2790a05fe76a93ec6bb79a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_374780bb854bb031f97debb2a2856aeb = $(`&lt;div id=&quot;html_374780bb854bb031f97debb2a2856aeb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7237a5eec2790a05fe76a93ec6bb79a2.setContent(html_374780bb854bb031f97debb2a2856aeb);
#
#
#
#         marker_cadcaae3e614a8aa09a821478475d659.bindPopup(popup_7237a5eec2790a05fe76a93ec6bb79a2)
#         ;
#
#
#
#
#             var marker_b82b507afbbace14cf62566eb2f49a2d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bc4b871f54581d8f997d4653f96aa304);
#
#
#         var popup_727505c8520694ce3369221dd8c01de3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38e08d61c70ea18ac82842c05d24414f = $(`&lt;div id=&quot;html_38e08d61c70ea18ac82842c05d24414f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_727505c8520694ce3369221dd8c01de3.setContent(html_38e08d61c70ea18ac82842c05d24414f);
#
#
#
#         marker_b82b507afbbace14cf62566eb2f49a2d.bindPopup(popup_727505c8520694ce3369221dd8c01de3)
#         ;
#
#
#
#
#             var marker_ea1a46a4f6124fe5290be9793b0851dd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bc4b871f54581d8f997d4653f96aa304);
#
#
#         var popup_aec868b691f4b04d2be3ed4e76dde7d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_883ec7045dd8b1cf2e89af2ff6fca020 = $(`&lt;div id=&quot;html_883ec7045dd8b1cf2e89af2ff6fca020&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_aec868b691f4b04d2be3ed4e76dde7d8.setContent(html_883ec7045dd8b1cf2e89af2ff6fca020);
#
#
#
#         marker_
