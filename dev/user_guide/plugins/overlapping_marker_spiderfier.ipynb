# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c66cd9545dd34cbd1df74e3b6536873 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c66cd9545dd34cbd1df74e3b6536873&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c66cd9545dd34cbd1df74e3b6536873 = L.map(
#                 &quot;map_1c66cd9545dd34cbd1df74e3b6536873&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d749ef3b4c14bac20090b1131b2b242 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1d749ef3b4c14bac20090b1131b2b242.addTo(map_1c66cd9545dd34cbd1df74e3b6536873);
#
#
#             var marker_949ea476868fb28c0367ea8ce44faece = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1c66cd9545dd34cbd1df74e3b6536873);
#
#
#         var popup_06c4f1ca0f8e35ac695729ef9a5e5ae7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f777c91540326084c3b0073f697fd93d = $(`&lt;div id=&quot;html_f777c91540326084c3b0073f697fd93d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_06c4f1ca0f8e35ac695729ef9a5e5ae7.setContent(html_f777c91540326084c3b0073f697fd93d);
#
#
#
#         marker_949ea476868fb28c0367ea8ce44faece.bindPopup(popup_06c4f1ca0f8e35ac695729ef9a5e5ae7)
#         ;
#
#
#
#
#             var marker_f0f9160bbe8bfe91eae78841145d9f46 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1c66cd9545dd34cbd1df74e3b6536873);
#
#
#         var popup_453555b3d0158be74dbf017b086dee0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa91e07620a33405faf1cade4825c127 = $(`&lt;div id=&quot;html_aa91e07620a33405faf1cade4825c127&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_453555b3d0158be74dbf017b086dee0c.setContent(html_aa91e07620a33405faf1cade4825c127);
#
#
#
#         marker_f0f9160bbe8bfe91eae78841145d9f46.bindPopup(popup_453555b3d0158be74dbf017b086dee0c)
#         ;
#
#
#
#
#             var marker_0b35fe22cc6a95f08ff0dc536899bcab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1c66cd9545dd34cbd1df74e3b6536873);
#
#
#         var popup_be0b2d6969d939d538dcdd5ae71391e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac775f6ae7354e741bb13180016e1ee8 = $(`&lt;div id=&quot;html_ac775f6ae7354e741bb13180016e1ee8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_be0b2d6969d939d538dcdd5ae71391e3.setContent(html_ac775f6ae7354e741bb13180016e1ee8);
#
#
#
#         marker_0b35fe22cc6a95f08ff0dc536899bcab.bindPopup(popup_be0b2d6969d939d538dcdd5ae71391e3)
#         ;
#
#
#
#
#             var marker_a25232734a3108a520a65c8c653b605b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1c66cd9545dd34cbd1df74e3b6536873);
#
#
#         var popup_67b5acfa36f56a690561b44a1763db12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d8a117c4e929fb6bd3f96d33fba098e = $(`&lt;div id=&quot;html_1d8a117c4e929fb6bd3f96d33fba098e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_67b5acfa36f56a690561b44a1763db12.setContent(html_1d8a117c4e929fb6bd3f96d33fba098e);
#
#
#
#         marker_a25232734a3108a520a65c8c653b605b.bindPopup(popup_67b5acfa36f56a690561b44a1763db12)
#         ;
#
#
#
#
#             var marker_05d2b98d43e58ce752736c37b13d744e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1c66cd9545dd34cbd1df74e3b6536873);
#
#
#         var popup_9c5270aa6d287b5c3c09f868e830d72a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e5ded9b65f2130c287a5a541b375f28 = $(`&lt;div id=&quot;html_3e5ded9b65f2130c287a5a541b375f28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9c5270aa6d287b5c3c09f868e830d72a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6657b48e0581e44b9d458d9d1707320f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6657b48e0581e44b9d458d9d1707320f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6657b48e0581e44b9d458d9d1707320f = L.map(
#                 &quot;map_6657b48e0581e44b9d458d9d1707320f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f8306f16d6d947d9912a362bb2a5c16 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f8306f16d6d947d9912a362bb2a5c16.addTo(map_6657b48e0581e44b9d458d9d1707320f);
#
#
#             var feature_group_ba3d0b1d7c6351c535cb448747985412 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_14b851a0a611355f113151502327cfba = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ba3d0b1d7c6351c535cb448747985412);
#
#
#         var popup_decd0499ec9017645f53083e93f60c17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4036463adaa4ed035f526fd417b5acd0 = $(`&lt;div id=&quot;html_4036463adaa4ed035f526fd417b5acd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_decd0499ec9017645f53083e93f60c17.setContent(html_4036463adaa4ed035f526fd417b5acd0);
#
#
#
#         marker_14b851a0a611355f113151502327cfba.bindPopup(popup_decd0499ec9017645f53083e93f60c17)
#         ;
#
#
#
#
#             var marker_db2e69a2ebf70ee1e084c7410940d970 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ba3d0b1d7c6351c535cb448747985412);
#
#
#         var popup_01d168f81bcf52b85a6d7d09c466eef8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe4d0d641fdc90af0b7cdf87dcb1db4c = $(`&lt;div id=&quot;html_fe4d0d641fdc90af0b7cdf87dcb1db4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_01d168f81bcf52b85a6d7d09c466eef8.setContent(html_fe4d0d641fdc90af0b7cdf87dcb1db4c);
#
#
#
#         marker_db2e69a2ebf70ee1e084c7410940d970.bindPopup(popup_01d168f81bcf52b85a6d7d09c466eef8)
#         ;
#
#
#
#
#             var marker_b7ad3f28b10b8ba4f0e1ff8cccdc8b5c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ba3d0b1d7c6351c535cb448747985412);
#
#
#         var popup_52d8778daedeba31106169f3900dd002 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_815f1e037b5470213daf9339e3b04a20 = $(`&lt;div id=&quot;html_815f1e037b5470213daf9339e3b04a20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_52d8778daedeba31106169f3900dd002.setContent(html_815f1e037b5470213daf9339e3b04a20);
#
#
#
#         marker_b7ad3f28b10b8ba4f0e1ff8cccdc8b5c.bindPopup(popup_52d8778daedeba31106169f3900dd002)
#         ;
#
#
#
#
#             var marker_b7587e5daa2a9c655ce2cfe0c8b57b67 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ba3d0b1d7c6351c535cb448747985412);
#
#
#         var popup_7c302e8596672065d0733290e3d8b8c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14e16ff5d95d4b664320233e4a549d74 = $(`&lt;div id=&quot;html_14e16ff5d95d4b664320233e4a549d74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7c302e8596672065d0733290e3d8b8c5.setContent(html_14e16ff5d95d4b664320233e4a549d74);
#
#
#
#         marker_b7587e5daa2a9c655ce2cfe0c8b57b67.bindPopup(popup_7c302e8596672065d0733290e3d8b8c5)
#         ;
#
#
#
#
#             var marker_a63fe31069112b703654120f1e9dba85 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ba3d0b1d7c6351c535cb448747985412);
#
#
#         var popup_d848ce9d6180a91db256277e084c5190 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23303a46a84b17e8504591b006f60023 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23303a46a84b17e8504591b006f60023&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23303a46a84b17e8504591b006f60023 = L.map(
#                 &quot;map_23303a46a84b17e8504591b006f60023&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a87d475e2731a7492b64bcf8db42a37 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a87d475e2731a7492b64bcf8db42a37.addTo(map_23303a46a84b17e8504591b006f60023);
#
#
#             var feature_group_af64d9a3382cbdb7168e639b27d2de78 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_af64d9a3382cbdb7168e639b27d2de78.addTo(map_23303a46a84b17e8504591b006f60023);
#
#
#             var feature_group_sub_group_fd1f16a8ef615ac045e11733297f6d81 = L.featureGroup.subGroup(
#                 feature_group_af64d9a3382cbdb7168e639b27d2de78
#             );
#
#
#             var marker_4f099e51afcae6c4278c4b70e7e3b367 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd1f16a8ef615ac045e11733297f6d81);
#
#
#         var popup_5d46dec631a0b9e6d98f6d2cfff9bbea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11de4e669e161a3f667bb6129a2d45ae = $(`&lt;div id=&quot;html_11de4e669e161a3f667bb6129a2d45ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5d46dec631a0b9e6d98f6d2cfff9bbea.setContent(html_11de4e669e161a3f667bb6129a2d45ae);
#
#
#
#         marker_4f099e51afcae6c4278c4b70e7e3b367.bindPopup(popup_5d46dec631a0b9e6d98f6d2cfff9bbea)
#         ;
#
#
#
#
#             var marker_3d421951011a010fbfaa17e617caad43 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd1f16a8ef615ac045e11733297f6d81);
#
#
#         var popup_add48b6579d7072c351040250a2137ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bc5f563ed16643c487d58374365df27 = $(`&lt;div id=&quot;html_8bc5f563ed16643c487d58374365df27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_add48b6579d7072c351040250a2137ba.setContent(html_8bc5f563ed16643c487d58374365df27);
#
#
#
#         marker_3d421951011a010fbfaa17e617caad43.bindPopup(popup_add48b6579d7072c351040250a2137ba)
#         ;
#
#
#
#
#             var marker_251a67d630c86c886f501ded7f5823f5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd1f16a8ef615ac045e11733297f6d81);
#
#
#         var popup_3f2b00f791b9ce42ad9886f32d79ff7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9e6daf3940dc6965fcd435ae065ffd7 = $(`&lt;div id=&quot;html_a9e6daf3940dc6965fcd435ae065ffd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3f2b00f791b9ce42ad9886f32d79ff7a.setContent(html_a9e6daf3940dc6965fcd435ae065ffd7);
#
#
#
#         marker_251a67d630c86c886f501ded7f5823f5.bindPopup(popup_3f2b00f791b9ce42ad9886f32d79ff7a)
#         ;
#
#
#
#
#             var marker_10c93b0d3958f9b55c8c5220da66fe4f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd1f16a8ef615ac045e11733297f6d81);
#
#
#         var popup_2dab47334df9b5343d61faed505c2db3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3adc1a523d1953468fbae663de8d178f = $(`&lt;div id=&quot;html_3adc1a523d1953468fbae663de8d178f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2dab47334df9b5343d61faed505c2db3.setContent(html_3adc1a523d1953468fbae663de8d178f);
#
#
#
#         marker_
