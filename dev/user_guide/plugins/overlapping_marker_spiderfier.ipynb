# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_602da80b305b868995c1430012f7c3c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_602da80b305b868995c1430012f7c3c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_602da80b305b868995c1430012f7c3c3 = L.map(
#                 &quot;map_602da80b305b868995c1430012f7c3c3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_25949c19361b16999acc2867895a7e22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_25949c19361b16999acc2867895a7e22.addTo(map_602da80b305b868995c1430012f7c3c3);
#
#
#             var marker_e1e8f3b98e615091a6e18180382b8544 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_602da80b305b868995c1430012f7c3c3);
#
#
#         var popup_a679b2005c984b4197bb826e949f2c5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afab48a52c673381748bba10d088794e = $(`&lt;div id=&quot;html_afab48a52c673381748bba10d088794e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a679b2005c984b4197bb826e949f2c5d.setContent(html_afab48a52c673381748bba10d088794e);
#
#
#
#         marker_e1e8f3b98e615091a6e18180382b8544.bindPopup(popup_a679b2005c984b4197bb826e949f2c5d)
#         ;
#
#
#
#
#             var marker_4460a5facf1b5f7f39bf5dadc568f556 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_602da80b305b868995c1430012f7c3c3);
#
#
#         var popup_f599e1462f1845a30f85c3cb14af3ea9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94a171050416fd0b4da2aaee7adf4692 = $(`&lt;div id=&quot;html_94a171050416fd0b4da2aaee7adf4692&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f599e1462f1845a30f85c3cb14af3ea9.setContent(html_94a171050416fd0b4da2aaee7adf4692);
#
#
#
#         marker_4460a5facf1b5f7f39bf5dadc568f556.bindPopup(popup_f599e1462f1845a30f85c3cb14af3ea9)
#         ;
#
#
#
#
#             var marker_5235a1acdf530416f986667aebc382df = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_602da80b305b868995c1430012f7c3c3);
#
#
#         var popup_355e813b3abcfd3fdfa6ca70ef354d53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34c1f95d97411210950a1aef15ae0e89 = $(`&lt;div id=&quot;html_34c1f95d97411210950a1aef15ae0e89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_355e813b3abcfd3fdfa6ca70ef354d53.setContent(html_34c1f95d97411210950a1aef15ae0e89);
#
#
#
#         marker_5235a1acdf530416f986667aebc382df.bindPopup(popup_355e813b3abcfd3fdfa6ca70ef354d53)
#         ;
#
#
#
#
#             var marker_5592856cce1500b6bf40ad22baef14f1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_602da80b305b868995c1430012f7c3c3);
#
#
#         var popup_3425d99a60b0bea92595e320019b6c01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3767275a4d52d9720109c4c318f48865 = $(`&lt;div id=&quot;html_3767275a4d52d9720109c4c318f48865&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3425d99a60b0bea92595e320019b6c01.setContent(html_3767275a4d52d9720109c4c318f48865);
#
#
#
#         marker_5592856cce1500b6bf40ad22baef14f1.bindPopup(popup_3425d99a60b0bea92595e320019b6c01)
#         ;
#
#
#
#
#             var marker_6ce3763152d0dd8ffbb3259ea4ff41be = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_602da80b305b868995c1430012f7c3c3);
#
#
#         var popup_5630cf38ce6f9183dea2b7cb96077dff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccd121ecb17323454dc4cb23d20d161d = $(`&lt;div id=&quot;html_ccd121ecb17323454dc4cb23d20d161d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5630cf38ce6f9183dea2b7cb96077dff.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6f348aff2ebf71cf8714766bd95effa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6f348aff2ebf71cf8714766bd95effa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6f348aff2ebf71cf8714766bd95effa = L.map(
#                 &quot;map_d6f348aff2ebf71cf8714766bd95effa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0082da76c50e844b52c24745751ea091 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0082da76c50e844b52c24745751ea091.addTo(map_d6f348aff2ebf71cf8714766bd95effa);
#
#
#             var feature_group_88e9b3337c704169050e26feb200e209 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3d1da78c72416e55bc6038a5d0e23dac = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_88e9b3337c704169050e26feb200e209);
#
#
#         var popup_f6936621803a78a66b33ae4b5c93b9b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_803849e2772db420e0756e903e67a19d = $(`&lt;div id=&quot;html_803849e2772db420e0756e903e67a19d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f6936621803a78a66b33ae4b5c93b9b4.setContent(html_803849e2772db420e0756e903e67a19d);
#
#
#
#         marker_3d1da78c72416e55bc6038a5d0e23dac.bindPopup(popup_f6936621803a78a66b33ae4b5c93b9b4)
#         ;
#
#
#
#
#             var marker_44c9e9b04a288b76d1a6de67ef506f0d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_88e9b3337c704169050e26feb200e209);
#
#
#         var popup_dc03984e0c526832b65a82b81d4fe9b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecf9ea9ef67d291882ebe3be5c7067c1 = $(`&lt;div id=&quot;html_ecf9ea9ef67d291882ebe3be5c7067c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_dc03984e0c526832b65a82b81d4fe9b9.setContent(html_ecf9ea9ef67d291882ebe3be5c7067c1);
#
#
#
#         marker_44c9e9b04a288b76d1a6de67ef506f0d.bindPopup(popup_dc03984e0c526832b65a82b81d4fe9b9)
#         ;
#
#
#
#
#             var marker_e97b0c4f421e8b7948f961bc0f08e2f3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_88e9b3337c704169050e26feb200e209);
#
#
#         var popup_413858929c59515b2524817683f2202a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f7289a57e3ef25ee17b383d1c7b4954 = $(`&lt;div id=&quot;html_4f7289a57e3ef25ee17b383d1c7b4954&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_413858929c59515b2524817683f2202a.setContent(html_4f7289a57e3ef25ee17b383d1c7b4954);
#
#
#
#         marker_e97b0c4f421e8b7948f961bc0f08e2f3.bindPopup(popup_413858929c59515b2524817683f2202a)
#         ;
#
#
#
#
#             var marker_a4d7a1e9e05fc7e4a5ef1e83c6650341 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_88e9b3337c704169050e26feb200e209);
#
#
#         var popup_d2304c901f27583908fdcf4487076d57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bad10216d8fecffb6fd3098996cfd504 = $(`&lt;div id=&quot;html_bad10216d8fecffb6fd3098996cfd504&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d2304c901f27583908fdcf4487076d57.setContent(html_bad10216d8fecffb6fd3098996cfd504);
#
#
#
#         marker_a4d7a1e9e05fc7e4a5ef1e83c6650341.bindPopup(popup_d2304c901f27583908fdcf4487076d57)
#         ;
#
#
#
#
#             var marker_280970cf715832104a3bad8955b9c42e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_88e9b3337c704169050e26feb200e209);
#
#
#         var popup_545e50cf4ebcb2a9eacd951a600a11a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40fa9cb6b55c7c797a2855e906add124 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40fa9cb6b55c7c797a2855e906add124&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40fa9cb6b55c7c797a2855e906add124 = L.map(
#                 &quot;map_40fa9cb6b55c7c797a2855e906add124&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea28981d56509af73ae87df3932a00dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea28981d56509af73ae87df3932a00dd.addTo(map_40fa9cb6b55c7c797a2855e906add124);
#
#
#             var feature_group_dbd81065a84c295aa9e75111b5f431f6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dbd81065a84c295aa9e75111b5f431f6.addTo(map_40fa9cb6b55c7c797a2855e906add124);
#
#
#             var feature_group_sub_group_88cb0f7465e53324817e79b5b92ee300 = L.featureGroup.subGroup(
#                 feature_group_dbd81065a84c295aa9e75111b5f431f6
#             );
#
#
#             var marker_b1fc3fcd00b5d8c541567005435dd9db = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_88cb0f7465e53324817e79b5b92ee300);
#
#
#         var popup_f6665af0e94f6bf26496dff5da82706e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7228512a0bd986883667f1286f32d5e = $(`&lt;div id=&quot;html_e7228512a0bd986883667f1286f32d5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f6665af0e94f6bf26496dff5da82706e.setContent(html_e7228512a0bd986883667f1286f32d5e);
#
#
#
#         marker_b1fc3fcd00b5d8c541567005435dd9db.bindPopup(popup_f6665af0e94f6bf26496dff5da82706e)
#         ;
#
#
#
#
#             var marker_35a0232bc676aa6246a055d0438ed2c3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_88cb0f7465e53324817e79b5b92ee300);
#
#
#         var popup_db524f289c85207892321de2f0c494ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d04241274d22f1ded52c816c28210b68 = $(`&lt;div id=&quot;html_d04241274d22f1ded52c816c28210b68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_db524f289c85207892321de2f0c494ae.setContent(html_d04241274d22f1ded52c816c28210b68);
#
#
#
#         marker_35a0232bc676aa6246a055d0438ed2c3.bindPopup(popup_db524f289c85207892321de2f0c494ae)
#         ;
#
#
#
#
#             var marker_922aaeaa8d64806a97b54026db6a1025 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_88cb0f7465e53324817e79b5b92ee300);
#
#
#         var popup_b4b5b6570666053b5fcd0cef9d75e466 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af078d639ada0afa1adc14329635f1fd = $(`&lt;div id=&quot;html_af078d639ada0afa1adc14329635f1fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b4b5b6570666053b5fcd0cef9d75e466.setContent(html_af078d639ada0afa1adc14329635f1fd);
#
#
#
#         marker_922aaeaa8d64806a97b54026db6a1025.bindPopup(popup_b4b5b6570666053b5fcd0cef9d75e466)
#         ;
#
#
#
#
#             var marker_32206968477422a10e5d23006e2ad97f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_88cb0f7465e53324817e79b5b92ee300);
#
#
#         var popup_5e4eb170bb9addfd2bc63698b2f01eab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd7e355684b6820da48da2e9164901cd = $(`&lt;div id=&quot;html_bd7e355684b6820da48da2e9164901cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5e4eb170bb9addfd2bc63698b2f01eab.setContent(html_bd7e355684b6820da48da2e9164901cd);
#
#
#
#         marker_
