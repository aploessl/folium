# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc1798c7d9220d3686ffa972e50249ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc1798c7d9220d3686ffa972e50249ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc1798c7d9220d3686ffa972e50249ef = L.map(
#                 &quot;map_bc1798c7d9220d3686ffa972e50249ef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_515b23ce7d5852690f1af1c1d9d88374 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_515b23ce7d5852690f1af1c1d9d88374.addTo(map_bc1798c7d9220d3686ffa972e50249ef);
#
#
#             var marker_e5ea3a3f5928d93b7675e323ed83fae6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bc1798c7d9220d3686ffa972e50249ef);
#
#
#         var popup_69bb0ad6f49d7f66332d040f695f0eb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a5eb7eede8cbf4d20d669a52d37634f = $(`&lt;div id=&quot;html_4a5eb7eede8cbf4d20d669a52d37634f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_69bb0ad6f49d7f66332d040f695f0eb7.setContent(html_4a5eb7eede8cbf4d20d669a52d37634f);
#
#
#
#         marker_e5ea3a3f5928d93b7675e323ed83fae6.bindPopup(popup_69bb0ad6f49d7f66332d040f695f0eb7)
#         ;
#
#
#
#
#             var marker_50d0da38fa8865a0b5b00efe242f476f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bc1798c7d9220d3686ffa972e50249ef);
#
#
#         var popup_4fa03c57b9744c49cf204a3b9d572bc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8893e666ad08e4eb40c8c95a68ac3e9d = $(`&lt;div id=&quot;html_8893e666ad08e4eb40c8c95a68ac3e9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4fa03c57b9744c49cf204a3b9d572bc2.setContent(html_8893e666ad08e4eb40c8c95a68ac3e9d);
#
#
#
#         marker_50d0da38fa8865a0b5b00efe242f476f.bindPopup(popup_4fa03c57b9744c49cf204a3b9d572bc2)
#         ;
#
#
#
#
#             var marker_affe799aafae2d171af13794280c086f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bc1798c7d9220d3686ffa972e50249ef);
#
#
#         var popup_caa00e8ab08e8c1545e76bdfcded8333 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2392dd97aabd388bf44dbee5638aa23e = $(`&lt;div id=&quot;html_2392dd97aabd388bf44dbee5638aa23e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_caa00e8ab08e8c1545e76bdfcded8333.setContent(html_2392dd97aabd388bf44dbee5638aa23e);
#
#
#
#         marker_affe799aafae2d171af13794280c086f.bindPopup(popup_caa00e8ab08e8c1545e76bdfcded8333)
#         ;
#
#
#
#
#             var marker_aac709095070920c10e56776bd4f140c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bc1798c7d9220d3686ffa972e50249ef);
#
#
#         var popup_d84cd27d7303756fb38d3dca23822e95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_734fe427be994b109e5938a480539cac = $(`&lt;div id=&quot;html_734fe427be994b109e5938a480539cac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d84cd27d7303756fb38d3dca23822e95.setContent(html_734fe427be994b109e5938a480539cac);
#
#
#
#         marker_aac709095070920c10e56776bd4f140c.bindPopup(popup_d84cd27d7303756fb38d3dca23822e95)
#         ;
#
#
#
#
#             var marker_37f2bde9db405fd4504c45fd6fd2f8c8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bc1798c7d9220d3686ffa972e50249ef);
#
#
#         var popup_4758790a8f67cd17c27567c3e176c13e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_347b9d9cde667e57efcdbff53bc13d97 = $(`&lt;div id=&quot;html_347b9d9cde667e57efcdbff53bc13d97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4758790a8f67cd17c27567c3e176c13e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e01e342edebf728cf879c9e95b297045 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e01e342edebf728cf879c9e95b297045&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e01e342edebf728cf879c9e95b297045 = L.map(
#                 &quot;map_e01e342edebf728cf879c9e95b297045&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e857fae08282ad3bf06fd76ea900485e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e857fae08282ad3bf06fd76ea900485e.addTo(map_e01e342edebf728cf879c9e95b297045);
#
#
#             var feature_group_be28af2794cd4757452125f13c7cec91 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_00fafe376f38f5a1322477cbdac6a8bd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_be28af2794cd4757452125f13c7cec91);
#
#
#         var popup_ca36741e424e5057002a915d45c4f7fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cff8d9ccc49729ef8f06f291c7d7db46 = $(`&lt;div id=&quot;html_cff8d9ccc49729ef8f06f291c7d7db46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ca36741e424e5057002a915d45c4f7fc.setContent(html_cff8d9ccc49729ef8f06f291c7d7db46);
#
#
#
#         marker_00fafe376f38f5a1322477cbdac6a8bd.bindPopup(popup_ca36741e424e5057002a915d45c4f7fc)
#         ;
#
#
#
#
#             var marker_eef44d901d680993342e64fd1203b459 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_be28af2794cd4757452125f13c7cec91);
#
#
#         var popup_216ce3348ce6eafd0f51cbba949b2e66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbdc35c1bbd2a6dbd66fa2210f59986a = $(`&lt;div id=&quot;html_bbdc35c1bbd2a6dbd66fa2210f59986a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_216ce3348ce6eafd0f51cbba949b2e66.setContent(html_bbdc35c1bbd2a6dbd66fa2210f59986a);
#
#
#
#         marker_eef44d901d680993342e64fd1203b459.bindPopup(popup_216ce3348ce6eafd0f51cbba949b2e66)
#         ;
#
#
#
#
#             var marker_d4275ab7234f416007772b3706dd3d5a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_be28af2794cd4757452125f13c7cec91);
#
#
#         var popup_82f18e988fe416d8b1ada1d5a7ce836f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_829bb8a999a966adc785ec356b43ce52 = $(`&lt;div id=&quot;html_829bb8a999a966adc785ec356b43ce52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_82f18e988fe416d8b1ada1d5a7ce836f.setContent(html_829bb8a999a966adc785ec356b43ce52);
#
#
#
#         marker_d4275ab7234f416007772b3706dd3d5a.bindPopup(popup_82f18e988fe416d8b1ada1d5a7ce836f)
#         ;
#
#
#
#
#             var marker_acf737536119f05c037d3ceb7f015ea2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_be28af2794cd4757452125f13c7cec91);
#
#
#         var popup_5ffed8fcff7b60d8f5e61b581d8d58d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce9bbeadf9ea50da6792e1ca1c24f380 = $(`&lt;div id=&quot;html_ce9bbeadf9ea50da6792e1ca1c24f380&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5ffed8fcff7b60d8f5e61b581d8d58d6.setContent(html_ce9bbeadf9ea50da6792e1ca1c24f380);
#
#
#
#         marker_acf737536119f05c037d3ceb7f015ea2.bindPopup(popup_5ffed8fcff7b60d8f5e61b581d8d58d6)
#         ;
#
#
#
#
#             var marker_09e733981a65ccca30df6375d68d1170 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_be28af2794cd4757452125f13c7cec91);
#
#
#         var popup_64e9052624625e532e5b6aaa2090fa1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1c67d00b814d2dbb74e869c656dfb65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1c67d00b814d2dbb74e869c656dfb65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1c67d00b814d2dbb74e869c656dfb65 = L.map(
#                 &quot;map_c1c67d00b814d2dbb74e869c656dfb65&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01cf1783794639831b05f6a9e1e0107f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_01cf1783794639831b05f6a9e1e0107f.addTo(map_c1c67d00b814d2dbb74e869c656dfb65);
#
#
#             var feature_group_8de72f1f8b4abee67b87dd56eff28c9f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8de72f1f8b4abee67b87dd56eff28c9f.addTo(map_c1c67d00b814d2dbb74e869c656dfb65);
#
#
#             var feature_group_sub_group_c638d76c61d4275a6d03b82a98f54b71 = L.featureGroup.subGroup(
#                 feature_group_8de72f1f8b4abee67b87dd56eff28c9f
#             );
#
#
#             var marker_a51cf3ff02879f40a057e27e71806762 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c638d76c61d4275a6d03b82a98f54b71);
#
#
#         var popup_c568756a72c033a2ed8b02f652df5231 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cd350d72b3217ca9a4814e5f1cec1f6 = $(`&lt;div id=&quot;html_7cd350d72b3217ca9a4814e5f1cec1f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c568756a72c033a2ed8b02f652df5231.setContent(html_7cd350d72b3217ca9a4814e5f1cec1f6);
#
#
#
#         marker_a51cf3ff02879f40a057e27e71806762.bindPopup(popup_c568756a72c033a2ed8b02f652df5231)
#         ;
#
#
#
#
#             var marker_81eef9f348ba685731b96d9516dad74a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c638d76c61d4275a6d03b82a98f54b71);
#
#
#         var popup_a1ed8eb22e63c1e565d77989733fcfc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69e2916690c3f30b810bd6e012937fe0 = $(`&lt;div id=&quot;html_69e2916690c3f30b810bd6e012937fe0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a1ed8eb22e63c1e565d77989733fcfc5.setContent(html_69e2916690c3f30b810bd6e012937fe0);
#
#
#
#         marker_81eef9f348ba685731b96d9516dad74a.bindPopup(popup_a1ed8eb22e63c1e565d77989733fcfc5)
#         ;
#
#
#
#
#             var marker_c1b5f48b6ea7b43c435da6a05aaedb90 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c638d76c61d4275a6d03b82a98f54b71);
#
#
#         var popup_f5bac2f1d3358c399f0d6106e339bf6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_357aeb9d00b0887c60cf7858fa9c3284 = $(`&lt;div id=&quot;html_357aeb9d00b0887c60cf7858fa9c3284&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f5bac2f1d3358c399f0d6106e339bf6e.setContent(html_357aeb9d00b0887c60cf7858fa9c3284);
#
#
#
#         marker_c1b5f48b6ea7b43c435da6a05aaedb90.bindPopup(popup_f5bac2f1d3358c399f0d6106e339bf6e)
#         ;
#
#
#
#
#             var marker_928832922aa3855d51f095b8f3bbf094 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c638d76c61d4275a6d03b82a98f54b71);
#
#
#         var popup_2fa2e6a0161835dc6422ea092e7363e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac08a6a78de11d795ebc41313385d960 = $(`&lt;div id=&quot;html_ac08a6a78de11d795ebc41313385d960&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2fa2e6a0161835dc6422ea092e7363e1.setContent(html_ac08a6a78de11d795ebc41313385d960);
#
#
#
#         marker_
