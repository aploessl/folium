# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7c4a20f8216194833f35e7878cb1237 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7c4a20f8216194833f35e7878cb1237&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7c4a20f8216194833f35e7878cb1237 = L.map(
#                 &quot;map_f7c4a20f8216194833f35e7878cb1237&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3439c308e869b6bc239dc66acc8eb206 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3439c308e869b6bc239dc66acc8eb206.addTo(map_f7c4a20f8216194833f35e7878cb1237);
#
#
#             var marker_0c63fe1b4ee06f9b1664a997618455a4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f7c4a20f8216194833f35e7878cb1237);
#
#
#         var popup_6de013fc842da0896b3798587a2027a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_856c279e4d4bfffbfadf2aba03150e06 = $(`&lt;div id=&quot;html_856c279e4d4bfffbfadf2aba03150e06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6de013fc842da0896b3798587a2027a6.setContent(html_856c279e4d4bfffbfadf2aba03150e06);
#
#
#
#         marker_0c63fe1b4ee06f9b1664a997618455a4.bindPopup(popup_6de013fc842da0896b3798587a2027a6)
#         ;
#
#
#
#
#             var marker_c8a81be57a0b11d8213daadd510f6b2d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f7c4a20f8216194833f35e7878cb1237);
#
#
#         var popup_cf4a4104d745686140e3c32d86fac03f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1221773b776a63a572da04d0ad4b46b3 = $(`&lt;div id=&quot;html_1221773b776a63a572da04d0ad4b46b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cf4a4104d745686140e3c32d86fac03f.setContent(html_1221773b776a63a572da04d0ad4b46b3);
#
#
#
#         marker_c8a81be57a0b11d8213daadd510f6b2d.bindPopup(popup_cf4a4104d745686140e3c32d86fac03f)
#         ;
#
#
#
#
#             var marker_87d51a697a433315d9e585a6fc6026c9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f7c4a20f8216194833f35e7878cb1237);
#
#
#         var popup_510748ce9566ab7b4e73626785f78578 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f72d7a6704b403488fdd433a41b4967a = $(`&lt;div id=&quot;html_f72d7a6704b403488fdd433a41b4967a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_510748ce9566ab7b4e73626785f78578.setContent(html_f72d7a6704b403488fdd433a41b4967a);
#
#
#
#         marker_87d51a697a433315d9e585a6fc6026c9.bindPopup(popup_510748ce9566ab7b4e73626785f78578)
#         ;
#
#
#
#
#             var marker_84d12704e4283e1af6c04307c496a2c1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f7c4a20f8216194833f35e7878cb1237);
#
#
#         var popup_170afeb5391dbe42d94d9cf06c16dbe4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7ebe77d09f277cd741d625aadfa8b6f = $(`&lt;div id=&quot;html_e7ebe77d09f277cd741d625aadfa8b6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_170afeb5391dbe42d94d9cf06c16dbe4.setContent(html_e7ebe77d09f277cd741d625aadfa8b6f);
#
#
#
#         marker_84d12704e4283e1af6c04307c496a2c1.bindPopup(popup_170afeb5391dbe42d94d9cf06c16dbe4)
#         ;
#
#
#
#
#             var marker_3e72a3cbdfa82f94a1bd0159172bbe07 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f7c4a20f8216194833f35e7878cb1237);
#
#
#         var popup_94a23ccdd5bb6d3e295cf7899e39bab3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_806eb01527af3ecd7a9cdbccdeed7bff = $(`&lt;div id=&quot;html_806eb01527af3ecd7a9cdbccdeed7bff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_94a23ccdd5bb6d3e295cf7899e39bab3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_173af36e36440aa49dac013b4485416a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_173af36e36440aa49dac013b4485416a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_173af36e36440aa49dac013b4485416a = L.map(
#                 &quot;map_173af36e36440aa49dac013b4485416a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_601209ec5912be5cd377c23656ccf3a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_601209ec5912be5cd377c23656ccf3a2.addTo(map_173af36e36440aa49dac013b4485416a);
#
#
#             var feature_group_691312c3734671295be1e9a22acc964f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1f86b45356ca995d5f14d7dc954339ed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_691312c3734671295be1e9a22acc964f);
#
#
#         var popup_13071c7a182af621a74d02b80269e046 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cec784c3d9eea516393405b1cc87e31 = $(`&lt;div id=&quot;html_6cec784c3d9eea516393405b1cc87e31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_13071c7a182af621a74d02b80269e046.setContent(html_6cec784c3d9eea516393405b1cc87e31);
#
#
#
#         marker_1f86b45356ca995d5f14d7dc954339ed.bindPopup(popup_13071c7a182af621a74d02b80269e046)
#         ;
#
#
#
#
#             var marker_cd7a477ffc240f46b8a4d67d096f1d31 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_691312c3734671295be1e9a22acc964f);
#
#
#         var popup_61f2916e952c3024c27baca5760925e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbef36361afa6636a7615b1b2f750a04 = $(`&lt;div id=&quot;html_dbef36361afa6636a7615b1b2f750a04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_61f2916e952c3024c27baca5760925e8.setContent(html_dbef36361afa6636a7615b1b2f750a04);
#
#
#
#         marker_cd7a477ffc240f46b8a4d67d096f1d31.bindPopup(popup_61f2916e952c3024c27baca5760925e8)
#         ;
#
#
#
#
#             var marker_759454a37cfd7a1831ba96c161b6ab94 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_691312c3734671295be1e9a22acc964f);
#
#
#         var popup_d4eaf060aabf85654264a2ea9bfb48e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6099a3b7b8bed51575f3f10ae9074570 = $(`&lt;div id=&quot;html_6099a3b7b8bed51575f3f10ae9074570&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d4eaf060aabf85654264a2ea9bfb48e9.setContent(html_6099a3b7b8bed51575f3f10ae9074570);
#
#
#
#         marker_759454a37cfd7a1831ba96c161b6ab94.bindPopup(popup_d4eaf060aabf85654264a2ea9bfb48e9)
#         ;
#
#
#
#
#             var marker_0a02a03552e1c7ffe4638a2eef458b53 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_691312c3734671295be1e9a22acc964f);
#
#
#         var popup_3618fc4a81bc3c68fe361ace44a21c59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_790c70b77836f5c4de9ec26874a46250 = $(`&lt;div id=&quot;html_790c70b77836f5c4de9ec26874a46250&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3618fc4a81bc3c68fe361ace44a21c59.setContent(html_790c70b77836f5c4de9ec26874a46250);
#
#
#
#         marker_0a02a03552e1c7ffe4638a2eef458b53.bindPopup(popup_3618fc4a81bc3c68fe361ace44a21c59)
#         ;
#
#
#
#
#             var marker_300d1195fc1742a5c9ebdf6c3f580021 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_691312c3734671295be1e9a22acc964f);
#
#
#         var popup_caac5333ed60364fa15c61f3cf946e4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_965e783a1800e1c77635b1966b61cb41 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_965e783a1800e1c77635b1966b61cb41&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_965e783a1800e1c77635b1966b61cb41 = L.map(
#                 &quot;map_965e783a1800e1c77635b1966b61cb41&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4bf689305cae9dd3489debf05e5b9126 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4bf689305cae9dd3489debf05e5b9126.addTo(map_965e783a1800e1c77635b1966b61cb41);
#
#
#             var feature_group_b713dabc4a86560bfbe1c20ecd577d7d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b713dabc4a86560bfbe1c20ecd577d7d.addTo(map_965e783a1800e1c77635b1966b61cb41);
#
#
#             var feature_group_sub_group_37ba2de35ac6e4e74d0686bf8c71b549 = L.featureGroup.subGroup(
#                 feature_group_b713dabc4a86560bfbe1c20ecd577d7d
#             );
#
#
#             var marker_2e18479cf51c0491b4a4cc42e96cfa2f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_37ba2de35ac6e4e74d0686bf8c71b549);
#
#
#         var popup_c7c98540ad0b7bb6178a8abe721afa40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06cd94ff2fd42a01e9b10148867e9e46 = $(`&lt;div id=&quot;html_06cd94ff2fd42a01e9b10148867e9e46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c7c98540ad0b7bb6178a8abe721afa40.setContent(html_06cd94ff2fd42a01e9b10148867e9e46);
#
#
#
#         marker_2e18479cf51c0491b4a4cc42e96cfa2f.bindPopup(popup_c7c98540ad0b7bb6178a8abe721afa40)
#         ;
#
#
#
#
#             var marker_a2b9a9564b6910b9266213233e09d87e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_37ba2de35ac6e4e74d0686bf8c71b549);
#
#
#         var popup_969be167e07246334e319d68da60ed49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c9438e5a381b35ef25b848e587d2437 = $(`&lt;div id=&quot;html_0c9438e5a381b35ef25b848e587d2437&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_969be167e07246334e319d68da60ed49.setContent(html_0c9438e5a381b35ef25b848e587d2437);
#
#
#
#         marker_a2b9a9564b6910b9266213233e09d87e.bindPopup(popup_969be167e07246334e319d68da60ed49)
#         ;
#
#
#
#
#             var marker_f5906415fbced0320fb4c9d2a8a59dab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_37ba2de35ac6e4e74d0686bf8c71b549);
#
#
#         var popup_0b7fec206622d6beb0fa12be18a85348 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_544063ee861dd61ab5d7bb5c7b1573a7 = $(`&lt;div id=&quot;html_544063ee861dd61ab5d7bb5c7b1573a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0b7fec206622d6beb0fa12be18a85348.setContent(html_544063ee861dd61ab5d7bb5c7b1573a7);
#
#
#
#         marker_f5906415fbced0320fb4c9d2a8a59dab.bindPopup(popup_0b7fec206622d6beb0fa12be18a85348)
#         ;
#
#
#
#
#             var marker_4dd14523c16a9a629c9294386d7c2a87 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_37ba2de35ac6e4e74d0686bf8c71b549);
#
#
#         var popup_82bcb881475d548164c2bb8519cb29d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df06034fa9d1b919b8ea29e2dc55aa4a = $(`&lt;div id=&quot;html_df06034fa9d1b919b8ea29e2dc55aa4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_82bcb881475d548164c2bb8519cb29d1.setContent(html_df06034fa9d1b919b8ea29e2dc55aa4a);
#
#
#
#         marker_
