# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c79f53f8bc5474317c1ff2710f9440dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c79f53f8bc5474317c1ff2710f9440dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c79f53f8bc5474317c1ff2710f9440dd = L.map(
#                 &quot;map_c79f53f8bc5474317c1ff2710f9440dd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50c0824a9c436e68420d5e1a4a424312 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50c0824a9c436e68420d5e1a4a424312.addTo(map_c79f53f8bc5474317c1ff2710f9440dd);
#
#
#             var marker_704e96f239f6721cd22cd6abfd230568 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c79f53f8bc5474317c1ff2710f9440dd);
#
#
#         var popup_4813239431fe489efe7c34919784890e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a19bc4340299e9e788054babeb15d5d4 = $(`&lt;div id=&quot;html_a19bc4340299e9e788054babeb15d5d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4813239431fe489efe7c34919784890e.setContent(html_a19bc4340299e9e788054babeb15d5d4);
#
#
#
#         marker_704e96f239f6721cd22cd6abfd230568.bindPopup(popup_4813239431fe489efe7c34919784890e)
#         ;
#
#
#
#
#             var marker_a7b9d7e85afcb045efdd05ac9f96de75 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c79f53f8bc5474317c1ff2710f9440dd);
#
#
#         var popup_020c3a171422bafd4da20787cee03d38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b93e300d9f5437ea82446b43421012f3 = $(`&lt;div id=&quot;html_b93e300d9f5437ea82446b43421012f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_020c3a171422bafd4da20787cee03d38.setContent(html_b93e300d9f5437ea82446b43421012f3);
#
#
#
#         marker_a7b9d7e85afcb045efdd05ac9f96de75.bindPopup(popup_020c3a171422bafd4da20787cee03d38)
#         ;
#
#
#
#
#             var marker_7fb8fec5d34589f8c3b10b979e72f570 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c79f53f8bc5474317c1ff2710f9440dd);
#
#
#         var popup_446b4f91df9bcbe637a0adf57b0b6ea0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f98212fec73de2ca6d84119f9f95bef = $(`&lt;div id=&quot;html_9f98212fec73de2ca6d84119f9f95bef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_446b4f91df9bcbe637a0adf57b0b6ea0.setContent(html_9f98212fec73de2ca6d84119f9f95bef);
#
#
#
#         marker_7fb8fec5d34589f8c3b10b979e72f570.bindPopup(popup_446b4f91df9bcbe637a0adf57b0b6ea0)
#         ;
#
#
#
#
#             var marker_252c520cacbecb9682159627b5c848c4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c79f53f8bc5474317c1ff2710f9440dd);
#
#
#         var popup_c545a680a9a9d7bbe2628d71ee431b3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d730165fbb47bd3fd415d193cbe84fba = $(`&lt;div id=&quot;html_d730165fbb47bd3fd415d193cbe84fba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c545a680a9a9d7bbe2628d71ee431b3d.setContent(html_d730165fbb47bd3fd415d193cbe84fba);
#
#
#
#         marker_252c520cacbecb9682159627b5c848c4.bindPopup(popup_c545a680a9a9d7bbe2628d71ee431b3d)
#         ;
#
#
#
#
#             var marker_1f6da1c488bdacfedd72c47e561146a3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c79f53f8bc5474317c1ff2710f9440dd);
#
#
#         var popup_56525cf23d1ea9455d6901c80988b7a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6300c4cbf9182ffda82ba0137edac7c5 = $(`&lt;div id=&quot;html_6300c4cbf9182ffda82ba0137edac7c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_56525cf23d1ea9455d6901c80988b7a1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01fa01a553a55a98a60caf6de3c61792 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01fa01a553a55a98a60caf6de3c61792&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01fa01a553a55a98a60caf6de3c61792 = L.map(
#                 &quot;map_01fa01a553a55a98a60caf6de3c61792&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96616e5c33c0d5b9397cf8217f4aa321 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_96616e5c33c0d5b9397cf8217f4aa321.addTo(map_01fa01a553a55a98a60caf6de3c61792);
#
#
#             var feature_group_6e203314c6c77f926c6739e69f70d7e0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b529d197d251b33ae3107a281ffe09f2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6e203314c6c77f926c6739e69f70d7e0);
#
#
#         var popup_786d959ae8cad486a7345f565be17b63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9371ef61ca5af9d41d91effb6fbc117c = $(`&lt;div id=&quot;html_9371ef61ca5af9d41d91effb6fbc117c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_786d959ae8cad486a7345f565be17b63.setContent(html_9371ef61ca5af9d41d91effb6fbc117c);
#
#
#
#         marker_b529d197d251b33ae3107a281ffe09f2.bindPopup(popup_786d959ae8cad486a7345f565be17b63)
#         ;
#
#
#
#
#             var marker_571d0dda51c2118340d88d92ae05c670 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6e203314c6c77f926c6739e69f70d7e0);
#
#
#         var popup_0c11364c152945587d0dbbcbf53f5f2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_190cfb8397f3af2ba2a966c0f5b7235f = $(`&lt;div id=&quot;html_190cfb8397f3af2ba2a966c0f5b7235f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0c11364c152945587d0dbbcbf53f5f2c.setContent(html_190cfb8397f3af2ba2a966c0f5b7235f);
#
#
#
#         marker_571d0dda51c2118340d88d92ae05c670.bindPopup(popup_0c11364c152945587d0dbbcbf53f5f2c)
#         ;
#
#
#
#
#             var marker_2a3ed8c44948d0147a868d3f586bb8d5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6e203314c6c77f926c6739e69f70d7e0);
#
#
#         var popup_aae4e37ef873a81d2161781eed781d3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd63695acbf9b6708a0191ca216c5c15 = $(`&lt;div id=&quot;html_cd63695acbf9b6708a0191ca216c5c15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_aae4e37ef873a81d2161781eed781d3d.setContent(html_cd63695acbf9b6708a0191ca216c5c15);
#
#
#
#         marker_2a3ed8c44948d0147a868d3f586bb8d5.bindPopup(popup_aae4e37ef873a81d2161781eed781d3d)
#         ;
#
#
#
#
#             var marker_c1368002543f7e55def6c706b18e5752 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6e203314c6c77f926c6739e69f70d7e0);
#
#
#         var popup_58c4f87218a4db130d0e86402222f8ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22f8e611470637869c29c1de2cc8cb2e = $(`&lt;div id=&quot;html_22f8e611470637869c29c1de2cc8cb2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_58c4f87218a4db130d0e86402222f8ad.setContent(html_22f8e611470637869c29c1de2cc8cb2e);
#
#
#
#         marker_c1368002543f7e55def6c706b18e5752.bindPopup(popup_58c4f87218a4db130d0e86402222f8ad)
#         ;
#
#
#
#
#             var marker_c2646bb4d6f29b50929d78bdfd8c4a04 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6e203314c6c77f926c6739e69f70d7e0);
#
#
#         var popup_998fbb924e8a579a6f00560349b642de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16ca69966d53b806afaabe4d2ea7ddd9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16ca69966d53b806afaabe4d2ea7ddd9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16ca69966d53b806afaabe4d2ea7ddd9 = L.map(
#                 &quot;map_16ca69966d53b806afaabe4d2ea7ddd9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a24608f4bd236af6bc45da0bc730aac2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a24608f4bd236af6bc45da0bc730aac2.addTo(map_16ca69966d53b806afaabe4d2ea7ddd9);
#
#
#             var feature_group_444f93eff90a0e4357f66497e73da6ff = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_444f93eff90a0e4357f66497e73da6ff.addTo(map_16ca69966d53b806afaabe4d2ea7ddd9);
#
#
#             var feature_group_sub_group_64f89ca501623b0f2737d2a851baba27 = L.featureGroup.subGroup(
#                 feature_group_444f93eff90a0e4357f66497e73da6ff
#             );
#
#
#             var marker_86db379103f9aec19ab72b4c501e4e01 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_64f89ca501623b0f2737d2a851baba27);
#
#
#         var popup_c941620fa45b4b0c3d143f0293372734 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8babf1a4d22b857d27520f03788d333 = $(`&lt;div id=&quot;html_a8babf1a4d22b857d27520f03788d333&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c941620fa45b4b0c3d143f0293372734.setContent(html_a8babf1a4d22b857d27520f03788d333);
#
#
#
#         marker_86db379103f9aec19ab72b4c501e4e01.bindPopup(popup_c941620fa45b4b0c3d143f0293372734)
#         ;
#
#
#
#
#             var marker_0db0b19cb41ef6f317ce24a6579d2e55 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_64f89ca501623b0f2737d2a851baba27);
#
#
#         var popup_63cecc253087bac76af92a3713714907 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17a641f68f7a98455699541fbac41fbc = $(`&lt;div id=&quot;html_17a641f68f7a98455699541fbac41fbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_63cecc253087bac76af92a3713714907.setContent(html_17a641f68f7a98455699541fbac41fbc);
#
#
#
#         marker_0db0b19cb41ef6f317ce24a6579d2e55.bindPopup(popup_63cecc253087bac76af92a3713714907)
#         ;
#
#
#
#
#             var marker_73f99b69093d2a49faa22f771e4400a4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_64f89ca501623b0f2737d2a851baba27);
#
#
#         var popup_585cd07583bbcc761099d95f34870fdf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f602748619c08d14ca5c38fad89f6cb6 = $(`&lt;div id=&quot;html_f602748619c08d14ca5c38fad89f6cb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_585cd07583bbcc761099d95f34870fdf.setContent(html_f602748619c08d14ca5c38fad89f6cb6);
#
#
#
#         marker_73f99b69093d2a49faa22f771e4400a4.bindPopup(popup_585cd07583bbcc761099d95f34870fdf)
#         ;
#
#
#
#
#             var marker_4b5147ed927218f9725cd4872e03a07c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_64f89ca501623b0f2737d2a851baba27);
#
#
#         var popup_574872806f8a0cb4e77504490cbf927d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c10acf7710eade6e49197dfbb6dce400 = $(`&lt;div id=&quot;html_c10acf7710eade6e49197dfbb6dce400&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_574872806f8a0cb4e77504490cbf927d.setContent(html_c10acf7710eade6e49197dfbb6dce400);
#
#
#
#         marker_
