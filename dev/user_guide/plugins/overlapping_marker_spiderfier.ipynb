# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_994d0aa84bdac01dd45558e74cd74a27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_994d0aa84bdac01dd45558e74cd74a27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_994d0aa84bdac01dd45558e74cd74a27 = L.map(
#                 &quot;map_994d0aa84bdac01dd45558e74cd74a27&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c70686b1b5608a52c41c1b5624c098f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c70686b1b5608a52c41c1b5624c098f1.addTo(map_994d0aa84bdac01dd45558e74cd74a27);
#
#
#             var marker_32f805a50cc711eaec0698a4b8df966e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_994d0aa84bdac01dd45558e74cd74a27);
#
#
#         var popup_608aa8635c7ad709cebb57ad03625d86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99146b0c4a4165e831f01f4381c89d71 = $(`&lt;div id=&quot;html_99146b0c4a4165e831f01f4381c89d71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_608aa8635c7ad709cebb57ad03625d86.setContent(html_99146b0c4a4165e831f01f4381c89d71);
#
#
#
#         marker_32f805a50cc711eaec0698a4b8df966e.bindPopup(popup_608aa8635c7ad709cebb57ad03625d86)
#         ;
#
#
#
#
#             var marker_e3a280e7c45baca5de15d1e97ffa0d32 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_994d0aa84bdac01dd45558e74cd74a27);
#
#
#         var popup_1e3763767cedb79f1d3796524ef5971a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5365d7e98dee9d7b62615ed6acd7595 = $(`&lt;div id=&quot;html_d5365d7e98dee9d7b62615ed6acd7595&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1e3763767cedb79f1d3796524ef5971a.setContent(html_d5365d7e98dee9d7b62615ed6acd7595);
#
#
#
#         marker_e3a280e7c45baca5de15d1e97ffa0d32.bindPopup(popup_1e3763767cedb79f1d3796524ef5971a)
#         ;
#
#
#
#
#             var marker_78ab12db3562e4f7c6e4b8610de02a44 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_994d0aa84bdac01dd45558e74cd74a27);
#
#
#         var popup_a4ab0e06129588ef18987a6b84323fd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3642748dbcca649402901a7081bf760 = $(`&lt;div id=&quot;html_e3642748dbcca649402901a7081bf760&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a4ab0e06129588ef18987a6b84323fd5.setContent(html_e3642748dbcca649402901a7081bf760);
#
#
#
#         marker_78ab12db3562e4f7c6e4b8610de02a44.bindPopup(popup_a4ab0e06129588ef18987a6b84323fd5)
#         ;
#
#
#
#
#             var marker_7f443e66c3ced86665a741c345da4eac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_994d0aa84bdac01dd45558e74cd74a27);
#
#
#         var popup_e014f188c84dacd95c248873fa6778b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94d1ab450bb71eb203b56c39ab608fbe = $(`&lt;div id=&quot;html_94d1ab450bb71eb203b56c39ab608fbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e014f188c84dacd95c248873fa6778b4.setContent(html_94d1ab450bb71eb203b56c39ab608fbe);
#
#
#
#         marker_7f443e66c3ced86665a741c345da4eac.bindPopup(popup_e014f188c84dacd95c248873fa6778b4)
#         ;
#
#
#
#
#             var marker_d0ae485e2d8eafb882f6265b8fb1de62 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_994d0aa84bdac01dd45558e74cd74a27);
#
#
#         var popup_765954b5852105ab3b66ec5ef5c9d32d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59ce952fa70f94998459d10fb7bdfde3 = $(`&lt;div id=&quot;html_59ce952fa70f94998459d10fb7bdfde3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_765954b5852105ab3b66ec5ef5c9d32d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66b98f79908f03e358e72df12b839958 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66b98f79908f03e358e72df12b839958&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66b98f79908f03e358e72df12b839958 = L.map(
#                 &quot;map_66b98f79908f03e358e72df12b839958&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b00570b741369a324ad2c8a32207e2f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b00570b741369a324ad2c8a32207e2f5.addTo(map_66b98f79908f03e358e72df12b839958);
#
#
#             var feature_group_7c90009e38915e394270eee0fce6b6a0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_28dbfcaa30f7dd3769d636fe66dec654 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7c90009e38915e394270eee0fce6b6a0);
#
#
#         var popup_f548d711db5b93741fd9ac1c47bf8650 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4691151ab4653fd2f9a04a27ec4ea3d7 = $(`&lt;div id=&quot;html_4691151ab4653fd2f9a04a27ec4ea3d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f548d711db5b93741fd9ac1c47bf8650.setContent(html_4691151ab4653fd2f9a04a27ec4ea3d7);
#
#
#
#         marker_28dbfcaa30f7dd3769d636fe66dec654.bindPopup(popup_f548d711db5b93741fd9ac1c47bf8650)
#         ;
#
#
#
#
#             var marker_df99b7f476cbf1ddcb831d8d1de3f1b8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7c90009e38915e394270eee0fce6b6a0);
#
#
#         var popup_7868699a3c501e7f7e5e7c8f67490abb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11a5473975360663362c19e2fadbae78 = $(`&lt;div id=&quot;html_11a5473975360663362c19e2fadbae78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7868699a3c501e7f7e5e7c8f67490abb.setContent(html_11a5473975360663362c19e2fadbae78);
#
#
#
#         marker_df99b7f476cbf1ddcb831d8d1de3f1b8.bindPopup(popup_7868699a3c501e7f7e5e7c8f67490abb)
#         ;
#
#
#
#
#             var marker_0b7e918573490b6b3c94a251dd96ef59 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7c90009e38915e394270eee0fce6b6a0);
#
#
#         var popup_0fd00c69298bbfcc415cfbfe56259423 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea5954b3a32b063eb15734fe99785152 = $(`&lt;div id=&quot;html_ea5954b3a32b063eb15734fe99785152&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0fd00c69298bbfcc415cfbfe56259423.setContent(html_ea5954b3a32b063eb15734fe99785152);
#
#
#
#         marker_0b7e918573490b6b3c94a251dd96ef59.bindPopup(popup_0fd00c69298bbfcc415cfbfe56259423)
#         ;
#
#
#
#
#             var marker_e5fd9ed4759e161b30326d630e24d625 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7c90009e38915e394270eee0fce6b6a0);
#
#
#         var popup_efdadb403fba01419e8de20974a32a2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce9770bef9946118ed00cea91cb07a68 = $(`&lt;div id=&quot;html_ce9770bef9946118ed00cea91cb07a68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_efdadb403fba01419e8de20974a32a2e.setContent(html_ce9770bef9946118ed00cea91cb07a68);
#
#
#
#         marker_e5fd9ed4759e161b30326d630e24d625.bindPopup(popup_efdadb403fba01419e8de20974a32a2e)
#         ;
#
#
#
#
#             var marker_8c6a383bf4784ded70b7297a738f8b67 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7c90009e38915e394270eee0fce6b6a0);
#
#
#         var popup_57e5e22eef7c786991861cf1b7279ad1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b65bf2ede7af626b0c4d8c9b565f9e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b65bf2ede7af626b0c4d8c9b565f9e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b65bf2ede7af626b0c4d8c9b565f9e7 = L.map(
#                 &quot;map_1b65bf2ede7af626b0c4d8c9b565f9e7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed3217a60614afeb42daab33cbf846bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed3217a60614afeb42daab33cbf846bd.addTo(map_1b65bf2ede7af626b0c4d8c9b565f9e7);
#
#
#             var feature_group_cdeb8c60242a458f276a2eb91d12feb9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cdeb8c60242a458f276a2eb91d12feb9.addTo(map_1b65bf2ede7af626b0c4d8c9b565f9e7);
#
#
#             var feature_group_sub_group_d03f06a2edeb7fee4198651afca4ee8c = L.featureGroup.subGroup(
#                 feature_group_cdeb8c60242a458f276a2eb91d12feb9
#             );
#
#
#             var marker_5ecaa083c666be733a15d10a0c2574de = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d03f06a2edeb7fee4198651afca4ee8c);
#
#
#         var popup_251de656cd2720445488bc5ad3c7b001 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_faa72ad58f92fe96ece0c8a1d682951d = $(`&lt;div id=&quot;html_faa72ad58f92fe96ece0c8a1d682951d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_251de656cd2720445488bc5ad3c7b001.setContent(html_faa72ad58f92fe96ece0c8a1d682951d);
#
#
#
#         marker_5ecaa083c666be733a15d10a0c2574de.bindPopup(popup_251de656cd2720445488bc5ad3c7b001)
#         ;
#
#
#
#
#             var marker_f5069eca981b0d0ffbcac15a30093019 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d03f06a2edeb7fee4198651afca4ee8c);
#
#
#         var popup_7d937bf76d28b393710b0a40a394f65f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78a73d5af2aabd834f34926c2f8b6e8d = $(`&lt;div id=&quot;html_78a73d5af2aabd834f34926c2f8b6e8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7d937bf76d28b393710b0a40a394f65f.setContent(html_78a73d5af2aabd834f34926c2f8b6e8d);
#
#
#
#         marker_f5069eca981b0d0ffbcac15a30093019.bindPopup(popup_7d937bf76d28b393710b0a40a394f65f)
#         ;
#
#
#
#
#             var marker_546f096400039ae8826224da7bda2a3f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d03f06a2edeb7fee4198651afca4ee8c);
#
#
#         var popup_6aefc8e425bd8c960c2e94f20bfaa39e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a864eec46ad54cda8e0a6897de3419f = $(`&lt;div id=&quot;html_1a864eec46ad54cda8e0a6897de3419f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6aefc8e425bd8c960c2e94f20bfaa39e.setContent(html_1a864eec46ad54cda8e0a6897de3419f);
#
#
#
#         marker_546f096400039ae8826224da7bda2a3f.bindPopup(popup_6aefc8e425bd8c960c2e94f20bfaa39e)
#         ;
#
#
#
#
#             var marker_d33dd648de6ac5d21aede0a323fde2d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d03f06a2edeb7fee4198651afca4ee8c);
#
#
#         var popup_a6be0dbd479c6a86a1036ab39ef8dc04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4caddf590c94874813bbc2d87be372ac = $(`&lt;div id=&quot;html_4caddf590c94874813bbc2d87be372ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a6be0dbd479c6a86a1036ab39ef8dc04.setContent(html_4caddf590c94874813bbc2d87be372ac);
#
#
#
#         marker_
