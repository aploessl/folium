# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f25c46bf7ed531705fc368a1feb3c4bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f25c46bf7ed531705fc368a1feb3c4bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f25c46bf7ed531705fc368a1feb3c4bf = L.map(
#                 &quot;map_f25c46bf7ed531705fc368a1feb3c4bf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c78b1da24609a79a22e57d32a5ebf95a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c78b1da24609a79a22e57d32a5ebf95a.addTo(map_f25c46bf7ed531705fc368a1feb3c4bf);
#
#
#             var marker_ad5a7863d4531f55fefb811905bcbd1b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f25c46bf7ed531705fc368a1feb3c4bf);
#
#
#         var popup_59d7ab1e6d216819b774f246529344d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_004d8d60e9087baded0cd518a92352b9 = $(`&lt;div id=&quot;html_004d8d60e9087baded0cd518a92352b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_59d7ab1e6d216819b774f246529344d1.setContent(html_004d8d60e9087baded0cd518a92352b9);
#
#
#
#         marker_ad5a7863d4531f55fefb811905bcbd1b.bindPopup(popup_59d7ab1e6d216819b774f246529344d1)
#         ;
#
#
#
#
#             var marker_47a21c21036ce1023466d23b1a48e62f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f25c46bf7ed531705fc368a1feb3c4bf);
#
#
#         var popup_5232c36cc506a84d62a8341bb6927ab9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34b857a1ff188c210807a7a657bf3580 = $(`&lt;div id=&quot;html_34b857a1ff188c210807a7a657bf3580&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5232c36cc506a84d62a8341bb6927ab9.setContent(html_34b857a1ff188c210807a7a657bf3580);
#
#
#
#         marker_47a21c21036ce1023466d23b1a48e62f.bindPopup(popup_5232c36cc506a84d62a8341bb6927ab9)
#         ;
#
#
#
#
#             var marker_4a6b48c0ed80d5eab0c6d58b9eea2771 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f25c46bf7ed531705fc368a1feb3c4bf);
#
#
#         var popup_8254be76c0c6dc6d4e4a77ab40dd3b11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e172b08962f11382108f552b83c9293 = $(`&lt;div id=&quot;html_3e172b08962f11382108f552b83c9293&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8254be76c0c6dc6d4e4a77ab40dd3b11.setContent(html_3e172b08962f11382108f552b83c9293);
#
#
#
#         marker_4a6b48c0ed80d5eab0c6d58b9eea2771.bindPopup(popup_8254be76c0c6dc6d4e4a77ab40dd3b11)
#         ;
#
#
#
#
#             var marker_d16e94e20933dcc977827f7a5c540920 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f25c46bf7ed531705fc368a1feb3c4bf);
#
#
#         var popup_109223ff1407a16f78872a532804e9bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b30ef895482751cbf450e8d716cf67e3 = $(`&lt;div id=&quot;html_b30ef895482751cbf450e8d716cf67e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_109223ff1407a16f78872a532804e9bc.setContent(html_b30ef895482751cbf450e8d716cf67e3);
#
#
#
#         marker_d16e94e20933dcc977827f7a5c540920.bindPopup(popup_109223ff1407a16f78872a532804e9bc)
#         ;
#
#
#
#
#             var marker_237c7cfe3c1aa900ae44b8b3fe0c371f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f25c46bf7ed531705fc368a1feb3c4bf);
#
#
#         var popup_641a43eb569dfbb9f67b7d9e4e7b1463 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08e6e7f1a18272c87afba6aece2f2952 = $(`&lt;div id=&quot;html_08e6e7f1a18272c87afba6aece2f2952&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_641a43eb569dfbb9f67b7d9e4e7b1463.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c4d214324522151c4a10a6d274fe482 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c4d214324522151c4a10a6d274fe482&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c4d214324522151c4a10a6d274fe482 = L.map(
#                 &quot;map_1c4d214324522151c4a10a6d274fe482&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f84883aa43bb46377fb51384676aa36 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f84883aa43bb46377fb51384676aa36.addTo(map_1c4d214324522151c4a10a6d274fe482);
#
#
#             var feature_group_5aeeccced9b5239f52cd189395d5aec6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8150e1f27dbe03c33b4cba9a3e5cda8b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5aeeccced9b5239f52cd189395d5aec6);
#
#
#         var popup_3c5d1b583558aca797f0e69c1fb40ce7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_138d4eb4de62c796209e1998b251fe20 = $(`&lt;div id=&quot;html_138d4eb4de62c796209e1998b251fe20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3c5d1b583558aca797f0e69c1fb40ce7.setContent(html_138d4eb4de62c796209e1998b251fe20);
#
#
#
#         marker_8150e1f27dbe03c33b4cba9a3e5cda8b.bindPopup(popup_3c5d1b583558aca797f0e69c1fb40ce7)
#         ;
#
#
#
#
#             var marker_20223a174bcbfcd79e0d98c637fb6626 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5aeeccced9b5239f52cd189395d5aec6);
#
#
#         var popup_a9d05cb5d2aad4bd1037a8dae9cd7151 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4a62b5c42f010611b1a3787006332db = $(`&lt;div id=&quot;html_a4a62b5c42f010611b1a3787006332db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a9d05cb5d2aad4bd1037a8dae9cd7151.setContent(html_a4a62b5c42f010611b1a3787006332db);
#
#
#
#         marker_20223a174bcbfcd79e0d98c637fb6626.bindPopup(popup_a9d05cb5d2aad4bd1037a8dae9cd7151)
#         ;
#
#
#
#
#             var marker_7b049d5f6406de49fb5a1479907b3dd2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5aeeccced9b5239f52cd189395d5aec6);
#
#
#         var popup_2283fc0f5aea6d317a25d3bfae370480 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bf5c10d3ec770fcd72a877d943d9b52 = $(`&lt;div id=&quot;html_5bf5c10d3ec770fcd72a877d943d9b52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2283fc0f5aea6d317a25d3bfae370480.setContent(html_5bf5c10d3ec770fcd72a877d943d9b52);
#
#
#
#         marker_7b049d5f6406de49fb5a1479907b3dd2.bindPopup(popup_2283fc0f5aea6d317a25d3bfae370480)
#         ;
#
#
#
#
#             var marker_e8d79dabfd7d852acba401a71741937e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5aeeccced9b5239f52cd189395d5aec6);
#
#
#         var popup_56fcb6fa6ff8c3580c85eff067c81dc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_753cf18207e28014ae0e3dd39bb96ee4 = $(`&lt;div id=&quot;html_753cf18207e28014ae0e3dd39bb96ee4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_56fcb6fa6ff8c3580c85eff067c81dc0.setContent(html_753cf18207e28014ae0e3dd39bb96ee4);
#
#
#
#         marker_e8d79dabfd7d852acba401a71741937e.bindPopup(popup_56fcb6fa6ff8c3580c85eff067c81dc0)
#         ;
#
#
#
#
#             var marker_3eb922c4c1981f2ab62f29c0a4a57de4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5aeeccced9b5239f52cd189395d5aec6);
#
#
#         var popup_e855f853ba86fe9c510dfbfb0d3527c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f59b1c965b82bed07dec174d4d62a56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f59b1c965b82bed07dec174d4d62a56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f59b1c965b82bed07dec174d4d62a56 = L.map(
#                 &quot;map_4f59b1c965b82bed07dec174d4d62a56&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50dfa661c6d0eaf47b2c073e66c8ff06 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50dfa661c6d0eaf47b2c073e66c8ff06.addTo(map_4f59b1c965b82bed07dec174d4d62a56);
#
#
#             var feature_group_ca8417622ed9b5ac1e8dc5c430f1c829 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ca8417622ed9b5ac1e8dc5c430f1c829.addTo(map_4f59b1c965b82bed07dec174d4d62a56);
#
#
#             var feature_group_sub_group_6bb246d01c6e94a02a51b52d16c52a16 = L.featureGroup.subGroup(
#                 feature_group_ca8417622ed9b5ac1e8dc5c430f1c829
#             );
#
#
#             var marker_55e31d2ad6b581143668f10ca742cdb7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6bb246d01c6e94a02a51b52d16c52a16);
#
#
#         var popup_c323a27f96c778471944f379e17d9635 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90c31364edea01f083f9b2aa394dd8e6 = $(`&lt;div id=&quot;html_90c31364edea01f083f9b2aa394dd8e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c323a27f96c778471944f379e17d9635.setContent(html_90c31364edea01f083f9b2aa394dd8e6);
#
#
#
#         marker_55e31d2ad6b581143668f10ca742cdb7.bindPopup(popup_c323a27f96c778471944f379e17d9635)
#         ;
#
#
#
#
#             var marker_38e1576d4c4ca0962a39c341bd5a71d2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6bb246d01c6e94a02a51b52d16c52a16);
#
#
#         var popup_029cc62a780d5deed03e547eff8b69da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4780ba92b5b8a570a536b6bdd7d7e2cd = $(`&lt;div id=&quot;html_4780ba92b5b8a570a536b6bdd7d7e2cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_029cc62a780d5deed03e547eff8b69da.setContent(html_4780ba92b5b8a570a536b6bdd7d7e2cd);
#
#
#
#         marker_38e1576d4c4ca0962a39c341bd5a71d2.bindPopup(popup_029cc62a780d5deed03e547eff8b69da)
#         ;
#
#
#
#
#             var marker_096ca747ba1043a66f9d45e9c9801505 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6bb246d01c6e94a02a51b52d16c52a16);
#
#
#         var popup_425cafa000b284df853e39be784a9436 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a55f38e3b788f32eabeb0bfcb9ab4623 = $(`&lt;div id=&quot;html_a55f38e3b788f32eabeb0bfcb9ab4623&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_425cafa000b284df853e39be784a9436.setContent(html_a55f38e3b788f32eabeb0bfcb9ab4623);
#
#
#
#         marker_096ca747ba1043a66f9d45e9c9801505.bindPopup(popup_425cafa000b284df853e39be784a9436)
#         ;
#
#
#
#
#             var marker_1526ea78779d5279737c5a6fbb0e48ff = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6bb246d01c6e94a02a51b52d16c52a16);
#
#
#         var popup_1aa1502be143e0cee1c69ab6ed142dea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcdddd5906249873d07a2d6fa7ce51e9 = $(`&lt;div id=&quot;html_fcdddd5906249873d07a2d6fa7ce51e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1aa1502be143e0cee1c69ab6ed142dea.setContent(html_fcdddd5906249873d07a2d6fa7ce51e9);
#
#
#
#         marker_
