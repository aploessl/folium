# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d320bf0f90f9679f8f25839159fcf497 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d320bf0f90f9679f8f25839159fcf497&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d320bf0f90f9679f8f25839159fcf497 = L.map(
#                 &quot;map_d320bf0f90f9679f8f25839159fcf497&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d32e880cc90a441c36feff8bf7c7262 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d32e880cc90a441c36feff8bf7c7262.addTo(map_d320bf0f90f9679f8f25839159fcf497);
#
#
#             var marker_87321f6bc35bb2f55ffc1292cae147e7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d320bf0f90f9679f8f25839159fcf497);
#
#
#         var popup_94830f3745d2a079396fc3d6d50df1c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aef30b5a76f02e5b1811b84ac40d51a0 = $(`&lt;div id=&quot;html_aef30b5a76f02e5b1811b84ac40d51a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_94830f3745d2a079396fc3d6d50df1c8.setContent(html_aef30b5a76f02e5b1811b84ac40d51a0);
#
#
#
#         marker_87321f6bc35bb2f55ffc1292cae147e7.bindPopup(popup_94830f3745d2a079396fc3d6d50df1c8)
#         ;
#
#
#
#
#             var marker_6d97492cc1181851590d5144b092ea8e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d320bf0f90f9679f8f25839159fcf497);
#
#
#         var popup_1e6aebb266beadb85a4c9f8001e419f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d281de3519ff9aadb8eed8a2e94c57f = $(`&lt;div id=&quot;html_1d281de3519ff9aadb8eed8a2e94c57f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1e6aebb266beadb85a4c9f8001e419f6.setContent(html_1d281de3519ff9aadb8eed8a2e94c57f);
#
#
#
#         marker_6d97492cc1181851590d5144b092ea8e.bindPopup(popup_1e6aebb266beadb85a4c9f8001e419f6)
#         ;
#
#
#
#
#             var marker_8c199920458b098d6c08f91eb0b5f0d5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d320bf0f90f9679f8f25839159fcf497);
#
#
#         var popup_eda75c56433dcc0c9cd805d0c54933df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe2743297408dc924efdb73c6183ac1e = $(`&lt;div id=&quot;html_fe2743297408dc924efdb73c6183ac1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_eda75c56433dcc0c9cd805d0c54933df.setContent(html_fe2743297408dc924efdb73c6183ac1e);
#
#
#
#         marker_8c199920458b098d6c08f91eb0b5f0d5.bindPopup(popup_eda75c56433dcc0c9cd805d0c54933df)
#         ;
#
#
#
#
#             var marker_51e1dea757239b9828df70a186ab41da = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d320bf0f90f9679f8f25839159fcf497);
#
#
#         var popup_2aad991c99de8e30ca34b5f7141a18d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_396d65133912439d03523a8978e654fc = $(`&lt;div id=&quot;html_396d65133912439d03523a8978e654fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2aad991c99de8e30ca34b5f7141a18d6.setContent(html_396d65133912439d03523a8978e654fc);
#
#
#
#         marker_51e1dea757239b9828df70a186ab41da.bindPopup(popup_2aad991c99de8e30ca34b5f7141a18d6)
#         ;
#
#
#
#
#             var marker_e8022404f6e45d8164c7953be27602fb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d320bf0f90f9679f8f25839159fcf497);
#
#
#         var popup_337e51e4d62973ce7385c296944aabb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5079832667f00e261a6887ce4b13e383 = $(`&lt;div id=&quot;html_5079832667f00e261a6887ce4b13e383&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_337e51e4d62973ce7385c296944aabb8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_400e682f0a855b69b794093fb524cfbb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_400e682f0a855b69b794093fb524cfbb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_400e682f0a855b69b794093fb524cfbb = L.map(
#                 &quot;map_400e682f0a855b69b794093fb524cfbb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a8f37537b8f37d15b4bc1123f4fef2f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a8f37537b8f37d15b4bc1123f4fef2f.addTo(map_400e682f0a855b69b794093fb524cfbb);
#
#
#             var feature_group_6a98d4ed5fa795e0f256e33bbd4692d3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8ae21f14a93f38a9be847cb3236606d5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6a98d4ed5fa795e0f256e33bbd4692d3);
#
#
#         var popup_220cf73d3a7e0546946cb137591624c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e5c2f0073cf9d007a6bcda3e7be3005 = $(`&lt;div id=&quot;html_6e5c2f0073cf9d007a6bcda3e7be3005&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_220cf73d3a7e0546946cb137591624c1.setContent(html_6e5c2f0073cf9d007a6bcda3e7be3005);
#
#
#
#         marker_8ae21f14a93f38a9be847cb3236606d5.bindPopup(popup_220cf73d3a7e0546946cb137591624c1)
#         ;
#
#
#
#
#             var marker_c65698e56616bbe3ea6f9214b2178436 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6a98d4ed5fa795e0f256e33bbd4692d3);
#
#
#         var popup_7c258bdf5a39909f56bbb6bcbdca1d2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74526f92b22ce2e081c97396487f2c3a = $(`&lt;div id=&quot;html_74526f92b22ce2e081c97396487f2c3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7c258bdf5a39909f56bbb6bcbdca1d2d.setContent(html_74526f92b22ce2e081c97396487f2c3a);
#
#
#
#         marker_c65698e56616bbe3ea6f9214b2178436.bindPopup(popup_7c258bdf5a39909f56bbb6bcbdca1d2d)
#         ;
#
#
#
#
#             var marker_a3f361c633813885ecdfd4d7f100d525 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6a98d4ed5fa795e0f256e33bbd4692d3);
#
#
#         var popup_98a97cd5ef6c6dc36a6b05e231b7170f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3ea9c04f2889586f85239b09fe0c51a = $(`&lt;div id=&quot;html_a3ea9c04f2889586f85239b09fe0c51a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_98a97cd5ef6c6dc36a6b05e231b7170f.setContent(html_a3ea9c04f2889586f85239b09fe0c51a);
#
#
#
#         marker_a3f361c633813885ecdfd4d7f100d525.bindPopup(popup_98a97cd5ef6c6dc36a6b05e231b7170f)
#         ;
#
#
#
#
#             var marker_bbca7f05eceb7944f0e5a6ca4547f43f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6a98d4ed5fa795e0f256e33bbd4692d3);
#
#
#         var popup_ef14938960a3bdd23125525951ff42a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e4d58ede9ce468570e26d8e68b47ce7 = $(`&lt;div id=&quot;html_5e4d58ede9ce468570e26d8e68b47ce7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ef14938960a3bdd23125525951ff42a7.setContent(html_5e4d58ede9ce468570e26d8e68b47ce7);
#
#
#
#         marker_bbca7f05eceb7944f0e5a6ca4547f43f.bindPopup(popup_ef14938960a3bdd23125525951ff42a7)
#         ;
#
#
#
#
#             var marker_71f126c1cb3a6082dc420539dfd14183 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6a98d4ed5fa795e0f256e33bbd4692d3);
#
#
#         var popup_99c49a1a0d425fc7e30b293f0a2fbc3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ae1309a27bee52214ce04e19e70a59e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ae1309a27bee52214ce04e19e70a59e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ae1309a27bee52214ce04e19e70a59e = L.map(
#                 &quot;map_7ae1309a27bee52214ce04e19e70a59e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a43013cc2d37171ced6d53d5ab9d57e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a43013cc2d37171ced6d53d5ab9d57e.addTo(map_7ae1309a27bee52214ce04e19e70a59e);
#
#
#             var feature_group_2756d7fcc752663381430126fdc92244 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2756d7fcc752663381430126fdc92244.addTo(map_7ae1309a27bee52214ce04e19e70a59e);
#
#
#             var feature_group_sub_group_b5c2859c1b665317623eed811bfbacae = L.featureGroup.subGroup(
#                 feature_group_2756d7fcc752663381430126fdc92244
#             );
#
#
#             var marker_88c5559e1737a3e6b5c8a2eaad4f4022 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5c2859c1b665317623eed811bfbacae);
#
#
#         var popup_3993bdf6b8bffea0cdd6fd002e437697 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a05b331b80ea6baf7cf0ac842f9db78f = $(`&lt;div id=&quot;html_a05b331b80ea6baf7cf0ac842f9db78f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3993bdf6b8bffea0cdd6fd002e437697.setContent(html_a05b331b80ea6baf7cf0ac842f9db78f);
#
#
#
#         marker_88c5559e1737a3e6b5c8a2eaad4f4022.bindPopup(popup_3993bdf6b8bffea0cdd6fd002e437697)
#         ;
#
#
#
#
#             var marker_a54f92f8911ca1216a91c89c4a6f1eb4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5c2859c1b665317623eed811bfbacae);
#
#
#         var popup_d47214b2ffb7e302da0a67a1e04f4b31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fa281003aee9b06ae932e4d521aba9e = $(`&lt;div id=&quot;html_5fa281003aee9b06ae932e4d521aba9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d47214b2ffb7e302da0a67a1e04f4b31.setContent(html_5fa281003aee9b06ae932e4d521aba9e);
#
#
#
#         marker_a54f92f8911ca1216a91c89c4a6f1eb4.bindPopup(popup_d47214b2ffb7e302da0a67a1e04f4b31)
#         ;
#
#
#
#
#             var marker_ade0be73962a63238f1adb15c982e676 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5c2859c1b665317623eed811bfbacae);
#
#
#         var popup_c1bdc17d428d98f913a88d2d57cb7a62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1eaadaab77548e4af7f9ac39e798bfae = $(`&lt;div id=&quot;html_1eaadaab77548e4af7f9ac39e798bfae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c1bdc17d428d98f913a88d2d57cb7a62.setContent(html_1eaadaab77548e4af7f9ac39e798bfae);
#
#
#
#         marker_ade0be73962a63238f1adb15c982e676.bindPopup(popup_c1bdc17d428d98f913a88d2d57cb7a62)
#         ;
#
#
#
#
#             var marker_554c1e4d556a2c870c201f19185258c7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5c2859c1b665317623eed811bfbacae);
#
#
#         var popup_d81f091172c3edf44309566febd6e4f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ceba236e97e38f6055268c8e91e8bb7b = $(`&lt;div id=&quot;html_ceba236e97e38f6055268c8e91e8bb7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d81f091172c3edf44309566febd6e4f7.setContent(html_ceba236e97e38f6055268c8e91e8bb7b);
#
#
#
#         marker_
