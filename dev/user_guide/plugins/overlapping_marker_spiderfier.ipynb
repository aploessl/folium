# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76f46e7f0b9dc906b64b5fe0f2eec7a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76f46e7f0b9dc906b64b5fe0f2eec7a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76f46e7f0b9dc906b64b5fe0f2eec7a1 = L.map(
#                 &quot;map_76f46e7f0b9dc906b64b5fe0f2eec7a1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dda3f2ee2ca4752006c7a0a0b91e6e30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dda3f2ee2ca4752006c7a0a0b91e6e30.addTo(map_76f46e7f0b9dc906b64b5fe0f2eec7a1);
#
#
#             var marker_3804797d5bd397ddf0991be906c34a6b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_76f46e7f0b9dc906b64b5fe0f2eec7a1);
#
#
#         var popup_03fe764ca0e295b249701f923b6a564e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_486309f06b2f601cb94f02fd367dc99f = $(`&lt;div id=&quot;html_486309f06b2f601cb94f02fd367dc99f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_03fe764ca0e295b249701f923b6a564e.setContent(html_486309f06b2f601cb94f02fd367dc99f);
#
#
#
#         marker_3804797d5bd397ddf0991be906c34a6b.bindPopup(popup_03fe764ca0e295b249701f923b6a564e)
#         ;
#
#
#
#
#             var marker_a07b8d808415139eeadc80bec6dc8a86 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_76f46e7f0b9dc906b64b5fe0f2eec7a1);
#
#
#         var popup_2be328c3dee88dc9cf9330e0b66e8bd0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f80c6b9187c97859aa93f333fa8dcda8 = $(`&lt;div id=&quot;html_f80c6b9187c97859aa93f333fa8dcda8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2be328c3dee88dc9cf9330e0b66e8bd0.setContent(html_f80c6b9187c97859aa93f333fa8dcda8);
#
#
#
#         marker_a07b8d808415139eeadc80bec6dc8a86.bindPopup(popup_2be328c3dee88dc9cf9330e0b66e8bd0)
#         ;
#
#
#
#
#             var marker_3eedf5ea9dfe31633111857691ae2eba = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_76f46e7f0b9dc906b64b5fe0f2eec7a1);
#
#
#         var popup_77dcfff6f13c9f24907bd172a24e7ca5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_690caf8d9db400d8e4db255f700c8a82 = $(`&lt;div id=&quot;html_690caf8d9db400d8e4db255f700c8a82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_77dcfff6f13c9f24907bd172a24e7ca5.setContent(html_690caf8d9db400d8e4db255f700c8a82);
#
#
#
#         marker_3eedf5ea9dfe31633111857691ae2eba.bindPopup(popup_77dcfff6f13c9f24907bd172a24e7ca5)
#         ;
#
#
#
#
#             var marker_a5856a290c0a93c4383645e5f16426b5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_76f46e7f0b9dc906b64b5fe0f2eec7a1);
#
#
#         var popup_3c067eec351fe1998cb2764a11bb007e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dacccdd09ae2b8f324cdbc2f957bb048 = $(`&lt;div id=&quot;html_dacccdd09ae2b8f324cdbc2f957bb048&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3c067eec351fe1998cb2764a11bb007e.setContent(html_dacccdd09ae2b8f324cdbc2f957bb048);
#
#
#
#         marker_a5856a290c0a93c4383645e5f16426b5.bindPopup(popup_3c067eec351fe1998cb2764a11bb007e)
#         ;
#
#
#
#
#             var marker_994cc424addcbd77d8728c6363717bd2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_76f46e7f0b9dc906b64b5fe0f2eec7a1);
#
#
#         var popup_62bcd981dec5afa6707868aa7c95fc95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc4df9623530ba945b5cddff2071a15a = $(`&lt;div id=&quot;html_bc4df9623530ba945b5cddff2071a15a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_62bcd981dec5afa6707868aa7c95fc95.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c94520856421a676b7b852dc326f42f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c94520856421a676b7b852dc326f42f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c94520856421a676b7b852dc326f42f9 = L.map(
#                 &quot;map_c94520856421a676b7b852dc326f42f9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df0e107d17b9dd247a3e1c5794cf4020 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df0e107d17b9dd247a3e1c5794cf4020.addTo(map_c94520856421a676b7b852dc326f42f9);
#
#
#             var feature_group_d7e6284082e5ea1865ec1085519f68d5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f9131d4b36e1e649b4407042d2db21ef = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d7e6284082e5ea1865ec1085519f68d5);
#
#
#         var popup_a9826e9ba42e6982dcb5b2d0dab14f17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2962b08931eb2ebc09a1f88f227e7371 = $(`&lt;div id=&quot;html_2962b08931eb2ebc09a1f88f227e7371&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a9826e9ba42e6982dcb5b2d0dab14f17.setContent(html_2962b08931eb2ebc09a1f88f227e7371);
#
#
#
#         marker_f9131d4b36e1e649b4407042d2db21ef.bindPopup(popup_a9826e9ba42e6982dcb5b2d0dab14f17)
#         ;
#
#
#
#
#             var marker_2ef8c14b59720ea10eb4fb48638c5a33 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d7e6284082e5ea1865ec1085519f68d5);
#
#
#         var popup_b64cc415dedefb7f3a6c2cfc9fcc8554 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a61e2ffb52206a9632f2020ed927a4e = $(`&lt;div id=&quot;html_0a61e2ffb52206a9632f2020ed927a4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b64cc415dedefb7f3a6c2cfc9fcc8554.setContent(html_0a61e2ffb52206a9632f2020ed927a4e);
#
#
#
#         marker_2ef8c14b59720ea10eb4fb48638c5a33.bindPopup(popup_b64cc415dedefb7f3a6c2cfc9fcc8554)
#         ;
#
#
#
#
#             var marker_419e90c4a96b6045b7dc250166244c95 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d7e6284082e5ea1865ec1085519f68d5);
#
#
#         var popup_9a4a9badc633c8bc5b3b1e1f98042ff4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa72e68c1da8eafd24b3419914a0cc3c = $(`&lt;div id=&quot;html_aa72e68c1da8eafd24b3419914a0cc3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9a4a9badc633c8bc5b3b1e1f98042ff4.setContent(html_aa72e68c1da8eafd24b3419914a0cc3c);
#
#
#
#         marker_419e90c4a96b6045b7dc250166244c95.bindPopup(popup_9a4a9badc633c8bc5b3b1e1f98042ff4)
#         ;
#
#
#
#
#             var marker_7705cec7aa6b69b9de985e434ff3452f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d7e6284082e5ea1865ec1085519f68d5);
#
#
#         var popup_ab3a92a3963ec7e5994e6fb3989026f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e75cadea46626e2f3494cfa31ce11db = $(`&lt;div id=&quot;html_0e75cadea46626e2f3494cfa31ce11db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ab3a92a3963ec7e5994e6fb3989026f3.setContent(html_0e75cadea46626e2f3494cfa31ce11db);
#
#
#
#         marker_7705cec7aa6b69b9de985e434ff3452f.bindPopup(popup_ab3a92a3963ec7e5994e6fb3989026f3)
#         ;
#
#
#
#
#             var marker_5cf6c2a3d1a1720acf98b1849550d5bf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d7e6284082e5ea1865ec1085519f68d5);
#
#
#         var popup_a1c81c56331416eb0d1c307d7944867e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8764771568de0ff217862d859b86c7bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8764771568de0ff217862d859b86c7bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8764771568de0ff217862d859b86c7bf = L.map(
#                 &quot;map_8764771568de0ff217862d859b86c7bf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0171bccca091be40d40002e449b87dde = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0171bccca091be40d40002e449b87dde.addTo(map_8764771568de0ff217862d859b86c7bf);
#
#
#             var feature_group_ba919a538c16b15b7befd2948e9c300b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ba919a538c16b15b7befd2948e9c300b.addTo(map_8764771568de0ff217862d859b86c7bf);
#
#
#             var feature_group_sub_group_3f3e959fd47d6e375b36e232b59f5764 = L.featureGroup.subGroup(
#                 feature_group_ba919a538c16b15b7befd2948e9c300b
#             );
#
#
#             var marker_9d00d35837c7a63d8b4a65e2d3014026 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3f3e959fd47d6e375b36e232b59f5764);
#
#
#         var popup_356bd555a1f9c6553b08dd956a9f0f24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d52437650399447929223a46eec7881e = $(`&lt;div id=&quot;html_d52437650399447929223a46eec7881e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_356bd555a1f9c6553b08dd956a9f0f24.setContent(html_d52437650399447929223a46eec7881e);
#
#
#
#         marker_9d00d35837c7a63d8b4a65e2d3014026.bindPopup(popup_356bd555a1f9c6553b08dd956a9f0f24)
#         ;
#
#
#
#
#             var marker_f94257a3346dae932596269186ee7626 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3f3e959fd47d6e375b36e232b59f5764);
#
#
#         var popup_69a4800bad7689517853a2a2cb8784bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8033ed0a30fdd5f0379be30d5bec43d = $(`&lt;div id=&quot;html_b8033ed0a30fdd5f0379be30d5bec43d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_69a4800bad7689517853a2a2cb8784bb.setContent(html_b8033ed0a30fdd5f0379be30d5bec43d);
#
#
#
#         marker_f94257a3346dae932596269186ee7626.bindPopup(popup_69a4800bad7689517853a2a2cb8784bb)
#         ;
#
#
#
#
#             var marker_36955af3abb82180928495a289ed758e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3f3e959fd47d6e375b36e232b59f5764);
#
#
#         var popup_202bd653c4fa4bcf382dc466812ea8d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af707fe36dd80f4e4bdc134eee0229ed = $(`&lt;div id=&quot;html_af707fe36dd80f4e4bdc134eee0229ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_202bd653c4fa4bcf382dc466812ea8d4.setContent(html_af707fe36dd80f4e4bdc134eee0229ed);
#
#
#
#         marker_36955af3abb82180928495a289ed758e.bindPopup(popup_202bd653c4fa4bcf382dc466812ea8d4)
#         ;
#
#
#
#
#             var marker_675556dd41307265004ab146edb0d109 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3f3e959fd47d6e375b36e232b59f5764);
#
#
#         var popup_26625044c5cd1bdec53979e3f76e398f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_109b96cf8931a14991df2aa3bf042ed9 = $(`&lt;div id=&quot;html_109b96cf8931a14991df2aa3bf042ed9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_26625044c5cd1bdec53979e3f76e398f.setContent(html_109b96cf8931a14991df2aa3bf042ed9);
#
#
#
#         marker_
