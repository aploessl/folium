# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ded1a1c86788b6736845bcf1078aa0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ded1a1c86788b6736845bcf1078aa0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ded1a1c86788b6736845bcf1078aa0a = L.map(
#                 &quot;map_4ded1a1c86788b6736845bcf1078aa0a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1c67bf1851f72fa3194bb05658f7205 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1c67bf1851f72fa3194bb05658f7205.addTo(map_4ded1a1c86788b6736845bcf1078aa0a);
#
#
#             var marker_20adcc0274b1db4fbe920b7dcc712a03 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4ded1a1c86788b6736845bcf1078aa0a);
#
#
#         var popup_30f7f4304c244a7c055ab054ddd9407e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86fdb667e71dd0b591c22f27fa737fe8 = $(`&lt;div id=&quot;html_86fdb667e71dd0b591c22f27fa737fe8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_30f7f4304c244a7c055ab054ddd9407e.setContent(html_86fdb667e71dd0b591c22f27fa737fe8);
#
#
#
#         marker_20adcc0274b1db4fbe920b7dcc712a03.bindPopup(popup_30f7f4304c244a7c055ab054ddd9407e)
#         ;
#
#
#
#
#             var marker_d71900ddfd9da3b32cdaaf30baed0ee3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4ded1a1c86788b6736845bcf1078aa0a);
#
#
#         var popup_c89f4b8720844011d919f7ed89ab07cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fc56a5a7b1df9b6603446fd981be120 = $(`&lt;div id=&quot;html_8fc56a5a7b1df9b6603446fd981be120&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c89f4b8720844011d919f7ed89ab07cc.setContent(html_8fc56a5a7b1df9b6603446fd981be120);
#
#
#
#         marker_d71900ddfd9da3b32cdaaf30baed0ee3.bindPopup(popup_c89f4b8720844011d919f7ed89ab07cc)
#         ;
#
#
#
#
#             var marker_f2aeae1234e8e37dbf10c2018a5fd374 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4ded1a1c86788b6736845bcf1078aa0a);
#
#
#         var popup_e5f9060f08c4ab00412b82f905c1e098 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7884d2ec3e3db8d81759c6c92d249f3 = $(`&lt;div id=&quot;html_d7884d2ec3e3db8d81759c6c92d249f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e5f9060f08c4ab00412b82f905c1e098.setContent(html_d7884d2ec3e3db8d81759c6c92d249f3);
#
#
#
#         marker_f2aeae1234e8e37dbf10c2018a5fd374.bindPopup(popup_e5f9060f08c4ab00412b82f905c1e098)
#         ;
#
#
#
#
#             var marker_3e2b28a3eb1fe86cde408cdcb84f5c85 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4ded1a1c86788b6736845bcf1078aa0a);
#
#
#         var popup_7258bb7edb96b78c31159900013a1179 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d79334a358f28f4e48bae08af73c817 = $(`&lt;div id=&quot;html_4d79334a358f28f4e48bae08af73c817&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7258bb7edb96b78c31159900013a1179.setContent(html_4d79334a358f28f4e48bae08af73c817);
#
#
#
#         marker_3e2b28a3eb1fe86cde408cdcb84f5c85.bindPopup(popup_7258bb7edb96b78c31159900013a1179)
#         ;
#
#
#
#
#             var marker_ae722debcdba08a032852cf3b191270b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4ded1a1c86788b6736845bcf1078aa0a);
#
#
#         var popup_64d779c93f6393d7699c10d9276eb340 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3afdeacd291cac3cb6eb337b5047f064 = $(`&lt;div id=&quot;html_3afdeacd291cac3cb6eb337b5047f064&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_64d779c93f6393d7699c10d9276eb340.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88448e6d52525127bb221d942b1d29d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88448e6d52525127bb221d942b1d29d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88448e6d52525127bb221d942b1d29d3 = L.map(
#                 &quot;map_88448e6d52525127bb221d942b1d29d3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_420e129cceab7d66ecf3c75a65cfe28c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_420e129cceab7d66ecf3c75a65cfe28c.addTo(map_88448e6d52525127bb221d942b1d29d3);
#
#
#             var feature_group_b8074a80b418ba49891028000086f1ef = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_be25cb680692a51d1ab2ff1cf2ecad20 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b8074a80b418ba49891028000086f1ef);
#
#
#         var popup_ec6c0266a76164750c077518b479c546 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_735d13a908d34344024aa39541116325 = $(`&lt;div id=&quot;html_735d13a908d34344024aa39541116325&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ec6c0266a76164750c077518b479c546.setContent(html_735d13a908d34344024aa39541116325);
#
#
#
#         marker_be25cb680692a51d1ab2ff1cf2ecad20.bindPopup(popup_ec6c0266a76164750c077518b479c546)
#         ;
#
#
#
#
#             var marker_0779092beaf48f70b69d2035bb5ae147 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b8074a80b418ba49891028000086f1ef);
#
#
#         var popup_5e87cf8f1e33c0b991436c366e8834b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26e7dff38c45362fbabecfff34fafe53 = $(`&lt;div id=&quot;html_26e7dff38c45362fbabecfff34fafe53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5e87cf8f1e33c0b991436c366e8834b1.setContent(html_26e7dff38c45362fbabecfff34fafe53);
#
#
#
#         marker_0779092beaf48f70b69d2035bb5ae147.bindPopup(popup_5e87cf8f1e33c0b991436c366e8834b1)
#         ;
#
#
#
#
#             var marker_fa122bbe1218767cbaba8f5e8b0f0b1b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b8074a80b418ba49891028000086f1ef);
#
#
#         var popup_c32441ae2af1a2f26ad5f9f84bc1d288 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a733da8e8666ffb7a490622293a794b3 = $(`&lt;div id=&quot;html_a733da8e8666ffb7a490622293a794b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c32441ae2af1a2f26ad5f9f84bc1d288.setContent(html_a733da8e8666ffb7a490622293a794b3);
#
#
#
#         marker_fa122bbe1218767cbaba8f5e8b0f0b1b.bindPopup(popup_c32441ae2af1a2f26ad5f9f84bc1d288)
#         ;
#
#
#
#
#             var marker_51d6ab5b1c14a586c4da1b3b6ba6a882 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b8074a80b418ba49891028000086f1ef);
#
#
#         var popup_1a9385972736e5ba225282c55375738d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f616fc9d0571d5b36b15221c130b5b75 = $(`&lt;div id=&quot;html_f616fc9d0571d5b36b15221c130b5b75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1a9385972736e5ba225282c55375738d.setContent(html_f616fc9d0571d5b36b15221c130b5b75);
#
#
#
#         marker_51d6ab5b1c14a586c4da1b3b6ba6a882.bindPopup(popup_1a9385972736e5ba225282c55375738d)
#         ;
#
#
#
#
#             var marker_2aec369ad9dfa5c2d95037d4a8f7b52f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b8074a80b418ba49891028000086f1ef);
#
#
#         var popup_ebcd13536060b22ae54d96c2b25a90a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e48fe9805e7220ea13d0a21a1e2a7bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e48fe9805e7220ea13d0a21a1e2a7bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e48fe9805e7220ea13d0a21a1e2a7bb = L.map(
#                 &quot;map_4e48fe9805e7220ea13d0a21a1e2a7bb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ad1ec2dd99c7bd990be3721ad605913 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ad1ec2dd99c7bd990be3721ad605913.addTo(map_4e48fe9805e7220ea13d0a21a1e2a7bb);
#
#
#             var feature_group_fbd7205a6d2f0ebb4c92df802d6435b1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fbd7205a6d2f0ebb4c92df802d6435b1.addTo(map_4e48fe9805e7220ea13d0a21a1e2a7bb);
#
#
#             var feature_group_sub_group_e5dc2cb417cdbf3b664c55fe158b6661 = L.featureGroup.subGroup(
#                 feature_group_fbd7205a6d2f0ebb4c92df802d6435b1
#             );
#
#
#             var marker_61068e194a384cac0789c81cc59ddc49 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e5dc2cb417cdbf3b664c55fe158b6661);
#
#
#         var popup_26eb02b770b4240ddf090f6d0d987cdb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8125037de1a258cff218e608461e9f5 = $(`&lt;div id=&quot;html_d8125037de1a258cff218e608461e9f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_26eb02b770b4240ddf090f6d0d987cdb.setContent(html_d8125037de1a258cff218e608461e9f5);
#
#
#
#         marker_61068e194a384cac0789c81cc59ddc49.bindPopup(popup_26eb02b770b4240ddf090f6d0d987cdb)
#         ;
#
#
#
#
#             var marker_869e9f3b169487541caaf5bcd5267e3e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e5dc2cb417cdbf3b664c55fe158b6661);
#
#
#         var popup_344a92517e2990f5ff019f02645a45df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98e34bebe54c51a16934791e7ef60a29 = $(`&lt;div id=&quot;html_98e34bebe54c51a16934791e7ef60a29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_344a92517e2990f5ff019f02645a45df.setContent(html_98e34bebe54c51a16934791e7ef60a29);
#
#
#
#         marker_869e9f3b169487541caaf5bcd5267e3e.bindPopup(popup_344a92517e2990f5ff019f02645a45df)
#         ;
#
#
#
#
#             var marker_48e2b231707acae98fcecdccd93f3404 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e5dc2cb417cdbf3b664c55fe158b6661);
#
#
#         var popup_69c8054ce5119066a34fd12bfcc0df9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b05d4958ea17649eadebc044a31eb6b7 = $(`&lt;div id=&quot;html_b05d4958ea17649eadebc044a31eb6b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_69c8054ce5119066a34fd12bfcc0df9c.setContent(html_b05d4958ea17649eadebc044a31eb6b7);
#
#
#
#         marker_48e2b231707acae98fcecdccd93f3404.bindPopup(popup_69c8054ce5119066a34fd12bfcc0df9c)
#         ;
#
#
#
#
#             var marker_a89917c23a00a8cffda053a5855c7b1f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e5dc2cb417cdbf3b664c55fe158b6661);
#
#
#         var popup_2084eec974b3a0c48c83cabcfd7d54ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bc56a9110b417537bb26041abcc1f39 = $(`&lt;div id=&quot;html_6bc56a9110b417537bb26041abcc1f39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2084eec974b3a0c48c83cabcfd7d54ed.setContent(html_6bc56a9110b417537bb26041abcc1f39);
#
#
#
#         marker_
