# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60ab2b66d3980a71fbbc7a1470acb170 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60ab2b66d3980a71fbbc7a1470acb170&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60ab2b66d3980a71fbbc7a1470acb170 = L.map(
#                 &quot;map_60ab2b66d3980a71fbbc7a1470acb170&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8cdf6ad898db7d85dccb28afedf0c54 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f8cdf6ad898db7d85dccb28afedf0c54.addTo(map_60ab2b66d3980a71fbbc7a1470acb170);
#
#
#             var marker_3c0e867ff964b117a340bf375283440e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_60ab2b66d3980a71fbbc7a1470acb170);
#
#
#         var popup_435cab10dc9b1be2a2021d36c00eb907 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a0dcf1a6e0a2b1b134923b0b441c632 = $(`&lt;div id=&quot;html_6a0dcf1a6e0a2b1b134923b0b441c632&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_435cab10dc9b1be2a2021d36c00eb907.setContent(html_6a0dcf1a6e0a2b1b134923b0b441c632);
#
#
#
#         marker_3c0e867ff964b117a340bf375283440e.bindPopup(popup_435cab10dc9b1be2a2021d36c00eb907)
#         ;
#
#
#
#
#             var marker_fd130ba4e4280a0d7fa563349dd3c382 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_60ab2b66d3980a71fbbc7a1470acb170);
#
#
#         var popup_38a336da116051209724d83c0bedaf1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6eabd9bc5ec22d1e51879f91bfeb021a = $(`&lt;div id=&quot;html_6eabd9bc5ec22d1e51879f91bfeb021a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_38a336da116051209724d83c0bedaf1f.setContent(html_6eabd9bc5ec22d1e51879f91bfeb021a);
#
#
#
#         marker_fd130ba4e4280a0d7fa563349dd3c382.bindPopup(popup_38a336da116051209724d83c0bedaf1f)
#         ;
#
#
#
#
#             var marker_8af9478cdb13c0293c98ae85ee5d2446 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_60ab2b66d3980a71fbbc7a1470acb170);
#
#
#         var popup_2d929def3d5a14ab0e9475483fe2c3b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4428bfec9170d917d4527d61ba20ac9b = $(`&lt;div id=&quot;html_4428bfec9170d917d4527d61ba20ac9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2d929def3d5a14ab0e9475483fe2c3b0.setContent(html_4428bfec9170d917d4527d61ba20ac9b);
#
#
#
#         marker_8af9478cdb13c0293c98ae85ee5d2446.bindPopup(popup_2d929def3d5a14ab0e9475483fe2c3b0)
#         ;
#
#
#
#
#             var marker_2ef6376b6b8f00d8ff1d38f53c409cd9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_60ab2b66d3980a71fbbc7a1470acb170);
#
#
#         var popup_7b64ee798b3dddd037f7e9fe3f8264cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13966aa39cb5eda7d5f94189f6eb0b24 = $(`&lt;div id=&quot;html_13966aa39cb5eda7d5f94189f6eb0b24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7b64ee798b3dddd037f7e9fe3f8264cb.setContent(html_13966aa39cb5eda7d5f94189f6eb0b24);
#
#
#
#         marker_2ef6376b6b8f00d8ff1d38f53c409cd9.bindPopup(popup_7b64ee798b3dddd037f7e9fe3f8264cb)
#         ;
#
#
#
#
#             var marker_3b1aab9fe4884c2cc2a31074a4d0c870 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_60ab2b66d3980a71fbbc7a1470acb170);
#
#
#         var popup_49fda7892ef235609f902c0455b0d004 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef466206795321f78a0cd3edcd64c526 = $(`&lt;div id=&quot;html_ef466206795321f78a0cd3edcd64c526&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_49fda7892ef235609f902c0455b0d004.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aba738c0eae87e6396e5e7d25551e3e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aba738c0eae87e6396e5e7d25551e3e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aba738c0eae87e6396e5e7d25551e3e4 = L.map(
#                 &quot;map_aba738c0eae87e6396e5e7d25551e3e4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8ddcd6b7a448d0bee6304dbf9efcdfd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c8ddcd6b7a448d0bee6304dbf9efcdfd.addTo(map_aba738c0eae87e6396e5e7d25551e3e4);
#
#
#             var feature_group_d2f28c30c02a656200453d5036363c72 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_eac4b12628177715500fd995fcdbcc55 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d2f28c30c02a656200453d5036363c72);
#
#
#         var popup_f43d1fb15679cd9385018accb7279360 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a3ce421acaa95b0b964e543e9f9c6d4 = $(`&lt;div id=&quot;html_8a3ce421acaa95b0b964e543e9f9c6d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f43d1fb15679cd9385018accb7279360.setContent(html_8a3ce421acaa95b0b964e543e9f9c6d4);
#
#
#
#         marker_eac4b12628177715500fd995fcdbcc55.bindPopup(popup_f43d1fb15679cd9385018accb7279360)
#         ;
#
#
#
#
#             var marker_5c328be1648476501b6614c69fd3123e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d2f28c30c02a656200453d5036363c72);
#
#
#         var popup_40049ed8ffb6ae8845e17697ce3e1ecc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84362ad955271faae94267321b9c9af8 = $(`&lt;div id=&quot;html_84362ad955271faae94267321b9c9af8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_40049ed8ffb6ae8845e17697ce3e1ecc.setContent(html_84362ad955271faae94267321b9c9af8);
#
#
#
#         marker_5c328be1648476501b6614c69fd3123e.bindPopup(popup_40049ed8ffb6ae8845e17697ce3e1ecc)
#         ;
#
#
#
#
#             var marker_499e5090e9892cb6b714646e9670d81e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d2f28c30c02a656200453d5036363c72);
#
#
#         var popup_6b4dacb9d22308a4d4ca2777b8164ad6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9f60b2e895eff708df8d873e817ab14 = $(`&lt;div id=&quot;html_f9f60b2e895eff708df8d873e817ab14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6b4dacb9d22308a4d4ca2777b8164ad6.setContent(html_f9f60b2e895eff708df8d873e817ab14);
#
#
#
#         marker_499e5090e9892cb6b714646e9670d81e.bindPopup(popup_6b4dacb9d22308a4d4ca2777b8164ad6)
#         ;
#
#
#
#
#             var marker_6e77a03e3dfd1388c211ff15e7593ed8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d2f28c30c02a656200453d5036363c72);
#
#
#         var popup_faa5ee5f8f83344e23a1d5944c822a09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12d688be182d23913fe42deda45685d0 = $(`&lt;div id=&quot;html_12d688be182d23913fe42deda45685d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_faa5ee5f8f83344e23a1d5944c822a09.setContent(html_12d688be182d23913fe42deda45685d0);
#
#
#
#         marker_6e77a03e3dfd1388c211ff15e7593ed8.bindPopup(popup_faa5ee5f8f83344e23a1d5944c822a09)
#         ;
#
#
#
#
#             var marker_fad21290f39b45f8f35be85f96f8bdc0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d2f28c30c02a656200453d5036363c72);
#
#
#         var popup_608da447f213e4590012bb80238af9cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1416bbfc5b3b1e945490795bdb3f9a14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1416bbfc5b3b1e945490795bdb3f9a14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1416bbfc5b3b1e945490795bdb3f9a14 = L.map(
#                 &quot;map_1416bbfc5b3b1e945490795bdb3f9a14&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea039ae56dc6f48e8d468e1da1a77658 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea039ae56dc6f48e8d468e1da1a77658.addTo(map_1416bbfc5b3b1e945490795bdb3f9a14);
#
#
#             var feature_group_432754fcd7185b3f778085f2e7418657 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_432754fcd7185b3f778085f2e7418657.addTo(map_1416bbfc5b3b1e945490795bdb3f9a14);
#
#
#             var feature_group_sub_group_068d207e8ea87f5613425ec9c2fd5185 = L.featureGroup.subGroup(
#                 feature_group_432754fcd7185b3f778085f2e7418657
#             );
#
#
#             var marker_c5534873ae6bb424803fb6d2414366f6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_068d207e8ea87f5613425ec9c2fd5185);
#
#
#         var popup_e0cc5fc7eb51ea413ee9f9a1a60bb5e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_807decc1ba55a1a7cc0f73b23fdccbe7 = $(`&lt;div id=&quot;html_807decc1ba55a1a7cc0f73b23fdccbe7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e0cc5fc7eb51ea413ee9f9a1a60bb5e0.setContent(html_807decc1ba55a1a7cc0f73b23fdccbe7);
#
#
#
#         marker_c5534873ae6bb424803fb6d2414366f6.bindPopup(popup_e0cc5fc7eb51ea413ee9f9a1a60bb5e0)
#         ;
#
#
#
#
#             var marker_fa5e605dce963b38f1fc6e478d963f16 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_068d207e8ea87f5613425ec9c2fd5185);
#
#
#         var popup_0c5684840dd0d02fe8e16bb73d28e60c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9738e39ff5434d6f9f02958094e8641a = $(`&lt;div id=&quot;html_9738e39ff5434d6f9f02958094e8641a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0c5684840dd0d02fe8e16bb73d28e60c.setContent(html_9738e39ff5434d6f9f02958094e8641a);
#
#
#
#         marker_fa5e605dce963b38f1fc6e478d963f16.bindPopup(popup_0c5684840dd0d02fe8e16bb73d28e60c)
#         ;
#
#
#
#
#             var marker_d46a9a9028539f33a0a4eb8d1d0628db = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_068d207e8ea87f5613425ec9c2fd5185);
#
#
#         var popup_69ef7597bf13b687b843f7ea588fff3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae5be24d4f998ea1311c7cbe327a4e5d = $(`&lt;div id=&quot;html_ae5be24d4f998ea1311c7cbe327a4e5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_69ef7597bf13b687b843f7ea588fff3d.setContent(html_ae5be24d4f998ea1311c7cbe327a4e5d);
#
#
#
#         marker_d46a9a9028539f33a0a4eb8d1d0628db.bindPopup(popup_69ef7597bf13b687b843f7ea588fff3d)
#         ;
#
#
#
#
#             var marker_e6958cccb75787731a8c1936a9a156dc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_068d207e8ea87f5613425ec9c2fd5185);
#
#
#         var popup_8fac5f21a2f267366185541b5a10922b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9932173313231319c706bcf1257cdda2 = $(`&lt;div id=&quot;html_9932173313231319c706bcf1257cdda2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8fac5f21a2f267366185541b5a10922b.setContent(html_9932173313231319c706bcf1257cdda2);
#
#
#
#         marker_
