# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_329af1894a9e1d11f26f89c9afde9214 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_329af1894a9e1d11f26f89c9afde9214&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_329af1894a9e1d11f26f89c9afde9214 = L.map(
#                 &quot;map_329af1894a9e1d11f26f89c9afde9214&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c2160b645ad89b7f27dadf41ac29219 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9c2160b645ad89b7f27dadf41ac29219.addTo(map_329af1894a9e1d11f26f89c9afde9214);
#
#
#             var marker_317c78c97e35b2abd487d638182ed13d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_329af1894a9e1d11f26f89c9afde9214);
#
#
#         var popup_20046359c5a19563513287429347d47d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6854f3393cedb605d4de49164399dc4b = $(`&lt;div id=&quot;html_6854f3393cedb605d4de49164399dc4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_20046359c5a19563513287429347d47d.setContent(html_6854f3393cedb605d4de49164399dc4b);
#
#
#
#         marker_317c78c97e35b2abd487d638182ed13d.bindPopup(popup_20046359c5a19563513287429347d47d)
#         ;
#
#
#
#
#             var marker_37d7869c72dbe8f502c4f996ed5a71dd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_329af1894a9e1d11f26f89c9afde9214);
#
#
#         var popup_9f2fb49673c2edbec32c233cf3fd5031 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a82c307b20ff5674ca84b283e29a8ff = $(`&lt;div id=&quot;html_8a82c307b20ff5674ca84b283e29a8ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9f2fb49673c2edbec32c233cf3fd5031.setContent(html_8a82c307b20ff5674ca84b283e29a8ff);
#
#
#
#         marker_37d7869c72dbe8f502c4f996ed5a71dd.bindPopup(popup_9f2fb49673c2edbec32c233cf3fd5031)
#         ;
#
#
#
#
#             var marker_078b52d334b827c149810d374c047a48 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_329af1894a9e1d11f26f89c9afde9214);
#
#
#         var popup_934a8f6cfef30166ae14288fdcccf3fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_243c5b9c98f7dbb4d1704da137c257b7 = $(`&lt;div id=&quot;html_243c5b9c98f7dbb4d1704da137c257b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_934a8f6cfef30166ae14288fdcccf3fd.setContent(html_243c5b9c98f7dbb4d1704da137c257b7);
#
#
#
#         marker_078b52d334b827c149810d374c047a48.bindPopup(popup_934a8f6cfef30166ae14288fdcccf3fd)
#         ;
#
#
#
#
#             var marker_37c343043891fdfa6b1e574ac944d6d0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_329af1894a9e1d11f26f89c9afde9214);
#
#
#         var popup_dde2f38fd9e48341e765bd283c42943f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_299a8e9769151de75b1f462f7f7f7195 = $(`&lt;div id=&quot;html_299a8e9769151de75b1f462f7f7f7195&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_dde2f38fd9e48341e765bd283c42943f.setContent(html_299a8e9769151de75b1f462f7f7f7195);
#
#
#
#         marker_37c343043891fdfa6b1e574ac944d6d0.bindPopup(popup_dde2f38fd9e48341e765bd283c42943f)
#         ;
#
#
#
#
#             var marker_e0d292bf67dc13b33ef4c8a6942cad96 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_329af1894a9e1d11f26f89c9afde9214);
#
#
#         var popup_bf9d902ee8f3863422d947e8c8229241 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d0ea13dda9f817c7941407080a84326 = $(`&lt;div id=&quot;html_3d0ea13dda9f817c7941407080a84326&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bf9d902ee8f3863422d947e8c8229241.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_539741b46fae51bde36035eefda629df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_539741b46fae51bde36035eefda629df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_539741b46fae51bde36035eefda629df = L.map(
#                 &quot;map_539741b46fae51bde36035eefda629df&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_925da8ccd52888b2632a91778cf1aed1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_925da8ccd52888b2632a91778cf1aed1.addTo(map_539741b46fae51bde36035eefda629df);
#
#
#             var feature_group_5c9a19978e48484732a5cb88579e860c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a006b34046c0b6f1b345a090dba4b933 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5c9a19978e48484732a5cb88579e860c);
#
#
#         var popup_b8b5e7975dd210f821c118d9210fed50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7528206024454db7efdf0b831b0a4e5d = $(`&lt;div id=&quot;html_7528206024454db7efdf0b831b0a4e5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b8b5e7975dd210f821c118d9210fed50.setContent(html_7528206024454db7efdf0b831b0a4e5d);
#
#
#
#         marker_a006b34046c0b6f1b345a090dba4b933.bindPopup(popup_b8b5e7975dd210f821c118d9210fed50)
#         ;
#
#
#
#
#             var marker_f1fa77e0391b2dec46807e6511af23ff = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5c9a19978e48484732a5cb88579e860c);
#
#
#         var popup_c73dd37d218e53674c50ffb2e1c16e60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad0ac6af4f5a410d786e29135a8ad25b = $(`&lt;div id=&quot;html_ad0ac6af4f5a410d786e29135a8ad25b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c73dd37d218e53674c50ffb2e1c16e60.setContent(html_ad0ac6af4f5a410d786e29135a8ad25b);
#
#
#
#         marker_f1fa77e0391b2dec46807e6511af23ff.bindPopup(popup_c73dd37d218e53674c50ffb2e1c16e60)
#         ;
#
#
#
#
#             var marker_b14f164ae3e30f314ffb7e8416c32c0f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5c9a19978e48484732a5cb88579e860c);
#
#
#         var popup_162399d54cf10eb34d97c8bd127c907d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c540fc8461c48b94ff5353ac8705023 = $(`&lt;div id=&quot;html_3c540fc8461c48b94ff5353ac8705023&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_162399d54cf10eb34d97c8bd127c907d.setContent(html_3c540fc8461c48b94ff5353ac8705023);
#
#
#
#         marker_b14f164ae3e30f314ffb7e8416c32c0f.bindPopup(popup_162399d54cf10eb34d97c8bd127c907d)
#         ;
#
#
#
#
#             var marker_030d5d389cb98698a77fcf3cde9305a1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5c9a19978e48484732a5cb88579e860c);
#
#
#         var popup_276690e878280a69dc0d5961370f880a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c6f7711af8efc8d312f4dcf5fd0dd53 = $(`&lt;div id=&quot;html_9c6f7711af8efc8d312f4dcf5fd0dd53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_276690e878280a69dc0d5961370f880a.setContent(html_9c6f7711af8efc8d312f4dcf5fd0dd53);
#
#
#
#         marker_030d5d389cb98698a77fcf3cde9305a1.bindPopup(popup_276690e878280a69dc0d5961370f880a)
#         ;
#
#
#
#
#             var marker_98d6745acff63d06809c969634744c4c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5c9a19978e48484732a5cb88579e860c);
#
#
#         var popup_5b38b64c39aac3d5b0889c0d6dfa9fba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_501765c3692879d426b896c1145c8ae8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_501765c3692879d426b896c1145c8ae8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_501765c3692879d426b896c1145c8ae8 = L.map(
#                 &quot;map_501765c3692879d426b896c1145c8ae8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83269034cbdd6cae3c9ef74f70d523fa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_83269034cbdd6cae3c9ef74f70d523fa.addTo(map_501765c3692879d426b896c1145c8ae8);
#
#
#             var feature_group_fd1cb845b944ee7ea2179ec931a913c8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fd1cb845b944ee7ea2179ec931a913c8.addTo(map_501765c3692879d426b896c1145c8ae8);
#
#
#             var feature_group_sub_group_8ce48d2658fe6a5d91088ba3d8a58857 = L.featureGroup.subGroup(
#                 feature_group_fd1cb845b944ee7ea2179ec931a913c8
#             );
#
#
#             var marker_f8e57225f101818651ea72bbb76a8d96 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8ce48d2658fe6a5d91088ba3d8a58857);
#
#
#         var popup_4aab44a46639f6a51d831ecd0dd2aac2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a164e910a56997b326319df00f1ceaa = $(`&lt;div id=&quot;html_5a164e910a56997b326319df00f1ceaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4aab44a46639f6a51d831ecd0dd2aac2.setContent(html_5a164e910a56997b326319df00f1ceaa);
#
#
#
#         marker_f8e57225f101818651ea72bbb76a8d96.bindPopup(popup_4aab44a46639f6a51d831ecd0dd2aac2)
#         ;
#
#
#
#
#             var marker_fec58b3b385b0ffe627abd0c86eed6ad = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8ce48d2658fe6a5d91088ba3d8a58857);
#
#
#         var popup_0e39b8afb0fb61ef712c8096df43a06c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7e6bd8175779559c1e7969210d12433 = $(`&lt;div id=&quot;html_f7e6bd8175779559c1e7969210d12433&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0e39b8afb0fb61ef712c8096df43a06c.setContent(html_f7e6bd8175779559c1e7969210d12433);
#
#
#
#         marker_fec58b3b385b0ffe627abd0c86eed6ad.bindPopup(popup_0e39b8afb0fb61ef712c8096df43a06c)
#         ;
#
#
#
#
#             var marker_dadb62dba48e4eaa2322ff9bb36b4acd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8ce48d2658fe6a5d91088ba3d8a58857);
#
#
#         var popup_bbadbc8da61717fab060dd0434ba00a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b582f389da13664f6b939b185eaa904a = $(`&lt;div id=&quot;html_b582f389da13664f6b939b185eaa904a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bbadbc8da61717fab060dd0434ba00a5.setContent(html_b582f389da13664f6b939b185eaa904a);
#
#
#
#         marker_dadb62dba48e4eaa2322ff9bb36b4acd.bindPopup(popup_bbadbc8da61717fab060dd0434ba00a5)
#         ;
#
#
#
#
#             var marker_01d19649e46e2e5517a4982f8213a6e0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8ce48d2658fe6a5d91088ba3d8a58857);
#
#
#         var popup_f4600f4e1ac4703ec1b3cf44bdf8da96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b939bf7a59d2ef5adb4d7d3a3b91a346 = $(`&lt;div id=&quot;html_b939bf7a59d2ef5adb4d7d3a3b91a346&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f4600f4e1ac4703ec1b3cf44bdf8da96.setContent(html_b939bf7a59d2ef5adb4d7d3a3b91a346);
#
#
#
#         marker_
