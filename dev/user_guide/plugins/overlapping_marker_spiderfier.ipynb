# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47e893606ee0afb64909bb5786cb8a86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47e893606ee0afb64909bb5786cb8a86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47e893606ee0afb64909bb5786cb8a86 = L.map(
#                 &quot;map_47e893606ee0afb64909bb5786cb8a86&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18eb9810c6a5bc39f27ba5d895629114 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18eb9810c6a5bc39f27ba5d895629114.addTo(map_47e893606ee0afb64909bb5786cb8a86);
#
#
#             var marker_232bbaffbe5796ac219bfbcd1fd6941a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_47e893606ee0afb64909bb5786cb8a86);
#
#
#         var popup_29604dd050535957024b769d5b3c9409 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5f1b994c0c1322780c926ff202574ca = $(`&lt;div id=&quot;html_e5f1b994c0c1322780c926ff202574ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_29604dd050535957024b769d5b3c9409.setContent(html_e5f1b994c0c1322780c926ff202574ca);
#
#
#
#         marker_232bbaffbe5796ac219bfbcd1fd6941a.bindPopup(popup_29604dd050535957024b769d5b3c9409)
#         ;
#
#
#
#
#             var marker_0dddcfd55569c0ac1819eecd5f715614 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_47e893606ee0afb64909bb5786cb8a86);
#
#
#         var popup_00ba1504b24da01d4342369cc734f9db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db6771e1d3b6f4e634516239141789c0 = $(`&lt;div id=&quot;html_db6771e1d3b6f4e634516239141789c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_00ba1504b24da01d4342369cc734f9db.setContent(html_db6771e1d3b6f4e634516239141789c0);
#
#
#
#         marker_0dddcfd55569c0ac1819eecd5f715614.bindPopup(popup_00ba1504b24da01d4342369cc734f9db)
#         ;
#
#
#
#
#             var marker_8fcce25dafcbd6331baf0a68e312a25f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_47e893606ee0afb64909bb5786cb8a86);
#
#
#         var popup_04c422cb9d9f8cc568501e32bf2d7e9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3f63e779ea4fcf05d34fdeaa1adef3c = $(`&lt;div id=&quot;html_a3f63e779ea4fcf05d34fdeaa1adef3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_04c422cb9d9f8cc568501e32bf2d7e9a.setContent(html_a3f63e779ea4fcf05d34fdeaa1adef3c);
#
#
#
#         marker_8fcce25dafcbd6331baf0a68e312a25f.bindPopup(popup_04c422cb9d9f8cc568501e32bf2d7e9a)
#         ;
#
#
#
#
#             var marker_546331a86a2b874f79ce095e9f26e0c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_47e893606ee0afb64909bb5786cb8a86);
#
#
#         var popup_b753503ac419bb01781ae1d74eaf053f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fea5b3f6718fbd752aa707c522a9d29 = $(`&lt;div id=&quot;html_6fea5b3f6718fbd752aa707c522a9d29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b753503ac419bb01781ae1d74eaf053f.setContent(html_6fea5b3f6718fbd752aa707c522a9d29);
#
#
#
#         marker_546331a86a2b874f79ce095e9f26e0c0.bindPopup(popup_b753503ac419bb01781ae1d74eaf053f)
#         ;
#
#
#
#
#             var marker_1695779ffb9ac579c4e2a33af945886e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_47e893606ee0afb64909bb5786cb8a86);
#
#
#         var popup_1635f4abaafdda4a71b156f627c3199d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_945baf1df7e54627fa10cf7f885d4769 = $(`&lt;div id=&quot;html_945baf1df7e54627fa10cf7f885d4769&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1635f4abaafdda4a71b156f627c3199d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e5981d7dc4b2cee218722319b45814a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e5981d7dc4b2cee218722319b45814a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e5981d7dc4b2cee218722319b45814a = L.map(
#                 &quot;map_3e5981d7dc4b2cee218722319b45814a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e13fcfed346a209025d22db83f2a33be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e13fcfed346a209025d22db83f2a33be.addTo(map_3e5981d7dc4b2cee218722319b45814a);
#
#
#             var feature_group_4ce2e57be8f7f72be2895a6d526ff16e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_892e70ca52fa8f8f41e46c71e98a7ac9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4ce2e57be8f7f72be2895a6d526ff16e);
#
#
#         var popup_62a63004dbd44488833e9cc0b0653106 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16f8655955500d8fde54f1030a19861b = $(`&lt;div id=&quot;html_16f8655955500d8fde54f1030a19861b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_62a63004dbd44488833e9cc0b0653106.setContent(html_16f8655955500d8fde54f1030a19861b);
#
#
#
#         marker_892e70ca52fa8f8f41e46c71e98a7ac9.bindPopup(popup_62a63004dbd44488833e9cc0b0653106)
#         ;
#
#
#
#
#             var marker_1455c2798e33225372daf64ab438bdcb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4ce2e57be8f7f72be2895a6d526ff16e);
#
#
#         var popup_58dde3f0f1ac7c44f125fed74d79d925 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85f02f666f5692a6dd314003e2051c43 = $(`&lt;div id=&quot;html_85f02f666f5692a6dd314003e2051c43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_58dde3f0f1ac7c44f125fed74d79d925.setContent(html_85f02f666f5692a6dd314003e2051c43);
#
#
#
#         marker_1455c2798e33225372daf64ab438bdcb.bindPopup(popup_58dde3f0f1ac7c44f125fed74d79d925)
#         ;
#
#
#
#
#             var marker_4db093663b2d6f810f431dc781ff092c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4ce2e57be8f7f72be2895a6d526ff16e);
#
#
#         var popup_0e49980c21a73d0bd071fdf5130aa2d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d2b4ef2a20c2ce7a0668027f6a0df8f = $(`&lt;div id=&quot;html_9d2b4ef2a20c2ce7a0668027f6a0df8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0e49980c21a73d0bd071fdf5130aa2d0.setContent(html_9d2b4ef2a20c2ce7a0668027f6a0df8f);
#
#
#
#         marker_4db093663b2d6f810f431dc781ff092c.bindPopup(popup_0e49980c21a73d0bd071fdf5130aa2d0)
#         ;
#
#
#
#
#             var marker_f9c77a0663afbea798e80093c6f845cc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4ce2e57be8f7f72be2895a6d526ff16e);
#
#
#         var popup_35fa9f447cd37369759409cb5c14a19f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ff84c5d195be961270ad8b6abbd6722 = $(`&lt;div id=&quot;html_8ff84c5d195be961270ad8b6abbd6722&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_35fa9f447cd37369759409cb5c14a19f.setContent(html_8ff84c5d195be961270ad8b6abbd6722);
#
#
#
#         marker_f9c77a0663afbea798e80093c6f845cc.bindPopup(popup_35fa9f447cd37369759409cb5c14a19f)
#         ;
#
#
#
#
#             var marker_5941068f5b54668eb62992874850440f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4ce2e57be8f7f72be2895a6d526ff16e);
#
#
#         var popup_c4d7b835ce082770fef62176fc9334f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23071f4e21029cc06f695a83aa5dabc5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23071f4e21029cc06f695a83aa5dabc5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23071f4e21029cc06f695a83aa5dabc5 = L.map(
#                 &quot;map_23071f4e21029cc06f695a83aa5dabc5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b7e114d18e8cb1da7552cfd3304382d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4b7e114d18e8cb1da7552cfd3304382d.addTo(map_23071f4e21029cc06f695a83aa5dabc5);
#
#
#             var feature_group_acf74075861a5d4ee5e37dde09f2d353 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_acf74075861a5d4ee5e37dde09f2d353.addTo(map_23071f4e21029cc06f695a83aa5dabc5);
#
#
#             var feature_group_sub_group_45ace4f4fc4d0e8f06aed9430e8821c5 = L.featureGroup.subGroup(
#                 feature_group_acf74075861a5d4ee5e37dde09f2d353
#             );
#
#
#             var marker_56e1416eb64599f6d9c4639d55ddc5ce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_45ace4f4fc4d0e8f06aed9430e8821c5);
#
#
#         var popup_8fcecd2d1ba498706b334960150c2ac1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e161f6d73108413593a9d1300ab838e = $(`&lt;div id=&quot;html_4e161f6d73108413593a9d1300ab838e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8fcecd2d1ba498706b334960150c2ac1.setContent(html_4e161f6d73108413593a9d1300ab838e);
#
#
#
#         marker_56e1416eb64599f6d9c4639d55ddc5ce.bindPopup(popup_8fcecd2d1ba498706b334960150c2ac1)
#         ;
#
#
#
#
#             var marker_0b5fe111d4f649e8374743b992444df6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_45ace4f4fc4d0e8f06aed9430e8821c5);
#
#
#         var popup_0564a9db8d76464b28e4c19dfb79190c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_679e3752ef5b7eaa13ceb128ccac2512 = $(`&lt;div id=&quot;html_679e3752ef5b7eaa13ceb128ccac2512&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0564a9db8d76464b28e4c19dfb79190c.setContent(html_679e3752ef5b7eaa13ceb128ccac2512);
#
#
#
#         marker_0b5fe111d4f649e8374743b992444df6.bindPopup(popup_0564a9db8d76464b28e4c19dfb79190c)
#         ;
#
#
#
#
#             var marker_be1fa70d8639abd5883a31b8adfee3e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_45ace4f4fc4d0e8f06aed9430e8821c5);
#
#
#         var popup_b1d586a90e7bb28809e44f2e65be8623 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a279d177e894a1e3646dfd4d4a7a9433 = $(`&lt;div id=&quot;html_a279d177e894a1e3646dfd4d4a7a9433&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b1d586a90e7bb28809e44f2e65be8623.setContent(html_a279d177e894a1e3646dfd4d4a7a9433);
#
#
#
#         marker_be1fa70d8639abd5883a31b8adfee3e8.bindPopup(popup_b1d586a90e7bb28809e44f2e65be8623)
#         ;
#
#
#
#
#             var marker_4daa563b20475e776813fd622011ad70 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_45ace4f4fc4d0e8f06aed9430e8821c5);
#
#
#         var popup_ba091dd649b5bb26e1c6cf8cefcfbfd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ea2f4b900ae938580d157d23fe9bd36 = $(`&lt;div id=&quot;html_0ea2f4b900ae938580d157d23fe9bd36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ba091dd649b5bb26e1c6cf8cefcfbfd4.setContent(html_0ea2f4b900ae938580d157d23fe9bd36);
#
#
#
#         marker_
