# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb251899a837690e10c2647c92dd28c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb251899a837690e10c2647c92dd28c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb251899a837690e10c2647c92dd28c5 = L.map(
#                 &quot;map_fb251899a837690e10c2647c92dd28c5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07cf3ddb38a35f214fc4a6740ba2239b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07cf3ddb38a35f214fc4a6740ba2239b.addTo(map_fb251899a837690e10c2647c92dd28c5);
#
#
#             var marker_c854d67355f6fa84e63af0644e32a4cc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fb251899a837690e10c2647c92dd28c5);
#
#
#         var popup_7b366c903f00b87005f9e863f2fa5fe0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e09c741157c16a588e52339662bbe45 = $(`&lt;div id=&quot;html_1e09c741157c16a588e52339662bbe45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7b366c903f00b87005f9e863f2fa5fe0.setContent(html_1e09c741157c16a588e52339662bbe45);
#
#
#
#         marker_c854d67355f6fa84e63af0644e32a4cc.bindPopup(popup_7b366c903f00b87005f9e863f2fa5fe0)
#         ;
#
#
#
#
#             var marker_43a6b32107398a603e355fb27df1a759 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fb251899a837690e10c2647c92dd28c5);
#
#
#         var popup_5c1e8126a61d305f0ea38ff6b15ce7b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_495e014ae03ca5d2bbc3b9b23e777a2a = $(`&lt;div id=&quot;html_495e014ae03ca5d2bbc3b9b23e777a2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5c1e8126a61d305f0ea38ff6b15ce7b7.setContent(html_495e014ae03ca5d2bbc3b9b23e777a2a);
#
#
#
#         marker_43a6b32107398a603e355fb27df1a759.bindPopup(popup_5c1e8126a61d305f0ea38ff6b15ce7b7)
#         ;
#
#
#
#
#             var marker_fef769cfa4500338591be49b8664d1ac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fb251899a837690e10c2647c92dd28c5);
#
#
#         var popup_b53f93b26b7027cc1b8b5a98592e3a2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_595fbc6d19188cba8e2d504fdeb678b4 = $(`&lt;div id=&quot;html_595fbc6d19188cba8e2d504fdeb678b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b53f93b26b7027cc1b8b5a98592e3a2b.setContent(html_595fbc6d19188cba8e2d504fdeb678b4);
#
#
#
#         marker_fef769cfa4500338591be49b8664d1ac.bindPopup(popup_b53f93b26b7027cc1b8b5a98592e3a2b)
#         ;
#
#
#
#
#             var marker_29d23e6a67d2c7e3416684dc010c5fc7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fb251899a837690e10c2647c92dd28c5);
#
#
#         var popup_7bf38cc554cd5c1263883ddd42c04f2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa644e17012a1bdf39caf8e27db5e4ac = $(`&lt;div id=&quot;html_aa644e17012a1bdf39caf8e27db5e4ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7bf38cc554cd5c1263883ddd42c04f2b.setContent(html_aa644e17012a1bdf39caf8e27db5e4ac);
#
#
#
#         marker_29d23e6a67d2c7e3416684dc010c5fc7.bindPopup(popup_7bf38cc554cd5c1263883ddd42c04f2b)
#         ;
#
#
#
#
#             var marker_054ec14544aee015c08bccca8bc39c1f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fb251899a837690e10c2647c92dd28c5);
#
#
#         var popup_1f883aaed80acc0ba0f0e6f60c3ffc75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57c96a65b7cac586050022e8429c3159 = $(`&lt;div id=&quot;html_57c96a65b7cac586050022e8429c3159&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1f883aaed80acc0ba0f0e6f60c3ffc75.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d036a11ee054db35486d5a829524767f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d036a11ee054db35486d5a829524767f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d036a11ee054db35486d5a829524767f = L.map(
#                 &quot;map_d036a11ee054db35486d5a829524767f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4d7994bfaf3481e6f349fccbb50687f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e4d7994bfaf3481e6f349fccbb50687f.addTo(map_d036a11ee054db35486d5a829524767f);
#
#
#             var feature_group_7de155e2f75cc03d44f8d69a4cd5cd9e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2391a1322bbec813eff824107e912688 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7de155e2f75cc03d44f8d69a4cd5cd9e);
#
#
#         var popup_0a147c98b1903a1847e71fa591e5c8b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49de39071f43c59804a218ee7dde5111 = $(`&lt;div id=&quot;html_49de39071f43c59804a218ee7dde5111&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0a147c98b1903a1847e71fa591e5c8b0.setContent(html_49de39071f43c59804a218ee7dde5111);
#
#
#
#         marker_2391a1322bbec813eff824107e912688.bindPopup(popup_0a147c98b1903a1847e71fa591e5c8b0)
#         ;
#
#
#
#
#             var marker_4c3e36e489e4df807dbcd3a6a8787fd9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7de155e2f75cc03d44f8d69a4cd5cd9e);
#
#
#         var popup_76257cbca001bddccc60ae5a2405fcac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c818fe9cec45c7c78dc14ae75bd7978 = $(`&lt;div id=&quot;html_4c818fe9cec45c7c78dc14ae75bd7978&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_76257cbca001bddccc60ae5a2405fcac.setContent(html_4c818fe9cec45c7c78dc14ae75bd7978);
#
#
#
#         marker_4c3e36e489e4df807dbcd3a6a8787fd9.bindPopup(popup_76257cbca001bddccc60ae5a2405fcac)
#         ;
#
#
#
#
#             var marker_07578a32ebb26ed60a368f7ff7f68248 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7de155e2f75cc03d44f8d69a4cd5cd9e);
#
#
#         var popup_f6624d54efd38783afa57d591363c618 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8624d72d3e03c16840437e72822a0710 = $(`&lt;div id=&quot;html_8624d72d3e03c16840437e72822a0710&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f6624d54efd38783afa57d591363c618.setContent(html_8624d72d3e03c16840437e72822a0710);
#
#
#
#         marker_07578a32ebb26ed60a368f7ff7f68248.bindPopup(popup_f6624d54efd38783afa57d591363c618)
#         ;
#
#
#
#
#             var marker_4021b7bc4c50b37bc540a5ba0410761c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7de155e2f75cc03d44f8d69a4cd5cd9e);
#
#
#         var popup_8848d424e4e2f1cd04a3c8305c818fa4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd863722f85c48d1a4acd5618f682950 = $(`&lt;div id=&quot;html_bd863722f85c48d1a4acd5618f682950&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8848d424e4e2f1cd04a3c8305c818fa4.setContent(html_bd863722f85c48d1a4acd5618f682950);
#
#
#
#         marker_4021b7bc4c50b37bc540a5ba0410761c.bindPopup(popup_8848d424e4e2f1cd04a3c8305c818fa4)
#         ;
#
#
#
#
#             var marker_4dac7346c162b6bc59ad8dc670047293 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7de155e2f75cc03d44f8d69a4cd5cd9e);
#
#
#         var popup_492e7d365d8bec2ecc58b07b4c5c5360 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_085618d80c1f362524b817de7c77fcf1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_085618d80c1f362524b817de7c77fcf1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_085618d80c1f362524b817de7c77fcf1 = L.map(
#                 &quot;map_085618d80c1f362524b817de7c77fcf1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8ed4717747dcc96741de3df711be07c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f8ed4717747dcc96741de3df711be07c.addTo(map_085618d80c1f362524b817de7c77fcf1);
#
#
#             var feature_group_1ed8dc314fb153a57d3597447b91c52f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1ed8dc314fb153a57d3597447b91c52f.addTo(map_085618d80c1f362524b817de7c77fcf1);
#
#
#             var feature_group_sub_group_e17f6ff5c8d78f0d1ffc0acda426bbb8 = L.featureGroup.subGroup(
#                 feature_group_1ed8dc314fb153a57d3597447b91c52f
#             );
#
#
#             var marker_4841e783bde94ccffec1f3448409a362 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e17f6ff5c8d78f0d1ffc0acda426bbb8);
#
#
#         var popup_a4ec13a7d2b0a58c4e1be5e5be7e560e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2e9cfa2ff0000a63ada052a5b80dfaf = $(`&lt;div id=&quot;html_d2e9cfa2ff0000a63ada052a5b80dfaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a4ec13a7d2b0a58c4e1be5e5be7e560e.setContent(html_d2e9cfa2ff0000a63ada052a5b80dfaf);
#
#
#
#         marker_4841e783bde94ccffec1f3448409a362.bindPopup(popup_a4ec13a7d2b0a58c4e1be5e5be7e560e)
#         ;
#
#
#
#
#             var marker_3c193875bfcff53c71af20fdf8ba760c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e17f6ff5c8d78f0d1ffc0acda426bbb8);
#
#
#         var popup_977d2058b0d5cff7ec5260e8be39d082 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23842fb00a4aaaa829b2565b90d62227 = $(`&lt;div id=&quot;html_23842fb00a4aaaa829b2565b90d62227&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_977d2058b0d5cff7ec5260e8be39d082.setContent(html_23842fb00a4aaaa829b2565b90d62227);
#
#
#
#         marker_3c193875bfcff53c71af20fdf8ba760c.bindPopup(popup_977d2058b0d5cff7ec5260e8be39d082)
#         ;
#
#
#
#
#             var marker_2400f74268e823703e663b3b29b01098 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e17f6ff5c8d78f0d1ffc0acda426bbb8);
#
#
#         var popup_c26125d4073a87dc5dd5d4f3381ad83b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bbc3d2a871e13270ed632a3ca39b663 = $(`&lt;div id=&quot;html_1bbc3d2a871e13270ed632a3ca39b663&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c26125d4073a87dc5dd5d4f3381ad83b.setContent(html_1bbc3d2a871e13270ed632a3ca39b663);
#
#
#
#         marker_2400f74268e823703e663b3b29b01098.bindPopup(popup_c26125d4073a87dc5dd5d4f3381ad83b)
#         ;
#
#
#
#
#             var marker_910e745880b65906f8a73e2cb37cac6e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e17f6ff5c8d78f0d1ffc0acda426bbb8);
#
#
#         var popup_b188fc2ad4fa91b1e08ee8b101e3b3ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db9ddb374793d1712c05ee7649d329e6 = $(`&lt;div id=&quot;html_db9ddb374793d1712c05ee7649d329e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b188fc2ad4fa91b1e08ee8b101e3b3ae.setContent(html_db9ddb374793d1712c05ee7649d329e6);
#
#
#
#         marker_
