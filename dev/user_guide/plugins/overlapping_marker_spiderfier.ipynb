# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1510719ec3e088e42ba40ff23ecff017 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1510719ec3e088e42ba40ff23ecff017&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1510719ec3e088e42ba40ff23ecff017 = L.map(
#                 &quot;map_1510719ec3e088e42ba40ff23ecff017&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_288e2723c9572a1eb56c51209eeceea4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_288e2723c9572a1eb56c51209eeceea4.addTo(map_1510719ec3e088e42ba40ff23ecff017);
#
#
#             var marker_719dc59fe509f1f1c813aee3063674a9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1510719ec3e088e42ba40ff23ecff017);
#
#
#         var popup_1b6dcf010e1d1457a002fe1257b0dd51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62c88cd04fbc195a98ef206a0f146a01 = $(`&lt;div id=&quot;html_62c88cd04fbc195a98ef206a0f146a01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1b6dcf010e1d1457a002fe1257b0dd51.setContent(html_62c88cd04fbc195a98ef206a0f146a01);
#
#
#
#         marker_719dc59fe509f1f1c813aee3063674a9.bindPopup(popup_1b6dcf010e1d1457a002fe1257b0dd51)
#         ;
#
#
#
#
#             var marker_c48589f714f358a3f82b6b01d4142f1a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1510719ec3e088e42ba40ff23ecff017);
#
#
#         var popup_4cf56f6a580d2abd781f8917e88cf151 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d473ac684005cf650d1d3d508bd8dd2e = $(`&lt;div id=&quot;html_d473ac684005cf650d1d3d508bd8dd2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4cf56f6a580d2abd781f8917e88cf151.setContent(html_d473ac684005cf650d1d3d508bd8dd2e);
#
#
#
#         marker_c48589f714f358a3f82b6b01d4142f1a.bindPopup(popup_4cf56f6a580d2abd781f8917e88cf151)
#         ;
#
#
#
#
#             var marker_f2add4bd3542cb6105a28144d79db02b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1510719ec3e088e42ba40ff23ecff017);
#
#
#         var popup_b115756619f0389060594b51a81962cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4d7493fd69ef88a09d97cb53cfdccdd = $(`&lt;div id=&quot;html_b4d7493fd69ef88a09d97cb53cfdccdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b115756619f0389060594b51a81962cb.setContent(html_b4d7493fd69ef88a09d97cb53cfdccdd);
#
#
#
#         marker_f2add4bd3542cb6105a28144d79db02b.bindPopup(popup_b115756619f0389060594b51a81962cb)
#         ;
#
#
#
#
#             var marker_339c93c4fd22405379b712e4a7d2eb85 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1510719ec3e088e42ba40ff23ecff017);
#
#
#         var popup_fe617ad57cbd0f2b8c7e01557773ede7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8128cd0177288107e72a62755a07952 = $(`&lt;div id=&quot;html_d8128cd0177288107e72a62755a07952&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fe617ad57cbd0f2b8c7e01557773ede7.setContent(html_d8128cd0177288107e72a62755a07952);
#
#
#
#         marker_339c93c4fd22405379b712e4a7d2eb85.bindPopup(popup_fe617ad57cbd0f2b8c7e01557773ede7)
#         ;
#
#
#
#
#             var marker_7f01046a68b6b520a25e6770f0273107 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1510719ec3e088e42ba40ff23ecff017);
#
#
#         var popup_e95d45cd1617bdc352fed45de9eb8efe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d01e0390a817803b5fffe32a7ae18782 = $(`&lt;div id=&quot;html_d01e0390a817803b5fffe32a7ae18782&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e95d45cd1617bdc352fed45de9eb8efe.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b6de5b69b64722f307b6fa773d2a02b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b6de5b69b64722f307b6fa773d2a02b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b6de5b69b64722f307b6fa773d2a02b = L.map(
#                 &quot;map_4b6de5b69b64722f307b6fa773d2a02b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afd9dc9e3d99e3b5a5cbd0727eca026f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afd9dc9e3d99e3b5a5cbd0727eca026f.addTo(map_4b6de5b69b64722f307b6fa773d2a02b);
#
#
#             var feature_group_b98ba04f0d2296ebc2e1e4ec6479cf93 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_27187068c5f88edf16b74af9ae7e49c3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b98ba04f0d2296ebc2e1e4ec6479cf93);
#
#
#         var popup_c316d8a36b7b750d5848bf9c0cb5a92f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4de88f4a267c50e2cee69bcab939ee63 = $(`&lt;div id=&quot;html_4de88f4a267c50e2cee69bcab939ee63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c316d8a36b7b750d5848bf9c0cb5a92f.setContent(html_4de88f4a267c50e2cee69bcab939ee63);
#
#
#
#         marker_27187068c5f88edf16b74af9ae7e49c3.bindPopup(popup_c316d8a36b7b750d5848bf9c0cb5a92f)
#         ;
#
#
#
#
#             var marker_9511499467faaa0d6e015d73b0448918 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b98ba04f0d2296ebc2e1e4ec6479cf93);
#
#
#         var popup_7aaa224b7b746707da402b4fb62a68e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a8019202645f33b4323054f59408839 = $(`&lt;div id=&quot;html_0a8019202645f33b4323054f59408839&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7aaa224b7b746707da402b4fb62a68e4.setContent(html_0a8019202645f33b4323054f59408839);
#
#
#
#         marker_9511499467faaa0d6e015d73b0448918.bindPopup(popup_7aaa224b7b746707da402b4fb62a68e4)
#         ;
#
#
#
#
#             var marker_fa231510d65a61086dc4367e847f3314 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b98ba04f0d2296ebc2e1e4ec6479cf93);
#
#
#         var popup_74e480864f18fc687032fa16570d76ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_caab4c5cb0533346878877536b80e520 = $(`&lt;div id=&quot;html_caab4c5cb0533346878877536b80e520&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_74e480864f18fc687032fa16570d76ab.setContent(html_caab4c5cb0533346878877536b80e520);
#
#
#
#         marker_fa231510d65a61086dc4367e847f3314.bindPopup(popup_74e480864f18fc687032fa16570d76ab)
#         ;
#
#
#
#
#             var marker_a33abf235ce98d05d7891dfb9e3d0945 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b98ba04f0d2296ebc2e1e4ec6479cf93);
#
#
#         var popup_92a802d6d3b407ae477b21d4d024ff96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc66d5e22990a1a6b41f09e3d562c1a6 = $(`&lt;div id=&quot;html_cc66d5e22990a1a6b41f09e3d562c1a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_92a802d6d3b407ae477b21d4d024ff96.setContent(html_cc66d5e22990a1a6b41f09e3d562c1a6);
#
#
#
#         marker_a33abf235ce98d05d7891dfb9e3d0945.bindPopup(popup_92a802d6d3b407ae477b21d4d024ff96)
#         ;
#
#
#
#
#             var marker_7542b35ca69cd4fdd2b1331ed8619478 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b98ba04f0d2296ebc2e1e4ec6479cf93);
#
#
#         var popup_88d60fdd13c4a7d716ccbd3b07ea9436 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_982bdc25693049d5c8c251c510ae7d8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_982bdc25693049d5c8c251c510ae7d8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_982bdc25693049d5c8c251c510ae7d8a = L.map(
#                 &quot;map_982bdc25693049d5c8c251c510ae7d8a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79417fee137881235d3855d1a197cf68 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_79417fee137881235d3855d1a197cf68.addTo(map_982bdc25693049d5c8c251c510ae7d8a);
#
#
#             var feature_group_ca7be8676352dda977ce7bfc9a9f2166 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ca7be8676352dda977ce7bfc9a9f2166.addTo(map_982bdc25693049d5c8c251c510ae7d8a);
#
#
#             var feature_group_sub_group_a71c044c6db31233cbd892981cc3ef68 = L.featureGroup.subGroup(
#                 feature_group_ca7be8676352dda977ce7bfc9a9f2166
#             );
#
#
#             var marker_b4fb1e2aa61e6e510b10a10866de9cca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a71c044c6db31233cbd892981cc3ef68);
#
#
#         var popup_5bee6301188c9a61733e6838bec71080 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee11c6749aa67e2b7df9c68edd19f757 = $(`&lt;div id=&quot;html_ee11c6749aa67e2b7df9c68edd19f757&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5bee6301188c9a61733e6838bec71080.setContent(html_ee11c6749aa67e2b7df9c68edd19f757);
#
#
#
#         marker_b4fb1e2aa61e6e510b10a10866de9cca.bindPopup(popup_5bee6301188c9a61733e6838bec71080)
#         ;
#
#
#
#
#             var marker_659de851644d3209ba76200bd5cd6cc4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a71c044c6db31233cbd892981cc3ef68);
#
#
#         var popup_42ef20295f82f75d992a20ae120738c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13a24c8fd690150c4b8367d7a8ba5157 = $(`&lt;div id=&quot;html_13a24c8fd690150c4b8367d7a8ba5157&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_42ef20295f82f75d992a20ae120738c0.setContent(html_13a24c8fd690150c4b8367d7a8ba5157);
#
#
#
#         marker_659de851644d3209ba76200bd5cd6cc4.bindPopup(popup_42ef20295f82f75d992a20ae120738c0)
#         ;
#
#
#
#
#             var marker_eced74673258b0425e09a141b9dd6631 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a71c044c6db31233cbd892981cc3ef68);
#
#
#         var popup_3520b0f47e6a4e42aabe2ccccc1e096c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4438830d2d5dddfdd7948c9e3700684 = $(`&lt;div id=&quot;html_e4438830d2d5dddfdd7948c9e3700684&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3520b0f47e6a4e42aabe2ccccc1e096c.setContent(html_e4438830d2d5dddfdd7948c9e3700684);
#
#
#
#         marker_eced74673258b0425e09a141b9dd6631.bindPopup(popup_3520b0f47e6a4e42aabe2ccccc1e096c)
#         ;
#
#
#
#
#             var marker_3ba23e44a51712611727437b0bc9de50 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a71c044c6db31233cbd892981cc3ef68);
#
#
#         var popup_8abd02d772a18d821e107542841348e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_769e6d991165bd31370d61179f363a63 = $(`&lt;div id=&quot;html_769e6d991165bd31370d61179f363a63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8abd02d772a18d821e107542841348e4.setContent(html_769e6d991165bd31370d61179f363a63);
#
#
#
#         marker_
