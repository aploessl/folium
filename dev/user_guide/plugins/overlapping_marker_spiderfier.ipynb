# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_410ac8328389d9b3c50787169563b65a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_410ac8328389d9b3c50787169563b65a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_410ac8328389d9b3c50787169563b65a = L.map(
#                 &quot;map_410ac8328389d9b3c50787169563b65a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1682571016db7b06a43d1ff9c9f54ef4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1682571016db7b06a43d1ff9c9f54ef4.addTo(map_410ac8328389d9b3c50787169563b65a);
#
#
#             var marker_622d7b93fba9ba07fb264ed6f946c834 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_410ac8328389d9b3c50787169563b65a);
#
#
#         var popup_7986ba75ad7dfea3def45121dd1f90da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dfc350833a5e17ebe825ce5a3ce339a = $(`&lt;div id=&quot;html_0dfc350833a5e17ebe825ce5a3ce339a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7986ba75ad7dfea3def45121dd1f90da.setContent(html_0dfc350833a5e17ebe825ce5a3ce339a);
#
#
#
#         marker_622d7b93fba9ba07fb264ed6f946c834.bindPopup(popup_7986ba75ad7dfea3def45121dd1f90da)
#         ;
#
#
#
#
#             var marker_d92afbbce39ef8f60d0ff04a54613ed4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_410ac8328389d9b3c50787169563b65a);
#
#
#         var popup_61f103d06cd523c103f9455e30fc93de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7603c2eee4494f514534f8e2cd6b7602 = $(`&lt;div id=&quot;html_7603c2eee4494f514534f8e2cd6b7602&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_61f103d06cd523c103f9455e30fc93de.setContent(html_7603c2eee4494f514534f8e2cd6b7602);
#
#
#
#         marker_d92afbbce39ef8f60d0ff04a54613ed4.bindPopup(popup_61f103d06cd523c103f9455e30fc93de)
#         ;
#
#
#
#
#             var marker_e81406b89a1ce0b77705cb9195025614 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_410ac8328389d9b3c50787169563b65a);
#
#
#         var popup_e4876950c1e848fd46bdd02361ab03c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c63841be0a4db11f041ae1dd661250e4 = $(`&lt;div id=&quot;html_c63841be0a4db11f041ae1dd661250e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e4876950c1e848fd46bdd02361ab03c2.setContent(html_c63841be0a4db11f041ae1dd661250e4);
#
#
#
#         marker_e81406b89a1ce0b77705cb9195025614.bindPopup(popup_e4876950c1e848fd46bdd02361ab03c2)
#         ;
#
#
#
#
#             var marker_ee72bc87f60bb30a01c4ac8695795593 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_410ac8328389d9b3c50787169563b65a);
#
#
#         var popup_a7122fdd6b2a0ffe13e3fa75bd680c82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53bcf3d1036fd94bc92e6e3b8f6e7fd0 = $(`&lt;div id=&quot;html_53bcf3d1036fd94bc92e6e3b8f6e7fd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a7122fdd6b2a0ffe13e3fa75bd680c82.setContent(html_53bcf3d1036fd94bc92e6e3b8f6e7fd0);
#
#
#
#         marker_ee72bc87f60bb30a01c4ac8695795593.bindPopup(popup_a7122fdd6b2a0ffe13e3fa75bd680c82)
#         ;
#
#
#
#
#             var marker_4dd25053109ae1b791a9598b801698a3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_410ac8328389d9b3c50787169563b65a);
#
#
#         var popup_e72573d970a814f9ee81da30e7178e7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5365d0a68885f4c843195a8e66b0a715 = $(`&lt;div id=&quot;html_5365d0a68885f4c843195a8e66b0a715&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e72573d970a814f9ee81da30e7178e7a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_194a4469fd4507e7a2119cbe1c6bb52e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_194a4469fd4507e7a2119cbe1c6bb52e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_194a4469fd4507e7a2119cbe1c6bb52e = L.map(
#                 &quot;map_194a4469fd4507e7a2119cbe1c6bb52e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_33edf4d6cc477ec9b8fb256309b47040 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_33edf4d6cc477ec9b8fb256309b47040.addTo(map_194a4469fd4507e7a2119cbe1c6bb52e);
#
#
#             var feature_group_e6b883de1a9413fea896643cacd0b841 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_73eec7a42a4413d4b5483ff06983c5ec = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e6b883de1a9413fea896643cacd0b841);
#
#
#         var popup_c01fbe4ddf713f3526fd9b2e1f712443 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa88a6c25249e2a4eb731d38e09bf675 = $(`&lt;div id=&quot;html_aa88a6c25249e2a4eb731d38e09bf675&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c01fbe4ddf713f3526fd9b2e1f712443.setContent(html_aa88a6c25249e2a4eb731d38e09bf675);
#
#
#
#         marker_73eec7a42a4413d4b5483ff06983c5ec.bindPopup(popup_c01fbe4ddf713f3526fd9b2e1f712443)
#         ;
#
#
#
#
#             var marker_3dc87439d135629459c5acb5bc959bb4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e6b883de1a9413fea896643cacd0b841);
#
#
#         var popup_99f6c9a520b92e1de33481fd0e9cd26d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85db2a2b7b83aed8fd2930a8a96bfe3b = $(`&lt;div id=&quot;html_85db2a2b7b83aed8fd2930a8a96bfe3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_99f6c9a520b92e1de33481fd0e9cd26d.setContent(html_85db2a2b7b83aed8fd2930a8a96bfe3b);
#
#
#
#         marker_3dc87439d135629459c5acb5bc959bb4.bindPopup(popup_99f6c9a520b92e1de33481fd0e9cd26d)
#         ;
#
#
#
#
#             var marker_5e791fe0ea650b45b7799a981733be0b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e6b883de1a9413fea896643cacd0b841);
#
#
#         var popup_7afeac9868187bfdafa136fd7fe62c6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4338103263b8a6e8cc970a6b8d873cc9 = $(`&lt;div id=&quot;html_4338103263b8a6e8cc970a6b8d873cc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7afeac9868187bfdafa136fd7fe62c6c.setContent(html_4338103263b8a6e8cc970a6b8d873cc9);
#
#
#
#         marker_5e791fe0ea650b45b7799a981733be0b.bindPopup(popup_7afeac9868187bfdafa136fd7fe62c6c)
#         ;
#
#
#
#
#             var marker_0220baae24492d3219578dbacff82b14 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e6b883de1a9413fea896643cacd0b841);
#
#
#         var popup_ca942bf687e9dd6b303d3b4d6148f49d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45ef75626eadf2e0394d23cb3a93394d = $(`&lt;div id=&quot;html_45ef75626eadf2e0394d23cb3a93394d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ca942bf687e9dd6b303d3b4d6148f49d.setContent(html_45ef75626eadf2e0394d23cb3a93394d);
#
#
#
#         marker_0220baae24492d3219578dbacff82b14.bindPopup(popup_ca942bf687e9dd6b303d3b4d6148f49d)
#         ;
#
#
#
#
#             var marker_e64d40e8c88b8df3742b53b32b3e3123 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e6b883de1a9413fea896643cacd0b841);
#
#
#         var popup_296aae89a95cacbd5f24abbfdab47aa5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5ec72d533eca13e360f2dd1d1eb7551 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5ec72d533eca13e360f2dd1d1eb7551&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5ec72d533eca13e360f2dd1d1eb7551 = L.map(
#                 &quot;map_b5ec72d533eca13e360f2dd1d1eb7551&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f903f99de3fabf3bef4505b8e3b7c137 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f903f99de3fabf3bef4505b8e3b7c137.addTo(map_b5ec72d533eca13e360f2dd1d1eb7551);
#
#
#             var feature_group_b5c9a4a177aa65ee2451409a6d745a61 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b5c9a4a177aa65ee2451409a6d745a61.addTo(map_b5ec72d533eca13e360f2dd1d1eb7551);
#
#
#             var feature_group_sub_group_b7b58b912e9ec5f92abf9d8cf0fdce0d = L.featureGroup.subGroup(
#                 feature_group_b5c9a4a177aa65ee2451409a6d745a61
#             );
#
#
#             var marker_f3e01234615afee9c8479cfd5cd66897 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b7b58b912e9ec5f92abf9d8cf0fdce0d);
#
#
#         var popup_14fc21b0829f675b063de6b2d995bf0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c4eb95b6e26a4088f516c19204f670d = $(`&lt;div id=&quot;html_0c4eb95b6e26a4088f516c19204f670d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_14fc21b0829f675b063de6b2d995bf0c.setContent(html_0c4eb95b6e26a4088f516c19204f670d);
#
#
#
#         marker_f3e01234615afee9c8479cfd5cd66897.bindPopup(popup_14fc21b0829f675b063de6b2d995bf0c)
#         ;
#
#
#
#
#             var marker_003b7dd5c6ff348b4e5a89d646d29363 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b7b58b912e9ec5f92abf9d8cf0fdce0d);
#
#
#         var popup_1bde51fc36f078785e9e7a5004ea75e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71515de79941548a1239aa096e9c83dd = $(`&lt;div id=&quot;html_71515de79941548a1239aa096e9c83dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1bde51fc36f078785e9e7a5004ea75e2.setContent(html_71515de79941548a1239aa096e9c83dd);
#
#
#
#         marker_003b7dd5c6ff348b4e5a89d646d29363.bindPopup(popup_1bde51fc36f078785e9e7a5004ea75e2)
#         ;
#
#
#
#
#             var marker_f83f8b93b9a64b5043928213e7d5c581 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b7b58b912e9ec5f92abf9d8cf0fdce0d);
#
#
#         var popup_591a8f970f53759ebb3be23dd248481a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83c08f1c928b26c99cbeefa9a197a61d = $(`&lt;div id=&quot;html_83c08f1c928b26c99cbeefa9a197a61d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_591a8f970f53759ebb3be23dd248481a.setContent(html_83c08f1c928b26c99cbeefa9a197a61d);
#
#
#
#         marker_f83f8b93b9a64b5043928213e7d5c581.bindPopup(popup_591a8f970f53759ebb3be23dd248481a)
#         ;
#
#
#
#
#             var marker_700265674b7e05e76e474990b1a73aec = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b7b58b912e9ec5f92abf9d8cf0fdce0d);
#
#
#         var popup_4b6181f7eef82cfe2b60eb4f5e01cbfd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf5f80730b8c5c048c16ccadfa0bdd67 = $(`&lt;div id=&quot;html_bf5f80730b8c5c048c16ccadfa0bdd67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4b6181f7eef82cfe2b60eb4f5e01cbfd.setContent(html_bf5f80730b8c5c048c16ccadfa0bdd67);
#
#
#
#         marker_
