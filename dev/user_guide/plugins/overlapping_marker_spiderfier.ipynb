# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90ba796c75bb683dccf4407fbdfbcd88 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90ba796c75bb683dccf4407fbdfbcd88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90ba796c75bb683dccf4407fbdfbcd88 = L.map(
#                 &quot;map_90ba796c75bb683dccf4407fbdfbcd88&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2cb25dabe920cdfbbc603e27b259f51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d2cb25dabe920cdfbbc603e27b259f51.addTo(map_90ba796c75bb683dccf4407fbdfbcd88);
#
#
#             var marker_7ca1859924b4c6aa0c7c6b637e0c5364 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_90ba796c75bb683dccf4407fbdfbcd88);
#
#
#         var popup_d6bdf5e08a2e3ac2522bcc70dc418e1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31f0271e22c44e60670fd64a5d72ee35 = $(`&lt;div id=&quot;html_31f0271e22c44e60670fd64a5d72ee35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d6bdf5e08a2e3ac2522bcc70dc418e1c.setContent(html_31f0271e22c44e60670fd64a5d72ee35);
#
#
#
#         marker_7ca1859924b4c6aa0c7c6b637e0c5364.bindPopup(popup_d6bdf5e08a2e3ac2522bcc70dc418e1c)
#         ;
#
#
#
#
#             var marker_d5a1539b588b5b91f219462a4911b7a1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_90ba796c75bb683dccf4407fbdfbcd88);
#
#
#         var popup_e18d8874a88ce5d2756c89c9e607b171 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7b398108e3e680000142cd194b87f94 = $(`&lt;div id=&quot;html_a7b398108e3e680000142cd194b87f94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e18d8874a88ce5d2756c89c9e607b171.setContent(html_a7b398108e3e680000142cd194b87f94);
#
#
#
#         marker_d5a1539b588b5b91f219462a4911b7a1.bindPopup(popup_e18d8874a88ce5d2756c89c9e607b171)
#         ;
#
#
#
#
#             var marker_007c31aab170380b8f1152b126ba8ac3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_90ba796c75bb683dccf4407fbdfbcd88);
#
#
#         var popup_519fa445effa6cd00bd85494437548da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d9bf1f13054ab95935f7fccdacd8e82 = $(`&lt;div id=&quot;html_0d9bf1f13054ab95935f7fccdacd8e82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_519fa445effa6cd00bd85494437548da.setContent(html_0d9bf1f13054ab95935f7fccdacd8e82);
#
#
#
#         marker_007c31aab170380b8f1152b126ba8ac3.bindPopup(popup_519fa445effa6cd00bd85494437548da)
#         ;
#
#
#
#
#             var marker_698d226530cfa1929a995ebe12decfdb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_90ba796c75bb683dccf4407fbdfbcd88);
#
#
#         var popup_f56e8987387e2b16db2eeddb99f35c4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a21c259ffa2cd2e15d3bb6b60b581436 = $(`&lt;div id=&quot;html_a21c259ffa2cd2e15d3bb6b60b581436&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f56e8987387e2b16db2eeddb99f35c4b.setContent(html_a21c259ffa2cd2e15d3bb6b60b581436);
#
#
#
#         marker_698d226530cfa1929a995ebe12decfdb.bindPopup(popup_f56e8987387e2b16db2eeddb99f35c4b)
#         ;
#
#
#
#
#             var marker_c3873669e05dc67c5ad665e46c9450d2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_90ba796c75bb683dccf4407fbdfbcd88);
#
#
#         var popup_27b6eee6d353618e9479595203b1092d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f69c6280a34bf2132a73fc3d67764369 = $(`&lt;div id=&quot;html_f69c6280a34bf2132a73fc3d67764369&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_27b6eee6d353618e9479595203b1092d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf4bff0e1226866c427b334ae5620505 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf4bff0e1226866c427b334ae5620505&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf4bff0e1226866c427b334ae5620505 = L.map(
#                 &quot;map_bf4bff0e1226866c427b334ae5620505&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9527b4aab412c98b51812e5e9ca215dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9527b4aab412c98b51812e5e9ca215dd.addTo(map_bf4bff0e1226866c427b334ae5620505);
#
#
#             var feature_group_6f27f19445635774ed5c1d6469b9667f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_93c9f2e41cc9db5ee3d67cb5437b5cb1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6f27f19445635774ed5c1d6469b9667f);
#
#
#         var popup_a0a3b6cb0f8d58ef7273b246f5f9b300 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a39f7523f3f45c06cdb95fd95aefa197 = $(`&lt;div id=&quot;html_a39f7523f3f45c06cdb95fd95aefa197&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a0a3b6cb0f8d58ef7273b246f5f9b300.setContent(html_a39f7523f3f45c06cdb95fd95aefa197);
#
#
#
#         marker_93c9f2e41cc9db5ee3d67cb5437b5cb1.bindPopup(popup_a0a3b6cb0f8d58ef7273b246f5f9b300)
#         ;
#
#
#
#
#             var marker_9e847f5c5843c151fb4d2969473f7770 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6f27f19445635774ed5c1d6469b9667f);
#
#
#         var popup_4e9eb51cd9f879a9c82a1c92acd4557c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7b6308fdcf129fff53083d507a9faa8 = $(`&lt;div id=&quot;html_a7b6308fdcf129fff53083d507a9faa8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4e9eb51cd9f879a9c82a1c92acd4557c.setContent(html_a7b6308fdcf129fff53083d507a9faa8);
#
#
#
#         marker_9e847f5c5843c151fb4d2969473f7770.bindPopup(popup_4e9eb51cd9f879a9c82a1c92acd4557c)
#         ;
#
#
#
#
#             var marker_3a90f33270d79c050dc18d73984fe3d0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6f27f19445635774ed5c1d6469b9667f);
#
#
#         var popup_f20e7533cc69a377e81469bf7a206183 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b1eb2c235e4940b1679a092a788a718 = $(`&lt;div id=&quot;html_5b1eb2c235e4940b1679a092a788a718&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f20e7533cc69a377e81469bf7a206183.setContent(html_5b1eb2c235e4940b1679a092a788a718);
#
#
#
#         marker_3a90f33270d79c050dc18d73984fe3d0.bindPopup(popup_f20e7533cc69a377e81469bf7a206183)
#         ;
#
#
#
#
#             var marker_3e29889a9ecac44886af8ee880e8fcef = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6f27f19445635774ed5c1d6469b9667f);
#
#
#         var popup_c39ea6a1fa3d89fb57618e34014668c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a64d186eaf08baa868d9ee293006625c = $(`&lt;div id=&quot;html_a64d186eaf08baa868d9ee293006625c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c39ea6a1fa3d89fb57618e34014668c9.setContent(html_a64d186eaf08baa868d9ee293006625c);
#
#
#
#         marker_3e29889a9ecac44886af8ee880e8fcef.bindPopup(popup_c39ea6a1fa3d89fb57618e34014668c9)
#         ;
#
#
#
#
#             var marker_d9e6e3186c435b523c14359fb0213b3b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6f27f19445635774ed5c1d6469b9667f);
#
#
#         var popup_ef57f91aa9b00f27f142b7c30bf65096 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28d129b6a2da752a1e97837c384e9a11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28d129b6a2da752a1e97837c384e9a11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28d129b6a2da752a1e97837c384e9a11 = L.map(
#                 &quot;map_28d129b6a2da752a1e97837c384e9a11&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e87f24236071bc70afea2fb689c2953e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e87f24236071bc70afea2fb689c2953e.addTo(map_28d129b6a2da752a1e97837c384e9a11);
#
#
#             var feature_group_16a5d595c24241502962f635bf0e88c6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_16a5d595c24241502962f635bf0e88c6.addTo(map_28d129b6a2da752a1e97837c384e9a11);
#
#
#             var feature_group_sub_group_ccbf9c54f329fc135e637f801f9a02e1 = L.featureGroup.subGroup(
#                 feature_group_16a5d595c24241502962f635bf0e88c6
#             );
#
#
#             var marker_884357e8e90fb9bd958869a6ed67e20e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ccbf9c54f329fc135e637f801f9a02e1);
#
#
#         var popup_0fec5e650ad40e2c25644869e99d9a87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_731c6e5a02d3169832956f0241f65f1a = $(`&lt;div id=&quot;html_731c6e5a02d3169832956f0241f65f1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0fec5e650ad40e2c25644869e99d9a87.setContent(html_731c6e5a02d3169832956f0241f65f1a);
#
#
#
#         marker_884357e8e90fb9bd958869a6ed67e20e.bindPopup(popup_0fec5e650ad40e2c25644869e99d9a87)
#         ;
#
#
#
#
#             var marker_c7aaba348f64b323e926a18e5089ade0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ccbf9c54f329fc135e637f801f9a02e1);
#
#
#         var popup_f1060978d3213e4ac2b4b0ac6fae38f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9f99d5a70b7e53930035e3690d87a65 = $(`&lt;div id=&quot;html_f9f99d5a70b7e53930035e3690d87a65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f1060978d3213e4ac2b4b0ac6fae38f3.setContent(html_f9f99d5a70b7e53930035e3690d87a65);
#
#
#
#         marker_c7aaba348f64b323e926a18e5089ade0.bindPopup(popup_f1060978d3213e4ac2b4b0ac6fae38f3)
#         ;
#
#
#
#
#             var marker_f36b27b12e485694b5ce5ee92c7da5b5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ccbf9c54f329fc135e637f801f9a02e1);
#
#
#         var popup_88820d67964d1551bd9cb5a2c9775626 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33fb1c2abd5ded02e6028ee9c32c06bc = $(`&lt;div id=&quot;html_33fb1c2abd5ded02e6028ee9c32c06bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_88820d67964d1551bd9cb5a2c9775626.setContent(html_33fb1c2abd5ded02e6028ee9c32c06bc);
#
#
#
#         marker_f36b27b12e485694b5ce5ee92c7da5b5.bindPopup(popup_88820d67964d1551bd9cb5a2c9775626)
#         ;
#
#
#
#
#             var marker_8d2e3616776f6c617315371572830d25 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ccbf9c54f329fc135e637f801f9a02e1);
#
#
#         var popup_c1cfa8464d60487336a6e3d1dab9a76b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3748121d323b3d0826a59fd1f2784fdf = $(`&lt;div id=&quot;html_3748121d323b3d0826a59fd1f2784fdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c1cfa8464d60487336a6e3d1dab9a76b.setContent(html_3748121d323b3d0826a59fd1f2784fdf);
#
#
#
#         marker_
