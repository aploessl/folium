# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_954d8b16a4004519b8585f55e01ce6d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_954d8b16a4004519b8585f55e01ce6d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_954d8b16a4004519b8585f55e01ce6d4 = L.map(
#                 &quot;map_954d8b16a4004519b8585f55e01ce6d4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd434afce491a161156479835aff09c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bd434afce491a161156479835aff09c5.addTo(map_954d8b16a4004519b8585f55e01ce6d4);
#
#
#             var marker_cf2d38d5a1198f51b7145f05e830b08d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_954d8b16a4004519b8585f55e01ce6d4);
#
#
#         var popup_b02fe4c74ed6419d35cc27ee8b053dab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8202ce2db63c976a7c99f8f30a1a5f8 = $(`&lt;div id=&quot;html_e8202ce2db63c976a7c99f8f30a1a5f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b02fe4c74ed6419d35cc27ee8b053dab.setContent(html_e8202ce2db63c976a7c99f8f30a1a5f8);
#
#
#
#         marker_cf2d38d5a1198f51b7145f05e830b08d.bindPopup(popup_b02fe4c74ed6419d35cc27ee8b053dab)
#         ;
#
#
#
#
#             var marker_a927865d74ac5b0d67271cfe82d9fc25 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_954d8b16a4004519b8585f55e01ce6d4);
#
#
#         var popup_5d0caea8824fa1f241598f9dd6639f79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef341d3579628b7c6994960caff62aad = $(`&lt;div id=&quot;html_ef341d3579628b7c6994960caff62aad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5d0caea8824fa1f241598f9dd6639f79.setContent(html_ef341d3579628b7c6994960caff62aad);
#
#
#
#         marker_a927865d74ac5b0d67271cfe82d9fc25.bindPopup(popup_5d0caea8824fa1f241598f9dd6639f79)
#         ;
#
#
#
#
#             var marker_b3f38cd9ba332e097366f59ed9541b07 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_954d8b16a4004519b8585f55e01ce6d4);
#
#
#         var popup_049e9a36f330dc1204c318a11f63aabb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5867d4660cbf07501e752ce9a8cf75b = $(`&lt;div id=&quot;html_f5867d4660cbf07501e752ce9a8cf75b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_049e9a36f330dc1204c318a11f63aabb.setContent(html_f5867d4660cbf07501e752ce9a8cf75b);
#
#
#
#         marker_b3f38cd9ba332e097366f59ed9541b07.bindPopup(popup_049e9a36f330dc1204c318a11f63aabb)
#         ;
#
#
#
#
#             var marker_0ed14cc2a204a0b71ae712f1786015eb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_954d8b16a4004519b8585f55e01ce6d4);
#
#
#         var popup_05974e3199c922fd9914b20f502121db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6518ffb236499b23f53f24c9d6802aab = $(`&lt;div id=&quot;html_6518ffb236499b23f53f24c9d6802aab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_05974e3199c922fd9914b20f502121db.setContent(html_6518ffb236499b23f53f24c9d6802aab);
#
#
#
#         marker_0ed14cc2a204a0b71ae712f1786015eb.bindPopup(popup_05974e3199c922fd9914b20f502121db)
#         ;
#
#
#
#
#             var marker_6563af4484ca4513abf249dd3eec6e3e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_954d8b16a4004519b8585f55e01ce6d4);
#
#
#         var popup_d27545fcd5d6f42b846bf70bf157526c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa8b173342fe1ff01806e4a2755ade4f = $(`&lt;div id=&quot;html_aa8b173342fe1ff01806e4a2755ade4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d27545fcd5d6f42b846bf70bf157526c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df783bdddd327b8970c0725bdbf7ac05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df783bdddd327b8970c0725bdbf7ac05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df783bdddd327b8970c0725bdbf7ac05 = L.map(
#                 &quot;map_df783bdddd327b8970c0725bdbf7ac05&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_abfb5fbc22a8781b0e78bb7b9ab2547f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_abfb5fbc22a8781b0e78bb7b9ab2547f.addTo(map_df783bdddd327b8970c0725bdbf7ac05);
#
#
#             var feature_group_3d377528bfbebb765bf80617b40668ab = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_48146a251c35dc2d3ce4e88490d1afed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3d377528bfbebb765bf80617b40668ab);
#
#
#         var popup_f6c1b4f35d7bf4d09a48a2d0fa1f0691 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa343e9323fa5872d738f367ffe24181 = $(`&lt;div id=&quot;html_aa343e9323fa5872d738f367ffe24181&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f6c1b4f35d7bf4d09a48a2d0fa1f0691.setContent(html_aa343e9323fa5872d738f367ffe24181);
#
#
#
#         marker_48146a251c35dc2d3ce4e88490d1afed.bindPopup(popup_f6c1b4f35d7bf4d09a48a2d0fa1f0691)
#         ;
#
#
#
#
#             var marker_6c4e13aae1321307f84e6095f6143faf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3d377528bfbebb765bf80617b40668ab);
#
#
#         var popup_cc4d97d1809c2d47807166cedf799422 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63915f26deb4ef708f39f595005a0779 = $(`&lt;div id=&quot;html_63915f26deb4ef708f39f595005a0779&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cc4d97d1809c2d47807166cedf799422.setContent(html_63915f26deb4ef708f39f595005a0779);
#
#
#
#         marker_6c4e13aae1321307f84e6095f6143faf.bindPopup(popup_cc4d97d1809c2d47807166cedf799422)
#         ;
#
#
#
#
#             var marker_3730c8fec3abe5363f333c28b8fc66d7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3d377528bfbebb765bf80617b40668ab);
#
#
#         var popup_4c4d0f3bc099363cb8bfd82d1de8fd72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6e973649a42a455ce1ffeabbaa02f81 = $(`&lt;div id=&quot;html_e6e973649a42a455ce1ffeabbaa02f81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4c4d0f3bc099363cb8bfd82d1de8fd72.setContent(html_e6e973649a42a455ce1ffeabbaa02f81);
#
#
#
#         marker_3730c8fec3abe5363f333c28b8fc66d7.bindPopup(popup_4c4d0f3bc099363cb8bfd82d1de8fd72)
#         ;
#
#
#
#
#             var marker_ed5bfd3fc4764d769b46f30a530637f3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3d377528bfbebb765bf80617b40668ab);
#
#
#         var popup_f08e281276b5276a8b4e19578f104384 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be9ac323927abb776ba787581b6f13ba = $(`&lt;div id=&quot;html_be9ac323927abb776ba787581b6f13ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f08e281276b5276a8b4e19578f104384.setContent(html_be9ac323927abb776ba787581b6f13ba);
#
#
#
#         marker_ed5bfd3fc4764d769b46f30a530637f3.bindPopup(popup_f08e281276b5276a8b4e19578f104384)
#         ;
#
#
#
#
#             var marker_94e2b2d74162f7cb04f50cfa1904c37b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3d377528bfbebb765bf80617b40668ab);
#
#
#         var popup_17a9ec5327ae92ca8181a6bebe9da220 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b7778484c035bae3f67fcbe046f26a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b7778484c035bae3f67fcbe046f26a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b7778484c035bae3f67fcbe046f26a0 = L.map(
#                 &quot;map_1b7778484c035bae3f67fcbe046f26a0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ce8afe8cea219235cc585aa74947dbb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ce8afe8cea219235cc585aa74947dbb.addTo(map_1b7778484c035bae3f67fcbe046f26a0);
#
#
#             var feature_group_a5c015ccab8a32373d0ccfc756d002ee = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a5c015ccab8a32373d0ccfc756d002ee.addTo(map_1b7778484c035bae3f67fcbe046f26a0);
#
#
#             var feature_group_sub_group_16840698c20f45b3e71f3a130e462746 = L.featureGroup.subGroup(
#                 feature_group_a5c015ccab8a32373d0ccfc756d002ee
#             );
#
#
#             var marker_5d3d4b258bac25939bfe9c88e9a70f47 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_16840698c20f45b3e71f3a130e462746);
#
#
#         var popup_d116bd41f66b94b194cb5c07e2b89166 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_209347b72c30115e5214d0faaf970a47 = $(`&lt;div id=&quot;html_209347b72c30115e5214d0faaf970a47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d116bd41f66b94b194cb5c07e2b89166.setContent(html_209347b72c30115e5214d0faaf970a47);
#
#
#
#         marker_5d3d4b258bac25939bfe9c88e9a70f47.bindPopup(popup_d116bd41f66b94b194cb5c07e2b89166)
#         ;
#
#
#
#
#             var marker_de7ab848b20924408aa65d99fd842850 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_16840698c20f45b3e71f3a130e462746);
#
#
#         var popup_eb664c88cd23b4f16cef036f2c13138a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0365cbc731b87aa4d788640f916a4fe5 = $(`&lt;div id=&quot;html_0365cbc731b87aa4d788640f916a4fe5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_eb664c88cd23b4f16cef036f2c13138a.setContent(html_0365cbc731b87aa4d788640f916a4fe5);
#
#
#
#         marker_de7ab848b20924408aa65d99fd842850.bindPopup(popup_eb664c88cd23b4f16cef036f2c13138a)
#         ;
#
#
#
#
#             var marker_4803e8a92653a6100658207237915a8a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_16840698c20f45b3e71f3a130e462746);
#
#
#         var popup_cf88b683c0307ddcfddd7733479c7a5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8cc3d21a7b69cc24763328d5eedefa6 = $(`&lt;div id=&quot;html_e8cc3d21a7b69cc24763328d5eedefa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_cf88b683c0307ddcfddd7733479c7a5a.setContent(html_e8cc3d21a7b69cc24763328d5eedefa6);
#
#
#
#         marker_4803e8a92653a6100658207237915a8a.bindPopup(popup_cf88b683c0307ddcfddd7733479c7a5a)
#         ;
#
#
#
#
#             var marker_3b4ff491eccc743580065c083e603d98 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_16840698c20f45b3e71f3a130e462746);
#
#
#         var popup_2e5ddd528e64d7f08c5750834add36f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22bf15001103edbff417cd43dfc7f0af = $(`&lt;div id=&quot;html_22bf15001103edbff417cd43dfc7f0af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2e5ddd528e64d7f08c5750834add36f0.setContent(html_22bf15001103edbff417cd43dfc7f0af);
#
#
#
#         marker_
