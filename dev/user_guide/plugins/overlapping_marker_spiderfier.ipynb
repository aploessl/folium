# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01389df7e8115fe05f315478e23f618b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01389df7e8115fe05f315478e23f618b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01389df7e8115fe05f315478e23f618b = L.map(
#                 &quot;map_01389df7e8115fe05f315478e23f618b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52211730281c0242c3fac821e5a4b7d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_52211730281c0242c3fac821e5a4b7d5.addTo(map_01389df7e8115fe05f315478e23f618b);
#
#
#             var marker_dd8e5db4a06d01d26a9b058823bfb201 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_01389df7e8115fe05f315478e23f618b);
#
#
#         var popup_1d5ee6bbf41ca427011abbcf1e0b8be5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7eb9c3e0f0f423db4a09ea27e20377ae = $(`&lt;div id=&quot;html_7eb9c3e0f0f423db4a09ea27e20377ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1d5ee6bbf41ca427011abbcf1e0b8be5.setContent(html_7eb9c3e0f0f423db4a09ea27e20377ae);
#
#
#
#         marker_dd8e5db4a06d01d26a9b058823bfb201.bindPopup(popup_1d5ee6bbf41ca427011abbcf1e0b8be5)
#         ;
#
#
#
#
#             var marker_aef181ec6ae7832be4810168228dd73f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_01389df7e8115fe05f315478e23f618b);
#
#
#         var popup_95e6a489c45bde6f3239c784aec3abac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_873647b7e45584711a6872f8c4889f09 = $(`&lt;div id=&quot;html_873647b7e45584711a6872f8c4889f09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_95e6a489c45bde6f3239c784aec3abac.setContent(html_873647b7e45584711a6872f8c4889f09);
#
#
#
#         marker_aef181ec6ae7832be4810168228dd73f.bindPopup(popup_95e6a489c45bde6f3239c784aec3abac)
#         ;
#
#
#
#
#             var marker_0479321c22c5b44f3dff50dc3616a693 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_01389df7e8115fe05f315478e23f618b);
#
#
#         var popup_de2482c37034d3410ec5df7273008a94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93c71e9a8e3f973197aa6f0c427e629c = $(`&lt;div id=&quot;html_93c71e9a8e3f973197aa6f0c427e629c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_de2482c37034d3410ec5df7273008a94.setContent(html_93c71e9a8e3f973197aa6f0c427e629c);
#
#
#
#         marker_0479321c22c5b44f3dff50dc3616a693.bindPopup(popup_de2482c37034d3410ec5df7273008a94)
#         ;
#
#
#
#
#             var marker_27549978441915bc36688215ec46d15b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_01389df7e8115fe05f315478e23f618b);
#
#
#         var popup_85ec9889c0d4827a2f9db530a0f6d627 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_317556ae22fc4193962c62b6a01d68d7 = $(`&lt;div id=&quot;html_317556ae22fc4193962c62b6a01d68d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_85ec9889c0d4827a2f9db530a0f6d627.setContent(html_317556ae22fc4193962c62b6a01d68d7);
#
#
#
#         marker_27549978441915bc36688215ec46d15b.bindPopup(popup_85ec9889c0d4827a2f9db530a0f6d627)
#         ;
#
#
#
#
#             var marker_7c992972c6cd5114408e1d2578740ea0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_01389df7e8115fe05f315478e23f618b);
#
#
#         var popup_5b7fed0454b151397c99cac61627da8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a473471eb082f0e3a38abe497c5b79df = $(`&lt;div id=&quot;html_a473471eb082f0e3a38abe497c5b79df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5b7fed0454b151397c99cac61627da8f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96f7e27c2ab407e8b3c6f15cf43493e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96f7e27c2ab407e8b3c6f15cf43493e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96f7e27c2ab407e8b3c6f15cf43493e5 = L.map(
#                 &quot;map_96f7e27c2ab407e8b3c6f15cf43493e5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc7be2880db859ef3a93cde88b9ccc60 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dc7be2880db859ef3a93cde88b9ccc60.addTo(map_96f7e27c2ab407e8b3c6f15cf43493e5);
#
#
#             var feature_group_0e8848f982e8abb6f80fc75f5dfa9e1d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_83b20344b148a1c595d615860004e38a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0e8848f982e8abb6f80fc75f5dfa9e1d);
#
#
#         var popup_a664f7d10f700ba71ec00662314a58df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cdbfc5a553ec6a47077546f85d65167 = $(`&lt;div id=&quot;html_1cdbfc5a553ec6a47077546f85d65167&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a664f7d10f700ba71ec00662314a58df.setContent(html_1cdbfc5a553ec6a47077546f85d65167);
#
#
#
#         marker_83b20344b148a1c595d615860004e38a.bindPopup(popup_a664f7d10f700ba71ec00662314a58df)
#         ;
#
#
#
#
#             var marker_e00f5e2be53ab3551b64ec219503b1fb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0e8848f982e8abb6f80fc75f5dfa9e1d);
#
#
#         var popup_b59f1b4809713ec0cde05543d1b13622 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d447cebc16575f1d2c8d11f614ab2ff0 = $(`&lt;div id=&quot;html_d447cebc16575f1d2c8d11f614ab2ff0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b59f1b4809713ec0cde05543d1b13622.setContent(html_d447cebc16575f1d2c8d11f614ab2ff0);
#
#
#
#         marker_e00f5e2be53ab3551b64ec219503b1fb.bindPopup(popup_b59f1b4809713ec0cde05543d1b13622)
#         ;
#
#
#
#
#             var marker_3a2c699134bd1bca4c11bf696282d262 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0e8848f982e8abb6f80fc75f5dfa9e1d);
#
#
#         var popup_76d9c4a89d7adc71593c244b172e06bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51720e225bfd236847bc2e1a9d9def00 = $(`&lt;div id=&quot;html_51720e225bfd236847bc2e1a9d9def00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_76d9c4a89d7adc71593c244b172e06bc.setContent(html_51720e225bfd236847bc2e1a9d9def00);
#
#
#
#         marker_3a2c699134bd1bca4c11bf696282d262.bindPopup(popup_76d9c4a89d7adc71593c244b172e06bc)
#         ;
#
#
#
#
#             var marker_ddd149ad4316eab46c78881f4443e540 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0e8848f982e8abb6f80fc75f5dfa9e1d);
#
#
#         var popup_3c856e766a6a958c207d4a5d5c968d39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93cdad67609da0c0ecda09dbf093e08a = $(`&lt;div id=&quot;html_93cdad67609da0c0ecda09dbf093e08a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3c856e766a6a958c207d4a5d5c968d39.setContent(html_93cdad67609da0c0ecda09dbf093e08a);
#
#
#
#         marker_ddd149ad4316eab46c78881f4443e540.bindPopup(popup_3c856e766a6a958c207d4a5d5c968d39)
#         ;
#
#
#
#
#             var marker_f9b2a7f5c9db0e1adbe418f31add4c13 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0e8848f982e8abb6f80fc75f5dfa9e1d);
#
#
#         var popup_a77367f8acd5736d9e6399b874f1436f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef09f1ac50d89e707aa06830989aa331 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef09f1ac50d89e707aa06830989aa331&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef09f1ac50d89e707aa06830989aa331 = L.map(
#                 &quot;map_ef09f1ac50d89e707aa06830989aa331&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02c2168c0bf872d206c7b27bd9124848 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_02c2168c0bf872d206c7b27bd9124848.addTo(map_ef09f1ac50d89e707aa06830989aa331);
#
#
#             var feature_group_aaf64aa4825edfdf2ce90c71bef63bfc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_aaf64aa4825edfdf2ce90c71bef63bfc.addTo(map_ef09f1ac50d89e707aa06830989aa331);
#
#
#             var feature_group_sub_group_2c3bd65d257f4e495d24789db85d8fcd = L.featureGroup.subGroup(
#                 feature_group_aaf64aa4825edfdf2ce90c71bef63bfc
#             );
#
#
#             var marker_5364d96d4b76188d17d8521dfe88a59a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2c3bd65d257f4e495d24789db85d8fcd);
#
#
#         var popup_6a6253e48d711d5d86baa936eff8adec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_773e72a9f62b0b0c65d72030371383a5 = $(`&lt;div id=&quot;html_773e72a9f62b0b0c65d72030371383a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6a6253e48d711d5d86baa936eff8adec.setContent(html_773e72a9f62b0b0c65d72030371383a5);
#
#
#
#         marker_5364d96d4b76188d17d8521dfe88a59a.bindPopup(popup_6a6253e48d711d5d86baa936eff8adec)
#         ;
#
#
#
#
#             var marker_daac0817932f0a64c5f0bd1f6fb29ca5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2c3bd65d257f4e495d24789db85d8fcd);
#
#
#         var popup_adc94f7f43008320563ee4822ab86943 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c409bf7c5dd87bd61dc5e7dfcf7b5ba = $(`&lt;div id=&quot;html_4c409bf7c5dd87bd61dc5e7dfcf7b5ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_adc94f7f43008320563ee4822ab86943.setContent(html_4c409bf7c5dd87bd61dc5e7dfcf7b5ba);
#
#
#
#         marker_daac0817932f0a64c5f0bd1f6fb29ca5.bindPopup(popup_adc94f7f43008320563ee4822ab86943)
#         ;
#
#
#
#
#             var marker_b59ab4e4f7db70fb1ac052bb04628fbe = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2c3bd65d257f4e495d24789db85d8fcd);
#
#
#         var popup_0297f9f85e729a8f0be18dcd5abfcbde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68ac5760701611de323240049473e31c = $(`&lt;div id=&quot;html_68ac5760701611de323240049473e31c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0297f9f85e729a8f0be18dcd5abfcbde.setContent(html_68ac5760701611de323240049473e31c);
#
#
#
#         marker_b59ab4e4f7db70fb1ac052bb04628fbe.bindPopup(popup_0297f9f85e729a8f0be18dcd5abfcbde)
#         ;
#
#
#
#
#             var marker_29c6c061439f4d540cacb8849cb68e7f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2c3bd65d257f4e495d24789db85d8fcd);
#
#
#         var popup_371898e04076dfe437d04f41c132366d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15d1a2f864af2d62fcec3fe15c19154d = $(`&lt;div id=&quot;html_15d1a2f864af2d62fcec3fe15c19154d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_371898e04076dfe437d04f41c132366d.setContent(html_15d1a2f864af2d62fcec3fe15c19154d);
#
#
#
#         marker_
