# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f15cfc67a1e2f677d1135a9a59ac4989 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f15cfc67a1e2f677d1135a9a59ac4989&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f15cfc67a1e2f677d1135a9a59ac4989 = L.map(
#                 &quot;map_f15cfc67a1e2f677d1135a9a59ac4989&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9f638a2e415b6d376f425168babd32a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a9f638a2e415b6d376f425168babd32a.addTo(map_f15cfc67a1e2f677d1135a9a59ac4989);
#
#
#             var marker_c9e93a7d65fdad0d11033e8562795af1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f15cfc67a1e2f677d1135a9a59ac4989);
#
#
#         var popup_b6510d65629abbf7e4fd60686e2e0c5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecbf346a98692fbb51b69f2b1e6b8264 = $(`&lt;div id=&quot;html_ecbf346a98692fbb51b69f2b1e6b8264&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b6510d65629abbf7e4fd60686e2e0c5a.setContent(html_ecbf346a98692fbb51b69f2b1e6b8264);
#
#
#
#         marker_c9e93a7d65fdad0d11033e8562795af1.bindPopup(popup_b6510d65629abbf7e4fd60686e2e0c5a)
#         ;
#
#
#
#
#             var marker_6676a83e299ca1ac26e385394c2f84cc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f15cfc67a1e2f677d1135a9a59ac4989);
#
#
#         var popup_53794a50de1b1db4d356d1f6b86b3032 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8826f5ca7317df2faec0dfc53d70350 = $(`&lt;div id=&quot;html_b8826f5ca7317df2faec0dfc53d70350&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_53794a50de1b1db4d356d1f6b86b3032.setContent(html_b8826f5ca7317df2faec0dfc53d70350);
#
#
#
#         marker_6676a83e299ca1ac26e385394c2f84cc.bindPopup(popup_53794a50de1b1db4d356d1f6b86b3032)
#         ;
#
#
#
#
#             var marker_bebeb2c3fd7f78c8ca1d73e80a0d0cb8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f15cfc67a1e2f677d1135a9a59ac4989);
#
#
#         var popup_e95bcd3ebaf973dfbbbd86c95d7c7353 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_658f71b7c4ae97c8931c6eb08238a08c = $(`&lt;div id=&quot;html_658f71b7c4ae97c8931c6eb08238a08c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e95bcd3ebaf973dfbbbd86c95d7c7353.setContent(html_658f71b7c4ae97c8931c6eb08238a08c);
#
#
#
#         marker_bebeb2c3fd7f78c8ca1d73e80a0d0cb8.bindPopup(popup_e95bcd3ebaf973dfbbbd86c95d7c7353)
#         ;
#
#
#
#
#             var marker_9b8ae479da11695fd92c704c5af2e02b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f15cfc67a1e2f677d1135a9a59ac4989);
#
#
#         var popup_c7a764f27519f903f1563accd1c32219 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8eea35d6a9e1240841c4f7f026fcc7e = $(`&lt;div id=&quot;html_c8eea35d6a9e1240841c4f7f026fcc7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c7a764f27519f903f1563accd1c32219.setContent(html_c8eea35d6a9e1240841c4f7f026fcc7e);
#
#
#
#         marker_9b8ae479da11695fd92c704c5af2e02b.bindPopup(popup_c7a764f27519f903f1563accd1c32219)
#         ;
#
#
#
#
#             var marker_417548b908a28676a5173184439dd390 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f15cfc67a1e2f677d1135a9a59ac4989);
#
#
#         var popup_329f07546b232c0edde99d97f48740c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_238005d36a607b7cbd214b1458424a55 = $(`&lt;div id=&quot;html_238005d36a607b7cbd214b1458424a55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_329f07546b232c0edde99d97f48740c0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c2718360e71ffc06ff4c0b8c1b2009c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c2718360e71ffc06ff4c0b8c1b2009c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c2718360e71ffc06ff4c0b8c1b2009c = L.map(
#                 &quot;map_5c2718360e71ffc06ff4c0b8c1b2009c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d800c9c4965dde6b0da06e99699ac7ac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d800c9c4965dde6b0da06e99699ac7ac.addTo(map_5c2718360e71ffc06ff4c0b8c1b2009c);
#
#
#             var feature_group_c70fdfac5bfa98891954723241b86992 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bfa5c1cc9a6dddce9dd6e34b950ad775 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c70fdfac5bfa98891954723241b86992);
#
#
#         var popup_b4acb3ddd6829ca83a7157e37c6398d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d8c36b1566a542a598ca9a063c6e96a = $(`&lt;div id=&quot;html_6d8c36b1566a542a598ca9a063c6e96a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b4acb3ddd6829ca83a7157e37c6398d9.setContent(html_6d8c36b1566a542a598ca9a063c6e96a);
#
#
#
#         marker_bfa5c1cc9a6dddce9dd6e34b950ad775.bindPopup(popup_b4acb3ddd6829ca83a7157e37c6398d9)
#         ;
#
#
#
#
#             var marker_1227991460ba2acd286e4f794d9c79e8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c70fdfac5bfa98891954723241b86992);
#
#
#         var popup_576cbe7080fce776ffdb3d2d1119a22b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15aa7420ae19f741df4499acae191683 = $(`&lt;div id=&quot;html_15aa7420ae19f741df4499acae191683&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_576cbe7080fce776ffdb3d2d1119a22b.setContent(html_15aa7420ae19f741df4499acae191683);
#
#
#
#         marker_1227991460ba2acd286e4f794d9c79e8.bindPopup(popup_576cbe7080fce776ffdb3d2d1119a22b)
#         ;
#
#
#
#
#             var marker_8f0f5a31949ee3a7a3c94e4192b73c5c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c70fdfac5bfa98891954723241b86992);
#
#
#         var popup_b69c1ea99e367b2164fa4da1265b4c67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed3e9f922b6b228ba6c88d692026d67c = $(`&lt;div id=&quot;html_ed3e9f922b6b228ba6c88d692026d67c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b69c1ea99e367b2164fa4da1265b4c67.setContent(html_ed3e9f922b6b228ba6c88d692026d67c);
#
#
#
#         marker_8f0f5a31949ee3a7a3c94e4192b73c5c.bindPopup(popup_b69c1ea99e367b2164fa4da1265b4c67)
#         ;
#
#
#
#
#             var marker_814a19cc4e52c84bf0d89a7e2060913e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c70fdfac5bfa98891954723241b86992);
#
#
#         var popup_1f65f849af5fd3c09af61c6c83b543e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00ef81e6809265f2909024aef550055e = $(`&lt;div id=&quot;html_00ef81e6809265f2909024aef550055e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1f65f849af5fd3c09af61c6c83b543e4.setContent(html_00ef81e6809265f2909024aef550055e);
#
#
#
#         marker_814a19cc4e52c84bf0d89a7e2060913e.bindPopup(popup_1f65f849af5fd3c09af61c6c83b543e4)
#         ;
#
#
#
#
#             var marker_0d5f5f5ee03e281244e58deb2a3fd317 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c70fdfac5bfa98891954723241b86992);
#
#
#         var popup_b5bd0d39fd0041cab1d548d0330adc1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ede0c2347dbf9102f20fd1e3348ce479 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ede0c2347dbf9102f20fd1e3348ce479&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ede0c2347dbf9102f20fd1e3348ce479 = L.map(
#                 &quot;map_ede0c2347dbf9102f20fd1e3348ce479&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3664dd2e9415b5a6223a4f2f5bfc25e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3664dd2e9415b5a6223a4f2f5bfc25e.addTo(map_ede0c2347dbf9102f20fd1e3348ce479);
#
#
#             var feature_group_84b42da9d088b79ca158f57a2275304d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_84b42da9d088b79ca158f57a2275304d.addTo(map_ede0c2347dbf9102f20fd1e3348ce479);
#
#
#             var feature_group_sub_group_25ce3279bcb6ea57d7bc577b82bb09a7 = L.featureGroup.subGroup(
#                 feature_group_84b42da9d088b79ca158f57a2275304d
#             );
#
#
#             var marker_cda5a82b56c70ed7f8b620f29d6cee35 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_25ce3279bcb6ea57d7bc577b82bb09a7);
#
#
#         var popup_9524adce87b9e15366ac164f41847dca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a50bd9d5a216d5b62cb6ad12d3aad3a0 = $(`&lt;div id=&quot;html_a50bd9d5a216d5b62cb6ad12d3aad3a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9524adce87b9e15366ac164f41847dca.setContent(html_a50bd9d5a216d5b62cb6ad12d3aad3a0);
#
#
#
#         marker_cda5a82b56c70ed7f8b620f29d6cee35.bindPopup(popup_9524adce87b9e15366ac164f41847dca)
#         ;
#
#
#
#
#             var marker_84dac0f1531642c44d807086e0aa5307 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_25ce3279bcb6ea57d7bc577b82bb09a7);
#
#
#         var popup_c8bd29eb41edd90e6936bffa7330c4fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d92c6aa897aa5a4c977fedf8c455d63 = $(`&lt;div id=&quot;html_2d92c6aa897aa5a4c977fedf8c455d63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c8bd29eb41edd90e6936bffa7330c4fc.setContent(html_2d92c6aa897aa5a4c977fedf8c455d63);
#
#
#
#         marker_84dac0f1531642c44d807086e0aa5307.bindPopup(popup_c8bd29eb41edd90e6936bffa7330c4fc)
#         ;
#
#
#
#
#             var marker_0ef2e6b4f7094c668fa3df95557bec76 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_25ce3279bcb6ea57d7bc577b82bb09a7);
#
#
#         var popup_89e19f7ce9b2a43f08498daf81796df9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b024e8f89d89f710e943f6317e5e5e08 = $(`&lt;div id=&quot;html_b024e8f89d89f710e943f6317e5e5e08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_89e19f7ce9b2a43f08498daf81796df9.setContent(html_b024e8f89d89f710e943f6317e5e5e08);
#
#
#
#         marker_0ef2e6b4f7094c668fa3df95557bec76.bindPopup(popup_89e19f7ce9b2a43f08498daf81796df9)
#         ;
#
#
#
#
#             var marker_9872070918eced4c7fb316f26833130b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_25ce3279bcb6ea57d7bc577b82bb09a7);
#
#
#         var popup_99fdedb4b6e90c44067dab36804fc520 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e064c67cbe61b5bfbb16b6c263e6d2c = $(`&lt;div id=&quot;html_5e064c67cbe61b5bfbb16b6c263e6d2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_99fdedb4b6e90c44067dab36804fc520.setContent(html_5e064c67cbe61b5bfbb16b6c263e6d2c);
#
#
#
#         marker_
