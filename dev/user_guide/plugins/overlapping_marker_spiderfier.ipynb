# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75e36a39f1407be134c64d9086f18651 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75e36a39f1407be134c64d9086f18651&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75e36a39f1407be134c64d9086f18651 = L.map(
#                 &quot;map_75e36a39f1407be134c64d9086f18651&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c87d5093b8c74238c1b8429b430d9a7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c87d5093b8c74238c1b8429b430d9a7.addTo(map_75e36a39f1407be134c64d9086f18651);
#
#
#             var marker_409829ee739485ad580765f620b549ff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_75e36a39f1407be134c64d9086f18651);
#
#
#         var popup_c6ef28b30d1fd052a36c9ab70b0b8d1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59f33f10b01e1361a9a001f53a70e693 = $(`&lt;div id=&quot;html_59f33f10b01e1361a9a001f53a70e693&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c6ef28b30d1fd052a36c9ab70b0b8d1f.setContent(html_59f33f10b01e1361a9a001f53a70e693);
#
#
#
#         marker_409829ee739485ad580765f620b549ff.bindPopup(popup_c6ef28b30d1fd052a36c9ab70b0b8d1f)
#         ;
#
#
#
#
#             var marker_63bf3153b6f5a78f92d0b31f9e75cbe2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_75e36a39f1407be134c64d9086f18651);
#
#
#         var popup_e55f9e189dbf2d0bd5ca07c14f3c095b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b41e4e76b41df166e339b77e4b0b14c5 = $(`&lt;div id=&quot;html_b41e4e76b41df166e339b77e4b0b14c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e55f9e189dbf2d0bd5ca07c14f3c095b.setContent(html_b41e4e76b41df166e339b77e4b0b14c5);
#
#
#
#         marker_63bf3153b6f5a78f92d0b31f9e75cbe2.bindPopup(popup_e55f9e189dbf2d0bd5ca07c14f3c095b)
#         ;
#
#
#
#
#             var marker_833d24cf74ea421efb06bfab563d59ec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_75e36a39f1407be134c64d9086f18651);
#
#
#         var popup_026b1b28d8e8cbed3a8e84c39baafeb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07e475952ae09fa6706573944cc59d22 = $(`&lt;div id=&quot;html_07e475952ae09fa6706573944cc59d22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_026b1b28d8e8cbed3a8e84c39baafeb5.setContent(html_07e475952ae09fa6706573944cc59d22);
#
#
#
#         marker_833d24cf74ea421efb06bfab563d59ec.bindPopup(popup_026b1b28d8e8cbed3a8e84c39baafeb5)
#         ;
#
#
#
#
#             var marker_956fb933aa6a5b7180e541d566b05b93 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_75e36a39f1407be134c64d9086f18651);
#
#
#         var popup_78faf43d01822a118fe493a4e3338c5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4acec90c2b6b2e2368dfec8fcf95a90 = $(`&lt;div id=&quot;html_a4acec90c2b6b2e2368dfec8fcf95a90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_78faf43d01822a118fe493a4e3338c5f.setContent(html_a4acec90c2b6b2e2368dfec8fcf95a90);
#
#
#
#         marker_956fb933aa6a5b7180e541d566b05b93.bindPopup(popup_78faf43d01822a118fe493a4e3338c5f)
#         ;
#
#
#
#
#             var marker_7876c36646f7cfdfaae3c321611506b9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_75e36a39f1407be134c64d9086f18651);
#
#
#         var popup_7c626a7cde7ee7fd73c4b3face34f87a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f356c14a1fed3203447570180a0555fd = $(`&lt;div id=&quot;html_f356c14a1fed3203447570180a0555fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7c626a7cde7ee7fd73c4b3face34f87a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7d8fe2ab370ca3e669bfd00c2736c2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7d8fe2ab370ca3e669bfd00c2736c2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7d8fe2ab370ca3e669bfd00c2736c2f = L.map(
#                 &quot;map_b7d8fe2ab370ca3e669bfd00c2736c2f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6ab67afb00faff8a55d9b1c01bc4171 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c6ab67afb00faff8a55d9b1c01bc4171.addTo(map_b7d8fe2ab370ca3e669bfd00c2736c2f);
#
#
#             var feature_group_9df6bc3c079d595e3ce0b6091a059b75 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6c0992b4659ea3341a6ac4b1a850f924 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9df6bc3c079d595e3ce0b6091a059b75);
#
#
#         var popup_4c70c32efcfd28bce51bb22c2dfe2bc1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba8f5bccbab368e76cd9275409e00734 = $(`&lt;div id=&quot;html_ba8f5bccbab368e76cd9275409e00734&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4c70c32efcfd28bce51bb22c2dfe2bc1.setContent(html_ba8f5bccbab368e76cd9275409e00734);
#
#
#
#         marker_6c0992b4659ea3341a6ac4b1a850f924.bindPopup(popup_4c70c32efcfd28bce51bb22c2dfe2bc1)
#         ;
#
#
#
#
#             var marker_8db6ce9be3c7b0c0395c5140e72d374c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9df6bc3c079d595e3ce0b6091a059b75);
#
#
#         var popup_72a625a5cc98fcf7c3228ac8d327b179 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39bff36a8b886aa48525a5f6c8ac76cf = $(`&lt;div id=&quot;html_39bff36a8b886aa48525a5f6c8ac76cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_72a625a5cc98fcf7c3228ac8d327b179.setContent(html_39bff36a8b886aa48525a5f6c8ac76cf);
#
#
#
#         marker_8db6ce9be3c7b0c0395c5140e72d374c.bindPopup(popup_72a625a5cc98fcf7c3228ac8d327b179)
#         ;
#
#
#
#
#             var marker_e256b178adb4357516cf4ddbe1299aec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9df6bc3c079d595e3ce0b6091a059b75);
#
#
#         var popup_3a1655a545c8b39d67d7672e5c62a5fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9724a083baf8fbf3edad77639aa23bd = $(`&lt;div id=&quot;html_d9724a083baf8fbf3edad77639aa23bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3a1655a545c8b39d67d7672e5c62a5fb.setContent(html_d9724a083baf8fbf3edad77639aa23bd);
#
#
#
#         marker_e256b178adb4357516cf4ddbe1299aec.bindPopup(popup_3a1655a545c8b39d67d7672e5c62a5fb)
#         ;
#
#
#
#
#             var marker_1c9699617844e796332bd3ccc29d9043 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9df6bc3c079d595e3ce0b6091a059b75);
#
#
#         var popup_e4d8b5bc9b079cbecbaa2610c1afebe1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f2e9a4db486e8bc266bb769a83508b2 = $(`&lt;div id=&quot;html_1f2e9a4db486e8bc266bb769a83508b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e4d8b5bc9b079cbecbaa2610c1afebe1.setContent(html_1f2e9a4db486e8bc266bb769a83508b2);
#
#
#
#         marker_1c9699617844e796332bd3ccc29d9043.bindPopup(popup_e4d8b5bc9b079cbecbaa2610c1afebe1)
#         ;
#
#
#
#
#             var marker_baf65a3b26b6795cf0f0a840774726d3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9df6bc3c079d595e3ce0b6091a059b75);
#
#
#         var popup_9a2dbd264f667ae027cc7c086e8947a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39b9aa7de745b2b3ed0940af23bab20a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39b9aa7de745b2b3ed0940af23bab20a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39b9aa7de745b2b3ed0940af23bab20a = L.map(
#                 &quot;map_39b9aa7de745b2b3ed0940af23bab20a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e14c520089227888afad691141b56e3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e14c520089227888afad691141b56e3e.addTo(map_39b9aa7de745b2b3ed0940af23bab20a);
#
#
#             var feature_group_ca7a80f9aed7978279aac39a20425dcd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ca7a80f9aed7978279aac39a20425dcd.addTo(map_39b9aa7de745b2b3ed0940af23bab20a);
#
#
#             var feature_group_sub_group_2024bbb0f0e9bf73020d0151ec552925 = L.featureGroup.subGroup(
#                 feature_group_ca7a80f9aed7978279aac39a20425dcd
#             );
#
#
#             var marker_c0a443d63c3ff4bf2e73b12cb83e43af = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2024bbb0f0e9bf73020d0151ec552925);
#
#
#         var popup_46cbf792482988a8a0f482ac1a62099b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd04906fae61bffecccb7af1fd152b36 = $(`&lt;div id=&quot;html_fd04906fae61bffecccb7af1fd152b36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_46cbf792482988a8a0f482ac1a62099b.setContent(html_fd04906fae61bffecccb7af1fd152b36);
#
#
#
#         marker_c0a443d63c3ff4bf2e73b12cb83e43af.bindPopup(popup_46cbf792482988a8a0f482ac1a62099b)
#         ;
#
#
#
#
#             var marker_4e177200fdc0465ffff0920baabddc98 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2024bbb0f0e9bf73020d0151ec552925);
#
#
#         var popup_42c8634a57426873d02a448069ce50b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c5faee0c74a6dc35ee3c6d9dfadefc5 = $(`&lt;div id=&quot;html_5c5faee0c74a6dc35ee3c6d9dfadefc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_42c8634a57426873d02a448069ce50b4.setContent(html_5c5faee0c74a6dc35ee3c6d9dfadefc5);
#
#
#
#         marker_4e177200fdc0465ffff0920baabddc98.bindPopup(popup_42c8634a57426873d02a448069ce50b4)
#         ;
#
#
#
#
#             var marker_492274908205d01e3498dc74097b174d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2024bbb0f0e9bf73020d0151ec552925);
#
#
#         var popup_273e3246e813a12dcaa6b794c8f7e912 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55c2b6ea29b97c38fb482aca04abc055 = $(`&lt;div id=&quot;html_55c2b6ea29b97c38fb482aca04abc055&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_273e3246e813a12dcaa6b794c8f7e912.setContent(html_55c2b6ea29b97c38fb482aca04abc055);
#
#
#
#         marker_492274908205d01e3498dc74097b174d.bindPopup(popup_273e3246e813a12dcaa6b794c8f7e912)
#         ;
#
#
#
#
#             var marker_ccf1f723083526dc186dd4faf25e8f0d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2024bbb0f0e9bf73020d0151ec552925);
#
#
#         var popup_c6417577e42e94396cb6fe50dca10ca2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a368e4b9e0e1aadcefff8c721cafff4f = $(`&lt;div id=&quot;html_a368e4b9e0e1aadcefff8c721cafff4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c6417577e42e94396cb6fe50dca10ca2.setContent(html_a368e4b9e0e1aadcefff8c721cafff4f);
#
#
#
#         marker_
