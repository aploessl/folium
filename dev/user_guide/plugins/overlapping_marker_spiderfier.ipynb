# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec2c347176ae26bc450544fcbab40020 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec2c347176ae26bc450544fcbab40020&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec2c347176ae26bc450544fcbab40020 = L.map(
#                 &quot;map_ec2c347176ae26bc450544fcbab40020&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb7c47974966a84e4e091ed45087b2ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb7c47974966a84e4e091ed45087b2ee.addTo(map_ec2c347176ae26bc450544fcbab40020);
#
#
#             var marker_3878958da6c4c7d64210aefce97ed15b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ec2c347176ae26bc450544fcbab40020);
#
#
#         var popup_794f8eff8d25c11e26b211203b57f98c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5d08287e086633a01d96a5c7c15eb69 = $(`&lt;div id=&quot;html_f5d08287e086633a01d96a5c7c15eb69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_794f8eff8d25c11e26b211203b57f98c.setContent(html_f5d08287e086633a01d96a5c7c15eb69);
#
#
#
#         marker_3878958da6c4c7d64210aefce97ed15b.bindPopup(popup_794f8eff8d25c11e26b211203b57f98c)
#         ;
#
#
#
#
#             var marker_5855d8654fbaa4c470d9a9ebae6f9995 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ec2c347176ae26bc450544fcbab40020);
#
#
#         var popup_6fc83d276afba12537fd0e4b8feebfe9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03be1c567c48fbf3d4c8a464e1e9c2ca = $(`&lt;div id=&quot;html_03be1c567c48fbf3d4c8a464e1e9c2ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6fc83d276afba12537fd0e4b8feebfe9.setContent(html_03be1c567c48fbf3d4c8a464e1e9c2ca);
#
#
#
#         marker_5855d8654fbaa4c470d9a9ebae6f9995.bindPopup(popup_6fc83d276afba12537fd0e4b8feebfe9)
#         ;
#
#
#
#
#             var marker_564d6c0930ab528f6fc49a97fb98face = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ec2c347176ae26bc450544fcbab40020);
#
#
#         var popup_28827bb04b8cc798d28eb9141c6397e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18aa69d62b33ded45b21e36ebe008085 = $(`&lt;div id=&quot;html_18aa69d62b33ded45b21e36ebe008085&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_28827bb04b8cc798d28eb9141c6397e9.setContent(html_18aa69d62b33ded45b21e36ebe008085);
#
#
#
#         marker_564d6c0930ab528f6fc49a97fb98face.bindPopup(popup_28827bb04b8cc798d28eb9141c6397e9)
#         ;
#
#
#
#
#             var marker_ebe21d3a6c28d251bae96ca4472e1adc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ec2c347176ae26bc450544fcbab40020);
#
#
#         var popup_76d8ef2031a03ee6efb4d47bfc4e1547 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_363c924187927f99ce0effee41040f45 = $(`&lt;div id=&quot;html_363c924187927f99ce0effee41040f45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_76d8ef2031a03ee6efb4d47bfc4e1547.setContent(html_363c924187927f99ce0effee41040f45);
#
#
#
#         marker_ebe21d3a6c28d251bae96ca4472e1adc.bindPopup(popup_76d8ef2031a03ee6efb4d47bfc4e1547)
#         ;
#
#
#
#
#             var marker_f601de947efed1a4b30e52659bd678e3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ec2c347176ae26bc450544fcbab40020);
#
#
#         var popup_eafddec5a14d81b0da7d8d453cb762c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5fd3a66b2901e5efb0eaa0854562ba5 = $(`&lt;div id=&quot;html_c5fd3a66b2901e5efb0eaa0854562ba5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_eafddec5a14d81b0da7d8d453cb762c8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_daba1c0ad592943a226f6c12f138eab0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_daba1c0ad592943a226f6c12f138eab0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_daba1c0ad592943a226f6c12f138eab0 = L.map(
#                 &quot;map_daba1c0ad592943a226f6c12f138eab0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec32297380f806ed80aaaf93fbf08b6d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec32297380f806ed80aaaf93fbf08b6d.addTo(map_daba1c0ad592943a226f6c12f138eab0);
#
#
#             var feature_group_95905fb00ff7765f5012872ac3e46fb5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3d0f49529a2c08aabb79182ef1258acd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_95905fb00ff7765f5012872ac3e46fb5);
#
#
#         var popup_21ab2abc905729bb807f2bc768f101b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4be5416ee35e40d7c9b12d2cb0ddaf29 = $(`&lt;div id=&quot;html_4be5416ee35e40d7c9b12d2cb0ddaf29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_21ab2abc905729bb807f2bc768f101b8.setContent(html_4be5416ee35e40d7c9b12d2cb0ddaf29);
#
#
#
#         marker_3d0f49529a2c08aabb79182ef1258acd.bindPopup(popup_21ab2abc905729bb807f2bc768f101b8)
#         ;
#
#
#
#
#             var marker_acd1d41feead9bf36d55e220fca5c2a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_95905fb00ff7765f5012872ac3e46fb5);
#
#
#         var popup_039f12a746d90cde430446f099336857 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93c12f7c02c11f63a5347af55ce5c244 = $(`&lt;div id=&quot;html_93c12f7c02c11f63a5347af55ce5c244&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_039f12a746d90cde430446f099336857.setContent(html_93c12f7c02c11f63a5347af55ce5c244);
#
#
#
#         marker_acd1d41feead9bf36d55e220fca5c2a6.bindPopup(popup_039f12a746d90cde430446f099336857)
#         ;
#
#
#
#
#             var marker_0de3cea62bd86673e4fd92a55028e4c1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_95905fb00ff7765f5012872ac3e46fb5);
#
#
#         var popup_2de4d24c111272216f6b8c2c73c3fa81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c3c3246a01d37f786d3a38af5252f68 = $(`&lt;div id=&quot;html_4c3c3246a01d37f786d3a38af5252f68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2de4d24c111272216f6b8c2c73c3fa81.setContent(html_4c3c3246a01d37f786d3a38af5252f68);
#
#
#
#         marker_0de3cea62bd86673e4fd92a55028e4c1.bindPopup(popup_2de4d24c111272216f6b8c2c73c3fa81)
#         ;
#
#
#
#
#             var marker_90ea42ce8e07fab6e9efa4230048e060 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_95905fb00ff7765f5012872ac3e46fb5);
#
#
#         var popup_c04fc2f6907c1ad4053f38cc49ae16b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1c9847a8423957875e765b0530318b1 = $(`&lt;div id=&quot;html_b1c9847a8423957875e765b0530318b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c04fc2f6907c1ad4053f38cc49ae16b9.setContent(html_b1c9847a8423957875e765b0530318b1);
#
#
#
#         marker_90ea42ce8e07fab6e9efa4230048e060.bindPopup(popup_c04fc2f6907c1ad4053f38cc49ae16b9)
#         ;
#
#
#
#
#             var marker_ea5eaa7eb72505a25802d534077f5a87 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_95905fb00ff7765f5012872ac3e46fb5);
#
#
#         var popup_0eeaf311cff728c749b82a786993629f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_622679704d5717187ef52ebaf638df7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_622679704d5717187ef52ebaf638df7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_622679704d5717187ef52ebaf638df7b = L.map(
#                 &quot;map_622679704d5717187ef52ebaf638df7b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf2215f7efcd8ec601032864bd5b89f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cf2215f7efcd8ec601032864bd5b89f2.addTo(map_622679704d5717187ef52ebaf638df7b);
#
#
#             var feature_group_0dff51837ac817bc52a114d00fd5e1f8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0dff51837ac817bc52a114d00fd5e1f8.addTo(map_622679704d5717187ef52ebaf638df7b);
#
#
#             var feature_group_sub_group_d94fd629406aa56726aa0c333e7b8ca4 = L.featureGroup.subGroup(
#                 feature_group_0dff51837ac817bc52a114d00fd5e1f8
#             );
#
#
#             var marker_1d0476c9792bca99b2c90859f25be329 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d94fd629406aa56726aa0c333e7b8ca4);
#
#
#         var popup_afed74abb2c9f4cf7f8a8d1b2cfbca28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cfcef5612055cdefae694735560b3c0 = $(`&lt;div id=&quot;html_1cfcef5612055cdefae694735560b3c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_afed74abb2c9f4cf7f8a8d1b2cfbca28.setContent(html_1cfcef5612055cdefae694735560b3c0);
#
#
#
#         marker_1d0476c9792bca99b2c90859f25be329.bindPopup(popup_afed74abb2c9f4cf7f8a8d1b2cfbca28)
#         ;
#
#
#
#
#             var marker_e2b207bdfce6cace1cd460ee310ff1d7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d94fd629406aa56726aa0c333e7b8ca4);
#
#
#         var popup_31c25b56381a9ba69351a1f3814216db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fffe7dcc4bcf09d2a3d7be670b7d28d0 = $(`&lt;div id=&quot;html_fffe7dcc4bcf09d2a3d7be670b7d28d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_31c25b56381a9ba69351a1f3814216db.setContent(html_fffe7dcc4bcf09d2a3d7be670b7d28d0);
#
#
#
#         marker_e2b207bdfce6cace1cd460ee310ff1d7.bindPopup(popup_31c25b56381a9ba69351a1f3814216db)
#         ;
#
#
#
#
#             var marker_62ca2e9d44b5de29ff2d54b718342a6f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d94fd629406aa56726aa0c333e7b8ca4);
#
#
#         var popup_e79f9f39a218653d2da8841c7037f1cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae71abd505140b015b3065799fe8bcba = $(`&lt;div id=&quot;html_ae71abd505140b015b3065799fe8bcba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e79f9f39a218653d2da8841c7037f1cb.setContent(html_ae71abd505140b015b3065799fe8bcba);
#
#
#
#         marker_62ca2e9d44b5de29ff2d54b718342a6f.bindPopup(popup_e79f9f39a218653d2da8841c7037f1cb)
#         ;
#
#
#
#
#             var marker_4b9d66ef63885fb0cbeb955a3cb21e07 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d94fd629406aa56726aa0c333e7b8ca4);
#
#
#         var popup_8b2de6b324c56d4d6dc39a66d5f22a72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d605156765e3d869cf7e2b20afd51ada = $(`&lt;div id=&quot;html_d605156765e3d869cf7e2b20afd51ada&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8b2de6b324c56d4d6dc39a66d5f22a72.setContent(html_d605156765e3d869cf7e2b20afd51ada);
#
#
#
#         marker_
