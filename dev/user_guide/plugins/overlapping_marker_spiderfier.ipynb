# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9eda256b6b9c92bc18e9e32a87e5b29a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9eda256b6b9c92bc18e9e32a87e5b29a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9eda256b6b9c92bc18e9e32a87e5b29a = L.map(
#                 &quot;map_9eda256b6b9c92bc18e9e32a87e5b29a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58fe6a3c5da119f68976606521ad50e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_58fe6a3c5da119f68976606521ad50e3.addTo(map_9eda256b6b9c92bc18e9e32a87e5b29a);
#
#
#             var marker_157d401a302d4fe11a99925a1f688579 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9eda256b6b9c92bc18e9e32a87e5b29a);
#
#
#         var popup_2ffbd9325058371dc058f99fab8bdc14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c016ba9fc3e66c31c999a34881a42eb = $(`&lt;div id=&quot;html_0c016ba9fc3e66c31c999a34881a42eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2ffbd9325058371dc058f99fab8bdc14.setContent(html_0c016ba9fc3e66c31c999a34881a42eb);
#
#
#
#         marker_157d401a302d4fe11a99925a1f688579.bindPopup(popup_2ffbd9325058371dc058f99fab8bdc14)
#         ;
#
#
#
#
#             var marker_454a32854e1dd119f072de901239a93c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9eda256b6b9c92bc18e9e32a87e5b29a);
#
#
#         var popup_ee6b7775fd5e1caccb8e411625f1731a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a1b903d0e4a6247cc954faaa9969f16 = $(`&lt;div id=&quot;html_1a1b903d0e4a6247cc954faaa9969f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ee6b7775fd5e1caccb8e411625f1731a.setContent(html_1a1b903d0e4a6247cc954faaa9969f16);
#
#
#
#         marker_454a32854e1dd119f072de901239a93c.bindPopup(popup_ee6b7775fd5e1caccb8e411625f1731a)
#         ;
#
#
#
#
#             var marker_722bdaaadd3ec215b818937748379337 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9eda256b6b9c92bc18e9e32a87e5b29a);
#
#
#         var popup_9a3ff17d8f04b590ca7923b74e84d476 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_153611045b455a55beecd7dfe5b53f5b = $(`&lt;div id=&quot;html_153611045b455a55beecd7dfe5b53f5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9a3ff17d8f04b590ca7923b74e84d476.setContent(html_153611045b455a55beecd7dfe5b53f5b);
#
#
#
#         marker_722bdaaadd3ec215b818937748379337.bindPopup(popup_9a3ff17d8f04b590ca7923b74e84d476)
#         ;
#
#
#
#
#             var marker_f98b1d8f3e9cfc3e8d9a8df6d6435fe7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9eda256b6b9c92bc18e9e32a87e5b29a);
#
#
#         var popup_b4bbedf625948d41c00ceaf4b8632365 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f76b9cff533dc79f781f7db71099dc9 = $(`&lt;div id=&quot;html_9f76b9cff533dc79f781f7db71099dc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b4bbedf625948d41c00ceaf4b8632365.setContent(html_9f76b9cff533dc79f781f7db71099dc9);
#
#
#
#         marker_f98b1d8f3e9cfc3e8d9a8df6d6435fe7.bindPopup(popup_b4bbedf625948d41c00ceaf4b8632365)
#         ;
#
#
#
#
#             var marker_a3096ce5613dd8401f284925335d4b61 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9eda256b6b9c92bc18e9e32a87e5b29a);
#
#
#         var popup_b2c2a926070f38382655e2384705c922 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b658d21ba21fb1cb194c2d51b4da2d02 = $(`&lt;div id=&quot;html_b658d21ba21fb1cb194c2d51b4da2d02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b2c2a926070f38382655e2384705c922.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb4ee37efe25e31380a3d3ee5a34dccf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb4ee37efe25e31380a3d3ee5a34dccf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb4ee37efe25e31380a3d3ee5a34dccf = L.map(
#                 &quot;map_cb4ee37efe25e31380a3d3ee5a34dccf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ccebd2286656a065876f13a8a39c165 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ccebd2286656a065876f13a8a39c165.addTo(map_cb4ee37efe25e31380a3d3ee5a34dccf);
#
#
#             var feature_group_eb73e4c3288b9eca169877510bd87931 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0a4088d700c4fd3f68a4dd4518a35c5e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_eb73e4c3288b9eca169877510bd87931);
#
#
#         var popup_8368b0b57dec2036d26e9d17f1824b8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a3a05db68af3a67c895072395c97b53 = $(`&lt;div id=&quot;html_7a3a05db68af3a67c895072395c97b53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8368b0b57dec2036d26e9d17f1824b8a.setContent(html_7a3a05db68af3a67c895072395c97b53);
#
#
#
#         marker_0a4088d700c4fd3f68a4dd4518a35c5e.bindPopup(popup_8368b0b57dec2036d26e9d17f1824b8a)
#         ;
#
#
#
#
#             var marker_c0a6f5f115c72bb9162df367b71edd72 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_eb73e4c3288b9eca169877510bd87931);
#
#
#         var popup_773f7e15bf942304ef6d9c927654ec93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fb83fbbafaeafce0b9bdda02ab19fc4 = $(`&lt;div id=&quot;html_3fb83fbbafaeafce0b9bdda02ab19fc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_773f7e15bf942304ef6d9c927654ec93.setContent(html_3fb83fbbafaeafce0b9bdda02ab19fc4);
#
#
#
#         marker_c0a6f5f115c72bb9162df367b71edd72.bindPopup(popup_773f7e15bf942304ef6d9c927654ec93)
#         ;
#
#
#
#
#             var marker_756fd4eaffb13d4082af8e6ff14c53cf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_eb73e4c3288b9eca169877510bd87931);
#
#
#         var popup_f07673c556acd922190a721e2d4084b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2986aa60031801fdb55f452547e95ff2 = $(`&lt;div id=&quot;html_2986aa60031801fdb55f452547e95ff2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f07673c556acd922190a721e2d4084b3.setContent(html_2986aa60031801fdb55f452547e95ff2);
#
#
#
#         marker_756fd4eaffb13d4082af8e6ff14c53cf.bindPopup(popup_f07673c556acd922190a721e2d4084b3)
#         ;
#
#
#
#
#             var marker_d61a75652d675aad216c98fb40ae6636 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_eb73e4c3288b9eca169877510bd87931);
#
#
#         var popup_e0aea57b1b7ee4e9608316e10d5b1db2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e41c3f4b9c3a61a152d33f663420c665 = $(`&lt;div id=&quot;html_e41c3f4b9c3a61a152d33f663420c665&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e0aea57b1b7ee4e9608316e10d5b1db2.setContent(html_e41c3f4b9c3a61a152d33f663420c665);
#
#
#
#         marker_d61a75652d675aad216c98fb40ae6636.bindPopup(popup_e0aea57b1b7ee4e9608316e10d5b1db2)
#         ;
#
#
#
#
#             var marker_5fa873b7a30dd749fced51650d4749d1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_eb73e4c3288b9eca169877510bd87931);
#
#
#         var popup_88e3d68d78a1823af5c1a2884c837553 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11502d47938544e8cd83b18e1c9713fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11502d47938544e8cd83b18e1c9713fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11502d47938544e8cd83b18e1c9713fa = L.map(
#                 &quot;map_11502d47938544e8cd83b18e1c9713fa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6088b011ff216f97cde362b683975df4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6088b011ff216f97cde362b683975df4.addTo(map_11502d47938544e8cd83b18e1c9713fa);
#
#
#             var feature_group_1dc23cda136b4661df49bf740f57ec9c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1dc23cda136b4661df49bf740f57ec9c.addTo(map_11502d47938544e8cd83b18e1c9713fa);
#
#
#             var feature_group_sub_group_ff11ef1dd222e1ed31aeee4c461c0530 = L.featureGroup.subGroup(
#                 feature_group_1dc23cda136b4661df49bf740f57ec9c
#             );
#
#
#             var marker_41e17da40a8219b1041eec403ecc12cd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ff11ef1dd222e1ed31aeee4c461c0530);
#
#
#         var popup_8046f27a6bc85c07c8812817644dc792 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33f3773a61dd4defb2b382ad6547576c = $(`&lt;div id=&quot;html_33f3773a61dd4defb2b382ad6547576c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8046f27a6bc85c07c8812817644dc792.setContent(html_33f3773a61dd4defb2b382ad6547576c);
#
#
#
#         marker_41e17da40a8219b1041eec403ecc12cd.bindPopup(popup_8046f27a6bc85c07c8812817644dc792)
#         ;
#
#
#
#
#             var marker_654c3ccbf5e7ecda4d4dc7e0fb25123e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ff11ef1dd222e1ed31aeee4c461c0530);
#
#
#         var popup_409ae52f3bab6e4f878954356b410ad7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdad04caac789ec79d5623b53be47d47 = $(`&lt;div id=&quot;html_fdad04caac789ec79d5623b53be47d47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_409ae52f3bab6e4f878954356b410ad7.setContent(html_fdad04caac789ec79d5623b53be47d47);
#
#
#
#         marker_654c3ccbf5e7ecda4d4dc7e0fb25123e.bindPopup(popup_409ae52f3bab6e4f878954356b410ad7)
#         ;
#
#
#
#
#             var marker_4a117c34297de4462a508ef657596719 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ff11ef1dd222e1ed31aeee4c461c0530);
#
#
#         var popup_61e3898784852546dbba770909c28414 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db3877d533f32e8228218590005d881d = $(`&lt;div id=&quot;html_db3877d533f32e8228218590005d881d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_61e3898784852546dbba770909c28414.setContent(html_db3877d533f32e8228218590005d881d);
#
#
#
#         marker_4a117c34297de4462a508ef657596719.bindPopup(popup_61e3898784852546dbba770909c28414)
#         ;
#
#
#
#
#             var marker_7c07e1032df0a3188df85c420547ad6b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ff11ef1dd222e1ed31aeee4c461c0530);
#
#
#         var popup_08d5b8297aabbf51ecaffc69c33eda6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d6732122ce4d335d9b3400f9b9b8bf8 = $(`&lt;div id=&quot;html_6d6732122ce4d335d9b3400f9b9b8bf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_08d5b8297aabbf51ecaffc69c33eda6b.setContent(html_6d6732122ce4d335d9b3400f9b9b8bf8);
#
#
#
#         marker_
